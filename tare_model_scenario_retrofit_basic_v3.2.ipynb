# %%
# pd.set_option("display.max_columns", None)
# pd.reset_option('display.max_columns')
# pd.set_option('display.max_rows', None)
# pd.reset_option('display.max_rows')

# %% [markdown]
# # Baseline Scenario

# %%
import os

# Measure Package 0: Baseline
menu_mp = 0
input_mp = 'baseline'

# Get the current working directory of the project
project_root = os.path.abspath(os.getcwd())
print(f"Project root directory: {project_root}")

# Relative path to the file from the project root
relative_path = r"tare_model_scenario_baseline_v3.2.ipynb"

# Construct the absolute path to the file
file_path = os.path.join(project_root, relative_path)
print(f"File path: {file_path}")

# Run the notebook and import variables
if os.path.exists(relative_path):
    get_ipython().run_line_magic('run', f'-i "{relative_path}"')
    print("Baseline Scenario - Model Run Complete")
else:
    print(f"File not found: {relative_path}")
# Out:
# Project root directory: c:\Users\14128\Research\cmu-tare-model
# File path: c:\Users\14128\Research\cmu-tare-model\tare_model_scenario_baseline_v3.2.ipynb
# Project root directory: c:\Users\14128\Research\cmu-tare-model
# File path: c:\Users\14128\Research\cmu-tare-model\tare_model_functions_v3.3.ipynb
# Loaded All TARE Model Functions
# Result outputs will be exported here: c:\Users\14128\Research\cmu-tare-model\output_results
#
# -------------------------------------------------------------------------------------------------------
# Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
# Let's start by reading the data from the NREL EUSS Database.
#
# Make sure that the zipped folders stay organized as they are once unzipped.
# If changes are made to the file path, then the program will not run properly.
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# BASELINE (Measure Package 0)
# -------------------------------------------------------------------------------------------------------
#
# Retrieved data for filename: baseline_metadata_and_annual_results.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\euss_data\resstock_amy2018_release_1.1\state\baseline_metadata_and_annual_results.csv
#
# -------------------------------------------------------------------------------------------------------
# Data Filters: Only occupied units and Single Family Homes
# -------------------------------------------------------------------------------------------------------
#
# You chose to analyze all of the United States.
# Retrieved data for filename: aeo_projections_2022_2050.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\aeo_projections_2022_2050.xlsx
#
# -------------------------------------------------------------------------------------------------------
# Baseline Consumption:
# -------------------------------------------------------------------------------------------------------
#
# Processing column: in.clothes_dryer
# Initial data types: object
# Data types after processing: object
# Processing column: in.cooking_range
# Initial data types: object
# Data types after processing: object
# 331531 rows remain after applying total heating consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 321357 rows remain after applying heating fuel filter
# Filtered for the following Heating technologies: ['Electricity ASHP', 'Electricity Baseboard', 'Electricity Electric Boiler', 'Electricity Electric Furnace', 'Fuel Oil Fuel Boiler', 'Fuel Oil Fuel Furnace', 'Natural Gas Fuel Boiler', 'Natural Gas Fuel Furnace', 'Propane Fuel Boiler', 'Propane Fuel Furnace']
# 291558 rows remain after applying heating technology filter
# 291558 rows remain after applying total waterHeating consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 291191 rows remain after applying waterHeating fuel filter
# Filtered for the following Water Heating technologies: ['Electric Heat Pump, 80 gal', 'Electric Premium', 'Electric Standard', 'Fuel Oil Premium', 'Fuel Oil Standard', 'Natural Gas Premium', 'Natural Gas Standard', 'Propane Premium', 'Propane Standard']
# 284744 rows remain after applying waterHeating technology filter
# 284744 rows remain after applying total clothesDrying consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 272458 rows remain after applying clothesDrying fuel filter
# 272458 rows remain after applying total cooking consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 270018 rows remain after applying cooking fuel filter
# Projecting Future Energy Consumption (Baseline Equipment): heating
# Projecting Future Energy Consumption (Baseline Equipment): waterHeating
# Projecting Future Energy Consumption (Baseline Equipment): clothesDrying
# Projecting Future Energy Consumption (Baseline Equipment): cooking
#
# -------------------------------------------------------------------------------------------------------
# Public Perspective: Monetized Marginal Damages from Emissions
# -------------------------------------------------------------------------------------------------------
# Step 1: Calculate emissions factors for different fuel sources
# - Electricity
# - Natural Gas
# - Fuel Oil
# - Propane
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
# Calculate Emissions Factors: ELECTRICITY
# -------------------------------------------------------------------------------------------------------
# Electricity Marginal Emissions Factors:
# - STATE Regional Aggregation is what is used in the Parth Analysis
# - "Marginal Emissions Factors for Electricity"
# - Factor Type: Marginal
# - Calculation Method: Regression
# - Metric: Emissions [kg/MWh]
# - Predictor: Year")
# - Pollutants: SO2, NOx, PM2.5, CO2
# -------------------------------------------------------------------------------------------------------
#
# Retrieved data for filename: Generation-MARREG-EMIT-state-byYear.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\margEmis_electricity\Generation-MARREG-EMIT-state-byYear.csv
#
#
#
# -------------------------------------------------------------------------------------------------------
# Calculate Emissions Factors: FOSSIL FUELS
# -------------------------------------------------------------------------------------------------------
# Fossil Fuels (Natural Gas, Fuel Oil, Propane):
# - NOx, SO2, CO2:
#     - RESNET Table 7.1.2 Emissions Factors for Household Combustion Fuels
#     - Source: https://www.resnet.us/wp-content/uploads/ANSIRESNETICC301-2022_resnetpblshd.pdf
#     - All factors are in units of lb/Mbtu so energy consumption in kWh need to be converted to kWh
#     - (1 lb / Mbtu) * (1 Mbtu / 1x10^6 Btu) * (3412 Btu / 1 kWh)
# - PM2.5:
#     - A National Methodology and Emission Inventory for Residential Fuel Combustion
#     - Source: https://www3.epa.gov/ttnchie1/conference/ei12/area/haneke.pdf
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
# Step 2: Adjust Natural Gas & Electricity Emissions Factors for Natural Gas Leakage
# -------------------------------------------------------------------------------------------------------
# Natural Gas (Deetjen et al.):
# "To account for the natural gas infrastructure's leakage of the greenhouse gas methane,
# we estimate the amount of methane leaked per therm of natural gas consumed for heating and
# convert to CO2-equivalent emissions via the GWP of methane. We assume that for every therm of
# natural gas consumed for heating, 0.023 therms of methane escape to the atmosphere [28].
# Using the energy density of natural gas, we convert from therms to kilograms and multiply
# by 28—the GWP of methane [29]—to calculate a rate of 1.27 kg CO2-equivalent per therm of
# consumed natural gas."
#
# Electricity NERC Regions (Deetjen et al):
# "To account for the natural gas infrastructure's leakage of the greenhouse gas methane,
# we estimate the amount of methane leaked per MWh of electricity generation in each NERC
# region and convert to CO2-equivalent emissions via the global warming potential (GWP) of methane.
# For example, we find that in 2017, the states comprising the western region (WECC) of
# the US electric grid consumed 1.45 million MMcf of natural gas in the power sector [27].
# We assume that for every MMcf of consumed natural gas, 0.023 MMcf of methane is leaked into
# the atmosphere [28]. By multiplying that leakage rate by the 1.45 million MMcf of consumed
# natural gas, converting to tonnes, and multiplying by a GWP of 28 [29], we estimate
# that the 2017 WECC power sector contributed to methane leakage amounting to 18.6 Mt CO2-equivalent.
# By dividing this 18.6 Mt by the 724 TWh of the WECC states' generated electricity [27], we
# calculate a methane leakage rate factor of 25.7 kg MWh−1. In the same manner, we calculate the
# methane leakage rate factors for the other NERC regions. We use the 100 years GWP value of 28
# for methane. Although there have been proposals to use 20 years GWP values, recent research
# shows that the benefits of this alternative 20 years time from are overstated [30]."
# -------------------------------------------------------------------------------------------------------
#
# Retrieved data for filename: natural_gas_leakage_rate.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\margEmis_electricity\natural_gas_leakage_rate.csv
#
#
# You chose to analyze all of the United States.
# Retrieved data for filename: easiur_National2024-06-1421-22.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\margDamages_EASIUR\easiur_batchConversion_download\easiur_National2024-06-1421-22.csv
#
#
# Retrieved data for filename: bls_cpiu_2005-2023.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\inflation_data\bls_cpiu_2005-2023.xlsx
# Retrieved data for filename: Generation-MARREG-DAMEASIUR-egrid-byYear_climate2006.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\margDamages_EASIUR\Generation-MARREG-DAMEASIUR-egrid-byYear_climate2006.csv
# Retrieved data for filename: Generation-MARREG-DAMEASIUR-egrid-byYear_climate2018.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\margDamages_EASIUR\Generation-MARREG-DAMEASIUR-egrid-byYear_climate2018.csv
# Retrieved data for filename: Generation-MARREG-DAMEASIUR-egrid-byYear_health2018.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\margDamages_EASIUR\Generation-MARREG-DAMEASIUR-egrid-byYear_health2018.csv
# C:\Users\14128\AppData\Local\Temp\ipykernel_4804\2680213165.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_margDamages_gridDecarb[column_name] = None
# -------------------------------------------------------------------------------------------------------
# Calculate Emissions Factors: FOSSIL FUELS
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
# Step 5: Calculate End-use specific marginal damages
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# Baseline Marginal Damages: WHOLE-HOME
# -------------------------------------------------------------------------------------------------------
#
csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\equity_data\nhgis0003_ds261_2022_puma.csv
#
#
# Retrieved data for filename: rsMeans_cityCostIndex.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\inflation_data\rsMeans_cityCostIndex.csv
#
#
# The code took 8 minutes and 50 seconds to execute.
# Baseline Scenario - Model Run Complete

# %% [markdown]
# # Basic Retrofit: Pre-IRA

# %% [markdown]
# ## Dataframe for Electric Resistance Cooking (MP7)

# %%
print(f"""
-------------------------------------------------------------------------------------------------------
We assume the use of Electric Resistance (MP7) rather than Induction (MP8).
Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
-------------------------------------------------------------------------------------------------------
""")

# Measure Package 7
menu_mp = 7
input_mp = 'upgrade07'

filename = "upgrade07_metadata_and_annual_results.csv"
relative_path = os.path.join(r"euss_data\\resstock_amy2018_release_1.1\\state", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

# Fix DtypeWarning error in columns 'in.neighbors' and 'in.geometry_stories_low_rise'
columns_to_string = {11: str, 61: str, 121: str, 103: str, 128: str, 129: str}
df_euss_am_mp7 = pd.read_csv(file_path, dtype=columns_to_string)
occupancy_filter = df_euss_am_mp7['in.vacancy_status'] == 'Occupied'
df_euss_am_mp7 = df_euss_am_mp7.loc[occupancy_filter]

# Filter for single family home building type
house_type_list = ['Single-Family Attached', 'Single-Family Detached']
house_type_filter = df_euss_am_mp7['in.geometry_building_type_recs'].isin(house_type_list)
df_euss_am_mp7 = df_euss_am_mp7.loc[house_type_filter]
# Out:
# -------------------------------------------------------------------------------------------------------
# We assume the use of Electric Resistance (MP7) rather than Induction (MP8).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# -------------------------------------------------------------------------------------------------------
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\euss_data\\resstock_amy2018_release_1.1\\state\upgrade07_metadata_and_annual_results.csv

# %%
# National Level 
if menu_state == 'N':
    print("You chose to analyze all of the United States.")
    input_state = 'National'

# Filter down to state or city
else:
    print(f"You chose to filter for: {input_state}")
    state_filter = df_euss_am_mp7['in.state'].eq(input_state)
    df_euss_am_mp7 = df_euss_am_mp7.loc[state_filter]

    # Filter for the entire selected state
    if menu_city == 'N':
        print(f"You chose to analyze all of state: {input_state}")
        
    # Filter to a city within the selected state
    else:
        print(f"You chose to filter for: {input_state}, {input_cityFilter}")
        city_filter = df_euss_am_mp7['in.city'].eq(f"{input_state}, {input_cityFilter}")
        df_euss_am_mp7 = df_euss_am_mp7.loc[city_filter]

# Display the filtered dataframe
df_euss_am_mp7
# Out:
# You chose to analyze all of the United States.
#         bldg_id  upgrade      weight  applicability  in.sqft  \
# 2           239        7  242.131013           True   1690.0
# 3           273        7  242.131013          False   1690.0
# 4           307        7  242.131013          False   1220.0
# 5           409        7  242.131013           True   1220.0
# 7           517        7  242.131013          False   1220.0
# ...         ...      ...         ...            ...      ...
# 548907   548226        7  242.131013           True   2176.0
# 548908   548228        7  242.131013           True   1690.0
# 548910   548417        7  242.131013           True    885.0
# 548914   549740        7  242.131013           True   1220.0
# 548915   549938        7  242.131013           True    885.0
#
#                       in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# 2       Non-CBSA East South Central                               3A
# 3       Non-CBSA East South Central                               3A
# 4       Non-CBSA East South Central                               3A
# 5       Non-CBSA East South Central                               3A
# 7       Non-CBSA East South Central                               3A
# ...                             ...                              ...
# 548907            Non-CBSA Mountain                               6B
# 548908            Non-CBSA Mountain                               6B
# 548910            Non-CBSA Mountain                               6B
# 548914            Non-CBSA Mountain                               7B
# 548915            Non-CBSA Mountain                               6B
#
#        in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# 2                                              3A                     Hour20
# 3                                              3A                     Hour12
# 4                                              3A                      Hour0
# 5                                              3A                     Hour20
# 7                                              3A                      Hour1
# ...                                           ...                        ...
# 548907                                         6B                      Hour3
# 548908                                         6B                      Hour6
# 548910                                         6B                     Hour18
# 548914                                         7B                      Hour4
# 548915                                         6B                      Hour2
#
#         in.bedrooms  ...  \
# 2                 3  ...
# 3                 3  ...
# 4                 4  ...
# 5                 2  ...
# 7                 3  ...
# ...             ...  ...
# 548907            4  ...
# 548908            4  ...
# 548910            2  ...
# 548914            2  ...
# 548915            2  ...
#
#        out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# 2                                                0.000000
# 3                                                0.000000
# 4                                                0.000000
# 5                                                0.000000
# 7                                                0.000000
# ...                                                   ...
# 548907                                           0.000000
# 548908                                           0.000000
# 548910                                           0.000000
# 548914                                         268.627834
# 548915                                           0.000000
#
#        out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# 2                                              142.374480
# 3                                                0.000000
# 4                                                0.000000
# 5                                             1439.855043
# 7                                                0.000000
# ...                                                   ...
# 548907                                        8790.508547
# 548908                                        5124.531468
# 548910                                        3748.197047
# 548914                                         152.327658
# 548915                                        7833.858198
#
#        out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# 2                                               75.157988
# 3                                                0.000000
# 4                                                0.000000
# 5                                             1235.288966
# 7                                                0.000000
# ...                                                   ...
# 548907                                        9652.472396
# 548908                                        5456.571515
# 548910                                        3986.523550
# 548914                                         178.841946
# 548915                                        8061.021339
#
#        out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# 2                                               91.998512
# 3                                                0.000000
# 4                                                0.000000
# 5                                             1299.421938
# 7                                                0.000000
# ...                                                   ...
# 548907                                       10147.078588
# 548908                                        5713.602807
# 548910                                        4071.210606
# 548914                                         198.041150
# 548915                                        8199.976187
#
#        out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# 2                                               19.421011
# 3                                                0.000000
# 4                                                0.000000
# 5                                             1129.822844
# 7                                                0.000000
# ...                                                   ...
# 548907                                        5326.981989
# 548908                                        3463.786920
# 548910                                        3004.825830
# 548914                                          75.301777
# 548915                                        6852.064771
#
#        upgrade.clothes_dryer upgrade.cooking_range  \
# 2                        NaN  Electric, 100% Usage
# 3                        NaN                   NaN
# 4                        NaN                   NaN
# 5                        NaN  Electric, 120% Usage
# 7                        NaN                   NaN
# ...                      ...                   ...
# 548907                   NaN                   NaN
# 548908                   NaN                   NaN
# 548910                   NaN                   NaN
# 548914                   NaN  Electric, 120% Usage
# 548915                   NaN   Electric, 80% Usage
#
#        upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# 5                            Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 7                                  NaN                                NaN
# ...                                ...                                ...
# 548907                       Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 548908                       Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 548910                       Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 548914                             NaN                                NaN
# 548915                       Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
#
#              upgrade.water_heater_efficiency
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5       Electric Heat Pump, 50 gal, 3.45 UEF
# 7                                        NaN
# ...                                      ...
# 548907  Electric Heat Pump, 66 gal, 3.35 UEF
# 548908  Electric Heat Pump, 66 gal, 3.35 UEF
# 548910  Electric Heat Pump, 50 gal, 3.45 UEF
# 548914                                   NaN
# 548915  Electric Heat Pump, 50 gal, 3.45 UEF
#
# [331531 rows x 347 columns]

# %% [markdown]
# ## Dataframe used for other end-uses (MP8)

# %%
# Measure Package 8
menu_mp = 8
input_mp = 'upgrade08'
scenario_name = 'Basic-BAU'
cost_scenario = 'BAU Costs'
grid_scenario = 'Current Electricity Grid'

print(f"""
-------------------------------------------------------------------------------------------------------
MODEL SCENARIO
-------------------------------------------------------------------------------------------------------
Scenario {scenario_name}:
Basic Retrofit: Measure Package {menu_mp}
{cost_scenario}
{grid_scenario}
-------------------------------------------------------------------------------------------------------
""")

filename = "upgrade08_metadata_and_annual_results.csv"
relative_path = os.path.join(r"euss_data\\resstock_amy2018_release_1.1\\state", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

# Fix DtypeWarning error in columns 'in.neighbors' and 'in.geometry_stories_low_rise'
columns_to_string = {11: str, 61: str, 121: str, 103: str, 128: str, 129: str}
df_euss_am_mp8 = pd.read_csv(file_path, dtype=columns_to_string)
occupancy_filter = df_euss_am_mp8['in.vacancy_status'] == 'Occupied'
df_euss_am_mp8 = df_euss_am_mp8.loc[occupancy_filter]

# Filter for single family home building type
house_type_list = ['Single-Family Attached', 'Single-Family Detached']
house_type_filter = df_euss_am_mp8['in.geometry_building_type_recs'].isin(house_type_list)
df_euss_am_mp8 = df_euss_am_mp8.loc[house_type_filter]
# df_euss_am_mp8
# Out:
# -------------------------------------------------------------------------------------------------------
# MODEL SCENARIO
# -------------------------------------------------------------------------------------------------------
# Scenario Basic-BAU:
# Basic Retrofit: Measure Package 8
# BAU Costs
# Current Electricity Grid
# -------------------------------------------------------------------------------------------------------
#
# Retrieved data for filename: upgrade08_metadata_and_annual_results.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\euss_data\\resstock_amy2018_release_1.1\\state\upgrade08_metadata_and_annual_results.csv

# %%
# National Level 
if menu_state == 'N':
    print("You chose to analyze all of the United States.")
    input_state = 'National'

# Filter down to state or city
else:
    print(f"You chose to filter for: {input_state}")
    state_filter = df_euss_am_mp8['in.state'].eq(input_state)
    df_euss_am_mp8 = df_euss_am_mp8.loc[state_filter]

    # Filter for the entire selected state
    if menu_city == 'N':
        print(f"You chose to analyze all of state: {input_state}")
        
    # Filter to a city within the selected state
    else:
        print(f"You chose to filter for: {input_state}, {input_cityFilter}")
        city_filter = df_euss_am_mp8['in.city'].eq(f"{input_state}, {input_cityFilter}")
        df_euss_am_mp8 = df_euss_am_mp8.loc[city_filter]

# Display the filtered dataframe
df_euss_am_mp8
# Out:
# You chose to analyze all of the United States.
#         bldg_id  upgrade      weight  applicability  in.sqft  \
# 2           239        8  242.131013           True   1690.0
# 3           273        8  242.131013           True   1690.0
# 4           307        8  242.131013           True   1220.0
# 5           409        8  242.131013           True   1220.0
# 7           517        8  242.131013           True   1220.0
# ...         ...      ...         ...            ...      ...
# 548907   548226        8  242.131013           True   2176.0
# 548908   548228        8  242.131013           True   1690.0
# 548910   548417        8  242.131013           True    885.0
# 548914   549740        8  242.131013           True   1220.0
# 548915   549938        8  242.131013           True    885.0
#
#                       in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# 2       Non-CBSA East South Central                               3A
# 3       Non-CBSA East South Central                               3A
# 4       Non-CBSA East South Central                               3A
# 5       Non-CBSA East South Central                               3A
# 7       Non-CBSA East South Central                               3A
# ...                             ...                              ...
# 548907            Non-CBSA Mountain                               6B
# 548908            Non-CBSA Mountain                               6B
# 548910            Non-CBSA Mountain                               6B
# 548914            Non-CBSA Mountain                               7B
# 548915            Non-CBSA Mountain                               6B
#
#        in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# 2                                              3A                     Hour20
# 3                                              3A                     Hour12
# 4                                              3A                      Hour0
# 5                                              3A                     Hour20
# 7                                              3A                      Hour1
# ...                                           ...                        ...
# 548907                                         6B                      Hour3
# 548908                                         6B                      Hour6
# 548910                                         6B                     Hour18
# 548914                                         7B                      Hour4
# 548915                                         6B                      Hour2
#
#         in.bedrooms  ...  \
# 2                 3  ...
# 3                 3  ...
# 4                 4  ...
# 5                 2  ...
# 7                 3  ...
# ...             ...  ...
# 548907            4  ...
# 548908            4  ...
# 548910            2  ...
# 548914            2  ...
# 548915            2  ...
#
#        out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# 2                                             1887.869588
# 3                                             2355.351410
# 4                                             1399.898998
# 5                                             1877.362574
# 7                                             1533.599432
# ...                                                   ...
# 548907                                       10526.028704
# 548908                                        6095.411916
# 548910                                        4422.476166
# 548914                                        3295.130844
# 548915                                        8585.635388
#
#        out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# 2                                             3309.780516
# 3                                             4481.959362
# 4                                             2594.169607
# 5                                             1991.130798
# 7                                             2851.013565
# ...                                                   ...
# 548907                                       11172.116151
# 548908                                        6322.017139
# 548910                                        4554.667951
# 548914                                        2733.143505
# 548915                                        8716.973513
#
#        out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# 2                                             2975.726519
# 3                                             3932.995114
# 4                                             2328.429795
# 5                                             2011.527032
# 7                                             2551.672538
# ...                                                   ...
# 548907                                       11534.918833
# 548908                                        6497.639486
# 548910                                        4598.532148
# 548914                                        2154.651754
# 548915                                        8798.731723
#
#        out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# 2                                             4560.862209
# 3                                             6062.861674
# 4                                             3657.914475
# 5                                             2289.243950
# 7                                             3978.273612
# ...                                                   ...
# 548907                                        8031.176776
# 548908                                        4976.686210
# 548910                                        4027.179941
# 548914                                        5254.338718
# 548915                                        8026.064790
#
#                                     upgrade.clothes_dryer  \
# 2       Electric, Premium, Heat Pump, Ventless, 100% U...
# 3       Electric, Premium, Heat Pump, Ventless, 100% U...
# 4       Electric, Premium, Heat Pump, Ventless, 100% U...
# 5       Electric, Premium, Heat Pump, Ventless, 120% U...
# 7       Electric, Premium, Heat Pump, Ventless, 80% Usage
# ...                                                   ...
# 548907  Electric, Premium, Heat Pump, Ventless, 100% U...
# 548908  Electric, Premium, Heat Pump, Ventless, 100% U...
# 548910  Electric, Premium, Heat Pump, Ventless, 120% U...
# 548914  Electric, Premium, Heat Pump, Ventless, 120% U...
# 548915  Electric, Premium, Heat Pump, Ventless, 80% Usage
#
#                   upgrade.cooking_range upgrade.hvac_cooling_efficiency  \
# 2       Electric, Induction, 100% Usage                       Heat Pump
# 3       Electric, Induction, 100% Usage                       Heat Pump
# 4       Electric, Induction, 100% Usage                       Heat Pump
# 5       Electric, Induction, 120% Usage                       Heat Pump
# 7        Electric, Induction, 80% Usage                       Heat Pump
# ...                                 ...                             ...
# 548907  Electric, Induction, 100% Usage                       Heat Pump
# 548908  Electric, Induction, 100% Usage                       Heat Pump
# 548910  Electric, Induction, 120% Usage                       Heat Pump
# 548914  Electric, Induction, 120% Usage                       Heat Pump
# 548915   Electric, Induction, 80% Usage                       Heat Pump
#
#            upgrade.hvac_heating_efficiency upgrade.hvac_heating_type  \
# 2                   MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 3                   MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 4                   MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 5                   MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 7                   MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# ...                                    ...                       ...
# 548907              MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 548908              MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 548910              MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 548914              MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 548915  MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
#
#              upgrade.water_heater_efficiency
# 2       Electric Heat Pump, 50 gal, 3.45 UEF
# 3       Electric Heat Pump, 50 gal, 3.45 UEF
# 4       Electric Heat Pump, 66 gal, 3.35 UEF
# 5       Electric Heat Pump, 50 gal, 3.45 UEF
# 7       Electric Heat Pump, 50 gal, 3.45 UEF
# ...                                      ...
# 548907  Electric Heat Pump, 66 gal, 3.35 UEF
# 548908  Electric Heat Pump, 66 gal, 3.35 UEF
# 548910  Electric Heat Pump, 50 gal, 3.45 UEF
# 548914  Electric Heat Pump, 50 gal, 3.45 UEF
# 548915  Electric Heat Pump, 50 gal, 3.45 UEF
#
# [331531 rows x 348 columns]

# %% [markdown]
# # Basic Pre-IRA Scenario:
# ## - NREL End-Use Savings Shapes Database: Measure Package 8
# ## - AEO2023 No Inflation Reduction Act
# ## - Bistline et al 2023 REFERENCE CASE (AVERAGE IN RANGE)

# %%
print("""
-------------------------------------------------------------------------------------------------------
Post-Retrofit (MP) Consumption: WHOLE-HOME
-------------------------------------------------------------------------------------------------------
""")

# df_enduse_compare(df_mp, category, df_baseline):
df_euss_am_mp8_home = df_enduse_compare(df_mp = df_euss_am_mp8,
                                        input_mp=input_mp,
                                        menu_mp=menu_mp,
                                        df_baseline = df_euss_am_baseline_home 
                                       )

# Project Future Energy Consumption
df_euss_am_mp8_home = project_future_consumption(df=df_euss_am_mp8_home,
                                                 hdd_factor_lookup=hdd_factor_lookup,
                                                 menu_mp=menu_mp
                                                 )
df_euss_am_mp8_home
# Out:
# -------------------------------------------------------------------------------------------------------
# Post-Retrofit (MP) Consumption: WHOLE-HOME
# -------------------------------------------------------------------------------------------------------
#
# Projecting Future Energy Consumption (Upgraded Equipment): heating
# Projecting Future Energy Consumption (Upgraded Equipment): waterHeating
# Projecting Future Energy Consumption (Upgraded Equipment): clothesDrying
# Projecting Future Energy Consumption (Upgraded Equipment): cooking
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ...  \
# 0         AL    Not in a census Place  G0100390  ...
# 1         AL  In another census Place  G0100150  ...
# 2         AL    Not in a census Place  G0100850  ...
# 3         AL    Not in a census Place  G0100050  ...
# 4         AL  In another census Place  G0101270  ...
# ...      ...                      ...       ...  ...
# 270013    WY  In another census Place  G5600050  ...
# 270014    WY  In another census Place  G5600050  ...
# 270015    WY    Not in a census Place  G5600010  ...
# 270016    WY                   Casper  G5600250  ...
# 270017    WY  In another census Place  G5600390  ...
#
#        mp8_2032_cooking_consumption mp8_2032_cooking_reduction_consumption  \
# 0                            471.26                                 508.18
# 1                            537.20                                   0.00
# 2                            537.20                                   0.00
# 3                            486.50                                 523.13
# 4                            377.18                                   0.00
# ...                             ...                                    ...
# 270013                       405.61                                   0.00
# 270014                       405.61                                   0.00
# 270015                       405.61                                   0.00
# 270016                       486.50                                   0.00
# 270017                       486.50                                 523.13
#
#        mp8_2033_cooking_consumption  mp8_2033_cooking_reduction_consumption  \
# 0                            471.26                                  508.18
# 1                            537.20                                    0.00
# 2                            537.20                                    0.00
# 3                            486.50                                  523.13
# 4                            377.18                                    0.00
# ...                             ...                                     ...
# 270013                       405.61                                    0.00
# 270014                       405.61                                    0.00
# 270015                       405.61                                    0.00
# 270016                       486.50                                    0.00
# 270017                       486.50                                  523.13
#
#         mp8_2034_cooking_consumption mp8_2034_cooking_reduction_consumption  \
# 0                             471.26                                 508.18
# 1                             537.20                                   0.00
# 2                             537.20                                   0.00
# 3                             486.50                                 523.13
# 4                             377.18                                   0.00
# ...                              ...                                    ...
# 270013                        405.61                                   0.00
# 270014                        405.61                                   0.00
# 270015                        405.61                                   0.00
# 270016                        486.50                                   0.00
# 270017                        486.50                                 523.13
#
#        mp8_2035_cooking_consumption mp8_2035_cooking_reduction_consumption  \
# 0                            471.26                                 508.18
# 1                            537.20                                   0.00
# 2                            537.20                                   0.00
# 3                            486.50                                 523.13
# 4                            377.18                                   0.00
# ...                             ...                                    ...
# 270013                       405.61                                   0.00
# 270014                       405.61                                   0.00
# 270015                       405.61                                   0.00
# 270016                       486.50                                   0.00
# 270017                       486.50                                 523.13
#
#        mp8_2036_cooking_consumption mp8_2036_cooking_reduction_consumption
# 0                            471.26                                 508.18
# 1                            537.20                                   0.00
# 2                            537.20                                   0.00
# 3                            486.50                                 523.13
# 4                            377.18                                   0.00
# ...                             ...                                    ...
# 270013                       405.61                                   0.00
# 270014                       405.61                                   0.00
# 270015                       405.61                                   0.00
# 270016                       486.50                                   0.00
# 270017                       486.50                                 523.13
#
# [270018 rows x 629 columns]

# %%
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Public Perspective: Monetized Marginal Damages from Emissions
------------------------------------------------------------------------------------------------------------------------------------------------
**Steps 1-4 were performed in the Baseline Scenario**
- Step 1: Calculate emissions factors for different fuel sources
- Step 2: Adjust Natural Gas & Electricity Emissions Factors for Natural Gas Leakage
- Step 3: Quantify monitized damages using EASIUR Marginal Social Cost Factors
- Step 4: Inflate Marginal Social Cost (Damage) Factors using BLS CPI for All Urban Consumers (CPI-U) 
------------------------------------------------------------------------------------------------------------------------------------------------
""")
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------
# Public Perspective: Monetized Marginal Damages from Emissions
# ------------------------------------------------------------------------------------------------------------------------------------------------
# **Steps 1-4 were performed in the Baseline Scenario**
# - Step 1: Calculate emissions factors for different fuel sources
# - Step 2: Adjust Natural Gas & Electricity Emissions Factors for Natural Gas Leakage
# - Step 3: Quantify monitized damages using EASIUR Marginal Social Cost Factors
# - Step 4: Inflate Marginal Social Cost (Damage) Factors using BLS CPI for All Urban Consumers (CPI-U)
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print("""
-------------------------------------------------------------------------------------------------------
Step 5: Calculate End-use specific marginal damages
-------------------------------------------------------------------------------------------------------  
-------------------------------------------------------------------------------------------------------
Post-Retrofit (MP) Marginal Damages: WHOLE-HOME
-------------------------------------------------------------------------------------------------------
""")

# calculate_marginal_damages(df, menu_mp, policy_scenario)
df_euss_am_mp8_home = calculate_marginal_damages(df=df_euss_am_mp8_home,
                                                 menu_mp=menu_mp,
                                                 policy_scenario='No Inflation Reduction Act',
                                                 )
df_euss_am_mp8_home
# Out:
# -------------------------------------------------------------------------------------------------------
# Step 5: Calculate End-use specific marginal damages
# -------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------
# Post-Retrofit (MP) Marginal Damages: WHOLE-HOME
# -------------------------------------------------------------------------------------------------------
#
# Calculating damages from 2022 to 2037 for heating
# Calculating damages from 2022 to 2034 for waterHeating
# Calculating damages from 2022 to 2035 for clothesDrying
# Calculating damages from 2022 to 2037 for cooking
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ...  \
# 0         AL    Not in a census Place  G0100390  ...
# 1         AL  In another census Place  G0100150  ...
# 2         AL    Not in a census Place  G0100850  ...
# 3         AL    Not in a census Place  G0100050  ...
# 4         AL  In another census Place  G0101270  ...
# ...      ...                      ...       ...  ...
# 270013    WY  In another census Place  G5600050  ...
# 270014    WY  In another census Place  G5600050  ...
# 270015    WY    Not in a census Place  G5600010  ...
# 270016    WY                   Casper  G5600250  ...
# 270017    WY  In another census Place  G5600390  ...
#
#        preIRA_2036_cooking_damages_nox  \
# 0                                 0.34
# 1                                 0.39
# 2                                 0.39
# 3                                 0.35
# 4                                 0.27
# ...                                ...
# 270013                            0.17
# 270014                            0.17
# 270015                            0.17
# 270016                            0.21
# 270017                            0.46
#
#        preIRA_2036_cooking_reduction_damages_nox  \
# 0                                           0.81
# 1                                           0.00
# 2                                           0.00
# 3                                           0.87
# 4                                           0.00
# ...                                          ...
# 270013                                      0.00
# 270014                                      0.00
# 270015                                      0.00
# 270016                                      0.00
# 270017                                      0.78
#
#        preIRA_2036_cooking_damages_pm25  \
# 0                                  1.68
# 1                                  1.92
# 2                                  1.92
# 3                                  1.74
# 4                                  1.35
# ...                                 ...
# 270013                             0.61
# 270014                             0.61
# 270015                             0.61
# 270016                             0.74
# 270017                             0.85
#
#         preIRA_2036_cooking_reduction_damages_pm25  \
# 0                                             2.02
# 1                                             0.00
# 2                                             0.00
# 3                                             2.10
# 4                                             0.00
# ...                                            ...
# 270013                                        0.00
# 270014                                        0.00
# 270015                                        0.00
# 270016                                        0.00
# 270017                                        0.97
#
#         preIRA_2036_cooking_damages_co2  \
# 0                                 36.26
# 1                                 41.33
# 2                                 41.33
# 3                                 37.43
# 4                                 29.02
# ...                                 ...
# 270013                            24.80
# 270014                            24.80
# 270015                            24.80
# 270016                            29.74
# 270017                            35.26
#
#        preIRA_2036_cooking_reduction_damages_co2  \
# 0                                          79.95
# 1                                           0.00
# 2                                           0.00
# 3                                          82.36
# 4                                           0.00
# ...                                          ...
# 270013                                      0.00
# 270014                                      0.00
# 270015                                      0.00
# 270016                                      0.00
# 270017                                     80.31
#
#        preIRA_2036_cooking_damages_health preIRA_2036_cooking_damages_climate  \
# 0                                    2.70                               36.26
# 1                                    3.09                               41.33
# 2                                    3.09                               41.33
# 3                                    2.79                               37.43
# 4                                    2.17                               29.02
# ...                                   ...                                 ...
# 270013                               1.32                               24.80
# 270014                               1.32                               24.80
# 270015                               1.32                               24.80
# 270016                               1.60                               29.74
# 270017                               3.17                               35.26
#
#        preIRA_2036_cooking_reduction_damages_health  \
# 0                                              3.58
# 1                                              0.00
# 2                                              0.00
# 3                                              3.75
# 4                                              0.00
# ...                                             ...
# 270013                                         0.00
# 270014                                         0.00
# 270015                                         0.00
# 270016                                         0.00
# 270017                                         3.75
#
#        preIRA_2036_cooking_reduction_damages_climate
# 0                                              79.95
# 1                                               0.00
# 2                                               0.00
# 3                                              82.36
# 4                                               0.00
# ...                                              ...
# 270013                                          0.00
# 270014                                          0.00
# 270015                                          0.00
# 270016                                          0.00
# 270017                                         80.31
#
# [270018 rows x 1289 columns]

# %%
print("""
-------------------------------------------------------------------------------------------------------
print("Public NPV: WHOLE-HOME
-------------------------------------------------------------------------------------------------------
""")

print("Calculating Public NPV for each end-use ...")
# calculate_public_npv(df, menu_mp, policy_scenario, equipment_specs, interest_rate=0.02)
df_euss_am_mp8_home = calculate_public_npv(df=df_euss_am_mp8_home,
                                           menu_mp=menu_mp,
                                           policy_scenario='No Inflation Reduction Act',
                                           equipment_specs=equipment_specs,
                                           interest_rate=0.02,
                                           )
df_euss_am_mp8_home
# Out:
# -------------------------------------------------------------------------------------------------------
# print("Public NPV: WHOLE-HOME
# -------------------------------------------------------------------------------------------------------
#
# Calculating Public NPV for each end-use ...
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ...  \
# 0         AL    Not in a census Place  G0100390  ...
# 1         AL  In another census Place  G0100150  ...
# 2         AL    Not in a census Place  G0100850  ...
# 3         AL    Not in a census Place  G0100050  ...
# 4         AL  In another census Place  G0101270  ...
# ...      ...                      ...       ...  ...
# 270013    WY  In another census Place  G5600050  ...
# 270014    WY  In another census Place  G5600050  ...
# 270015    WY    Not in a census Place  G5600010  ...
# 270016    WY                   Casper  G5600250  ...
# 270017    WY  In another census Place  G5600390  ...
#
#        preIRA_heating_public_npv preIRA_waterHeating_climate_npv  \
# 0                        4658.19                         1864.09
# 1                        7284.02                         2471.44
# 2                        1858.17                         2335.22
# 3                        2234.32                         6528.61
# 4                        3154.54                          981.82
# ...                          ...                             ...
# 270013                  54070.02                         2044.79
# 270014                 103686.37                         5903.55
# 270015                  50011.40                         6157.78
# 270016                  24505.15                        10411.53
# 270017                  28772.68                         4382.99
#
#        preIRA_waterHeating_health_npv  preIRA_waterHeating_public_npv  \
# 0                              135.82                         1999.92
# 1                              180.10                         2651.56
# 2                              170.21                         2505.41
# 3                              347.15                         6875.78
# 4                               71.53                         1053.36
# ...                               ...                             ...
# 270013                          88.02                         2132.80
# 270014                         177.02                         6080.58
# 270015                         180.31                         6338.08
# 270016                         306.67                        10718.19
# 270017                         342.57                         4725.52
#
#         preIRA_clothesDrying_climate_npv preIRA_clothesDrying_health_npv  \
# 0                                 297.05                           21.66
# 1                                 700.08                           51.07
# 2                                 366.08                           26.71
# 3                                 271.56                           19.86
# 4                                 237.72                           17.35
# ...                                  ...                             ...
# 270013                            411.45                           17.90
# 270014                            216.94                            9.42
# 270015                            216.94                            9.42
# 270016                            496.41                           21.58
# 270017                            285.54                           22.45
#
#        preIRA_clothesDrying_public_npv preIRA_cooking_climate_npv  \
# 0                               318.75                    1204.85
# 1                               751.16                       0.00
# 2                               392.78                       0.00
# 3                               291.38                    1240.94
# 4                               255.09                       0.00
# ...                                ...                        ...
# 270013                          429.34                       0.00
# 270014                          226.38                       0.00
# 270015                          226.38                       0.00
# 270016                          517.99                       0.00
# 270017                          307.99                    1263.76
#
#        preIRA_cooking_health_npv preIRA_cooking_public_npv
# 0                          56.80                   1261.66
# 1                           0.00                      0.00
# 2                           0.00                      0.00
# 3                          59.44                   1300.39
# 4                           0.00                      0.00
# ...                          ...                       ...
# 270013                      0.00                      0.00
# 270014                      0.00                      0.00
# 270015                      0.00                      0.00
# 270016                      0.00                      0.00
# 270017                     60.71                   1324.47
#
# [270018 rows x 1301 columns]

# %%
preIRA_fuel_price_lookup
# Out:
# {'National': {'naturalGas': {'No Inflation Reduction Act': {2022: 0
#     2041: 0.10471106783450046,
#     2042: 0.104854673447709,
#     2043: 0.1048153404477247,
#     2044: 0.1049778531714457,
#     2045: 0.10528032306380831,
#     2046: 0.10581724180153823,
#     2047: 0.1063838712307785,
#     2048: 0.1067763979653053,
#     2049: 0.10699901045998225,
#     2050: 0.10737014266156754}}},
#  'New England': {'fuelOil': {'No Inflation Reduction Act': {2022: 0.11504722021660649,
#     2023: 0.10711042021278061,
#     2024: 0.10357991670979357,
#     2025: 0.09760372724317617,
#     2026: 0.0957699078238029,
#     2027: 0.09457342443559111,
#     2028: 0.09311916352939979,
#     2029: 0.09350222683770891,
#     2030: 0.09365792024365154,
#     2031: 0.09395708772313263,
#     2032: 0.09436312691060866,
#     2033: 0.09492931330997317,
#     2034: 0.09494805136496672,
#     2035: 0.09527925286825706,
#     2036: 0.09578667913568586,
#     2037: 0.09608008382878144,
#     2038: 0.0963450312871191,
#     2039: 0.09682260952807287,
#     2040: 0.09691703937698895,
#     2041: 0.09714894489657884,
#     2042: 0.09723641096955599,
#     2043: 0.09741705681512934,
#     2044: 0.09755646650440275,
#     2045: 0.09784410841111278,
#     2046: 0.09835039259310799,
#     2047: 0.09861018266851346,
#     2048: 0.0986784623606965,
#     2049: 0.09878479084180895,
#     2050: 0.09890829969119175}}}}

# %%
# def calculate_annual_fuelCost(df, menu_mp, policy_scenario):
#     """
#     Calculate the annual fuel cost for baseline and measure packages.

#     Parameters:
#     df (pd.DataFrame): DataFrame containing baseline fuel consumption data.
#     fuel_price_lookup (dict): Dictionary containing fuel prices indexed by location and fuel type.
#     menu_mp (int): Measure package identifier
#     policy_scenario (str): Name of EIA AEO policy_scenario used to project fuel prices

#     Returns:
#     pd.DataFrame: DataFrame with additional columns for annual fuel costs, savings, and changes.
#     """
#     df_copy = df.copy()

#     # Determine the scenario prefix and fuel price lookup based on menu_mp and policy_scenario
#     if menu_mp == 0:
#         scenario_prefix = "baseline_"
#         fuel_price_lookup = preIRA_fuel_price_lookup
#     else:
#         if policy_scenario == 'No Inflation Reduction Act':
#             scenario_prefix = f"preIRA_"
#             fuel_price_lookup = preIRA_fuel_price_lookup
#         elif policy_scenario == 'AEO2023 Reference Case':
#             scenario_prefix = f"iraRef_mp{menu_mp}_"
#             fuel_price_lookup = iraRef_fuel_price_lookup
#         elif policy_scenario == 'High Uptake of Inflation Reduction Act':
#             scenario_prefix = f"iraHigh_mp{menu_mp}_"
#             fuel_price_lookup = iraHigh_fuel_price_lookup

#     # Fuel type mapping and equipment lifetime specifications
#     fuel_mapping = {'Electricity': 'electricity', 'Natural Gas': 'naturalGas', 'Fuel Oil': 'fuelOil', 'Propane': 'propane'}
#     equipment_specs = {'heating': 15, 'waterHeating': 12, 'clothesDrying': 13, 'cooking': 15}

#     # If baseline calculations are required
#     if menu_mp == 0:
#         for category in equipment_specs:
#             df_copy[f'fuel_type_{category}'] = df_copy[f'base_{category}_fuel'].map(fuel_mapping)

#         for category, lifetime in equipment_specs.items():
#             print(f"Calculating BASELINE (no retrofit) fuel costs from 2022 to {2022 + lifetime} for {category}")
#             for year in range(1, lifetime + 1):
#                 year_label = year + 2021

#                 fuel_costs = df_copy.apply(lambda row: round(
#                     row[f'baseline_{year_label}_{category}_consumption'] *
#                     fuel_price_lookup.get(
#                         row['state'] if row[f'fuel_type_{category}'] in ['electricity', 'naturalGas'] else row['census_division'],
#                         {}
#                     ).get(row[f'fuel_type_{category}'], {}).get(policy_scenario, {}).get(year_label, 0), 2),
#                     axis=1
#                 )

#                 df_copy[f'baseline_{year_label}_{category}_fuelCost'] = fuel_costs

#     else:
#         for category, lifetime in equipment_specs.items():
#             print(f"Calculating POST-RETROFIT (MP{menu_mp}) fuel costs from 2022 to {2022 + lifetime} for {category}")
#             for year in range(1, lifetime + 1):
#                 year_label = year + 2021

#                 fuel_costs = df_copy.apply(lambda row: round(
#                     row[f'mp{menu_mp}_{year_label}_{category}_consumption'] *
#                     fuel_price_lookup.get(row['state'], {}).get('electricity', {}).get(policy_scenario, {}).get(year_label, 0), 2),
#                     axis=1
#                 )

#                 df_copy[f'{scenario_prefix}{year_label}_{category}_fuelCost'] = fuel_costs

#                 df_copy[f'{scenario_prefix}{year_label}_{category}_savings_fuelCost'] = df_copy[f'baseline_{year_label}_{category}_fuelCost'] - fuel_costs
#                 df_copy[f'{scenario_prefix}{year_label}_{category}_delta_fuelCost'] = fuel_costs - df_copy[f'baseline_{year_label}_{category}_fuelCost']
#                 df_copy[f'{scenario_prefix}{year_label}_{category}_percentChange_fuelCost'] = (
#                     df_copy[f'{scenario_prefix}{year_label}_{category}_delta_fuelCost'] /
#                     df_copy[f'baseline_{year_label}_{category}_fuelCost']
#                 ).mul(100).round(2)

#     return df_copy

# %%
# def calculate_annual_fuelCost(df, menu_mp, policy_scenario):
#     """
#     Calculate the annual fuel cost for baseline and measure packages.

#     Parameters:
#     df (pd.DataFrame): DataFrame containing baseline fuel consumption data.
#     menu_mp (int): Measure package identifier
#     policy_scenario (str): Name of EIA AEO policy_scenario used to project fuel prices

#     Returns:
#     pd.DataFrame: DataFrame with additional columns for annual fuel costs, savings, and changes.
#     """
#     df_copy = df.copy()

#     # Determine the scenario prefix and fuel price lookup based on menu_mp and policy_scenario
#     if menu_mp == 0:
#         scenario_prefix = "baseline_"
#         fuel_price_lookup = preIRA_fuel_price_lookup
#     else:
#         if policy_scenario == 'No Inflation Reduction Act':
#             scenario_prefix = f"preIRA_"
#             fuel_price_lookup = preIRA_fuel_price_lookup
#         elif policy_scenario == 'AEO2023 Reference Case':
#             scenario_prefix = f"iraRef_mp{menu_mp}_"
#             fuel_price_lookup = iraRef_fuel_price_lookup
#         elif policy_scenario == 'High Uptake of Inflation Reduction Act':
#             scenario_prefix = f"iraHigh_mp{menu_mp}_"
#             fuel_price_lookup = iraHigh_fuel_price_lookup

#     # Fuel type mapping and equipment lifetime specifications
#     fuel_mapping = {'Electricity': 'electricity', 'Natural Gas': 'naturalGas', 'Fuel Oil': 'fuelOil', 'Propane': 'propane'}
#     equipment_specs = {'heating': 15, 'waterHeating': 12, 'clothesDrying': 13, 'cooking': 15}

#     # Initialize a dictionary to hold new columns
#     new_columns = {}

#     # If baseline calculations are required
#     if menu_mp == 0:
#         for category in equipment_specs:
#             df_copy[f'fuel_type_{category}'] = df_copy[f'base_{category}_fuel'].map(fuel_mapping)

#         for category, lifetime in equipment_specs.items():
#             print(f"Calculating BASELINE (no retrofit) fuel costs from 2022 to {2022 + lifetime} for {category}")
#             for year in range(1, lifetime + 1):
#                 year_label = year + 2021

#                 fuel_costs = df_copy.apply(lambda row: round(
#                     row[f'baseline_{year_label}_{category}_consumption'] *
#                     fuel_price_lookup.get(
#                         row['state'] if row[f'fuel_type_{category}'] in ['electricity', 'naturalGas'] else row['census_division'],
#                         {}
#                     ).get(row[f'fuel_type_{category}'], {}).get(policy_scenario, {}).get(year_label, 0), 2),
#                     axis=1
#                 )

#                 new_columns[f'baseline_{year_label}_{category}_fuelCost'] = fuel_costs

#     else:
#         for category, lifetime in equipment_specs.items():
#             print(f"Calculating POST-RETROFIT (MP{menu_mp}) fuel costs from 2022 to {2022 + lifetime} for {category}")
#             for year in range(1, lifetime + 1):
#                 year_label = year + 2021

#                 fuel_costs = df_copy.apply(lambda row: round(
#                     row[f'mp{menu_mp}_{year_label}_{category}_consumption'] *
#                     fuel_price_lookup.get(row['state'], {}).get('electricity', {}).get(policy_scenario, {}).get(year_label, 0), 2),
#                     axis=1
#                 )

#                 # Store all new columns in the dictionary first
#                 new_columns[f'{scenario_prefix}{year_label}_{category}_fuelCost'] = 
                
#                 new_columns[f'{scenario_prefix}{year_label}_{category}_savings_fuelCost'] = (
#                     df_copy[f'baseline_{year_label}_{category}_fuelCost'] - fuel_costs
#                 )

#                 # new_columns[f'{scenario_prefix}{year_label}_{category}_delta_fuelCost'] = (
#                 #     fuel_costs - df_copy[f'baseline_{year_label}_{category}_fuelCost']
#                 # )

#                 # new_columns[f'{scenario_prefix}{year_label}_{category}_percentChange_fuelCost'] = (
#                 #     new_columns[f'{scenario_prefix}{year_label}_{category}_delta_fuelCost'] /
#                 #     df_copy[f'baseline_{year_label}_{category}_fuelCost']
#                 # ).mul(100).round(2)

#     # Combine all new columns at once to avoid fragmentation
#     df_new_columns = pd.DataFrame(new_columns, index=df_copy.index)
#     columns_to_add = df_new_columns.columns.difference(df_copy.columns)
#     df_copy = pd.concat([df_copy, df_new_columns[columns_to_add]], axis=1)

#     return df_copy

#     # df_new_columns = pd.DataFrame(new_columns, index=df_copy.index)
#     # df_copy = pd.concat([df_copy, df_new_columns], axis=1)
    
#     # return df_copy

# %%
print("\n")
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Private Perspective: Annual Energy Costs
------------------------------------------------------------------------------------------------------------------------------------------------
- Step 1: Obtain Level Energy Fuel Cost Data from the EIA
- Step 2: Calculate Annual Operating (Fuel) Costs
------------------------------------------------------------------------------------------------------------------------------------------------

------------------------------------------------------------------------------------------------------------------------------------------------
Post-Retrofit (MP) Fuel Cost: WHOLE-HOME
------------------------------------------------------------------------------------------------------------------------------------------------
""")

# calculate_annual_fuelCost(df, menu_mp, policy_scenario)
df_euss_am_mp8_home = calculate_annual_fuelCost(df=df_euss_am_mp8_home,
                                                menu_mp=menu_mp,
                                                policy_scenario='No Inflation Reduction Act',
                                                )
df_euss_am_mp8_home
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------
# Private Perspective: Annual Energy Costs
# ------------------------------------------------------------------------------------------------------------------------------------------------
# - Step 1: Obtain Level Energy Fuel Cost Data from the EIA
# - Step 2: Calculate Annual Operating (Fuel) Costs
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
# ------------------------------------------------------------------------------------------------------------------------------------------------
# Post-Retrofit (MP) Fuel Cost: WHOLE-HOME
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
# Calculating POST-RETROFIT (MP8) fuel costs from 2022 to 2037 for heating
# Calculating POST-RETROFIT (MP8) fuel costs from 2022 to 2034 for waterHeating
# Calculating POST-RETROFIT (MP8) fuel costs from 2022 to 2035 for clothesDrying
# Calculating POST-RETROFIT (MP8) fuel costs from 2022 to 2037 for cooking
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ...  \
# 0         AL    Not in a census Place  G0100390  ...
# 1         AL  In another census Place  G0100150  ...
# 2         AL    Not in a census Place  G0100850  ...
# 3         AL    Not in a census Place  G0100050  ...
# 4         AL  In another census Place  G0101270  ...
# ...      ...                      ...       ...  ...
# 270013    WY  In another census Place  G5600050  ...
# 270014    WY  In another census Place  G5600050  ...
# 270015    WY    Not in a census Place  G5600010  ...
# 270016    WY                   Casper  G5600250  ...
# 270017    WY  In another census Place  G5600390  ...
#
#        preIRA_2032_cooking_fuelCost preIRA_2032_cooking_savings_fuelCost  \
# 0                             59.84                                -7.06
# 1                             68.21                                 0.00
# 2                             68.21                                 0.00
# 3                             61.77                                -7.37
# 4                             47.89                                 0.00
# ...                             ...                                  ...
# 270013                        44.13                                 0.00
# 270014                        44.13                                 0.00
# 270015                        44.13                                 0.00
# 270016                        52.94                                 0.00
# 270017                        52.94                                43.80
#
#        preIRA_2033_cooking_fuelCost  preIRA_2033_cooking_savings_fuelCost  \
# 0                             59.85                                 -6.42
# 1                             68.23                                  0.00
# 2                             68.23                                  0.00
# 3                             61.79                                 -6.71
# 4                             47.91                                  0.00
# ...                             ...                                   ...
# 270013                        44.45                                  0.00
# 270014                        44.45                                  0.00
# 270015                        44.45                                  0.00
# 270016                        53.32                                  0.00
# 270017                        53.32                                 44.88
#
#         preIRA_2034_cooking_fuelCost preIRA_2034_cooking_savings_fuelCost  \
# 0                              59.94                                -6.06
# 1                              68.33                                 0.00
# 2                              68.33                                 0.00
# 3                              61.88                                -6.34
# 4                              47.98                                 0.00
# ...                              ...                                  ...
# 270013                         44.69                                 0.00
# 270014                         44.69                                 0.00
# 270015                         44.69                                 0.00
# 270016                         53.60                                 0.00
# 270017                         53.60                                45.71
#
#        preIRA_2035_cooking_fuelCost preIRA_2035_cooking_savings_fuelCost  \
# 0                             59.86                                -5.60
# 1                             68.24                                 0.00
# 2                             68.24                                 0.00
# 3                             61.80                                -5.87
# 4                             47.91                                 0.00
# ...                             ...                                  ...
# 270013                        44.78                                 0.00
# 270014                        44.78                                 0.00
# 270015                        44.78                                 0.00
# 270016                        53.71                                 0.00
# 270017                        53.71                                46.63
#
#        preIRA_2036_cooking_fuelCost preIRA_2036_cooking_savings_fuelCost
# 0                             59.73                                -5.23
# 1                             68.08                                 0.00
# 2                             68.08                                 0.00
# 3                             61.66                                -5.48
# 4                             47.80                                 0.00
# ...                             ...                                  ...
# 270013                        45.20                                 0.00
# 270014                        45.20                                 0.00
# 270015                        45.20                                 0.00
# 270016                        54.21                                 0.00
# 270017                        54.21                                47.16
#
# [270018 rows x 1411 columns]

# %%
print("\n")
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Private Perspective: Private NPV
------------------------------------------------------------------------------------------------------------------------------------------------
- Step 1: Calculate annual operating (fuel) costs
- Step 2: Calculate equipment capital costs (For space heating, include ductwork and weatherization (MP9 and MP8))
- Step 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)
- Step 4: Calculate net equipment capital costs
- Step 5: Calculate private NPV
------------------------------------------------------------------------------------------------------------------------------------------------
""")
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------
# Private Perspective: Private NPV
# ------------------------------------------------------------------------------------------------------------------------------------------------
# - Step 1: Calculate annual operating (fuel) costs
# - Step 2: Calculate equipment capital costs (For space heating, include ductwork and weatherization (MP9 and MP8))
# - Step 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)
# - Step 4: Calculate net equipment capital costs
# - Step 5: Calculate private NPV
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Collect Capital Cost Data for different End-uses
filename = "tare_retrofit_costs_cpi.xlsx"
relative_path = os.path.join(r"retrofit_costs", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_heating_retrofit_costs = pd.read_excel(io=file_path, sheet_name='heating_costs')
df_waterHeating_retrofit_costs = pd.read_excel(io=file_path, sheet_name='waterHeating_costs')
df_clothesDrying_retrofit_costs = pd.read_excel(io=file_path, sheet_name='clothesDrying_costs')
df_cooking_retrofit_costs = pd.read_excel(io=file_path, sheet_name='cooking_costs')
df_enclosure_retrofit_costs = pd.read_excel(io=file_path, sheet_name='enclosure_upgrade_costs')
# Out:
# Retrieved data for filename: tare_retrofit_costs_cpi.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\retrofit_costs\tare_retrofit_costs_cpi.xlsx

# %%
# Assuming df_rsMeans_cityCostIndex is your DataFrame with average costs
# Accounts for the costs of materials, labor and equipment and compares it to a national average of 30 major U.S. cities
average_cost_map = df_rsMeans_cityCostIndex.set_index('City')['Average'].to_dict()
rsMeans_national_avg = round((3.00 * (cpi_ratio_2022_2019)), 2)

# Use CCI to adjust for cost differences when compared to the national average
# Call the function and map the values for CCI adjustment
df_euss_am_mp8_home['rsMeans_CCI_avg'] = df_euss_am_mp8_home['city'].apply(map_average_cost)
df_euss_am_mp8_home
# Out:
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ...  \
# 0         AL    Not in a census Place  G0100390  ...
# 1         AL  In another census Place  G0100150  ...
# 2         AL    Not in a census Place  G0100850  ...
# 3         AL    Not in a census Place  G0100050  ...
# 4         AL  In another census Place  G0101270  ...
# ...      ...                      ...       ...  ...
# 270013    WY  In another census Place  G5600050  ...
# 270014    WY  In another census Place  G5600050  ...
# 270015    WY    Not in a census Place  G5600010  ...
# 270016    WY                   Casper  G5600250  ...
# 270017    WY  In another census Place  G5600390  ...
#
#        preIRA_2032_cooking_savings_fuelCost preIRA_2033_cooking_fuelCost  \
# 0                                     -7.06                        59.85
# 1                                      0.00                        68.23
# 2                                      0.00                        68.23
# 3                                     -7.37                        61.79
# 4                                      0.00                        47.91
# ...                                     ...                          ...
# 270013                                 0.00                        44.45
# 270014                                 0.00                        44.45
# 270015                                 0.00                        44.45
# 270016                                 0.00                        53.32
# 270017                                43.80                        53.32
#
#        preIRA_2033_cooking_savings_fuelCost  preIRA_2034_cooking_fuelCost  \
# 0                                     -6.42                         59.94
# 1                                      0.00                         68.33
# 2                                      0.00                         68.33
# 3                                     -6.71                         61.88
# 4                                      0.00                         47.98
# ...                                     ...                           ...
# 270013                                 0.00                         44.69
# 270014                                 0.00                         44.69
# 270015                                 0.00                         44.69
# 270016                                 0.00                         53.60
# 270017                                44.88                         53.60
#
#         preIRA_2034_cooking_savings_fuelCost preIRA_2035_cooking_fuelCost  \
# 0                                      -6.06                        59.86
# 1                                       0.00                        68.24
# 2                                       0.00                        68.24
# 3                                      -6.34                        61.80
# 4                                       0.00                        47.91
# ...                                      ...                          ...
# 270013                                  0.00                        44.78
# 270014                                  0.00                        44.78
# 270015                                  0.00                        44.78
# 270016                                  0.00                        53.71
# 270017                                 45.71                        53.71
#
#        preIRA_2035_cooking_savings_fuelCost preIRA_2036_cooking_fuelCost  \
# 0                                     -5.60                        59.73
# 1                                      0.00                        68.08
# 2                                      0.00                        68.08
# 3                                     -5.87                        61.66
# 4                                      0.00                        47.80
# ...                                     ...                          ...
# 270013                                 0.00                        45.20
# 270014                                 0.00                        45.20
# 270015                                 0.00                        45.20
# 270016                                 0.00                        54.21
# 270017                                46.63                        54.21
#
#        preIRA_2036_cooking_savings_fuelCost rsMeans_CCI_avg
# 0                                     -5.23            3.00
# 1                                      0.00            3.00
# 2                                      0.00            3.00
# 3                                     -5.48            3.00
# 4                                      0.00            3.00
# ...                                     ...             ...
# 270013                                 0.00            3.00
# 270014                                 0.00            3.00
# 270015                                 0.00            3.00
# 270016                                 0.00            4.05
# 270017                                47.16            3.00
#
# [270018 rows x 1412 columns]

# %% [markdown]
# ### Space Heating and No Enclosure Upgrade

# %% [markdown]
# #### Space Heating Capital Costs

# %%
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Capital Costs: Space Heating
------------------------------------------------------------------------------------------------------------------------------------------------

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
""")

# Columns to update
cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
    'cost_per_kBtuh_progressive', 'cost_per_kBtuh_reference', 'cost_per_kBtuh_conservative',
    'otherCost_progressive', 'otherCost_reference', 'otherCost_conservative'
]

# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_heating_retrofit_costs[column] = round((df_heating_retrofit_costs[column] * df_heating_retrofit_costs['cpi_ratio'] * df_heating_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_heating_equipment_cost = df_heating_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')
# dict_heating_equipment_cost
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------
# Capital Costs: Space Heating
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...

# %%
# Call the function and obtain equipment specifications
# obtain_heating_system_specs(df)
print("Obtaining system specs ...")
df_euss_am_mp8_home = obtain_heating_system_specs(df_euss_am_mp8_home)

# calculate_installation_cost(df, cost_dict, rsMeans_national_avg, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Heat Pump for Space Heating (No Enclosure Upgrade) ...")
calculate_installation_cost(df_euss_am_mp8_home, dict_heating_equipment_cost, rsMeans_national_avg, menu_mp, 'heating')

# calculate_replacement_cost(df, cost_dict, rsMeans_national_avg, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
calculate_replacement_cost(df_euss_am_mp8_home, dict_heating_equipment_cost, rsMeans_national_avg, menu_mp, 'heating')

# Call the function and calculate installation premium based on existing housing characteristics
# calculate_heating_installation_premium(df, rsMeans_national_avg, cpi_ratio_2022_2013)
print("Calculating Space Heating Specific Premiums (Ex: Removing Hydronic Boiler) ...")
df_euss_am_mp8_home = calculate_heating_installation_premium(df_euss_am_mp8_home, rsMeans_national_avg, cpi_ratio_2022_2013)

# Display the df
df_euss_am_mp8_home
# Out:
# Obtaining system specs ...
# Calculating Cost of Retrofit Upgrade: Heat Pump for Space Heating (No Enclosure Upgrade) ...
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
# Calculating Space Heating Specific Premiums (Ex: Removing Hydronic Boiler) ...
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ...  \
# 0         AL    Not in a census Place  G0100390  ...
# 1         AL  In another census Place  G0100150  ...
# 2         AL    Not in a census Place  G0100850  ...
# 3         AL    Not in a census Place  G0100050  ...
# 4         AL  In another census Place  G0101270  ...
# ...      ...                      ...       ...  ...
# 270013    WY  In another census Place  G5600050  ...
# 270014    WY  In another census Place  G5600050  ...
# 270015    WY    Not in a census Place  G5600010  ...
# 270016    WY                   Casper  G5600250  ...
# 270017    WY  In another census Place  G5600390  ...
#
#        preIRA_2036_cooking_savings_fuelCost rsMeans_CCI_avg  \
# 0                                     -5.23            3.00
# 1                                      0.00            3.00
# 2                                      0.00            3.00
# 3                                     -5.48            3.00
# 4                                      0.00            3.00
# ...                                     ...             ...
# 270013                                 0.00            3.00
# 270014                                 0.00            3.00
# 270015                                 0.00            3.00
# 270016                                 0.00            4.05
# 270017                                47.16            3.00
#
#        total_heating_load_kBtuh  baseline_AFUE  baseline_SEER baseline_HSPF  \
# 0                         92.75          100.0            NaN           NaN
# 1                        112.96          100.0            NaN           NaN
# 2                        107.16            NaN           15.0           8.5
# 3                         90.00           92.5            NaN           NaN
# 4                        127.09            NaN           13.0           7.7
# ...                         ...            ...            ...           ...
# 270013                   151.98          100.0            NaN           NaN
# 270014                   180.03           92.5            NaN           NaN
# 270015                   102.33           80.0            NaN           NaN
# 270016                    53.85           76.0            NaN           NaN
# 270017                    90.92          100.0            NaN           NaN
#
#        ugrade_newInstall_HSPF mp8_heating_installationCost  \
# 0                         NaN                     21671.35
# 1                         NaN                     22642.54
# 2                         NaN                     25968.46
# 3                         NaN                     19224.33
# 4                         NaN                     29309.75
# ...                       ...                          ...
# 270013                    NaN                     29424.64
# 270014                    NaN                     45014.39
# 270015                    NaN                     23095.25
# 270016                    NaN                     22012.08
# 270017                    NaN                     24784.14
#
#        mp8_heating_replacementCost mp8_heating_installation_premium
# 0                          7135.81                              0.0
# 1                          8291.85                              0.0
# 2                          8974.75                              0.0
# 3                          3261.46                              0.0
# 4                         16038.03                              0.0
# ...                            ...                              ...
# 270013                    10523.84                              0.0
# 270014                     3663.06                              0.0
# 270015                     3316.46                              0.0
# 270016                     4185.29                              0.0
# 270017                     7031.13                              0.0
#
# [270018 rows x 1420 columns]

# %% [markdown]
# ### Water Heating

# %%
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Capital Costs: Water Heating
------------------------------------------------------------------------------------------------------------------------------------------------

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
""")

cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
    'cost_per_gallon_progressive', 'cost_per_gallon_reference', 'cost_per_gallon_conservative',
]

# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_waterHeating_retrofit_costs[column] = round((df_waterHeating_retrofit_costs[column] * df_waterHeating_retrofit_costs['cpi_ratio'] * df_waterHeating_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_waterHeating_equipment_cost = df_waterHeating_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')
# dict_waterHeating_equipment_cost
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------
# Capital Costs: Water Heating
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...

# %%
# calculate_installation_cost(df, cost_dict, rsMeans_national_avg, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Electric Heat Pump Water Heater ...")
calculate_installation_cost(df_euss_am_mp8_home, dict_waterHeating_equipment_cost, rsMeans_national_avg, menu_mp, 'waterHeating')

# calculate_replacement_cost(df, cost_dict, rsMeans_national_avg, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
calculate_replacement_cost(df_euss_am_mp8_home, dict_waterHeating_equipment_cost, rsMeans_national_avg, menu_mp, 'waterHeating')

# Display the df
df_euss_am_mp8_home
# Out:
# Calculating Cost of Retrofit Upgrade: Electric Heat Pump Water Heater ...
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ... total_heating_load_kBtuh  \
# 0         AL    Not in a census Place  G0100390  ...                    92.75
# 1         AL  In another census Place  G0100150  ...                   112.96
# 2         AL    Not in a census Place  G0100850  ...                   107.16
# 3         AL    Not in a census Place  G0100050  ...                    90.00
# 4         AL  In another census Place  G0101270  ...                   127.09
# ...      ...                      ...       ...  ...                      ...
# 270013    WY  In another census Place  G5600050  ...                   151.98
# 270014    WY  In another census Place  G5600050  ...                   180.03
# 270015    WY    Not in a census Place  G5600010  ...                   102.33
# 270016    WY                   Casper  G5600250  ...                    53.85
# 270017    WY  In another census Place  G5600390  ...                    90.92
#
#        baseline_AFUE baseline_SEER  baseline_HSPF  ugrade_newInstall_HSPF  \
# 0              100.0           NaN            NaN                     NaN
# 1              100.0           NaN            NaN                     NaN
# 2                NaN          15.0            8.5                     NaN
# 3               92.5           NaN            NaN                     NaN
# 4                NaN          13.0            7.7                     NaN
# ...              ...           ...            ...                     ...
# 270013         100.0           NaN            NaN                     NaN
# 270014          92.5           NaN            NaN                     NaN
# 270015          80.0           NaN            NaN                     NaN
# 270016          76.0           NaN            NaN                     NaN
# 270017         100.0           NaN            NaN                     NaN
#
#        mp8_heating_installationCost mp8_heating_replacementCost  \
# 0                          21671.35                     7135.81
# 1                          22642.54                     8291.85
# 2                          25968.46                     8974.75
# 3                          19224.33                     3261.46
# 4                          29309.75                    16038.03
# ...                             ...                         ...
# 270013                     29424.64                    10523.84
# 270014                     45014.39                     3663.06
# 270015                     23095.25                     3316.46
# 270016                     22012.08                     4185.29
# 270017                     24784.14                     7031.13
#
#        mp8_heating_installation_premium mp8_waterHeating_installationCost  \
# 0                                   0.0                           2924.87
# 1                                   0.0                           2343.47
# 2                                   0.0                           2595.56
# 3                                   0.0                           2166.47
# 4                                   0.0                           2965.66
# ...                                 ...                               ...
# 270013                              0.0                           2770.37
# 270014                              0.0                           2587.80
# 270015                              0.0                           2425.39
# 270016                              0.0                           3572.90
# 270017                              0.0                           2711.67
#
#        mp8_waterHeating_replacementCost
# 0                                875.26
# 1                                875.26
# 2                                939.35
# 3                               1452.98
# 4                                875.26
# ...                                 ...
# 270013                           939.35
# 270014                          1654.36
# 270015                          1654.36
# 270016                          1961.52
# 270017                           875.26
#
# [270018 rows x 1422 columns]

# %% [markdown]
# ### Clothes Drying

# %%
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Capital Costs: Clothes Drying
------------------------------------------------------------------------------------------------------------------------------------------------

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ... 
""")

# Columns to update
cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
]
 
# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_clothesDrying_retrofit_costs[column] = round((df_clothesDrying_retrofit_costs[column] * df_clothesDrying_retrofit_costs['cpi_ratio'] * df_clothesDrying_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_clothesDrying_equipment_cost = df_clothesDrying_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')
# dict_clothesDrying_equipment_cost
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------
# Capital Costs: Clothes Drying
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...

# %%
# calculate_installation_cost(df, cost_dict, rsMeans_national_avg, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Ventless Heat Pump Clothes Dryer ...")
calculate_installation_cost(df_euss_am_mp8_home, dict_clothesDrying_equipment_cost, rsMeans_national_avg, menu_mp, 'clothesDrying')

# calculate_replacement_cost(df, cost_dict, rsMeans_national_avg, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
calculate_replacement_cost(df_euss_am_mp8_home, dict_clothesDrying_equipment_cost, rsMeans_national_avg, menu_mp, 'clothesDrying')

# Display the df
df_euss_am_mp8_home
# Out:
# Calculating Cost of Retrofit Upgrade: Ventless Heat Pump Clothes Dryer ...
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ... baseline_SEER  \
# 0         AL    Not in a census Place  G0100390  ...           NaN
# 1         AL  In another census Place  G0100150  ...           NaN
# 2         AL    Not in a census Place  G0100850  ...          15.0
# 3         AL    Not in a census Place  G0100050  ...           NaN
# 4         AL  In another census Place  G0101270  ...          13.0
# ...      ...                      ...       ...  ...           ...
# 270013    WY  In another census Place  G5600050  ...           NaN
# 270014    WY  In another census Place  G5600050  ...           NaN
# 270015    WY    Not in a census Place  G5600010  ...           NaN
# 270016    WY                   Casper  G5600250  ...           NaN
# 270017    WY  In another census Place  G5600390  ...           NaN
#
#        baseline_HSPF ugrade_newInstall_HSPF  mp8_heating_installationCost  \
# 0                NaN                    NaN                      21671.35
# 1                NaN                    NaN                      22642.54
# 2                8.5                    NaN                      25968.46
# 3                NaN                    NaN                      19224.33
# 4                7.7                    NaN                      29309.75
# ...              ...                    ...                           ...
# 270013           NaN                    NaN                      29424.64
# 270014           NaN                    NaN                      45014.39
# 270015           NaN                    NaN                      23095.25
# 270016           NaN                    NaN                      22012.08
# 270017           NaN                    NaN                      24784.14
#
#         mp8_heating_replacementCost mp8_heating_installation_premium  \
# 0                           7135.81                              0.0
# 1                           8291.85                              0.0
# 2                           8974.75                              0.0
# 3                           3261.46                              0.0
# 4                          16038.03                              0.0
# ...                             ...                              ...
# 270013                     10523.84                              0.0
# 270014                      3663.06                              0.0
# 270015                      3316.46                              0.0
# 270016                      4185.29                              0.0
# 270017                      7031.13                              0.0
#
#        mp8_waterHeating_installationCost mp8_waterHeating_replacementCost  \
# 0                                2924.87                           875.26
# 1                                2343.47                           875.26
# 2                                2595.56                           939.35
# 3                                2166.47                          1452.98
# 4                                2965.66                           875.26
# ...                                  ...                              ...
# 270013                           2770.37                           939.35
# 270014                           2587.80                          1654.36
# 270015                           2425.39                          1654.36
# 270016                           3572.90                          1961.52
# 270017                           2711.67                           875.26
#
#        mp8_clothesDrying_installationCost mp8_clothesDrying_replacementCost
# 0                                 1311.35                            869.44
# 1                                 1521.42                            869.44
# 2                                 1277.71                            869.44
# 3                                 1743.68                            869.44
# 4                                 1943.03                            869.44
# ...                                   ...                               ...
# 270013                             782.95                            869.44
# 270014                            2429.40                            869.44
# 270015                            1704.68                            869.44
# 270016                            2416.42                           1173.74
# 270017                            2095.74                            869.44
#
# [270018 rows x 1424 columns]

# %% [markdown]
# ### Cooking

# %%
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Capital Costs: Cooking
------------------------------------------------------------------------------------------------------------------------------------------------

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...      
""")

# Columns to update
cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
]
 
# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_cooking_retrofit_costs[column] = round((df_cooking_retrofit_costs[column] * df_cooking_retrofit_costs['cpi_ratio'] * df_cooking_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_cooking_equipment_cost = df_cooking_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')
# dict_cooking_equipment_cost
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------
# Capital Costs: Cooking
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...

# %%
# calculate_installation_cost(df, cost_dict, rsMeans_national_avg, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Electric Resistance Range ...")
calculate_installation_cost(df_euss_am_mp8_home, dict_cooking_equipment_cost, rsMeans_national_avg, menu_mp, 'cooking')

# calculate_replacement_cost(df, cost_dict, rsMeans_national_avg, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
calculate_replacement_cost(df_euss_am_mp8_home, dict_cooking_equipment_cost, rsMeans_national_avg, menu_mp, 'cooking')

# Display the df
df_euss_am_mp8_home
# Out:
# Calculating Cost of Retrofit Upgrade: Electric Resistance Range ...
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ... ugrade_newInstall_HSPF  \
# 0         AL    Not in a census Place  G0100390  ...                    NaN
# 1         AL  In another census Place  G0100150  ...                    NaN
# 2         AL    Not in a census Place  G0100850  ...                    NaN
# 3         AL    Not in a census Place  G0100050  ...                    NaN
# 4         AL  In another census Place  G0101270  ...                    NaN
# ...      ...                      ...       ...  ...                    ...
# 270013    WY  In another census Place  G5600050  ...                    NaN
# 270014    WY  In another census Place  G5600050  ...                    NaN
# 270015    WY    Not in a census Place  G5600010  ...                    NaN
# 270016    WY                   Casper  G5600250  ...                    NaN
# 270017    WY  In another census Place  G5600390  ...                    NaN
#
#        mp8_heating_installationCost mp8_heating_replacementCost  \
# 0                          21671.35                     7135.81
# 1                          22642.54                     8291.85
# 2                          25968.46                     8974.75
# 3                          19224.33                     3261.46
# 4                          29309.75                    16038.03
# ...                             ...                         ...
# 270013                     29424.64                    10523.84
# 270014                     45014.39                     3663.06
# 270015                     23095.25                     3316.46
# 270016                     22012.08                     4185.29
# 270017                     24784.14                     7031.13
#
#         mp8_heating_installation_premium  mp8_waterHeating_installationCost  \
# 0                                    0.0                            2924.87
# 1                                    0.0                            2343.47
# 2                                    0.0                            2595.56
# 3                                    0.0                            2166.47
# 4                                    0.0                            2965.66
# ...                                  ...                                ...
# 270013                               0.0                            2770.37
# 270014                               0.0                            2587.80
# 270015                               0.0                            2425.39
# 270016                               0.0                            3572.90
# 270017                               0.0                            2711.67
#
#        mp8_waterHeating_replacementCost mp8_clothesDrying_installationCost  \
# 0                                875.26                            1311.35
# 1                                875.26                            1521.42
# 2                                939.35                            1277.71
# 3                               1452.98                            1743.68
# 4                                875.26                            1943.03
# ...                                 ...                                ...
# 270013                           939.35                             782.95
# 270014                          1654.36                            2429.40
# 270015                          1654.36                            1704.68
# 270016                          1961.52                            2416.42
# 270017                           875.26                            2095.74
#
#        mp8_clothesDrying_replacementCost mp8_cooking_installationCost  \
# 0                                 869.44                       791.60
# 1                                 869.44                      1762.44
# 2                                 869.44                      1721.83
# 3                                 869.44                      2136.98
# 4                                 869.44                       545.36
# ...                                  ...                          ...
# 270013                            869.44                      1709.28
# 270014                            869.44                      1705.90
# 270015                            869.44                      1983.58
# 270016                           1173.74                      2191.03
# 270017                            869.44                      1469.64
#
#        mp8_cooking_replacementCost
# 0                           938.08
# 1                          1052.48
# 2                          1052.48
# 3                           938.08
# 4                          1052.48
# ...                            ...
# 270013                     1052.48
# 270014                     1052.48
# 270015                     1052.48
# 270016                     1420.85
# 270017                      938.08
#
# [270018 rows x 1426 columns]

# %%
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Calculate Private NPV for WHOLE-HOME
------------------------------------------------------------------------------------------------------------------------------------------------
""")

# Assume 15 year lifetime and 7% discount ratecalculate_private_NPV
# (df, interest_rate, input_mp, menu_mp, policy_scenario)
df_euss_am_mp8_home = calculate_private_NPV(df=df_euss_am_mp8_home,
                                            menu_mp=menu_mp,
                                            input_mp=input_mp,
                                            policy_scenario='No Inflation Reduction Act',
                                            interest_rate=0.07,
                                            )
df_euss_am_mp8_home
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------
# Calculate Private NPV for WHOLE-HOME
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Calculating for category: heating with lifetime: 15
#
# Calculating costs for category: heating, input_mp: upgrade08, menu_mp: 8, policy_scenario: No Inflation Reduction Act
# Weatherization cost (no IRA rebates): 0.0
# Calculated total_capital_cost: 0         21671.35
# 1         22642.54
# 2         25968.46
# 3         19224.33
# 4         29309.75
#             ...
# 270013    29424.64
# 270014    45014.39
# 270015    23095.25
# 270016    22012.08
# 270017    24784.14
# Length: 270018, dtype: float64, net_capital_cost: 0         14535.54
# 1         14350.69
# 2         16993.71
# 3         15962.87
# 4         13271.72
#             ...
# 270013    18900.80
# 270014    41351.33
# 270015    19778.79
# 270016    17826.79
# 270017    17753.01
# Length: 270018, dtype: float64
# Total capital cost for heating: 0         21671.35
# 1         22642.54
# 2         25968.46
# 3         19224.33
# 4         29309.75
#             ...
# 270013    29424.64
# 270014    45014.39
# 270015    23095.25
# 270016    22012.08
# 270017    24784.14
# Length: 270018, dtype: float64
# Net capital cost for heating: 0         14535.54
# 1         14350.69
# 2         16993.71
# 3         15962.87
# 4         13271.72
#             ...
# 270013    18900.80
# 270014    41351.33
# 270015    19778.79
# 270016    17826.79
# 270017    17753.01
# Length: 270018, dtype: float64
#
# Calculating NPV for category: heating, lifetime: 15, interest_rate: 0.07, policy_scenario: No Inflation Reduction Act
# Total discounted savings over 15 years for heating: 0          3950.881536
# 1          6177.952937
# 2          1576.001960
# 3           344.696591
# 4          2675.537967
#               ...
# 270013    41306.159195
# 270014    13012.451683
# 270015     5186.347219
# 270016     2724.290750
# 270017    19274.528925
# Length: 270018, dtype: float64
# Updated df_new_columns with NPV for heating:
#     preIRA_heating_total_capitalCost  preIRA_heating_net_capitalCost  \
# 0                          21671.35                        14535.54
# 1                          22642.54                        14350.69
# 2                          25968.46                        16993.71
# 3                          19224.33                        15962.87
# 4                          29309.75                        13271.72
#
#    preIRA_heating_private_npv_lessWTP  preIRA_heating_private_npv_moreWTP
# 0                           -17720.47                           -10584.66
# 1                           -16464.59                            -8172.74
# 2                           -24392.46                           -15417.71
# 3                           -18879.63                           -15618.17
# 4                           -26634.21                           -10596.18
#
# Calculating for category: waterHeating with lifetime: 12
#
# Calculating costs for category: waterHeating, input_mp: upgrade08, menu_mp: 8, policy_scenario: No Inflation Reduction Act
# Calculated total_capital_cost: 0         2924.87
# 1         2343.47
# 2         2595.56
# 3         2166.47
# 4         2965.66
#            ...
# 270013    2770.37
# 270014    2587.80
# 270015    2425.39
# 270016    3572.90
# 270017    2711.67
# Name: mp8_waterHeating_installationCost, Length: 270018, dtype: float64, net_capital_cost: 0         2049.61
# 1         1468.21
# 2         1656.21
# 3          713.49
# 4         2090.40
#            ...
# 270013    1831.02
# 270014     933.44
# 270015     771.03
# 270016    1611.38
# 270017    1836.41
# Length: 270018, dtype: float64
# Total capital cost for waterHeating: 0         2924.87
# 1         2343.47
# 2         2595.56
# 3         2166.47
# 4         2965.66
#            ...
# 270013    2770.37
# 270014    2587.80
# 270015    2425.39
# 270016    3572.90
# 270017    2711.67
# Name: mp8_waterHeating_installationCost, Length: 270018, dtype: float64
# Net capital cost for waterHeating: 0         2049.61
# 1         1468.21
# 2         1656.21
# 3          713.49
# 4         2090.40
#            ...
# 270013    1831.02
# 270014     933.44
# 270015     771.03
# 270016    1611.38
# 270017    1836.41
# Length: 270018, dtype: float64
#
# Calculating NPV for category: waterHeating, lifetime: 12, interest_rate: 0.07, policy_scenario: No Inflation Reduction Act
# Total discounted savings over 12 years for waterHeating: 0         1718.575591
# 1         2278.526441
# 2         2152.920042
# 3         1172.120523
# 4          905.212822
#              ...
# 270013    1603.877614
# 270014     717.012969
# 270015     723.358814
# 270016    1244.797126
# 270017    3144.465766
# Length: 270018, dtype: float64
# Updated df_new_columns with NPV for waterHeating:
#     preIRA_waterHeating_total_capitalCost  preIRA_waterHeating_net_capitalCost  \
# 0                                2924.87                              2049.61
# 1                                2343.47                              1468.21
# 2                                2595.56                              1656.21
# 3                                2166.47                               713.49
# 4                                2965.66                              2090.40
#
#    preIRA_waterHeating_private_npv_lessWTP  \
# 0                                 -1206.29
# 1                                   -64.94
# 2                                  -442.64
# 3                                  -994.35
# 4                                 -2060.45
#
#    preIRA_waterHeating_private_npv_moreWTP
# 0                                  -331.03
# 1                                   810.32
# 2                                   496.71
# 3                                   458.63
# 4                                 -1185.19
#
# Calculating for category: clothesDrying with lifetime: 13
#
# Calculating costs for category: clothesDrying, input_mp: upgrade08, menu_mp: 8, policy_scenario: No Inflation Reduction Act
# Calculated total_capital_cost: 0         1311.35
# 1         1521.42
# 2         1277.71
# 3         1743.68
# 4         1943.03
#            ...
# 270013     782.95
# 270014    2429.40
# 270015    1704.68
# 270016    2416.42
# 270017    2095.74
# Name: mp8_clothesDrying_installationCost, Length: 270018, dtype: float64, net_capital_cost: 0          441.91
# 1          651.98
# 2          408.27
# 3          874.24
# 4         1073.59
#            ...
# 270013     -86.49
# 270014    1559.96
# 270015     835.24
# 270016    1242.68
# 270017    1226.30
# Length: 270018, dtype: float64
# Total capital cost for clothesDrying: 0         1311.35
# 1         1521.42
# 2         1277.71
# 3         1743.68
# 4         1943.03
#            ...
# 270013     782.95
# 270014    2429.40
# 270015    1704.68
# 270016    2416.42
# 270017    2095.74
# Name: mp8_clothesDrying_installationCost, Length: 270018, dtype: float64
# Net capital cost for clothesDrying: 0          441.91
# 1          651.98
# 2          408.27
# 3          874.24
# 4         1073.59
#            ...
# 270013     -86.49
# 270014    1559.96
# 270015     835.24
# 270016    1242.68
# 270017    1226.30
# Length: 270018, dtype: float64
#
# Calculating NPV for category: clothesDrying, lifetime: 13, interest_rate: 0.07, policy_scenario: No Inflation Reduction Act
# Total discounted savings over 13 years for clothesDrying: 0         271.713989
# 1         640.281625
# 2         334.793137
# 3         248.334844
# 4         217.426287
#              ...
# 270013    324.678925
# 270014    171.218290
# 270015    171.218290
# 270016    391.741444
# 270017    205.403339
# Length: 270018, dtype: float64
# Updated df_new_columns with NPV for clothesDrying:
#     preIRA_clothesDrying_total_capitalCost  \
# 0                                 1311.35
# 1                                 1521.42
# 2                                 1277.71
# 3                                 1743.68
# 4                                 1943.03
#
#    preIRA_clothesDrying_net_capitalCost  \
# 0                                441.91
# 1                                651.98
# 2                                408.27
# 3                                874.24
# 4                               1073.59
#
#    preIRA_clothesDrying_private_npv_lessWTP  \
# 0                                  -1039.64
# 1                                   -881.14
# 2                                   -942.92
# 3                                  -1495.35
# 4                                  -1725.60
#
#    preIRA_clothesDrying_private_npv_moreWTP
# 0                                   -170.20
# 1                                    -11.70
# 2                                    -73.48
# 3                                   -625.91
# 4                                   -856.16
#
# Calculating for category: cooking with lifetime: 15
#
# Calculating costs for category: cooking, input_mp: upgrade08, menu_mp: 8, policy_scenario: No Inflation Reduction Act
# Calculated total_capital_cost: 0          791.60
# 1         1762.44
# 2         1721.83
# 3         2136.98
# 4          545.36
#            ...
# 270013    1709.28
# 270014    1705.90
# 270015    1983.58
# 270016    2191.03
# 270017    1469.64
# Name: mp8_cooking_installationCost, Length: 270018, dtype: float64, net_capital_cost: 0         -146.48
# 1          709.96
# 2          669.35
# 3         1198.90
# 4         -507.12
#            ...
# 270013     656.80
# 270014     653.42
# 270015     931.10
# 270016     770.18
# 270017     531.56
# Length: 270018, dtype: float64
# Total capital cost for cooking: 0          791.60
# 1         1762.44
# 2         1721.83
# 3         2136.98
# 4          545.36
#            ...
# 270013    1709.28
# 270014    1705.90
# 270015    1983.58
# 270016    2191.03
# 270017    1469.64
# Name: mp8_cooking_installationCost, Length: 270018, dtype: float64
# Net capital cost for cooking: 0         -146.48
# 1          709.96
# 2          669.35
# 3         1198.90
# 4         -507.12
#            ...
# 270013     656.80
# 270014     653.42
# 270015     931.10
# 270016     770.18
# 270017     531.56
# Length: 270018, dtype: float64
#
# Calculating NPV for category: cooking, lifetime: 15, interest_rate: 0.07, policy_scenario: No Inflation Reduction Act
# Total discounted savings over 15 years for cooking: 0         -77.077066
# 1           0.000000
# 2           0.000000
# 3         -80.285390
# 4           0.000000
#              ...
# 270013      0.000000
# 270014      0.000000
# 270015      0.000000
# 270016      0.000000
# 270017    412.815025
# Length: 270018, dtype: float64
# Updated df_new_columns with NPV for cooking:
#     preIRA_cooking_total_capitalCost  preIRA_cooking_net_capitalCost  \
# 0                            791.60                         -146.48
# 1                           1762.44                          709.96
# 2                           1721.83                          669.35
# 3                           2136.98                         1198.90
# 4                            545.36                         -507.12
#
#    preIRA_cooking_private_npv_lessWTP  preIRA_cooking_private_npv_moreWTP
# 0                             -868.68                               69.40
# 1                            -1762.44                             -709.96
# 2                            -1721.83                             -669.35
# 3                            -2217.27                            -1279.19
# 4                             -545.36                              507.12
# Final DataFrame after NPV calculations:
#     bldg_id  square_footage census_region     census_division  \
# 0      239          1690.0         South  East South Central
# 1      273          1690.0         South  East South Central
# 2      307          1220.0         South  East South Central
# 3      409          1220.0         South  East South Central
# 4      517          1220.0         South  East South Central
#
#   census_division_recs building_america_climate_zone cambium_GEA_region state  \
# 0   East South Central                     Hot-Humid              SRSOc    AL
# 1   East South Central                   Mixed-Humid              SRSOc    AL
# 2   East South Central                     Hot-Humid              SRSOc    AL
# 3   East South Central                     Hot-Humid              SRSOc    AL
# 4   East South Central                   Mixed-Humid              SRSOc    AL
#
#                       city    county  ...  \
# 0    Not in a census Place  G0100390  ...
# 1  In another census Place  G0100150  ...
# 2    Not in a census Place  G0100850  ...
# 3    Not in a census Place  G0100050  ...
# 4  In another census Place  G0101270  ...
#
#   preIRA_waterHeating_private_npv_lessWTP  \
# 0                                -1206.29
# 1                                  -64.94
# 2                                 -442.64
# 3                                 -994.35
# 4                                -2060.45
#
#   preIRA_waterHeating_private_npv_moreWTP  \
# 0                                 -331.03
# 1                                  810.32
# 2                                  496.71
# 3                                  458.63
# 4                                -1185.19
#
#   preIRA_clothesDrying_total_capitalCost  \
# 0                                1311.35
# 1                                1521.42
# 2                                1277.71
# 3                                1743.68
# 4                                1943.03
#
#    preIRA_clothesDrying_net_capitalCost  \
# 0                                441.91
# 1                                651.98
# 2                                408.27
# 3                                874.24
# 4                               1073.59
#
#    preIRA_clothesDrying_private_npv_lessWTP  \
# 0                                  -1039.64
# 1                                   -881.14
# 2                                   -942.92
# 3                                  -1495.35
# 4                                  -1725.60
#
#   preIRA_clothesDrying_private_npv_moreWTP preIRA_cooking_total_capitalCost  \
# 0                                  -170.20                           791.60
# 1                                   -11.70                          1762.44
# 2                                   -73.48                          1721.83
# 3                                  -625.91                          2136.98
# 4                                  -856.16                           545.36
#
#   preIRA_cooking_net_capitalCost preIRA_cooking_private_npv_lessWTP  \
# 0                        -146.48                            -868.68
# 1                         709.96                           -1762.44
# 2                         669.35                           -1721.83
# 3                        1198.90                           -2217.27
# 4                        -507.12                            -545.36
#
#   preIRA_cooking_private_npv_moreWTP
# 0                              69.40
# 1                            -709.96
# 2                            -669.35
# 3                           -1279.19
# 4                             507.12
#
# [5 rows x 1442 columns]
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ...  \
# 0         AL    Not in a census Place  G0100390  ...
# 1         AL  In another census Place  G0100150  ...
# 2         AL    Not in a census Place  G0100850  ...
# 3         AL    Not in a census Place  G0100050  ...
# 4         AL  In another census Place  G0101270  ...
# ...      ...                      ...       ...  ...
# 270013    WY  In another census Place  G5600050  ...
# 270014    WY  In another census Place  G5600050  ...
# 270015    WY    Not in a census Place  G5600010  ...
# 270016    WY                   Casper  G5600250  ...
# 270017    WY  In another census Place  G5600390  ...
#
#        preIRA_waterHeating_private_npv_lessWTP  \
# 0                                     -1206.29
# 1                                       -64.94
# 2                                      -442.64
# 3                                      -994.35
# 4                                     -2060.45
# ...                                        ...
# 270013                                -1166.49
# 270014                                -1870.79
# 270015                                -1702.03
# 270016                                -2328.10
# 270017                                  432.80
#
#        preIRA_waterHeating_private_npv_moreWTP  \
# 0                                      -331.03
# 1                                       810.32
# 2                                       496.71
# 3                                       458.63
# 4                                     -1185.19
# ...                                        ...
# 270013                                 -227.14
# 270014                                 -216.43
# 270015                                  -47.67
# 270016                                 -366.58
# 270017                                 1308.06
#
#        preIRA_clothesDrying_total_capitalCost  \
# 0                                     1311.35
# 1                                     1521.42
# 2                                     1277.71
# 3                                     1743.68
# 4                                     1943.03
# ...                                       ...
# 270013                                 782.95
# 270014                                2429.40
# 270015                                1704.68
# 270016                                2416.42
# 270017                                2095.74
#
#         preIRA_clothesDrying_net_capitalCost  \
# 0                                     441.91
# 1                                     651.98
# 2                                     408.27
# 3                                     874.24
# 4                                    1073.59
# ...                                      ...
# 270013                                -86.49
# 270014                               1559.96
# 270015                                835.24
# 270016                               1242.68
# 270017                               1226.30
#
#         preIRA_clothesDrying_private_npv_lessWTP  \
# 0                                       -1039.64
# 1                                        -881.14
# 2                                        -942.92
# 3                                       -1495.35
# 4                                       -1725.60
# ...                                          ...
# 270013                                   -458.27
# 270014                                  -2258.18
# 270015                                  -1533.46
# 270016                                  -2024.68
# 270017                                  -1890.34
#
#        preIRA_clothesDrying_private_npv_moreWTP  \
# 0                                       -170.20
# 1                                        -11.70
# 2                                        -73.48
# 3                                       -625.91
# 4                                       -856.16
# ...                                         ...
# 270013                                   411.17
# 270014                                 -1388.74
# 270015                                  -664.02
# 270016                                  -850.94
# 270017                                 -1020.90
#
#        preIRA_cooking_total_capitalCost preIRA_cooking_net_capitalCost  \
# 0                                791.60                        -146.48
# 1                               1762.44                         709.96
# 2                               1721.83                         669.35
# 3                               2136.98                        1198.90
# 4                                545.36                        -507.12
# ...                                 ...                            ...
# 270013                          1709.28                         656.80
# 270014                          1705.90                         653.42
# 270015                          1983.58                         931.10
# 270016                          2191.03                         770.18
# 270017                          1469.64                         531.56
#
#        preIRA_cooking_private_npv_lessWTP preIRA_cooking_private_npv_moreWTP
# 0                                 -868.68                              69.40
# 1                                -1762.44                            -709.96
# 2                                -1721.83                            -669.35
# 3                                -2217.27                           -1279.19
# 4                                 -545.36                             507.12
# ...                                   ...                                ...
# 270013                           -1709.28                            -656.80
# 270014                           -1705.90                            -653.42
# 270015                           -1983.58                            -931.10
# 270016                           -2191.03                            -770.18
# 270017                           -1056.82                            -118.74
#
# [270018 rows x 1442 columns]

# %%
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Home Retrofit Adoption without IRA Rebates
------------------------------------------------------------------------------------------------------------------------------------------------
""")
# adoption_decision(df, policy_scenario)
df_euss_am_mp8_home = adoption_decision(df=df_euss_am_mp8_home,
                                        policy_scenario='No Inflation Reduction Act'
                                        )
df_euss_am_mp8_home
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------
# Home Retrofit Adoption without IRA Rebates
# ------------------------------------------------------------------------------------------------------------------------------------------------
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ...  \
# 0         AL    Not in a census Place  G0100390  ...
# 1         AL  In another census Place  G0100150  ...
# 2         AL    Not in a census Place  G0100850  ...
# 3         AL    Not in a census Place  G0100050  ...
# 4         AL  In another census Place  G0101270  ...
# ...      ...                      ...       ...  ...
# 270013    WY  In another census Place  G5600050  ...
# 270014    WY  In another census Place  G5600050  ...
# 270015    WY    Not in a census Place  G5600010  ...
# 270016    WY                   Casper  G5600250  ...
# 270017    WY  In another census Place  G5600390  ...
#
#                  preIRA_waterHeating_adoption  \
# 0       Tier 3: Subsidy-Dependent Feasibility
# 1            Tier 2: Feasible vs. Alternative
# 2            Tier 2: Feasible vs. Alternative
# 3            Tier 2: Feasible vs. Alternative
# 4                              Tier 4: Averse
# ...                                       ...
# 270013  Tier 3: Subsidy-Dependent Feasibility
# 270014  Tier 3: Subsidy-Dependent Feasibility
# 270015  Tier 3: Subsidy-Dependent Feasibility
# 270016  Tier 3: Subsidy-Dependent Feasibility
# 270017                       Tier 1: Feasible
#
#        preIRA_waterHeating_retrofit_publicImpact  \
# 0                                 Public Benefit
# 1                                 Public Benefit
# 2                                 Public Benefit
# 3                                 Public Benefit
# 4                                 Public Benefit
# ...                                          ...
# 270013                            Public Benefit
# 270014                            Public Benefit
# 270015                            Public Benefit
# 270016                            Public Benefit
# 270017                            Public Benefit
#
#        preIRA_clothesDrying_total_npv_lessWTP  \
# 0                                     -720.89
# 1                                     -129.98
# 2                                     -550.14
# 3                                    -1203.97
# 4                                    -1470.51
# ...                                       ...
# 270013                                 -28.93
# 270014                               -2031.80
# 270015                               -1307.08
# 270016                               -1506.69
# 270017                               -1582.35
#
#         preIRA_clothesDrying_total_npv_moreWTP  \
# 0                                       148.55
# 1                                       739.46
# 2                                       319.30
# 3                                      -334.53
# 4                                      -601.07
# ...                                        ...
# 270013                                  840.51
# 270014                                -1162.36
# 270015                                 -437.64
# 270016                                 -332.95
# 270017                                 -712.91
#
#                 preIRA_clothesDrying_adoption  \
# 0       Tier 3: Subsidy-Dependent Feasibility
# 1       Tier 3: Subsidy-Dependent Feasibility
# 2       Tier 3: Subsidy-Dependent Feasibility
# 3                              Tier 4: Averse
# 4                              Tier 4: Averse
# ...                                       ...
# 270013       Tier 2: Feasible vs. Alternative
# 270014                         Tier 4: Averse
# 270015                         Tier 4: Averse
# 270016                         Tier 4: Averse
# 270017                         Tier 4: Averse
#
#        preIRA_clothesDrying_retrofit_publicImpact  \
# 0                                  Public Benefit
# 1                                  Public Benefit
# 2                                  Public Benefit
# 3                                  Public Benefit
# 4                                  Public Benefit
# ...                                           ...
# 270013                             Public Benefit
# 270014                             Public Benefit
# 270015                             Public Benefit
# 270016                             Public Benefit
# 270017                             Public Benefit
#
#        preIRA_cooking_total_npv_lessWTP preIRA_cooking_total_npv_moreWTP  \
# 0                                392.98                          1331.06
# 1                              -1762.44                          -709.96
# 2                              -1721.83                          -669.35
# 3                               -916.88                            21.20
# 4                               -545.36                           507.12
# ...                                 ...                              ...
# 270013                         -1709.28                          -656.80
# 270014                         -1705.90                          -653.42
# 270015                         -1983.58                          -931.10
# 270016                         -2191.03                          -770.18
# 270017                           267.65                          1205.73
#
#                       preIRA_cooking_adoption  \
# 0            Tier 2: Feasible vs. Alternative
# 1                          Existing Equipment
# 2                          Existing Equipment
# 3       Tier 3: Subsidy-Dependent Feasibility
# 4                          Existing Equipment
# ...                                       ...
# 270013                     Existing Equipment
# 270014                     Existing Equipment
# 270015                     Existing Equipment
# 270016                     Existing Equipment
# 270017  Tier 3: Subsidy-Dependent Feasibility
#
#        preIRA_cooking_retrofit_publicImpact
# 0                            Public Benefit
# 1                               No Retrofit
# 2                               No Retrofit
# 3                            Public Benefit
# 4                               No Retrofit
# ...                                     ...
# 270013                          No Retrofit
# 270014                          No Retrofit
# 270015                          No Retrofit
# 270016                          No Retrofit
# 270017                       Public Benefit
#
# [270018 rows x 1458 columns]

# %% [markdown]
# # Basic IRA-Reference Scenario:
# ## - NREL End-Use Savings Shapes Database: Measure Package 8
# ## - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
# ## - Bistline et al 2023 INFLATION REDUCTION ACT DECARB (AVERAGE IN RANGE)

# %%
# Measure Package 8
scenario_name = 'Basic-IRA'
cost_scenario = 'IRA Rebates'
grid_scenario = 'Current Electricity Grid'

print(f"""
-------------------------------------------------------------------------------------------------------
MODEL SCENARIO
-------------------------------------------------------------------------------------------------------
Scenario {scenario_name}:
Basic Retrofit: Measure Package {menu_mp}
{cost_scenario}
{grid_scenario}
-------------------------------------------------------------------------------------------------------
""")
# Out:
# -------------------------------------------------------------------------------------------------------
# MODEL SCENARIO
# -------------------------------------------------------------------------------------------------------
# Scenario Basic-IRA:
# Basic Retrofit: Measure Package 8
# IRA Rebates
# Current Electricity Grid
# -------------------------------------------------------------------------------------------------------

# %%
print("Calculating Marginal Damages for each end-use ...")

# calculate_marginal_damages(df, grid_decarb, scenario, emis_fossilFuel_lookup, damages_electricity_lookup)
df_euss_am_mp8_home = calculate_marginal_damages(df=df_euss_am_mp8_home,
                                                 menu_mp=menu_mp,
                                                 policy_scenario='AEO2023 Reference Case',
                                                 )
df_euss_am_mp8_home
# Out:
# Calculating Marginal Damages for each end-use ...
# Calculating damages from 2022 to 2037 for heating
# Calculating damages from 2022 to 2034 for waterHeating
# Calculating damages from 2022 to 2035 for clothesDrying
# Calculating damages from 2022 to 2037 for cooking
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ...  \
# 0         AL    Not in a census Place  G0100390  ...
# 1         AL  In another census Place  G0100150  ...
# 2         AL    Not in a census Place  G0100850  ...
# 3         AL    Not in a census Place  G0100050  ...
# 4         AL  In another census Place  G0101270  ...
# ...      ...                      ...       ...  ...
# 270013    WY  In another census Place  G5600050  ...
# 270014    WY  In another census Place  G5600050  ...
# 270015    WY    Not in a census Place  G5600010  ...
# 270016    WY                   Casper  G5600250  ...
# 270017    WY  In another census Place  G5600390  ...
#
#        iraRef_mp8_2036_cooking_damages_nox  \
# 0                                     0.09
# 1                                     0.10
# 2                                     0.10
# 3                                     0.09
# 4                                     0.07
# ...                                    ...
# 270013                                0.04
# 270014                                0.04
# 270015                                0.04
# 270016                                0.05
# 270017                                0.12
#
#        iraRef_mp8_2036_cooking_reduction_damages_nox  \
# 0                                               1.06
# 1                                               0.29
# 2                                               0.29
# 3                                               1.13
# 4                                               0.20
# ...                                              ...
# 270013                                          0.13
# 270014                                          0.13
# 270015                                          0.13
# 270016                                          0.16
# 270017                                          1.12
#
#        iraRef_mp8_2036_cooking_damages_pm25  \
# 0                                      0.43
# 1                                      0.50
# 2                                      0.50
# 3                                      0.45
# 4                                      0.35
# ...                                     ...
# 270013                                 0.16
# 270014                                 0.16
# 270015                                 0.16
# 270016                                 0.19
# 270017                                 0.22
#
#         iraRef_mp8_2036_cooking_reduction_damages_pm25  \
# 0                                                 3.27
# 1                                                 1.42
# 2                                                 1.42
# 3                                                 3.39
# 4                                                 1.00
# ...                                                ...
# 270013                                            0.45
# 270014                                            0.45
# 270015                                            0.45
# 270016                                            0.55
# 270017                                            1.60
#
#         iraRef_mp8_2036_cooking_damages_co2  \
# 0                                     16.97
# 1                                     19.35
# 2                                     19.35
# 3                                     17.52
# 4                                     13.58
# ...                                     ...
# 270013                                11.61
# 270014                                11.61
# 270015                                11.61
# 270016                                13.92
# 270017                                16.50
#
#        iraRef_mp8_2036_cooking_reduction_damages_co2  \
# 0                                              99.24
# 1                                              21.98
# 2                                              21.98
# 3                                             102.27
# 4                                              15.44
# ...                                              ...
# 270013                                         13.19
# 270014                                         13.19
# 270015                                         13.19
# 270016                                         15.82
# 270017                                         99.07
#
#        iraRef_mp8_2036_cooking_damages_health  \
# 0                                        0.70
# 1                                        0.80
# 2                                        0.80
# 3                                        0.72
# 4                                        0.56
# ...                                       ...
# 270013                                   0.34
# 270014                                   0.34
# 270015                                   0.34
# 270016                                   0.41
# 270017                                   0.82
#
#        iraRef_mp8_2036_cooking_damages_climate  \
# 0                                        16.97
# 1                                        19.35
# 2                                        19.35
# 3                                        17.52
# 4                                        13.58
# ...                                        ...
# 270013                                   11.61
# 270014                                   11.61
# 270015                                   11.61
# 270016                                   13.92
# 270017                                   16.50
#
#        iraRef_mp8_2036_cooking_reduction_damages_health  \
# 0                                                  5.58
# 1                                                  2.29
# 2                                                  2.29
# 3                                                  5.82
# 4                                                  1.61
# ...                                                 ...
# 270013                                             0.98
# 270014                                             0.98
# 270015                                             0.98
# 270016                                             1.19
# 270017                                             6.10
#
#        iraRef_mp8_2036_cooking_reduction_damages_climate
# 0                                                  99.24
# 1                                                  21.98
# 2                                                  21.98
# 3                                                 102.27
# 4                                                  15.44
# ...                                                  ...
# 270013                                             13.19
# 270014                                             13.19
# 270015                                             13.19
# 270016                                             15.82
# 270017                                             99.07
#
# [270018 rows x 2118 columns]

# %%
print("Calculating Public NPV for each end-use ...")
# calculate_public_npv(df, menu_mp, policy_scenario, equipment_specs, interest_rate=0.02)
df_euss_am_mp8_home = calculate_public_npv(df=df_euss_am_mp8_home,
                                           menu_mp=menu_mp,
                                           policy_scenario='AEO2023 Reference Case',
                                           equipment_specs=equipment_specs,
                                           interest_rate=0.02,
                                           )
df_euss_am_mp8_home
# Out:
# Calculating Public NPV for each end-use ...
#         bldg_id  square_footage census_region     census_division  \
# 0           239          1690.0         South  East South Central
# 1           273          1690.0         South  East South Central
# 2           307          1220.0         South  East South Central
# 3           409          1220.0         South  East South Central
# 4           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 270013   548109          1690.0          West            Mountain
# 270014   548226          2176.0          West            Mountain
# 270015   548228          1690.0          West            Mountain
# 270016   548417           885.0          West            Mountain
# 270017   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone cambium_GEA_region  \
# 0        East South Central                     Hot-Humid              SRSOc
# 1        East South Central                   Mixed-Humid              SRSOc
# 2        East South Central                     Hot-Humid              SRSOc
# 3        East South Central                     Hot-Humid              SRSOc
# 4        East South Central                   Mixed-Humid              SRSOc
# ...                     ...                           ...                ...
# 270013       Mountain North                          Cold              RMPAc
# 270014       Mountain North                          Cold              RMPAc
# 270015       Mountain North                          Cold              RMPAc
# 270016       Mountain North                          Cold              RMPAc
# 270017       Mountain North                     Very Cold              NWPPc
#
#        state                     city    county  ...  \
# 0         AL    Not in a census Place  G0100390  ...
# 1         AL  In another census Place  G0100150  ...
# 2         AL    Not in a census Place  G0100850  ...
# 3         AL    Not in a census Place  G0100050  ...
# 4         AL  In another census Place  G0101270  ...
# ...      ...                      ...       ...  ...
# 270013    WY  In another census Place  G5600050  ...
# 270014    WY  In another census Place  G5600050  ...
# 270015    WY    Not in a census Place  G5600010  ...
# 270016    WY                   Casper  G5600250  ...
# 270017    WY  In another census Place  G5600390  ...
#
#        iraRef_mp8_heating_public_npv iraRef_mp8_waterHeating_climate_npv  \
# 0                            5083.04                             1992.36
# 1                            7816.46                             2657.37
# 2                            2455.46                             2507.66
# 3                            2313.30                             6688.99
# 4                            3978.75                             1070.38
# ...                              ...                                 ...
# 270013                      56433.22                             2191.36
# 270014                     106251.78                             6037.90
# 270015                      51659.62                             6305.14
# 270016                      25243.93                            10654.29
# 270017                      30618.72                             4705.94
#
#        iraRef_mp8_waterHeating_health_npv  iraRef_mp8_waterHeating_public_npv  \
# 0                                  146.72                             2139.09
# 1                                  195.93                             2853.29
# 2                                  184.85                             2692.50
# 3                                  360.78                             7049.76
# 4                                   79.07                             1149.44
# ...                                   ...                                 ...
# 270013                              96.98                             2288.34
# 270014                             185.27                             6223.15
# 270015                             189.34                             6494.48
# 270016                             321.53                            10975.83
# 270017                             375.69                             5081.61
#
#         iraRef_mp8_clothesDrying_climate_npv  \
# 0                                     369.40
# 1                                     870.71
# 2                                     455.21
# 3                                     337.78
# 4                                     295.58
# ...                                      ...
# 270013                                494.52
# 270014                                260.81
# 270015                                260.81
# 270016                                596.76
# 270017                                347.95
#
#        iraRef_mp8_clothesDrying_health_npv  \
# 0                                    27.98
# 1                                    65.99
# 2                                    34.51
# 3                                    25.60
# 4                                    22.43
# ...                                    ...
# 270013                               23.08
# 270014                               12.18
# 270015                               12.18
# 270016                               27.91
# 270017                               29.03
#
#        iraRef_mp8_clothesDrying_public_npv iraRef_mp8_cooking_climate_npv  \
# 0                                   397.39                        1359.00
# 1                                   936.73                         175.70
# 2                                   489.71                         175.70
# 3                                   363.38                        1400.05
# 4                                   318.00                         123.36
# ...                                    ...                            ...
# 270013                              517.62                         105.42
# 270014                              273.01                         105.42
# 270015                              273.01                         105.42
# 270016                              624.66                         126.45
# 270017                              376.99                        1413.64
#
#        iraRef_mp8_cooking_health_npv iraRef_mp8_cooking_public_npv
# 0                              70.73                       1429.71
# 1                              15.87                        191.55
# 2                              15.87                        191.55
# 3                              73.83                       1473.90
# 4                              11.22                        134.56
# ...                              ...                           ...
# 270013                          6.86                        112.25
# 270014                          6.86                        112.25
# 270015                          6.86                        112.25
# 270016                          8.24                        134.70
# 270017                         77.04                       1490.68
#
# [270018 rows x 2130 columns]

# %%
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Post-Retrofit (MP) Fuel Cost: WHOLE-HOME
------------------------------------------------------------------------------------------------------------------------------------------------
""")
# calculate_annual_fuelCost(df, menu_mp, policy_scenario)
df_euss_am_mp8_home = calculate_annual_fuelCost(df=df_euss_am_mp8_home,
                                                menu_mp=menu_mp,
                                                policy_scenario='AEO2023 Reference Case',
                                                )
df_euss_am_mp8_home
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------
# Post-Retrofit (MP) Fuel Cost: WHOLE-HOME
# ------------------------------------------------------------------------------------------------------------------------------------------------
#
# Calculating POST-RETROFIT (MP8) fuel costs from 2022 to 2037 for heating

# %%
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Home Retrofit Adoption with IRA Rebates
------------------------------------------------------------------------------------------------------------------------------------------------
""")

# %%
# Determine Percent AMI and Rebate Amounts
# Create a copy of the results df and define it as results_IRA
# This needs to be done before running the calculate_percent_AMI function
df_euss_am_mp8_home = df_euss_am_mp8_home.copy()

# calculate_percent_AMI(df_results_IRA, df_county_medianIncome):
df_euss_am_mp8_home = calculate_percent_AMI(df_euss_am_mp8_home, df_county_medianIncome)

print("Calculating rebate amounts for Space Heating ...")
calculate_rebateIRA(df_euss_am_mp8_home, "heating", menu_mp)

print("Calculating rebate amounts for Water Heating ...")
calculate_rebateIRA(df_euss_am_mp8_home, "waterHeating", menu_mp)

print("Calculating rebate amounts for Clothes Drying ...")
calculate_rebateIRA(df_euss_am_mp8_home, "clothesDrying", menu_mp)

print("Calculating rebate amounts for Cooking ...")
calculate_rebateIRA(df_euss_am_mp8_home, "cooking", menu_mp)

# %%
print("Calculating Private NPV for each end-use ...")
# Assume 15 year lifetime and 7% discount rate
# calculate_private_NPV(df, interest_rate, input_mp, menu_mp, ira_rebates=False)
df_euss_am_mp8_home = calculate_private_NPV(df=df_euss_am_mp8_home,
                                            interest_rate=0.07,
                                            menu_mp=menu_mp,
                                            input_mp=input_mp,
                                            policy_scenario='AEO2023 Reference Case',
                                            )
df_euss_am_mp8_home

# %%
print("Determining Adoption Decision for each end-use ...")

# adoption_decision(df, policy_scenario)
df_euss_am_mp8_home = adoption_decision(df=df_euss_am_mp8_home,
                                        policy_scenario='AEO2023 Reference Case'
                                        )
df_euss_am_mp8_home

# %% [markdown]
# # Basic IRA-High Scenario:
# ## - NREL End-Use Savings Shapes Database: Measure Package 8
# ## - AEO2023 HIGH UPTAKE OF INFLATION REDUCTION ACT - HDD and Fuel Price Projections
# ## - Bistline et al 2023 INFLATION REDUCTION ACT DECARB (UPPER BOUND IN RANGE)

# %%
# Measure Package 8
scenario_name = 'Basic-IRA-High'
cost_scenario = 'High Uptake of IRA - Fuel Price Projections'
grid_scenario = 'Bistline Upper Bound'

print(f"""
-------------------------------------------------------------------------------------------------------
MODEL SCENARIO
-------------------------------------------------------------------------------------------------------
Scenario {scenario_name}:
Basic Retrofit: Measure Package {menu_mp}
{cost_scenario}
{grid_scenario}
-------------------------------------------------------------------------------------------------------
""")

# %%
print("Calculating Marginal Damages for each end-use ...")

# calculate_marginal_damages(df, grid_decarb, scenario, emis_fossilFuel_lookup, damages_electricity_lookup)
df_euss_am_mp8_home = calculate_marginal_damages(df=df_euss_am_mp8_home,
                                                 menu_mp=menu_mp,
                                                 policy_scenario='High Uptake of Inflation Reduction Act',
                                                 )
df_euss_am_mp8_home

# %%
print("Calculating Public NPV for each end-use ...")
# calculate_public_npv(df, menu_mp, policy_scenario, equipment_specs, interest_rate=0.02)
df_euss_am_mp8_home = calculate_public_npv(df=df_euss_am_mp8_home,
                                           menu_mp=menu_mp,
                                           policy_scenario='High Uptake of Inflation Reduction Act',
                                           equipment_specs=equipment_specs,
                                           interest_rate=0.02,
                                           )
df_euss_am_mp8_home

# %%
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Post-Retrofit (MP) Fuel Cost: WHOLE-HOME
------------------------------------------------------------------------------------------------------------------------------------------------
""")
# calculate_annual_fuelCost(df, menu_mp, policy_scenario)
df_euss_am_mp8_home = calculate_annual_fuelCost(df=df_euss_am_mp8_home,
                                                menu_mp=menu_mp,
                                                policy_scenario='High Uptake of Inflation Reduction Act',
                                                )
df_euss_am_mp8_home

# %%
## PRIVATE NPV
print("""
------------------------------------------------------------------------------------------------------------------------------------------------
Calculate Private NPV for WHOLE-HOME
------------------------------------------------------------------------------------------------------------------------------------------------
""")

# Assume 15 year lifetime and 7% discount ratecalculate_private_NPV
# (df, interest_rate, input_mp, menu_mp, policy_scenario)
df_euss_am_mp8_home = calculate_private_NPV(df=df_euss_am_mp8_home,
                                            menu_mp=menu_mp,
                                            input_mp=input_mp,
                                            policy_scenario='High Uptake of Inflation Reduction Act',
                                            interest_rate=0.07,
                                            )
df_euss_am_mp8_home

# %%
print("Determining Adoption Decision for each end-use ...")
# adoption_decision(df, policy_scenario)
df_euss_am_mp8_home = adoption_decision(df=df_euss_am_mp8_home,
                                        policy_scenario='High Uptake of Inflation Reduction Act'
                                        )
df_euss_am_mp8_home

# %% [markdown]
# # Model Runtime

# %%
# Get the current datetime again
end_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Calculate the elapsed time
elapsed_time = datetime.strptime(end_time, "%Y-%m-%d_%H-%M-%S") - datetime.strptime(start_time, "%Y-%m-%d_%H-%M-%S")

# Format the elapsed time
elapsed_seconds = elapsed_time.total_seconds()
elapsed_minutes = int(elapsed_seconds // 60)
elapsed_seconds = int(elapsed_seconds % 60)

# Print the elapsed time
print(f"The code took {elapsed_minutes} minutes and {elapsed_seconds} seconds to execute.")
