# %%
# Set columns in display
# pd.set_option('display.max_columns', None)
# pd.reset_option('display.max_columns') # Reset options to default

# Set rows in display
# pd.set_option('display.max_rows', None)
# pd.reset_option('display.max_rows') # Reset options to default

# %% [markdown]
# # Load Util File with TARE Model Functions

# %%
import os

# Measure Package 0: Baseline
menu_mp = 0
input_mp = 'baseline'

# Get the current working directory of the project
project_root = os.path.abspath(os.getcwd())
print(f"Project root directory: {project_root}")

# Relative path to the file from the project root
relative_path = r"tare_model_functions_v1.5.ipynb"

# Construct the absolute path to the file
file_path = os.path.join(project_root, relative_path)
print(f"File path: {file_path}")

# Run the notebook and import variables
if os.path.exists(relative_path):
    get_ipython().run_line_magic('run', f'-i "{relative_path}"')
    print("Loaded All TARE Model Functions")
else:
    print(f"File not found: {relative_path}")
# Out:
# Project root directory: c:\Users\14128\Research\cmu-tare-model
# File path: c:\Users\14128\Research\cmu-tare-model\tare_model_functions_v1.5.ipynb
# Loaded All TARE Model Functions

# %%
# Storing Result Outputs in output_results folder
relative_path = r"output_results"
output_folder_path = os.path.join(project_root, relative_path)
print(f"Result outputs will be exported here: {output_folder_path}")
# Out:
# Result outputs will be exported here: c:\Users\14128\Research\cmu-tare-model\output_results

# %% [markdown]
# # Simulate Residential Energy Consumption using NREL End-Use Savings Shapes
# - Filter EUSS Data: Only occupied units and Single Family Homes

# %%
# The ``inline`` flag will use the appropriate backend to make figures appear inline in the notebook.  
# %matplotlib inline

import pandas as pd
import numpy as np

# `plt` is an alias for the `matplotlib.pyplot` module
import matplotlib.pyplot as plt

# import seaborn library (wrapper of matplotlib)
import seaborn as sns
sns.set(style="darkgrid")

# For regex, import re
import re

from datetime import datetime

# Get the current datetime
# Start the timer
start_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# %%
print("""
-------------------------------------------------------------------------------------------------------
Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
Let's start by reading the data from the NREL EUSS Database.

Make sure that the zipped folders stay organized as they are once unzipped.
If changes are made to the file path, then the program will not run properly.
-------------------------------------------------------------------------------------------------------

-------------------------------------------------------------------------------------------------------
BASELINE (Measure Package 0)
-------------------------------------------------------------------------------------------------------
""")

# Measure Package 0: Baseline
menu_mp = 0
input_mp = 'baseline'

filename = "baseline_metadata_and_annual_results.csv"
relative_path = os.path.join(r"euss_data\resstock_amy2018_release_1.1\state", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")

print("""
-------------------------------------------------------------------------------------------------------
Data Filters: Only occupied units and Single Family Homes
-------------------------------------------------------------------------------------------------------
""")

# Fix DtypeWarning error in columns:
# 'in.neighbors', 'in.geometry_stories_low_rise', 'in.iso_rto_region', 'in.pv_orientation', 'in.pv_system_size'
columns_to_string = {11: str, 61: str, 121: str, 103: str, 128: str, 129: str}
df_euss_am_baseline = pd.read_csv(file_path, dtype=columns_to_string)
occupancy_filter = df_euss_am_baseline['in.vacancy_status'] == 'Occupied'
df_euss_am_baseline = df_euss_am_baseline.loc[occupancy_filter]

# Filter for single family home building type
house_type_list = ['Single-Family Attached', 'Single-Family Detached']
house_type_filter = df_euss_am_baseline['in.geometry_building_type_recs'].isin(house_type_list)
df_euss_am_baseline = df_euss_am_baseline.loc[house_type_filter]
# df_euss_am_baseline
# Out:
# -------------------------------------------------------------------------------------------------------
# Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
# Let's start by reading the data from the NREL EUSS Database.
#
# Make sure that the zipped folders stay organized as they are once unzipped.
# If changes are made to the file path, then the program will not run properly.
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# BASELINE (Measure Package 0)
# -------------------------------------------------------------------------------------------------------
#
# Retrieved data for filename: baseline_metadata_and_annual_results.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\euss_data\resstock_amy2018_release_1.1\state\baseline_metadata_and_annual_results.csv
#
# -------------------------------------------------------------------------------------------------------
# Data Filters: Only occupied units and Single Family Homes
# -------------------------------------------------------------------------------------------------------

# %%
# # Create a location ID for the name of the batch conversion file
# while True:
#     if menu_state == 'N':
#         location_id = 'National'
#         print("You chose to analyze all of the United States.")
#         break
#     elif menu_state == 'Y':
#         if menu_city == 'N':
#             try:
#                 location_id = str(input_state)
#                 print(f"Location ID is: {location_id}")
#                 break
#             except ValueError:
#                 print("Invalid input for state!")
#         elif menu_city == 'Y':
#             try:
#                 location_id = input_cityFilter.replace(', ', '_').strip()
#                 print(f"Location ID is: {location_id}")
#                 break
#             except AttributeError:
#                 print("Invalid input for city filter!")
#         else:
#             print("Incorrect state or city filter assignment!")
#     else:
#         print("Invalid data location. Check your inputs at the beginning of this notebook!")

# %%
# # Make a copy of the dataframe
# df_euss_am_baseline = df_euss_am_baseline.copy()

# Choose between national or sub-national level analysis
menu_state = get_menu_choice(menu_prompt, {'N', 'Y'})   # This code is only run in baseline

# National Level 
if menu_state == 'N':
    print("You chose to analyze all of the United States.")
    input_state = 'National'
    location_id = 'National'

# Filter down to state or city
else:
    input_state = get_state_choice(df_euss_am_baseline)    
    print(f"You chose to filter for: {input_state}")

    location_id = str(input_state)
    print(f"Location ID is: {location_id}")


    state_filter = df_euss_am_baseline['in.state'].eq(input_state)
    df_euss_am_baseline = df_euss_am_baseline.loc[state_filter]

    print(city_prompt)
    print(df_euss_am_baseline['in.city'].value_counts())

    menu_city = get_menu_choice(city_menu_prompt, {'N', 'Y'})

    # Filter for the entire selected state
    if menu_city == 'N':
        print(f"You chose to analyze all of state: {input_state}")
        
        location_id = str(input_state)
        print(f"Location ID is: {location_id}")
        
    # Filter to a city within the selected state
    else:
        input_cityFilter = get_city_choice(df_euss_am_baseline, input_state)
        print(f"You chose to filter for: {input_state}, {input_cityFilter}")

        location_id = input_cityFilter.replace(', ', '_').strip()
        print(f"Location ID is: {location_id}")

        city_filter = df_euss_am_baseline['in.city'].eq(f"{input_state}, {input_cityFilter}")
        df_euss_am_baseline = df_euss_am_baseline.loc[city_filter]

# Display the filtered dataframe
df_euss_am_baseline
# Out:
# You chose to analyze all of the United States.
#         bldg_id  upgrade      weight  applicability  in.sqft  \
# 2           239        0  242.131013           True   1690.0
# 3           273        0  242.131013           True   1690.0
# 4           307        0  242.131013           True   1220.0
# 5           409        0  242.131013           True   1220.0
# 7           517        0  242.131013           True   1220.0
# ...         ...      ...         ...            ...      ...
# 548907   548226        0  242.131013           True   2176.0
# 548908   548228        0  242.131013           True   1690.0
# 548910   548417        0  242.131013           True    885.0
# 548914   549740        0  242.131013           True   1220.0
# 548915   549938        0  242.131013           True    885.0
#
#                       in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# 2       Non-CBSA East South Central                               3A
# 3       Non-CBSA East South Central                               3A
# 4       Non-CBSA East South Central                               3A
# 5       Non-CBSA East South Central                               3A
# 7       Non-CBSA East South Central                               3A
# ...                             ...                              ...
# 548907            Non-CBSA Mountain                               6B
# 548908            Non-CBSA Mountain                               6B
# 548910            Non-CBSA Mountain                               6B
# 548914            Non-CBSA Mountain                               7B
# 548915            Non-CBSA Mountain                               6B
#
#        in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# 2                                              3A                     Hour20
# 3                                              3A                     Hour12
# 4                                              3A                      Hour0
# 5                                              3A                     Hour20
# 7                                              3A                      Hour1
# ...                                           ...                        ...
# 548907                                         6B                      Hour3
# 548908                                         6B                      Hour6
# 548910                                         6B                     Hour18
# 548914                                         7B                      Hour4
# 548915                                         6B                      Hour2
#
#         in.bedrooms  ...  \
# 2                 3  ...
# 3                 3  ...
# 4                 4  ...
# 5                 2  ...
# 7                 3  ...
# ...             ...  ...
# 548907            4  ...
# 548908            4  ...
# 548910            2  ...
# 548914            2  ...
# 548915            2  ...
#
#        out.emissions.natural_gas.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# 2                                              215.943534
# 3                                                0.000000
# 4                                                0.000000
# 5                                             1642.477930
# 7                                                0.000000
# ...                                                   ...
# 548907                                       15324.356044
# 548908                                        8192.601682
# 548910                                        5212.758359
# 548914                                           0.000000
# 548915                                        9625.513133
#
#        out.emissions.propane.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# 2                                                0.000000
# 3                                                0.000000
# 4                                                0.000000
# 5                                                0.000000
# 7                                                0.000000
# ...                                                   ...
# 548907                                           0.000000
# 548908                                           0.000000
# 548910                                           0.000000
# 548914                                         268.627834
# 548915                                           0.000000
#
#        out.emissions.electricity.lrmer_mid_case_15_2025_start.co2e_kg  \
# 2                                             8773.384074
# 3                                            11296.731129
# 4                                             8750.011820
# 5                                             5725.103641
# 7                                             8932.439414
# ...                                                   ...
# 548907                                        2313.298407
# 548908                                        1889.439924
# 548910                                        2112.907195
# 548914                                       11423.104685
# 548915                                        1109.233379
#
#        out.emissions.fuel_oil.lrmer_mid_case_15_2025_start.co2e_kg  \
# 2                                                     0.0
# 3                                                     0.0
# 4                                                     0.0
# 5                                                     0.0
# 7                                                     0.0
# ...                                                   ...
# 548907                                                0.0
# 548908                                                0.0
# 548910                                                0.0
# 548914                                                0.0
# 548915                                                0.0
#
#        out.emissions.natural_gas.lrmer_mid_case_15_2025_start.co2e_kg  \
# 2                                              215.943534
# 3                                                0.000000
# 4                                                0.000000
# 5                                             1642.477930
# 7                                                0.000000
# ...                                                   ...
# 548907                                       15324.356044
# 548908                                        8192.601682
# 548910                                        5212.758359
# 548914                                           0.000000
# 548915                                        9625.513133
#
#        out.emissions.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# 2                                                0.000000
# 3                                                0.000000
# 4                                                0.000000
# 5                                                0.000000
# 7                                                0.000000
# ...                                                   ...
# 548907                                           0.000000
# 548908                                           0.000000
# 548910                                           0.000000
# 548914                                         268.627834
# 548915                                           0.000000
#
#        out.emissions.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# 2                                             3565.038262
# 3                                             4339.903757
# 4                                             3345.187937
# 5                                             3784.993820
# 7                                             3441.414837
# ...                                                   ...
# 548907                                       16802.023908
# 548908                                        9394.122057
# 548910                                        6546.826589
# 548914                                        7173.561517
# 548915                                       10320.128613
#
#        out.emissions.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# 2                                             6416.193347
# 3                                             8193.678510
# 4                                             6249.625611
# 5                                             5489.549041
# 7                                             6415.303853
# ...                                                   ...
# 548907                                       16545.095582
# 548908                                        9195.903552
# 548910                                        6318.763521
# 548914                                        5931.433285
# 548915                                       10198.241539
#
#        out.emissions.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# 2                                             5755.373221
# 3                                             7254.665194
# 4                                             5587.946834
# 5                                             5164.458936
# 7                                             5721.073473
# ...                                                   ...
# 548907                                       16472.920871
# 548908                                        9129.578822
# 548910                                        6253.986448
# 548914                                        4609.821155
# 548915                                       10166.744085
#
#        out.emissions.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg
#   2032: 0.85375854214123,
#   2033: 0.8496583143507973,
#   2034: 0.8460136674259681,
#   2035: 0.8423690205011389,
#   2036: 0.8382687927107062,
#   2037: 0.834624145785877,
#   2038: 0.8309794988610478,
#   2039: 0.826879271070615,
#   2040: 0.8232346241457859,
#   2041: 0.8195899772209567,
#   2042: 0.8159453302961276,
#   2043: 0.8123006833712985,
#   2044: 0.8082004555808656,
#   2045: 0.8045558086560365,
#   2046: 0.8009111617312072,
#   2047: 0.7972665148063781,
#   2048: 0.793621867881549,
#   2049: 0.7899772209567198,
#   2050: 0.7863325740318906}}

# %%
print("""
-------------------------------------------------------------------------------------------------------
Baseline Consumption:
-------------------------------------------------------------------------------------------------------
""")

# df_baseline_enduse(df_baseline, df_enduse, category, fuel_filter='Yes', tech_filter='Yes')
df_euss_am_baseline_home = df_enduse_refactored(df_baseline = df_euss_am_baseline,
                                                fuel_filter = 'Yes',
                                                tech_filter = 'Yes')

# Project Future Energy Consumption
df_euss_am_baseline_home = project_future_consumption(df=df_euss_am_baseline_home, hdd_factor_lookup=hdd_factor_lookup, menu_mp=menu_mp)
df_euss_am_baseline_home
# Out:
# -------------------------------------------------------------------------------------------------------
# Baseline Consumption:
# -------------------------------------------------------------------------------------------------------
#
# Processing column: in.clothes_dryer
# Initial data types: object
# Data types after processing: object
# Processing column: in.cooking_range
# Initial data types: object
# Data types after processing: object
# 331531 rows remain after applying total heating consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 321357 rows remain after applying heating fuel filter
# Filtered for the following Heating technologies: ['Electricity ASHP', 'Electricity Baseboard', 'Electricity Electric Boiler', 'Electricity Electric Furnace', 'Fuel Oil Fuel Boiler', 'Fuel Oil Fuel Furnace', 'Natural Gas Fuel Boiler', 'Natural Gas Fuel Furnace', 'Propane Fuel Boiler', 'Propane Fuel Furnace']
# 291558 rows remain after applying heating technology filter
# 291558 rows remain after applying total waterHeating consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 291191 rows remain after applying waterHeating fuel filter
# Filtered for the following Water Heating technologies: ['Electric Heat Pump, 80 gal', 'Electric Premium', 'Electric Standard', 'Fuel Oil Premium', 'Fuel Oil Standard', 'Natural Gas Premium', 'Natural Gas Standard', 'Propane Premium', 'Propane Standard']
# 284744 rows remain after applying waterHeating technology filter
# 284744 rows remain after applying total clothesDrying consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 272458 rows remain after applying clothesDrying fuel filter
# 272458 rows remain after applying total cooking consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 270018 rows remain after applying cooking fuel filter
# Projecting Future Energy Consumption (Baseline Equipment): heating
# Projecting Future Energy Consumption (Baseline Equipment): waterHeating
# Projecting Future Energy Consumption (Baseline Equipment): clothesDrying
# Projecting Future Energy Consumption (Baseline Equipment): cooking
#         bldg_id  square_footage census_region     census_division  \
# 2           239          1690.0         South  East South Central
# 3           273          1690.0         South  East South Central
# 4           307          1220.0         South  East South Central
# 5           409          1220.0         South  East South Central
# 7           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 548905   548109          1690.0          West            Mountain
# 548907   548226          2176.0          West            Mountain
# 548908   548228          1690.0          West            Mountain
# 548910   548417           885.0          West            Mountain
# 548914   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone  \
# 2        East South Central                     Hot-Humid
# 3        East South Central                   Mixed-Humid
# 4        East South Central                     Hot-Humid
# 5        East South Central                     Hot-Humid
# 7        East South Central                   Mixed-Humid
# ...                     ...                           ...
# 548905       Mountain North                          Cold
# 548907       Mountain North                          Cold
# 548908       Mountain North                          Cold
# 548910       Mountain North                          Cold
# 548914       Mountain North                     Very Cold
#
#         reeds_balancing_area gea_region state                     city  ...  \
# 2                         90      SRSOc    AL    Not in a census Place  ...
# 3                         90      SRSOc    AL  In another census Place  ...
# 4                         90      SRSOc    AL    Not in a census Place  ...
# 5                         90      SRSOc    AL    Not in a census Place  ...
# 7                         89      SRSOc    AL  In another census Place  ...
# ...                      ...        ...   ...                      ...  ...
# 548905                    23      RMPAc    WY  In another census Place  ...
# 548907                    23      RMPAc    WY  In another census Place  ...
# 548908                    24      RMPAc    WY    Not in a census Place  ...
# 548910                    24      RMPAc    WY                   Casper  ...
# 548914                    21      NWPPc    WY  In another census Place  ...
#
#        baseline_2029_cooking_consumption baseline_2030_cooking_consumption  \
# 2                                 979.44                            979.44
# 3                                 537.20                            537.20
# 4                                 537.20                            537.20
# 5                                1009.63                           1009.63
# 7                                 377.18                            377.18
# ...                                  ...                               ...
# 548905                            405.61                            405.61
# 548907                            405.61                            405.61
# 548908                            405.61                            405.61
# 548910                            486.50                            486.50
# 548914                           1009.63                           1009.63
#
#        baseline_2031_cooking_consumption baseline_2032_cooking_consumption  \
# 2                                 979.44                            979.44
# 3                                 537.20                            537.20
# 4                                 537.20                            537.20
# 5                                1009.63                           1009.63
# 7                                 377.18                            377.18
# ...                                  ...                               ...
# 548905                            405.61                            405.61
# 548907                            405.61                            405.61
# 548908                            405.61                            405.61
# 548910                            486.50                            486.50
# 548914                           1009.63                           1009.63
#
#         baseline_2033_cooking_consumption  baseline_2034_cooking_consumption  \
# 2                                  979.44                             979.44
# 3                                  537.20                             537.20
# 4                                  537.20                             537.20
# 5                                 1009.63                            1009.63
# 7                                  377.18                             377.18
# ...                                   ...                                ...
# 548905                             405.61                             405.61
# 548907                             405.61                             405.61
# 548908                             405.61                             405.61
# 548910                             486.50                             486.50
# 548914                            1009.63                            1009.63
#
#        baseline_2035_cooking_consumption baseline_2036_cooking_consumption  \
# 2                                 979.44                            979.44
# 3                                 537.20                            537.20
# 4                                 537.20                            537.20
# 5                                1009.63                           1009.63
# 7                                 377.18                            377.18
# ...                                  ...                               ...
# 548905                            405.61                            405.61
# 548907                            405.61                            405.61
# 548908                            405.61                            405.61
# 548910                            486.50                            486.50
# 548914                           1009.63                           1009.63
#
#        baseline_2037_cooking_consumption baseline_2038_cooking_consumption
# 2                                 979.44                            979.44
# 3                                 537.20                            537.20
# 4                                 537.20                            537.20
# 5                                1009.63                           1009.63
# 7                                 377.18                            377.18
# ...                                  ...                               ...
# 548905                            405.61                            405.61
# 548907                            405.61                            405.61
# 548908                            405.61                            405.61
# 548910                            486.50                            486.50
# 548914                           1009.63                           1009.63
#
# [270018 rows x 104 columns]

# %% [markdown]
# # Public Perspective: Monetized Marginal Damages from Emissions

# %% [markdown]
# ## Fossil Fuels: Climate and Health-Related Pollutants

# %%
# Calculate emissions factors for fossil fuels
# This is before adjusting for natural gas leakage
# Note: We use electricity marginal damages directly instead of multiplying
# CEDM emissions factors by the EASIUR marginal damages. 
def calculate_fossilFuel_emission_factor(fuel_type, so2_factor, nox_factor, pm25_factor, fuelConversion_factor1, fuelConversion_factor2):
    """
    Calculate Emissions Factors: FOSSIL FUELS
    Fossil Fuels (Natural Gas, Fuel Oil, Propane):
    - NOx, SO2, CO2: 
        - RESNET Table 7.1.2 Emissions Factors for Household Combustion Fuels
        - Source: https://www.resnet.us/wp-content/uploads/ANSIRESNETICC301-2022_resnetpblshd.pdf
        - All factors are in units of lb/Mbtu so energy consumption in kWh need to be converted to kWh 
        - (1 lb / Mbtu) * (1 Mbtu / 1x10^6 Btu) * (3412 Btu / 1 kWh)
    - PM2.5: 
        - A National Methodology and Emission Inventory for Residential Fuel Combustion
        - Source: https://www3.epa.gov/ttnchie1/conference/ei12/area/haneke.pdf
    """
    
    # Create an empty dictionary called margEmis_factors to store the values
    margEmis_factors = {}

    # SO2, NOx, CO2: (_ lb / Mbtu) * (1 Mbtu / 1x10^6 Btu) * (3412 Btu / 1 kWh)
    # PM2.5 - FUEL OIL: 0.83 lb/thousand gallons * (1 thousand gallons / 1000 gallons) * (1 gallon heating oil/138,500 BTU) * (3412 BTU/1 kWh)
    # PM2.5 - NATURAL GAS: 1.9 lb/million cf * (million cf/1000000 cf) * (1 cf natural gas/1039 BTU) * (3412 BTU/1 kWh)
    # PM2.5 - PROPANE: 0.17 lb/thousand gallons * (1 thousand gallons / 1000 gallons) * (1 gallon propane/91,452 BTU) * (3412 BTU/1 kWh)
    margEmis_factors[f"{fuel_type}_so2"] = so2_factor * (1 / 1000000) * (3412 / 1)
    margEmis_factors[f"{fuel_type}_nox"] = nox_factor * (1 / 1000000) * (3412 / 1)
    margEmis_factors[f"{fuel_type}_pm25"] = pm25_factor * (1 / fuelConversion_factor1) * (1 / fuelConversion_factor2) * (3412 / 1)

    # NATURAL GAS LEAKAGE: NATURAL GAS INFRASTRUCTURE
    # leakage rate for natural gas infrastructure
    # 1 Therm = 29.30 kWh --> 1.27 kg CO2e/therm * (1 therm/29.30 kWh) = 0.043 kg CO2e/kWh = 0.095 lb CO2e/kWh
    naturalGas_leakage_mtCO2e_perkWh = 0.043 * (1/1000)

    # CO2e include pre- and post-combustion emissions
    margEmis_factors[f"naturalGas_co2e"] = (228.5 * (1/1000) * (1/1000)) + naturalGas_leakage_mtCO2e_perkWh
    margEmis_factors[f"propane_co2e"]  = 275.8 * (1/1000) * (1/1000)
    margEmis_factors[f"fuelOil_co2e"]  = 303.9 * (1/1000) * (1/1000)

    return margEmis_factors

print("""
-------------------------------------------------------------------------------------------------------
Calculate Emissions Factors: FOSSIL FUELS
-------------------------------------------------------------------------------------------------------
Fossil Fuels (Natural Gas, Fuel Oil, Propane):
- NOx, SO2, CO2: 
    - RESNET Table 7.1.2 Emissions Factors for Household Combustion Fuels
    - Source: https://www.resnet.us/wp-content/uploads/ANSIRESNETICC301-2022_resnetpblshd.pdf
    - All factors are in units of lb/Mbtu so energy consumption in kWh need to be converted to kWh 
    - (1 lb / Mbtu) * (1 Mbtu / 1x10^6 Btu) * (3412 Btu / 1 kWh)
- PM2.5: 
    - A National Methodology and Emission Inventory for Residential Fuel Combustion
    - Source: https://www3.epa.gov/ttnchie1/conference/ei12/area/haneke.pdf
-------------------------------------------------------------------------------------------------------
""")

fuelOil_factors = calculate_fossilFuel_emission_factor(fuel_type="fuelOil", so2_factor=0.0015, nox_factor=0.1300, pm25_factor=0.83, fuelConversion_factor1=1000, fuelConversion_factor2=138500)
naturalGas_factors = calculate_fossilFuel_emission_factor(fuel_type="naturalGas", so2_factor=0.0006, nox_factor=0.0922, pm25_factor=1.9, fuelConversion_factor1=1000000, fuelConversion_factor2=1039)
propane_factors = calculate_fossilFuel_emission_factor(fuel_type="propane", so2_factor=0.0002, nox_factor=0.1421, pm25_factor=0.17, fuelConversion_factor1=1000, fuelConversion_factor2=91452)

all_factors = {**fuelOil_factors, **naturalGas_factors, **propane_factors}

df_margEmis_factors = pd.DataFrame.from_dict(all_factors, orient="index", columns=["value"])
df_margEmis_factors.reset_index(inplace=True)
df_margEmis_factors.columns = ["pollutant", "value"]
df_margEmis_factors[["fuel_type", "pollutant"]] = df_margEmis_factors["pollutant"].str.split("_", expand=True)
# df_margEmis_factors["unit"] = "[lb/kWh]"

# Update the units to metric tons per kWh
df_margEmis_factors["unit"] = "[mt/kWh]"

# Convert the values from lb/kWh to mt/kWh
lb_to_mt = 0.00045359237
df_margEmis_factors["value"] = df_margEmis_factors["value"] * lb_to_mt

# Add the 'state' column and assign 'National' to every row
df_margEmis_factors = df_margEmis_factors.assign(state='National')

df_margEmis_factors = df_margEmis_factors[["state", "fuel_type", "pollutant", "value", "unit"]]
df_margEmis_factors
# Out:
# -------------------------------------------------------------------------------------------------------
# Calculate Emissions Factors: FOSSIL FUELS
# -------------------------------------------------------------------------------------------------------
# Fossil Fuels (Natural Gas, Fuel Oil, Propane):
# - NOx, SO2, CO2:
#     - RESNET Table 7.1.2 Emissions Factors for Household Combustion Fuels
#     - Source: https://www.resnet.us/wp-content/uploads/ANSIRESNETICC301-2022_resnetpblshd.pdf
#     - All factors are in units of lb/Mbtu so energy consumption in kWh need to be converted to kWh
#     - (1 lb / Mbtu) * (1 Mbtu / 1x10^6 Btu) * (3412 Btu / 1 kWh)
# - PM2.5:
#     - A National Methodology and Emission Inventory for Residential Fuel Combustion
#     - Source: https://www3.epa.gov/ttnchie1/conference/ei12/area/haneke.pdf
# -------------------------------------------------------------------------------------------------------
#        state   fuel_type pollutant         value      unit
# 0   National     fuelOil       so2  2.321486e-09  [mt/kWh]
# 1   National     fuelOil       nox  2.011954e-07  [mt/kWh]
# 2   National     fuelOil      pm25  9.274769e-09  [mt/kWh]
# 3   National  naturalGas      co2e  1.231503e-07  [mt/kWh]
# 4   National     propane      co2e  1.251008e-07  [mt/kWh]
# 5   National     fuelOil      co2e  1.378467e-07  [mt/kWh]
# 6   National  naturalGas       so2  9.285943e-10  [mt/kWh]
# 7   National  naturalGas       nox  1.426940e-07  [mt/kWh]
# 8   National  naturalGas      pm25  2.830172e-09  [mt/kWh]
# 9   National     propane       so2  3.095314e-10  [mt/kWh]
# 10  National     propane       nox  2.199221e-07  [mt/kWh]
# 11  National     propane      pm25  2.876938e-09  [mt/kWh]

# %%
# Extract fossil fuel emissions factors from the dataframe
emis_factors_fossil_fuels = {
    'naturalGas': {
        'co2e': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'naturalGas') & (df_margEmis_factors['pollutant'] == 'co2e')]['value'].values[0],
        'so2': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'naturalGas') & (df_margEmis_factors['pollutant'] == 'so2')]['value'].values[0],
        'nox': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'naturalGas') & (df_margEmis_factors['pollutant'] == 'nox')]['value'].values[0],
        'pm25': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'naturalGas') & (df_margEmis_factors['pollutant'] == 'pm25')]['value'].values[0]
        },
    'propane': {
        'co2e': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'propane') & (df_margEmis_factors['pollutant'] == 'co2e')]['value'].values[0],
        'so2': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'propane') & (df_margEmis_factors['pollutant'] == 'so2')]['value'].values[0],
        'nox': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'propane') & (df_margEmis_factors['pollutant'] == 'nox')]['value'].values[0],
        'pm25': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'propane') & (df_margEmis_factors['pollutant'] == 'pm25')]['value'].values[0]
        },
    'fuelOil': {
        'co2e': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'fuelOil') & (df_margEmis_factors['pollutant'] == 'co2e')]['value'].values[0],
        'so2': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'fuelOil') & (df_margEmis_factors['pollutant'] == 'so2')]['value'].values[0],
        'nox': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'fuelOil') & (df_margEmis_factors['pollutant'] == 'nox')]['value'].values[0],
        'pm25': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'fuelOil') & (df_margEmis_factors['pollutant'] == 'pm25')]['value'].values[0]
        }
    }

emis_factors_fossil_fuels

# %% [markdown]
# ## Emissions from Electricity Generation

# %% [markdown]
# ### Climate-Related Emissions from CAMBIUM LRMER/SRMER
# ### Includes pre-combustion (fugitive) and combustion

# %%
from scipy.interpolate import interp1d
import numpy as np
import pandas as pd

def calculate_electricity_co2e_cambium(df_cambium_import):
    """
    Interpolates Cambium electricity emission factors and converts units.

    This function takes a dataframe containing Cambium electricity emission factors and performs the following:
    - Interpolates the Long Run Marginal Emissions Rates (LRMER) and Short Run Marginal Emissions Rates (SRMER)
      values for each scenario and GEA region on an annual basis.
    - Converts the LRMER and SRMER values from kg per MWh to tons per MWh and tons per kWh.

    Parameters
    ----------
    df_cambium_import : pandas.DataFrame
        DataFrame containing Cambium electricity emission factors with the following columns:
        - 'scenario': Scenario name or identifier.
        - 'gea_region': GEA region identifier.
        - 'year': Year of the data.
        - 'lrmer_co2e_kg_per_MWh': Long Run Marginal Emissions Rate in kg CO2e per MWh.
        - 'srmer_co2e_kg_per_MWh': Short Run Marginal Emissions Rate in kg CO2e per MWh.

    Returns
    -------
    df_cambium_import_copy : pandas.DataFrame
        DataFrame with interpolated LRMER and SRMER values for each year and additional columns for emission factors
        converted to tons per MWh and tons per kWh.

    Notes
    -----
    - The interpolation is performed linearly between the available years for each unique combination of scenario and GEA region.
    - The converted emission factors are added as new columns:
        - 'lrmer_co2e_ton_per_MWh'
        - 'lrmer_co2e_ton_per_kWh'
        - 'srmer_co2e_ton_per_MWh'
        - 'srmer_co2e_ton_per_kWh'
    - The conversion from kg to tons is done by dividing by 1,000 (1 ton = 1,000 kg).
    - The conversion from MWh to kWh is done by dividing by 1,000 (1 MWh = 1,000 kWh).

    """
    # Create a copy of the dataframe
    df_cambium_import_copy = df_cambium_import.copy()

    # Create a new DataFrame to store interpolated results
    interpolated_data = []

    # Group by 'scenario', 'state', and 'gea_region'
    grouped = df_cambium_import_copy.groupby(['scenario', 'gea_region'])

    for (scenario, gea_region), group in grouped:
        years = group['year'].values

        # Interpolate for LRMER (Long Run Marginal Emissions Rates)
        lrmer_values = group['lrmer_co2e_kg_per_MWh'].values
        lrmer_interp_func = interp1d(years, lrmer_values, kind='linear')

        # Interpolate for SRMER (Short Run Marginal Emissions Rates)
        srmer_values = group['srmer_co2e_kg_per_MWh'].values
        srmer_interp_func = interp1d(years, srmer_values, kind='linear')

        # Generate new years in 1-year increments
        new_years = np.arange(years.min(), years.max() + 1)

        # Interpolate the LRMER and SRMER values for these new years
        new_lrmer_values = lrmer_interp_func(new_years)
        new_srmer_values = srmer_interp_func(new_years)

        # Store the results in a DataFrame
        interpolated_group = pd.DataFrame({
            'scenario': scenario,
            'gea_region': gea_region,
            'year': new_years,
            'lrmer_co2e_kg_per_MWh': new_lrmer_values,
            'srmer_co2e_kg_per_MWh': new_srmer_values
        })

        interpolated_data.append(interpolated_group)

    # Concatenate all the interpolated data into a single DataFrame
    df_cambium_import_copy = pd.concat(interpolated_data).reset_index(drop=True)

    # Convert both LRMER and SRMER values to tons per MWh and tons per kWh
    df_cambium_import_copy['lrmer_co2e_ton_per_MWh'] = df_cambium_import_copy['lrmer_co2e_kg_per_MWh'] / 1000
    df_cambium_import_copy['lrmer_co2e_ton_per_kWh'] = df_cambium_import_copy['lrmer_co2e_kg_per_MWh'] / 1_000_000

    df_cambium_import_copy['srmer_co2e_ton_per_MWh'] = df_cambium_import_copy['srmer_co2e_kg_per_MWh'] / 1000
    df_cambium_import_copy['srmer_co2e_ton_per_kWh'] = df_cambium_import_copy['srmer_co2e_kg_per_MWh'] / 1_000_000

    return df_cambium_import_copy

def create_cambium_co2e_lookup(df_cambium_processed):
    """
    Creates a nested lookup dictionary for Cambium emission factors.

    This function takes a processed dataframe containing Cambium emission factors and constructs a nested dictionary
    that allows quick lookup of LRMER and SRMER emission factors based on scenario, GEA region, and year.

    Parameters
    ----------
    df_cambium_processed : pandas.DataFrame
        DataFrame containing processed Cambium emission factors with the following columns:
        - 'scenario': Scenario name or identifier.
        - 'gea_region': GEA region identifier.
        - 'year': Year of the data.
        - 'lrmer_co2e_ton_per_kWh': Long Run Marginal Emissions Rate in tons CO2e per kWh.
        - 'srmer_co2e_ton_per_kWh': Short Run Marginal Emissions Rate in tons CO2e per kWh.

    Returns
    -------
    emis_scenario_cambium_lookup : dict
        Nested dictionary structured as:
        {
            (scenario, gea_region): {
                year: {
                    'lrmer_co2e': lrmer_value,
                    'srmer_co2e': srmer_value
                },
                ...
            },
            ...
        }

    Notes
    -----
    - The outer keys of the dictionary are tuples containing (scenario, gea_region).
    - The inner dictionary maps years to a dictionary containing both LRMER and SRMER values.
    - This structure allows efficient retrieval of emission factors based on scenario, location, and year.

    """

    # Create a copy of the dataframe
    df_cambium_processed_copy = df_cambium_processed.copy()

    # Create the nested lookup dictionary for both LRMER and SRMER in tons CO2e per kWh
    emis_scenario_cambium_lookup = {}

    # Populate the dictionary
    for _, row in df_cambium_processed_copy.iterrows():
        outer_key = (row['scenario'], row['gea_region'])
        year = row['year']

        # Extract both LRMER and SRMER values in tons per kWh
        lrmer_value = row['lrmer_co2e_ton_per_kWh']
        srmer_value = row['srmer_co2e_ton_per_kWh']

        # Initialize the outer key if not already present
        if outer_key not in emis_scenario_cambium_lookup:
            emis_scenario_cambium_lookup[outer_key] = {}

        # Assign both LRMER and SRMER values in the inner dictionary for each year
        emis_scenario_cambium_lookup[outer_key][year] = {
            'lrmer_co2e': lrmer_value,
            'srmer_co2e': srmer_value
        }

    return emis_scenario_cambium_lookup

# %%
# INTERPOLATE ANNUAL DATA BETWEEN 5-YEAR TIME STEPS
print("""
-------------------------------------------------------------------------------------------------------
CLIMATE DAMAGES FROM CAMBIUM
-------------------------------------------------------------------------------------------------------
- Load CSV
- Convert MWh --> kWh and kg --> metric tons (mt)
- Inflate updated Social Cost of Carbon from $190 USD2020 to $USD2023
- Convert SCC to $USD2023/lb
- Calculate damage factors for CO2e: LRMER[lb/kWh] * SCC[$USD2023/lb] = $USD2023/kWh
- Map state, county pairs to Cambium 2023 GEA region

Possibly for other emissions projections:
- Calculate projection factors for each group of scenario and GEA region for 2025 to 2050 (normalize all annual data in group by 2025 value) 
-------------------------------------------------------------------------------------------------------
""")
# Out:
# -------------------------------------------------------------------------------------------------------
# CLIMATE DAMAGES FROM CAMBIUM
# -------------------------------------------------------------------------------------------------------
# - Load CSV
# - Convert MWh --> kWh and kg --> metric tons (mt)
# - Inflate updated Social Cost of Carbon from $190 USD2020 to $USD2023
# - Convert SCC to $USD2023/lb
# - Calculate damage factors for CO2e: LRMER[lb/kWh] * SCC[$USD2023/lb] = $USD2023/kWh
# - Map state, county pairs to Cambium 2023 GEA region
#
# Possibly for other emissions projections:
# - Calculate projection factors for each group of scenario and GEA region for 2025 to 2050 (normalize all annual data in group by 2025 value)
# -------------------------------------------------------------------------------------------------------

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

print("""
-------------------------------------------------------------------------------------------------------
PRE-IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2021 RELEASE
-------------------------------------------------------------------------------------------------------
""")

# CAMBIUM 2021 FOR PRE-IRA SCENARIO
filename = 'cambium21_midCase_annual_gea.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_cambium21_margEmis_electricity = pd.read_excel(io=file_path, sheet_name='proc_Cambium21_MidCase_gea')

print(f"""
Retrieved data for filename: {filename}
Located at filepath: {file_path}

Loading dataframe ...
Creating lookup dictionary for LRMER and SRMER ...
-------------------------------------------------------------------------------------------------------
""")

# Calculate electricity emission factors for Cambium 2021
# Process the data using the provided function to interpolate and convert units
df_cambium21_processed = calculate_electricity_co2e_cambium(df_cambium21_margEmis_electricity)

# Display the processed DataFrame
df_cambium21_processed
# Out:
# -------------------------------------------------------------------------------------------------------
# PRE-IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2021 RELEASE
# -------------------------------------------------------------------------------------------------------
#
#
# Retrieved data for filename: cambium21_midCase_annual_gea.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\cambium21_midCase_annual_gea.xlsx
#
# Loading dataframe ...
# Creating lookup dictionary for LRMER and SRMER ...
# -------------------------------------------------------------------------------------------------------
#     scenario gea_region  year  lrmer_co2e_kg_per_MWh  srmer_co2e_kg_per_MWh  \
# 0    MidCase      AZNMc  2022                 525.60                  811.8
# 1    MidCase      AZNMc  2023                 507.00                  810.1
# 2    MidCase      AZNMc  2024                 488.40                  808.4
# 3    MidCase      AZNMc  2025                 455.75                  812.2
# 4    MidCase      AZNMc  2026                 423.10                  816.0
# ..       ...        ...   ...                    ...                    ...
# 575  MidCase      SRVCc  2046                 320.60                  754.9
# 576  MidCase      SRVCc  2047                 319.25                  753.1
# 577  MidCase      SRVCc  2048                 317.90                  751.3
# 578  MidCase      SRVCc  2049                 312.30                  734.8
# 579  MidCase      SRVCc  2050                 306.70                  718.3
#
#      lrmer_co2e_ton_per_MWh  lrmer_co2e_ton_per_kWh  srmer_co2e_ton_per_MWh  \
# 0                   0.52560                0.000526                  0.8118
# 1                   0.50700                0.000507                  0.8101
# 2                   0.48840                0.000488                  0.8084
# 3                   0.45575                0.000456                  0.8122
# 4                   0.42310                0.000423                  0.8160
# ..                      ...                     ...                     ...
# 575                 0.32060                0.000321                  0.7549
# 576                 0.31925                0.000319                  0.7531
# 577                 0.31790                0.000318                  0.7513
# 578                 0.31230                0.000312                  0.7348
# 579                 0.30670                0.000307                  0.7183
#
#      srmer_co2e_ton_per_kWh
# 0                  0.000812
# 1                  0.000810
# 2                  0.000808
# 3                  0.000812
# 4                  0.000816
# ..                      ...
# 575                0.000755
# 576                0.000753
# 577                0.000751
# 578                0.000735
# 579                0.000718
#
# [580 rows x 9 columns]

# %%
# Create the lookup dictionary using the create_cambium_emission_factor_lookup function
emis_preIRA_co2e_cambium21_lookup = create_cambium_co2e_lookup(df_cambium21_processed)

# Display the lookup dictionary
emis_preIRA_co2e_cambium21_lookup
# Out:
# {('MidCase',
#   'AZNMc'): {2022: {'lrmer_co2e': 0.0005256,
#    'srmer_co2e': 0.0008118}, 2023: {'lrmer_co2e': 0.000507, 'srmer_co2e': 0.0008100999999999999}, 2024: {'lrmer_co2e': 0.0004883999999999999,
#    'srmer_co2e': 0.0008084}, 2025: {'lrmer_co2e': 0.00045575,
#    'srmer_co2e': 0.0008122}, 2026: {'lrmer_co2e': 0.00042310000000000004,
#    'srmer_co2e': 0.000816}, 2027: {'lrmer_co2e': 0.00036945000000000006,
#    'srmer_co2e': 0.00080035}, 2028: {'lrmer_co2e': 0.00031580000000000003,
#    'srmer_co2e': 0.0007847}, 2029: {'lrmer_co2e': 0.00031470000000000006,
#    'srmer_co2e': 0.00076725}, 2030: {'lrmer_co2e': 0.00031360000000000003,
#    'srmer_co2e': 0.0007497999999999999}, 2031: {'lrmer_co2e': 0.00029605,
#    'srmer_co2e': 0.00073815}, 2032: {'lrmer_co2e': 0.0002785,
#    'srmer_co2e': 0.0007265}, 2033: {'lrmer_co2e': 0.00029995,
#    'srmer_co2e': 0.00073055}, 2034: {'lrmer_co2e': 0.00032139999999999995,
#    'srmer_co2e': 0.0007346000000000001}, 2035: {'lrmer_co2e': 0.00029375,
#    'srmer_co2e': 0.0007183}, 2036: {'lrmer_co2e': 0.0002661,
#    'srmer_co2e': 0.000702}, 2037: {'lrmer_co2e': 0.00026925,
#    'srmer_co2e': 0.00069155}, 2038: {'lrmer_co2e': 0.00027239999999999995,
#    'srmer_co2e': 0.0006811}, 2039: {'lrmer_co2e': 0.0002525,
#    'srmer_co2e': 0.0006772999999999999}, 2040: {'lrmer_co2e': 0.0002326,
#    'srmer_co2e': 0.0006735}, 2041: {'lrmer_co2e': 0.00022214999999999998,
#    'srmer_co2e': 0.0006747000000000001}, 2042: {'lrmer_co2e': 0.0002117,
#    'srmer_co2e': 0.0006759}, 2043: {'lrmer_co2e': 0.0001941,
#    'srmer_co2e': 0.00067085}, 2044: {'lrmer_co2e': 0.0001765,
#    'srmer_co2e': 0.0006657999999999999}, 2045: {'lrmer_co2e': 0.00016365,
#    'srmer_co2e': 0.0006524500000000001}, 2046: {'lrmer_co2e': 0.0001508,
#    'srmer_co2e': 0.0006391}, 2047: {'lrmer_co2e': 0.00015455000000000002,
#    'srmer_co2e': 0.0006349000000000001}, 2048: {'lrmer_co2e': 0.0001583,
#    'srmer_co2e': 0.0006307000000000001}, 2049: {'lrmer_co2e': 0.00015030000000000002,
#    'srmer_co2e': 0.0006299000000000001}, 2050: {'lrmer_co2e': 0.00014230000000000002,
#    'srmer_co2e': 0.0006291000000000001}},
#    'srmer_co2e': 0.00079705}, 2040: {'lrmer_co2e': 0.000285,
#    'srmer_co2e': 0.0007876000000000001}, 2041: {'lrmer_co2e': 0.0002857,
#    'srmer_co2e': 0.0007839500000000001}, 2042: {'lrmer_co2e': 0.00028639999999999997,
#    'srmer_co2e': 0.0007802999999999999}, 2043: {'lrmer_co2e': 0.0002876,
#    'srmer_co2e': 0.00076495}, 2044: {'lrmer_co2e': 0.0002888,
#    'srmer_co2e': 0.0007496}, 2045: {'lrmer_co2e': 0.0002983,
#    'srmer_co2e': 0.0007353500000000001}, 2046: {'lrmer_co2e': 0.0003078,
#    'srmer_co2e': 0.0007211}, 2047: {'lrmer_co2e': 0.00030585000000000003,
#    'srmer_co2e': 0.0007088}, 2048: {'lrmer_co2e': 0.00030389999999999996,
#    'srmer_co2e': 0.0006965}, 2049: {'lrmer_co2e': 0.00029495,
#    'srmer_co2e': 0.0007014}, 2050: {'lrmer_co2e': 0.000286,
#    'srmer_co2e': 0.0007063}},
#  ('MidCase',
#   'MROWc'): {2022: {'lrmer_co2e': 0.000682,
#    'srmer_co2e': 0.0008983}, 2023: {'lrmer_co2e': 0.00062025, 'srmer_co2e': 0.0009047}, 2024: {'lrmer_co2e': 0.0005585,
#    'srmer_co2e': 0.0009111}, 2025: {'lrmer_co2e': 0.0004915,
#    'srmer_co2e': 0.0008862000000000001}, 2026: {'lrmer_co2e': 0.0004245,
#    'srmer_co2e': 0.0008613}, 2027: {'lrmer_co2e': 0.0003908,
#    'srmer_co2e': 0.00083725}, 2028: {'lrmer_co2e': 0.0003571,
#    'srmer_co2e': 0.0008132}, 2029: {'lrmer_co2e': 0.00037175,
#    'srmer_co2e': 0.00082635}, 2030: {'lrmer_co2e': 0.00038639999999999996,
#    'srmer_co2e': 0.0008395}, 2031: {'lrmer_co2e': 0.00033089999999999997,
#    'srmer_co2e': 0.00084415}, 2032: {'lrmer_co2e': 0.00027539999999999997,
#    'srmer_co2e': 0.0008487999999999999}, 2033: {'lrmer_co2e': 0.00026014999999999995,
#    'srmer_co2e': 0.0008304}, 2034: {'lrmer_co2e': 0.0002449,
#    'srmer_co2e': 0.000812}, 2035: {'lrmer_co2e': 0.0002063,
#    'srmer_co2e': 0.0008055499999999999}, 2036: {'lrmer_co2e': 0.00016769999999999998,
#    'srmer_co2e': 0.0007991000000000001}, 2037: {'lrmer_co2e': 0.00017585,
#    'srmer_co2e': 0.00077985}, 2038: {'lrmer_co2e': 0.000184,
#    'srmer_co2e': 0.0007606000000000001}, 2039: {'lrmer_co2e': 0.00016905000000000002,
#    'srmer_co2e': 0.00076245}, 2040: {'lrmer_co2e': 0.0001541,
#    'srmer_co2e': 0.0007643}, 2041: {'lrmer_co2e': 0.00015725,
#    'srmer_co2e': 0.0007632}, 2042: {'lrmer_co2e': 0.0001604,
#    'srmer_co2e': 0.0007621}, 2043: {'lrmer_co2e': 0.00016125,
#    'srmer_co2e': 0.0007434000000000001}, 2044: {'lrmer_co2e': 0.00016209999999999998,
#    'srmer_co2e': 0.000523}},
#  ('MidCase',
#   'NWPPc'): {2022: {'lrmer_co2e': 0.0004868,
#    'srmer_co2e': 0.0007863}, 2023: {'lrmer_co2e': 0.00045535000000000004, 'srmer_co2e': 0.0008104}, 2024: {'lrmer_co2e': 0.0004239,
#    'srmer_co2e': 0.0008345}, 2025: {'lrmer_co2e': 0.00037775,
#    'srmer_co2e': 0.0008397999999999999}, 2026: {'lrmer_co2e': 0.00033160000000000004,
#    'srmer_co2e': 0.0008451}, 2027: {'lrmer_co2e': 0.00032025,
#    'srmer_co2e': 0.000835}, 2028: {'lrmer_co2e': 0.0003089,
#    'srmer_co2e': 0.0008248999999999999}, 2029: {'lrmer_co2e': 0.00031364999999999995,
#    'srmer_co2e': 0.00080345}, 2030: {'lrmer_co2e': 0.0003184,
#    'srmer_co2e': 0.000782}, 2031: {'lrmer_co2e': 0.00030355,
#    'srmer_co2e': 0.0007722}, 2032: {'lrmer_co2e': 0.00028869999999999997,
#    'srmer_co2e': 0.0007624}, 2033: {'lrmer_co2e': 0.00028744999999999997,
#    'srmer_co2e': 0.0007729}, 2034: {'lrmer_co2e': 0.00028619999999999996,
#    'srmer_co2e': 0.0007834}, 2035: {'lrmer_co2e': 0.00026045,
#    'srmer_co2e': 0.00076005}, 2036: {'lrmer_co2e': 0.00023469999999999999,
#    'srmer_co2e': 0.0007367000000000001}, 2037: {'lrmer_co2e': 0.00023905,
#    'srmer_co2e': 0.00073305}, 2038: {'lrmer_co2e': 0.0002434,
#    'srmer_co2e': 0.0007294}, 2039: {'lrmer_co2e': 0.00021525,
#    'srmer_co2e': 0.00072575}, 2040: {'lrmer_co2e': 0.0001871,
#    'srmer_co2e': 0.0007221}, 2041: {'lrmer_co2e': 0.0001926,
#    'srmer_co2e': 0.0007284500000000001}, 2042: {'lrmer_co2e': 0.0001981,
#    'srmer_co2e': 0.0007348}, 2043: {'lrmer_co2e': 0.00019575,
#    'srmer_co2e': 0.0007168499999999999}, 2044: {'lrmer_co2e': 0.0001934,
#    'srmer_co2e': 0.0006989}, 2045: {'lrmer_co2e': 0.00020005,
#    'srmer_co2e': 0.0006804500000000001}, 2046: {'lrmer_co2e': 0.00020669999999999998,
#    'srmer_co2e': 0.000662}, 2047: {'lrmer_co2e': 0.00020455,
#    'srmer_co2e': 0.00065545}, 2048: {'lrmer_co2e': 0.00020240000000000001,
#    'srmer_co2e': 0.0006489}, 2049: {'lrmer_co2e': 0.00019245,
#    'srmer_co2e': 0.0006390999999999999}, 2050: {'lrmer_co2e': 0.0001825,
#    'srmer_co2e': 0.0006293}},
#  ('MidCase',
#   'NYSTc'): {2022: {'lrmer_co2e': 0.0003975,
#    'srmer_co2e': 0.0007164}, 2023: {'lrmer_co2e': 0.00037894999999999997, 'srmer_co2e': 0.00072745}, 2024: {'lrmer_co2e': 0.0003604,
#    'srmer_co2e': 0.0007385}, 2025: {'lrmer_co2e': 0.0003327,
#    'srmer_co2e': 0.0007298}, 2026: {'lrmer_co2e': 0.000305,
#    'srmer_co2e': 0.0007904}, 2043: {'lrmer_co2e': 0.00041455,
#    'srmer_co2e': 0.0007794}, 2044: {'lrmer_co2e': 0.000419,
#    'srmer_co2e': 0.0007684}, 2045: {'lrmer_co2e': 0.0004287,
#    'srmer_co2e': 0.00075165}, 2046: {'lrmer_co2e': 0.0004384,
#    'srmer_co2e': 0.0007349}, 2047: {'lrmer_co2e': 0.0004217,
#    'srmer_co2e': 0.0007275999999999999}, 2048: {'lrmer_co2e': 0.000405,
#    'srmer_co2e': 0.0007203}, 2049: {'lrmer_co2e': 0.00037985000000000004,
#    'srmer_co2e': 0.0007095}, 2050: {'lrmer_co2e': 0.0003547,
#    'srmer_co2e': 0.0006987}},
#  ('MidCase',
#   'RMPAc'): {2022: {'lrmer_co2e': 0.0006303999999999999,
#    'srmer_co2e': 0.0009712000000000001}, 2023: {'lrmer_co2e': 0.00054765,
#    'srmer_co2e': 0.0009221}, 2024: {'lrmer_co2e': 0.00046489999999999997,
#    'srmer_co2e': 0.000873}, 2025: {'lrmer_co2e': 0.00037545,
#    'srmer_co2e': 0.0008715}, 2026: {'lrmer_co2e': 0.000286,
#    'srmer_co2e': 0.00087}, 2027: {'lrmer_co2e': 0.000264,
#    'srmer_co2e': 0.0008548}, 2028: {'lrmer_co2e': 0.000242,
#    'srmer_co2e': 0.0008396}, 2029: {'lrmer_co2e': 0.00028464999999999995,
#    'srmer_co2e': 0.0008136}, 2030: {'lrmer_co2e': 0.0003273,
#    'srmer_co2e': 0.0007876000000000001}, 2031: {'lrmer_co2e': 0.00032245000000000006,
#    'srmer_co2e': 0.00077975}, 2032: {'lrmer_co2e': 0.0003176,
#    'srmer_co2e': 0.0007719}, 2033: {'lrmer_co2e': 0.0002979,
#    'srmer_co2e': 0.00078115}, 2034: {'lrmer_co2e': 0.0002782,
#    'srmer_co2e': 0.0007904}, 2035: {'lrmer_co2e': 0.0002365,
#    'srmer_co2e': 0.000768}, 2036: {'lrmer_co2e': 0.00019480000000000002,
#    'srmer_co2e': 0.0007456}, 2037: {'lrmer_co2e': 0.00019755,
#    'srmer_co2e': 0.00074475}, 2038: {'lrmer_co2e': 0.00020030000000000002,
#    'srmer_co2e': 0.0007439}, 2039: {'lrmer_co2e': 0.00016735000000000003,
#    'srmer_co2e': 0.0007493499999999999}, 2040: {'lrmer_co2e': 0.00013440000000000001,
#    'srmer_co2e': 0.0007547999999999999}, 2041: {'lrmer_co2e': 0.00013580000000000002,
#    'srmer_co2e': 0.0007535}, 2042: {'lrmer_co2e': 0.0001372,
#    'srmer_co2e': 0.0007522000000000001}, 2043: {'lrmer_co2e': 0.00014205,
#    'srmer_co2e': 0.0007497000000000001}, 2044: {'lrmer_co2e': 0.0001469,
#    'srmer_co2e': 0.0007472000000000001}, 2045: {'lrmer_co2e': 0.00016455000000000002,
#    'srmer_co2e': 0.0007306500000000001}, 2046: {'lrmer_co2e': 0.00018219999999999998,
#    'srmer_co2e': 0.0007141000000000001}, 2047: {'lrmer_co2e': 0.00019535,
#    'srmer_co2e': 0.0007047}, 2048: {'lrmer_co2e': 0.0002085,
#    'srmer_co2e': 0.0006952999999999999}, 2049: {'lrmer_co2e': 0.0002116,
#    'srmer_co2e': 0.0006910499999999999}, 2050: {'lrmer_co2e': 0.0002147,
#    'srmer_co2e': 0.0006868}},
#  ('MidCase',
#   'SPNOc'): {2022: {'lrmer_co2e': 0.0007434,
#    'srmer_co2e': 0.0009123}, 2023: {'lrmer_co2e': 0.0006887999999999999, 'srmer_co2e': 0.0009115}, 2024: {'lrmer_co2e': 0.0006342,
#    'srmer_co2e': 0.0009107000000000001}, 2025: {'lrmer_co2e': 0.00054845,
#    'srmer_co2e': 0.00088395}, 2026: {'lrmer_co2e': 0.00046269999999999997,
#    'srmer_co2e': 0.0008572}, 2027: {'lrmer_co2e': 0.0004093,
#    'srmer_co2e': 0.0008661000000000001}, 2028: {'lrmer_co2e': 0.0003559,
#    'srmer_co2e': 0.000875}, 2029: {'lrmer_co2e': 0.00034839999999999996,
#    'srmer_co2e': 0.000864}, 2030: {'lrmer_co2e': 0.0003409,
#    'srmer_co2e': 0.000853}, 2031: {'lrmer_co2e': 0.0002935,
#    'srmer_co2e': 0.0008544500000000001}, 2032: {'lrmer_co2e': 0.0002461,
#    'srmer_co2e': 0.0008558999999999999}, 2033: {'lrmer_co2e': 0.000249,
#    'srmer_co2e': 0.00080905}, 2034: {'lrmer_co2e': 0.0002519,
#    'srmer_co2e': 0.0007622000000000001}, 2035: {'lrmer_co2e': 0.0002375,
#    'srmer_co2e': 0.0007702000000000001}, 2036: {'lrmer_co2e': 0.0002231,
#    'srmer_co2e': 0.0007782}, 2037: {'lrmer_co2e': 0.00024095,
#    'srmer_co2e': 0.0007696000000000001}, 2038: {'lrmer_co2e': 0.0002588,
#    'srmer_co2e': 0.000761}, 2039: {'lrmer_co2e': 0.00024419999999999997,
#    'srmer_co2e': 0.00075975}, 2040: {'lrmer_co2e': 0.0002296,
#    'srmer_co2e': 0.0007585}, 2041: {'lrmer_co2e': 0.00022025,
#    'srmer_co2e': 0.0007578999999999999}, 2042: {'lrmer_co2e': 0.0002109,
#    'srmer_co2e': 0.0007572999999999999}, 2043: {'lrmer_co2e': 0.00021175,
#    'srmer_co2e': 0.0007492}, 2044: {'lrmer_co2e': 0.0002126,
#    'srmer_co2e': 0.0007411000000000001}, 2045: {'lrmer_co2e': 0.00022114999999999998,
#    'srmer_co2e': 0.0007137000000000001}, 2046: {'lrmer_co2e': 0.0002297,
#    'srmer_co2e': 0.0006862999999999999}, 2047: {'lrmer_co2e': 0.0002168,
#    'srmer_co2e': 0.00068565}, 2048: {'lrmer_co2e': 0.0002039,
#    'srmer_co2e': 0.000685}, 2049: {'lrmer_co2e': 0.0001915,
#    'srmer_co2e': 0.0006624500000000001}, 2050: {'lrmer_co2e': 0.0001791,
#    'srmer_co2e': 0.0006399}},
#  ('MidCase',
#   'SPSOc'): {2022: {'lrmer_co2e': 0.0005974,
#    'srmer_co2e': 0.0007665}, 2023: {'lrmer_co2e': 0.0005417999999999999, 'srmer_co2e': 0.0007449}, 2024: {'lrmer_co2e': 0.0004862,
#    'srmer_co2e': 0.0008777}, 2029: {'lrmer_co2e': 0.00040445000000000005,
#    'srmer_co2e': 0.000872}, 2030: {'lrmer_co2e': 0.0004108,
#    'srmer_co2e': 0.0008663}, 2031: {'lrmer_co2e': 0.00040364999999999997,
#    'srmer_co2e': 0.00085755}, 2032: {'lrmer_co2e': 0.0003965,
#    'srmer_co2e': 0.0008487999999999999}, 2033: {'lrmer_co2e': 0.00040425,
#    'srmer_co2e': 0.00084465}, 2034: {'lrmer_co2e': 0.000412,
#    'srmer_co2e': 0.0008405}, 2035: {'lrmer_co2e': 0.0004075,
#    'srmer_co2e': 0.00082975}, 2036: {'lrmer_co2e': 0.000403,
#    'srmer_co2e': 0.000819}, 2037: {'lrmer_co2e': 0.0004227,
#    'srmer_co2e': 0.0008112999999999999}, 2038: {'lrmer_co2e': 0.00044239999999999997,
#    'srmer_co2e': 0.0008036}, 2039: {'lrmer_co2e': 0.00043925,
#    'srmer_co2e': 0.00079495}, 2040: {'lrmer_co2e': 0.00043610000000000003,
#    'srmer_co2e': 0.0007863}, 2041: {'lrmer_co2e': 0.0004369,
#    'srmer_co2e': 0.00079175}, 2042: {'lrmer_co2e': 0.0004377,
#    'srmer_co2e': 0.0007972000000000001}, 2043: {'lrmer_co2e': 0.00043264999999999997,
#    'srmer_co2e': 0.00078735}, 2044: {'lrmer_co2e': 0.00042760000000000004,
#    'srmer_co2e': 0.0007775}, 2045: {'lrmer_co2e': 0.00041620000000000003,
#    'srmer_co2e': 0.0007561}, 2046: {'lrmer_co2e': 0.00040480000000000003,
#    'srmer_co2e': 0.0007347}, 2047: {'lrmer_co2e': 0.00039370000000000003,
#    'srmer_co2e': 0.00072525}, 2048: {'lrmer_co2e': 0.00038260000000000003,
#    'srmer_co2e': 0.0007157999999999999}, 2049: {'lrmer_co2e': 0.00037815,
#    'srmer_co2e': 0.0007090999999999999}, 2050: {'lrmer_co2e': 0.0003737,
#    'srmer_co2e': 0.0007023999999999999}},
#  ('MidCase',
#   'SRMWc'): {2022: {'lrmer_co2e': 0.0006925,
#    'srmer_co2e': 0.0009201}, 2023: {'lrmer_co2e': 0.0006485, 'srmer_co2e': 0.000929}, 2024: {'lrmer_co2e': 0.0006045,
#    'srmer_co2e': 0.0009379}, 2025: {'lrmer_co2e': 0.0005283,
#    'srmer_co2e': 0.00092595}, 2026: {'lrmer_co2e': 0.00045210000000000004,
#    'srmer_co2e': 0.000914}, 2027: {'lrmer_co2e': 0.00041775,
#    'srmer_co2e': 0.0009106}, 2028: {'lrmer_co2e': 0.0003834,
#    'srmer_co2e': 0.0009072}, 2029: {'lrmer_co2e': 0.00037795,
#    'srmer_co2e': 0.000904}, 2030: {'lrmer_co2e': 0.0003725,
#    'srmer_co2e': 0.0009008}, 2031: {'lrmer_co2e': 0.00034635000000000004,
#    'srmer_co2e': 0.00089785}, 2032: {'lrmer_co2e': 0.0003202,
#    'srmer_co2e': 0.0008949}, 2033: {'lrmer_co2e': 0.0003211,
#    'srmer_co2e': 0.00089165}, 2034: {'lrmer_co2e': 0.000322,
#    'srmer_co2e': 0.0008884}, 2035: {'lrmer_co2e': 0.0003207,
#    'srmer_co2e': 0.00088255}, 2036: {'lrmer_co2e': 0.00031939999999999996,
#    'srmer_co2e': 0.0008767}, 2037: {'lrmer_co2e': 0.0003412,
#    'srmer_co2e': 0.0008698}, 2038: {'lrmer_co2e': 0.000363,
#    'srmer_co2e': 0.0008629}, 2039: {'lrmer_co2e': 0.00034889999999999997,
#    'srmer_co2e': 0.0008564}, 2040: {'lrmer_co2e': 0.0003348,
#    'srmer_co2e': 0.0008499}, 2041: {'lrmer_co2e': 0.00031905000000000003,
#    'srmer_co2e': 0.0008445999999999999}, 2042: {'lrmer_co2e': 0.0003033,
#    'srmer_co2e': 0.0008393}, 2043: {'lrmer_co2e': 0.0003029,
#    'srmer_co2e': 0.00082555}, 2044: {'lrmer_co2e': 0.0003025,
#    'srmer_co2e': 0.0008118}, 2045: {'lrmer_co2e': 0.0003103,
#    'srmer_co2e': 0.0007925999999999999}, 2046: {'lrmer_co2e': 0.00031810000000000003,
#    'srmer_co2e': 0.0007733999999999999}, 2047: {'lrmer_co2e': 0.00030485,
#    'srmer_co2e': 0.0007565499999999999}, 2048: {'lrmer_co2e': 0.00029160000000000004,
#    'srmer_co2e': 0.0007397}, 2049: {'lrmer_co2e': 0.00026685,
#    'srmer_co2e': 0.00071575}, 2050: {'lrmer_co2e': 0.0002421,
#    'srmer_co2e': 0.0006917999999999999}},
#  ('MidCase',
#   'SRSOc'): {2022: {'lrmer_co2e': 0.0006936,
#    'srmer_co2e': 0.0008908}, 2023: {'lrmer_co2e': 0.0006782, 'srmer_co2e': 0.00089}, 2024: {'lrmer_co2e': 0.0006628,
#    'srmer_co2e': 0.0008892}, 2025: {'lrmer_co2e': 0.00060825,
#    'srmer_co2e': 0.0008908}, 2026: {'lrmer_co2e': 0.0005537000000000001,
#    'srmer_co2e': 0.0008924}, 2027: {'lrmer_co2e': 0.00051345,
#    'srmer_co2e': 0.0008946}, 2028: {'lrmer_co2e': 0.0004732,
#    'srmer_co2e': 0.0008968}, 2029: {'lrmer_co2e': 0.00045535000000000004,
#    'srmer_co2e': 0.00088765}, 2030: {'lrmer_co2e': 0.0004375,
#    'srmer_co2e': 0.0008785}, 2031: {'lrmer_co2e': 0.00043375,
#    'srmer_co2e': 0.0008716}, 2032: {'lrmer_co2e': 0.00043,
#    'srmer_co2e': 0.0008647}, 2033: {'lrmer_co2e': 0.0004577,
#    'srmer_co2e': 0.0008651500000000001}, 2034: {'lrmer_co2e': 0.0004854,
#    'srmer_co2e': 0.0008656}, 2035: {'lrmer_co2e': 0.00046794999999999996,
#    'srmer_co2e': 0.00085575}, 2036: {'lrmer_co2e': 0.0004505,
#    'srmer_co2e': 0.0008459}, 2037: {'lrmer_co2e': 0.0004348,
#    'srmer_co2e': 0.0008357999999999999}, 2038: {'lrmer_co2e': 0.00041910000000000005,
#    'srmer_co2e': 0.0008257000000000001}, 2039: {'lrmer_co2e': 0.00040510000000000003,
#    'srmer_co2e': 0.0008136500000000001}, 2040: {'lrmer_co2e': 0.0003911,
#    'srmer_co2e': 0.0008016}, 2041: {'lrmer_co2e': 0.0004241,
#    'srmer_co2e': 0.00080615}, 2042: {'lrmer_co2e': 0.0004571,
#    'srmer_co2e': 0.0008107}, 2043: {'lrmer_co2e': 0.0004895,
#    'srmer_co2e': 0.00080395}, 2044: {'lrmer_co2e': 0.0005219,
#    'srmer_co2e': 0.0007972000000000001}, 2045: {'lrmer_co2e': 0.0005244500000000001,
#    'srmer_co2e': 0.00077325}, 2046: {'lrmer_co2e': 0.000527,
#    'srmer_co2e': 0.0007492999999999999}, 2047: {'lrmer_co2e': 0.0005026000000000001,
#    'srmer_co2e': 0.00074375}, 2048: {'lrmer_co2e': 0.00047819999999999997,
#    'srmer_co2e': 0.0007382}, 2049: {'lrmer_co2e': 0.00045529999999999995,
#    'srmer_co2e': 0.00072475}, 2050: {'lrmer_co2e': 0.0004324,
#    'srmer_co2e': 0.0007113}},
#  ('MidCase',
#   'SRTVc'): {2022: {'lrmer_co2e': 0.0007727000000000001,
#    'srmer_co2e': 0.0009231}, 2023: {'lrmer_co2e': 0.00072325,
#    'srmer_co2e': 0.0009433}, 2024: {'lrmer_co2e': 0.0006738,
#    'srmer_co2e': 0.0009635}, 2025: {'lrmer_co2e': 0.0006017,
#    'srmer_co2e': 0.00095995}, 2026: {'lrmer_co2e': 0.0005296,
#    'srmer_co2e': 0.0009563999999999999}, 2027: {'lrmer_co2e': 0.0004658,
#    'srmer_co2e': 0.0009440999999999999}, 2028: {'lrmer_co2e': 0.000402,
#    'srmer_co2e': 0.0009318}, 2029: {'lrmer_co2e': 0.0004041,
#    'srmer_co2e': 0.0009255}, 2030: {'lrmer_co2e': 0.0004062,
#    'srmer_co2e': 0.0009192}, 2031: {'lrmer_co2e': 0.00040325,
#    'srmer_co2e': 0.0009118500000000001}, 2032: {'lrmer_co2e': 0.0004003,
#    'srmer_co2e': 0.0009045}, 2033: {'lrmer_co2e': 0.0004345,
#    'srmer_co2e': 0.00090335}, 2034: {'lrmer_co2e': 0.0004687,
#    'srmer_co2e': 0.0009022}, 2035: {'lrmer_co2e': 0.00046829999999999994,
#    'srmer_co2e': 0.0008899000000000001}, 2036: {'lrmer_co2e': 0.0004679,
#    'srmer_co2e': 0.0008776}, 2037: {'lrmer_co2e': 0.00048029999999999997,
#    'srmer_co2e': 0.00086655}, 2038: {'lrmer_co2e': 0.0004927,
#    'srmer_co2e': 0.0008555}, 2039: {'lrmer_co2e': 0.00048895,
#    'srmer_co2e': 0.00085125}, 2040: {'lrmer_co2e': 0.0004852,
#    'srmer_co2e': 0.000847}, 2041: {'lrmer_co2e': 0.0004971,
#    'srmer_co2e': 0.0008535499999999999}, 2042: {'lrmer_co2e': 0.000509,
#    'srmer_co2e': 0.0008601}, 2043: {'lrmer_co2e': 0.00052285,
#    'srmer_co2e': 0.00084875}, 2044: {'lrmer_co2e': 0.0005367000000000001,
#    'srmer_co2e': 0.0008374}, 2045: {'lrmer_co2e': 0.0005324500000000001,
# %%
import os
import pandas as pd

print("""
-------------------------------------------------------------------------------------------------------
IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2022 RELEASE
-------------------------------------------------------------------------------------------------------
""")

# CAMBIUM 2022 FOR IRA SCENARIO
filename = 'cambium22_allScenarios_annual_gea.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_cambium22_margEmis_electricity = pd.read_excel(io=file_path, sheet_name='proc_Cambium22_MidCase_gea')

print(f"""
Retrieved data for filename: {filename}
Located at filepath: {file_path}

Loading dataframe ...
Creating lookup dictionary for 2024 LRMER and SRMER ...
-------------------------------------------------------------------------------------------------------
""")

# Calculate electricity emission factors for Cambium 2021
# Process the data using the provided function to interpolate and convert units
df_cambium22_processed = calculate_electricity_co2e_cambium(df_cambium22_margEmis_electricity)

# Display the processed DataFrame
df_cambium22_processed
# Out:
# -------------------------------------------------------------------------------------------------------
# IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2022 RELEASE
# -------------------------------------------------------------------------------------------------------
#
#
# Retrieved data for filename: cambium22_allScenarios_annual_gea.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\cambium22_allScenarios_annual_gea.xlsx
#
# Loading dataframe ...
# Creating lookup dictionary for 2024 LRMER and SRMER ...
# -------------------------------------------------------------------------------------------------------
#     scenario gea_region  year  lrmer_co2e_kg_per_MWh  srmer_co2e_kg_per_MWh  \
# 0    MidCase      AZNMc  2024                  326.9                 777.10
# 1    MidCase      AZNMc  2025                  260.4                 743.40
# 2    MidCase      AZNMc  2026                  193.9                 709.70
# 3    MidCase      AZNMc  2027                  162.2                 643.05
# 4    MidCase      AZNMc  2028                  130.5                 576.40
# ..       ...        ...   ...                    ...                    ...
# 535  MidCase      SRVCc  2046                  136.4                 500.16
# 536  MidCase      SRVCc  2047                  130.6                 502.92
# 537  MidCase      SRVCc  2048                  124.8                 505.68
# 538  MidCase      SRVCc  2049                  119.0                 508.44
# 539  MidCase      SRVCc  2050                  113.2                 511.20
#
#      lrmer_co2e_ton_per_MWh  lrmer_co2e_ton_per_kWh  srmer_co2e_ton_per_MWh  \
# 0                    0.3269                0.000327                 0.77710
# 1                    0.2604                0.000260                 0.74340
# 2                    0.1939                0.000194                 0.70970
# 3                    0.1622                0.000162                 0.64305
# 4                    0.1305                0.000131                 0.57640
# ..                      ...                     ...                     ...
# 535                  0.1364                0.000136                 0.50016
# 536                  0.1306                0.000131                 0.50292
# 537                  0.1248                0.000125                 0.50568
# 538                  0.1190                0.000119                 0.50844
# 539                  0.1132                0.000113                 0.51120
#
#      srmer_co2e_ton_per_kWh
# 0                  0.000777
# 1                  0.000743
# 2                  0.000710
# 3                  0.000643
# 4                  0.000576
# ..                      ...
# 535                0.000500
# 536                0.000503
# 537                0.000506
# 538                0.000508
# 539                0.000511
#
# [540 rows x 9 columns]

# %%
# Create the lookup dictionary using the create_cambium_co2e_lookup function
emis_IRA_co2e_cambium22_lookup = create_cambium_co2e_lookup(df_cambium22_processed)

# Display the lookup dictionary
emis_IRA_co2e_cambium22_lookup
# Out:
# {('MidCase',
#   'AZNMc'): {2024: {'lrmer_co2e': 0.0003269,
#    'srmer_co2e': 0.0007771}, 2025: {'lrmer_co2e': 0.0002604, 'srmer_co2e': 0.0007434000000000001}, 2026: {'lrmer_co2e': 0.0001939,
#    'srmer_co2e': 0.0007097000000000001}, 2027: {'lrmer_co2e': 0.00016219999999999999,
#    'srmer_co2e': 0.0006430499999999999}, 2028: {'lrmer_co2e': 0.0001305,
#    'srmer_co2e': 0.0005764}, 2029: {'lrmer_co2e': 0.0001171,
#    'srmer_co2e': 0.00053155}, 2030: {'lrmer_co2e': 0.0001037,
#    'srmer_co2e': 0.0004867}, 2031: {'lrmer_co2e': 0.00011284,
#    'srmer_co2e': 0.00046903999999999994}, 2032: {'lrmer_co2e': 0.00012198000000000001,
#    'srmer_co2e': 0.00045138}, 2033: {'lrmer_co2e': 0.00013112,
#    'srmer_co2e': 0.00043371999999999996}, 2034: {'lrmer_co2e': 0.00014026,
#    'srmer_co2e': 0.00041605999999999994}, 2035: {'lrmer_co2e': 0.0001494,
#    'srmer_co2e': 0.0003984}, 2036: {'lrmer_co2e': 0.00015762,
#    'srmer_co2e': 0.0002627}},
#  ('MidCase',
#   'FRCCc'): {2024: {'lrmer_co2e': 0.00028680000000000003,
#    'srmer_co2e': 0.0007726}, 2025: {'lrmer_co2e': 0.00025745,
#    'srmer_co2e': 0.0007025}, 2026: {'lrmer_co2e': 0.0002281,
#    'srmer_co2e': 0.0006324}, 2027: {'lrmer_co2e': 0.0002008,
#    'srmer_co2e': 0.0005904500000000001}, 2028: {'lrmer_co2e': 0.0001735,
#    'srmer_co2e': 0.0005485}, 2029: {'lrmer_co2e': 0.00018465000000000002,
#    'srmer_co2e': 0.0005265}, 2030: {'lrmer_co2e': 0.00019580000000000002,
#    'srmer_co2e': 0.0005045}, 2031: {'lrmer_co2e': 0.0002055,
#    'srmer_co2e': 0.00049152}, 2032: {'lrmer_co2e': 0.00021520000000000003,
#    'srmer_co2e': 0.00047854}, 2033: {'lrmer_co2e': 0.00022490000000000002,
#    'srmer_co2e': 0.00046556}, 2034: {'lrmer_co2e': 0.0002346,
#    'srmer_co2e': 0.00045258000000000006}, 2035: {'lrmer_co2e': 0.00024430000000000003,
#    'srmer_co2e': 0.0004396}, 2036: {'lrmer_co2e': 0.00025442,
#    'srmer_co2e': 0.00043672000000000003}, 2037: {'lrmer_co2e': 0.00026454,
#    'srmer_co2e': 0.00043384}, 2038: {'lrmer_co2e': 0.00027466,
#    'srmer_co2e': 0.00043096}, 2039: {'lrmer_co2e': 0.00028478,
#    'srmer_co2e': 0.00042808}, 2040: {'lrmer_co2e': 0.00029489999999999996,
#    'srmer_co2e': 0.0004252}, 2041: {'lrmer_co2e': 0.00030386,
#    'srmer_co2e': 0.00041672}, 2042: {'lrmer_co2e': 0.00031282,
#    'srmer_co2e': 0.00040824000000000004}, 2043: {'lrmer_co2e': 0.00032177999999999997,
#    'srmer_co2e': 0.00039976}, 2044: {'lrmer_co2e': 0.00033074,
#    'srmer_co2e': 0.00039128000000000003}, 2045: {'lrmer_co2e': 0.00033969999999999996,
#    'srmer_co2e': 0.00038280000000000003}, 2046: {'lrmer_co2e': 0.00034313999999999997,
#    'srmer_co2e': 0.00038510000000000004}, 2047: {'lrmer_co2e': 0.00034658,
#    'srmer_co2e': 0.00038740000000000004}, 2048: {'lrmer_co2e': 0.00035002,
#    'srmer_co2e': 0.0003897}, 2049: {'lrmer_co2e': 0.00035346,
#    'srmer_co2e': 0.000392}, 2050: {'lrmer_co2e': 0.0003569,
#    'srmer_co2e': 0.0003943}},
#  ('MidCase',
#   'MROEc'): {2024: {'lrmer_co2e': 0.000349,
#    'srmer_co2e': 0.0009433}, 2025: {'lrmer_co2e': 0.0003097, 'srmer_co2e': 0.0009196499999999999}, 2026: {'lrmer_co2e': 0.00027039999999999996,
#    'srmer_co2e': 0.000896}, 2027: {'lrmer_co2e': 0.00024714999999999996,
#    'srmer_co2e': 0.00078855}, 2028: {'lrmer_co2e': 0.0002239,
#    'srmer_co2e': 0.0006811}, 2029: {'lrmer_co2e': 0.00021875,
#    'srmer_co2e': 0.00062625}, 2030: {'lrmer_co2e': 0.0002136,
#    'srmer_co2e': 0.0004768}, 2031: {'lrmer_co2e': 0.00011302,
#    'srmer_co2e': 0.00046986}, 2032: {'lrmer_co2e': 0.00012043999999999999,
#    'srmer_co2e': 0.00046292}, 2033: {'lrmer_co2e': 0.00012785999999999999,
#    'srmer_co2e': 0.00045598000000000004}, 2034: {'lrmer_co2e': 0.00013528,
#    'srmer_co2e': 0.00044904}, 2035: {'lrmer_co2e': 0.0001427,
#    'srmer_co2e': 0.0004421}, 2036: {'lrmer_co2e': 0.00014906,
#    'srmer_co2e': 0.00043034000000000003}, 2037: {'lrmer_co2e': 0.00015542,
#    'srmer_co2e': 0.00041858000000000005}, 2038: {'lrmer_co2e': 0.00016178,
#    'srmer_co2e': 0.00040682000000000007}, 2039: {'lrmer_co2e': 0.00016814,
#    'srmer_co2e': 0.00039506000000000003}, 2040: {'lrmer_co2e': 0.0001745,
#    'srmer_co2e': 0.0003833}, 2041: {'lrmer_co2e': 0.00017718,
#    'srmer_co2e': 0.00037184}, 2042: {'lrmer_co2e': 0.00017986,
#    'srmer_co2e': 0.00036038}, 2043: {'lrmer_co2e': 0.00018254,
#    'srmer_co2e': 0.00034892}, 2044: {'lrmer_co2e': 0.00018522,
#    'srmer_co2e': 0.00033746}, 2045: {'lrmer_co2e': 0.00018790000000000001,
#    'srmer_co2e': 0.000326}, 2046: {'lrmer_co2e': 0.00018922,
#    'srmer_co2e': 0.00032212}, 2047: {'lrmer_co2e': 0.00019054,
#    'srmer_co2e': 0.00031824}, 2048: {'lrmer_co2e': 0.00019186000000000002,
#    'srmer_co2e': 0.00031436}, 2049: {'lrmer_co2e': 0.00019318000000000002,
#    'srmer_co2e': 0.00031048}, 2050: {'lrmer_co2e': 0.0001945,
#    'srmer_co2e': 0.0003066}},
#  ('MidCase',
#   'SPSOc'): {2024: {'lrmer_co2e': 0.000402,
#    'srmer_co2e': 0.0006807}, 2025: {'lrmer_co2e': 0.00034205, 'srmer_co2e': 0.00063445}, 2026: {'lrmer_co2e': 0.0002821,
#    'srmer_co2e': 0.0005882000000000001}, 2027: {'lrmer_co2e': 0.0002298,
#    'srmer_co2e': 0.0005323}, 2028: {'lrmer_co2e': 0.0001775,
#    'srmer_co2e': 0.0004764}, 2029: {'lrmer_co2e': 0.00014915,
#    'srmer_co2e': 0.00045085000000000004}, 2030: {'lrmer_co2e': 0.0001208,
#    'srmer_co2e': 0.00042530000000000004}, 2031: {'lrmer_co2e': 0.00012628,
#    'srmer_co2e': 0.00041696}, 2032: {'lrmer_co2e': 0.00013176,
#    'srmer_co2e': 0.00040862}, 2033: {'lrmer_co2e': 0.00013724,
#    'srmer_co2e': 0.00040028000000000004}, 2034: {'lrmer_co2e': 0.00014272,
#    'srmer_co2e': 0.00039194}, 2035: {'lrmer_co2e': 0.0001482,
#    'srmer_co2e': 0.0003836}, 2036: {'lrmer_co2e': 0.00015529999999999998,
#    'srmer_co2e': 0.00037422000000000003}, 2037: {'lrmer_co2e': 0.0001624,
#    'srmer_co2e': 0.00036484}, 2038: {'lrmer_co2e': 0.0001695,
#    'srmer_co2e': 0.00053188}, 2042: {'lrmer_co2e': 0.00016986,
#    'srmer_co2e': 0.00052326}, 2043: {'lrmer_co2e': 0.00016063999999999998,
#    'srmer_co2e': 0.00051464}, 2044: {'lrmer_co2e': 0.00015141999999999998,
#    'srmer_co2e': 0.0005060199999999999}, 2045: {'lrmer_co2e': 0.0001422,
#    'srmer_co2e': 0.0004974}, 2046: {'lrmer_co2e': 0.00013639999999999998,
#    'srmer_co2e': 0.0005001599999999999}, 2047: {'lrmer_co2e': 0.0001306,
#    'srmer_co2e': 0.0005029199999999999}, 2048: {'lrmer_co2e': 0.0001248,
#    'srmer_co2e': 0.00050568}, 2049: {'lrmer_co2e': 0.000119,
#    'srmer_co2e': 0.00050844}, 2050: {'lrmer_co2e': 0.0001132,
#    'srmer_co2e': 0.0005112}}}

# %% [markdown]
# ## HEALTH-RELATED EMISSIONS

# %% [markdown]
# ### Electricity - Method 1: Schmitt et al 2024 Study (Assumes GEA Region and EPA eGRID subregions are the same - which they aren't)

# %%
# Adjust for regional cost differences with RSMeans
filename = "grid_mix_reg_full_delta.csv"
relative_path = os.path.join(r"projections\schmitt_ev_study", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_grid_mix = pd.read_csv(file_path)

df_grid_mix = pd.DataFrame({
    'year': df_grid_mix['Year'],
    'cambium_gea_region': df_grid_mix['Cambium.GEA'],
    'fuel_source': df_grid_mix['Source'],
    'fraction_generation': df_grid_mix['Fraction'],
})
df_grid_mix
# Out:
# Retrieved data for filename: grid_mix_reg_full_delta.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\schmitt_ev_study\grid_mix_reg_full_delta.csv
#       year cambium_gea_region fuel_source  fraction_generation
# 0     2022              AZNMc        Coal             0.000000
# 1     2023              AZNMc        Coal             0.000000
# 2     2024              AZNMc        Coal             0.000000
# 3     2025              AZNMc        Coal             0.137832
# 4     2026              AZNMc        Coal             0.275665
# ...    ...                ...         ...                  ...
# 2895  2046              SRVCc   Renewable             0.868251
# 2896  2047              SRVCc   Renewable             0.883341
# 2897  2048              SRVCc   Renewable             0.898431
# 2898  2049              SRVCc   Renewable             0.913521
# 2899  2050              SRVCc   Renewable             0.928611
#
# [2900 rows x 4 columns]

# %%
# Adjust for regional cost differences with RSMeans
filename = "ef_pollutants_egrid.csv"
relative_path = os.path.join(r"projections\schmitt_ev_study", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_grid_emis_factors = pd.read_csv(file_path)

df_grid_emis_factors = pd.DataFrame({
    'cambium_gea_region': df_grid_emis_factors['eGRID_subregion'],
    'fuel_source': df_grid_emis_factors['Fuel'],
    'pollutant': df_grid_emis_factors['Pollutant'],
    'emis_rate': df_grid_emis_factors['Emission_rate'],
    'unit': df_grid_emis_factors['Unit'],
})

mapping = {
    'AKGD': None,       # Alaska Grid - Not included
    'AKMS': None,       # Alaska Miscellaneous - Not included
    'AZNM': 'AZNMc',    # Arizona/New Mexico Power Area
    'CAMX': 'CAMXc',    # California Mexico
    'ERCT': 'ERCTc',    # Electric Reliability Council of Texas
    'FRCC': 'FRCCc',    # Florida Reliability Coordinating Council
    'HIMS': None,       # Hawaii Maui Subregion - Not included
    'HIOA': None,       # Hawaii Oahu Subregion - Not included
    'MROE': 'MROEc',    # Midwest Reliability Organization East
    'MROW': 'MROWc',    # Midwest Reliability Organization West
    'NEWE': 'NEWEc',    # New England
    'NWPP': 'NWPPc',    # Northwest Power Pool
    'NYCW': 'NYSTc',    # New York City/Westchester mapped to New York State
    'NYLI': 'NYSTc',    # New York Long Island mapped to New York State
    'NYUP': 'NYSTc',    # New York Upstate mapped to New York State
    'PRMS': None,       # Puerto Rico Miscellaneous - Not included
    'RFCE': 'RFCEc',    # ReliabilityFirst Corporation East
    'RFCM': 'RFCMc',    # ReliabilityFirst Corporation Midwest
    'RFCW': 'RFCWc',    # ReliabilityFirst Corporation West
    'RMPA': 'RMPAc',    # Rocky Mountain Power Area
    'SPNO': 'SPNOc',    # Southwest Power Pool North
    'SPSO': 'SPSOc',    # Southwest Power Pool South
    'SRMV': 'SRMVc',    # SERC Reliability Corporation Mississippi Valley
    'SRMW': 'SRMWc',    # SERC Reliability Corporation Midwest
    'SRSO': 'SRSOc',    # SERC Reliability Corporation South
    'SRTV': 'SRTVc',    # SERC Reliability Corporation Tennessee Valley
    'SRVC': 'SRVCc',    # SERC Reliability Corporation Virginia/Carolina
}

# Apply the mapping to the 'cambium_gea_region' column
df_grid_emis_factors['cambium_gea_region'] = df_grid_emis_factors['cambium_gea_region'].map(mapping)

# Drop rows where 'cambium_gea_region' is None (regions not included in the mapping)
df_grid_emis_factors = df_grid_emis_factors.dropna(subset=['cambium_gea_region']).reset_index(drop=True)

# Conversion factor from pounds to metric tons
lb_to_mt = 0.00045359237
perMWh_to_perkWh = 1/1000

# Apply the conversion where the unit is 'lb/MWh'
df_grid_emis_factors.loc[df_grid_emis_factors['unit'] == 'lb/MWh', 'emis_rate'] *= (lb_to_mt * perMWh_to_perkWh)
df_grid_emis_factors.loc[df_grid_emis_factors['unit'] == 'lb/MWh', 'unit'] = 'mt/kWh'

df_grid_emis_factors
# Out:
# Retrieved data for filename: ef_pollutants_egrid.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\schmitt_ev_study\ef_pollutants_egrid.csv
#     cambium_gea_region fuel_source pollutant     emis_rate    unit
# 0                AZNMc        Coal       NOx  7.171295e-07  mt/kWh
# 1                CAMXc        Coal       NOx  1.243750e-06  mt/kWh
# 2                ERCTc        Coal       NOx  5.030339e-07  mt/kWh
# 3                FRCCc        Coal       NOx  2.326929e-07  mt/kWh
# 4                MROEc        Coal       NOx  3.451838e-07  mt/kWh
# ..                 ...         ...       ...           ...     ...
# 545              SRMVc  Renewables       VOC  0.000000e+00  mt/kWh
# 546              SRMWc  Renewables       VOC  0.000000e+00  mt/kWh
# 547              SRSOc  Renewables       VOC  0.000000e+00  mt/kWh
# 548              SRTVc  Renewables       VOC  0.000000e+00  mt/kWh
# 549              SRVCc  Renewables       VOC  0.000000e+00  mt/kWh
#
# [550 rows x 5 columns]

# %%
def process_Schmitt_emissions_data(df_grid_mix, df_grid_emis_factors):
    # Check unique fuel sources in both dataframes
    fuel_sources_mix = set(df_grid_mix['fuel_source'].unique())
    fuel_sources_emis = set(df_grid_emis_factors['fuel_source'].unique())

    print("Fuel sources in df_grid_mix:", fuel_sources_mix)
    print("Fuel sources in df_grid_emis_factors:", fuel_sources_emis)

    # Merge the dataframes
    df_combined = pd.merge(
        df_grid_mix,
        df_grid_emis_factors,
        on=['cambium_gea_region', 'fuel_source'],
        how='inner'
    )

    # Calculate emissions contribution
    df_combined['emis_contribution'] = df_combined['fraction_generation'] * df_combined['emis_rate']

    # Sum emissions contributions
    df_emis_factors = df_combined.groupby(
        ['year', 'cambium_gea_region', 'pollutant']
    )['emis_contribution'].sum().reset_index()

    # Pivot the dataframe
    df_emis_factors_pivot = df_emis_factors.pivot_table(
        index=['year', 'cambium_gea_region'],
        columns='pollutant',
        values='emis_contribution'
    ).reset_index()

    # Rename columns
    df_emis_factors_pivot.rename(columns={
        'NH3': 'delta_egrid_nh3',
        'NOx': 'delta_egrid_nox',
        'PM25': 'delta_egrid_pm25',
        'SO2': 'delta_egrid_so2',
        'VOC': 'delta_egrid_voc'
    }, inplace=True)

    return df_emis_factors_pivot

# Example usage
df_emis_factors_epa_egrid = process_Schmitt_emissions_data(df_grid_mix, df_grid_emis_factors)
df_emis_factors_epa_egrid
# Out:
# Fuel sources in df_grid_mix: {'Coal', 'Natural Gas', 'Renewable', 'Oil', 'Nuclear'}
# Fuel sources in df_grid_emis_factors: {'Renewables', 'Coal', 'Natural Gas', 'Oil', 'Nuclear'}
# pollutant  year cambium_gea_region  delta_egrid_nh3  delta_egrid_nox  \
# 0          2022              AZNMc     4.284055e-11     9.898048e-09
# 1          2022              CAMXc     7.522755e-09     2.069686e-07
# 2          2022              ERCTc     4.432087e-09     4.835162e-07
# 3          2022              FRCCc     0.000000e+00     0.000000e+00
# 4          2022              MROEc     4.849361e-09     5.447874e-07
# ..          ...                ...              ...              ...
# 575        2050              SRMVc     1.411854e-09     1.876759e-08
# 576        2050              SRMWc     6.359354e-10     1.704447e-08
# 577        2050              SRSOc     4.354236e-10     1.003789e-08
# 578        2050              SRTVc     2.546688e-09     2.709200e-08
# 579        2050              SRVCc     5.009715e-10     1.195286e-08
#
# pollutant  delta_egrid_pm25  delta_egrid_so2  delta_egrid_voc
# 0              4.965068e-11     3.457965e-09     1.953264e-11
# 1              9.580178e-09     3.556412e-09     2.775051e-09
# 2              4.317288e-08     1.320681e-06     1.101529e-08
# 3              0.000000e+00     0.000000e+00     0.000000e+00
# 4              1.078161e-08     8.474062e-08     9.076871e-09
# ..                      ...              ...              ...
# 575            2.205976e-09     5.428756e-09     6.989808e-10
# 576            9.728582e-10     4.954324e-09     2.334395e-10
# 577            1.331772e-09     3.118447e-09     4.730064e-10
# 578            4.472789e-09     2.509969e-08     1.490707e-09
# 579            1.611943e-09     6.482390e-09     4.793847e-10
#
# [580 rows x 7 columns]

# %%
# Convert the emissions factors dataframe into a lookup dictionary
lookup_electricity_emissions_egrid = df_emis_factors_epa_egrid.set_index(['year', 'cambium_gea_region']).to_dict('index')

# Display the lookup dictionary
lookup_electricity_emissions_egrid
# Out:
# {(2022, 'AZNMc'): {'delta_egrid_nh3': 4.2840552430687625e-11,
#   'delta_egrid_nox': 9.898047990490191e-09,
#   'delta_egrid_pm25': 4.965068338564084e-11,
#   'delta_egrid_so2': 3.457964622852321e-09,
#   'delta_egrid_voc': 1.9532640138985512e-11},
#  (2022, 'CAMXc'): {'delta_egrid_nh3': 7.522755410773406e-09,
#   'delta_egrid_nox': 2.0696856018167551e-07,
#   'delta_egrid_pm25': 9.580177724431295e-09,
#   'delta_egrid_so2': 3.55641151857646e-09,
#   'delta_egrid_voc': 2.7750506632228643e-09},
#  (2022, 'ERCTc'): {'delta_egrid_nh3': 4.432086644184407e-09,
#   'delta_egrid_nox': 4.835161961260566e-07,
#   'delta_egrid_pm25': 4.3172882994071317e-08,
#   'delta_egrid_so2': 1.3206809363102089e-06,
#   'delta_egrid_voc': 1.101529215996984e-08},
#  (2022, 'FRCCc'): {'delta_egrid_nh3': 0.0,
#   'delta_egrid_nox': 0.0,
#   'delta_egrid_pm25': 0.0,
#   'delta_egrid_so2': 0.0,
#   'delta_egrid_voc': 0.0},
#  (2022, 'MROEc'): {'delta_egrid_nh3': 4.849361388656854e-09,
#   'delta_egrid_nox': 5.447873793436593e-07,
#   'delta_egrid_pm25': 1.0781606810673732e-08,
#   'delta_egrid_so2': 8.474061860290337e-08,
#   'delta_egrid_voc': 9.076870780199286e-09},
#  (2022, 'MROWc'): {'delta_egrid_nh3': 1.7336072380517544e-09,
#   'delta_egrid_nox': 6.168937511165802e-08,
#   'delta_egrid_pm25': 2.587011950711336e-10,
#   'delta_egrid_so2': 8.929875240585145e-09,
#   'delta_egrid_voc': 2.5335292128114916e-10},
#  (2022, 'NEWEc'): {'delta_egrid_nh3': 1.1818972620014011e-08,
#   'delta_egrid_nox': 9.911819965165683e-08,
#   'delta_egrid_pm25': 1.1302243158205714e-08,
#   'delta_egrid_so2': 1.319802349624567e-08,
#   'delta_egrid_voc': 6.636744874881027e-09},
#  (2022, 'NWPPc'): {'delta_egrid_nh3': 1.0803811557863018e-10,
#   'delta_egrid_nox': 2.091673893323325e-09,
#   'delta_egrid_pm25': 1.2619422788729265e-10,
#   'delta_egrid_so2': 1.5195430531729346e-09,
#   'delta_egrid_voc': 5.229756857394434e-11},
#  (2022, 'NYSTc'): {'delta_egrid_nh3': 1.2227845095800112e-07,
#   'delta_egrid_nox': 2.3102571105725708e-06,
#   'delta_egrid_pm25': 1.3747266061024178e-07,
#   'delta_egrid_so2': 3.8918349080421003e-07,
#   'delta_egrid_voc': 3.976575788597393e-08},
#  (2022, 'RFCEc'): {'delta_egrid_nh3': 6.205379749566676e-09,
#   'delta_egrid_nox': 1.280616112319544e-07,
#   'delta_egrid_pm25': 2.136933246409656e-08,
#   'delta_egrid_so2': 1.3986834331598275e-07,
#   'delta_egrid_voc': 4.402767879162515e-09},
#  (2022, 'RFCMc'): {'delta_egrid_nh3': 1.1257712785559177e-11,
#   'delta_egrid_nox': 1.7489706355751261e-09,
#   'delta_egrid_pm25': 1.5643871363958994e-10,
#   'delta_egrid_so2': 3.7924462550596455e-09,
#   'delta_egrid_voc': 3.5250254497789685e-11},
#  (2022, 'RFCWc'): {'delta_egrid_nh3': 2.793561974177535e-09,
#   'delta_egrid_nox': 2.938581842299993e-07,
#   'delta_egrid_pm25': 3.253461451859659e-08,
#   'delta_egrid_so2': 4.10477400244084e-07,
#   'delta_egrid_voc': 6.073130932933494e-09},
#  (2022, 'RMPAc'): {'delta_egrid_nh3': 1.499464754573248e-09,
#   'delta_egrid_nox': 2.2666213439948367e-07,
#   'delta_egrid_pm25': 9.21742570476116e-09,
#   'delta_egrid_so2': 1.5598055452960385e-07,
#   'delta_egrid_voc': 4.695137921530063e-09},
#  (2022, 'SPNOc'): {'delta_egrid_nh3': 1.0557070646139219e-10,
#   'delta_egrid_nox': 4.0049216729117416e-09,
#   'delta_egrid_pm25': 2.406801577126419e-10,
#   'delta_egrid_so2': 2.224956484950967e-10,
#   'delta_egrid_voc': 7.03689994193395e-11},
#  (2022, 'SPSOc'): {'delta_egrid_nh3': 1.9802156173727835e-
 'NWPPc'): {'delta_egrid_nh3': 1.0803811557863018e-10,
#   'delta_egrid_nox': 2.091673893323325e-09,
#   'delta_egrid_pm25': 1.2619422788729265e-10,
#   'delta_egrid_so2': 1.5195430531729346e-09,
#   'delta_egrid_voc': 5.229756857394434e-11},
#  (2023, 'NYSTc'): {'delta_egrid_nh3': 1.2227845095800112e-07,
#   'delta_egrid_nox': 2.3102571105725708e-06,
#   'delta_egrid_pm25': 1.3747266061024178e-07,
#   'delta_egrid_so2': 3.8918349080421003e-07,
#   'delta_egrid_voc': 3.976575788597393e-08},
#  (2023, 'RFCEc'): {'delta_egrid_nh3': 6.205379749566676e-09,
#   'delta_egrid_nox': 1.280616112319544e-07,
#   'delta_egrid_pm25': 2.136933246409656e-08,
#   'delta_egrid_so2': 1.3986834331598275e-07,
#   'delta_egrid_voc': 4.402767879162515e-09},
#  (2023, 'RFCMc'): {'delta_egrid_nh3': 1.1257712785559177e-11,
#   'delta_egrid_nox': 1.7489706355751261e-09,
#   'delta_egrid_pm25': 1.5643871363958994e-10,
#   'delta_egrid_so2': 3.7924462550596455e-09,
#   'delta_egrid_voc': 3.5250254497789685e-11},
#  (2023, 'RFCWc'): {'delta_egrid_nh3': 2.793561974177535e-09,
#   'delta_egrid_nox': 2.938581842299993e-07,
#   'delta_egrid_pm25': 3.253461451859659e-08,
#   'delta_egrid_so2': 4.10477400244084e-07,
#   'delta_egrid_voc': 6.073130932933494e-09},
#  (2023, 'RMPAc'): {'delta_egrid_nh3': 1.499464754573248e-09,
#   'delta_egrid_nox': 2.2666213439948367e-07,
#   'delta_egrid_pm25': 9.21742570476116e-09,
#   'delta_egrid_so2': 1.5598055452960385e-07,
#   'delta_egrid_voc': 4.695137921530063e-09},
#  (2023, 'SPNOc'): {'delta_egrid_nh3': 1.0557070646139219e-10,
#   'delta_egrid_nox': 4.0049216729117416e-09,
#   'delta_egrid_pm25': 2.406801577126419e-10,
#   'delta_egrid_so2': 2.224956484950967e-10,
#   'delta_egrid_voc': 7.03689994193395e-11},
#  (2023, 'SPSOc'): {'delta_egrid_nh3': 1.9802156173727835e-10,
#   'delta_egrid_nox': 7.778488729668226e-09,
#   'delta_egrid_pm25': 5.200444332066354e-10,
#   'delta_egrid_so2': 7.553047231988934e-09,
#   'delta_egrid_voc': 1.6790126402156844e-10},
#  (2023, 'SRMVc'): {'delta_egrid_nh3': 1.1283095650164155e-08,
#   'delta_egrid_nox': 3.110745260815928e-07,
#   'delta_egrid_pm25': 3.3133289004500695e-08,
#   'delta_egrid_so2': 5.723024883766816e-07,
#   'delta_egrid_voc': 8.11737466534651e-09},
#  (2023, 'SRMWc'): {'delta_egrid_nh3': 6.451342236582435e-09,
#   'delta_egrid_nox': 6.351587187199333e-07,
#   'delta_egrid_pm25': 3.423070058615794e-08,
#   'delta_egrid_so2': 1.3311060273977186e-06,
#   'delta_egrid_voc': 9.745283931162503e-09},
#  (2023, 'SRSOc'): {'delta_egrid_nh3': 7.26514065326633e-09,
#   'delta_egrid_nox': 2.448742671882815e-07,
#   'delta_egrid_pm25': 2.5846881009262006e-08,
#   'delta_egrid_so2': 9.492341657326844e-08,
#   'delta_egrid_voc': 9.753088907806246e-09},
#  (2023, 'SRTVc'): {'delta_egrid_nh3': 3.3444167015957022e-09,
#   'delta_egrid_nox': 1.7399534844061337e-07,
#   'delta_egrid_pm25': 1.6441948240156624e-08,
#   'delta_egrid_so2': 2.6903051569179297e-07,
#   'delta_egrid_voc': 4.8139875659354785e-09},
#  (2023, 'SRVCc'): {'delta_egrid_nh3': 4.822949895662047e-09,
#   'delta_egrid_nox': 2.2139215257943798e-07,
#   'delta_egrid_pm25': 2.327306995719924e-08,
#   'delta_egrid_so2': 1.3329105431375388e-07,
#   'delta_egrid_voc': 6.351919067887989e-09},
#  (2024, 'AZNMc'): {'delta_egrid_nh3': 4.2840552430687625e-
#   'delta_egrid_nox': 6.169915108816059e-08,
#   'delta_egrid_pm25': 2.1436526358792065e-09,
#   'delta_egrid_so2': 4.7571745796005286e-08,
#   'delta_egrid_voc': 5.818732792342467e-10},
#  (2025, 'NEWEc'): {'delta_egrid_nh3': 6.089486319381256e-09,
#   'delta_egrid_nox': 7.834746060741735e-08,
#   'delta_egrid_pm25': 7.71305707298391e-09,
#   'delta_egrid_so2': 2.2248669292656213e-08,
#   'delta_egrid_voc': 3.6148694013600555e-09},
#  (2025, 'NWPPc'): {'delta_egrid_nh3': 4.1074775043626415e-09,
#   'delta_egrid_nox': 2.9245499767704436e-07,
#   'delta_egrid_pm25': 1.556231934427126e-08,
#   'delta_egrid_so2': 1.7969920651311817e-07,
#   'delta_egrid_voc': 4.4881071243635855e-09},
#  (2025, 'NYSTc'): {'delta_egrid_nh3': 1.510858384400355e-07,
#   'delta_egrid_nox': 2.9763688381916046e-06,
#   'delta_egrid_pm25': 1.6890008508299168e-07,
#   'delta_egrid_so2': 6.835252115509069e-07,
#   'delta_egrid_voc': 5.152900284499442e-08},
#  (2025, 'RFCEc'): {'delta_egrid_nh3': 3.839584890924854e-09,
#   'delta_egrid_nox': 1.9333476962155083e-07,
#   'delta_egrid_pm25': 2.8454997299149638e-08,
#   'delta_egrid_so2': 3.3545286005199655e-07,
#   'delta_egrid_voc': 4.508756436280735e-09},
#  (2025, 'RFCMc'): {'delta_egrid_nh3': 4.1042912627922663e-10,
#   'delta_egrid_nox': 6.376326199829121e-08,
#   'delta_egrid_pm25': 5.703379165766648e-09,
#   'delta_egrid_so2': 1.3826346724013903e-07,
#   'delta_egrid_voc': 1.285139479948953e-09},
#  (2025, 'RFCWc'): {'delta_egrid_nh3': 4.722688977987049e-09,
#   'delta_egrid_nox': 2.989832541895575e-07,
#   'delta_egrid_pm25': 3.348058704718827e-08,
#   'delta_egrid_so2': 3.71965191380899e-07,
#   'delta_egrid_voc': 6.471153177700919e-09},
#  (2025, 'RMPAc'): {'delta_egrid_nh3': 2.147376217794283e-09,
#   'delta_egrid_nox': 3.2460174565588055e-07,
#   'delta_egrid_pm25': 1.3200230740550518e-08,
#   'delta_egrid_so2': 2.2337899721461816e-07,
#   'delta_egrid_voc': 6.7238842935172365e-09},
#  (2025, 'SPNOc'): {'delta_egrid_nh3': 7.932869932613495e-11,
#   'delta_egrid_nox': 5.176308443965794e-09,
#   'delta_egrid_pm25': 3.772932744834421e-10,
#   'delta_egrid_so2': 1.4246770199250401e-09,
#   'delta_egrid_voc': 1.1829727074139925e-10},
#  (2025, 'SPSOc'): {'delta_egrid_nh3': 1.8442050348384245e-10,
#   'delta_egrid_nox': 2.1205400705214845e-08,
#   'delta_egrid_pm25': 1.1808406061511862e-09,
#   'delta_egrid_so2': 3.357127344816509e-08,
#   'delta_egrid_voc': 3.5138634618476197e-10},
#  (2025, 'SRMVc'): {'delta_egrid_nh3': 1.5470260384700318e-08,
#   'delta_egrid_nox': 2.7565777091919135e-07,
#   'delta_egrid_pm25': 2.0300223190586124e-08,
#   'delta_egrid_so2': 2.925702490624564e-08,
#   'delta_egrid_voc': 1.0365170501939606e-08},
#  (2030, 'RFCWc'): {'delta_egrid_nh3': 5.339986541743724e-09,
#   'delta_egrid_nox': 1.7172088817010324e-07,
#   'delta_egrid_pm25': 1.9726396941454464e-08,
#   'delta_egrid_so2': 1.511733007853854e-07,
#   'delta_egrid_voc': 4.107890729485616e-09},
#  (2030, 'RMPAc'): {'delta_egrid_nh3': 0.0,
#   'delta_egrid_nox': 0.0,
#   'delta_egrid_pm25': 0.0,
#   'delta_egrid_so2': 0.0,
#   'delta_egrid_voc': 0.0},
#  (2030, 'SPNOc'): {'delta_egrid_nh3': 1.1488209230168774e-10,
#   'delta_egrid_nox': 1.3736710228108487e-08,
#   'delta_egrid_pm25': 1.112117539028752e-09,
#   'delta_egrid_so2': 5.684644789960272e-09,
#   'delta_egrid_voc': 3.5971987099082053e-10},
#  (2030, 'SPSOc'): {'delta_egrid_nh3': 4.775180702062519e-12,
#   'delta_egrid_nox': 9.681307122728536e-10,
#   'delta_egrid_pm25': 5.148212720094434e-11,
#   'delta_egrid_so2': 1.6657976406545081e-09,
#   'delta_egrid_voc': 1.4952090022811588e-11},
#  (2030, 'SRMVc'): {'delta_egrid_nh3': 1.8808968734956135e-08,
#   'delta_egrid_nox': 2.632545114486018e-07,
#   'delta_egrid_pm25': 3.0636872886715366e-08,
#   'delta_egrid_so2': 1.130044468430654e-07,
#   'delta_egrid_voc': 9.512657122590187e-09},
#  (2030, 'SRMWc'): {'delta_egrid_nh3': 5.044754902892576e-10,
#   'delta_egrid_nox': 9.765826425000403e-08,
#   'delta_egrid_pm25': 5.365248496145651e-09,
#   'delta_egrid_so2': 2.4324342428887093e-07,
#   'delta_egrid_voc': 1.5773306238208286e-09},
#  (2030, 'SRSOc'): {'delta_egrid_nh3': 1.0149729792642581e-09,
#   'delta_egrid_nox': 1.0971479856956173e-07,
#   'delta_egrid_pm25': 7.148571654318988e-09,
#   'delta_egrid_so2': 5.510788969247393e-08,
#   'delta_egrid_voc': 3.17809278926881e-09},
#  (2030, 'SRTVc'): {'delta_egrid_nh3': 1.531805189109803e-08,
#   'delta_egrid_nox': 1.2797881104734643e-07,
#   'delta_egrid_pm25': 2.4232882978628378e-08,
#   'delta_egrid_so2': 9.131970887463929e-08,
#   'delta_egrid_voc': 8.244671015501043e-09},
#  (2030, 'SRVCc'): {'delta_egrid_nh3': 3.5553760553608624e-11,
#   'delta_egrid_nox': 5.536787895468479e-09,
#   'delta_egrid_pm25': 4.430724323940151e-10,
#   'delta_egrid_so2': 3.549422479014644e-09,
#   'delta_egrid_voc': 1.0770271200505242e-10},
#  (2031, 'AZNMc'): {'delta_egrid_nh3': 2.8190325919734563e-10,
#   'delta_egrid_nox': 3.754190312179467e-08,
#   'delta_egrid_pm25': 1.602214561690265e-09,
#   'delta_egrid_so2': 1.67887427675222e-08,
#   'delta_egrid_voc': 6.379996914720229e-10},
#  (2031, 'CAMXc'): {'delta_egrid_nh3': 2.3491314249167226e-10,
#   'delta_egrid_nox': 1.0712687114777293e-08,
#   'delta_egrid_pm25': 3.008666058000848e-10,
#   'delta_egrid_so2': 4.521700301615389e-10,
#   'delta_egrid_voc': 8.708727657512932e-11},
#  (2031, 'ERCTc'): {'delta_egrid_nh3': 2.440912387447246e-10,
#   'delta_egrid_nox': 2.7452879928583032e-08,
#   'delta_egrid_pm25': 2.452787900724089e-09,
#   'delta_egrid_so2': 7.550840415625406e-08,
#   'delta_egrid_voc': 6.258250477045923e-10},
#  (2031, 'FRCCc'): {'delta_egrid_nh3': 5.037765518989846e-10,
#   'delta_egrid_nox': 3.1890544762553955e-08,
#   'delta_egrid_pm25': 1.254727702355857e-08,
#   'delta_egrid_so2': 5.035349173034835e-08,
#   'delta_egrid_voc': 1.5774298032578648e-09},
#  (2031, 'MROEc'): {'delta_egrid_nh3': 1.0150467387783033e-09,
#   'delta_egrid_nox': 1.062146828971577e-07,
#   'delta_egrid_pm25': 2.756119480800616e-09,
#   'delta_egrid_so2': 4.584377913665114e-08,
#   'delta_egrid_voc': 2.737020158044949e-09},
#  (2031, 'MROWc'): {'delta_egrid_nh3': 1.2467701711956997e-10,
#   'delta_egrid_nox': 1.79002139990471e-08,
#   'delta_egrid_pm25': 1.1099279468051103e-09,
#   'delta_egrid_so2': 2.383094646318825e-08,
#   'delta_egrid_voc': 2.530714540305487e-10},
#  (2031, 'NEWEc'): {'delta_egrid_nh3': 9.010510036939333e-09,
#   'delta_egrid_nox': 7.181160717676778e-08,
#   'delta_egrid_pm25': 8.187052778977768e-09,
#   'delta_egrid_so2': 8.070107469651453e-09,
#   'delta_egrid_voc': 5.010791163859789e-09},
#  (2031, 'NWPPc'): {'delta_egrid_nh3': 9.536976269818254e-09,
#   'delta_egrid_nox': 3.879900737399049e-07,
#   'delta_egrid_pm25': 2.0918065240338167e-08,
#   'delta_egrid_so2': 1.665786310079901e-07,
#   'delta_egrid_voc': 7.000922833691556e-09},
#  (2031, 'NYSTc'): {'delta_egrid_nh3': 4.1047364011118525e-08,
#   'delta_egrid_nox': 7.332864691977455e-07,
#   'delta_egrid_pm25': 5.301666848980797e-08,
#   'delta_egrid_so2': 1.238614836017221e-07,
#   'delta_egrid_voc': 1.7471209606188137e-08},
#  (2031, 'RFCEc'): {'delta_egrid_nh3': 2.3352731887546708e-09,
#   'delta_egrid_nox': 2.190618254227435e-07,
#   'delta_egrid_pm25': 2.9016219025065158e-08,
#   'delta_egrid_so2': 3.933419470798027e-07,
#   'delta_egrid_voc': 4.138790780760528e-09},
#  (2031, 'RFCMc'): {'delta_egrid_nh3': 1.1019039004314869e-08,
#   'delta_egrid_nox': 1.7674511381834767e-07,
#   'delta_egrid_pm25': 1.8897647051708173e-08,
#   'delta_egrid_so2': 5.790622430562672e-08,
#   'delta_egrid_voc': 9.26530476067428e-09},
#  (2031, 'RFCWc'): {'delta_egrid_nh3': 4.7216440415231746e-09,
#   'delta_egrid_nox': 1.5070679237348717e-07,
#   'delta_egrid_voc': 2.5952705749060876e-12},
#  (2050, 'NEWEc'): {'delta_egrid_nh3': 3.4907815695483846e-09,
#   'delta_egrid_nox': 3.221174712893331e-08,
#   'delta_egrid_pm25': 3.2103881693944418e-09,
#   'delta_egrid_so2': 5.823396514444565e-09,
#   'delta_egrid_voc': 1.9381933536812488e-09},
#  (2050, 'NWPPc'): {'delta_egrid_nh3': 2.060848360954791e-09,
#   'delta_egrid_nox': 5.056738298932853e-08,
#   'delta_egrid_pm25': 2.7817331699469454e-09,
#   'delta_egrid_so2': 7.509569594614302e-09,
#   'delta_egrid_voc': 1.121873845817696e-09},
#  (2050, 'NYSTc'): {'delta_egrid_nh3': 1.644785579672998e-08,
#   'delta_egrid_nox': 1.852446854412016e-07,
#   'delta_egrid_pm25': 3.994129611470981e-08,
#   'delta_egrid_so2': 4.2284042571739375e-08,
#   'delta_egrid_voc': 1.8385745087212658e-08},
#  (2050, 'RFCEc'): {'delta_egrid_nh3': 3.9971213972500265e-09,
#   'delta_egrid_nox': 4.057675387241223e-08,
#   'delta_egrid_pm25': 8.859568588308587e-09,
#   'delta_egrid_so2': 1.070118086501293e-08,
#   'delta_egrid_voc': 2.25204783611104e-09},
#  (2050, 'RFCMc'): {'delta_egrid_nh3': 1.543018983840609e-09,
#   'delta_egrid_nox': 2.235412028766896e-08,
#   'delta_egrid_pm25': 2.4367959540586945e-09,
#   'delta_egrid_so2': 2.4058033022028563e-09,
#   'delta_egrid_voc': 1.2580521722969223e-09},
#  (2050, 'RFCWc'): {'delta_egrid_nh3': 2.4375145578539124e-09,
#   'delta_egrid_nox': 4.804849905576339e-08,
#   'delta_egrid_pm25': 5.689888157919158e-09,
#   'delta_egrid_so2': 2.021149052594047e-08,
#   'delta_egrid_voc': 1.2856040325265299e-09},
#  (2050, 'RMPAc'): {'delta_egrid_nh3': 1.1414298321057555e-09,
#   'delta_egrid_nox': 6.077417304806603e-08,
#   'delta_egrid_pm25': 3.017629062633667e-09,
#   'delta_egrid_so2': 3.538726317700401e-08,
#   'delta_egrid_voc': 1.4935571742458922e-09},
#  (2050, 'SPNOc'): {'delta_egrid_nh3': 3.9994237838744383e-10,
#   'delta_egrid_nox': 3.3229728080361794e-08,
#   'delta_egrid_pm25': 2.548789210468866e-09,
#   'delta_egrid_so2': 1.1321983813637848e-08,
#   'delta_egrid_voc': 8.117532793458217e-10},
#  (2050, 'SPSOc'): {'delta_egrid_nh3': 2.4644377104104193e-10,
#   'delta_egrid_nox': 1.0929176887664765e-08,
#   'delta_egrid_pm25': 7.09503570687544e-10,
#   'delta_egrid_so2': 1.177332456517372e-08,
#   'delta_egrid_voc': 2.263994869067272e-10},
#  (2050, 'SRMVc'): {'delta_egrid_nh3': 1.4118538262837829e-09,
#   'delta_egrid_nox': 1.8767585248870803e-08,
#   'delta_egrid_pm25': 2.2059758001868487e-09,
#   'delta_egrid_so2': 5.4287557165417305e-09,
#   'delta_egrid_voc': 6.989807992096654e-10},
#  (2050, 'SRMWc'): {'delta_egrid_nh3': 6.359353651154698e-10,
#   'delta_egrid_nox': 1.704447498286052e-08,
#   'delta_egrid_pm25': 9.728582118726556e-10,
#   'delta_egrid_so2': 4.9543236724377115e-09,
#   'delta_egrid_voc': 2.3343946609875245e-10},
#  (2050, 'SRSOc'): {'delta_egrid_nh3': 4.3542355481160475e-10,
#   'delta_egrid_nox': 1.0037888161919653e-08,
#   'delta_egrid_pm25': 1.3317717654385732e-09,
#   'delta_egrid_so2': 3.118447442025165e-09,
#   'delta_egrid_voc': 4.730064270608178e-10},
#  (2050, 'SRTVc'): {'delta_egrid_nh3': 2.546688417930353e-09,
#   'delta_egrid_nox': 2.7092002634874156e-08,
#   'delta_egrid_pm25': 4.472789180948378e-09,
#   'delta_egrid_so2': 2.5099694416336604e-08,
#   'delta_egrid_voc': 1.4907066926746873e-09},
#  (2050, 'SRVCc'): {'delta_egrid_nh3': 5.009714816997781e-10,
#   'delta_egrid_nox': 1.195285577588597e-08,
#   'delta_egrid_pm25': 1.6119427329709485e-09,
#   'delta_egrid_so2': 6.482389600585455e-09,
#   'delta_egrid_voc': 4.793846657231758e-10}}

# %%
# # Check unique fuel sources in both dataframes
# fuel_sources_mix = set(df_grid_mix['fuel_source'].unique())
# fuel_sources_emis = set(df_grid_emis_factors['fuel_source'].unique())

# print("Fuel sources in df_grid_mix:", fuel_sources_mix)
# print("Fuel sources in df_grid_emis_factors:", fuel_sources_emis)

# # Merge the dataframes
# df_combined = pd.merge(
#     df_grid_mix,
#     df_grid_emis_factors,
#     on=['cambium_gea_region', 'fuel_source'],
#     how='inner'
# )

# # Calculate emissions contribution
# df_combined['emis_contribution'] = df_combined['fraction_generation'] * df_combined['emis_rate']

# # Sum emissions contributions
# df_emis_factors = df_combined.groupby(
#     ['year', 'cambium_gea_region', 'pollutant']
# )['emis_contribution'].sum().reset_index()
# df_emis_factors

# %% [markdown]
# ### Electricity - Method 2: CEDM Marginal Emissions Factors and EASIUR (Coal Generation Reduction)

# %%
import os
import pandas as pd

print("""
-------------------------------------------------------------------------------------------------------
COAL USED IN ELECTRICITY GENERATION FROM CAMBIUM 2021 RELEASE
-------------------------------------------------------------------------------------------------------
""")

# CAMBIUM 2022 FOR IRA SCENARIO
filename = 'cambium21_midCase_annual_gea.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_cambium21_COAL_processed = pd.read_excel(io=file_path, sheet_name='proc_Cambium21_coal_gea')

print(f"""
Retrieved data for filename: {filename}
Located at filepath: {file_path}
-------------------------------------------------------------------------------------------------------
""")
df_cambium21_COAL_processed
# Out:
# -------------------------------------------------------------------------------------------------------
# COAL USED IN ELECTRICITY GENERATION FROM CAMBIUM 2021 RELEASE
# -------------------------------------------------------------------------------------------------------
#
#
# Retrieved data for filename: cambium21_midCase_annual_gea.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\cambium21_midCase_annual_gea.xlsx
# -------------------------------------------------------------------------------------------------------
#       data_source scenario gea_region  year    coal_MWh
# 0    Cambium_2021  MidCase      AZNMc  2022  32912356.0
# 1    Cambium_2021  MidCase      AZNMc  2024  27460646.0
# 2    Cambium_2021  MidCase      AZNMc  2026  26772840.0
# 3    Cambium_2021  MidCase      AZNMc  2028  26693880.0
# 4    Cambium_2021  MidCase      AZNMc  2030  24898662.0
# ..            ...      ...        ...   ...         ...
# 295  Cambium_2021  MidCase      SRVCc  2042  37576316.0
# 296  Cambium_2021  MidCase      SRVCc  2044  33240228.0
# 297  Cambium_2021  MidCase      SRVCc  2046  27152428.0
# 298  Cambium_2021  MidCase      SRVCc  2048  27861414.0
# 299  Cambium_2021  MidCase      SRVCc  2050  14777366.0
#
# [300 rows x 5 columns]

# %%
import os
import pandas as pd

print("""
-------------------------------------------------------------------------------------------------------
COAL USED IN ELECTRICITY GENERATION FROM CAMBIUM 2022 RELEASE
-------------------------------------------------------------------------------------------------------
""")

# CAMBIUM 2022 FOR IRA SCENARIO
filename = 'cambium22_allScenarios_annual_gea.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_cambium22_COAL_processed = pd.read_excel(io=file_path, sheet_name='proc_Cambium22_coal_gea')

print(f"""
Retrieved data for filename: {filename}
Located at filepath: {file_path}
-------------------------------------------------------------------------------------------------------
""")
df_cambium22_COAL_processed
# Out:
# -------------------------------------------------------------------------------------------------------
# COAL USED IN ELECTRICITY GENERATION FROM CAMBIUM 2022 RELEASE
# -------------------------------------------------------------------------------------------------------
#
#
# Retrieved data for filename: cambium22_allScenarios_annual_gea.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\cambium22_allScenarios_annual_gea.xlsx
# -------------------------------------------------------------------------------------------------------
#       data_source scenario gea_region  year    coal_MWh
# 0    Cambium_2022  MidCase      AZNMc  2024  22849070.0
# 1    Cambium_2022  MidCase      AZNMc  2026  21009922.0
# 2    Cambium_2022  MidCase      AZNMc  2028  14483350.0
# 3    Cambium_2022  MidCase      AZNMc  2030  13433882.0
# 4    Cambium_2022  MidCase      AZNMc  2035   8231337.5
# ..            ...      ...        ...   ...         ...
# 155  Cambium_2022  MidCase      SRVCc  2030  17312904.0
# 156  Cambium_2022  MidCase      SRVCc  2035   8787109.0
# 157  Cambium_2022  MidCase      SRVCc  2040   6132569.5
# 158  Cambium_2022  MidCase      SRVCc  2045   4301606.5
# 159  Cambium_2022  MidCase      SRVCc  2050   1924772.2
#
# [160 rows x 5 columns]

# %%
# EPA eGRID Coal Generation Data for 2018 to 2022 ()
filename = 'epa_eGRID_total_coal_generation_2018_2022.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_epa_eGRID_COAL_processed = pd.read_excel(io=file_path, sheet_name='coal_generation_2018_2022')

print(f"""
Retrieved data for filename: {filename}
Located at filepath: {file_path}
-------------------------------------------------------------------------------------------------------
""") 

# Apply the mapping to the 'cambium_gea_region' column
df_epa_eGRID_COAL_processed['cambium_gea_region'] = df_epa_eGRID_COAL_processed['eGRID_subregion'].map(mapping)

# Drop rows where 'cambium_gea_region' is None (regions not included in the mapping)
df_epa_eGRID_COAL_processed = df_epa_eGRID_COAL_processed.dropna(subset=['cambium_gea_region'])

# Group by 'cambium_gea_region' and aggregate
df_epa_eGRID_COAL_processed = (
    df_epa_eGRID_COAL_processed
    .groupby('cambium_gea_region', as_index=False)
    .agg({
        'eGRID_subregion': 'first',  # Retain the first value (or use a different strategy)
        'coal_MWh_2018': 'sum',
        'coal_MWh_2019': 'sum',
        'coal_MWh_2020': 'sum',
        'coal_MWh_2021': 'sum',
        'coal_MWh_2022': 'sum'
    })
)
df_epa_eGRID_COAL_processed
# Out:
# Retrieved data for filename: epa_eGRID_total_coal_generation_2018_2022.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\epa_eGRID_total_coal_generation_2018_2022.xlsx
# -------------------------------------------------------------------------------------------------------
#    cambium_gea_region eGRID_subregion  coal_MWh_2018  coal_MWh_2019  \
# 0               AZNMc            AZNM   4.414615e+07   3.790964e+07
# 1               CAMXc            CAMX   8.763279e+06   7.780068e+06
# 2               ERCTc            ERCT   9.316147e+07   7.783883e+07
# 3               FRCCc            FRCC   2.712368e+07   1.867757e+07
# 4               MROEc            MROE   1.544367e+07   1.145490e+07
# 5               MROWc            MROW   1.226471e+08   1.026703e+08
# 6               NEWEc            NEWE   1.036896e+06   4.671207e+05
# 7               NWPPc            NWPP   6.285837e+07   6.498340e+07
# 8               NYSTc            NYCW   6.903856e+05   4.219514e+05
# 9               RFCEc            RFCE   4.622571e+07   3.655599e+07
# 10              RFCMc            RFCM   4.076499e+07   3.710288e+07
# 11              RFCWc            RFCW   2.362675e+08   1.922758e+08
# 12              RMPAc            RMPA   2.928132e+07   2.817545e+07
# 13              SPNOc            SPNO   3.324073e+07   2.957866e+07
# 14              SPSOc            SPSO   4.971438e+07   3.543939e+07
# 15              SRMVc            SRMV   2.984704e+07   1.986385e+07
# 16              SRMWc            SRMW   9.014568e+07   8.007919e+07
# 17              SRSOc            SRSO   6.902160e+07   5.642709e+07
# 18              SRTVc            SRTV   7.953831e+07   6.913109e+07
# 19              SRVCc            SRVC   6.267483e+07   5.231708e+07
#
#     coal_MWh_2020  coal_MWh_2021  coal_MWh_2022
# 0        26535437   2.683689e+07       26741465
# 1         7033071   7.855352e+06        5747480
# 2        68260811   7.451014e+07       71217304
# 3        15879327   1.837499e+07       15227544
# 4        10581044   1.311374e+07       10480887
# 5        86817250   9.622939e+07       95599125
# 6          164881   5.788068e+05         347898
# 7        52353815   5.373488e+07       52895365
# 8          143692   0.000000e+00              0
# 9        24332566   2.996836e+07       25441381
# 10       27960123   3.705257e+07       34477355
# 11      159396263   1.854556e+08      168150600
# 12       22383379   2.621280e+07       24543081
# 13       25942028   2.979506e+07       29145931
# 14       27573930   3.991079e+07       36492339
# 15       11265932   1.901804e+07       19136714
# 16       66855639   7.696128e+07       70231873
# 17       38458688   4.876479e+07       45464600
# 18       57525460   6.791764e+07       62715588
# 19       40994163   4.325049e+07       35634460

# %%
import pandas as pd
import numpy as np

# Step 1: Melt the DataFrame to Long Format
columns_to_melt = ['coal_MWh_2018', 'coal_MWh_2019', 'coal_MWh_2020', 'coal_MWh_2021', 'coal_MWh_2022']
df_melted = pd.melt(
    df_epa_eGRID_COAL_processed,
    id_vars=['eGRID_subregion', 'cambium_gea_region'],
    value_vars=columns_to_melt,
    var_name='year',
    value_name='coal_MWh'
)

# Step 2: Extract the Year from Column Names
df_melted['year'] = df_melted['year'].str.extract('(\d{4})').astype(int)

# Step 3: Create Columns to Match the Target DataFrame
df_preIRA_transformed = pd.DataFrame({
    'data_source': 'EPA_eGRID',
    'scenario': 'MidCase',
    'eGRID_subregion': df_melted['eGRID_subregion'],
    'gea_region': df_melted['cambium_gea_region'],
    'year': df_melted['year'],
    'coal_MWh': df_melted['coal_MWh'],
})

# Step 4: Combine the DataFrames
df_preIRA_coal_generation = pd.concat([df_preIRA_transformed, df_cambium21_COAL_processed], ignore_index=True)
df_preIRA_coal_generation
# Out:
#       data_source scenario eGRID_subregion gea_region  year     coal_MWh
# 0       EPA_eGRID  MidCase            AZNM      AZNMc  2018  44146154.50
# 1       EPA_eGRID  MidCase            CAMX      CAMXc  2018   8763279.09
# 2       EPA_eGRID  MidCase            ERCT      ERCTc  2018  93161470.51
# 3       EPA_eGRID  MidCase            FRCC      FRCCc  2018  27123675.80
# 4       EPA_eGRID  MidCase            MROE      MROEc  2018  15443667.62
# ..            ...      ...             ...        ...   ...          ...
# 395  Cambium_2021  MidCase             NaN      SRVCc  2042  37576316.00
# 396  Cambium_2021  MidCase             NaN      SRVCc  2044  33240228.00
# 397  Cambium_2021  MidCase             NaN      SRVCc  2046  27152428.00
# 398  Cambium_2021  MidCase             NaN      SRVCc  2048  27861414.00
# 399  Cambium_2021  MidCase             NaN      SRVCc  2050  14777366.00
#
# [400 rows x 6 columns]

# %%
# Step 3: Create Columns to Match the Target DataFrame
df_iraRef_transformed = pd.DataFrame({
    'data_source': 'EPA_eGRID',
    'scenario': 'MidCase',
    'eGRID_subregion': df_melted['eGRID_subregion'],
    'gea_region': df_melted['cambium_gea_region'],
    'year': df_melted['year'],
    'coal_MWh': df_melted['coal_MWh'],
})

# Step 4: Combine the DataFrames
df_iraRef_coal_generation = pd.concat([df_iraRef_transformed, df_cambium22_COAL_processed], ignore_index=True)
df_iraRef_coal_generation
# Out:
#       data_source scenario eGRID_subregion gea_region  year     coal_MWh
# 0       EPA_eGRID  MidCase            AZNM      AZNMc  2018  44146154.50
# 1       EPA_eGRID  MidCase            CAMX      CAMXc  2018   8763279.09
# 2       EPA_eGRID  MidCase            ERCT      ERCTc  2018  93161470.51
# 3       EPA_eGRID  MidCase            FRCC      FRCCc  2018  27123675.80
# 4       EPA_eGRID  MidCase            MROE      MROEc  2018  15443667.62
# ..            ...      ...             ...        ...   ...          ...
# 255  Cambium_2022  MidCase             NaN      SRVCc  2030  17312904.00
# 256  Cambium_2022  MidCase             NaN      SRVCc  2035   8787109.00
# 257  Cambium_2022  MidCase             NaN      SRVCc  2040   6132569.50
# 258  Cambium_2022  MidCase             NaN      SRVCc  2045   4301606.50
# 259  Cambium_2022  MidCase             NaN      SRVCc  2050   1924772.20
#
# [260 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

def calculate_coal_projection_factors(df_cambium):
    """
    Interpolates coal_MWh and calculates coal projection factors for each region from 2018 to 2050,
    using 2018 coal generation as the reference point.

    Parameters
    ----------
    df_cambium : pandas.DataFrame
        DataFrame containing Cambium coal generation data with the following columns:
        - 'scenario': Scenario name or identifier.
        - 'gea_region': GEA region identifier.
        - 'year': Year of the data.
        - 'coal_MWh': Coal generation in MWh.

    Returns
    -------
    df_coal_factors : pandas.DataFrame
        DataFrame with interpolated coal_MWh values and a new column 'coal_projection_factors'.
    """
    # Create a copy of the dataframe
    df_cambium_copy = df_cambium.copy()

    # Create a new DataFrame to store interpolated results
    interpolated_data = []

    # Group by 'scenario' and 'gea_region'
    grouped = df_cambium_copy.groupby(['scenario', 'gea_region'])

    for (scenario, gea_region), group in grouped:
        # Extract existing years and coal_MWh values
        years = group['year'].values
        coal_MWh_values = group['coal_MWh'].values

        # Create interpolation function, allowing extrapolation
        coal_MWh_interp_func = interp1d(years, coal_MWh_values, kind='linear', bounds_error=False, fill_value="extrapolate")

        # Generate years from 2018 to 2050
        all_years = np.arange(2018, 2051)

        # Interpolate the coal_MWh values for these years
        interpolated_values = coal_MWh_interp_func(all_years)

        # Store the results in a DataFrame
        interpolated_group = pd.DataFrame({
            'scenario': scenario,
            'gea_region': gea_region,
            'year': all_years,
            'coal_MWh': interpolated_values
        })

        interpolated_data.append(interpolated_group)

    # Concatenate all the interpolated data into a single DataFrame
    df_interpolated = pd.concat(interpolated_data).reset_index(drop=True)

    # Get the coal_MWh value in 2018 for each scenario and gea_region
    coal_MWh_2018 = df_interpolated[df_interpolated['year'] == 2018][['scenario', 'gea_region', 'coal_MWh']]
    coal_MWh_2018 = coal_MWh_2018.set_index(['scenario', 'gea_region'])['coal_MWh']

    # Map the 2018 coal_MWh values to the DataFrame
    df_interpolated['coal_MWh_2018'] = df_interpolated.set_index(['scenario', 'gea_region']).index.map(coal_MWh_2018)

    # Avoid division by zero by replacing zero coal_MWh_2018 with NaN
    df_interpolated['coal_MWh_2018'] = df_interpolated['coal_MWh_2018'].replace(0, np.nan)

    # Conditions for regions other than CAMX
    condition_regions = (df_interpolated['gea_region'] != 'CAMX')

    # Calculate coal projection factors for regions other than CAMX
    df_interpolated.loc[condition_regions, 'coal_projection_factors'] = (
        df_interpolated.loc[condition_regions, 'coal_MWh'] / df_interpolated.loc[condition_regions, 'coal_MWh_2018']
    )

    # For CAMX region, assign coal_projection_factors as 1
    condition_CAMX = (df_interpolated['gea_region'] == 'CAMX')
    df_interpolated.loc[condition_CAMX, 'coal_projection_factors'] = 1

    # Replace any NaN or infinite values resulting from division by zero with 0
    df_interpolated['coal_projection_factors'] = df_interpolated['coal_projection_factors'].replace([np.inf, -np.inf, np.nan], 0)

    # Drop temporary columns
    df_interpolated.drop(columns=['coal_MWh_2018'], inplace=True)

    return df_interpolated

# %%
# Calculate Coal Generation Projection Factors
df_preIRA_coal_projection_factors = calculate_coal_projection_factors(df_preIRA_coal_generation)
df_preIRA_coal_projection_factors
# Out:
#     scenario gea_region  year     coal_MWh  coal_projection_factors
# 0    MidCase      AZNMc  2018  44146154.50                 1.000000
# 1    MidCase      AZNMc  2019  37909639.38                 0.858730
# 2    MidCase      AZNMc  2020  26535437.00                 0.601082
# 3    MidCase      AZNMc  2021  26836891.44                 0.607910
# 4    MidCase      AZNMc  2022  26741465.00                 0.605748
# ..       ...        ...   ...          ...                      ...
# 655  MidCase      SRVCc  2046  27152428.00                 0.433227
# 656  MidCase      SRVCc  2047  27506921.00                 0.438883
# 657  MidCase      SRVCc  2048  27861414.00                 0.444539
# 658  MidCase      SRVCc  2049  21319390.00                 0.340159
# 659  MidCase      SRVCc  2050  14777366.00                 0.235778
#
# [660 rows x 5 columns]

# %%
# Calculate Coal Generation Projection Factors
df_iraRef_coal_projection_factors = calculate_coal_projection_factors(df_iraRef_coal_generation)
df_iraRef_coal_projection_factors
# Out:
#     scenario gea_region  year     coal_MWh  coal_projection_factors
# 0    MidCase      AZNMc  2018  44146154.50                 1.000000
# 1    MidCase      AZNMc  2019  37909639.38                 0.858730
# 2    MidCase      AZNMc  2020  26535437.00                 0.601082
# 3    MidCase      AZNMc  2021  26836891.44                 0.607910
# 4    MidCase      AZNMc  2022  26741465.00                 0.605748
# ..       ...        ...   ...          ...                      ...
# 655  MidCase      SRVCc  2046   3826239.64                 0.061049
# 656  MidCase      SRVCc  2047   3350872.78                 0.053464
# 657  MidCase      SRVCc  2048   2875505.92                 0.045880
# 658  MidCase      SRVCc  2049   2400139.06                 0.038295
# 659  MidCase      SRVCc  2050   1924772.20                 0.030710
#
# [660 rows x 5 columns]

# %% [markdown]
# ### Step 3: Obtain CPI-U Inflation Data
# - Series Id:	CUUR0000SA0
# - Not Seasonally Adjusted
# - Series Title:	All items in U.S. city average, all urban consumers, not seasonally adjusted
# - Area:	U.S. city average
# - Item:	All items
# - Base Period:	1982-84=100

# %%
# Load the BLS Inflation Data
filename = 'bls_cpiu_2005-2023.xlsx'
relative_path = os.path.join(r"inflation_data", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")

# Create a pandas dataframe
df_bls_cpiu = pd.read_excel(file_path, sheet_name='bls_cpiu')

df_bls_cpiu = pd.DataFrame({
    'year': df_bls_cpiu['Year'],
    'cpiu_annual': df_bls_cpiu['Annual']
})

# Obtain the Annual CPIU values for the years of interest
bls_cpi_annual_2008 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2008)].item()
bls_cpi_annual_2010 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2010)].item()
bls_cpi_annual_2013 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2013)].item()
bls_cpi_annual_2018 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2018)].item()
bls_cpi_annual_2019 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2019)].item()
bls_cpi_annual_2020 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2020)].item()
bls_cpi_annual_2021 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2021)].item()
bls_cpi_annual_2022 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2022)].item()
bls_cpi_annual_2023 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2023)].item()

# Precompute constant values
cpi_ratio_2023_2023 = bls_cpi_annual_2023 / bls_cpi_annual_2023
cpi_ratio_2023_2022 = bls_cpi_annual_2023 / bls_cpi_annual_2022
cpi_ratio_2023_2021 = bls_cpi_annual_2023 / bls_cpi_annual_2021  # For EPA VSL (11.3M USD-2021)
cpi_ratio_2023_2020 = bls_cpi_annual_2023 / bls_cpi_annual_2020  # For SCC
cpi_ratio_2023_2019 = bls_cpi_annual_2023 / bls_cpi_annual_2019 
cpi_ratio_2023_2018 = bls_cpi_annual_2023 / bls_cpi_annual_2018 
cpi_ratio_2023_2013 = bls_cpi_annual_2023 / bls_cpi_annual_2013
cpi_ratio_2023_2010 = bls_cpi_annual_2023 / bls_cpi_annual_2010
cpi_ratio_2023_2008 = bls_cpi_annual_2023 / bls_cpi_annual_2008  # For EPA VSL and SCC
# Out:
# Retrieved data for filename: bls_cpiu_2005-2023.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\inflation_data\bls_cpiu_2005-2023.xlsx

# %% [markdown]
# ### Step 4: Use the updated Social Cost of Carbon (190 USD-2020/ton co2e) and inflate to USD-2023
# - EPA Median for 2% near term discount rate and most commonly mentioned value is 190 USD-2020 using the GIVE model.
# - 190 USD-2020 has some inconsistency with the VSL being used. An old study and 2008 VSL is noted
# - 190 USD value and inflate to USD 2023 because there is a clear source and ease of replicability.

# %%
# For co2e adjust SCC
EPA_SCC_USD2023_PER_TON = 190 * cpi_ratio_2023_2020

print(f"""
Steps 3 and 4: Obtain BLS CPI-U Data and Inflate Current Social Cost of Carbon (SCC) to USD2023
      
EPA Median for 2% near term discount rate and most commonly mentioned value is 190 USD-2020 using the GIVE model.
Inflate 190 $USD-2020 Social Cost of Carbon to $USD-2023

SCC Value used in analysis is: ${round(EPA_SCC_USD2023_PER_TON, 2)} per mt CO2e
""")
# Out:
# Steps 3 and 4: Obtain BLS CPI-U Data and Inflate Current Social Cost of Carbon (SCC) to USD2023
#
# EPA Median for 2% near term discount rate and most commonly mentioned value is 190 USD-2020 using the GIVE model.
# Inflate 190 $USD-2020 Social Cost of Carbon to $USD-2023
#
# SCC Value used in analysis is: $223.69 per mt CO2e

# %% [markdown]
# ### Step 4: Quantify monitized HEALTH damages using EASIUR Marginal Social Cost Factors
# #### THE STEPS BELOW SUMMARIZE WHAT WAS DONE TO OBTAIN ALL NATIONAL EASIUR VALUES INCLUDED ON GITHUB
# - Obtain all of the dwelling unit latitude and longitude values from the metadata columns
# - Make a new dataframe of just the longitude and latitude values
#     - Make sure that the order is (longitude, latitude)
#     - Do not include the index or column name when exporting
# - Export the CSV
# - **Upload csv to EASIUR Website:**
#     - Website: https://barney.ce.cmu.edu/~jinhyok/easiur/online/
#     - See inputs in respective sections
# - Download the file and put it in the 'easiur_batchConversion_download' folder
# - Copy and paste the name of the file EASIUR generated when prompted
# - Copy and paste the name of the filepath for the 'easiur_batchConversion_download' folder when prompted
# - Match up the longitude and latitudes for each dwelling unit with the selected damages

# %% [markdown]
# ### Fossil Fuels: EASIUR Marginal Damage (Social Cost) Factors Info
# - Factor Type: Marginal Social Cost
# - Calculation Method: Regression
# - Metric: Marginal Social Cost [USD per metric ton]
# - Dollar Year: 2010
# - Income Year: 2018
# - Population Year: 2018
# - Aggregation: Longitude, and Latitude Coordinates
# - Pollutants: Primary PM2.5, Sulfur Dioxide (SO2), Nitrogen Oxides (NOx), Ammonia (NH3)
# - Elevation (Ground, 150m, 300m) and Seasons (Winter, Spring, Summer, Fall)

# %%
# Create a dataframe containing just the longitude and Latitude
df_EASIUR_batchConversion = pd.DataFrame({
    'Longitude':df_euss_am_baseline['in.weather_file_longitude'],
    'Latitude':df_euss_am_baseline['in.weather_file_latitude'],
})

# Drop duplicate rows based on 'Longitude' and 'Latitude' columns
df_EASIUR_batchConversion.drop_duplicates(subset=['Longitude', 'Latitude'], keep='first', inplace=True)

# Create a location ID for the name of the batch conversion file
while True:
    if menu_state == 'N':
        location_id = 'National'
        print("You chose to analyze all of the United States.")
        break
    elif menu_state == 'Y':
        if menu_city == 'N':
            try:
                location_id = str(input_state)
                print(f"Location ID is: {location_id}")
                break
            except ValueError:
                print("Invalid input for state!")
        elif menu_city == 'Y':
            try:
                location_id = input_cityFilter.replace(', ', '_').strip()
                print(f"Location ID is: {location_id}")
                break
            except AttributeError:
                print("Invalid input for city filter!")
        else:
            print("Incorrect state or city filter assignment!")
    else:
        print("Invalid data location. Check your inputs at the beginning of this notebook!")

# Updated GitHub code has EASIUR file with all unique latitude, longitude coordinates in the US
filename = 'easiur_National2024-06-1421-22.csv'
relative_path = os.path.join(r"margDamages_EASIUR\easiur_batchConversion_download", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_margSocialCosts = pd.read_csv(file_path)

# Convert from kg/MWh to lb/kWh
# Obtain value from the CSV file and convert to lbs pollutant per kWh 

# Define df_margSocialCosts_EASIUR DataFrame first
df_margSocialCosts_EASIUR = pd.DataFrame({
    'Longitude': df_margSocialCosts['Longitude'],
    'Latitude': df_margSocialCosts['Latitude'],
})
df_margSocialCosts_EASIUR
# Out:
# You chose to analyze all of the United States.
# Retrieved data for filename: easiur_National2024-06-1421-22.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\margDamages_EASIUR\easiur_batchConversion_download\easiur_National2024-06-1421-22.csv
#       Longitude  Latitude    x   y  PM25 Annual Ground  PM25 Winter Ground  \
# 0        -87.04     31.42  103  33        81072.352921        97983.065682
# 1        -85.86     33.59  106  40       122086.659729       149040.298282
# 2        -86.39     32.30  105  36       111079.763889       130673.294214
# 3        -85.45     31.32  108  34        92900.934172       109103.501316
# 4        -86.75     33.56  103  40       210586.246246       239273.221876
# ...         ...       ...  ...  ..                 ...                 ...
# 1024    -106.72     44.38   56  73        22039.484828        31488.281032
# 1025    -105.54     44.34   58  73        24398.158766        36094.854622
# 1026    -107.95     43.97   53  72        18881.775892        27708.279306
# 1027    -108.08     44.52   53  74        19824.063398        29425.186031
# 1028    -107.20     41.81   54  65        21080.211942        33235.072238
#
#       PM25 Spring Ground  PM25 Summer Ground  PM25 Fall Ground  \
# 0           66122.238834        67093.464543      92772.783977
# 1          111701.789450        94277.068143     132887.342049
# 2           96866.726087       102723.887457     113635.286609
# 3           76080.870209        85266.429711     100637.850615
# 4          200288.217454       185276.680504     217158.132018
# ...                  ...                 ...               ...
# 1024        12364.586732        12580.294751      31712.802929
# 1025        13764.885657        12374.329591      35351.688558
# 1026        10197.591814         8352.447782      29154.889039
# 1027        11196.853635         8785.910661      29878.593194
# 1028         9336.606538        10176.795293      31569.056306
#
#       SO2 Annual Ground  ...  NOX Annual 300m  NOX Winter 300m  \
# 0          19955.830745  ...      2483.710419      5929.794762
# 1          21749.886294  ...      3590.227171      8058.611768
# 2          20685.101097  ...      2935.774496      6702.323634
# 3          20825.206151  ...      2793.030035      6718.838552
# 4          23868.371679  ...      3904.341520      8116.282158
# ...                 ...  ...              ...              ...
# 1024       10711.825984  ...      1711.170222      4765.897596
# 1025       12910.498172  ...      2174.378290      5591.793338
# 1026        9542.723432  ...      1324.757563      3540.476903
# 1027       12250.358578  ...      1636.477039      3529.366581
# 1028       11973.357107  ...      1441.738276      3311.706768
#
#       NOX Spring 300m  NOX Summer 300m  NOX Fall 300m  NH3 Annual 300m  \
# 0         2232.787468       857.316844     823.300965     32236.247484
# 1         3515.993478      1172.232495    1497.218427     45035.383139
# 2         2612.117692      1279.482824    1049.983462     41446.800963
# 3         2282.425801      1099.280251     970.074774     33185.456262
# 4         4696.203368      1496.731684    1204.250267     67219.188151
# ...               ...              ...            ...              ...
# 1024       354.608117       115.532932    1541.745057      9483.584564
# 1025       464.462503       196.267315    2374.571409     11429.479302
# 1026       252.826004       101.678277    1349.397287      8939.007581
# 1027       462.694413       255.114128    2247.879874      9751.985832
# 1028       268.339561       164.339744    1978.354924     10921.979569
#
#       NH3 Winter 300m  NH3 Spring 300m  NH3 Summer 300m  NH3 Fall 300m
# 0        43160.622278     22326.210380     27742.933871   35523.886882
# 1        57571.789826     33629.721297     39705.559055   48905.820895
# 2        48977.921967     27814.892512     46317.760766   42467.417598
# 3        45103.101045     20799.662615     28677.411776   37902.133176
# 4        77701.008208     63595.925126     67646.084789   59851.399474
# ...               ...              ...              ...            ...
# 1024     15249.799497      3791.953612      5543.820281   13347.159040
# 1025     19973.941403      4219.051097      4585.702249   16922.536072
# 1026     13060.681060      4351.246899      3642.042009   14697.004788
# 1027     16313.581753      3835.375269      2597.783323   16238.070755
# 1028     19176.241426      3431.818362      3279.369376   17679.470249
#
# [1029 rows x 64 columns]

# %%
print("""
-------------------------------------------------------------------------------------------------------
Calculate Emissions Factors: FOSSIL FUELS
-------------------------------------------------------------------------------------------------------
""")
pollutants = ['so2', 'nox', 'pm25', 'co2']

# Create a lookup dictionary of emissions factors for fossil fuels
fossilFuel_factors = df_margEmis_factors[df_margEmis_factors['state'] == 'National']
emis_fossilFuel_lookup = {(row['fuel_type'], row['pollutant']): row['margEmis_factor_adjusted'] for _, row in fossilFuel_factors.iterrows()}

# FOSSIL FUELS DAMAGES LOOKUP
# Create a damages_fossilFuel_lookup dictionary from df_margSocialCosts_EASIUR
damages_fossilFuel_lookup = df_margSocialCosts_EASIUR.groupby(['Longitude', 'Latitude']).first().to_dict()
damages_fossilFuel_lookup
# Out:
# -------------------------------------------------------------------------------------------------------
# Calculate Emissions Factors: FOSSIL FUELS
# -------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\14128\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'margEmis_factor_adjusted'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[115], line 10
#       8 # Create a lookup dictionary of emissions factors for fossil fuels
#       9 fossilFuel_factors = df_margEmis_factors[df_margEmis_factors['state'] == 'National']
# ---> 10 emis_fossilFuel_lookup = {(row['fuel_type'], row['pollutant']): row['margEmis_factor_adjusted'] for _, row in fossilFuel_factors.iterrows()}
#      12 # FOSSIL FUELS DAMAGES LOOKUP
#      13 # Create a damages_fossilFuel_lookup dictionary from df_margSocialCosts_EASIUR
#      14 damages_fossilFuel_lookup = df_margSocialCosts_EASIUR.groupby(['Longitude', 'Latitude']).first().to_dict()
#
# Cell In[115], line 10, in <dictcomp>(.0)
#       8 # Create a lookup dictionary of emissions factors for fossil fuels
#       9 fossilFuel_factors = df_margEmis_factors[df_margEmis_factors['state'] == 'National']
# ---> 10 emis_fossilFuel_lookup = {(row['fuel_type'], row['pollutant']): row['margEmis_factor_adjusted'] for _, row in fossilFuel_factors.iterrows()}
#      12 # FOSSIL FUELS DAMAGES LOOKUP
#      13 # Create a damages_fossilFuel_lookup dictionary from df_margSocialCosts_EASIUR
#      14 damages_fossilFuel_lookup = df_margSocialCosts_EASIUR.groupby(['Longitude', 'Latitude']).first().to_dict()
#
# File c:\Users\14128\anaconda3\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File c:\Users\14128\anaconda3\Lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File c:\Users\14128\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'margEmis_factor_adjusted'

# %% [markdown]
# ### Step 4: Inflate Marginal Social Cost (Damage) Factors using BLS CPI for All Urban Consumers (CPI-U)
# - Series Id:	CUUR0000SA0
# - Not Seasonally Adjusted
# - Series Title:	All items in U.S. city average, all urban consumers, not seasonally adjusted
# - Area:	U.S. city average
# - Item:	All items
# - Base Period:	1982-84=100
#
# ### Use the updated Social Cost of Carbon (190 USD-2020/ton CO2) and inflate to USD-2022
# - EPA Median for 2% near term discount rate and most commonly mentioned value is 190 USD-2020 using the GIVE model.
# - 190 USD-2020 has some inconsistency with the VSL being used. An old study and 2008 VSL is noted
# - 190 USD value and inflate to USD 2022 because there is a clear source and ease of replicability.
#
# ### Adjustment for VSL
# - EASIUR uses a VSL of 8.8M USD-2010
# - New EPA VSL is 11.3M USD-2021
# - INFLATE TO $USD-2022
#
# ### ALL DOLLAR VALUES ARE NOW IN USD2022, PREVIOUSLY USED $USD-2021

# %% [markdown]
# ## Electricity CEDM-EASIUR Marginal Damages: Current and Decarbonizing Grid
# - Factor Type: Marginal
# - Calculation Method: Regression
# - Metric: Marginal Damages EASIUR [USD per MWh or kWh]
# - Year: 2018
# - Regional Aggregation: eGRID subregion (all regions)
# - Pollutants: SO2, NOx, PM2.5 CO2
#
# SCC Adjustment: We use the EPA suggested 190 USD-2020 value for the social cost of carbon and inflate to 2022 USD. **PREVIOUSLY USED 2021 USD**
#
# VSL: "We use a value of a statistical life (VSL) of USD 8.8 million (in 2010 dollars) for both our AP2 and EASIUR calculations. EASIUR reports damage intensities in USD/metric ton using this VSL and dollar year."

# %%
# For CO2 adjust SCC
# Create an adjustment factor for the new Social Cost of Carbon (SCC)
epa_scc = 190 * cpi_ratio_2023_2020
old_scc = 40 * cpi_ratio_2023_2010
scc_adjustment_factor = epa_scc / old_scc

# For Health-Related Emissions Adjust for different Value of a Statistical Life (VSL) values
# Current VSL is $11.3 M USD2021
# INFLATE TO USD2022, PREVIOUSLY USD2021
current_VSL_USD2022 = 11.3 * cpi_ratio_2023_2021

# Easiur uses a VSL of $8.8 M USD2010
# INFLATE TO USD2022, PREVIOUSLY USD2021
easiur_VSL_USD2022 = 8.8 * (cpi_ratio_2023_2010)

# Calculate VSL adjustment factor
vsl_adjustment_factor = current_VSL_USD2022 / easiur_VSL_USD2022

# %% [markdown]
# ### Electricity Damages from Health Related Emissions

# %%
filename = 'Generation-MARREG-DAMEASIUR-egrid-byYear_health2018.csv'
relative_path = os.path.join(r"margDamages_EASIUR", filename)
file_path = os.path.join(project_root, relative_path)
df_margDamages_health2018 = pd.read_csv(file_path, index_col=0)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
# Out:
# Retrieved data for filename: Generation-MARREG-DAMEASIUR-egrid-byYear_health2018.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\margDamages_EASIUR\Generation-MARREG-DAMEASIUR-egrid-byYear_health2018.csv

# %%
# Marginal damages [$/kWh]
# Inflate from 2010 to 2022
# Note only 2018 data available, used in place of 2021
df_margDamages_EASIUR_health = pd.DataFrame({
    'subregion_eGRID': df_margDamages_health2018['region'],
    'pollutant': df_margDamages_health2018['pollutant'],
    'unit': '[$USD2023/kWh]',
    'margDamages_dollarPerkWh_adjustVSL_ref': (df_margDamages_health2018['factor'] * (vsl_adjustment_factor) * (1/1000)) * (cpi_ratio_2023_2010),
    'margDamages_dollarPerkWh_adjustVSL_2018': (df_margDamages_health2018['factor'] * (vsl_adjustment_factor) * (1/1000)) * (cpi_ratio_2023_2010)
})

# Apply the mapping to the 'cambium_gea_region' column
df_margDamages_EASIUR_health['cambium_gea_region'] = df_margDamages_EASIUR_health['subregion_eGRID'].map(mapping)
df_margDamages_EASIUR_health
# Out:
#    subregion_eGRID pollutant            unit  \
# 1             AZNM       so2  [$USD2023/kWh]
# 2             AZNM       nox  [$USD2023/kWh]
# 3             AZNM      pm25  [$USD2023/kWh]
# 4             CAMX       so2  [$USD2023/kWh]
# 5             CAMX       nox  [$USD2023/kWh]
# ..             ...       ...             ...
# 62            SRTV       nox  [$USD2023/kWh]
# 63            SRTV      pm25  [$USD2023/kWh]
# 64            SRVC       so2  [$USD2023/kWh]
# 65            SRVC       nox  [$USD2023/kWh]
# 66            SRVC      pm25  [$USD2023/kWh]
#
#     margDamages_dollarPerkWh_adjustVSL_ref  \
# 1                                 0.001760
# 2                                 0.000575
# 3                                 0.002026
# 4                                 0.000599
# 5                                 0.000714
# ..                                     ...
# 62                                0.002780
# 63                                0.007428
# 64                                0.008226
# 65                                0.002431
# 66                                0.007534
#
#     margDamages_dollarPerkWh_adjustVSL_2018 cambium_gea_region
# 1                                  0.001760              AZNMc
# 2                                  0.000575              AZNMc
# 3                                  0.002026              AZNMc
# 4                                  0.000599              CAMXc
# 5                                  0.000714              CAMXc
# ..                                      ...                ...
# 62                                 0.002780              SRTVc
# 63                                 0.007428              SRTVc
# 64                                 0.008226              SRVCc
# 65                                 0.002431              SRVCc
# 66                                 0.007534              SRVCc
#
# [66 rows x 6 columns]

# %% [markdown]
# #### Pre-IRA Projections

# %%
# Create dictionaries mapping 'gea_region' to marginal damage factors for each pollutant
# For SO2
so2_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'so2'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# For NOx
nox_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'nox'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# For PM2.5
pm25_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'pm25'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# Map the marginal damage factors to the projection factors dataframe
df_preIRA_coal_projection_factors['so2_marg_damage'] = df_preIRA_coal_projection_factors['gea_region'].map(so2_marg_damages)
df_preIRA_coal_projection_factors['nox_marg_damage'] = df_preIRA_coal_projection_factors['gea_region'].map(nox_marg_damages)
df_preIRA_coal_projection_factors['pm25_marg_damage'] = df_preIRA_coal_projection_factors['gea_region'].map(pm25_marg_damages)

# Calculate the new columns by multiplying the coal projection factors with the marginal damages
df_preIRA_coal_projection_factors['so2_dollarPerkWh_adjustVSL'] = (
    df_preIRA_coal_projection_factors['coal_projection_factors'] * df_preIRA_coal_projection_factors['so2_marg_damage']
)
df_preIRA_coal_projection_factors['nox_dollarPerkWh_adjustVSL'] = (
    df_preIRA_coal_projection_factors['coal_projection_factors'] * df_preIRA_coal_projection_factors['nox_marg_damage']
)
df_preIRA_coal_projection_factors['pm25_dollarPerkWh_adjustVSL'] = (
    df_preIRA_coal_projection_factors['coal_projection_factors'] * df_preIRA_coal_projection_factors['pm25_marg_damage']
)

# Optionally, drop the intermediate marginal damage columns if they're no longer needed
df_preIRA_coal_projection_factors.drop(
    columns=['so2_marg_damage', 'nox_marg_damage', 'pm25_marg_damage'], 
    inplace=True
)
df_preIRA_coal_projection_factors
# Out:
#     scenario gea_region  year     coal_MWh  coal_projection_factors  \
# 0    MidCase      AZNMc  2018  44146154.50                 1.000000
# 1    MidCase      AZNMc  2019  37909639.38                 0.858730
# 2    MidCase      AZNMc  2020  26535437.00                 0.601082
# 3    MidCase      AZNMc  2021  26836891.44                 0.607910
# 4    MidCase      AZNMc  2022  26741465.00                 0.605748
# ..       ...        ...   ...          ...                      ...
# 655  MidCase      SRVCc  2046  27152428.00                 0.433227
# 656  MidCase      SRVCc  2047  27506921.00                 0.438883
# 657  MidCase      SRVCc  2048  27861414.00                 0.444539
# 658  MidCase      SRVCc  2049  21319390.00                 0.340159
# 659  MidCase      SRVCc  2050  14777366.00                 0.235778
#
#      so2_dollarPerkWh_adjustVSL  nox_dollarPerkWh_adjustVSL  \
# 0                      0.001760                    0.000575
# 1                      0.001512                    0.000494
# 2                      0.001058                    0.000346
# 3                      0.001070                    0.000350
# 4                      0.001066                    0.000348
# ..                          ...                         ...
# 655                    0.003564                    0.001053
# 656                    0.003610                    0.001067
# 657                    0.003657                    0.001081
# 658                    0.002798                    0.000827
# 659                    0.001940                    0.000573
#
#      pm25_dollarPerkWh_adjustVSL
# 0                       0.002026
# 1                       0.001740
# 2                       0.001218
# 3                       0.001232
# 4                       0.001227
# ..                           ...
# 655                     0.003264
# 656                     0.003307
# 657                     0.003349
# 658                     0.002563
# 659                     0.001776
#
# [660 rows x 8 columns]

# %%
import pandas as pd

# Assuming df_preIRA_coal_projection_factors is your dataframe

# Initialize the lookup dictionary
damages_preIRA_health_damages_lookup = {}

# Group the dataframe
grouped = df_preIRA_coal_projection_factors.groupby(['scenario', 'gea_region'])

for (scenario, gea_region), group in grouped:
    year_dict = {}
    for _, row in group.iterrows():
        year = int(row['year'])
        data_dict = {
            'so2_dollarPerkWh_adjustVSL': row['so2_dollarPerkWh_adjustVSL'],
            'nox_dollarPerkWh_adjustVSL': row['nox_dollarPerkWh_adjustVSL'],
            'pm25_dollarPerkWh_adjustVSL': row['pm25_dollarPerkWh_adjustVSL']
        }
        year_dict[year] = data_dict
    damages_preIRA_health_damages_lookup[(scenario, gea_region)] = year_dict

# Now, lookup_dict contains the desired nested dictionary
damages_preIRA_health_damages_lookup
# Out:
# {('MidCase',
#   'AZNMc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.0017604045476692913,
#    'nox_dollarPerkWh_adjustVSL': 0.000575015374879764,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020259847537919245}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0015117126807739248,
#    'nox_dollarPerkWh_adjustVSL': 0.0004937831108176674,
#    'pm25_dollarPerkWh_adjustVSL': 0.0017397744441280825}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0010581466154473767,
#    'nox_dollarPerkWh_adjustVSL': 0.00034563110710250785,
#    'pm25_dollarPerkWh_adjustVSL': 0.001217781965521054}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0010701676345622147,
#    'nox_dollarPerkWh_adjustVSL': 0.0003495576311630751,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012316165136559971}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0010663623396085199,
#    'nox_dollarPerkWh_adjustVSL': 0.00034831467646426797,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012272371398523595}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0012037391306330793,
#    'nox_dollarPerkWh_adjustVSL': 0.0003931871843746519,
#    'pm25_dollarPerkWh_adjustVSL': 0.0013853390287102963}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.001095040930469641,
#    'nox_dollarPerkWh_adjustVSL': 0.00035768219979682466,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012602422737698976}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0010813272013348166,
#    'nox_dollarPerkWh_adjustVSL': 0.0003532027719801328,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012444596480197135}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0010676134721999922,
#    'nox_dollarPerkWh_adjustVSL': 0.00034872334416344097,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012286770222695294}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.001066039138663376,
#    'nox_dollarPerkWh_adjustVSL': 0.0003482091066889118,
#    'pm25_dollarPerkWh_adjustVSL': 0.001226865179788896}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0010644648051267602,
#    'nox_dollarPerkWh_adjustVSL': 0.00034769486921438277,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012250533373082627}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0010286710880176315,
#    'nox_dollarPerkWh_adjustVSL': 0.0003360032738426851,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011838596666598619}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.000992877370908503,
#    'nox_dollarPerkWh_adjustVSL': 0.0003243116784709874,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011426659960114612}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0005587350435597805,
#    'nox_dollarPerkWh_adjustVSL': 0.00018250420958997897,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006430275820180607}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.00012459271621105832,
#    'nox_dollarPerkWh_adjustVSL': 4.069674070897055e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014338916802466027}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.00012654413014464178,
#    'nox_dollarPerkWh_adjustVSL': 4.133414704608249e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014563497844534542}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0001284955440782252,
#    'nox_dollarPerkWh_adjustVSL': 4.197155338319442e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014788078886603052}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0001287060733058484,
#    'nox_dollarPerkWh_adjustVSL': 4.204032027141065e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014812307919978188}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0001289166025334716,
#    'nox_dollarPerkWh_adjustVSL': 4.210908715962687e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014836536953353324}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0001258822122163833,
#    'nox_dollarPerkWh_adjustVSL': 4.111793936463729e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014487320148181244}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.00012284782189929503,
#    'nox_dollarPerkWh_adjustVSL': 4.012679156964771e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014138103343009162}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.00012108548949088626,
#    'nox_dollarPerkWh_adjustVSL': 3.9551146481803786e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001393528299723826}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.00011932315708247749,
#    'nox_dollarPerkWh_adjustVSL': 3.897550139395987e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013732462651467356}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.00011949993464076455,
#    'nox_dollarPerkWh_adjustVSL': 3.9033243697615775e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001375280732953447}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.00011967671219905159,
#    'nox_dollarPerkWh_adjustVSL': 3.909098600127168e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001377315200760158}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.00011904269801679737,
#    'nox_dollarPerkWh_adjustVSL': 3.888389274922875e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013700185650599407}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.00011840868383454315,
#    'nox_dollarPerkWh_adjustVSL': 3.8676799497185815e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001362721929359723}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.00011823835633830137,
#    'nox_dollarPerkWh_adjustVSL': 3.8621164030194174e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013607616929413712}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.00011806802884205961,
#    'nox_dollarPerkWh_adjustVSL': 3.856552856320253e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001358801456523019}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0001182876539531606,
#    'nox_dollarPerkWh_adjustVSL': 3.863726651443649e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001361329041033236}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.00011850727906426158,
#    'nox_dollarPerkWh_adjustVSL': 3.870900446567045e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013638566255434533}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0001171732267879858,
#    'nox_dollarPerkWh_adjustVSL': 3.827325202980704e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013485035092607528}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.00011583917451171001,
#    'nox_dollarPerkWh_adjustVSL': 3.783749959394363e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013331503929780522}},
#  ('MidCase',
#   'CAMXc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.0005985940993128373,
#    'nox_dollarPerkWh_adjustVSL': 0.0007136726494222902,
#    'pm25_dollarPerkWh_adjustVSL': 0.004942314992523925}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0005314338138668267,
#    'nox_dollarPerkWh_adjustVSL': 0.0006336009298626856,
#    'pm25_dollarPerkWh_adjustVSL': 0.00438780353635848}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.00048040861844196223,
#    'nox_dollarPerkWh_adjustVSL': 0.0005727662399652133,
#    'pm25_dollarPerkWh_adjustVSL': 0.003966512065837359}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0005365762254811468,
#    'nox_dollarPerkWh_adjustVSL': 0.000639731960097405,
#    'pm25_dollarPerkWh_adjustVSL': 0.004430262053821914}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0003925936374483933,
#    'nox_dollarPerkWh_adjustVSL': 0.00046806899985443967,
#    'pm25_dollarPerkWh_adjustVSL': 0.0032414643287631967}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}},
#  ('MidCase',
#   'ERCTc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.012666544314406074,
#    'nox_dollarPerkWh_adjustVSL': 0.0011137260353787004,
#    'pm25_dollarPerkWh_adjustVSL': 0.004887701560349267}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.01058322703966602,
#    'nox_dollarPerkWh_adjustVSL': 0.0009305470537054345,
#    'pm25_dollarPerkWh_adjustVSL': 0.004083801708763977}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.009280967579574518,
#    'nox_dollarPerkWh_adjustVSL': 0.0008160438214487429,
#    'pm25_dollarPerkWh_adjustVSL': 0.003581292465747344}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.010130647748639804,
#    'nox_dollarPerkWh_adjustVSL': 0.0008907533004150554,
#    'pm25_dollarPerkWh_adjustVSL': 0.003909162718679307}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.009682942230626336,
#    'nox_dollarPerkWh_adjustVSL': 0.0008513880813610147,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037364043952838213}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.009149137664981386,
#    'nox_dollarPerkWh_adjustVSL': 0.0008044524667366977,
#    'pm25_dollarPerkWh_adjustVSL': 0.0035304226102237093}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0075136526437591614,
#    'nox_dollarPerkWh_adjustVSL': 0.0006606498475380701,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028993299860843725}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.007373659762401065,
#    'nox_dollarPerkWh_adjustVSL': 0.0006483407510026507,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028453102465510302}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.007233666881042971,
#    'nox_dollarPerkWh_adjustVSL': 0.0006360316544672313,
#    'pm25_dollarPerkWh_adjustVSL': 0.0027912905070176883}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.007830736954438105,
#    'nox_dollarPerkWh_adjustVSL': 0.0006885299893863566,
#    'pm25_dollarPerkWh_adjustVSL': 0.003021684863752553}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.00842780702783324,
#    'nox_dollarPerkWh_adjustVSL': 0.000741028324305482,
#    'pm25_dollarPerkWh_adjustVSL': 0.003252079220487419}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.00829852221092613,
#    'nox_dollarPerkWh_adjustVSL': 0.0007296607513515189,
#    'pm25_dollarPerkWh_adjustVSL': 0.0032021914542868404}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.00816923739401902,
#    'nox_dollarPerkWh_adjustVSL': 0.0007182931783975559,
#    'pm25_dollarPerkWh_adjustVSL': 0.0031523036880862624}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.008135282726273901,
#    'nox_dollarPerkWh_adjustVSL': 0.0007153076602837193,
#    'pm25_dollarPerkWh_adjustVSL': 0.0031392014339592066}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.008101328058528779,
#    'nox_dollarPerkWh_adjustVSL': 0.0007123221421698826,
#    'pm25_dollarPerkWh_adjustVSL': 0.0031260991798321503}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.007969713917749833,
#    'nox_dollarPerkWh_adjustVSL': 0.0007007497597133038,
#    'pm25_dollarPerkWh_adjustVSL': 0.0030753125860081623}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.007838099776970886,
#    'nox_dollarPerkWh_adjustVSL': 0.000689177377256725,
#    'pm25_dollarPerkWh_adjustVSL': 0.0030245259921841744}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.007267588917587458,
#    'nox_dollarPerkWh_adjustVSL': 0.0006390143034309028,
#    'pm25_dollarPerkWh_adjustVSL': 0.002804380169583361}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.006697078058204029,
#    'nox_dollarPerkWh_adjustVSL': 0.0005888512296050805,
#    'pm25_dollarPerkWh_adjustVSL': 0.002584234346982547}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0063030769769901705,
#    'nox_dollarPerkWh_adjustVSL': 0.0005542080584904334,
#    'pm25_dollarPerkWh_adjustVSL': 0.0024321992179349152}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.005909075895776312,
#    'nox_dollarPerkWh_adjustVSL': 0.000519564887375786,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022801640888872833}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.005694023774979324,
#    'nox_dollarPerkWh_adjustVSL': 0.0005006560879471519,
#    'pm25_dollarPerkWh_adjustVSL': 0.0021971808726062338}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.005478971654182336,
#    'nox_dollarPerkWh_adjustVSL': 0.0004817472885185177,
#    'pm25_dollarPerkWh_adjustVSL': 0.0021141976563251843}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.005254866550623124,
#    'nox_dollarPerkWh_adjustVSL': 0.0004620424911957573,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020277211211976983}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.005030761447063913,
#    'nox_dollarPerkWh_adjustVSL': 0.00044233769387299704,
#    'pm25_dollarPerkWh_adjustVSL': 0.0019412445860702125}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.005123741469963661,
#    'nox_dollarPerkWh_adjustVSL': 0.0004505131101272774,
#    'pm25_dollarPerkWh_adjustVSL': 0.0019771232433999425}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0052167214928634095,
#    'nox_dollarPerkWh_adjustVSL': 0.00045868852638155776,
#    'pm25_dollarPerkWh_adjustVSL': 0.002013001900729672}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0052752482704650355,
#    'nox_dollarPerkWh_adjustVSL': 0.0004638345862984378,
#    'pm25_dollarPerkWh_adjustVSL': 0.002035585915367377}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.005333775048066662,
#    'nox_dollarPerkWh_adjustVSL': 0.0004689806462153179,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020581699300050815}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0056275324011199135,
#    'nox_dollarPerkWh_adjustVSL': 0.0004948097282489427,
#    'pm25_dollarPerkWh_adjustVSL': 0.0021715235201590645}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.005921289754173165,
#    'nox_dollarPerkWh_adjustVSL': 0.0005206388102825675,
#    'pm25_dollarPerkWh_adjustVSL': 0.002284877110313047}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.005329549307584716,
#    'nox_dollarPerkWh_adjustVSL': 0.00046860909126894275,
#    'pm25_dollarPerkWh_adjustVSL': 0.002056539322805946}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.004737808860996268,
#    'nox_dollarPerkWh_adjustVSL': 0.00041657937225531797,
#    'pm25_dollarPerkWh_adjustVSL': 0.001828201535298845}},
#  ('MidCase',
#   'FRCCc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.004087382457213744,
#    'nox_dollarPerkWh_adjustVSL': 0.0009462959863423146,
#    'pm25_dollarPerkWh_adjustVSL': 0.004568195586332583}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0028146027513577363,
#    'nox_dollarPerkWh_adjustVSL': 0.000651626637496864,
#    'pm25_dollarPerkWh_adjustVSL': 0.003145694341213341}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0023929235510240297,
#    'nox_dollarPerkWh_adjustVSL': 0.0005540009959091587,
#    'pm25_dollarPerkWh_adjustVSL': 0.0026744115381047216}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0027690054146686997,
#    'nox_dollarPerkWh_adjustVSL': 0.0006410701072116732,
#    'pm25_dollarPerkWh_adjustVSL': 0.003094733229941809}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0022947035892550522,
#    'nox_dollarPerkWh_adjustVSL': 0.0005312614660086372,
#    'pm25_dollarPerkWh_adjustVSL': 0.0025646376178661305}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.004343350413918846,
#    'nox_dollarPerkWh_adjustVSL': 0.001005556760834995,
#    'pm25_dollarPerkWh_adjustVSL': 0.0048542739512282196}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.003425612529576068,
#    'nox_dollarPerkWh_adjustVSL': 0.0007930854089224416,
#    'pm25_dollarPerkWh_adjustVSL': 0.0038285793418907}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0034953719198978395,
#    'nox_dollarPerkWh_adjustVSL': 0.0008092358503754244,
#    'pm25_dollarPerkWh_adjustVSL': 0.003906544773877801}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.003565131310219611,
#    'nox_dollarPerkWh_adjustVSL': 0.0008253862918284071,
#    'pm25_dollarPerkWh_adjustVSL': 0.0039845102058649025}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.003973284624086053,
#    'nox_dollarPerkWh_adjustVSL': 0.0009198804691575857,
#    'pm25_dollarPerkWh_adjustVSL': 0.004440676025058317}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.004381437937952495,
#    'nox_dollarPerkWh_adjustVSL': 0.0010143746464867643,
#    'pm25_dollarPerkWh_adjustVSL': 0.004896841844251731}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.004092427279346466,
#    'nox_dollarPerkWh_adjustVSL': 0.0009474639452955025,
#    'pm25_dollarPerkWh_adjustVSL': 0.004573833848580311}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.003803416620740438,
#    'nox_dollarPerkWh_adjustVSL': 0.0008805532441042408,
#    'pm25_dollarPerkWh_adjustVSL': 0.004250825852908892}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.003695871848391401,
#    'nox_dollarPerkWh_adjustVSL': 0.0008556548678227698,
#    'pm25_dollarPerkWh_adjustVSL': 0.0041306302119282065}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0035883270760423643,
#    'nox_dollarPerkWh_adjustVSL': 0.0008307564915412988,
#    'pm25_dollarPerkWh_adjustVSL': 0.004010434570947522}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0035667515749840187,
#    'nox_dollarPerkWh_adjustVSL': 0.0008257614096597872,
#    'pm25_dollarPerkWh_adjustVSL': 0.00398632106805432}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0035451760739256735,
#    'nox_dollarPerkWh_adjustVSL': 0.0008207663277782757,
#    'pm25_dollarPerkWh_adjustVSL': 0.003962207565161118}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.003652318944663226,
#    'nox_dollarPerkWh_adjustVSL': 0.0008455716572539159,
#    'pm25_dollarPerkWh_adjustVSL': 0.004081954027434662}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.003759461815400779,
#    'nox_dollarPerkWh_adjustVSL': 0.0008703769867295564,
#    'pm25_dollarPerkWh_adjustVSL': 0.0042017004897082055}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0036877339058623538,
#    'nox_dollarPerkWh_adjustVSL': 0.0008537708008354169,
#    'pm25_dollarPerkWh_adjustVSL': 0.004121534974687217}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0036160059963239286,
#    'nox_dollarPerkWh_adjustVSL': 0.0008371646149412773,
#    'pm25_dollarPerkWh_adjustVSL': 0.004041369459666227}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0035209162558799394,
#    'nox_dollarPerkWh_adjustVSL': 0.0008151497825475849,
#    'pm25_dollarPerkWh_adjustVSL': 0.003935093979661879}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0034258265154359507,
#    'nox_dollarPerkWh_adjustVSL': 0.0007931349501538925,
#    'pm25_dollarPerkWh_adjustVSL': 0.003828818499657532}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0032763953672632767,
#    'nox_dollarPerkWh_adjustVSL': 0.0007585391918096347,
#    'pm25_dollarPerkWh_adjustVSL': 0.003661809241608225}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0031269642190906023,
#    'nox_dollarPerkWh_adjustVSL': 0.000723943433465377,
#    'pm25_dollarPerkWh_adjustVSL': 0.003494799983558918}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.003170299520296474,
#    'nox_dollarPerkWh_adjustVSL': 0.000733976265486192,
#    'pm25_dollarPerkWh_adjustVSL': 0.00354323296818253}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0032136348215023457,
#    'nox_dollarPerkWh_adjustVSL': 0.000744009097507007,
#    'pm25_dollarPerkWh_adjustVSL': 0.0035916659528061425}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0030176204585758756,
#    'nox_dollarPerkWh_adjustVSL': 0.0006986285619578071,
#    'pm25_dollarPerkWh_adjustVSL': 0.0033725937331272222}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.002821606095649405,
#    'nox_dollarPerkWh_adjustVSL': 0.000653248026408607,
#    'pm25_dollarPerkWh_adjustVSL': 0.003153521513448302}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0029331118668202852,
#    'nox_dollarPerkWh_adjustVSL': 0.0006790634387947866,
#    'pm25_dollarPerkWh_adjustVSL': 0.003278144099429809}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.003044617637991165,
#    'nox_dollarPerkWh_adjustVSL': 0.000704878851180966,
#    'pm25_dollarPerkWh_adjustVSL': 0.003402766685411317}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0028628071139443476,
#    'nox_dollarPerkWh_adjustVSL': 0.0006627867369779864,
#    'pm25_dollarPerkWh_adjustVSL': 0.003199569151979213}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0026809965898975303,
#    'nox_dollarPerkWh_adjustVSL': 0.0006206946227750068,
#    'pm25_dollarPerkWh_adjustVSL': 0.0029963716185471088}},
#  ('MidCase',
#   'MROEc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.013246333152908747,
#    'nox_dollarPerkWh_adjustVSL': 0.006215755580135027,
#    'pm25_dollarPerkWh_adjustVSL': 0.01270588475547516}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.009825087614629385,
#    'nox_dollarPerkWh_adjustVSL': 0.004610358388316527,
#    'pm25_dollarPerkWh_adjustVSL': 0.009424225519838646}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.00907556659326667,
#    'nox_dollarPerkWh_adjustVSL': 0.00425865052945592,
#    'pm25_dollarPerkWh_adjustVSL': 0.008705284843252274}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.01124791314131969,
#    'nox_dollarPerkWh_adjustVSL': 0.005278010002162717,
#    'pm25_dollarPerkWh_adjustVSL': 0.01078899997935052}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.008989659992435806,
#    'nox_dollarPerkWh_adjustVSL': 0.004218339416386291,
#    'pm25_dollarPerkWh_adjustVSL': 0.008622883218795781}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.008523024620677219,
#    'nox_dollarPerkWh_adjustVSL': 0.0039993738066273436,
#    'pm25_dollarPerkWh_adjustVSL': 0.00817528649991883}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.008042896465212345,
#    'nox_dollarPerkWh_adjustVSL': 0.0037740767959708217,
#    'pm25_dollarPerkWh_adjustVSL': 0.0077147475008784855}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.007662755660925688,
#    'nox_dollarPerkWh_adjustVSL': 0.003595698198799351,
#    'pm25_dollarPerkWh_adjustVSL': 0.0073501163841487}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.007282614856639033,
#    'nox_dollarPerkWh_adjustVSL': 0.003417319601627881,
#    'pm25_dollarPerkWh_adjustVSL': 0.006985485267418916}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.007308604182981431,
#    'nox_dollarPerkWh_adjustVSL': 0.003429514923787753,
#    'pm25_dollarPerkWh_adjustVSL': 0.00701041423316114}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.00733459350932383,
#    'nox_dollarPerkWh_adjustVSL': 0.003441710245947625,
#    'pm25_dollarPerkWh_adjustVSL': 0.007035343198903364}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0077205942524752325,
#    'nox_dollarPerkWh_adjustVSL': 0.003622838581275107,
#    'pm25_dollarPerkWh_adjustVSL': 0.007405595169874856}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.008106594995626635,
#    'nox_dollarPerkWh_adjustVSL': 0.0038039669166025887,
#    'pm25_dollarPerkWh_adjustVSL': 0.007775847140846348}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.008123435029247977,
#    'nox_dollarPerkWh_adjustVSL': 0.003811868992727599,
#    'pm25_dollarPerkWh_adjustVSL': 0.0077920001036324415}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.00814027506286932,
#    'nox_dollarPerkWh_adjustVSL': 0.003819771068852608,
#    'pm25_dollarPerkWh_adjustVSL': 0.007808153066418532}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.008010773158660455,
#    'nox_dollarPerkWh_adjustVSL': 0.003759003143538303,
#    'pm25_dollarPerkWh_adjustVSL': 0.007683934820395398}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.007881271254451592,
#    'nox_dollarPerkWh_adjustVSL': 0.003698235218223998,
#    'pm25_dollarPerkWh_adjustVSL': 0.007559716574372264}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0077424425096081755,
#    'nox_dollarPerkWh_adjustVSL': 0.003633090733672504,
#    'pm25_dollarPerkWh_adjustVSL': 0.0074265520214076295}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.00760361376476476,
#    'nox_dollarPerkWh_adjustVSL': 0.0035679462491210105,
#    'pm25_dollarPerkWh_adjustVSL': 0.007293387468442996}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0071073068773273625,
#    'nox_dollarPerkWh_adjustVSL': 0.003335057473832203,
#    'pm25_dollarPerkWh_adjustVSL': 0.006817329827257712}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.006610999989889964,
#    'nox_dollarPerkWh_adjustVSL': 0.0031021686985433943,
#    'pm25_dollarPerkWh_adjustVSL': 0.006341272186072428}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.006425278868337739,
#    'nox_dollarPerkWh_adjustVSL': 0.0030150202715552295,
#    'pm25_dollarPerkWh_adjustVSL': 0.006163128458305624}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.006239557746785514,
#    'nox_dollarPerkWh_adjustVSL': 0.0029278718445670646,
#    'pm25_dollarPerkWh_adjustVSL': 0.00598498473053882}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.006106744402446077,
#    'nox_dollarPerkWh_adjustVSL': 0.0028655500475335233,
#    'pm25_dollarPerkWh_adjustVSL': 0.005857590150643662}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.005973931058106641,
#    'nox_dollarPerkWh_adjustVSL': 0.002803228250499982,
#    'pm25_dollarPerkWh_adjustVSL': 0.005730195570748504}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0059065861481404245,
#    'nox_dollarPerkWh_adjustVSL': 0.0027716270900064247,
#    'pm25_dollarPerkWh_adjustVSL': 0.005665598322965203}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.005839241238174208,
#    'nox_dollarPerkWh_adjustVSL': 0.002740025929512867,
#    'pm25_dollarPerkWh_adjustVSL': 0.005601001075181903}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.005989954542869781,
#    'nox_dollarPerkWh_adjustVSL': 0.002810747166390137,
#    'pm25_dollarPerkWh_adjustVSL': 0.005745565299746816}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.006140667847565353,
#    'nox_dollarPerkWh_adjustVSL': 0.002881468403267407,
#    'pm25_dollarPerkWh_adjustVSL': 0.005890129524311729}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.00605789792653958,
#    'nox_dollarPerkWh_adjustVSL': 0.002842629156772213,
#    'pm25_dollarPerkWh_adjustVSL': 0.005810736603596737}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.005975128005513806,
#    'nox_dollarPerkWh_adjustVSL': 0.002803789910277019,
#    'pm25_dollarPerkWh_adjustVSL': 0.005731343682881745}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.005787962484510727,
#    'nox_dollarPerkWh_adjustVSL': 0.00271596370825157,
#    'pm25_dollarPerkWh_adjustVSL': 0.005551814486944122}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0056007969635076486,
#    'nox_dollarPerkWh_adjustVSL': 0.0026281375062261205,
#    'pm25_dollarPerkWh_adjustVSL': 0.005372285291006499}},
#  ('MidCase',
#   'MROWc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.023005225539313577,
#    'nox_dollarPerkWh_adjustVSL': 0.007306287069895563,
#    'pm25_dollarPerkWh_adjustVSL': 0.00856107691560267}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.019258115923299526,
#    'nox_dollarPerkWh_adjustVSL': 0.0061162331627873925,
#    'pm25_dollarPerkWh_adjustVSL': 0.007166641830449063}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.016284528407799415,
#    'nox_dollarPerkWh_adjustVSL': 0.005171844072640285,
#    'pm25_dollarPerkWh_adjustVSL': 0.006060062310419203}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.018049986241535542,
#    'nox_dollarPerkWh_adjustVSL': 0.005732540237997549,
#    'pm25_dollarPerkWh_adjustVSL': 0.006717053057153662}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.017931766634203077,
#    'nox_dollarPerkWh_adjustVSL': 0.00569499457746989,
#    'pm25_dollarPerkWh_adjustVSL': 0.00667305926324036}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.011852022602274626,
#    'nox_dollarPerkWh_adjustVSL': 0.0037641134768762997,
#    'pm25_dollarPerkWh_adjustVSL': 0.004410566500647396}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.011335066796869547,
#    'nox_dollarPerkWh_adjustVSL': 0.003599932190747023,
#    'pm25_dollarPerkWh_adjustVSL': 0.004218188538324135}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.010547430747510148,
#    'nox_dollarPerkWh_adjustVSL': 0.003349784889500877,
#    'pm25_dollarPerkWh_adjustVSL': 0.0039250806620920965}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.009759794698150748,
#    'nox_dollarPerkWh_adjustVSL': 0.003099637588254731,
#    'pm25_dollarPerkWh_adjustVSL': 0.0036319727858600587}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.009870306036207522,
#    'nox_dollarPerkWh_adjustVSL': 0.0031347351602798892,
#    'pm25_dollarPerkWh_adjustVSL': 0.0036730980538359557}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.009980817374264298,
#    'nox_dollarPerkWh_adjustVSL': 0.0031698327323050482,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037142233218118528}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.00997933180008417,
#    'nox_dollarPerkWh_adjustVSL': 0.0031693609250886792,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037136704859008036}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.00997784622590404,
#    'nox_dollarPerkWh_adjustVSL': 0.0031688891178723103,
#    'pm25_dollarPerkWh_adjustVSL': 0.003713117649989755}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.01007012420419721,
#    'nox_dollarPerkWh_adjustVSL': 0.0031981959116043394,
#    'pm25_dollarPerkWh_adjustVSL': 0.003747457624985179}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.010162402182490378,
#    'nox_dollarPerkWh_adjustVSL': 0.003227502705336369,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037817975999806038}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.009156602249451688,
#    'nox_dollarPerkWh_adjustVSL': 0.0029080681910733253,
#    'pm25_dollarPerkWh_adjustVSL': 0.003407503047912971}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.008150802316412999,
#    'nox_dollarPerkWh_adjustVSL': 0.0025886336768102818,
#    'pm25_dollarPerkWh_adjustVSL': 0.0030332084958453387}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.00796097069576223,
#    'nox_dollarPerkWh_adjustVSL': 0.0025283445780119305,
#    'pm25_dollarPerkWh_adjustVSL': 0.0029625652803451255}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.007771139075111462,
#    'nox_dollarPerkWh_adjustVSL': 0.0024680554792135792,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028919220648449123}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.007393062697138699,
#    'nox_dollarPerkWh_adjustVSL': 0.002347981257507089,
#    'pm25_dollarPerkWh_adjustVSL': 0.002751226163113106}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.007014986319165934,
#    'nox_dollarPerkWh_adjustVSL': 0.0022279070358005985,
#    'pm25_dollarPerkWh_adjustVSL': 0.0026105302613813}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.007015178018258371,
#    'nox_dollarPerkWh_adjustVSL': 0.002227967917994428,
#    'pm25_dollarPerkWh_adjustVSL': 0.00261060159955063}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.007015369717350806,
#    'nox_dollarPerkWh_adjustVSL': 0.002228028800188257,
#    'pm25_dollarPerkWh_adjustVSL': 0.0026106729377199595}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.006969256144277632,
#    'nox_dollarPerkWh_adjustVSL': 0.0022133834752765123,
#    'pm25_dollarPerkWh_adjustVSL': 0.0025935124084628973}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.006923142571204457,
#    'nox_dollarPerkWh_adjustVSL': 0.002198738150364768,
#    'pm25_dollarPerkWh_adjustVSL': 0.002576351879205835}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.006509468872230351,
#    'nox_dollarPerkWh_adjustVSL': 0.002067358486522508,
#    'pm25_dollarPerkWh_adjustVSL': 0.0024224089261655726}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.006095795173256246,
#    'nox_dollarPerkWh_adjustVSL': 0.001935978822680249,
#    'pm25_dollarPerkWh_adjustVSL': 0.002268465973125311}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.005985266766102199,
#    'nox_dollarPerkWh_adjustVSL': 0.0019008758296378317,
#    'pm25_dollarPerkWh_adjustVSL': 0.002227334353120638}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.005874738358948152,
#    'nox_dollarPerkWh_adjustVSL': 0.0018657728365954144,
#    'pm25_dollarPerkWh_adjustVSL': 0.002186202733115965}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.005731709640298837,
#    'nox_dollarPerkWh_adjustVSL': 0.0018203479884057973,
#    'pm25_dollarPerkWh_adjustVSL': 0.0021329765711118427}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.005588680921649523,
#    'nox_dollarPerkWh_adjustVSL': 0.0017749231402161803,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020797504091077204}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0050946708598625145,
#    'nox_dollarPerkWh_adjustVSL': 0.0016180292501447849,
#    'pm25_dollarPerkWh_adjustVSL': 0.0018959113883246883}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.004600660798075506,
#    'nox_dollarPerkWh_adjustVSL': 0.0014611353600733892,
#    'pm25_dollarPerkWh_adjustVSL': 0.0017120723675416564}},
#  ('MidCase',
#   'NEWEc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.003167972308851938,
#    'nox_dollarPerkWh_adjustVSL': 0.0014729562382107386,
#    'pm25_dollarPerkWh_adjustVSL': 0.007170684602939741}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0014271691825102802,
#    'nox_dollarPerkWh_adjustVSL': 0.0006635656961037174,
#    'pm25_dollarPerkWh_adjustVSL': 0.0032303881111022865}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.000503752197149397,
#    'nox_dollarPerkWh_adjustVSL': 0.00023422077877078098,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011402398037706684}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0017683978492900878,
#    'nox_dollarPerkWh_adjustVSL': 0.0008222207739859471,
#    'pm25_dollarPerkWh_adjustVSL': 0.004002756966765154}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0010629143557103662,
#    'nox_dollarPerkWh_adjustVSL': 0.0004942045505109574,
#    'pm25_dollarPerkWh_adjustVSL': 0.0024058996928221447}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0016767269412537662,
#    'nox_dollarPerkWh_adjustVSL': 0.0007795981678863766,
#    'pm25_dollarPerkWh_adjustVSL': 0.003795260465941327}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}},
#  ('MidCase',
#   'NWPPc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.006036059052925846,
#    'nox_dollarPerkWh_adjustVSL': 0.0014906377272315239,
#    'pm25_dollarPerkWh_adjustVSL': 0.002749497620689984}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0062401179629307454,
#    'nox_dollarPerkWh_adjustVSL': 0.0015410311887871398,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028424489126868875}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.005027345288260074,
#    'nox_dollarPerkWh_adjustVSL': 0.0012415303576043678,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022900163479609827}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.005159963980739061,
#    'nox_dollarPerkWh_adjustVSL': 0.0012742812675295234,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023504257601673203}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.005079348353191584,
#    'nox_dollarPerkWh_adjustVSL': 0.0012543727983159118,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023137043705671345}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.003996619862547934,
#    'nox_dollarPerkWh_adjustVSL': 0.0009869870881447135,
#    'pm25_dollarPerkWh_adjustVSL': 0.0018205084984301715}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0025008840961106187,
#    'nox_dollarPerkWh_adjustVSL': 0.000617606977070374,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011391828362819767}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0026614567507052397,
#    'nox_dollarPerkWh_adjustVSL': 0.0006572612705094742,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012123256150196667}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0028220294052998616,
#    'nox_dollarPerkWh_adjustVSL': 0.0006969155639485745,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012854683937573567}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0028500886862254395,
#    'nox_dollarPerkWh_adjustVSL': 0.0007038449565174528,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012982497342755137}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0028781479671510174,
#    'nox_dollarPerkWh_adjustVSL': 0.000710774349086331,
#    'pm25_dollarPerkWh_adjustVSL': 0.0013110310747936704}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.002688165517171956,
#    'nox_dollarPerkWh_adjustVSL': 0.0006638571461617849,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012244917799308936}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0024981830671928942,
#    'nox_dollarPerkWh_adjustVSL': 0.0006169399432372389,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011379524850681166}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.002563843670516083,
#    'nox_dollarPerkWh_adjustVSL': 0.0006331551875958714,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011678616809568923}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.002629504273839272,
#    'nox_dollarPerkWh_adjustVSL': 0.000649370431954504,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011977708768456678}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0026533867930396892,
#    'nox_dollarPerkWh_adjustVSL': 0.0006552683504190718,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012086496520766358}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.002677269312240106,
#    'nox_dollarPerkWh_adjustVSL': 0.0006611662688836396,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012195284273076037}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.002675691023300554,
#    'nox_dollarPerkWh_adjustVSL': 0.0006607765018158989,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012188094976805061}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0026741127343610028,
#    'nox_dollarPerkWh_adjustVSL': 0.0006603867347481584,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012180905680534086}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.002294960889431547,
#    'nox_dollarPerkWh_adjustVSL': 0.000566753117275956,
#    'pm25_dollarPerkWh_adjustVSL': 0.001045382334689052}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0019158090445020916,
#    'nox_dollarPerkWh_adjustVSL': 0.00047311949980375365,
#    'pm25_dollarPerkWh_adjustVSL': 0.000872674101324695}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0018827821289074398,
#    'nox_dollarPerkWh_adjustVSL': 0.00046496332274057275,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008576299433650065}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.001849755213312788,
#    'nox_dollarPerkWh_adjustVSL': 0.00045680714567739185,
#    'pm25_dollarPerkWh_adjustVSL': 0.000842585785405318}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0018511469230719094,
#    'nox_dollarPerkWh_adjustVSL': 0.00045715083599819767,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008432197259678348}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0018525386328310314,
#    'nox_dollarPerkWh_adjustVSL': 0.00045749452631900354,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008438536665303515}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0017609723313303375,
#    'nox_dollarPerkWh_adjustVSL': 0.00043488172840513474,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008021441130114039}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0016694060298296438,
#    'nox_dollarPerkWh_adjustVSL': 0.0004122689304912659,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007604345594924562}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0015840505680208947,
#    'nox_dollarPerkWh_adjustVSL': 0.00039118993333736677,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007215541182810183}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0014986951062121454,
#    'nox_dollarPerkWh_adjustVSL': 0.0003701109361834676,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006826736770695805}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0014989369485517816,
#    'nox_dollarPerkWh_adjustVSL': 0.00037017066046918825,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006827838391689869}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0014991787908914178,
#    'nox_dollarPerkWh_adjustVSL': 0.0003702303847549089,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006828940012683935}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0013596778684718046,
#    'nox_dollarPerkWh_adjustVSL': 0.0003357798705835016,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006193496504074018}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0012201769460521913,
#    'nox_dollarPerkWh_adjustVSL': 0.0003013293564120942,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005558052995464102}},
#  ('MidCase',
#   'NYSTc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.00665162210640999,
#    'nox_dollarPerkWh_adjustVSL': 0.0019335789965290178,
#    'pm25_dollarPerkWh_adjustVSL': 0.007329761610473915}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.004065352963812652,
#    'nox_dollarPerkWh_adjustVSL': 0.0011817690449867871,
#    'pm25_dollarPerkWh_adjustVSL': 0.004479819750804052}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0013844217624233764,
#    'nox_dollarPerkWh_adjustVSL': 0.0004024415096551983,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015255649410895798}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0064260429742335895,
#    'nox_dollarPerkWh_adjustVSL': 0.0018680047553809526,
#    'pm25_dollarPerkWh_adjustVSL': 0.007081184460915581}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0034764717689194907,
#    'nox_dollarPerkWh_adjustVSL': 0.0010105854913090998,
#    'pm25_dollarPerkWh_adjustVSL': 0.0038309015310966613}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.003432941468243008,
#    'nox_dollarPerkWh_adjustVSL': 0.0009979315440832753,
#    'pm25_dollarPerkWh_adjustVSL': 0.003782933272875348}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0033894111675665264,
#    'nox_dollarPerkWh_adjustVSL': 0.000985277596857451,
#    'pm25_dollarPerkWh_adjustVSL': 0.003734965014654036}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0032206709154654575,
#    'nox_dollarPerkWh_adjustVSL': 0.0009362260118287076,
#    'pm25_dollarPerkWh_adjustVSL': 0.0035490215256515248}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.003051930663364389,
#    'nox_dollarPerkWh_adjustVSL': 0.0008871744267999644,
#    'pm25_dollarPerkWh_adjustVSL': 0.003363078036649014}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.00236275373263698,
#    'nox_dollarPerkWh_adjustVSL': 0.0006868356196896385,
#    'pm25_dollarPerkWh_adjustVSL': 0.002603638830864608}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0016735768019095717,
#    'nox_dollarPerkWh_adjustVSL': 0.0004864968125793125,
#    'pm25_dollarPerkWh_adjustVSL': 0.0018441996250802022}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.001312597392559266,
#    'nox_dollarPerkWh_adjustVSL': 0.0003815626787795924,
#    'pm25_dollarPerkWh_adjustVSL': 0.0014464180051235237}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0009516179832089598,
#    'nox_dollarPerkWh_adjustVSL': 0.0002766285449798722,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010486363851668445}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0004758089916044799,
#    'nox_dollarPerkWh_adjustVSL': 0.0001383142724899361,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005243181925834223}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}},
#  ('MidCase',
#   'RFCEc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.012996373701117567,
#    'nox_dollarPerkWh_adjustVSL': 0.0026710315291054846,
#    'pm25_dollarPerkWh_adjustVSL': 0.009354037689040239}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.010277728652690459,
#    'nox_dollarPerkWh_adjustVSL': 0.002112292083180589,
# ...
#    'nox_dollarPerkWh_adjustVSL': 0.00079602516028138,
#    'pm25_dollarPerkWh_adjustVSL': 0.003943570596609465}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0016354256992399123,
#    'nox_dollarPerkWh_adjustVSL': 0.0008160841639987025,
#    'pm25_dollarPerkWh_adjustVSL': 0.004042944462165362}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.001675623771482508,
#    'nox_dollarPerkWh_adjustVSL': 0.0008361431677160252,
#    'pm25_dollarPerkWh_adjustVSL': 0.00414231832772126}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0018980272790820453,
#    'nox_dollarPerkWh_adjustVSL': 0.0009471234345995052,
#    'pm25_dollarPerkWh_adjustVSL': 0.0046921232071686116}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0021204307866815827,
#    'nox_dollarPerkWh_adjustVSL': 0.001058103701482985,
#    'pm25_dollarPerkWh_adjustVSL': 0.005241928086615963}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0021031976377722315,
#    'nox_dollarPerkWh_adjustVSL': 0.001049504289154263,
#    'pm25_dollarPerkWh_adjustVSL': 0.005199325928669495}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0020859644888628808,
#    'nox_dollarPerkWh_adjustVSL': 0.001040904876825541,
#    'pm25_dollarPerkWh_adjustVSL': 0.005156723770723028}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0020351981186164515,
#    'nox_dollarPerkWh_adjustVSL': 0.0010155722488491916,
#    'pm25_dollarPerkWh_adjustVSL': 0.005031223960155401}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0019844317483700222,
#    'nox_dollarPerkWh_adjustVSL': 0.000990239620872842,
#    'pm25_dollarPerkWh_adjustVSL': 0.004905724149587774}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.001978371909280973,
#    'nox_dollarPerkWh_adjustVSL': 0.000987215736192999,
#    'pm25_dollarPerkWh_adjustVSL': 0.004890743589542722}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0019723120701919243,
#    'nox_dollarPerkWh_adjustVSL': 0.000984191851513156,
#    'pm25_dollarPerkWh_adjustVSL': 0.004875763029497671}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0019793627161501554,
#    'nox_dollarPerkWh_adjustVSL': 0.000987710152904132,
#    'pm25_dollarPerkWh_adjustVSL': 0.004893192968408846}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.001986413362108386,
#    'nox_dollarPerkWh_adjustVSL': 0.0009912284542951079,
#    'pm25_dollarPerkWh_adjustVSL': 0.004910622907320022}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0019105494828833636,
#    'nox_dollarPerkWh_adjustVSL': 0.0009533720659041067,
#    'pm25_dollarPerkWh_adjustVSL': 0.004723079412966389}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0018346856036583414,
#    'nox_dollarPerkWh_adjustVSL': 0.0009155156775131054,
#    'pm25_dollarPerkWh_adjustVSL': 0.004535535918612757}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0017675411952030478,
#    'nox_dollarPerkWh_adjustVSL': 0.0008820103409717434,
#    'pm25_dollarPerkWh_adjustVSL': 0.004369547873753328}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0017003967867477545,
#    'nox_dollarPerkWh_adjustVSL': 0.0008485050044303813,
#    'pm25_dollarPerkWh_adjustVSL': 0.004203559828893899}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0016581773243313804,
#    'nox_dollarPerkWh_adjustVSL': 0.0008274373186855906,
#    'pm25_dollarPerkWh_adjustVSL': 0.004099188874070816}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0016159578619150063,
#    'nox_dollarPerkWh_adjustVSL': 0.0008063696329407997,
#    'pm25_dollarPerkWh_adjustVSL': 0.003994817919247732}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0016153903781568884,
#    'nox_dollarPerkWh_adjustVSL': 0.0008060864562067287,
#    'pm25_dollarPerkWh_adjustVSL': 0.003993415039668233}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.00161482289439877,
#    'nox_dollarPerkWh_adjustVSL': 0.0008058032794726576,
#    'pm25_dollarPerkWh_adjustVSL': 0.003992012160088734}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0015117029319560945,
#    'nox_dollarPerkWh_adjustVSL': 0.0007543459932255842,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037370887592334825}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0014085829695134194,
#    'nox_dollarPerkWh_adjustVSL': 0.0007028887069785108,
#    'pm25_dollarPerkWh_adjustVSL': 0.003482165358378232}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.00145684097756547,
#    'nox_dollarPerkWh_adjustVSL': 0.0007269696518821552,
#    'pm25_dollarPerkWh_adjustVSL': 0.003601464233588428}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.001505098985617521,
#    'nox_dollarPerkWh_adjustVSL': 0.0007510505967857997,
#    'pm25_dollarPerkWh_adjustVSL': 0.003720763108798625}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0012801270378658765,
#    'nox_dollarPerkWh_adjustVSL': 0.0006387886676811088,
#    'pm25_dollarPerkWh_adjustVSL': 0.003164608774958945}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.001055155090114232,
#    'nox_dollarPerkWh_adjustVSL': 0.0005265267385764178,
#    'pm25_dollarPerkWh_adjustVSL': 0.002608454441119265}},
#  ('MidCase',
#   'SRTVc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.019124945198742256,
#    'nox_dollarPerkWh_adjustVSL': 0.0027802748893221937,
#    'pm25_dollarPerkWh_adjustVSL': 0.007428081065680646}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.016622535355147627,
#    'nox_dollarPerkWh_adjustVSL': 0.002416488892623161,
#    'pm25_dollarPerkWh_adjustVSL': 0.006456151317144657}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.013831967726987957,
#    'nox_dollarPerkWh_adjustVSL': 0.0020108121692180682,
#    'pm25_dollarPerkWh_adjustVSL': 0.005372301803024355}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.01633076234752472,
#    'nox_dollarPerkWh_adjustVSL': 0.00237407260551509,
#    'pm25_dollarPerkWh_adjustVSL': 0.006342827407931942}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.015079931376386616,
#    'nox_dollarPerkWh_adjustVSL': 0.002192233969968544,
#    'pm25_dollarPerkWh_adjustVSL': 0.005857007775168293}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.02183834147322967,
#    'nox_dollarPerkWh_adjustVSL': 0.0031747328837552382,
#    'pm25_dollarPerkWh_adjustVSL': 0.008481957418305902}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.01893095411556391,
#    'nox_dollarPerkWh_adjustVSL': 0.0027520735778042583,
#    'pm25_dollarPerkWh_adjustVSL': 0.007352735412300017}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.019191816568939694,
#    'nox_dollarPerkWh_adjustVSL': 0.0027899962657466724,
#    'pm25_dollarPerkWh_adjustVSL': 0.007454053739256326}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.01945267902231548,
#    'nox_dollarPerkWh_adjustVSL': 0.002827918953689087,
#    'pm25_dollarPerkWh_adjustVSL': 0.007555372066212636}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.019924810018761424,
#    'nox_dollarPerkWh_adjustVSL': 0.002896554651216505,
#    'pm25_dollarPerkWh_adjustVSL': 0.0077387465689250255}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.020396941015207365,
#    'nox_dollarPerkWh_adjustVSL': 0.0029651903487439234,
#    'pm25_dollarPerkWh_adjustVSL': 0.007922121071637414}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.01899893399639883,
#    'nox_dollarPerkWh_adjustVSL': 0.002761956103150102,
#    'pm25_dollarPerkWh_adjustVSL': 0.007379138628645458}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.01760092697759029,
#    'nox_dollarPerkWh_adjustVSL': 0.0025587218575562807,
#    'pm25_dollarPerkWh_adjustVSL': 0.0068361561856535025}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.017290872645462203,
#    'nox_dollarPerkWh_adjustVSL': 0.002513647936298824,
#    'pm25_dollarPerkWh_adjustVSL': 0.006715731855550618}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.016980818313334117,
#    'nox_dollarPerkWh_adjustVSL': 0.0024685740150413673,
#    'pm25_dollarPerkWh_adjustVSL': 0.006595307525447735}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.016781920415811478,
#    'nox_dollarPerkWh_adjustVSL': 0.002439659378984918,
#    'pm25_dollarPerkWh_adjustVSL': 0.006518056077601036}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.016583022518288842,
#    'nox_dollarPerkWh_adjustVSL': 0.0024107447429284686,
#    'pm25_dollarPerkWh_adjustVSL': 0.006440804629754339}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.016458133051305047,
#    'nox_dollarPerkWh_adjustVSL': 0.002392589028212031,
#    'pm25_dollarPerkWh_adjustVSL': 0.006392297871938046}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.016333243584321255,
#    'nox_dollarPerkWh_adjustVSL': 0.0023744333134955928,
#    'pm25_dollarPerkWh_adjustVSL': 0.0063437911141217525}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.016093467349288064,
#    'nox_dollarPerkWh_adjustVSL': 0.002339576019088138,
#    'pm25_dollarPerkWh_adjustVSL': 0.006250662621833714}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.015853691114254873,
#    'nox_dollarPerkWh_adjustVSL': 0.0023047187246806834,
#    'pm25_dollarPerkWh_adjustVSL': 0.0061575341295456755}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.015626418252889678,
#    'nox_dollarPerkWh_adjustVSL': 0.0022716790990550055,
#    'pm25_dollarPerkWh_adjustVSL': 0.00606926191643832}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.015399145391524484,
#    'nox_dollarPerkWh_adjustVSL': 0.002238639473429327,
#    'pm25_dollarPerkWh_adjustVSL': 0.005980989703330965}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.015388587254259838,
#    'nox_dollarPerkWh_adjustVSL': 0.002237104591963793,
#    'pm25_dollarPerkWh_adjustVSL': 0.005976888949122815}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.01537802911699519,
#    'nox_dollarPerkWh_adjustVSL': 0.0022355697104982576,
#    'pm25_dollarPerkWh_adjustVSL': 0.005972788194914664}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.01525994316843324,
#    'nox_dollarPerkWh_adjustVSL': 0.0022184030522852884,
#    'pm25_dollarPerkWh_adjustVSL': 0.005926923906702552}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.015141857219871291,
#    'nox_dollarPerkWh_adjustVSL': 0.0022012363940723187,
#    'pm25_dollarPerkWh_adjustVSL': 0.005881059618490441}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.01469365960422184,
#    'nox_dollarPerkWh_adjustVSL': 0.002136079994234572,
#    'pm25_dollarPerkWh_adjustVSL': 0.005706980781249755}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.014245461988572392,
#    'nox_dollarPerkWh_adjustVSL': 0.0020709235943968253,
#    'pm25_dollarPerkWh_adjustVSL': 0.0055329019440090695}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.012489076781555416,
#    'nox_dollarPerkWh_adjustVSL': 0.0018155903823901631,
#    'pm25_dollarPerkWh_adjustVSL': 0.004850726305610776}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.010732691574538442,
#    'nox_dollarPerkWh_adjustVSL': 0.0015602571703835005,
#    'pm25_dollarPerkWh_adjustVSL': 0.004168550667212483}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.010194640387619884,
#    'nox_dollarPerkWh_adjustVSL': 0.001482038373486867,
#    'pm25_dollarPerkWh_adjustVSL': 0.003959572926759685}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.009656589200701329,
#    'nox_dollarPerkWh_adjustVSL': 0.0014038195765902338,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037505951863068886}},
#  ('MidCase',
#   'SRVCc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.008226296131836222,
#    'nox_dollarPerkWh_adjustVSL': 0.0024308903916151164,
#    'pm25_dollarPerkWh_adjustVSL': 0.007534057412737781}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.006866804179516115,
#    'nox_dollarPerkWh_adjustVSL': 0.0020291572335315706,
#    'pm25_dollarPerkWh_adjustVSL': 0.0062889660305669335}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0053806308723014585,
#    'nox_dollarPerkWh_adjustVSL': 0.0015899894288616747,
#    'pm25_dollarPerkWh_adjustVSL': 0.004927853466371618}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.005676781522458289,
#    'nox_dollarPerkWh_adjustVSL': 0.0016775026618403317,
#    'pm25_dollarPerkWh_adjustVSL': 0.00519908318693398}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.004677150637123422,
#    'nox_dollarPerkWh_adjustVSL': 0.0013821093189094796,
#    'pm25_dollarPerkWh_adjustVSL': 0.004283570742334238}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.008418148989595546,
#    'nox_dollarPerkWh_adjustVSL': 0.0024875833748309955,
#    'pm25_dollarPerkWh_adjustVSL': 0.007709765948145674}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.00708861920935403,
#    'nox_dollarPerkWh_adjustVSL': 0.002094704111021434,
#    'pm25_dollarPerkWh_adjustVSL': 0.006492115436207643}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.006810132177138153,
#    'nox_dollarPerkWh_adjustVSL': 0.002012410519840943,
#    'pm25_dollarPerkWh_adjustVSL': 0.006237062948940929}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.006531645144922277,
#    'nox_dollarPerkWh_adjustVSL': 0.0019301169286604525,
#    'pm25_dollarPerkWh_adjustVSL': 0.0059820104616742165}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.007054902919602097,
#    'nox_dollarPerkWh_adjustVSL': 0.0020847408659004987,
#    'pm25_dollarPerkWh_adjustVSL': 0.006461236355432457}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.007578160694281917,
#    'nox_dollarPerkWh_adjustVSL': 0.0022393648031405456,
#    'pm25_dollarPerkWh_adjustVSL': 0.006940462249190699}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.007386353398579677,
#    'nox_dollarPerkWh_adjustVSL': 0.0021826852836226676,
#    'pm25_dollarPerkWh_adjustVSL': 0.006764795441815495}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.007194546102877436,
#    'nox_dollarPerkWh_adjustVSL': 0.0021260057641047892,
#    'pm25_dollarPerkWh_adjustVSL': 0.006589128634440292}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.007024636236580417,
#    'nox_dollarPerkWh_adjustVSL': 0.0020757969879067655,
#    'pm25_dollarPerkWh_adjustVSL': 0.006433516598700629}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.006854726370283399,
#    'nox_dollarPerkWh_adjustVSL': 0.002025588211708742,
#    'pm25_dollarPerkWh_adjustVSL': 0.006277904562960969}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.006451650284764264,
#    'nox_dollarPerkWh_adjustVSL': 0.0019064782541196536,
#    'pm25_dollarPerkWh_adjustVSL': 0.0059087471291250785}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.006048574199245128,
#    'nox_dollarPerkWh_adjustVSL': 0.0017873682965305643,
#    'pm25_dollarPerkWh_adjustVSL': 0.005539589695289188}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.005977573884784195,
#    'nox_dollarPerkWh_adjustVSL': 0.001766387531984928,
#    'pm25_dollarPerkWh_adjustVSL': 0.005474564021900051}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.005906573570323263,
#    'nox_dollarPerkWh_adjustVSL': 0.0017454067674392921,
#    'pm25_dollarPerkWh_adjustVSL': 0.005409538348510914}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.005702925363671972,
#    'nox_dollarPerkWh_adjustVSL': 0.0016852282301140415,
#    'pm25_dollarPerkWh_adjustVSL': 0.005223027036940924}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.005499277157020682,
#    'nox_dollarPerkWh_adjustVSL': 0.001625049692788791,
#    'pm25_dollarPerkWh_adjustVSL': 0.005036515725370934}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.005218818039684875,
#    'nox_dollarPerkWh_adjustVSL': 0.0015421733456884232,
#    'pm25_dollarPerkWh_adjustVSL': 0.004779657102964147}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.004938358922349067,
#    'nox_dollarPerkWh_adjustVSL': 0.0014592969985880555,
#    'pm25_dollarPerkWh_adjustVSL': 0.00452279848055736}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.004935192560856009,
#    'nox_dollarPerkWh_adjustVSL': 0.0014583613311131066,
#    'pm25_dollarPerkWh_adjustVSL': 0.00451989856680567}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.004932026199362949,
#    'nox_dollarPerkWh_adjustVSL': 0.0014574256636381575,
#    'pm25_dollarPerkWh_adjustVSL': 0.0045169986530539784}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0046474626511595635,
#    'nox_dollarPerkWh_adjustVSL': 0.0013733364472951629,
#    'pm25_dollarPerkWh_adjustVSL': 0.004256380985591267}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.004362899102956178,
#    'nox_dollarPerkWh_adjustVSL': 0.0012892472309521687,
#    'pm25_dollarPerkWh_adjustVSL': 0.003995763318128557}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.003963376314499724,
#    'nox_dollarPerkWh_adjustVSL': 0.001171187281234155,
#    'pm25_dollarPerkWh_adjustVSL': 0.0036298601731786628}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0035638535260432693,
#    'nox_dollarPerkWh_adjustVSL': 0.0010531273315161414,
#    'pm25_dollarPerkWh_adjustVSL': 0.003263957028228769}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0036103820032758636,
#    'nox_dollarPerkWh_adjustVSL': 0.0010668766090073164,
#    'pm25_dollarPerkWh_adjustVSL': 0.0033065701572943503}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0036569104805084583,
#    'nox_dollarPerkWh_adjustVSL': 0.0010806258864984916,
#    'pm25_dollarPerkWh_adjustVSL': 0.003349183286359932}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0027982463750421,
#    'nox_dollarPerkWh_adjustVSL': 0.000826888567764618,
#    'pm25_dollarPerkWh_adjustVSL': 0.002562775337367625}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0019395822695757422,
#    'nox_dollarPerkWh_adjustVSL': 0.0005731512490307444,
#    'pm25_dollarPerkWh_adjustVSL': 0.0017763673883753178}}}

# %% [markdown]
# #### IRA-Reference Projections

# %%
# Create dictionaries mapping 'gea_region' to marginal damage factors for each pollutant
# For SO2
so2_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'so2'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# For NOx
nox_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'nox'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# For PM2.5
pm25_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'pm25'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# Map the marginal damage factors to the projection factors dataframe
df_iraRef_coal_projection_factors['so2_marg_damage'] = df_iraRef_coal_projection_factors['gea_region'].map(so2_marg_damages)
df_iraRef_coal_projection_factors['nox_marg_damage'] = df_iraRef_coal_projection_factors['gea_region'].map(nox_marg_damages)
df_iraRef_coal_projection_factors['pm25_marg_damage'] = df_iraRef_coal_projection_factors['gea_region'].map(pm25_marg_damages)

# Calculate the new columns by multiplying the coal projection factors with the marginal damages
df_iraRef_coal_projection_factors['so2_dollarPerkWh_adjustVSL'] = (
    df_iraRef_coal_projection_factors['coal_projection_factors'] * df_iraRef_coal_projection_factors['so2_marg_damage']
)
df_iraRef_coal_projection_factors['nox_dollarPerkWh_adjustVSL'] = (
    df_iraRef_coal_projection_factors['coal_projection_factors'] * df_iraRef_coal_projection_factors['nox_marg_damage']
)
df_iraRef_coal_projection_factors['pm25_dollarPerkWh_adjustVSL'] = (
    df_iraRef_coal_projection_factors['coal_projection_factors'] * df_iraRef_coal_projection_factors['pm25_marg_damage']
)

# Optionally, drop the intermediate marginal damage columns if they're no longer needed
df_iraRef_coal_projection_factors.drop(
    columns=['so2_marg_damage', 'nox_marg_damage', 'pm25_marg_damage'], 
    inplace=True
)
df_iraRef_coal_projection_factors
# Out:
#     scenario gea_region  year     coal_MWh  coal_projection_factors  \
# 0    MidCase      AZNMc  2018  44146154.50                 1.000000
# 1    MidCase      AZNMc  2019  37909639.38                 0.858730
# 2    MidCase      AZNMc  2020  26535437.00                 0.601082
# 3    MidCase      AZNMc  2021  26836891.44                 0.607910
# 4    MidCase      AZNMc  2022  26741465.00                 0.605748
# ..       ...        ...   ...          ...                      ...
# 655  MidCase      SRVCc  2046   3826239.64                 0.061049
# 656  MidCase      SRVCc  2047   3350872.78                 0.053464
# 657  MidCase      SRVCc  2048   2875505.92                 0.045880
# 658  MidCase      SRVCc  2049   2400139.06                 0.038295
# 659  MidCase      SRVCc  2050   1924772.20                 0.030710
#
#      so2_dollarPerkWh_adjustVSL  nox_dollarPerkWh_adjustVSL  \
# 0                      0.001760                    0.000575
# 1                      0.001512                    0.000494
# 2                      0.001058                    0.000346
# 3                      0.001070                    0.000350
# 4                      0.001066                    0.000348
# ..                          ...                         ...
# 655                    0.000502                    0.000148
# 656                    0.000440                    0.000130
# 657                    0.000377                    0.000112
# 658                    0.000315                    0.000093
# 659                    0.000253                    0.000075
#
#      pm25_dollarPerkWh_adjustVSL
# 0                       0.002026
# 1                       0.001740
# 2                       0.001218
# 3                       0.001232
# 4                       0.001227
# ..                           ...
# 655                     0.000460
# 656                     0.000403
# 657                     0.000346
# 658                     0.000289
# 659                     0.000231
#
# [660 rows x 8 columns]

# %%
import pandas as pd

# Assuming df_iraRef_coal_projection_factors is your dataframe

# Initialize the lookup dictionary
damages_iraRef_health_damages_lookup = {}

# Group the dataframe
grouped = df_iraRef_coal_projection_factors.groupby(['scenario', 'gea_region'])

for (scenario, gea_region), group in grouped:
    year_dict = {}
    for _, row in group.iterrows():
        year = int(row['year'])
        data_dict = {
            'so2_dollarPerkWh_adjustVSL': row['so2_dollarPerkWh_adjustVSL'],
            'nox_dollarPerkWh_adjustVSL': row['nox_dollarPerkWh_adjustVSL'],
            'pm25_dollarPerkWh_adjustVSL': row['pm25_dollarPerkWh_adjustVSL']
        }
        year_dict[year] = data_dict
    damages_iraRef_health_damages_lookup[(scenario, gea_region)] = year_dict

# Now, lookup_dict contains the desired nested dictionary
damages_iraRef_health_damages_lookup
# Out:
# {('MidCase',
#   'AZNMc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.0017604045476692913,
#    'nox_dollarPerkWh_adjustVSL': 0.000575015374879764,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020259847537919245}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0015117126807739248,
#    'nox_dollarPerkWh_adjustVSL': 0.0004937831108176674,
#    'pm25_dollarPerkWh_adjustVSL': 0.0017397744441280825}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0010581466154473767,
#    'nox_dollarPerkWh_adjustVSL': 0.00034563110710250785,
#    'pm25_dollarPerkWh_adjustVSL': 0.001217781965521054}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0010701676345622147,
#    'nox_dollarPerkWh_adjustVSL': 0.0003495576311630751,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012316165136559971}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0010663623396085199,
#    'nox_dollarPerkWh_adjustVSL': 0.00034831467646426797,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012272371398523595}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0009887543357298897,
#    'nox_dollarPerkWh_adjustVSL': 0.000322964937676656,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011379209466861357}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0009111463318512595,
#    'nox_dollarPerkWh_adjustVSL': 0.0002976151988890441,
#    'pm25_dollarPerkWh_adjustVSL': 0.001048604753519912}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0008744767222362603,
#    'nox_dollarPerkWh_adjustVSL': 0.000285637503564762,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010064030504478253}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.000837807112621261,
#    'nox_dollarPerkWh_adjustVSL': 0.0002736598082404799,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009642013473757389}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0007076779183616448,
#    'nox_dollarPerkWh_adjustVSL': 0.00023115464230060432,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008144404506873844}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0005775487241020287,
#    'nox_dollarPerkWh_adjustVSL': 0.00018864947636072874,
#    'pm25_dollarPerkWh_adjustVSL': 0.00066467955399903}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0005566240449226292,
#    'nox_dollarPerkWh_adjustVSL': 0.00018181467679235052,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006405981114399447}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0005356993657432299,
#    'nox_dollarPerkWh_adjustVSL': 0.0001749798772239723,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006165166688808594}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0004942072670497781,
#    'nox_dollarPerkWh_adjustVSL': 0.0001614269727416752,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005687649407527662}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.00045271516835632624,
#    'nox_dollarPerkWh_adjustVSL': 0.0001478740682593781,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005210132126246727}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0004112230696628745,
#    'nox_dollarPerkWh_adjustVSL': 0.000134321163777081,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004732614844965794}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0003697309709694227,
#    'nox_dollarPerkWh_adjustVSL': 0.00012076825929478388,
#    'pm25_dollarPerkWh_adjustVSL': 0.00042550975636848604}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0003282388722759708,
#    'nox_dollarPerkWh_adjustVSL': 0.00010721535481248676,
#    'pm25_dollarPerkWh_adjustVSL': 0.00037775802824039257}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.00031074484053296143,
#    'nox_dollarPerkWh_adjustVSL': 0.0001015011357517696,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003576247914564876}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.00029325080878995206,
#    'nox_dollarPerkWh_adjustVSL': 9.578691669105243e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003374915546725826}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0002757567770469427,
#    'nox_dollarPerkWh_adjustVSL': 9.007269763033528e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003173583178886777}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0002582627453039333,
#    'nox_dollarPerkWh_adjustVSL': 8.435847856961812e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00029722508110477267}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0002407687135609239,
#    'nox_dollarPerkWh_adjustVSL': 7.864425950890097e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0002770918443208677}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.00023347141841992462,
#    'nox_dollarPerkWh_adjustVSL': 7.626068415023388e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00026869365612079845}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.00022617412327892534,
#    'nox_dollarPerkWh_adjustVSL': 7.38771087915668e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00026029546792072925}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.000218876828137926,
#    'nox_dollarPerkWh_adjustVSL': 7.149353343289971e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00025189727972066}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.00021157953299692675,
#    'nox_dollarPerkWh_adjustVSL': 6.910995807423265e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00024349909152059077}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.00020428223785592747,
#    'nox_dollarPerkWh_adjustVSL': 6.672638271556558e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00023510090332052154}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.00020773031142594207,
#    'nox_dollarPerkWh_adjustVSL': 6.78526552641681e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00023906916419104212}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0002111783849959567,
#    'nox_dollarPerkWh_adjustVSL': 6.897892781277063e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0002430374250615627}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.00021462645856597137,
#    'nox_dollarPerkWh_adjustVSL': 7.010520036137316e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00024700568593208333}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.000218074532135986,
#    'nox_dollarPerkWh_adjustVSL': 7.123147290997567e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0002509739468026039}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0002215226057060006,
#    'nox_dollarPerkWh_adjustVSL': 7.23577454585782e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00025494220767312444}},
#  ('MidCase',
#   'CAMXc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.0005985940993128373,
#    'nox_dollarPerkWh_adjustVSL': 0.0007136726494222902,
#    'pm25_dollarPerkWh_adjustVSL': 0.004942314992523925}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0005314338138668267,
#    'nox_dollarPerkWh_adjustVSL': 0.0006336009298626856,
#    'pm25_dollarPerkWh_adjustVSL': 0.00438780353635848}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.00048040861844196223,
#    'nox_dollarPerkWh_adjustVSL': 0.0005727662399652133,
#    'pm25_dollarPerkWh_adjustVSL': 0.003966512065837359}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0005365762254811468,
#    'nox_dollarPerkWh_adjustVSL': 0.000639731960097405,
#    'pm25_dollarPerkWh_adjustVSL': 0.004430262053821914}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0003925936374483933,
#    'nox_dollarPerkWh_adjustVSL': 0.00046806899985443967,
#    'pm25_dollarPerkWh_adjustVSL': 0.0032414643287631967}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.00019629681872419664,
#    'nox_dollarPerkWh_adjustVSL': 0.00023403449992721984,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016207321643815983}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}},
#  ('MidCase',
#   'ERCTc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.012666544314406074,
#    'nox_dollarPerkWh_adjustVSL': 0.0011137260353787004,
#    'pm25_dollarPerkWh_adjustVSL': 0.004887701560349267}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.01058322703966602,
#    'nox_dollarPerkWh_adjustVSL': 0.0009305470537054345,
#    'pm25_dollarPerkWh_adjustVSL': 0.004083801708763977}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.009280967579574518,
#    'nox_dollarPerkWh_adjustVSL': 0.0008160438214487429,
#    'pm25_dollarPerkWh_adjustVSL': 0.003581292465747344}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.010130647748639804,
#    'nox_dollarPerkWh_adjustVSL': 0.0008907533004150554,
#    'pm25_dollarPerkWh_adjustVSL': 0.003909162718679307}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.009682942230626336,
#    'nox_dollarPerkWh_adjustVSL': 0.0008513880813610147,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037364043952838213}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.007492994374491886,
#    'nox_dollarPerkWh_adjustVSL': 0.0006588334363877407,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028913584784319704}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.005303046518357437,
#    'nox_dollarPerkWh_adjustVSL': 0.0004662787914144667,
#    'pm25_dollarPerkWh_adjustVSL': 0.00204631256158012}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.004276562489225045,
#    'nox_dollarPerkWh_adjustVSL': 0.0003760235521188563,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016502181362712507}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0032500784600926536,
#    'nox_dollarPerkWh_adjustVSL': 0.000285768312823246,
#    'pm25_dollarPerkWh_adjustVSL': 0.001254123710962382}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0023353917795582517,
#    'nox_dollarPerkWh_adjustVSL': 0.00020534303304376654,
#    'pm25_dollarPerkWh_adjustVSL': 0.000901169076714271}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0014207050990238499,
#    'nox_dollarPerkWh_adjustVSL': 0.00012491775326428707,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005482144424661597}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0013191844032118128,
#    'nox_dollarPerkWh_adjustVSL': 0.00011599138477347202,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005090401538037114}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0012176637073997756,
#    'nox_dollarPerkWh_adjustVSL': 0.00010706501628265694,
#    'pm25_dollarPerkWh_adjustVSL': 0.000469865865141263}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0011790004389813451,
#    'nox_dollarPerkWh_adjustVSL': 0.00010366548697287769,
#    'pm25_dollarPerkWh_adjustVSL': 0.00045494668018550223}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0011403371705629149,
#    'nox_dollarPerkWh_adjustVSL': 0.00010026595766309847,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004400274952297415}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0011016739021444846,
#    'nox_dollarPerkWh_adjustVSL': 9.686642835331924e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00042510831027398066}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0010630106337260544,
#    'nox_dollarPerkWh_adjustVSL': 9.346689904354002e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004101891253182199}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0010243473653076239,
#    'nox_dollarPerkWh_adjustVSL': 9.006736973376078e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00039526994036245914}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.001008123825766015,
#    'nox_dollarPerkWh_adjustVSL': 8.864088924113455e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00038900968361336893}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0009919002862244057,
#    'nox_dollarPerkWh_adjustVSL': 8.721440874850833e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00038274942686427867}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0009756767466827964,
#    'nox_dollarPerkWh_adjustVSL': 8.578792825588208e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003764891701151884}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0009594532071411873,
#    'nox_dollarPerkWh_adjustVSL': 8.436144776325586e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003702289133660982}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.000943229667599578,
#    'nox_dollarPerkWh_adjustVSL': 8.293496727062962e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00036396865661700794}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0009179213706641293,
#    'nox_dollarPerkWh_adjustVSL': 8.070969504890401e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003542028199885845}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0008926130737286805,
#    'nox_dollarPerkWh_adjustVSL': 7.848442282717841e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00034443698336016103}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0008673047767932317,
#    'nox_dollarPerkWh_adjustVSL': 7.62591506054528e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003346711467317376}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0008419964798577828,
#    'nox_dollarPerkWh_adjustVSL': 7.403387838372718e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003249053101033141}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0008166881829223341,
#    'nox_dollarPerkWh_adjustVSL': 7.180860616200158e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003151394734748907}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0008352206518353852,
#    'nox_dollarPerkWh_adjustVSL': 7.343810293839043e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003222906881215266}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0008537531207484359,
#    'nox_dollarPerkWh_adjustVSL': 7.506759971477928e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00032944190276816245}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.000872285589661487,
#    'nox_dollarPerkWh_adjustVSL': 7.669709649116814e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003365931174147984}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0008908180585745378,
#    'nox_dollarPerkWh_adjustVSL': 7.832659326755698e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003437443320614343}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0009093505274875889,
#    'nox_dollarPerkWh_adjustVSL': 7.995609004394584e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003508955467080702}},
#  ('MidCase',
#   'FRCCc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.004087382457213744,
#    'nox_dollarPerkWh_adjustVSL': 0.0009462959863423146,
#    'pm25_dollarPerkWh_adjustVSL': 0.004568195586332583}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0028146027513577363,
#    'nox_dollarPerkWh_adjustVSL': 0.000651626637496864,
#    'pm25_dollarPerkWh_adjustVSL': 0.003145694341213341}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0023929235510240297,
#    'nox_dollarPerkWh_adjustVSL': 0.0005540009959091587,
#    'pm25_dollarPerkWh_adjustVSL': 0.0026744115381047216}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0027690054146686997,
#    'nox_dollarPerkWh_adjustVSL': 0.0006410701072116732,
#    'pm25_dollarPerkWh_adjustVSL': 0.003094733229941809}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0022947035892550522,
#    'nox_dollarPerkWh_adjustVSL': 0.0005312614660086372,
#    'pm25_dollarPerkWh_adjustVSL': 0.0025646376178661305}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0022478308154662103,
#    'nox_dollarPerkWh_adjustVSL': 0.000520409651144376,
#    'pm25_dollarPerkWh_adjustVSL': 0.0025122510353569622}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.002200958041677369,
#    'nox_dollarPerkWh_adjustVSL': 0.0005095578362801149,
#    'pm25_dollarPerkWh_adjustVSL': 0.002459864452847795}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0020221800890701854,
#    'nox_dollarPerkWh_adjustVSL': 0.0004681678120360912,
#    'pm25_dollarPerkWh_adjustVSL': 0.002260056222866197}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.001843402136463002,
#    'nox_dollarPerkWh_adjustVSL': 0.00042677778779206746,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020602479928845995}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.001479945081405999,
#    'nox_dollarPerkWh_adjustVSL': 0.000342631526460141,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016540362101328948}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0011164880263489958,
#    'nox_dollarPerkWh_adjustVSL': 0.00025848526512821444,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012478244273811895}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0010152762182661825,
#    'nox_dollarPerkWh_adjustVSL': 0.00023505307380239878,
#    'pm25_dollarPerkWh_adjustVSL': 0.001134706719457223}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0009140644101833691,
#    'nox_dollarPerkWh_adjustVSL': 0.0002116208824765831,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010215890115332566}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.000787022144419652,
#    'nox_dollarPerkWh_adjustVSL': 0.00018220851711892838,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008796023186278134}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.000659979878655935,
#    'nox_dollarPerkWh_adjustVSL': 0.00015279615176127373,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007376156257223706}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0005329376128922179,
#    'nox_dollarPerkWh_adjustVSL': 0.000123383786403619,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005956289328169274}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.000405895347128501,
#    'nox_dollarPerkWh_adjustVSL': 9.397142104596433e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00045364223991148443}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.000278853081364784,
#    'nox_dollarPerkWh_adjustVSL': 6.455905568830964e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003116555470060414}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0002643361178805304,
#    'nox_dollarPerkWh_adjustVSL': 6.119814086743636e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00029543090220954623}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.00024981915439627677,
#    'nox_dollarPerkWh_adjustVSL': 5.783722604656307e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00027920625741305105}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.00023530219091202315,
#    'nox_dollarPerkWh_adjustVSL': 5.447631122568978e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00026298161261655587}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0002207852274277695,
#    'nox_dollarPerkWh_adjustVSL': 5.1115396404816484e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00024675696782006063}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.00020626826394351587,
#    'nox_dollarPerkWh_adjustVSL': 4.77544815839432e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00023053232302356542}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.00019143796186880157,
#    'nox_dollarPerkWh_adjustVSL': 4.432102374718555e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00021395748051962452}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.00017660765979408727,
#    'nox_dollarPerkWh_adjustVSL': 4.088756591042791e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001973826380156836}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.00016177735771937294,
#    'nox_dollarPerkWh_adjustVSL': 3.7454108073670257e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00018080779551174264}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.00014694705564465861,
#    'nox_dollarPerkWh_adjustVSL': 3.4020650236912616e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00016423295300780174}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0001321167535699443,
#    'nox_dollarPerkWh_adjustVSL': 3.058719240015497e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001476581105038608}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.00014322412965441883,
#    'nox_dollarPerkWh_adjustVSL': 3.315873189213043e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001600720861804656}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.00015433150573889332,
#    'nox_dollarPerkWh_adjustVSL': 3.573027138410589e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00017248606185707037}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0001654388818233678,
#    'nox_dollarPerkWh_adjustVSL': 3.8301810876081346e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00018490003753367516}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.00017654625790784233,
#    'nox_dollarPerkWh_adjustVSL': 4.08733503680568e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00019731401321027993}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.00018765363399231684,
#    'nox_dollarPerkWh_adjustVSL': 4.3444889860032265e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00020972798888688475}},
#  ('MidCase',
#   'MROEc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.013246333152908747,
#    'nox_dollarPerkWh_adjustVSL': 0.006215755580135027,
#    'pm25_dollarPerkWh_adjustVSL': 0.01270588475547516}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.009825087614629385,
#    'nox_dollarPerkWh_adjustVSL': 0.004610358388316527,
#    'pm25_dollarPerkWh_adjustVSL': 0.009424225519838646}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.00907556659326667,
#    'nox_dollarPerkWh_adjustVSL': 0.00425865052945592,
#    'pm25_dollarPerkWh_adjustVSL': 0.008705284843252274}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.01124791314131969,
#    'nox_dollarPerkWh_adjustVSL': 0.005278010002162717,
#    'pm25_dollarPerkWh_adjustVSL': 0.01078899997935052}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.008989659992435806,
#    'nox_dollarPerkWh_adjustVSL': 0.004218339416386291,
#    'pm25_dollarPerkWh_adjustVSL': 0.008622883218795781}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.005795209870258907,
#    'nox_dollarPerkWh_adjustVSL': 0.002719364496823443,
#    'pm25_dollarPerkWh_adjustVSL': 0.0055587661804454005}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0026007597480820093,
#    'nox_dollarPerkWh_adjustVSL': 0.0012203895772605953,
#    'pm25_dollarPerkWh_adjustVSL': 0.002494649142095019}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.002414666633630832,
#    'nox_dollarPerkWh_adjustVSL': 0.001133066595026783,
#    'pm25_dollarPerkWh_adjustVSL': 0.00231614859868351}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.002228573519179655,
#    'nox_dollarPerkWh_adjustVSL': 0.0010457436127929707,
#    'pm25_dollarPerkWh_adjustVSL': 0.0021376480552720003}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0016278914454864067,
#    'nox_dollarPerkWh_adjustVSL': 0.0007638774609797791,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015614737197087803}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0010272093717931584,
#    'nox_dollarPerkWh_adjustVSL': 0.00048201130916658775,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009852993841455602}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0009104290757880473,
#    'nox_dollarPerkWh_adjustVSL': 0.00042721291566670853,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008732837066276359}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0007936487797829366,
#    'nox_dollarPerkWh_adjustVSL': 0.00037241452216682947,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007612680291097118}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0007648660500892601,
#    'nox_dollarPerkWh_adjustVSL': 0.0003589084136732724,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007336596304521905}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0007360833203955839,
#    'nox_dollarPerkWh_adjustVSL': 0.00034540230517971545,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007060512317946694}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0007073005907019076,
#    'nox_dollarPerkWh_adjustVSL': 0.00033189619668615844,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006784428331371483}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0006785178610082313,
#    'nox_dollarPerkWh_adjustVSL': 0.00031839008819260143,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006508344344796271}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.000649735131314555,
#    'nox_dollarPerkWh_adjustVSL': 0.0003048839796990444,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006232260358221059}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0006076637551291448,
#    'nox_dollarPerkWh_adjustVSL': 0.0002851422603666268,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005828711654481352}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0005655923789437348,
#    'nox_dollarPerkWh_adjustVSL': 0.0002654005410342092,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005425162950741645}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0005235210027583247,
#    'nox_dollarPerkWh_adjustVSL': 0.0002456588217017916,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005021614247001938}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.00048144962657291465,
#    'nox_dollarPerkWh_adjustVSL': 0.00022591710236937406,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004618065543262232}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.00043937825038750444,
#    'nox_dollarPerkWh_adjustVSL': 0.00020617538303695644,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004214516839522524}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0004660002477055198,
#    'nox_dollarPerkWh_adjustVSL': 0.00021866758193257735,
#    'pm25_dollarPerkWh_adjustVSL': 0.00044698750778958315}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0004926222450235351,
#    'nox_dollarPerkWh_adjustVSL': 0.00023115978082819828,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004725233316269139}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0005192442423415505,
#    'nox_dollarPerkWh_adjustVSL': 0.00024365197972381922,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004980591554642446}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0005458662396595657,
#    'nox_dollarPerkWh_adjustVSL': 0.0002561441786194401,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005235949793015753}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0005724882369775811,
#    'nox_dollarPerkWh_adjustVSL': 0.00026863637751506104,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005491308031389061}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.000631398445977189,
#    'nox_dollarPerkWh_adjustVSL': 0.00029627960950155436,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006056374844845742}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0006903086549767968,
#    'nox_dollarPerkWh_adjustVSL': 0.00032392284148804757,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006621441658302423}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0007492188639764047,
#    'nox_dollarPerkWh_adjustVSL': 0.00035156607347454084,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007186508471759103}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0008081290729760126,
#    'nox_dollarPerkWh_adjustVSL': 0.00037920930546103416,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007751575285215784}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0008670392819756204,
#    'nox_dollarPerkWh_adjustVSL': 0.0004068525374475274,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008316642098672465}},
#  ('MidCase',
#   'MROWc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.023005225539313577,
#    'nox_dollarPerkWh_adjustVSL': 0.007306287069895563,
#    'pm25_dollarPerkWh_adjustVSL': 0.00856107691560267}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.019258115923299526,
#    'nox_dollarPerkWh_adjustVSL': 0.0061162331627873925,
#    'pm25_dollarPerkWh_adjustVSL': 0.007166641830449063}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.016284528407799415,
#    'nox_dollarPerkWh_adjustVSL': 0.005171844072640285,
#    'pm25_dollarPerkWh_adjustVSL': 0.006060062310419203}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.018049986241535542,
#    'nox_dollarPerkWh_adjustVSL': 0.005732540237997549,
#    'pm25_dollarPerkWh_adjustVSL': 0.006717053057153662}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.017931766634203077,
#    'nox_dollarPerkWh_adjustVSL': 0.00569499457746989,
#    'pm25_dollarPerkWh_adjustVSL': 0.00667305926324036}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.01449113997502944,
#    'nox_dollarPerkWh_adjustVSL': 0.004602277358536317,
#    'pm25_dollarPerkWh_adjustVSL': 0.005392677577056837}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0110505133158558,
#    'nox_dollarPerkWh_adjustVSL': 0.0035095601396027444,
#    'pm25_dollarPerkWh_adjustVSL': 0.004112295890873313}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.009325825279803123,
#    'nox_dollarPerkWh_adjustVSL': 0.0029618121561769215,
#    'pm25_dollarPerkWh_adjustVSL': 0.00347047706119766}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.007601137243750445,
#    'nox_dollarPerkWh_adjustVSL': 0.0024140641727510986,
#    'pm25_dollarPerkWh_adjustVSL': 0.002828658231522007}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0060836175915741355,
#    'nox_dollarPerkWh_adjustVSL': 0.001932111314081624,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022639342543100175}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.004566097939397827,
#    'nox_dollarPerkWh_adjustVSL': 0.0014501584554121498,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016992102770980284}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0039693926855244935,
#    'nox_dollarPerkWh_adjustVSL': 0.0012606493426471736,
#    'pm25_dollarPerkWh_adjustVSL': 0.0014771546590983686}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0033726874316511593,
#    'nox_dollarPerkWh_adjustVSL': 0.0010711402298821974,
#    'pm25_dollarPerkWh_adjustVSL': 0.001255099041098709}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0032133870614459974,
#    'nox_dollarPerkWh_adjustVSL': 0.001020547627211531,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011958176087267548}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0030540866912408364,
#    'nox_dollarPerkWh_adjustVSL': 0.0009699550245408654,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011365361763548008}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.002894786321035674,
#    'nox_dollarPerkWh_adjustVSL': 0.0009193624218701993,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010772547439828466}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0027354859508305126,
#    'nox_dollarPerkWh_adjustVSL': 0.0008687698191995333,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010179733116108924}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0025761855806253507,
#    'nox_dollarPerkWh_adjustVSL': 0.0008181772165288673,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009586918792389384}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0024246936284037417,
#    'nox_dollarPerkWh_adjustVSL': 0.0007700645088391081,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009023162417626759}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.002273201676182133,
#    'nox_dollarPerkWh_adjustVSL': 0.000721951801149349,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008459406042864133}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.002121709723960524,
#    'nox_dollarPerkWh_adjustVSL': 0.0006738390934595896,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007895649668101508}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0019702177717389156,
#    'nox_dollarPerkWh_adjustVSL': 0.0006257263857698306,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007331893293338884}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0018187258195173064,
#    'nox_dollarPerkWh_adjustVSL': 0.0005776136780800713,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006768136918576258}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0017891769612700587,
#    'nox_dollarPerkWh_adjustVSL': 0.0005682291823456955,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006658174924163019}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0017596281030228108,
#    'nox_dollarPerkWh_adjustVSL': 0.0005588446866113195,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006548212929749781}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0017300792447755634,
#    'nox_dollarPerkWh_adjustVSL': 0.0005494601908769438,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006438250935336543}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0017005303865283157,
#    'nox_dollarPerkWh_adjustVSL': 0.0005400756951425679,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006328288940923305}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0016709815282810677,
#    'nox_dollarPerkWh_adjustVSL': 0.000530691199408192,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006218326946510068}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.001606878158332279,
#    'nox_dollarPerkWh_adjustVSL': 0.0005103324499495878,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005979775109779287}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0015427747883834907,
#    'nox_dollarPerkWh_adjustVSL': 0.0004899737004909838,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005741223273048506}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.001478671418434702,
#    'nox_dollarPerkWh_adjustVSL': 0.00046961495103237967,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005502671436317725}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0014145680484859134,
#    'nox_dollarPerkWh_adjustVSL': 0.0004492562015737755,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005264119599586944}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0013504646785371247,
#    'nox_dollarPerkWh_adjustVSL': 0.0004288974521151714,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005025567762856163}},
#  ('MidCase',
#   'NEWEc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0
, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0062401179629307454,
#    'nox_dollarPerkWh_adjustVSL': 0.0015410311887871398,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028424489126868875}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.005027345288260074,
#    'nox_dollarPerkWh_adjustVSL': 0.0012415303576043678,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022900163479609827}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.005159963980739061,
#    'nox_dollarPerkWh_adjustVSL': 0.0012742812675295234,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023504257601673203}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.005079348353191584,
#    'nox_dollarPerkWh_adjustVSL': 0.0012543727983159118,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023137043705671345}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.004460185438960622,
#    'nox_dollarPerkWh_adjustVSL': 0.0011014671373270736,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020316682034967823}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0038410225247296603,
#    'nox_dollarPerkWh_adjustVSL': 0.0009485614763382352,
#    'pm25_dollarPerkWh_adjustVSL': 0.00174963203642643}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.003329581623663578,
#    'nox_dollarPerkWh_adjustVSL': 0.0008222583544347403,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015166645441811201}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0028181407225974955,
#    'nox_dollarPerkWh_adjustVSL': 0.0006959552325312452,
#    'pm25_dollarPerkWh_adjustVSL': 0.00128369705193581}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0024858337916700674,
#    'nox_dollarPerkWh_adjustVSL': 0.0006138902222459606,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011323272412841283}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0021535268607426397,
#    'nox_dollarPerkWh_adjustVSL': 0.0005318252119606762,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009809574306324468}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.002039922321945461,
#    'nox_dollarPerkWh_adjustVSL': 0.0005037699510642928,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009292091945095715}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0019263177831482824,
#    'nox_dollarPerkWh_adjustVSL': 0.0004757146901679094,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008774609583866963}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0018564280261283202,
#    'nox_dollarPerkWh_adjustVSL': 0.0004584550332216274,
#    'pm25_dollarPerkWh_adjustVSL': 0.000845625332036447}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0017865382691083585,
#    'nox_dollarPerkWh_adjustVSL': 0.0004411953762753455,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008137897056861977}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0017166485120883963,
#    'nox_dollarPerkWh_adjustVSL': 0.0004239357193290635,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007819540793359484}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0016467587550684343,
#    'nox_dollarPerkWh_adjustVSL': 0.0004066760623827816,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007501184529856992}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0015768689980484721,
#    'nox_dollarPerkWh_adjustVSL': 0.0003894164054364996,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007182828266354499}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0015155471720928644,
#    'nox_dollarPerkWh_adjustVSL': 0.0003742726458293357,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006903499961109404}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0014542253461372564,
#    'nox_dollarPerkWh_adjustVSL': 0.0003591288862221718,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006624171655864308}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0013929035201816484,
#    'nox_dollarPerkWh_adjustVSL': 0.00034398512661500786,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006344843350619212}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0013315816942260407,
#    'nox_dollarPerkWh_adjustVSL': 0.00032884136700784395,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006065515045374117}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0012702598682704327,
#    'nox_dollarPerkWh_adjustVSL': 0.00031369760740068003,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005786186740129022}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0012130229068317141,
#    'nox_dollarPerkWh_adjustVSL': 0.00029956262738067954,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005525465484900417}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0011557859453929958,
#    'nox_dollarPerkWh_adjustVSL': 0.00028542764736067916,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005264744229671812}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0010985489839542772,
#    'nox_dollarPerkWh_adjustVSL': 0.00027129266734067867,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005004022974443207}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0010413120225155588,
#    'nox_dollarPerkWh_adjustVSL': 0.00025715768732067823,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004743301719214604}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0009840750610768403,
#    'nox_dollarPerkWh_adjustVSL': 0.0002430227073006778,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004482580463985999}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.000943902028434838,
#    'nox_dollarPerkWh_adjustVSL': 0.00023310175762997418,
#    'pm25_dollarPerkWh_adjustVSL': 0.000429958746027848}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.000903728995792836,
#    'nox_dollarPerkWh_adjustVSL': 0.00022318080795927068,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004116594456570962}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0008635559631508336,
#    'nox_dollarPerkWh_adjustVSL': 0.00021325985828856708,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003933601452863443}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0008233829305088317,
#    'nox_dollarPerkWh_adjustVSL': 0.00020333890861786355,
#    'pm25_dollarPerkWh_adjustVSL': 0.00037506084491559255}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0007832098978668295,
#    'nox_dollarPerkWh_adjustVSL': 0.00019341795894716,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003567615445448407}},
#  ('MidCase',
#   'NYSTc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.00665162210640999,
#    'nox_dollarPerkWh_adjustVSL': 0.0019335789965290178,
#    'pm25_dollarPerkWh_adjustVSL': 0.007329761610473915}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.004065352963812652,
#    'nox_dollarPerkWh_adjustVSL': 0.0011817690449867871,
#    'pm25_dollarPerkWh_adjustVSL': 0.004479819750804052}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0013844217624233764,
#    'nox_dollarPerkWh_adjustVSL': 0.0004024415096551983,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015255649410895798}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.007946691907448887,
#    'nox_dollarPerkWh_adjustVSL': 0.002310046529751429,
#    'pm25_dollarPerkWh_adjustVSL': 0.008756865068650123}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.015893383814897775,
#    'nox_dollarPerkWh_adjustVSL': 0.004620093059502858,
#    'pm25_dollarPerkWh_adjustVSL': 0.017513730137300246}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.012413665651517575,
#    'nox_dollarPerkWh_adjustVSL': 0.003608563864531214,
#    'pm25_dollarPerkWh_adjustVSL': 0.013679251238591608}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.008933947488137374,
#    'nox_dollarPerkWh_adjustVSL': 0.0025970346695595703,
#    'pm25_dollarPerkWh_adjustVSL': 0.009844772339882972}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.007125212479571257,
#    'nox_dollarPerkWh_adjustVSL': 0.002071248332497534,
#    'pm25_dollarPerkWh_adjustVSL': 0.007851634994252328}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.005316477471005142,
#    'nox_dollarPerkWh_adjustVSL': 0.001545461995435498,
#    'pm25_dollarPerkWh_adjustVSL': 0.005858497648621684}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.004448775340219109,
#    'nox_dollarPerkWh_adjustVSL': 0.0012932271888738734,
#    'pm25_dollarPerkWh_adjustVSL': 0.004902332420679334}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.003581073209433075,
#    'nox_dollarPerkWh_adjustVSL': 0.001040992382312249,
#    'pm25_dollarPerkWh_adjustVSL': 0.003946167192736984}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0028648585675464604,
#    'nox_dollarPerkWh_adjustVSL': 0.0008327939058497992,
#    'pm25_dollarPerkWh_adjustVSL': 0.003156933754189587}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.002148643925659845,
#    'nox_dollarPerkWh_adjustVSL': 0.0006245954293873495,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023677003156421903}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0014324292837732304,
#    'nox_dollarPerkWh_adjustVSL': 0.00041639695292489966,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015784668770947937}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0007162146418866153,
#    'nox_dollarPerkWh_adjustVSL': 0.00020819847646244989,
#    'pm25_dollarPerkWh_adjustVSL': 0.000789233438547397}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0,
# ...
#    'nox_dollarPerkWh_adjustVSL': 0.00072465422876406,
#    'pm25_dollarPerkWh_adjustVSL': 0.0035899934472580033}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0013944658067000341,
#    'nox_dollarPerkWh_adjustVSL': 0.0006958441845535852,
#    'pm25_dollarPerkWh_adjustVSL': 0.003447266246028225}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0011866170357678083,
#    'nox_dollarPerkWh_adjustVSL': 0.0005921267912515126,
#    'pm25_dollarPerkWh_adjustVSL': 0.002933442207553796}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0009787682648355828,
#    'nox_dollarPerkWh_adjustVSL': 0.0004884093979494399,
#    'pm25_dollarPerkWh_adjustVSL': 0.002419618169079367}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0009361811597048514,
#    'nox_dollarPerkWh_adjustVSL': 0.0004671582569750193,
#    'pm25_dollarPerkWh_adjustVSL': 0.002314338362770853}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0008935940545741199,
#    'nox_dollarPerkWh_adjustVSL': 0.0004459071160005986,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022090585564623383}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0008647186769691175,
#    'nox_dollarPerkWh_adjustVSL': 0.00043149818357164307,
#    'pm25_dollarPerkWh_adjustVSL': 0.002137675583799419}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0008358432993641149,
#    'nox_dollarPerkWh_adjustVSL': 0.0004170892511426875,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020662926111364994}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0008069679217591125,
#    'nox_dollarPerkWh_adjustVSL': 0.00040268031871373193,
#    'pm25_dollarPerkWh_adjustVSL': 0.00199490963847358}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.00077809254415411,
#    'nox_dollarPerkWh_adjustVSL': 0.00038827138628477634,
#    'pm25_dollarPerkWh_adjustVSL': 0.0019235266658106606}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0007492171665491076,
#    'nox_dollarPerkWh_adjustVSL': 0.0003738624538558208,
#    'pm25_dollarPerkWh_adjustVSL': 0.0018521436931477413}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.000706222113238707,
#    'nox_dollarPerkWh_adjustVSL': 0.0003524077450584689,
#    'pm25_dollarPerkWh_adjustVSL': 0.0017458553960012693}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0006632270599283063,
#    'nox_dollarPerkWh_adjustVSL': 0.000330953036261117,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016395670988547972}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0006202320066179057,
#    'nox_dollarPerkWh_adjustVSL': 0.0003094983274637651,
#    'pm25_dollarPerkWh_adjustVSL': 0.001533278801708325}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.000577236953307505,
#    'nox_dollarPerkWh_adjustVSL': 0.00028804361866641316,
#    'pm25_dollarPerkWh_adjustVSL': 0.001426990504561853}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0005342418999971045,
#    'nox_dollarPerkWh_adjustVSL': 0.0002665889098690613,
#    'pm25_dollarPerkWh_adjustVSL': 0.0013207022074153809}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0005172157472608775,
#    'nox_dollarPerkWh_adjustVSL': 0.000258092789483821,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012786117657958669}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0005001895945246505,
#    'nox_dollarPerkWh_adjustVSL': 0.0002495966690985808,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012365213241763526}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.00048316344178842344,
#    'nox_dollarPerkWh_adjustVSL': 0.00024110054871334045,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011944308825568384}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.00046613728905219644,
#    'nox_dollarPerkWh_adjustVSL': 0.0002326044283281002,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011523404409373244}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.00044911113631596945,
#    'nox_dollarPerkWh_adjustVSL': 0.00022410830794285995,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011102499993178101}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.00042200379646685753,
#    'nox_dollarPerkWh_adjustVSL': 0.00021058163364070563,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010432378020789283}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0003948964566177456,
#    'nox_dollarPerkWh_adjustVSL': 0.00019705495933855136,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009762256048400463}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0003677891167686337,
#    'nox_dollarPerkWh_adjustVSL': 0.0001835282850363971,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009092134076011643}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.00034068177691952173,
#    'nox_dollarPerkWh_adjustVSL': 0.0001700016107342428,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008422012103622822}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.00031357443707040976,
#    'nox_dollarPerkWh_adjustVSL': 0.00015647493643208848,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007751890131234001}},
#  ('MidCase',
#   'SRTVc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.019124945198742256,
#    'nox_dollarPerkWh_adjustVSL': 0.0027802748893221937,
#    'pm25_dollarPerkWh_adjustVSL': 0.007428081065680646}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.016622535355147627,
#    'nox_dollarPerkWh_adjustVSL': 0.002416488892623161,
#    'pm25_dollarPerkWh_adjustVSL': 0.006456151317144657}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.013831967726987957,
#    'nox_dollarPerkWh_adjustVSL': 0.0020108121692180682,
#    'pm25_dollarPerkWh_adjustVSL': 0.005372301803024355}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.01633076234752472,
#    'nox_dollarPerkWh_adjustVSL': 0.00237407260551509,
#    'pm25_dollarPerkWh_adjustVSL': 0.006342827407931942}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.015079931376386616,
#    'nox_dollarPerkWh_adjustVSL': 0.002192233969968544,
#    'pm25_dollarPerkWh_adjustVSL': 0.005857007775168293}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.015831335082136497,
#    'nox_dollarPerkWh_adjustVSL': 0.0023014687328988667,
#    'pm25_dollarPerkWh_adjustVSL': 0.006148851102370612}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.016582738787886374,
#    'nox_dollarPerkWh_adjustVSL': 0.00241070349582919,
#    'pm25_dollarPerkWh_adjustVSL': 0.0064406944295729305}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.014951414969241128,
#    'nox_dollarPerkWh_adjustVSL': 0.002173550991484715,
#    'pm25_dollarPerkWh_adjustVSL': 0.005807092322829665}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.013320091150595884,
#    'nox_dollarPerkWh_adjustVSL': 0.00193639848714024,
#    'pm25_dollarPerkWh_adjustVSL': 0.005173490216086399}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.010947971776960077,
#    'nox_dollarPerkWh_adjustVSL': 0.0015915533720061035,
#    'pm25_dollarPerkWh_adjustVSL': 0.0042521649614656876}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.008575852403324273,
#    'nox_dollarPerkWh_adjustVSL': 0.0012467082568719675,
#    'pm25_dollarPerkWh_adjustVSL': 0.0033308397068449766}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.007973877958977579,
#    'nox_dollarPerkWh_adjustVSL': 0.0011591966632836699,
#    'pm25_dollarPerkWh_adjustVSL': 0.003097034332470917}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.007371903514630885,
#    'nox_dollarPerkWh_adjustVSL': 0.0010716850696953725,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028632289580968573}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.006989713084080838,
#    'nox_dollarPerkWh_adjustVSL': 0.0010161244160069418,
#    'pm25_dollarPerkWh_adjustVSL': 0.002714787147092879}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.00660752265353079,
#    'nox_dollarPerkWh_adjustVSL': 0.000960563762318511,
#    'pm25_dollarPerkWh_adjustVSL': 0.0025663453360889005}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.006225332222980742,
#    'nox_dollarPerkWh_adjustVSL': 0.0009050031086300801,
#    'pm25_dollarPerkWh_adjustVSL': 0.002417903525084922}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0058431417924306945,
#    'nox_dollarPerkWh_adjustVSL': 0.0008494424549416494,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022694617140809436}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0054609513618806465,
#    'nox_dollarPerkWh_adjustVSL': 0.0007938818012532186,
#    'pm25_dollarPerkWh_adjustVSL': 0.002121019903076965}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0051950573104913664,
#    'nox_dollarPerkWh_adjustVSL': 0.0007552276484378486,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020177473159883642}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.004929163259102085,
#    'nox_dollarPerkWh_adjustVSL': 0.0007165734956224784,
#    'pm25_dollarPerkWh_adjustVSL': 0.001914474728899763}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.004663269207712805,
#    'nox_dollarPerkWh_adjustVSL': 0.0006779193428071084,
#    'pm25_dollarPerkWh_adjustVSL': 0.001811202141811162}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.004397375156323525,
#    'nox_dollarPerkWh_adjustVSL': 0.0006392651899917382,
#    'pm25_dollarPerkWh_adjustVSL': 0.001707929554722561}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.004131481104934244,
#    'nox_dollarPerkWh_adjustVSL': 0.0006006110371763681,
#    'pm25_dollarPerkWh_adjustVSL': 0.00160465696763396}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.004163781262490373,
#    'nox_dollarPerkWh_adjustVSL': 0.0006053066489044667,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016172022683534082}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.004196081420046503,
#    'nox_dollarPerkWh_adjustVSL': 0.0006100022606325654,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016297475690728563}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.004228381577602632,
#    'nox_dollarPerkWh_adjustVSL': 0.000614697872360664,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016422928697923044}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0042606817351587625,
#    'nox_dollarPerkWh_adjustVSL': 0.0006193934840887628,
#    'pm25_dollarPerkWh_adjustVSL': 0.001654838170511753}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.004292981892714892,
#    'nox_dollarPerkWh_adjustVSL': 0.0006240890958168614,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016673834712312011}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.004164730941810356,
#    'nox_dollarPerkWh_adjustVSL': 0.0006054447078394765,
#    'pm25_dollarPerkWh_adjustVSL': 0.001617571121435178}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.004036479990905821,
#    'nox_dollarPerkWh_adjustVSL': 0.0005868003198620917,
#    'pm25_dollarPerkWh_adjustVSL': 0.001567758771639155}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0039082290400012844,
#    'nox_dollarPerkWh_adjustVSL': 0.0005681559318847068,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015179464218431319}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.003779978089096749,
#    'nox_dollarPerkWh_adjustVSL': 0.0005495115439073219,
#    'pm25_dollarPerkWh_adjustVSL': 0.0014681340720471088}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0036517271381922133,
#    'nox_dollarPerkWh_adjustVSL': 0.0005308671559299371,
#    'pm25_dollarPerkWh_adjustVSL': 0.001418321722251086}},
#  ('MidCase',
#   'SRVCc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.008226296131836222,
#    'nox_dollarPerkWh_adjustVSL': 0.0024308903916151164,
#    'pm25_dollarPerkWh_adjustVSL': 0.007534057412737781}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.006866804179516115,
#    'nox_dollarPerkWh_adjustVSL': 0.0020291572335315706,
#    'pm25_dollarPerkWh_adjustVSL': 0.0062889660305669335}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0053806308723014585,
#    'nox_dollarPerkWh_adjustVSL': 0.0015899894288616747,
#    'pm25_dollarPerkWh_adjustVSL': 0.004927853466371618}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.005676781522458289,
#    'nox_dollarPerkWh_adjustVSL': 0.0016775026618403317,
#    'pm25_dollarPerkWh_adjustVSL': 0.00519908318693398}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.004677150637123422,
#    'nox_dollarPerkWh_adjustVSL': 0.0013821093189094796,
#    'pm25_dollarPerkWh_adjustVSL': 0.004283570742334238}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.005075105995263589,
#    'nox_dollarPerkWh_adjustVSL': 0.0014997060891802272,
#    'pm25_dollarPerkWh_adjustVSL': 0.004648038355447674}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0054730613534037555,
#    'nox_dollarPerkWh_adjustVSL': 0.0016173028594509747,
#    'pm25_dollarPerkWh_adjustVSL': 0.00501250596856111}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.00518894354237623,
#    'nox_dollarPerkWh_adjustVSL': 0.0015333453595208857,
#    'pm25_dollarPerkWh_adjustVSL': 0.004752296529713088}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.004904825731348704,
#    'nox_dollarPerkWh_adjustVSL': 0.0014493878595907964,
#    'pm25_dollarPerkWh_adjustVSL': 0.004492087090865064}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0038833726603514913,
#    'nox_dollarPerkWh_adjustVSL': 0.0011475460080479895,
#    'pm25_dollarPerkWh_adjustVSL': 0.003556588786649199}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.002861919589354279,
#    'nox_dollarPerkWh_adjustVSL': 0.0008457041565051824,
#    'pm25_dollarPerkWh_adjustVSL': 0.002621090482433334}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0025671501561145885,
#    'nox_dollarPerkWh_adjustVSL': 0.0007585990764642268,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023511257500730015}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.002272380722874898,
#    'nox_dollarPerkWh_adjustVSL': 0.0006714939964232713,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020811610177126688}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0020485724905277055,
#    'nox_dollarPerkWh_adjustVSL': 0.0006053581227739339,
#    'pm25_dollarPerkWh_adjustVSL': 0.0018761861365603264}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0018247642581805132,
#    'nox_dollarPerkWh_adjustVSL': 0.0005392222491245964,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016712112554079837}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0016009560258333205,
#    'nox_dollarPerkWh_adjustVSL': 0.00047308637547525896,
#    'pm25_dollarPerkWh_adjustVSL': 0.0014662363742556411}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0013771477934861282,
#    'nox_dollarPerkWh_adjustVSL': 0.00040695050182592153,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012612614931032985}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0011533395611389356,
#    'nox_dollarPerkWh_adjustVSL': 0.0003408146281765841,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010562866119509559}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0010836559957716238,
#    'nox_dollarPerkWh_adjustVSL': 0.00032022296617096756,
#    'pm25_dollarPerkWh_adjustVSL': 0.000992466883875545}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.001013972430404312,
#    'nox_dollarPerkWh_adjustVSL': 0.000299631304165351,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009286471558001339}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0009442888650370002,
#    'nox_dollarPerkWh_adjustVSL': 0.0002790396421597345,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008648274277247228}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0008746052996696883,
#    'nox_dollarPerkWh_adjustVSL': 0.00025844798015411794,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008010076996493119}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0008049217343023765,
#    'nox_dollarPerkWh_adjustVSL': 0.0002378563181485014,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007371879715739008}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0007568576426225846,
#    'nox_dollarPerkWh_adjustVSL': 0.000223653262876282,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006931684492514268}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0007087935509427925,
#    'nox_dollarPerkWh_adjustVSL': 0.0002094502076040626,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006491489269289529}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0006607294592630004,
#    'nox_dollarPerkWh_adjustVSL': 0.00019524715233184322,
#    'pm25_dollarPerkWh_adjustVSL': 0.000605129404606479}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0006126653675832084,
#    'nox_dollarPerkWh_adjustVSL': 0.0001810440970596238,
#    'pm25_dollarPerkWh_adjustVSL': 0.000561109882284005}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0005646012759034164,
#    'nox_dollarPerkWh_adjustVSL': 0.0001668410417874044,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005170903599615312}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0005022076711703472,
#    'nox_dollarPerkWh_adjustVSL': 0.00014840358077054772,
#    'pm25_dollarPerkWh_adjustVSL': 0.00045994714596667065}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0004398140664372782,
#    'nox_dollarPerkWh_adjustVSL': 0.0001299661197536911,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004028039319718102}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0003774204617042091,
#    'nox_dollarPerkWh_adjustVSL': 0.0001115286587368344,
#    'pm25_dollarPerkWh_adjustVSL': 0.00034566071797694967}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.00031502685697114004,
#    'nox_dollarPerkWh_adjustVSL': 9.309119771997775e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0002885175039820892}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.000252633252238071,
#    'nox_dollarPerkWh_adjustVSL': 7.46537367031211e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0002313742899872288}}}

# %%
# Combine them top to bottom
df_margDamages_EASIUR = pd.concat([df_margDamages_EASIUR_health], ignore_index=True)
df_margDamages_EASIUR

# %% [markdown]
# ### Step 5: Calculate End-use specific marginal damages
# **I used the total emissions column for each of the end uses for the following reasons:**
# - Most homes only have 1 of each end-use, so it is unlikely that the homes have a significant consumption values from different fuel types. Thus, the total consumption and total emissions column (sum of each dwelling units consumption by end-use for each fuel) is fine to use to calculate marginal damages (social cost)
# - We can visualize the emissions in 2 by 2 grid (CO2, PM25, SO2, NOx) with each appliance's heating fuel in a different shape or color.

# %% [markdown]
# ### Baseline Marginal Damages: WHOLE-HOME

# %%
print("""
-------------------------------------------------------------------------------------------------------
Step 5: Calculate End-use specific marginal damages
-------------------------------------------------------------------------------------------------------
      
-------------------------------------------------------------------------------------------------------
Baseline Marginal Damages: WHOLE-HOME
-------------------------------------------------------------------------------------------------------
""")

# calculate_marginal_damages(df, menu_mp, policy_scenario)
df_euss_am_baseline_home = calculate_marginal_damages(df=df_euss_am_baseline_home,
                                                      menu_mp=menu_mp,
                                                      policy_scenario='No Inflation Reduction Act',
                                                      drop_pollutant_damage_cols=True
                                                     )
df_euss_am_baseline_home

# %% [markdown]
# ### Electricity - Method 3: CEDM Marginal Emissions Factors and EASIUR (Use Cambium CO2e reductions as a proxy)

# %% [markdown]
# ### Step 5: Calculate End-use specific marginal damages

# %% [markdown]
# ### Baseline Marginal Damages: WHOLE-HOME

# %%
import numpy as np
import pandas as pd

# Constants
TD_LOSSES = 0.06
TD_LOSSES_MULTIPLIER = 1 / (1 - TD_LOSSES)
EQUIPMENT_SPECS = {'heating': 15, 'waterHeating': 12, 'clothesDrying': 13, 'cooking': 15}

def calculate_marginal_damages(df, menu_mp, policy_scenario, df_summary):
    """
    Calculate marginal damages of pollutants based on equipment usage, emissions, and policy scenarios.

    Parameters:
        df (DataFrame): Input data with emissions and consumption data.
        menu_mp (int): Measure package identifier.
        policy_scenario (str): Specifies the policy scenario ('No Inflation Reduction Act' or 'AEO2023 Reference Case').
        df_summary (DataFrame): Summary DataFrame to store aggregated results.

    Returns:
        DataFrame: Updated DataFrame with calculated marginal emissions and damages.
    """
    df_copy = df.copy()

    # Define policy-specific settings
    scenario_prefix, cambium_scenario, emis_electricity_lookup = define_scenario_settings(menu_mp, policy_scenario)

    # Precompute HDD adjustment factors by region and year
    hdd_factors_per_year = precompute_hdd_factors(df_copy)

    # Compute marginal damages based on grid scenario
    df_new_columns = calculate_damages_grid_scenario(
        df_copy, df_summary, menu_mp, TD_LOSSES_MULTIPLIER, emis_electricity_lookup,
        cambium_scenario, scenario_prefix, hdd_factors_per_year
    )

    # Handle overlapping columns
    overlapping_columns = df_new_columns.columns.intersection(df_copy.columns)
    if not overlapping_columns.empty:
        df_copy.drop(columns=overlapping_columns, inplace=True)

    # Merge newly calculated columns
    df_copy = df_copy.join(df_new_columns, how='left')
    return df_copy


def define_scenario_settings(menu_mp, policy_scenario):
    """
    Define scenario-specific settings based on menu and policy inputs.

    Parameters:
        menu_mp (int): Measure package identifier.
        policy_scenario (str): Policy scenario.

    Returns:
        Tuple: (scenario_prefix, cambium_scenario, emis_electricity_lookup)
    """
    if menu_mp == 0:
        return "baseline_", "MidCase", emis_preIRA_co2e_cambium21_lookup

    if policy_scenario == 'No Inflation Reduction Act':
        return f"preIRA_mp{menu_mp}_", "MidCase", emis_preIRA_co2e_cambium21_lookup

    if policy_scenario == 'AEO2023 Reference Case':
        return f"iraRef_mp{menu_mp}_", "MidCase", emis_IRA_co2e_cambium22_lookup

    raise ValueError("Invalid Policy Scenario! Choose 'No Inflation Reduction Act' or 'AEO2023 Reference Case'.")


def precompute_hdd_factors(df):
    """
    Precompute heating degree day (HDD) factors for each region and year.

    Parameters:
        df (DataFrame): Input data.

    Returns:
        dict: HDD factors mapped by year and region.
    """
    max_lifetime = max(EQUIPMENT_SPECS.values())
    hdd_factors_per_year = {}
    for year_label in range(2024, 2024 + max_lifetime + 1):
        # Map census_division to HDD factors
        hdd_factors = df['census_division'].map(
            lambda x: hdd_factor_lookup.get(x, hdd_factor_lookup['National']).get(year_label, 1.0)
        )
        hdd_factors_per_year[year_label] = hdd_factors
    return hdd_factors_per_year


def calculate_damages_grid_scenario(df, df_summary, menu_mp, td_losses_multiplier, emis_electricity_lookup,
                                    cambium_scenario, scenario_prefix, hdd_factors):
    """
    Calculate damages for electricity grid emissions under different scenarios.

    Parameters:
        df (DataFrame): Input DataFrame.
        df_summary (DataFrame): DataFrame to store summary results.
        menu_mp (int): Measure package identifier.
        td_losses_multiplier (float): Adjusted factor for transmission/distribution losses.
        emis_electricity_lookup (dict): Lookup for emissions data.
        cambium_scenario (str): Scenario identifier for emissions data.
        scenario_prefix (str): Prefix for column naming.
        hdd_factors (dict): Precomputed HDD adjustment factors.

    Returns:
        DataFrame: New columns with calculated emissions and damages.
    """
    new_columns_data = {}
    for category, lifetime in EQUIPMENT_SPECS.items():
        for mer_type in ['lrmer', 'srmer']:
            process_emissions_for_category(
                df, df_summary, menu_mp, td_losses_multiplier, emis_electricity_lookup,
                cambium_scenario, scenario_prefix, hdd_factors, new_columns_data,
                category, lifetime, mer_type
            )

    return pd.DataFrame(new_columns_data, index=df.index)


def process_emissions_for_category(df, df_summary, menu_mp, td_losses_multiplier, emis_electricity_lookup,
                                   cambium_scenario, scenario_prefix, hdd_factors, new_columns_data,
                                   category, lifetime, mer_type):
    """
    Process emissions and damages for a specific category and MER type.

    Parameters:
        df (DataFrame): Input DataFrame.
        df_summary (DataFrame): Summary DataFrame.
        category (str): Equipment category (e.g., heating, cooking).
        lifetime (int): Equipment lifetime in years.
        mer_type (str): Marginal emissions type ('lrmer' or 'srmer').
        hdd_factors (dict): Precomputed HDD factors.
    """
    lifetime_emissions = np.zeros(len(df))
    lifetime_damages = np.zeros(len(df))

    for year in range(1, lifetime + 1):
        year_label = year + 2023
        emis_col, damage_col = generate_column_names(scenario_prefix, year_label, category, mer_type)

        # Calculate electricity emissions
        emis_electricity = calculate_electricity_emissions(
            df, category, hdd_factors[year_label], td_losses_multiplier, emis_electricity_lookup,
            cambium_scenario, year_label, mer_type
        )

        # Calculate fossil fuel emissions
        fossil_fuel_emissions = calculate_fossil_fuel_emissions(
            df, category, hdd_factors[year_label], emission_factors=emis_factors_fossil_fuels
        )

        # Total emissions and damages
        total_emissions = fossil_fuel_emissions + emis_electricity
        total_damages = total_emissions * EPA_SCC_USD2023_PER_TON

        # Store results
        new_columns_data[emis_col] = np.round(total_emissions, 2)
        new_columns_data[damage_col] = np.round(total_damages, 2)
        lifetime_emissions += total_emissions
        lifetime_damages += total_damages

    # Lifetime and avoided emissions
    store_lifetime_and_avoided_emissions(df, df_summary, scenario_prefix, category, mer_type,
                                         lifetime_emissions, lifetime_damages, new_columns_data)


def generate_column_names(scenario_prefix, year_label, category, mer_type):
    """
    Generate column names for emissions and damages.

    Parameters:
        scenario_prefix (str): Scenario prefix.
        year_label (int): Year of calculation.
        category (str): Equipment category.
        mer_type (str): Marginal emissions type.

    Returns:
        tuple: Emission and damage column names.
    """
    emis_col = f'{scenario_prefix}{year_label}_{category}_tons_co2e_{mer_type}'
    damage_col = f'{scenario_prefix}{year_label}_{category}_damages_climate_{mer_type}'
    return emis_col, damage_col


def calculate_electricity_emissions(df, category, hdd_factor, td_losses_multiplier,
                                    emis_electricity_lookup, cambium_scenario, year_label, mer_type):
    """
    Calculate electricity emissions for a category.

    Returns:
        Series: Calculated emissions.
    """
    # Precompute emission factors for each gea_region
    emis_factors = df['gea_region'].map(
        lambda gea_region: emis_electricity_lookup.get(
            (cambium_scenario, gea_region), {}
        ).get(year_label, {}).get(f'{mer_type}_co2e', 0)
    )

    return (
        df[f'base_electricity_{category}_consumption'] *
        hdd_factor * td_losses_multiplier *
        emis_factors.fillna(0)
    )


def calculate_fossil_fuel_emissions(df, category, hdd_factor, emission_factors=emis_factors_fossil_fuels):
    """
    Calculate fossil fuel emissions for a category using the provided emission factors lookup dictionary.

    Parameters:
        df (DataFrame): Input DataFrame containing fuel consumption data.
        category (str): Equipment category (e.g., 'heating', 'cooking').
        hdd_factor (float or Series): Heating Degree Day adjustment factor.
        emission_factors (dict): Lookup dictionary for emission factors.

    Returns:
        Series: Combined fossil fuel emissions (in tons CO2e).
    """
    # Access emission factors from the lookup dictionary
    natural_gas_factor = emission_factors['naturalGas']['co2e']
    propane_factor = emission_factors['propane']['co2e']
    fuel_oil_factor = emission_factors['fuelOil']['co2e']

    # Calculate emissions for each fuel type
    emis_naturalGas = (
        df[f'base_naturalGas_{category}_consumption'] * hdd_factor * natural_gas_factor
    )
    emis_propane = (
        df[f'base_propane_{category}_consumption'] * hdd_factor * propane_factor
    )

    # Fuel oil is not used for cooking or clothes drying
    if category not in ['cooking', 'clothesDrying']:
        emis_fuelOil = (
            df[f'base_fuelOil_{category}_consumption'] * hdd_factor * fuel_oil_factor
        )
    else:
        emis_fuelOil = pd.Series(0, index=df.index)

    # Sum the emissions from all applicable fuel types
    total_emissions = (
        emis_naturalGas.fillna(0) +
        emis_propane.fillna(0) +
        emis_fuelOil.fillna(0)
    )

    return total_emissions


def store_lifetime_and_avoided_emissions(df, df_summary, scenario_prefix, category, mer_type,
                                         lifetime_emissions, lifetime_damages, new_columns_data):
    """
    Store lifetime and avoided emissions in the summary DataFrame and new columns.
    """
    lifetime_emissions_col = f'{scenario_prefix}{category}_lifetime_tons_co2e_{mer_type}'
    lifetime_damages_col = f'{scenario_prefix}{category}_lifetime_damages_climate_{mer_type}'

    new_columns_data[lifetime_emissions_col] = np.round(lifetime_emissions, 2)
    new_columns_data[lifetime_damages_col] = np.round(lifetime_damages, 2)

    df_summary[lifetime_emissions_col] = np.round(lifetime_emissions, 2)
    df_summary[lifetime_damages_col] = np.round(lifetime_damages, 2)

# %%
print("""
-------------------------------------------------------------------------------------------------------
Step 5: Calculate End-use specific marginal damages
-------------------------------------------------------------------------------------------------------
      
-------------------------------------------------------------------------------------------------------
Baseline Marginal Damages: WHOLE-HOME
-------------------------------------------------------------------------------------------------------
""")
# Make copies from scenario consumption to keep df smaller
print("\n", "Creating dataframe to store marginal damages calculations ...")
df_baseline_scenario_damages = df_euss_am_baseline_home.copy()

# calculate_marginal_damages(df, menu_mp, policy_scenario)
df_euss_am_baseline_home = calculate_marginal_damages(df=df_euss_am_baseline_home,
                                                      menu_mp=menu_mp,
                                                      policy_scenario='No Inflation Reduction Act',
                                                      df_summary=df_baseline_scenario_damages
                                                     )
df_euss_am_baseline_home
# Out:
# -------------------------------------------------------------------------------------------------------
# Step 5: Calculate End-use specific marginal damages
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# Baseline Marginal Damages: WHOLE-HOME
# -------------------------------------------------------------------------------------------------------
#
#
#  Creating dataframe to store marginal damages calculations ...
#         bldg_id  square_footage census_region     census_division  \
# 2           239          1690.0         South  East South Central
# 3           273          1690.0         South  East South Central
# 4           307          1220.0         South  East South Central
# 5           409          1220.0         South  East South Central
# 7           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 548905   548109          1690.0          West            Mountain
# 548907   548226          2176.0          West            Mountain
# 548908   548228          1690.0          West            Mountain
# 548910   548417           885.0          West            Mountain
# 548914   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone  \
# 2        East South Central                     Hot-Humid
# 3        East South Central                   Mixed-Humid
# 4        East South Central                     Hot-Humid
# 5        East South Central                     Hot-Humid
# 7        East South Central                   Mixed-Humid
# ...                     ...                           ...
# 548905       Mountain North                          Cold
# 548907       Mountain North                          Cold
# 548908       Mountain North                          Cold
# 548910       Mountain North                          Cold
# 548914       Mountain North                     Very Cold
#
#         reeds_balancing_area gea_region state                     city  ...  \
# 2                         90      SRSOc    AL    Not in a census Place  ...
# 3                         90      SRSOc    AL  In another census Place  ...
# 4                         90      SRSOc    AL    Not in a census Place  ...
# 5                         90      SRSOc    AL    Not in a census Place  ...
# 7                         89      SRSOc    AL  In another census Place  ...
# ...                      ...        ...   ...                      ...  ...
# 548905                    23      RMPAc    WY  In another census Place  ...
# 548907                    23      RMPAc    WY  In another census Place  ...
# 548908                    24      RMPAc    WY    Not in a census Place  ...
# 548910                    24      RMPAc    WY                   Casper  ...
# 548914                    21      NWPPc    WY  In another census Place  ...
#
#        baseline_2035_cooking_tons_co2e_srmer  \
# 2                                       0.03
# 3                                       0.43
# 4                                       0.43
# 5                                       0.03
# 7                                       0.30
# ...                                      ...
# 548905                                  0.31
# 548907                                  0.31
# 548908                                  0.31
# 548910                                  0.37
# 548914                                  0.03
#
#        baseline_2035_cooking_damages_climate_srmer  \
# 2                                             5.75
# 3                                            95.47
# 4                                            95.47
# 5                                             5.96
# 7                                            67.03
# ...                                            ...
# 548905                                       69.28
# 548907                                       69.28
# 548908                                       69.28
# 548910                                       83.10
# 548914                                        5.67
#
#        baseline_2036_cooking_tons_co2e_srmer  \
# 2                                       0.03
# 3                                       0.42
# 4                                       0.42
# 5                                       0.03
# 7                                       0.30
# ...                                      ...
# 548905                                  0.30
# 548907                                  0.30
# 548908                                  0.30
# 548910                                  0.36
# 548914                                  0.02
#
#        baseline_2036_cooking_damages_climate_srmer  \
# 2                                             5.66
# 3                                            94.00
# 4                                            94.00
# 5                                             5.87
# 7                                            66.00
# ...                                            ...
# 548905                                       67.07
# 548907                                       67.07
# 548908                                       67.07
# 548910                                       80.45
# 548914                                        5.48
#
#         baseline_2037_cooking_tons_co2e_srmer  \
# 2                                        0.02
# 3                                        0.41
# 4                                        0.41
# 5                                        0.03
# 7                                        0.29
# ...                                       ...
# 548905                                   0.30
# 548907                                   0.30
# 548908                                   0.30
# 548910                                   0.36
# 548914                                   0.02
#
#         baseline_2037_cooking_damages_climate_srmer  \
# 2                                              5.57
# 3                                             92.47
# 4                                             92.47
# 5                                              5.77
# 7                                             64.93
# ...                                             ...
# 548905                                        66.81
# 548907                                        66.81
# 548908                                        66.81
# 548910                                        80.13
# 548914                                         5.44
#
#        baseline_2038_cooking_tons_co2e_srmer  \
# 2                                       0.02
# 3                                       0.41
# 4                                       0.41
# 5                                       0.03
# 7                                       0.29
# ...                                      ...
# 548905                                  0.30
# 548907                                  0.30
# 548908                                  0.30
# 548910                                  0.36
# 548914                                  0.02
#
#        baseline_2038_cooking_damages_climate_srmer  \
# 2                                             5.48
# 3                                            90.96
# 4                                            90.96
# 5                                             5.68
# 7                                            63.87
# ...                                            ...
# 548905                                       66.54
# 548907                                       66.54
# 548908                                       66.54
# 548910                                       79.81
# 548914                                        5.40
#
#        baseline_cooking_lifetime_tons_co2e_srmer  \
# 2                                           0.40
# 3                                           6.62
# 4                                           6.62
# 5                                           0.41
# 7                                           4.65
# ...                                          ...
# 548905                                      4.91
# 548907                                      4.91
# 548908                                      4.91
# 548910                                      5.89
# 548914                                      0.40
#
#        baseline_cooking_lifetime_damages_climate_srmer
# 2                                                89.27
# 3                                              1481.71
# 4                                              1481.71
# 5                                                92.51
# 7                                              1040.35
# ...                                                ...
# 548905                                         1098.83
# 548907                                         1098.83
# 548908                                         1098.83
# 548910                                         1317.96
# 548914                                           89.23
#
# [270018 rows x 340 columns]

# %%
import unittest
import pandas as pd
import numpy as np

# Mock data and constants for testing
EQUIPMENT_SPECS = {'heating': 15, 'waterHeating': 12, 'clothesDrying': 13, 'cooking': 15}

emis_preIRA_co2e_cambium21_lookup = {
    ('MidCase', 'Region1'): {
        2024: {'lrmer_co2e': 0.5, 'srmer_co2e': 0.6},
        2025: {'lrmer_co2e': 0.4, 'srmer_co2e': 0.5},
    },
    ('MidCase', 'Region2'): {
        2024: {'lrmer_co2e': 0.3, 'srmer_co2e': 0.35},
        2025: {'lrmer_co2e': 0.25, 'srmer_co2e': 0.3},
    },
}

emis_IRA_co2e_cambium22_lookup = emis_preIRA_co2e_cambium21_lookup  # Using the same for simplicity

EPA_SCC_USD2023_PER_TON = 51  # Example value

emis_factors_fossil_fuels = {
    'naturalGas': {'co2e': 0.2},
    'propane': {'co2e': 0.25},
    'fuelOil': {'co2e': 0.3},
}

hdd_factor_lookup = {
    'Division1': {2024: 1.1, 2025: 1.0},
    'Division2': {2024: 0.9, 2025: 0.95},
    'National': {2024: 1.0, 2025: 1.0},
}

class TestMarginalDamagesCalculations(unittest.TestCase):
    def setUp(self):
        # Create a sample DataFrame for testing
        data = {
            'census_division': ['Division1', 'Division2'],
            'gea_region': ['Region1', 'Region2'],
        }
        
        # Add consumption data for all equipment categories
        for category in EQUIPMENT_SPECS.keys():
            data[f'base_electricity_{category}_consumption'] = [1000, 2000]
            data[f'base_naturalGas_{category}_consumption'] = [500, 600]
            data[f'base_propane_{category}_consumption'] = [300, 400]
            # Fuel oil is not used for 'cooking' and 'clothesDrying'
            if category not in ['cooking', 'clothesDrying']:
                data[f'base_fuelOil_{category}_consumption'] = [200, 300]
        
        self.df = pd.DataFrame(data)
        # Sample df_summary DataFrame
        self.df_summary = pd.DataFrame(index=self.df.index)

    # (Your test methods remain the same.)

    def test_define_scenario_settings(self):
        # Test with menu_mp = 0
        scenario_prefix, cambium_scenario, emis_electricity_lookup = define_scenario_settings(0, 'AEO2023 Reference Case')
        self.assertEqual(scenario_prefix, 'baseline_')
        self.assertEqual(cambium_scenario, 'MidCase')
        self.assertEqual(emis_electricity_lookup, emis_preIRA_co2e_cambium21_lookup)

        # Test with 'No Inflation Reduction Act' policy
        scenario_prefix, cambium_scenario, emis_electricity_lookup = define_scenario_settings(1, 'No Inflation Reduction Act')
        self.assertEqual(scenario_prefix, 'preIRA_mp1_')
        self.assertEqual(emis_electricity_lookup, emis_preIRA_co2e_cambium21_lookup)

        # Test with 'AEO2023 Reference Case' policy
        scenario_prefix, cambium_scenario, emis_electricity_lookup = define_scenario_settings(2, 'AEO2023 Reference Case')
        self.assertEqual(scenario_prefix, 'iraRef_mp2_')
        self.assertEqual(emis_electricity_lookup, emis_IRA_co2e_cambium22_lookup)

        # Test with an invalid policy scenario
        with self.assertRaises(ValueError):
            define_scenario_settings(1, 'Invalid Policy')

    def test_precompute_hdd_factors(self):
        hdd_factors = precompute_hdd_factors(self.df)
        # Check that the HDD factors are correctly computed
        self.assertIn(2024, hdd_factors)
        self.assertIn(2025, hdd_factors)

        np.testing.assert_array_almost_equal(
            hdd_factors[2024],
            pd.Series([1.1, 0.9], index=self.df.index)
        )
        np.testing.assert_array_almost_equal(
            hdd_factors[2025],
            pd.Series([1.0, 0.95], index=self.df.index)
        )

    def test_calculate_electricity_emissions(self):
        hdd_factor = pd.Series([1.1, 0.9], index=self.df.index)
        td_losses_multiplier = 1 / (1 - 0.06)
        year_label = 2024
        mer_type = 'lrmer'
        cambium_scenario = 'MidCase'

        emis_electricity = calculate_electricity_emissions(
            self.df, 'heating', hdd_factor, td_losses_multiplier,
            emis_preIRA_co2e_cambium21_lookup, cambium_scenario, year_label, mer_type
        )

        expected_emissions = pd.Series([
            1000 * 1.1 * td_losses_multiplier * 0.5,
            2000 * 0.9 * td_losses_multiplier * 0.3
        ], index=self.df.index)

        np.testing.assert_array_almost_equal(emis_electricity, expected_emissions)

    def test_calculate_fossil_fuel_emissions(self):
        hdd_factor = pd.Series([1.1, 0.9], index=self.df.index)

        emissions = calculate_fossil_fuel_emissions(
            self.df, 'heating', hdd_factor, emission_factors=emis_factors_fossil_fuels
        )

        expected_emissions = pd.Series([
            500 * 1.1 * 0.2 + 300 * 1.1 * 0.25 + 200 * 1.1 * 0.3,
            600 * 0.9 * 0.2 + 400 * 0.9 * 0.25 + 300 * 0.9 * 0.3
        ], index=self.df.index)

        np.testing.assert_array_almost_equal(emissions, expected_emissions)

    def test_process_emissions_for_category(self):
        new_columns_data = {}
        category = 'heating'
        lifetime = EQUIPMENT_SPECS[category]
        mer_type = 'lrmer'
        scenario_prefix = 'test_'
        cambium_scenario = 'MidCase'
        td_losses_multiplier = TD_LOSSES_MULTIPLIER

        hdd_factors = precompute_hdd_factors(self.df)

        process_emissions_for_category(
            self.df, self.df_summary, 1, td_losses_multiplier,
            emis_preIRA_co2e_cambium21_lookup, cambium_scenario,
            scenario_prefix, hdd_factors, new_columns_data,
            category, lifetime, mer_type
        )

        # Check that new_columns_data has expected keys
        expected_columns = []
        for year in range(1, lifetime + 1):
            year_label = year + 2023
            emis_col, damage_col = generate_column_names(scenario_prefix, year_label, category, mer_type)
            expected_columns.extend([emis_col, damage_col])

        # Add lifetime columns
        lifetime_emissions_col = f'{scenario_prefix}{category}_lifetime_tons_co2e_{mer_type}'
        lifetime_damages_col = f'{scenario_prefix}{category}_lifetime_damages_climate_{mer_type}'
        expected_columns.extend([lifetime_emissions_col, lifetime_damages_col])

        self.assertEqual(set(new_columns_data.keys()), set(expected_columns))

    def test_calculate_damages_grid_scenario(self):
        scenario_prefix = 'test_'
        cambium_scenario = 'MidCase'
        td_losses_multiplier = TD_LOSSES_MULTIPLIER
        hdd_factors = precompute_hdd_factors(self.df)

        df_new_columns = calculate_damages_grid_scenario(
            self.df, self.df_summary, 1, td_losses_multiplier,
            emis_preIRA_co2e_cambium21_lookup, cambium_scenario,
            scenario_prefix, hdd_factors
        )

        # Check that df_new_columns has expected columns
        expected_columns = []
        for category, lifetime in EQUIPMENT_SPECS.items():
            for mer_type in ['lrmer', 'srmer']:
                for year in range(1, lifetime + 1):
                    year_label = year + 2023
                    emis_col, damage_col = generate_column_names(scenario_prefix, year_label, category, mer_type)
                    expected_columns.extend([emis_col, damage_col])

                # Lifetime columns
                lifetime_emissions_col = f'{scenario_prefix}{category}_lifetime_tons_co2e_{mer_type}'
                lifetime_damages_col = f'{scenario_prefix}{category}_lifetime_damages_climate_{mer_type}'
                expected_columns.extend([lifetime_emissions_col, lifetime_damages_col])

        self.assertEqual(set(df_new_columns.columns), set(expected_columns))

    def test_calculate_marginal_damages(self):
        # Run the full calculation and check outputs
        menu_mp = 1
        policy_scenario = 'No Inflation Reduction Act'

        df_result = calculate_marginal_damages(self.df, menu_mp, policy_scenario, self.df_summary)

        # Expected columns
        expected_columns = set(self.df.columns)
        scenario_prefix = 'preIRA_mp1_'
        for category, lifetime in EQUIPMENT_SPECS.items():
            for mer_type in ['lrmer', 'srmer']:
                for year in range(1, lifetime + 1):
                    year_label = year + 2023
                    emis_col, damage_col = generate_column_names(scenario_prefix, year_label, category, mer_type)
                    expected_columns.update([emis_col, damage_col])

                # Lifetime columns
                lifetime_emissions_col = f'{scenario_prefix}{category}_lifetime_tons_co2e_{mer_type}'
                lifetime_damages_col = f'{scenario_prefix}{category}_lifetime_damages_climate_{mer_type}'
                expected_columns.update([lifetime_emissions_col, lifetime_damages_col])

        self.assertEqual(set(df_result.columns), expected_columns)

        # Check that df_summary has the lifetime columns
        expected_summary_columns = []
        for category, lifetime in EQUIPMENT_SPECS.items():
            for mer_type in ['lrmer', 'srmer']:
                lifetime_emissions_col = f'{scenario_prefix}{category}_lifetime_tons_co2e_{mer_type}'
                lifetime_damages_col = f'{scenario_prefix}{category}_lifetime_damages_climate_{mer_type}'
                expected_summary_columns.extend([lifetime_emissions_col, lifetime_damages_col])

        self.assertEqual(set(self.df_summary.columns), set(expected_summary_columns))

# if __name__ == '__main__':
#     unittest.main(argv=['first-arg-is-ignored'], exit=False)
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False, verbosity=2)
# Out:
# test_calculate_damages_grid_scenario (__main__.TestMarginalDamagesCalculations.test_calculate_damages_grid_scenario) ... ok
# test_calculate_electricity_emissions (__main__.TestMarginalDamagesCalculations.test_calculate_electricity_emissions) ... ok
# test_calculate_fossil_fuel_emissions (__main__.TestMarginalDamagesCalculations.test_calculate_fossil_fuel_emissions) ... ok
# test_calculate_marginal_damages (__main__.TestMarginalDamagesCalculations.test_calculate_marginal_damages) ... ok
# test_define_scenario_settings (__main__.TestMarginalDamagesCalculations.test_define_scenario_settings) ... ok
# test_precompute_hdd_factors (__main__.TestMarginalDamagesCalculations.test_precompute_hdd_factors) ... ok
# test_process_emissions_for_category (__main__.TestMarginalDamagesCalculations.test_process_emissions_for_category) ... ok
#
# ----------------------------------------------------------------------
# Ran 7 tests in 0.231s
#
# OK

# %% [markdown]
# ## Private Perspective: Annual Energy Costs

# %% [markdown]
# ### Step 1: Obtain Level Energy Fuel Cost Data from the EIA
# **Data Sources for Excel workbook containing state average Residential fuel cost for each fuel in 2018**
# - EIA State Electricity Price: https://www.eia.gov/electricity/state/archive/2018/
# - EIA Natural Gas Prices: https://www.eia.gov/dnav/ng/ng_pri_sum_dcu_SPA_a.htm
# - Propane and Fuel Oil: EIA March 2023 Short Term Energy Outlook
#     - https://www.eia.gov/outlooks/steo/pdf/wf01.pdf
#     - Table WF01: Average Consumer Prices and Expenditures for Heating Fuels During the Winter
#     - US Average: 2018-2019 Data

# %%
print("""
-------------------------------------------------------------------------------------------------------
Private Perspective: Annual Energy Costs
-------------------------------------------------------------------------------------------------------
- Step 1: Obtain Level Energy Fuel Cost Data from the EIA
- Step 2: Calculate Annual Operating (Fuel) Costs
-------------------------------------------------------------------------------------------------------
      
-------------------------------------------------------------------------------------------------------
Step 1: Obtain Level Energy Fuel Cost Data from the EIA
-------------------------------------------------------------------------------------------------------
**Data Sources for Excel workbook containing state average Residential fuel cost for each fuel in 2018**
- EIA State Electricity Price: https://www.eia.gov/electricity/state/archive/2018/
- EIA Natural Gas Prices: https://www.eia.gov/dnav/ng/ng_pri_sum_dcu_SPA_a.htm
- Propane and Fuel Oil: EIA March 2023 Short Term Energy Outlook
    - https://www.eia.gov/outlooks/steo/pdf/wf01.pdf
    - Table WF01: Average Consumer Prices and Expenditures for Heating Fuels During the Winter
    - US Average: 2018-2019 Data
-------------------------------------------------------------------------------------------------------
""")

filename = 'fuel_prices_nominal.csv'
relative_path = os.path.join(r"fuel_prices", filename)
file_path = os.path.join(project_root, relative_path)
df_fuelPrices_perkWh = pd.read_csv(file_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")

# New units for the converted and inflated prices below
# $USD-2023, PREVIOUSLY USED $USD-2021
df_fuelPrices_perkWh['units'] = 'USD2022 per kWh'

years = ['2018', '2019', '2020', '2021', '2022']

# Take dataframe with nominal prices in their base units and convert to $/kWh equivalent
# https://www.eia.gov/energyexplained/units-and-calculators/british-thermal-units.php
for year in years:
    for index, row in df_fuelPrices_perkWh.iterrows():
        
        # Propane: (dollars per gallon) * (1 gallon propane/91,452 BTU) * (3412 BTU/1 kWh)
        if row['fuel_type'] == 'propane':
            df_fuelPrices_perkWh.at[index, f'{year}_fuelPrice_perkWh'] = row[f'{year}_nominal_unit_price'] * (1/91452) * (3412/1)
        
        # Fuel Oil: (dollars/gallon) * (1 gallon heating oil/138,500 BTU) * (3412 BTU/1 kWh)
        elif row['fuel_type'] == 'fuelOil':
            df_fuelPrices_perkWh.at[index, f'{year}_fuelPrice_perkWh'] = row[f'{year}_nominal_unit_price'] * (1/138500) * (3412/1)
        
        # Natural Gas: (dollars/cf) * (thousand cf/1000 cf) * (1 cf natural gas/1039 BTU) * (3412 BTU/1 kWh)
        elif row['fuel_type'] == 'naturalGas':
            df_fuelPrices_perkWh.at[index, f'{year}_fuelPrice_perkWh'] = row[f'{year}_nominal_unit_price'] * (1/1000) * (1/1039) * (3412/1)
        
        # Electricity: convert cents per kWh to $ per kWh
        elif row['fuel_type'] == 'electricity':
            df_fuelPrices_perkWh.at[index, f'{year}_fuelPrice_perkWh'] = row[f'{year}_nominal_unit_price'] / 100

# Convert nominal dollars to real 2022 US dollars (USD2022)
# $USD-2023, PREVIOUSLY USED $USD-2021
df_fuelPrices_perkWh['2018_fuelPrice_perkWh'] = df_fuelPrices_perkWh['2018_fuelPrice_perkWh'] * cpi_ratio_2023_2018
df_fuelPrices_perkWh['2019_fuelPrice_perkWh'] = df_fuelPrices_perkWh['2019_fuelPrice_perkWh'] * cpi_ratio_2023_2019
df_fuelPrices_perkWh['2020_fuelPrice_perkWh'] = df_fuelPrices_perkWh['2020_fuelPrice_perkWh'] * cpi_ratio_2023_2020
df_fuelPrices_perkWh['2021_fuelPrice_perkWh'] = df_fuelPrices_perkWh['2021_fuelPrice_perkWh'] * cpi_ratio_2023_2021
df_fuelPrices_perkWh['2022_fuelPrice_perkWh'] = df_fuelPrices_perkWh['2022_fuelPrice_perkWh'] * cpi_ratio_2023_2022

# Original dictionary mapping census divisions to states
map_states_census_divisions = {
    "New England": ["CT", "ME", "MA", "NH", "RI", "VT"],
    "Middle Atlantic": ["NJ", "NY", "PA"],
    "East North Central": ["IN", "IL", "MI", "OH", "WI"],
    "West North Central": ["IA", "KS", "MN", "MO", "NE", "ND", "SD"],
    "South Atlantic": ["DE", "DC", "FL", "GA", "MD", "NC", "SC", "VA", "WV"],
    "East South Central": ["AL", "KY", "MS", "TN"],
    "West South Central": ["AR", "LA", "OK", "TX"],
    "Mountain": ["AZ", "CO", "ID", "NM", "MT", "UT", "NV", "WY"],
    "Pacific": ["AK", "CA", "HI", "OR", "WA"]
}

# Reverse the mapping to create a state-to-census-division map
state_to_census_division = {}
for division, states in map_states_census_divisions.items():
    for state in states:
        state_to_census_division[state] = division

# Function to map location to census division
def map_location_to_census_division(location):
    if location in state_to_census_division:
        return state_to_census_division[location]
    return location

# Apply the function to map locations using .loc
df_fuelPrices_perkWh.loc[:, 'census_division'] = df_fuelPrices_perkWh['location_map'].apply(map_location_to_census_division)
# print(df_fuelPrices_perkWh)

# %%
# Project Fuel Prices from 2022 to 2050
filename = 'aeo_projections_2022_2050.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_fuelPrices_projection_factors = pd.read_excel(io=file_path, sheet_name='fuel_price_factors_2022_2050')

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
# print(df_fuelPrices_projection_factors)

# Convert the factors dataframe into a lookup dictionary including policy_scenario
factor_dict = df_fuelPrices_projection_factors.set_index(['region', 'fuel_type', 'policy_scenario']).to_dict('index')
# print(factor_dict)

# %%
# Pre-IRA policy_scenario: No Inflation Reduction Act
# Pass the desired policy_scenario as a parameter when applying the function
preIRA_projected_prices_df = df_fuelPrices_perkWh.apply(lambda row: project_future_prices(row, factor_dict, 'No Inflation Reduction Act'), axis=1)

# Concatenate the projected prices with the original DataFrame
df_fuelPrices_perkWh_preIRA = pd.concat([df_fuelPrices_perkWh, preIRA_projected_prices_df], axis=1)

# Create Fuel Price Lookup with the policy_scenario included
preIRA_fuel_price_lookup = create_fuel_price_lookup(df_fuelPrices_perkWh_preIRA, 'No Inflation Reduction Act')
# print(preIRA_fuel_price_lookup)

# %%
# IRA-Reference policy_scenario: AEO2023 Reference Case
# Pass the desired policy_scenario as a parameter when applying the function
iraRef_projected_prices_df = df_fuelPrices_perkWh.apply(lambda row: project_future_prices(row, factor_dict, 'AEO2023 Reference Case'), axis=1)

# Concatenate the projected prices with the original DataFrame
df_fuelPrices_perkWh_iraRef = pd.concat([df_fuelPrices_perkWh, iraRef_projected_prices_df], axis=1)

# Create Fuel Price Lookup with the policy_scenario included
iraRef_fuel_price_lookup = create_fuel_price_lookup(df_fuelPrices_perkWh_iraRef, 'AEO2023 Reference Case')
# print(iraRef_fuel_price_lookup)

# %% [markdown]
# ### Step 2: Calculate Annual Operating (Fuel) Costs

# %% [markdown]
# ### Baseline Fuel Cost: WHOLE-HOME

# %%
print("""
-------------------------------------------------------------------------------------------------------
Step 2: Calculate Annual Operating (Fuel) Costs
-------------------------------------------------------------------------------------------------------
- Create a mapping dictionary for fuel types
- Create new merge columns to ensure a proper match.
- Merge df_copy with df_fuel_prices to get fuel prices for electricity, natural gas, propane, and fuel oil
- Calculate the per kWh fuel costs for each fuel type and region
- Calculate the baseline fuel cost 
-------------------------------------------------------------------------------------------------------
""")
# calculate_annual_fuelCost(df, menu_mp, policy_scenario, drop_fuel_cost_columns)
df_euss_am_baseline_home = calculate_annual_fuelCost(df=df_euss_am_baseline_home,
                                                     menu_mp=menu_mp,
                                                     policy_scenario='No Inflation Reduction Act',
                                                     drop_fuel_cost_columns=False
                                                     )
df_euss_am_baseline_home

# %% [markdown]
# ## Area Median Income Data Used to determine LMI Designation and IRA Rebates Eligibility/Amount

# %% [markdown]
# ### PUMA Median Income

# %%
# Collect Area Median Income Data at PUMA-resolution
filename = "nhgis0003_ds261_2022_puma.csv"
relative_path = os.path.join(r"equity_data", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_puma_medianIncome = pd.read_csv(file_path, encoding='ISO-8859-1')
# df_puma_medianIncome = df_puma_medianIncome.drop(0)
df_puma_medianIncome = df_puma_medianIncome.reset_index(drop=True)

cols_interest = ['GISJOIN', 'STUSAB', 'PUMAA', 'NAME_E', 'AP2PE001', 'AP2PM001']
df_puma_medianIncome = df_puma_medianIncome[cols_interest]
df_puma_medianIncome = df_puma_medianIncome.rename(columns={"GISJOIN": "gis_joinID_puma", "STUSAB": "state_abbrev", "PUMAA": "puma_code", "NAME_E": "name_estimate", "AP2PE001": "median_income_USD2022", "AP2PM001": "median_income_USD2022_marginOfError"})
df_puma_medianIncome['median_income_USD2023'] = round((df_puma_medianIncome['median_income_USD2022'] * cpi_ratio_2023_2022), 2)
df_puma_medianIncome

# %% [markdown]
# ### County Median Income

# %%
# Collect Area Median Income Data at PUMA-resolution
filename = "nhgis0005_ds261_2022_county.csv"
relative_path = os.path.join(r"equity_data", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_county_medianIncome = pd.read_csv(file_path, encoding='ISO-8859-1')
# df_county_medianIncome = df_county_medianIncome.drop(0)
df_county_medianIncome = df_county_medianIncome.reset_index(drop=True)

cols_interest = ['GISJOIN', 'STUSAB', 'COUNTYA', 'NAME_E', 'AP2PE001', 'AP2PM001']
df_county_medianIncome = df_county_medianIncome[cols_interest]
df_county_medianIncome = df_county_medianIncome.rename(columns={"GISJOIN": "gis_joinID_county", "STUSAB": "state_abbrev", "COUNTYA": "county_code", "NAME_E": "name_estimate", "AP2PE001": "median_income_USD2022", "AP2PM001": "median_income_USD2022_marginOfError"})
df_county_medianIncome['median_income_USD2023'] = round((df_county_medianIncome['median_income_USD2022'] * cpi_ratio_2023_2022), 2)
df_county_medianIncome

# %% [markdown]
# ### State Median Income

# %%
# Collect Area Median Income Data at PUMA-resolution
filename = "nhgis0004_ds261_2022_state.csv"
relative_path = os.path.join(r"equity_data", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_state_medianIncome = pd.read_csv(file_path, encoding='ISO-8859-1')
# df_state_medianIncome = df_state_medianIncome.drop(0)
df_state_medianIncome = df_state_medianIncome.reset_index(drop=True)

cols_interest = ['GISJOIN', 'STUSAB','STATEA', 'NAME_E', 'AP2PE001', 'AP2PM001']
df_state_medianIncome = df_state_medianIncome[cols_interest]
df_state_medianIncome = df_state_medianIncome.rename(columns={"GISJOIN": "gis_joinID_state", "STUSAB": "state_abbrev", "STATEA": "state_code", "NAME_E": "name_estimate", "AP2PE001": "median_income_USD2022", "AP2PM001": "median_income_USD2022_marginOfError"})
df_state_medianIncome['median_income_USD2023'] = round((df_state_medianIncome['median_income_USD2022'] * cpi_ratio_2023_2022), 2)
df_state_medianIncome

# %% [markdown]
# ### Adjustment Factors for Construction:
# #### RSMeans City Cost Index
# #### Consumer Price Index for All Urban Consumers (CPI, CPI-U)

# %%
# Adjust for regional cost differences with RSMeans
filename = "rsMeans_cityCostIndex.csv"
relative_path = os.path.join(r"inflation_data", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_rsMeans_cityCostIndex = pd.read_csv(file_path)

df_rsMeans_cityCostIndex = pd.DataFrame({
    'State': df_rsMeans_cityCostIndex['State'],
    'City': df_rsMeans_cityCostIndex['City'],
    'Material': (df_rsMeans_cityCostIndex['Material']).round(2),
    'Installation': (df_rsMeans_cityCostIndex['Installation']).round(2),
    'Average': (df_rsMeans_cityCostIndex['Average']).round(2),
})
df_rsMeans_cityCostIndex

# %% [markdown]
# # Model Runtime

# %%
# Get the current datetime again
end_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Calculate the elapsed time
elapsed_time = datetime.strptime(end_time, "%Y-%m-%d_%H-%M-%S") - datetime.strptime(start_time, "%Y-%m-%d_%H-%M-%S")

# Format the elapsed time
elapsed_seconds = elapsed_time.total_seconds()
elapsed_minutes = int(elapsed_seconds // 60)
elapsed_seconds = int(elapsed_seconds % 60)

# Print the elapsed time
print(f"The code took {elapsed_minutes} minutes and {elapsed_seconds} seconds to execute.")
