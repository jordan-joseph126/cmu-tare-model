# %%
# Set columns in display
# pd.set_option('display.max_columns', None)
# pd.reset_option('display.max_columns') # Reset options to default

# Set rows in display
# pd.set_option('display.max_rows', None)
# pd.reset_option('display.max_rows') # Reset options to default

# %% [markdown]
# # Load Util File with TARE Model Functions

# %%
import os

# Measure Package 0: Baseline
menu_mp = 0
input_mp = 'baseline'

# Get the current working directory of the project
project_root = os.path.abspath(os.getcwd())
print(f"Project root directory: {project_root}")

# Relative path to the file from the project root
relative_path = r"tare_model_functions_v1.5.1.ipynb"

# Construct the absolute path to the file
file_path = os.path.join(project_root, relative_path)
print(f"File path: {file_path}")

# Run the notebook and import variables
if os.path.exists(relative_path):
    get_ipython().run_line_magic('run', f'-i "{relative_path}"')
    print("Loaded All TARE Model Functions")
else:
    print(f"File not found: {relative_path}")
# Out:
# Project root directory: c:\Users\14128\Research\cmu-tare-model
# File path: c:\Users\14128\Research\cmu-tare-model\tare_model_functions_v1.5.1.ipynb
# Loaded All TARE Model Functions

# %%
# Storing Result Outputs in output_results folder
relative_path = r"output_results"
output_folder_path = os.path.join(project_root, relative_path)
print(f"Result outputs will be exported here: {output_folder_path}")
# Out:
# Result outputs will be exported here: c:\Users\14128\Research\cmu-tare-model\output_results

# %% [markdown]
# # Simulate Residential Energy Consumption using NREL End-Use Savings Shapes
# - Filter EUSS Data: Only occupied units and Single Family Homes

# %%
# The ``inline`` flag will use the appropriate backend to make figures appear inline in the notebook.  
# %matplotlib inline

import pandas as pd
import numpy as np

# `plt` is an alias for the `matplotlib.pyplot` module
import matplotlib.pyplot as plt

# import seaborn library (wrapper of matplotlib)
import seaborn as sns
sns.set(style="darkgrid")

# For regex, import re
import re

from datetime import datetime

# Get the current datetime
# Start the timer
start_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# %%
print("""
-------------------------------------------------------------------------------------------------------
Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
Let's start by reading the data from the NREL EUSS Database.

Make sure that the zipped folders stay organized as they are once unzipped.
If changes are made to the file path, then the program will not run properly.
-------------------------------------------------------------------------------------------------------

-------------------------------------------------------------------------------------------------------
BASELINE (Measure Package 0)
-------------------------------------------------------------------------------------------------------
""")

# Measure Package 0: Baseline
menu_mp = 0
input_mp = 'baseline'

filename = "baseline_metadata_and_annual_results.csv"
relative_path = os.path.join(r"euss_data\resstock_amy2018_release_1.1\state", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")

print("""
-------------------------------------------------------------------------------------------------------
Data Filters: Only occupied units and Single Family Homes
-------------------------------------------------------------------------------------------------------
""")

# Fix DtypeWarning error in columns:
# 'in.neighbors', 'in.geometry_stories_low_rise', 'in.iso_rto_region', 'in.pv_orientation', 'in.pv_system_size'
columns_to_string = {11: str, 61: str, 121: str, 103: str, 128: str, 129: str}
df_euss_am_baseline = pd.read_csv(file_path, dtype=columns_to_string)
occupancy_filter = df_euss_am_baseline['in.vacancy_status'] == 'Occupied'
df_euss_am_baseline = df_euss_am_baseline.loc[occupancy_filter]

# Filter for single family home building type
house_type_list = ['Single-Family Attached', 'Single-Family Detached']
house_type_filter = df_euss_am_baseline['in.geometry_building_type_recs'].isin(house_type_list)
df_euss_am_baseline = df_euss_am_baseline.loc[house_type_filter]
# df_euss_am_baseline
# Out:
# -------------------------------------------------------------------------------------------------------
# Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
# Let's start by reading the data from the NREL EUSS Database.
#
# Make sure that the zipped folders stay organized as they are once unzipped.
# If changes are made to the file path, then the program will not run properly.
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# BASELINE (Measure Package 0)
# -------------------------------------------------------------------------------------------------------
#
# Retrieved data for filename: baseline_metadata_and_annual_results.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\euss_data\resstock_amy2018_release_1.1\state\baseline_metadata_and_annual_results.csv
#
# -------------------------------------------------------------------------------------------------------
# Data Filters: Only occupied units and Single Family Homes
# -------------------------------------------------------------------------------------------------------

# %%
# # Make a copy of the dataframe
# df_euss_am_baseline = df_euss_am_baseline.copy()

# Choose between national or sub-national level analysis
menu_state = get_menu_choice(menu_prompt, {'N', 'Y'})   # This code is only run in baseline

# National Level 
if menu_state == 'N':
    print("You chose to analyze all of the United States.")
    input_state = 'National'
    location_id = 'National'

# Filter down to state or city
else:
    input_state = get_state_choice(df_euss_am_baseline)    
    print(f"You chose to filter for: {input_state}")

    location_id = str(input_state)
    print(f"Location ID is: {location_id}")


    state_filter = df_euss_am_baseline['in.state'].eq(input_state)
    df_euss_am_baseline = df_euss_am_baseline.loc[state_filter]

    print(city_prompt)
    print(df_euss_am_baseline['in.city'].value_counts())

    menu_city = get_menu_choice(city_menu_prompt, {'N', 'Y'})

    # Filter for the entire selected state
    if menu_city == 'N':
        print(f"You chose to analyze all of state: {input_state}")
        
        location_id = str(input_state)
        print(f"Location ID is: {location_id}")
        
    # Filter to a city within the selected state
    else:
        input_cityFilter = get_city_choice(df_euss_am_baseline, input_state)
        print(f"You chose to filter for: {input_state}, {input_cityFilter}")

        location_id = input_cityFilter.replace(', ', '_').strip()
        print(f"Location ID is: {location_id}")

        city_filter = df_euss_am_baseline['in.city'].eq(f"{input_state}, {input_cityFilter}")
        df_euss_am_baseline = df_euss_am_baseline.loc[city_filter]

# Display the filtered dataframe
df_euss_am_baseline
# Out:
# You chose to analyze all of the United States.
#         bldg_id  upgrade      weight  applicability  in.sqft  \
# 2           239        0  242.131013           True   1690.0
# 3           273        0  242.131013           True   1690.0
# 4           307        0  242.131013           True   1220.0
# 5           409        0  242.131013           True   1220.0
# 7           517        0  242.131013           True   1220.0
# ...         ...      ...         ...            ...      ...
# 548907   548226        0  242.131013           True   2176.0
# 548908   548228        0  242.131013           True   1690.0
# 548910   548417        0  242.131013           True    885.0
# 548914   549740        0  242.131013           True   1220.0
# 548915   549938        0  242.131013           True    885.0
#
#                       in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# 2       Non-CBSA East South Central                               3A
# 3       Non-CBSA East South Central                               3A
# 4       Non-CBSA East South Central                               3A
# 5       Non-CBSA East South Central                               3A
# 7       Non-CBSA East South Central                               3A
# ...                             ...                              ...
# 548907            Non-CBSA Mountain                               6B
# 548908            Non-CBSA Mountain                               6B
# 548910            Non-CBSA Mountain                               6B
# 548914            Non-CBSA Mountain                               7B
# 548915            Non-CBSA Mountain                               6B
#
#        in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# 2                                              3A                     Hour20
# 3                                              3A                     Hour12
# 4                                              3A                      Hour0
# 5                                              3A                     Hour20
# 7                                              3A                      Hour1
# ...                                           ...                        ...
# 548907                                         6B                      Hour3
# 548908                                         6B                      Hour6
# 548910                                         6B                     Hour18
# 548914                                         7B                      Hour4
# 548915                                         6B                      Hour2
#
#         in.bedrooms  ...  \
# 2                 3  ...
# 3                 3  ...
# 4                 4  ...
# 5                 2  ...
# 7                 3  ...
# ...             ...  ...
# 548907            4  ...
# 548908            4  ...
# 548910            2  ...
# 548914            2  ...
# 548915            2  ...
#
#        out.emissions.natural_gas.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# 2                                              215.943534
# 3                                                0.000000
# 4                                                0.000000
# 5                                             1642.477930
# 7                                                0.000000
# ...                                                   ...
# 548907                                       15324.356044
# 548908                                        8192.601682
# 548910                                        5212.758359
# 548914                                           0.000000
# 548915                                        9625.513133
#
#        out.emissions.propane.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# 2                                                0.000000
# 3                                                0.000000
# 4                                                0.000000
# 5                                                0.000000
# 7                                                0.000000
# ...                                                   ...
# 548907                                           0.000000
# 548908                                           0.000000
# 548910                                           0.000000
# 548914                                         268.627834
# 548915                                           0.000000
#
#        out.emissions.electricity.lrmer_mid_case_15_2025_start.co2e_kg  \
# 2                                             8773.384074
# 3                                            11296.731129
# 4                                             8750.011820
# 5                                             5725.103641
# 7                                             8932.439414
# ...                                                   ...
# 548907                                        2313.298407
# 548908                                        1889.439924
# 548910                                        2112.907195
# 548914                                       11423.104685
# 548915                                        1109.233379
#
#        out.emissions.fuel_oil.lrmer_mid_case_15_2025_start.co2e_kg  \
# 2                                                     0.0
# 3                                                     0.0
# 4                                                     0.0
# 5                                                     0.0
# 7                                                     0.0
# ...                                                   ...
# 548907                                                0.0
# 548908                                                0.0
# 548910                                                0.0
# 548914                                                0.0
# 548915                                                0.0
#
#        out.emissions.natural_gas.lrmer_mid_case_15_2025_start.co2e_kg  \
# 2                                              215.943534
# 3                                                0.000000
# 4                                                0.000000
# 5                                             1642.477930
# 7                                                0.000000
# ...                                                   ...
# 548907                                       15324.356044
# 548908                                        8192.601682
# 548910                                        5212.758359
# 548914                                           0.000000
# 548915                                        9625.513133
#
#        out.emissions.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# 2                                                0.000000
# 3                                                0.000000
# 4                                                0.000000
# 5                                                0.000000
# 7                                                0.000000
# ...                                                   ...
# 548907                                           0.000000
# 548908                                           0.000000
# 548910                                           0.000000
# 548914                                         268.627834
# 548915                                           0.000000
#
#        out.emissions.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# 2                                             3565.038262
# 3                                             4339.903757
# 4                                             3345.187937
# 5                                             3784.993820
# 7                                             3441.414837
# ...                                                   ...
# 548907                                       16802.023908
# 548908                                        9394.122057
# 548910                                        6546.826589
# 548914                                        7173.561517
# 548915                                       10320.128613
#
#        out.emissions.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# 2                                             6416.193347
# 3                                             8193.678510
# 4                                             6249.625611
# 5                                             5489.549041
# 7                                             6415.303853
# ...                                                   ...
# 548907                                       16545.095582
# 548908                                        9195.903552
# 548910                                        6318.763521
# 548914                                        5931.433285
# 548915                                       10198.241539
#
#        out.emissions.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# 2                                             5755.373221
# 3                                             7254.665194
# 4                                             5587.946834
# 5                                             5164.458936
# 7                                             5721.073473
# ...                                                   ...
# 548907                                       16472.920871
# 548908                                        9129.578822
# 548910                                        6253.986448
# 548914                                        4609.821155
# 548915                                       10166.744085
#
#        out.emissions.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg
# 2                                             8989.327608
# 3                                            11296.731129
# 4                                             8750.011820
# 5                                             7367.581571
# 7                                             8932.439414
# ...                                                   ...
# 548907                                       17637.654451
# 548908                                       10082.041606
# 548910                                        7325.665554
# 548914                                       11691.732519
# 548915                                       10734.746512
#
# [331531 rows x 260 columns]

# %% [markdown]
# ## Project Future Energy Consumption Using EIA Heating Degree Day (HDD) Forecasted Data (Factors)

# %%
# Factors for 2022 to 2050
filename = 'aeo_projections_2022_2050.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_hdd_projection_factors = pd.read_excel(io=file_path, sheet_name='hdd_factors_2022_2050')

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")

# Convert the factors dataframe into a lookup dictionary
hdd_factor_lookup = df_hdd_projection_factors.set_index(['census_division']).to_dict('index')
hdd_factor_lookup
# Out:
# Retrieved data for filename: aeo_projections_2022_2050.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\aeo_projections_2022_2050.xlsx
# {'National': {2022: 1,
#   2023: 1.0028349414260749,
#   2024: 0.9389536266963965,
#   2025: 0.9344844368179533,
#   2026: 0.9300828169743566,
#   2027: 0.9257070259326153,
#   2028: 0.9212779053519207,
#   2029: 0.9168538581973203,
#   2030: 0.9124351151864318,
#   2031: 0.9080377039911245,
#   2032: 0.9036541297129915,
#   2033: 0.8992492812396443,
#   2034: 0.894875507855348,
#   2035: 0.8904758482849783,
#   2036: 0.8860390020882589,
#   2037: 0.8817285900905196,
#   2038: 0.877365886428882,
#   2039: 0.8729314040841085,
#   2040: 0.8685839209369028,
#   2041: 0.8642702226890459,
#   2042: 0.8599120736340495,
#   2043: 0.8555441810694344,
#   2044: 0.8511753084862802,
#   2045: 0.8468232704962843,
#   2046: 0.8425090534289743,
#   2047: 0.8382247585710751,
#   2048: 0.8339389072548168,
#   2049: 0.8297055204635582,
#   2050: 0.8255002687057338},
#  'East North Central': {2022: 1,
#   2023: 0.9811731756651626,
#   2024: 0.9307608526528707,
#   2025: 0.928426948809709,
#   2026: 0.9262486385560915,
#   2027: 0.9239147347129298,
#   2028: 0.9215808308697682,
#   2029: 0.9192469270266065,
#   2030: 0.9169130231834448,
#   2031: 0.9147347129298273,
#   2032: 0.9124008090866657,
#   2033: 0.910066905243504,
#   2034: 0.9077330014003423,
#   2035: 0.9053990975571806,
#   2036: 0.9030651937140189,
#   2037: 0.9008868834604015,
#   2038: 0.8985529796172398,
#   2039: 0.8962190757740781,
#   2040: 0.8938851719309164,
#   2041: 0.8915512680877548,
#   2042: 0.8892173642445931,
#   2043: 0.8870390539909756,
#   2044: 0.8847051501478139,
#   2045: 0.8823712463046522,
#   2046: 0.8800373424614906,
#   2047: 0.8777034386183289,
#   2048: 0.8753695347751672,
#   2049: 0.8730356309320056,
#   2050: 0.8708573206783881},
#  'East South Central': {2022: 1,
#   2023: 0.9870949240034413,
#   2024: 0.911958703756811,
#   2025: 0.9085173501577287,
#   2026: 0.9050759965586465,
#   2027: 0.9016346429595641,
#   2028: 0.8979065098938916,
#   2029: 0.8944651562948093,
#   2030: 0.8907370232291368,
#   2031: 0.8872956696300545,
#   2032: 0.883567536564382,
#   2033: 0.8801261829652997,
#   2034: 0.8763980498996272,
#   2035: 0.8726699168339547,
#   2036: 0.8692285632348724,
#   2037: 0.8655004301691999,
#   2038: 0.8617722971035274,
#   2039: 0.8580441640378549,
#   2040: 0.8546028104387726,
#   2041: 0.8508746773731001,
#   2042: 0.8471465443074276,
#   2043: 0.8434184112417551,
#   2044: 0.8399770576426728,
#   2045: 0.8362489245770003,
#   2046: 0.8325207915113277,
#   2047: 0.8287926584456553,
#   2048: 0.8250645253799828,
#   2049: 0.8216231717809005,
#   2050: 0.817895038715228},
#  'Middle Atlantic': {2022: 1,
#   2023: 1.0064437478230581,
#   2024: 0.931382793451759,
#   2025: 0.9273772204806687,
#   2026: 0.9235458028561477,
#   2027: 0.9197143852316266,
#   2028: 0.9158829676071055,
#   2029: 0.9118773946360154,
#   2030: 0.9080459770114943,
#   2031: 0.9042145593869731,
#   2032: 0.900208986415883,
#   2033: 0.8963775687913619,
#   2034: 0.8925461511668408,
#   2035: 0.8885405781957506,
#   2036: 0.8847091605712295,
#   2037: 0.8808777429467085,
#   2038: 0.8770463253221874,
#   2039: 0.8730407523510971,
#   2040: 0.8692093347265761,
#   2041: 0.865377917102055,
#   2042: 0.8615464994775339,
#   2043: 0.8575409265064438,
#   2044: 0.8537095088819227,
#   2045: 0.8498780912574015,
#   2046: 0.8460466736328806,
#   2047: 0.8420411006617903,
#   2048: 0.8382096830372693,
#   2049: 0.8343782654127482,
#   2050: 0.8305468477882271},
#  'Mountain': {2022: 1,
#   2023: 1.001609657947686,
#   2024: 0.9635814889336016,
#   2025: 0.9609657947686117,
#   2026: 0.9583501006036217,
#   2027: 0.9559356136820926,
#   2028: 0.9533199195171026,
#   2029: 0.9507042253521126,
#   2030: 0.9480885311871228,
#   2031: 0.9452716297786721,
#   2032: 0.9426559356136821,
#   2033: 0.9400402414486921,
#   2034: 0.9372233400402414,
#   2035: 0.9346076458752515,
#   2036: 0.9319919517102616,
#   2037: 0.9293762575452716,
#   2038: 0.9267605633802817,
#   2039: 0.9241448692152917,
#   2040: 0.9215291750503019,
#   2041: 0.9191146881287726,
#   2042: 0.9164989939637826,
#   2043: 0.9138832997987928,
#   2044: 0.9114688128772636,
#   2045: 0.9088531187122736,
#   2046: 0.9062374245472837,
#   2047: 0.9038229376257545,
#   2048: 0.9012072434607646,
#   2049: 0.8987927565392354,
#   2050: 0.8961770623742454},
#  'New England': {2022: 1,
#   2023: 1.0358180058083253,
#   2024: 0.9635366247176509,
#   2025: 0.9598257502420136,
#   2026: 0.9559535333978703,
#   2027: 0.952242658922233,
#   2028: 0.9483704420780897,
#   2029: 0.9444982252339464,
#   2030: 0.9406260083898031,
#   2031: 0.9369151339141658,
#   2032: 0.9330429170700226,
#   2033: 0.9291707002258793,
#   2034: 0.925298483381736,
#   2035: 0.9214262665375927,
#   2036: 0.9175540496934494,
#   2037: 0.9136818328493063,
#   2038: 0.909809616005163,
#   2039: 0.9059373991610197,
#   2040: 0.9020651823168764,
#   2041: 0.8981929654727331,
#   2042: 0.8943207486285899,
#   2043: 0.8904485317844466,
#   2044: 0.8865763149403033,
#   2045: 0.88270409809616,
#   2046: 0.8788318812520168,
#   2047: 0.8749596644078735,
#   2048: 0.8710874475637302,
#   2049: 0.867053888351081,
#   2050: 0.8631816715069377},
#  'Pacific': {2022: 1,
#   2023: 1.0905977584059776,
#   2024: 1.0118306351183064,
#   2025: 1.0090286425902864,
#   2026: 1.0062266500622665,
#   2027: 1.0034246575342465,
#   2028: 1.0003113325031132,
#   2029: 0.9975093399750934,
#   2030: 0.9947073474470735,
#   2031: 0.9915940224159402,
#   2032: 0.9887920298879203,
#   2033: 0.9856787048567871,
#   2034: 0.9828767123287672,
#   2035: 0.9797633872976339,
#   2036: 0.9766500622665006,
#   2037: 0.9738480697384807,
#   2038: 0.9707347447073474,
#   2039: 0.9676214196762142,
#   2040: 0.9645080946450809,
#   2041: 0.961706102117061,
#   2042: 0.9585927770859277,
#   2043: 0.9554794520547946,
#   2044: 0.9523661270236613,
#   2045: 0.949252801992528,
#   2046: 0.9464508094645081,
#   2047: 0.9433374844333748,
#   2048: 0.9402241594022416,
#   2049: 0.9371108343711083,
#   2050: 0.933997509339975},
#  'South Atlantic': {2022: 1,
#   2023: 1.0132501948558068,
#   2024: 0.9255650818394389,
#   2025: 0.9189399844115355,
#   2026: 0.9127045985970382,
#   2027: 0.9064692127825409,
#   2028: 0.9002338269680437,
#   2029: 0.8939984411535464,
#   2030: 0.887373343725643,
#   2031: 0.8811379579111458,
#   2032: 0.8749025720966485,
#   2033: 0.8686671862821512,
#   2034: 0.8624318004676539,
#   2035: 0.8561964146531567,
#   2036: 0.8495713172252534,
#   2037: 0.843335931410756,
#   2038: 0.8371005455962588,
#   2039: 0.8308651597817615,
#   2040: 0.8246297739672642,
#   2041: 0.818394388152767,
#   2042: 0.8121590023382697,
#   2043: 0.8059236165237724,
#   2044: 0.7996882307092751,
#   2045: 0.7934528448947779,
#   2046: 0.7872174590802806,
#   2047: 0.7813717848791893,
#   2048: 0.7751363990646921,
#   2049: 0.7689010132501949,
#   2050: 0.7626656274356975},
#  'West North Central': {2022: 1,
#   2023: 0.9643535427319211,
#   2024: 0.9275383491599708,
#   2025: 0.9262235208181154,
#   2026: 0.9247626004382761,
#   2027: 0.9234477720964207,
#   2028: 0.9219868517165815,
#   2029: 0.9205259313367421,
#   2030: 0.9190650109569029,
#   2031: 0.9176040905770636,
#   2032: 0.9161431701972242,
#   2033: 0.914682249817385,
#   2034: 0.9130752373995618,
#   2035: 0.9116143170197224,
#   2036: 0.9101533966398831,
#   2037: 0.9085463842220599,
#   2038: 0.9070854638422206,
#   2039: 0.9054784514243974,
#   2040: 0.9040175310445581,
#   2041: 0.9024105186267348,
#   2042: 0.9009495982468956,
#   2043: 0.8993425858290723,
#   2044: 0.8977355734112491,
#   2045: 0.8962746530314097,
#   2046: 0.8946676406135866,
#   2047: 0.8930606281957634,
#   2048: 0.891599707815924,
#   2049: 0.8899926953981008,
#   2050: 0.8883856829802775},
#  'West South Central': {2022: 1,
#   2023: 0.9366742596810934,
#   2024: 0.8847380410022779,
#   2025: 0.8810933940774488,
#   2026: 0.876993166287016,
#   2027: 0.8728929384965831,
#   2028: 0.869248291571754,
#   2029: 0.8651480637813211,
#   2030: 0.861503416856492,
#   2031: 0.8574031890660593,
#   2032: 0.85375854214123,
#   2033: 0.8496583143507973,
#   2034: 0.8460136674259681,
#   2035: 0.8423690205011389,
#   2036: 0.8382687927107062,
#   2037: 0.834624145785877,
#   2038: 0.8309794988610478,
#   2039: 0.826879271070615,
#   2040: 0.8232346241457859,
#   2041: 0.8195899772209567,
#   2042: 0.8159453302961276,
#   2043: 0.8123006833712985,
#   2044: 0.8082004555808656,
#   2045: 0.8045558086560365,
#   2046: 0.8009111617312072,
#   2047: 0.7972665148063781,
#   2048: 0.793621867881549,
#   2049: 0.7899772209567198,
#   2050: 0.7863325740318906}}

# %%
print("""
-------------------------------------------------------------------------------------------------------
Baseline Consumption:
-------------------------------------------------------------------------------------------------------
""")

# df_baseline_enduse(df_baseline, df_enduse, category, fuel_filter='Yes', tech_filter='Yes')
df_euss_am_baseline_home = df_enduse_refactored(df_baseline = df_euss_am_baseline,
                                                fuel_filter = 'Yes',
                                                tech_filter = 'Yes')

# Project Future Energy Consumption
df_euss_am_baseline_home = project_future_consumption(df=df_euss_am_baseline_home, hdd_factor_lookup=hdd_factor_lookup, menu_mp=menu_mp)
df_euss_am_baseline_home
# Out:
# -------------------------------------------------------------------------------------------------------
# Baseline Consumption:
# -------------------------------------------------------------------------------------------------------
#
# Processing column: in.clothes_dryer
# Initial data types: object
# Data types after processing: object
# Processing column: in.cooking_range
# Initial data types: object
# Data types after processing: object
# 331531 rows remain after applying total heating consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 321357 rows remain after applying heating fuel filter
# Filtered for the following Heating technologies: ['Electricity ASHP', 'Electricity Baseboard', 'Electricity Electric Boiler', 'Electricity Electric Furnace', 'Fuel Oil Fuel Boiler', 'Fuel Oil Fuel Furnace', 'Natural Gas Fuel Boiler', 'Natural Gas Fuel Furnace', 'Propane Fuel Boiler', 'Propane Fuel Furnace']
# 291558 rows remain after applying heating technology filter
# 291558 rows remain after applying total waterHeating consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 291191 rows remain after applying waterHeating fuel filter
# Filtered for the following Water Heating technologies: ['Electric Heat Pump, 80 gal', 'Electric Premium', 'Electric Standard', 'Fuel Oil Premium', 'Fuel Oil Standard', 'Natural Gas Premium', 'Natural Gas Standard', 'Propane Premium', 'Propane Standard']
# 284744 rows remain after applying waterHeating technology filter
# 284744 rows remain after applying total clothesDrying consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 272458 rows remain after applying clothesDrying fuel filter
# 272458 rows remain after applying total cooking consumption calculation
# Filtered for the following fuels: ['Natural Gas', 'Electricity', 'Propane', 'Fuel Oil']
# 270018 rows remain after applying cooking fuel filter
# Projecting Future Energy Consumption (Baseline Equipment): heating
# Projecting Future Energy Consumption (Baseline Equipment): waterHeating
# Projecting Future Energy Consumption (Baseline Equipment): clothesDrying
# Projecting Future Energy Consumption (Baseline Equipment): cooking
#         bldg_id  square_footage census_region     census_division  \
# 2           239          1690.0         South  East South Central
# 3           273          1690.0         South  East South Central
# 4           307          1220.0         South  East South Central
# 5           409          1220.0         South  East South Central
# 7           517          1220.0         South  East South Central
# ...         ...             ...           ...                 ...
# 548905   548109          1690.0          West            Mountain
# 548907   548226          2176.0          West            Mountain
# 548908   548228          1690.0          West            Mountain
# 548910   548417           885.0          West            Mountain
# 548914   549740          1220.0          West            Mountain
#
#        census_division_recs building_america_climate_zone  \
# 2        East South Central                     Hot-Humid
# 3        East South Central                   Mixed-Humid
# 4        East South Central                     Hot-Humid
# 5        East South Central                     Hot-Humid
# 7        East South Central                   Mixed-Humid
# ...                     ...                           ...
# 548905       Mountain North                          Cold
# 548907       Mountain North                          Cold
# 548908       Mountain North                          Cold
# 548910       Mountain North                          Cold
# 548914       Mountain North                     Very Cold
#
#         reeds_balancing_area gea_region state                     city  ...  \
# 2                         90      SRSOc    AL    Not in a census Place  ...
# 3                         90      SRSOc    AL  In another census Place  ...
# 4                         90      SRSOc    AL    Not in a census Place  ...
# 5                         90      SRSOc    AL    Not in a census Place  ...
# 7                         89      SRSOc    AL  In another census Place  ...
# ...                      ...        ...   ...                      ...  ...
# 548905                    23      RMPAc    WY  In another census Place  ...
# 548907                    23      RMPAc    WY  In another census Place  ...
# 548908                    24      RMPAc    WY    Not in a census Place  ...
# 548910                    24      RMPAc    WY                   Casper  ...
# 548914                    21      NWPPc    WY  In another census Place  ...
#
#        baseline_2029_cooking_consumption baseline_2030_cooking_consumption  \
# 2                                 979.44                            979.44
# 3                                 537.20                            537.20
# 4                                 537.20                            537.20
# 5                                1009.63                           1009.63
# 7                                 377.18                            377.18
# ...                                  ...                               ...
# 548905                            405.61                            405.61
# 548907                            405.61                            405.61
# 548908                            405.61                            405.61
# 548910                            486.50                            486.50
# 548914                           1009.63                           1009.63
#
#        baseline_2031_cooking_consumption baseline_2032_cooking_consumption  \
# 2                                 979.44                            979.44
# 3                                 537.20                            537.20
# 4                                 537.20                            537.20
# 5                                1009.63                           1009.63
# 7                                 377.18                            377.18
# ...                                  ...                               ...
# 548905                            405.61                            405.61
# 548907                            405.61                            405.61
# 548908                            405.61                            405.61
# 548910                            486.50                            486.50
# 548914                           1009.63                           1009.63
#
#         baseline_2033_cooking_consumption  baseline_2034_cooking_consumption  \
# 2                                  979.44                             979.44
# 3                                  537.20                             537.20
# 4                                  537.20                             537.20
# 5                                 1009.63                            1009.63
# 7                                  377.18                             377.18
# ...                                   ...                                ...
# 548905                             405.61                             405.61
# 548907                             405.61                             405.61
# 548908                             405.61                             405.61
# 548910                             486.50                             486.50
# 548914                            1009.63                            1009.63
#
#        baseline_2035_cooking_consumption baseline_2036_cooking_consumption  \
# 2                                 979.44                            979.44
# 3                                 537.20                            537.20
# 4                                 537.20                            537.20
# 5                                1009.63                           1009.63
# 7                                 377.18                            377.18
# ...                                  ...                               ...
# 548905                            405.61                            405.61
# 548907                            405.61                            405.61
# 548908                            405.61                            405.61
# 548910                            486.50                            486.50
# 548914                           1009.63                           1009.63
#
#        baseline_2037_cooking_consumption baseline_2038_cooking_consumption
# 2                                 979.44                            979.44
# 3                                 537.20                            537.20
# 4                                 537.20                            537.20
# 5                                1009.63                           1009.63
# 7                                 377.18                            377.18
# ...                                  ...                               ...
# 548905                            405.61                            405.61
# 548907                            405.61                            405.61
# 548908                            405.61                            405.61
# 548910                            486.50                            486.50
# 548914                           1009.63                           1009.63
#
# [270018 rows x 104 columns]

# %% [markdown]
# # Public Perspective: Monetized Marginal Damages from Emissions

# %% [markdown]
# ## Fossil Fuels: Climate and Health-Related Pollutants

# %%
print("""
-------------------------------------------------------------------------------------------------------
Calculate Emissions Factors: FOSSIL FUELS
-------------------------------------------------------------------------------------------------------
Fossil Fuels (Natural Gas, Fuel Oil, Propane):
- NOx, SO2, CO2: 
    - RESNET Table 7.1.2 Emissions Factors for Household Combustion Fuels
    - Source: https://www.resnet.us/wp-content/uploads/ANSIRESNETICC301-2022_resnetpblshd.pdf
    - All factors are in units of lb/Mbtu so energy consumption in kWh need to be converted to kWh 
    - (1 lb / Mbtu) * (1 Mbtu / 1x10^6 Btu) * (3412 Btu / 1 kWh)
- PM2.5: 
    - A National Methodology and Emission Inventory for Residential Fuel Combustion
    - Source: https://www3.epa.gov/ttnchie1/conference/ei12/area/haneke.pdf
-------------------------------------------------------------------------------------------------------
""")

fuelOil_factors = calculate_fossilFuel_emission_factor(fuel_type="fuelOil", so2_factor=0.0015, nox_factor=0.1300, pm25_factor=0.83, fuelConversion_factor1=1000, fuelConversion_factor2=138500)
naturalGas_factors = calculate_fossilFuel_emission_factor(fuel_type="naturalGas", so2_factor=0.0006, nox_factor=0.0922, pm25_factor=1.9, fuelConversion_factor1=1000000, fuelConversion_factor2=1039)
propane_factors = calculate_fossilFuel_emission_factor(fuel_type="propane", so2_factor=0.0002, nox_factor=0.1421, pm25_factor=0.17, fuelConversion_factor1=1000, fuelConversion_factor2=91452)

all_factors = {**fuelOil_factors, **naturalGas_factors, **propane_factors}

df_margEmis_factors = pd.DataFrame.from_dict(all_factors, orient="index", columns=["value"])
df_margEmis_factors.reset_index(inplace=True)
df_margEmis_factors.columns = ["pollutant", "value"]
df_margEmis_factors[["fuel_type", "pollutant"]] = df_margEmis_factors["pollutant"].str.split("_", expand=True)
# df_margEmis_factors["unit"] = "[lb/kWh]"

# Update the units to metric tons per kWh
df_margEmis_factors["unit"] = "[mt/kWh]"

# Convert the values from lb/kWh to mt/kWh
lb_to_mt = 0.00045359237
df_margEmis_factors["value"] = df_margEmis_factors["value"] * lb_to_mt

# Add the 'state' column and assign 'National' to every row
df_margEmis_factors = df_margEmis_factors.assign(state='National')

df_margEmis_factors = df_margEmis_factors[["state", "fuel_type", "pollutant", "value", "unit"]]
df_margEmis_factors
# Out:
# -------------------------------------------------------------------------------------------------------
# Calculate Emissions Factors: FOSSIL FUELS
# -------------------------------------------------------------------------------------------------------
# Fossil Fuels (Natural Gas, Fuel Oil, Propane):
# - NOx, SO2, CO2:
#     - RESNET Table 7.1.2 Emissions Factors for Household Combustion Fuels
#     - Source: https://www.resnet.us/wp-content/uploads/ANSIRESNETICC301-2022_resnetpblshd.pdf
#     - All factors are in units of lb/Mbtu so energy consumption in kWh need to be converted to kWh
#     - (1 lb / Mbtu) * (1 Mbtu / 1x10^6 Btu) * (3412 Btu / 1 kWh)
# - PM2.5:
#     - A National Methodology and Emission Inventory for Residential Fuel Combustion
#     - Source: https://www3.epa.gov/ttnchie1/conference/ei12/area/haneke.pdf
# -------------------------------------------------------------------------------------------------------
#        state   fuel_type pollutant         value      unit
# 0   National     fuelOil       so2  2.321486e-09  [mt/kWh]
# 1   National     fuelOil       nox  2.011954e-07  [mt/kWh]
# 2   National     fuelOil      pm25  9.274769e-09  [mt/kWh]
# 3   National  naturalGas      co2e  1.231503e-07  [mt/kWh]
# 4   National     propane      co2e  1.251008e-07  [mt/kWh]
# 5   National     fuelOil      co2e  1.378467e-07  [mt/kWh]
# 6   National  naturalGas       so2  9.285943e-10  [mt/kWh]
# 7   National  naturalGas       nox  1.426940e-07  [mt/kWh]
# 8   National  naturalGas      pm25  2.830172e-09  [mt/kWh]
# 9   National     propane       so2  3.095314e-10  [mt/kWh]
# 10  National     propane       nox  2.199221e-07  [mt/kWh]
# 11  National     propane      pm25  2.876938e-09  [mt/kWh]

# %%
# Extract fossil fuel emissions factors from the dataframe
emis_fossilFuel_lookup = {
    'naturalGas': {
        'co2e': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'naturalGas') & (df_margEmis_factors['pollutant'] == 'co2e')]['value'].values[0],
        'so2': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'naturalGas') & (df_margEmis_factors['pollutant'] == 'so2')]['value'].values[0],
        'nox': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'naturalGas') & (df_margEmis_factors['pollutant'] == 'nox')]['value'].values[0],
        'pm25': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'naturalGas') & (df_margEmis_factors['pollutant'] == 'pm25')]['value'].values[0]
        },
    'propane': {
        'co2e': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'propane') & (df_margEmis_factors['pollutant'] == 'co2e')]['value'].values[0],
        'so2': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'propane') & (df_margEmis_factors['pollutant'] == 'so2')]['value'].values[0],
        'nox': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'propane') & (df_margEmis_factors['pollutant'] == 'nox')]['value'].values[0],
        'pm25': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'propane') & (df_margEmis_factors['pollutant'] == 'pm25')]['value'].values[0]
        },
    'fuelOil': {
        'co2e': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'fuelOil') & (df_margEmis_factors['pollutant'] == 'co2e')]['value'].values[0],
        'so2': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'fuelOil') & (df_margEmis_factors['pollutant'] == 'so2')]['value'].values[0],
        'nox': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'fuelOil') & (df_margEmis_factors['pollutant'] == 'nox')]['value'].values[0],
        'pm25': df_margEmis_factors[(df_margEmis_factors['fuel_type'] == 'fuelOil') & (df_margEmis_factors['pollutant'] == 'pm25')]['value'].values[0]
        }
    }

emis_fossilFuel_lookup
# Out:
# {'naturalGas': {'co2e': 1.23150328455e-07,
#   'so2': 9.285942998639998e-10,
#   'nox': 1.42693990745768e-07,
#   'pm25': 2.8301719116804617e-09},
#  'propane': {'co2e': 1.2510077564599998e-07,
#   'so2': 3.09531433288e-10,
#   'nox': 2.1992208335112402e-07,
#   'pm25': 2.876937828530814e-09},
#  'fuelOil': {'co2e': 1.37846721243e-07,
#   'so2': 2.3214857496599997e-09,
#   'nox': 2.0119543163720001e-07,
#   'pm25': 9.274768578665706e-09}}

# %% [markdown]
# ### Inflate Marginal Social Cost (Damage) Factors using BLS CPI for All Urban Consumers (CPI-U)
# - Series Id:	CUUR0000SA0
# - Not Seasonally Adjusted
# - Series Title:	All items in U.S. city average, all urban consumers, not seasonally adjusted
# - Area:	U.S. city average
# - Item:	All items
# - Base Period:	1982-84=100

# %%
# Load the BLS Inflation Data
filename = 'bls_cpiu_2005-2023.xlsx'
relative_path = os.path.join(r"inflation_data", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")

# Create a pandas dataframe
df_bls_cpiu = pd.read_excel(file_path, sheet_name='bls_cpiu')

df_bls_cpiu = pd.DataFrame({
    'year': df_bls_cpiu['Year'],
    'cpiu_annual': df_bls_cpiu['Annual']
})

# Obtain the Annual CPIU values for the years of interest
bls_cpi_annual_2008 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2008)].item()
bls_cpi_annual_2010 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2010)].item()
bls_cpi_annual_2013 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2013)].item()
bls_cpi_annual_2018 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2018)].item()
bls_cpi_annual_2019 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2019)].item()
bls_cpi_annual_2020 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2020)].item()
bls_cpi_annual_2021 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2021)].item()
bls_cpi_annual_2022 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2022)].item()
bls_cpi_annual_2023 = df_bls_cpiu['cpiu_annual'].loc[(df_bls_cpiu['year'] == 2023)].item()

# Precompute constant values
cpi_ratio_2023_2023 = bls_cpi_annual_2023 / bls_cpi_annual_2023
cpi_ratio_2023_2022 = bls_cpi_annual_2023 / bls_cpi_annual_2022
cpi_ratio_2023_2021 = bls_cpi_annual_2023 / bls_cpi_annual_2021  # For EPA VSL (11.3M USD-2021)
cpi_ratio_2023_2020 = bls_cpi_annual_2023 / bls_cpi_annual_2020  # For SCC
cpi_ratio_2023_2019 = bls_cpi_annual_2023 / bls_cpi_annual_2019 
cpi_ratio_2023_2018 = bls_cpi_annual_2023 / bls_cpi_annual_2018 
cpi_ratio_2023_2013 = bls_cpi_annual_2023 / bls_cpi_annual_2013
cpi_ratio_2023_2010 = bls_cpi_annual_2023 / bls_cpi_annual_2010
cpi_ratio_2023_2008 = bls_cpi_annual_2023 / bls_cpi_annual_2008  # For EPA VSL and SCC
# Out:
# Retrieved data for filename: bls_cpiu_2005-2023.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\inflation_data\bls_cpiu_2005-2023.xlsx

# %% [markdown]
# ### Use the updated Social Cost of Carbon (190 USD-2020/ton CO2) and inflate to USD-2023
# - EPA Median for 2% near term discount rate and most commonly mentioned value is 190 USD-2020 using the GIVE model.
# - 190 USD-2020 has some inconsistency with the VSL being used. An old study and 2008 VSL is noted
# - 190 USD value and inflate to USD 2023 because there is a clear source and ease of replicability.
#
# ### Adjustment for VSL
# - EASIUR uses a VSL of 8.8M USD-2010
# - New EPA VSL is 11.3M USD-2021
# - INFLATE TO $USD-2023
#
# ### ALL DOLLAR VALUES ARE NOW IN USD2023, PREVIOUSLY USED $USD-2021

# %%
# For CO2 adjust SCC
# Create an adjustment factor for the new Social Cost of Carbon (SCC)
epa_scc = 190 * cpi_ratio_2023_2020
old_scc = 40 * cpi_ratio_2023_2010
scc_adjustment_factor = epa_scc / old_scc

# For Health-Related Emissions Adjust for different Value of a Statistical Life (VSL) values
# Current VSL is $11.3 M USD2021
# INFLATE TO USD2022, PREVIOUSLY USD2021
current_VSL_USD2022 = 11.3 * cpi_ratio_2023_2021

# Easiur uses a VSL of $8.8 M USD2010
# INFLATE TO USD2022, PREVIOUSLY USD2021
easiur_VSL_USD2022 = 8.8 * (cpi_ratio_2023_2010)

# Calculate VSL adjustment factor
vsl_adjustment_factor = current_VSL_USD2022 / easiur_VSL_USD2022

# %% [markdown]
# ### Quantify monitized HEALTH damages using EASIUR Marginal Social Cost Factors
# #### THE STEPS BELOW SUMMARIZE WHAT WAS DONE TO OBTAIN ALL NATIONAL EASIUR VALUES INCLUDED ON GITHUB
# - Obtain all of the dwelling unit latitude and longitude values from the metadata columns
# - Make a new dataframe of just the longitude and latitude values
#     - Make sure that the order is (longitude, latitude)
#     - Do not include the index or column name when exporting
# - Export the CSV
# - **Upload csv to EASIUR Website:**
#     - Website: https://barney.ce.cmu.edu/~jinhyok/easiur/online/
#     - See inputs in respective sections
# - Download the file and put it in the 'easiur_batchConversion_download' folder
# - Copy and paste the name of the file EASIUR generated when prompted
# - Copy and paste the name of the filepath for the 'easiur_batchConversion_download' folder when prompted
# - Match up the longitude and latitudes for each dwelling unit with the selected damages

# %%
# Create a dataframe containing just the longitude and Latitude
df_EASIUR_batchConversion = pd.DataFrame({
    'Longitude':df_euss_am_baseline['in.weather_file_longitude'],
    'Latitude':df_euss_am_baseline['in.weather_file_latitude'],
})

# Drop duplicate rows based on 'Longitude' and 'Latitude' columns
df_EASIUR_batchConversion.drop_duplicates(subset=['Longitude', 'Latitude'], keep='first', inplace=True)

# Create a location ID for the name of the batch conversion file
while True:
    if menu_state == 'N':
        location_id = 'National'
        print("You chose to analyze all of the United States.")
        break
    elif menu_state == 'Y':
        if menu_city == 'N':
            try:
                location_id = str(input_state)
                print(f"Location ID is: {location_id}")
                break
            except ValueError:
                print("Invalid input for state!")
        elif menu_city == 'Y':
            try:
                location_id = input_cityFilter.replace(', ', '_').strip()
                print(f"Location ID is: {location_id}")
                break
            except AttributeError:
                print("Invalid input for city filter!")
        else:
            print("Incorrect state or city filter assignment!")
    else:
        print("Invalid data location. Check your inputs at the beginning of this notebook!")

# Updated GitHub code has EASIUR file with all unique latitude, longitude coordinates in the US
filename = 'easiur_National2024-06-1421-22.csv'
relative_path = os.path.join(r"margDamages_EASIUR\easiur_batchConversion_download", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_margSocialCosts = pd.read_csv(file_path)

# Convert from kg/MWh to lb/kWh
# Obtain value from the CSV file and convert to lbs pollutant per kWh 

# Define df_margSocialCosts_EASIUR DataFrame first
df_margSocialCosts_EASIUR = pd.DataFrame({
    'Longitude': df_margSocialCosts['Longitude'],
    'Latitude': df_margSocialCosts['Latitude'],
})

# Use df_margSocialCosts_EASIUR in the calculation of other columns
# Also adjust the VSL
df_margSocialCosts_EASIUR['margSocialCosts_pm25'] = round((df_margSocialCosts['PM25 Annual Ground'] * (1/2204.6) * vsl_adjustment_factor), 2)
df_margSocialCosts_EASIUR['margSocialCosts_so2'] = round((df_margSocialCosts['SO2 Annual Ground'] * (1/2204.6) * vsl_adjustment_factor), 2)
df_margSocialCosts_EASIUR['margSocialCosts_nox'] = round((df_margSocialCosts['NOX Annual Ground'] * (1/2204.6) * vsl_adjustment_factor), 2)
df_margSocialCosts_EASIUR['unit'] = '[$USD2023/lb]'

# Dispalay the EASIUR marginal social costs df
df_margSocialCosts_EASIUR
# Out:
# You chose to analyze all of the United States.
# Retrieved data for filename: easiur_National2024-06-1421-22.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\margDamages_EASIUR\easiur_batchConversion_download\easiur_National2024-06-1421-22.csv
#       Longitude  Latitude  margSocialCosts_pm25  margSocialCosts_so2  \
# 0        -87.04     31.42                 38.00                 9.35
# 1        -85.86     33.59                 57.22                10.19
# 2        -86.39     32.30                 52.07                 9.70
# 3        -85.45     31.32                 43.54                 9.76
# 4        -86.75     33.56                 98.71                11.19
# ...         ...       ...                   ...                  ...
# 1024    -106.72     44.38                 10.33                 5.02
# 1025    -105.54     44.34                 11.44                 6.05
# 1026    -107.95     43.97                  8.85                 4.47
# 1027    -108.08     44.52                  9.29                 5.74
# 1028    -107.20     41.81                  9.88                 5.61
#
#       margSocialCosts_nox           unit
# 0                    1.70  [$USD2023/lb]
# 1                    2.64  [$USD2023/lb]
# 2                    2.13  [$USD2023/lb]
# 3                    1.86  [$USD2023/lb]
# 4                    3.00  [$USD2023/lb]
# ...                   ...            ...
# 1024                 0.76  [$USD2023/lb]
# 1025                 0.96  [$USD2023/lb]
# 1026                 0.61  [$USD2023/lb]
# 1027                 0.82  [$USD2023/lb]
# 1028                 0.65  [$USD2023/lb]
#
# [1029 rows x 6 columns]

# %%
# FOSSIL FUELS DAMAGES LOOKUP
# Create a damages_fossilFuel_lookup dictionary from df_margSocialCosts_EASIUR
damages_fossilFuel_lookup = df_margSocialCosts_EASIUR.groupby(['Longitude', 'Latitude']).first().to_dict()
damages_fossilFuel_lookup
# Out:
# {'margSocialCosts_pm25': {(-124.25, 43.42): 39.96,
#   (-124.24, 41.78): 26.13,
#   (-124.11, 40.98): 25.91,
#   (-124.07, 44.62): 39.38,
#   (-123.94, 46.97): 60.55,
#   (-123.88, 46.16): 51.33,
#   (-123.5, 48.12): 61.62,
#   (-123.38, 42.62): 34.41,
#   (-123.36, 43.24): 32.46,
#   (-123.29, 44.5): 72.79,
#   (-123.21, 44.13): 70.7,
#   (-123.2, 39.13): 38.57,
#   (-123.15, 47.24): 70.68,
#   (-123.13, 45.2): 124.73,
#   (-123.02, 48.52): 66.41,
#   (-123.0, 44.91): 112.52,
#   (-122.95, 45.54): 124.73,
#   (-122.9, 46.97): 135.35,
#   (-122.87, 42.39): 38.26,
#   (-122.86, 45.77): 130.55,
#   (-122.81, 38.51): 80.93,
#   (-122.77, 45.25): 94.07,
#   (-122.76, 47.49): 117.71,
#   (-122.66, 45.62): 130.55,
#   (-122.6, 45.59): 206.04,
#   (-122.55, 47.12): 185.76,
#   (-122.54, 48.79): 61.79,
#   (-122.47, 41.78): 19.69,
#   (-122.43, 47.67): 191.74,
#   (-122.4, 37.62): 301.86,
#   (-122.31, 40.52): 37.49,
#   (-122.28, 38.21): 157.85,
#   (-122.28, 47.91): 173.1,
#   (-122.25, 40.15): 31.58,
#   (-122.21, 47.49): 179.48,
#   (-122.15, 48.16): 93.42,
#   (-122.12, 37.66): 203.57,
#   (-122.05, 37.99): 157.85,
#   (-121.95, 38.27): 157.85,
#   (-121.93, 37.36): 191.78,
#   (-121.79, 36.94): 94.05,
#   (-121.72, 42.15): 21.3,
#   (-121.62, 39.49): 40.51,
#   (-121.61, 36.66): 69.64,
#   (-121.59, 38.7): 156.52,
#   (-121.57, 39.1): 57.67,
#   (-121.44, 39.14): 57.67,
#   (-121.4, 38.67): 156.52,
#   (-121.24, 37.89): 113.84,
#   (-121.17, 45.62): 34.65,
#   (-121.15, 44.25): 27.14,
#   (-120.95, 37.63): 115.17,
#   (-120.71, 39.29): 26.02,
#   (-120.64, 35.24): 51.18,
#   (-120.57, 41.48): 11.9,
#   (-120.53, 46.56): 46.38,
#   (-120.53, 47.03): 28.45,
#   (-120.51, 37.29): 65.44,
#   (-120.4, 42.17): 11.22,
#   (-120.21, 47.4): 26.48,
#   (-120.13, 39.32): 27.78,
#   (-120.11, 36.99): 75.13,
#   (-120.0, 38.89): 26.15,
#   (-119.84, 34.43): 40.8,
#   (-119.77, 39.48): 36.95,
#   (-119.72, 36.78): 47.29,
#   (-119.63, 36.32): 59.59,
#   (-119.6, 46.57): 28.75,
#   (-119.52, 48.46): 21.1,
#   (-119.38, 36.32): 55.08,
#   (-119.32, 47.21): 32.43,
#   (-119.26, 45.83): 29.2,
#   (-119.12, 46.27): 45.29,
#   (-119.1, 34.22): 85.68,
#   (-119.06, 35.43): 70.19,
#   (-118.95, 43.59): 12.67,
#   (-118.83, 45.7): 28.13,
#   (-118.7, 39.42): 17.16,
#   (-118.57, 40.07): 13.09,
#   (-118.36, 37.37): 13.46,
#   (-118.3, 34.03): 319.23,
#   (-118.29, 46.1): 19.93,
#   (-118.01, 45.29): 14.96,
#   (-117.81, 40.9): 11.41,
#   (-117.81, 44.84): 13.86,
#   (-117.73, 33.68): 238.6,
#   (-117.65, 47.62): 45.56,
#   (-117.57, 34.05): 145.45,
#   (-117.42, 47.97): 34.9,
#   (-117.32, 47.68): 63.96,
#   (-117.25, 33.9): 122.34,
#   (-117.15, 32.87): 146.63,
#   (-117.11, 46.74): 23.03,
#   (-117.01, 44.02): 23.01,
#   (-117.01, 46.38): 23.64,
#   (-116.82, 47.77): 41.77,
#   (-116.63, 43.64): 33.92,
#   (-116.22, 43.57): 54.82,
#   (-116.1, 44.88): 12.43,
#   (-116.03, 36.62): 16.02,
#   (-116.01, 39.6): 8.31,
#   (-115.87, 43.04): 16.6,
#   (-115.8, 47.47): 14.02,
#   (-115.79, 40.83): 12.28,
#   (-115.6, 46.14): 11.04,
#   (-115.58, 32.83): 30.91,
#   (-115.16, 36.08): 86.1,
#   (-114.93, 44.17): 8.55,
#   (-114.85, 39.3): 8.21,
#   (-114.72, 33.62): 20.19,
#   (-114.6, 32.65): 27.23,
#   (-114.49, 42.48): 16.6,
#   (-114.46, 42.73): 16.84,
#   (-114.26, 48.3): 20.83,
#   (-114.22, 44.52): 8.0,
#   (-114.09, 46.92): 23.36,
#   (-114.02, 40.72): 10.68,
#   (-113.94, 35.26): 14.35,
#   (-113.87, 45.12): 9.26,
#   (-113.77, 42.54): 17.11,
#   (-113.58, 37.09): 17.6,
#   (-113.1, 37.7): 11.28,
#   (-112.57, 42.92): 18.69,
#   (-112.55, 45.26): 8.73,
#   (-112.51, 45.95): 15.14,
#   (-112.42, 34.65): 23.08,
#   (-112.38, 48.61): 8.8,
#   (-112.07, 43.52): 18.13,
#   (-112.01, 41.2): 37.79,
#   (-111.99, 33.44): 65.55,
#   (-111.97, 40.79): 40.56,
#   (-111.97, 41.12): 37.79,
#   (-111.96, 46.61): 16.54,
#   (-111.88, 43.83): 15.42,
#   (-111.85, 41.79): 17.59,
#   (-111.72, 40.22): 34.48,
#   (-111.67, 35.14): 13.4,
#   (-111.45, 36.93): 8.32,
#   (-111.38, 47.47): 20.53,
#   (-111.19, 47.5): 20.53,
#   (-111.15, 45.79): 10.67,
#   (-110.88, 32.17): 39.19,
#   (-110.85, 31.42): 16.4,
#   (-110.75, 39.55): 10.9,
#   (-110.73, 43.61): 9.84,
#   (-110.72, 35.02): 9.84,
#   (-110.45, 45.7): 10.55,
#   (-110.11, 42.58): 9.22,
#   (-109.78, 48.56): 11.06,
#   (-109.75, 38.76): 9.14,
#   (-109.64, 32.86): 10.96,
#   (-109.6, 31.47): 9.31,
#   (-109.51, 40.44): 11.03,
#   (-109.47, 47.05): 9.49,
#   (-109.38, 34.52): 8.6,
#   (-109.07, 41.59): 11.86,
#   (-109.06, 35.66): 9.59,
#   (-108.95, 44.62): 9.36,
#   (-108.79, 35.51): 9.59,
#   (-108.63, 37.3): 10.83,
#   (-108.54, 39.13): 16.57,
#   (-108.54, 45.81): 26.11,
#   (-108.46, 43.06): 10.56,
#   (-108.23, 36.74): 13.53,
#   (-108.08, 44.52): 9.29,
#   (-107.95, 43.97): 8.85,
#   (-107.9, 38.51): 12.78,
#   (-107.89, 40.05): 9.55,
#   (-107.76, 37.14): 10.91,
#   (-107.73, 39.53): 12.89,
#   (-107.72, 32.26): 10.05,
#   (-107.52, 40.5): 10.96,
#   (-107.22, 40.48): 11.74,
#   (-107.2, 41.81): 9.88,
#   (-107.03, 38.45): 10.38,
#   (-106.98, 44.77): 11.23,
#   (-106.95, 47.33): 9.26,
#   (-106.92, 39.64): 15.3,
#   (-106.87, 39.22): 12.72,
#   (-106.72, 44.38): 10.33,
#   (-106.62, 35.04): 22.45,
#   (-106.62, 48.21): 11.13,
#   (-106.48, 32.38): 17.31,
#   (-106.47, 42.9): 15.36,
#   (-106.38, 31.81): 29.42,
#   (-106.32, 39.23): 14.08,
#   (-106.09, 35.62): 17.71,
#   (-105.98, 32.84): 11.5,
#   (-105.89, 46.43): 12.28,
#   (-105.87, 37.44): 10.48,
#   (-105.67, 36.46): 9.85,
#   (-105.67, 41.31): 13.8,
#   (-105.66, 35.0): 9.97,
#   (-105.57, 48.09): 11.8,
#   (-105.54, 44.34): 11.44,
#   (-105.53, 33.46): 8.61,
#   (-105.39, 42.8): 10.28,
#   (-105.14, 35.65): 8.33,
#   (-104.85, 39.57): 74.94,
#   (-104.81, 31.83): 7.42,
#   (-104.81, 41.16): 17.77,
#   (-104.8, 47.13): 12.95,
#   (-104.75, 39.7): 44.44,
#   (-104.71, 38.81): 27.43,
#   (-104.66, 39.83): 38.41,
#   (-104.62, 40.44): 28.78,
#   (-104.54, 33.31): 13.55,
#   (-104.5, 38.29): 20.78,
#   (-104.34, 37.26): 10.22,
#   (-104.26, 32.34): 11.95,
#   (-104.25, 46.36): 11.37,
#   (-104.18, 47.71): 14.44,
#   (-104.15, 42.07): 13.46,
#   (-104.02, 30.37): 7.19,
#   (-103.72, 39.19): 14.84,
#   (-103.64, 48.2): 16.76,
#   (-103.63, 43.73): 12.69,
#   (-103.6, 41.87): 14.73,
#   (-103.55, 45.6): 11.18,
#   (-103.53, 38.05): 13.3,
#   (-103.32, 34.38): 14.73,
#   (-103.23, 40.17): 13.77,
#   (-103.2, 31.78): 12.15,
#   (-103.15, 36.45): 10.33,
#   (-103.1, 44.15): 17.01,
#   (-103.07, 34.43): 14.04,
#   (-103.05, 44.05): 14.19,
#   (-102.99, 41.1): 13.18,
#   (-102.92, 30.92): 11.24,
#   (-102.8, 42.06): 12.8,
#   (-102.8, 46.8): 17.6,
#   (-102.69, 38.07): 12.44,
#   (-102.66, 46.01): 12.94,
#   (-102.61, 37.28): 10.47,
#   (-102.55, 36.02): 12.85,
#   (-102.52, 43.02): 12.53,
#   (-102.39, 31.92): 26.72,
#   (-102.28, 39.25): 12.07,
#   (-102.21, 31.93): 26.72,
#   (-101.87, 37.0): 12.45,
#   (-101.82, 33.67): 20.97,
#   (-101.77, 41.12): 14.18,
#   (-101.71, 35.22): 29.36,
#   (-101.69, 39.37): 14.03,
#   (-101.6, 44.05): 13.25,
#   (-101.44, 47.66): 18.62,
#   (-101.39, 35.7): 17.22,
#   (-101.36, 48.43): 18.73,
#   (-101.28, 48.26): 28.13,
#   (-100.96, 37.04): 15.91,
#   (-100.92, 29.37): 15.5,
#   (-100.78, 29.36): 13.78,
#   (-100.75, 46.77): 22.19,
#   (-100.73, 37.93): 18.22,
#   (-100.67, 41.12): 18.6,
#   (-100.59, 40.21): 16.7,
#   (-100.55, 42.86): 15.81,
#   (-100.49, 31.35): 24.4,
#   (-100.41, 45.55): 16.91,
#   (-100.29, 34.43): 16.87,
#   (-100.29, 44.38): 18.83,
#   (-99.98, 42.58): 16.17,
#   (-99.97, 37.77): 19.51,
#   (-99.85, 32.43): 30.52,
#   (-99.84, 43.39): 18.49,
#   (-99.83, 39.38): 17.66,
#   (-99.78, 36.3): 17.64,
#   (-99.77, 30.51): 20.12,
#   (-99.68, 32.41): 30.52,
#   (-99.64, 41.44): 19.15,
#   (-99.47, 27.55): 31.58,
#   (-99.33, 40.45): 22.75,
#   (-99.32, 43.77): 19.02,
#   (-99.28, 38.85): 20.51,
#   (-99.27, 34.66): 22.1,
#   (-99.22, 28.46): 17.88,
#   (-99.2, 35.34): 20.14,
#   (-99.17, 29.36): 28.14,
#   (-99.05, 35.01): 21.37,
#   (-99.0, 40.73): 25.7,
#   (-98.98, 34.35): 23.69,
#   (-98.9, 48.11): 23.73,
#   (-98.85, 38.34): 25.0,
#   (-98.83, 38.87): 22.16,
#   (-98.68, 42.47): 22.05,
#   (-98.68, 46.93): 24.92,
#   (-98.55, 37.28): 21.63,
#   (-98.49, 33.98): 35.63,
#   (-98.47, 29.34): 112.65,
#   (-98.46, 29.53): 112.65,
#   (-98.43, 40.6): 28.81,
#   (-98.42, 34.57): 31.36,
#   (-98.42, 45.45): 25.99,
#   (-98.4, 34.65): 31.36,
#   (-98.31, 40.96): 31.8,
#   (-98.28, 29.53): 68.33,
#   (-98.24, 26.18): 42.36,
#   (-98.24, 30.74): 42.37,
#   (-98.23, 44.39): 24.08,
#   (-98.18, 32.22): 39.74,
#   (-98.06, 32.78): 40.35,
#   (-98.05, 29.71): 61.46,
#   (-98.04, 43.78): 27.12,
#   (-98.03, 27.74): 26.6,
#   (-97.99, 36.34): 34.29,
#   (-97.98, 40.89): 29.08,
#   (-97.86, 38.07): 33.2,
#   (-97.85, 29.89): 55.95,
#   (-97.83, 31.07): 52.5,
#   (-97.82, 27.5): 29.48,
#   (-97.77, 30.32): 92.6,
#   (-97.69, 31.09): 52.5,
#   (-97.68, 30.18): 80.92,
#   (-97.67, 28.37): 31.98,
#   (-97.67, 30.68): 54.27,
#   (-97.66, 38.81): 26.63,
#   (-97.65, 26.23): 45.66,
#   (-97.65, 35.53): 52.76,
#   (-97.65, 39.55): 24.34,
#   (-97.6, 35.39): 48.2,
#   (-97.51, 27.77): 49.97,
#   (-97.45, 35.24): 69.43,
#   (-97.44, 41.98): 31.46,
#   (-97.43, 25.91): 41.83,
#   (-97.43, 37.65): 64.06,
#   (-97.42, 35.85): 40.02,
#   (-97.4, 31.15): 51.83,
#   (-97.4, 47.95): 30.49,
#   (-97.38, 35.42): 69.43,
#   (-97.38, 42.92): 32.61,
#   (-97.36, 32.82): 113.63,
#   (-97.33, 41.45): 33.74,
#   (-97.32, 32.97): 84.71,
#   (-97.3, 31.49): 49.36,
#   (-97.27, 37.62): 64.06,
#   (-97.27, 38.07): 42.28,
#   (-97.23, 31.61): 48.16,
#   (-97.22, 37.75): 42.28,
#   (-97.2, 33.21): 50.79,
#   (-97.18, 47.95): 39.35,
#   (-97.15, 44.93): 32.18,
#   (-97.15, 46.1): 29.85,
#   (-97.12, 34.15): 35.12,
#   (-97.1, 36.73): 33.5,
#   (-97.09, 32.66): 148.41,
#   (-97.09, 36.16): 34.45,
#   (-97.05, 28.08): 31.53,
#   (-97.04, 37.17): 35.4,
#   (-96.99, 45.67): 29.43,
#   (-96.97, 32.73): 148.41,
#   (-96.95, 29.91): 42.44,
#   (-96.93, 28.86): 39.56,
#   (-96.93, 48.75): 23.36,
#   (-96.85, 32.85): 148.41,
#   (-96.81, 46.93): 48.16,
#   (-96.8, 44.3): 31.64,
#   (-96.76, 39.06): 36.19,
#   (-96.76, 40.83): 68.45,
#   (-96.75, 40.3): 36.91,
#   (-96.75, 43.58): 49.65,
#   (-96.68, 39.13): 36.19,
#   (-96.62, 47.84): 29.36,
#   (-96.59, 33.18): 136.05,
#   (-96.53, 45.78): 31.59,
#   (-96.52, 41.45): 47.08,
#   (-96.42, 45.31): 31.99,
#   (-96.4, 32.03): 54.88,
#   (-96.38, 42.39): 46.21,
#   (-96.36, 30.59): 50.03,
#   (-96.3, 43.98): 35.62,
#   (-96.27, 32.71): 81.98,
#   (-96.25, 28.73): 34.45,
#   (-96.19, 38.33): 32.1,
#   (-96.18, 41.76): 38.72,
#   (-96.18, 42.78): 36.76,
#   (-96.18, 48.07): 30.15,
#   (-96.17, 44.99): 35.63,
#   (-96.05, 42.99): 37.99,
#   (-96.02, 41.37): 53.64,
#   (-95.98, 36.04): 69.44,
#   (-95.97, 45.57): 35.56,
#   (-95.9, 41.12): 62.95,
#   (-95.89, 36.2): 66.14,
#   (-95.88, 46.83): 38.86,
#   (-95.83, 43.21): 37.63,
#   (-95.82, 44.45): 40.34,
#   (-95.78, 34.9): 36.31,
#   (-95.75, 41.26): 62.95,
#   (-95.7, 44.97): 40.89,
#   (-95.68, 48.86): 24.96,
#   (-95.66, 29.62): 177.79,
#   (-95.66, 38.95): 53.84,
#   (-95.63, 39.07): 50.47,
#   (-95.59, 30.75): 53.15,
#   (-95.59, 40.08): 37.03,
#   (-95.57, 37.09): 35.45,
#   (-95.57, 43.66): 38.43,
#   (-95.55, 30.06): 135.39,
#   (-95.5, 37.33): 35.45,
#   (-95.48, 37.67): 35.02,
#   (-95.46, 29.11): 68.6,
#   (-95.45, 33.64): 39.78,
#   (-95.41, 30.35): 76.6,
#   (-95.4, 32.35): 57.1,
#   (-95.4, 40.75): 40.83,
#   (-95.39, 45.88): 41.38,
#   (-95.37, 41.99): 38.26,
#   (-95.36, 29.99): 135.39,
#   (-95.36, 35.66): 45.73,
#   (-95.32, 45.64): 47.97,
#   (-95.25, 41.01): 41.97,
#   (-95.23, 42.6): 37.88,
#   (-95.21, 39.01): 61.94,
#   (-95.2, 43.16): 39.54,
#   (-95.2, 46.45): 41.95,
#   (-95.16, 29.61): 123.26,
#   (-95.1, 43.91): 41.61,
#   (-95.08, 44.55): 44.6,
#   (-95.08, 45.12): 49.53,
#   (-95.07, 46.9): 36.09,
#   (-95.03, 41.41): 40.31,
#   (-95.02, 40.72): 39.16,
#   (-94.98, 43.65): 44.19,
#   (-94.93, 47.51): 32.57,
#   (-94.92, 41.7): 40.3,
#   (-94.91, 39.77): 54.01,
#   (-94.89, 38.83): 92.12,
#   (-94.86, 29.27): 52.33,
#   (-94.81, 46.38): 44.76,
#   (-94.78, 42.05): 41.99,
#   (-94.75, 31.23): 46.05,
#   (-94.75, 43.41): 41.93,
#   (-94.74, 38.85): 92.12,
#   (-94.72, 39.3): 83.82,
#   (-94.71, 32.39): 50.21,
#   (-94.7, 31.58): 44.64,
#   (-94.61, 48.73): 23.33,
#   (-94.59, 39.12): 116.23,
#   (-94.5, 37.15): 47.61,
#   (-94.5, 45.15): 58.97,
#   (-94.42, 43.65): 51.24,
#   (-94.4, 34.05): 34.44,
#   (-94.38, 46.73): 43.42,
#   (-94.37, 35.33): 47.96,
#   (-94.37, 44.86): 73.85,
#   (-94.35, 41.01): 43.06,
#   (-94.3, 42.61): 42.7,
#   (-94.27, 43.08): 42.82,
#   (-94.22, 36.35): 59.82,
#   (-94.17, 36.01): 47.38,
#   (-94.13, 46.41): 51.14,
#   (-94.1, 36.37): 59.82,
#   (-94.05, 45.55): 75.2,
#   (-94.02, 29.95): 68.09,
#   (-94.01, 33.45): 41.75,
#   (-93.92, 44.22): 82.47,
#   (-93.9, 40.63): 40.3,
#   (-93.87, 42.44): 47.03,
#   (-93.84, 42.05): 51.4,
#   (-93.82, 32.45): 52.79,
#   (-93.75, 42.74): 44.89,
#   (-93.67, 41.54): 74.39,
#   (-93.67, 46.55): 42.01,
#   (-93.66, 32.5): 49.34,
#   (-93.62, 41.99): 59.49,
#   (-93.61, 45.56): 74.5,
#   (-93.58, 34.55): 36.54,
#   (-93.55, 38.73): 53.69,
#   (-93.48, 47.16): 38.64,
#   (-93.47, 44.83): 163.71,
#   (-93.4, 48.57): 25.55,
#   (-93.39, 37.24): 66.27,
#   (-93.37, 43.68): 59.84,
#   (-93.35, 41.02): 51.76,
#   (-93.35, 45.06): 219.29,
#   (-93.33, 43.16): 49.98,
#   (-93.27, 45.89): 58.14,
#   (-93.25, 45.56): 78.06,
#   (-93.23, 30.13): 46.47,
#   (-93.2, 45.15): 219.29,
#   (-93.19, 31.05): 37.72,
#   (-93.18, 38.7): 49.86,
#   (-93.16, 36.26): 42.01,
#   (-93.1, 34.48): 48.75,
#   (-93.1, 35.26): 44.14,
#   (-93.1, 41.3): 57.7,
#   (-93.05, 44.93): 162.57,
#   (-93.03, 44.85): 162.57,
#   (-93.02, 41.67): 58.68,
#   (-92.95, 45.7): 68.08,
#   (-92.93, 43.67): 61.84,
#   (-92.92, 42.11): 56.44,
#   (-92.81, 33.22): 38.14,
#   (-92.69, 45.31): 103.57,
#   (-92.56, 31.34): 45.61,
#   (-92.55, 38.1): 47.38,
#   (-92.54, 40.1): 46.03,
#   (-92.5, 46.7): 57.81,
#   (-92.49, 43.9): 78.64,
#   (-92.48, 44.59): 86.75,
#   (-92.47, 36.37): 39.78,
#   (-92.45, 41.11): 53.95,
#   (-92.4, 42.55): 54.73,
#   (-92.3, 31.4): 45.61,
#   (-92.25, 34.83): 70.44,
#   (-92.22, 38.82): 55.32,
#   (-92.19, 46.84): 57.46,
#   (-92.16, 38.59): 54.98,
#   (-92.15, 34.92): 70.44,
#   (-92.09, 46.69): 57.81,
#   (-92.04, 32.51): 46.41,
#   (-91.99, 30.21): 57.65,
#   (-91.97, 41.05): 54.57,
#   (-91.94, 34.18): 43.05,
#   (-91.9, 36.88): 39.41,
#   (-91.88, 30.04): 47.34,
#   (-91.77, 38.13): 53.64,
#   (-91.77, 45.42): 62.62,
#   (-91.75, 33.64): 34.6,
#   (-91.73, 43.28): 58.72,
#   (-91.71, 41.88): 79.94,
#   (-91.7, 44.08): 66.46,
#   (-91.67, 41.28): 57.3,
#   (-91.64, 35.73): 41.43,
#   (-91.57, 34.6): 39.08,
#   (-91.54, 41.63): 68.67,
#   (-91.49, 44.87): 70.57,
#   (-91.44, 46.03): 43.92,
#   (-91.42, 40.46): 54.75,
#   (-91.4, 47.25): 37.99,
#   (-91.33, 29.71): 34.47,
#   (-91.3, 31.61): 39.19,
#   (-91.25, 43.88): 72.32,
#   (-91.19, 39.94): 54.62,
#   (-91.15, 30.54): 73.18,
#   (-91.15, 42.22): 64.2,
#   (-91.14, 41.37): 69.03,
#   (-91.13, 40.78): 62.34,
#   (-91.12, 43.02): 61.33,
#   (-91.03, 32.35): 40.64,
#   (-90.93, 36.13): 44.29,
#   (-90.92, 46.55): 39.33,
#   (-90.73, 43.96): 66.65,
#   (-90.7, 42.4): 65.75,
#   (-90.68, 43.16): 65.14,
#   (-90.66, 38.66): 114.85,
#   (-90.65, 35.83): 50.13,
#   (-90.59, 41.61): 97.12,
#   (-90.52, 41.47): 78.18,
#   (-90.47, 31.18): 41.04,
#   (-90.45, 45.93): 41.75,
#   (-90.42, 37.76): 61.36,
#   (-90.37, 38.75): 164.93,
#   (-90.34, 47.75): 30.11,
#   (-90.33, 36.77): 47.06,
#   (-90.32, 41.83): 73.01,
#   (-90.3, 45.1): 53.53,
#   (-90.25, 29.99): 79.67,
#   (-90.24, 42.89): 70.91,
#   (-90.23, 39.78): 65.2,
#   (-90.19, 44.64): 65.53,
#   (-90.16, 38.57): 164.93,
#   (-90.12, 46.53): 37.36,
#   (-90.08, 32.32): 59.39,
#   (-90.08, 33.5): 40.86,
#   (-90.03, 29.83): 99.46,
#   (-90.03, 30.04): 99.46,
#   (-89.99, 35.06): 123.96,
#   (-89.87, 35.35): 73.44,
#   (-89.84, 44.36): 70.65,
#   (-89.83, 38.53): 109.69,
#   (-89.82, 30.35): 57.23,
#   (-89.77, 43.52): 79.73,
#   (-89.72, 45.93): 46.03,
#   (-89.7, 45.2): 57.98,
#   (-89.68, 39.85): 72.48,
#   (-89.68, 40.67): 92.36,
#   (-89.67, 41.74): 85.6,
#   (-89.63, 44.93): 73.01,
#   (-89.58, 42.62): 98.52,
#   (-89.57, 37.23): 57.09,
#   (-89.52, 44.55): 72.83,
#   (-89.47, 45.63): 50.99,
#   (-89.4, 36.0): 53.04,
#   (-89.35, 43.14): 114.18,
#   (-89.34, 31.47): 43.93,
#   (-89.27, 45.93): 45.53,
#   (-89.25, 37.78): 61.25,
#   (-89.1, 45.15): 60.64,
#   (-89.09, 42.2): 131.8,
#   (-89.07, 30.41): 57.22,
#   (-89.04, 42.62): 124.91,
#   (-89.0, 37.75): 61.25,
#   (-88.95, 38.64): 62.6,
#   (-88.92, 35.59): 58.96,
#   (-88.92, 40.48): 83.38,
#   (-88.87, 39.98): 73.52,
#   (-88.86, 38.32): 58.58,
#   (-88.77, 34.26): 50.81,
#   (-88.77, 37.06): 57.4,
#   (-88.75, 32.33): 41.85,
#   (-88.73, 44.61): 81.4,
#   (-88.72, 43.17): 138.32,
#   (-88.7, 43.43): 108.37,
#   (-88.68, 41.37): 131.95,
#   (-88.57, 32.55): 36.7,
#   (-88.56, 43.98): 109.93,
#   (-88.53, 30.46): 51.94,
#   (-88.52, 44.26): 109.93,
#   (-88.51, 47.17): 36.73,
#   (-88.49, 43.77): 98.08,
#   (-88.48, 41.77): 265.34,
#   (-88.44, 33.64): 44.68,
#   (-88.28, 39.48): 66.32,
#   (-88.28, 40.04): 79.02,
#   (-88.25, 30.69): 54.4,
#   (-88.25, 41.91): 265.34,
#   (-88.23, 43.04): 195.61,
#   (-88.17, 41.52): 192.62,
#   (-88.12, 43.42): 118.95,
#   (-88.12, 44.51): 99.81,
#   (-88.11, 45.82): 54.46,
#   (-88.08, 41.61): 227.08,
#   (-88.07, 30.63): 67.33,
#   (-87.94, 42.6): 191.0,
#   (-87.9, 42.95): 124.68,
#   (-87.88, 47.47): 30.16,
#   (-87.87, 42.42): 191.0,
#   (-87.85, 43.77): 94.26,
#   (-87.81, 42.76): 145.33,
#   (-87.75, 41.79): 354.12,
#   (-87.68, 37.81): 81.21,
#   (-87.67, 44.13): 77.96,
#   (-87.64, 45.13): 57.79,
#   (-87.62, 33.21): 52.28,
#   (-87.61, 34.75): 62.32,
#   (-87.61, 38.76): 68.41,
#   (-87.54, 38.04): 73.84,
#   (-87.5, 36.67): 61.23,
#   (-87.42, 44.84): 59.29,
#   (-87.38, 46.35): 43.41,
#   (-87.3, 39.45): 79.93,
#   (-87.25, 32.9): 45.05,
#   (-87.19, 30.47): 60.12,
#   (-87.09, 45.72): 45.48,
#   (-87.04, 31.42): 38.0,
#   (-87.02, 30.72): 47.16,
#   (-87.01, 41.45): 132.33,
#   (-86.95, 34.65): 65.05,
#   (-86.95, 38.25): 71.0,
#   (-86.94, 40.41): 93.94,
#   (-86.79, 34.64): 66.23,
#   (-86.78, 33.18): 70.19,
#   (-86.75, 33.56): 98.71,
#   (-86.69, 36.12): 105.31,
#   (-86.62, 39.14): 89.34,
#   (-86.52, 30.48): 50.72,
#   (-86.47, 30.4): 50.72,
#   (-86.44, 36.98): 68.8,
#   (-86.42, 42.13): 106.0,
#   (-86.4, 43.96): 62.37,
#   (-86.39, 32.3): 52.07,
#   (-86.36, 32.38): 65.97,
#   (-86.33, 41.71): 128.43,
#   (-86.3, 39.83): 118.62,
#   (-86.27, 39.71): 118.62,
#   (-86.24, 43.17): 98.11,
#   (-86.23, 44.27): 56.77,
#   (-86.23, 45.95): 36.76,
#   (-86.15, 40.65): 90.14,
#   (-86.1, 42.75): 107.46,
#   (-86.08, 33.97): 67.68,
#   (-85.97, 37.9): 107.2,
#   (-85.86, 33.59): 57.22,
#   (-85.8, 39.58): 99.65,
#   (-85.73, 38.18): 128.46,
#   (-85.71, 31.28): 43.42,
#   (-85.68, 30.21): 36.82,
#   (-85.66, 38.23): 128.46,
#   (-85.58, 44.74): 58.33,
#   (-85.55, 42.24): 118.27,
#   (-85.52, 42.88): 136.26,
#   (-85.5, 43.72): 87.78,
#   (-85.45, 31.32): 43.54,
#   (-85.45, 46.31): 36.75,
#   (-85.44, 41.82): 102.36,
#   (-85.42, 44.28): 67.98,
#   (-85.39, 40.23): 96.73,
#   (-85.27, 45.31): 48.32,
#   (-85.25, 42.31): 109.36,
#   (-85.21, 41.01): 98.63,
#   (-85.2, 35.03): 91.2,
#   (-85.19, 44.99): 55.1,
#   (-85.18, 30.84): 41.75,
#   (-85.16, 34.35): 76.11,
#   (-85.09, 35.95): 63.58,
#   (-85.05, 41.93): 101.73,
#   (-85.03, 29.73): 31.38,
#   (-85.0, 32.33): 61.43,
#   (-84.94, 32.52): 59.64,
#   (-84.9, 38.19): 86.19,
#   (-84.87, 34.72): 75.62,
#   (-84.85, 34.12): 108.33,
#   (-84.8, 45.57): 52.42,
#   (-84.77, 33.31): 87.12,
#   (-84.73, 43.62): 93.08,
#   (-84.7, 45.01): 51.05,
#   (-84.69, 43.32): 104.55,
#   (-84.69, 44.37): 62.85,
#   (-84.67, 39.04): 106.71,
#   (-84.64, 45.87): 41.12,
#   (-84.61, 38.04): 93.82,
#   (-84.6, 37.05): 62.01,
#   (-84.58, 41.92): 100.02,
#   (-84.58, 42.78): 128.73,
#   (-84.57, 33.36): 87.12,
#   (-84.53, 39.36): 178.09,
#   (-84.52, 33.78): 167.21,
#   (-84.52, 33.92): 167.21,
#   (-84.46, 42.26): 131.74,
#   (-84.43, 33.64): 134.13,
#   (-84.43, 41.34): 97.4,
#   (-84.42, 39.1): 178.09,
#   (-84.42, 42.57): 116.84,
#   (-84.37, 46.47): 48.26,
#   (-84.35, 30.39): 51.23,
#   (-84.3, 33.88): 167.21,
#   (-84.23, 36.02): 92.93,
#   (-84.23, 39.59): 146.81,
#   (-84.22, 39.91): 142.32,
#   (-84.19, 31.54): 54.84,
#   (-84.08, 37.09): 63.01,
#   (-84.08, 41.87): 127.63,
#   (-84.08, 43.53): 119.51,
#   (-84.05, 39.83): 118.84,
#   (-84.03, 40.71): 97.03,
#   (-83.99, 35.82): 92.93,
#   (-83.98, 42.63): 128.75,
#   (-83.83, 34.27): 91.24,
#   (-83.82, 39.42): 108.5,
#   (-83.8, 41.59): 127.63,
#   (-83.75, 42.22): 153.74,
#   (-83.75, 42.97): 152.54,
#   (-83.67, 33.98): 95.67,
#   (-83.67, 41.01): 101.73,
#   (-83.65, 32.69): 67.6,
#   (-83.6, 32.63): 63.43,
#   (-83.58, 45.07): 53.96,
#   (-83.57, 30.07): 39.6,
#   (-83.48, 41.56): 150.64,
#   (-83.43, 41.93): 170.19,
#   (-83.42, 42.67): 225.63,
#   (-83.37, 44.45): 59.9,
#   (-83.35, 42.22): 276.1,
#   (-83.33, 33.95): 71.16,
#   (-83.31, 37.59): 61.84,
#   (-83.28, 30.78): 45.83,
#   (-83.19, 30.97): 45.83,
#   (-83.11, 29.55): 44.7,
#   (-83.08, 40.08): 181.82,
#   (-83.06, 40.62): 96.09,
#   (-82.98, 43.78): 71.99,
#   (-82.92, 39.8): 112.0,
#   (-82.89, 34.67): 77.99,
#   (-82.88, 39.99): 181.82,
#   (-82.83, 41.62): 105.9,
#   (-82.83, 42.6): 198.25,
#   (-82.71, 34.5): 69.47,
#   (-82.69, 27.91): 106.2,
#   (-82.66, 39.76): 100.31,
#   (-82.56, 27.4): 101.3,
#   (-82.56, 38.38): 84.48,
#   (-82.54, 27.96): 121.55,
#   (-82.54, 35.43): 74.63,
#   (-82.52, 36.99): 61.95,
#   (-82.52, 40.82): 120.31,
#   (-82.52, 42.91): 100.12,
#   (-82.51, 31.54): 42.96,
#   (-82.45, 27.07): 75.25,
#   (-82.45, 28.47): 96.67,
#   (-82.4, 31.25): 47.22,
#   (-82.4, 36.48): 68.15,
#   (-82.27, 29.69): 62.87,
#   (-82.22, 29.17): 77.2,
#   (-82.22, 34.9): 94.29,
#   (-82.18, 41.34): 136.48,
#   (-82.16, 34.25): 66.87,
#   (-82.04, 33.47): 69.23,
#   (-82.03, 36.69): 63.64,
#   (-81.99, 26.92): 67.45,
#   (-81.97, 33.37): 58.56,
#   (-81.93, 35.43): 74.54,
#   (-81.89, 39.94): 84.54,
#   (-81.89, 40.88): 135.09,
#   (-81.87, 30.22): 116.72,
#   (-81.86, 26.59): 75.65,
#   (-81.85, 41.41): 201.09,
#   (-81.81, 28.82): 86.74,
#   (-81.78, 26.15): 60.09,
#   (-81.76, 26.54): 73.3,
#   (-81.69, 30.49): 68.25,
#   (-81.68, 30.23): 116.72,
#   (-81.68, 41.52): 201.09,
#   (-81.59, 38.38): 76.73,
#   (-81.45, 31.26): 48.54,
#   (-81.44, 39.35): 81.56,
#   (-81.44, 40.92): 154.75,
#   (-81.42, 36.43): 57.95,
#   (-81.42, 40.47): 110.09,
#   (-81.39, 35.74): 90.64,
#   (-81.34, 36.9): 56.19,
#   (-81.33, 28.43): 103.43,
#   (-81.33, 28.55): 144.71,
#   (-81.27, 29.87): 65.39,
#   (-81.24, 28.78): 105.59,
#   (-81.21, 37.3): 57.34,
#   (-81.2, 32.12): 58.88,
#   (-81.16, 35.2): 109.04,
#   (-81.15, 32.01): 50.31,
#   (-81.13, 37.8): 64.93,
#   (-81.12, 33.94): 69.13,
#   (-81.06, 29.18): 75.23,
#   (-81.06, 34.99): 109.04,
#   (-81.05, 24.73): 22.02,
#   (-81.0, 33.97): 89.65,
#   (-80.94, 35.21): 109.04,
#   (-80.86, 33.46): 61.25,
#   (-80.82, 36.77): 64.28,
#   (-80.72, 32.48): 50.07,
#   (-80.7, 41.78): 101.05,
#   (-80.67, 37.14): 64.98,
#   (-80.67, 41.25): 109.49,
#   (-80.65, 28.1): 72.8,
#   (-80.65, 40.18): 111.25,
#   (-80.62, 35.02): 118.49,
#   (-80.48, 33.97): 70.53,
#   (-80.42, 27.66): 53.43,
#   (-80.4, 37.21): 75.15,
#   (-80.4, 37.86): 53.1,
#   (-80.38, 27.5): 64.34,
#   (-80.3, 25.82): 170.39,
#   (-80.28, 40.14): 111.12,
#   (-80.23, 39.3): 80.77,
#   (-80.23, 40.5): 156.37,
#   (-80.22, 36.13): 110.29,
#   (-80.22, 41.63): 90.64,
#   (-80.18, 42.08): 88.61,
#   (-80.17, 26.2): 163.98,
#   (-80.1, 26.69): 106.02,
#   (-80.04, 32.9): 77.68,
#   (-80.02, 36.63): 81.81,
#   (-79.97, 37.32): 75.15,
#   (-79.94, 36.1): 110.29,
#   (-79.94, 40.78): 108.83,
#   (-79.92, 39.64): 93.86,
#   (-79.92, 40.36): 172.41,
#   (-79.88, 35.65): 78.28,
#   (-79.85, 38.89): 64.47,
#   (-79.85, 41.44): 86.41,
#   (-79.83, 37.95): 56.98,
#   (-79.73, 34.19): 67.68,
#   (-79.48, 36.05): 93.86,
#   (-79.38, 35.24): 74.86,
#   (-79.37, 34.79): 69.25,
#   (-79.35, 42.48): 86.47,
#   (-79.34, 36.57): 81.26,
#   (-79.21, 37.34): 72.91,
#   (-79.1, 40.63): 101.72,
#   (-79.03, 35.17): 90.1,
#   (-78.95, 43.11): 103.98,
#   (-78.94, 35.13): 90.1,
#   (-78.92, 33.68): 55.81,
#   (-78.9, 41.18): 85.55,
#   (-78.88, 34.99): 73.07,
#   (-78.88, 38.26): 77.93,
#   (-78.83, 40.3): 101.72,
#   (-78.79, 35.87): 114.88,
#   (-78.74, 42.94): 149.09,
#   (-78.73, 35.38): 87.14,
#   (-78.64, 41.8): 75.63,
#   (-78.45, 38.14): 87.85,
#   (-78.43, 37.36): 67.21,
#   (-78.41, 41.05): 88.91,
#   (-78.32, 40.3): 100.17,
#   (-78.13, 39.14): 123.67,
#   (-78.05, 36.69): 62.9,
#   (-77.99, 42.11): 76.92,
#   (-77.98, 39.4): 135.57,
#   (-77.97, 38.01): 92.05,
#   (-77.96, 35.34): 69.83,
#   (-77.9, 34.27): 63.17,
#   (-77.89, 35.86): 76.59,
#   (-77.85, 38.53): 132.4,
#   (-77.84, 40.85): 96.56,
#   (-77.73, 39.71): 133.6,
#   (-77.71, 36.44): 64.18,
#   (-77.68, 43.12): 146.09,
#   (-77.61, 34.83): 57.08,
#   (-77.58, 33.48): 22.68,
#   (-77.55, 39.08): 183.47,
#   (-77.5, 37.18): 89.21,
#   (-77.5, 38.72): 132.4,
#   (-77.44, 37.71): 100.04,
#   (-77.44, 38.27): 115.52,
#   (-77.43, 34.7): 42.88,
#   (-77.38, 35.64): 69.42,
#   (-77.32, 37.51): 104.0,
#   (-77.32, 38.72): 274.6,
#   (-77.3, 38.5): 166.23,
#   (-77.06, 42.64): 91.19,
#   (-77.05, 35.07): 59.3,
#   (-77.03, 38.87): 274.6,
#   (-77.01, 36.98): 91.75,
#   (-76.92, 41.24): 118.27,
#   (-76.9, 36.7): 81.06,
#   (-76.89, 42.16): 107.75,
#   (-76.88, 34.9): 34.34,
#   (-76.87, 39.92): 173.24,
#   (-76.85, 38.82): 228.88,
#   (-76.85, 40.22): 180.17,
#   (-76.76, 40.19): 180.17,
#   (-76.68, 39.17): 251.82,
#   (-76.66, 34.73): 34.34,
#   (-76.6, 36.68): 94.48,
#   (-76.57, 36.03): 56.63,
#   (-76.49, 37.13): 131.73,
#   (-76.43, 38.9): 162.87,
#   (-76.4, 38.28): 123.14,
#   (-76.39, 43.35): 99.82,
#   (-76.35, 37.08): 131.73,
#   (-76.29, 40.12): 190.89,
#   (-76.28, 36.93): 140.96,
#   (-76.19, 36.9): 140.96,
#   (-76.18, 36.26): 71.35,
#   (-76.1, 43.11): 122.29,
#   (-76.02, 43.99): 58.08,
#   (-75.98, 42.21): 104.86,
#   (-75.96, 40.37): 214.79,
#   (-75.75, 37.65): 79.53,
#   (-75.73, 41.34): 164.04,
#   (-75.72, 36.9): 81.5,
#   (-75.72, 44.05): 59.7,
#   (-75.7, 35.92): 42.51,
#   (-75.6, 39.67): 199.51,
#   (-75.56, 40.24): 258.35,
#   (-75.55, 35.27): 19.52,
#   (-75.51, 38.34): 94.72,
#   (-75.5, 37.94): 74.34,
#   (-75.47, 39.12): 145.81,
#   (-75.45, 40.65): 256.5,
#   (-75.41, 43.23): 108.25,
#   (-75.38, 41.14): 186.19,
#   (-75.36, 38.69): 114.94,
#   (-75.23, 39.87): 315.54,
#   (-75.15, 40.2): 342.69,
#   (-75.12, 38.31): 103.3,
#   (-75.12, 40.33): 273.57,
#   (-75.08, 39.37): 180.47,
#   (-75.01, 40.08): 342.69,
#   (-74.9, 39.01): 139.48,
#   (-74.85, 44.94): 49.78,
#   (-74.84, 39.94): 290.79,
#   (-74.81, 40.28): 343.95,
#   (-74.78, 41.7): 179.37,
#   (-74.58, 39.46): 168.85,
#   (-74.28, 40.88): 378.4,
#   (-74.27, 41.51): 223.15,
#   (-74.21, 44.39): 55.96,
#   (-74.17, 40.68): 652.44,
#   (-74.12, 40.19): 375.44,
#   (-74.06, 40.85): 612.18,
#   (-73.97, 40.77): 612.18,
#   (-73.88, 40.78): 612.18,
#   (-73.88, 41.63): 237.56,
#   (-73.8, 40.66): 406.23,
#   (-73.8, 42.75): 145.13,
#   (-73.71, 41.07): 322.07,
#   (-73.61, 43.34): 102.39,
#   (-73.48, 41.37): 231.49,
#   (-73.47, 44.65): 62.49,
#   (-73.42, 40.73): 423.49,
#   (-73.25, 42.89): 113.14,
#   (-73.17, 42.7): 113.14,
#   (-73.15, 41.18): 229.83,
#   (-73.15, 44.47): 78.71,
#   (-73.13, 41.48): 231.49,
#   (-73.1, 40.79): 287.42,
#   (-72.94, 43.53): 84.95,
#   (-72.83, 41.51): 243.04,
#   (-72.65, 41.74): 238.42,
#   (-72.61, 44.53): 53.1,
#   (-72.58, 44.2): 65.33,
#   (-72.53, 42.2): 167.36,
#   (-72.52, 43.34): 92.69,
#   (-72.31, 43.63): 102.16,
#   (-72.28, 42.79): 122.18,
#   (-72.18, 41.74): 172.45,
#   (-71.88, 42.27): 223.81,
#   (-71.58, 41.17): 109.69,
#   (-71.54, 44.37): 58.07,
#   ...},
#  'margSocialCosts_so2': {(-124.25, 43.42): 13.99,
#   (-124.24, 41.78): 14.43,
#   (-124.11, 40.98): 10.95,
#   (-124.07, 44.62): 15.15,
#   (-123.94, 46.97): 18.67,
#   (-123.88, 46.16): 17.9,
#   (-123.5, 48.12): 16.41,
#   (-123.38, 42.62): 9.16,
#   (-123.36, 43.24): 9.43,
#   (-123.29, 44.5): 12.98,
#   (-123.21, 44.13): 10.61,
#   (-123.2, 39.13): 10.59,
#   (-123.15, 47.24): 17.01,
#   (-123.13, 45.2): 15.3,
#   (-123.02, 48.52): 19.89,
#   (-123.0, 44.91): 13.57,
#   (-122.95, 45.54): 15.3,
#   (-122.9, 46.97): 17.19,
#   (-122.87, 42.39): 7.52,
#   (-122.86, 45.77): 15.68,
#   (-122.81, 38.51): 13.14,
#   (-122.77, 45.25): 12.59,
#   (-122.76, 47.49): 17.96,
#   (-122.66, 45.62): 15.68,
#   (-122.6, 45.59): 14.94,
#   (-122.55, 47.12): 15.19,
#   (-122.54, 48.79): 13.25,
#   (-122.47, 41.78): 7.04,
#   (-122.43, 47.67): 16.65,
#   (-122.4, 37.62): 22.25,
#   (-122.31, 40.52): 8.56,
#   (-122.28, 38.21): 16.1,
#   (-122.28, 47.91): 15.82,
#   (-122.25, 40.15): 8.8,
#   (-122.21, 47.49): 15.69,
#   (-122.15, 48.16): 14.82,
#   (-122.12, 37.66): 18.34,
#   (-122.05, 37.99): 16.1,
#   (-121.95, 38.27): 16.1,
#   (-121.93, 37.36): 17.37,
#   (-121.79, 36.94): 16.44,
#   (-121.72, 42.15): 6.32,
#   (-121.62, 39.49): 9.26,
#   (-121.61, 36.66): 14.24,
#   (-121.59, 38.7): 12.81,
#   (-121.57, 39.1): 10.87,
#   (-121.44, 39.14): 10.87,
#   (-121.4, 38.67): 12.81,
#   (-121.24, 37.89): 13.05,
#   (-121.17, 45.62): 11.64,
#   (-121.15, 44.25): 7.33,
#   (-120.95, 37.63): 13.33,
#   (-120.71, 39.29): 8.29,
#   (-120.64, 35.24): 12.83,
#   (-120.57, 41.48): 5.42,
#   (-120.53, 46.56): 9.94,
#   (-120.53, 47.03): 10.21,
#   (-120.51, 37.29): 10.72,
#   (-120.4, 42.17): 5.81,
#   (-120.21, 47.4): 9.39,
#   (-120.13, 39.32): 7.83,
#   (-120.11, 36.99): 9.41,
#   (-120.0, 38.89): 7.62,
#   (-119.84, 34.43): 10.48,
#   (-119.77, 39.48): 6.87,
#   (-119.72, 36.78): 7.35,
#   (-119.63, 36.32): 11.23,
#   (-119.6, 46.57): 10.26,
#   (-119.52, 48.46): 8.91,
#   (-119.38, 36.32): 8.24,
#   (-119.32, 47.21): 10.47,
#   (-119.26, 45.83): 9.53,
#   (-119.12, 46.27): 10.26,
#   (-119.1, 34.22): 10.08,
#   (-119.06, 35.43): 8.54,
#   (-118.95, 43.59): 5.72,
#   (-118.83, 45.7): 9.24,
#   (-118.7, 39.42): 4.84,
#   (-118.57, 40.07): 4.91,
#   (-118.36, 37.37): 4.29,
#   (-118.3, 34.03): 13.71,
#   (-118.29, 46.1): 8.93,
#   (-118.01, 45.29): 8.16,
#   (-117.81, 40.9): 5.28,
#   (-117.81, 44.84): 8.18,
#   (-117.73, 33.68): 15.72,
#   (-117.65, 47.62): 9.55,
#   (-117.57, 34.05): 10.06,
#   (-117.42, 47.97): 9.12,
#   (-117.32, 47.68): 9.21,
#   (-117.25, 33.9): 11.36,
#   (-117.15, 32.87): 11.85,
#   (-117.11, 46.74): 8.79,
#   (-117.01, 44.02): 7.53,
#   (-117.01, 46.38): 8.03,
#   (-116.82, 47.77): 8.86,
#   (-116.63, 43.64): 6.65,
#   (-116.22, 43.57): 6.97,
#   (-116.1, 44.88): 6.89,
#   (-116.03, 36.62): 4.83,
#   (-116.01, 39.6): 4.1,
#   (-115.87, 43.04): 6.43,
#   (-115.8, 47.47): 7.85,
#   (-115.79, 40.83): 5.28,
#   (-115.6, 46.14): 6.43,
#   (-115.58, 32.83): 6.59,
#   (-115.16, 36.08): 5.22,
#   (-114.93, 44.17): 5.83,
#   (-114.85, 39.3): 4.5,
#   (-114.72, 33.62): 6.36,
#   (-114.6, 32.65): 6.38,
#   (-114.49, 42.48): 6.0,
#   (-114.46, 42.73): 6.5,
#   (-114.26, 48.3): 7.12,
#   (-114.22, 44.52): 4.66,
#   (-114.09, 46.92): 6.27,
#   (-114.02, 40.72): 4.57,
#   (-113.94, 35.26): 4.57,
#   (-113.87, 45.12): 4.91,
#   (-113.77, 42.54): 6.94,
#   (-113.58, 37.09): 4.48,
#   (-113.1, 37.7): 4.95,
#   (-112.57, 42.92): 7.35,
#   (-112.55, 45.26): 4.86,
#   (-112.51, 45.95): 5.4,
#   (-112.42, 34.65): 5.15,
#   (-112.38, 48.61): 6.69,
#   (-112.07, 43.52): 7.43,
#   (-112.01, 41.2): 7.7,
#   (-111.99, 33.44): 6.11,
#   (-111.97, 40.79): 7.22,
#   (-111.97, 41.12): 7.7,
#   (-111.96, 46.61): 5.49,
#   (-111.88, 43.83): 7.01,
#   (-111.85, 41.79): 7.97,
#   (-111.72, 40.22): 7.14,
#   (-111.67, 35.14): 5.19,
#   (-111.45, 36.93): 4.13,
#   (-111.38, 47.47): 5.74,
#   (-111.19, 47.5): 5.74,
#   (-111.15, 45.79): 5.11,
#   (-110.88, 32.17): 4.15,
#   (-110.85, 31.42): 3.36,
#   (-110.75, 39.55): 5.27,
#   (-110.73, 43.61): 5.68,
#   (-110.72, 35.02): 4.07,
#   (-110.45, 45.7): 4.66,
#   (-110.11, 42.58): 6.42,
#   (-109.78, 48.56): 8.13,
#   (-109.75, 38.76): 4.36,
#   (-109.64, 32.86): 2.96,
#   (-109.6, 31.47): 3.04,
#   (-109.51, 40.44): 5.77,
#   (-109.47, 47.05): 5.55,
#   (-109.38, 34.52): 3.62,
#   (-109.07, 41.59): 6.57,
#   (-109.06, 35.66): 4.93,
#   (-108.95, 44.62): 4.04,
#   (-108.79, 35.51): 4.93,
#   (-108.63, 37.3): 5.18,
#   (-108.54, 39.13): 5.15,
#   (-108.54, 45.81): 5.11,
#   (-108.46, 43.06): 4.3,
#   (-108.23, 36.74): 5.7,
#   (-108.08, 44.52): 5.74,
#   (-107.95, 43.97): 4.47,
#   (-107.9, 38.51): 4.38,
#   (-107.89, 40.05): 5.21,
#   (-107.76, 37.14): 5.08,
#   (-107.73, 39.53): 5.12,
#   (-107.72, 32.26): 3.37,
#   (-107.52, 40.5): 5.15,
#   (-107.22, 40.48): 5.37,
#   (-107.2, 41.81): 5.61,
#   (-107.03, 38.45): 4.48,
#   (-106.98, 44.77): 4.59,
#   (-106.95, 47.33): 7.34,
#   (-106.92, 39.64): 4.77,
#   (-106.87, 39.22): 5.23,
#   (-106.72, 44.38): 5.02,
#   (-106.62, 35.04): 5.12,
#   (-106.62, 48.21): 9.51,
#   (-106.48, 32.38): 3.78,
#   (-106.47, 42.9): 5.12,
#   (-106.38, 31.81): 3.86,
#   (-106.32, 39.23): 4.27,
#   (-106.09, 35.62): 4.67,
#   (-105.98, 32.84): 4.08,
#   (-105.89, 46.43): 7.0,
#   (-105.87, 37.44): 3.7,
#   (-105.67, 36.46): 4.96,
#   (-105.67, 41.31): 4.72,
#   (-105.66, 35.0): 4.27,
#   (-105.57, 48.09): 9.05,
#   (-105.54, 44.34): 6.05,
#   (-105.53, 33.46): 3.21,
#   (-105.39, 42.8): 5.04,
#   (-105.14, 35.65): 3.59,
#   (-104.85, 39.57): 4.72,
#   (-104.81, 31.83): 3.7,
#   (-104.81, 41.16): 4.52,
#   (-104.8, 47.13): 7.61,
#   (-104.75, 39.7): 5.05,
#   (-104.71, 38.81): 5.02,
#   (-104.66, 39.83): 5.07,
#   (-104.62, 40.44): 4.92,
#   (-104.54, 33.31): 3.96,
#   (-104.5, 38.29): 4.28,
#   (-104.34, 37.26): 3.77,
#   (-104.26, 32.34): 3.91,
#   (-104.25, 46.36): 7.11,
#   (-104.18, 47.71): 8.53,
#   (-104.15, 42.07): 5.09,
#   (-104.02, 30.37): 3.01,
#   (-103.72, 39.19): 5.33,
#   (-103.64, 48.2): 9.33,
#   (-103.63, 43.73): 5.45,
#   (-103.6, 41.87): 5.29,
#   (-103.55, 45.6): 6.68,
#   (-103.53, 38.05): 4.51,
#   (-103.32, 34.38): 5.03,
#   (-103.23, 40.17): 5.87,
#   (-103.2, 31.78): 4.98,
#   (-103.15, 36.45): 4.45,
#   (-103.1, 44.15): 5.7,
#   (-103.07, 34.43): 5.54,
#   (-103.05, 44.05): 5.79,
#   (-102.99, 41.1): 5.59,
#   (-102.92, 30.92): 3.94,
#   (-102.8, 42.06): 6.1,
#   (-102.8, 46.8): 8.19,
#   (-102.69, 38.07): 5.04,
#   (-102.66, 46.01): 7.43,
#   (-102.61, 37.28): 4.84,
#   (-102.55, 36.02): 5.5,
#   (-102.52, 43.02): 6.4,
#   (-102.39, 31.92): 5.43,
#   (-102.28, 39.25): 6.06,
#   (-102.21, 31.93): 5.43,
#   (-101.87, 37.0): 5.61,
#   (-101.82, 33.67): 5.72,
#   (-101.77, 41.12): 6.64,
#   (-101.71, 35.22): 5.59,
#   (-101.69, 39.37): 6.89,
#   (-101.6, 44.05): 6.87,
#   (-101.44, 47.66): 9.31,
#   (-101.39, 35.7): 5.95,
#   (-101.36, 48.43): 9.69,
#   (-101.28, 48.26): 9.97,
#   (-100.96, 37.04): 6.47,
#   (-100.92, 29.37): 5.87,
#   (-100.78, 29.36): 6.67,
#   (-100.75, 46.77): 8.52,
#   (-100.73, 37.93): 7.06,
#   (-100.67, 41.12): 7.39,
#   (-100.59, 40.21): 8.25,
#   (-100.55, 42.86): 7.84,
#   (-100.49, 31.35): 5.28,
#   (-100.41, 45.55): 8.17,
#   (-100.29, 34.43): 6.2,
#   (-100.29, 44.38): 7.88,
#   (-99.98, 42.58): 8.1,
#   (-99.97, 37.77): 7.61,
#   (-99.85, 32.43): 6.44,
#   (-99.84, 43.39): 8.52,
#   (-99.83, 39.38): 8.66,
#   (-99.78, 36.3): 7.5,
#   (-99.77, 30.51): 6.53,
#   (-99.68, 32.41): 6.44,
#   (-99.64, 41.44): 8.98,
#   (-99.47, 27.55): 6.76,
#   (-99.33, 40.45): 9.07,
#   (-99.32, 43.77): 8.91,
#   (-99.28, 38.85): 8.74,
#   (-99.27, 34.66): 7.18,
#   (-99.22, 28.46): 7.78,
#   (-99.2, 35.34): 7.58,
#   (-99.17, 29.36): 7.61,
#   (-99.05, 35.01): 7.81,
#   (-99.0, 40.73): 9.32,
#   (-98.98, 34.35): 7.18,
#   (-98.9, 48.11): 10.44,
#   (-98.85, 38.34): 9.1,
#   (-98.83, 38.87): 9.09,
#   (-98.68, 42.47): 9.5,
#   (-98.68, 46.93): 10.14,
#   (-98.55, 37.28): 8.72,
#   (-98.49, 33.98): 7.86,
#   (-98.47, 29.34): 8.9,
#   (-98.46, 29.53): 8.9,
#   (-98.43, 40.6): 9.58,
#   (-98.42, 34.57): 8.11,
#   (-98.42, 45.45): 9.88,
#   (-98.4, 34.65): 8.11,
#   (-98.31, 40.96): 9.68,
#   (-98.28, 29.53): 9.93,
#   (-98.24, 26.18): 6.92,
#   (-98.24, 30.74): 8.73,
#   (-98.23, 44.39): 9.79,
#   (-98.18, 32.22): 8.09,
#   (-98.06, 32.78): 8.18,
#   (-98.05, 29.71): 9.2,
#   (-98.04, 43.78): 10.12,
#   (-98.03, 27.74): 8.9,
#   (-97.99, 36.34): 9.39,
#   (-97.98, 40.89): 10.0,
#   (-97.86, 38.07): 9.57,
#   (-97.85, 29.89): 10.41,
#   (-97.83, 31.07): 8.96,
#   (-97.82, 27.5): 8.36,
#   (-97.77, 30.32): 9.27,
#   (-97.69, 31.09): 8.96,
#   (-97.68, 30.18): 9.79,
#   (-97.67, 28.37): 10.34,
#   (-97.67, 30.68): 9.21,
#   (-97.66, 38.81): 9.74,
#   (-97.65, 26.23): 7.47,
#   (-97.65, 35.53): 8.67,
#   (-97.65, 39.55): 9.79,
#   (-97.6, 35.39): 8.82,
#   (-97.51, 27.77): 10.0,
#   (-97.45, 35.24): 8.7,
#   (-97.44, 41.98): 10.51,
#   (-97.43, 25.91): 7.84,
#   (-97.43, 37.65): 9.52,
#   (-97.42, 35.85): 9.18,
#   (-97.4, 31.15): 9.59,
#   (-97.4, 47.95): 10.98,
#   (-97.38, 35.42): 8.7,
#   (-97.38, 42.92): 10.58,
#   (-97.36, 32.82): 8.78,
#   (-97.33, 41.45): 10.39,
#   (-97.32, 32.97): 8.79,
#   (-97.3, 31.49): 9.56,
#   (-97.27, 37.62): 9.52,
#   (-97.27, 38.07): 9.51,
#   (-97.23, 31.61): 9.8,
#   (-97.22, 37.75): 9.51,
#   (-97.2, 33.21): 8.67,
#   (-97.18, 47.95): 10.66,
#   (-97.15, 44.93): 11.4,
#   (-97.15, 46.1): 10.95,
#   (-97.12, 34.15): 8.9,
#   (-97.1, 36.73): 9.25,
#   (-97.09, 32.66): 9.16,
#   (-97.09, 36.16): 9.22,
#   (-97.05, 28.08): 10.04,
#   (-97.04, 37.17): 9.43,
#   (-96.99, 45.67): 11.15,
#   (-96.97, 32.73): 9.16,
#   (-96.95, 29.91): 10.87,
#   (-96.93, 28.86): 10.79,
#   (-96.93, 48.75): 10.66,
#   (-96.85, 32.85): 9.16,
#   (-96.81, 46.93): 10.82,
#   (-96.8, 44.3): 10.59,
#   (-96.76, 39.06): 10.67,
#   (-96.76, 40.83): 11.09,
#   (-96.75, 40.3): 11.36,
#   (-96.75, 43.58): 10.11,
#   (-96.68, 39.13): 10.67,
#   (-96.62, 47.84): 11.08,
#   (-96.59, 33.18): 9.66,
#   (-96.53, 45.78): 11.33,
#   (-96.52, 41.45): 10.92,
#   (-96.42, 45.31): 11.32,
#   (-96.4, 32.03): 10.1,
#   (-96.38, 42.39): 10.17,
#   (-96.36, 30.59): 10.89,
#   (-96.3, 43.98): 11.16,
#   (-96.27, 32.71): 10.03,
#   (-96.25, 28.73): 10.44,
#   (-96.19, 38.33): 10.06,
#   (-96.18, 41.76): 11.25,
#   (-96.18, 42.78): 10.56,
#   (-96.18, 48.07): 11.12,
#   (-96.17, 44.99): 11.79,
#   (-96.05, 42.99): 10.28,
#   (-96.02, 41.37): 10.99,
#   (-95.98, 36.04): 9.71,
#   (-95.97, 45.57): 11.52,
#   (-95.9, 41.12): 11.44,
#   (-95.89, 36.2): 9.44,
#   (-95.88, 46.83): 11.41,
#   (-95.83, 43.21): 10.84,
#   (-95.82, 44.45): 11.81,
#   (-95.78, 34.9): 9.13,
#   (-95.75, 41.26): 11.44,
#   (-95.7, 44.97): 12.28,
#   (-95.68, 48.86): 11.45,
#   (-95.66, 29.62): 9.76,
#   (-95.66, 38.95): 10.87,
#   (-95.63, 39.07): 11.2,
#   (-95.59, 30.75): 10.53,
#   (-95.59, 40.08): 11.16,
#   (-95.57, 37.09): 9.69,
#   (-95.57, 43.66): 11.19,
#   (-95.55, 30.06): 11.05,
#   (-95.5, 37.33): 9.69,
#   (-95.48, 37.67): 9.83,
#   (-95.46, 29.11): 11.06,
#   (-95.45, 33.64): 9.53,
#   (-95.41, 30.35): 10.97,
#   (-95.4, 32.35): 10.1,
#   (-95.4, 40.75): 11.3,
#   (-95.39, 45.88): 11.91,
#   (-95.37, 41.99): 11.28,
#   (-95.36, 29.99): 11.05,
#   (-95.36, 35.66): 9.2,
#   (-95.32, 45.64): 12.66,
#   (-95.25, 41.01): 11.28,
#   (-95.23, 42.6): 11.35,
#   (-95.21, 39.01): 11.17,
#   (-95.2, 43.16): 11.46,
#   (-95.2, 46.45): 12.16,
#   (-95.16, 29.61): 11.87,
#   (-95.1, 43.91): 11.95,
#   (-95.08, 44.55): 12.47,
#   (-95.08, 45.12): 12.49,
#   (-95.07, 46.9): 11.74,
#   (-95.03, 41.41): 11.82,
#   (-95.02, 40.72): 11.75,
#   (-94.98, 43.65): 12.31,
#   (-94.93, 47.51): 11.52,
#   (-94.92, 41.7): 12.02,
#   (-94.91, 39.77): 11.82,
#   (-94.89, 38.83): 11.45,
#   (-94.86, 29.27): 12.02,
#   (-94.81, 46.38): 12.33,
#   (-94.78, 42.05): 12.03,
#   (-94.75, 31.23): 9.55,
#   (-94.75, 43.41): 12.1,
#   (-94.74, 38.85): 11.45,
#   (-94.72, 39.3): 11.4,
#   (-94.71, 32.39): 9.7,
#   (-94.7, 31.58): 9.38,
#   (-94.61, 48.73): 10.77,
#   (-94.59, 39.12): 11.9,
#   (-94.5, 37.15): 10.55,
#   (-94.5, 45.15): 13.42,
#   (-94.42, 43.65): 13.24,
#   (-94.4, 34.05): 8.73,
#   (-94.38, 46.73): 12.37,
#   (-94.37, 35.33): 9.37,
#   (-94.37, 44.86): 14.12,
#   (-94.35, 41.01): 12.3,
#   (-94.3, 42.61): 12.37,
#   (-94.27, 43.08): 12.42,
#   (-94.22, 36.35): 9.87,
#   (-94.17, 36.01): 9.44,
#   (-94.13, 46.41): 12.84,
#   (-94.1, 36.37): 9.87,
#   (-94.05, 45.55): 13.53,
#   (-94.02, 29.95): 10.79,
#   (-94.01, 33.45): 8.83,
#   (-93.92, 44.22): 14.05,
#   (-93.9, 40.63): 12.54,
#   (-93.87, 42.44): 12.5,
#   (-93.84, 42.05): 12.7,
#   (-93.82, 32.45): 9.24,
#   (-93.75, 42.74): 12.58,
#   (-93.67, 41.54): 13.02,
#   (-93.67, 46.55): 12.65,
#   (-93.66, 32.5): 9.29,
#   (-93.62, 41.99): 12.95,
#   (-93.61, 45.56): 13.86,
#   (-93.58, 34.55): 9.34,
#   (-93.55, 38.73): 12.4,
#   (-93.48, 47.16): 11.9,
#   (-93.47, 44.83): 14.84,
#   (-93.4, 48.57): 11.14,
#   (-93.39, 37.24): 10.38,
#   (-93.37, 43.68): 13.73,
#   (-93.35, 41.02): 13.18,
#   (-93.35, 45.06): 14.24,
#   (-93.33, 43.16): 12.95,
#   (-93.27, 45.89): 13.91,
#   (-93.25, 45.56): 14.13,
#   (-93.23, 30.13): 11.18,
#   (-93.2, 45.15): 14.24,
#   (-93.19, 31.05): 10.1,
#   (-93.18, 38.7): 12.35,
#   (-93.16, 36.26): 10.21,
#   (-93.1, 34.48): 9.42,
#   (-93.1, 35.26): 9.42,
#   (-93.1, 41.3): 13.08,
#   (-93.05, 44.93): 15.19,
#   (-93.03, 44.85): 15.19,
#   (-93.02, 41.67): 13.01,
#   (-92.95, 45.7): 14.03,
#   (-92.93, 43.67): 14.12,
#   (-92.92, 42.11): 12.97,
#   (-92.81, 33.22): 9.18,
#   (-92.69, 45.31): 14.59,
#   (-92.56, 31.34): 10.17,
#   (-92.55, 38.1): 11.06,
#   (-92.54, 40.1): 13.01,
#   (-92.5, 46.7): 13.82,
#   (-92.49, 43.9): 15.31,
#   (-92.48, 44.59): 15.98,
#   (-92.47, 36.37): 9.99,
#   (-92.45, 41.11): 13.41,
#   (-92.4, 42.55): 13.31,
#   (-92.3, 31.4): 10.17,
#   (-92.25, 34.83): 9.93,
#   (-92.22, 38.82): 11.98,
#   (-92.19, 46.84): 14.14,
#   (-92.16, 38.59): 11.63,
#   (-92.15, 34.92): 9.93,
#   (-92.09, 46.69): 13.82,
#   (-92.04, 32.51): 9.92,
#   (-91.99, 30.21): 10.88,
#   (-91.97, 41.05): 13.45,
#   (-91.94, 34.18): 9.71,
#   (-91.9, 36.88): 10.08,
#   (-91.88, 30.04): 10.29,
#   (-91.77, 38.13): 11.64,
#   (-91.77, 45.42): 14.97,
#   (-91.75, 33.64): 10.09,
#   (-91.73, 43.28): 15.24,
#   (-91.71, 41.88): 13.65,
#   (-91.7, 44.08): 15.64,
#   (-91.67, 41.28): 13.24,
#   (-91.64, 35.73): 10.29,
#   (-91.57, 34.6): 10.25,
#   (-91.54, 41.63): 13.96,
#   (-91.49, 44.87): 14.93,
#   (-91.44, 46.03): 13.53,
#   (-91.42, 40.46): 13.21,
#   (-91.4, 47.25): 19.44,
#   (-91.33, 29.71): 10.63,
#   (-91.3, 31.61): 10.09,
#   (-91.25, 43.88): 15.38,
#   (-91.19, 39.94): 13.23,
#   (-91.15, 30.54): 10.2,
#   (-91.15, 42.22): 14.44,
#   (-91.14, 41.37): 14.31,
#   (-91.13, 40.78): 14.27,
#   (-91.12, 43.02): 15.26,
#   (-91.03, 32.35): 9.82,
#   (-90.93, 36.13): 10.91,
#   (-90.92, 46.55): 13.49,
#   (-90.73, 43.96): 15.57,
#   (-90.7, 42.4): 14.55,
#   (-90.68, 43.16): 16.06,
#   (-90.66, 38.66): 11.9,
#   (-90.65, 35.83): 10.5,
#   (-90.59, 41.61): 14.94,
#   (-90.52, 41.47): 14.88,
#   (-90.47, 31.18): 10.38,
#   (-90.45, 45.93): 13.51,
#   (-90.42, 37.76): 12.5,
#   (-90.37, 38.75): 12.06,
#   (-90.34, 47.75): 17.67,
#   (-90.33, 36.77): 11.32,
#   (-90.32, 41.83): 14.25,
#   (-90.3, 45.1): 13.96,
#   (-90.25, 29.99): 10.33,
#   (-90.24, 42.89): 15.88,
#   (-90.23, 39.78): 13.84,
#   (-90.19, 44.64): 14.89,
#   (-90.16, 38.57): 12.06,
#   (-90.12, 46.53): 13.16,
#   (-90.08, 32.32): 9.21,
#   (-90.08, 33.5): 9.95,
#   (-90.03, 29.83): 11.08,
#   (-90.03, 30.04): 11.08,
#   (-89.99, 35.06): 12.21,
#   (-89.87, 35.35): 12.03,
#   (-89.84, 44.36): 15.89,
#   (-89.83, 38.53): 12.87,
#   (-89.82, 30.35): 10.95,
#   (-89.77, 43.52): 15.94,
#   (-89.72, 45.93): 13.09,
#   (-89.7, 45.2): 14.32,
#   (-89.68, 39.85): 14.37,
#   (-89.68, 40.67): 14.93,
#   (-89.67, 41.74): 15.76,
#   (-89.63, 44.93): 14.85,
#   (-89.58, 42.62): 16.4,
#   (-89.57, 37.23): 12.41,
#   (-89.52, 44.55): 15.31,
#   (-89.47, 45.63): 13.58,
#   (-89.4, 36.0): 11.99,
#   (-89.35, 43.14): 16.32,
#   (-89.34, 31.47): 9.23,
#   (-89.27, 45.93): 13.62,
#   (-89.25, 37.78): 13.77,
#   (-89.1, 45.15): 15.34,
#   (-89.09, 42.2): 16.17,
#   (-89.07, 30.41): 11.21,
#   (-89.04, 42.62): 17.08,
#   (-89.0, 37.75): 13.77,
#   (-88.95, 38.64): 14.14,
#   (-88.92, 35.59): 12.43,
#   (-88.92, 40.48): 14.94,
#   (-88.87, 39.98): 14.13,
#   (-88.86, 38.32): 14.11,
#   (-88.77, 34.26): 10.74,
#   (-88.77, 37.06): 12.98,
#   (-88.75, 32.33): 9.17,
#   (-88.73, 44.61): 16.41,
#   (-88.72, 43.17): 18.1,
#   (-88.7, 43.43): 17.16,
#   (-88.68, 41.37): 16.43,
#   (-88.57, 32.55): 9.51,
#   (-88.56, 43.98): 16.58,
#   (-88.53, 30.46): 11.51,
#   (-88.52, 44.26): 16.58,
#   (-88.51, 47.17): 17.4,
#   (-88.49, 43.77): 16.85,
#   (-88.48, 41.77): 17.01,
#   (-88.44, 33.64): 10.31,
#   (-88.28, 39.48): 14.86,
#   (-88.28, 40.04): 14.78,
#   (-88.25, 30.69): 10.29,
#   (-88.25, 41.91): 17.01,
#   (-88.23, 43.04): 17.77,
#   (-88.17, 41.52): 17.22,
#   (-88.12, 43.42): 19.89,
#   (-88.12, 44.51): 16.86,
#   (-88.11, 45.82): 15.11,
#   (-88.08, 41.61): 17.26,
#   (-88.07, 30.63): 10.16,
#   (-87.94, 42.6): 21.54,
#   (-87.9, 42.95): 22.18,
#   (-87.88, 47.47): 18.03,
#   (-87.87, 42.42): 21.54,
#   (-87.85, 43.77): 17.45,
#   (-87.81, 42.76): 21.85,
#   (-87.75, 41.79): 17.2,
#   (-87.68, 37.81): 14.21,
#   (-87.67, 44.13): 20.42,
#   (-87.64, 45.13): 17.37,
#   (-87.62, 33.21): 10.34,
#   (-87.61, 34.75): 11.8,
#   (-87.61, 38.76): 14.44,
#   (-87.54, 38.04): 14.59,
#   (-87.5, 36.67): 13.07,
#   (-87.42, 44.84): 18.53,
#   (-87.38, 46.35): 14.91,
#   (-87.3, 39.45): 15.1,
#   (-87.25, 32.9): 9.97,
#   (-87.19, 30.47): 10.06,
#   (-87.09, 45.72): 16.95,
#   (-87.04, 31.42): 9.35,
#   (-87.02, 30.72): 9.99,
#   (-87.01, 41.45): 17.18,
#   (-86.95, 34.65): 11.38,
#   (-86.95, 38.25): 14.68,
#   (-86.94, 40.41): 15.56,
#   (-86.79, 34.64): 11.28,
#   (-86.78, 33.18): 10.58,
#   (-86.75, 33.56): 11.19,
#   (-86.69, 36.12): 13.05,
#   (-86.62, 39.14): 15.67,
#   (-86.52, 30.48): 10.12,
#   (-86.47, 30.4): 10.12,
#   (-86.44, 36.98): 13.87,
#   (-86.42, 42.13): 17.43,
#   (-86.4, 43.96): 15.96,
#   (-86.39, 32.3): 9.7,
#   (-86.36, 32.38): 10.07,
#   (-86.33, 41.71): 17.45,
#   (-86.3, 39.83): 14.72,
#   (-86.27, 39.71): 14.72,
#   (-86.24, 43.17): 16.96,
#   (-86.23, 44.27): 15.46,
#   (-86.23, 45.95): 16.4,
#   (-86.15, 40.65): 16.2,
#   (-86.1, 42.75): 17.6,
#   (-86.08, 33.97): 11.39,
#   (-85.97, 37.9): 14.9,
#   (-85.86, 33.59): 10.19,
#   (-85.8, 39.58): 15.85,
#   (-85.73, 38.18): 15.46,
#   (-85.71, 31.28): 9.77,
#   (-85.68, 30.21): 8.47,
#   (-85.66, 38.23): 15.46,
#   (-85.58, 44.74): 15.13,
#   (-85.55, 42.24): 17.98,
#   (-85.52, 42.88): 19.05,
#   (-85.5, 43.72): 18.04,
#   (-85.45, 31.32): 9.76,
#   (-85.45, 46.31): 15.5,
#   (-85.44, 41.82): 17.91,
#   (-85.42, 44.28): 17.15,
#   (-85.39, 40.23): 16.14,
#   (-85.27, 45.31): 15.05,
#   (-85.25, 42.31): 18.22,
#   (-85.21, 41.01): 16.64,
#   (-85.2, 35.03): 11.71,
#   (-85.19, 44.99): 15.51,
#   (-85.18, 30.84): 9.65,
#   (-85.16, 34.35): 11.9,
#   (-85.09, 35.95): 12.28,
#   (-85.05, 41.93): 18.72,
#   (-85.03, 29.73): 10.52,
#   (-85.0, 32.33): 10.12,
#   (-84.94, 32.52): 9.99,
#   (-84.9, 38.19): 14.85,
#   (-84.87, 34.72): 11.08,
#   (-84.85, 34.12): 11.54,
#   (-84.8, 45.57): 15.76,
#   (-84.77, 33.31): 10.85,
#   (-84.73, 43.62): 18.16,
#   (-84.7, 45.01): 15.56,
#   (-84.69, 43.32): 19.0,
#   (-84.69, 44.37): 17.03,
#   (-84.67, 39.04): 15.77,
#   (-84.64, 45.87): 17.85,
#   (-84.61, 38.04): 14.29,
#   (-84.6, 37.05): 13.05,
#   (-84.58, 41.92): 18.24,
#   (-84.58, 42.78): 18.3,
#   (-84.57, 33.36): 10.85,
#   (-84.53, 39.36): 16.93,
#   (-84.52, 33.78): 11.14,
#   (-84.52, 33.92): 11.14,
#   (-84.46, 42.26): 18.98,
#   (-84.43, 33.64): 11.67,
#   (-84.43, 41.34): 17.24,
#   (-84.42, 39.1): 16.93,
#   (-84.42, 42.57): 18.28,
#   (-84.37, 46.47): 15.58,
#   (-84.35, 30.39): 9.79,
#   (-84.3, 33.88): 11.14,
#   (-84.23, 36.02): 11.83,
#   (-84.23, 39.59): 17.06,
#   (-84.22, 39.91): 16.74,
#   (-84.19, 31.54): 10.27,
#   (-84.08, 37.09): 13.13,
#   (-84.08, 41.87): 18.15,
#   (-84.08, 43.53): 18.68,
#   (-84.05, 39.83): 16.76,
#   (-84.03, 40.71): 17.19,
#   (-83.99, 35.82): 11.83,
#   (-83.98, 42.63): 18.97,
#   (-83.83, 34.27): 10.7,
#   (-83.82, 39.42): 16.74,
#   (-83.8, 41.59): 18.15,
#   (-83.75, 42.22): 19.19,
#   (-83.75, 42.97): 19.59,
#   (-83.67, 33.98): 11.24,
#   (-83.67, 41.01): 17.67,
#   (-83.65, 32.69): 11.0,
#   (-83.6, 32.63): 10.68,
#   (-83.58, 45.07): 17.07,
#   (-83.57, 30.07): 9.66,
#   (-83.48, 41.56): 19.63,
#   (-83.43, 41.93): 20.14,
#   (-83.42, 42.67): 19.05,
#   (-83.37, 44.45): 19.83,
#   (-83.35, 42.22): 18.68,
#   (-83.33, 33.95): 11.1,
#   (-83.31, 37.59): 13.74,
#   (-83.28, 30.78): 9.73,
#   (-83.19, 30.97): 9.73,
#   (-83.11, 29.55): 10.62,
#   (-83.08, 40.08): 16.86,
#   (-83.06, 40.62): 17.76,
#   (-82.98, 43.78): 18.02,
#   (-82.92, 39.8): 16.7,
#   (-82.89, 34.67): 10.84,
#   (-82.88, 39.99): 16.86,
#   (-82.83, 41.62): 20.38,
#   (-82.83, 42.6): 21.84,
#   (-82.71, 34.5): 10.82,
#   (-82.69, 27.91): 12.01,
#   (-82.66, 39.76): 16.47,
#   (-82.56, 27.4): 12.72,
#   (-82.56, 38.38): 15.01,
#   (-82.54, 27.96): 12.86,
#   (-82.54, 35.43): 10.69,
#   (-82.52, 36.99): 12.73,
#   (-82.52, 40.82): 18.45,
#   (-82.52, 42.91): 17.74,
#   (-82.51, 31.54): 9.64,
#   (-82.45, 27.07): 12.61,
#   (-82.45, 28.47): 12.17,
#   (-82.4, 31.25): 10.07,
#   (-82.4, 36.48): 11.36,
#   (-82.27, 29.69): 10.81,
#   (-82.22, 29.17): 11.7,
#   (-82.22, 34.9): 11.18,
#   (-82.18, 41.34): 18.51,
#   (-82.16, 34.25): 11.51,
#   (-82.04, 33.47): 11.35,
#   (-82.03, 36.69): 11.64,
#   (-81.99, 26.92): 12.87,
#   (-81.97, 33.37): 11.24,
#   (-81.93, 35.43): 11.27,
#   (-81.89, 39.94): 16.54,
#   (-81.89, 40.88): 17.99,
#   (-81.87, 30.22): 12.17,
#   (-81.86, 26.59): 12.34,
#   (-81.85, 41.41): 17.37,
#   (-81.81, 28.82): 12.82,
#   (-81.78, 26.15): 11.86,
#   (-81.76, 26.54): 11.84,
#   (-81.69, 30.49): 11.98,
#   (-81.68, 30.23): 12.17,
#   (-81.68, 41.52): 17.37,
#   (-81.59, 38.38): 14.38,
#   (-81.45, 31.26): 11.84,
#   (-81.44, 39.35): 16.15,
#   (-81.44, 40.92): 17.99,
#   (-81.42, 36.43): 11.07,
#   (-81.42, 40.47): 16.96,
#   (-81.39, 35.74): 11.72,
#   (-81.34, 36.9): 11.44,
#   (-81.33, 28.43): 12.64,
#   (-81.33, 28.55): 12.8,
#   (-81.27, 29.87): 11.54,
#   (-81.24, 28.78): 12.12,
#   (-81.21, 37.3): 11.91,
#   (-81.2, 32.12): 11.27,
#   (-81.16, 35.2): 12.0,
#   (-81.15, 32.01): 11.52,
#   (-81.13, 37.8): 13.38,
#   (-81.12, 33.94): 12.03,
#   (-81.06, 29.18): 10.4,
#   (-81.06, 34.99): 12.0,
#   (-81.05, 24.73): 9.27,
#   (-81.0, 33.97): 12.08,
#   (-80.94, 35.21): 12.0,
#   (-80.86, 33.46): 11.97,
#   (-80.82, 36.77): 11.42,
#   (-80.72, 32.48): 11.64,
#   (-80.7, 41.78): 18.5,
#   (-80.67, 37.14): 11.92,
#   (-80.67, 41.25): 18.13,
#   (-80.65, 28.1): 10.48,
#   (-80.65, 40.18): 17.14,
#   (-80.62, 35.02): 11.73,
#   (-80.48, 33.97): 12.47,
#   (-80.42, 27.66): 10.37,
#   (-80.4, 37.21): 12.36,
#   (-80.4, 37.86): 12.72,
#   (-80.38, 27.5): 10.21,
#   (-80.3, 25.82): 10.08,
#   (-80.28, 40.14): 16.62,
#   (-80.23, 39.3): 14.85,
#   (-80.23, 40.5): 17.49,
#   (-80.22, 36.13): 12.42,
#   (-80.22, 41.63): 17.98,
#   (-80.18, 42.08): 17.5,
#   (-80.17, 26.2): 10.06,
#   (-80.1, 26.69): 10.1,
#   (-80.04, 32.9): 12.3,
#   (-80.02, 36.63): 12.32,
# ...
#   (-90.33, 36.77): '[$USD2023/lb]',
#   (-90.32, 41.83): '[$USD2023/lb]',
#   (-90.3, 45.1): '[$USD2023/lb]',
#   (-90.25, 29.99): '[$USD2023/lb]',
#   (-90.24, 42.89): '[$USD2023/lb]',
#   (-90.23, 39.78): '[$USD2023/lb]',
#   (-90.19, 44.64): '[$USD2023/lb]',
#   (-90.16, 38.57): '[$USD2023/lb]',
#   (-90.12, 46.53): '[$USD2023/lb]',
#   (-90.08, 32.32): '[$USD2023/lb]',
#   (-90.08, 33.5): '[$USD2023/lb]',
#   (-90.03, 29.83): '[$USD2023/lb]',
#   (-90.03, 30.04): '[$USD2023/lb]',
#   (-89.99, 35.06): '[$USD2023/lb]',
#   (-89.87, 35.35): '[$USD2023/lb]',
#   (-89.84, 44.36): '[$USD2023/lb]',
#   (-89.83, 38.53): '[$USD2023/lb]',
#   (-89.82, 30.35): '[$USD2023/lb]',
#   (-89.77, 43.52): '[$USD2023/lb]',
#   (-89.72, 45.93): '[$USD2023/lb]',
#   (-89.7, 45.2): '[$USD2023/lb]',
#   (-89.68, 39.85): '[$USD2023/lb]',
#   (-89.68, 40.67): '[$USD2023/lb]',
#   (-89.67, 41.74): '[$USD2023/lb]',
#   (-89.63, 44.93): '[$USD2023/lb]',
#   (-89.58, 42.62): '[$USD2023/lb]',
#   (-89.57, 37.23): '[$USD2023/lb]',
#   (-89.52, 44.55): '[$USD2023/lb]',
#   (-89.47, 45.63): '[$USD2023/lb]',
#   (-89.4, 36.0): '[$USD2023/lb]',
#   (-89.35, 43.14): '[$USD2023/lb]',
#   (-89.34, 31.47): '[$USD2023/lb]',
#   (-89.27, 45.93): '[$USD2023/lb]',
#   (-89.25, 37.78): '[$USD2023/lb]',
#   (-89.1, 45.15): '[$USD2023/lb]',
#   (-89.09, 42.2): '[$USD2023/lb]',
#   (-89.07, 30.41): '[$USD2023/lb]',
#   (-89.04, 42.62): '[$USD2023/lb]',
#   (-89.0, 37.75): '[$USD2023/lb]',
#   (-88.95, 38.64): '[$USD2023/lb]',
#   (-88.92, 35.59): '[$USD2023/lb]',
#   (-88.92, 40.48): '[$USD2023/lb]',
#   (-88.87, 39.98): '[$USD2023/lb]',
#   (-88.86, 38.32): '[$USD2023/lb]',
#   (-88.77, 34.26): '[$USD2023/lb]',
#   (-88.77, 37.06): '[$USD2023/lb]',
#   (-88.75, 32.33): '[$USD2023/lb]',
#   (-88.73, 44.61): '[$USD2023/lb]',
#   (-88.72, 43.17): '[$USD2023/lb]',
#   (-88.7, 43.43): '[$USD2023/lb]',
#   (-88.68, 41.37): '[$USD2023/lb]',
#   (-88.57, 32.55): '[$USD2023/lb]',
#   (-88.56, 43.98): '[$USD2023/lb]',
#   (-88.53, 30.46): '[$USD2023/lb]',
#   (-88.52, 44.26): '[$USD2023/lb]',
#   (-88.51, 47.17): '[$USD2023/lb]',
#   (-88.49, 43.77): '[$USD2023/lb]',
#   (-88.48, 41.77): '[$USD2023/lb]',
#   (-88.44, 33.64): '[$USD2023/lb]',
#   (-88.28, 39.48): '[$USD2023/lb]',
#   (-88.28, 40.04): '[$USD2023/lb]',
#   (-88.25, 30.69): '[$USD2023/lb]',
#   (-88.25, 41.91): '[$USD2023/lb]',
#   (-88.23, 43.04): '[$USD2023/lb]',
#   (-88.17, 41.52): '[$USD2023/lb]',
#   (-88.12, 43.42): '[$USD2023/lb]',
#   (-88.12, 44.51): '[$USD2023/lb]',
#   (-88.11, 45.82): '[$USD2023/lb]',
#   (-88.08, 41.61): '[$USD2023/lb]',
#   (-88.07, 30.63): '[$USD2023/lb]',
#   (-87.94, 42.6): '[$USD2023/lb]',
#   (-87.9, 42.95): '[$USD2023/lb]',
#   (-87.88, 47.47): '[$USD2023/lb]',
#   (-87.87, 42.42): '[$USD2023/lb]',
#   (-87.85, 43.77): '[$USD2023/lb]',
#   (-87.81, 42.76): '[$USD2023/lb]',
#   (-87.75, 41.79): '[$USD2023/lb]',
#   (-87.68, 37.81): '[$USD2023/lb]',
#   (-87.67, 44.13): '[$USD2023/lb]',
#   (-87.64, 45.13): '[$USD2023/lb]',
#   (-87.62, 33.21): '[$USD2023/lb]',
#   (-87.61, 34.75): '[$USD2023/lb]',
#   (-87.61, 38.76): '[$USD2023/lb]',
#   (-87.54, 38.04): '[$USD2023/lb]',
#   (-87.5, 36.67): '[$USD2023/lb]',
#   (-87.42, 44.84): '[$USD2023/lb]',
#   (-87.38, 46.35): '[$USD2023/lb]',
#   (-87.3, 39.45): '[$USD2023/lb]',
#   (-87.25, 32.9): '[$USD2023/lb]',
#   (-87.19, 30.47): '[$USD2023/lb]',
#   (-87.09, 45.72): '[$USD2023/lb]',
#   (-87.04, 31.42): '[$USD2023/lb]',
#   (-87.02, 30.72): '[$USD2023/lb]',
#   (-87.01, 41.45): '[$USD2023/lb]',
#   (-86.95, 34.65): '[$USD2023/lb]',
#   (-86.95, 38.25): '[$USD2023/lb]',
#   (-86.94, 40.41): '[$USD2023/lb]',
#   (-86.79, 34.64): '[$USD2023/lb]',
#   (-86.78, 33.18): '[$USD2023/lb]',
#   (-86.75, 33.56): '[$USD2023/lb]',
#   (-86.69, 36.12): '[$USD2023/lb]',
#   (-86.62, 39.14): '[$USD2023/lb]',
#   (-86.52, 30.48): '[$USD2023/lb]',
#   (-86.47, 30.4): '[$USD2023/lb]',
#   (-86.44, 36.98): '[$USD2023/lb]',
#   (-86.42, 42.13): '[$USD2023/lb]',
#   (-86.4, 43.96): '[$USD2023/lb]',
#   (-86.39, 32.3): '[$USD2023/lb]',
#   (-86.36, 32.38): '[$USD2023/lb]',
#   (-86.33, 41.71): '[$USD2023/lb]',
#   (-86.3, 39.83): '[$USD2023/lb]',
#   (-86.27, 39.71): '[$USD2023/lb]',
#   (-86.24, 43.17): '[$USD2023/lb]',
#   (-86.23, 44.27): '[$USD2023/lb]',
#   (-86.23, 45.95): '[$USD2023/lb]',
#   (-86.15, 40.65): '[$USD2023/lb]',
#   (-86.1, 42.75): '[$USD2023/lb]',
#   (-86.08, 33.97): '[$USD2023/lb]',
#   (-85.97, 37.9): '[$USD2023/lb]',
#   (-85.86, 33.59): '[$USD2023/lb]',
#   (-85.8, 39.58): '[$USD2023/lb]',
#   (-85.73, 38.18): '[$USD2023/lb]',
#   (-85.71, 31.28): '[$USD2023/lb]',
#   (-85.68, 30.21): '[$USD2023/lb]',
#   (-85.66, 38.23): '[$USD2023/lb]',
#   (-85.58, 44.74): '[$USD2023/lb]',
#   (-85.55, 42.24): '[$USD2023/lb]',
#   (-85.52, 42.88): '[$USD2023/lb]',
#   (-85.5, 43.72): '[$USD2023/lb]',
#   (-85.45, 31.32): '[$USD2023/lb]',
#   (-85.45, 46.31): '[$USD2023/lb]',
#   (-85.44, 41.82): '[$USD2023/lb]',
#   (-85.42, 44.28): '[$USD2023/lb]',
#   (-85.39, 40.23): '[$USD2023/lb]',
#   (-85.27, 45.31): '[$USD2023/lb]',
#   (-85.25, 42.31): '[$USD2023/lb]',
#   (-85.21, 41.01): '[$USD2023/lb]',
#   (-85.2, 35.03): '[$USD2023/lb]',
#   (-85.19, 44.99): '[$USD2023/lb]',
#   (-85.18, 30.84): '[$USD2023/lb]',
#   (-85.16, 34.35): '[$USD2023/lb]',
#   (-85.09, 35.95): '[$USD2023/lb]',
#   (-85.05, 41.93): '[$USD2023/lb]',
#   (-85.03, 29.73): '[$USD2023/lb]',
#   (-85.0, 32.33): '[$USD2023/lb]',
#   (-84.94, 32.52): '[$USD2023/lb]',
#   (-84.9, 38.19): '[$USD2023/lb]',
#   (-84.87, 34.72): '[$USD2023/lb]',
#   (-84.85, 34.12): '[$USD2023/lb]',
#   (-84.8, 45.57): '[$USD2023/lb]',
#   (-84.77, 33.31): '[$USD2023/lb]',
#   (-84.73, 43.62): '[$USD2023/lb]',
#   (-84.7, 45.01): '[$USD2023/lb]',
#   (-84.69, 43.32): '[$USD2023/lb]',
#   (-84.69, 44.37): '[$USD2023/lb]',
#   (-84.67, 39.04): '[$USD2023/lb]',
#   (-84.64, 45.87): '[$USD2023/lb]',
#   (-84.61, 38.04): '[$USD2023/lb]',
#   (-84.6, 37.05): '[$USD2023/lb]',
#   (-84.58, 41.92): '[$USD2023/lb]',
#   (-84.58, 42.78): '[$USD2023/lb]',
#   (-84.57, 33.36): '[$USD2023/lb]',
#   (-84.53, 39.36): '[$USD2023/lb]',
#   (-84.52, 33.78): '[$USD2023/lb]',
#   (-84.52, 33.92): '[$USD2023/lb]',
#   (-84.46, 42.26): '[$USD2023/lb]',
#   (-84.43, 33.64): '[$USD2023/lb]',
#   (-84.43, 41.34): '[$USD2023/lb]',
#   (-84.42, 39.1): '[$USD2023/lb]',
#   (-84.42, 42.57): '[$USD2023/lb]',
#   (-84.37, 46.47): '[$USD2023/lb]',
#   (-84.35, 30.39): '[$USD2023/lb]',
#   (-84.3, 33.88): '[$USD2023/lb]',
#   (-84.23, 36.02): '[$USD2023/lb]',
#   (-84.23, 39.59): '[$USD2023/lb]',
#   (-84.22, 39.91): '[$USD2023/lb]',
#   (-84.19, 31.54): '[$USD2023/lb]',
#   (-84.08, 37.09): '[$USD2023/lb]',
#   (-84.08, 41.87): '[$USD2023/lb]',
#   (-84.08, 43.53): '[$USD2023/lb]',
#   (-84.05, 39.83): '[$USD2023/lb]',
#   (-84.03, 40.71): '[$USD2023/lb]',
#   (-83.99, 35.82): '[$USD2023/lb]',
#   (-83.98, 42.63): '[$USD2023/lb]',
#   (-83.83, 34.27): '[$USD2023/lb]',
#   (-83.82, 39.42): '[$USD2023/lb]',
#   (-83.8, 41.59): '[$USD2023/lb]',
#   (-83.75, 42.22): '[$USD2023/lb]',
#   (-83.75, 42.97): '[$USD2023/lb]',
#   (-83.67, 33.98): '[$USD2023/lb]',
#   (-83.67, 41.01): '[$USD2023/lb]',
#   (-83.65, 32.69): '[$USD2023/lb]',
#   (-83.6, 32.63): '[$USD2023/lb]',
#   (-83.58, 45.07): '[$USD2023/lb]',
#   (-83.57, 30.07): '[$USD2023/lb]',
#   (-83.48, 41.56): '[$USD2023/lb]',
#   (-83.43, 41.93): '[$USD2023/lb]',
#   (-83.42, 42.67): '[$USD2023/lb]',
#   (-83.37, 44.45): '[$USD2023/lb]',
#   (-83.35, 42.22): '[$USD2023/lb]',
#   (-83.33, 33.95): '[$USD2023/lb]',
#   (-83.31, 37.59): '[$USD2023/lb]',
#   (-83.28, 30.78): '[$USD2023/lb]',
#   (-83.19, 30.97): '[$USD2023/lb]',
#   (-83.11, 29.55): '[$USD2023/lb]',
#   (-83.08, 40.08): '[$USD2023/lb]',
#   (-83.06, 40.62): '[$USD2023/lb]',
#   (-82.98, 43.78): '[$USD2023/lb]',
#   (-82.92, 39.8): '[$USD2023/lb]',
#   (-82.89, 34.67): '[$USD2023/lb]',
#   (-82.88, 39.99): '[$USD2023/lb]',
#   (-82.83, 41.62): '[$USD2023/lb]',
#   (-82.83, 42.6): '[$USD2023/lb]',
#   (-82.71, 34.5): '[$USD2023/lb]',
#   (-82.69, 27.91): '[$USD2023/lb]',
#   (-82.66, 39.76): '[$USD2023/lb]',
#   (-82.56, 27.4): '[$USD2023/lb]',
#   (-82.56, 38.38): '[$USD2023/lb]',
#   (-82.54, 27.96): '[$USD2023/lb]',
#   (-82.54, 35.43): '[$USD2023/lb]',
#   (-82.52, 36.99): '[$USD2023/lb]',
#   (-82.52, 40.82): '[$USD2023/lb]',
#   (-82.52, 42.91): '[$USD2023/lb]',
#   (-82.51, 31.54): '[$USD2023/lb]',
#   (-82.45, 27.07): '[$USD2023/lb]',
#   (-82.45, 28.47): '[$USD2023/lb]',
#   (-82.4, 31.25): '[$USD2023/lb]',
#   (-82.4, 36.48): '[$USD2023/lb]',
#   (-82.27, 29.69): '[$USD2023/lb]',
#   (-82.22, 29.17): '[$USD2023/lb]',
#   (-82.22, 34.9): '[$USD2023/lb]',
#   (-82.18, 41.34): '[$USD2023/lb]',
#   (-82.16, 34.25): '[$USD2023/lb]',
#   (-82.04, 33.47): '[$USD2023/lb]',
#   (-82.03, 36.69): '[$USD2023/lb]',
#   (-81.99, 26.92): '[$USD2023/lb]',
#   (-81.97, 33.37): '[$USD2023/lb]',
#   (-81.93, 35.43): '[$USD2023/lb]',
#   (-81.89, 39.94): '[$USD2023/lb]',
#   (-81.89, 40.88): '[$USD2023/lb]',
#   (-81.87, 30.22): '[$USD2023/lb]',
#   (-81.86, 26.59): '[$USD2023/lb]',
#   (-81.85, 41.41): '[$USD2023/lb]',
#   (-81.81, 28.82): '[$USD2023/lb]',
#   (-81.78, 26.15): '[$USD2023/lb]',
#   (-81.76, 26.54): '[$USD2023/lb]',
#   (-81.69, 30.49): '[$USD2023/lb]',
#   (-81.68, 30.23): '[$USD2023/lb]',
#   (-81.68, 41.52): '[$USD2023/lb]',
#   (-81.59, 38.38): '[$USD2023/lb]',
#   (-81.45, 31.26): '[$USD2023/lb]',
#   (-81.44, 39.35): '[$USD2023/lb]',
#   (-81.44, 40.92): '[$USD2023/lb]',
#   (-81.42, 36.43): '[$USD2023/lb]',
#   (-81.42, 40.47): '[$USD2023/lb]',
#   (-81.39, 35.74): '[$USD2023/lb]',
#   (-81.34, 36.9): '[$USD2023/lb]',
#   (-81.33, 28.43): '[$USD2023/lb]',
#   (-81.33, 28.55): '[$USD2023/lb]',
#   (-81.27, 29.87): '[$USD2023/lb]',
#   (-81.24, 28.78): '[$USD2023/lb]',
#   (-81.21, 37.3): '[$USD2023/lb]',
#   (-81.2, 32.12): '[$USD2023/lb]',
#   (-81.16, 35.2): '[$USD2023/lb]',
#   (-81.15, 32.01): '[$USD2023/lb]',
#   (-81.13, 37.8): '[$USD2023/lb]',
#   (-81.12, 33.94): '[$USD2023/lb]',
#   (-81.06, 29.18): '[$USD2023/lb]',
#   (-81.06, 34.99): '[$USD2023/lb]',
#   (-81.05, 24.73): '[$USD2023/lb]',
#   (-81.0, 33.97): '[$USD2023/lb]',
#   (-80.94, 35.21): '[$USD2023/lb]',
#   (-80.86, 33.46): '[$USD2023/lb]',
#   (-80.82, 36.77): '[$USD2023/lb]',
#   (-80.72, 32.48): '[$USD2023/lb]',
#   (-80.7, 41.78): '[$USD2023/lb]',
#   (-80.67, 37.14): '[$USD2023/lb]',
#   (-80.67, 41.25): '[$USD2023/lb]',
#   (-80.65, 28.1): '[$USD2023/lb]',
#   (-80.65, 40.18): '[$USD2023/lb]',
#   (-80.62, 35.02): '[$USD2023/lb]',
#   (-80.48, 33.97): '[$USD2023/lb]',
#   (-80.42, 27.66): '[$USD2023/lb]',
#   (-80.4, 37.21): '[$USD2023/lb]',
#   (-80.4, 37.86): '[$USD2023/lb]',
#   (-80.38, 27.5): '[$USD2023/lb]',
#   (-80.3, 25.82): '[$USD2023/lb]',
#   (-80.28, 40.14): '[$USD2023/lb]',
#   (-80.23, 39.3): '[$USD2023/lb]',
#   (-80.23, 40.5): '[$USD2023/lb]',
#   (-80.22, 36.13): '[$USD2023/lb]',
#   (-80.22, 41.63): '[$USD2023/lb]',
#   (-80.18, 42.08): '[$USD2023/lb]',
#   (-80.17, 26.2): '[$USD2023/lb]',
#   (-80.1, 26.69): '[$USD2023/lb]',
#   (-80.04, 32.9): '[$USD2023/lb]',
#   (-80.02, 36.63): '[$USD2023/lb]',
#   (-79.97, 37.32): '[$USD2023/lb]',
#   (-79.94, 36.1): '[$USD2023/lb]',
#   (-79.94, 40.78): '[$USD2023/lb]',
#   (-79.92, 39.64): '[$USD2023/lb]',
#   (-79.92, 40.36): '[$USD2023/lb]',
#   (-79.88, 35.65): '[$USD2023/lb]',
#   (-79.85, 38.89): '[$USD2023/lb]',
#   (-79.85, 41.44): '[$USD2023/lb]',
#   (-79.83, 37.95): '[$USD2023/lb]',
#   (-79.73, 34.19): '[$USD2023/lb]',
#   (-79.48, 36.05): '[$USD2023/lb]',
#   (-79.38, 35.24): '[$USD2023/lb]',
#   (-79.37, 34.79): '[$USD2023/lb]',
#   (-79.35, 42.48): '[$USD2023/lb]',
#   (-79.34, 36.57): '[$USD2023/lb]',
#   (-79.21, 37.34): '[$USD2023/lb]',
#   (-79.1, 40.63): '[$USD2023/lb]',
#   (-79.03, 35.17): '[$USD2023/lb]',
#   (-78.95, 43.11): '[$USD2023/lb]',
#   (-78.94, 35.13): '[$USD2023/lb]',
#   (-78.92, 33.68): '[$USD2023/lb]',
#   (-78.9, 41.18): '[$USD2023/lb]',
#   (-78.88, 34.99): '[$USD2023/lb]',
#   (-78.88, 38.26): '[$USD2023/lb]',
#   (-78.83, 40.3): '[$USD2023/lb]',
#   (-78.79, 35.87): '[$USD2023/lb]',
#   (-78.74, 42.94): '[$USD2023/lb]',
#   (-78.73, 35.38): '[$USD2023/lb]',
#   (-78.64, 41.8): '[$USD2023/lb]',
#   (-78.45, 38.14): '[$USD2023/lb]',
#   (-78.43, 37.36): '[$USD2023/lb]',
#   (-78.41, 41.05): '[$USD2023/lb]',
#   (-78.32, 40.3): '[$USD2023/lb]',
#   (-78.13, 39.14): '[$USD2023/lb]',
#   (-78.05, 36.69): '[$USD2023/lb]',
#   (-77.99, 42.11): '[$USD2023/lb]',
#   (-77.98, 39.4): '[$USD2023/lb]',
#   (-77.97, 38.01): '[$USD2023/lb]',
#   (-77.96, 35.34): '[$USD2023/lb]',
#   (-77.9, 34.27): '[$USD2023/lb]',
#   (-77.89, 35.86): '[$USD2023/lb]',
#   (-77.85, 38.53): '[$USD2023/lb]',
#   (-77.84, 40.85): '[$USD2023/lb]',
#   (-77.73, 39.71): '[$USD2023/lb]',
#   (-77.71, 36.44): '[$USD2023/lb]',
#   (-77.68, 43.12): '[$USD2023/lb]',
#   (-77.61, 34.83): '[$USD2023/lb]',
#   (-77.58, 33.48): '[$USD2023/lb]',
#   (-77.55, 39.08): '[$USD2023/lb]',
#   (-77.5, 37.18): '[$USD2023/lb]',
#   (-77.5, 38.72): '[$USD2023/lb]',
#   (-77.44, 37.71): '[$USD2023/lb]',
#   (-77.44, 38.27): '[$USD2023/lb]',
#   (-77.43, 34.7): '[$USD2023/lb]',
#   (-77.38, 35.64): '[$USD2023/lb]',
#   (-77.32, 37.51): '[$USD2023/lb]',
#   (-77.32, 38.72): '[$USD2023/lb]',
#   (-77.3, 38.5): '[$USD2023/lb]',
#   (-77.06, 42.64): '[$USD2023/lb]',
#   (-77.05, 35.07): '[$USD2023/lb]',
#   (-77.03, 38.87): '[$USD2023/lb]',
#   (-77.01, 36.98): '[$USD2023/lb]',
#   (-76.92, 41.24): '[$USD2023/lb]',
#   (-76.9, 36.7): '[$USD2023/lb]',
#   (-76.89, 42.16): '[$USD2023/lb]',
#   (-76.88, 34.9): '[$USD2023/lb]',
#   (-76.87, 39.92): '[$USD2023/lb]',
#   (-76.85, 38.82): '[$USD2023/lb]',
#   (-76.85, 40.22): '[$USD2023/lb]',
#   (-76.76, 40.19): '[$USD2023/lb]',
#   (-76.68, 39.17): '[$USD2023/lb]',
#   (-76.66, 34.73): '[$USD2023/lb]',
#   (-76.6, 36.68): '[$USD2023/lb]',
#   (-76.57, 36.03): '[$USD2023/lb]',
#   (-76.49, 37.13): '[$USD2023/lb]',
#   (-76.43, 38.9): '[$USD2023/lb]',
#   (-76.4, 38.28): '[$USD2023/lb]',
#   (-76.39, 43.35): '[$USD2023/lb]',
#   (-76.35, 37.08): '[$USD2023/lb]',
#   (-76.29, 40.12): '[$USD2023/lb]',
#   (-76.28, 36.93): '[$USD2023/lb]',
#   (-76.19, 36.9): '[$USD2023/lb]',
#   (-76.18, 36.26): '[$USD2023/lb]',
#   (-76.1, 43.11): '[$USD2023/lb]',
#   (-76.02, 43.99): '[$USD2023/lb]',
#   (-75.98, 42.21): '[$USD2023/lb]',
#   (-75.96, 40.37): '[$USD2023/lb]',
#   (-75.75, 37.65): '[$USD2023/lb]',
#   (-75.73, 41.34): '[$USD2023/lb]',
#   (-75.72, 36.9): '[$USD2023/lb]',
#   (-75.72, 44.05): '[$USD2023/lb]',
#   (-75.7, 35.92): '[$USD2023/lb]',
#   (-75.6, 39.67): '[$USD2023/lb]',
#   (-75.56, 40.24): '[$USD2023/lb]',
#   (-75.55, 35.27): '[$USD2023/lb]',
#   (-75.51, 38.34): '[$USD2023/lb]',
#   (-75.5, 37.94): '[$USD2023/lb]',
#   (-75.47, 39.12): '[$USD2023/lb]',
#   (-75.45, 40.65): '[$USD2023/lb]',
#   (-75.41, 43.23): '[$USD2023/lb]',
#   (-75.38, 41.14): '[$USD2023/lb]',
#   (-75.36, 38.69): '[$USD2023/lb]',
#   (-75.23, 39.87): '[$USD2023/lb]',
#   (-75.15, 40.2): '[$USD2023/lb]',
#   (-75.12, 38.31): '[$USD2023/lb]',
#   (-75.12, 40.33): '[$USD2023/lb]',
#   (-75.08, 39.37): '[$USD2023/lb]',
#   (-75.01, 40.08): '[$USD2023/lb]',
#   (-74.9, 39.01): '[$USD2023/lb]',
#   (-74.85, 44.94): '[$USD2023/lb]',
#   (-74.84, 39.94): '[$USD2023/lb]',
#   (-74.81, 40.28): '[$USD2023/lb]',
#   (-74.78, 41.7): '[$USD2023/lb]',
#   (-74.58, 39.46): '[$USD2023/lb]',
#   (-74.28, 40.88): '[$USD2023/lb]',
#   (-74.27, 41.51): '[$USD2023/lb]',
#   (-74.21, 44.39): '[$USD2023/lb]',
#   (-74.17, 40.68): '[$USD2023/lb]',
#   (-74.12, 40.19): '[$USD2023/lb]',
#   (-74.06, 40.85): '[$USD2023/lb]',
#   (-73.97, 40.77): '[$USD2023/lb]',
#   (-73.88, 40.78): '[$USD2023/lb]',
#   (-73.88, 41.63): '[$USD2023/lb]',
#   (-73.8, 40.66): '[$USD2023/lb]',
#   (-73.8, 42.75): '[$USD2023/lb]',
#   (-73.71, 41.07): '[$USD2023/lb]',
#   (-73.61, 43.34): '[$USD2023/lb]',
#   (-73.48, 41.37): '[$USD2023/lb]',
#   (-73.47, 44.65): '[$USD2023/lb]',
#   (-73.42, 40.73): '[$USD2023/lb]',
#   (-73.25, 42.89): '[$USD2023/lb]',
#   (-73.17, 42.7): '[$USD2023/lb]',
#   (-73.15, 41.18): '[$USD2023/lb]',
#   (-73.15, 44.47): '[$USD2023/lb]',
#   (-73.13, 41.48): '[$USD2023/lb]',
#   (-73.1, 40.79): '[$USD2023/lb]',
#   (-72.94, 43.53): '[$USD2023/lb]',
#   (-72.83, 41.51): '[$USD2023/lb]',
#   (-72.65, 41.74): '[$USD2023/lb]',
#   (-72.61, 44.53): '[$USD2023/lb]',
#   (-72.58, 44.2): '[$USD2023/lb]',
#   (-72.53, 42.2): '[$USD2023/lb]',
#   (-72.52, 43.34): '[$USD2023/lb]',
#   (-72.31, 43.63): '[$USD2023/lb]',
#   (-72.28, 42.79): '[$USD2023/lb]',
#   (-72.18, 41.74): '[$USD2023/lb]',
#   (-71.88, 42.27): '[$USD2023/lb]',
#   (-71.58, 41.17): '[$USD2023/lb]',
#   (-71.54, 44.37): '[$USD2023/lb]',
#   ...}}

# %% [markdown]
# ## Emissions from Electricity Generation

# %% [markdown]
# ### Climate-Related Emissions from CAMBIUM LRMER/SRMER
# ### Includes pre-combustion (fugitive) and combustion

# %%
# INTERPOLATE ANNUAL DATA BETWEEN 5-YEAR TIME STEPS
print("""
-------------------------------------------------------------------------------------------------------
CLIMATE DAMAGES FROM CAMBIUM
-------------------------------------------------------------------------------------------------------
- Load CSV
- Convert MWh --> kWh and kg --> metric tons (mt)
- Inflate updated Social Cost of Carbon from $190 USD2020 to $USD2023
- Convert SCC to $USD2023/lb
- Calculate damage factors for CO2e: LRMER[lb/kWh] * SCC[$USD2023/lb] = $USD2023/kWh
- Map state, county pairs to Cambium 2023 GEA region

Possibly for other emissions projections:
- Calculate projection factors for each group of scenario and GEA region for 2025 to 2050 (normalize all annual data in group by 2025 value) 
-------------------------------------------------------------------------------------------------------
""")
# Out:
# -------------------------------------------------------------------------------------------------------
# CLIMATE DAMAGES FROM CAMBIUM
# -------------------------------------------------------------------------------------------------------
# - Load CSV
# - Convert MWh --> kWh and kg --> metric tons (mt)
# - Inflate updated Social Cost of Carbon from $190 USD2020 to $USD2023
# - Convert SCC to $USD2023/lb
# - Calculate damage factors for CO2e: LRMER[lb/kWh] * SCC[$USD2023/lb] = $USD2023/kWh
# - Map state, county pairs to Cambium 2023 GEA region
#
# Possibly for other emissions projections:
# - Calculate projection factors for each group of scenario and GEA region for 2025 to 2050 (normalize all annual data in group by 2025 value)
# -------------------------------------------------------------------------------------------------------

# %%
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

print("""
-------------------------------------------------------------------------------------------------------
PRE-IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2021 RELEASE
-------------------------------------------------------------------------------------------------------
""")

# CAMBIUM 2021 FOR PRE-IRA SCENARIO
filename = 'cambium21_midCase_annual_gea.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_cambium21_margEmis_electricity = pd.read_excel(io=file_path, sheet_name='proc_Cambium21_MidCase_gea')

print(f"""
Retrieved data for filename: {filename}
Located at filepath: {file_path}

Loading dataframe ...
Creating lookup dictionary for LRMER and SRMER ...
-------------------------------------------------------------------------------------------------------
""")

# Calculate electricity emission factors for Cambium 2021
# Process the data using the provided function to interpolate and convert units
df_cambium21_processed = calculate_electricity_co2e_cambium(df_cambium21_margEmis_electricity)

# # Display the processed DataFrame
# df_cambium21_processed

# Create the lookup dictionary using the create_cambium_emission_factor_lookup function
emis_preIRA_co2e_cambium21_lookup = create_cambium_co2e_lookup(df_cambium21_processed)

# Display the lookup dictionary
emis_preIRA_co2e_cambium21_lookup
# Out:
# -------------------------------------------------------------------------------------------------------
# PRE-IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2021 RELEASE
# -------------------------------------------------------------------------------------------------------
#
#
# Retrieved data for filename: cambium21_midCase_annual_gea.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\cambium21_midCase_annual_gea.xlsx
#
# Loading dataframe ...
# Creating lookup dictionary for LRMER and SRMER ...
# -------------------------------------------------------------------------------------------------------
# {('MidCase',
#   'AZNMc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0005256,
#    'srmer_ton_per_kWh_co2e': 0.0008118}, 2023: {'lrmer_ton_per_kWh_co2e': 0.000507,
#    'srmer_ton_per_kWh_co2e': 0.0008100999999999999}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0004883999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0008084}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00045575,
#    'srmer_ton_per_kWh_co2e': 0.0008122}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00042310000000000004,
#    'srmer_ton_per_kWh_co2e': 0.000816}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00036945000000000006,
#    'srmer_ton_per_kWh_co2e': 0.00080035}, 2028: {'lrmer_ton_per_kWh_co2e': 0.00031580000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007847}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00031470000000000006,
#    'srmer_ton_per_kWh_co2e': 0.00076725}, 2030: {'lrmer_ton_per_kWh_co2e': 0.00031360000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007497999999999999}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00029605,
#    'srmer_ton_per_kWh_co2e': 0.00073815}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0002785,
#    'srmer_ton_per_kWh_co2e': 0.0007265}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00029995,
#    'srmer_ton_per_kWh_co2e': 0.00073055}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00032139999999999995,
#    'srmer_ton_per_kWh_co2e': 0.0007346000000000001}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00029375,
#    'srmer_ton_per_kWh_co2e': 0.0007183}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0002661,
#    'srmer_ton_per_kWh_co2e': 0.000702}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00026925,
#    'srmer_ton_per_kWh_co2e': 0.00069155}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00027239999999999995,
#    'srmer_ton_per_kWh_co2e': 0.0006811}, 2039: {'lrmer_ton_per_kWh_co2e': 0.0002525,
#    'srmer_ton_per_kWh_co2e': 0.0006772999999999999}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0002326,
#    'srmer_ton_per_kWh_co2e': 0.0006735}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00022214999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0006747000000000001}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0002117,
#    'srmer_ton_per_kWh_co2e': 0.0006759}, 2043: {'lrmer_ton_per_kWh_co2e': 0.0001941,
#    'srmer_ton_per_kWh_co2e': 0.00067085}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0001765,
#    'srmer_ton_per_kWh_co2e': 0.0006657999999999999}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00016365,
#    'srmer_ton_per_kWh_co2e': 0.0006524500000000001}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0001508,
#    'srmer_ton_per_kWh_co2e': 0.0006391}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00015455000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0006349000000000001}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0001583,
#    'srmer_ton_per_kWh_co2e': 0.0006307000000000001}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00015030000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0006299000000000001}, 2050: {'lrmer_ton_per_kWh_co2e': 0.00014230000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0006291000000000001}},
#  ('MidCase',
#   'CAMXc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0003514,
#    'srmer_ton_per_kWh_co2e': 0.0007704}, 2023: {'lrmer_ton_per_kWh_co2e': 0.00031610000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0007775999999999999}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0002808,
#    'srmer_ton_per_kWh_co2e': 0.0007848}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00023835000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0007924}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00019590000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0008}, 2027: {'lrmer_ton_per_kWh_co2e': 0.000163,
#    'srmer_ton_per_kWh_co2e': 0.00079265}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0001301,
#    'srmer_ton_per_kWh_co2e': 0.0007853}, 2029: {'lrmer_ton_per_kWh_co2e': 0.0001547,
#    'srmer_ton_per_kWh_co2e': 0.00076595}, 2030: {'lrmer_ton_per_kWh_co2e': 0.00017930000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0007466}, 2031: {'lrmer_ton_per_kWh_co2e': 0.0001778,
#    'srmer_ton_per_kWh_co2e': 0.0007307}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0001763,
#    'srmer_ton_per_kWh_co2e': 0.0007147999999999999}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00018675,
#    'srmer_ton_per_kWh_co2e': 0.0007218}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0001972,
#    'srmer_ton_per_kWh_co2e': 0.0007287999999999999}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0001712,
#    'srmer_ton_per_kWh_co2e': 0.00070595}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00014519999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0006831000000000001}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00014814999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0006824000000000001}, 2038: {'lrmer_ton_per_kWh_co2e': 0.0001511,
#    'srmer_ton_per_kWh_co2e': 0.0006817}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00013455000000000002,
#    'srmer_ton_per_kWh_co2e': 0.000673}, 2040: {'lrmer_ton_per_kWh_co2e': 0.000118,
#    'srmer_ton_per_kWh_co2e': 0.0006642999999999999}, 2041: {'lrmer_ton_per_kWh_co2e': 0.0001034,
#    'srmer_ton_per_kWh_co2e': 0.0006679}, 2042: {'lrmer_ton_per_kWh_co2e': 8.88e-05,
#    'srmer_ton_per_kWh_co2e': 0.0006715}, 2043: {'lrmer_ton_per_kWh_co2e': 7.434999999999999e-05,
#    'srmer_ton_per_kWh_co2e': 0.0006638}, 2044: {'lrmer_ton_per_kWh_co2e': 5.99e-05,
#    'srmer_ton_per_kWh_co2e': 0.0006561000000000001}, 2045: {'lrmer_ton_per_kWh_co2e': 5.215e-05,
#    'srmer_ton_per_kWh_co2e': 0.0006420499999999999}, 2046: {'lrmer_ton_per_kWh_co2e': 4.44e-05,
#    'srmer_ton_per_kWh_co2e': 0.000628}, 2047: {'lrmer_ton_per_kWh_co2e': 4.455e-05,
#    'srmer_ton_per_kWh_co2e': 0.0006216}, 2048: {'lrmer_ton_per_kWh_co2e': 4.47e-05,
#    'srmer_ton_per_kWh_co2e': 0.0006152}, 2049: {'lrmer_ton_per_kWh_co2e': 4.0400000000000006e-05,
#    'srmer_ton_per_kWh_co2e': 0.0006161500000000001}, 2050: {'lrmer_ton_per_kWh_co2e': 3.61e-05,
#    'srmer_ton_per_kWh_co2e': 0.0006171}},
#  ('MidCase',
#   'ERCTc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0005771,
#    'srmer_ton_per_kWh_co2e': 0.0008089}, 2023: {'lrmer_ton_per_kWh_co2e': 0.00053415,
#    'srmer_ton_per_kWh_co2e': 0.00079355}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0004912,
#    'srmer_ton_per_kWh_co2e': 0.0007782}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00046995,
#    'srmer_ton_per_kWh_co2e': 0.00076425}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0004487,
#    'srmer_ton_per_kWh_co2e': 0.0007503}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00041754999999999993,
#    'srmer_ton_per_kWh_co2e': 0.00075245}, 2028: {'lrmer_ton_per_kWh_co2e': 0.00038639999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0007546}, 2029: {'lrmer_ton_per_kWh_co2e': 0.0003964,
#    'srmer_ton_per_kWh_co2e': 0.0007586500000000001}, 2030: {'lrmer_ton_per_kWh_co2e': 0.00040639999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0007627}, 2031: {'lrmer_ton_per_kWh_co2e': 0.000364,
#    'srmer_ton_per_kWh_co2e': 0.00077245}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0003216,
#    'srmer_ton_per_kWh_co2e': 0.0007822}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00029785,
#    'srmer_ton_per_kWh_co2e': 0.00077915}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00027410000000000005,
#    'srmer_ton_per_kWh_co2e': 0.0007761}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0002455,
#    'srmer_ton_per_kWh_co2e': 0.00074875}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00021690000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0007214}, 2037: {'lrmer_ton_per_kWh_co2e': 0.0002295,
#    'srmer_ton_per_kWh_co2e': 0.0007010499999999999}, 2038: {'lrmer_ton_per_kWh_co2e': 0.0002421,
#    'srmer_ton_per_kWh_co2e': 0.0006807}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00026294999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00066965}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0002838,
#    'srmer_ton_per_kWh_co2e': 0.0006586000000000001}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00032,
#    'srmer_ton_per_kWh_co2e': 0.0006535}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0003562,
#    'srmer_ton_per_kWh_co2e': 0.0006483999999999999}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00035765,
#    'srmer_ton_per_kWh_co2e': 0.0006578499999999999}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0003591,
#    'srmer_ton_per_kWh_co2e': 0.0006672999999999999}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00033325,
#    'srmer_ton_per_kWh_co2e': 0.00067675}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0003074,
#    'srmer_ton_per_kWh_co2e': 0.0006862000000000001}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00027089999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0006903500000000001}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0002344,
#    'srmer_ton_per_kWh_co2e': 0.0006945}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00021745,
#    'srmer_ton_per_kWh_co2e': 0.0006545}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0002005,
#    'srmer_ton_per_kWh_co2e': 0.0006145}},
#  ('MidCase',
#   'FRCCc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0005147000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0007794}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0005301500000000001,
#    'srmer_ton_per_kWh_co2e': 0.0007988499999999999}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0005456,
#    'srmer_ton_per_kWh_co2e': 0.0008183}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0005245499999999999,
#    'srmer_ton_per_kWh_co2e': 0.0008233}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0005035,
#    'srmer_ton_per_kWh_co2e': 0.0008282999999999999}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00048555,
#    'srmer_ton_per_kWh_co2e': 0.0008230999999999999}, 2028: {'lrmer_ton_per_kWh_co2e': 0.00046760000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0008179}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00043685,
#    'srmer_ton_per_kWh_co2e': 0.00077565}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0004061,
#    'srmer_ton_per_kWh_co2e': 0.0007333999999999999}, 2031: {'lrmer_ton_per_kWh_co2e': 0.0004038,
#    'srmer_ton_per_kWh_co2e': 0.0007303499999999999}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0004015,
#    'srmer_ton_per_kWh_co2e': 0.0007273}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00043630000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007323}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0004711,
#    'srmer_ton_per_kWh_co2e': 0.0007373}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00047725,
#    'srmer_ton_per_kWh_co2e': 0.0007317000000000001}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0004834,
#    'srmer_ton_per_kWh_co2e': 0.0007261}, 2037: {'lrmer_ton_per_kWh_co2e': 0.0004787,
#    'srmer_ton_per_kWh_co2e': 0.00072125}, 2038: {'lrmer_ton_per_kWh_co2e': 0.000474,
#    'srmer_ton_per_kWh_co2e': 0.0007164}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00046845,
#    'srmer_ton_per_kWh_co2e': 0.0007054}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0004629,
#    'srmer_ton_per_kWh_co2e': 0.0006944}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00046814999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0006942000000000001}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00047339999999999996,
#    'srmer_ton_per_kWh_co2e': 0.000694}, 2043: {'lrmer_ton_per_kWh_co2e': 0.0004529,
#    'srmer_ton_per_kWh_co2e': 0.0006867}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0004324,
#    'srmer_ton_per_kWh_co2e': 0.0006793999999999999}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00042529999999999993,
#    'srmer_ton_per_kWh_co2e': 0.0006738}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0004182,
#    'srmer_ton_per_kWh_co2e': 0.0006682000000000001}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00036904999999999994,
#    'srmer_ton_per_kWh_co2e': 0.0006671}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00031989999999999997,
#    'srmer_ton_per_kWh_co2e': 0.000666}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00031435,
#    'srmer_ton_per_kWh_co2e': 0.000662}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0003088,
#    'srmer_ton_per_kWh_co2e': 0.000658}},
#  ('MidCase',
#   'MROEc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0006782,
#    'srmer_ton_per_kWh_co2e': 0.0009092999999999999}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0006217999999999999,
#    'srmer_ton_per_kWh_co2e': 0.00093495}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0005654,
#    'srmer_ton_per_kWh_co2e': 0.0009606}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00050855,
#    'srmer_ton_per_kWh_co2e': 0.000943}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0004517,
#    'srmer_ton_per_kWh_co2e': 0.0009253999999999999}, 2027: {'lrmer_ton_per_kWh_co2e': 0.0004062,
#    'srmer_ton_per_kWh_co2e': 0.0008977000000000001}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0003607,
#    'srmer_ton_per_kWh_co2e': 0.00087}, 2029: {'lrmer_ton_per_kWh_co2e': 0.0003726,
#    'srmer_ton_per_kWh_co2e': 0.00087365}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0003845,
#    'srmer_ton_per_kWh_co2e': 0.0008772999999999999}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00035245,
#    'srmer_ton_per_kWh_co2e': 0.00088075}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0003204,
#    'srmer_ton_per_kWh_co2e': 0.0008842}, 2033: {'lrmer_ton_per_kWh_co2e': 0.0003255,
#    'srmer_ton_per_kWh_co2e': 0.0008754000000000001}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0003306,
#    'srmer_ton_per_kWh_co2e': 0.0008666}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00031420000000000005,
#    'srmer_ton_per_kWh_co2e': 0.0008558}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00029780000000000003,
#    'srmer_ton_per_kWh_co2e': 0.000845}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00030520000000000005,
#    'srmer_ton_per_kWh_co2e': 0.00082575}, 2038: {'lrmer_ton_per_kWh_co2e': 0.0003126,
#    'srmer_ton_per_kWh_co2e': 0.0008065}, 2039: {'lrmer_ton_per_kWh_co2e': 0.0002988,
#    'srmer_ton_per_kWh_co2e': 0.00079705}, 2040: {'lrmer_ton_per_kWh_co2e': 0.000285,
#    'srmer_ton_per_kWh_co2e': 0.0007876000000000001}, 2041: {'lrmer_ton_per_kWh_co2e': 0.0002857,
#    'srmer_ton_per_kWh_co2e': 0.0007839500000000001}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00028639999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0007802999999999999}, 2043: {'lrmer_ton_per_kWh_co2e': 0.0002876,
#    'srmer_ton_per_kWh_co2e': 0.00076495}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0002888,
#    'srmer_ton_per_kWh_co2e': 0.0007496}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0002983,
#    'srmer_ton_per_kWh_co2e': 0.0007353500000000001}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0003078,
#    'srmer_ton_per_kWh_co2e': 0.0007211}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00030585000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007088}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00030389999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0006965}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00029495,
#    'srmer_ton_per_kWh_co2e': 0.0007014}, 2050: {'lrmer_ton_per_kWh_co2e': 0.000286,
#    'srmer_ton_per_kWh_co2e': 0.0007063}},
#  ('MidCase',
#   'MROWc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.000682,
#    'srmer_ton_per_kWh_co2e': 0.0008983}, 2023: {'lrmer_ton_per_kWh_co2e': 0.00062025,
#    'srmer_ton_per_kWh_co2e': 0.0009047}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0005585,
#    'srmer_ton_per_kWh_co2e': 0.0009111}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0004915,
#    'srmer_ton_per_kWh_co2e': 0.0008862000000000001}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0004245,
#    'srmer_ton_per_kWh_co2e': 0.0008613}, 2027: {'lrmer_ton_per_kWh_co2e': 0.0003908,
#    'srmer_ton_per_kWh_co2e': 0.00083725}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0003571,
#    'srmer_ton_per_kWh_co2e': 0.0008132}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00037175,
#    'srmer_ton_per_kWh_co2e': 0.00082635}, 2030: {'lrmer_ton_per_kWh_co2e': 0.00038639999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0008395}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00033089999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00084415}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00027539999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0008487999999999999}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00026014999999999995,
#    'srmer_ton_per_kWh_co2e': 0.0008304}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0002449,
#    'srmer_ton_per_kWh_co2e': 0.000812}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0002063,
#    'srmer_ton_per_kWh_co2e': 0.0008055499999999999}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00016769999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0007991000000000001}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00017585,
#    'srmer_ton_per_kWh_co2e': 0.00077985}, 2038: {'lrmer_ton_per_kWh_co2e': 0.000184,
#    'srmer_ton_per_kWh_co2e': 0.0007606000000000001}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00016905000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00076245}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0001541,
#    'srmer_ton_per_kWh_co2e': 0.0007643}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00015725,
#    'srmer_ton_per_kWh_co2e': 0.0007632}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0001604,
#    'srmer_ton_per_kWh_co2e': 0.0007621}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00016125,
#    'srmer_ton_per_kWh_co2e': 0.0007434000000000001}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00016209999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0007247}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0001685,
#    'srmer_ton_per_kWh_co2e': 0.0007028}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0001749,
#    'srmer_ton_per_kWh_co2e': 0.0006809}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00017030000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0006653}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0001657,
#    'srmer_ton_per_kWh_co2e': 0.0006497}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00015785,
#    'srmer_ton_per_kWh_co2e': 0.0006214000000000001}, 2050: {'lrmer_ton_per_kWh_co2e': 0.00015,
#    'srmer_ton_per_kWh_co2e': 0.0005931}},
#  ('MidCase',
#   'NEWEc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0004057,
#    'srmer_ton_per_kWh_co2e': 0.000676}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0004021,
#    'srmer_ton_per_kWh_co2e': 0.00066695}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0003985,
#    'srmer_ton_per_kWh_co2e': 0.0006579}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00039180000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0006504}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00038510000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0006429}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00037065,
#    'srmer_ton_per_kWh_co2e': 0.00065005}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0003562,
#    'srmer_ton_per_kWh_co2e': 0.0006572}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00034544999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0006304500000000001}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0003347,
#    'srmer_ton_per_kWh_co2e': 0.0006037000000000001}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00032645,
#    'srmer_ton_per_kWh_co2e': 0.00058205}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0003182,
#    'srmer_ton_per_kWh_co2e': 0.0005604}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00031554999999999995,
#    'srmer_ton_per_kWh_co2e': 0.0005534}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00031289999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0005463999999999999}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00030895,
#    'srmer_ton_per_kWh_co2e': 0.0005478499999999999}, 2036: {'lrmer_ton_per_kWh_co2e': 0.000305,
#    'srmer_ton_per_kWh_co2e': 0.0005493}, 2037: {'lrmer_ton_per_kWh_co2e': 0.0003018,
#    'srmer_ton_per_kWh_co2e': 0.00055895}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00029860000000000005,
#    'srmer_ton_per_kWh_co2e': 0.0005686}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00029205,
#    'srmer_ton_per_kWh_co2e': 0.0005721}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0002855,
#    'srmer_ton_per_kWh_co2e': 0.0005756}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00027719999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0005779000000000001}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0002689,
#    'srmer_ton_per_kWh_co2e': 0.0005802}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00024975,
#    'srmer_ton_per_kWh_co2e': 0.0005791}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0002306,
#    'srmer_ton_per_kWh_co2e': 0.000578}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00020419999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00057635}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0001778,
#    'srmer_ton_per_kWh_co2e': 0.0005747}, 2047: {'lrmer_ton_per_kWh_co2e': 0.000162,
#    'srmer_ton_per_kWh_co2e': 0.00057325}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00014619999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0005717999999999999}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00013785,
#    'srmer_ton_per_kWh_co2e': 0.0005474}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0001295,
#    'srmer_ton_per_kWh_co2e': 0.000523}},
#  ('MidCase',
#   'NWPPc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0004868,
#    'srmer_ton_per_kWh_co2e': 0.0007863}, 2023: {'lrmer_ton_per_kWh_co2e': 0.00045535000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0008104}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0004239,
#    'srmer_ton_per_kWh_co2e': 0.0008345}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00037775,
#    'srmer_ton_per_kWh_co2e': 0.0008397999999999999}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00033160000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0008451}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00032025,
#    'srmer_ton_per_kWh_co2e': 0.000835}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0003089,
#    'srmer_ton_per_kWh_co2e': 0.0008248999999999999}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00031364999999999995,
#    'srmer_ton_per_kWh_co2e': 0.00080345}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0003184,
#    'srmer_ton_per_kWh_co2e': 0.000782}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00030355,
#    'srmer_ton_per_kWh_co2e': 0.0007722}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00028869999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0007624}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00028744999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0007729}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00028619999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0007834}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00026045,
#    'srmer_ton_per_kWh_co2e': 0.00076005}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00023469999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0007367000000000001}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00023905,
#    'srmer_ton_per_kWh_co2e': 0.00073305}, 2038: {'lrmer_ton_per_kWh_co2e': 0.0002434,
#    'srmer_ton_per_kWh_co2e': 0.0007294}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00021525,
#    'srmer_ton_per_kWh_co2e': 0.00072575}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0001871,
#    'srmer_ton_per_kWh_co2e': 0.0007221}, 2041: {'lrmer_ton_per_kWh_co2e': 0.0001926,
#    'srmer_ton_per_kWh_co2e': 0.0007284500000000001}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0001981,
#    'srmer_ton_per_kWh_co2e': 0.0007348}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00019575,
#    'srmer_ton_per_kWh_co2e': 0.0007168499999999999}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0001934,
#    'srmer_ton_per_kWh_co2e': 0.0006989}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00020005,
#    'srmer_ton_per_kWh_co2e': 0.0006804500000000001}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00020669999999999998,
#    'srmer_ton_per_kWh_co2e': 0.000662}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00020455,
#    'srmer_ton_per_kWh_co2e': 0.00065545}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00020240000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0006489}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00019245,
#    'srmer_ton_per_kWh_co2e': 0.0006390999999999999}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0001825,
#    'srmer_ton_per_kWh_co2e': 0.0006293}},
#  ('MidCase',
#   'NYSTc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0003975,
#    'srmer_ton_per_kWh_co2e': 0.0007164}, 2023: {'lrmer_ton_per_kWh_co2e': 0.00037894999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00072745}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0003604,
#    'srmer_ton_per_kWh_co2e': 0.0007385}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0003327,
#    'srmer_ton_per_kWh_co2e': 0.0007298}, 2026: {'lrmer_ton_per_kWh_co2e': 0.000305,
#    'srmer_ton_per_kWh_co2e': 0.0007211}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00027039999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0007059000000000001}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0002358,
#    'srmer_ton_per_kWh_co2e': 0.0006907}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00021480000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0006573}, 2030: {'lrmer_ton_per_kWh_co2e': 0.00019380000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0006238999999999999}, 2031: {'lrmer_ton_per_kWh_co2e': 0.0001755,
#    'srmer_ton_per_kWh_co2e': 0.00060025}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0001572,
#    'srmer_ton_per_kWh_co2e': 0.0005766}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00014685,
#    'srmer_ton_per_kWh_co2e': 0.000567}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0001365,
#    'srmer_ton_per_kWh_co2e': 0.0005574}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0001205,
#    'srmer_ton_per_kWh_co2e': 0.00055885}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0001045,
#    'srmer_ton_per_kWh_co2e': 0.0005602999999999999}, 2037: {'lrmer_ton_per_kWh_co2e': 9.740000000000001e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005708499999999999}, 2038: {'lrmer_ton_per_kWh_co2e': 9.03e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005813999999999999}, 2039: {'lrmer_ton_per_kWh_co2e': 9.5e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005802}, 2040: {'lrmer_ton_per_kWh_co2e': 9.97e-05,
#    'srmer_ton_per_kWh_co2e': 0.000579}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00010515000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0005828}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00011059999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0005866000000000001}, 2043: {'lrmer_ton_per_kWh_co2e': 0.0001094,
#    'srmer_ton_per_kWh_co2e': 0.0005821}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0001082,
#    'srmer_ton_per_kWh_co2e': 0.0005776}, 2045: {'lrmer_ton_per_kWh_co2e': 9.955000000000001e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005772}, 2046: {'lrmer_ton_per_kWh_co2e': 9.09e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005767999999999999}, 2047: {'lrmer_ton_per_kWh_co2e': 8.605000000000002e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005778499999999999}, 2048: {'lrmer_ton_per_kWh_co2e': 8.120000000000001e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005789}, 2049: {'lrmer_ton_per_kWh_co2e': 7.77e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005593499999999999}, 2050: {'lrmer_ton_per_kWh_co2e': 7.42e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005398}},
#  ('MidCase',
#   'RFCEc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0006812999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0008544}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0006339500000000001,
#    'srmer_ton_per_kWh_co2e': 0.0008551499999999999}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0005866000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0008558999999999999}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0005554000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0008470499999999999}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0005242000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0008382000000000001}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00047290000000000006,
#    'srmer_ton_per_kWh_co2e': 0.00082675}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0004216,
#    'srmer_ton_per_kWh_co2e': 0.0008152999999999999}, 2029: {'lrmer_ton_per_kWh_co2e': 0.0004126,
#    'srmer_ton_per_kWh_co2e': 0.0008073499999999999}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0004036,
#    'srmer_ton_per_kWh_co2e': 0.0007994}, 2031: {'lrmer_ton_per_kWh_co2e': 0.0003805,
#    'srmer_ton_per_kWh_co2e': 0.0007920999999999999}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00035739999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0007848}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00035235,
#    'srmer_ton_per_kWh_co2e': 0.00078115}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0003473,
#    'srmer_ton_per_kWh_co2e': 0.0007775}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0003488,
#    'srmer_ton_per_kWh_co2e': 0.000769}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0003503,
#    'srmer_ton_per_kWh_co2e': 0.0007605}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00035135,
#    'srmer_ton_per_kWh_co2e': 0.00075625}, 2038: {'lrmer_ton_per_kWh_co2e': 0.0003524,
#    'srmer_ton_per_kWh_co2e': 0.000752}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00035039999999999995,
#    'srmer_ton_per_kWh_co2e': 0.00075235}, 2040: {'lrmer_ton_per_kWh_co2e': 0.00034839999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0007527}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00034895,
#    'srmer_ton_per_kWh_co2e': 0.0007464000000000001}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0003495,
#    'srmer_ton_per_kWh_co2e': 0.0007401}, 2043: {'lrmer_ton_per_kWh_co2e': 0.0003525,
#    'srmer_ton_per_kWh_co2e': 0.00073545}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0003555,
#    'srmer_ton_per_kWh_co2e': 0.0007308}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0003614,
#    'srmer_ton_per_kWh_co2e': 0.0007170999999999999}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00036730000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0007034}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00036465,
#    'srmer_ton_per_kWh_co2e': 0.0006932}, 2048: {'lrmer_ton_per_kWh_co2e': 0.000362,
#    'srmer_ton_per_kWh_co2e': 0.000683}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00035864999999999996,
#    'srmer_ton_per_kWh_co2e': 0.000678}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0003553,
#    'srmer_ton_per_kWh_co2e': 0.000673}},
#  ('MidCase',
#   'RFCMc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.000609,
#    'srmer_ton_per_kWh_co2e': 0.000936}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0005847000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0009602}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0005604,
#    'srmer_ton_per_kWh_co2e': 0.0009844}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0005082999999999999,
#    'srmer_ton_per_kWh_co2e': 0.00098015}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0004562,
#    'srmer_ton_per_kWh_co2e': 0.0009759}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00042919999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0009587}, 2028: {'lrmer_ton_per_kWh_co2e': 0.00040219999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0009415}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00039765,
#    'srmer_ton_per_kWh_co2e': 0.0009249}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0003931,
#    'srmer_ton_per_kWh_co2e': 0.0009082999999999999}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00039255000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0009047}, 2032: {'lrmer_ton_per_kWh_co2e': 0.000392,
#    'srmer_ton_per_kWh_co2e': 0.0009011000000000001}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00041455,
#    'srmer_ton_per_kWh_co2e': 0.0008912999999999999}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0004371,
#    'srmer_ton_per_kWh_co2e': 0.0008815}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0004401,
#    'srmer_ton_per_kWh_co2e': 0.0008765499999999999}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00044310000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0008716}, 2037: {'lrmer_ton_per_kWh_co2e': 0.0004441,
#    'srmer_ton_per_kWh_co2e': 0.0008612}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00044510000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0008508}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00042305,
#    'srmer_ton_per_kWh_co2e': 0.00084415}, 2040: {'lrmer_ton_per_kWh_co2e': 0.000401,
#    'srmer_ton_per_kWh_co2e': 0.0008375}, 2041: {'lrmer_ton_per_kWh_co2e': 0.0003775,
#    'srmer_ton_per_kWh_co2e': 0.00083135}, 2042: {'lrmer_ton_per_kWh_co2e': 0.000354,
#    'srmer_ton_per_kWh_co2e': 0.0008252}, 2043: {'lrmer_ton_per_kWh_co2e': 0.0003608,
#    'srmer_ton_per_kWh_co2e': 0.0008145}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00036760000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0008037999999999999}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0003744,
#    'srmer_ton_per_kWh_co2e': 0.0007779}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0003812,
#    'srmer_ton_per_kWh_co2e': 0.000752}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00039614999999999995,
#    'srmer_ton_per_kWh_co2e': 0.0007426}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0004111,
#    'srmer_ton_per_kWh_co2e': 0.0007332}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00039270000000000006,
#    'srmer_ton_per_kWh_co2e': 0.00070445}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0003743,
#    'srmer_ton_per_kWh_co2e': 0.0006757}},
#  ('MidCase',
#   'RFCWc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0006753,
#    'srmer_ton_per_kWh_co2e': 0.0009046}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0006308499999999999,
#    'srmer_ton_per_kWh_co2e': 0.0009232}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0005863999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0009417999999999999}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00052495,
#    'srmer_ton_per_kWh_co2e': 0.0009353499999999999}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0004635,
#    'srmer_ton_per_kWh_co2e': 0.0009289}, 2027: {'lrmer_ton_per_kWh_co2e': 0.0004324,
#    'srmer_ton_per_kWh_co2e': 0.0009165}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0004013,
#    'srmer_ton_per_kWh_co2e': 0.0009041}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00040839999999999995,
#    'srmer_ton_per_kWh_co2e': 0.0008947}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0004155,
#    'srmer_ton_per_kWh_co2e': 0.0008853}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00041065,
#    'srmer_ton_per_kWh_co2e': 0.00087775}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0004058,
#    'srmer_ton_per_kWh_co2e': 0.0008702}, 2033: {'lrmer_ton_per_kWh_co2e': 0.0004144,
#    'srmer_ton_per_kWh_co2e': 0.00086185}, 2034: {'lrmer_ton_per_kWh_co2e': 0.000423,
#    'srmer_ton_per_kWh_co2e': 0.0008535}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00042185000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00083995}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0004207,
#    'srmer_ton_per_kWh_co2e': 0.0008264}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00042935,
#    'srmer_ton_per_kWh_co2e': 0.0008167999999999999}, 2038: {'lrmer_ton_per_kWh_co2e': 0.000438,
#    'srmer_ton_per_kWh_co2e': 0.0008072}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00042655,
#    'srmer_ton_per_kWh_co2e': 0.0008024000000000001}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0004151,
#    'srmer_ton_per_kWh_co2e': 0.0007976}, 2041: {'lrmer_ton_per_kWh_co2e': 0.0004126,
#    'srmer_ton_per_kWh_co2e': 0.000794}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00041010000000000005,
#    'srmer_ton_per_kWh_co2e': 0.0007904}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00041455,
#    'srmer_ton_per_kWh_co2e': 0.0007794}, 2044: {'lrmer_ton_per_kWh_co2e': 0.000419,
#    'srmer_ton_per_kWh_co2e': 0.0007684}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0004287,
#    'srmer_ton_per_kWh_co2e': 0.00075165}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0004384,
#    'srmer_ton_per_kWh_co2e': 0.0007349}, 2047: {'lrmer_ton_per_kWh_co2e': 0.0004217,
#    'srmer_ton_per_kWh_co2e': 0.0007275999999999999}, 2048: {'lrmer_ton_per_kWh_co2e': 0.000405,
#    'srmer_ton_per_kWh_co2e': 0.0007203}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00037985000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0007095}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0003547,
#    'srmer_ton_per_kWh_co2e': 0.0006987}},
#  ('MidCase',
#   'RMPAc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0006303999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0009712000000000001}, 2023: {'lrmer_ton_per_kWh_co2e': 0.00054765,
#    'srmer_ton_per_kWh_co2e': 0.0009221}, 2024: {'lrmer_ton_per_kWh_co2e': 0.00046489999999999997,
#    'srmer_ton_per_kWh_co2e': 0.000873}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00037545,
#    'srmer_ton_per_kWh_co2e': 0.0008715}, 2026: {'lrmer_ton_per_kWh_co2e': 0.000286,
#    'srmer_ton_per_kWh_co2e': 0.00087}, 2027: {'lrmer_ton_per_kWh_co2e': 0.000264,
#    'srmer_ton_per_kWh_co2e': 0.0008548}, 2028: {'lrmer_ton_per_kWh_co2e': 0.000242,
#    'srmer_ton_per_kWh_co2e': 0.0008396}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00028464999999999995,
#    'srmer_ton_per_kWh_co2e': 0.0008136}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0003273,
#    'srmer_ton_per_kWh_co2e': 0.0007876000000000001}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00032245000000000006,
#    'srmer_ton_per_kWh_co2e': 0.00077975}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0003176,
#    'srmer_ton_per_kWh_co2e': 0.0007719}, 2033: {'lrmer_ton_per_kWh_co2e': 0.0002979,
#    'srmer_ton_per_kWh_co2e': 0.00078115}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0002782,
#    'srmer_ton_per_kWh_co2e': 0.0007904}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0002365,
#    'srmer_ton_per_kWh_co2e': 0.000768}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00019480000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0007456}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00019755,
#    'srmer_ton_per_kWh_co2e': 0.00074475}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00020030000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0007439}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00016735000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007493499999999999}, 2040: {'lrmer_ton_per_kWh_co2e': 0.00013440000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0007547999999999999}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00013580000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0007535}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0001372,
#    'srmer_ton_per_kWh_co2e': 0.0007522000000000001}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00014205,
#    'srmer_ton_per_kWh_co2e': 0.0007497000000000001}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0001469,
#    'srmer_ton_per_kWh_co2e': 0.0007472000000000001}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00016455000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0007306500000000001}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00018219999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0007141000000000001}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00019535,
#    'srmer_ton_per_kWh_co2e': 0.0007047}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0002085,
#    'srmer_ton_per_kWh_co2e': 0.0006952999999999999}, 2049: {'lrmer_ton_per_kWh_co2e': 0.0002116,
#    'srmer_ton_per_kWh_co2e': 0.0006910499999999999}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0002147,
#    'srmer_ton_per_kWh_co2e': 0.0006868}},
#  ('MidCase',
#   'SPNOc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0007434,
#    'srmer_ton_per_kWh_co2e': 0.0009123}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0006887999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0009115}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0006342,
#    'srmer_ton_per_kWh_co2e': 0.0009107000000000001}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00054845,
#    'srmer_ton_per_kWh_co2e': 0.00088395}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00046269999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0008572}, 2027: {'lrmer_ton_per_kWh_co2e': 0.0004093,
#    'srmer_ton_per_kWh_co2e': 0.0008661000000000001}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0003559,
#    'srmer_ton_per_kWh_co2e': 0.000875}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00034839999999999996,
#    'srmer_ton_per_kWh_co2e': 0.000864}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0003409,
#    'srmer_ton_per_kWh_co2e': 0.000853}, 2031: {'lrmer_ton_per_kWh_co2e': 0.0002935,
#    'srmer_ton_per_kWh_co2e': 0.0008544500000000001}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0002461,
#    'srmer_ton_per_kWh_co2e': 0.0008558999999999999}, 2033: {'lrmer_ton_per_kWh_co2e': 0.000249,
#    'srmer_ton_per_kWh_co2e': 0.00080905}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0002519,
#    'srmer_ton_per_kWh_co2e': 0.0007622000000000001}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0002375,
#    'srmer_ton_per_kWh_co2e': 0.0007702000000000001}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0002231,
#    'srmer_ton_per_kWh_co2e': 0.0007782}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00024095,
#    'srmer_ton_per_kWh_co2e': 0.0007696000000000001}, 2038: {'lrmer_ton_per_kWh_co2e': 0.0002588,
#    'srmer_ton_per_kWh_co2e': 0.000761}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00024419999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00075975}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0002296,
#    'srmer_ton_per_kWh_co2e': 0.0007585}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00022025,
#    'srmer_ton_per_kWh_co2e': 0.0007578999999999999}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0002109,
#    'srmer_ton_per_kWh_co2e': 0.0007572999999999999}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00021175,
#    'srmer_ton_per_kWh_co2e': 0.0007492}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0002126,
#    'srmer_ton_per_kWh_co2e': 0.0007411000000000001}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00022114999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0007137000000000001}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0002297,
#    'srmer_ton_per_kWh_co2e': 0.0006862999999999999}, 2047: {'lrmer_ton_per_kWh_co2e': 0.0002168,
#    'srmer_ton_per_kWh_co2e': 0.00068565}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0002039,
#    'srmer_ton_per_kWh_co2e': 0.000685}, 2049: {'lrmer_ton_per_kWh_co2e': 0.0001915,
#    'srmer_ton_per_kWh_co2e': 0.0006624500000000001}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0001791,
#    'srmer_ton_per_kWh_co2e': 0.0006399}},
#  ('MidCase',
#   'SPSOc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0005974,
#    'srmer_ton_per_kWh_co2e': 0.0007665}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0005417999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0007449}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0004862,
#    'srmer_ton_per_kWh_co2e': 0.0007233}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00042814999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00066415}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0003701,
#    'srmer_ton_per_kWh_co2e': 0.000605}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00034735,
#    'srmer_ton_per_kWh_co2e': 0.0006358}, 2028: {'lrmer_ton_per_kWh_co2e': 0.00032460000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0006666}, 2029: {'lrmer_ton_per_kWh_co2e': 0.000345,
#    'srmer_ton_per_kWh_co2e': 0.0006909}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0003654,
#    'srmer_ton_per_kWh_co2e': 0.0007152}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00033745,
#    'srmer_ton_per_kWh_co2e': 0.0007281500000000001}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0003095,
#    'srmer_ton_per_kWh_co2e': 0.0007411000000000001}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00031,
#    'srmer_ton_per_kWh_co2e': 0.0007119000000000001}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0003105,
#    'srmer_ton_per_kWh_co2e': 0.0006827000000000001}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00029545,
#    'srmer_ton_per_kWh_co2e': 0.00070175}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0002804,
#    'srmer_ton_per_kWh_co2e': 0.0007208}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00028744999999999997,
#    'srmer_ton_per_kWh_co2e': 0.000717}, 2038: {'lrmer_ton_per_kWh_co2e': 0.0002945,
#    'srmer_ton_per_kWh_co2e': 0.0007132000000000001}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00028175,
#    'srmer_ton_per_kWh_co2e': 0.0007173500000000001}, 2040: {'lrmer_ton_per_kWh_co2e': 0.000269,
#    'srmer_ton_per_kWh_co2e': 0.0007215}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00027194999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00072355}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00027489999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0007256000000000001}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00026629999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00072395}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0002577,
#    'srmer_ton_per_kWh_co2e': 0.0007222999999999999}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00024925,
#    'srmer_ton_per_kWh_co2e': 0.0006945999999999999}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0002408,
#    'srmer_ton_per_kWh_co2e': 0.0006669}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00022395,
#    'srmer_ton_per_kWh_co2e': 0.0006718}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0002071,
#    'srmer_ton_per_kWh_co2e': 0.0006767}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00020655,
#    'srmer_ton_per_kWh_co2e': 0.0006552000000000001}, 2050: {'lrmer_ton_per_kWh_co2e': 0.000206,
#    'srmer_ton_per_kWh_co2e': 0.0006337000000000001}},
#  ('MidCase',
#   'SRMVc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0006827000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0009142999999999999}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0006415,
#    'srmer_ton_per_kWh_co2e': 0.0009050499999999999}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0006002999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0008958}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0005201499999999999,
#    'srmer_ton_per_kWh_co2e': 0.00089}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00044,
#    'srmer_ton_per_kWh_co2e': 0.0008842}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00041905,
#    'srmer_ton_per_kWh_co2e': 0.00088095}, 2028: {'lrmer_ton_per_kWh_co2e': 0.00039810000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0008777}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00040445000000000005,
#    'srmer_ton_per_kWh_co2e': 0.000872}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0004108,
#    'srmer_ton_per_kWh_co2e': 0.0008663}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00040364999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00085755}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0003965,
#    'srmer_ton_per_kWh_co2e': 0.0008487999999999999}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00040425,
#    'srmer_ton_per_kWh_co2e': 0.00084465}, 2034: {'lrmer_ton_per_kWh_co2e': 0.000412,
#    'srmer_ton_per_kWh_co2e': 0.0008405}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0004075,
#    'srmer_ton_per_kWh_co2e': 0.00082975}, 2036: {'lrmer_ton_per_kWh_co2e': 0.000403,
#    'srmer_ton_per_kWh_co2e': 0.000819}, 2037: {'lrmer_ton_per_kWh_co2e': 0.0004227,
#    'srmer_ton_per_kWh_co2e': 0.0008112999999999999}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00044239999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0008036}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00043925,
#    'srmer_ton_per_kWh_co2e': 0.00079495}, 2040: {'lrmer_ton_per_kWh_co2e': 0.00043610000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007863}, 2041: {'lrmer_ton_per_kWh_co2e': 0.0004369,
#    'srmer_ton_per_kWh_co2e': 0.00079175}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0004377,
#    'srmer_ton_per_kWh_co2e': 0.0007972000000000001}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00043264999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00078735}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00042760000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0007775}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00041620000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007561}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00040480000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007347}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00039370000000000003,
#    'srmer_ton_per_kWh_co2e': 0.00072525}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00038260000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007157999999999999}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00037815,
#    'srmer_ton_per_kWh_co2e': 0.0007090999999999999}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0003737,
#    'srmer_ton_per_kWh_co2e': 0.0007023999999999999}},
#  ('MidCase',
#   'SRMWc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0006925,
#    'srmer_ton_per_kWh_co2e': 0.0009201}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0006485,
#    'srmer_ton_per_kWh_co2e': 0.000929}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0006045,
#    'srmer_ton_per_kWh_co2e': 0.0009379}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0005283,
#    'srmer_ton_per_kWh_co2e': 0.00092595}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00045210000000000004,
#    'srmer_ton_per_kWh_co2e': 0.000914}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00041775,
#    'srmer_ton_per_kWh_co2e': 0.0009106}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0003834,
#    'srmer_ton_per_kWh_co2e': 0.0009072}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00037795,
#    'srmer_ton_per_kWh_co2e': 0.000904}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0003725,
#    'srmer_ton_per_kWh_co2e': 0.0009008}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00034635000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00089785}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0003202,
#    'srmer_ton_per_kWh_co2e': 0.0008949}, 2033: {'lrmer_ton_per_kWh_co2e': 0.0003211,
#    'srmer_ton_per_kWh_co2e': 0.00089165}, 2034: {'lrmer_ton_per_kWh_co2e': 0.000322,
#    'srmer_ton_per_kWh_co2e': 0.0008884}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0003207,
#    'srmer_ton_per_kWh_co2e': 0.00088255}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00031939999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0008767}, 2037: {'lrmer_ton_per_kWh_co2e': 0.0003412,
#    'srmer_ton_per_kWh_co2e': 0.0008698}, 2038: {'lrmer_ton_per_kWh_co2e': 0.000363,
#    'srmer_ton_per_kWh_co2e': 0.0008629}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00034889999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0008564}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0003348,
#    'srmer_ton_per_kWh_co2e': 0.0008499}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00031905000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0008445999999999999}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0003033,
#    'srmer_ton_per_kWh_co2e': 0.0008393}, 2043: {'lrmer_ton_per_kWh_co2e': 0.0003029,
#    'srmer_ton_per_kWh_co2e': 0.00082555}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0003025,
#    'srmer_ton_per_kWh_co2e': 0.0008118}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0003103,
#    'srmer_ton_per_kWh_co2e': 0.0007925999999999999}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00031810000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007733999999999999}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00030485,
#    'srmer_ton_per_kWh_co2e': 0.0007565499999999999}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00029160000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0007397}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00026685,
#    'srmer_ton_per_kWh_co2e': 0.00071575}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0002421,
#    'srmer_ton_per_kWh_co2e': 0.0006917999999999999}},
#  ('MidCase',
#   'SRSOc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0006936,
#    'srmer_ton_per_kWh_co2e': 0.0008908}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0006782,
#    'srmer_ton_per_kWh_co2e': 0.00089}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0006628,
#    'srmer_ton_per_kWh_co2e': 0.0008892}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00060825,
#    'srmer_ton_per_kWh_co2e': 0.0008908}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0005537000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0008924}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00051345,
#    'srmer_ton_per_kWh_co2e': 0.0008946}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0004732,
#    'srmer_ton_per_kWh_co2e': 0.0008968}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00045535000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00088765}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0004375,
#    'srmer_ton_per_kWh_co2e': 0.0008785}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00043375,
#    'srmer_ton_per_kWh_co2e': 0.0008716}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00043,
#    'srmer_ton_per_kWh_co2e': 0.0008647}, 2033: {'lrmer_ton_per_kWh_co2e': 0.0004577,
#    'srmer_ton_per_kWh_co2e': 0.0008651500000000001}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0004854,
#    'srmer_ton_per_kWh_co2e': 0.0008656}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00046794999999999996,
#    'srmer_ton_per_kWh_co2e': 0.00085575}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0004505,
#    'srmer_ton_per_kWh_co2e': 0.0008459}, 2037: {'lrmer_ton_per_kWh_co2e': 0.0004348,
#    'srmer_ton_per_kWh_co2e': 0.0008357999999999999}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00041910000000000005,
#    'srmer_ton_per_kWh_co2e': 0.0008257000000000001}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00040510000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0008136500000000001}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0003911,
#    'srmer_ton_per_kWh_co2e': 0.0008016}, 2041: {'lrmer_ton_per_kWh_co2e': 0.0004241,
#    'srmer_ton_per_kWh_co2e': 0.00080615}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0004571,
#    'srmer_ton_per_kWh_co2e': 0.0008107}, 2043: {'lrmer_ton_per_kWh_co2e': 0.0004895,
#    'srmer_ton_per_kWh_co2e': 0.00080395}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0005219,
#    'srmer_ton_per_kWh_co2e': 0.0007972000000000001}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0005244500000000001,
#    'srmer_ton_per_kWh_co2e': 0.00077325}, 2046: {'lrmer_ton_per_kWh_co2e': 0.000527,
#    'srmer_ton_per_kWh_co2e': 0.0007492999999999999}, 2047: {'lrmer_ton_per_kWh_co2e': 0.0005026000000000001,
#    'srmer_ton_per_kWh_co2e': 0.00074375}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00047819999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0007382}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00045529999999999995,
#    'srmer_ton_per_kWh_co2e': 0.00072475}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0004324,
#    'srmer_ton_per_kWh_co2e': 0.0007113}},
#  ('MidCase',
#   'SRTVc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0007727000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0009231}, 2023: {'lrmer_ton_per_kWh_co2e': 0.00072325,
#    'srmer_ton_per_kWh_co2e': 0.0009433}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0006738,
#    'srmer_ton_per_kWh_co2e': 0.0009635}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0006017,
#    'srmer_ton_per_kWh_co2e': 0.00095995}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0005296,
#    'srmer_ton_per_kWh_co2e': 0.0009563999999999999}, 2027: {'lrmer_ton_per_kWh_co2e': 0.0004658,
#    'srmer_ton_per_kWh_co2e': 0.0009440999999999999}, 2028: {'lrmer_ton_per_kWh_co2e': 0.000402,
#    'srmer_ton_per_kWh_co2e': 0.0009318}, 2029: {'lrmer_ton_per_kWh_co2e': 0.0004041,
#    'srmer_ton_per_kWh_co2e': 0.0009255}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0004062,
#    'srmer_ton_per_kWh_co2e': 0.0009192}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00040325,
#    'srmer_ton_per_kWh_co2e': 0.0009118500000000001}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0004003,
#    'srmer_ton_per_kWh_co2e': 0.0009045}, 2033: {'lrmer_ton_per_kWh_co2e': 0.0004345,
#    'srmer_ton_per_kWh_co2e': 0.00090335}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0004687,
#    'srmer_ton_per_kWh_co2e': 0.0009022}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00046829999999999994,
#    'srmer_ton_per_kWh_co2e': 0.0008899000000000001}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0004679,
#    'srmer_ton_per_kWh_co2e': 0.0008776}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00048029999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00086655}, 2038: {'lrmer_ton_per_kWh_co2e': 0.0004927,
#    'srmer_ton_per_kWh_co2e': 0.0008555}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00048895,
#    'srmer_ton_per_kWh_co2e': 0.00085125}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0004852,
#    'srmer_ton_per_kWh_co2e': 0.000847}, 2041: {'lrmer_ton_per_kWh_co2e': 0.0004971,
#    'srmer_ton_per_kWh_co2e': 0.0008535499999999999}, 2042: {'lrmer_ton_per_kWh_co2e': 0.000509,
#    'srmer_ton_per_kWh_co2e': 0.0008601}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00052285,
#    'srmer_ton_per_kWh_co2e': 0.00084875}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0005367000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0008374}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0005324500000000001,
#    'srmer_ton_per_kWh_co2e': 0.0008192999999999999}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0005282,
#    'srmer_ton_per_kWh_co2e': 0.0008012000000000001}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00051355,
#    'srmer_ton_per_kWh_co2e': 0.00078375}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0004988999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0007662999999999999}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00047575,
#    'srmer_ton_per_kWh_co2e': 0.00075925}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0004526,
#    'srmer_ton_per_kWh_co2e': 0.0007522000000000001}},
#  ('MidCase',
#   'SRVCc'): {2022: {'lrmer_ton_per_kWh_co2e': 0.0007542,
#    'srmer_ton_per_kWh_co2e': 0.000915}, 2023: {'lrmer_ton_per_kWh_co2e': 0.0007007999999999999,
#    'srmer_ton_per_kWh_co2e': 0.00091785}, 2024: {'lrmer_ton_per_kWh_co2e': 0.0006474,
#    'srmer_ton_per_kWh_co2e': 0.0009207000000000001}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0005887,
#    'srmer_ton_per_kWh_co2e': 0.0009197000000000001}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00053,
#    'srmer_ton_per_kWh_co2e': 0.0009187}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00047555,
#    'srmer_ton_per_kWh_co2e': 0.00091725}, 2028: {'lrmer_ton_per_kWh_co2e': 0.00042110000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0009157999999999999}, 2029: {'lrmer_ton_per_kWh_co2e': 0.0004184,
#    'srmer_ton_per_kWh_co2e': 0.0009055}, 2030: {'lrmer_ton_per_kWh_co2e': 0.00041569999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0008952000000000001}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00039029999999999995,
#    'srmer_ton_per_kWh_co2e': 0.0008892}, 2032: {'lrmer_ton_per_kWh_co2e': 0.0003649,
#    'srmer_ton_per_kWh_co2e': 0.0008832}, 2033: {'lrmer_ton_per_kWh_co2e': 0.0003627,
#    'srmer_ton_per_kWh_co2e': 0.000877}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0003605,
#    'srmer_ton_per_kWh_co2e': 0.0008707999999999999}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0003485,
#    'srmer_ton_per_kWh_co2e': 0.0008591499999999999}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0003365,
#    'srmer_ton_per_kWh_co2e': 0.0008475}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00034075,
#    'srmer_ton_per_kWh_co2e': 0.0008321499999999999}, 2038: {'lrmer_ton_per_kWh_co2e': 0.000345,
#    'srmer_ton_per_kWh_co2e': 0.0008167999999999999}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00033,
#    'srmer_ton_per_kWh_co2e': 0.0008093}, 2040: {'lrmer_ton_per_kWh_co2e': 0.000315,
#    'srmer_ton_per_kWh_co2e': 0.0008018}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00031444999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0008036499999999999}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0003139,
#    'srmer_ton_per_kWh_co2e': 0.0008055}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00031425,
#    'srmer_ton_per_kWh_co2e': 0.0007957999999999999}, 2044: {'lrmer_ton_per_kWh_co2e': 0.0003146,
#    'srmer_ton_per_kWh_co2e': 0.0007861}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0003176,
#    'srmer_ton_per_kWh_co2e': 0.0007705}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00032060000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0007549}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00031925,
#    'srmer_ton_per_kWh_co2e': 0.0007530999999999999}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0003179,
#    'srmer_ton_per_kWh_co2e': 0.0007513}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00031229999999999995,
#    'srmer_ton_per_kWh_co2e': 0.0007348}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0003067,
#    'srmer_ton_per_kWh_co2e': 0.0007183}}}

# %%
import os
import pandas as pd

print("""
-------------------------------------------------------------------------------------------------------
IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2022 RELEASE
-------------------------------------------------------------------------------------------------------
""")

# CAMBIUM 2022 FOR IRA SCENARIO
filename = 'cambium22_allScenarios_annual_gea.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_cambium22_margEmis_electricity = pd.read_excel(io=file_path, sheet_name='proc_Cambium22_MidCase_gea')

print(f"""
Retrieved data for filename: {filename}
Located at filepath: {file_path}

Loading dataframe ...
Creating lookup dictionary for 2024 LRMER and SRMER ...
-------------------------------------------------------------------------------------------------------
""")

# Calculate electricity emission factors for Cambium 2021
# Process the data using the provided function to interpolate and convert units
df_cambium22_processed = calculate_electricity_co2e_cambium(df_cambium22_margEmis_electricity)

# # Display the processed DataFrame
# df_cambium22_processed

# Create the lookup dictionary using the create_cambium_co2e_lookup function
emis_IRA_co2e_cambium22_lookup = create_cambium_co2e_lookup(df_cambium22_processed)

# Display the lookup dictionary
emis_IRA_co2e_cambium22_lookup
# Out:
# -------------------------------------------------------------------------------------------------------
# IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2022 RELEASE
# -------------------------------------------------------------------------------------------------------
#
#
# Retrieved data for filename: cambium22_allScenarios_annual_gea.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\cambium22_allScenarios_annual_gea.xlsx
#
# Loading dataframe ...
# Creating lookup dictionary for 2024 LRMER and SRMER ...
# -------------------------------------------------------------------------------------------------------
# {('MidCase',
#   'AZNMc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0003269,
#    'srmer_ton_per_kWh_co2e': 0.0007771}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0002604,
#    'srmer_ton_per_kWh_co2e': 0.0007434000000000001}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0001939,
#    'srmer_ton_per_kWh_co2e': 0.0007097000000000001}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00016219999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0006430499999999999}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0001305,
#    'srmer_ton_per_kWh_co2e': 0.0005764}, 2029: {'lrmer_ton_per_kWh_co2e': 0.0001171,
#    'srmer_ton_per_kWh_co2e': 0.00053155}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0001037,
#    'srmer_ton_per_kWh_co2e': 0.0004867}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00011284,
#    'srmer_ton_per_kWh_co2e': 0.00046903999999999994}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00012198000000000001,
#    'srmer_ton_per_kWh_co2e': 0.00045138}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00013112,
#    'srmer_ton_per_kWh_co2e': 0.00043371999999999996}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00014026,
#    'srmer_ton_per_kWh_co2e': 0.00041605999999999994}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0001494,
#    'srmer_ton_per_kWh_co2e': 0.0003984}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00015762,
#    'srmer_ton_per_kWh_co2e': 0.00039015999999999996}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00016584,
#    'srmer_ton_per_kWh_co2e': 0.00038191999999999995}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00017406,
#    'srmer_ton_per_kWh_co2e': 0.00037368}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00018228,
#    'srmer_ton_per_kWh_co2e': 0.00036544}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0001905,
#    'srmer_ton_per_kWh_co2e': 0.0003572}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00019030000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00033806}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00019009999999999999,
#    'srmer_ton_per_kWh_co2e': 0.00031892}, 2043: {'lrmer_ton_per_kWh_co2e': 0.0001899,
#    'srmer_ton_per_kWh_co2e': 0.00029978}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00018969999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00028063999999999997}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0001895,
#    'srmer_ton_per_kWh_co2e': 0.0002615}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00018998,
#    'srmer_ton_per_kWh_co2e': 0.00025874000000000003}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00019046000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00025598}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00019093999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00025322}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00019142,
#    'srmer_ton_per_kWh_co2e': 0.00025046}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0001919,
#    'srmer_ton_per_kWh_co2e': 0.0002477}},
#  ('MidCase',
#   'CAMXc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0002075,
#    'srmer_ton_per_kWh_co2e': 0.0007543}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00016319999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0007245999999999999}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0001189,
#    'srmer_ton_per_kWh_co2e': 0.0006948999999999999}, 2027: {'lrmer_ton_per_kWh_co2e': 9.085e-05,
#    'srmer_ton_per_kWh_co2e': 0.0006426499999999999}, 2028: {'lrmer_ton_per_kWh_co2e': 6.28e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005903999999999999}, 2029: {'lrmer_ton_per_kWh_co2e': 5.1349999999999995e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005424500000000001}, 2030: {'lrmer_ton_per_kWh_co2e': 3.99e-05,
#    'srmer_ton_per_kWh_co2e': 0.0004945}, 2031: {'lrmer_ton_per_kWh_co2e': 4.042e-05,
#    'srmer_ton_per_kWh_co2e': 0.00047744}, 2032: {'lrmer_ton_per_kWh_co2e': 4.094e-05,
#    'srmer_ton_per_kWh_co2e': 0.00046038}, 2033: {'lrmer_ton_per_kWh_co2e': 4.146e-05,
#    'srmer_ton_per_kWh_co2e': 0.00044332}, 2034: {'lrmer_ton_per_kWh_co2e': 4.1979999999999994e-05,
#    'srmer_ton_per_kWh_co2e': 0.00042626}, 2035: {'lrmer_ton_per_kWh_co2e': 4.25e-05,
#    'srmer_ton_per_kWh_co2e': 0.00040919999999999997}, 2036: {'lrmer_ton_per_kWh_co2e': 3.818e-05,
#    'srmer_ton_per_kWh_co2e': 0.00040258}, 2037: {'lrmer_ton_per_kWh_co2e': 3.386e-05,
#    'srmer_ton_per_kWh_co2e': 0.00039596}, 2038: {'lrmer_ton_per_kWh_co2e': 2.954e-05,
#    'srmer_ton_per_kWh_co2e': 0.00038934}, 2039: {'lrmer_ton_per_kWh_co2e': 2.522e-05,
#    'srmer_ton_per_kWh_co2e': 0.00038272}, 2040: {'lrmer_ton_per_kWh_co2e': 2.09e-05,
#    'srmer_ton_per_kWh_co2e': 0.00037610000000000003}, 2041: {'lrmer_ton_per_kWh_co2e': 1.842e-05,
#    'srmer_ton_per_kWh_co2e': 0.00035682}, 2042: {'lrmer_ton_per_kWh_co2e': 1.594e-05,
#    'srmer_ton_per_kWh_co2e': 0.00033754}, 2043: {'lrmer_ton_per_kWh_co2e': 1.3460000000000002e-05,
#    'srmer_ton_per_kWh_co2e': 0.00031826}, 2044: {'lrmer_ton_per_kWh_co2e': 1.098e-05,
#    'srmer_ton_per_kWh_co2e': 0.00029898}, 2045: {'lrmer_ton_per_kWh_co2e': 8.5e-06,
#    'srmer_ton_per_kWh_co2e': 0.00027969999999999997}, 2046: {'lrmer_ton_per_kWh_co2e': 6.8e-06,
#    'srmer_ton_per_kWh_co2e': 0.00028122}, 2047: {'lrmer_ton_per_kWh_co2e': 5.0999999999999995e-06,
#    'srmer_ton_per_kWh_co2e': 0.00028274}, 2048: {'lrmer_ton_per_kWh_co2e': 3.4000000000000005e-06,
#    'srmer_ton_per_kWh_co2e': 0.00028426}, 2049: {'lrmer_ton_per_kWh_co2e': 1.7000000000000002e-06,
#    'srmer_ton_per_kWh_co2e': 0.00028578}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0,
#    'srmer_ton_per_kWh_co2e': 0.0002873}},
#  ('MidCase',
#   'ERCTc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.000294,
#    'srmer_ton_per_kWh_co2e': 0.0006552000000000001}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00024165000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0006087999999999999}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00018930000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0005624}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00013135000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00049715}, 2028: {'lrmer_ton_per_kWh_co2e': 7.340000000000001e-05,
#    'srmer_ton_per_kWh_co2e': 0.0004319}, 2029: {'lrmer_ton_per_kWh_co2e': 5.67e-05,
#    'srmer_ton_per_kWh_co2e': 0.00040445}, 2030: {'lrmer_ton_per_kWh_co2e': 4e-05,
#    'srmer_ton_per_kWh_co2e': 0.000377}, 2031: {'lrmer_ton_per_kWh_co2e': 4.592e-05,
#    'srmer_ton_per_kWh_co2e': 0.00036784}, 2032: {'lrmer_ton_per_kWh_co2e': 5.184e-05,
#    'srmer_ton_per_kWh_co2e': 0.00035868}, 2033: {'lrmer_ton_per_kWh_co2e': 5.7759999999999996e-05,
#    'srmer_ton_per_kWh_co2e': 0.00034952}, 2034: {'lrmer_ton_per_kWh_co2e': 6.367999999999999e-05,
#    'srmer_ton_per_kWh_co2e': 0.00034036}, 2035: {'lrmer_ton_per_kWh_co2e': 6.96e-05,
#    'srmer_ton_per_kWh_co2e': 0.0003312}, 2036: {'lrmer_ton_per_kWh_co2e': 7.442e-05,
#    'srmer_ton_per_kWh_co2e': 0.00032772}, 2037: {'lrmer_ton_per_kWh_co2e': 7.924e-05,
#    'srmer_ton_per_kWh_co2e': 0.00032424}, 2038: {'lrmer_ton_per_kWh_co2e': 8.406e-05,
#    'srmer_ton_per_kWh_co2e': 0.00032076}, 2039: {'lrmer_ton_per_kWh_co2e': 8.887999999999999e-05,
#    'srmer_ton_per_kWh_co2e': 0.00031728}, 2040: {'lrmer_ton_per_kWh_co2e': 9.37e-05,
#    'srmer_ton_per_kWh_co2e': 0.00031380000000000004}, 2041: {'lrmer_ton_per_kWh_co2e': 9.174000000000001e-05,
#    'srmer_ton_per_kWh_co2e': 0.00030772000000000004}, 2042: {'lrmer_ton_per_kWh_co2e': 8.978e-05,
#    'srmer_ton_per_kWh_co2e': 0.00030164}, 2043: {'lrmer_ton_per_kWh_co2e': 8.782000000000001e-05,
#    'srmer_ton_per_kWh_co2e': 0.00029556}, 2044: {'lrmer_ton_per_kWh_co2e': 8.586e-05,
#    'srmer_ton_per_kWh_co2e': 0.00028947999999999995}, 2045: {'lrmer_ton_per_kWh_co2e': 8.39e-05,
#    'srmer_ton_per_kWh_co2e': 0.0002834}, 2046: {'lrmer_ton_per_kWh_co2e': 7.906e-05,
#    'srmer_ton_per_kWh_co2e': 0.00027926}, 2047: {'lrmer_ton_per_kWh_co2e': 7.422e-05,
#    'srmer_ton_per_kWh_co2e': 0.00027512}, 2048: {'lrmer_ton_per_kWh_co2e': 6.937999999999999e-05,
#    'srmer_ton_per_kWh_co2e': 0.00027098}, 2049: {'lrmer_ton_per_kWh_co2e': 6.454e-05,
#    'srmer_ton_per_kWh_co2e': 0.00026683999999999996}, 2050: {'lrmer_ton_per_kWh_co2e': 5.97e-05,
#    'srmer_ton_per_kWh_co2e': 0.0002627}},
#  ('MidCase',
#   'FRCCc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.00028680000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007726}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00025745,
#    'srmer_ton_per_kWh_co2e': 0.0007025}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0002281,
#    'srmer_ton_per_kWh_co2e': 0.0006324}, 2027: {'lrmer_ton_per_kWh_co2e': 0.0002008,
#    'srmer_ton_per_kWh_co2e': 0.0005904500000000001}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0001735,
#    'srmer_ton_per_kWh_co2e': 0.0005485}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00018465000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0005265}, 2030: {'lrmer_ton_per_kWh_co2e': 0.00019580000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0005045}, 2031: {'lrmer_ton_per_kWh_co2e': 0.0002055,
#    'srmer_ton_per_kWh_co2e': 0.00049152}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00021520000000000003,
#    'srmer_ton_per_kWh_co2e': 0.00047854}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00022490000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00046556}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0002346,
#    'srmer_ton_per_kWh_co2e': 0.00045258000000000006}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00024430000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0004396}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00025442,
#    'srmer_ton_per_kWh_co2e': 0.00043672000000000003}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00026454,
#    'srmer_ton_per_kWh_co2e': 0.00043384}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00027466,
#    'srmer_ton_per_kWh_co2e': 0.00043096}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00028478,
#    'srmer_ton_per_kWh_co2e': 0.00042808}, 2040: {'lrmer_ton_per_kWh_co2e': 0.00029489999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0004252}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00030386,
#    'srmer_ton_per_kWh_co2e': 0.00041672}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00031282,
#    'srmer_ton_per_kWh_co2e': 0.00040824000000000004}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00032177999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00039976}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00033074,
#    'srmer_ton_per_kWh_co2e': 0.00039128000000000003}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00033969999999999996,
#    'srmer_ton_per_kWh_co2e': 0.00038280000000000003}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00034313999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00038510000000000004}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00034658,
#    'srmer_ton_per_kWh_co2e': 0.00038740000000000004}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00035002,
#    'srmer_ton_per_kWh_co2e': 0.0003897}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00035346,
#    'srmer_ton_per_kWh_co2e': 0.000392}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0003569,
#    'srmer_ton_per_kWh_co2e': 0.0003943}},
#  ('MidCase',
#   'MROEc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.000349,
#    'srmer_ton_per_kWh_co2e': 0.0009433}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0003097,
#    'srmer_ton_per_kWh_co2e': 0.0009196499999999999}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00027039999999999996,
#    'srmer_ton_per_kWh_co2e': 0.000896}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00024714999999999996,
#    'srmer_ton_per_kWh_co2e': 0.00078855}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0002239,
#    'srmer_ton_per_kWh_co2e': 0.0006811}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00021875,
#    'srmer_ton_per_kWh_co2e': 0.00062625}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0002136,
#    'srmer_ton_per_kWh_co2e': 0.0005714}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00021685999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0005625}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00022012,
#    'srmer_ton_per_kWh_co2e': 0.0005536}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00022338,
#    'srmer_ton_per_kWh_co2e': 0.0005447}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00022664,
#    'srmer_ton_per_kWh_co2e': 0.0005357999999999999}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0002299,
#    'srmer_ton_per_kWh_co2e': 0.0005269}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00023132,
#    'srmer_ton_per_kWh_co2e': 0.00051242}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00023274,
#    'srmer_ton_per_kWh_co2e': 0.00049794}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00023416,
#    'srmer_ton_per_kWh_co2e': 0.00048345999999999996}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00023558000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00046898}, 2040: {'lrmer_ton_per_kWh_co2e': 0.000237,
#    'srmer_ton_per_kWh_co2e': 0.0004545}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00024207999999999999,
#    'srmer_ton_per_kWh_co2e': 0.00045198}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00024716,
#    'srmer_ton_per_kWh_co2e': 0.00044946}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00025224,
#    'srmer_ton_per_kWh_co2e': 0.00044694}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00025732,
#    'srmer_ton_per_kWh_co2e': 0.00044441999999999995}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0002624,
#    'srmer_ton_per_kWh_co2e': 0.00044189999999999995}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00026341999999999994,
#    'srmer_ton_per_kWh_co2e': 0.00044184}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00026444,
#    'srmer_ton_per_kWh_co2e': 0.00044177999999999996}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00026545999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00044172000000000005}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00026648000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00044166}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0002675,
#    'srmer_ton_per_kWh_co2e': 0.0004416}},
#  ('MidCase',
#   'MROWc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.00028660000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0008846}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00022715000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00081305}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00016769999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0007415}, 2027: {'lrmer_ton_per_kWh_co2e': 0.0001343,
#    'srmer_ton_per_kWh_co2e': 0.0006559}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0001009,
#    'srmer_ton_per_kWh_co2e': 0.0005702999999999999}, 2029: {'lrmer_ton_per_kWh_co2e': 0.0001104,
#    'srmer_ton_per_kWh_co2e': 0.00052675}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0001199,
#    'srmer_ton_per_kWh_co2e': 0.0004832}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00012656,
#    'srmer_ton_per_kWh_co2e': 0.00047832}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00013322,
#    'srmer_ton_per_kWh_co2e': 0.00047344}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00013988,
#    'srmer_ton_per_kWh_co2e': 0.00046856}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00014654,
#    'srmer_ton_per_kWh_co2e': 0.00046368}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00015319999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0004588}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0001578,
#    'srmer_ton_per_kWh_co2e': 0.0004443}, 2037: {'lrmer_ton_per_kWh_co2e': 0.0001624,
#    'srmer_ton_per_kWh_co2e': 0.0004298}, 2038: {'lrmer_ton_per_kWh_co2e': 0.000167,
#    'srmer_ton_per_kWh_co2e': 0.0004153}, 2039: {'lrmer_ton_per_kWh_co2e': 0.0001716,
#    'srmer_ton_per_kWh_co2e': 0.0004008}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0001762,
#    'srmer_ton_per_kWh_co2e': 0.0003863}, 2041: {'lrmer_ton_per_kWh_co2e': 0.0001769,
#    'srmer_ton_per_kWh_co2e': 0.00038234000000000006}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0001776,
#    'srmer_ton_per_kWh_co2e': 0.00037838}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00017829999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00037442000000000004}, 2044: {'lrmer_ton_per_kWh_co2e': 0.000179,
#    'srmer_ton_per_kWh_co2e': 0.00037046}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00017969999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0003665}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00018039999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00036157999999999996}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00018109999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00035665999999999996}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00018179999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00035174}, 2049: {'lrmer_ton_per_kWh_co2e': 0.0001825,
#    'srmer_ton_per_kWh_co2e': 0.00034682}, 2050: {'lrmer_ton_per_kWh_co2e': 0.00018319999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00034189999999999996}},
#  ('MidCase',
#   'NEWEc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0003674,
#    'srmer_ton_per_kWh_co2e': 0.0007582}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00034475,
#    'srmer_ton_per_kWh_co2e': 0.0007327000000000001}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0003221,
#    'srmer_ton_per_kWh_co2e': 0.0007072000000000001}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00029925,
#    'srmer_ton_per_kWh_co2e': 0.0006758}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0002764,
#    'srmer_ton_per_kWh_co2e': 0.0006443999999999999}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00026165,
#    'srmer_ton_per_kWh_co2e': 0.0006255999999999999}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0002469,
#    'srmer_ton_per_kWh_co2e': 0.0006068}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00024326,
#    'srmer_ton_per_kWh_co2e': 0.0005970999999999999}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00023962,
#    'srmer_ton_per_kWh_co2e': 0.0005874}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00023598,
#    'srmer_ton_per_kWh_co2e': 0.0005776999999999999}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00023234000000000002,
#    'srmer_ton_per_kWh_co2e': 0.000568}, 2035: {'lrmer_ton_per_kWh_co2e': 0.00022869999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0005583}, 2036: {'lrmer_ton_per_kWh_co2e': 0.0002255,
#    'srmer_ton_per_kWh_co2e': 0.00055474}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00022229999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00055118}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00021909999999999999,
#    'srmer_ton_per_kWh_co2e': 0.00054762}, 2039: {'lrmer_ton_per_kWh_co2e': 0.0002159,
#    'srmer_ton_per_kWh_co2e': 0.00054406}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0002127,
#    'srmer_ton_per_kWh_co2e': 0.0005405}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00020895999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0005445}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00020522,
#    'srmer_ton_per_kWh_co2e': 0.0005485}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00020148,
#    'srmer_ton_per_kWh_co2e': 0.0005525}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00019774000000000001,
#    'srmer_ton_per_kWh_co2e': 0.0005565}, 2045: {'lrmer_ton_per_kWh_co2e': 0.000194,
#    'srmer_ton_per_kWh_co2e': 0.0005605}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00019176,
#    'srmer_ton_per_kWh_co2e': 0.0005589}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00018952000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0005572999999999999}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00018728,
#    'srmer_ton_per_kWh_co2e': 0.0005557}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00018504000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0005541}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0001828,
#    'srmer_ton_per_kWh_co2e': 0.0005525}},
#  ('MidCase',
#   'NWPPc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0003339,
#    'srmer_ton_per_kWh_co2e': 0.0007938}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00028595,
#    'srmer_ton_per_kWh_co2e': 0.000754}, 2026: {'lrmer_ton_per_kWh_co2e': 0.000238,
#    'srmer_ton_per_kWh_co2e': 0.0007142}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00019395,
#    'srmer_ton_per_kWh_co2e': 0.0006704000000000001}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0001499,
#    'srmer_ton_per_kWh_co2e': 0.0006266}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00011830000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00058095}, 2030: {'lrmer_ton_per_kWh_co2e': 8.67e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005353}, 2031: {'lrmer_ton_per_kWh_co2e': 8.570000000000001e-05,
#    'srmer_ton_per_kWh_co2e': 0.00051768}, 2032: {'lrmer_ton_per_kWh_co2e': 8.47e-05,
#    'srmer_ton_per_kWh_co2e': 0.00050006}, 2033: {'lrmer_ton_per_kWh_co2e': 8.37e-05,
#    'srmer_ton_per_kWh_co2e': 0.00048243999999999994}, 2034: {'lrmer_ton_per_kWh_co2e': 8.27e-05,
#    'srmer_ton_per_kWh_co2e': 0.00046482}, 2035: {'lrmer_ton_per_kWh_co2e': 8.170000000000001e-05,
#    'srmer_ton_per_kWh_co2e': 0.0004472}, 2036: {'lrmer_ton_per_kWh_co2e': 8.329999999999999e-05,
#    'srmer_ton_per_kWh_co2e': 0.00044266}, 2037: {'lrmer_ton_per_kWh_co2e': 8.49e-05,
#    'srmer_ton_per_kWh_co2e': 0.00043812}, 2038: {'lrmer_ton_per_kWh_co2e': 8.65e-05,
#    'srmer_ton_per_kWh_co2e': 0.00043358}, 2039: {'lrmer_ton_per_kWh_co2e': 8.810000000000001e-05,
#    'srmer_ton_per_kWh_co2e': 0.00042904}, 2040: {'lrmer_ton_per_kWh_co2e': 8.97e-05,
#    'srmer_ton_per_kWh_co2e': 0.0004245}, 2041: {'lrmer_ton_per_kWh_co2e': 8.852e-05,
#    'srmer_ton_per_kWh_co2e': 0.00041136}, 2042: {'lrmer_ton_per_kWh_co2e': 8.734e-05,
#    'srmer_ton_per_kWh_co2e': 0.00039822}, 2043: {'lrmer_ton_per_kWh_co2e': 8.616e-05,
#    'srmer_ton_per_kWh_co2e': 0.00038508000000000005}, 2044: {'lrmer_ton_per_kWh_co2e': 8.498e-05,
#    'srmer_ton_per_kWh_co2e': 0.00037194}, 2045: {'lrmer_ton_per_kWh_co2e': 8.379999999999999e-05,
#    'srmer_ton_per_kWh_co2e': 0.0003588}, 2046: {'lrmer_ton_per_kWh_co2e': 8.456e-05,
#    'srmer_ton_per_kWh_co2e': 0.00036}, 2047: {'lrmer_ton_per_kWh_co2e': 8.531999999999999e-05,
#    'srmer_ton_per_kWh_co2e': 0.0003612}, 2048: {'lrmer_ton_per_kWh_co2e': 8.608e-05,
#    'srmer_ton_per_kWh_co2e': 0.0003624}, 2049: {'lrmer_ton_per_kWh_co2e': 8.683999999999999e-05,
#    'srmer_ton_per_kWh_co2e': 0.0003636}, 2050: {'lrmer_ton_per_kWh_co2e': 8.759999999999999e-05,
#    'srmer_ton_per_kWh_co2e': 0.00036480000000000003}},
#  ('MidCase',
#   'NYSTc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0003073,
#    'srmer_ton_per_kWh_co2e': 0.0008238}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00028685,
#    'srmer_ton_per_kWh_co2e': 0.0007917}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00026639999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0007596}, 2027: {'lrmer_ton_per_kWh_co2e': 0.0002205,
#    'srmer_ton_per_kWh_co2e': 0.00072645}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0001746,
#    'srmer_ton_per_kWh_co2e': 0.0006933}, 2029: {'lrmer_ton_per_kWh_co2e': 0.0001383,
#    'srmer_ton_per_kWh_co2e': 0.0006698499999999999}, 2030: {'lrmer_ton_per_kWh_co2e': 0.000102,
#    'srmer_ton_per_kWh_co2e': 0.0006464}, 2031: {'lrmer_ton_per_kWh_co2e': 8.784e-05,
#    'srmer_ton_per_kWh_co2e': 0.0006336}, 2032: {'lrmer_ton_per_kWh_co2e': 7.368000000000001e-05,
#    'srmer_ton_per_kWh_co2e': 0.0006207999999999999}, 2033: {'lrmer_ton_per_kWh_co2e': 5.952e-05,
#    'srmer_ton_per_kWh_co2e': 0.000608}, 2034: {'lrmer_ton_per_kWh_co2e': 4.536e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005951999999999999}, 2035: {'lrmer_ton_per_kWh_co2e': 3.1200000000000006e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005824}, 2036: {'lrmer_ton_per_kWh_co2e': 2.6759999999999998e-05,
#    'srmer_ton_per_kWh_co2e': 0.00057778}, 2037: {'lrmer_ton_per_kWh_co2e': 2.232e-05,
#    'srmer_ton_per_kWh_co2e': 0.00057316}, 2038: {'lrmer_ton_per_kWh_co2e': 1.788e-05,
#    'srmer_ton_per_kWh_co2e': 0.00056854}, 2039: {'lrmer_ton_per_kWh_co2e': 1.3440000000000002e-05,
#    'srmer_ton_per_kWh_co2e': 0.00056392}, 2040: {'lrmer_ton_per_kWh_co2e': 9.000000000000004e-06,
#    'srmer_ton_per_kWh_co2e': 0.0005593}, 2041: {'lrmer_ton_per_kWh_co2e': 7.2000000000000005e-06,
#    'srmer_ton_per_kWh_co2e': 0.00056294}, 2042: {'lrmer_ton_per_kWh_co2e': 5.4e-06,
#    'srmer_ton_per_kWh_co2e': 0.0005665799999999999}, 2043: {'lrmer_ton_per_kWh_co2e': 3.6e-06,
#    'srmer_ton_per_kWh_co2e': 0.0005702200000000001}, 2044: {'lrmer_ton_per_kWh_co2e': 1.8e-06,
#    'srmer_ton_per_kWh_co2e': 0.00057386}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0,
#    'srmer_ton_per_kWh_co2e': 0.0005775}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0,
#    'srmer_ton_per_kWh_co2e': 0.00057478}, 2047: {'lrmer_ton_per_kWh_co2e': 0.0,
#    'srmer_ton_per_kWh_co2e': 0.00057206}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0,
#    'srmer_ton_per_kWh_co2e': 0.00056934}, 2049: {'lrmer_ton_per_kWh_co2e': 0.0,
#    'srmer_ton_per_kWh_co2e': 0.00056662}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0,
#    'srmer_ton_per_kWh_co2e': 0.0005639}},
#  ('MidCase',
#   'RFCEc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0004171,
#    'srmer_ton_per_kWh_co2e': 0.0008577999999999999}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00039325,
#    'srmer_ton_per_kWh_co2e': 0.00083}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0003694,
#    'srmer_ton_per_kWh_co2e': 0.0008022000000000001}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00033845,
#    'srmer_ton_per_kWh_co2e': 0.0007665}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0003075,
#    'srmer_ton_per_kWh_co2e': 0.0007308}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00031045,
#    'srmer_ton_per_kWh_co2e': 0.0007063999999999999}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0003134,
#    'srmer_ton_per_kWh_co2e': 0.000682}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00031724,
#    'srmer_ton_per_kWh_co2e': 0.00067316}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00032108,
#    'srmer_ton_per_kWh_co2e': 0.0006643199999999999}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00032492,
#    'srmer_ton_per_kWh_co2e': 0.0006554800000000001}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00032876,
#    'srmer_ton_per_kWh_co2e': 0.00064664}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0003326,
#    'srmer_ton_per_kWh_co2e': 0.0006378}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00033724,
#    'srmer_ton_per_kWh_co2e': 0.00062806}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00034187999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0006183199999999999}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00034652000000000006,
#    'srmer_ton_per_kWh_co2e': 0.0006085800000000001}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00035116000000000005,
#    'srmer_ton_per_kWh_co2e': 0.00059884}, 2040: {'lrmer_ton_per_kWh_co2e': 0.00035580000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0005891000000000001}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00035626,
#    'srmer_ton_per_kWh_co2e': 0.00059136}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00035672000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00059362}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00035718,
#    'srmer_ton_per_kWh_co2e': 0.00059588}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00035764000000000005,
#    'srmer_ton_per_kWh_co2e': 0.0005981399999999999}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00035810000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0006004}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00035734000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00060062}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00035658000000000006,
#    'srmer_ton_per_kWh_co2e': 0.0006008400000000001}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00035582,
#    'srmer_ton_per_kWh_co2e': 0.0006010599999999999}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00035506,
#    'srmer_ton_per_kWh_co2e': 0.0006012799999999999}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0003543,
#    'srmer_ton_per_kWh_co2e': 0.0006015}},
#  ('MidCase',
#   'RFCMc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.000436,
#    'srmer_ton_per_kWh_co2e': 0.0009234}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00043010000000000005,
#    'srmer_ton_per_kWh_co2e': 0.00089875}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0004242,
#    'srmer_ton_per_kWh_co2e': 0.0008741}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00042144999999999997,
#    'srmer_ton_per_kWh_co2e': 0.000831}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0004187,
#    'srmer_ton_per_kWh_co2e': 0.0007879}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00041845,
#    'srmer_ton_per_kWh_co2e': 0.00076175}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0004182,
#    'srmer_ton_per_kWh_co2e': 0.0007356}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00042127999999999995,
#    'srmer_ton_per_kWh_co2e': 0.0007231000000000001}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00042436000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0007106}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00042744,
#    'srmer_ton_per_kWh_co2e': 0.0006981}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00043052000000000005,
#    'srmer_ton_per_kWh_co2e': 0.0006856000000000001}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0004336,
#    'srmer_ton_per_kWh_co2e': 0.0006731}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00043416,
#    'srmer_ton_per_kWh_co2e': 0.00065784}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00043472000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00064258}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00043527999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0006273199999999999}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00043584,
#    'srmer_ton_per_kWh_co2e': 0.00061206}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0004364,
#    'srmer_ton_per_kWh_co2e': 0.0005968}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00043574,
#    'srmer_ton_per_kWh_co2e': 0.00059864}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00043507999999999996,
#    'srmer_ton_per_kWh_co2e': 0.00060048}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00043442000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0006023199999999999}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00043376,
#    'srmer_ton_per_kWh_co2e': 0.00060416}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0004331,
#    'srmer_ton_per_kWh_co2e': 0.000606}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00043008000000000006,
#    'srmer_ton_per_kWh_co2e': 0.00059922}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00042706,
#    'srmer_ton_per_kWh_co2e': 0.0005924400000000001}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00042404000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00058566}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00042102,
#    'srmer_ton_per_kWh_co2e': 0.00057888}, 2050: {'lrmer_ton_per_kWh_co2e': 0.000418,
#    'srmer_ton_per_kWh_co2e': 0.0005721}},
#  ('MidCase',
#   'RFCWc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0004491,
#    'srmer_ton_per_kWh_co2e': 0.000916}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00043555,
#    'srmer_ton_per_kWh_co2e': 0.0008927000000000001}, 2026: {'lrmer_ton_per_kWh_co2e': 0.000422,
#    'srmer_ton_per_kWh_co2e': 0.0008694}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00039694999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00081245}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0003719,
#    'srmer_ton_per_kWh_co2e': 0.0007555}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00037,
#    'srmer_ton_per_kWh_co2e': 0.0007228}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0003681,
#    'srmer_ton_per_kWh_co2e': 0.0006901}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00036976,
#    'srmer_ton_per_kWh_co2e': 0.0006785}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00037142,
#    'srmer_ton_per_kWh_co2e': 0.0006669}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00037307999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0006553}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00037474000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0006437000000000001}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0003764,
#    'srmer_ton_per_kWh_co2e': 0.0006321}, 2036: {'lrmer_ton_per_kWh_co2e': 0.000376,
#    'srmer_ton_per_kWh_co2e': 0.00061828}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00037559999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00060446}, 2038: {'lrmer_ton_per_kWh_co2e': 0.0003752,
#    'srmer_ton_per_kWh_co2e': 0.00059064}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00037479999999999995,
#    'srmer_ton_per_kWh_co2e': 0.00057682}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0003744,
#    'srmer_ton_per_kWh_co2e': 0.000563}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00036847999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0005623}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00036256,
#    'srmer_ton_per_kWh_co2e': 0.0005616}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00035664,
#    'srmer_ton_per_kWh_co2e': 0.0005609}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00035072,
#    'srmer_ton_per_kWh_co2e': 0.0005602000000000001}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00034480000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0005595}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00033978000000000003,
#    'srmer_ton_per_kWh_co2e': 0.00055838}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00033476,
#    'srmer_ton_per_kWh_co2e': 0.00055726}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00032974,
#    'srmer_ton_per_kWh_co2e': 0.00055614}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00032471999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00055502}, 2050: {'lrmer_ton_per_kWh_co2e': 0.00031969999999999996,
#    'srmer_ton_per_kWh_co2e': 0.0005539}},
#  ('MidCase',
#   'RMPAc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0003935,
#    'srmer_ton_per_kWh_co2e': 0.0008767}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00035160000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00082705}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0003097,
#    'srmer_ton_per_kWh_co2e': 0.0007774}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00026210000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007285999999999999}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0002145,
#    'srmer_ton_per_kWh_co2e': 0.0006797999999999999}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00018425,
#    'srmer_ton_per_kWh_co2e': 0.0005934}, 2030: {'lrmer_ton_per_kWh_co2e': 0.000154,
#    'srmer_ton_per_kWh_co2e': 0.000507}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00015208000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00048674}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00015015999999999999,
#    'srmer_ton_per_kWh_co2e': 0.00046648}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00014824,
#    'srmer_ton_per_kWh_co2e': 0.00044622000000000005}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00014632,
#    'srmer_ton_per_kWh_co2e': 0.00042595999999999997}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0001444,
#    'srmer_ton_per_kWh_co2e': 0.0004057}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00014752,
#    'srmer_ton_per_kWh_co2e': 0.0003939}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00015064,
#    'srmer_ton_per_kWh_co2e': 0.00038209999999999996}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00015376,
#    'srmer_ton_per_kWh_co2e': 0.00037029999999999995}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00015688,
#    'srmer_ton_per_kWh_co2e': 0.0003585}, 2040: {'lrmer_ton_per_kWh_co2e': 0.00016,
#    'srmer_ton_per_kWh_co2e': 0.00034669999999999997}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00015944,
#    'srmer_ton_per_kWh_co2e': 0.00032196}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00015888,
#    'srmer_ton_per_kWh_co2e': 0.00029721999999999995}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00015832,
#    'srmer_ton_per_kWh_co2e': 0.00027248}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00015775999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00024774}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0001572,
#    'srmer_ton_per_kWh_co2e': 0.000223}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00016007999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00022356}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00016295999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00022412000000000002}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00016584,
#    'srmer_ton_per_kWh_co2e': 0.00022468}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00016872,
#    'srmer_ton_per_kWh_co2e': 0.00022524}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0001716,
#    'srmer_ton_per_kWh_co2e': 0.0002258}},
#  ('MidCase',
#   'SPNOc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0003539,
#    'srmer_ton_per_kWh_co2e': 0.0008211000000000001}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00028660000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0007514500000000001}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00021930000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0006818}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00015885,
#    'srmer_ton_per_kWh_co2e': 0.00061295}, 2028: {'lrmer_ton_per_kWh_co2e': 9.84e-05,
#    'srmer_ton_per_kWh_co2e': 0.0005441}, 2029: {'lrmer_ton_per_kWh_co2e': 0.000102,
#    'srmer_ton_per_kWh_co2e': 0.0005104500000000001}, 2030: {'lrmer_ton_per_kWh_co2e': 0.00010559999999999999,
#    'srmer_ton_per_kWh_co2e': 0.0004768}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00011302,
#    'srmer_ton_per_kWh_co2e': 0.00046986}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00012043999999999999,
#    'srmer_ton_per_kWh_co2e': 0.00046292}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00012785999999999999,
#    'srmer_ton_per_kWh_co2e': 0.00045598000000000004}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00013528,
#    'srmer_ton_per_kWh_co2e': 0.00044904}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0001427,
#    'srmer_ton_per_kWh_co2e': 0.0004421}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00014906,
#    'srmer_ton_per_kWh_co2e': 0.00043034000000000003}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00015542,
#    'srmer_ton_per_kWh_co2e': 0.00041858000000000005}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00016178,
#    'srmer_ton_per_kWh_co2e': 0.00040682000000000007}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00016814,
#    'srmer_ton_per_kWh_co2e': 0.00039506000000000003}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0001745,
#    'srmer_ton_per_kWh_co2e': 0.0003833}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00017718,
#    'srmer_ton_per_kWh_co2e': 0.00037184}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00017986,
#    'srmer_ton_per_kWh_co2e': 0.00036038}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00018254,
#    'srmer_ton_per_kWh_co2e': 0.00034892}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00018522,
#    'srmer_ton_per_kWh_co2e': 0.00033746}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00018790000000000001,
#    'srmer_ton_per_kWh_co2e': 0.000326}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00018922,
#    'srmer_ton_per_kWh_co2e': 0.00032212}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00019054,
#    'srmer_ton_per_kWh_co2e': 0.00031824}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00019186000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00031436}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00019318000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00031048}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0001945,
#    'srmer_ton_per_kWh_co2e': 0.0003066}},
#  ('MidCase',
#   'SPSOc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.000402,
#    'srmer_ton_per_kWh_co2e': 0.0006807}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00034205,
#    'srmer_ton_per_kWh_co2e': 0.00063445}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0002821,
#    'srmer_ton_per_kWh_co2e': 0.0005882000000000001}, 2027: {'lrmer_ton_per_kWh_co2e': 0.0002298,
#    'srmer_ton_per_kWh_co2e': 0.0005323}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0001775,
#    'srmer_ton_per_kWh_co2e': 0.0004764}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00014915,
#    'srmer_ton_per_kWh_co2e': 0.00045085000000000004}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0001208,
#    'srmer_ton_per_kWh_co2e': 0.00042530000000000004}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00012628,
#    'srmer_ton_per_kWh_co2e': 0.00041696}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00013176,
#    'srmer_ton_per_kWh_co2e': 0.00040862}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00013724,
#    'srmer_ton_per_kWh_co2e': 0.00040028000000000004}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00014272,
#    'srmer_ton_per_kWh_co2e': 0.00039194}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0001482,
#    'srmer_ton_per_kWh_co2e': 0.0003836}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00015529999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00037422000000000003}, 2037: {'lrmer_ton_per_kWh_co2e': 0.0001624,
#    'srmer_ton_per_kWh_co2e': 0.00036484}, 2038: {'lrmer_ton_per_kWh_co2e': 0.0001695,
#    'srmer_ton_per_kWh_co2e': 0.00035546}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00017659999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00034607999999999997}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0001837,
#    'srmer_ton_per_kWh_co2e': 0.0003367}, 2041: {'lrmer_ton_per_kWh_co2e': 0.0001865,
#    'srmer_ton_per_kWh_co2e': 0.00032436}, 2042: {'lrmer_ton_per_kWh_co2e': 0.0001893,
#    'srmer_ton_per_kWh_co2e': 0.00031202}, 2043: {'lrmer_ton_per_kWh_co2e': 0.0001921,
#    'srmer_ton_per_kWh_co2e': 0.00029968000000000003}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00019489999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00028733999999999997}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00019769999999999998,
#    'srmer_ton_per_kWh_co2e': 0.000275}, 2046: {'lrmer_ton_per_kWh_co2e': 0.0001972,
#    'srmer_ton_per_kWh_co2e': 0.00027163999999999997}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00019669999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00026827999999999997}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0001962,
#    'srmer_ton_per_kWh_co2e': 0.00026492000000000003}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00019569999999999999,
#    'srmer_ton_per_kWh_co2e': 0.00026156}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0001952,
#    'srmer_ton_per_kWh_co2e': 0.0002582}},
#  ('MidCase',
#   'SRMVc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0005021,
#    'srmer_ton_per_kWh_co2e': 0.0009}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0004826,
#    'srmer_ton_per_kWh_co2e': 0.0008752}, 2026: {'lrmer_ton_per_kWh_co2e': 0.00046310000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0008504}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00043335000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0007811}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0004036,
#    'srmer_ton_per_kWh_co2e': 0.0007118}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00039914999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0006772000000000001}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0003947,
#    'srmer_ton_per_kWh_co2e': 0.0006426}, 2031: {'lrmer_ton_per_kWh_co2e': 0.0003894,
#    'srmer_ton_per_kWh_co2e': 0.00063048}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00038409999999999996,
#    'srmer_ton_per_kWh_co2e': 0.00061836}, 2033: {'lrmer_ton_per_kWh_co2e': 0.0003788,
#    'srmer_ton_per_kWh_co2e': 0.00060624}, 2034: {'lrmer_ton_per_kWh_co2e': 0.0003735,
#    'srmer_ton_per_kWh_co2e': 0.00059412}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0003682,
#    'srmer_ton_per_kWh_co2e': 0.000582}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00036156000000000003,
#    'srmer_ton_per_kWh_co2e': 0.00055946}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00035492,
#    'srmer_ton_per_kWh_co2e': 0.00053692}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00034827999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00051438}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00034164,
#    'srmer_ton_per_kWh_co2e': 0.00049184}, 2040: {'lrmer_ton_per_kWh_co2e': 0.000335,
#    'srmer_ton_per_kWh_co2e': 0.0004693}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00032186000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00045772}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00030872,
#    'srmer_ton_per_kWh_co2e': 0.00044614}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00029558000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00043456}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00028244,
#    'srmer_ton_per_kWh_co2e': 0.00042297999999999994}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0002693,
#    'srmer_ton_per_kWh_co2e': 0.00041139999999999997}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00026404,
#    'srmer_ton_per_kWh_co2e': 0.00041153999999999995}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00025878,
#    'srmer_ton_per_kWh_co2e': 0.00041168}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00025352,
#    'srmer_ton_per_kWh_co2e': 0.00041181999999999997}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00024826,
#    'srmer_ton_per_kWh_co2e': 0.00041196000000000006}, 2050: {'lrmer_ton_per_kWh_co2e': 0.000243,
#    'srmer_ton_per_kWh_co2e': 0.00041210000000000004}},
#  ('MidCase',
#   'SRMWc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0004297,
#    'srmer_ton_per_kWh_co2e': 0.0009465}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00038085,
#    'srmer_ton_per_kWh_co2e': 0.0009258}, 2026: {'lrmer_ton_per_kWh_co2e': 0.000332,
#    'srmer_ton_per_kWh_co2e': 0.0009051}, 2027: {'lrmer_ton_per_kWh_co2e': 0.0002894,
#    'srmer_ton_per_kWh_co2e': 0.000797}, 2028: {'lrmer_ton_per_kWh_co2e': 0.00024680000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0006889}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00022475,
#    'srmer_ton_per_kWh_co2e': 0.0006350999999999999}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0002027,
#    'srmer_ton_per_kWh_co2e': 0.0005813}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00021041999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00057252}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00021814,
#    'srmer_ton_per_kWh_co2e': 0.00056374}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00022586,
#    'srmer_ton_per_kWh_co2e': 0.00055496}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00023358000000000002,
#    'srmer_ton_per_kWh_co2e': 0.00054618}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0002413,
#    'srmer_ton_per_kWh_co2e': 0.0005373999999999999}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00023734,
#    'srmer_ton_per_kWh_co2e': 0.0005246000000000001}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00023338,
#    'srmer_ton_per_kWh_co2e': 0.0005118}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00022942,
#    'srmer_ton_per_kWh_co2e': 0.000499}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00022546,
#    'srmer_ton_per_kWh_co2e': 0.0004862}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0002215,
#    'srmer_ton_per_kWh_co2e': 0.00047339999999999996}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00021584,
#    'srmer_ton_per_kWh_co2e': 0.00046919999999999997}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00021018,
#    'srmer_ton_per_kWh_co2e': 0.000465}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00020451999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0004608}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00019885999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0004566}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00019319999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0004524}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00018156,
#    'srmer_ton_per_kWh_co2e': 0.00045002}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00016992,
#    'srmer_ton_per_kWh_co2e': 0.00044763999999999996}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00015828,
#    'srmer_ton_per_kWh_co2e': 0.00044526}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00014664,
#    'srmer_ton_per_kWh_co2e': 0.00044288}, 2050: {'lrmer_ton_per_kWh_co2e': 0.000135,
#    'srmer_ton_per_kWh_co2e': 0.0004405}},
#  ('MidCase',
#   'SRSOc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0003733,
#    'srmer_ton_per_kWh_co2e': 0.0008743}, 2025: {'lrmer_ton_per_kWh_co2e': 0.0003343,
#    'srmer_ton_per_kWh_co2e': 0.0008527999999999999}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0002953,
#    'srmer_ton_per_kWh_co2e': 0.0008313}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00027055,
#    'srmer_ton_per_kWh_co2e': 0.0007679}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0002458,
#    'srmer_ton_per_kWh_co2e': 0.0007045}, 2029: {'lrmer_ton_per_kWh_co2e': 0.0002834,
#    'srmer_ton_per_kWh_co2e': 0.00067745}, 2030: {'lrmer_ton_per_kWh_co2e': 0.000321,
#    'srmer_ton_per_kWh_co2e': 0.0006504}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00033914,
#    'srmer_ton_per_kWh_co2e': 0.00063698}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00035727999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0006235599999999999}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00037541999999999995,
#    'srmer_ton_per_kWh_co2e': 0.00061014}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00039356,
#    'srmer_ton_per_kWh_co2e': 0.0005967199999999999}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0004117,
#    'srmer_ton_per_kWh_co2e': 0.0005832999999999999}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00042008,
#    'srmer_ton_per_kWh_co2e': 0.0005724399999999999}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00042846,
#    'srmer_ton_per_kWh_co2e': 0.0005615799999999999}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00043684,
#    'srmer_ton_per_kWh_co2e': 0.00055072}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00044522,
#    'srmer_ton_per_kWh_co2e': 0.00053986}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0004536,
#    'srmer_ton_per_kWh_co2e': 0.000529}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00044384000000000003,
#    'srmer_ton_per_kWh_co2e': 0.00051464}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00043408000000000005,
#    'srmer_ton_per_kWh_co2e': 0.00050028}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00042432,
#    'srmer_ton_per_kWh_co2e': 0.00048592}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00041456,
#    'srmer_ton_per_kWh_co2e': 0.00047156}, 2045: {'lrmer_ton_per_kWh_co2e': 0.00040480000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0004572}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00039782,
#    'srmer_ton_per_kWh_co2e': 0.000456}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00039084,
#    'srmer_ton_per_kWh_co2e': 0.0004548}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00038386000000000003,
#    'srmer_ton_per_kWh_co2e': 0.00045359999999999997}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00037688,
#    'srmer_ton_per_kWh_co2e': 0.0004524}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0003699,
#    'srmer_ton_per_kWh_co2e': 0.00045119999999999996}},
#  ('MidCase',
#   'SRTVc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.0003668,
#    'srmer_ton_per_kWh_co2e': 0.0009168}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00036280000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0008921}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0003588,
#    'srmer_ton_per_kWh_co2e': 0.0008673999999999999}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00036285,
#    'srmer_ton_per_kWh_co2e': 0.0008118499999999999}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0003669,
#    'srmer_ton_per_kWh_co2e': 0.0007563}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00040054999999999995,
#    'srmer_ton_per_kWh_co2e': 0.00073075}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0004342,
#    'srmer_ton_per_kWh_co2e': 0.0007052}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00044446,
#    'srmer_ton_per_kWh_co2e': 0.00069352}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00045472,
#    'srmer_ton_per_kWh_co2e': 0.0006818400000000001}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00046498000000000004,
#    'srmer_ton_per_kWh_co2e': 0.0006701599999999999}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00047524,
#    'srmer_ton_per_kWh_co2e': 0.00065848}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0004855,
#    'srmer_ton_per_kWh_co2e': 0.0006468}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00048434,
#    'srmer_ton_per_kWh_co2e': 0.00063438}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00048318,
#    'srmer_ton_per_kWh_co2e': 0.0006219600000000001}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00048202,
#    'srmer_ton_per_kWh_co2e': 0.00060954}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00048086,
#    'srmer_ton_per_kWh_co2e': 0.00059712}, 2040: {'lrmer_ton_per_kWh_co2e': 0.0004797,
#    'srmer_ton_per_kWh_co2e': 0.0005847000000000001}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00047324,
#    'srmer_ton_per_kWh_co2e': 0.0005745400000000001}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00046677999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00056438}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00046032,
#    'srmer_ton_per_kWh_co2e': 0.00055422}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00045385999999999994,
#    'srmer_ton_per_kWh_co2e': 0.00054406}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0004474,
#    'srmer_ton_per_kWh_co2e': 0.0005339}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00044024,
#    'srmer_ton_per_kWh_co2e': 0.00053292}, 2047: {'lrmer_ton_per_kWh_co2e': 0.00043307999999999997,
#    'srmer_ton_per_kWh_co2e': 0.00053194}, 2048: {'lrmer_ton_per_kWh_co2e': 0.00042592000000000004,
#    'srmer_ton_per_kWh_co2e': 0.00053096}, 2049: {'lrmer_ton_per_kWh_co2e': 0.00041876,
#    'srmer_ton_per_kWh_co2e': 0.00052998}, 2050: {'lrmer_ton_per_kWh_co2e': 0.00041160000000000003,
#    'srmer_ton_per_kWh_co2e': 0.000529}},
#  ('MidCase',
#   'SRVCc'): {2024: {'lrmer_ton_per_kWh_co2e': 0.00037830000000000003,
#    'srmer_ton_per_kWh_co2e': 0.0008696}, 2025: {'lrmer_ton_per_kWh_co2e': 0.00032889999999999997,
#    'srmer_ton_per_kWh_co2e': 0.0008482}, 2026: {'lrmer_ton_per_kWh_co2e': 0.0002795,
#    'srmer_ton_per_kWh_co2e': 0.0008267999999999999}, 2027: {'lrmer_ton_per_kWh_co2e': 0.00024565,
#    'srmer_ton_per_kWh_co2e': 0.00077515}, 2028: {'lrmer_ton_per_kWh_co2e': 0.0002118,
#    'srmer_ton_per_kWh_co2e': 0.0007235}, 2029: {'lrmer_ton_per_kWh_co2e': 0.00021175,
#    'srmer_ton_per_kWh_co2e': 0.0006932}, 2030: {'lrmer_ton_per_kWh_co2e': 0.0002117,
#    'srmer_ton_per_kWh_co2e': 0.0006629}, 2031: {'lrmer_ton_per_kWh_co2e': 0.00021167999999999998,
#    'srmer_ton_per_kWh_co2e': 0.000647}, 2032: {'lrmer_ton_per_kWh_co2e': 0.00021166,
#    'srmer_ton_per_kWh_co2e': 0.0006311}, 2033: {'lrmer_ton_per_kWh_co2e': 0.00021164,
#    'srmer_ton_per_kWh_co2e': 0.0006151999999999999}, 2034: {'lrmer_ton_per_kWh_co2e': 0.00021162,
#    'srmer_ton_per_kWh_co2e': 0.0005993}, 2035: {'lrmer_ton_per_kWh_co2e': 0.0002116,
#    'srmer_ton_per_kWh_co2e': 0.0005834}, 2036: {'lrmer_ton_per_kWh_co2e': 0.00020694,
#    'srmer_ton_per_kWh_co2e': 0.00057482}, 2037: {'lrmer_ton_per_kWh_co2e': 0.00020228,
#    'srmer_ton_per_kWh_co2e': 0.00056624}, 2038: {'lrmer_ton_per_kWh_co2e': 0.00019762,
#    'srmer_ton_per_kWh_co2e': 0.00055766}, 2039: {'lrmer_ton_per_kWh_co2e': 0.00019296,
#    'srmer_ton_per_kWh_co2e': 0.0005490800000000001}, 2040: {'lrmer_ton_per_kWh_co2e': 0.00018830000000000002,
#    'srmer_ton_per_kWh_co2e': 0.0005405}, 2041: {'lrmer_ton_per_kWh_co2e': 0.00017908,
#    'srmer_ton_per_kWh_co2e': 0.00053188}, 2042: {'lrmer_ton_per_kWh_co2e': 0.00016986,
#    'srmer_ton_per_kWh_co2e': 0.00052326}, 2043: {'lrmer_ton_per_kWh_co2e': 0.00016063999999999998,
#    'srmer_ton_per_kWh_co2e': 0.00051464}, 2044: {'lrmer_ton_per_kWh_co2e': 0.00015141999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0005060199999999999}, 2045: {'lrmer_ton_per_kWh_co2e': 0.0001422,
#    'srmer_ton_per_kWh_co2e': 0.0004974}, 2046: {'lrmer_ton_per_kWh_co2e': 0.00013639999999999998,
#    'srmer_ton_per_kWh_co2e': 0.0005001599999999999}, 2047: {'lrmer_ton_per_kWh_co2e': 0.0001306,
#    'srmer_ton_per_kWh_co2e': 0.0005029199999999999}, 2048: {'lrmer_ton_per_kWh_co2e': 0.0001248,
#    'srmer_ton_per_kWh_co2e': 0.00050568}, 2049: {'lrmer_ton_per_kWh_co2e': 0.000119,
#    'srmer_ton_per_kWh_co2e': 0.00050844}, 2050: {'lrmer_ton_per_kWh_co2e': 0.0001132,
#    'srmer_ton_per_kWh_co2e': 0.0005112}}}

# %% [markdown]
# ### Step 4: Use the updated Social Cost of Carbon (190 USD-2020/ton co2e) and inflate to USD-2023
# - EPA Median for 2% near term discount rate and most commonly mentioned value is 190 USD-2020 using the GIVE model.
# - 190 USD-2020 has some inconsistency with the VSL being used. An old study and 2008 VSL is noted
# - 190 USD value and inflate to USD 2023 because there is a clear source and ease of replicability.

# %%
# For co2e adjust SCC
EPA_SCC_USD2023_PER_TON = 190 * cpi_ratio_2023_2020

print(f"""
Steps 3 and 4: Obtain BLS CPI-U Data and Inflate Current Social Cost of Carbon (SCC) to USD2023
      
EPA Median for 2% near term discount rate and most commonly mentioned value is 190 USD-2020 using the GIVE model.
Inflate 190 $USD-2020 Social Cost of Carbon to $USD-2023

SCC Value used in analysis is: ${round(EPA_SCC_USD2023_PER_TON, 2)} per mt CO2e
""")
# Out:
# Steps 3 and 4: Obtain BLS CPI-U Data and Inflate Current Social Cost of Carbon (SCC) to USD2023
#
# EPA Median for 2% near term discount rate and most commonly mentioned value is 190 USD-2020 using the GIVE model.
# Inflate 190 $USD-2020 Social Cost of Carbon to $USD-2023
#
# SCC Value used in analysis is: $223.69 per mt CO2e

# %% [markdown]
# ## HEALTH-RELATED EMISSIONS: Grid Emissions Intensity Projections

# %% [markdown]
# ### PROJECTION FACTORS FOR FUTURE GRID EMISSIONS INTENSITY (Coal Generation Reduction)

# %%
import os
import pandas as pd

print("""
-------------------------------------------------------------------------------------------------------
COAL USED IN ELECTRICITY GENERATION FROM CAMBIUM 2021 RELEASE
-------------------------------------------------------------------------------------------------------
""")

# CAMBIUM 2022 FOR IRA SCENARIO
filename = 'cambium21_midCase_annual_gea.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_cambium21_COAL_processed = pd.read_excel(io=file_path, sheet_name='proc_Cambium21_coal_gea')

print(f"""
Retrieved data for filename: {filename}
Located at filepath: {file_path}
-------------------------------------------------------------------------------------------------------
""")
# df_cambium21_COAL_processed
# Out:
# -------------------------------------------------------------------------------------------------------
# COAL USED IN ELECTRICITY GENERATION FROM CAMBIUM 2021 RELEASE
# -------------------------------------------------------------------------------------------------------
#
#
# Retrieved data for filename: cambium21_midCase_annual_gea.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\cambium21_midCase_annual_gea.xlsx
# -------------------------------------------------------------------------------------------------------

# %%
import os
import pandas as pd

print("""
-------------------------------------------------------------------------------------------------------
COAL USED IN ELECTRICITY GENERATION FROM CAMBIUM 2022 RELEASE
-------------------------------------------------------------------------------------------------------
""")

# CAMBIUM 2022 FOR IRA SCENARIO
filename = 'cambium22_allScenarios_annual_gea.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_cambium22_COAL_processed = pd.read_excel(io=file_path, sheet_name='proc_Cambium22_coal_gea')

print(f"""
Retrieved data for filename: {filename}
Located at filepath: {file_path}
-------------------------------------------------------------------------------------------------------
""")
# df_cambium22_COAL_processed
# Out:
# -------------------------------------------------------------------------------------------------------
# COAL USED IN ELECTRICITY GENERATION FROM CAMBIUM 2022 RELEASE
# -------------------------------------------------------------------------------------------------------
#
#
# Retrieved data for filename: cambium22_allScenarios_annual_gea.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\cambium22_allScenarios_annual_gea.xlsx
# -------------------------------------------------------------------------------------------------------

# %%
mapping = {
    'AKGD': None,       # Alaska Grid - Not included
    'AKMS': None,       # Alaska Miscellaneous - Not included
    'AZNM': 'AZNMc',    # Arizona/New Mexico Power Area
    'CAMX': 'CAMXc',    # California Mexico
    'ERCT': 'ERCTc',    # Electric Reliability Council of Texas
    'FRCC': 'FRCCc',    # Florida Reliability Coordinating Council
    'HIMS': None,       # Hawaii Maui Subregion - Not included
    'HIOA': None,       # Hawaii Oahu Subregion - Not included
    'MROE': 'MROEc',    # Midwest Reliability Organization East
    'MROW': 'MROWc',    # Midwest Reliability Organization West
    'NEWE': 'NEWEc',    # New England
    'NWPP': 'NWPPc',    # Northwest Power Pool
    'NYCW': 'NYSTc',    # New York City/Westchester mapped to New York State
    'NYLI': 'NYSTc',    # New York Long Island mapped to New York State
    'NYUP': 'NYSTc',    # New York Upstate mapped to New York State
    'PRMS': None,       # Puerto Rico Miscellaneous - Not included
    'RFCE': 'RFCEc',    # ReliabilityFirst Corporation East
    'RFCM': 'RFCMc',    # ReliabilityFirst Corporation Midwest
    'RFCW': 'RFCWc',    # ReliabilityFirst Corporation West
    'RMPA': 'RMPAc',    # Rocky Mountain Power Area
    'SPNO': 'SPNOc',    # Southwest Power Pool North
    'SPSO': 'SPSOc',    # Southwest Power Pool South
    'SRMV': 'SRMVc',    # SERC Reliability Corporation Mississippi Valley
    'SRMW': 'SRMWc',    # SERC Reliability Corporation Midwest
    'SRSO': 'SRSOc',    # SERC Reliability Corporation South
    'SRTV': 'SRTVc',    # SERC Reliability Corporation Tennessee Valley
    'SRVC': 'SRVCc',    # SERC Reliability Corporation Virginia/Carolina
}

# EPA eGRID Coal Generation Data for 2018 to 2022 ()
filename = 'epa_eGRID_total_coal_generation_2018_2022.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_epa_eGRID_COAL_processed = pd.read_excel(io=file_path, sheet_name='coal_generation_2018_2022')

print(f"""
Retrieved data for filename: {filename}
Located at filepath: {file_path}
-------------------------------------------------------------------------------------------------------
""") 

# Apply the mapping to the 'cambium_gea_region' column
df_epa_eGRID_COAL_processed['cambium_gea_region'] = df_epa_eGRID_COAL_processed['eGRID_subregion'].map(mapping)

# Drop rows where 'cambium_gea_region' is None (regions not included in the mapping)
df_epa_eGRID_COAL_processed = df_epa_eGRID_COAL_processed.dropna(subset=['cambium_gea_region'])

# Group by 'cambium_gea_region' and aggregate
df_epa_eGRID_COAL_processed = (
    df_epa_eGRID_COAL_processed
    .groupby('cambium_gea_region', as_index=False)
    .agg({
        'eGRID_subregion': 'first',  # Retain the first value (or use a different strategy)
        'coal_MWh_2018': 'sum',
        'coal_MWh_2019': 'sum',
        'coal_MWh_2020': 'sum',
        'coal_MWh_2021': 'sum',
        'coal_MWh_2022': 'sum'
    })
)

# Step 1: Melt the DataFrame to Long Format
columns_to_melt = ['coal_MWh_2018', 'coal_MWh_2019', 'coal_MWh_2020', 'coal_MWh_2021', 'coal_MWh_2022']
df_melted = pd.melt(
    df_epa_eGRID_COAL_processed,
    id_vars=['eGRID_subregion', 'cambium_gea_region'],
    value_vars=columns_to_melt,
    var_name='year',
    value_name='coal_MWh'
)

# Step 2: Extract the Year from Column Names
df_melted['year'] = df_melted['year'].str.extract('(\d{4})').astype(int)
# Out:
# Retrieved data for filename: epa_eGRID_total_coal_generation_2018_2022.xlsx
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\projections\epa_eGRID_total_coal_generation_2018_2022.xlsx
# -------------------------------------------------------------------------------------------------------

# %%
# Pre-IRA Scenario
# Step 3: Create Columns to Match the Target DataFrame
df_preIRA_transformed = pd.DataFrame({
    'data_source': 'EPA_eGRID',
    'scenario': 'MidCase',
    'eGRID_subregion': df_melted['eGRID_subregion'],
    'gea_region': df_melted['cambium_gea_region'],
    'year': df_melted['year'],
    'coal_MWh': df_melted['coal_MWh'],
})

# Step 4: Combine the DataFrames
df_preIRA_coal_generation = pd.concat([df_preIRA_transformed, df_cambium21_COAL_processed], ignore_index=True)
# df_preIRA_coal_generation

# Calculate Coal Generation Projection Factors
df_preIRA_coal_projection_factors = calculate_coal_projection_factors(df_preIRA_coal_generation)
df_preIRA_coal_projection_factors
# Out:
#     scenario gea_region  year     coal_MWh  coal_projection_factors
# 0    MidCase      AZNMc  2018  44146154.50                 1.000000
# 1    MidCase      AZNMc  2019  37909639.38                 0.858730
# 2    MidCase      AZNMc  2020  26535437.00                 0.601082
# 3    MidCase      AZNMc  2021  26836891.44                 0.607910
# 4    MidCase      AZNMc  2022  26741465.00                 0.605748
# ..       ...        ...   ...          ...                      ...
# 655  MidCase      SRVCc  2046  27152428.00                 0.433227
# 656  MidCase      SRVCc  2047  27506921.00                 0.438883
# 657  MidCase      SRVCc  2048  27861414.00                 0.444539
# 658  MidCase      SRVCc  2049  21319390.00                 0.340159
# 659  MidCase      SRVCc  2050  14777366.00                 0.235778
#
# [660 rows x 5 columns]

# %%
# IRA Reference Scenario
# Step 3: Create Columns to Match the Target DataFrame
df_iraRef_transformed = pd.DataFrame({
    'data_source': 'EPA_eGRID',
    'scenario': 'MidCase',
    'eGRID_subregion': df_melted['eGRID_subregion'],
    'gea_region': df_melted['cambium_gea_region'],
    'year': df_melted['year'],
    'coal_MWh': df_melted['coal_MWh'],
})

# Step 4: Combine the DataFrames
df_iraRef_coal_generation = pd.concat([df_iraRef_transformed, df_cambium22_COAL_processed], ignore_index=True)
# df_iraRef_coal_generation

# Calculate Coal Generation Projection Factors
df_iraRef_coal_projection_factors = calculate_coal_projection_factors(df_iraRef_coal_generation)
df_iraRef_coal_projection_factors
# Out:
#     scenario gea_region  year     coal_MWh  coal_projection_factors
# 0    MidCase      AZNMc  2018  44146154.50                 1.000000
# 1    MidCase      AZNMc  2019  37909639.38                 0.858730
# 2    MidCase      AZNMc  2020  26535437.00                 0.601082
# 3    MidCase      AZNMc  2021  26836891.44                 0.607910
# 4    MidCase      AZNMc  2022  26741465.00                 0.605748
# ..       ...        ...   ...          ...                      ...
# 655  MidCase      SRVCc  2046   3826239.64                 0.061049
# 656  MidCase      SRVCc  2047   3350872.78                 0.053464
# 657  MidCase      SRVCc  2048   2875505.92                 0.045880
# 658  MidCase      SRVCc  2049   2400139.06                 0.038295
# 659  MidCase      SRVCc  2050   1924772.20                 0.030710
#
# [660 rows x 5 columns]

# %% [markdown]
# ## ADJUSTED Electricity CEDM-EASIUR Marginal Damages: Pre-IRA and IRA-Reference
# - Factor Type: Marginal
# - Calculation Method: Regression
# - Metric: Marginal Damages EASIUR [USD per MWh or kWh]
# - Year: 2018
# - Regional Aggregation: eGRID subregion (all regions)
# - Pollutants: SO2, NOx, PM2.5 CO2
#
# SCC Adjustment: We use the EPA suggested 190 USD-2020 value for the social cost of carbon and inflate to 2022 USD. **PREVIOUSLY USED 2021 USD**
#
# VSL: "We use a value of a statistical life (VSL) of USD 8.8 million (in 2010 dollars) for both our AP2 and EASIUR calculations. EASIUR reports damage intensities in USD/metric ton using this VSL and dollar year."

# %%
filename = 'Generation-MARREG-DAMEASIUR-egrid-byYear_health2018.csv'
relative_path = os.path.join(r"margDamages_EASIUR", filename)
file_path = os.path.join(project_root, relative_path)
df_margDamages_health2018 = pd.read_csv(file_path, index_col=0)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")

# Marginal damages [$/kWh]
# Inflate from 2010 to 2022
# Note only 2018 data available, used in place of 2021
df_margDamages_EASIUR_health = pd.DataFrame({
    'subregion_eGRID': df_margDamages_health2018['region'],
    'pollutant': df_margDamages_health2018['pollutant'],
    'unit': '[$USD2023/kWh]',
    'margDamages_dollarPerkWh_adjustVSL_ref': (df_margDamages_health2018['factor'] * (vsl_adjustment_factor) * (1/1000)) * (cpi_ratio_2023_2010),
    'margDamages_dollarPerkWh_adjustVSL_2018': (df_margDamages_health2018['factor'] * (vsl_adjustment_factor) * (1/1000)) * (cpi_ratio_2023_2010)
})

# Apply the mapping to the 'cambium_gea_region' column
df_margDamages_EASIUR_health['cambium_gea_region'] = df_margDamages_EASIUR_health['subregion_eGRID'].map(mapping)
df_margDamages_EASIUR_health
# Out:
# Retrieved data for filename: Generation-MARREG-DAMEASIUR-egrid-byYear_health2018.csv
# Located at filepath: c:\Users\14128\Research\cmu-tare-model\margDamages_EASIUR\Generation-MARREG-DAMEASIUR-egrid-byYear_health2018.csv
#    subregion_eGRID pollutant            unit  \
# 1             AZNM       so2  [$USD2023/kWh]
# 2             AZNM       nox  [$USD2023/kWh]
# 3             AZNM      pm25  [$USD2023/kWh]
# 4             CAMX       so2  [$USD2023/kWh]
# 5             CAMX       nox  [$USD2023/kWh]
# ..             ...       ...             ...
# 62            SRTV       nox  [$USD2023/kWh]
# 63            SRTV      pm25  [$USD2023/kWh]
# 64            SRVC       so2  [$USD2023/kWh]
# 65            SRVC       nox  [$USD2023/kWh]
# 66            SRVC      pm25  [$USD2023/kWh]
#
#     margDamages_dollarPerkWh_adjustVSL_ref  \
# 1                                 0.001760
# 2                                 0.000575
# 3                                 0.002026
# 4                                 0.000599
# 5                                 0.000714
# ..                                     ...
# 62                                0.002780
# 63                                0.007428
# 64                                0.008226
# 65                                0.002431
# 66                                0.007534
#
#     margDamages_dollarPerkWh_adjustVSL_2018 cambium_gea_region
# 1                                  0.001760              AZNMc
# 2                                  0.000575              AZNMc
# 3                                  0.002026              AZNMc
# 4                                  0.000599              CAMXc
# 5                                  0.000714              CAMXc
# ..                                      ...                ...
# 62                                 0.002780              SRTVc
# 63                                 0.007428              SRTVc
# 64                                 0.008226              SRVCc
# 65                                 0.002431              SRVCc
# 66                                 0.007534              SRVCc
#
# [66 rows x 6 columns]

# %% [markdown]
# ### Pre-IRA Projections

# %%
# Create dictionaries mapping 'gea_region' to marginal damage factors for each pollutant
# For SO2
so2_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'so2'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# For NOx
nox_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'nox'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# For PM2.5
pm25_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'pm25'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# Map the marginal damage factors to the projection factors dataframe
df_preIRA_coal_projection_factors['so2_marg_damage'] = df_preIRA_coal_projection_factors['gea_region'].map(so2_marg_damages)
df_preIRA_coal_projection_factors['nox_marg_damage'] = df_preIRA_coal_projection_factors['gea_region'].map(nox_marg_damages)
df_preIRA_coal_projection_factors['pm25_marg_damage'] = df_preIRA_coal_projection_factors['gea_region'].map(pm25_marg_damages)

# Calculate the new columns by multiplying the coal projection factors with the marginal damages
df_preIRA_coal_projection_factors['so2_dollarPerkWh_adjustVSL'] = (
    df_preIRA_coal_projection_factors['coal_projection_factors'] * df_preIRA_coal_projection_factors['so2_marg_damage']
)
df_preIRA_coal_projection_factors['nox_dollarPerkWh_adjustVSL'] = (
    df_preIRA_coal_projection_factors['coal_projection_factors'] * df_preIRA_coal_projection_factors['nox_marg_damage']
)
df_preIRA_coal_projection_factors['pm25_dollarPerkWh_adjustVSL'] = (
    df_preIRA_coal_projection_factors['coal_projection_factors'] * df_preIRA_coal_projection_factors['pm25_marg_damage']
)

# Optionally, drop the intermediate marginal damage columns if they're no longer needed
df_preIRA_coal_projection_factors.drop(
    columns=['so2_marg_damage', 'nox_marg_damage', 'pm25_marg_damage'], 
    inplace=True
)
df_preIRA_coal_projection_factors
# Out:
#     scenario gea_region  year     coal_MWh  coal_projection_factors  \
# 0    MidCase      AZNMc  2018  44146154.50                 1.000000
# 1    MidCase      AZNMc  2019  37909639.38                 0.858730
# 2    MidCase      AZNMc  2020  26535437.00                 0.601082
# 3    MidCase      AZNMc  2021  26836891.44                 0.607910
# 4    MidCase      AZNMc  2022  26741465.00                 0.605748
# ..       ...        ...   ...          ...                      ...
# 655  MidCase      SRVCc  2046  27152428.00                 0.433227
# 656  MidCase      SRVCc  2047  27506921.00                 0.438883
# 657  MidCase      SRVCc  2048  27861414.00                 0.444539
# 658  MidCase      SRVCc  2049  21319390.00                 0.340159
# 659  MidCase      SRVCc  2050  14777366.00                 0.235778
#
#      so2_dollarPerkWh_adjustVSL  nox_dollarPerkWh_adjustVSL  \
# 0                      0.001760                    0.000575
# 1                      0.001512                    0.000494
# 2                      0.001058                    0.000346
# 3                      0.001070                    0.000350
# 4                      0.001066                    0.000348
# ..                          ...                         ...
# 655                    0.003564                    0.001053
# 656                    0.003610                    0.001067
# 657                    0.003657                    0.001081
# 658                    0.002798                    0.000827
# 659                    0.001940                    0.000573
#
#      pm25_dollarPerkWh_adjustVSL
# 0                       0.002026
# 1                       0.001740
# 2                       0.001218
# 3                       0.001232
# 4                       0.001227
# ..                           ...
# 655                     0.003264
# 656                     0.003307
# 657                     0.003349
# 658                     0.002563
# 659                     0.001776
#
# [660 rows x 8 columns]

# %%
# Initialize the lookup dictionary
damages_preIRA_health_damages_lookup = {}

# Group the dataframe
grouped = df_preIRA_coal_projection_factors.groupby(['scenario', 'gea_region'])

for (scenario, gea_region), group in grouped:
    year_dict = {}
    for _, row in group.iterrows():
        year = int(row['year'])
        data_dict = {
            'so2_dollarPerkWh_adjustVSL': row['so2_dollarPerkWh_adjustVSL'],
            'nox_dollarPerkWh_adjustVSL': row['nox_dollarPerkWh_adjustVSL'],
            'pm25_dollarPerkWh_adjustVSL': row['pm25_dollarPerkWh_adjustVSL']
        }
        year_dict[year] = data_dict
    damages_preIRA_health_damages_lookup[(scenario, gea_region)] = year_dict

# Now, lookup_dict contains the desired nested dictionary
damages_preIRA_health_damages_lookup
# Out:
# {('MidCase',
#   'AZNMc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.0017604045476692913,
#    'nox_dollarPerkWh_adjustVSL': 0.000575015374879764,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020259847537919245}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0015117126807739248,
#    'nox_dollarPerkWh_adjustVSL': 0.0004937831108176674,
#    'pm25_dollarPerkWh_adjustVSL': 0.0017397744441280825}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0010581466154473767,
#    'nox_dollarPerkWh_adjustVSL': 0.00034563110710250785,
#    'pm25_dollarPerkWh_adjustVSL': 0.001217781965521054}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0010701676345622147,
#    'nox_dollarPerkWh_adjustVSL': 0.0003495576311630751,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012316165136559971}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0010663623396085199,
#    'nox_dollarPerkWh_adjustVSL': 0.00034831467646426797,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012272371398523595}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0012037391306330793,
#    'nox_dollarPerkWh_adjustVSL': 0.0003931871843746519,
#    'pm25_dollarPerkWh_adjustVSL': 0.0013853390287102963}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.001095040930469641,
#    'nox_dollarPerkWh_adjustVSL': 0.00035768219979682466,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012602422737698976}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0010813272013348166,
#    'nox_dollarPerkWh_adjustVSL': 0.0003532027719801328,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012444596480197135}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0010676134721999922,
#    'nox_dollarPerkWh_adjustVSL': 0.00034872334416344097,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012286770222695294}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.001066039138663376,
#    'nox_dollarPerkWh_adjustVSL': 0.0003482091066889118,
#    'pm25_dollarPerkWh_adjustVSL': 0.001226865179788896}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0010644648051267602,
#    'nox_dollarPerkWh_adjustVSL': 0.00034769486921438277,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012250533373082627}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0010286710880176315,
#    'nox_dollarPerkWh_adjustVSL': 0.0003360032738426851,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011838596666598619}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.000992877370908503,
#    'nox_dollarPerkWh_adjustVSL': 0.0003243116784709874,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011426659960114612}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0005587350435597805,
#    'nox_dollarPerkWh_adjustVSL': 0.00018250420958997897,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006430275820180607}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.00012459271621105832,
#    'nox_dollarPerkWh_adjustVSL': 4.069674070897055e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014338916802466027}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.00012654413014464178,
#    'nox_dollarPerkWh_adjustVSL': 4.133414704608249e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014563497844534542}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0001284955440782252,
#    'nox_dollarPerkWh_adjustVSL': 4.197155338319442e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014788078886603052}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0001287060733058484,
#    'nox_dollarPerkWh_adjustVSL': 4.204032027141065e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014812307919978188}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0001289166025334716,
#    'nox_dollarPerkWh_adjustVSL': 4.210908715962687e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014836536953353324}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0001258822122163833,
#    'nox_dollarPerkWh_adjustVSL': 4.111793936463729e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014487320148181244}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.00012284782189929503,
#    'nox_dollarPerkWh_adjustVSL': 4.012679156964771e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00014138103343009162}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.00012108548949088626,
#    'nox_dollarPerkWh_adjustVSL': 3.9551146481803786e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001393528299723826}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.00011932315708247749,
#    'nox_dollarPerkWh_adjustVSL': 3.897550139395987e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013732462651467356}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.00011949993464076455,
#    'nox_dollarPerkWh_adjustVSL': 3.9033243697615775e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001375280732953447}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.00011967671219905159,
#    'nox_dollarPerkWh_adjustVSL': 3.909098600127168e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001377315200760158}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.00011904269801679737,
#    'nox_dollarPerkWh_adjustVSL': 3.888389274922875e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013700185650599407}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.00011840868383454315,
#    'nox_dollarPerkWh_adjustVSL': 3.8676799497185815e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001362721929359723}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.00011823835633830137,
#    'nox_dollarPerkWh_adjustVSL': 3.8621164030194174e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013607616929413712}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.00011806802884205961,
#    'nox_dollarPerkWh_adjustVSL': 3.856552856320253e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001358801456523019}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0001182876539531606,
#    'nox_dollarPerkWh_adjustVSL': 3.863726651443649e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001361329041033236}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.00011850727906426158,
#    'nox_dollarPerkWh_adjustVSL': 3.870900446567045e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013638566255434533}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0001171732267879858,
#    'nox_dollarPerkWh_adjustVSL': 3.827325202980704e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013485035092607528}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.00011583917451171001,
#    'nox_dollarPerkWh_adjustVSL': 3.783749959394363e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00013331503929780522}},
#  ('MidCase',
#   'CAMXc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.0005985940993128373,
#    'nox_dollarPerkWh_adjustVSL': 0.0007136726494222902,
#    'pm25_dollarPerkWh_adjustVSL': 0.004942314992523925}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0005314338138668267,
#    'nox_dollarPerkWh_adjustVSL': 0.0006336009298626856,
#    'pm25_dollarPerkWh_adjustVSL': 0.00438780353635848}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.00048040861844196223,
#    'nox_dollarPerkWh_adjustVSL': 0.0005727662399652133,
#    'pm25_dollarPerkWh_adjustVSL': 0.003966512065837359}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0005365762254811468,
#    'nox_dollarPerkWh_adjustVSL': 0.000639731960097405,
#    'pm25_dollarPerkWh_adjustVSL': 0.004430262053821914}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0003925936374483933,
#    'nox_dollarPerkWh_adjustVSL': 0.00046806899985443967,
#    'pm25_dollarPerkWh_adjustVSL': 0.0032414643287631967}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}},
#  ('MidCase',
#   'ERCTc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.012666544314406074,
#    'nox_dollarPerkWh_adjustVSL': 0.0011137260353787004,
#    'pm25_dollarPerkWh_adjustVSL': 0.004887701560349267}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.01058322703966602,
#    'nox_dollarPerkWh_adjustVSL': 0.0009305470537054345,
#    'pm25_dollarPerkWh_adjustVSL': 0.004083801708763977}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.009280967579574518,
#    'nox_dollarPerkWh_adjustVSL': 0.0008160438214487429,
#    'pm25_dollarPerkWh_adjustVSL': 0.003581292465747344}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.010130647748639804,
#    'nox_dollarPerkWh_adjustVSL': 0.0008907533004150554,
#    'pm25_dollarPerkWh_adjustVSL': 0.003909162718679307}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.009682942230626336,
#    'nox_dollarPerkWh_adjustVSL': 0.0008513880813610147,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037364043952838213}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.009149137664981386,
#    'nox_dollarPerkWh_adjustVSL': 0.0008044524667366977,
#    'pm25_dollarPerkWh_adjustVSL': 0.0035304226102237093}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0075136526437591614,
#    'nox_dollarPerkWh_adjustVSL': 0.0006606498475380701,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028993299860843725}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.007373659762401065,
#    'nox_dollarPerkWh_adjustVSL': 0.0006483407510026507,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028453102465510302}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.007233666881042971,
#    'nox_dollarPerkWh_adjustVSL': 0.0006360316544672313,
#    'pm25_dollarPerkWh_adjustVSL': 0.0027912905070176883}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.007830736954438105,
#    'nox_dollarPerkWh_adjustVSL': 0.0006885299893863566,
#    'pm25_dollarPerkWh_adjustVSL': 0.003021684863752553}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.00842780702783324,
#    'nox_dollarPerkWh_adjustVSL': 0.000741028324305482,
#    'pm25_dollarPerkWh_adjustVSL': 0.003252079220487419}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.00829852221092613,
#    'nox_dollarPerkWh_adjustVSL': 0.0007296607513515189,
#    'pm25_dollarPerkWh_adjustVSL': 0.0032021914542868404}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.00816923739401902,
#    'nox_dollarPerkWh_adjustVSL': 0.0007182931783975559,
#    'pm25_dollarPerkWh_adjustVSL': 0.0031523036880862624}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.008135282726273901,
#    'nox_dollarPerkWh_adjustVSL': 0.0007153076602837193,
#    'pm25_dollarPerkWh_adjustVSL': 0.0031392014339592066}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.008101328058528779,
#    'nox_dollarPerkWh_adjustVSL': 0.0007123221421698826,
#    'pm25_dollarPerkWh_adjustVSL': 0.0031260991798321503}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.007969713917749833,
#    'nox_dollarPerkWh_adjustVSL': 0.0007007497597133038,
#    'pm25_dollarPerkWh_adjustVSL': 0.0030753125860081623}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.007838099776970886,
#    'nox_dollarPerkWh_adjustVSL': 0.000689177377256725,
#    'pm25_dollarPerkWh_adjustVSL': 0.0030245259921841744}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.007267588917587458,
#    'nox_dollarPerkWh_adjustVSL': 0.0006390143034309028,
#    'pm25_dollarPerkWh_adjustVSL': 0.002804380169583361}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.006697078058204029,
#    'nox_dollarPerkWh_adjustVSL': 0.0005888512296050805,
#    'pm25_dollarPerkWh_adjustVSL': 0.002584234346982547}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0063030769769901705,
#    'nox_dollarPerkWh_adjustVSL': 0.0005542080584904334,
#    'pm25_dollarPerkWh_adjustVSL': 0.0024321992179349152}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.005909075895776312,
#    'nox_dollarPerkWh_adjustVSL': 0.000519564887375786,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022801640888872833}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.005694023774979324,
#    'nox_dollarPerkWh_adjustVSL': 0.0005006560879471519,
#    'pm25_dollarPerkWh_adjustVSL': 0.0021971808726062338}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.005478971654182336,
#    'nox_dollarPerkWh_adjustVSL': 0.0004817472885185177,
#    'pm25_dollarPerkWh_adjustVSL': 0.0021141976563251843}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.005254866550623124,
#    'nox_dollarPerkWh_adjustVSL': 0.0004620424911957573,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020277211211976983}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.005030761447063913,
#    'nox_dollarPerkWh_adjustVSL': 0.00044233769387299704,
#    'pm25_dollarPerkWh_adjustVSL': 0.0019412445860702125}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.005123741469963661,
#    'nox_dollarPerkWh_adjustVSL': 0.0004505131101272774,
#    'pm25_dollarPerkWh_adjustVSL': 0.0019771232433999425}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0052167214928634095,
#    'nox_dollarPerkWh_adjustVSL': 0.00045868852638155776,
#    'pm25_dollarPerkWh_adjustVSL': 0.002013001900729672}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0052752482704650355,
#    'nox_dollarPerkWh_adjustVSL': 0.0004638345862984378,
#    'pm25_dollarPerkWh_adjustVSL': 0.002035585915367377}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.005333775048066662,
#    'nox_dollarPerkWh_adjustVSL': 0.0004689806462153179,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020581699300050815}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0056275324011199135,
#    'nox_dollarPerkWh_adjustVSL': 0.0004948097282489427,
#    'pm25_dollarPerkWh_adjustVSL': 0.0021715235201590645}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.005921289754173165,
#    'nox_dollarPerkWh_adjustVSL': 0.0005206388102825675,
#    'pm25_dollarPerkWh_adjustVSL': 0.002284877110313047}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.005329549307584716,
#    'nox_dollarPerkWh_adjustVSL': 0.00046860909126894275,
#    'pm25_dollarPerkWh_adjustVSL': 0.002056539322805946}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.004737808860996268,
#    'nox_dollarPerkWh_adjustVSL': 0.00041657937225531797,
#    'pm25_dollarPerkWh_adjustVSL': 0.001828201535298845}},
#  ('MidCase',
#   'FRCCc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.004087382457213744,
#    'nox_dollarPerkWh_adjustVSL': 0.0009462959863423146,
#    'pm25_dollarPerkWh_adjustVSL': 0.004568195586332583}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0028146027513577363,
#    'nox_dollarPerkWh_adjustVSL': 0.000651626637496864,
#    'pm25_dollarPerkWh_adjustVSL': 0.003145694341213341}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0023929235510240297,
#    'nox_dollarPerkWh_adjustVSL': 0.0005540009959091587,
#    'pm25_dollarPerkWh_adjustVSL': 0.0026744115381047216}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0027690054146686997,
#    'nox_dollarPerkWh_adjustVSL': 0.0006410701072116732,
#    'pm25_dollarPerkWh_adjustVSL': 0.003094733229941809}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0022947035892550522,
#    'nox_dollarPerkWh_adjustVSL': 0.0005312614660086372,
#    'pm25_dollarPerkWh_adjustVSL': 0.0025646376178661305}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.004343350413918846,
#    'nox_dollarPerkWh_adjustVSL': 0.001005556760834995,
#    'pm25_dollarPerkWh_adjustVSL': 0.0048542739512282196}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.003425612529576068,
#    'nox_dollarPerkWh_adjustVSL': 0.0007930854089224416,
#    'pm25_dollarPerkWh_adjustVSL': 0.0038285793418907}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0034953719198978395,
#    'nox_dollarPerkWh_adjustVSL': 0.0008092358503754244,
#    'pm25_dollarPerkWh_adjustVSL': 0.003906544773877801}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.003565131310219611,
#    'nox_dollarPerkWh_adjustVSL': 0.0008253862918284071,
#    'pm25_dollarPerkWh_adjustVSL': 0.0039845102058649025}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.003973284624086053,
#    'nox_dollarPerkWh_adjustVSL': 0.0009198804691575857,
#    'pm25_dollarPerkWh_adjustVSL': 0.004440676025058317}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.004381437937952495,
#    'nox_dollarPerkWh_adjustVSL': 0.0010143746464867643,
#    'pm25_dollarPerkWh_adjustVSL': 0.004896841844251731}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.004092427279346466,
#    'nox_dollarPerkWh_adjustVSL': 0.0009474639452955025,
#    'pm25_dollarPerkWh_adjustVSL': 0.004573833848580311}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.003803416620740438,
#    'nox_dollarPerkWh_adjustVSL': 0.0008805532441042408,
#    'pm25_dollarPerkWh_adjustVSL': 0.004250825852908892}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.003695871848391401,
#    'nox_dollarPerkWh_adjustVSL': 0.0008556548678227698,
#    'pm25_dollarPerkWh_adjustVSL': 0.0041306302119282065}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0035883270760423643,
#    'nox_dollarPerkWh_adjustVSL': 0.0008307564915412988,
#    'pm25_dollarPerkWh_adjustVSL': 0.004010434570947522}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0035667515749840187,
#    'nox_dollarPerkWh_adjustVSL': 0.0008257614096597872,
#    'pm25_dollarPerkWh_adjustVSL': 0.00398632106805432}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0035451760739256735,
#    'nox_dollarPerkWh_adjustVSL': 0.0008207663277782757,
#    'pm25_dollarPerkWh_adjustVSL': 0.003962207565161118}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.003652318944663226,
#    'nox_dollarPerkWh_adjustVSL': 0.0008455716572539159,
#    'pm25_dollarPerkWh_adjustVSL': 0.004081954027434662}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.003759461815400779,
#    'nox_dollarPerkWh_adjustVSL': 0.0008703769867295564,
#    'pm25_dollarPerkWh_adjustVSL': 0.0042017004897082055}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0036877339058623538,
#    'nox_dollarPerkWh_adjustVSL': 0.0008537708008354169,
#    'pm25_dollarPerkWh_adjustVSL': 0.004121534974687217}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0036160059963239286,
#    'nox_dollarPerkWh_adjustVSL': 0.0008371646149412773,
#    'pm25_dollarPerkWh_adjustVSL': 0.004041369459666227}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0035209162558799394,
#    'nox_dollarPerkWh_adjustVSL': 0.0008151497825475849,
#    'pm25_dollarPerkWh_adjustVSL': 0.003935093979661879}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0034258265154359507,
#    'nox_dollarPerkWh_adjustVSL': 0.0007931349501538925,
#    'pm25_dollarPerkWh_adjustVSL': 0.003828818499657532}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0032763953672632767,
#    'nox_dollarPerkWh_adjustVSL': 0.0007585391918096347,
#    'pm25_dollarPerkWh_adjustVSL': 0.003661809241608225}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0031269642190906023,
#    'nox_dollarPerkWh_adjustVSL': 0.000723943433465377,
#    'pm25_dollarPerkWh_adjustVSL': 0.003494799983558918}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.003170299520296474,
#    'nox_dollarPerkWh_adjustVSL': 0.000733976265486192,
#    'pm25_dollarPerkWh_adjustVSL': 0.00354323296818253}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0032136348215023457,
#    'nox_dollarPerkWh_adjustVSL': 0.000744009097507007,
#    'pm25_dollarPerkWh_adjustVSL': 0.0035916659528061425}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0030176204585758756,
#    'nox_dollarPerkWh_adjustVSL': 0.0006986285619578071,
#    'pm25_dollarPerkWh_adjustVSL': 0.0033725937331272222}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.002821606095649405,
#    'nox_dollarPerkWh_adjustVSL': 0.000653248026408607,
#    'pm25_dollarPerkWh_adjustVSL': 0.003153521513448302}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0029331118668202852,
#    'nox_dollarPerkWh_adjustVSL': 0.0006790634387947866,
#    'pm25_dollarPerkWh_adjustVSL': 0.003278144099429809}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.003044617637991165,
#    'nox_dollarPerkWh_adjustVSL': 0.000704878851180966,
#    'pm25_dollarPerkWh_adjustVSL': 0.003402766685411317}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0028628071139443476,
#    'nox_dollarPerkWh_adjustVSL': 0.0006627867369779864,
#    'pm25_dollarPerkWh_adjustVSL': 0.003199569151979213}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0026809965898975303,
#    'nox_dollarPerkWh_adjustVSL': 0.0006206946227750068,
#    'pm25_dollarPerkWh_adjustVSL': 0.0029963716185471088}},
#  ('MidCase',
#   'MROEc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.013246333152908747,
#    'nox_dollarPerkWh_adjustVSL': 0.006215755580135027,
#    'pm25_dollarPerkWh_adjustVSL': 0.01270588475547516}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.009825087614629385,
#    'nox_dollarPerkWh_adjustVSL': 0.004610358388316527,
#    'pm25_dollarPerkWh_adjustVSL': 0.009424225519838646}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.00907556659326667,
#    'nox_dollarPerkWh_adjustVSL': 0.00425865052945592,
#    'pm25_dollarPerkWh_adjustVSL': 0.008705284843252274}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.01124791314131969,
#    'nox_dollarPerkWh_adjustVSL': 0.005278010002162717,
#    'pm25_dollarPerkWh_adjustVSL': 0.01078899997935052}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.008989659992435806,
#    'nox_dollarPerkWh_adjustVSL': 0.004218339416386291,
#    'pm25_dollarPerkWh_adjustVSL': 0.008622883218795781}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.008523024620677219,
#    'nox_dollarPerkWh_adjustVSL': 0.0039993738066273436,
#    'pm25_dollarPerkWh_adjustVSL': 0.00817528649991883}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.008042896465212345,
#    'nox_dollarPerkWh_adjustVSL': 0.0037740767959708217,
#    'pm25_dollarPerkWh_adjustVSL': 0.0077147475008784855}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.007662755660925688,
#    'nox_dollarPerkWh_adjustVSL': 0.003595698198799351,
#    'pm25_dollarPerkWh_adjustVSL': 0.0073501163841487}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.007282614856639033,
#    'nox_dollarPerkWh_adjustVSL': 0.003417319601627881,
#    'pm25_dollarPerkWh_adjustVSL': 0.006985485267418916}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.007308604182981431,
#    'nox_dollarPerkWh_adjustVSL': 0.003429514923787753,
#    'pm25_dollarPerkWh_adjustVSL': 0.00701041423316114}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.00733459350932383,
#    'nox_dollarPerkWh_adjustVSL': 0.003441710245947625,
#    'pm25_dollarPerkWh_adjustVSL': 0.007035343198903364}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0077205942524752325,
#    'nox_dollarPerkWh_adjustVSL': 0.003622838581275107,
#    'pm25_dollarPerkWh_adjustVSL': 0.007405595169874856}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.008106594995626635,
#    'nox_dollarPerkWh_adjustVSL': 0.0038039669166025887,
#    'pm25_dollarPerkWh_adjustVSL': 0.007775847140846348}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.008123435029247977,
#    'nox_dollarPerkWh_adjustVSL': 0.003811868992727599,
#    'pm25_dollarPerkWh_adjustVSL': 0.0077920001036324415}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.00814027506286932,
#    'nox_dollarPerkWh_adjustVSL': 0.003819771068852608,
#    'pm25_dollarPerkWh_adjustVSL': 0.007808153066418532}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.008010773158660455,
#    'nox_dollarPerkWh_adjustVSL': 0.003759003143538303,
#    'pm25_dollarPerkWh_adjustVSL': 0.007683934820395398}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.007881271254451592,
#    'nox_dollarPerkWh_adjustVSL': 0.003698235218223998,
#    'pm25_dollarPerkWh_adjustVSL': 0.007559716574372264}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0077424425096081755,
#    'nox_dollarPerkWh_adjustVSL': 0.003633090733672504,
#    'pm25_dollarPerkWh_adjustVSL': 0.0074265520214076295}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.00760361376476476,
#    'nox_dollarPerkWh_adjustVSL': 0.0035679462491210105,
#    'pm25_dollarPerkWh_adjustVSL': 0.007293387468442996}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0071073068773273625,
#    'nox_dollarPerkWh_adjustVSL': 0.003335057473832203,
#    'pm25_dollarPerkWh_adjustVSL': 0.006817329827257712}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.006610999989889964,
#    'nox_dollarPerkWh_adjustVSL': 0.0031021686985433943,
#    'pm25_dollarPerkWh_adjustVSL': 0.006341272186072428}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.006425278868337739,
#    'nox_dollarPerkWh_adjustVSL': 0.0030150202715552295,
#    'pm25_dollarPerkWh_adjustVSL': 0.006163128458305624}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.006239557746785514,
#    'nox_dollarPerkWh_adjustVSL': 0.0029278718445670646,
#    'pm25_dollarPerkWh_adjustVSL': 0.00598498473053882}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.006106744402446077,
#    'nox_dollarPerkWh_adjustVSL': 0.0028655500475335233,
#    'pm25_dollarPerkWh_adjustVSL': 0.005857590150643662}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.005973931058106641,
#    'nox_dollarPerkWh_adjustVSL': 0.002803228250499982,
#    'pm25_dollarPerkWh_adjustVSL': 0.005730195570748504}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0059065861481404245,
#    'nox_dollarPerkWh_adjustVSL': 0.0027716270900064247,
#    'pm25_dollarPerkWh_adjustVSL': 0.005665598322965203}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.005839241238174208,
#    'nox_dollarPerkWh_adjustVSL': 0.002740025929512867,
#    'pm25_dollarPerkWh_adjustVSL': 0.005601001075181903}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.005989954542869781,
#    'nox_dollarPerkWh_adjustVSL': 0.002810747166390137,
#    'pm25_dollarPerkWh_adjustVSL': 0.005745565299746816}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.006140667847565353,
#    'nox_dollarPerkWh_adjustVSL': 0.002881468403267407,
#    'pm25_dollarPerkWh_adjustVSL': 0.005890129524311729}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.00605789792653958,
#    'nox_dollarPerkWh_adjustVSL': 0.002842629156772213,
#    'pm25_dollarPerkWh_adjustVSL': 0.005810736603596737}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.005975128005513806,
#    'nox_dollarPerkWh_adjustVSL': 0.002803789910277019,
#    'pm25_dollarPerkWh_adjustVSL': 0.005731343682881745}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.005787962484510727,
#    'nox_dollarPerkWh_adjustVSL': 0.00271596370825157,
#    'pm25_dollarPerkWh_adjustVSL': 0.005551814486944122}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0056007969635076486,
#    'nox_dollarPerkWh_adjustVSL': 0.0026281375062261205,
#    'pm25_dollarPerkWh_adjustVSL': 0.005372285291006499}},
#  ('MidCase',
#   'MROWc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.023005225539313577,
#    'nox_dollarPerkWh_adjustVSL': 0.007306287069895563,
#    'pm25_dollarPerkWh_adjustVSL': 0.00856107691560267}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.019258115923299526,
#    'nox_dollarPerkWh_adjustVSL': 0.0061162331627873925,
#    'pm25_dollarPerkWh_adjustVSL': 0.007166641830449063}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.016284528407799415,
#    'nox_dollarPerkWh_adjustVSL': 0.005171844072640285,
#    'pm25_dollarPerkWh_adjustVSL': 0.006060062310419203}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.018049986241535542,
#    'nox_dollarPerkWh_adjustVSL': 0.005732540237997549,
#    'pm25_dollarPerkWh_adjustVSL': 0.006717053057153662}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.017931766634203077,
#    'nox_dollarPerkWh_adjustVSL': 0.00569499457746989,
#    'pm25_dollarPerkWh_adjustVSL': 0.00667305926324036}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.011852022602274626,
#    'nox_dollarPerkWh_adjustVSL': 0.0037641134768762997,
#    'pm25_dollarPerkWh_adjustVSL': 0.004410566500647396}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.011335066796869547,
#    'nox_dollarPerkWh_adjustVSL': 0.003599932190747023,
#    'pm25_dollarPerkWh_adjustVSL': 0.004218188538324135}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.010547430747510148,
#    'nox_dollarPerkWh_adjustVSL': 0.003349784889500877,
#    'pm25_dollarPerkWh_adjustVSL': 0.0039250806620920965}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.009759794698150748,
#    'nox_dollarPerkWh_adjustVSL': 0.003099637588254731,
#    'pm25_dollarPerkWh_adjustVSL': 0.0036319727858600587}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.009870306036207522,
#    'nox_dollarPerkWh_adjustVSL': 0.0031347351602798892,
#    'pm25_dollarPerkWh_adjustVSL': 0.0036730980538359557}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.009980817374264298,
#    'nox_dollarPerkWh_adjustVSL': 0.0031698327323050482,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037142233218118528}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.00997933180008417,
#    'nox_dollarPerkWh_adjustVSL': 0.0031693609250886792,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037136704859008036}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.00997784622590404,
#    'nox_dollarPerkWh_adjustVSL': 0.0031688891178723103,
#    'pm25_dollarPerkWh_adjustVSL': 0.003713117649989755}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.01007012420419721,
#    'nox_dollarPerkWh_adjustVSL': 0.0031981959116043394,
#    'pm25_dollarPerkWh_adjustVSL': 0.003747457624985179}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.010162402182490378,
#    'nox_dollarPerkWh_adjustVSL': 0.003227502705336369,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037817975999806038}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.009156602249451688,
#    'nox_dollarPerkWh_adjustVSL': 0.0029080681910733253,
#    'pm25_dollarPerkWh_adjustVSL': 0.003407503047912971}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.008150802316412999,
#    'nox_dollarPerkWh_adjustVSL': 0.0025886336768102818,
#    'pm25_dollarPerkWh_adjustVSL': 0.0030332084958453387}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.00796097069576223,
#    'nox_dollarPerkWh_adjustVSL': 0.0025283445780119305,
#    'pm25_dollarPerkWh_adjustVSL': 0.0029625652803451255}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.007771139075111462,
#    'nox_dollarPerkWh_adjustVSL': 0.0024680554792135792,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028919220648449123}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.007393062697138699,
#    'nox_dollarPerkWh_adjustVSL': 0.002347981257507089,
#    'pm25_dollarPerkWh_adjustVSL': 0.002751226163113106}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.007014986319165934,
#    'nox_dollarPerkWh_adjustVSL': 0.0022279070358005985,
#    'pm25_dollarPerkWh_adjustVSL': 0.0026105302613813}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.007015178018258371,
#    'nox_dollarPerkWh_adjustVSL': 0.002227967917994428,
#    'pm25_dollarPerkWh_adjustVSL': 0.00261060159955063}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.007015369717350806,
#    'nox_dollarPerkWh_adjustVSL': 0.002228028800188257,
#    'pm25_dollarPerkWh_adjustVSL': 0.0026106729377199595}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.006969256144277632,
#    'nox_dollarPerkWh_adjustVSL': 0.0022133834752765123,
#    'pm25_dollarPerkWh_adjustVSL': 0.0025935124084628973}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.006923142571204457,
#    'nox_dollarPerkWh_adjustVSL': 0.002198738150364768,
#    'pm25_dollarPerkWh_adjustVSL': 0.002576351879205835}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.006509468872230351,
#    'nox_dollarPerkWh_adjustVSL': 0.002067358486522508,
#    'pm25_dollarPerkWh_adjustVSL': 0.0024224089261655726}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.006095795173256246,
#    'nox_dollarPerkWh_adjustVSL': 0.001935978822680249,
#    'pm25_dollarPerkWh_adjustVSL': 0.002268465973125311}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.005985266766102199,
#    'nox_dollarPerkWh_adjustVSL': 0.0019008758296378317,
#    'pm25_dollarPerkWh_adjustVSL': 0.002227334353120638}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.005874738358948152,
#    'nox_dollarPerkWh_adjustVSL': 0.0018657728365954144,
#    'pm25_dollarPerkWh_adjustVSL': 0.002186202733115965}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.005731709640298837,
#    'nox_dollarPerkWh_adjustVSL': 0.0018203479884057973,
#    'pm25_dollarPerkWh_adjustVSL': 0.0021329765711118427}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.005588680921649523,
#    'nox_dollarPerkWh_adjustVSL': 0.0017749231402161803,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020797504091077204}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0050946708598625145,
#    'nox_dollarPerkWh_adjustVSL': 0.0016180292501447849,
#    'pm25_dollarPerkWh_adjustVSL': 0.0018959113883246883}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.004600660798075506,
#    'nox_dollarPerkWh_adjustVSL': 0.0014611353600733892,
#    'pm25_dollarPerkWh_adjustVSL': 0.0017120723675416564}},
#  ('MidCase',
#   'NEWEc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.003167972308851938,
#    'nox_dollarPerkWh_adjustVSL': 0.0014729562382107386,
#    'pm25_dollarPerkWh_adjustVSL': 0.007170684602939741}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0014271691825102802,
#    'nox_dollarPerkWh_adjustVSL': 0.0006635656961037174,
#    'pm25_dollarPerkWh_adjustVSL': 0.0032303881111022865}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.000503752197149397,
#    'nox_dollarPerkWh_adjustVSL': 0.00023422077877078098,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011402398037706684}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0017683978492900878,
#    'nox_dollarPerkWh_adjustVSL': 0.0008222207739859471,
#    'pm25_dollarPerkWh_adjustVSL': 0.004002756966765154}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0010629143557103662,
#    'nox_dollarPerkWh_adjustVSL': 0.0004942045505109574,
#    'pm25_dollarPerkWh_adjustVSL': 0.0024058996928221447}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0016767269412537662,
#    'nox_dollarPerkWh_adjustVSL': 0.0007795981678863766,
#    'pm25_dollarPerkWh_adjustVSL': 0.003795260465941327}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}},
#  ('MidCase',
#   'NWPPc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.006036059052925846,
#    'nox_dollarPerkWh_adjustVSL': 0.0014906377272315239,
#    'pm25_dollarPerkWh_adjustVSL': 0.002749497620689984}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0062401179629307454,
#    'nox_dollarPerkWh_adjustVSL': 0.0015410311887871398,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028424489126868875}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.005027345288260074,
#    'nox_dollarPerkWh_adjustVSL': 0.0012415303576043678,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022900163479609827}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.005159963980739061,
#    'nox_dollarPerkWh_adjustVSL': 0.0012742812675295234,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023504257601673203}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.005079348353191584,
#    'nox_dollarPerkWh_adjustVSL': 0.0012543727983159118,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023137043705671345}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.003996619862547934,
#    'nox_dollarPerkWh_adjustVSL': 0.0009869870881447135,
#    'pm25_dollarPerkWh_adjustVSL': 0.0018205084984301715}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0025008840961106187,
#    'nox_dollarPerkWh_adjustVSL': 0.000617606977070374,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011391828362819767}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0026614567507052397,
#    'nox_dollarPerkWh_adjustVSL': 0.0006572612705094742,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012123256150196667}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0028220294052998616,
#    'nox_dollarPerkWh_adjustVSL': 0.0006969155639485745,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012854683937573567}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0028500886862254395,
#    'nox_dollarPerkWh_adjustVSL': 0.0007038449565174528,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012982497342755137}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0028781479671510174,
#    'nox_dollarPerkWh_adjustVSL': 0.000710774349086331,
#    'pm25_dollarPerkWh_adjustVSL': 0.0013110310747936704}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.002688165517171956,
#    'nox_dollarPerkWh_adjustVSL': 0.0006638571461617849,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012244917799308936}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0024981830671928942,
#    'nox_dollarPerkWh_adjustVSL': 0.0006169399432372389,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011379524850681166}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.002563843670516083,
#    'nox_dollarPerkWh_adjustVSL': 0.0006331551875958714,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011678616809568923}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.002629504273839272,
#    'nox_dollarPerkWh_adjustVSL': 0.000649370431954504,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011977708768456678}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0026533867930396892,
#    'nox_dollarPerkWh_adjustVSL': 0.0006552683504190718,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012086496520766358}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.002677269312240106,
#    'nox_dollarPerkWh_adjustVSL': 0.0006611662688836396,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012195284273076037}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.002675691023300554,
#    'nox_dollarPerkWh_adjustVSL': 0.0006607765018158989,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012188094976805061}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0026741127343610028,
#    'nox_dollarPerkWh_adjustVSL': 0.0006603867347481584,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012180905680534086}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.002294960889431547,
#    'nox_dollarPerkWh_adjustVSL': 0.000566753117275956,
#    'pm25_dollarPerkWh_adjustVSL': 0.001045382334689052}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0019158090445020916,
#    'nox_dollarPerkWh_adjustVSL': 0.00047311949980375365,
#    'pm25_dollarPerkWh_adjustVSL': 0.000872674101324695}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0018827821289074398,
#    'nox_dollarPerkWh_adjustVSL': 0.00046496332274057275,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008576299433650065}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.001849755213312788,
#    'nox_dollarPerkWh_adjustVSL': 0.00045680714567739185,
#    'pm25_dollarPerkWh_adjustVSL': 0.000842585785405318}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0018511469230719094,
#    'nox_dollarPerkWh_adjustVSL': 0.00045715083599819767,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008432197259678348}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0018525386328310314,
#    'nox_dollarPerkWh_adjustVSL': 0.00045749452631900354,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008438536665303515}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0017609723313303375,
#    'nox_dollarPerkWh_adjustVSL': 0.00043488172840513474,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008021441130114039}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0016694060298296438,
#    'nox_dollarPerkWh_adjustVSL': 0.0004122689304912659,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007604345594924562}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0015840505680208947,
#    'nox_dollarPerkWh_adjustVSL': 0.00039118993333736677,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007215541182810183}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0014986951062121454,
#    'nox_dollarPerkWh_adjustVSL': 0.0003701109361834676,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006826736770695805}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0014989369485517816,
#    'nox_dollarPerkWh_adjustVSL': 0.00037017066046918825,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006827838391689869}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0014991787908914178,
#    'nox_dollarPerkWh_adjustVSL': 0.0003702303847549089,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006828940012683935}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0013596778684718046,
#    'nox_dollarPerkWh_adjustVSL': 0.0003357798705835016,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006193496504074018}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0012201769460521913,
#    'nox_dollarPerkWh_adjustVSL': 0.0003013293564120942,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005558052995464102}},
#  ('MidCase',
#   'NYSTc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.00665162210640999,
#    'nox_dollarPerkWh_adjustVSL': 0.0019335789965290178,
#    'pm25_dollarPerkWh_adjustVSL': 0.007329761610473915}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.004065352963812652,
#    'nox_dollarPerkWh_adjustVSL': 0.0011817690449867871,
#    'pm25_dollarPerkWh_adjustVSL': 0.004479819750804052}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0013844217624233764,
#    'nox_dollarPerkWh_adjustVSL': 0.0004024415096551983,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015255649410895798}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0064260429742335895,
#    'nox_dollarPerkWh_adjustVSL': 0.0018680047553809526,
#    'pm25_dollarPerkWh_adjustVSL': 0.007081184460915581}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0034764717689194907,
#    'nox_dollarPerkWh_adjustVSL': 0.0010105854913090998,
#    'pm25_dollarPerkWh_adjustVSL': 0.0038309015310966613}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.003432941468243008,
#    'nox_dollarPerkWh_adjustVSL': 0.0009979315440832753,
#    'pm25_dollarPerkWh_adjustVSL': 0.003782933272875348}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0033894111675665264,
#    'nox_dollarPerkWh_adjustVSL': 0.000985277596857451,
#    'pm25_dollarPerkWh_adjustVSL': 0.003734965014654036}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0032206709154654575,
#    'nox_dollarPerkWh_adjustVSL': 0.0009362260118287076,
#    'pm25_dollarPerkWh_adjustVSL': 0.0035490215256515248}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.003051930663364389,
#    'nox_dollarPerkWh_adjustVSL': 0.0008871744267999644,
#    'pm25_dollarPerkWh_adjustVSL': 0.003363078036649014}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.00236275373263698,
#    'nox_dollarPerkWh_adjustVSL': 0.0006868356196896385,
#    'pm25_dollarPerkWh_adjustVSL': 0.002603638830864608}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0016735768019095717,
#    'nox_dollarPerkWh_adjustVSL': 0.0004864968125793125,
#    'pm25_dollarPerkWh_adjustVSL': 0.0018441996250802022}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.001312597392559266,
#    'nox_dollarPerkWh_adjustVSL': 0.0003815626787795924,
#    'pm25_dollarPerkWh_adjustVSL': 0.0014464180051235237}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0009516179832089598,
#    'nox_dollarPerkWh_adjustVSL': 0.0002766285449798722,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010486363851668445}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0004758089916044799,
#    'nox_dollarPerkWh_adjustVSL': 0.0001383142724899361,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005243181925834223}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}},
#  ('MidCase',
#   'RFCEc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.012996373701117567,
#    'nox_dollarPerkWh_adjustVSL': 0.0026710315291054846,
#    'pm25_dollarPerkWh_adjustVSL': 0.009354037689040239}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.010277728652690459,
#    'nox_dollarPerkWh_adjustVSL': 0.002112292083180589,
# ...
#    'nox_dollarPerkWh_adjustVSL': 0.00079602516028138,
#    'pm25_dollarPerkWh_adjustVSL': 0.003943570596609465}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0016354256992399123,
#    'nox_dollarPerkWh_adjustVSL': 0.0008160841639987025,
#    'pm25_dollarPerkWh_adjustVSL': 0.004042944462165362}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.001675623771482508,
#    'nox_dollarPerkWh_adjustVSL': 0.0008361431677160252,
#    'pm25_dollarPerkWh_adjustVSL': 0.00414231832772126}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0018980272790820453,
#    'nox_dollarPerkWh_adjustVSL': 0.0009471234345995052,
#    'pm25_dollarPerkWh_adjustVSL': 0.0046921232071686116}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0021204307866815827,
#    'nox_dollarPerkWh_adjustVSL': 0.001058103701482985,
#    'pm25_dollarPerkWh_adjustVSL': 0.005241928086615963}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0021031976377722315,
#    'nox_dollarPerkWh_adjustVSL': 0.001049504289154263,
#    'pm25_dollarPerkWh_adjustVSL': 0.005199325928669495}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0020859644888628808,
#    'nox_dollarPerkWh_adjustVSL': 0.001040904876825541,
#    'pm25_dollarPerkWh_adjustVSL': 0.005156723770723028}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0020351981186164515,
#    'nox_dollarPerkWh_adjustVSL': 0.0010155722488491916,
#    'pm25_dollarPerkWh_adjustVSL': 0.005031223960155401}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0019844317483700222,
#    'nox_dollarPerkWh_adjustVSL': 0.000990239620872842,
#    'pm25_dollarPerkWh_adjustVSL': 0.004905724149587774}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.001978371909280973,
#    'nox_dollarPerkWh_adjustVSL': 0.000987215736192999,
#    'pm25_dollarPerkWh_adjustVSL': 0.004890743589542722}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0019723120701919243,
#    'nox_dollarPerkWh_adjustVSL': 0.000984191851513156,
#    'pm25_dollarPerkWh_adjustVSL': 0.004875763029497671}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0019793627161501554,
#    'nox_dollarPerkWh_adjustVSL': 0.000987710152904132,
#    'pm25_dollarPerkWh_adjustVSL': 0.004893192968408846}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.001986413362108386,
#    'nox_dollarPerkWh_adjustVSL': 0.0009912284542951079,
#    'pm25_dollarPerkWh_adjustVSL': 0.004910622907320022}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0019105494828833636,
#    'nox_dollarPerkWh_adjustVSL': 0.0009533720659041067,
#    'pm25_dollarPerkWh_adjustVSL': 0.004723079412966389}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0018346856036583414,
#    'nox_dollarPerkWh_adjustVSL': 0.0009155156775131054,
#    'pm25_dollarPerkWh_adjustVSL': 0.004535535918612757}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0017675411952030478,
#    'nox_dollarPerkWh_adjustVSL': 0.0008820103409717434,
#    'pm25_dollarPerkWh_adjustVSL': 0.004369547873753328}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0017003967867477545,
#    'nox_dollarPerkWh_adjustVSL': 0.0008485050044303813,
#    'pm25_dollarPerkWh_adjustVSL': 0.004203559828893899}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0016581773243313804,
#    'nox_dollarPerkWh_adjustVSL': 0.0008274373186855906,
#    'pm25_dollarPerkWh_adjustVSL': 0.004099188874070816}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0016159578619150063,
#    'nox_dollarPerkWh_adjustVSL': 0.0008063696329407997,
#    'pm25_dollarPerkWh_adjustVSL': 0.003994817919247732}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0016153903781568884,
#    'nox_dollarPerkWh_adjustVSL': 0.0008060864562067287,
#    'pm25_dollarPerkWh_adjustVSL': 0.003993415039668233}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.00161482289439877,
#    'nox_dollarPerkWh_adjustVSL': 0.0008058032794726576,
#    'pm25_dollarPerkWh_adjustVSL': 0.003992012160088734}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0015117029319560945,
#    'nox_dollarPerkWh_adjustVSL': 0.0007543459932255842,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037370887592334825}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0014085829695134194,
#    'nox_dollarPerkWh_adjustVSL': 0.0007028887069785108,
#    'pm25_dollarPerkWh_adjustVSL': 0.003482165358378232}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.00145684097756547,
#    'nox_dollarPerkWh_adjustVSL': 0.0007269696518821552,
#    'pm25_dollarPerkWh_adjustVSL': 0.003601464233588428}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.001505098985617521,
#    'nox_dollarPerkWh_adjustVSL': 0.0007510505967857997,
#    'pm25_dollarPerkWh_adjustVSL': 0.003720763108798625}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0012801270378658765,
#    'nox_dollarPerkWh_adjustVSL': 0.0006387886676811088,
#    'pm25_dollarPerkWh_adjustVSL': 0.003164608774958945}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.001055155090114232,
#    'nox_dollarPerkWh_adjustVSL': 0.0005265267385764178,
#    'pm25_dollarPerkWh_adjustVSL': 0.002608454441119265}},
#  ('MidCase',
#   'SRTVc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.019124945198742256,
#    'nox_dollarPerkWh_adjustVSL': 0.0027802748893221937,
#    'pm25_dollarPerkWh_adjustVSL': 0.007428081065680646}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.016622535355147627,
#    'nox_dollarPerkWh_adjustVSL': 0.002416488892623161,
#    'pm25_dollarPerkWh_adjustVSL': 0.006456151317144657}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.013831967726987957,
#    'nox_dollarPerkWh_adjustVSL': 0.0020108121692180682,
#    'pm25_dollarPerkWh_adjustVSL': 0.005372301803024355}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.01633076234752472,
#    'nox_dollarPerkWh_adjustVSL': 0.00237407260551509,
#    'pm25_dollarPerkWh_adjustVSL': 0.006342827407931942}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.015079931376386616,
#    'nox_dollarPerkWh_adjustVSL': 0.002192233969968544,
#    'pm25_dollarPerkWh_adjustVSL': 0.005857007775168293}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.02183834147322967,
#    'nox_dollarPerkWh_adjustVSL': 0.0031747328837552382,
#    'pm25_dollarPerkWh_adjustVSL': 0.008481957418305902}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.01893095411556391,
#    'nox_dollarPerkWh_adjustVSL': 0.0027520735778042583,
#    'pm25_dollarPerkWh_adjustVSL': 0.007352735412300017}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.019191816568939694,
#    'nox_dollarPerkWh_adjustVSL': 0.0027899962657466724,
#    'pm25_dollarPerkWh_adjustVSL': 0.007454053739256326}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.01945267902231548,
#    'nox_dollarPerkWh_adjustVSL': 0.002827918953689087,
#    'pm25_dollarPerkWh_adjustVSL': 0.007555372066212636}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.019924810018761424,
#    'nox_dollarPerkWh_adjustVSL': 0.002896554651216505,
#    'pm25_dollarPerkWh_adjustVSL': 0.0077387465689250255}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.020396941015207365,
#    'nox_dollarPerkWh_adjustVSL': 0.0029651903487439234,
#    'pm25_dollarPerkWh_adjustVSL': 0.007922121071637414}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.01899893399639883,
#    'nox_dollarPerkWh_adjustVSL': 0.002761956103150102,
#    'pm25_dollarPerkWh_adjustVSL': 0.007379138628645458}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.01760092697759029,
#    'nox_dollarPerkWh_adjustVSL': 0.0025587218575562807,
#    'pm25_dollarPerkWh_adjustVSL': 0.0068361561856535025}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.017290872645462203,
#    'nox_dollarPerkWh_adjustVSL': 0.002513647936298824,
#    'pm25_dollarPerkWh_adjustVSL': 0.006715731855550618}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.016980818313334117,
#    'nox_dollarPerkWh_adjustVSL': 0.0024685740150413673,
#    'pm25_dollarPerkWh_adjustVSL': 0.006595307525447735}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.016781920415811478,
#    'nox_dollarPerkWh_adjustVSL': 0.002439659378984918,
#    'pm25_dollarPerkWh_adjustVSL': 0.006518056077601036}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.016583022518288842,
#    'nox_dollarPerkWh_adjustVSL': 0.0024107447429284686,
#    'pm25_dollarPerkWh_adjustVSL': 0.006440804629754339}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.016458133051305047,
#    'nox_dollarPerkWh_adjustVSL': 0.002392589028212031,
#    'pm25_dollarPerkWh_adjustVSL': 0.006392297871938046}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.016333243584321255,
#    'nox_dollarPerkWh_adjustVSL': 0.0023744333134955928,
#    'pm25_dollarPerkWh_adjustVSL': 0.0063437911141217525}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.016093467349288064,
#    'nox_dollarPerkWh_adjustVSL': 0.002339576019088138,
#    'pm25_dollarPerkWh_adjustVSL': 0.006250662621833714}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.015853691114254873,
#    'nox_dollarPerkWh_adjustVSL': 0.0023047187246806834,
#    'pm25_dollarPerkWh_adjustVSL': 0.0061575341295456755}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.015626418252889678,
#    'nox_dollarPerkWh_adjustVSL': 0.0022716790990550055,
#    'pm25_dollarPerkWh_adjustVSL': 0.00606926191643832}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.015399145391524484,
#    'nox_dollarPerkWh_adjustVSL': 0.002238639473429327,
#    'pm25_dollarPerkWh_adjustVSL': 0.005980989703330965}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.015388587254259838,
#    'nox_dollarPerkWh_adjustVSL': 0.002237104591963793,
#    'pm25_dollarPerkWh_adjustVSL': 0.005976888949122815}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.01537802911699519,
#    'nox_dollarPerkWh_adjustVSL': 0.0022355697104982576,
#    'pm25_dollarPerkWh_adjustVSL': 0.005972788194914664}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.01525994316843324,
#    'nox_dollarPerkWh_adjustVSL': 0.0022184030522852884,
#    'pm25_dollarPerkWh_adjustVSL': 0.005926923906702552}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.015141857219871291,
#    'nox_dollarPerkWh_adjustVSL': 0.0022012363940723187,
#    'pm25_dollarPerkWh_adjustVSL': 0.005881059618490441}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.01469365960422184,
#    'nox_dollarPerkWh_adjustVSL': 0.002136079994234572,
#    'pm25_dollarPerkWh_adjustVSL': 0.005706980781249755}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.014245461988572392,
#    'nox_dollarPerkWh_adjustVSL': 0.0020709235943968253,
#    'pm25_dollarPerkWh_adjustVSL': 0.0055329019440090695}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.012489076781555416,
#    'nox_dollarPerkWh_adjustVSL': 0.0018155903823901631,
#    'pm25_dollarPerkWh_adjustVSL': 0.004850726305610776}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.010732691574538442,
#    'nox_dollarPerkWh_adjustVSL': 0.0015602571703835005,
#    'pm25_dollarPerkWh_adjustVSL': 0.004168550667212483}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.010194640387619884,
#    'nox_dollarPerkWh_adjustVSL': 0.001482038373486867,
#    'pm25_dollarPerkWh_adjustVSL': 0.003959572926759685}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.009656589200701329,
#    'nox_dollarPerkWh_adjustVSL': 0.0014038195765902338,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037505951863068886}},
#  ('MidCase',
#   'SRVCc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.008226296131836222,
#    'nox_dollarPerkWh_adjustVSL': 0.0024308903916151164,
#    'pm25_dollarPerkWh_adjustVSL': 0.007534057412737781}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.006866804179516115,
#    'nox_dollarPerkWh_adjustVSL': 0.0020291572335315706,
#    'pm25_dollarPerkWh_adjustVSL': 0.0062889660305669335}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0053806308723014585,
#    'nox_dollarPerkWh_adjustVSL': 0.0015899894288616747,
#    'pm25_dollarPerkWh_adjustVSL': 0.004927853466371618}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.005676781522458289,
#    'nox_dollarPerkWh_adjustVSL': 0.0016775026618403317,
#    'pm25_dollarPerkWh_adjustVSL': 0.00519908318693398}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.004677150637123422,
#    'nox_dollarPerkWh_adjustVSL': 0.0013821093189094796,
#    'pm25_dollarPerkWh_adjustVSL': 0.004283570742334238}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.008418148989595546,
#    'nox_dollarPerkWh_adjustVSL': 0.0024875833748309955,
#    'pm25_dollarPerkWh_adjustVSL': 0.007709765948145674}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.00708861920935403,
#    'nox_dollarPerkWh_adjustVSL': 0.002094704111021434,
#    'pm25_dollarPerkWh_adjustVSL': 0.006492115436207643}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.006810132177138153,
#    'nox_dollarPerkWh_adjustVSL': 0.002012410519840943,
#    'pm25_dollarPerkWh_adjustVSL': 0.006237062948940929}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.006531645144922277,
#    'nox_dollarPerkWh_adjustVSL': 0.0019301169286604525,
#    'pm25_dollarPerkWh_adjustVSL': 0.0059820104616742165}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.007054902919602097,
#    'nox_dollarPerkWh_adjustVSL': 0.0020847408659004987,
#    'pm25_dollarPerkWh_adjustVSL': 0.006461236355432457}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.007578160694281917,
#    'nox_dollarPerkWh_adjustVSL': 0.0022393648031405456,
#    'pm25_dollarPerkWh_adjustVSL': 0.006940462249190699}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.007386353398579677,
#    'nox_dollarPerkWh_adjustVSL': 0.0021826852836226676,
#    'pm25_dollarPerkWh_adjustVSL': 0.006764795441815495}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.007194546102877436,
#    'nox_dollarPerkWh_adjustVSL': 0.0021260057641047892,
#    'pm25_dollarPerkWh_adjustVSL': 0.006589128634440292}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.007024636236580417,
#    'nox_dollarPerkWh_adjustVSL': 0.0020757969879067655,
#    'pm25_dollarPerkWh_adjustVSL': 0.006433516598700629}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.006854726370283399,
#    'nox_dollarPerkWh_adjustVSL': 0.002025588211708742,
#    'pm25_dollarPerkWh_adjustVSL': 0.006277904562960969}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.006451650284764264,
#    'nox_dollarPerkWh_adjustVSL': 0.0019064782541196536,
#    'pm25_dollarPerkWh_adjustVSL': 0.0059087471291250785}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.006048574199245128,
#    'nox_dollarPerkWh_adjustVSL': 0.0017873682965305643,
#    'pm25_dollarPerkWh_adjustVSL': 0.005539589695289188}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.005977573884784195,
#    'nox_dollarPerkWh_adjustVSL': 0.001766387531984928,
#    'pm25_dollarPerkWh_adjustVSL': 0.005474564021900051}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.005906573570323263,
#    'nox_dollarPerkWh_adjustVSL': 0.0017454067674392921,
#    'pm25_dollarPerkWh_adjustVSL': 0.005409538348510914}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.005702925363671972,
#    'nox_dollarPerkWh_adjustVSL': 0.0016852282301140415,
#    'pm25_dollarPerkWh_adjustVSL': 0.005223027036940924}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.005499277157020682,
#    'nox_dollarPerkWh_adjustVSL': 0.001625049692788791,
#    'pm25_dollarPerkWh_adjustVSL': 0.005036515725370934}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.005218818039684875,
#    'nox_dollarPerkWh_adjustVSL': 0.0015421733456884232,
#    'pm25_dollarPerkWh_adjustVSL': 0.004779657102964147}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.004938358922349067,
#    'nox_dollarPerkWh_adjustVSL': 0.0014592969985880555,
#    'pm25_dollarPerkWh_adjustVSL': 0.00452279848055736}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.004935192560856009,
#    'nox_dollarPerkWh_adjustVSL': 0.0014583613311131066,
#    'pm25_dollarPerkWh_adjustVSL': 0.00451989856680567}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.004932026199362949,
#    'nox_dollarPerkWh_adjustVSL': 0.0014574256636381575,
#    'pm25_dollarPerkWh_adjustVSL': 0.0045169986530539784}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0046474626511595635,
#    'nox_dollarPerkWh_adjustVSL': 0.0013733364472951629,
#    'pm25_dollarPerkWh_adjustVSL': 0.004256380985591267}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.004362899102956178,
#    'nox_dollarPerkWh_adjustVSL': 0.0012892472309521687,
#    'pm25_dollarPerkWh_adjustVSL': 0.003995763318128557}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.003963376314499724,
#    'nox_dollarPerkWh_adjustVSL': 0.001171187281234155,
#    'pm25_dollarPerkWh_adjustVSL': 0.0036298601731786628}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0035638535260432693,
#    'nox_dollarPerkWh_adjustVSL': 0.0010531273315161414,
#    'pm25_dollarPerkWh_adjustVSL': 0.003263957028228769}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0036103820032758636,
#    'nox_dollarPerkWh_adjustVSL': 0.0010668766090073164,
#    'pm25_dollarPerkWh_adjustVSL': 0.0033065701572943503}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0036569104805084583,
#    'nox_dollarPerkWh_adjustVSL': 0.0010806258864984916,
#    'pm25_dollarPerkWh_adjustVSL': 0.003349183286359932}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0027982463750421,
#    'nox_dollarPerkWh_adjustVSL': 0.000826888567764618,
#    'pm25_dollarPerkWh_adjustVSL': 0.002562775337367625}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0019395822695757422,
#    'nox_dollarPerkWh_adjustVSL': 0.0005731512490307444,
#    'pm25_dollarPerkWh_adjustVSL': 0.0017763673883753178}}}

# %% [markdown]
# ### IRA-Reference Projections

# %%
# Create dictionaries mapping 'gea_region' to marginal damage factors for each pollutant
# For SO2
so2_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'so2'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# For NOx
nox_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'nox'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# For PM2.5
pm25_marg_damages = df_margDamages_EASIUR_health[df_margDamages_EASIUR_health['pollutant'] == 'pm25'] \
    .set_index('cambium_gea_region')['margDamages_dollarPerkWh_adjustVSL_ref'].to_dict()

# Map the marginal damage factors to the projection factors dataframe
df_iraRef_coal_projection_factors['so2_marg_damage'] = df_iraRef_coal_projection_factors['gea_region'].map(so2_marg_damages)
df_iraRef_coal_projection_factors['nox_marg_damage'] = df_iraRef_coal_projection_factors['gea_region'].map(nox_marg_damages)
df_iraRef_coal_projection_factors['pm25_marg_damage'] = df_iraRef_coal_projection_factors['gea_region'].map(pm25_marg_damages)

# Calculate the new columns by multiplying the coal projection factors with the marginal damages
df_iraRef_coal_projection_factors['so2_dollarPerkWh_adjustVSL'] = (
    df_iraRef_coal_projection_factors['coal_projection_factors'] * df_iraRef_coal_projection_factors['so2_marg_damage']
)
df_iraRef_coal_projection_factors['nox_dollarPerkWh_adjustVSL'] = (
    df_iraRef_coal_projection_factors['coal_projection_factors'] * df_iraRef_coal_projection_factors['nox_marg_damage']
)
df_iraRef_coal_projection_factors['pm25_dollarPerkWh_adjustVSL'] = (
    df_iraRef_coal_projection_factors['coal_projection_factors'] * df_iraRef_coal_projection_factors['pm25_marg_damage']
)

# Optionally, drop the intermediate marginal damage columns if they're no longer needed
df_iraRef_coal_projection_factors.drop(
    columns=['so2_marg_damage', 'nox_marg_damage', 'pm25_marg_damage'], 
    inplace=True
)
df_iraRef_coal_projection_factors
# Out:
#     scenario gea_region  year     coal_MWh  coal_projection_factors  \
# 0    MidCase      AZNMc  2018  44146154.50                 1.000000
# 1    MidCase      AZNMc  2019  37909639.38                 0.858730
# 2    MidCase      AZNMc  2020  26535437.00                 0.601082
# 3    MidCase      AZNMc  2021  26836891.44                 0.607910
# 4    MidCase      AZNMc  2022  26741465.00                 0.605748
# ..       ...        ...   ...          ...                      ...
# 655  MidCase      SRVCc  2046   3826239.64                 0.061049
# 656  MidCase      SRVCc  2047   3350872.78                 0.053464
# 657  MidCase      SRVCc  2048   2875505.92                 0.045880
# 658  MidCase      SRVCc  2049   2400139.06                 0.038295
# 659  MidCase      SRVCc  2050   1924772.20                 0.030710
#
#      so2_dollarPerkWh_adjustVSL  nox_dollarPerkWh_adjustVSL  \
# 0                      0.001760                    0.000575
# 1                      0.001512                    0.000494
# 2                      0.001058                    0.000346
# 3                      0.001070                    0.000350
# 4                      0.001066                    0.000348
# ..                          ...                         ...
# 655                    0.000502                    0.000148
# 656                    0.000440                    0.000130
# 657                    0.000377                    0.000112
# 658                    0.000315                    0.000093
# 659                    0.000253                    0.000075
#
#      pm25_dollarPerkWh_adjustVSL
# 0                       0.002026
# 1                       0.001740
# 2                       0.001218
# 3                       0.001232
# 4                       0.001227
# ..                           ...
# 655                     0.000460
# 656                     0.000403
# 657                     0.000346
# 658                     0.000289
# 659                     0.000231
#
# [660 rows x 8 columns]

# %%
# Initialize the lookup dictionary
damages_iraRef_health_damages_lookup = {}

# Group the dataframe
grouped = df_iraRef_coal_projection_factors.groupby(['scenario', 'gea_region'])

for (scenario, gea_region), group in grouped:
    year_dict = {}
    for _, row in group.iterrows():
        year = int(row['year'])
        data_dict = {
            'so2_dollarPerkWh_adjustVSL': row['so2_dollarPerkWh_adjustVSL'],
            'nox_dollarPerkWh_adjustVSL': row['nox_dollarPerkWh_adjustVSL'],
            'pm25_dollarPerkWh_adjustVSL': row['pm25_dollarPerkWh_adjustVSL']
        }
        year_dict[year] = data_dict
    damages_iraRef_health_damages_lookup[(scenario, gea_region)] = year_dict

# Now, lookup_dict contains the desired nested dictionary
damages_iraRef_health_damages_lookup
# Out:
# {('MidCase',
#   'AZNMc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.0017604045476692913,
#    'nox_dollarPerkWh_adjustVSL': 0.000575015374879764,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020259847537919245}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0015117126807739248,
#    'nox_dollarPerkWh_adjustVSL': 0.0004937831108176674,
#    'pm25_dollarPerkWh_adjustVSL': 0.0017397744441280825}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0010581466154473767,
#    'nox_dollarPerkWh_adjustVSL': 0.00034563110710250785,
#    'pm25_dollarPerkWh_adjustVSL': 0.001217781965521054}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0010701676345622147,
#    'nox_dollarPerkWh_adjustVSL': 0.0003495576311630751,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012316165136559971}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0010663623396085199,
#    'nox_dollarPerkWh_adjustVSL': 0.00034831467646426797,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012272371398523595}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0009887543357298897,
#    'nox_dollarPerkWh_adjustVSL': 0.000322964937676656,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011379209466861357}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0009111463318512595,
#    'nox_dollarPerkWh_adjustVSL': 0.0002976151988890441,
#    'pm25_dollarPerkWh_adjustVSL': 0.001048604753519912}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0008744767222362603,
#    'nox_dollarPerkWh_adjustVSL': 0.000285637503564762,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010064030504478253}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.000837807112621261,
#    'nox_dollarPerkWh_adjustVSL': 0.0002736598082404799,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009642013473757389}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0007076779183616448,
#    'nox_dollarPerkWh_adjustVSL': 0.00023115464230060432,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008144404506873844}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0005775487241020287,
#    'nox_dollarPerkWh_adjustVSL': 0.00018864947636072874,
#    'pm25_dollarPerkWh_adjustVSL': 0.00066467955399903}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0005566240449226292,
#    'nox_dollarPerkWh_adjustVSL': 0.00018181467679235052,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006405981114399447}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0005356993657432299,
#    'nox_dollarPerkWh_adjustVSL': 0.0001749798772239723,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006165166688808594}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0004942072670497781,
#    'nox_dollarPerkWh_adjustVSL': 0.0001614269727416752,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005687649407527662}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.00045271516835632624,
#    'nox_dollarPerkWh_adjustVSL': 0.0001478740682593781,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005210132126246727}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0004112230696628745,
#    'nox_dollarPerkWh_adjustVSL': 0.000134321163777081,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004732614844965794}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0003697309709694227,
#    'nox_dollarPerkWh_adjustVSL': 0.00012076825929478388,
#    'pm25_dollarPerkWh_adjustVSL': 0.00042550975636848604}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0003282388722759708,
#    'nox_dollarPerkWh_adjustVSL': 0.00010721535481248676,
#    'pm25_dollarPerkWh_adjustVSL': 0.00037775802824039257}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.00031074484053296143,
#    'nox_dollarPerkWh_adjustVSL': 0.0001015011357517696,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003576247914564876}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.00029325080878995206,
#    'nox_dollarPerkWh_adjustVSL': 9.578691669105243e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003374915546725826}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0002757567770469427,
#    'nox_dollarPerkWh_adjustVSL': 9.007269763033528e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003173583178886777}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0002582627453039333,
#    'nox_dollarPerkWh_adjustVSL': 8.435847856961812e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00029722508110477267}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0002407687135609239,
#    'nox_dollarPerkWh_adjustVSL': 7.864425950890097e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0002770918443208677}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.00023347141841992462,
#    'nox_dollarPerkWh_adjustVSL': 7.626068415023388e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00026869365612079845}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.00022617412327892534,
#    'nox_dollarPerkWh_adjustVSL': 7.38771087915668e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00026029546792072925}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.000218876828137926,
#    'nox_dollarPerkWh_adjustVSL': 7.149353343289971e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00025189727972066}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.00021157953299692675,
#    'nox_dollarPerkWh_adjustVSL': 6.910995807423265e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00024349909152059077}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.00020428223785592747,
#    'nox_dollarPerkWh_adjustVSL': 6.672638271556558e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00023510090332052154}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.00020773031142594207,
#    'nox_dollarPerkWh_adjustVSL': 6.78526552641681e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00023906916419104212}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0002111783849959567,
#    'nox_dollarPerkWh_adjustVSL': 6.897892781277063e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0002430374250615627}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.00021462645856597137,
#    'nox_dollarPerkWh_adjustVSL': 7.010520036137316e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00024700568593208333}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.000218074532135986,
#    'nox_dollarPerkWh_adjustVSL': 7.123147290997567e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0002509739468026039}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0002215226057060006,
#    'nox_dollarPerkWh_adjustVSL': 7.23577454585782e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00025494220767312444}},
#  ('MidCase',
#   'CAMXc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.0005985940993128373,
#    'nox_dollarPerkWh_adjustVSL': 0.0007136726494222902,
#    'pm25_dollarPerkWh_adjustVSL': 0.004942314992523925}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0005314338138668267,
#    'nox_dollarPerkWh_adjustVSL': 0.0006336009298626856,
#    'pm25_dollarPerkWh_adjustVSL': 0.00438780353635848}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.00048040861844196223,
#    'nox_dollarPerkWh_adjustVSL': 0.0005727662399652133,
#    'pm25_dollarPerkWh_adjustVSL': 0.003966512065837359}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0005365762254811468,
#    'nox_dollarPerkWh_adjustVSL': 0.000639731960097405,
#    'pm25_dollarPerkWh_adjustVSL': 0.004430262053821914}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0003925936374483933,
#    'nox_dollarPerkWh_adjustVSL': 0.00046806899985443967,
#    'pm25_dollarPerkWh_adjustVSL': 0.0032414643287631967}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.00019629681872419664,
#    'nox_dollarPerkWh_adjustVSL': 0.00023403449992721984,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016207321643815983}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}},
#  ('MidCase',
#   'ERCTc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.012666544314406074,
#    'nox_dollarPerkWh_adjustVSL': 0.0011137260353787004,
#    'pm25_dollarPerkWh_adjustVSL': 0.004887701560349267}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.01058322703966602,
#    'nox_dollarPerkWh_adjustVSL': 0.0009305470537054345,
#    'pm25_dollarPerkWh_adjustVSL': 0.004083801708763977}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.009280967579574518,
#    'nox_dollarPerkWh_adjustVSL': 0.0008160438214487429,
#    'pm25_dollarPerkWh_adjustVSL': 0.003581292465747344}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.010130647748639804,
#    'nox_dollarPerkWh_adjustVSL': 0.0008907533004150554,
#    'pm25_dollarPerkWh_adjustVSL': 0.003909162718679307}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.009682942230626336,
#    'nox_dollarPerkWh_adjustVSL': 0.0008513880813610147,
#    'pm25_dollarPerkWh_adjustVSL': 0.0037364043952838213}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.007492994374491886,
#    'nox_dollarPerkWh_adjustVSL': 0.0006588334363877407,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028913584784319704}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.005303046518357437,
#    'nox_dollarPerkWh_adjustVSL': 0.0004662787914144667,
#    'pm25_dollarPerkWh_adjustVSL': 0.00204631256158012}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.004276562489225045,
#    'nox_dollarPerkWh_adjustVSL': 0.0003760235521188563,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016502181362712507}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0032500784600926536,
#    'nox_dollarPerkWh_adjustVSL': 0.000285768312823246,
#    'pm25_dollarPerkWh_adjustVSL': 0.001254123710962382}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0023353917795582517,
#    'nox_dollarPerkWh_adjustVSL': 0.00020534303304376654,
#    'pm25_dollarPerkWh_adjustVSL': 0.000901169076714271}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0014207050990238499,
#    'nox_dollarPerkWh_adjustVSL': 0.00012491775326428707,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005482144424661597}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0013191844032118128,
#    'nox_dollarPerkWh_adjustVSL': 0.00011599138477347202,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005090401538037114}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0012176637073997756,
#    'nox_dollarPerkWh_adjustVSL': 0.00010706501628265694,
#    'pm25_dollarPerkWh_adjustVSL': 0.000469865865141263}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0011790004389813451,
#    'nox_dollarPerkWh_adjustVSL': 0.00010366548697287769,
#    'pm25_dollarPerkWh_adjustVSL': 0.00045494668018550223}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0011403371705629149,
#    'nox_dollarPerkWh_adjustVSL': 0.00010026595766309847,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004400274952297415}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0011016739021444846,
#    'nox_dollarPerkWh_adjustVSL': 9.686642835331924e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00042510831027398066}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0010630106337260544,
#    'nox_dollarPerkWh_adjustVSL': 9.346689904354002e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004101891253182199}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0010243473653076239,
#    'nox_dollarPerkWh_adjustVSL': 9.006736973376078e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00039526994036245914}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.001008123825766015,
#    'nox_dollarPerkWh_adjustVSL': 8.864088924113455e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00038900968361336893}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0009919002862244057,
#    'nox_dollarPerkWh_adjustVSL': 8.721440874850833e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00038274942686427867}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0009756767466827964,
#    'nox_dollarPerkWh_adjustVSL': 8.578792825588208e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003764891701151884}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0009594532071411873,
#    'nox_dollarPerkWh_adjustVSL': 8.436144776325586e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003702289133660982}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.000943229667599578,
#    'nox_dollarPerkWh_adjustVSL': 8.293496727062962e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00036396865661700794}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0009179213706641293,
#    'nox_dollarPerkWh_adjustVSL': 8.070969504890401e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003542028199885845}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0008926130737286805,
#    'nox_dollarPerkWh_adjustVSL': 7.848442282717841e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00034443698336016103}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0008673047767932317,
#    'nox_dollarPerkWh_adjustVSL': 7.62591506054528e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003346711467317376}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0008419964798577828,
#    'nox_dollarPerkWh_adjustVSL': 7.403387838372718e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003249053101033141}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0008166881829223341,
#    'nox_dollarPerkWh_adjustVSL': 7.180860616200158e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003151394734748907}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0008352206518353852,
#    'nox_dollarPerkWh_adjustVSL': 7.343810293839043e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003222906881215266}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0008537531207484359,
#    'nox_dollarPerkWh_adjustVSL': 7.506759971477928e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00032944190276816245}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.000872285589661487,
#    'nox_dollarPerkWh_adjustVSL': 7.669709649116814e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003365931174147984}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0008908180585745378,
#    'nox_dollarPerkWh_adjustVSL': 7.832659326755698e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003437443320614343}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0009093505274875889,
#    'nox_dollarPerkWh_adjustVSL': 7.995609004394584e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003508955467080702}},
#  ('MidCase',
#   'FRCCc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.004087382457213744,
#    'nox_dollarPerkWh_adjustVSL': 0.0009462959863423146,
#    'pm25_dollarPerkWh_adjustVSL': 0.004568195586332583}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0028146027513577363,
#    'nox_dollarPerkWh_adjustVSL': 0.000651626637496864,
#    'pm25_dollarPerkWh_adjustVSL': 0.003145694341213341}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0023929235510240297,
#    'nox_dollarPerkWh_adjustVSL': 0.0005540009959091587,
#    'pm25_dollarPerkWh_adjustVSL': 0.0026744115381047216}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0027690054146686997,
#    'nox_dollarPerkWh_adjustVSL': 0.0006410701072116732,
#    'pm25_dollarPerkWh_adjustVSL': 0.003094733229941809}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0022947035892550522,
#    'nox_dollarPerkWh_adjustVSL': 0.0005312614660086372,
#    'pm25_dollarPerkWh_adjustVSL': 0.0025646376178661305}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0022478308154662103,
#    'nox_dollarPerkWh_adjustVSL': 0.000520409651144376,
#    'pm25_dollarPerkWh_adjustVSL': 0.0025122510353569622}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.002200958041677369,
#    'nox_dollarPerkWh_adjustVSL': 0.0005095578362801149,
#    'pm25_dollarPerkWh_adjustVSL': 0.002459864452847795}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0020221800890701854,
#    'nox_dollarPerkWh_adjustVSL': 0.0004681678120360912,
#    'pm25_dollarPerkWh_adjustVSL': 0.002260056222866197}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.001843402136463002,
#    'nox_dollarPerkWh_adjustVSL': 0.00042677778779206746,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020602479928845995}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.001479945081405999,
#    'nox_dollarPerkWh_adjustVSL': 0.000342631526460141,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016540362101328948}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0011164880263489958,
#    'nox_dollarPerkWh_adjustVSL': 0.00025848526512821444,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012478244273811895}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0010152762182661825,
#    'nox_dollarPerkWh_adjustVSL': 0.00023505307380239878,
#    'pm25_dollarPerkWh_adjustVSL': 0.001134706719457223}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0009140644101833691,
#    'nox_dollarPerkWh_adjustVSL': 0.0002116208824765831,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010215890115332566}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.000787022144419652,
#    'nox_dollarPerkWh_adjustVSL': 0.00018220851711892838,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008796023186278134}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.000659979878655935,
#    'nox_dollarPerkWh_adjustVSL': 0.00015279615176127373,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007376156257223706}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0005329376128922179,
#    'nox_dollarPerkWh_adjustVSL': 0.000123383786403619,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005956289328169274}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.000405895347128501,
#    'nox_dollarPerkWh_adjustVSL': 9.397142104596433e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00045364223991148443}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.000278853081364784,
#    'nox_dollarPerkWh_adjustVSL': 6.455905568830964e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003116555470060414}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0002643361178805304,
#    'nox_dollarPerkWh_adjustVSL': 6.119814086743636e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00029543090220954623}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.00024981915439627677,
#    'nox_dollarPerkWh_adjustVSL': 5.783722604656307e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00027920625741305105}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.00023530219091202315,
#    'nox_dollarPerkWh_adjustVSL': 5.447631122568978e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00026298161261655587}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0002207852274277695,
#    'nox_dollarPerkWh_adjustVSL': 5.1115396404816484e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00024675696782006063}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.00020626826394351587,
#    'nox_dollarPerkWh_adjustVSL': 4.77544815839432e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00023053232302356542}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.00019143796186880157,
#    'nox_dollarPerkWh_adjustVSL': 4.432102374718555e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00021395748051962452}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.00017660765979408727,
#    'nox_dollarPerkWh_adjustVSL': 4.088756591042791e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001973826380156836}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.00016177735771937294,
#    'nox_dollarPerkWh_adjustVSL': 3.7454108073670257e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00018080779551174264}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.00014694705564465861,
#    'nox_dollarPerkWh_adjustVSL': 3.4020650236912616e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00016423295300780174}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0001321167535699443,
#    'nox_dollarPerkWh_adjustVSL': 3.058719240015497e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001476581105038608}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.00014322412965441883,
#    'nox_dollarPerkWh_adjustVSL': 3.315873189213043e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0001600720861804656}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.00015433150573889332,
#    'nox_dollarPerkWh_adjustVSL': 3.573027138410589e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00017248606185707037}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0001654388818233678,
#    'nox_dollarPerkWh_adjustVSL': 3.8301810876081346e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00018490003753367516}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.00017654625790784233,
#    'nox_dollarPerkWh_adjustVSL': 4.08733503680568e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00019731401321027993}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.00018765363399231684,
#    'nox_dollarPerkWh_adjustVSL': 4.3444889860032265e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.00020972798888688475}},
#  ('MidCase',
#   'MROEc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.013246333152908747,
#    'nox_dollarPerkWh_adjustVSL': 0.006215755580135027,
#    'pm25_dollarPerkWh_adjustVSL': 0.01270588475547516}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.009825087614629385,
#    'nox_dollarPerkWh_adjustVSL': 0.004610358388316527,
#    'pm25_dollarPerkWh_adjustVSL': 0.009424225519838646}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.00907556659326667,
#    'nox_dollarPerkWh_adjustVSL': 0.00425865052945592,
#    'pm25_dollarPerkWh_adjustVSL': 0.008705284843252274}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.01124791314131969,
#    'nox_dollarPerkWh_adjustVSL': 0.005278010002162717,
#    'pm25_dollarPerkWh_adjustVSL': 0.01078899997935052}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.008989659992435806,
#    'nox_dollarPerkWh_adjustVSL': 0.004218339416386291,
#    'pm25_dollarPerkWh_adjustVSL': 0.008622883218795781}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.005795209870258907,
#    'nox_dollarPerkWh_adjustVSL': 0.002719364496823443,
#    'pm25_dollarPerkWh_adjustVSL': 0.0055587661804454005}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0026007597480820093,
#    'nox_dollarPerkWh_adjustVSL': 0.0012203895772605953,
#    'pm25_dollarPerkWh_adjustVSL': 0.002494649142095019}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.002414666633630832,
#    'nox_dollarPerkWh_adjustVSL': 0.001133066595026783,
#    'pm25_dollarPerkWh_adjustVSL': 0.00231614859868351}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.002228573519179655,
#    'nox_dollarPerkWh_adjustVSL': 0.0010457436127929707,
#    'pm25_dollarPerkWh_adjustVSL': 0.0021376480552720003}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0016278914454864067,
#    'nox_dollarPerkWh_adjustVSL': 0.0007638774609797791,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015614737197087803}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0010272093717931584,
#    'nox_dollarPerkWh_adjustVSL': 0.00048201130916658775,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009852993841455602}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0009104290757880473,
#    'nox_dollarPerkWh_adjustVSL': 0.00042721291566670853,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008732837066276359}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0007936487797829366,
#    'nox_dollarPerkWh_adjustVSL': 0.00037241452216682947,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007612680291097118}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0007648660500892601,
#    'nox_dollarPerkWh_adjustVSL': 0.0003589084136732724,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007336596304521905}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0007360833203955839,
#    'nox_dollarPerkWh_adjustVSL': 0.00034540230517971545,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007060512317946694}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0007073005907019076,
#    'nox_dollarPerkWh_adjustVSL': 0.00033189619668615844,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006784428331371483}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0006785178610082313,
#    'nox_dollarPerkWh_adjustVSL': 0.00031839008819260143,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006508344344796271}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.000649735131314555,
#    'nox_dollarPerkWh_adjustVSL': 0.0003048839796990444,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006232260358221059}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0006076637551291448,
#    'nox_dollarPerkWh_adjustVSL': 0.0002851422603666268,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005828711654481352}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0005655923789437348,
#    'nox_dollarPerkWh_adjustVSL': 0.0002654005410342092,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005425162950741645}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0005235210027583247,
#    'nox_dollarPerkWh_adjustVSL': 0.0002456588217017916,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005021614247001938}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.00048144962657291465,
#    'nox_dollarPerkWh_adjustVSL': 0.00022591710236937406,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004618065543262232}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.00043937825038750444,
#    'nox_dollarPerkWh_adjustVSL': 0.00020617538303695644,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004214516839522524}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0004660002477055198,
#    'nox_dollarPerkWh_adjustVSL': 0.00021866758193257735,
#    'pm25_dollarPerkWh_adjustVSL': 0.00044698750778958315}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0004926222450235351,
#    'nox_dollarPerkWh_adjustVSL': 0.00023115978082819828,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004725233316269139}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0005192442423415505,
#    'nox_dollarPerkWh_adjustVSL': 0.00024365197972381922,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004980591554642446}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0005458662396595657,
#    'nox_dollarPerkWh_adjustVSL': 0.0002561441786194401,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005235949793015753}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0005724882369775811,
#    'nox_dollarPerkWh_adjustVSL': 0.00026863637751506104,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005491308031389061}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.000631398445977189,
#    'nox_dollarPerkWh_adjustVSL': 0.00029627960950155436,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006056374844845742}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0006903086549767968,
#    'nox_dollarPerkWh_adjustVSL': 0.00032392284148804757,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006621441658302423}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0007492188639764047,
#    'nox_dollarPerkWh_adjustVSL': 0.00035156607347454084,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007186508471759103}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0008081290729760126,
#    'nox_dollarPerkWh_adjustVSL': 0.00037920930546103416,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007751575285215784}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0008670392819756204,
#    'nox_dollarPerkWh_adjustVSL': 0.0004068525374475274,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008316642098672465}},
#  ('MidCase',
#   'MROWc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.023005225539313577,
#    'nox_dollarPerkWh_adjustVSL': 0.007306287069895563,
#    'pm25_dollarPerkWh_adjustVSL': 0.00856107691560267}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.019258115923299526,
#    'nox_dollarPerkWh_adjustVSL': 0.0061162331627873925,
#    'pm25_dollarPerkWh_adjustVSL': 0.007166641830449063}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.016284528407799415,
#    'nox_dollarPerkWh_adjustVSL': 0.005171844072640285,
#    'pm25_dollarPerkWh_adjustVSL': 0.006060062310419203}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.018049986241535542,
#    'nox_dollarPerkWh_adjustVSL': 0.005732540237997549,
#    'pm25_dollarPerkWh_adjustVSL': 0.006717053057153662}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.017931766634203077,
#    'nox_dollarPerkWh_adjustVSL': 0.00569499457746989,
#    'pm25_dollarPerkWh_adjustVSL': 0.00667305926324036}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.01449113997502944,
#    'nox_dollarPerkWh_adjustVSL': 0.004602277358536317,
#    'pm25_dollarPerkWh_adjustVSL': 0.005392677577056837}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0110505133158558,
#    'nox_dollarPerkWh_adjustVSL': 0.0035095601396027444,
#    'pm25_dollarPerkWh_adjustVSL': 0.004112295890873313}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.009325825279803123,
#    'nox_dollarPerkWh_adjustVSL': 0.0029618121561769215,
#    'pm25_dollarPerkWh_adjustVSL': 0.00347047706119766}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.007601137243750445,
#    'nox_dollarPerkWh_adjustVSL': 0.0024140641727510986,
#    'pm25_dollarPerkWh_adjustVSL': 0.002828658231522007}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0060836175915741355,
#    'nox_dollarPerkWh_adjustVSL': 0.001932111314081624,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022639342543100175}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.004566097939397827,
#    'nox_dollarPerkWh_adjustVSL': 0.0014501584554121498,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016992102770980284}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0039693926855244935,
#    'nox_dollarPerkWh_adjustVSL': 0.0012606493426471736,
#    'pm25_dollarPerkWh_adjustVSL': 0.0014771546590983686}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0033726874316511593,
#    'nox_dollarPerkWh_adjustVSL': 0.0010711402298821974,
#    'pm25_dollarPerkWh_adjustVSL': 0.001255099041098709}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0032133870614459974,
#    'nox_dollarPerkWh_adjustVSL': 0.001020547627211531,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011958176087267548}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0030540866912408364,
#    'nox_dollarPerkWh_adjustVSL': 0.0009699550245408654,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011365361763548008}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.002894786321035674,
#    'nox_dollarPerkWh_adjustVSL': 0.0009193624218701993,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010772547439828466}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0027354859508305126,
#    'nox_dollarPerkWh_adjustVSL': 0.0008687698191995333,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010179733116108924}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0025761855806253507,
#    'nox_dollarPerkWh_adjustVSL': 0.0008181772165288673,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009586918792389384}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0024246936284037417,
#    'nox_dollarPerkWh_adjustVSL': 0.0007700645088391081,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009023162417626759}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.002273201676182133,
#    'nox_dollarPerkWh_adjustVSL': 0.000721951801149349,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008459406042864133}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.002121709723960524,
#    'nox_dollarPerkWh_adjustVSL': 0.0006738390934595896,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007895649668101508}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0019702177717389156,
#    'nox_dollarPerkWh_adjustVSL': 0.0006257263857698306,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007331893293338884}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0018187258195173064,
#    'nox_dollarPerkWh_adjustVSL': 0.0005776136780800713,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006768136918576258}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0017891769612700587,
#    'nox_dollarPerkWh_adjustVSL': 0.0005682291823456955,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006658174924163019}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0017596281030228108,
#    'nox_dollarPerkWh_adjustVSL': 0.0005588446866113195,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006548212929749781}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0017300792447755634,
#    'nox_dollarPerkWh_adjustVSL': 0.0005494601908769438,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006438250935336543}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0017005303865283157,
#    'nox_dollarPerkWh_adjustVSL': 0.0005400756951425679,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006328288940923305}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0016709815282810677,
#    'nox_dollarPerkWh_adjustVSL': 0.000530691199408192,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006218326946510068}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.001606878158332279,
#    'nox_dollarPerkWh_adjustVSL': 0.0005103324499495878,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005979775109779287}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0015427747883834907,
#    'nox_dollarPerkWh_adjustVSL': 0.0004899737004909838,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005741223273048506}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.001478671418434702,
#    'nox_dollarPerkWh_adjustVSL': 0.00046961495103237967,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005502671436317725}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0014145680484859134,
#    'nox_dollarPerkWh_adjustVSL': 0.0004492562015737755,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005264119599586944}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0013504646785371247,
#    'nox_dollarPerkWh_adjustVSL': 0.0004288974521151714,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005025567762856163}},
#  ('MidCase',
#   'NEWEc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.003167972308851938,
#    'nox_dollarPerkWh_adjustVSL': 0.0014729562382107386,
#    'pm25_dollarPerkWh_adjustVSL': 0.007170684602939741}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0014271691825102802,
#    'nox_dollarPerkWh_adjustVSL': 0.0006635656961037174,
#    'pm25_dollarPerkWh_adjustVSL': 0.0032303881111022865}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.000503752197149397,
#    'nox_dollarPerkWh_adjustVSL': 0.00023422077877078098,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011402398037706684}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0017683978492900878,
#    'nox_dollarPerkWh_adjustVSL': 0.0008222207739859471,
#    'pm25_dollarPerkWh_adjustVSL': 0.004002756966765154}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0010629143557103662,
#    'nox_dollarPerkWh_adjustVSL': 0.0004942045505109574,
#    'pm25_dollarPerkWh_adjustVSL': 0.0024058996928221447}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.0010028271165128996,
#    'nox_dollarPerkWh_adjustVSL': 0.00046626684614230917,
#    'pm25_dollarPerkWh_adjustVSL': 0.002269892619861783}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0009427398773154332,
#    'nox_dollarPerkWh_adjustVSL': 0.0004383291417736611,
#    'pm25_dollarPerkWh_adjustVSL': 0.0021338855469014216}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.0007083126004554254,
#    'nox_dollarPerkWh_adjustVSL': 0.00032933162342639995,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016032609388541563}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0004738853235954177,
#    'nox_dollarPerkWh_adjustVSL': 0.00022033410507913884,
#    'pm25_dollarPerkWh_adjustVSL': 0.001072636330806891}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.00023977441757264912,
#    'nox_dollarPerkWh_adjustVSL': 0.00011148368410296181,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005427278260806907}, 2028: {'so2_dollarPerkWh_adjustVSL': 5.6635115498804775e-06,
#    'nox_dollarPerkWh_adjustVSL': 2.6332631267847685e-06,
#    'pm25_dollarPerkWh_adjustVSL': 1.2819321354490217e-05}, 2029: {'so2_dollarPerkWh_adjustVSL': 2.831755774940221e-06,
#    'nox_dollarPerkWh_adjustVSL': 1.316631563392376e-06,
#    'pm25_dollarPerkWh_adjustVSL': 6.409660677245068e-06}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2031: {'so2_dollarPerkWh_adjustVSL': 1.1327023099760884e-06,
#    'nox_dollarPerkWh_adjustVSL': 5.266526253569504e-07,
#    'pm25_dollarPerkWh_adjustVSL': 2.563864270898027e-06}, 2032: {'so2_dollarPerkWh_adjustVSL': 2.2654046199521767e-06,
#    'nox_dollarPerkWh_adjustVSL': 1.0533052507139009e-06,
#    'pm25_dollarPerkWh_adjustVSL': 5.127728541796054e-06}, 2033: {'so2_dollarPerkWh_adjustVSL': 3.3981069299282653e-06,
#    'nox_dollarPerkWh_adjustVSL': 1.5799578760708513e-06,
#    'pm25_dollarPerkWh_adjustVSL': 7.691592812694082e-06}, 2034: {'so2_dollarPerkWh_adjustVSL': 4.530809239904353e-06,
#    'nox_dollarPerkWh_adjustVSL': 2.1066105014278018e-06,
#    'pm25_dollarPerkWh_adjustVSL': 1.0255457083592109e-05}, 2035: {'so2_dollarPerkWh_adjustVSL': 5.663511549880442e-06,
#    'nox_dollarPerkWh_adjustVSL': 2.633263126784752e-06,
#    'pm25_dollarPerkWh_adjustVSL': 1.2819321354490136e-05}, 2036: {'so2_dollarPerkWh_adjustVSL': 4.530809239904353e-06,
#    'nox_dollarPerkWh_adjustVSL': 2.1066105014278018e-06,
#    'pm25_dollarPerkWh_adjustVSL': 1.0255457083592109e-05}, 2037: {'so2_dollarPerkWh_adjustVSL': 3.3981069299282653e-06,
#    'nox_dollarPerkWh_adjustVSL': 1.5799578760708513e-06,
#    'pm25_dollarPerkWh_adjustVSL': 7.691592812694082e-06}, 2038: {'so2_dollarPerkWh_adjustVSL': 2.2654046199521767e-06,
#    'nox_dollarPerkWh_adjustVSL': 1.0533052507139009e-06,
#    'pm25_dollarPerkWh_adjustVSL': 5.127728541796054e-06}, 2039: {'so2_dollarPerkWh_adjustVSL': 1.1327023099760884e-06,
#    'nox_dollarPerkWh_adjustVSL': 5.266526253569504e-07,
#    'pm25_dollarPerkWh_adjustVSL': 2.563864270898027e-06}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}},
#  ('MidCase',
#   'NWPPc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.006036059052925846,
#    'nox_dollarPerkWh_adjustVSL': 0.0014906377272315239,
#    'pm25_dollarPerkWh_adjustVSL': 0.002749497620689984}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.0062401179629307454,
#    'nox_dollarPerkWh_adjustVSL': 0.0015410311887871398,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028424489126868875}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.005027345288260074,
#    'nox_dollarPerkWh_adjustVSL': 0.0012415303576043678,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022900163479609827}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.005159963980739061,
#    'nox_dollarPerkWh_adjustVSL': 0.0012742812675295234,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023504257601673203}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.005079348353191584,
#    'nox_dollarPerkWh_adjustVSL': 0.0012543727983159118,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023137043705671345}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.004460185438960622,
#    'nox_dollarPerkWh_adjustVSL': 0.0011014671373270736,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020316682034967823}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0038410225247296603,
#    'nox_dollarPerkWh_adjustVSL': 0.0009485614763382352,
#    'pm25_dollarPerkWh_adjustVSL': 0.00174963203642643}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.003329581623663578,
#    'nox_dollarPerkWh_adjustVSL': 0.0008222583544347403,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015166645441811201}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0028181407225974955,
#    'nox_dollarPerkWh_adjustVSL': 0.0006959552325312452,
#    'pm25_dollarPerkWh_adjustVSL': 0.00128369705193581}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0024858337916700674,
#    'nox_dollarPerkWh_adjustVSL': 0.0006138902222459606,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011323272412841283}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0021535268607426397,
#    'nox_dollarPerkWh_adjustVSL': 0.0005318252119606762,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009809574306324468}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.002039922321945461,
#    'nox_dollarPerkWh_adjustVSL': 0.0005037699510642928,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009292091945095715}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0019263177831482824,
#    'nox_dollarPerkWh_adjustVSL': 0.0004757146901679094,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008774609583866963}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0018564280261283202,
#    'nox_dollarPerkWh_adjustVSL': 0.0004584550332216274,
#    'pm25_dollarPerkWh_adjustVSL': 0.000845625332036447}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0017865382691083585,
#    'nox_dollarPerkWh_adjustVSL': 0.0004411953762753455,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008137897056861977}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0017166485120883963,
#    'nox_dollarPerkWh_adjustVSL': 0.0004239357193290635,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007819540793359484}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0016467587550684343,
#    'nox_dollarPerkWh_adjustVSL': 0.0004066760623827816,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007501184529856992}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0015768689980484721,
#    'nox_dollarPerkWh_adjustVSL': 0.0003894164054364996,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007182828266354499}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0015155471720928644,
#    'nox_dollarPerkWh_adjustVSL': 0.0003742726458293357,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006903499961109404}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0014542253461372564,
#    'nox_dollarPerkWh_adjustVSL': 0.0003591288862221718,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006624171655864308}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0013929035201816484,
#    'nox_dollarPerkWh_adjustVSL': 0.00034398512661500786,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006344843350619212}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0013315816942260407,
#    'nox_dollarPerkWh_adjustVSL': 0.00032884136700784395,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006065515045374117}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0012702598682704327,
#    'nox_dollarPerkWh_adjustVSL': 0.00031369760740068003,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005786186740129022}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0012130229068317141,
#    'nox_dollarPerkWh_adjustVSL': 0.00029956262738067954,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005525465484900417}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0011557859453929958,
#    'nox_dollarPerkWh_adjustVSL': 0.00028542764736067916,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005264744229671812}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0010985489839542772,
#    'nox_dollarPerkWh_adjustVSL': 0.00027129266734067867,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005004022974443207}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0010413120225155588,
#    'nox_dollarPerkWh_adjustVSL': 0.00025715768732067823,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004743301719214604}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0009840750610768403,
#    'nox_dollarPerkWh_adjustVSL': 0.0002430227073006778,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004482580463985999}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.000943902028434838,
#    'nox_dollarPerkWh_adjustVSL': 0.00023310175762997418,
#    'pm25_dollarPerkWh_adjustVSL': 0.000429958746027848}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.000903728995792836,
#    'nox_dollarPerkWh_adjustVSL': 0.00022318080795927068,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004116594456570962}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0008635559631508336,
#    'nox_dollarPerkWh_adjustVSL': 0.00021325985828856708,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003933601452863443}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.0008233829305088317,
#    'nox_dollarPerkWh_adjustVSL': 0.00020333890861786355,
#    'pm25_dollarPerkWh_adjustVSL': 0.00037506084491559255}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0007832098978668295,
#    'nox_dollarPerkWh_adjustVSL': 0.00019341795894716,
#    'pm25_dollarPerkWh_adjustVSL': 0.0003567615445448407}},
#  ('MidCase',
#   'NYSTc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.00665162210640999,
#    'nox_dollarPerkWh_adjustVSL': 0.0019335789965290178,
#    'pm25_dollarPerkWh_adjustVSL': 0.007329761610473915}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.004065352963812652,
#    'nox_dollarPerkWh_adjustVSL': 0.0011817690449867871,
#    'pm25_dollarPerkWh_adjustVSL': 0.004479819750804052}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0013844217624233764,
#    'nox_dollarPerkWh_adjustVSL': 0.0004024415096551983,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015255649410895798}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.007946691907448887,
#    'nox_dollarPerkWh_adjustVSL': 0.002310046529751429,
#    'pm25_dollarPerkWh_adjustVSL': 0.008756865068650123}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.015893383814897775,
#    'nox_dollarPerkWh_adjustVSL': 0.004620093059502858,
#    'pm25_dollarPerkWh_adjustVSL': 0.017513730137300246}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.012413665651517575,
#    'nox_dollarPerkWh_adjustVSL': 0.003608563864531214,
#    'pm25_dollarPerkWh_adjustVSL': 0.013679251238591608}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.008933947488137374,
#    'nox_dollarPerkWh_adjustVSL': 0.0025970346695595703,
#    'pm25_dollarPerkWh_adjustVSL': 0.009844772339882972}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.007125212479571257,
#    'nox_dollarPerkWh_adjustVSL': 0.002071248332497534,
#    'pm25_dollarPerkWh_adjustVSL': 0.007851634994252328}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.005316477471005142,
#    'nox_dollarPerkWh_adjustVSL': 0.001545461995435498,
#    'pm25_dollarPerkWh_adjustVSL': 0.005858497648621684}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.004448775340219109,
#    'nox_dollarPerkWh_adjustVSL': 0.0012932271888738734,
#    'pm25_dollarPerkWh_adjustVSL': 0.004902332420679334}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.003581073209433075,
#    'nox_dollarPerkWh_adjustVSL': 0.001040992382312249,
#    'pm25_dollarPerkWh_adjustVSL': 0.003946167192736984}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0028648585675464604,
#    'nox_dollarPerkWh_adjustVSL': 0.0008327939058497992,
#    'pm25_dollarPerkWh_adjustVSL': 0.003156933754189587}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.002148643925659845,
#    'nox_dollarPerkWh_adjustVSL': 0.0006245954293873495,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023677003156421903}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0014324292837732304,
#    'nox_dollarPerkWh_adjustVSL': 0.00041639695292489966,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015784668770947937}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0007162146418866153,
#    'nox_dollarPerkWh_adjustVSL': 0.00020819847646244989,
#    'pm25_dollarPerkWh_adjustVSL': 0.000789233438547397}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0,
#    'nox_dollarPerkWh_adjustVSL': 0.0,
#    'pm25_dollarPerkWh_adjustVSL': 0.0}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0,
# ...
#    'nox_dollarPerkWh_adjustVSL': 0.00072465422876406,
#    'pm25_dollarPerkWh_adjustVSL': 0.0035899934472580033}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.0013944658067000341,
#    'nox_dollarPerkWh_adjustVSL': 0.0006958441845535852,
#    'pm25_dollarPerkWh_adjustVSL': 0.003447266246028225}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0011866170357678083,
#    'nox_dollarPerkWh_adjustVSL': 0.0005921267912515126,
#    'pm25_dollarPerkWh_adjustVSL': 0.002933442207553796}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.0009787682648355828,
#    'nox_dollarPerkWh_adjustVSL': 0.0004884093979494399,
#    'pm25_dollarPerkWh_adjustVSL': 0.002419618169079367}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0009361811597048514,
#    'nox_dollarPerkWh_adjustVSL': 0.0004671582569750193,
#    'pm25_dollarPerkWh_adjustVSL': 0.002314338362770853}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.0008935940545741199,
#    'nox_dollarPerkWh_adjustVSL': 0.0004459071160005986,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022090585564623383}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0008647186769691175,
#    'nox_dollarPerkWh_adjustVSL': 0.00043149818357164307,
#    'pm25_dollarPerkWh_adjustVSL': 0.002137675583799419}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0008358432993641149,
#    'nox_dollarPerkWh_adjustVSL': 0.0004170892511426875,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020662926111364994}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0008069679217591125,
#    'nox_dollarPerkWh_adjustVSL': 0.00040268031871373193,
#    'pm25_dollarPerkWh_adjustVSL': 0.00199490963847358}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.00077809254415411,
#    'nox_dollarPerkWh_adjustVSL': 0.00038827138628477634,
#    'pm25_dollarPerkWh_adjustVSL': 0.0019235266658106606}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0007492171665491076,
#    'nox_dollarPerkWh_adjustVSL': 0.0003738624538558208,
#    'pm25_dollarPerkWh_adjustVSL': 0.0018521436931477413}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.000706222113238707,
#    'nox_dollarPerkWh_adjustVSL': 0.0003524077450584689,
#    'pm25_dollarPerkWh_adjustVSL': 0.0017458553960012693}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.0006632270599283063,
#    'nox_dollarPerkWh_adjustVSL': 0.000330953036261117,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016395670988547972}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0006202320066179057,
#    'nox_dollarPerkWh_adjustVSL': 0.0003094983274637651,
#    'pm25_dollarPerkWh_adjustVSL': 0.001533278801708325}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.000577236953307505,
#    'nox_dollarPerkWh_adjustVSL': 0.00028804361866641316,
#    'pm25_dollarPerkWh_adjustVSL': 0.001426990504561853}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0005342418999971045,
#    'nox_dollarPerkWh_adjustVSL': 0.0002665889098690613,
#    'pm25_dollarPerkWh_adjustVSL': 0.0013207022074153809}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0005172157472608775,
#    'nox_dollarPerkWh_adjustVSL': 0.000258092789483821,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012786117657958669}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0005001895945246505,
#    'nox_dollarPerkWh_adjustVSL': 0.0002495966690985808,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012365213241763526}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.00048316344178842344,
#    'nox_dollarPerkWh_adjustVSL': 0.00024110054871334045,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011944308825568384}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.00046613728905219644,
#    'nox_dollarPerkWh_adjustVSL': 0.0002326044283281002,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011523404409373244}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.00044911113631596945,
#    'nox_dollarPerkWh_adjustVSL': 0.00022410830794285995,
#    'pm25_dollarPerkWh_adjustVSL': 0.0011102499993178101}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.00042200379646685753,
#    'nox_dollarPerkWh_adjustVSL': 0.00021058163364070563,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010432378020789283}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0003948964566177456,
#    'nox_dollarPerkWh_adjustVSL': 0.00019705495933855136,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009762256048400463}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0003677891167686337,
#    'nox_dollarPerkWh_adjustVSL': 0.0001835282850363971,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009092134076011643}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.00034068177691952173,
#    'nox_dollarPerkWh_adjustVSL': 0.0001700016107342428,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008422012103622822}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.00031357443707040976,
#    'nox_dollarPerkWh_adjustVSL': 0.00015647493643208848,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007751890131234001}},
#  ('MidCase',
#   'SRTVc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.019124945198742256,
#    'nox_dollarPerkWh_adjustVSL': 0.0027802748893221937,
#    'pm25_dollarPerkWh_adjustVSL': 0.007428081065680646}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.016622535355147627,
#    'nox_dollarPerkWh_adjustVSL': 0.002416488892623161,
#    'pm25_dollarPerkWh_adjustVSL': 0.006456151317144657}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.013831967726987957,
#    'nox_dollarPerkWh_adjustVSL': 0.0020108121692180682,
#    'pm25_dollarPerkWh_adjustVSL': 0.005372301803024355}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.01633076234752472,
#    'nox_dollarPerkWh_adjustVSL': 0.00237407260551509,
#    'pm25_dollarPerkWh_adjustVSL': 0.006342827407931942}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.015079931376386616,
#    'nox_dollarPerkWh_adjustVSL': 0.002192233969968544,
#    'pm25_dollarPerkWh_adjustVSL': 0.005857007775168293}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.015831335082136497,
#    'nox_dollarPerkWh_adjustVSL': 0.0023014687328988667,
#    'pm25_dollarPerkWh_adjustVSL': 0.006148851102370612}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.016582738787886374,
#    'nox_dollarPerkWh_adjustVSL': 0.00241070349582919,
#    'pm25_dollarPerkWh_adjustVSL': 0.0064406944295729305}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.014951414969241128,
#    'nox_dollarPerkWh_adjustVSL': 0.002173550991484715,
#    'pm25_dollarPerkWh_adjustVSL': 0.005807092322829665}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.013320091150595884,
#    'nox_dollarPerkWh_adjustVSL': 0.00193639848714024,
#    'pm25_dollarPerkWh_adjustVSL': 0.005173490216086399}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.010947971776960077,
#    'nox_dollarPerkWh_adjustVSL': 0.0015915533720061035,
#    'pm25_dollarPerkWh_adjustVSL': 0.0042521649614656876}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.008575852403324273,
#    'nox_dollarPerkWh_adjustVSL': 0.0012467082568719675,
#    'pm25_dollarPerkWh_adjustVSL': 0.0033308397068449766}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.007973877958977579,
#    'nox_dollarPerkWh_adjustVSL': 0.0011591966632836699,
#    'pm25_dollarPerkWh_adjustVSL': 0.003097034332470917}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.007371903514630885,
#    'nox_dollarPerkWh_adjustVSL': 0.0010716850696953725,
#    'pm25_dollarPerkWh_adjustVSL': 0.0028632289580968573}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.006989713084080838,
#    'nox_dollarPerkWh_adjustVSL': 0.0010161244160069418,
#    'pm25_dollarPerkWh_adjustVSL': 0.002714787147092879}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.00660752265353079,
#    'nox_dollarPerkWh_adjustVSL': 0.000960563762318511,
#    'pm25_dollarPerkWh_adjustVSL': 0.0025663453360889005}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.006225332222980742,
#    'nox_dollarPerkWh_adjustVSL': 0.0009050031086300801,
#    'pm25_dollarPerkWh_adjustVSL': 0.002417903525084922}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0058431417924306945,
#    'nox_dollarPerkWh_adjustVSL': 0.0008494424549416494,
#    'pm25_dollarPerkWh_adjustVSL': 0.0022694617140809436}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0054609513618806465,
#    'nox_dollarPerkWh_adjustVSL': 0.0007938818012532186,
#    'pm25_dollarPerkWh_adjustVSL': 0.002121019903076965}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0051950573104913664,
#    'nox_dollarPerkWh_adjustVSL': 0.0007552276484378486,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020177473159883642}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.004929163259102085,
#    'nox_dollarPerkWh_adjustVSL': 0.0007165734956224784,
#    'pm25_dollarPerkWh_adjustVSL': 0.001914474728899763}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.004663269207712805,
#    'nox_dollarPerkWh_adjustVSL': 0.0006779193428071084,
#    'pm25_dollarPerkWh_adjustVSL': 0.001811202141811162}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.004397375156323525,
#    'nox_dollarPerkWh_adjustVSL': 0.0006392651899917382,
#    'pm25_dollarPerkWh_adjustVSL': 0.001707929554722561}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.004131481104934244,
#    'nox_dollarPerkWh_adjustVSL': 0.0006006110371763681,
#    'pm25_dollarPerkWh_adjustVSL': 0.00160465696763396}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.004163781262490373,
#    'nox_dollarPerkWh_adjustVSL': 0.0006053066489044667,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016172022683534082}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.004196081420046503,
#    'nox_dollarPerkWh_adjustVSL': 0.0006100022606325654,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016297475690728563}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.004228381577602632,
#    'nox_dollarPerkWh_adjustVSL': 0.000614697872360664,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016422928697923044}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0042606817351587625,
#    'nox_dollarPerkWh_adjustVSL': 0.0006193934840887628,
#    'pm25_dollarPerkWh_adjustVSL': 0.001654838170511753}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.004292981892714892,
#    'nox_dollarPerkWh_adjustVSL': 0.0006240890958168614,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016673834712312011}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.004164730941810356,
#    'nox_dollarPerkWh_adjustVSL': 0.0006054447078394765,
#    'pm25_dollarPerkWh_adjustVSL': 0.001617571121435178}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.004036479990905821,
#    'nox_dollarPerkWh_adjustVSL': 0.0005868003198620917,
#    'pm25_dollarPerkWh_adjustVSL': 0.001567758771639155}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0039082290400012844,
#    'nox_dollarPerkWh_adjustVSL': 0.0005681559318847068,
#    'pm25_dollarPerkWh_adjustVSL': 0.0015179464218431319}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.003779978089096749,
#    'nox_dollarPerkWh_adjustVSL': 0.0005495115439073219,
#    'pm25_dollarPerkWh_adjustVSL': 0.0014681340720471088}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.0036517271381922133,
#    'nox_dollarPerkWh_adjustVSL': 0.0005308671559299371,
#    'pm25_dollarPerkWh_adjustVSL': 0.001418321722251086}},
#  ('MidCase',
#   'SRVCc'): {2018: {'so2_dollarPerkWh_adjustVSL': 0.008226296131836222,
#    'nox_dollarPerkWh_adjustVSL': 0.0024308903916151164,
#    'pm25_dollarPerkWh_adjustVSL': 0.007534057412737781}, 2019: {'so2_dollarPerkWh_adjustVSL': 0.006866804179516115,
#    'nox_dollarPerkWh_adjustVSL': 0.0020291572335315706,
#    'pm25_dollarPerkWh_adjustVSL': 0.0062889660305669335}, 2020: {'so2_dollarPerkWh_adjustVSL': 0.0053806308723014585,
#    'nox_dollarPerkWh_adjustVSL': 0.0015899894288616747,
#    'pm25_dollarPerkWh_adjustVSL': 0.004927853466371618}, 2021: {'so2_dollarPerkWh_adjustVSL': 0.005676781522458289,
#    'nox_dollarPerkWh_adjustVSL': 0.0016775026618403317,
#    'pm25_dollarPerkWh_adjustVSL': 0.00519908318693398}, 2022: {'so2_dollarPerkWh_adjustVSL': 0.004677150637123422,
#    'nox_dollarPerkWh_adjustVSL': 0.0013821093189094796,
#    'pm25_dollarPerkWh_adjustVSL': 0.004283570742334238}, 2023: {'so2_dollarPerkWh_adjustVSL': 0.005075105995263589,
#    'nox_dollarPerkWh_adjustVSL': 0.0014997060891802272,
#    'pm25_dollarPerkWh_adjustVSL': 0.004648038355447674}, 2024: {'so2_dollarPerkWh_adjustVSL': 0.0054730613534037555,
#    'nox_dollarPerkWh_adjustVSL': 0.0016173028594509747,
#    'pm25_dollarPerkWh_adjustVSL': 0.00501250596856111}, 2025: {'so2_dollarPerkWh_adjustVSL': 0.00518894354237623,
#    'nox_dollarPerkWh_adjustVSL': 0.0015333453595208857,
#    'pm25_dollarPerkWh_adjustVSL': 0.004752296529713088}, 2026: {'so2_dollarPerkWh_adjustVSL': 0.004904825731348704,
#    'nox_dollarPerkWh_adjustVSL': 0.0014493878595907964,
#    'pm25_dollarPerkWh_adjustVSL': 0.004492087090865064}, 2027: {'so2_dollarPerkWh_adjustVSL': 0.0038833726603514913,
#    'nox_dollarPerkWh_adjustVSL': 0.0011475460080479895,
#    'pm25_dollarPerkWh_adjustVSL': 0.003556588786649199}, 2028: {'so2_dollarPerkWh_adjustVSL': 0.002861919589354279,
#    'nox_dollarPerkWh_adjustVSL': 0.0008457041565051824,
#    'pm25_dollarPerkWh_adjustVSL': 0.002621090482433334}, 2029: {'so2_dollarPerkWh_adjustVSL': 0.0025671501561145885,
#    'nox_dollarPerkWh_adjustVSL': 0.0007585990764642268,
#    'pm25_dollarPerkWh_adjustVSL': 0.0023511257500730015}, 2030: {'so2_dollarPerkWh_adjustVSL': 0.002272380722874898,
#    'nox_dollarPerkWh_adjustVSL': 0.0006714939964232713,
#    'pm25_dollarPerkWh_adjustVSL': 0.0020811610177126688}, 2031: {'so2_dollarPerkWh_adjustVSL': 0.0020485724905277055,
#    'nox_dollarPerkWh_adjustVSL': 0.0006053581227739339,
#    'pm25_dollarPerkWh_adjustVSL': 0.0018761861365603264}, 2032: {'so2_dollarPerkWh_adjustVSL': 0.0018247642581805132,
#    'nox_dollarPerkWh_adjustVSL': 0.0005392222491245964,
#    'pm25_dollarPerkWh_adjustVSL': 0.0016712112554079837}, 2033: {'so2_dollarPerkWh_adjustVSL': 0.0016009560258333205,
#    'nox_dollarPerkWh_adjustVSL': 0.00047308637547525896,
#    'pm25_dollarPerkWh_adjustVSL': 0.0014662363742556411}, 2034: {'so2_dollarPerkWh_adjustVSL': 0.0013771477934861282,
#    'nox_dollarPerkWh_adjustVSL': 0.00040695050182592153,
#    'pm25_dollarPerkWh_adjustVSL': 0.0012612614931032985}, 2035: {'so2_dollarPerkWh_adjustVSL': 0.0011533395611389356,
#    'nox_dollarPerkWh_adjustVSL': 0.0003408146281765841,
#    'pm25_dollarPerkWh_adjustVSL': 0.0010562866119509559}, 2036: {'so2_dollarPerkWh_adjustVSL': 0.0010836559957716238,
#    'nox_dollarPerkWh_adjustVSL': 0.00032022296617096756,
#    'pm25_dollarPerkWh_adjustVSL': 0.000992466883875545}, 2037: {'so2_dollarPerkWh_adjustVSL': 0.001013972430404312,
#    'nox_dollarPerkWh_adjustVSL': 0.000299631304165351,
#    'pm25_dollarPerkWh_adjustVSL': 0.0009286471558001339}, 2038: {'so2_dollarPerkWh_adjustVSL': 0.0009442888650370002,
#    'nox_dollarPerkWh_adjustVSL': 0.0002790396421597345,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008648274277247228}, 2039: {'so2_dollarPerkWh_adjustVSL': 0.0008746052996696883,
#    'nox_dollarPerkWh_adjustVSL': 0.00025844798015411794,
#    'pm25_dollarPerkWh_adjustVSL': 0.0008010076996493119}, 2040: {'so2_dollarPerkWh_adjustVSL': 0.0008049217343023765,
#    'nox_dollarPerkWh_adjustVSL': 0.0002378563181485014,
#    'pm25_dollarPerkWh_adjustVSL': 0.0007371879715739008}, 2041: {'so2_dollarPerkWh_adjustVSL': 0.0007568576426225846,
#    'nox_dollarPerkWh_adjustVSL': 0.000223653262876282,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006931684492514268}, 2042: {'so2_dollarPerkWh_adjustVSL': 0.0007087935509427925,
#    'nox_dollarPerkWh_adjustVSL': 0.0002094502076040626,
#    'pm25_dollarPerkWh_adjustVSL': 0.0006491489269289529}, 2043: {'so2_dollarPerkWh_adjustVSL': 0.0006607294592630004,
#    'nox_dollarPerkWh_adjustVSL': 0.00019524715233184322,
#    'pm25_dollarPerkWh_adjustVSL': 0.000605129404606479}, 2044: {'so2_dollarPerkWh_adjustVSL': 0.0006126653675832084,
#    'nox_dollarPerkWh_adjustVSL': 0.0001810440970596238,
#    'pm25_dollarPerkWh_adjustVSL': 0.000561109882284005}, 2045: {'so2_dollarPerkWh_adjustVSL': 0.0005646012759034164,
#    'nox_dollarPerkWh_adjustVSL': 0.0001668410417874044,
#    'pm25_dollarPerkWh_adjustVSL': 0.0005170903599615312}, 2046: {'so2_dollarPerkWh_adjustVSL': 0.0005022076711703472,
#    'nox_dollarPerkWh_adjustVSL': 0.00014840358077054772,
#    'pm25_dollarPerkWh_adjustVSL': 0.00045994714596667065}, 2047: {'so2_dollarPerkWh_adjustVSL': 0.0004398140664372782,
#    'nox_dollarPerkWh_adjustVSL': 0.0001299661197536911,
#    'pm25_dollarPerkWh_adjustVSL': 0.0004028039319718102}, 2048: {'so2_dollarPerkWh_adjustVSL': 0.0003774204617042091,
#    'nox_dollarPerkWh_adjustVSL': 0.0001115286587368344,
#    'pm25_dollarPerkWh_adjustVSL': 0.00034566071797694967}, 2049: {'so2_dollarPerkWh_adjustVSL': 0.00031502685697114004,
#    'nox_dollarPerkWh_adjustVSL': 9.309119771997775e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0002885175039820892}, 2050: {'so2_dollarPerkWh_adjustVSL': 0.000252633252238071,
#    'nox_dollarPerkWh_adjustVSL': 7.46537367031211e-05,
#    'pm25_dollarPerkWh_adjustVSL': 0.0002313742899872288}}}

# %% [markdown]
# ### Calculate End-use specific marginal damages
# **I used the total emissions column for each of the end uses for the following reasons:**
# - Most homes only have 1 of each end-use, so it is unlikely that the homes have a significant consumption values from different fuel types. Thus, the total consumption and total emissions column (sum of each dwelling units consumption by end-use for each fuel) is fine to use to calculate marginal damages (social cost)
# - We can visualize the emissions in 2 by 2 grid (CO2, PM25, SO2, NOx) with each appliance's heating fuel in a different shape or color.

# %% [markdown]
# ### Baseline Marginal Damages: WHOLE-HOME

# %%
print("""
-------------------------------------------------------------------------------------------------------
Step 5: Calculate End-use specific marginal damages
-------------------------------------------------------------------------------------------------------
      
-------------------------------------------------------------------------------------------------------
Baseline Marginal Damages: WHOLE-HOME
-------------------------------------------------------------------------------------------------------
""")

# calculate_marginal_damages(df, menu_mp, policy_scenario)
df_euss_am_baseline_home = calculate_marginal_damages(df=df_euss_am_baseline_home,
                                                      menu_mp=menu_mp,
                                                      policy_scenario='No Inflation Reduction Act',
                                                      drop_pollutant_damage_cols=True
                                                     )
df_euss_am_baseline_home

# %% [markdown]
# ## Private Perspective: Annual Energy Costs

# %% [markdown]
# ### Step 1: Obtain Level Energy Fuel Cost Data from the EIA
# **Data Sources for Excel workbook containing state average Residential fuel cost for each fuel in 2018**
# - EIA State Electricity Price: https://www.eia.gov/electricity/state/archive/2018/
# - EIA Natural Gas Prices: https://www.eia.gov/dnav/ng/ng_pri_sum_dcu_SPA_a.htm
# - Propane and Fuel Oil: EIA March 2023 Short Term Energy Outlook
#     - https://www.eia.gov/outlooks/steo/pdf/wf01.pdf
#     - Table WF01: Average Consumer Prices and Expenditures for Heating Fuels During the Winter
#     - US Average: 2018-2019 Data

# %%
print("""
-------------------------------------------------------------------------------------------------------
Private Perspective: Annual Energy Costs
-------------------------------------------------------------------------------------------------------
- Step 1: Obtain Level Energy Fuel Cost Data from the EIA
- Step 2: Calculate Annual Operating (Fuel) Costs
-------------------------------------------------------------------------------------------------------
      
-------------------------------------------------------------------------------------------------------
Step 1: Obtain Level Energy Fuel Cost Data from the EIA
-------------------------------------------------------------------------------------------------------
**Data Sources for Excel workbook containing state average Residential fuel cost for each fuel in 2018**
- EIA State Electricity Price: https://www.eia.gov/electricity/state/archive/2018/
- EIA Natural Gas Prices: https://www.eia.gov/dnav/ng/ng_pri_sum_dcu_SPA_a.htm
- Propane and Fuel Oil: EIA March 2023 Short Term Energy Outlook
    - https://www.eia.gov/outlooks/steo/pdf/wf01.pdf
    - Table WF01: Average Consumer Prices and Expenditures for Heating Fuels During the Winter
    - US Average: 2018-2019 Data
-------------------------------------------------------------------------------------------------------
""")

filename = 'fuel_prices_nominal.csv'
relative_path = os.path.join(r"fuel_prices", filename)
file_path = os.path.join(project_root, relative_path)
df_fuelPrices_perkWh = pd.read_csv(file_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")

# New units for the converted and inflated prices below
# $USD-2023, PREVIOUSLY USED $USD-2021
df_fuelPrices_perkWh['units'] = 'USD2022 per kWh'

years = ['2018', '2019', '2020', '2021', '2022']

# Take dataframe with nominal prices in their base units and convert to $/kWh equivalent
# https://www.eia.gov/energyexplained/units-and-calculators/british-thermal-units.php
for year in years:
    for index, row in df_fuelPrices_perkWh.iterrows():
        
        # Propane: (dollars per gallon) * (1 gallon propane/91,452 BTU) * (3412 BTU/1 kWh)
        if row['fuel_type'] == 'propane':
            df_fuelPrices_perkWh.at[index, f'{year}_fuelPrice_perkWh'] = row[f'{year}_nominal_unit_price'] * (1/91452) * (3412/1)
        
        # Fuel Oil: (dollars/gallon) * (1 gallon heating oil/138,500 BTU) * (3412 BTU/1 kWh)
        elif row['fuel_type'] == 'fuelOil':
            df_fuelPrices_perkWh.at[index, f'{year}_fuelPrice_perkWh'] = row[f'{year}_nominal_unit_price'] * (1/138500) * (3412/1)
        
        # Natural Gas: (dollars/cf) * (thousand cf/1000 cf) * (1 cf natural gas/1039 BTU) * (3412 BTU/1 kWh)
        elif row['fuel_type'] == 'naturalGas':
            df_fuelPrices_perkWh.at[index, f'{year}_fuelPrice_perkWh'] = row[f'{year}_nominal_unit_price'] * (1/1000) * (1/1039) * (3412/1)
        
        # Electricity: convert cents per kWh to $ per kWh
        elif row['fuel_type'] == 'electricity':
            df_fuelPrices_perkWh.at[index, f'{year}_fuelPrice_perkWh'] = row[f'{year}_nominal_unit_price'] / 100

# Convert nominal dollars to real 2022 US dollars (USD2022)
# $USD-2023, PREVIOUSLY USED $USD-2021
df_fuelPrices_perkWh['2018_fuelPrice_perkWh'] = df_fuelPrices_perkWh['2018_fuelPrice_perkWh'] * cpi_ratio_2023_2018
df_fuelPrices_perkWh['2019_fuelPrice_perkWh'] = df_fuelPrices_perkWh['2019_fuelPrice_perkWh'] * cpi_ratio_2023_2019
df_fuelPrices_perkWh['2020_fuelPrice_perkWh'] = df_fuelPrices_perkWh['2020_fuelPrice_perkWh'] * cpi_ratio_2023_2020
df_fuelPrices_perkWh['2021_fuelPrice_perkWh'] = df_fuelPrices_perkWh['2021_fuelPrice_perkWh'] * cpi_ratio_2023_2021
df_fuelPrices_perkWh['2022_fuelPrice_perkWh'] = df_fuelPrices_perkWh['2022_fuelPrice_perkWh'] * cpi_ratio_2023_2022

# Original dictionary mapping census divisions to states
map_states_census_divisions = {
    "New England": ["CT", "ME", "MA", "NH", "RI", "VT"],
    "Middle Atlantic": ["NJ", "NY", "PA"],
    "East North Central": ["IN", "IL", "MI", "OH", "WI"],
    "West North Central": ["IA", "KS", "MN", "MO", "NE", "ND", "SD"],
    "South Atlantic": ["DE", "DC", "FL", "GA", "MD", "NC", "SC", "VA", "WV"],
    "East South Central": ["AL", "KY", "MS", "TN"],
    "West South Central": ["AR", "LA", "OK", "TX"],
    "Mountain": ["AZ", "CO", "ID", "NM", "MT", "UT", "NV", "WY"],
    "Pacific": ["AK", "CA", "HI", "OR", "WA"]
}

# Reverse the mapping to create a state-to-census-division map
state_to_census_division = {}
for division, states in map_states_census_divisions.items():
    for state in states:
        state_to_census_division[state] = division

# Function to map location to census division
def map_location_to_census_division(location):
    if location in state_to_census_division:
        return state_to_census_division[location]
    return location

# Apply the function to map locations using .loc
df_fuelPrices_perkWh.loc[:, 'census_division'] = df_fuelPrices_perkWh['location_map'].apply(map_location_to_census_division)
# print(df_fuelPrices_perkWh)

# %%
# Project Fuel Prices from 2022 to 2050
filename = 'aeo_projections_2022_2050.xlsx'
relative_path = os.path.join(r"projections", filename)
file_path = os.path.join(project_root, relative_path)
df_fuelPrices_projection_factors = pd.read_excel(io=file_path, sheet_name='fuel_price_factors_2022_2050')

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
# print(df_fuelPrices_projection_factors)

# Convert the factors dataframe into a lookup dictionary including policy_scenario
factor_dict = df_fuelPrices_projection_factors.set_index(['region', 'fuel_type', 'policy_scenario']).to_dict('index')
# print(factor_dict)

# %%
# Pre-IRA policy_scenario: No Inflation Reduction Act
# Pass the desired policy_scenario as a parameter when applying the function
preIRA_projected_prices_df = df_fuelPrices_perkWh.apply(lambda row: project_future_prices(row, factor_dict, 'No Inflation Reduction Act'), axis=1)

# Concatenate the projected prices with the original DataFrame
df_fuelPrices_perkWh_preIRA = pd.concat([df_fuelPrices_perkWh, preIRA_projected_prices_df], axis=1)

# Create Fuel Price Lookup with the policy_scenario included
preIRA_fuel_price_lookup = create_fuel_price_lookup(df_fuelPrices_perkWh_preIRA, 'No Inflation Reduction Act')
# print(preIRA_fuel_price_lookup)

# %%
# IRA-Reference policy_scenario: AEO2023 Reference Case
# Pass the desired policy_scenario as a parameter when applying the function
iraRef_projected_prices_df = df_fuelPrices_perkWh.apply(lambda row: project_future_prices(row, factor_dict, 'AEO2023 Reference Case'), axis=1)

# Concatenate the projected prices with the original DataFrame
df_fuelPrices_perkWh_iraRef = pd.concat([df_fuelPrices_perkWh, iraRef_projected_prices_df], axis=1)

# Create Fuel Price Lookup with the policy_scenario included
iraRef_fuel_price_lookup = create_fuel_price_lookup(df_fuelPrices_perkWh_iraRef, 'AEO2023 Reference Case')
# print(iraRef_fuel_price_lookup)

# %% [markdown]
# ### Step 2: Calculate Annual Operating (Fuel) Costs

# %% [markdown]
# ### Baseline Fuel Cost: WHOLE-HOME

# %%
print("""
-------------------------------------------------------------------------------------------------------
Step 2: Calculate Annual Operating (Fuel) Costs
-------------------------------------------------------------------------------------------------------
- Create a mapping dictionary for fuel types
- Create new merge columns to ensure a proper match.
- Merge df_copy with df_fuel_prices to get fuel prices for electricity, natural gas, propane, and fuel oil
- Calculate the per kWh fuel costs for each fuel type and region
- Calculate the baseline fuel cost 
-------------------------------------------------------------------------------------------------------
""")
# calculate_annual_fuelCost(df, menu_mp, policy_scenario, drop_fuel_cost_columns)
df_euss_am_baseline_home = calculate_annual_fuelCost(df=df_euss_am_baseline_home,
                                                     menu_mp=menu_mp,
                                                     policy_scenario='No Inflation Reduction Act',
                                                     drop_fuel_cost_columns=False
                                                     )
df_euss_am_baseline_home

# %% [markdown]
# ## Area Median Income Data Used to determine LMI Designation and IRA Rebates Eligibility/Amount

# %% [markdown]
# ### PUMA Median Income

# %%
# Collect Area Median Income Data at PUMA-resolution
filename = "nhgis0003_ds261_2022_puma.csv"
relative_path = os.path.join(r"equity_data", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_puma_medianIncome = pd.read_csv(file_path, encoding='ISO-8859-1')
# df_puma_medianIncome = df_puma_medianIncome.drop(0)
df_puma_medianIncome = df_puma_medianIncome.reset_index(drop=True)

cols_interest = ['GISJOIN', 'STUSAB', 'PUMAA', 'NAME_E', 'AP2PE001', 'AP2PM001']
df_puma_medianIncome = df_puma_medianIncome[cols_interest]
df_puma_medianIncome = df_puma_medianIncome.rename(columns={"GISJOIN": "gis_joinID_puma", "STUSAB": "state_abbrev", "PUMAA": "puma_code", "NAME_E": "name_estimate", "AP2PE001": "median_income_USD2022", "AP2PM001": "median_income_USD2022_marginOfError"})
df_puma_medianIncome['median_income_USD2023'] = round((df_puma_medianIncome['median_income_USD2022'] * cpi_ratio_2023_2022), 2)
df_puma_medianIncome

# %% [markdown]
# ### County Median Income

# %%
# Collect Area Median Income Data at PUMA-resolution
filename = "nhgis0005_ds261_2022_county.csv"
relative_path = os.path.join(r"equity_data", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_county_medianIncome = pd.read_csv(file_path, encoding='ISO-8859-1')
# df_county_medianIncome = df_county_medianIncome.drop(0)
df_county_medianIncome = df_county_medianIncome.reset_index(drop=True)

cols_interest = ['GISJOIN', 'STUSAB', 'COUNTYA', 'NAME_E', 'AP2PE001', 'AP2PM001']
df_county_medianIncome = df_county_medianIncome[cols_interest]
df_county_medianIncome = df_county_medianIncome.rename(columns={"GISJOIN": "gis_joinID_county", "STUSAB": "state_abbrev", "COUNTYA": "county_code", "NAME_E": "name_estimate", "AP2PE001": "median_income_USD2022", "AP2PM001": "median_income_USD2022_marginOfError"})
df_county_medianIncome['median_income_USD2023'] = round((df_county_medianIncome['median_income_USD2022'] * cpi_ratio_2023_2022), 2)
df_county_medianIncome

# %% [markdown]
# ### State Median Income

# %%
# Collect Area Median Income Data at PUMA-resolution
filename = "nhgis0004_ds261_2022_state.csv"
relative_path = os.path.join(r"equity_data", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_state_medianIncome = pd.read_csv(file_path, encoding='ISO-8859-1')
# df_state_medianIncome = df_state_medianIncome.drop(0)
df_state_medianIncome = df_state_medianIncome.reset_index(drop=True)

cols_interest = ['GISJOIN', 'STUSAB','STATEA', 'NAME_E', 'AP2PE001', 'AP2PM001']
df_state_medianIncome = df_state_medianIncome[cols_interest]
df_state_medianIncome = df_state_medianIncome.rename(columns={"GISJOIN": "gis_joinID_state", "STUSAB": "state_abbrev", "STATEA": "state_code", "NAME_E": "name_estimate", "AP2PE001": "median_income_USD2022", "AP2PM001": "median_income_USD2022_marginOfError"})
df_state_medianIncome['median_income_USD2023'] = round((df_state_medianIncome['median_income_USD2022'] * cpi_ratio_2023_2022), 2)
df_state_medianIncome

# %% [markdown]
# ### Adjustment Factors for Construction:
# #### RSMeans City Cost Index
# #### Consumer Price Index for All Urban Consumers (CPI, CPI-U)

# %%
# Adjust for regional cost differences with RSMeans
filename = "rsMeans_cityCostIndex.csv"
relative_path = os.path.join(r"inflation_data", filename)
file_path = os.path.join(project_root, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_rsMeans_cityCostIndex = pd.read_csv(file_path)

df_rsMeans_cityCostIndex = pd.DataFrame({
    'State': df_rsMeans_cityCostIndex['State'],
    'City': df_rsMeans_cityCostIndex['City'],
    'Material': (df_rsMeans_cityCostIndex['Material']).round(2),
    'Installation': (df_rsMeans_cityCostIndex['Installation']).round(2),
    'Average': (df_rsMeans_cityCostIndex['Average']).round(2),
})
df_rsMeans_cityCostIndex

# %% [markdown]
# # Model Runtime

# %%
# Get the current datetime again
end_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Calculate the elapsed time
elapsed_time = datetime.strptime(end_time, "%Y-%m-%d_%H-%M-%S") - datetime.strptime(start_time, "%Y-%m-%d_%H-%M-%S")

# Format the elapsed time
elapsed_seconds = elapsed_time.total_seconds()
elapsed_minutes = int(elapsed_seconds // 60)
elapsed_seconds = int(elapsed_seconds % 60)

# Print the elapsed time
print(f"The code took {elapsed_minutes} minutes and {elapsed_seconds} seconds to execute.")
