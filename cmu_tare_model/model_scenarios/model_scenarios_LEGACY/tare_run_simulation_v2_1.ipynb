# %%
"""
This file runs all of the code responsible for generating the output CSVs but does not visualize the data.
Data visualization is done in the main program.
"""
# Out:
# '\nThis file runs all of the code responsible for generating the output CSVs but does not visualize the data.\nData visualization is done in the main program.\n'

# %%
import os
import pandas as pd
# from IPython import get_ipython

# Format the name of the exported results file using the location ID
from datetime import datetime
result_export_time = datetime.now()
model_run_date_time = result_export_time.strftime("%Y-%m-%d_%H-%M")

from config import PROJECT_ROOT
from cmu_tare_model.utils.export_model_run_results import export_model_run_output
# from cmu_tare_model.model_scenarios.model_scenarios_LEGACY.export_model_run_results_BACKUP_24Jan2026 import export_model_run_output


print(f"""
The results will be exported using the export_model_run_output function.
Documentation for this function:
{export_model_run_output.__doc__}

""")
# Out:
# The results will be exported using the export_model_run_output function.
# Documentation for this function:
# Export data for various result categories to appropriate directories.
#
#     This function exports DataFrame results to CSV files in the appropriate
#     directory based on the results category and measure package. It supports
#     the expanded sensitivity analysis categories and directory structure.
#
#     Args:
#         df_results_export: DataFrame containing the data to be exported.
#         results_category: Type of results being exported:
#             - For summaries: 'summary_baseline', 'summary_basic_ap2', etc.
#             - For damages: 'damages_climate_IRA', 'damages_climate_noIRA', etc.
#             - For fuel costs: 'fuel_costs_IRA', 'fuel_costs_noIRA'
#             - For consumption: 'consumption'
#         menu_mp: Measure package identifier (0 for baseline, 8/9/10 for retrofits).
#         output_folder_path: Base directory for exporting results. If None, uses
#             a global/predefined variable.
#         location_id: Location identifier for the filename. If None, uses
#             a global/predefined variable.
#         results_export_formatted_date: Formatted date string for the filename. If None,
#             uses a global/predefined variable.
#
#     Raises:
#         ValueError: If the results_category is not recognized or if required
#             parameters are missing.
#         OSError: If there is an error creating directories or writing the file.

# %% [markdown]
# # Baseline Scenario

# %%
# ===================================================================================================================================================================================
# Measure Package 0: Baseline
# ===================================================================================================================================================================================
# BASELINE Pre-IRA Scenario:
menu_mp = 0
input_mp = 'baseline'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "model_scenarios_LEGACY", "tare_baseline_v2_1.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")

print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Baseline Scenario - Model Run Complete")
# Out:
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/model_scenarios_LEGACY/tare_baseline_v2_1.ipynb
#
# =========================================================================================================
# Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
# Let's start by reading the data from the NREL EUSS Database.
#
# Make sure that the zipped folders stay organized as they are once unzipped.
# If changes are made to the file path, then the program will not run properly.
# ==========================================================================================================
#
# Project root directory: c:\users\jorda\desktop\projects\cmu-tare-model
# Result outputs will be exported here: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results
#
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# Load data from the NREL EUSS Database for the baseline scenario and apply various filters.
#
# DATA: NREL EUSS Database
# HOUSING FILTERS: Occupied units and Single Family Homes
# GEOGRAPHIC FILTERS: National, State, or City
#
# Additional details data can be found in the official End-Use Load Profiles/Savings Shapes documentation.
# Our methodology is detailed in the process_euss_data.py file and its associated imports.
#
# RESULTS OUTPUT:
#
# Retrieved data for filename: baseline_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\baseline_metadata_and_annual_results.csv
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 259)
# You chose to filter for: PA
# Location ID is: PA
#
# To accurately characterize load profile, it is recommended to select subsets of data with >= 1000 models (~240,000 representative dwelling units).
#
# The following cities (number of models also shown) are available for this state:
#
# in.city
# Not in a census Place      7035
# In another census Place    5851
# PA, Philadelphia           1631
# PA, Pittsburgh              329
# PA, Erie                    105
# PA, Allentown               104
# PA, Reading                  92
# PA, Bethlehem                85
# PA, Scranton                 80
# PA, Harrisburg               63
# PA, Lancaster                58
# PA, Levittown                58
# PA, Altoona                  56
# PA, York                     56
# PA, Wilkes-Barre             48
# Name: count, dtype: int64
# You chose to analyze all of state: PA
# Location ID is: PA
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline
#
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            0  242.131013           True   2152.0
# 122            0  242.131013           True   2176.0
# 150            0  242.131013           True   1690.0
# 153            0  242.131013           True   2176.0
# 162            0  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         0  242.131013           True   1202.0
# 549915         0  242.131013           True   2176.0
# 549937         0  242.131013           True    885.0
# 549963         0  242.131013           True   1690.0
# 549989         0  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions.natural_gas.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            5540.594966
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                             890.321536
# ...                                                    ...
# 549882                                         6675.629132
# 549915                                            0.000000
# 549937                                         7002.945922
# 549963                                         8277.210267
# 549989                                            0.000000
#
#         out.emissions.propane.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions.electricity.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4179.118870
# 122                                            3794.589113
# 150                                           11378.222173
# 153                                            4612.318634
# 162                                            4330.249044
# ...                                                    ...
# 549882                                         2916.093184
# 549915                                        16728.421288
# 549937                                         3823.559604
# 549963                                         3992.118611
# 549989                                         2136.040859
#
#         out.emissions.fuel_oil.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                           13038.928166
# 150                                               0.000000
# 153                                           14589.636195
# 162                                           15002.759507
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                         6042.544365
#
#         out.emissions.natural_gas.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            5540.594966
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                             890.321536
# ...                                                    ...
# 549882                                         6675.629132
# 549915                                            0.000000
# 549937                                         7002.945922
# 549963                                         8277.210267
# 549989                                            0.000000
#
#         out.emissions.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            7380.371515
# 122                                           14675.825549
# 150                                            4530.910597
# 153                                           16564.727059
# 162                                           17837.666007
# ...                                                    ...
# 549882                                         7916.182492
# 549915                                         6870.847124
# 549937                                         8577.560537
# 549963                                         9951.214681
# 549989                                         7176.439561
#
#         out.emissions.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            9495.197860
# 122                                           16590.276103
# 150                                           10702.844907
# 153                                           18949.747039
# 162                                           20060.715408
# ...                                                    ...
# 549882                                         9422.157695
# 549915                                        15814.400458
# 549937                                        10516.078249
# 549963                                        11921.778240
# 549989                                         8281.270372
#
#         out.emissions.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            9035.427108
# 122                                           16204.985672
# 150                                            9290.264827
# 153                                           18437.677994
# 162                                           19596.115712
# ...                                                    ...
# 549882                                         9095.470037
# 549915                                        13772.445542
# 549937                                        10222.759114
# 549963                                        11608.667963
# 549989                                         8040.946248
#
#         out.emissions.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg
# bldg_id
# 119                                            9719.713836
# 122                                           16833.517280
# 150                                           11378.222173
# 153                                           19201.954829
# 162                                           20223.330087
# ...                                                    ...
# 549882                                         9591.722316
# 549915                                        16728.421288
# 549937                                        10826.505527
# 549963                                        12269.328878
# 549989                                         8402.441677
#
# [15651 rows x 259 columns]
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# In addition to the housing type and occupancy filters, the data has been filtered for fuel and technology
# Please see the energy_consumption_and_metadata folder for more details on data processing.
#
# We employ the df_enduse_refactored function to process the data and create a new dataframe, which is part of the 5-step data validation process:
# 1. Mask Initialization with initialize_validation_tracking()
# 2. Series Initialization with create_retrofit_only_series()
# 3. Valid-Only Calculation for qualifying homes
# 4. Valid-Only Updates using list-based collection
# 5. Final Masking with apply_final_masking()
#
# Documentation for df_enduse_refactored function:
# Creates a standardized energy usage DataFrame and applies data quality filters.
#
#     This function creates a new DataFrame with standardized column names and structure,
#     calculates total consumption by fuel type, creates data quality flags for analysis,
#     and sets invalid consumption values to NaN.
#
#     Args:
#         df_baseline: The baseline DataFrame containing raw EUSS/ResStock data.
#
#     Returns:
#         A standardized DataFrame with processed consumption data and data quality flags.
#
#     Raises:
#         ValueError: If required columns are missing from the input DataFrame.
#
# ----------------------------------------------------------------
#
# RESULTS OUTPUT (BASELINE):
#
# Processing column: in.clothes_dryer
# Initial data types: object
# Data types after processing: object
# Processing column: in.cooking_range
# Initial data types: object
# Data types after processing: object
# Calculated total heating consumption
# Calculated total waterHeating consumption
# Calculated total clothesDrying consumption
# Calculated total cooking consumption
#
# Creating data quality flags for all categories
#
# --- Processing heating ---
# Values in base_heating_fuel (top 5):
# base_heating_fuel
# Natural Gas    8594
# Fuel Oil       2922
# Electricity    2722
# Other Fuel      789
# Propane         615
# Name: count, dtype: int64
#   heating: Found 798 homes (5.1%) with invalid fuel types
#   Invalid fuel types (top 5):
# Values in heating_type (top 5):
# heating_type
# Natural Gas Fuel Furnace               5686
# Fuel Oil Fuel Furnace                  1855
# Natural Gas Fuel Wall/Floor Furnace    1437
# Natural Gas Fuel Boiler                1301
# Electricity Baseboard                  1130
# Name: count, dtype: int64
# Allowed values for heating:
# ['Electricity Baseboard', 'Electricity Electric Boiler', 'Electricity Electric Furnace', 'Fuel Oil Fuel Boiler', 'Fuel Oil Fuel Furnace', 'Natural Gas Fuel Boiler', 'Natural Gas Fuel Furnace', 'Propane Fuel Boiler', 'Propane Fuel Furnace']
#   heating: Found 3385 homes (21.6%) with invalid technology types
#   Invalid technology types (top 5):
# heating_type
# Natural Gas Fuel Wall/Floor Furnace    1437
# Electricity ASHP                        684
# Natural Gas Shared Heating              170
# Propane Fuel Wall/Floor Furnace         121
# Fuel Oil Fuel Wall/Floor Furnace         93
# Name: count, dtype: int64
#   heating: Total 3385 homes (21.6%) excluded from analysis
#
# --- Processing waterHeating ---
# Values in base_waterHeating_fuel (top 5):
# base_waterHeating_fuel
# Natural Gas    8669
# Electricity    4652
# Fuel Oil       1728
# Propane         578
# Other Fuel       24
# Name: count, dtype: int64
#   waterHeating: Found 24 homes (0.2%) with invalid fuel types
#   Invalid fuel types (top 5):
# Values in waterHeating_type (top 5):
# waterHeating_type
# Natural Gas Standard    7788
# Electric Standard       3698
# Fuel Oil Standard       1142
# Electric Premium         824
# Natural Gas Premium      673
# Name: count, dtype: int64
# Allowed values for waterHeating:
# ['Electric Premium', 'Electric Standard', 'Fuel Oil Premium', 'Fuel Oil Standard', 'Natural Gas Premium', 'Natural Gas Standard', 'Propane Premium', 'Propane Standard']
#   waterHeating: Found 652 homes (4.2%) with invalid technology types
#   Invalid technology types (top 5):
# waterHeating_type
# FIXME Fuel Oil Indirect       261
# Natural Gas Tankless          208
# Electric Tankless             100
# Electric Heat Pump, 80 gal     30
# Propane Tankless               29
# Name: count, dtype: int64
#   waterHeating: Total 652 homes (4.2%) excluded from analysis
#
# --- Processing clothesDrying ---
# Values in base_clothesDrying_fuel (top 5):
# base_clothesDrying_fuel
# Electricity    10551
# Natural Gas     3899
# Propane          293
# Name: count, dtype: int64
#   clothesDrying: Found 908 homes (5.8%) with invalid fuel types
#   Invalid fuel types (top 5):
#   clothesDrying: Technology validation not applicable (no technology type column)
#   clothesDrying: Total 908 homes (5.8%) excluded from analysis
#
# --- Processing cooking ---
# Values in base_cooking_fuel (top 5):
# base_cooking_fuel
# Electricity    7620
# Natural Gas    6686
# Propane        1181
# Name: count, dtype: int64
#   cooking: Found 7784 homes (49.7%) with invalid fuel types
#   Invalid fuel types (top 5):
#   cooking: Technology validation not applicable (no technology type column)
#   cooking: Total 7784 homes (49.7%) excluded from analysis
#
# Overall: Total 9976 homes (63.7%) excluded from ALL categories
#
# Applying data validation (baseline only):
# Baseline calculation for heating:
#   - 12266 homes have valid data
#   - 3385 homes have invalid data (values will be NaN)
#   base_electricity_heating_consumption: Masked 3385 values
#   base_naturalGas_heating_consumption: Masked 3385 values
#   base_fuelOil_heating_consumption: Masked 3385 values
#   base_propane_heating_consumption: Masked 3385 values
#   baseline_heating_consumption: Masked 2587 values
# Baseline calculation for waterHeating:
#   - 14999 homes have valid data
#   - 652 homes have invalid data (values will be NaN)
#   base_electricity_waterHeating_consumption: Masked 652 values
#   base_naturalGas_waterHeating_consumption: Masked 652 values
#   base_fuelOil_waterHeating_consumption: Masked 652 values
#   base_propane_waterHeating_consumption: Masked 652 values
#   baseline_waterHeating_consumption: Masked 628 values
# Baseline calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 908 homes have invalid data (values will be NaN)
#   base_electricity_clothesDrying_consumption: Masked 908 values
#   base_naturalGas_clothesDrying_consumption: Masked 908 values
#   base_propane_clothesDrying_consumption: Masked 908 values
# Baseline calculation for cooking:
#   - 7867 homes have valid data
#   - 7784 homes have invalid data (values will be NaN)
#   base_naturalGas_cooking_consumption: Masked 7784 values
#   base_propane_cooking_consumption: Masked 7784 values
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline_home
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... valid_fuel_heating  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...               True
# 122      In another census Place   Suburban  ...               True
# 150      In another census Place      Rural  ...               True
# 153        Not in a census Place   Suburban  ...               True
# 162        Not in a census Place   Suburban  ...               True
# ...                          ...        ...  ...                ...
# 549882     Not in a census Place   Suburban  ...               True
# 549915                 Lancaster   Suburban  ...               True
# 549937   In another census Place      Rural  ...               True
# 549963   In another census Place   Suburban  ...               True
# 549989     Not in a census Place      Rural  ...               True
#
#         valid_tech_heating include_heating valid_fuel_waterHeating  \
# bldg_id
# 119                   True            True                    True
# 122                   True            True                    True
# 150                   True            True                    True
# 153                   True            True                    True
# 162                   True            True                    True
# ...                    ...             ...                     ...
# 549882               False           False                    True
# 549915                True            True                    True
# 549937                True            True                    True
# 549963                True            True                    True
# 549989                True            True                    True
#
#         valid_tech_waterHeating  include_waterHeating  \
# bldg_id
# 119                        True                  True
# 122                        True                  True
# 150                        True                  True
# 153                        True                  True
# 162                        True                  True
# ...                         ...                   ...
# 549882                     True                  True
# 549915                     True                  True
# 549937                     True                  True
# 549963                     True                  True
# 549989                     True                  True
#
#          valid_fuel_clothesDrying include_clothesDrying valid_fuel_cooking  \
# bldg_id
# 119                          True                  True               True
# 122                          True                  True              False
# 150                          True                  True              False
# 153                         False                 False              False
# 162                          True                  True              False
# ...                           ...                   ...                ...
# 549882                       True                  True              False
# 549915                       True                  True              False
# 549937                       True                  True               True
# 549963                       True                  True              False
# 549989                       True                  True               True
#
#         include_cooking
# bldg_id
# 119                True
# 122               False
# 150               False
# 153               False
# 162               False
# ...                 ...
# 549882            False
# 549915            False
# 549937             True
# 549963            False
# 549989             True
#
# [15651 rows x 61 columns]
#
#
# ====================================================================================================================================================================
#
# DATAFRAME: df_euss_am_baseline_home
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... valid_fuel_heating  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...               True
# 122      In another census Place   Suburban  ...               True
# 150      In another census Place      Rural  ...               True
# 153        Not in a census Place   Suburban  ...               True
# 162        Not in a census Place   Suburban  ...               True
# ...                          ...        ...  ...                ...
# 549882     Not in a census Place   Suburban  ...               True
# 549915                 Lancaster   Suburban  ...               True
# 549937   In another census Place      Rural  ...               True
# 549963   In another census Place   Suburban  ...               True
# 549989     Not in a census Place      Rural  ...               True
#
#         valid_tech_heating include_heating valid_fuel_waterHeating  \
# bldg_id
# 119                   True            True                    True
# 122                   True            True                    True
# 150                   True            True                    True
# 153                   True            True                    True
# 162                   True            True                    True
# ...                    ...             ...                     ...
# 549882               False           False                    True
# 549915                True            True                    True
# 549937                True            True                    True
# 549963                True            True                    True
# 549989                True            True                    True
#
#         valid_tech_waterHeating  include_waterHeating  \
# bldg_id
# 119                        True                  True
# 122                        True                  True
# 150                        True                  True
# 153                        True                  True
# 162                        True                  True
# ...                         ...                   ...
# 549882                     True                  True
# 549915                     True                  True
# 549937                     True                  True
# 549963                     True                  True
# 549989                     True                  True
#
#          valid_fuel_clothesDrying include_clothesDrying valid_fuel_cooking  \
# bldg_id
# 119                          True                  True               True
# 122                          True                  True              False
# 150                          True                  True              False
# 153                         False                 False              False
# 162                          True                  True              False
# ...                           ...                   ...                ...
# 549882                       True                  True              False
# 549915                       True                  True              False
# 549937                       True                  True               True
# 549963                       True                  True              False
# 549989                       True                  True               True
#
#         include_cooking
# bldg_id
# 119                True
# 122               False
# 150               False
# 153               False
# 162               False
# ...                 ...
# 549882            False
# 549915            False
# 549937             True
# 549963            False
# 549989             True
#
# [15651 rows x 61 columns]
#
#
# Retrieved data for filename: bls_cpiu_2005-2023.xlsx
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\inflation_data\bls_cpiu_2005-2023.xlsx
#     year  cpiu_annual
# 0   2005      195.300
# 1   2006      201.600
# 2   2007      207.342
# 3   2008      215.303
# 4   2009      214.537
# 5   2010      218.056
# 6   2011      224.939
# 7   2012      229.594
# 8   2013      232.957
# 9   2014      236.736
# 10  2015      237.017
# 11  2016      240.007
# 12  2017      245.120
# 13  2018      251.107
# 14  2019      255.657
# 15  2020      258.811
# 16  2021      270.970
# 17  2022      292.655
# 18  2023      304.702
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# ====================================================================================================================================================================
# PUBLIC IMPACTS (BASELINE): DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
# Detailed documentation of the methods used to calculate the climate and public health impacts can be
# found in the public_impacts folder of the cmu-tare-model package. All monetary values are in 2023
# inflation-adjusted dollars ($USD2023).
# - data_processing sub-folder: contains the data processing scripts used for lookup dictionaries
# - calculations sub-folder: contains the calculations for emissions from fossul fuel appliances
# - Main folder contains the scripts for calculating lifetime climate and public health impacts as
#   as well as climate NPV, health NPV, and combined public NPV.
#
# Step 1: Calculate the baseline marginal damages for climate and health-related emissions
# Step 2: Calculate the post-retrofit marginal damages for climate and health-related emissions
# Step 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
#
# ----------------------------------------------------------------------------------------------
# Step 1: Calculate the baseline marginal damages for climate and health-related emissions
# ----------------------------------------------------------------------------------------------
#
# Documentation for calculate_lifetime_climate_impacts_sensitivity function:
#
#     Calculate lifetime climate impacts (CO2e emissions and climate damages) for each
#     equipment category across all (mer_type, scc_value) combinations.
#
#     This function processes each equipment category over its lifetime, computing annual
#     and lifetime climate emissions/damages. Results are combined into two DataFrames:
#     a main summary (df_main) and a detailed annual breakdown (df_detailed).
#
#     This function follows the five-STEP validation framework:
#     1. Mask Initialization: Identifies valid homes using inclusion flags and retrofit status
#     2. Series Initialization: Creates result series with zeros for valid homes, NaN for others
#     3. Valid-Only Calculation: Performs calculations only for valid homes
#     4. Valid-Only Updates: Uses list-based collection of yearly values instead of incremental updates
#     5. Final Masking: Applies consistent masking to all result columns
#
#     The list-based collection approach stores yearly values in lists and sums them using pandas
#     vectorized operations after all years have been processed. This approach prevents accumulation
#     errors that can occur with incremental updates.
#
#     Args:
#         df (pd.DataFrame): Input DataFrame containing equipment consumption data, region info, etc.
#         menu_mp (int): Measure package identifier (0 for baseline, nonzero for different scenarios).
#         policy_scenario (str): Determines emissions scenario inputs (e.g., 'No Inflation Reduction Act' or 'AEO2023 Reference Case').
#         base_year (int, optional): Base year for calculations. Defaults to 2024.
#         df_baseline_damages (pd.DataFrame, optional): Baseline damages for computing avoided emissions/damages.
#         verbose (bool, optional): Whether to print detailed progress messages. Defaults to False.
#
#     Returns:
#         Tuple[pd.DataFrame, pd.DataFrame]:
#             - df_main: Main summary of lifetime climate impacts (rounded to 2 decimals).
#             - df_detailed: Detailed annual and lifetime results (rounded to 2 decimals).
#
#     Raises:
#         ValueError: If menu_mp or policy_scenario is invalid.
#         RuntimeError: If processing fails at the category or year level (e.g., missing data or key lookups).
#
#
# Documentation for calculate_lifetime_health_impacts_sensitivity function:
#
#     Calculate lifetime health impacts for each equipment category over all (rcm, cr) combinations.
#
#     This function calculates lifetime health damages for each equipment category by iterating over each year of the
#     equipment's lifetime and each (rcm, cr) combination. It returns a tuple of two DataFrames:
#     - The main DataFrame updated with lifetime health damages.
#     - A detailed DataFrame containing annual results with lifetime breakdowns.
#
#     This function follows the five-step validation framework:
#     1. Mask Initialization: Identifies valid homes using inclusion flags and retrofit status
#     2. Series Initialization: Creates result series with zeros for valid homes, NaN for others
#     3. Valid-Only Calculation: Performs calculations only for valid homes
#     4. Valid-Only Updates: Uses list-based collection of yearly values instead of incremental updates
#     5. Final Masking: Applies consistent masking to all result columns
#
#     The list-based collection approach stores yearly values in lists and sums them using pandas
#     vectorized operations after all years have been processed. This approach prevents accumulation
#     errors that can occur with incremental updates.
#
#     Args:
#         df (pd.DataFrame): Input data.
#         menu_mp (int): Measure package identifier.
#         policy_scenario (str): Policy scenario name that determines model inputs
#             ('No Inflation Reduction Act' or 'AEO2023 Reference Case').
#         base_year (int): The base year for calculations (default is 2024).
#         df_baseline_damages (Optional[pd.DataFrame]): Baseline health damages data.
#         debug (bool): If True, enables debug mode for additional output.
#         verbose (bool, optional): Whether to print detailed progress messages. Defaults to False.
#
#     Returns:
#         Tuple[pd.DataFrame, pd.DataFrame]: A tuple containing:
#             - df_main (pd.DataFrame): The aggregated lifetime health impacts.
#             - df_detailed (pd.DataFrame): The detailed annual health damages results.
#
#     Raises:
#         ValueError: If menu_mp or policy_scenario is invalid.
#         RuntimeError: If processing fails at the category or year level due to missing data or calculation errors.
#         KeyError: If an HDD factor is not found for a required year.
#
#
#
#
# ==================== PUBLIC IMPACTS (BASELINE): DAMAGES FROM CLIMATE-RELATED EMISSIONS ====================
#
#
# -- Scenario: Baseline (mp0) --
#
# ====================================================================================================================================================================
#
# df_euss_am_baseline_home: DataFrame containing the baseline scenario data
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_clothesDrying_lifetime_damages_climate_srmer_central  \
# bldg_id
# 119                                                 619.65
# 122                                                 784.65
# ...
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#         baseline_cooking_lifetime_damages_health_inmap_h6c fuel_type_heating  \
# bldg_id
# 119                                                 380.50        naturalGas
# 122                                                    NaN           fuelOil
# 150                                                    NaN       electricity
# 153                                                    NaN           fuelOil
# 162                                                    NaN           fuelOil
# ...                                                    ...               ...
# 549882                                                 NaN        naturalGas
# 549915                                                 NaN       electricity
# 549937                                              129.68        naturalGas
# 549963                                                 NaN        naturalGas
# 549989                                              146.99           fuelOil
#
#         fuel_type_waterHeating fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 119                 naturalGas              naturalGas         naturalGas
# 122                    fuelOil             electricity        electricity
# 150                electricity             electricity        electricity
# 153                    fuelOil                     NaN        electricity
# 162                 naturalGas             electricity        electricity
# ...                        ...                     ...                ...
# 549882              naturalGas             electricity        electricity
# 549915             electricity             electricity        electricity
# 549937              naturalGas              naturalGas         naturalGas
# 549963              naturalGas             electricity        electricity
# 549989                 fuelOil             electricity            propane
#
#          baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                  9692.04
# 122                                 56634.48
# 150                                 48835.85
# 153                                 52691.10
# 162                                 69001.23
# ...                                      ...
# 549882                                   NaN
# 549915                              52898.91
# 549937                               8456.00
# 549963                              17473.34
# 549989                              22285.90
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                        351.02
# 122                                        619.28
# 150                                        718.64
# 153                                           NaN
# 162                                       2222.41
# ...                                           ...
# 549882                                     997.02
# 549915                                    1736.07
# 549937                                     982.27
# 549963                                     898.31
# 549989                                     898.31
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 126 columns]
#
# df_baseline_fuel_costs: DataFrame containing the baseline scenario data with fuel costs
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  baseline_2030_cooking_fuel_cost  \
# bldg_id                            ...
# 119                          True  ...                            38.66
# 122                          True  ...                              NaN
# 150                          True  ...                              NaN
# 153                         False  ...                              NaN
# 162                          True  ...                              NaN
# ...                           ...  ...                              ...
# 549882                       True  ...                              NaN
# 549915                       True  ...                              NaN
# 549937                       True  ...                            52.58
# 549963                       True  ...                              NaN
# 549989                       True  ...                           108.64
#
#          baseline_2031_cooking_fuel_cost  baseline_2032_cooking_fuel_cost  \
# bldg_id
# 119                                38.81                            38.64
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             52.79                            52.56
# 549963                               NaN                              NaN
# 549989                            109.76                           111.26
#
#          baseline_2033_cooking_fuel_cost  baseline_2034_cooking_fuel_cost  \
# bldg_id
# 119                                39.10                            39.11
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.19                            53.20
# 549963                               NaN                              NaN
# 549989                            112.94                           114.21
#
#          baseline_2035_cooking_fuel_cost  baseline_2036_cooking_fuel_cost  \
# bldg_id
# 119                                39.02                            38.84
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.07                            52.84
# 549963                               NaN                              NaN
# 549989                            115.40                           116.58
#
#          baseline_2037_cooking_fuel_cost  baseline_2038_cooking_fuel_cost  \
# bldg_id
# 119                                39.25                            39.49
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.38                            53.71
# 549963                               NaN                              NaN
# 549989                            117.97                           119.31
#
#          baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                   589.84
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                802.29
# 549963                                   NaN
# 549989                               1691.55
#
# [15651 rows x 70 columns]
#
#
# The code took 0 minutes and 53 seconds to execute.
# Baseline Scenario - Model Run Complete

# %%
print(output_folder_path)
# Out:
# c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_baseline_damages_climate,
    results_category='damages_climate_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_baseline_damages_health,
    results_category='damages_health_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_baseline_fuel_costs,
    results_category='fuel_costs_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# ===== SUMMARY RESULTS =====
export_model_run_output(
    df_results_export=df_euss_am_baseline_home,
    results_category='summary_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )
# Out:
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_climate_baseline
# Dataframe results will be saved in this csv file: mp8_damages_climate_baseline_PA_2026-02-04_17-33.csv
# Dataframe for MP8 damages_climate_baseline results were exported here: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_baseline\mp8_damages_climate_baseline_PA_2026-02-04_17-33.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_health_baseline
# Dataframe results will be saved in this csv file: mp8_damages_health_baseline_PA_2026-02-04_17-33.csv
# Dataframe for MP8 damages_health_baseline results were exported here: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_baseline\mp8_damages_health_baseline_PA_2026-02-04_17-33.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: fuel_costs_baseline
# Dataframe results will be saved in this csv file: mp8_fuel_costs_baseline_PA_2026-02-04_17-33.csv
# Dataframe for MP8 fuel_costs_baseline results were exported here: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_baseline\mp8_fuel_costs_baseline_PA_2026-02-04_17-33.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# BASELINE SUMMARY RESULTS:
# Dataframe results will be saved in this csv file: baseline_results_PA_2026-02-04_17-33.csv
# Dataframe for MP8 summary_baseline results were exported here: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\baseline_summary\summary_baseline\baseline_results_PA_2026-02-04_17-33.csv
# -------------------------------------------------------------------------------------------------------

# %%
print("""
Scenarios for Basic, Moderate, and Advanced Retrofit
- Rows in the Baseline CSV are merged with the Post-Retrofit Measure Package.
- The same filters are applied.

-------------------------------------------------------------------------------------------------------
MODEL SCENARIOS
-------------------------------------------------------------------------------------------------------
- BASIC/MODERATE/ADVANCED Pre-IRA Scenario:
    - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
    - AEO2023 No Inflation Reduction Act
    - Cambium 2021 MidCase
      
- BASIC/MODERATE/ADVANCED IRA-Reference Scenario:
    - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
    - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
    - Cambium 2022 and 2023 MidCase
""")
# Out:
# Scenarios for Basic, Moderate, and Advanced Retrofit
# - Rows in the Baseline CSV are merged with the Post-Retrofit Measure Package.
# - The same filters are applied.
#
# -------------------------------------------------------------------------------------------------------
# MODEL SCENARIOS
# -------------------------------------------------------------------------------------------------------
# - BASIC/MODERATE/ADVANCED Pre-IRA Scenario:
#     - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
#     - AEO2023 No Inflation Reduction Act
#     - Cambium 2021 MidCase
#
# - BASIC/MODERATE/ADVANCED IRA-Reference Scenario:
#     - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
#     - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
#     - Cambium 2022 and 2023 MidCase

# %% [markdown]
# -------------------------------------------------------------------------------------------------------
# # POST-RETROFIT SCENARIOS: Basic (MP8), Moderate (MP9), Advanced (MP10)
# -------------------------------------------------------------------------------------------------------
# ## No IRA Scenario:
# - AEO2023 No Inflation Reduction Act
# - Cambium 2021 MidCase
# ## IRA-Reference Scenario:
# - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
# - Cambium 2022 and 2023 MidCase
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Basic Retrofit: Measure Package 8 (MP8)

# %%
# Measure Package 8
menu_mp = 8
input_mp = 'upgrade08'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "model_scenarios_LEGACY", "tare_basic_v2_1.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Basic Retrofit Scenario - Model Run Complete")
# Out:
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/model_scenarios_LEGACY/tare_basic_v2_1.ipynb
#
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (MP8).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 346)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            7  242.131013           True   2152.0
# 122            7  242.131013           True   2176.0
# 150            7  242.131013          False   1690.0
# 153            7  242.131013           True   2176.0
# 162            7  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         7  242.131013           True   1202.0
# 549915         7  242.131013          False   2176.0
# 549937         7  242.131013           True    885.0
# 549963         7  242.131013           True   1690.0
# 549989         7  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4367.397352
# 122                                           10479.768179
# 150                                               0.000000
# 153                                           11048.097647
# 162                                           12947.903971
# ...                                                    ...
# 549882                                         5212.871757
# 549915                                            0.000000
# 549937                                         4636.242910
# 549963                                         4903.857419
# 549989                                         4686.866540
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2552.828291
# 122                                            6954.371623
# 150                                               0.000000
# 153                                            6200.439415
# 162                                            8666.012863
# ...                                                    ...
# 549882                                         3310.560695
# 549915                                            0.000000
# 549937                                         1673.632015
# 549963                                          609.743358
# 549989                                         2436.617472
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            2985.641141
# 122                                            7797.415226
# 150                                               0.000000
# 153                                            7363.122758
# 162                                            9676.629818
# ...                                                    ...
# 549882                                         3739.637305
# 549915                                            0.000000
# 549937                                         2257.364571
# 549963                                         1488.137683
# 549989                                         2959.741017
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2356.289439
# 122                                            6648.492515
# 150                                               0.000000
# 153                                            5775.168899
# 162                                            8324.377523
# ...                                                    ...
# 549882                                         3185.908976
# 549915                                            0.000000
# 549937                                         1154.203887
# 549963                                          -84.117798
# 549989                                         2177.081897
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 119      Electric, 100% Usage  Electric, 100% Usage
# 122                       NaN                   NaN
# 150                       NaN                   NaN
# 153                       NaN                   NaN
# 162                       NaN                   NaN
# ...                       ...                   ...
# 549882                    NaN                   NaN
# 549915                    NaN                   NaN
# 549937   Electric, 120% Usage  Electric, 120% Usage
# 549963                    NaN                   NaN
# 549989                    NaN  Electric, 100% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 122                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 150                                 NaN                                NaN
# 153                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 162                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# ...                                 ...                                ...
# 549882                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
# 549915                              NaN                                NaN
# 549937                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549963                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549989                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150                                       NaN
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                                    NaN
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 346 columns]
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Basic-BAU:
# Basic Retrofit: Measure Package 8
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade08_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade08_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 347)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 347)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 347)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 347)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            8  242.131013           True   2152.0
# 122            8  242.131013           True   2176.0
# 150            8  242.131013           True   1690.0
# 153            8  242.131013           True   2176.0
# 162            8  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         8  242.131013           True   1202.0
# 549915         8  242.131013           True   2176.0
# 549937         8  242.131013           True    885.0
# 549963         8  242.131013           True   1690.0
# 549989         8  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            5063.088752
# 122                                           12066.712342
# 150                                            3103.153770
# 153                                           12691.688692
# 162                                           14912.014271
# ...                                                    ...
# 549882                                         5882.269769
# 549915                                         3949.186094
# 549937                                         5643.594000
# 549963                                         6479.951652
# 549989                                         5231.517125
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4214.733128
# 122                                           10590.254662
# 150                                            7434.178003
# 153                                           10026.235230
# 162                                           13274.793477
# ...                                                    ...
# 549882                                         4814.108725
# 549915                                         9153.072186
# 549937                                         3941.494074
# 549963                                         4162.716516
# 549989                                         3713.809302
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            4421.232869
# 122                                           10962.614536
# 150                                            6435.450158
# 153                                           10675.202534
# 162                                           13682.148002
# ...                                                    ...
# 549882                                         5058.857189
# 549915                                         7958.419199
# 549937                                         4289.405772
# 549963                                         4656.122049
# 549989                                         4068.275863
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4103.394799
# 122                                           10472.994231
# 150                                            7914.527787
# 153                                            9808.721813
# 162                                           13130.752498
# ...                                                    ...
# 549882                                         4740.981471
# 549915                                         9734.504122
# 549937                                         3628.586099
# 549963                                         3803.239573
# 549989                                         3542.402188
#
#                                      upgrade.clothes_dryer  \
# bldg_id
# 119      Electric, Premium, Heat Pump, Ventless, 100% U...
# 122      Electric, Premium, Heat Pump, Ventless, 100% U...
# 150      Electric, Premium, Heat Pump, Ventless, 80% Usage
# 153                                                    NaN
# 162      Electric, Premium, Heat Pump, Ventless, 80% Usage
# ...                                                    ...
# 549882   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549915   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549937   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549963   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549989   Electric, Premium, Heat Pump, Ventless, 100% U...
#
#                    upgrade.cooking_range upgrade.hvac_cooling_efficiency  \
# bldg_id
# 119      Electric, Induction, 100% Usage                       Heat Pump
# 122      Electric, Induction, 100% Usage                       Heat Pump
# 150       Electric, Induction, 80% Usage                       Heat Pump
# 153      Electric, Induction, 120% Usage                       Heat Pump
# 162       Electric, Induction, 80% Usage                       Heat Pump
# ...                                  ...                             ...
# 549882   Electric, Induction, 120% Usage                       Heat Pump
# 549915   Electric, Induction, 100% Usage                       Heat Pump
# 549937   Electric, Induction, 120% Usage                       Heat Pump
# 549963   Electric, Induction, 100% Usage                       Heat Pump
# 549989   Electric, Induction, 100% Usage                       Heat Pump
#
#             upgrade.hvac_heating_efficiency upgrade.hvac_heating_type  \
# bldg_id
# 119                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 122                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 150      MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 153                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 162                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# ...                                     ...                       ...
# 549882   MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 549915               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549937               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549963               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549989               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150      Electric Heat Pump, 66 gal, 3.35 UEF
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915   Electric Heat Pump, 80 gal, 3.45 UEF
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 347 columns]
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 8 (MP8)
# ====================================================================================================================================================================
# You'll notice that the number of rows differs from df_euss_am_mp7 and df_euss_am_mp8.
#       - df_euss_am_baseline_home has fewer rows (representative dwelling units) because a tech filter was applied.
#       - df_euss_am_mp8_home will have the same number of rows as df_euss_am_baseline_home after df_enduse_compare function is run.
#       - df_enduse_compare function performs an inner merge on the two dataframes, keeping only the rows that are present in both dataframes.
# ====================================================================================================================================================================
# df_euss_am_mp8_home will be created by running the df_enduse_compare function (contains post-retrofit consumption data for the entire home in 2024).
# process_euss_data.py file contains the function definition.
#
# Documentation for df_enduse_compare function:
# Creates a comparison DataFrame by merging multiple DataFrames based on measure packages.
#
#     This function constructs a new DataFrame (df_compare) that includes columns
#     from df_mp, df_cooking_range, and merges them with df_baseline to compare
#     baseline vs. measure package outputs for heating, water heating, clothes drying,
#     and cooking.
#
#     Args:
#         df_mp: The main DataFrame containing modeling parameters and outputs.
#         input_mp: The input measure package ID (e.g., 'upgrade09', 'upgrade10').
#         menu_mp: The menu measure package number.
#         df_baseline: The baseline DataFrame to merge with df_compare.
#         df_cooking_range: Additional DataFrame for cooking range parameters/outputs.
#         verbose: Whether to print detailed comparison information.
#
#     Returns:
#         A merged DataFrame (df_compare) that includes relevant columns for
#         baseline and measure packages comparison.
#
# ----------------------------------------------------------------
#
# RESULTING DATAFRAME:
#
#
# Applying combined validation (data quality + retrofit status):
#   Using 'upgrade_hvac_heating_efficiency' column:
#   - 15649 homes will receive heating retrofits.
#   - 2 homes will NOT receive retrofits (values will be NaN).
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
#   mp8_heating_consumption: Masked 3385 values
#   Using 'upgrade_water_heater_efficiency' column:
#   - 15551 homes will receive waterHeating retrofits.
#   - 100 homes will NOT receive retrofits (values will be NaN).
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
#   mp8_waterHeating_consumption: Masked 652 values
#   Using 'upgrade_clothes_dryer' column:
#   - 14743 homes will receive clothesDrying retrofits.
#   - 908 homes will NOT receive retrofits (values will be NaN).
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
#   mp8_clothesDrying_consumption: Masked 908 values
#   Using 'upgrade_cooking_range' column:
#   - 7867 homes will receive cooking retrofits.
#   - 7784 homes will NOT receive retrofits (values will be NaN).
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#   mp8_cooking_consumption: Masked 7784 values
#
# ====================================================================================================================================================================
# PUBLIC IMPACTS: DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
#
#
#
#  Creating dataframe to store marginal damages calculations ...
#
# ====================================================================================================================================================================
# df_euss_am_baseline_home: DataFrame containing the baseline scenario data
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#         baseline_cooking_lifetime_damages_health_inmap_h6c fuel_type_heating  \
# bldg_id
# 119                                                 380.50        naturalGas
# 122                                                    NaN           fuelOil
# 150                                                    NaN       electricity
# 153                                                    NaN           fuelOil
# 162                                                    NaN           fuelOil
# ...                                                    ...               ...
# 549882                                                 NaN        naturalGas
# 549915                                                 NaN       electricity
# 549937                                              129.68        naturalGas
# 549963                                                 NaN        naturalGas
# 549989                                              146.99           fuelOil
#
#         fuel_type_waterHeating fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 119                 naturalGas              naturalGas         naturalGas
# 122                    fuelOil             electricity        electricity
# 150                electricity             electricity        electricity
# 153                    fuelOil                     NaN        electricity
# 162                 naturalGas             electricity        electricity
# ...                        ...                     ...                ...
# 549882              naturalGas             electricity        electricity
# 549915             electricity             electricity        electricity
# 549937              naturalGas              naturalGas         naturalGas
# 549963              naturalGas             electricity        electricity
# 549989                 fuelOil             electricity            propane
#
#          baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                  9692.04
# 122                                 56634.48
# 150                                 48835.85
# 153                                 52691.10
# 162                                 69001.23
# ...                                      ...
# 549882                                   NaN
# 549915                              52898.91
# 549937                               8456.00
# 549963                              17473.34
# 549989                              22285.90
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                        351.02
# 122                                        619.28
# 150                                        718.64
# 153                                           NaN
# 162                                       2222.41
# ...                                           ...
# 549882                                     997.02
# 549915                                    1736.07
# 549937                                     982.27
# 549963                                     898.31
# 549989                                     898.31
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 126 columns]
#
# df_baseline_damages_health: DataFrame containing the baseline scenario data with health damages
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          baseline_2038_cooking_damages_so2_inmap_h6c  \
# bldg_id
# 119                                             0.92
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          0.63
# 549963                                           NaN
# 549989                                          0.82
#
#          baseline_2038_cooking_damages_nox_inmap_h6c  \
# bldg_id
# 119                                            17.35
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          7.15
# 549963                                           NaN
# 549989                                          8.32
#
#          baseline_2038_cooking_damages_pm25_inmap_h6c  \
# bldg_id
# 119                                              8.30
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                           0.91
# 549963                                            NaN
# 549989                                           0.68
#
#          baseline_2038_cooking_damages_health_inmap_h6c  \
# bldg_id
# 119                                               26.56
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                             8.69
# 549963                                              NaN
# 549989                                             9.83
#
#          baseline_cooking_lifetime_damages_health_ap2_acs  \
# bldg_id
# 119                                                 37.49
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              20.82
# 549963                                                NaN
# 549989                                              23.53
#
#          baseline_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 96.32
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              53.48
# 549963                                                NaN
# 549989                                              60.44
#
#          baseline_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 130.47
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# ...
# 549882                                                 NaN
# 549915                                            37593.48
# 549937                                            -1530.58
# 549963                                              698.21
# 549989                                             7341.86
#
#         iraRef_mp8_waterHeating_total_npv_healthOnly_easiur_h6c_fixed_base  \
# bldg_id
# 119                                                1152.91
# 122                                                3981.91
# 150                                                1313.76
# 153                                                9235.56
# 162                                               -1581.16
# ...                                                    ...
# 549882                                              206.87
# 549915                                             7405.21
# 549937                                             1862.19
# 549963                                              816.13
# 549989                                             2848.17
#
#          iraRef_mp8_clothesDrying_total_npv_healthOnly_easiur_h6c_fixed_base  \
# bldg_id
# 119                                                -633.25
# 122                                                 256.19
# 150                                                -598.54
# 153                                                    NaN
# 162                                                -797.06
# ...                                                    ...
# 549882                                              514.22
# 549915                                                2.24
# 549937                                             -902.59
# 549963                                             -496.59
# 549989                                             -369.32
#
#         iraRef_mp8_cooking_total_npv_healthOnly_easiur_h6c_fixed_base
# bldg_id
# 119                                                -587.18
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -495.96
# 549963                                                 NaN
# 549989                                              -84.97
#
# [15651 rows x 774 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp8_cooking_total_npv_climateOnly_central_fixed_base  \
# bldg_id
# 119                                                -188.26
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -202.08
# 549963                                                 NaN
# 549989                                              388.16
#
#         iraRef_mp8_cooking_total_npv_climateOnly_upper_fixed_base  \
# bldg_id
# 119                                                 -43.80
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -75.85
# 549963                                                 NaN
# 549989                                              599.84
#
#         iraRef_mp8_heating_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                               -2190.51
# 122                                                2793.86
# 150                                               31578.20
# 153                                               14059.12
# 162                                               23103.11
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            29970.65
# 549937                                            -2042.44
# 549963                                             -430.92
# 549989                                             6018.62
#
#         iraRef_mp8_waterHeating_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                                1034.41
# 122                                                3706.07
# 150                                                1093.06
# 153                                                6887.96
# 162                                               -1674.11
# ...                                                    ...
# 549882                                               36.93
# 549915                                             5916.14
# 549937                                             1452.66
# 549963                                              690.62
# 549989                                             2588.01
#
#         iraRef_mp8_clothesDrying_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                                -569.99
# 122                                                 172.36
# 150                                                -638.12
# 153                                                    NaN
# 162                                               -1098.27
# ...                                                    ...
# 549882                                              440.66
# 549915                                             -161.79
# 549937                                             -897.71
# 549963                                             -534.62
# 549989                                             -421.75
#
#          iraRef_mp8_cooking_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                                -418.29
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -469.04
# 549963                                                 NaN
# 549989                                              -45.81
#
#          iraRef_mp8_heating_total_npv_healthOnly_inmap_h6c_fixed_base  \
# bldg_id
# 119                                                  19.51
# 122                                               15220.30
# 150                                               42372.65
# 153                                               19311.42
# 162                                               38443.08
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            39134.05
# 549937                                            -2099.91
# 549963                                              289.83
# 549989                                             6328.72
#
#         iraRef_mp8_waterHeating_total_npv_healthOnly_inmap_h6c_fixed_base  \
# bldg_id
# 119                                                1565.09
# 122                                                4355.71
# 150                                                1646.91
# 153                                                8256.32
# 162                                               -1244.42
# ...                                                    ...
# 549882                                             -200.64
# 549915                                             7741.45
# 549937                                             1468.15
# 549963                                              769.86
# 549989                                             2600.93
#
#          iraRef_mp8_clothesDrying_total_npv_healthOnly_inmap_h6c_fixed_base  \
# bldg_id
# 119                                                -537.93
# 122                                                 217.60
# 150                                                -539.51
# 153                                                    NaN
# 162                                                -935.71
# ...                                                    ...
# 549882                                              595.46
# 549915                                               37.87
# 549937                                             -965.99
# 549963                                             -488.13
# 549989                                             -337.81
#
#         iraRef_mp8_cooking_total_npv_healthOnly_inmap_h6c_fixed_base
# bldg_id
# 119                                                -392.74
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -549.17
# 549963                                                 NaN
# 549989                                             -160.78
#
# [15651 rows x 774 columns]
#
#
# The code took 4 minutes and 53 seconds to execute.
# Basic Retrofit Scenario - Model Run Complete

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp8_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp8_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp8_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp8_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp8_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp8_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )
# Out:
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_noIRA
# Saved to: mp8_damages_climate_noIRA_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_noIRA\mp8_damages_climate_noIRA_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_IRA
# Saved to: mp8_damages_climate_IRA_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_IRA\mp8_damages_climate_IRA_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_noIRA
# Saved to: mp8_damages_health_noIRA_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_noIRA\mp8_damages_health_noIRA_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_IRA
# Saved to: mp8_damages_health_IRA_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_IRA\mp8_damages_health_IRA_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_noIRA
# Saved to: mp8_fuel_costs_noIRA_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_noIRA\mp8_fuel_costs_noIRA_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_IRA
# Saved to: mp8_fuel_costs_IRA_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_IRA\mp8_fuel_costs_IRA_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------

# %%
# ===== SUMMARY RESULTS (RCM MODELS × DISCOUNT RATES) =====
print(f"Exporting MP{menu_mp} Summary Results (AP2 model with discount rate sensitivity)...")
# AP2
export_model_run_output(
    df_results_export=df_euss_am_mp8_home_ap2_fixed_low,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='fixed_low'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp8_home_ap2_fixed_base,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='fixed_base'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp8_home_ap2_fixed_high,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='fixed_high'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp8_home_ap2_variable,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='variable'
    )

# EASIUR
export_model_run_output(
    df_results_export=df_euss_am_mp8_home_easiur_fixed_low,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='fixed_low'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp8_home_easiur_fixed_base,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='fixed_base'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp8_home_easiur_fixed_high,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='fixed_high'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp8_home_easiur_variable,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='variable'
    )

# InMAP
export_model_run_output(
    df_results_export=df_euss_am_mp8_home_inmap_fixed_low,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='fixed_low'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp8_home_inmap_fixed_base,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='fixed_base'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp8_home_inmap_fixed_high,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='fixed_high'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp8_home_inmap_variable,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='variable'
    )
# Out:
# Exporting MP8 Summary Results (AP2 model with discount rate sensitivity)...
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_low
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_fixed_low\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_base
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_fixed_base\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_high
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_fixed_high\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: variable
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_variable\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_low
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_fixed_low\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_base
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_fixed_base\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_high
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_fixed_high\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: variable
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_variable\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_low
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_fixed_low\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_base
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_fixed_base\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_high
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_fixed_high\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: variable
# Saved to: mp8_results_PA_2026-02-04_17-13.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_variable\mp8_results_PA_2026-02-04_17-13.csv
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Moderate Retrofit: Measure Package 9 (MP9)

# %%
# Measure Package 9
menu_mp = 9
input_mp = 'upgrade09'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "model_scenarios_LEGACY", "tare_moderate_v2_1.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Moderate Retrofit Scenario - Model Run Complete")

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp9_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp9_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp9_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp9_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp9_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp9_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# %%
# ===== SUMMARY RESULTS (RCM MODELS × DISCOUNT RATES) =====
print(f"Exporting MP{menu_mp} Summary Results (AP2 model with discount rate sensitivity)...")
# AP2
export_model_run_output(
    df_results_export=df_euss_am_mp9_home_ap2_fixed_low,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='fixed_low'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp9_home_ap2_fixed_base,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='fixed_base'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp9_home_ap2_fixed_high,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='fixed_high'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp9_home_ap2_variable,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='variable'
    )

# EASIUR
export_model_run_output(
    df_results_export=df_euss_am_mp9_home_easiur_fixed_low,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='fixed_low'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp9_home_easiur_fixed_base,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='fixed_base'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp9_home_easiur_fixed_high,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='fixed_high'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp9_home_easiur_variable,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='variable'
    )

# InMAP
export_model_run_output(
    df_results_export=df_euss_am_mp9_home_inmap_fixed_low,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='fixed_low'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp9_home_inmap_fixed_base,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='fixed_base'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp9_home_inmap_fixed_high,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='fixed_high'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp9_home_inmap_variable,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='variable'
    )

# %% [markdown]
# ## Advanced Retrofit: Measure Package 10 (MP10)

# %%
# Measure Package 10
menu_mp = 10
input_mp = 'upgrade10'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "model_scenarios_LEGACY", "tare_advanced_v2_1.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Advanced Retrofit Scenario - Model Run Complete")

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp10_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp10_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp10_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp10_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp10_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_mp10_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# %%
# ===== SUMMARY RESULTS (RCM MODELS × DISCOUNT RATES) =====
print(f"Exporting MP{menu_mp} Summary Results (AP2 model with discount rate sensitivity)...")
# AP2
export_model_run_output(
    df_results_export=df_euss_am_mp10_home_ap2_fixed_low,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='fixed_low'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp10_home_ap2_fixed_base,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='fixed_base'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp10_home_ap2_fixed_high,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='fixed_high'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp10_home_ap2_variable,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='ap2',
    discount_rate='variable'
    )

# EASIUR
export_model_run_output(
    df_results_export=df_euss_am_mp10_home_easiur_fixed_low,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='fixed_low'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp10_home_easiur_fixed_base,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='fixed_base'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp10_home_easiur_fixed_high,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='fixed_high'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp10_home_easiur_variable,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='easiur',
    discount_rate='variable'
    )

# InMAP
export_model_run_output(
    df_results_export=df_euss_am_mp10_home_inmap_fixed_low,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='fixed_low'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp10_home_inmap_fixed_base,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='fixed_base'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp10_home_inmap_fixed_high,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='fixed_high'
    )

export_model_run_output(
    df_results_export=df_euss_am_mp10_home_inmap_variable,
    results_category='summary',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time,
    rcm_model='inmap',
    discount_rate='variable'
    )
