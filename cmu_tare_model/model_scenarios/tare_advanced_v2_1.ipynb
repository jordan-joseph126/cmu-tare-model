# %%
import os

# import from cmu-tare-model package
from config import PROJECT_ROOT

# Measure Package 0: Baseline
menu_mp = 0
input_mp = 'baseline'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_baseline_v2_1.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")

print(f"Running file: {file_path}")

# %run magic command to run a .py file and import variables into the current IPython session
# # If your path has spaces, wrap it in quotes:
# %run -i {file_path} # If your path has NO spaces, no quotes needed.

print("Baseline Scenario - Model Run Complete")

# Flag to prevent excessive output in other scenario files
individual_scenario_run = True
# Out:
# Project root directory: c:\users\jorda\desktop\projects\cmu-tare-model
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_baseline_v2_1.ipynb
#
# =========================================================================================================
# Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
# Let's start by reading the data from the NREL EUSS Database.
#
# Make sure that the zipped folders stay organized as they are once unzipped.
# If changes are made to the file path, then the program will not run properly.
# ==========================================================================================================
#
# Project root directory: c:\users\jorda\desktop\projects\cmu-tare-model
# Result outputs will be exported here: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results
#
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# Load data from the NREL EUSS Database for the baseline scenario and apply various filters.
#
# DATA: NREL EUSS Database
# HOUSING FILTERS: Occupied units and Single Family Homes
# GEOGRAPHIC FILTERS: National, State, or City
#
# Additional details data can be found in the official End-Use Load Profiles/Savings Shapes documentation.
# Our methodology is detailed in the process_euss_data.py file and its associated imports.
#
# RESULTS OUTPUT:
#
# Retrieved data for filename: baseline_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\baseline_metadata_and_annual_results.csv
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 259)
# You chose to filter for: PA
# Location ID is: PA
#
# To accurately characterize load profile, it is recommended to select subsets of data with >= 1000 models (~240,000 representative dwelling units).
#
# The following cities (number of models also shown) are available for this state:
#
# in.city
# Not in a census Place      7035
# In another census Place    5851
# PA, Philadelphia           1631
# PA, Pittsburgh              329
# PA, Erie                    105
# PA, Allentown               104
# PA, Reading                  92
# PA, Bethlehem                85
# PA, Scranton                 80
# PA, Harrisburg               63
# PA, Lancaster                58
# PA, Levittown                58
# PA, Altoona                  56
# PA, York                     56
# PA, Wilkes-Barre             48
# Name: count, dtype: int64
# You chose to analyze all of state: PA
# Location ID is: PA
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline
#
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            0  242.131013           True   2152.0
# 122            0  242.131013           True   2176.0
# 150            0  242.131013           True   1690.0
# 153            0  242.131013           True   2176.0
# 162            0  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         0  242.131013           True   1202.0
# 549915         0  242.131013           True   2176.0
# 549937         0  242.131013           True    885.0
# 549963         0  242.131013           True   1690.0
# 549989         0  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions.natural_gas.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            5540.594966
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                             890.321536
# ...                                                    ...
# 549882                                         6675.629132
# 549915                                            0.000000
# 549937                                         7002.945922
# 549963                                         8277.210267
# 549989                                            0.000000
#
#         out.emissions.propane.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions.electricity.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4179.118870
# 122                                            3794.589113
# 150                                           11378.222173
# 153                                            4612.318634
# 162                                            4330.249044
# ...                                                    ...
# 549882                                         2916.093184
# 549915                                        16728.421288
# 549937                                         3823.559604
# 549963                                         3992.118611
# 549989                                         2136.040859
#
#         out.emissions.fuel_oil.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                           13038.928166
# 150                                               0.000000
# 153                                           14589.636195
# 162                                           15002.759507
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                         6042.544365
#
#         out.emissions.natural_gas.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            5540.594966
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                             890.321536
# ...                                                    ...
# 549882                                         6675.629132
# 549915                                            0.000000
# 549937                                         7002.945922
# 549963                                         8277.210267
# 549989                                            0.000000
#
#         out.emissions.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            7380.371515
# 122                                           14675.825549
# 150                                            4530.910597
# 153                                           16564.727059
# 162                                           17837.666007
# ...                                                    ...
# 549882                                         7916.182492
# 549915                                         6870.847124
# 549937                                         8577.560537
# 549963                                         9951.214681
# 549989                                         7176.439561
#
#         out.emissions.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            9495.197860
# 122                                           16590.276103
# 150                                           10702.844907
# 153                                           18949.747039
# 162                                           20060.715408
# ...                                                    ...
# 549882                                         9422.157695
# 549915                                        15814.400458
# 549937                                        10516.078249
# 549963                                        11921.778240
# 549989                                         8281.270372
#
#         out.emissions.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            9035.427108
# 122                                           16204.985672
# 150                                            9290.264827
# 153                                           18437.677994
# 162                                           19596.115712
# ...                                                    ...
# 549882                                         9095.470037
# 549915                                        13772.445542
# 549937                                        10222.759114
# 549963                                        11608.667963
# 549989                                         8040.946248
#
#         out.emissions.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg
# bldg_id
# 119                                            9719.713836
# 122                                           16833.517280
# 150                                           11378.222173
# 153                                           19201.954829
# 162                                           20223.330087
# ...                                                    ...
# 549882                                         9591.722316
# 549915                                        16728.421288
# 549937                                        10826.505527
# 549963                                        12269.328878
# 549989                                         8402.441677
#
# [15651 rows x 259 columns]
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# In addition to the housing type and occupancy filters, the data has been filtered for fuel and technology
# Please see the energy_consumption_and_metadata folder for more details on data processing.
#
# We employ the df_enduse_refactored function to process the data and create a new dataframe, which is part of the 5-step data validation process:
# 1. Mask Initialization with initialize_validation_tracking()
# 2. Series Initialization with create_retrofit_only_series()
# 3. Valid-Only Calculation for qualifying homes
# 4. Valid-Only Updates using list-based collection
# 5. Final Masking with apply_final_masking()
#
# Documentation for df_enduse_refactored function:
# Creates a standardized energy usage DataFrame and applies data quality filters.
#
#     This function creates a new DataFrame with standardized column names and structure,
#     calculates total consumption by fuel type, creates data quality flags for analysis,
#     and sets invalid consumption values to NaN.
#
#     Args:
#         df_baseline: The baseline DataFrame containing raw EUSS/ResStock data.
#
#     Returns:
#         A standardized DataFrame with processed consumption data and data quality flags.
#
#     Raises:
#         ValueError: If required columns are missing from the input DataFrame.
#
# ----------------------------------------------------------------
#
# RESULTS OUTPUT (BASELINE):
#
# Processing column: in.clothes_dryer
# Initial data types: object
# Data types after processing: object
# Processing column: in.cooking_range
# Initial data types: object
# Data types after processing: object
# Calculated total heating consumption
# Calculated total waterHeating consumption
# Calculated total clothesDrying consumption
# Calculated total cooking consumption
#
# Creating data quality flags for all categories
#
# --- Processing heating ---
# Values in base_heating_fuel (top 5):
# base_heating_fuel
# Natural Gas    8594
# Fuel Oil       2922
# Electricity    2722
# Other Fuel      789
# Propane         615
# Name: count, dtype: int64
#   heating: Found 798 homes (5.1%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_heating_fuel
# Other Fuel    789
# Name: count, dtype: int64
# Values in heating_type (top 5):
# heating_type
# Natural Gas Fuel Furnace               5686
# Fuel Oil Fuel Furnace                  1855
# Natural Gas Fuel Wall/Floor Furnace    1437
# Natural Gas Fuel Boiler                1301
# Electricity Baseboard                  1130
# Name: count, dtype: int64
# Allowed values for heating:
# ['Electricity Baseboard', 'Electricity Electric Boiler', 'Electricity Electric Furnace', 'Fuel Oil Fuel Boiler', 'Fuel Oil Fuel Furnace', 'Natural Gas Fuel Boiler', 'Natural Gas Fuel Furnace', 'Propane Fuel Boiler', 'Propane Fuel Furnace']
#   heating: Found 3385 homes (21.6%) with invalid technology types
#   Invalid technology types (top 5):
# heating_type
# Natural Gas Fuel Wall/Floor Furnace    1437
# Electricity ASHP                        684
# Natural Gas Shared Heating              170
# Propane Fuel Wall/Floor Furnace         121
# Fuel Oil Fuel Wall/Floor Furnace         93
# Name: count, dtype: int64
#   heating: Total 3385 homes (21.6%) excluded from analysis
#
# --- Processing waterHeating ---
# Values in base_waterHeating_fuel (top 5):
# base_waterHeating_fuel
# Natural Gas    8669
# Electricity    4652
# Fuel Oil       1728
# Propane         578
# Other Fuel       24
# Name: count, dtype: int64
#   waterHeating: Found 24 homes (0.2%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_waterHeating_fuel
# Other Fuel    24
# Name: count, dtype: int64
# Values in waterHeating_type (top 5):
# waterHeating_type
# Natural Gas Standard    7788
# Electric Standard       3698
# Fuel Oil Standard       1142
# Electric Premium         824
# Natural Gas Premium      673
# Name: count, dtype: int64
# Allowed values for waterHeating:
# ['Electric Premium', 'Electric Standard', 'Fuel Oil Premium', 'Fuel Oil Standard', 'Natural Gas Premium', 'Natural Gas Standard', 'Propane Premium', 'Propane Standard']
#   waterHeating: Found 652 homes (4.2%) with invalid technology types
#   Invalid technology types (top 5):
# waterHeating_type
# FIXME Fuel Oil Indirect       261
# Natural Gas Tankless          208
# Electric Tankless             100
# Electric Heat Pump, 80 gal     30
# Propane Tankless               29
# Name: count, dtype: int64
#   waterHeating: Total 652 homes (4.2%) excluded from analysis
#
# --- Processing clothesDrying ---
# Values in base_clothesDrying_fuel (top 5):
# base_clothesDrying_fuel
# Electricity    10551
# Natural Gas     3899
# Propane          293
# Name: count, dtype: int64
#   clothesDrying: Found 908 homes (5.8%) with invalid fuel types
#   Invalid fuel types (top 5):
# Series([], Name: count, dtype: int64)
#   clothesDrying: Technology validation not applicable (no technology type column)
#   clothesDrying: Total 908 homes (5.8%) excluded from analysis
#
# --- Processing cooking ---
# Values in base_cooking_fuel (top 5):
# base_cooking_fuel
# Electricity    7620
# Natural Gas    6686
# Propane        1181
# Name: count, dtype: int64
#   cooking: Found 7784 homes (49.7%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_cooking_fuel
# Electricity    7620
# Name: count, dtype: int64
#   cooking: Technology validation not applicable (no technology type column)
#   cooking: Total 7784 homes (49.7%) excluded from analysis
#
# Total 9976 homes (63.7%) excluded from all categories
#
# Applying data validation (baseline only):
# Baseline calculation for heating:
#   - 12266 homes have valid data
#   - 3385 homes have invalid data (values will be NaN)
#   base_electricity_heating_consumption: Masked 3385 values
#   base_naturalGas_heating_consumption: Masked 3385 values
#   base_fuelOil_heating_consumption: Masked 3385 values
#   base_propane_heating_consumption: Masked 3385 values
#   baseline_heating_consumption: Masked 2587 values
# Baseline calculation for waterHeating:
#   - 14999 homes have valid data
#   - 652 homes have invalid data (values will be NaN)
#   base_electricity_waterHeating_consumption: Masked 652 values
#   base_naturalGas_waterHeating_consumption: Masked 652 values
#   base_fuelOil_waterHeating_consumption: Masked 652 values
#   base_propane_waterHeating_consumption: Masked 652 values
#   baseline_waterHeating_consumption: Masked 628 values
# Baseline calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 908 homes have invalid data (values will be NaN)
#   base_electricity_clothesDrying_consumption: Masked 908 values
#   base_naturalGas_clothesDrying_consumption: Masked 908 values
#   base_propane_clothesDrying_consumption: Masked 908 values
# Baseline calculation for cooking:
#   - 7867 homes have valid data
#   - 7784 homes have invalid data (values will be NaN)
#   base_electricity_cooking_consumption: Masked 7784 values
#   base_naturalGas_cooking_consumption: Masked 7784 values
#   base_propane_cooking_consumption: Masked 7784 values
#   baseline_cooking_consumption: Masked 7620 values
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline_home
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... valid_fuel_heating  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...               True
# 122      In another census Place   Suburban  ...               True
# 150      In another census Place      Rural  ...               True
# 153        Not in a census Place   Suburban  ...               True
# 162        Not in a census Place   Suburban  ...               True
# ...                          ...        ...  ...                ...
# 549882     Not in a census Place   Suburban  ...               True
# 549915                 Lancaster   Suburban  ...               True
# 549937   In another census Place      Rural  ...               True
# 549963   In another census Place   Suburban  ...               True
# 549989     Not in a census Place      Rural  ...               True
#
#         valid_tech_heating include_heating valid_fuel_waterHeating  \
# bldg_id
# 119                   True            True                    True
# 122                   True            True                    True
# 150                   True            True                    True
# 153                   True            True                    True
# 162                   True            True                    True
# ...                    ...             ...                     ...
# 549882               False           False                    True
# 549915                True            True                    True
# 549937                True            True                    True
# 549963                True            True                    True
# 549989                True            True                    True
#
#         valid_tech_waterHeating  include_waterHeating  \
# bldg_id
# 119                        True                  True
# 122                        True                  True
# 150                        True                  True
# 153                        True                  True
# 162                        True                  True
# ...                         ...                   ...
# 549882                     True                  True
# 549915                     True                  True
# 549937                     True                  True
# 549963                     True                  True
# 549989                     True                  True
#
#          valid_fuel_clothesDrying include_clothesDrying valid_fuel_cooking  \
# bldg_id
# 119                          True                  True               True
# 122                          True                  True              False
# 150                          True                  True              False
# 153                         False                 False              False
# 162                          True                  True              False
# ...                           ...                   ...                ...
# 549882                       True                  True              False
# 549915                       True                  True              False
# 549937                       True                  True               True
# 549963                       True                  True              False
# 549989                       True                  True               True
#
#         include_cooking
# bldg_id
# 119                True
# 122               False
# 150               False
# 153               False
# 162               False
# ...                 ...
# 549882            False
# 549915            False
# 549937             True
# 549963            False
# 549989             True
#
# [15651 rows x 61 columns]
#
#
# ====================================================================================================================================================================
#
# DATAFRAME: df_euss_am_baseline_home
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... valid_fuel_heating  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...               True
# 122      In another census Place   Suburban  ...               True
# 150      In another census Place      Rural  ...               True
# 153        Not in a census Place   Suburban  ...               True
# 162        Not in a census Place   Suburban  ...               True
# ...                          ...        ...  ...                ...
# 549882     Not in a census Place   Suburban  ...               True
# 549915                 Lancaster   Suburban  ...               True
# 549937   In another census Place      Rural  ...               True
# 549963   In another census Place   Suburban  ...               True
# 549989     Not in a census Place      Rural  ...               True
#
#         valid_tech_heating include_heating valid_fuel_waterHeating  \
# bldg_id
# 119                   True            True                    True
# 122                   True            True                    True
# 150                   True            True                    True
# 153                   True            True                    True
# 162                   True            True                    True
# ...                    ...             ...                     ...
# 549882               False           False                    True
# 549915                True            True                    True
# 549937                True            True                    True
# 549963                True            True                    True
# 549989                True            True                    True
#
#         valid_tech_waterHeating  include_waterHeating  \
# bldg_id
# 119                        True                  True
# 122                        True                  True
# 150                        True                  True
# 153                        True                  True
# 162                        True                  True
# ...                         ...                   ...
# 549882                     True                  True
# 549915                     True                  True
# 549937                     True                  True
# 549963                     True                  True
# 549989                     True                  True
#
#          valid_fuel_clothesDrying include_clothesDrying valid_fuel_cooking  \
# bldg_id
# 119                          True                  True               True
# 122                          True                  True              False
# 150                          True                  True              False
# 153                         False                 False              False
# 162                          True                  True              False
# ...                           ...                   ...                ...
# 549882                       True                  True              False
# 549915                       True                  True              False
# 549937                       True                  True               True
# 549963                       True                  True              False
# 549989                       True                  True               True
#
#         include_cooking
# bldg_id
# 119                True
# 122               False
# 150               False
# 153               False
# 162               False
# ...                 ...
# 549882            False
# 549915            False
# 549937             True
# 549963            False
# 549989             True
#
# [15651 rows x 61 columns]
#
#
#
#     -------------------------------------------------------------------------------------------------------
#     PRE-IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2021 RELEASE
#     -------------------------------------------------------------------------------------------------------
#
#
#
#     Retrieved data for filename: cambium21_midCase_annual_gea.xlsx
#     Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\projections\cambium21_midCase_annual_gea.xlsx
#
#     Loading dataframe ...
#
#               dataset scenario gea_region  year  cef_gen  aer_co2e_kg_per_MWh  \
# 0    Cambium_2021  MidCase      AZNMc  2022      NaN                423.2
# 1    Cambium_2021  MidCase      AZNMc  2024      NaN                389.5
# 2    Cambium_2021  MidCase      AZNMc  2026      NaN                374.7
# 3    Cambium_2021  MidCase      AZNMc  2028      NaN                364.8
# 4    Cambium_2021  MidCase      AZNMc  2030      NaN                315.8
# ..            ...      ...        ...   ...      ...                  ...
# 295  Cambium_2021  MidCase      SRVCc  2042      NaN                240.8
# 296  Cambium_2021  MidCase      SRVCc  2044      NaN                222.5
# 297  Cambium_2021  MidCase      SRVCc  2046      NaN                178.5
# 298  Cambium_2021  MidCase      SRVCc  2048      NaN                182.1
# 299  Cambium_2021  MidCase      SRVCc  2050      NaN                169.3
#
#      lrmer_co2e_kg_per_MWh  srmer_co2e_kg_per_MWh  generation  \
# 0                    525.6                  811.8   143037980
# 1                    488.4                  808.4   151806820
# 2                    423.1                  816.0   154638340
# 3                    315.8                  784.7   159426910
# 4                    313.6                  749.8   175350740
# ..                     ...                    ...         ...
# 295                  313.9                  805.5   400253860
# 296                  314.6                  786.1   427886080
# 297                  320.6                  754.9   444492960
# 298                  317.9                  751.3   453625180
# 299                  306.7                  718.3   466444480
#
#      variable_generation  ...  total_coal  total_natural_gas  total_oil  \
# 0             27345228.0  ...  32912356.0         40391114.7    29364.0
# 1             29423460.0  ...  27460646.0         52221791.8    14086.3
# 2             29648762.0  ...  26772840.0         53833046.4     8814.2
# 3             32619604.0  ...  26693880.0         55589546.7    10161.3
# 4             50951904.0  ...  24898662.0         54122073.2    13228.5
# ..                   ...  ...         ...                ...        ...
# 295           96427260.0  ...  37576316.0        117368159.3     2205.4
# 296          115764890.0  ...  33240228.0        125603043.3     1392.8
# 297          150328400.0  ...  27152428.0        105858843.0       74.8
# 298          152065260.0  ...  27861414.0        111393181.0       49.1
# 299          154687700.0  ...  14777366.0        134385100.3        9.9
#
#      total_nuclear  total_renewable  fraction_coal  fraction_natural_gas  \
# 0         31446266       37669404.5       0.231047              0.283549
# 1         31446266       40074547.2       0.181597              0.345343
# 2         31446266       41990327.2       0.173792              0.349449
# 3         31446266       45101365.5       0.168054              0.349969
# 4         31446266       64294435.2       0.142462              0.309668
# ..             ...              ...            ...                   ...
# 295      122300980      121063293.0       0.094339              0.294665
# 296      122300980      144866950.7       0.078026              0.294834
# 297      122300980      187251355.2       0.061353              0.239195
# 298      122300980      190141835.5       0.061682              0.246610
# 299      122300980      193718661.2       0.031767              0.288887
#
#      fraction_oil  fraction_nuclear  fraction_renewable
# 0    2.061377e-04          0.220755            0.264442
# 1    9.315268e-05          0.207954            0.265013
# 2    5.721601e-05          0.204129            0.272574
# 3    6.397143e-05          0.197973            0.283940
# 4    7.568889e-05          0.179925            0.367870
# ..            ...               ...                 ...
# 295  5.536880e-06          0.307049            0.303942
# 296  3.269387e-06          0.287083            0.340053
# 297  1.690152e-07          0.276347            0.423106
# 298  1.087011e-07          0.270759            0.420950
# 299  2.128199e-08          0.262910            0.416436
#
# [300 rows x 43 columns]
#
#     Creating lookup dictionary for LRMER and SRMER ...
#     -------------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------------
#     IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2022 RELEASE
#     -------------------------------------------------------------------------------------------------------
#
#
#     Retrieved data for filename: cambium22_allScenarios_annual_gea.xlsx
#     Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\projections\cambium22_allScenarios_annual_gea.xlsx
#
#     Loading dataframe ...
#
#           data_source scenario gea_region  year  cef_gen  aer_co2e_kg_per_MWh  \
# 0    Cambium_2022  MidCase      AZNMc  2024     0.63                279.4
# 1    Cambium_2022  MidCase      AZNMc  2026     0.69                237.5
# 2    Cambium_2022  MidCase      AZNMc  2028     0.80                157.9
# 3    Cambium_2022  MidCase      AZNMc  2030     0.84                133.3
# 4    Cambium_2022  MidCase      AZNMc  2035     0.89                 81.9
# ..            ...      ...        ...   ...      ...                  ...
# 155  Cambium_2022  MidCase      SRVCc  2030     0.75                147.1
# 156  Cambium_2022  MidCase      SRVCc  2035     0.83                 92.1
# 157  Cambium_2022  MidCase      SRVCc  2040     0.86                 75.5
# 158  Cambium_2022  MidCase      SRVCc  2045     0.93                 38.7
# 159  Cambium_2022  MidCase      SRVCc  2050     0.93                 38.9
#
#      lrmer_co2e_kg_per_MWh  srmer_co2e_kg_per_MWh  generation  \
# 0                    326.9                  777.1   185725700
# 1                    193.9                  709.7   192790580
# 2                    130.5                  576.4   193906060
# 3                    103.7                  486.7   193562020
# 4                    149.4                  398.4   210627860
# ..                     ...                    ...         ...
# 155                  211.7                  662.9   391723170
# 156                  211.6                  583.4   459622500
# 157                  188.3                  540.5   481364480
# 158                  142.2                  497.4   501150400
# 159                  113.2                  511.2   501907700
#
#      variable_generation  ...  total_coal  total_natural_gas  total_oil  \
# 0             74605900.0  ...  22849070.0         46188801.1    35759.0
# 1             87517200.0  ...  21009922.0         38928884.4    26155.8
# 2            108173544.0  ...  14483350.0         25156486.8    19751.4
# 3            113367950.0  ...  13433882.0         18404394.4     2684.8
# 4            128952530.0  ...   8231337.5         14217323.4     4222.1
# ..                   ...  ...         ...                ...        ...
# 155          139815250.0  ...  17312904.0         79749385.0     2648.2
# 156          209080400.0  ...   8787109.0         67359566.6     2424.3
# 157          229834830.0  ...   6132569.5         60580299.5     2979.2
# 158          265812640.0  ...   4301606.5         28826117.4      748.2
# 159          271552540.0  ...   1924772.2         34071135.0       17.9
#
#      total_nuclear  total_renewable  fraction_coal  fraction_natural_gas  \
# 0       30865014.0       85518978.5       0.123204              0.249053
# 1       30392044.0      102169009.2       0.109128              0.202201
# 2       29352388.0      124638520.0       0.074791              0.129907
# 3       28571094.0      132901330.4       0.069493              0.095205
# 4       27536908.0      160412983.2       0.039122              0.067572
# ..             ...              ...            ...                   ...
# 155    119012670.0      173052397.5       0.044491              0.204943
# 156    116559336.0      264783518.0       0.019207              0.147237
# 157    115754584.0      296807708.5       0.012795              0.126399
# 158    114458344.0      352150817.0       0.008608              0.057683
# 159    111073256.0      353415175.0       0.003846              0.068076
#
#      fraction_oil  fraction_nuclear  fraction_renewable
# 0    1.928149e-04          0.166426            0.461124
# 1    1.358559e-04          0.157859            0.530676
# 2    1.019951e-04          0.151574            0.643626
# 3    1.388833e-05          0.147797            0.687492
# 4    2.006675e-05          0.130877            0.762409
# ..            ...               ...                 ...
# 155  6.805438e-06          0.305843            0.444716
# 156  5.299110e-06          0.254779            0.578772
# 157  6.216015e-06          0.241519            0.619281
# 158  1.497186e-06          0.229037            0.704671
# 159  3.576535e-08          0.221932            0.706146
#
# [160 rows x 44 columns]
#
#     Creating lookup dictionary for 2024 LRMER and SRMER ...
#     -------------------------------------------------------------------------------------------------------
#
# Fuel sources in df_grid_mix: {'Oil', 'Coal', 'Natural Gas', 'Renewable', 'Nuclear'}
# Fuel sources in df_grid_emis_factors: {'Oil', 'Coal', 'Natural Gas', 'Renewables', 'Nuclear'}
# Retrieved data for filename: bls_cpiu_2005-2023.xlsx
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\inflation_data\bls_cpiu_2005-2023.xlsx
#     year  cpiu_annual
# 0   2005      195.300
# 1   2006      201.600
# 2   2007      207.342
# 3   2008      215.303
# 4   2009      214.537
# 5   2010      218.056
# 6   2011      224.939
# 7   2012      229.594
# 8   2013      232.957
# 9   2014      236.736
# 10  2015      237.017
# 11  2016      240.007
# 12  2017      245.120
# 13  2018      251.107
# 14  2019      255.657
# 15  2020      258.811
# 16  2021      270.970
# 17  2022      292.655
# 18  2023      304.702
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# ...
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#         baseline_cooking_lifetime_damages_health_inmap_h6c fuel_type_heating  \
# bldg_id
# 119                                                 380.50        naturalGas
# 122                                                    NaN           fuelOil
# 150                                                    NaN       electricity
# 153                                                    NaN           fuelOil
# 162                                                    NaN           fuelOil
# ...                                                    ...               ...
# 549882                                                 NaN        naturalGas
# 549915                                                 NaN       electricity
# 549937                                              129.68        naturalGas
# 549963                                                 NaN        naturalGas
# 549989                                              146.99           fuelOil
#
#         fuel_type_waterHeating fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 119                 naturalGas              naturalGas         naturalGas
# 122                    fuelOil             electricity        electricity
# 150                electricity             electricity        electricity
# 153                    fuelOil                     NaN        electricity
# 162                 naturalGas             electricity        electricity
# ...                        ...                     ...                ...
# 549882              naturalGas             electricity        electricity
# 549915             electricity             electricity        electricity
# 549937              naturalGas              naturalGas         naturalGas
# 549963              naturalGas             electricity        electricity
# 549989                 fuelOil             electricity            propane
#
#          baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                  9692.04
# 122                                 56634.48
# 150                                 48835.85
# 153                                 52691.10
# 162                                 69001.23
# ...                                      ...
# 549882                                   NaN
# 549915                              52898.91
# 549937                               8456.00
# 549963                              17473.34
# 549989                              22285.90
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                        351.02
# 122                                        619.28
# 150                                        718.64
# 153                                           NaN
# 162                                       2222.41
# ...                                           ...
# 549882                                     997.02
# 549915                                    1736.07
# 549937                                     982.27
# 549963                                     898.31
# 549989                                     898.31
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 126 columns]
#
# df_baseline_fuel_costs: DataFrame containing the baseline scenario data with fuel costs
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  baseline_2030_cooking_fuel_cost  \
# bldg_id                            ...
# 119                          True  ...                            38.66
# 122                          True  ...                              NaN
# 150                          True  ...                              NaN
# 153                         False  ...                              NaN
# 162                          True  ...                              NaN
# ...                           ...  ...                              ...
# 549882                       True  ...                              NaN
# 549915                       True  ...                              NaN
# 549937                       True  ...                            52.58
# 549963                       True  ...                              NaN
# 549989                       True  ...                           108.64
#
#          baseline_2031_cooking_fuel_cost  baseline_2032_cooking_fuel_cost  \
# bldg_id
# 119                                38.81                            38.64
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             52.79                            52.56
# 549963                               NaN                              NaN
# 549989                            109.76                           111.26
#
#          baseline_2033_cooking_fuel_cost  baseline_2034_cooking_fuel_cost  \
# bldg_id
# 119                                39.10                            39.11
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.19                            53.20
# 549963                               NaN                              NaN
# 549989                            112.94                           114.21
#
#          baseline_2035_cooking_fuel_cost  baseline_2036_cooking_fuel_cost  \
# bldg_id
# 119                                39.02                            38.84
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.07                            52.84
# 549963                               NaN                              NaN
# 549989                            115.40                           116.58
#
#          baseline_2037_cooking_fuel_cost  baseline_2038_cooking_fuel_cost  \
# bldg_id
# 119                                39.25                            39.49
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.38                            53.71
# 549963                               NaN                              NaN
# 549989                            117.97                           119.31
#
#          baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                   589.84
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                802.29
# 549963                                   NaN
# 549989                               1691.55
#
# [15651 rows x 70 columns]
#
#
# The code took 0 minutes and 44 seconds to execute.
# Baseline Scenario - Model Run Complete

# %% [markdown]
# # LOAD EUSS DATA: Annual Energy Consumption and Metadata
# ## MEASURE PACKAGE 7 (MP7): Data for Electric Resistance Cooking

# %%
print(f"""
====================================================================================================================================================================
We assume the use of Electric Resistance (MP7) rather than Induction (MP8-10).
Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
====================================================================================================================================================================
""")
# from cmu_tare_model.constants import ALLOWED_HOUSING_TYPES

# Measure Package 7
menu_mp = 7
input_mp = 'upgrade07'

filename = "upgrade07_metadata_and_annual_results.csv"
relative_path = os.path.join("cmu_tare_model", "data", "euss_data", "resstock_amy2018_release_1.1", "resstock_amy2018_release_1.1_processed_data", filename)

file_path = os.path.join(PROJECT_ROOT, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

# Fix DtypeWarning error in columns 'in.neighbors' and 'in.geometry_stories_low_rise'
columns_to_string = {11: str, 61: str, 121: str, 103: str, 128: str, 129: str}
df_euss_am_mp7 = pd.read_csv(file_path, dtype=columns_to_string, index_col="bldg_id") # UPDATE: Set index to 'bldg_id' (unique identifier)
print(f"DATAFRAME SIZE before applying any filters: {df_euss_am_mp7.shape}")


# Filter for occupied homes
occupancy_filter = df_euss_am_mp7['in.vacancy_status'] == 'Occupied'
df_euss_am_mp7 = df_euss_am_mp7.loc[occupancy_filter]
print(f"DATAFRAME SIZE after filtering for 'Occupied' homes: {df_euss_am_mp7.shape}")

# Filter for allowed housing types
house_type_filter = df_euss_am_mp7['in.geometry_building_type_recs'].isin(ALLOWED_HOUSING_TYPES)
df_euss_am_mp7 = df_euss_am_mp7.loc[house_type_filter]
print(f"Allowed housing types: {ALLOWED_HOUSING_TYPES}")
print(f"DATAFRAME SIZE after filtering for allowed housing types: {df_euss_am_mp7.shape}")

# National Level 
if menu_state == 'N':
    print("You chose to analyze all of the United States.")
    input_state = 'National'

# Filter down to state or city
else:
    print(f"You chose to filter for: {input_state}")
    state_filter = df_euss_am_mp7['in.state'].eq(input_state)
    df_euss_am_mp7 = df_euss_am_mp7.loc[state_filter]

    # Filter for the entire selected state
    if menu_city == 'N':
        print(f"You chose to analyze all of state: {input_state}")
        
    # Filter to a city within the selected state
    else:
        print(f"You chose to filter for: {input_state}, {input_cityFilter}")
        city_filter = df_euss_am_mp7['in.city'].eq(f"{input_state}, {input_cityFilter}")
        df_euss_am_mp7 = df_euss_am_mp7.loc[city_filter]

# Display the filtered dataframe
print(f"DATAFRAME SIZE after applying geographic filter: {df_euss_am_mp7.shape}")
print(df_euss_am_mp7)
# Out:
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (MP8-10).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 346)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            7  242.131013           True   2152.0
# 122            7  242.131013           True   2176.0
# 150            7  242.131013          False   1690.0
# 153            7  242.131013           True   2176.0
# 162            7  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         7  242.131013           True   1202.0
# 549915         7  242.131013          False   2176.0
# 549937         7  242.131013           True    885.0
# 549963         7  242.131013           True   1690.0
# 549989         7  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4367.397352
# 122                                           10479.768179
# 150                                               0.000000
# 153                                           11048.097647
# 162                                           12947.903971
# ...                                                    ...
# 549882                                         5212.871757
# 549915                                            0.000000
# 549937                                         4636.242910
# 549963                                         4903.857419
# 549989                                         4686.866540
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2552.828291
# 122                                            6954.371623
# 150                                               0.000000
# 153                                            6200.439415
# 162                                            8666.012863
# ...                                                    ...
# 549882                                         3310.560695
# 549915                                            0.000000
# 549937                                         1673.632015
# 549963                                          609.743358
# 549989                                         2436.617472
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            2985.641141
# 122                                            7797.415226
# 150                                               0.000000
# 153                                            7363.122758
# 162                                            9676.629818
# ...                                                    ...
# 549882                                         3739.637305
# 549915                                            0.000000
# 549937                                         2257.364571
# 549963                                         1488.137683
# 549989                                         2959.741017
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2356.289439
# 122                                            6648.492515
# 150                                               0.000000
# 153                                            5775.168899
# 162                                            8324.377523
# ...                                                    ...
# 549882                                         3185.908976
# 549915                                            0.000000
# 549937                                         1154.203887
# 549963                                          -84.117798
# 549989                                         2177.081897
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 119      Electric, 100% Usage  Electric, 100% Usage
# 122                       NaN                   NaN
# 150                       NaN                   NaN
# 153                       NaN                   NaN
# 162                       NaN                   NaN
# ...                       ...                   ...
# 549882                    NaN                   NaN
# 549915                    NaN                   NaN
# 549937   Electric, 120% Usage  Electric, 120% Usage
# 549963                    NaN                   NaN
# 549989                    NaN  Electric, 100% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 122                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 150                                 NaN                                NaN
# 153                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 162                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# ...                                 ...                                ...
# 549882                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
# 549915                              NaN                                NaN
# 549937                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549963                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549989                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150                                       NaN
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                                    NaN
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 346 columns]

# %% [markdown]
# ## MEASURE PACKAGE 10 (MP10): Metadata, Space Heating, Water Heating, and Clothes Drying

# %%
# Print debugging information
print_debug = False

if print_debug:
    from cmu_tare_model.utils.create_sample_df import create_sample_df

# %%
# Measure Package 10
menu_mp = 10
input_mp = 'upgrade10'
scenario_name = 'Advanced-BAU'
cost_scenario = 'BAU Costs'
grid_scenario = 'Current Electricity Grid'

print(f"""
====================================================================================================================================================================
MODEL SCENARIO
====================================================================================================================================================================
Scenario {scenario_name}:
Advanced Retrofit: Measure Package {menu_mp}
{cost_scenario}
{grid_scenario}
====================================================================================================================================================================
""")

filename = "upgrade10_metadata_and_annual_results.csv"
relative_path = os.path.join("cmu_tare_model", "data", "euss_data", "resstock_amy2018_release_1.1", "resstock_amy2018_release_1.1_processed_data", filename)
file_path = os.path.join(PROJECT_ROOT, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

# Fix DtypeWarning error in columns 'in.neighbors' and 'in.geometry_stories_low_rise'
columns_to_string = {11: str, 61: str, 121: str, 103: str, 128: str, 129: str}
df_euss_am_mp10 = pd.read_csv(file_path, dtype=columns_to_string, index_col="bldg_id") # UPDATE: Set index to 'bldg_id' (unique identifier)
print(f"DATAFRAME SIZE before applying any filters: {df_euss_am_mp10.shape}")

# Filter for occupied homes
occupancy_filter = df_euss_am_mp10['in.vacancy_status'] == 'Occupied'
df_euss_am_mp10 = df_euss_am_mp10.loc[occupancy_filter]
print(f"DATAFRAME SIZE after filtering for 'Occupied' homes: {df_euss_am_mp10.shape}")

# Filter for allowed housing types
house_type_filter = df_euss_am_mp10['in.geometry_building_type_recs'].isin(ALLOWED_HOUSING_TYPES)
df_euss_am_mp10 = df_euss_am_mp10.loc[house_type_filter]
print(f"Allowed housing types: {ALLOWED_HOUSING_TYPES}")
print(f"DATAFRAME SIZE after filtering for allowed housing types: {df_euss_am_mp10.shape}")

# National Level 
if menu_state == 'N':
    print("You chose to analyze all of the United States.")
    input_state = 'National'

# Filter down to state or city
else:
    print(f"You chose to filter for: {input_state}")
    state_filter = df_euss_am_mp10['in.state'].eq(input_state)
    df_euss_am_mp10 = df_euss_am_mp10.loc[state_filter]

    # Filter for the entire selected state
    if menu_city == 'N':
        print(f"You chose to analyze all of state: {input_state}")
        
    # Filter to a city within the selected state
    else:
        print(f"You chose to filter for: {input_state}, {input_cityFilter}")
        city_filter = df_euss_am_mp10['in.city'].eq(f"{input_state}, {input_cityFilter}")
        df_euss_am_mp10 = df_euss_am_mp10.loc[city_filter]

# Display the filtered dataframe
# Display the filtered dataframe
print(f"DATAFRAME SIZE after applying geographic filter: {df_euss_am_mp10.shape}")
print(df_euss_am_mp10)
# Out:
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Advanced-BAU:
# Advanced Retrofit: Measure Package 10
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade10_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade10_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 354)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 354)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 354)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 354)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119           10  242.131013           True   2152.0
# 122           10  242.131013           True   2176.0
# 150           10  242.131013           True   1690.0
# 153           10  242.131013           True   2176.0
# 162           10  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882        10  242.131013           True   1202.0
# 549915        10  242.131013           True   2176.0
# 549937        10  242.131013           True    885.0
# 549963        10  242.131013           True   1690.0
# 549989        10  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         upgrade.geometry_foundation_type upgrade.hvac_cooling_efficiency  \
# bldg_id
# 119                  Unvented Crawlspace                       Heat Pump
# 122                                  NaN                       Heat Pump
# 150                  Unvented Crawlspace                       Heat Pump
# 153                                  NaN                       Heat Pump
# 162                  Unvented Crawlspace                       Heat Pump
# ...                                  ...                             ...
# 549882                               NaN                       Heat Pump
# 549915               Unvented Crawlspace                       Heat Pump
# 549937                               NaN                       Heat Pump
# 549963               Unvented Crawlspace                       Heat Pump
# 549989                               NaN                       Heat Pump
#
#             upgrade.hvac_heating_efficiency upgrade.hvac_heating_type  \
# bldg_id
# 119                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 122                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 150      MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 153                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 162                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# ...                                     ...                       ...
# 549882   MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 549915               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549937               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549963               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549989               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
#
#         upgrade.infiltration_reduction upgrade.insulation_ceiling  \
# bldg_id
# 119                                NaN                       R-60
# 122                                30%                       R-60
# 150                                30%                       R-60
# 153                                30%                       R-60
# 162                                30%                       R-60
# ...                                ...                        ...
# 549882                             30%                       R-60
# 549915                             30%                       R-60
# 549937                             30%                        NaN
# 549963                             NaN                        NaN
# 549989                             NaN                       R-60
#
#         upgrade.insulation_foundation_wall upgrade.insulation_roof  \
# bldg_id
# 119                    Wall R-10, Interior                     NaN
# 122                                    NaN                     NaN
# 150                    Wall R-10, Interior                     NaN
# 153                                    NaN                     NaN
# 162                    Wall R-10, Interior                     NaN
# ...                                    ...                     ...
# 549882                                 NaN                     NaN
# 549915                 Wall R-10, Interior                     NaN
# 549937                                 NaN                     NaN
# 549963                 Wall R-10, Interior                     NaN
# 549989                                 NaN                     NaN
#
#         upgrade.insulation_wall       upgrade.water_heater_efficiency
# bldg_id
# 119                         NaN  Electric Heat Pump, 66 gal, 3.35 UEF
# 122             Wood Stud, R-13  Electric Heat Pump, 66 gal, 3.35 UEF
# 150             Wood Stud, R-13  Electric Heat Pump, 66 gal, 3.35 UEF
# 153                         NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 162             Wood Stud, R-13  Electric Heat Pump, 80 gal, 3.45 UEF
# ...                         ...                                   ...
# 549882                      NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                      NaN  Electric Heat Pump, 80 gal, 3.45 UEF
# 549937          Wood Stud, R-13  Electric Heat Pump, 66 gal, 3.35 UEF
# 549963                      NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 549989          Wood Stud, R-13  Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 354 columns]

# %% [markdown]
# # Project Future Energy Consumption

# %%
from cmu_tare_model.energy_consumption_and_metadata.process_euss_data import df_enduse_compare

print(F"""
====================================================================================================================================================================
LOAD EUSS DATA FOR MEASURE PACKAGE {menu_mp} (MP{menu_mp})
====================================================================================================================================================================

RESULTING DATAFRAME:
""")

# df_enduse_compare(df_mp, category, df_baseline):
df_euss_am_mp10_home = df_enduse_compare(
    df_mp = df_euss_am_mp10,
    input_mp=input_mp,
    menu_mp=menu_mp,
    df_baseline = df_euss_am_baseline_home,
    df_cooking_range=df_euss_am_mp7,
    )
# Out:
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 10 (MP10)
# ====================================================================================================================================================================
#
# RESULTING DATAFRAME:
#
#
# Applying combined validation (data quality + retrofit status):
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
#   mp10_heating_consumption: Masked 3385 values
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
#   mp10_waterHeating_consumption: Masked 652 values
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
#   mp10_clothesDrying_consumption: Masked 908 values
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#   mp10_cooking_consumption: Masked 7784 values

# %%
if print_debug:
    # Create a sample dataframe for the heating category
    df_sample_heating = create_sample_df(
        df=df_euss_am_mp10_home,
        include_groups=['base_equipment'],
        categories=['heating'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_heating', 'valid_fuel_heating', 'valid_tech_heating', 'include_heating', 'heating_consumption']
    )
    print(df_sample_heating)

    # Create a sample dataframe for the waterHeating category
    df_sample_waterHeating = create_sample_df(
        df=df_euss_am_mp10_home,
        include_groups=['base_equipment'],
        categories=['waterHeating'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_waterHeating', 'valid_fuel_waterHeating', 'valid_tech_waterHeating', 'include_waterHeating', 'waterHeating_consumption']
    )
    print(df_sample_waterHeating)

    # Create a sample dataframe for the clothesDrying category
    df_sample_clothesDrying = create_sample_df(
        df=df_euss_am_mp10_home,
        include_groups=['base_equipment'],
        categories=['clothesDrying'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_clothesDrying', 'valid_fuel_clothesDrying', 'include_clothesDrying', 'clothesDrying_consumption']
    )
    print(df_sample_clothesDrying)

    # Create a sample dataframe for the cooking category
    df_sample_cooking = create_sample_df(
        df=df_euss_am_mp10_home,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', 'cooking_consumption']
    )
    print(df_sample_cooking)

# %% [markdown]
# # PUBLIC IMPACTS: Climate and Health Damages
# ## Scenarios: No IRA and IRA-Reference

# %%
from cmu_tare_model.public_impact.calculate_lifetime_climate_impacts_sensitivity import calculate_lifetime_climate_impacts
from cmu_tare_model.public_impact.calculate_lifetime_health_impacts_sensitivity import calculate_lifetime_health_impacts

print(f"""
====================================================================================================================================================================
PUBLIC IMPACTS: DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
====================================================================================================================================================================

""")

# Make copies from scenario consumption to keep df smaller
print("\n", "Creating dataframe to store marginal damages calculations ...")
# Climate damages: No IRA and IRA-Reference
df_mp10_noIRA_damages_climate = df_euss_am_mp10_home.copy()
df_mp10_IRA_damages_climate = df_euss_am_mp10_home.copy()

# Health damages: No IRA and IRA-Reference
df_mp10_noIRA_damages_health = df_euss_am_mp10_home.copy()
df_mp10_IRA_damages_health = df_euss_am_mp10_home.copy()
# Out:
# ====================================================================================================================================================================
# PUBLIC IMPACTS: DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
#
#
#
#  Creating dataframe to store marginal damages calculations ...

# %%
print("""
==================== SCENARIO: No Inflation Reduction Act ==========
""")
df_euss_am_mp10_home, df_mp10_noIRA_damages_climate = calculate_lifetime_climate_impacts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp, 
    policy_scenario='No Inflation Reduction Act', 
    df_baseline_damages=df_baseline_damages_climate,
    verbose=False  # Add this parameter
    )

df_euss_am_mp10_home, df_mp10_noIRA_damages_health = calculate_lifetime_health_impacts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp, 
    policy_scenario='No Inflation Reduction Act', 
    df_baseline_damages=df_baseline_damages_health,
    debug=False,
    verbose=False  # Add this parameter
    )


print("""
==================== SCENARIO: Inflation Reduction Act (AEO2023 Reference Case) ==========
""")
df_euss_am_mp10_home, df_mp10_IRA_damages_climate = calculate_lifetime_climate_impacts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp, 
    policy_scenario='AEO2023 Reference Case', 
    df_baseline_damages=df_baseline_damages_climate,
    verbose=False  # Add this parameter
    )


df_euss_am_mp10_home, df_mp10_IRA_damages_health = calculate_lifetime_health_impacts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp, 
    policy_scenario='AEO2023 Reference Case', 
    df_baseline_damages=df_baseline_damages_health,
    debug=False,
    verbose=False  # Add this parameter
    )


print(f"""  
====================================================================================================================================================================
Post-Retrofit (MP10) Marginal Damages: WHOLE-HOME
Scenario: No Inflation Reduction Act and AEO2023 Reference Case
====================================================================================================================================================================
calculate_emissions_damages.py file contains the definition for the calculate_marginal_damages function.
Additional information on emissions and damage factor lookups can be found in the calculate_emissions_damages.py file as well. 
      
CLIMATE DAMAGES: No IRA and IRA-Reference
--------------------------------------------------------
Climate Damages (No IRA): df_mp10_noIRA_damages_climate
{df_mp10_noIRA_damages_climate}

Climate Damages (IRA): df_mp10_IRA_damages_climate
{df_mp10_IRA_damages_climate}

HEALTH DAMAGES: No IRA and IRA-Reference
--------------------------------------------------------
Health Damages (No IRA): df_mp10_noIRA_damages_health
{df_mp10_noIRA_damages_health}

Health Damages (IRA): df_mp10_IRA_damages_health
{df_mp10_IRA_damages_health}

SUMMARY DATAFRAME FOR mp10: df_euss_am_mp10_home
{df_euss_am_mp10_home}
====================================================================================================================================================================
""")
# Out:
# ==================== SCENARIO: No Inflation Reduction Act ==========
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
#
# ==================== SCENARIO: Inflation Reduction Act (AEO2023 Reference Case) ==========
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
#
# ====================================================================================================================================================================
# Post-Retrofit (MP10) Marginal Damages: WHOLE-HOME
# Scenario: No Inflation Reduction Act and AEO2023 Reference Case
# ====================================================================================================================================================================
# calculate_emissions_damages.py file contains the definition for the calculate_marginal_damages function.
# Additional information on emissions and damage factor lookups can be found in the calculate_emissions_damages.py file as well.
#
# CLIMATE DAMAGES: No IRA and IRA-Reference
# --------------------------------------------------------
# Climate Damages (No IRA): df_mp10_noIRA_damages_climate
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          preIRA_mp10_cooking_avoided_damages_climate_lrmer_upper  \
# bldg_id
# 119                                                 166.95
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              120.55
# 549963                                                 NaN
# 549989                                              380.99
#
#          preIRA_mp10_cooking_avoided_mt_co2e_lrmer  \
# bldg_id
# 119                                           0.37
# 122                                            NaN
# 150                                            NaN
# 153                                            NaN
# 162                                            NaN
# ...                                            ...
# 549882                                         NaN
# 549915                                         NaN
# 549937                                        0.27
# 549963                                         NaN
# 549989                                        0.90
#
#          preIRA_mp10_cooking_lifetime_mt_co2e_srmer  \
# bldg_id
# 119                                            5.98
# 122                                             NaN
# 150                                             NaN
# 153                                             NaN
# 162                                             NaN
# ...                                             ...
# 549882                                          NaN
# 549915                                          NaN
# 549937                                         8.93
# 549963                                          NaN
# 549989                                         5.11
#
#          preIRA_mp10_cooking_lifetime_damages_climate_srmer_lower  \
# bldg_id
# 119                                                 440.52
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              658.13
# 549963                                                 NaN
# 549989                                              376.58
#
#          preIRA_mp10_cooking_avoided_damages_climate_srmer_lower  \
# bldg_id
# 119                                                -168.60
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -284.18
# 549963                                                 NaN
# 549989                                             -101.83
#
#          preIRA_mp10_cooking_lifetime_damages_climate_srmer_central  \
# bldg_id
# 119                                                1565.05
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             2338.49
# 549963                                                 NaN
# 549989                                             1337.88
#
#          preIRA_mp10_cooking_avoided_damages_climate_srmer_central  \
# bldg_id
# 119                                                -599.59
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1010.75
# 549963                                                 NaN
# 549989                                             -362.41
#
#          preIRA_mp10_cooking_lifetime_damages_climate_srmer_upper  \
# bldg_id
# 119                                                2485.36
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             3713.87
# 549963                                                 NaN
# 549989                                             2124.61
#
#          preIRA_mp10_cooking_avoided_damages_climate_srmer_upper  \
# bldg_id
# 119                                                -952.69
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1606.04
# 549963                                                 NaN
# 549989                                             -576.04
#
#          preIRA_mp10_cooking_avoided_mt_co2e_srmer
# bldg_id
# 119                                          -2.30
# 122                                            NaN
# 150                                            NaN
# 153                                            NaN
# 162                                            NaN
# ...                                            ...
# 549882                                         NaN
# 549915                                         NaN
# 549937                                       -3.87
# 549963                                         NaN
# 549989                                       -1.39
#
# [15651 rows x 515 columns]
#
# Climate Damages (IRA): df_mp10_IRA_damages_climate
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          iraRef_mp10_cooking_avoided_damages_climate_lrmer_upper  \
# bldg_id
# 119                                                 390.79
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              342.11
# 549963                                                 NaN
# 549989                                              572.34
#
#          iraRef_mp10_cooking_avoided_mt_co2e_lrmer  \
# bldg_id
# 119                                           0.93
# 122                                            NaN
# 150                                            NaN
# 153                                            NaN
# 162                                            NaN
# ...                                            ...
# 549882                                         NaN
# 549915                                         NaN
# 549937                                        0.81
# 549963                                         NaN
# 549989                                        1.37
#
#          iraRef_mp10_cooking_lifetime_mt_co2e_srmer  \
# bldg_id
# 119                                            5.25
# 122                                             NaN
# 150                                             NaN
# 153                                             NaN
# 162                                             NaN
# ...                                             ...
# 549882                                          NaN
# 549915                                          NaN
# 549937                                         7.30
# 549963                                          NaN
# 549989                                         4.49
#
#          iraRef_mp10_cooking_lifetime_damages_climate_srmer_lower  \
# bldg_id
# 119                                                 385.00
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              533.74
# 549963                                                 NaN
# 549989                                              329.12
#
#          iraRef_mp10_cooking_avoided_damages_climate_srmer_lower  \
# bldg_id
# 119                                                -113.08
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -159.79
# 549963                                                 NaN
# 549989                                              -54.37
#
#          iraRef_mp10_cooking_lifetime_damages_climate_srmer_central  \
# bldg_id
# 119                                                1369.47
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             1899.76
# 549963                                                 NaN
# 549989                                             1170.69
#
#          iraRef_mp10_cooking_avoided_damages_climate_srmer_central  \
# bldg_id
# 119                                                -404.01
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -572.02
# 549963                                                 NaN
# 549989                                             -195.22
#
#          iraRef_mp10_cooking_lifetime_damages_climate_srmer_upper  \
# bldg_id
# 119                                                2176.10
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             3019.70
# 549963                                                 NaN
# 549989                                             1860.24
#
#          iraRef_mp10_cooking_avoided_damages_climate_srmer_upper  \
# bldg_id
# 119                                                -643.43
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -911.87
# 549963                                                 NaN
# 549989                                             -311.67
#
#          iraRef_mp10_cooking_avoided_mt_co2e_srmer
# bldg_id
# 119                                          -1.57
# 122                                            NaN
# 150                                            NaN
# 153                                            NaN
# 162                                            NaN
# ...                                            ...
# 549882                                         NaN
# 549915                                         NaN
# 549937                                       -2.24
# 549963                                         NaN
# 549989                                       -0.77
#
# [15651 rows x 515 columns]
#
# HEALTH DAMAGES: No IRA and IRA-Reference
# --------------------------------------------------------
# Health Damages (No IRA): df_mp10_noIRA_damages_health
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          preIRA_mp10_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 437.20
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              199.62
# 549963                                                 NaN
# 549989                                              297.36
#
#          preIRA_mp10_cooking_avoided_damages_health_ap2_h6c  \
# bldg_id
# 119                                                -340.88
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -146.14
# 549963                                                 NaN
# 549989                                             -236.92
#
#          preIRA_mp10_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 197.71
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              103.71
# 549963                                                 NaN
# 549989                                              108.76
#
#          preIRA_mp10_cooking_avoided_damages_health_easiur_acs  \
# bldg_id
# 119                                                 -67.24
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -30.36
# 549963                                                 NaN
# 549989                                              -49.59
#
#          preIRA_mp10_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 507.98
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              266.46
# 549963                                                 NaN
# 549989                                              279.44
#
#          preIRA_mp10_cooking_avoided_damages_health_easiur_h6c  \
# bldg_id
# 119                                                -172.77
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -77.99
# 549963                                                 NaN
# 549989                                             -127.43
#
#          preIRA_mp10_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 128.43
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              104.39
# 549963                                                 NaN
# 549989                                              140.35
#
#          preIRA_mp10_cooking_avoided_damages_health_inmap_acs  \
# bldg_id
# 119                                                  19.66
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -53.91
# 549963                                                 NaN
# 549989                                              -83.14
#
#          preIRA_mp10_cooking_lifetime_damages_health_inmap_h6c  \
# bldg_id
# 119                                                 329.97
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              268.21
# 549963                                                 NaN
# 549989                                              360.59
#
#          preIRA_mp10_cooking_avoided_damages_health_inmap_h6c
# bldg_id
# 119                                                  50.53
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -138.53
# 549963                                                 NaN
# 549989                                             -213.60
#
# [15651 rows x 1379 columns]
#
# Health Damages (IRA): df_mp10_IRA_damages_health
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          iraRef_mp10_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 437.20
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              199.62
# 549963                                                 NaN
# 549989                                              297.36
#
#          iraRef_mp10_cooking_avoided_damages_health_ap2_h6c  \
# bldg_id
# 119                                                -340.88
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -146.14
# 549963                                                 NaN
# 549989                                             -236.92
#
#          iraRef_mp10_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 197.71
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              103.71
# 549963                                                 NaN
# 549989                                              108.76
#
#          iraRef_mp10_cooking_avoided_damages_health_easiur_acs  \
# bldg_id
# 119                                                 -67.24
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -30.36
# 549963                                                 NaN
# 549989                                              -49.59
#
#          iraRef_mp10_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 507.98
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              266.46
# 549963                                                 NaN
# 549989                                              279.44
#
#          iraRef_mp10_cooking_avoided_damages_health_easiur_h6c  \
# bldg_id
# 119                                                -172.77
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -77.99
# 549963                                                 NaN
# 549989                                             -127.43
#
#          iraRef_mp10_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 128.43
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              104.39
# 549963                                                 NaN
# 549989                                              140.35
#
#          iraRef_mp10_cooking_avoided_damages_health_inmap_acs  \
# bldg_id
# 119                                                  19.66
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -53.91
# 549963                                                 NaN
# 549989                                              -83.14
#
#          iraRef_mp10_cooking_lifetime_damages_health_inmap_h6c  \
# bldg_id
# 119                                                 329.97
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              268.21
# 549963                                                 NaN
# 549989                                              360.59
#
#          iraRef_mp10_cooking_avoided_damages_health_inmap_h6c
# bldg_id
# 119                                                  50.53
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -138.53
# 549963                                                 NaN
# 549989                                             -213.60
#
# [15651 rows x 1379 columns]
#
# SUMMARY DATAFRAME FOR mp10: df_euss_am_mp10_home
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp10_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 437.20
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              199.62
# 549963                                                 NaN
# 549989                                              297.36
#
#         iraRef_mp10_cooking_avoided_damages_health_ap2_h6c  \
# bldg_id
# 119                                                -340.88
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -146.14
# 549963                                                 NaN
# 549989                                             -236.92
#
#         iraRef_mp10_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 197.71
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              103.71
# 549963                                                 NaN
# 549989                                              108.76
#
#         iraRef_mp10_cooking_avoided_damages_health_easiur_acs  \
# bldg_id
# 119                                                 -67.24
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -30.36
# 549963                                                 NaN
# 549989                                              -49.59
#
#         iraRef_mp10_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 507.98
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              266.46
# 549963                                                 NaN
# 549989                                              279.44
#
#          iraRef_mp10_cooking_avoided_damages_health_easiur_h6c  \
# bldg_id
# 119                                                -172.77
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -77.99
# 549963                                                 NaN
# 549989                                             -127.43
#
#          iraRef_mp10_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 128.43
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              104.39
# 549963                                                 NaN
# 549989                                              140.35
#
#         iraRef_mp10_cooking_avoided_damages_health_inmap_acs  \
# bldg_id
# 119                                                  19.66
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -53.91
# 549963                                                 NaN
# 549989                                              -83.14
#
#         iraRef_mp10_cooking_lifetime_damages_health_inmap_h6c  \
# bldg_id
# 119                                                 329.97
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              268.21
# 549963                                                 NaN
# 549989                                              360.59
#
#         iraRef_mp10_cooking_avoided_damages_health_inmap_h6c
# bldg_id
# 119                                                  50.53
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -138.53
# 549963                                                 NaN
# 549989                                             -213.60
#
# [15651 rows x 391 columns]
# ====================================================================================================================================================================

# %%
if print_debug:
   # Create a sample dataframe for the heating category
    df_sample_heating = create_sample_df(
        df=df_euss_am_mp10_home,
        include_groups=['base_equipment'],
        categories=['heating'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_heating', 'valid_fuel_heating', 'include_heating', 'heating_lifetime_damages']
    )
    print(df_sample_heating)

    # Create a sample dataframe for the waterHeating category
    df_sample_waterHeating = create_sample_df(
        df=df_euss_am_mp10_home,
        include_groups=['base_equipment'],
        categories=['waterHeating'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_waterHeating', 'valid_fuel_waterHeating', 'include_waterHeating', 'waterHeating_lifetime_damages']
    )
    print(df_sample_waterHeating)

    # Create a sample dataframe for the clothesDrying category
    df_sample_clothesDrying = create_sample_df(
        df=df_euss_am_mp10_home,
        include_groups=['base_equipment'],
        categories=['clothesDrying'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_clothesDrying', 'valid_fuel_clothesDrying', 'include_clothesDrying', 'clothesDrying_lifetime_damages']
    )
    print(df_sample_clothesDrying)

    # Create a sample dataframe for the cooking category
    df_sample_cooking = create_sample_df(
        df=df_euss_am_mp10_home,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', 'cooking_lifetime_damages']
    )
    print(df_sample_cooking)

# %%
if print_debug:
    print("""
==================== SUMMARY DATAFRAME WITH LIFETIME DAMAGES ==========
""")
    # Create a sample dataframe for the heating category
    df_main_sample = create_sample_df(
        df=df_euss_am_mp10_home,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', 'cooking_lifetime_damages']
    )
    print(f"""
df_main_sample dataframe is created using df_euss_am_mp10_home:
-----------------------------------------------------------------------------

{df_main_sample}

-----------------------------------------------------------------------------
""")


    print("""
==================== CLIMATE IMPACTS WITH ANNUAL AND LIFETIME ==========
""")

    # Create a sample dataframe for the heating category
    df_detailed_climate_noIRA = create_sample_df(
        df=df_mp10_noIRA_damages_climate,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['preIRA'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', f'cooking_damages_health']
    )
    print(f"""
df_detailed_climate_noIRA dataframe is created using df_mp10_noIRA_damages_climate:
-----------------------------------------------------------------------------
          
{df_detailed_climate_noIRA}

-----------------------------------------------------------------------------
""")

    # Create a sample dataframe for the heating category
    df_detailed_climate_IRA = create_sample_df(
        df=df_mp10_IRA_damages_climate,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', f'cooking_damages_health']
    )
    print(f"""
df_detailed_climate_IRA dataframe is created using df_mp10_IRA_damages_climate:
-----------------------------------------------------------------------------
          
{df_detailed_climate_IRA}

-----------------------------------------------------------------------------
""")

    print("""
==================== HEALTH IMPACTS WITH ANNUAL AND LIFETIME ==========
""")
    # Create a sample dataframe for the heating category
    df_detailed_health_noIRA = create_sample_df(
        df=df_mp10_noIRA_damages_health,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['preIRA'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', f'cooking_damages_health']
    )
    print(f"""
df_detailed_health_noIRA dataframe is created using df_mp10_noIRA_damages_health:
-----------------------------------------------------------------------------
          
{df_detailed_health_noIRA}

-----------------------------------------------------------------------------
""")

    # Create a sample dataframe for the heating category
    df_detailed_health_IRA = create_sample_df(
        df=df_mp10_IRA_damages_health,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', f'cooking_damages_health']
    )
    print(f"""
df_detailed_health_IRA dataframe is created using df_mp10_IRA_damages_health:
-----------------------------------------------------------------------------
          
{df_detailed_health_IRA}

-----------------------------------------------------------------------------
""")

# %% [markdown]
# # PRIVATE IMPACTS: FUEL COSTS
# ## Scenarios: No IRA and IRA-Reference

# %%
from cmu_tare_model.private_impact.calculate_lifetime_fuel_costs import calculate_lifetime_fuel_costs

print(f"""
====================================================================================================================================================================
PRIVATE IMPACTS: OVERVIEW
====================================================================================================================================================================
Step 1: Calculate annual operating (fuel) costs
Step 2: Calculate equipment capital costs (For space heating, include ductwork and weatherization (MP10 and MP10))
Step 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)
Step 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)

----------------------------------------------------------------------------------------------------------------------
Step 1: Calculate annual operating (fuel) costs
----------------------------------------------------------------------------------------------------------------------

====================================================================================================================================================================
FUEL COSTS RESULTS: No IRA and IRA-Reference

""")

print("\n", "Creating dataframe to store annual fuel cost calculations ...")
# Annual fuel costs: No IRA and IRA-Reference
df_mp10_fuel_costs_noIRA = df_euss_am_mp10_home.copy()
df_mp10_fuel_costs_IRA = df_euss_am_mp10_home.copy()
# Out:
# ====================================================================================================================================================================
# PRIVATE IMPACTS: OVERVIEW
# ====================================================================================================================================================================
# Step 1: Calculate annual operating (fuel) costs
# Step 2: Calculate equipment capital costs (For space heating, include ductwork and weatherization (MP10 and MP10))
# Step 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)
# Step 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
#
# ----------------------------------------------------------------------------------------------------------------------
# Step 1: Calculate annual operating (fuel) costs
# ----------------------------------------------------------------------------------------------------------------------
#
# ====================================================================================================================================================================
# FUEL COSTS RESULTS: No IRA and IRA-Reference
#
#
#
#  Creating dataframe to store annual fuel cost calculations ...

# %%
print("""
==================== SCENARIO: No Inflation Reduction Act ==========
""")
df_euss_am_mp10_home, df_mp10_noIRA_fuel_costs = calculate_lifetime_fuel_costs(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    df_baseline_costs=df_baseline_fuel_costs  # Add this line
    )

print("""
==================== SCENARIO: Inflation Reduction Act (AEO2023 Reference Case) ==========
""")
df_euss_am_mp10_home, df_mp10_IRA_fuel_costs = calculate_lifetime_fuel_costs(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    df_baseline_costs=df_baseline_fuel_costs  # Add this line
    )


print(f"""  
====================================================================================================================================================================
Creating Dataframes for Lifetime Fuel Costs ...

FUEL COSTS (No IRA): df_mp10_noIRA_fuel_costs
{df_mp10_noIRA_fuel_costs}

FUEL COSTS (IRA): df_mp10_IRA_fuel_costs
{df_mp10_IRA_fuel_costs}

SUMMARY DATAFRAME FOR mp10: df_euss_am_mp10_home
{df_euss_am_mp10_home}

====================================================================================================================================================================
""")
# Out:
# ==================== SCENARIO: No Inflation Reduction Act ==========
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# Calculating Fuel Costs from 2024 to 2039 for heating
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2036 for waterHeating
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2037 for clothesDrying
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2039 for cooking
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'heating'
# Masking 1 columns for category 'waterHeating'
# Masking 1 columns for category 'clothesDrying'
# Masking 3 columns for category 'cooking'
# WARNING: Replacing 4 existing columns. Function was called on data that already contains results.
# Columns being replaced: ['baseline_heating_lifetime_fuel_cost', 'baseline_waterHeating_lifetime_fuel_cost', 'baseline_clothesDrying_lifetime_fuel_cost', 'baseline_cooking_lifetime_fuel_cost']
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'heating'
# Masking 1 columns for category 'waterHeating'
# Masking 1 columns for category 'clothesDrying'
# Masking 48 columns for category 'cooking'
#
# ==================== SCENARIO: Inflation Reduction Act (AEO2023 Reference Case) ==========
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# Calculating Fuel Costs from 2024 to 2039 for heating
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2036 for waterHeating
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2037 for clothesDrying
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2039 for cooking
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'heating'
# Masking 1 columns for category 'waterHeating'
# Masking 1 columns for category 'clothesDrying'
# Masking 3 columns for category 'cooking'
# WARNING: Replacing 4 existing columns. Function was called on data that already contains results.
# Columns being replaced: ['baseline_heating_lifetime_fuel_cost', 'baseline_waterHeating_lifetime_fuel_cost', 'baseline_clothesDrying_lifetime_fuel_cost', 'baseline_cooking_lifetime_fuel_cost']
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'heating'
# Masking 1 columns for category 'waterHeating'
# Masking 1 columns for category 'clothesDrying'
# Masking 48 columns for category 'cooking'
#
# ====================================================================================================================================================================
# Creating Dataframes for Lifetime Fuel Costs ...
#
# FUEL COSTS (No IRA): df_mp10_noIRA_fuel_costs
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  baseline_2035_cooking_fuel_cost  \
# bldg_id                            ...
# 119                          True  ...                            39.02
# 122                          True  ...                              NaN
# 150                          True  ...                              NaN
# 153                         False  ...                              NaN
# 162                          True  ...                              NaN
# ...                           ...  ...                              ...
# 549882                       True  ...                              NaN
# 549915                       True  ...                              NaN
# 549937                       True  ...                            53.07
# 549963                       True  ...                              NaN
# 549989                       True  ...                           115.40
#
#          preIRA_mp10_2036_cooking_fuel_cost  baseline_2036_cooking_fuel_cost  \
# bldg_id
# 119                                   86.54                            38.84
# 122                                     NaN                              NaN
# 150                                     NaN                              NaN
# 153                                     NaN                              NaN
# 162                                     NaN                              NaN
# ...                                     ...                              ...
# 549882                                  NaN                              NaN
# 549915                                  NaN                              NaN
# 549937                               117.60                            52.84
# 549963                                  NaN                              NaN
# 549989                                73.98                           116.58
#
#          preIRA_mp10_2037_cooking_fuel_cost  baseline_2037_cooking_fuel_cost  \
# bldg_id
# 119                                   87.04                            39.25
# 122                                     NaN                              NaN
# 150                                     NaN                              NaN
# 153                                     NaN                              NaN
# 162                                     NaN                              NaN
# ...                                     ...                              ...
# 549882                                  NaN                              NaN
# 549915                                  NaN                              NaN
# 549937                               118.27                            53.38
# 549963                                  NaN                              NaN
# 549989                                74.40                           117.97
#
#          preIRA_mp10_2038_cooking_fuel_cost  baseline_2038_cooking_fuel_cost  \
# bldg_id
# 119                                   87.81                            39.49
# 122                                     NaN                              NaN
# 150                                     NaN                              NaN
# 153                                     NaN                              NaN
# 162                                     NaN                              NaN
# ...                                     ...                              ...
# 549882                                  NaN                              NaN
# 549915                                  NaN                              NaN
# 549937                               119.32                            53.71
# 549963                                  NaN                              NaN
# 549989                                75.06                           119.31
#
#          preIRA_mp10_cooking_lifetime_fuel_cost  \
# bldg_id
# 119                                     1240.31
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                  1685.42
# 549963                                      NaN
# 549989                                  1060.28
#
#          preIRA_mp10_cooking_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                             -650.47
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                          -883.13
# 549963                                              NaN
# 549989                                           631.27
#
#          baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                   589.84
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                802.29
# 549963                                   NaN
# 549989                               1691.55
#
# [15651 rows x 133 columns]
#
# FUEL COSTS (IRA): df_mp10_IRA_fuel_costs
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  baseline_2035_cooking_fuel_cost  \
# bldg_id                            ...
# 119                          True  ...                            39.02
# 122                          True  ...                              NaN
# 150                          True  ...                              NaN
# 153                         False  ...                              NaN
# 162                          True  ...                              NaN
# ...                           ...  ...                              ...
# 549882                       True  ...                              NaN
# 549915                       True  ...                              NaN
# 549937                       True  ...                            53.07
# 549963                       True  ...                              NaN
# 549989                       True  ...                           115.40
#
#          iraRef_mp10_2036_cooking_fuel_cost  baseline_2036_cooking_fuel_cost  \
# bldg_id
# 119                                   84.01                            38.84
# 122                                     NaN                              NaN
# 150                                     NaN                              NaN
# 153                                     NaN                              NaN
# 162                                     NaN                              NaN
# ...                                     ...                              ...
# 549882                                  NaN                              NaN
# 549915                                  NaN                              NaN
# 549937                               114.15                            52.84
# 549963                                  NaN                              NaN
# 549989                                71.81                           116.58
#
#          iraRef_mp10_2037_cooking_fuel_cost  baseline_2037_cooking_fuel_cost  \
# bldg_id
# 119                                   84.44                            39.25
# 122                                     NaN                              NaN
# 150                                     NaN                              NaN
# 153                                     NaN                              NaN
# 162                                     NaN                              NaN
# ...                                     ...                              ...
# 549882                                  NaN                              NaN
# 549915                                  NaN                              NaN
# 549937                               114.74                            53.38
# 549963                                  NaN                              NaN
# 549989                                72.18                           117.97
#
#          iraRef_mp10_2038_cooking_fuel_cost  baseline_2038_cooking_fuel_cost  \
# bldg_id
# 119                                   85.44                            39.49
# 122                                     NaN                              NaN
# 150                                     NaN                              NaN
# 153                                     NaN                              NaN
# 162                                     NaN                              NaN
# ...                                     ...                              ...
# 549882                                  NaN                              NaN
# 549915                                  NaN                              NaN
# 549937                               116.10                            53.71
# 549963                                  NaN                              NaN
# 549989                                73.04                           119.31
#
#          iraRef_mp10_cooking_lifetime_fuel_cost  \
# bldg_id
# 119                                     1214.19
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                  1649.94
# 549963                                      NaN
# 549989                                  1037.95
#
#          iraRef_mp10_cooking_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                             -624.35
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                          -847.65
# 549963                                              NaN
# 549989                                           653.60
#
#          baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                   589.84
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                802.29
# 549963                                   NaN
# 549989                               1691.55
#
# [15651 rows x 133 columns]
#
# SUMMARY DATAFRAME FOR mp10: df_euss_am_mp10_home
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                 9692.04
# 122                                56634.48
# 150                                48835.85
# 153                                52691.10
# 162                                69001.23
# ...                                     ...
# 549882                                  NaN
# 549915                             52898.91
# 549937                              8456.00
# 549963                             17473.34
# 549989                             22285.90
#
#         iraRef_mp10_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                         1546.94
# 122                                          803.72
# 150                                          850.57
# 153                                         3478.24
# 162                                         1264.00
# ...                                             ...
# 549882                                      2614.62
# 549915                                      2529.79
# 549937                                      4097.48
# 549963                                      1234.35
# 549989                                      1293.06
#
#         iraRef_mp10_waterHeating_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                                 752.61
# 122                                                2142.78
# 150                                                1913.88
# 153                                                9253.82
# 162                                                 606.10
# ...                                                    ...
# 549882                                             -179.49
# 549915                                             7496.47
# 549937                                             1661.02
# 549963                                              682.90
# 549989                                             3571.19
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         iraRef_mp10_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                           606.34
# 122                                           315.42
# 150                                           365.73
# 153                                              NaN
# 162                                          1130.75
# ...                                              ...
# 549882                                        507.65
# 549915                                        883.71
# 549937                                       1696.46
# 549963                                        457.34
# 549989                                        457.34
#
#          iraRef_mp10_clothesDrying_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                                -255.32
# 122                                                 303.86
# 150                                                 352.91
# 153                                                    NaN
# 162                                                1091.66
# ...                                                    ...
# 549882                                              489.37
# 549915                                              852.36
# 549937                                             -714.19
# 549963                                              440.97
# 549989                                              440.97
#
#          baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                         351.02
# 122                                         619.28
# 150                                         718.64
# 153                                            NaN
# 162                                        2222.41
# ...                                            ...
# 549882                                      997.02
# 549915                                     1736.07
# 549937                                      982.27
# 549963                                      898.31
# 549989                                      898.31
#
#         iraRef_mp10_cooking_lifetime_fuel_cost  \
# bldg_id
# 119                                    1214.19
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                 1649.94
# 549963                                     NaN
# 549989                                 1037.95
#
#         iraRef_mp10_cooking_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                            -624.35
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                         -847.65
# 549963                                             NaN
# 549989                                          653.60
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 407 columns]
#
# ====================================================================================================================================================================

# %%
if print_debug:
    # Create a sample dataframe for the heating category
    df_main_sample = create_sample_df(
        df=df_euss_am_mp10_home,
        include_groups=['base_equipment', 'costs'],
        categories=['cooking'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', 'cooking_lifetime_fuel_cost']
    )
    print(f"""
df_main_sample dataframe is created using df_euss_am_mp10_home:
-----------------------------------------------------------------------------

{df_main_sample}

-----------------------------------------------------------------------------
""")

    # Create a sample dataframe for the heating category
    df_detailed_test = create_sample_df(
        df=df_mp10_IRA_fuel_costs,
        include_groups=['base_equipment', 'costs'],
        categories=['cooking'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', f'_fuel_cost']
    )
    print(f"""
df_detailed_test dataframe is created using df_mp10_IRA_fuel_costs:
-----------------------------------------------------------------------------
          
{df_detailed_test}

-----------------------------------------------------------------------------
""")

    # # Create a sample dataframe for the waterHeating category
    # df_sample_waterHeating = create_sample_df(
    #     df=df_euss_am_mp10_home,
    #     include_groups=['base_equipment', 'costs'],
    #     categories=['waterHeating'],
    #     scenarios=['preIRA', 'iraRef'],
    #     metrics=[],
    #     mp_number=menu_mp,
    #     regex_patterns=['upgrade_waterHeating', 'valid_fuel_waterHeating', 'include_waterHeating', 'waterHeating_lifetime_fuel_cost']
    # )
    # print(df_sample_waterHeating)

    # # Create a sample dataframe for the clothesDrying category
    # df_sample_clothesDrying = create_sample_df(
    #     df=df_euss_am_mp10_home,
    #     include_groups=['base_equipment', 'costs'],
    #     categories=['clothesDrying'],
    #     scenarios=['preIRA', 'iraRef'],
    #     metrics=[],
    #     mp_number=menu_mp,
    #     regex_patterns=['upgrade_clothesDrying', 'valid_fuel_clothesDrying', 'include_clothesDrying', 'clothesDrying_lifetime_fuel_cost']
    # )
    # print(df_sample_clothesDrying)

    # # Create a sample dataframe for the cooking category
    # df_sample_cooking = create_sample_df(
    #     df=df_euss_am_mp10_home,
    #     include_groups=['base_equipment', 'costs'],
    #     categories=['cooking'],
    #     scenarios=['preIRA', 'iraRef'],
    #     metrics=[],
    #     mp_number=menu_mp,
    #     regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', 'cooking_lifetime_fuel_cost']
    # )
    # print(df_sample_cooking)

# %% [markdown]
# # PRIVATE IMPACTS: CAPITAL COSTS
# ## Scenarios: No IRA and IRA-Reference

# %%
from cmu_tare_model.utils.inflation_adjustment import *
from cmu_tare_model.private_impact.calculations.calculate_equipment_installation_costs import (
    obtain_heating_system_specs,
    calculate_heating_installation_premium,
    calculate_installation_cost
    )
from cmu_tare_model.private_impact.calculations.calculate_equipment_replacement_costs import (
    calculate_replacement_cost
)
from cmu_tare_model.private_impact.calculations.calculate_enclosure_upgrade_costs import calculate_enclosure_retrofit_upgradeCosts

print(f"""
====================================================================================================================================================================
PRIVATE IMPACTS: NET CAPITAL COSTS AND TOTAL CAPITAL COSTS
====================================================================================================================================================================
Step 1: Calculate annual operating (fuel) costs                                                     [COMPLETED]
Step 2: Calculate equipment capital costs (For space heating, include ductwork)
Step 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)

-----------------------------------------------------------------------------------------------------------------------
Step 4 (MP9 AND MP10 SPACE HEATING ONLY): Calculate Enclosure Upgrade Costs

FOR MODERATE (MP9) AND ADVANCED (MP10) ONLY:
calculate_enclosure_upgrade_costs.py file contains the definition for the calculate_enclosure_upgrade_costs function.

NOTE: Total enclosure upgrade costs were originally calculated using another function that employed a data validation framework.
      However, NaN values for these columns are later set to zero in private impact calculations.
      We decided to keep things simple and avoid side effects by using the original approach.

Documentation for calculate_enclosure_upgrade_costs function:
{calculate_enclosure_retrofit_upgradeCosts.__doc__}

====================================================================================================================================================================
LIFETIME CAPITAL COSTS RESULTS: No IRA and IRA-Reference (Rebates)

""")
# Out:
# ====================================================================================================================================================================
# PRIVATE IMPACTS: NET CAPITAL COSTS AND TOTAL CAPITAL COSTS
# ====================================================================================================================================================================
# Step 1: Calculate annual operating (fuel) costs                                                     [COMPLETED]
# Step 2: Calculate equipment capital costs (For space heating, include ductwork)
# Step 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)
#
# -----------------------------------------------------------------------------------------------------------------------
# Step 4 (MP9 AND MP10 SPACE HEATING ONLY): Calculate Enclosure Upgrade Costs
#
# FOR MODERATE (MP9) AND ADVANCED (MP10) ONLY:
# calculate_enclosure_upgrade_costs.py file contains the definition for the calculate_enclosure_upgrade_costs function.
#
# NOTE: Total enclosure upgrade costs were originally calculated using another function that employed a data validation framework.
#       However, NaN values for these columns are later set to zero in private impact calculations.
#       We decided to keep things simple and avoid side effects by using the original approach.
#
# Documentation for calculate_enclosure_upgrade_costs function:
#
#     Calculate the enclosure retrofit upgrade costs based on given parameters and conditions.
#
#     This function uses a probabilistic approach to sample costs from distributions defined
#     by progressive, reference, and conservative estimates. It applies data validation to
#     ensure only valid homes are included in calculations.
#
#     Args:
#         df: DataFrame containing data for different scenarios
#         menu_mp: Measure package identifier (0 for baseline, 8/9/10 for retrofits)
#         cost_dict: Dictionary with cost information for different technology and efficiency combinations
#         retrofit_col: Column name for the retrofit cost to be calculated
#         params_col: Column name for the parameter to use in the cost calculation
#
#     Returns:
#         Updated DataFrame with calculated retrofit costs
#
#     Raises:
#         ValueError: If missing cost data for certain technology and efficiency combinations
#         RuntimeError: If an unexpected error occurs during calculation
#
#     Notes:
#         This function implements the validation framework:
#         1. Uses initialize_validation_tracking() to determine valid homes
#         2. Creates retrofit-only series with NaN for invalid homes
#         3. Calculates values only for valid homes with identifiable technology
#         4. Applies final verification masking
#
#
# ====================================================================================================================================================================
# LIFETIME CAPITAL COSTS RESULTS: No IRA and IRA-Reference (Rebates)

# %%
# Collect Capital Cost Data for different End-uses
filename = "tare_retrofit_costs_cpi.xlsx"
relative_path = os.path.join("cmu_tare_model", "data", "retrofit_costs", filename)
file_path = os.path.join(PROJECT_ROOT, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_heating_retrofit_costs = pd.read_excel(io=file_path, sheet_name='heating_costs')
df_waterHeating_retrofit_costs = pd.read_excel(io=file_path, sheet_name='waterHeating_costs')
df_clothesDrying_retrofit_costs = pd.read_excel(io=file_path, sheet_name='clothesDrying_costs')
df_cooking_retrofit_costs = pd.read_excel(io=file_path, sheet_name='cooking_costs')
df_enclosure_retrofit_costs = pd.read_excel(io=file_path, sheet_name='enclosure_upgrade_costs')
# Out:
# Retrieved data for filename: tare_retrofit_costs_cpi.xlsx
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\retrofit_costs\tare_retrofit_costs_cpi.xlsx

# %% [markdown]
# ### Advanced Retrofit (MP10): High-Efficiency Space Heating (MP8) + Enhanced Enclosure Upgrade (MP2)

# %% [markdown]
# #### Space Heating Capital Costs

# %%
print("""
========================== Capital Costs: Space Heating ==========================

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
""")

# Columns to update
cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
    'cost_per_kBtuh_progressive', 'cost_per_kBtuh_reference', 'cost_per_kBtuh_conservative',
    'otherCost_progressive', 'otherCost_reference', 'otherCost_conservative'
]

# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_heating_retrofit_costs[column] = round((df_heating_retrofit_costs[column] * df_heating_retrofit_costs['cpi_ratio'] * df_heating_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_heating_equipment_cost = df_heating_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')

# Call the function and obtain equipment specifications
print("Obtaining heating system specs ...")
df_euss_am_mp10_home = obtain_heating_system_specs(df=df_euss_am_mp10_home)

# calculate_installation_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Heat Pump for Space Heating ...")
df_euss_am_mp10_home = calculate_installation_cost(
    df=df_euss_am_mp10_home,
    cost_dict=dict_heating_equipment_cost,
    menu_mp=menu_mp,
    end_use='heating'
    )

# calculate_replacement_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
df_euss_am_mp10_home = calculate_replacement_cost(
    df=df_euss_am_mp10_home,
    cost_dict=dict_heating_equipment_cost,
    menu_mp=menu_mp,
    end_use='heating'
    )

# Call the function and calculate installation premium based on existing housing characteristics
# calculate_heating_installation_premium(df, menu_mp, cpi_ratio_2023_2013)
print("Calculating Space Heating Specific Premiums (Ex: Removing Hydronic Boiler) ...")
df_euss_am_mp10_home = calculate_heating_installation_premium(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp,
    cpi_ratio_2023_2013=cpi_ratio_2023_2013
    )

# Display the df
print(df_euss_am_mp10_home)
# Out:
# ========================== Capital Costs: Space Heating ==========================
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
#
# Obtaining heating system specs ...
# Calculating Cost of Retrofit Upgrade: Heat Pump for Space Heating ...
# Starting heating installation cost calculation with validation framework
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for heating installation
# After tech filtering: 12266 homes remain valid for heating installation
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'heating'
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
# Starting heating replacement cost calculation with validation framework
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for heating replacement
# After tech filtering: 12266 homes remain valid for heating replacement
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating Space Heating Specific Premiums (Ex: Removing Hydronic Boiler) ...
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp10_cooking_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                            -624.35
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                         -847.65
# 549963                                             NaN
# 549989                                          653.60
#
#         baseline_cooking_lifetime_fuel_cost total_heating_load_kBtuh  \
# bldg_id
# 119                                  589.84                    55.96
# 122                                     NaN                    89.04
# 150                                     NaN                    52.30
# 153                                     NaN                    92.00
# 162                                     NaN                    59.70
# ...                                     ...                      ...
# 549882                                  NaN                    99.30
# 549915                                  NaN                    70.03
# 549937                               802.29                    44.92
# 549963                                  NaN                    67.53
# 549989                              1691.55                    32.10
#
#         baseline_AFUE baseline_SEER  baseline_HSPF  ugrade_newInstall_HSPF  \
# bldg_id
# 119              80.0           NaN            NaN                    13.0
# 122              92.5           NaN            NaN                    13.0
# 150             100.0           NaN            NaN                    14.0
# 153              80.0           NaN            NaN                    13.0
# 162              80.0           NaN            NaN                    13.0
# ...               ...           ...            ...                     ...
# 549882           68.0           NaN            NaN                    14.0
# 549915          100.0           NaN            NaN                    13.0
# 549937           92.5           NaN            NaN                    13.0
# 549963           80.0           NaN            NaN                    13.0
# 549989           80.0           NaN            NaN                    13.0
#
#         mp10_heating_installationCost mp10_heating_replacementCost  \
# bldg_id
# 119                          21213.42                      3555.34
# 122                          24413.95                      5816.80
# 150                          12845.64                      5513.18
# 153                          23356.98                      5831.90
# 162                          23911.56                      5667.17
# ...                               ...                          ...
# 549882                            NaN                          NaN
# 549915                       23546.58                      6672.72
# 549937                       20971.31                      3499.03
# 549963                       22663.07                      3614.34
# 549989                       15850.48                      5526.41
#
#         mp10_heating_installation_premium
# bldg_id
# 119                                   0.0
# 122                                   0.0
# 150                                   0.0
# 153                                   0.0
# 162                                   0.0
# ...                                   ...
# 549882                                0.0
# 549915                                0.0
# 549937                                0.0
# 549963                                0.0
# 549989                                0.0
#
# [15651 rows x 415 columns]

# %% [markdown]
# #### Weatherization (MP1: Basic Enclosure Upgrade) Capital Costs

# %%
print(f"""
-------------------------------------------------------------------------------------------------
BASIC ENCLOSURE UPGRADE (MP1)
-------------------------------------------------------------------------------------------------
Measure Package 9 (MP9) contains the Basic Enclosure Upgrade (MP1), with the following upgrades: 
    - Attic Floor Insulation
    - Infiltration Reduction
    - Duct Sealing
    - Drill and Fill Wall Insulation      

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...

""")
# Weatherization Capital Costs
cost_columns = [
    'normalized_cost_progressive', 'normalized_cost_reference', 'normalized_cost_conservative',
]

# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_enclosure_retrofit_costs[column] = round((df_enclosure_retrofit_costs[column] * df_enclosure_retrofit_costs['cpi_ratio'] * df_enclosure_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_enclosure_retrofit_cost = df_enclosure_retrofit_costs.set_index(['technology', 'existing_characteristic']).to_dict(orient='index')

# ATTIC FLOOR INSULATION
df_euss_am_mp10_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='insulation_atticFloor_upgradeCost',
    params_col='out_params_floor_area_attic_ft_2'
    )

# INFILTRATION REDUCTION
df_euss_am_mp10_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='infiltration_reduction_upgradeCost',
    params_col='square_footage'
    )

# DUCT SEALING
df_euss_am_mp10_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='duct_sealing_upgradeCost',
    params_col='out_params_duct_unconditioned_surface_area_ft_2'
    )

# DRILL AND FILL WALL INSULATION
df_euss_am_mp10_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='insulation_wall_upgradeCost',
    params_col='out_params_wall_area_above_grade_exterior_ft_2'
    )

# Calculate the total upgrade cost
print("Calculating the total cost of a Basic Enclosure Upgrade (MP1) ...")
mp9_total_enclosure_upgradeCost = (
    df_euss_am_mp10_home['insulation_atticFloor_upgradeCost'].fillna(0.0) +
    df_euss_am_mp10_home['infiltration_reduction_upgradeCost'].fillna(0.0) +
    df_euss_am_mp10_home['duct_sealing_upgradeCost'].fillna(0.0) +
    df_euss_am_mp10_home['insulation_wall_upgradeCost'].fillna(0.0)
    )
df_euss_am_mp10_home['mp9_enclosure_upgradeCost'] = round(mp9_total_enclosure_upgradeCost, 2)
# Out:
# -------------------------------------------------------------------------------------------------
# BASIC ENCLOSURE UPGRADE (MP1)
# -------------------------------------------------------------------------------------------------
# Measure Package 9 (MP9) contains the Basic Enclosure Upgrade (MP1), with the following upgrades:
#     - Attic Floor Insulation
#     - Infiltration Reduction
#     - Duct Sealing
#     - Drill and Fill Wall Insulation
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
#
#
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): insulation_atticFloor_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for insulation_atticFloor_upgradeCost
# After tech filtering: 11255 homes remain valid for insulation_atticFloor_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): infiltration_reduction_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for infiltration_reduction_upgradeCost
# After tech filtering: 8553 homes remain valid for infiltration_reduction_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): duct_sealing_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for duct_sealing_upgradeCost
# After tech filtering: 5388 homes remain valid for duct_sealing_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): insulation_wall_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for insulation_wall_upgradeCost
# After tech filtering: 2933 homes remain valid for insulation_wall_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating the total cost of a Basic Enclosure Upgrade (MP1) ...

# %%
print(f"""
-------------------------------------------------------------------------------------------------
Enhanced Enclosure Upgrade (MP2)
-------------------------------------------------------------------------------------------------
Enhanced Enclosure Upgrade (MP2) includes everything in Basic Enclosure Upgrade (MP1) plus:
    - Foundation Wall Insulation
    - Rim Joist Insulation
    - Seal Crawlspace
    - Roof Insulation (Finished Attics and Cathedral Ceilings)     

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...

""")
# INSULATE FOUNDATION WALLS
df_euss_am_mp10_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='insulation_foundation_wall_upgradeCost',
    params_col='out_params_floor_area_foundation_ft_2'
    )

# INSULATE RIM JOISTS
df_euss_am_mp10_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='insulation_rim_joist_upgradeCost',
    params_col='out_params_rim_joist_area_above_grade_exterior_ft_2'
    )

# SEAL CRAWLSPACE
df_euss_am_mp10_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='seal_crawlspace_upgradeCost',
    params_col='out_params_floor_area_foundation_ft_2'
    )

# INSULATE FINISHED ATTICS AND CATHEDRAL CEILINGS
df_euss_am_mp10_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp10_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='insulation_roof_upgradeCost',
    params_col='out_params_roof_area_ft_2'
    )

print("Calculating the total cost of an Enhanced Enclosure Upgrade (MP2) ...")
mp10_total_enclosure_upgradeCost = (
    df_euss_am_mp10_home[f'mp9_enclosure_upgradeCost'].fillna(0.0) +
    df_euss_am_mp10_home[f'insulation_foundation_wall_upgradeCost'].fillna(0.0) +
    df_euss_am_mp10_home[f'insulation_rim_joist_upgradeCost'].fillna(0.0) +
    df_euss_am_mp10_home[f'seal_crawlspace_upgradeCost'].fillna(0.0) +
    df_euss_am_mp10_home[f'insulation_roof_upgradeCost'].fillna(0.0)
    )
df_euss_am_mp10_home['mp10_enclosure_upgradeCost'] = round(mp10_total_enclosure_upgradeCost, 2)

print(f"""  
-------------------------------------------------------------------------------------------------
DATAFRAME WITH MP10 ENCLOSURE COSTS: df_euss_am_mp10_home
      
{df_euss_am_mp10_home}

====================================================================================================================================================================
""")
# Out:
# -------------------------------------------------------------------------------------------------
# Enhanced Enclosure Upgrade (MP2)
# -------------------------------------------------------------------------------------------------
# Enhanced Enclosure Upgrade (MP2) includes everything in Basic Enclosure Upgrade (MP1) plus:
#     - Foundation Wall Insulation
#     - Rim Joist Insulation
#     - Seal Crawlspace
#     - Roof Insulation (Finished Attics and Cathedral Ceilings)
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
#
#
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): insulation_foundation_wall_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for insulation_foundation_wall_upgradeCost
# After tech filtering: 2303 homes remain valid for insulation_foundation_wall_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): insulation_rim_joist_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for insulation_rim_joist_upgradeCost
# After tech filtering: 5115 homes remain valid for insulation_rim_joist_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): seal_crawlspace_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for seal_crawlspace_upgradeCost
# After tech filtering: 2119 homes remain valid for seal_crawlspace_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): insulation_roof_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for insulation_roof_upgradeCost
# After tech filtering: 64 homes remain valid for insulation_roof_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating the total cost of an Enhanced Enclosure Upgrade (MP2) ...
#
# -------------------------------------------------------------------------------------------------
# DATAFRAME WITH MP10 ENCLOSURE COSTS: df_euss_am_mp10_home
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         insulation_atticFloor_upgradeCost infiltration_reduction_upgradeCost  \
# bldg_id
# 119                               3582.38                               0.00
# 122                              11814.33                            7970.68
# 150                               5435.20                            3607.33
# 153                               7819.36                            5069.46
# 162                               3814.21                            5727.57
# ...                                   ...                                ...
# 549882                                NaN                                NaN
# 549915                            3426.83                            4099.01
# 549937                               0.00                            2032.44
# 549963                               0.00                               0.00
# 549989                             984.37                               0.00
#
#         duct_sealing_upgradeCost insulation_wall_upgradeCost  \
# bldg_id
# 119                         0.00                        0.00
# 122                      2368.07                     7937.87
# 150                         0.00                     6052.47
# 153                      1721.89                        0.00
# 162                      2032.27                     5860.22
# ...                          ...                         ...
# 549882                       NaN                         NaN
# 549915                   1907.38                        0.00
# 549937                      0.00                     3279.56
# 549963                      0.00                        0.00
# 549989                      0.00                     3645.83
#
#         mp9_enclosure_upgradeCost  insulation_foundation_wall_upgradeCost  \
# bldg_id
# 119                       3582.38                                 7614.46
# 122                      30090.95                                    0.00
# 150                      15095.00                                11291.03
# 153                      14610.71                                    0.00
# 162                      17434.27                                12368.51
# ...                           ...                                     ...
# 549882                       0.00                                     NaN
# 549915                    9433.22                                 4877.34
# 549937                    5312.00                                    0.00
# 549963                       0.00                                 9786.53
# 549989                    4630.20                                    0.00
#
#          insulation_rim_joist_upgradeCost seal_crawlspace_upgradeCost  \
# bldg_id
# 119                                492.46                     2637.02
# 122                                  0.00                        0.00
# 150                                489.32                     1913.91
# 153                                  0.00                        0.00
# 162                                447.30                     2828.90
# ...                                   ...                         ...
# 549882                                NaN                         NaN
# 549915                             310.86                      935.62
# 549937                             196.12                        0.00
# 549963                             505.27                     2642.82
# 549989                             168.25                        0.00
#
#         insulation_roof_upgradeCost mp10_enclosure_upgradeCost
# bldg_id
# 119                             0.0                   14326.32
# 122                             0.0                   30090.95
# 150                             0.0                   28789.26
# 153                             0.0                   14610.71
# 162                             0.0                   33078.98
# ...                             ...                        ...
# 549882                          NaN                       0.00
# 549915                          0.0                   15557.04
# 549937                          0.0                    5508.12
# 549963                          0.0                   12934.62
# 549989                          0.0                    4798.45
#
# [15651 rows x 425 columns]
#
# ====================================================================================================================================================================

# %%
if print_debug:
    # Create a sample dataframe for the heating category
    df_sample_heating = create_sample_df(
        df=df_euss_am_mp10_home,
        include_groups=['base_equipment'],
        categories=['heating'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['valid_fuel_heating', 'include_heating', 'baseline_AFUE', 'baseline_SEER', 'baseline_HSPF', 
                        'hvac_heating_efficiency', 'upgrade_hvac_', 'upgrade_heating','ugrade_newInstall_HSPF']
    )
    print(df_sample_heating)

# %% [markdown]
# ### Water Heating

# %%
print("""
========================== Capital Costs: Water Heating ==========================

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
""")

cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
    'cost_per_gallon_progressive', 'cost_per_gallon_reference', 'cost_per_gallon_conservative',
]

# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_waterHeating_retrofit_costs[column] = round((df_waterHeating_retrofit_costs[column] * df_waterHeating_retrofit_costs['cpi_ratio'] * df_waterHeating_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_waterHeating_equipment_cost = df_waterHeating_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')
# dict_waterHeating_equipment_cost

# calculate_installation_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Electric Heat Pump Water Heater ...")
df_euss_am_mp10_home = calculate_installation_cost(df=df_euss_am_mp10_home,
                                                  cost_dict=dict_waterHeating_equipment_cost,
                                                  menu_mp=menu_mp,
                                                  end_use='waterHeating')

# calculate_replacement_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
df_euss_am_mp10_home = calculate_replacement_cost(df=df_euss_am_mp10_home,
                                                 cost_dict=dict_waterHeating_equipment_cost,
                                                 menu_mp=menu_mp,
                                                 end_use='waterHeating')

# Display the df
print(df_euss_am_mp10_home)
# Out:
# ========================== Capital Costs: Water Heating ==========================
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
#
# Calculating Cost of Retrofit Upgrade: Electric Heat Pump Water Heater ...
# Starting waterHeating installation cost calculation with validation framework
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
# Found 14999 valid homes out of 15651 for waterHeating installation
# After tech filtering: 14999 homes remain valid for waterHeating installation
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'waterHeating'
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
# Starting waterHeating replacement cost calculation with validation framework
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
# Found 14999 valid homes out of 15651 for waterHeating replacement
# After tech filtering: 14999 homes remain valid for waterHeating replacement
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'waterHeating'
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... duct_sealing_upgradeCost  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...                     0.00
# 122      In another census Place   Suburban  ...                  2368.07
# 150      In another census Place      Rural  ...                     0.00
# 153        Not in a census Place   Suburban  ...                  1721.89
# 162        Not in a census Place   Suburban  ...                  2032.27
# ...                          ...        ...  ...                      ...
# 549882     Not in a census Place   Suburban  ...                      NaN
# 549915                 Lancaster   Suburban  ...                  1907.38
# 549937   In another census Place      Rural  ...                     0.00
# 549963   In another census Place   Suburban  ...                     0.00
# 549989     Not in a census Place      Rural  ...                     0.00
#
#         insulation_wall_upgradeCost mp9_enclosure_upgradeCost  \
# bldg_id
# 119                            0.00                   3582.38
# 122                         7937.87                  30090.95
# 150                         6052.47                  15095.00
# 153                            0.00                  14610.71
# 162                         5860.22                  17434.27
# ...                             ...                       ...
# 549882                          NaN                      0.00
# 549915                         0.00                   9433.22
# 549937                      3279.56                   5312.00
# 549963                         0.00                      0.00
# 549989                      3645.83                   4630.20
#
#         insulation_foundation_wall_upgradeCost  \
# bldg_id
# 119                                    7614.46
# 122                                       0.00
# 150                                   11291.03
# 153                                       0.00
# 162                                   12368.51
# ...                                        ...
# 549882                                     NaN
# 549915                                 4877.34
# 549937                                    0.00
# 549963                                 9786.53
# 549989                                    0.00
#
#         insulation_rim_joist_upgradeCost  seal_crawlspace_upgradeCost  \
# bldg_id
# 119                               492.46                      2637.02
# 122                                 0.00                         0.00
# 150                               489.32                      1913.91
# 153                                 0.00                         0.00
# 162                               447.30                      2828.90
# ...                                  ...                          ...
# 549882                               NaN                          NaN
# 549915                            310.86                       935.62
# 549937                            196.12                         0.00
# 549963                            505.27                      2642.82
# 549989                            168.25                         0.00
#
#          insulation_roof_upgradeCost mp10_enclosure_upgradeCost  \
# bldg_id
# 119                              0.0                   14326.32
# 122                              0.0                   30090.95
# 150                              0.0                   28789.26
# 153                              0.0                   14610.71
# 162                              0.0                   33078.98
# ...                              ...                        ...
# 549882                           NaN                       0.00
# 549915                           0.0                   15557.04
# 549937                           0.0                    5508.12
# 549963                           0.0                   12934.62
# 549989                           0.0                    4798.45
#
#         mp10_waterHeating_installationCost mp10_waterHeating_replacementCost
# bldg_id
# 119                                2426.98                           1891.48
# 122                                2732.65                           2862.44
# 150                                2569.83                           1073.99
# 153                                3169.19                           2707.56
# 162                                3822.14                           2092.94
# ...                                    ...                               ...
# 549882                             2350.35                           1661.24
# 549915                             4911.98                           1138.11
# 549937                             2969.53                           1891.48
# 549963                             2325.16                           1661.24
# 549989                             2726.55                           2707.56
#
# [15651 rows x 427 columns]

# %% [markdown]
# ### Clothes Drying

# %%
print("""
========================== Capital Costs: Clothes Drying ==========================

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ... 
""")

# Columns to update
cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
]
 
# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_clothesDrying_retrofit_costs[column] = round((df_clothesDrying_retrofit_costs[column] * df_clothesDrying_retrofit_costs['cpi_ratio'] * df_clothesDrying_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_clothesDrying_equipment_cost = df_clothesDrying_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')
# dict_clothesDrying_equipment_cost

# calculate_installation_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Ventless Heat Pump Clothes Dryer ...")
df_euss_am_mp10_home = calculate_installation_cost(df=df_euss_am_mp10_home,
                                                  cost_dict=dict_clothesDrying_equipment_cost,
                                                  menu_mp=menu_mp,
                                                  end_use='clothesDrying')


# calculate_replacement_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
df_euss_am_mp10_home = calculate_replacement_cost(df=df_euss_am_mp10_home,
                                                 cost_dict=dict_clothesDrying_equipment_cost,
                                                 menu_mp=menu_mp,
                                                 end_use='clothesDrying')

# Display the df
print(df_euss_am_mp10_home)
# Out:
# ========================== Capital Costs: Clothes Drying ==========================
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
#
# Calculating Cost of Retrofit Upgrade: Ventless Heat Pump Clothes Dryer ...
# Starting clothesDrying installation cost calculation with validation framework
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
# Found 14743 valid homes out of 15651 for clothesDrying installation
# After tech filtering: 14743 homes remain valid for clothesDrying installation
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'clothesDrying'
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
# Starting clothesDrying replacement cost calculation with validation framework
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
# Found 14743 valid homes out of 15651 for clothesDrying replacement
# After tech filtering: 14743 homes remain valid for clothesDrying replacement
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'clothesDrying'
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... mp9_enclosure_upgradeCost  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...                   3582.38
# 122      In another census Place   Suburban  ...                  30090.95
# 150      In another census Place      Rural  ...                  15095.00
# 153        Not in a census Place   Suburban  ...                  14610.71
# 162        Not in a census Place   Suburban  ...                  17434.27
# ...                          ...        ...  ...                       ...
# 549882     Not in a census Place   Suburban  ...                      0.00
# 549915                 Lancaster   Suburban  ...                   9433.22
# 549937   In another census Place      Rural  ...                   5312.00
# 549963   In another census Place   Suburban  ...                      0.00
# 549989     Not in a census Place      Rural  ...                   4630.20
#
#         insulation_foundation_wall_upgradeCost  \
# bldg_id
# 119                                    7614.46
# 122                                       0.00
# 150                                   11291.03
# 153                                       0.00
# 162                                   12368.51
# ...                                        ...
# 549882                                     NaN
# 549915                                 4877.34
# 549937                                    0.00
# 549963                                 9786.53
# 549989                                    0.00
#
#         insulation_rim_joist_upgradeCost seal_crawlspace_upgradeCost  \
# bldg_id
# 119                               492.46                     2637.02
# 122                                 0.00                        0.00
# 150                               489.32                     1913.91
# 153                                 0.00                        0.00
# 162                               447.30                     2828.90
# ...                                  ...                         ...
# 549882                               NaN                         NaN
# 549915                            310.86                      935.62
# 549937                            196.12                        0.00
# 549963                            505.27                     2642.82
# 549989                            168.25                        0.00
#
#         insulation_roof_upgradeCost  mp10_enclosure_upgradeCost  \
# bldg_id
# 119                             0.0                    14326.32
# 122                             0.0                    30090.95
# 150                             0.0                    28789.26
# 153                             0.0                    14610.71
# 162                             0.0                    33078.98
# ...                             ...                         ...
# 549882                          NaN                        0.00
# 549915                          0.0                    15557.04
# 549937                          0.0                     5508.12
# 549963                          0.0                    12934.62
# 549989                          0.0                     4798.45
#
#          mp10_waterHeating_installationCost mp10_waterHeating_replacementCost  \
# bldg_id
# 119                                 2426.98                           1891.48
# 122                                 2732.65                           2862.44
# 150                                 2569.83                           1073.99
# 153                                 3169.19                           2707.56
# 162                                 3822.14                           2092.94
# ...                                     ...                               ...
# 549882                              2350.35                           1661.24
# 549915                              4911.98                           1138.11
# 549937                              2969.53                           1891.48
# 549963                              2325.16                           1661.24
# 549989                              2726.55                           2707.56
#
#         mp10_clothesDrying_installationCost mp10_clothesDrying_replacementCost
# bldg_id
# 119                                 2535.89                            1307.98
# 122                                 2312.72                             994.06
# 150                                 1863.89                             994.06
# 153                                     NaN                                NaN
# 162                                 2547.05                             994.06
# ...                                     ...                                ...
# 549882                              2739.49                             994.06
# 549915                              2293.11                             994.06
# 549937                              2247.76                            1307.98
# 549963                              3512.63                             994.06
# 549989                              2459.03                             994.06
#
# [15651 rows x 429 columns]

# %% [markdown]
# ### Cooking

# %%
print("""
========================== Capital Costs: Cooking ==========================

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...      
""")

# Columns to update
cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
]
 
# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_cooking_retrofit_costs[column] = round((df_cooking_retrofit_costs[column] * df_cooking_retrofit_costs['cpi_ratio'] * df_cooking_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_cooking_equipment_cost = df_cooking_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')
# dict_cooking_equipment_cost

# calculate_installation_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Electric Resistance Range ...")
df_euss_am_mp10_home = calculate_installation_cost(df=df_euss_am_mp10_home,
                                                  cost_dict=dict_cooking_equipment_cost,
                                                  menu_mp=menu_mp,
                                                  end_use='cooking')

# calculate_replacement_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
df_euss_am_mp10_home = calculate_replacement_cost(df=df_euss_am_mp10_home,
                                                 cost_dict=dict_cooking_equipment_cost,
                                                 menu_mp=menu_mp,
                                                 end_use='cooking')

# Display the df
print(df_euss_am_mp10_home)
# Out:
# ========================== Capital Costs: Cooking ==========================
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
#
# Calculating Cost of Retrofit Upgrade: Electric Resistance Range ...
# Starting cooking installation cost calculation with validation framework
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
# Found 7867 valid homes out of 15651 for cooking installation
# After tech filtering: 7867 homes remain valid for cooking installation
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'cooking'
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
# Starting cooking replacement cost calculation with validation framework
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
# Found 7867 valid homes out of 15651 for cooking replacement
# After tech filtering: 7867 homes remain valid for cooking replacement
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'cooking'
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         insulation_rim_joist_upgradeCost seal_crawlspace_upgradeCost  \
# bldg_id
# 119                               492.46                     2637.02
# 122                                 0.00                        0.00
# 150                               489.32                     1913.91
# 153                                 0.00                        0.00
# 162                               447.30                     2828.90
# ...                                  ...                         ...
# 549882                               NaN                         NaN
# 549915                            310.86                      935.62
# 549937                            196.12                        0.00
# 549963                            505.27                     2642.82
# 549989                            168.25                        0.00
#
#         insulation_roof_upgradeCost mp10_enclosure_upgradeCost  \
# bldg_id
# 119                             0.0                   14326.32
# 122                             0.0                   30090.95
# 150                             0.0                   28789.26
# 153                             0.0                   14610.71
# 162                             0.0                   33078.98
# ...                             ...                        ...
# 549882                          NaN                       0.00
# 549915                          0.0                   15557.04
# 549937                          0.0                    5508.12
# 549963                          0.0                   12934.62
# 549989                          0.0                    4798.45
#
#         mp10_waterHeating_installationCost  mp10_waterHeating_replacementCost  \
# bldg_id
# 119                                2426.98                            1891.48
# 122                                2732.65                            2862.44
# 150                                2569.83                            1073.99
# 153                                3169.19                            2707.56
# 162                                3822.14                            2092.94
# ...                                    ...                                ...
# 549882                             2350.35                            1661.24
# 549915                             4911.98                            1138.11
# 549937                             2969.53                            1891.48
# 549963                             2325.16                            1661.24
# 549989                             2726.55                            2707.56
#
#          mp10_clothesDrying_installationCost  \
# bldg_id
# 119                                  2535.89
# 122                                  2312.72
# 150                                  1863.89
# 153                                      NaN
# 162                                  2547.05
# ...                                      ...
# 549882                               2739.49
# 549915                               2293.11
# 549937                               2247.76
# 549963                               3512.63
# 549989                               2459.03
#
#         mp10_clothesDrying_replacementCost mp10_cooking_installationCost  \
# bldg_id
# 119                                1307.98                        508.87
# 122                                 994.06                           NaN
# 150                                 994.06                           NaN
# 153                                    NaN                           NaN
# 162                                 994.06                           NaN
# ...                                    ...                           ...
# 549882                              994.06                           NaN
# 549915                              994.06                           NaN
# 549937                             1307.98                       2371.84
# 549963                              994.06                           NaN
# 549989                              994.06                       1417.94
#
#         mp10_cooking_replacementCost
# bldg_id
# 119                          1072.54
# 122                              NaN
# 150                              NaN
# 153                              NaN
# 162                              NaN
# ...                              ...
# 549882                           NaN
# 549915                           NaN
# 549937                       1072.54
# 549963                           NaN
# 549989                       1072.54
#
# [15651 rows x 431 columns]

# %% [markdown]
#  ## Calculate Rebate Amounts (Applicable to IRA-Reference)

# %%
from cmu_tare_model.private_impact.data_processing.determine_rebate_eligibility_and_amount import calculate_percent_AMI, calculate_rebateIRA
from cmu_tare_model.utils.discounting import prepare_discount_rates
from cmu_tare_model.constants import PRIVATE_DISCOUNTING_METHOD, PUBLIC_DISCOUNTING_METHOD

print(f"""
====================================================================================================================================================================
CALCULATE HOUSEHOLD PERCENT AREA MEDIAN INCOME (%AMI) AND REBATE ELIGIBILITY/AMOUNTS
====================================================================================================================================================================

""")

# Determine Percent AMI and Rebate Amounts
# This needs to be done before running the calculate_percent_AMI function
df_euss_am_mp10_home = df_euss_am_mp10_home.copy()

# calculate_percent_AMI(df_results_IRA, df_county_medianIncome):
df_euss_am_mp10_home = calculate_percent_AMI(df_results_IRA=df_euss_am_mp10_home)

# NEW - ADD TO ALL SCENARIO FILES
# prepare_discount_rates(df):
df_euss_am_mp10_home = prepare_discount_rates(df=df_euss_am_mp10_home)

print("Calculating rebate amounts for Space Heating ...")
df_euss_am_mp10_home = calculate_rebateIRA(df_results_IRA=df_euss_am_mp10_home,
                                          category="heating",
                                          menu_mp=menu_mp)

print("Calculating rebate amounts for Water Heating ...")
df_euss_am_mp10_home = calculate_rebateIRA(df_results_IRA=df_euss_am_mp10_home,
                                          category="waterHeating",
                                          menu_mp=menu_mp)

print("Calculating rebate amounts for Clothes Drying ...")
df_euss_am_mp10_home = calculate_rebateIRA(df_results_IRA=df_euss_am_mp10_home,
                                          category="clothesDrying",
                                          menu_mp=menu_mp)

print("Calculating rebate amounts for Cooking ...")
df_euss_am_mp10_home = calculate_rebateIRA(df_results_IRA=df_euss_am_mp10_home,
                                          category="cooking",
                                          menu_mp=menu_mp)

print(f"""
====================================================================================================================================================================
DATAFRAME: df_euss_am_mp10_home AFTER CALCULATING REBATE AMOUNTS
{df_euss_am_mp10_home}

====================================================================================================================================================================
""")
# Out:
# ====================================================================================================================================================================
# CALCULATE HOUSEHOLD PERCENT AREA MEDIAN INCOME (%AMI) AND REBATE ELIGIBILITY/AMOUNTS
# ====================================================================================================================================================================
#
#
# Calculating rebate amounts for Space Heating ...
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
# Calculating rebate amounts for Water Heating ...
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
# Calculating rebate amounts for Clothes Drying ...
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
# Calculating rebate amounts for Cooking ...
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_mp10_home AFTER CALCULATING REBATE AMOUNTS
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...            income_level  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...         Moderate-Income
# 122      In another census Place   Suburban  ...              Low-Income
# 150      In another census Place      Rural  ...         Moderate-Income
# 153        Not in a census Place   Suburban  ...  Middle-to-Upper-Income
# 162        Not in a census Place   Suburban  ...  Middle-to-Upper-Income
# ...                          ...        ...  ...                     ...
# 549882     Not in a census Place   Suburban  ...         Moderate-Income
# 549915                 Lancaster   Suburban  ...         Moderate-Income
# 549937   In another census Place      Rural  ...  Middle-to-Upper-Income
# 549963   In another census Place   Suburban  ...         Moderate-Income
# 549989     Not in a census Place      Rural  ...  Middle-to-Upper-Income
#
#         lmi_or_mui public_discount_rate private_fixed_discount_rate  \
# bldg_id
# 119            LMI                 0.02                        0.07
# 122            LMI                 0.02                        0.07
# 150            LMI                 0.02                        0.07
# 153            MUI                 0.02                        0.07
# 162            MUI                 0.02                        0.07
# ...            ...                  ...                         ...
# 549882         LMI                 0.02                        0.07
# 549915         LMI                 0.02                        0.07
# 549937         MUI                 0.02                        0.07
# 549963         LMI                 0.02                        0.07
# 549989         MUI                 0.02                        0.07
#
#         private_variable_discount_rate  mp10_heating_rebate_amount  \
# bldg_id
# 119                           0.040313                     8000.00
# 122                           0.098647                     8000.00
# 150                           0.063887                     6422.82
# 153                           0.020000                        0.00
# 162                           0.020000                        0.00
# ...                                ...                         ...
# 549882                        0.059653                         NaN
# 549915                        0.040093                     8000.00
# 549937                        0.020000                        0.00
# 549963                        0.027013                     8000.00
# 549989                        0.020000                        0.00
#
#          weatherization_rebate_amount mp10_waterHeating_rebate_amount  \
# bldg_id
# 119                            1600.0                         1213.49
# 122                               0.0                         1750.00
# 150                               0.0                         1284.91
# 153                               0.0                            0.00
# 162                               0.0                            0.00
# ...                               ...                             ...
# 549882                            0.0                         1175.17
# 549915                            0.0                         1750.00
# 549937                            0.0                            0.00
# 549963                            0.0                         1162.58
# 549989                            0.0                            0.00
#
#          mp10_clothesDrying_rebate_amount mp10_cooking_rebate_amount
# bldg_id
# 119                                 840.0                     254.44
# 122                                 840.0                        NaN
# 150                                 840.0                        NaN
# 153                                   NaN                        NaN
# 162                                   0.0                        NaN
# ...                                   ...                        ...
# 549882                              840.0                        NaN
# 549915                              840.0                        NaN
# 549937                                0.0                       0.00
# 549963                              840.0                        NaN
# 549989                                0.0                       0.00
#
# [15651 rows x 444 columns]
#
# ====================================================================================================================================================================

# %% [markdown]
# # SCENARIO ANALYSIS:
# ## "No Inflation Reduction Act" and "AEO2023 Reference Case"
# ## Public Impact, Private Impact and Adoption Potential (Degree of Adoption Feasibility)

# %%
from cmu_tare_model.private_impact.calculate_lifetime_private_impact import calculate_private_npv
from cmu_tare_model.public_impact.calculate_lifetime_public_impact_sensitivity import calculate_public_npv
from cmu_tare_model.adoption_potential.determine_adoption_potential_sensitivity import *

print(f"""  
====================================================================================================================================================================
SCENARIO ANALYSIS: OVERVIEW
====================================================================================================================================================================

-------------------------------------------------------
PUBLIC IMPACTS: CLIMATE AND HEALTH
-------------------------------------------------------

--------------------------------------------------------
PRIVATE IMPACTS: LIFETIME CAPITAL COSTS AND SAVINGS
--------------------------------------------------------

--------------------------------------------------------
ADOPTION POTENTIAL
--------------------------------------------------------
determine_adoption_potential_sensitivity.py file contains the definitions for:
- adoption_decision function (combined climate + health analysis)
- calculate_climate_only_adoption_robust function (climate-only analysis)
- calculate_health_only_adoption_robust function (health-only analysis)
      
====================================================================================================================================================================
""")
# Out:
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: OVERVIEW
# ====================================================================================================================================================================
#
# -------------------------------------------------------
# PUBLIC IMPACTS: CLIMATE AND HEALTH
# -------------------------------------------------------
#
# --------------------------------------------------------
# PRIVATE IMPACTS: LIFETIME CAPITAL COSTS AND SAVINGS
# --------------------------------------------------------
#
# --------------------------------------------------------
# ADOPTION POTENTIAL
# --------------------------------------------------------
# determine_adoption_potential_sensitivity.py file contains the definitions for:
# - adoption_decision function (combined climate + health analysis)
# - calculate_climate_only_adoption_robust function (climate-only analysis)
# - calculate_health_only_adoption_robust function (health-only analysis)
#
# ====================================================================================================================================================================

# %% [markdown]
# ## Advanced MEASURE PACKAGE (MP10): NO INFLATION REDUCTION ACT
# ## Assumptions
# - NREL End-Use Savings Shapes Database: Measure Package 10
# - AEO2023 No Inflation Reduction Act:  HDD and Fuel Price Projections
# - Cambium 2021 MidCase Scenario

# %%
# Measure Package 10
scenario_name = 'No Inflation Reduction Act'
cost_scenario = 'Fuel Costs: AEO2023 No Inflation Reduction Act'
grid_scenario = 'Electricity Grid: Cambium 2021 MidCase Scenario'

print(f"""
====================================================================================================================================================================
Scenario {scenario_name}:
Advanced Retrofit: Measure Package {menu_mp}
{cost_scenario}
{grid_scenario}
====================================================================================================================================================================
""")
# Out:
# ====================================================================================================================================================================
# Scenario No Inflation Reduction Act:
# Advanced Retrofit: Measure Package 10
# Fuel Costs: AEO2023 No Inflation Reduction Act
# Electricity Grid: Cambium 2021 MidCase Scenario
# ====================================================================================================================================================================

# %%
print(f"""  
====================================================================================================================================================================
SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PUBLIC IMPACT 
====================================================================================================================================================================
STEP 1. Calculate the baseline marginal damages for climate and health-related emissions         [COMPLETED]
STEP 2. Calculate the post-retrofit marginal damages for climate and health-related emissions    [COMPLETED]
STEP 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)

---------------------------------------------------------------------------------------------

RESULTS OUTPUT:
""")

# Create copies to prevent overwriting the original dataframe and compare the differences
df_euss_am_mp10_home_ap2 = df_euss_am_mp10_home.copy()
df_euss_am_mp10_home_easiur = df_euss_am_mp10_home.copy()
df_euss_am_mp10_home_inmap = df_euss_am_mp10_home.copy()

# ========================== AP2  ========================== 
df_euss_am_mp10_home_ap2 = calculate_public_npv(
    df=df_euss_am_mp10_home_ap2,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp10_noIRA_damages_climate,
    df_mp_health=df_mp10_noIRA_damages_health,
    menu_mp="10",
    policy_scenario='No Inflation Reduction Act',
    rcm_model='ap2',
    base_year=2024,
    discounting_method=PUBLIC_DISCOUNTING_METHOD
)

# ====================== EASIUR ========================== 
df_euss_am_mp10_home_easiur = calculate_public_npv(
    df=df_euss_am_mp10_home_easiur,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp10_noIRA_damages_climate,
    df_mp_health=df_mp10_noIRA_damages_health,
    menu_mp="10",
    policy_scenario='No Inflation Reduction Act',
    rcm_model='easiur',
    base_year=2024,
    discounting_method=PUBLIC_DISCOUNTING_METHOD
)

# ========================== InMAP ========================== 
df_euss_am_mp10_home_inmap = calculate_public_npv(
    df=df_euss_am_mp10_home_inmap,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp10_noIRA_damages_climate,
    df_mp_health=df_mp10_noIRA_damages_health,
    menu_mp="10",
    policy_scenario='No Inflation Reduction Act',
    rcm_model='inmap',
    base_year=2024,
    discounting_method=PUBLIC_DISCOUNTING_METHOD
)

print(f"""  
====================================================================================================================================================================
DATAFRAME FOR mp10 AFTER CALCULATING PUBLIC NPV (NO IRA): df_euss_am_mp10_home

-----------------------------------------------
AP2: 
-----------------------------------------------

{df_euss_am_mp10_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp10_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp10_home_inmap}
      
""")
# Out:
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PUBLIC IMPACT
# ====================================================================================================================================================================
# STEP 1. Calculate the baseline marginal damages for climate and health-related emissions         [COMPLETED]
# STEP 2. Calculate the post-retrofit marginal damages for climate and health-related emissions    [COMPLETED]
# STEP 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
#
# ---------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT:
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
#
# ====================================================================================================================================================================
# DATAFRAME FOR mp10 AFTER CALCULATING PUBLIC NPV (NO IRA): df_euss_am_mp10_home
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp10_clothesDrying_public_npv_central_ap2_h6c  \
# bldg_id
# 119                                                   9.78
# 122                                                 295.27
# 150                                                 295.32
# 153                                                    NaN
# 162                                                1060.72
# ...                                                    ...
# 549882                                              466.75
# 549915                                              798.68
# 549937                                              235.36
# 549963                                              401.60
# 549989                                              399.86
#
#         preIRA_mp10_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                          229.76
# 122                                          314.41
# 150                                          365.15
# 153                                             NaN
# 162                                         1129.56
# ...                                             ...
# 549882                                       506.33
# 549915                                       881.90
# 549937                                       577.42
# 549963                                       476.07
# 549989                                       456.24
#
#         preIRA_mp10_clothesDrying_public_npv_upper_ap2_h6c  \
# bldg_id
# 119                                                  94.59
# 122                                                 412.35
# 150                                                 431.28
# 153                                                    NaN
# 162                                                1481.32
# ...                                                    ...
# 549882                                              655.28
# 549915                                             1127.04
# 549937                                              449.16
# 549963                                              578.59
# 549989                                              569.73
#
#         preIRA_mp10_cooking_climate_npv_lower  \
# bldg_id
# 119                                     30.63
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                  21.95
# 549963                                    NaN
# 549989                                  68.47
#
#         preIRA_mp10_cooking_health_npv_ap2_h6c  \
# bldg_id
# 119                                    -299.42
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                 -135.35
# 549963                                     NaN
# 549989                                 -208.25
#
#          preIRA_mp10_cooking_public_npv_lower_ap2_h6c  \
# bldg_id
# 119                                           -268.79
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                        -113.40
# 549963                                            NaN
# 549989                                        -139.78
#
#          preIRA_mp10_cooking_climate_npv_central  \
# bldg_id
# 119                                       106.37
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                     76.59
# 549963                                       NaN
# 549989                                    241.05
#
#         preIRA_mp10_cooking_public_npv_central_ap2_h6c  \
# bldg_id
# 119                                            -193.05
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                          -58.76
# 549963                                             NaN
# 549989                                           32.80
#
#          preIRA_mp10_cooking_climate_npv_upper  \
# bldg_id
# 119                                     166.96
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                  120.54
# 549963                                     NaN
# 549989                                  380.96
#
#         preIRA_mp10_cooking_public_npv_upper_ap2_h6c
# bldg_id
# 119                                          -132.46
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                        -14.81
# 549963                                           NaN
# 549989                                        172.71
#
# [15651 rows x 500 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp10_clothesDrying_public_npv_central_easiur_h6c  \
# bldg_id
# 119                                                 102.16
# 122                                                 309.99
# 150                                                 331.59
# 153                                                    NaN
# 162                                                1113.74
# ...                                                    ...
# 549882                                              489.97
# 549915                                              844.81
# 549937                                              315.24
# 549963                                              366.72
# 549989                                              392.31
#
#         preIRA_mp10_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                          229.76
# 122                                          314.41
# 150                                          365.15
# 153                                             NaN
# 162                                         1129.56
# ...                                             ...
# 549882                                       506.33
# 549915                                       881.90
# 549937                                       577.42
# 549963                                       476.07
# 549989                                       456.24
#
#         preIRA_mp10_clothesDrying_public_npv_upper_easiur_h6c  \
# bldg_id
# 119                                                 186.97
# 122                                                 427.07
# 150                                                 467.55
# 153                                                    NaN
# 162                                                1534.34
# ...                                                    ...
# 549882                                              678.50
# 549915                                             1173.17
# 549937                                              529.04
# 549963                                              543.71
# 549989                                              562.18
#
#         preIRA_mp10_cooking_climate_npv_lower  \
# bldg_id
# 119                                     30.63
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                  21.95
# 549963                                    NaN
# 549989                                  68.47
#
#         preIRA_mp10_cooking_health_npv_easiur_h6c  \
# bldg_id
# 119                                       -152.59
# 122                                           NaN
# 150                                           NaN
# 153                                           NaN
# 162                                           NaN
# ...                                           ...
# 549882                                        NaN
# 549915                                        NaN
# 549937                                     -77.98
# 549963                                        NaN
# 549989                                    -112.46
#
#          preIRA_mp10_cooking_public_npv_lower_easiur_h6c  \
# bldg_id
# 119                                              -121.96
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                            -56.03
# 549963                                               NaN
# 549989                                            -43.99
#
#          preIRA_mp10_cooking_climate_npv_central  \
# bldg_id
# 119                                       106.37
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                     76.59
# 549963                                       NaN
# 549989                                    241.05
#
#         preIRA_mp10_cooking_public_npv_central_easiur_h6c  \
# bldg_id
# 119                                                -46.22
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              -1.39
# 549963                                                NaN
# 549989                                             128.59
#
#          preIRA_mp10_cooking_climate_npv_upper  \
# bldg_id
# 119                                     166.96
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                  120.54
# 549963                                     NaN
# 549989                                  380.96
#
#         preIRA_mp10_cooking_public_npv_upper_easiur_h6c
# bldg_id
# 119                                               14.37
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                            42.56
# 549963                                              NaN
# 549989                                           268.50
#
# [15651 rows x 500 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp10_clothesDrying_public_npv_central_inmap_h6c  \
# bldg_id
# 119                                                 197.48
# 122                                                 271.40
# 150                                                 390.62
# 153                                                    NaN
# 162                                                 975.09
# ...                                                    ...
# 549882                                              571.21
# 549915                                              880.44
# 549937                                              251.84
# 549963                                              375.18
# 549989                                              423.82
#
#         preIRA_mp10_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                          229.76
# 122                                          314.41
# 150                                          365.15
# 153                                             NaN
# 162                                         1129.56
# ...                                             ...
# 549882                                       506.33
# 549915                                       881.90
# 549937                                       577.42
# 549963                                       476.07
# 549989                                       456.24
#
#         preIRA_mp10_clothesDrying_public_npv_upper_inmap_h6c  \
# bldg_id
# 119                                                 282.29
# 122                                                 388.48
# 150                                                 526.58
# 153                                                    NaN
# 162                                                1395.69
# ...                                                    ...
# 549882                                              759.74
# 549915                                             1208.80
# 549937                                              465.64
# 549963                                              552.17
# 549989                                              593.69
#
#         preIRA_mp10_cooking_climate_npv_lower  \
# bldg_id
# 119                                     30.63
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                  21.95
# 549963                                    NaN
# 549989                                  68.47
#
#         preIRA_mp10_cooking_health_npv_inmap_h6c  \
# bldg_id
# 119                                        41.85
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                   -131.19
# 549963                                       NaN
# 549989                                   -188.27
#
#          preIRA_mp10_cooking_public_npv_lower_inmap_h6c  \
# bldg_id
# 119                                               72.48
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                          -109.24
# 549963                                              NaN
# 549989                                          -119.80
#
#          preIRA_mp10_cooking_climate_npv_central  \
# bldg_id
# 119                                       106.37
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                     76.59
# 549963                                       NaN
# 549989                                    241.05
#
#         preIRA_mp10_cooking_public_npv_central_inmap_h6c  \
# bldg_id
# 119                                               148.22
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                            -54.60
# 549963                                               NaN
# 549989                                             52.78
#
#          preIRA_mp10_cooking_climate_npv_upper  \
# bldg_id
# 119                                     166.96
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                  120.54
# 549963                                     NaN
# 549989                                  380.96
#
#         preIRA_mp10_cooking_public_npv_upper_inmap_h6c
# bldg_id
# 119                                             208.81
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                          -10.65
# 549963                                             NaN
# 549989                                          192.69
#
# [15651 rows x 500 columns]

# %%
print(f"""
====================================================================================================================================================================
SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PRIVATE IMPACT
====================================================================================================================================================================
STEP 1: Calculate annual operating (fuel) costs                                                          [COMPLETED]
STEP 2: Calculate equipment capital costs (HEATING: include ductwork and weatherization (MP9 and MP10))  [COMPLETED]
STEP 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)        [COMPLETED]
STEP 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
----------------------------------------------------------------------------------------------------------------------

RESULTS OUTPUT (NO INFLATION REDUCTION ACT):
""")


# ========================== AP2  ========================== 
df_euss_am_mp10_home_ap2 = calculate_private_npv(
    df=df_euss_am_mp10_home_ap2,
    df_fuel_costs=df_mp10_noIRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='No Inflation Reduction Act',
    discounting_method='private_fixed',
    base_year=2024,
    verbose=False  # Add this parameter
    )

# ====================== EASIUR ========================== 
df_euss_am_mp10_home_easiur = calculate_private_npv(
    df=df_euss_am_mp10_home_easiur,
    df_fuel_costs=df_mp10_noIRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='No Inflation Reduction Act',
    discounting_method='private_fixed',
    base_year=2024,
    verbose=False  # Add this parameter
    )

# ====================== InMAP ========================== 
df_euss_am_mp10_home_inmap = calculate_private_npv(
    df=df_euss_am_mp10_home_inmap,
    df_fuel_costs=df_mp10_noIRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='No Inflation Reduction Act',
    discounting_method='private_fixed',
    base_year=2024,
    verbose=False  # Add this parameter
    )


print(f"""  
====================================================================================================================================================================
DATAFRAME FOR mp10 AFTER CALCULATING PRIVATE NPV (NO INFLATION REDUCTION ACT): df_euss_am_mp10_home

-----------------------------------------------
AP2: 
-----------------------------------------------

{df_euss_am_mp10_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp10_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp10_home_inmap}
      
""")
# Out:
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PRIVATE IMPACT
# ====================================================================================================================================================================
# STEP 1: Calculate annual operating (fuel) costs                                                          [COMPLETED]
# STEP 2: Calculate equipment capital costs (HEATING: include ductwork and weatherization (MP9 and MP10))  [COMPLETED]
# STEP 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)        [COMPLETED]
# STEP 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
# ----------------------------------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT (NO INFLATION REDUCTION ACT):
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Calculating costs for heating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Calculating costs for heating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Calculating costs for heating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp10_
#
#
# Verifying masking for all calculated columns:
#
# ====================================================================================================================================================================
# DATAFRAME FOR mp10 AFTER CALCULATING PRIVATE NPV (NO INFLATION REDUCTION ACT): df_euss_am_mp10_home
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp10_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                         -1899.09
# 122                                         -1214.11
# 150                                         -1235.39
# 153                                          3388.82
# 162                                         -3397.12
# ...                                              ...
# 549882                                      -2491.40
# 549915                                        325.78
# 549937                                      -1807.97
# 549963                                      -1845.30
# 549989                                       -195.40
#
#         preIRA_mp10_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                            -7.61
# 122                                          1648.33
# 150                                          -161.40
# 153                                          6096.38
# 162                                         -1304.18
# ...                                              ...
# 549882                                       -830.16
# 549915                                       1463.89
# 549937                                         83.51
# 549963                                       -184.06
# 549989                                       2512.16
#
#         preIRA_mp10_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                         2535.89
# 122                                         2312.72
# 150                                         1863.89
# 153                                             NaN
# 162                                         2547.05
# ...                                             ...
# 549882                                      2739.49
# 549915                                      2293.11
# 549937                                      2247.76
# 549963                                      3512.63
# 549989                                      2459.03
#
#         preIRA_mp10_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                       1227.91
# 122                                       1318.66
# 150                                        869.83
# 153                                           NaN
# 162                                       1552.99
# ...                                           ...
# 549882                                    1745.43
# 549915                                    1299.05
# 549937                                     939.78
# 549963                                    2518.57
# 549989                                    1464.97
#
#         preIRA_mp10_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                          -2715.22
# 122                                          -2109.78
# 150                                          -1628.17
# 153                                               NaN
# 162                                          -1817.90
# ...                                               ...
# 549882                                       -2412.64
# 549915                                       -1723.80
# 549937                                       -2749.37
# 549963                                       -3218.10
# 549989                                       -2164.50
#
#          preIRA_mp10_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                           -1407.24
# 122                                           -1115.72
# 150                                            -634.11
# 153                                                NaN
# 162                                            -823.84
# ...                                                ...
# 549882                                        -1418.58
# 549915                                         -729.74
# 549937                                        -1441.39
# 549963                                        -2224.04
# 549989                                        -1170.44
#
#          preIRA_mp10_cooking_total_capitalCost  \
# bldg_id
# 119                                     508.87
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                 2371.84
# 549963                                     NaN
# 549989                                 1417.94
#
#         preIRA_mp10_cooking_net_capitalCost  \
# bldg_id
# 119                                 -563.67
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                              1299.30
# 549963                                  NaN
# 549989                               345.40
#
#          preIRA_mp10_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                      -920.91
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                  -2931.25
# 549963                                       NaN
# 549989                                  -1004.73
#
#         preIRA_mp10_cooking_private_npv_moreWTP
# bldg_id
# 119                                      151.63
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -1858.71
# 549963                                      NaN
# 549989                                    67.81
#
# [15651 rows x 516 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp10_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                         -1899.09
# 122                                         -1214.11
# 150                                         -1235.39
# 153                                          3388.82
# 162                                         -3397.12
# ...                                              ...
# 549882                                      -2491.40
# 549915                                        325.78
# 549937                                      -1807.97
# 549963                                      -1845.30
# 549989                                       -195.40
#
#         preIRA_mp10_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                            -7.61
# 122                                          1648.33
# 150                                          -161.40
# 153                                          6096.38
# 162                                         -1304.18
# ...                                              ...
# 549882                                       -830.16
# 549915                                       1463.89
# 549937                                         83.51
# 549963                                       -184.06
# 549989                                       2512.16
#
#         preIRA_mp10_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                         2535.89
# 122                                         2312.72
# 150                                         1863.89
# 153                                             NaN
# 162                                         2547.05
# ...                                             ...
# 549882                                      2739.49
# 549915                                      2293.11
# 549937                                      2247.76
# 549963                                      3512.63
# 549989                                      2459.03
#
#         preIRA_mp10_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                       1227.91
# 122                                       1318.66
# 150                                        869.83
# 153                                           NaN
# 162                                       1552.99
# ...                                           ...
# 549882                                    1745.43
# 549915                                    1299.05
# 549937                                     939.78
# 549963                                    2518.57
# 549989                                    1464.97
#
#         preIRA_mp10_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                          -2715.22
# 122                                          -2109.78
# 150                                          -1628.17
# 153                                               NaN
# 162                                          -1817.90
# ...                                               ...
# 549882                                       -2412.64
# 549915                                       -1723.80
# 549937                                       -2749.37
# 549963                                       -3218.10
# 549989                                       -2164.50
#
#          preIRA_mp10_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                           -1407.24
# 122                                           -1115.72
# 150                                            -634.11
# 153                                                NaN
# 162                                            -823.84
# ...                                                ...
# 549882                                        -1418.58
# 549915                                         -729.74
# 549937                                        -1441.39
# 549963                                        -2224.04
# 549989                                        -1170.44
#
#          preIRA_mp10_cooking_total_capitalCost  \
# bldg_id
# 119                                     508.87
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                 2371.84
# 549963                                     NaN
# 549989                                 1417.94
#
#         preIRA_mp10_cooking_net_capitalCost  \
# bldg_id
# 119                                 -563.67
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                              1299.30
# 549963                                  NaN
# 549989                               345.40
#
#          preIRA_mp10_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                      -920.91
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                  -2931.25
# 549963                                       NaN
# 549989                                  -1004.73
#
#         preIRA_mp10_cooking_private_npv_moreWTP
# bldg_id
# 119                                      151.63
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -1858.71
# 549963                                      NaN
# 549989                                    67.81
#
# [15651 rows x 516 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp10_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                         -1899.09
# 122                                         -1214.11
# 150                                         -1235.39
# 153                                          3388.82
# 162                                         -3397.12
# ...                                              ...
# 549882                                      -2491.40
# 549915                                        325.78
# 549937                                      -1807.97
# 549963                                      -1845.30
# 549989                                       -195.40
#
#         preIRA_mp10_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                            -7.61
# 122                                          1648.33
# 150                                          -161.40
# 153                                          6096.38
# 162                                         -1304.18
# ...                                              ...
# 549882                                       -830.16
# 549915                                       1463.89
# 549937                                         83.51
# 549963                                       -184.06
# 549989                                       2512.16
#
#         preIRA_mp10_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                         2535.89
# 122                                         2312.72
# 150                                         1863.89
# 153                                             NaN
# 162                                         2547.05
# ...                                             ...
# 549882                                      2739.49
# 549915                                      2293.11
# 549937                                      2247.76
# 549963                                      3512.63
# 549989                                      2459.03
#
#         preIRA_mp10_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                       1227.91
# 122                                       1318.66
# 150                                        869.83
# 153                                           NaN
# 162                                       1552.99
# ...                                           ...
# 549882                                    1745.43
# 549915                                    1299.05
# 549937                                     939.78
# 549963                                    2518.57
# 549989                                    1464.97
#
#         preIRA_mp10_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                          -2715.22
# 122                                          -2109.78
# 150                                          -1628.17
# 153                                               NaN
# 162                                          -1817.90
# ...                                               ...
# 549882                                       -2412.64
# 549915                                       -1723.80
# 549937                                       -2749.37
# 549963                                       -3218.10
# 549989                                       -2164.50
#
#          preIRA_mp10_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                           -1407.24
# 122                                           -1115.72
# 150                                            -634.11
# 153                                                NaN
# 162                                            -823.84
# ...                                                ...
# 549882                                        -1418.58
# 549915                                         -729.74
# 549937                                        -1441.39
# 549963                                        -2224.04
# 549989                                        -1170.44
#
#          preIRA_mp10_cooking_total_capitalCost  \
# bldg_id
# 119                                     508.87
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                 2371.84
# 549963                                     NaN
# 549989                                 1417.94
#
#         preIRA_mp10_cooking_net_capitalCost  \
# bldg_id
# 119                                 -563.67
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                              1299.30
# 549963                                  NaN
# 549989                               345.40
#
#          preIRA_mp10_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                      -920.91
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                  -2931.25
# 549963                                       NaN
# 549989                                  -1004.73
#
#         preIRA_mp10_cooking_private_npv_moreWTP
# bldg_id
# 119                                      151.63
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -1858.71
# 549963                                      NaN
# 549989                                    67.81
#
# [15651 rows x 516 columns]

# %%
print(f"""
====================================================================================================================================================================
SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): ADOPTION POTENTIAL
====================================================================================================================================================================
determine_adoption_potential_sensitivity.py file contains the definitions for:
- adoption_decision function (combined climate + health analysis)
- calculate_climate_only_adoption_robust function (climate-only analysis)
- calculate_health_only_adoption_robust function (health-only analysis)
      
RESULTS OUTPUT (NO INFLATION REDUCTION ACT):
""")

# ========================== AP2  ========================== 
print("Processing AP2 model...")

# Combined climate + health analysis (existing)
df_euss_am_mp10_home_ap2 = adoption_decision(
    df=df_euss_am_mp10_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='ap2',
    cr_function='acs',
    )

df_euss_am_mp10_home_ap2 = adoption_decision(
    df=df_euss_am_mp10_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='ap2',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp10_home_ap2 = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp10_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp10_home_ap2 = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='ap2',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp10_home_ap2 = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='ap2',
    cr_function='h6c',
    verbose=False
    )

# ====================== EASIUR ========================== 
print("Processing EASIUR model...")

# Combined climate + health analysis (existing)
df_euss_am_mp10_home_easiur = adoption_decision(
    df=df_euss_am_mp10_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='easiur',
    cr_function='acs',
    )

df_euss_am_mp10_home_easiur = adoption_decision(
    df=df_euss_am_mp10_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='easiur',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp10_home_easiur = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp10_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp10_home_easiur = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='easiur',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp10_home_easiur = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='easiur',
    cr_function='h6c',
    verbose=False
    )

# ====================== InMAP ========================== 
print("Processing InMAP model...")

# Combined climate + health analysis (existing)
df_euss_am_mp10_home_inmap = adoption_decision(
    df=df_euss_am_mp10_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='inmap',
    cr_function='acs',
    )

df_euss_am_mp10_home_inmap = adoption_decision(
    df=df_euss_am_mp10_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='inmap',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp10_home_inmap = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp10_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp10_home_inmap = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='inmap',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp10_home_inmap = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='inmap',
    cr_function='h6c',
    verbose=False
    )

print(f"""
====================================================================================================================================================================
DATAFRAME FOR MP10 AFTER DETERMINING ADOPTION FEASIBILITY (NO INFLATION REDUCTION ACT): df_euss_am_mp10_home
Includes: Combined (Climate + Health), Climate-Only, and Health-Only Adoption Analysis

-----------------------------------------------
AP2: 
-----------------------------------------------

{df_euss_am_mp10_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp10_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp10_home_inmap}
      
""")
# Out:
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): ADOPTION POTENTIAL
# ====================================================================================================================================================================
# determine_adoption_potential_sensitivity.py file contains the definitions for:
# - adoption_decision function (combined climate + health analysis)
# - calculate_climate_only_adoption_robust function (climate-only analysis)
# - calculate_health_only_adoption_robust function (health-only analysis)
#
# RESULTS OUTPUT (NO INFLATION REDUCTION ACT):
#
# Processing AP2 model...
# Fixed 12 duplicate columns
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | ap2-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | ap2-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Climate-only Analysis: No Inflation Reduction Act
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | ap2-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | ap2-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# Processing EASIUR model...
# Fixed 12 duplicate columns
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | easiur-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | easiur-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Climate-only Analysis: No Inflation Reduction Act
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | easiur-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | easiur-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# Processing InMAP model...
# Fixed 12 duplicate columns
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | inmap-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | inmap-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Climate-only Analysis: No Inflation Reduction Act
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | inmap-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | inmap-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
#
# ====================================================================================================================================================================
# DATAFRAME FOR MP10 AFTER DETERMINING ADOPTION FEASIBILITY (NO INFLATION REDUCTION ACT): df_euss_am_mp10_home
# Includes: Combined (Climate + Health), Climate-Only, and Health-Only Adoption Analysis
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp10_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                                258.00
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                           -1782.12
# 549963                                                NaN
# 549989                                             308.86
#
#         preIRA_mp10_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                              318.59
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                         -1738.17
# 549963                                              NaN
# 549989                                           448.77
#
#         preIRA_mp10_heating_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                            -27466.16
# 122                                            -13965.42
# 150                                             -4154.89
# 153                                             -4554.47
# 162                                             -8271.06
# ...                                                  ...
# 549882                                               NaN
# 549915                                           1978.23
# 549937                                         -21342.60
# 549963                                         -26115.77
# 549989                                          -2979.81
#
#         preIRA_mp10_waterHeating_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                                -122.91
# 122                                                1672.45
# 150                                                 -16.21
# 153                                                6168.27
# 162                                               -1398.74
# ...                                                    ...
# 549882                                            -1051.53
# 549915                                             2338.06
# 549937                                              -18.62
# 549963                                             -234.97
# 549989                                             2476.06
#
#         preIRA_mp10_clothesDrying_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                               -1459.84
# 122                                               -1077.60
# 150                                                -608.37
# 153                                                    NaN
# 162                                                -686.93
# ...                                                    ...
# 549882                                            -1360.61
# 549915                                             -634.32
# 549937                                            -1491.30
# 549963                                            -2184.13
# 549989                                            -1126.28
#
#          preIRA_mp10_cooking_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                                 35.10
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                           -1911.39
# 549963                                                NaN
# 549989                                             -13.23
#
#          preIRA_mp10_heating_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                             -27415.95
# 122                                             -11254.22
# 150                                                746.76
# 153                                              -3230.83
# 162                                              -4783.14
# ...                                                   ...
# 549882                                                NaN
# 549915                                            9681.12
# 549937                                          -21506.35
# 549963                                          -26245.25
# 549989                                           -2847.71
#
#         preIRA_mp10_waterHeating_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                                -303.85
# 122                                                1710.29
# 150                                                 211.70
# 153                                                6281.09
# 162                                               -1547.15
# ...                                                    ...
# 549882                                            -1399.00
# 549915                                             3709.84
# 549937                                             -178.94
# 549963                                             -314.85
# 549989                                             2419.39
#
#          preIRA_mp10_clothesDrying_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                               -1542.41
# 122                                               -1017.78
# 150                                                -567.98
# 153                                                    NaN
# 162                                                -472.08
# ...                                                    ...
# 549882                                            -1269.63
# 549915                                             -484.60
# 549937                                            -1569.65
# 549963                                            -2121.52
# 549989                                            -1056.95
#
#         preIRA_mp10_cooking_total_npv_healthOnly_ap2_h6c
# bldg_id
# 119                                              -147.79
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                          -1994.06
# 549963                                               NaN
# 549989                                           -140.44
#
# [15651 rows x 624 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp10_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                                258.00
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                           -1782.12
# 549963                                                NaN
# 549989                                             308.86
#
#         preIRA_mp10_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                              318.59
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                         -1738.17
# 549963                                              NaN
# 549989                                           448.77
#
#         preIRA_mp10_heating_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                              -26173.65
# 122                                               -9148.07
# 150                                               -2413.18
# 153                                                 250.70
# 162                                               -2383.10
# ...                                                    ...
# 549882                                                 NaN
# 549915                                             2943.91
# 549937                                           -20943.65
# 549963                                           -25171.71
# 549989                                            -2364.61
#
#         preIRA_mp10_waterHeating_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                                 170.94
# 122                                                1917.62
# 150                                                  62.72
# 153                                                7351.81
# 162                                               -1159.89
# ...                                                    ...
# 549882                                             -822.51
# 549915                                             2498.37
# 549937                                              248.04
# 549963                                             -115.52
# 549989                                             2616.72
#
#         preIRA_mp10_clothesDrying_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                               -1423.90
# 122                                               -1071.84
# 150                                                -594.27
# 153                                                    NaN
# 162                                                -666.31
# ...                                                    ...
# 549882                                            -1351.57
# 549915                                             -616.38
# 549937                                            -1460.24
# 549963                                            -2197.73
# 549989                                            -1129.19
#
#          preIRA_mp10_cooking_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                                  92.25
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1889.06
# 549963                                                 NaN
# 549989                                               24.05
#
#          preIRA_mp10_heating_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                              -24095.01
# 122                                                1123.14
# 150                                                5221.85
# 153                                                9115.25
# 162                                               10344.99
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            12162.19
# 549937                                           -20481.30
# 549963                                           -23819.63
# 549989                                            -1267.02
#
#         preIRA_mp10_waterHeating_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                                 451.15
# 122                                                2340.19
# 150                                                 414.43
# 153                                                9321.98
# 162                                                -933.44
# ...                                                    ...
# 549882                                             -810.50
# 549915                                             4121.71
# 549937                                              506.22
# 549963                                               -7.97
# 549989                                             2780.83
#
#          preIRA_mp10_clothesDrying_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                               -1450.03
# 122                                               -1003.06
# 150                                                -531.71
# 153                                                    NaN
# 162                                                -419.06
# ...                                                    ...
# 549882                                            -1246.41
# 549915                                             -438.47
# 549937                                            -1489.77
# 549963                                            -2156.40
# 549989                                            -1064.50
#
#         preIRA_mp10_cooking_total_npv_healthOnly_easiur_h6c
# bldg_id
# 119                                                  -0.96
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1936.69
# 549963                                                 NaN
# 549989                                              -44.65
#
# [15651 rows x 624 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp10_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                                258.00
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                           -1782.12
# 549963                                                NaN
# 549989                                             308.86
#
#         preIRA_mp10_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                              318.59
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                         -1738.17
# 549963                                              NaN
# 549989                                           448.77
#
#         preIRA_mp10_heating_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                              -25701.11
# 122                                               -6881.67
# 150                                                 350.63
# 153                                               -1425.29
# 162                                                 330.71
# ...                                                    ...
# 549882                                                 NaN
# 549915                                             3616.17
# 549937                                           -21164.26
# 549963                                           -25300.86
# 549989                                            -2727.49
#
#         preIRA_mp10_waterHeating_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                                 331.08
# 122                                                2062.78
# 150                                                 192.90
# 153                                                6970.06
# 162                                               -1029.36
# ...                                                    ...
# 549882                                             -980.92
# 549915                                             2629.50
# 549937                                               94.68
# 549963                                             -133.53
# 549989                                             2520.54
#
#         preIRA_mp10_clothesDrying_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                               -1386.77
# 122                                               -1086.89
# 150                                                -571.29
# 153                                                    NaN
# 162                                                -720.27
# ...                                                    ...
# 549882                                            -1319.97
# 549915                                             -602.50
# 549937                                            -1484.89
# 549963                                            -2194.43
# 549989                                            -1116.93
#
#          preIRA_mp10_cooking_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                                 167.93
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1909.77
# 549963                                                 NaN
# 549989                                               -5.49
#
#          preIRA_mp10_heating_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                              -22880.96
# 122                                                6946.28
# 150                                               12322.92
# 153                                                4809.07
# 162                                               17317.62
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            13889.36
# 549937                                           -21048.12
# 549963                                           -24151.52
# 549989                                            -2199.51
#
#         preIRA_mp10_waterHeating_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                                 862.60
# 122                                                2713.29
# 150                                                 748.87
# 153                                                8341.15
# 162                                                -598.04
# ...                                                    ...
# 549882                                            -1217.48
# 549915                                             4458.66
# 549937                                              112.24
# 549963                                              -54.25
# 549989                                             2533.70
#
#          preIRA_mp10_clothesDrying_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                               -1354.71
# 122                                               -1041.65
# 150                                                -472.68
# 153                                                    NaN
# 162                                                -557.71
# ...                                                    ...
# 549882                                            -1165.17
# 549915                                             -402.84
# 549937                                            -1553.17
# 549963                                            -2147.94
# 549989                                            -1032.99
#
#         preIRA_mp10_cooking_total_npv_healthOnly_inmap_h6c
# bldg_id
# 119                                                 193.48
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1989.90
# 549963                                                 NaN
# 549989                                             -120.46
#
# [15651 rows x 624 columns]

# %% [markdown]
# ## Advanced MEASURE PACKAGE (MP10): AEO2023 REFERENCE CASE
# ## Assumptions
# - NREL End-Use Savings Shapes Database: Measure Package 10
# - AEO2023 REFERENCE CASE: HDD and Fuel Price Projections
# - Cambium 2023 MidCase Scenario

# %%
# Measure Package 10
scenario_name = 'Advanced IRA-Reference'
cost_scenario = 'Fuel Costs: AEO2023 Reference Case'
grid_scenario = 'Electricity Grid: Cambium 2023 MidCase Scenario'

print(f"""
====================================================================================================================================================================
MODEL SCENARIO
====================================================================================================================================================================
Scenario {scenario_name}:
Advanced Retrofit: Measure Package {menu_mp}
{cost_scenario}
{grid_scenario}
====================================================================================================================================================================
""")
# Out:
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Advanced IRA-Reference:
# Advanced Retrofit: Measure Package 10
# Fuel Costs: AEO2023 Reference Case
# Electricity Grid: Cambium 2023 MidCase Scenario
# ====================================================================================================================================================================

# %%
print(f"""  
====================================================================================================================================================================
SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PUBLIC IMPACT 
====================================================================================================================================================================
STEP 1. Calculate the baseline marginal damages for climate and health-related emissions         [COMPLETED]
STEP 2. Calculate the post-retrofit marginal damages for climate and health-related emissions    [COMPLETED]
STEP 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)

---------------------------------------------------------------------------------------------

RESULTS OUTPUT (AEO2023 REFERENCE CASE):
""")

# ========================== AP2  ========================== 
df_euss_am_mp10_home_ap2 = calculate_public_npv(
    df=df_euss_am_mp10_home_ap2,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp10_IRA_damages_climate,
    df_mp_health=df_mp10_IRA_damages_health,
    menu_mp="10",
    policy_scenario='AEO2023 Reference Case',
    rcm_model='ap2',
    base_year=2024,
    discounting_method=PUBLIC_DISCOUNTING_METHOD
)

# ====================== EASIUR ========================== 
df_euss_am_mp10_home_easiur = calculate_public_npv(
    df=df_euss_am_mp10_home_easiur,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp10_IRA_damages_climate,
    df_mp_health=df_mp10_IRA_damages_health,
    menu_mp="10",
    policy_scenario='AEO2023 Reference Case',
    rcm_model='easiur',
    base_year=2024,
    discounting_method=PUBLIC_DISCOUNTING_METHOD
)

# ========================== InMAP ========================== 
df_euss_am_mp10_home_inmap = calculate_public_npv(
    df=df_euss_am_mp10_home_inmap,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp10_IRA_damages_climate,
    df_mp_health=df_mp10_IRA_damages_health,
    menu_mp="10",
    policy_scenario='AEO2023 Reference Case',
    rcm_model='inmap',
    base_year=2024,
    discounting_method=PUBLIC_DISCOUNTING_METHOD
)

print(f"""  
=====================================================================================================================================================================
DATAFRAME FOR mp10 AFTER CALCULATING PUBLIC NPV (AEO2023 REFERENCE CASE): df_euss_am_mp10_home

-----------------------------------------------
AP2: 
-----------------------------------------------
      
{df_euss_am_mp10_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp10_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp10_home_inmap}
      
""")
# Out:
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PUBLIC IMPACT
# ====================================================================================================================================================================
# STEP 1. Calculate the baseline marginal damages for climate and health-related emissions         [COMPLETED]
# STEP 2. Calculate the post-retrofit marginal damages for climate and health-related emissions    [COMPLETED]
# STEP 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
#
# ---------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT (AEO2023 REFERENCE CASE):
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Verifying masking for all calculated columns:
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Verifying masking for all calculated columns:
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Verifying masking for all calculated columns:
#
# =====================================================================================================================================================================
# DATAFRAME FOR mp10 AFTER CALCULATING PUBLIC NPV (AEO2023 REFERENCE CASE): df_euss_am_mp10_home
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp10_clothesDrying_public_npv_central_ap2_h6c  \
# bldg_id
# 119                                                  89.78
# 122                                                 336.88
# 150                                                 343.57
# 153                                                    NaN
# 162                                                1209.88
# ...                                                    ...
# 549882                                              533.72
# 549915                                              915.26
# 549937                                              374.90
# 549963                                              439.22
# 549989                                              460.17
#
#         iraRef_mp10_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                          357.75
# 122                                          380.96
# 150                                          442.35
# 153                                             NaN
# 162                                         1368.22
# ...                                             ...
# 549882                                       613.48
# 549915                                      1068.42
# 549937                                       799.95
# 549963                                       536.06
# 549989                                       552.77
#
#         iraRef_mp10_clothesDrying_public_npv_upper_ap2_h6c  \
# bldg_id
# 119                                                 222.58
# 122                                                 478.90
# 150                                                 508.48
# 153                                                    NaN
# 162                                                1719.98
# ...                                                    ...
# 549882                                              762.43
# 549915                                             1313.56
# 549937                                              671.69
# 549963                                              638.58
# 549989                                              666.26
#
#         iraRef_mp10_cooking_climate_npv_lower  \
# bldg_id
# 119                                     69.50
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                  61.03
# 549963                                    NaN
# 549989                                 101.67
#
#         iraRef_mp10_cooking_health_npv_ap2_h6c  \
# bldg_id
# 119                                    -299.42
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                 -135.35
# 549963                                     NaN
# 549989                                 -208.25
#
#          iraRef_mp10_cooking_public_npv_lower_ap2_h6c  \
# bldg_id
# 119                                           -229.92
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                         -74.32
# 549963                                            NaN
# 549989                                        -106.58
#
#          iraRef_mp10_cooking_climate_npv_central  \
# bldg_id
# 119                                       246.33
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                    215.90
# 549963                                       NaN
# 549989                                    360.67
#
#         iraRef_mp10_cooking_public_npv_central_ap2_h6c  \
# bldg_id
# 119                                             -53.09
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                           80.55
# 549963                                             NaN
# 549989                                          152.42
#
#          iraRef_mp10_cooking_climate_npv_upper  \
# bldg_id
# 119                                     390.79
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                  342.13
# 549963                                     NaN
# 549989                                  572.35
#
#         iraRef_mp10_cooking_public_npv_upper_ap2_h6c
# bldg_id
# 119                                            91.37
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                        206.78
# 549963                                           NaN
# 549989                                        364.10
#
# [15651 rows x 680 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp10_clothesDrying_public_npv_central_easiur_h6c  \
# bldg_id
# 119                                                 182.16
# 122                                                 351.60
# 150                                                 379.84
# 153                                                    NaN
# 162                                                1262.90
# ...                                                    ...
# 549882                                              556.94
# 549915                                              961.39
# 549937                                              454.78
# 549963                                              404.34
# 549989                                              452.62
#
#         iraRef_mp10_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                          357.75
# 122                                          380.96
# 150                                          442.35
# 153                                             NaN
# 162                                         1368.22
# ...                                             ...
# 549882                                       613.48
# 549915                                      1068.42
# 549937                                       799.95
# 549963                                       536.06
# 549989                                       552.77
#
#         iraRef_mp10_clothesDrying_public_npv_upper_easiur_h6c  \
# bldg_id
# 119                                                 314.96
# 122                                                 493.62
# 150                                                 544.75
# 153                                                    NaN
# 162                                                1773.00
# ...                                                    ...
# 549882                                              785.65
# 549915                                             1359.69
# 549937                                              751.57
# 549963                                              603.70
# 549989                                              658.71
#
#         iraRef_mp10_cooking_climate_npv_lower  \
# bldg_id
# 119                                     69.50
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                  61.03
# 549963                                    NaN
# 549989                                 101.67
#
#         iraRef_mp10_cooking_health_npv_easiur_h6c  \
# bldg_id
# 119                                       -152.59
# 122                                           NaN
# 150                                           NaN
# 153                                           NaN
# 162                                           NaN
# ...                                           ...
# 549882                                        NaN
# 549915                                        NaN
# 549937                                     -77.98
# 549963                                        NaN
# 549989                                    -112.46
#
#          iraRef_mp10_cooking_public_npv_lower_easiur_h6c  \
# bldg_id
# 119                                               -83.09
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                            -16.95
# 549963                                               NaN
# 549989                                            -10.79
#
#          iraRef_mp10_cooking_climate_npv_central  \
# bldg_id
# 119                                       246.33
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                    215.90
# 549963                                       NaN
# 549989                                    360.67
#
#         iraRef_mp10_cooking_public_npv_central_easiur_h6c  \
# bldg_id
# 119                                                 93.74
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                             137.92
# 549963                                                NaN
# 549989                                             248.21
#
#          iraRef_mp10_cooking_climate_npv_upper  \
# bldg_id
# 119                                     390.79
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                  342.13
# 549963                                     NaN
# 549989                                  572.35
#
#         iraRef_mp10_cooking_public_npv_upper_easiur_h6c
# bldg_id
# 119                                              238.20
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                           264.15
# 549963                                              NaN
# 549989                                           459.89
#
# [15651 rows x 680 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp10_clothesDrying_public_npv_central_inmap_h6c  \
# bldg_id
# 119                                                 277.48
# 122                                                 313.01
# 150                                                 438.87
# 153                                                    NaN
# 162                                                1124.25
# ...                                                    ...
# 549882                                              638.18
# 549915                                              997.02
# 549937                                              391.38
# 549963                                              412.80
# 549989                                              484.13
#
#         iraRef_mp10_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                          357.75
# 122                                          380.96
# 150                                          442.35
# 153                                             NaN
# 162                                         1368.22
# ...                                             ...
# 549882                                       613.48
# 549915                                      1068.42
# 549937                                       799.95
# 549963                                       536.06
# 549989                                       552.77
#
#         iraRef_mp10_clothesDrying_public_npv_upper_inmap_h6c  \
# bldg_id
# 119                                                 410.28
# 122                                                 455.03
# 150                                                 603.78
# 153                                                    NaN
# 162                                                1634.35
# ...                                                    ...
# 549882                                              866.89
# 549915                                             1395.32
# 549937                                              688.17
# 549963                                              612.16
# 549989                                              690.22
#
#         iraRef_mp10_cooking_climate_npv_lower  \
# bldg_id
# 119                                     69.50
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                  61.03
# 549963                                    NaN
# 549989                                 101.67
#
#         iraRef_mp10_cooking_health_npv_inmap_h6c  \
# bldg_id
# 119                                        41.85
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                   -131.19
# 549963                                       NaN
# 549989                                   -188.27
#
#          iraRef_mp10_cooking_public_npv_lower_inmap_h6c  \
# bldg_id
# 119                                              111.35
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                           -70.16
# 549963                                              NaN
# 549989                                           -86.60
#
#          iraRef_mp10_cooking_climate_npv_central  \
# bldg_id
# 119                                       246.33
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                    215.90
# 549963                                       NaN
# 549989                                    360.67
#
#         iraRef_mp10_cooking_public_npv_central_inmap_h6c  \
# bldg_id
# 119                                               288.18
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                             84.71
# 549963                                               NaN
# 549989                                            172.40
#
#          iraRef_mp10_cooking_climate_npv_upper  \
# bldg_id
# 119                                     390.79
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                  342.13
# 549963                                     NaN
# 549989                                  572.35
#
#         iraRef_mp10_cooking_public_npv_upper_inmap_h6c
# bldg_id
# 119                                             432.64
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                          210.94
# 549963                                             NaN
# 549989                                          384.08
#
# [15651 rows x 680 columns]

# %%
print(f"""
====================================================================================================================================================================
SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PRIVATE IMPACT
====================================================================================================================================================================
STEP 1: Calculate annual operating (fuel) costs                                                          [COMPLETED]
STEP 2: Calculate equipment capital costs (HEATING: include ductwork and weatherization (MP9 and MP10))  [COMPLETED]
STEP 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)        [COMPLETED]
STEP 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
----------------------------------------------------------------------------------------------------------------------

RESULTS OUTPUT (AEO2023 REFERENCE CASE):
""")


# ========================== AP2  ========================== 
df_euss_am_mp10_home_ap2 = calculate_private_npv(
    df=df_euss_am_mp10_home_ap2,
    df_fuel_costs=df_mp10_IRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='AEO2023 Reference Case',
    discounting_method='private_fixed',
    base_year=2024,
    verbose=False  # Add this parameter
    )

# ====================== EASIUR ========================== 
df_euss_am_mp10_home_easiur = calculate_private_npv(
    df=df_euss_am_mp10_home_easiur,
    df_fuel_costs=df_mp10_IRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='AEO2023 Reference Case',
    discounting_method='private_fixed',
    base_year=2024,
    verbose=False  # Add this parameter
    )

# ====================== InMAP ========================== 
df_euss_am_mp10_home_inmap = calculate_private_npv(
    df=df_euss_am_mp10_home_inmap,
    df_fuel_costs=df_mp10_IRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='AEO2023 Reference Case',
    discounting_method='private_fixed',
    base_year=2024,
    verbose=False  # Add this parameter
    )



print(f"""  
=====================================================================================================================================================================
DATAFRAME FOR mp10 AFTER CALCULATING PRIVATE NPV (AEO2023 REFERENCE CASE): df_euss_am_mp10_home

-----------------------------------------------
AP2: 
-----------------------------------------------
      
{df_euss_am_mp10_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp10_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp10_home_inmap}
      
""")
# Out:
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PRIVATE IMPACT
# ====================================================================================================================================================================
# STEP 1: Calculate annual operating (fuel) costs                                                          [COMPLETED]
# STEP 2: Calculate equipment capital costs (HEATING: include ductwork and weatherization (MP9 and MP10))  [COMPLETED]
# STEP 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)        [COMPLETED]
# STEP 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
# ----------------------------------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT (AEO2023 REFERENCE CASE):
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Calculating costs for heating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Verifying masking for all calculated columns:
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Calculating costs for heating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Verifying masking for all calculated columns:
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Calculating costs for heating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp10_
#
#
# Verifying masking for all calculated columns:
#
# =====================================================================================================================================================================
# DATAFRAME FOR mp10 AFTER CALCULATING PRIVATE NPV (AEO2023 REFERENCE CASE): df_euss_am_mp10_home
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp10_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                          -667.28
# 122                                           545.43
# 150                                            59.59
# 153                                          3430.05
# 162                                         -3382.14
# ...                                              ...
# 549882                                      -1285.25
# 549915                                       2105.77
# 549937                                      -1759.40
# 549963                                       -668.09
# 549989                                       -180.08
#
#         iraRef_mp10_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                          1224.20
# 122                                          3407.87
# 150                                          1133.58
# 153                                          6137.61
# 162                                         -1289.20
# ...                                              ...
# 549882                                        375.99
# 549915                                       3243.88
# 549937                                        132.08
# 549963                                        993.15
# 549989                                       2527.48
#
#         iraRef_mp10_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                         1695.89
# 122                                         1472.72
# 150                                         1023.89
# 153                                             NaN
# 162                                         2547.05
# ...                                             ...
# 549882                                      1899.49
# 549915                                      1453.11
# 549937                                      2247.76
# 549963                                      2672.63
# 549989                                      2459.03
#
#         iraRef_mp10_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                        387.91
# 122                                        478.66
# 150                                         29.83
# 153                                           NaN
# 162                                       1552.99
# ...                                           ...
# 549882                                     905.43
# 549915                                     459.05
# 549937                                     939.78
# 549963                                    1678.57
# 549989                                    1464.97
#
#         iraRef_mp10_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                          -1867.95
# 122                                          -1266.00
# 150                                           -783.80
# 153                                               NaN
# 162                                          -1804.36
# ...                                               ...
# 549882                                       -1566.58
# 549915                                        -873.22
# 549937                                       -2729.06
# 549963                                       -2372.62
# 549989                                       -2159.02
#
#          iraRef_mp10_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                            -559.97
# 122                                            -271.94
# 150                                             210.26
# 153                                                NaN
# 162                                            -810.30
# ...                                                ...
# 549882                                         -572.52
# 549915                                          120.84
# 549937                                        -1421.08
# 549963                                        -1378.56
# 549989                                        -1164.96
#
#          iraRef_mp10_cooking_total_capitalCost  \
# bldg_id
# 119                                     254.43
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                 2371.84
# 549963                                     NaN
# 549989                                 1417.94
#
#         iraRef_mp10_cooking_net_capitalCost  \
# bldg_id
# 119                                 -818.11
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                              1299.30
# 549963                                  NaN
# 549989                               345.40
#
#          iraRef_mp10_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                      -651.97
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                  -2911.55
# 549963                                       NaN
# 549989                                   -992.34
#
#         iraRef_mp10_cooking_private_npv_moreWTP
# bldg_id
# 119                                      420.57
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -1839.01
# 549963                                      NaN
# 549989                                    80.20
#
# [15651 rows x 696 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp10_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                          -667.28
# 122                                           545.43
# 150                                            59.59
# 153                                          3430.05
# 162                                         -3382.14
# ...                                              ...
# 549882                                      -1285.25
# 549915                                       2105.77
# 549937                                      -1759.40
# 549963                                       -668.09
# 549989                                       -180.08
#
#         iraRef_mp10_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                          1224.20
# 122                                          3407.87
# 150                                          1133.58
# 153                                          6137.61
# 162                                         -1289.20
# ...                                              ...
# 549882                                        375.99
# 549915                                       3243.88
# 549937                                        132.08
# 549963                                        993.15
# 549989                                       2527.48
#
#         iraRef_mp10_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                         1695.89
# 122                                         1472.72
# 150                                         1023.89
# 153                                             NaN
# 162                                         2547.05
# ...                                             ...
# 549882                                      1899.49
# 549915                                      1453.11
# 549937                                      2247.76
# 549963                                      2672.63
# 549989                                      2459.03
#
#         iraRef_mp10_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                        387.91
# 122                                        478.66
# 150                                         29.83
# 153                                           NaN
# 162                                       1552.99
# ...                                           ...
# 549882                                     905.43
# 549915                                     459.05
# 549937                                     939.78
# 549963                                    1678.57
# 549989                                    1464.97
#
#         iraRef_mp10_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                          -1867.95
# 122                                          -1266.00
# 150                                           -783.80
# 153                                               NaN
# 162                                          -1804.36
# ...                                               ...
# 549882                                       -1566.58
# 549915                                        -873.22
# 549937                                       -2729.06
# 549963                                       -2372.62
# 549989                                       -2159.02
#
#          iraRef_mp10_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                            -559.97
# 122                                            -271.94
# 150                                             210.26
# 153                                                NaN
# 162                                            -810.30
# ...                                                ...
# 549882                                         -572.52
# 549915                                          120.84
# 549937                                        -1421.08
# 549963                                        -1378.56
# 549989                                        -1164.96
#
#          iraRef_mp10_cooking_total_capitalCost  \
# bldg_id
# 119                                     254.43
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                 2371.84
# 549963                                     NaN
# 549989                                 1417.94
#
#         iraRef_mp10_cooking_net_capitalCost  \
# bldg_id
# 119                                 -818.11
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                              1299.30
# 549963                                  NaN
# 549989                               345.40
#
#          iraRef_mp10_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                      -651.97
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                  -2911.55
# 549963                                       NaN
# 549989                                   -992.34
#
#         iraRef_mp10_cooking_private_npv_moreWTP
# bldg_id
# 119                                      420.57
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -1839.01
# 549963                                      NaN
# 549989                                    80.20
#
# [15651 rows x 696 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp10_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                          -667.28
# 122                                           545.43
# 150                                            59.59
# 153                                          3430.05
# 162                                         -3382.14
# ...                                              ...
# 549882                                      -1285.25
# 549915                                       2105.77
# 549937                                      -1759.40
# 549963                                       -668.09
# 549989                                       -180.08
#
#         iraRef_mp10_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                          1224.20
# 122                                          3407.87
# 150                                          1133.58
# 153                                          6137.61
# 162                                         -1289.20
# ...                                              ...
# 549882                                        375.99
# 549915                                       3243.88
# 549937                                        132.08
# 549963                                        993.15
# 549989                                       2527.48
#
#         iraRef_mp10_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                         1695.89
# 122                                         1472.72
# 150                                         1023.89
# 153                                             NaN
# 162                                         2547.05
# ...                                             ...
# 549882                                      1899.49
# 549915                                      1453.11
# 549937                                      2247.76
# 549963                                      2672.63
# 549989                                      2459.03
#
#         iraRef_mp10_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                        387.91
# 122                                        478.66
# 150                                         29.83
# 153                                           NaN
# 162                                       1552.99
# ...                                           ...
# 549882                                     905.43
# 549915                                     459.05
# 549937                                     939.78
# 549963                                    1678.57
# 549989                                    1464.97
#
#         iraRef_mp10_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                          -1867.95
# 122                                          -1266.00
# 150                                           -783.80
# 153                                               NaN
# 162                                          -1804.36
# ...                                               ...
# 549882                                       -1566.58
# 549915                                        -873.22
# 549937                                       -2729.06
# 549963                                       -2372.62
# 549989                                       -2159.02
#
#          iraRef_mp10_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                            -559.97
# 122                                            -271.94
# 150                                             210.26
# 153                                                NaN
# 162                                            -810.30
# ...                                                ...
# 549882                                         -572.52
# 549915                                          120.84
# 549937                                        -1421.08
# 549963                                        -1378.56
# 549989                                        -1164.96
#
#          iraRef_mp10_cooking_total_capitalCost  \
# bldg_id
# 119                                     254.43
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                 2371.84
# 549963                                     NaN
# 549989                                 1417.94
#
#         iraRef_mp10_cooking_net_capitalCost  \
# bldg_id
# 119                                 -818.11
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                              1299.30
# 549963                                  NaN
# 549989                               345.40
#
#          iraRef_mp10_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                      -651.97
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                  -2911.55
# 549963                                       NaN
# 549989                                   -992.34
#
#         iraRef_mp10_cooking_private_npv_moreWTP
# bldg_id
# 119                                      420.57
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -1839.01
# 549963                                      NaN
# 549989                                    80.20
#
# [15651 rows x 696 columns]

# %%
print(f"""
====================================================================================================================================================================
SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): ADOPTION POTENTIAL
====================================================================================================================================================================
determine_adoption_potential_sensitivity.py file contains the definitions for:
- adoption_decision function (combined climate + health analysis)
- calculate_climate_only_adoption_robust function (climate-only analysis)
- calculate_health_only_adoption_robust function (health-only analysis)
      
RESULTS OUTPUT (AEO2023 REFERENCE CASE):
""")

# ========================== AP2  ========================== 
print("Processing AP2 model...")

# Combined climate + health analysis (existing)
df_euss_am_mp10_home_ap2 = adoption_decision(
    df=df_euss_am_mp10_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='ap2',
    cr_function='acs',
    )

df_euss_am_mp10_home_ap2 = adoption_decision(
    df=df_euss_am_mp10_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='ap2',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp10_home_ap2 = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp10_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp10_home_ap2 = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='ap2',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp10_home_ap2 = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='ap2',
    cr_function='h6c',
    verbose=False
    )

# ====================== EASIUR ========================== 
print("Processing EASIUR model...")

# Combined climate + health analysis (existing)
df_euss_am_mp10_home_easiur = adoption_decision(
    df=df_euss_am_mp10_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='easiur',
    cr_function='acs',
    )

df_euss_am_mp10_home_easiur = adoption_decision(
    df=df_euss_am_mp10_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='easiur',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp10_home_easiur = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp10_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp10_home_easiur = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='easiur',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp10_home_easiur = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='easiur',
    cr_function='h6c',
    verbose=False
    )

# ====================== InMAP ========================== 
print("Processing InMAP model...")

# Combined climate + health analysis (existing)
df_euss_am_mp10_home_inmap = adoption_decision(
    df=df_euss_am_mp10_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='inmap',
    cr_function='acs',
    )

df_euss_am_mp10_home_inmap = adoption_decision(
    df=df_euss_am_mp10_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='inmap',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp10_home_inmap = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp10_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp10_home_inmap = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='inmap',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp10_home_inmap = calculate_health_only_adoption_robust(
    df=df_euss_am_mp10_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='inmap',
    cr_function='h6c',
    verbose=False
    )

print(f"""
====================================================================================================================================================================
DATAFRAME FOR MP10 AFTER DETERMINING ADOPTION FEASIBILITY (AEO2023 REFERENCE CASE): df_euss_am_mp10_home
Includes: Combined (Climate + Health), Climate-Only, and Health-Only Adoption Analysis

-----------------------------------------------   
AP2: 
-----------------------------------------------
      
{df_euss_am_mp10_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp10_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp10_home_inmap}
      
""")
# Out:
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): ADOPTION POTENTIAL
# ====================================================================================================================================================================
# determine_adoption_potential_sensitivity.py file contains the definitions for:
# - adoption_decision function (combined climate + health analysis)
# - calculate_climate_only_adoption_robust function (climate-only analysis)
# - calculate_health_only_adoption_robust function (health-only analysis)
#
# RESULTS OUTPUT (AEO2023 REFERENCE CASE):
#
# Processing AP2 model...
# Fixed 12 duplicate columns
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | ap2-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | ap2-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Climate-only Analysis: AEO2023 Reference Case
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | ap2-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | ap2-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# Processing EASIUR model...
# Fixed 12 duplicate columns
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | easiur-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | easiur-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Climate-only Analysis: AEO2023 Reference Case
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | easiur-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | easiur-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# Processing InMAP model...
# Fixed 12 duplicate columns
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | inmap-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | inmap-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Climate-only Analysis: AEO2023 Reference Case
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | inmap-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | inmap-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
#
# ====================================================================================================================================================================
# DATAFRAME FOR MP10 AFTER DETERMINING ADOPTION FEASIBILITY (AEO2023 REFERENCE CASE): df_euss_am_mp10_home
# Includes: Combined (Climate + Health), Climate-Only, and Health-Only Adoption Analysis
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp10_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                                666.90
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                           -1623.11
# 549963                                                NaN
# 549989                                             440.87
#
#         iraRef_mp10_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                              811.36
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                         -1496.88
# 549963                                              NaN
# 549989                                           652.55
#
#         iraRef_mp10_heating_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                            -17832.41
# 122                                             -5891.50
# 150                                              2316.71
# 153                                             -4414.39
# 162                                             -8192.32
# ...                                                  ...
# 549882                                               NaN
# 549915                                          10062.45
# 549937                                         -21274.03
# 549963                                         -18016.42
# 549989                                          -2934.04
#
#         iraRef_mp10_waterHeating_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                                1108.90
# 122                                                3431.99
# 150                                                1278.77
# 153                                                6209.50
# 162                                               -1383.76
# ...                                                    ...
# 549882                                              154.62
# 549915                                             4118.05
# 549937                                               29.95
# 549963                                              942.24
# 549989                                             2491.38
#
#         iraRef_mp10_clothesDrying_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                                -612.57
# 122                                                -233.82
# 150                                                 236.00
# 153                                                    NaN
# 162                                                -673.39
# ...                                                    ...
# 549882                                             -514.55
# 549915                                              216.26
# 549937                                            -1470.99
# 549963                                            -1338.65
# 549989                                            -1120.80
#
#          iraRef_mp10_cooking_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                                304.04
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                           -1891.69
# 549963                                                NaN
# 549989                                              -0.84
#
#          iraRef_mp10_heating_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                             -17782.20
# 122                                              -3180.30
# 150                                               7218.36
# 153                                              -3090.75
# 162                                              -4704.40
# ...                                                   ...
# 549882                                                NaN
# 549915                                           17765.34
# 549937                                          -21437.78
# 549963                                          -18145.90
# 549989                                           -2801.94
#
#         iraRef_mp10_waterHeating_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                                 927.96
# 122                                                3469.83
# 150                                                1506.68
# 153                                                6322.32
# 162                                               -1532.17
# ...                                                    ...
# 549882                                             -192.85
# 549915                                             5489.83
# 549937                                             -130.37
# 549963                                              862.36
# 549989                                             2434.71
#
#          iraRef_mp10_clothesDrying_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                                -695.14
# 122                                                -174.00
# 150                                                 276.39
# 153                                                    NaN
# 162                                                -458.54
# ...                                                    ...
# 549882                                             -423.57
# 549915                                              365.98
# 549937                                            -1549.34
# 549963                                            -1276.04
# 549989                                            -1051.47
#
#         iraRef_mp10_cooking_total_npv_healthOnly_ap2_h6c
# bldg_id
# 119                                               121.15
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                          -1974.36
# 549963                                               NaN
# 549989                                           -128.05
#
# [15651 rows x 804 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp10_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                                666.90
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                           -1623.11
# 549963                                                NaN
# 549989                                             440.87
#
#         iraRef_mp10_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                              811.36
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                         -1496.88
# 549963                                              NaN
# 549989                                           652.55
#
#         iraRef_mp10_heating_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                              -16539.90
# 122                                               -1074.15
# 150                                                4058.42
# 153                                                 390.78
# 162                                               -2304.36
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            11028.13
# 549937                                           -20875.08
# 549963                                           -17072.36
# 549989                                            -2318.84
#
#         iraRef_mp10_waterHeating_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                                1402.75
# 122                                                3677.16
# 150                                                1357.70
# 153                                                7393.04
# 162                                               -1144.91
# ...                                                    ...
# 549882                                              383.64
# 549915                                             4278.36
# 549937                                              296.61
# 549963                                             1061.69
# 549989                                             2632.04
#
#         iraRef_mp10_clothesDrying_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                                -576.63
# 122                                                -228.06
# 150                                                 250.10
# 153                                                    NaN
# 162                                                -652.77
# ...                                                    ...
# 549882                                             -505.51
# 549915                                              234.20
# 549937                                            -1439.93
# 549963                                            -1352.25
# 549989                                            -1123.71
#
#          iraRef_mp10_cooking_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                                 361.19
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1869.36
# 549963                                                 NaN
# 549989                                               36.44
#
#          iraRef_mp10_heating_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                              -14461.26
# 122                                                9197.06
# 150                                               11693.45
# 153                                                9255.33
# 162                                               10423.73
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            20246.41
# 549937                                           -20412.73
# 549963                                           -15720.28
# 549989                                            -1221.25
#
#         iraRef_mp10_waterHeating_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                                1682.96
# 122                                                4099.73
# 150                                                1709.41
# 153                                                9363.21
# 162                                                -918.46
# ...                                                    ...
# 549882                                              395.65
# 549915                                             5901.70
# 549937                                              554.79
# 549963                                             1169.24
# 549989                                             2796.15
#
#          iraRef_mp10_clothesDrying_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                                -602.76
# 122                                                -159.28
# 150                                                 312.66
# 153                                                    NaN
# 162                                                -405.52
# ...                                                    ...
# 549882                                             -400.35
# 549915                                              412.11
# 549937                                            -1469.46
# 549963                                            -1310.92
# 549989                                            -1059.02
#
#         iraRef_mp10_cooking_total_npv_healthOnly_easiur_h6c
# bldg_id
# 119                                                 267.98
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1916.99
# 549963                                                 NaN
# 549989                                              -32.26
#
# [15651 rows x 804 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp10_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                                666.90
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                           -1623.11
# 549963                                                NaN
# 549989                                             440.87
#
#         iraRef_mp10_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                              811.36
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                         -1496.88
# 549963                                              NaN
# 549989                                           652.55
#
#         iraRef_mp10_heating_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                              -16067.36
# 122                                                1192.25
# 150                                                6822.23
# 153                                               -1285.21
# 162                                                 409.45
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            11700.39
# 549937                                           -21095.69
# 549963                                           -17201.51
# 549989                                            -2681.72
#
#         iraRef_mp10_waterHeating_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                                1562.89
# 122                                                3822.32
# 150                                                1487.88
# 153                                                7011.29
# 162                                               -1014.38
# ...                                                    ...
# 549882                                              225.23
# 549915                                             4409.49
# 549937                                              143.25
# 549963                                             1043.68
# 549989                                             2535.86
#
#         iraRef_mp10_clothesDrying_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                                -539.50
# 122                                                -243.11
# 150                                                 273.08
# 153                                                    NaN
# 162                                                -706.73
# ...                                                    ...
# 549882                                             -473.91
# 549915                                              248.08
# 549937                                            -1464.58
# 549963                                            -1348.95
# 549989                                            -1111.45
#
#          iraRef_mp10_cooking_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                                 436.87
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1890.07
# 549963                                                 NaN
# 549989                                                6.90
#
#          iraRef_mp10_heating_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                              -13247.21
# 122                                               15020.20
# 150                                               18794.52
# 153                                                4949.15
# 162                                               17396.36
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            21973.58
# 549937                                           -20979.55
# 549963                                           -16052.17
# 549989                                            -2153.74
#
#         iraRef_mp10_waterHeating_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                                2094.41
# 122                                                4472.83
# 150                                                2043.85
# 153                                                8382.38
# 162                                                -583.06
# ...                                                    ...
# 549882                                              -11.33
# 549915                                             6238.65
# 549937                                              160.81
# 549963                                             1122.96
# 549989                                             2549.02
#
#          iraRef_mp10_clothesDrying_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                                -507.44
# 122                                                -197.87
# 150                                                 371.69
# 153                                                    NaN
# 162                                                -544.17
# ...                                                    ...
# 549882                                             -319.11
# 549915                                              447.74
# 549937                                            -1532.86
# 549963                                            -1302.46
# 549989                                            -1027.51
#
#         iraRef_mp10_cooking_total_npv_healthOnly_inmap_h6c
# bldg_id
# 119                                                 462.42
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1970.20
# 549963                                                 NaN
# 549989                                             -108.07
#
# [15651 rows x 804 columns]

# %% [markdown]
# # Model Runtime

# %%
# Flag to prevent excessive output in other scenario files
individual_scenario_run = False

# Get the current datetime again
end_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Calculate the elapsed time
elapsed_time = datetime.strptime(end_time, "%Y-%m-%d_%H-%M-%S") - datetime.strptime(start_time, "%Y-%m-%d_%H-%M-%S")

# Format the elapsed time
elapsed_seconds = elapsed_time.total_seconds()
elapsed_minutes = int(elapsed_seconds // 60)
elapsed_seconds = int(elapsed_seconds % 60)

# Print the elapsed time
print(f"The code took {elapsed_minutes} minutes and {elapsed_seconds} seconds to execute.")
# Out:
# The code took 3 minutes and 3 seconds to execute.
