# %%
"""
This file runs all of the code responsible for generating the output CSVs but does not visualize the data.
Data visualization is done in the main program.
"""
# Out:
# '\nThis file runs all of the code responsible for generating the output CSVs but does not visualize the data.\nData visualization is done in the main program.\n'

# %%
import os
import pandas as pd
# from IPython import get_ipython

# Format the name of the exported results file using the location ID
from datetime import datetime
result_export_time = datetime.now()
model_run_date_time = result_export_time.strftime("%Y-%m-%d_%H-%M")

from config import PROJECT_ROOT
from cmu_tare_model.utils.export_model_run_results import export_model_run_output

print(f"""
The results will be exported using the export_model_run_output function.
Documentation for this function:
{export_model_run_output.__doc__}

""")
# Out:
# Project root directory: c:\users\jorda\desktop\projects\cmu-tare-model
#
# The results will be exported using the export_model_run_output function.
# Documentation for this function:
# Export model run results to CSV files with sensitivity tracking.
#
#     This function exports DataFrame results to CSV files organized by result type.
#     For retrofit summary results, it adds sensitivity columns (RCM model and discount
#     rate method) to the DataFrame before export, enabling easy filtering and analysis
#     of sensitivity scenarios.
#
#     Directory Structure:
#         baseline_summary/summary_baseline/
#             - baseline_results_{location_id}_{date}.csv
#
#         retrofit_mp{menu_mp}_results/summary_mp{menu_mp}_{rcm_model}_{discount_rate_col}/
#             - mp{menu_mp}_results_{location_id}_{date}.csv
#             - DataFrame includes: rcm_model, discount_rate_col columns
#
#         supplemental_data_damages/{results_category}/
#             - mp{menu_mp}_{results_category}_{location_id}_{date}.csv
#
#         supplemental_data_fuelCosts/{results_category}/
#             - mp{menu_mp}_{results_category}_{location_id}_{date}.csv
#
#     Args:
#         df_results_export: DataFrame containing the results to export.
#         results_category: Category of results being exported. Valid options:
#             - 'summary_baseline': Baseline summary results
#             - 'summary': Retrofit summary results (requires rcm_model and discount_rate_col)
#             - 'damages_climate_IRA', 'damages_climate_noIRA': Climate damages
#             - 'damages_health_IRA', 'damages_health_noIRA': Health damages
#             - 'fuel_costs_IRA', 'fuel_costs_noIRA': Fuel costs
#         menu_mp: Measure package identifier (0 for baseline, 8/9/10 for retrofits).
#         output_folder_path: Base directory for all exports.
#         location_id: Location identifier for the filename (e.g., 'NYC', 'LA').
#         results_export_formatted_date: Date string for the filename (e.g., '2024_01_15').
#         rcm_model: RCM model used for health damage calculations (e.g., 'ap2', 'easiur',
#             'inmap'). Required when results_category='summary' and menu_mp != 0.
#         discount_rate_col: Discount rate method used (e.g., 'private_discount_rate_fixed_base',
#             'private_discount_rate_variable'). Required when results_category='summary' and menu_mp != 0.
#
#     Raises:
#         ValueError: If any required parameter is missing, results_category is invalid,
#             or sensitivity parameters are missing when required.
#         OSError: If there is an error creating directories or writing the file.

# %% [markdown]
# # Baseline Scenario

# %%
# ===================================================================================================================================================================================
# Measure Package 0: Baseline
# ===================================================================================================================================================================================
# BASELINE Pre-IRA Scenario:
menu_mp = 0
input_mp = 'baseline'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_baseline_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")

print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Baseline Scenario - Model Run Complete")
# Out:
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_baseline_v2_2.ipynb
#
# =========================================================================================================
# Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
# Let's start by reading the data from the NREL EUSS Database.
#
# Make sure that the zipped folders stay organized as they are once unzipped.
# If changes are made to the file path, then the program will not run properly.
# ==========================================================================================================
#
# Project root directory: c:\users\jorda\desktop\projects\cmu-tare-model
# Result outputs will be exported here: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results
#
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# Load data from the NREL EUSS Database for the baseline scenario and apply various filters.
#
# DATA: NREL EUSS Database
# HOUSING FILTERS: Occupied units and Single Family Homes
# GEOGRAPHIC FILTERS: National, State, or City
#
# Additional details data can be found in the official End-Use Load Profiles/Savings Shapes documentation.
# Our methodology is detailed in the process_euss_data.py file and its associated imports.
#
# RESULTS OUTPUT:
#
# Retrieved data for filename: baseline_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\baseline_metadata_and_annual_results.csv
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 259)
# You chose to filter for: PA
# Location ID is: PA
#
# To accurately characterize load profile, it is recommended to select subsets of data with >= 1000 models (~240,000 representative dwelling units).
#
# The following cities (number of models also shown) are available for this state:
#
# in.city
# Not in a census Place      7035
# In another census Place    5851
# PA, Philadelphia           1631
# PA, Pittsburgh              329
# PA, Erie                    105
# PA, Allentown               104
# PA, Reading                  92
# PA, Bethlehem                85
# PA, Scranton                 80
# PA, Harrisburg               63
# PA, Lancaster                58
# PA, Levittown                58
# PA, Altoona                  56
# PA, York                     56
# PA, Wilkes-Barre             48
# Name: count, dtype: int64
# You chose to analyze all of state: PA
# Location ID is: PA
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline
#
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            0  242.131013           True   2152.0
# 122            0  242.131013           True   2176.0
# 150            0  242.131013           True   1690.0
# 153            0  242.131013           True   2176.0
# 162            0  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         0  242.131013           True   1202.0
# 549915         0  242.131013           True   2176.0
# 549937         0  242.131013           True    885.0
# 549963         0  242.131013           True   1690.0
# 549989         0  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions.natural_gas.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            5540.594966
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                             890.321536
# ...                                                    ...
# 549882                                         6675.629132
# 549915                                            0.000000
# 549937                                         7002.945922
# 549963                                         8277.210267
# 549989                                            0.000000
#
#         out.emissions.propane.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions.electricity.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4179.118870
# 122                                            3794.589113
# 150                                           11378.222173
# 153                                            4612.318634
# 162                                            4330.249044
# ...                                                    ...
# 549882                                         2916.093184
# 549915                                        16728.421288
# 549937                                         3823.559604
# 549963                                         3992.118611
# 549989                                         2136.040859
#
#         out.emissions.fuel_oil.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                           13038.928166
# 150                                               0.000000
# 153                                           14589.636195
# 162                                           15002.759507
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                         6042.544365
#
#         out.emissions.natural_gas.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            5540.594966
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                             890.321536
# ...                                                    ...
# 549882                                         6675.629132
# 549915                                            0.000000
# 549937                                         7002.945922
# 549963                                         8277.210267
# 549989                                            0.000000
#
#         out.emissions.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            7380.371515
# 122                                           14675.825549
# 150                                            4530.910597
# 153                                           16564.727059
# 162                                           17837.666007
# ...                                                    ...
# 549882                                         7916.182492
# 549915                                         6870.847124
# 549937                                         8577.560537
# 549963                                         9951.214681
# 549989                                         7176.439561
#
#         out.emissions.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            9495.197860
# 122                                           16590.276103
# 150                                           10702.844907
# 153                                           18949.747039
# 162                                           20060.715408
# ...                                                    ...
# 549882                                         9422.157695
# 549915                                        15814.400458
# 549937                                        10516.078249
# 549963                                        11921.778240
# 549989                                         8281.270372
#
#         out.emissions.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            9035.427108
# 122                                           16204.985672
# 150                                            9290.264827
# 153                                           18437.677994
# 162                                           19596.115712
# ...                                                    ...
# 549882                                         9095.470037
# 549915                                        13772.445542
# 549937                                        10222.759114
# 549963                                        11608.667963
# 549989                                         8040.946248
#
#         out.emissions.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg
# bldg_id
# 119                                            9719.713836
# 122                                           16833.517280
# 150                                           11378.222173
# 153                                           19201.954829
# 162                                           20223.330087
# ...                                                    ...
# 549882                                         9591.722316
# 549915                                        16728.421288
# 549937                                        10826.505527
# 549963                                        12269.328878
# 549989                                         8402.441677
#
# [15651 rows x 259 columns]
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# In addition to the housing type and occupancy filters, the data has been filtered for fuel and technology
# Please see the energy_consumption_and_metadata folder for more details on data processing.
#
# We employ the df_enduse_refactored function to process the data and create a new dataframe, which is part of the 5-step data validation process:
# 1. Mask Initialization with initialize_validation_tracking()
# 2. Series Initialization with create_retrofit_only_series()
# 3. Valid-Only Calculation for qualifying homes
# 4. Valid-Only Updates using list-based collection
# 5. Final Masking with apply_final_masking()
#
# Documentation for df_enduse_refactored function:
# Creates a standardized energy usage DataFrame and applies data quality filters.
#
#     This function creates a new DataFrame with standardized column names and structure,
#     calculates total consumption by fuel type, creates data quality flags for analysis,
#     and sets invalid consumption values to NaN.
#
#     Args:
#         df_baseline: The baseline DataFrame containing raw EUSS/ResStock data.
#
#     Returns:
#         A standardized DataFrame with processed consumption data and data quality flags.
#
#     Raises:
#         ValueError: If required columns are missing from the input DataFrame.
#
# ----------------------------------------------------------------
#
# RESULTS OUTPUT (BASELINE):
#
# Processing column: in.clothes_dryer
# Initial data types: object
# Data types after processing: object
# Processing column: in.cooking_range
# Initial data types: object
# Data types after processing: object
# Calculated total heating consumption
# Calculated total waterHeating consumption
# Calculated total clothesDrying consumption
# Calculated total cooking consumption
#
# Creating data quality flags for all categories
#
# --- Processing heating ---
# Values in base_heating_fuel (top 5):
# base_heating_fuel
# Natural Gas    8594
# Fuel Oil       2922
# Electricity    2722
# Other Fuel      789
# Propane         615
# Name: count, dtype: int64
#   heating: Found 798 homes (5.1%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_heating_fuel
# Other Fuel    789
# Name: count, dtype: int64
# Values in heating_type (top 5):
# heating_type
# Natural Gas Fuel Furnace               5686
# Fuel Oil Fuel Furnace                  1855
# Natural Gas Fuel Wall/Floor Furnace    1437
# Natural Gas Fuel Boiler                1301
# Electricity Baseboard                  1130
# Name: count, dtype: int64
# Allowed values for heating:
# ['Electricity Baseboard', 'Electricity Electric Boiler', 'Electricity Electric Furnace', 'Fuel Oil Fuel Boiler', 'Fuel Oil Fuel Furnace', 'Natural Gas Fuel Boiler', 'Natural Gas Fuel Furnace', 'Propane Fuel Boiler', 'Propane Fuel Furnace']
#   heating: Found 3385 homes (21.6%) with invalid technology types
#   Invalid technology types (top 5):
# heating_type
# Natural Gas Fuel Wall/Floor Furnace    1437
# Electricity ASHP                        684
# Natural Gas Shared Heating              170
# Propane Fuel Wall/Floor Furnace         121
# Fuel Oil Fuel Wall/Floor Furnace         93
# Name: count, dtype: int64
#   heating: Total 3385 homes (21.6%) excluded from analysis
#
# --- Processing waterHeating ---
# Values in base_waterHeating_fuel (top 5):
# base_waterHeating_fuel
# Natural Gas    8669
# Electricity    4652
# Fuel Oil       1728
# Propane         578
# Other Fuel       24
# Name: count, dtype: int64
#   waterHeating: Found 24 homes (0.2%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_waterHeating_fuel
# Other Fuel    24
# Name: count, dtype: int64
# Values in waterHeating_type (top 5):
# waterHeating_type
# Natural Gas Standard    7788
# Electric Standard       3698
# Fuel Oil Standard       1142
# Electric Premium         824
# Natural Gas Premium      673
# Name: count, dtype: int64
# Allowed values for waterHeating:
# ['Electric Premium', 'Electric Standard', 'Fuel Oil Premium', 'Fuel Oil Standard', 'Natural Gas Premium', 'Natural Gas Standard', 'Propane Premium', 'Propane Standard']
#   waterHeating: Found 652 homes (4.2%) with invalid technology types
#   Invalid technology types (top 5):
# waterHeating_type
# FIXME Fuel Oil Indirect       261
# Natural Gas Tankless          208
# Electric Tankless             100
# Electric Heat Pump, 80 gal     30
# Propane Tankless               29
# Name: count, dtype: int64
#   waterHeating: Total 652 homes (4.2%) excluded from analysis
#
# --- Processing clothesDrying ---
# Values in base_clothesDrying_fuel (top 5):
# base_clothesDrying_fuel
# Electricity    10551
# Natural Gas     3899
# Propane          293
# Name: count, dtype: int64
#   clothesDrying: Found 908 homes (5.8%) with invalid fuel types
#   Invalid fuel types (top 5):
# Series([], Name: count, dtype: int64)
#   clothesDrying: Technology validation not applicable (no technology type column)
#   clothesDrying: Total 908 homes (5.8%) excluded from analysis
#
# --- Processing cooking ---
# Values in base_cooking_fuel (top 5):
# base_cooking_fuel
# Electricity    7620
# Natural Gas    6686
# Propane        1181
# Name: count, dtype: int64
#   cooking: Found 7784 homes (49.7%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_cooking_fuel
# Electricity    7620
# Name: count, dtype: int64
#   cooking: Technology validation not applicable (no technology type column)
#   cooking: Total 7784 homes (49.7%) excluded from analysis
#
# Total 9976 homes (63.7%) excluded from all categories
#
# Applying data validation (baseline only):
# Baseline calculation for heating:
#   - 12266 homes have valid data
#   - 3385 homes have invalid data (values will be NaN)
#   base_electricity_heating_consumption: Masked 3385 values
#   base_naturalGas_heating_consumption: Masked 3385 values
#   base_fuelOil_heating_consumption: Masked 3385 values
#   base_propane_heating_consumption: Masked 3385 values
#   baseline_heating_consumption: Masked 2587 values
# Baseline calculation for waterHeating:
#   - 14999 homes have valid data
#   - 652 homes have invalid data (values will be NaN)
#   base_electricity_waterHeating_consumption: Masked 652 values
#   base_naturalGas_waterHeating_consumption: Masked 652 values
#   base_fuelOil_waterHeating_consumption: Masked 652 values
#   base_propane_waterHeating_consumption: Masked 652 values
#   baseline_waterHeating_consumption: Masked 628 values
# Baseline calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 908 homes have invalid data (values will be NaN)
#   base_electricity_clothesDrying_consumption: Masked 908 values
#   base_naturalGas_clothesDrying_consumption: Masked 908 values
#   base_propane_clothesDrying_consumption: Masked 908 values
# Baseline calculation for cooking:
#   - 7867 homes have valid data
#   - 7784 homes have invalid data (values will be NaN)
#   base_electricity_cooking_consumption: Masked 7784 values
#   base_naturalGas_cooking_consumption: Masked 7784 values
#   base_propane_cooking_consumption: Masked 7784 values
#   baseline_cooking_consumption: Masked 7620 values
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline_home
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... valid_fuel_heating  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...               True
# 122      In another census Place   Suburban  ...               True
# 150      In another census Place      Rural  ...               True
# 153        Not in a census Place   Suburban  ...               True
# 162        Not in a census Place   Suburban  ...               True
# ...                          ...        ...  ...                ...
# 549882     Not in a census Place   Suburban  ...               True
# 549915                 Lancaster   Suburban  ...               True
# 549937   In another census Place      Rural  ...               True
# 549963   In another census Place   Suburban  ...               True
# 549989     Not in a census Place      Rural  ...               True
#
#         valid_tech_heating include_heating valid_fuel_waterHeating  \
# bldg_id
# 119                   True            True                    True
# 122                   True            True                    True
# 150                   True            True                    True
# 153                   True            True                    True
# 162                   True            True                    True
# ...                    ...             ...                     ...
# 549882               False           False                    True
# 549915                True            True                    True
# 549937                True            True                    True
# 549963                True            True                    True
# 549989                True            True                    True
#
#         valid_tech_waterHeating  include_waterHeating  \
# bldg_id
# 119                        True                  True
# 122                        True                  True
# 150                        True                  True
# 153                        True                  True
# 162                        True                  True
# ...                         ...                   ...
# 549882                     True                  True
# 549915                     True                  True
# 549937                     True                  True
# 549963                     True                  True
# 549989                     True                  True
#
#          valid_fuel_clothesDrying include_clothesDrying valid_fuel_cooking  \
# bldg_id
# 119                          True                  True               True
# 122                          True                  True              False
# 150                          True                  True              False
# 153                         False                 False              False
# 162                          True                  True              False
# ...                           ...                   ...                ...
# 549882                       True                  True              False
# 549915                       True                  True              False
# 549937                       True                  True               True
# 549963                       True                  True              False
# 549989                       True                  True               True
#
#         include_cooking
# bldg_id
# 119                True
# 122               False
# 150               False
# 153               False
# 162               False
# ...                 ...
# 549882            False
# 549915            False
# 549937             True
# 549963            False
# 549989             True
#
# [15651 rows x 61 columns]
#
#
# ====================================================================================================================================================================
#
# DATAFRAME: df_euss_am_baseline_home
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... valid_fuel_heating  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...               True
# 122      In another census Place   Suburban  ...               True
# 150      In another census Place      Rural  ...               True
# 153        Not in a census Place   Suburban  ...               True
# 162        Not in a census Place   Suburban  ...               True
# ...                          ...        ...  ...                ...
# 549882     Not in a census Place   Suburban  ...               True
# 549915                 Lancaster   Suburban  ...               True
# 549937   In another census Place      Rural  ...               True
# 549963   In another census Place   Suburban  ...               True
# 549989     Not in a census Place      Rural  ...               True
#
#         valid_tech_heating include_heating valid_fuel_waterHeating  \
# bldg_id
# 119                   True            True                    True
# 122                   True            True                    True
# 150                   True            True                    True
# 153                   True            True                    True
# 162                   True            True                    True
# ...                    ...             ...                     ...
# 549882               False           False                    True
# 549915                True            True                    True
# 549937                True            True                    True
# 549963                True            True                    True
# 549989                True            True                    True
#
#         valid_tech_waterHeating  include_waterHeating  \
# bldg_id
# 119                        True                  True
# 122                        True                  True
# 150                        True                  True
# 153                        True                  True
# 162                        True                  True
# ...                         ...                   ...
# 549882                     True                  True
# 549915                     True                  True
# 549937                     True                  True
# 549963                     True                  True
# 549989                     True                  True
#
#          valid_fuel_clothesDrying include_clothesDrying valid_fuel_cooking  \
# bldg_id
# 119                          True                  True               True
# 122                          True                  True              False
# 150                          True                  True              False
# 153                         False                 False              False
# 162                          True                  True              False
# ...                           ...                   ...                ...
# 549882                       True                  True              False
# 549915                       True                  True              False
# 549937                       True                  True               True
# 549963                       True                  True              False
# 549989                       True                  True               True
#
#         include_cooking
# bldg_id
# 119                True
# 122               False
# 150               False
# 153               False
# 162               False
# ...                 ...
# 549882            False
# 549915            False
# 549937             True
# 549963            False
# 549989             True
#
# [15651 rows x 61 columns]
#
#
#
#     -------------------------------------------------------------------------------------------------------
#     PRE-IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2021 RELEASE
#     -------------------------------------------------------------------------------------------------------
#
#
#
#     Retrieved data for filename: cambium21_midCase_annual_gea.xlsx
#     Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\projections\cambium21_midCase_annual_gea.xlsx
#
#     Loading dataframe ...
#
#               dataset scenario gea_region  year  cef_gen  aer_co2e_kg_per_MWh  \
# 0    Cambium_2021  MidCase      AZNMc  2022      NaN                423.2
# 1    Cambium_2021  MidCase      AZNMc  2024      NaN                389.5
# 2    Cambium_2021  MidCase      AZNMc  2026      NaN                374.7
# 3    Cambium_2021  MidCase      AZNMc  2028      NaN                364.8
# 4    Cambium_2021  MidCase      AZNMc  2030      NaN                315.8
# ..            ...      ...        ...   ...      ...                  ...
# 295  Cambium_2021  MidCase      SRVCc  2042      NaN                240.8
# 296  Cambium_2021  MidCase      SRVCc  2044      NaN                222.5
# 297  Cambium_2021  MidCase      SRVCc  2046      NaN                178.5
# 298  Cambium_2021  MidCase      SRVCc  2048      NaN                182.1
# 299  Cambium_2021  MidCase      SRVCc  2050      NaN                169.3
#
#      lrmer_co2e_kg_per_MWh  srmer_co2e_kg_per_MWh  generation  \
# 0                    525.6                  811.8   143037980
# 1                    488.4                  808.4   151806820
# 2                    423.1                  816.0   154638340
# 3                    315.8                  784.7   159426910
# 4                    313.6                  749.8   175350740
# ..                     ...                    ...         ...
# 295                  313.9                  805.5   400253860
# 296                  314.6                  786.1   427886080
# 297                  320.6                  754.9   444492960
# 298                  317.9                  751.3   453625180
# 299                  306.7                  718.3   466444480
#
#      variable_generation  ...  total_coal  total_natural_gas  total_oil  \
# 0             27345228.0  ...  32912356.0         40391114.7    29364.0
# 1             29423460.0  ...  27460646.0         52221791.8    14086.3
# 2             29648762.0  ...  26772840.0         53833046.4     8814.2
# 3             32619604.0  ...  26693880.0         55589546.7    10161.3
# 4             50951904.0  ...  24898662.0         54122073.2    13228.5
# ..                   ...  ...         ...                ...        ...
# 295           96427260.0  ...  37576316.0        117368159.3     2205.4
# 296          115764890.0  ...  33240228.0        125603043.3     1392.8
# 297          150328400.0  ...  27152428.0        105858843.0       74.8
# 298          152065260.0  ...  27861414.0        111393181.0       49.1
# 299          154687700.0  ...  14777366.0        134385100.3        9.9
#
#      total_nuclear  total_renewable  fraction_coal  fraction_natural_gas  \
# 0         31446266       37669404.5       0.231047              0.283549
# 1         31446266       40074547.2       0.181597              0.345343
# 2         31446266       41990327.2       0.173792              0.349449
# 3         31446266       45101365.5       0.168054              0.349969
# 4         31446266       64294435.2       0.142462              0.309668
# ..             ...              ...            ...                   ...
# 295      122300980      121063293.0       0.094339              0.294665
# 296      122300980      144866950.7       0.078026              0.294834
# 297      122300980      187251355.2       0.061353              0.239195
# 298      122300980      190141835.5       0.061682              0.246610
# 299      122300980      193718661.2       0.031767              0.288887
#
#      fraction_oil  fraction_nuclear  fraction_renewable
# 0    2.061377e-04          0.220755            0.264442
# 1    9.315268e-05          0.207954            0.265013
# 2    5.721601e-05          0.204129            0.272574
# 3    6.397143e-05          0.197973            0.283940
# 4    7.568889e-05          0.179925            0.367870
# ..            ...               ...                 ...
# 295  5.536880e-06          0.307049            0.303942
# 296  3.269387e-06          0.287083            0.340053
# 297  1.690152e-07          0.276347            0.423106
# 298  1.087011e-07          0.270759            0.420950
# 299  2.128199e-08          0.262910            0.416436
#
# [300 rows x 43 columns]
#
#     Creating lookup dictionary for LRMER and SRMER ...
#     -------------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------------
#     IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2022 RELEASE
#     -------------------------------------------------------------------------------------------------------
#
#
#     Retrieved data for filename: cambium22_allScenarios_annual_gea.xlsx
#     Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\projections\cambium22_allScenarios_annual_gea.xlsx
#
#     Loading dataframe ...
#
#           data_source scenario gea_region  year  cef_gen  aer_co2e_kg_per_MWh  \
# 0    Cambium_2022  MidCase      AZNMc  2024     0.63                279.4
# 1    Cambium_2022  MidCase      AZNMc  2026     0.69                237.5
# 2    Cambium_2022  MidCase      AZNMc  2028     0.80                157.9
# 3    Cambium_2022  MidCase      AZNMc  2030     0.84                133.3
# 4    Cambium_2022  MidCase      AZNMc  2035     0.89                 81.9
# ..            ...      ...        ...   ...      ...                  ...
# 155  Cambium_2022  MidCase      SRVCc  2030     0.75                147.1
# 156  Cambium_2022  MidCase      SRVCc  2035     0.83                 92.1
# 157  Cambium_2022  MidCase      SRVCc  2040     0.86                 75.5
# 158  Cambium_2022  MidCase      SRVCc  2045     0.93                 38.7
# 159  Cambium_2022  MidCase      SRVCc  2050     0.93                 38.9
#
#      lrmer_co2e_kg_per_MWh  srmer_co2e_kg_per_MWh  generation  \
# 0                    326.9                  777.1   185725700
# 1                    193.9                  709.7   192790580
# 2                    130.5                  576.4   193906060
# 3                    103.7                  486.7   193562020
# 4                    149.4                  398.4   210627860
# ..                     ...                    ...         ...
# 155                  211.7                  662.9   391723170
# 156                  211.6                  583.4   459622500
# 157                  188.3                  540.5   481364480
# 158                  142.2                  497.4   501150400
# 159                  113.2                  511.2   501907700
#
#      variable_generation  ...  total_coal  total_natural_gas  total_oil  \
# 0             74605900.0  ...  22849070.0         46188801.1    35759.0
# 1             87517200.0  ...  21009922.0         38928884.4    26155.8
# 2            108173544.0  ...  14483350.0         25156486.8    19751.4
# 3            113367950.0  ...  13433882.0         18404394.4     2684.8
# 4            128952530.0  ...   8231337.5         14217323.4     4222.1
# ..                   ...  ...         ...                ...        ...
# 155          139815250.0  ...  17312904.0         79749385.0     2648.2
# 156          209080400.0  ...   8787109.0         67359566.6     2424.3
# 157          229834830.0  ...   6132569.5         60580299.5     2979.2
# 158          265812640.0  ...   4301606.5         28826117.4      748.2
# 159          271552540.0  ...   1924772.2         34071135.0       17.9
#
#      total_nuclear  total_renewable  fraction_coal  fraction_natural_gas  \
# 0       30865014.0       85518978.5       0.123204              0.249053
# 1       30392044.0      102169009.2       0.109128              0.202201
# 2       29352388.0      124638520.0       0.074791              0.129907
# 3       28571094.0      132901330.4       0.069493              0.095205
# 4       27536908.0      160412983.2       0.039122              0.067572
# ..             ...              ...            ...                   ...
# 155    119012670.0      173052397.5       0.044491              0.204943
# 156    116559336.0      264783518.0       0.019207              0.147237
# 157    115754584.0      296807708.5       0.012795              0.126399
# 158    114458344.0      352150817.0       0.008608              0.057683
# 159    111073256.0      353415175.0       0.003846              0.068076
#
#      fraction_oil  fraction_nuclear  fraction_renewable
# 0    1.928149e-04          0.166426            0.461124
# 1    1.358559e-04          0.157859            0.530676
# 2    1.019951e-04          0.151574            0.643626
# 3    1.388833e-05          0.147797            0.687492
# 4    2.006675e-05          0.130877            0.762409
# ..            ...               ...                 ...
# 155  6.805438e-06          0.305843            0.444716
# 156  5.299110e-06          0.254779            0.578772
# 157  6.216015e-06          0.241519            0.619281
# 158  1.497186e-06          0.229037            0.704671
# 159  3.576535e-08          0.221932            0.706146
#
# [160 rows x 44 columns]
#
#     Creating lookup dictionary for 2024 LRMER and SRMER ...
#     -------------------------------------------------------------------------------------------------------
#
# Fuel sources in df_grid_mix: {'Nuclear', 'Renewable', 'Coal', 'Oil', 'Natural Gas'}
# Fuel sources in df_grid_emis_factors: {'Nuclear', 'Coal', 'Renewables', 'Oil', 'Natural Gas'}
# Retrieved data for filename: bls_cpiu_2005-2023.xlsx
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\inflation_data\bls_cpiu_2005-2023.xlsx
#     year  cpiu_annual
# 0   2005      195.300
# 1   2006      201.600
# 2   2007      207.342
# 3   2008      215.303
# 4   2009      214.537
# 5   2010      218.056
# 6   2011      224.939
# 7   2012      229.594
# 8   2013      232.957
# 9   2014      236.736
# 10  2015      237.017
# 11  2016      240.007
# 12  2017      245.120
# 13  2018      251.107
# 14  2019      255.657
# 15  2020      258.811
# 16  2021      270.970
# 17  2022      292.655
# 18  2023      304.702
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# ...
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#         baseline_cooking_lifetime_damages_health_inmap_h6c fuel_type_heating  \
# bldg_id
# 119                                                 380.50        naturalGas
# 122                                                    NaN           fuelOil
# 150                                                    NaN       electricity
# 153                                                    NaN           fuelOil
# 162                                                    NaN           fuelOil
# ...                                                    ...               ...
# 549882                                                 NaN        naturalGas
# 549915                                                 NaN       electricity
# 549937                                              129.68        naturalGas
# 549963                                                 NaN        naturalGas
# 549989                                              146.99           fuelOil
#
#         fuel_type_waterHeating fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 119                 naturalGas              naturalGas         naturalGas
# 122                    fuelOil             electricity        electricity
# 150                electricity             electricity        electricity
# 153                    fuelOil                     NaN        electricity
# 162                 naturalGas             electricity        electricity
# ...                        ...                     ...                ...
# 549882              naturalGas             electricity        electricity
# 549915             electricity             electricity        electricity
# 549937              naturalGas              naturalGas         naturalGas
# 549963              naturalGas             electricity        electricity
# 549989                 fuelOil             electricity            propane
#
#          baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                  9692.04
# 122                                 56634.48
# 150                                 48835.85
# 153                                 52691.10
# 162                                 69001.23
# ...                                      ...
# 549882                                   NaN
# 549915                              52898.91
# 549937                               8456.00
# 549963                              17473.34
# 549989                              22285.90
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                        351.02
# 122                                        619.28
# 150                                        718.64
# 153                                           NaN
# 162                                       2222.41
# ...                                           ...
# 549882                                     997.02
# 549915                                    1736.07
# 549937                                     982.27
# 549963                                     898.31
# 549989                                     898.31
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 126 columns]
#
# df_baseline_fuel_costs: DataFrame containing the baseline scenario data with fuel costs
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  baseline_2030_cooking_fuel_cost  \
# bldg_id                            ...
# 119                          True  ...                            38.66
# 122                          True  ...                              NaN
# 150                          True  ...                              NaN
# 153                         False  ...                              NaN
# 162                          True  ...                              NaN
# ...                           ...  ...                              ...
# 549882                       True  ...                              NaN
# 549915                       True  ...                              NaN
# 549937                       True  ...                            52.58
# 549963                       True  ...                              NaN
# 549989                       True  ...                           108.64
#
#          baseline_2031_cooking_fuel_cost  baseline_2032_cooking_fuel_cost  \
# bldg_id
# 119                                38.81                            38.64
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             52.79                            52.56
# 549963                               NaN                              NaN
# 549989                            109.76                           111.26
#
#          baseline_2033_cooking_fuel_cost  baseline_2034_cooking_fuel_cost  \
# bldg_id
# 119                                39.10                            39.11
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.19                            53.20
# 549963                               NaN                              NaN
# 549989                            112.94                           114.21
#
#          baseline_2035_cooking_fuel_cost  baseline_2036_cooking_fuel_cost  \
# bldg_id
# 119                                39.02                            38.84
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.07                            52.84
# 549963                               NaN                              NaN
# 549989                            115.40                           116.58
#
#          baseline_2037_cooking_fuel_cost  baseline_2038_cooking_fuel_cost  \
# bldg_id
# 119                                39.25                            39.49
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.38                            53.71
# 549963                               NaN                              NaN
# 549989                            117.97                           119.31
#
#          baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                   589.84
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                802.29
# 549963                                   NaN
# 549989                               1691.55
#
# [15651 rows x 70 columns]
#
#
# The code took 0 minutes and 45 seconds to execute.
# Baseline Scenario - Model Run Complete

# %%
print(output_folder_path)
# Out:
# c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_baseline_damages_climate,
    results_category='damages_climate_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_baseline_damages_health,
    results_category='damages_health_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_baseline_fuel_costs,
    results_category='fuel_costs_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# ===== SUMMARY RESULTS =====
export_model_run_output(
    df_results_export=df_euss_am_baseline_home,
    results_category='summary_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )
# Out:
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_baseline
# Saved to: mp0_damages_climate_baseline_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_baseline\mp0_damages_climate_baseline_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_baseline
# Saved to: mp0_damages_health_baseline_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_baseline\mp0_damages_health_baseline_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_baseline
# Saved to: mp0_fuel_costs_baseline_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_baseline\mp0_fuel_costs_baseline_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# BASELINE SUMMARY RESULTS:
# Saved to: baseline_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\baseline_summary\summary_baseline\baseline_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------

# %%
print("""
Scenarios for Basic, Moderate, and Advanced Retrofit
- Rows in the Baseline CSV are merged with the Post-Retrofit Measure Package.
- The same filters are applied.

-------------------------------------------------------------------------------------------------------
MODEL SCENARIOS
-------------------------------------------------------------------------------------------------------
- BASIC/MODERATE/ADVANCED Pre-IRA Scenario:
    - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
    - AEO2023 No Inflation Reduction Act
    - Cambium 2021 MidCase
      
- BASIC/MODERATE/ADVANCED IRA-Reference Scenario:
    - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
    - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
    - Cambium 2022 and 2023 MidCase
""")
# Out:
# Scenarios for Basic, Moderate, and Advanced Retrofit
# - Rows in the Baseline CSV are merged with the Post-Retrofit Measure Package.
# - The same filters are applied.
#
# -------------------------------------------------------------------------------------------------------
# MODEL SCENARIOS
# -------------------------------------------------------------------------------------------------------
# - BASIC/MODERATE/ADVANCED Pre-IRA Scenario:
#     - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
#     - AEO2023 No Inflation Reduction Act
#     - Cambium 2021 MidCase
#
# - BASIC/MODERATE/ADVANCED IRA-Reference Scenario:
#     - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
#     - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
#     - Cambium 2022 and 2023 MidCase

# %% [markdown]
# -------------------------------------------------------------------------------------------------------
# # POST-RETROFIT SCENARIOS: Basic (MP8), Moderate (MP9), Advanced (MP10)
# -------------------------------------------------------------------------------------------------------
# ## No IRA Scenario:
# - AEO2023 No Inflation Reduction Act
# - Cambium 2021 MidCase
# ## IRA-Reference Scenario:
# - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
# - Cambium 2022 and 2023 MidCase
# -------------------------------------------------------------------------------------------------------

# %%
from cmu_tare_model.constants import CR_FUNCTIONS, RCM_MODELS
from cmu_tare_model.utils.discounting import PRIVATE_DISCOUNT_RATE_COLS

# %% [markdown]
# ## Basic Retrofit: Measure Package 8 (MP8)

# %%
# Measure Package 8
menu_mp = 8
input_mp = 'upgrade08'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_basic_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Basic Retrofit Scenario - Model Run Complete")
# Out:
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_basic_v2_2.ipynb
#
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (MP8).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 346)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            7  242.131013           True   2152.0
# 122            7  242.131013           True   2176.0
# 150            7  242.131013          False   1690.0
# 153            7  242.131013           True   2176.0
# 162            7  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         7  242.131013           True   1202.0
# 549915         7  242.131013          False   2176.0
# 549937         7  242.131013           True    885.0
# 549963         7  242.131013           True   1690.0
# 549989         7  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4367.397352
# 122                                           10479.768179
# 150                                               0.000000
# 153                                           11048.097647
# 162                                           12947.903971
# ...                                                    ...
# 549882                                         5212.871757
# 549915                                            0.000000
# 549937                                         4636.242910
# 549963                                         4903.857419
# 549989                                         4686.866540
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2552.828291
# 122                                            6954.371623
# 150                                               0.000000
# 153                                            6200.439415
# 162                                            8666.012863
# ...                                                    ...
# 549882                                         3310.560695
# 549915                                            0.000000
# 549937                                         1673.632015
# 549963                                          609.743358
# 549989                                         2436.617472
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            2985.641141
# 122                                            7797.415226
# 150                                               0.000000
# 153                                            7363.122758
# 162                                            9676.629818
# ...                                                    ...
# 549882                                         3739.637305
# 549915                                            0.000000
# 549937                                         2257.364571
# 549963                                         1488.137683
# 549989                                         2959.741017
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2356.289439
# 122                                            6648.492515
# 150                                               0.000000
# 153                                            5775.168899
# 162                                            8324.377523
# ...                                                    ...
# 549882                                         3185.908976
# 549915                                            0.000000
# 549937                                         1154.203887
# 549963                                          -84.117798
# 549989                                         2177.081897
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 119      Electric, 100% Usage  Electric, 100% Usage
# 122                       NaN                   NaN
# 150                       NaN                   NaN
# 153                       NaN                   NaN
# 162                       NaN                   NaN
# ...                       ...                   ...
# 549882                    NaN                   NaN
# 549915                    NaN                   NaN
# 549937   Electric, 120% Usage  Electric, 120% Usage
# 549963                    NaN                   NaN
# 549989                    NaN  Electric, 100% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 122                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 150                                 NaN                                NaN
# 153                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 162                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# ...                                 ...                                ...
# 549882                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
# 549915                              NaN                                NaN
# 549937                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549963                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549989                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150                                       NaN
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                                    NaN
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 346 columns]
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Basic-BAU:
# Basic Retrofit: Measure Package 8
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade08_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade08_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 347)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 347)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 347)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 347)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            8  242.131013           True   2152.0
# 122            8  242.131013           True   2176.0
# 150            8  242.131013           True   1690.0
# 153            8  242.131013           True   2176.0
# 162            8  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         8  242.131013           True   1202.0
# 549915         8  242.131013           True   2176.0
# 549937         8  242.131013           True    885.0
# 549963         8  242.131013           True   1690.0
# 549989         8  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            5063.088752
# 122                                           12066.712342
# 150                                            3103.153770
# 153                                           12691.688692
# 162                                           14912.014271
# ...                                                    ...
# 549882                                         5882.269769
# 549915                                         3949.186094
# 549937                                         5643.594000
# 549963                                         6479.951652
# 549989                                         5231.517125
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4214.733128
# 122                                           10590.254662
# 150                                            7434.178003
# 153                                           10026.235230
# 162                                           13274.793477
# ...                                                    ...
# 549882                                         4814.108725
# 549915                                         9153.072186
# 549937                                         3941.494074
# 549963                                         4162.716516
# 549989                                         3713.809302
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            4421.232869
# 122                                           10962.614536
# 150                                            6435.450158
# 153                                           10675.202534
# 162                                           13682.148002
# ...                                                    ...
# 549882                                         5058.857189
# 549915                                         7958.419199
# 549937                                         4289.405772
# 549963                                         4656.122049
# 549989                                         4068.275863
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4103.394799
# 122                                           10472.994231
# 150                                            7914.527787
# 153                                            9808.721813
# 162                                           13130.752498
# ...                                                    ...
# 549882                                         4740.981471
# 549915                                         9734.504122
# 549937                                         3628.586099
# 549963                                         3803.239573
# 549989                                         3542.402188
#
#                                      upgrade.clothes_dryer  \
# bldg_id
# 119      Electric, Premium, Heat Pump, Ventless, 100% U...
# 122      Electric, Premium, Heat Pump, Ventless, 100% U...
# 150      Electric, Premium, Heat Pump, Ventless, 80% Usage
# 153                                                    NaN
# 162      Electric, Premium, Heat Pump, Ventless, 80% Usage
# ...                                                    ...
# 549882   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549915   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549937   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549963   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549989   Electric, Premium, Heat Pump, Ventless, 100% U...
#
#                    upgrade.cooking_range upgrade.hvac_cooling_efficiency  \
# bldg_id
# 119      Electric, Induction, 100% Usage                       Heat Pump
# 122      Electric, Induction, 100% Usage                       Heat Pump
# 150       Electric, Induction, 80% Usage                       Heat Pump
# 153      Electric, Induction, 120% Usage                       Heat Pump
# 162       Electric, Induction, 80% Usage                       Heat Pump
# ...                                  ...                             ...
# 549882   Electric, Induction, 120% Usage                       Heat Pump
# 549915   Electric, Induction, 100% Usage                       Heat Pump
# 549937   Electric, Induction, 120% Usage                       Heat Pump
# 549963   Electric, Induction, 100% Usage                       Heat Pump
# 549989   Electric, Induction, 100% Usage                       Heat Pump
#
#             upgrade.hvac_heating_efficiency upgrade.hvac_heating_type  \
# bldg_id
# 119                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 122                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 150      MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 153                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 162                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# ...                                     ...                       ...
# 549882   MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 549915               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549937               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549963               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549989               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150      Electric Heat Pump, 66 gal, 3.35 UEF
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915   Electric Heat Pump, 80 gal, 3.45 UEF
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 347 columns]
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 8 (MP8)
# ====================================================================================================================================================================
# You'll notice that the number of rows differs from df_euss_am_mp7 and df_euss_am_mp8.
#       - df_euss_am_baseline_home has fewer rows (representative dwelling units) because a tech filter was applied.
#       - df_euss_am_mp8_home will have the same number of rows as df_euss_am_baseline_home after df_enduse_compare function is run.
#       - df_enduse_compare function performs an inner merge on the two dataframes, keeping only the rows that are present in both dataframes.
# ====================================================================================================================================================================
# df_euss_am_mp8_home will be created by running the df_enduse_compare function (contains post-retrofit consumption data for the entire home in 2024).
# process_euss_data.py file contains the function definition.
#
# Documentation for df_enduse_compare function:
# Creates a comparison DataFrame by merging multiple DataFrames based on measure packages.
#
#     This function constructs a new DataFrame (df_compare) that includes columns
#     from df_mp, df_cooking_range, and merges them with df_baseline to compare
#     baseline vs. measure package outputs for heating, water heating, clothes drying,
#     and cooking.
#
#     Args:
#         df_mp: The main DataFrame containing modeling parameters and outputs.
#         input_mp: The input measure package ID (e.g., 'upgrade09', 'upgrade10').
#         menu_mp: The menu measure package number.
#         df_baseline: The baseline DataFrame to merge with df_compare.
#         df_cooking_range: Additional DataFrame for cooking range parameters/outputs.
#
#     Returns:
#         A merged DataFrame (df_compare) that includes relevant columns for
#         baseline and measure packages comparison.
#
# ----------------------------------------------------------------
#
# RESULTING DATAFRAME:
#
#
# Applying combined validation (data quality + retrofit status):
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
#   mp8_heating_consumption: Masked 3385 values
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
#   mp8_waterHeating_consumption: Masked 652 values
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
#   mp8_clothesDrying_consumption: Masked 908 values
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#   mp8_cooking_consumption: Masked 7784 values
#
# ====================================================================================================================================================================
# PUBLIC IMPACTS: DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
#
#
#
#  Creating dataframe to store marginal damages calculations ...
#
# ====================================================================================================================================================================
# df_euss_am_baseline_home: DataFrame containing the baseline scenario data
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#         baseline_cooking_lifetime_damages_health_inmap_h6c fuel_type_heating  \
# bldg_id
# 119                                                 380.50        naturalGas
# 122                                                    NaN           fuelOil
# 150                                                    NaN       electricity
# 153                                                    NaN           fuelOil
# 162                                                    NaN           fuelOil
# ...                                                    ...               ...
# 549882                                                 NaN        naturalGas
# 549915                                                 NaN       electricity
# 549937                                              129.68        naturalGas
# 549963                                                 NaN        naturalGas
# 549989                                              146.99           fuelOil
#
#         fuel_type_waterHeating fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 119                 naturalGas              naturalGas         naturalGas
# 122                    fuelOil             electricity        electricity
# 150                electricity             electricity        electricity
# 153                    fuelOil                     NaN        electricity
# 162                 naturalGas             electricity        electricity
# ...                        ...                     ...                ...
# 549882              naturalGas             electricity        electricity
# 549915             electricity             electricity        electricity
# 549937              naturalGas              naturalGas         naturalGas
# 549963              naturalGas             electricity        electricity
# 549989                 fuelOil             electricity            propane
#
#          baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                  9692.04
# 122                                 56634.48
# 150                                 48835.85
# 153                                 52691.10
# 162                                 69001.23
# ...                                      ...
# 549882                                   NaN
# 549915                              52898.91
# 549937                               8456.00
# 549963                              17473.34
# 549989                              22285.90
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                        351.02
# 122                                        619.28
# 150                                        718.64
# 153                                           NaN
# 162                                       2222.41
# ...                                           ...
# 549882                                     997.02
# 549915                                    1736.07
# 549937                                     982.27
# 549963                                     898.31
# 549989                                     898.31
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 126 columns]
#
# df_baseline_damages_health: DataFrame containing the baseline scenario data with health damages
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          baseline_2038_cooking_damages_so2_inmap_h6c  \
# bldg_id
# 119                                             0.92
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          0.63
# 549963                                           NaN
# 549989                                          0.82
#
#          baseline_2038_cooking_damages_nox_inmap_h6c  \
# bldg_id
# 119                                            17.35
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          7.15
# 549963                                           NaN
# 549989                                          8.32
#
#          baseline_2038_cooking_damages_pm25_inmap_h6c  \
# bldg_id
# 119                                              8.30
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                           0.91
# 549963                                            NaN
# 549989                                           0.68
#
#          baseline_2038_cooking_damages_health_inmap_h6c  \
# bldg_id
# 119                                               26.56
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                             8.69
# 549963                                              NaN
# 549989                                             9.83
#
#          baseline_cooking_lifetime_damages_health_ap2_acs  \
# bldg_id
# 119                                                 37.49
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              20.82
# 549963                                                NaN
# 549989                                              23.53
#
#          baseline_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 96.32
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              53.48
# 549963                                                NaN
# 549989                                              60.44
#
#          baseline_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 130.47
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               73.35
# 549963                                                 NaN
# 549989                                               59.17
#
#          baseline_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 335.21
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# ...
# 549882                                                 NaN
# 549915                                            37112.47
# 549937                                            -1734.11
# 549963                                             -509.56
# 549989                                             6983.13
#
#         iraRef_mp8_waterHeating_total_npv_healthOnly_easiur_h6c_fixed_base  \
# bldg_id
# 119                                                1510.09
# 122                                                3284.31
# 150                                                 781.10
# 153                                                9938.25
# 162                                               -1595.39
# ...                                                    ...
# 549882                                             -159.02
# 549915                                             5512.27
# 549937                                             1856.42
# 549963                                             1055.54
# 549989                                             2140.85
#
#          iraRef_mp8_clothesDrying_total_npv_healthOnly_easiur_h6c_fixed_base  \
# bldg_id
# 119                                                 650.96
# 122                                                 288.27
# 150                                                -539.62
# 153                                                    NaN
# 162                                                -705.66
# ...                                                    ...
# 549882                                             -660.28
# 549915                                              902.83
# 549937                                             -498.67
# 549963                                               28.10
# 549989                                             -496.62
#
#         iraRef_mp8_cooking_total_npv_healthOnly_easiur_h6c_fixed_base
# bldg_id
# 119                                                -433.08
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -250.21
# 549963                                                 NaN
# 549989                                             -864.59
#
# [15651 rows x 774 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp8_cooking_total_npv_climateOnly_central_fixed_base  \
# bldg_id
# 119                                                 -34.16
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               43.67
# 549963                                                 NaN
# 549989                                             -391.46
#
#         iraRef_mp8_cooking_total_npv_climateOnly_upper_fixed_base  \
# bldg_id
# 119                                                 110.30
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              169.90
# 549963                                                 NaN
# 549989                                             -179.78
#
#         iraRef_mp8_heating_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                               -1272.56
# 122                                                1251.74
# 150                                               32642.15
# 153                                               15900.07
# 162                                               29739.96
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            29489.64
# 549937                                            -2245.97
# 549963                                            -1638.69
# 549989                                             5659.89
#
#         iraRef_mp8_waterHeating_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                                1391.59
# 122                                                3008.47
# 150                                                 560.40
# 153                                                7590.65
# 162                                               -1688.34
# ...                                                    ...
# 549882                                             -328.96
# 549915                                             4023.20
# 549937                                             1446.89
# 549963                                              930.03
# 549989                                             1880.69
#
#         iraRef_mp8_clothesDrying_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                                 714.22
# 122                                                 204.44
# 150                                                -579.20
# 153                                                    NaN
# 162                                               -1006.87
# ...                                                    ...
# 549882                                             -733.84
# 549915                                              738.80
# 549937                                             -493.79
# 549963                                               -9.93
# 549989                                             -549.05
#
#          iraRef_mp8_cooking_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                                -264.19
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -223.29
# 549963                                                 NaN
# 549989                                             -825.43
#
#          iraRef_mp8_heating_total_npv_healthOnly_inmap_h6c_fixed_base  \
# bldg_id
# 119                                                 937.46
# 122                                               13678.18
# 150                                               43436.60
# 153                                               21152.37
# 162                                               45079.93
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            38653.04
# 549937                                            -2303.44
# 549963                                             -917.94
# 549989                                             5969.99
#
#         iraRef_mp8_waterHeating_total_npv_healthOnly_inmap_h6c_fixed_base  \
# bldg_id
# 119                                                1922.27
# 122                                                3658.11
# 150                                                1114.25
# 153                                                8959.01
# 162                                               -1258.65
# ...                                                    ...
# 549882                                             -566.53
# 549915                                             5848.51
# 549937                                             1462.38
# 549963                                             1009.27
# 549989                                             1893.61
#
#          iraRef_mp8_clothesDrying_total_npv_healthOnly_inmap_h6c_fixed_base  \
# bldg_id
# 119                                                 746.28
# 122                                                 249.68
# 150                                                -480.59
# 153                                                    NaN
# 162                                                -844.31
# ...                                                    ...
# 549882                                             -579.04
# 549915                                              938.46
# 549937                                             -562.07
# 549963                                               36.56
# 549989                                             -465.11
#
#         iraRef_mp8_cooking_total_npv_healthOnly_inmap_h6c_fixed_base
# bldg_id
# 119                                                -238.64
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -303.42
# 549963                                                 NaN
# 549989                                             -940.40
#
# [15651 rows x 774 columns]
#
#
# The code took 6 minutes and 42 seconds to execute.
# Basic Retrofit Scenario - Model Run Complete

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUPPLEMENTAL DATA
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp8_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp8_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)
# Out:
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_noIRA
# Saved to: mp8_damages_climate_noIRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_noIRA\mp8_damages_climate_noIRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_IRA
# Saved to: mp8_damages_climate_IRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_IRA\mp8_damages_climate_IRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_noIRA
# Saved to: mp8_damages_health_noIRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_noIRA\mp8_damages_health_noIRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_IRA
# Saved to: mp8_damages_health_IRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_IRA\mp8_damages_health_IRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_noIRA
# Saved to: mp8_fuel_costs_noIRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_noIRA\mp8_fuel_costs_noIRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_IRA
# Saved to: mp8_fuel_costs_IRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_IRA\mp8_fuel_costs_IRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUMMARY RESULTS FOR RCM MODELS AND DISCOUNT RATES SENSITIVITY ANALYSIS
# ===================================================================================================================================================================================
DATAFRAMES_MP8_RCM_DISCOUNT_RATE_RESULTS = {
    'ap2': {
        'private_discount_rate_fixed_low': df_euss_am_mp8_home_ap2_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp8_home_ap2_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp8_home_ap2_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp8_home_ap2_variable
    },
    'easiur': {
        'private_discount_rate_fixed_low': df_euss_am_mp8_home_easiur_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp8_home_easiur_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp8_home_easiur_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp8_home_easiur_variable
    },
    'inmap': {
        'private_discount_rate_fixed_low': df_euss_am_mp8_home_inmap_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp8_home_inmap_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp8_home_inmap_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp8_home_inmap_variable
    }
}

# Process each RCM model
for rcm_model in RCM_MODELS:
    print(f"Exporting SUMMARY RESULTS for {rcm_model.upper()} model...")
    
    # Process each discount method
    for discount_rate_col in PRIVATE_DISCOUNT_RATE_COLS:
        print(f"  Private Discounting Method: {discount_rate_col}")
        
        # Get the specific DataFrame for this RCM × discount rate combination
        df_results_export = DATAFRAMES_MP8_RCM_DISCOUNT_RATE_RESULTS[rcm_model][discount_rate_col]
        
        # Export summary results with explicit sensitivity parameters
        export_model_run_output(
            df_results_export=df_results_export,
            results_category='summary',  # Simplified - no parsing needed!
            menu_mp=menu_mp,
            output_folder_path=output_folder_path,
            location_id=location_id,
            results_export_formatted_date=model_run_date_time,
            rcm_model=rcm_model,  # Explicit sensitivity parameter
            discount_rate_col=discount_rate_col  # Explicit sensitivity parameter
        )
# Out:
# Exporting SUMMARY RESULTS for AP2 model...
#   Private Discounting Method: private_discount_rate_fixed_low
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_fixed_low
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_private_discount_rate_fixed_low\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_base
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_fixed_base
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_private_discount_rate_fixed_base\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_high
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_fixed_high
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_private_discount_rate_fixed_high\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_variable
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_variable
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_private_discount_rate_variable\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for EASIUR model...
#   Private Discounting Method: private_discount_rate_fixed_low
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_fixed_low
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_private_discount_rate_fixed_low\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_base
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_fixed_base
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_private_discount_rate_fixed_base\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_high
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_fixed_high
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_private_discount_rate_fixed_high\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_variable
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_variable
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_private_discount_rate_variable\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for INMAP model...
#   Private Discounting Method: private_discount_rate_fixed_low
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_fixed_low
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_private_discount_rate_fixed_low\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_base
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_fixed_base
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_private_discount_rate_fixed_base\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_high
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_fixed_high
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_private_discount_rate_fixed_high\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_variable
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_variable
# Saved to: mp8_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_private_discount_rate_variable\mp8_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Moderate Retrofit: Measure Package 9 (MP9)

# %%
# Measure Package 9
menu_mp = 9
input_mp = 'upgrade09'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_moderate_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Moderate Retrofit Scenario - Model Run Complete")
# Out:
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_moderate_v2_2.ipynb
#
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (MP9-10).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 346)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            7  242.131013           True   2152.0
# 122            7  242.131013           True   2176.0
# 150            7  242.131013          False   1690.0
# 153            7  242.131013           True   2176.0
# 162            7  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         7  242.131013           True   1202.0
# 549915         7  242.131013          False   2176.0
# 549937         7  242.131013           True    885.0
# 549963         7  242.131013           True   1690.0
# 549989         7  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4367.397352
# 122                                           10479.768179
# 150                                               0.000000
# 153                                           11048.097647
# 162                                           12947.903971
# ...                                                    ...
# 549882                                         5212.871757
# 549915                                            0.000000
# 549937                                         4636.242910
# 549963                                         4903.857419
# 549989                                         4686.866540
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2552.828291
# 122                                            6954.371623
# 150                                               0.000000
# 153                                            6200.439415
# 162                                            8666.012863
# ...                                                    ...
# 549882                                         3310.560695
# 549915                                            0.000000
# 549937                                         1673.632015
# 549963                                          609.743358
# 549989                                         2436.617472
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            2985.641141
# 122                                            7797.415226
# 150                                               0.000000
# 153                                            7363.122758
# 162                                            9676.629818
# ...                                                    ...
# 549882                                         3739.637305
# 549915                                            0.000000
# 549937                                         2257.364571
# 549963                                         1488.137683
# 549989                                         2959.741017
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2356.289439
# 122                                            6648.492515
# 150                                               0.000000
# 153                                            5775.168899
# 162                                            8324.377523
# ...                                                    ...
# 549882                                         3185.908976
# 549915                                            0.000000
# 549937                                         1154.203887
# 549963                                          -84.117798
# 549989                                         2177.081897
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 119      Electric, 100% Usage  Electric, 100% Usage
# 122                       NaN                   NaN
# 150                       NaN                   NaN
# 153                       NaN                   NaN
# 162                       NaN                   NaN
# ...                       ...                   ...
# 549882                    NaN                   NaN
# 549915                    NaN                   NaN
# 549937   Electric, 120% Usage  Electric, 120% Usage
# 549963                    NaN                   NaN
# 549989                    NaN  Electric, 100% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 122                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 150                                 NaN                                NaN
# 153                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 162                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# ...                                 ...                                ...
# 549882                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
# 549915                              NaN                                NaN
# 549937                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549963                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549989                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150                                       NaN
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                                    NaN
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 346 columns]
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Moderate-BAU:
# Moderate Retrofit: Measure Package 9
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade09_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade09_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 351)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 351)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 351)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 351)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            9  242.131013           True   2152.0
# 122            9  242.131013           True   2176.0
# 150            9  242.131013           True   1690.0
# 153            9  242.131013           True   2176.0
# 162            9  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         9  242.131013           True   1202.0
# 549915         9  242.131013           True   2176.0
# 549937         9  242.131013           True    885.0
# 549963         9  242.131013           True   1690.0
# 549989         9  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#                                      upgrade.clothes_dryer  \
# bldg_id
# 119      Electric, Premium, Heat Pump, Ventless, 100% U...
# 122      Electric, Premium, Heat Pump, Ventless, 100% U...
# 150      Electric, Premium, Heat Pump, Ventless, 80% Usage
# 153                                                    NaN
# 162      Electric, Premium, Heat Pump, Ventless, 80% Usage
# ...                                                    ...
# 549882   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549915   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549937   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549963   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549989   Electric, Premium, Heat Pump, Ventless, 100% U...
#
#                    upgrade.cooking_range     upgrade.ducts  \
# bldg_id
# 119      Electric, Induction, 100% Usage               NaN
# 122      Electric, Induction, 100% Usage  10% Leakage, R-8
# 150       Electric, Induction, 80% Usage               NaN
# 153      Electric, Induction, 120% Usage  10% Leakage, R-8
# 162       Electric, Induction, 80% Usage  10% Leakage, R-8
# ...                                  ...               ...
# 549882   Electric, Induction, 120% Usage               NaN
# 549915   Electric, Induction, 100% Usage  10% Leakage, R-8
# 549937   Electric, Induction, 120% Usage               NaN
# 549963   Electric, Induction, 100% Usage               NaN
# 549989   Electric, Induction, 100% Usage               NaN
#
#         upgrade.hvac_cooling_efficiency     upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 122                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 150                           Heat Pump  MSHP, SEER 29.3, 14 HSPF, Max Load
# 153                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 162                           Heat Pump              MSHP, SEER 24, 13 HSPF
# ...                                 ...                                 ...
# 549882                        Heat Pump  MSHP, SEER 29.3, 14 HSPF, Max Load
# 549915                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 549937                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 549963                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 549989                        Heat Pump              MSHP, SEER 24, 13 HSPF
#
#         upgrade.hvac_heating_type upgrade.infiltration_reduction  \
# bldg_id
# 119              Ducted Heat Pump                            NaN
# 122              Ducted Heat Pump                            30%
# 150                           NaN                            30%
# 153              Ducted Heat Pump                            30%
# 162              Ducted Heat Pump                            30%
# ...                           ...                            ...
# 549882                        NaN                            30%
# 549915           Ducted Heat Pump                            30%
# 549937           Ducted Heat Pump                            30%
# 549963           Ducted Heat Pump                            NaN
# 549989           Ducted Heat Pump                            NaN
#
#         upgrade.insulation_ceiling upgrade.insulation_wall  \
# bldg_id
# 119                           R-60                     NaN
# 122                           R-60         Wood Stud, R-13
# 150                           R-60         Wood Stud, R-13
# 153                           R-60                     NaN
# 162                           R-60         Wood Stud, R-13
# ...                            ...                     ...
# 549882                        R-60                     NaN
# 549915                        R-60                     NaN
# 549937                         NaN         Wood Stud, R-13
# 549963                         NaN                     NaN
# 549989                        R-60         Wood Stud, R-13
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150      Electric Heat Pump, 66 gal, 3.35 UEF
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915   Electric Heat Pump, 80 gal, 3.45 UEF
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 351 columns]
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 9 (MP9)
# ====================================================================================================================================================================
# You'll notice that the number of rows differs from df_euss_am_mp7 and df_euss_am_mp9.
#       - df_euss_am_baseline_home has fewer rows (representative dwelling units) because a tech filter was applied.
#       - df_euss_am_mp9_home will have the same number of rows as df_euss_am_baseline_home after df_enduse_compare function is run.
#       - df_enduse_compare function performs an inner merge on the two dataframes, keeping only the rows that are present in both dataframes.
# ====================================================================================================================================================================
# df_euss_am_mp9_home will be created by running the df_enduse_compare function (contains post-retrofit consumption data for the entire home in 2024).
# process_euss_data.py file contains the function definition.
#
# Documentation for df_enduse_compare function:
# Creates a comparison DataFrame by merging multiple DataFrames based on measure packages.
#
#     This function constructs a new DataFrame (df_compare) that includes columns
#     from df_mp, df_cooking_range, and merges them with df_baseline to compare
#     baseline vs. measure package outputs for heating, water heating, clothes drying,
#     and cooking.
#
#     Args:
#         df_mp: The main DataFrame containing modeling parameters and outputs.
#         input_mp: The input measure package ID (e.g., 'upgrade09', 'upgrade10').
#         menu_mp: The menu measure package number.
#         df_baseline: The baseline DataFrame to merge with df_compare.
#         df_cooking_range: Additional DataFrame for cooking range parameters/outputs.
#
#     Returns:
#         A merged DataFrame (df_compare) that includes relevant columns for
#         baseline and measure packages comparison.
#
# ----------------------------------------------------------------
#
# RESULTING DATAFRAME:
#
#
# Applying combined validation (data quality + retrofit status):
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
#   mp9_heating_consumption: Masked 3385 values
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
#   mp9_waterHeating_consumption: Masked 652 values
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
#   mp9_clothesDrying_consumption: Masked 908 values
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#   mp9_cooking_consumption: Masked 7784 values
#
# ====================================================================================================================================================================
# PUBLIC IMPACTS: DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
#
#
#
#  Creating dataframe to store marginal damages calculations ...
#
# ====================================================================================================================================================================
# df_euss_am_baseline_home: DataFrame containing the baseline scenario data
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#         baseline_cooking_lifetime_damages_health_inmap_h6c fuel_type_heating  \
# bldg_id
# 119                                                 380.50        naturalGas
# 122                                                    NaN           fuelOil
# 150                                                    NaN       electricity
# 153                                                    NaN           fuelOil
# 162                                                    NaN           fuelOil
# ...                                                    ...               ...
# 549882                                                 NaN        naturalGas
# 549915                                                 NaN       electricity
# 549937                                              129.68        naturalGas
# 549963                                                 NaN        naturalGas
# 549989                                              146.99           fuelOil
#
#         fuel_type_waterHeating fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 119                 naturalGas              naturalGas         naturalGas
# 122                    fuelOil             electricity        electricity
# 150                electricity             electricity        electricity
# 153                    fuelOil                     NaN        electricity
# 162                 naturalGas             electricity        electricity
# ...                        ...                     ...                ...
# 549882              naturalGas             electricity        electricity
# 549915             electricity             electricity        electricity
# 549937              naturalGas              naturalGas         naturalGas
# 549963              naturalGas             electricity        electricity
# 549989                 fuelOil             electricity            propane
#
#          baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                  9692.04
# 122                                 56634.48
# 150                                 48835.85
# 153                                 52691.10
# 162                                 69001.23
# ...                                      ...
# 549882                                   NaN
# 549915                              52898.91
# 549937                               8456.00
# 549963                              17473.34
# 549989                              22285.90
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                        351.02
# 122                                        619.28
# 150                                        718.64
# 153                                           NaN
# 162                                       2222.41
# ...                                           ...
# 549882                                     997.02
# 549915                                    1736.07
# 549937                                     982.27
# 549963                                     898.31
# 549989                                     898.31
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 126 columns]
#
# df_baseline_damages_health: DataFrame containing the baseline scenario data with health damages
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          baseline_2038_cooking_damages_so2_inmap_h6c  \
# bldg_id
# 119                                             0.92
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          0.63
# 549963                                           NaN
# 549989                                          0.82
#
#          baseline_2038_cooking_damages_nox_inmap_h6c  \
# bldg_id
# 119                                            17.35
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          7.15
# 549963                                           NaN
# 549989                                          8.32
#
#          baseline_2038_cooking_damages_pm25_inmap_h6c  \
# bldg_id
# 119                                              8.30
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                           0.91
# 549963                                            NaN
# 549989                                           0.68
#
#          baseline_2038_cooking_damages_health_inmap_h6c  \
# bldg_id
# 119                                               26.56
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                             8.69
# 549963                                              NaN
# 549989                                             9.83
#
#          baseline_cooking_lifetime_damages_health_ap2_acs  \
# bldg_id
# 119                                                 37.49
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              20.82
# 549963                                                NaN
# 549989                                              23.53
#
#          baseline_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 96.32
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              53.48
# 549963                                                NaN
# 549989                                              60.44
#
#          baseline_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 130.47
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               73.35
# 549963                                                 NaN
# 549989                                               59.17
#
#          baseline_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 335.21
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              188.47
# 549963                                                 NaN
# 549989                                              152.01
#
#          baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#          baseline_cooking_lifetime_damages_health_inmap_h6c
# bldg_id
# 119                                                 380.50
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              129.68
# 549963                                                 NaN
# 549989                                              146.99
#
# [15651 rows x 1355 columns]
#
#
#
# ==================== SCENARIO: No Inflation Reduction Act ==========
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
# ...
# 549882                                                 NaN
# 549915                                            28814.50
# 549937                                           -11674.44
# 549963                                             1729.62
# 549989                                             7990.53
#
#         iraRef_mp9_waterHeating_total_npv_healthOnly_easiur_h6c_fixed_base  \
# bldg_id
# 119                                                1023.78
# 122                                                3393.83
# 150                                                1418.73
# 153                                                9730.42
# 162                                                -549.91
# ...                                                    ...
# 549882                                               46.36
# 549915                                             6080.51
# 549937                                             -281.66
# 549963                                              470.40
# 549989                                             3122.20
#
#          iraRef_mp9_clothesDrying_total_npv_healthOnly_easiur_h6c_fixed_base  \
# bldg_id
# 119                                                -153.07
# 122                                                -677.21
# 150                                                 538.81
# 153                                                    NaN
# 162                                                 -72.96
# ...                                                    ...
# 549882                                             -525.29
# 549915                                              733.02
# 549937                                            -1376.58
# 549963                                              171.53
# 549989                                            -1065.07
#
#         iraRef_mp9_cooking_total_npv_healthOnly_easiur_h6c_fixed_base
# bldg_id
# 119                                                -280.10
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1350.96
# 549963                                                 NaN
# 549989                                              166.16
#
# [15651 rows x 790 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_cooking_total_npv_climateOnly_central_fixed_base  \
# bldg_id
# 119                                                 118.82
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1057.08
# 549963                                                 NaN
# 549989                                              639.29
#
#         iraRef_mp9_cooking_total_npv_climateOnly_upper_fixed_base  \
# bldg_id
# 119                                                 263.28
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -930.85
# 549963                                                 NaN
# 549989                                              850.97
#
#         iraRef_mp9_heating_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                               -4955.63
# 122                                               18820.63
# 150                                               21144.68
# 153                                                9246.46
# 162                                               17664.62
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            20385.83
# 549937                                           -12357.40
# 549963                                              600.49
# 549989                                             6530.06
#
#         iraRef_mp9_waterHeating_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                                 904.57
# 122                                                3116.42
# 150                                                1197.25
# 153                                                7378.50
# 162                                                -645.83
# ...                                                    ...
# 549882                                             -124.06
# 549915                                             4587.69
# 549937                                             -693.20
# 549963                                              344.89
# 549989                                             2861.91
#
#         iraRef_mp9_clothesDrying_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                                 -89.81
# 122                                                -761.04
# 150                                                 499.23
# 153                                                    NaN
# 162                                                -374.17
# ...                                                    ...
# 549882                                             -598.85
# 549915                                              568.99
# 549937                                            -1371.70
# 549963                                              133.50
# 549989                                            -1117.50
#
#          iraRef_mp9_cooking_total_npv_healthOnly_inmap_acs_fixed_base  \
# bldg_id
# 119                                                -111.21
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1324.04
# 549963                                                 NaN
# 549989                                              205.32
#
#          iraRef_mp9_heating_total_npv_healthOnly_inmap_h6c_fixed_base  \
# bldg_id
# 119                                               -2690.95
# 122                                               32648.58
# 150                                               32832.17
# 153                                               15480.82
# 162                                               34201.68
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            30517.93
# 549937                                           -12241.26
# 549963                                             1321.24
# 549989                                             7058.04
#
#         iraRef_mp9_waterHeating_total_npv_healthOnly_inmap_h6c_fixed_base  \
# bldg_id
# 119                                                1435.62
# 122                                                3766.93
# 150                                                1753.06
# 153                                                8749.59
# 162                                                -214.51
# ...                                                    ...
# 549882                                             -360.62
# 549915                                             6417.60
# 549937                                             -675.64
# 549963                                              424.13
# 549989                                             2875.07
#
#          iraRef_mp9_clothesDrying_total_npv_healthOnly_inmap_h6c_fixed_base  \
# bldg_id
# 119                                                 -57.75
# 122                                                -715.80
# 150                                                 597.84
# 153                                                    NaN
# 162                                                -211.61
# ...                                                    ...
# 549882                                             -444.05
# 549915                                              768.65
# 549937                                            -1439.98
# 549963                                              179.99
# 549989                                            -1033.56
#
#         iraRef_mp9_cooking_total_npv_healthOnly_inmap_h6c_fixed_base
# bldg_id
# 119                                                 -85.66
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1404.17
# 549963                                                 NaN
# 549989                                               90.35
#
# [15651 rows x 790 columns]
#
#
# The code took 13 minutes and 6 seconds to execute.
# Moderate Retrofit Scenario - Model Run Complete

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUPPLEMENTAL DATA
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp9_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp9_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)
# Out:
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_noIRA
# Saved to: mp9_damages_climate_noIRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_noIRA\mp9_damages_climate_noIRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_IRA
# Saved to: mp9_damages_climate_IRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_IRA\mp9_damages_climate_IRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_noIRA
# Saved to: mp9_damages_health_noIRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_noIRA\mp9_damages_health_noIRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_IRA
# Saved to: mp9_damages_health_IRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_IRA\mp9_damages_health_IRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_noIRA
# Saved to: mp9_fuel_costs_noIRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_noIRA\mp9_fuel_costs_noIRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_IRA
# Saved to: mp9_fuel_costs_IRA_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_IRA\mp9_fuel_costs_IRA_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUMMARY RESULTS FOR RCM MODELS AND DISCOUNT RATES SENSITIVITY ANALYSIS
# ===================================================================================================================================================================================
DATAFRAMES_MP9_RCM_DISCOUNT_RATE_RESULTS = {
    'ap2': {
        'private_discount_rate_fixed_low': df_euss_am_mp9_home_ap2_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp9_home_ap2_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp9_home_ap2_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp9_home_ap2_variable
    },
    'easiur': {
        'private_discount_rate_fixed_low': df_euss_am_mp9_home_easiur_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp9_home_easiur_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp9_home_easiur_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp9_home_easiur_variable
    },
    'inmap': {
        'private_discount_rate_fixed_low': df_euss_am_mp9_home_inmap_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp9_home_inmap_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp9_home_inmap_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp9_home_inmap_variable
    }
}

# Process each RCM model
for rcm_model in RCM_MODELS:
    print(f"Exporting SUMMARY RESULTS for {rcm_model.upper()} model...")
    
    # Process each discount method
    for discount_rate_col in PRIVATE_DISCOUNT_RATE_COLS:
        print(f"  Private Discounting Method: {discount_rate_col}")
        
        # Get the specific DataFrame for this RCM × discount rate combination
        df_results_export = DATAFRAMES_MP9_RCM_DISCOUNT_RATE_RESULTS[rcm_model][discount_rate_col]
        
        # Export summary results with explicit sensitivity parameters
        export_model_run_output(
            df_results_export=df_results_export,
            results_category='summary',  # Simplified - no parsing needed!
            menu_mp=menu_mp,
            output_folder_path=output_folder_path,
            location_id=location_id,
            results_export_formatted_date=model_run_date_time,
            rcm_model=rcm_model,  # Explicit sensitivity parameter
            discount_rate_col=discount_rate_col  # Explicit sensitivity parameter
        )
# Out:
# Exporting SUMMARY RESULTS for AP2 model...
#   Private Discounting Method: private_discount_rate_fixed_low
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_fixed_low
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_ap2_private_discount_rate_fixed_low\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_base
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_fixed_base
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_ap2_private_discount_rate_fixed_base\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_high
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_fixed_high
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_ap2_private_discount_rate_fixed_high\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_variable
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_variable
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_ap2_private_discount_rate_variable\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for EASIUR model...
#   Private Discounting Method: private_discount_rate_fixed_low
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_fixed_low
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_easiur_private_discount_rate_fixed_low\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_base
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_fixed_base
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_easiur_private_discount_rate_fixed_base\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_high
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_fixed_high
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_easiur_private_discount_rate_fixed_high\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_variable
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_variable
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_easiur_private_discount_rate_variable\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for INMAP model...
#   Private Discounting Method: private_discount_rate_fixed_low
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_fixed_low
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_inmap_private_discount_rate_fixed_low\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_base
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_fixed_base
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_inmap_private_discount_rate_fixed_base\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_high
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_fixed_high
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_inmap_private_discount_rate_fixed_high\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_variable
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_variable
# Saved to: mp9_results_PA_2026-01-24_03-35.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_inmap_private_discount_rate_variable\mp9_results_PA_2026-01-24_03-35.csv
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Advanced Retrofit: Measure Package 10 (MP10)

# %%
# Measure Package 10
menu_mp = 10
input_mp = 'upgrade10'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_advanced_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Advanced Retrofit Scenario - Model Run Complete")
# Out:
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_advanced_v2_2.ipynb
#
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (MP8-10).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 346)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            7  242.131013           True   2152.0
# 122            7  242.131013           True   2176.0
# 150            7  242.131013          False   1690.0
# 153            7  242.131013           True   2176.0
# 162            7  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         7  242.131013           True   1202.0
# 549915         7  242.131013          False   2176.0
# 549937         7  242.131013           True    885.0
# 549963         7  242.131013           True   1690.0
# 549989         7  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4367.397352
# 122                                           10479.768179
# 150                                               0.000000
# 153                                           11048.097647
# 162                                           12947.903971
# ...                                                    ...
# 549882                                         5212.871757
# 549915                                            0.000000
# 549937                                         4636.242910
# 549963                                         4903.857419
# 549989                                         4686.866540
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2552.828291
# 122                                            6954.371623
# 150                                               0.000000
# 153                                            6200.439415
# 162                                            8666.012863
# ...                                                    ...
# 549882                                         3310.560695
# 549915                                            0.000000
# 549937                                         1673.632015
# 549963                                          609.743358
# 549989                                         2436.617472
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            2985.641141
# 122                                            7797.415226
# 150                                               0.000000
# 153                                            7363.122758
# 162                                            9676.629818
# ...                                                    ...
# 549882                                         3739.637305
# 549915                                            0.000000
# 549937                                         2257.364571
# 549963                                         1488.137683
# 549989                                         2959.741017
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2356.289439
# 122                                            6648.492515
# 150                                               0.000000
# 153                                            5775.168899
# 162                                            8324.377523
# ...                                                    ...
# 549882                                         3185.908976
# 549915                                            0.000000
# 549937                                         1154.203887
# 549963                                          -84.117798
# 549989                                         2177.081897
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 119      Electric, 100% Usage  Electric, 100% Usage
# 122                       NaN                   NaN
# 150                       NaN                   NaN
# 153                       NaN                   NaN
# 162                       NaN                   NaN
# ...                       ...                   ...
# 549882                    NaN                   NaN
# 549915                    NaN                   NaN
# 549937   Electric, 120% Usage  Electric, 120% Usage
# 549963                    NaN                   NaN
# 549989                    NaN  Electric, 100% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 122                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 150                                 NaN                                NaN
# 153                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 162                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# ...                                 ...                                ...
# 549882                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
# 549915                              NaN                                NaN
# 549937                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549963                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549989                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150                                       NaN
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                                    NaN
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 346 columns]
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Advanced-BAU:
# Advanced Retrofit: Measure Package 10
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade10_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade10_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 354)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 354)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 354)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 354)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119           10  242.131013           True   2152.0
# 122           10  242.131013           True   2176.0
# 150           10  242.131013           True   1690.0
# 153           10  242.131013           True   2176.0
# 162           10  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882        10  242.131013           True   1202.0
# 549915        10  242.131013           True   2176.0
# 549937        10  242.131013           True    885.0
# 549963        10  242.131013           True   1690.0
# 549989        10  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         upgrade.geometry_foundation_type upgrade.hvac_cooling_efficiency  \
# bldg_id
# 119                  Unvented Crawlspace                       Heat Pump
# 122                                  NaN                       Heat Pump
# 150                  Unvented Crawlspace                       Heat Pump
# 153                                  NaN                       Heat Pump
# 162                  Unvented Crawlspace                       Heat Pump
# ...                                  ...                             ...
# 549882                               NaN                       Heat Pump
# 549915               Unvented Crawlspace                       Heat Pump
# 549937                               NaN                       Heat Pump
# 549963               Unvented Crawlspace                       Heat Pump
# 549989                               NaN                       Heat Pump
#
#             upgrade.hvac_heating_efficiency upgrade.hvac_heating_type  \
# bldg_id
# 119                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 122                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 150      MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 153                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 162                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# ...                                     ...                       ...
# 549882   MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 549915               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549937               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549963               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549989               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
#
#         upgrade.infiltration_reduction upgrade.insulation_ceiling  \
# bldg_id
# 119                                NaN                       R-60
# 122                                30%                       R-60
# 150                                30%                       R-60
# 153                                30%                       R-60
# 162                                30%                       R-60
# ...                                ...                        ...
# 549882                             30%                       R-60
# 549915                             30%                       R-60
# 549937                             30%                        NaN
# 549963                             NaN                        NaN
# 549989                             NaN                       R-60
#
#         upgrade.insulation_foundation_wall upgrade.insulation_roof  \
# bldg_id
# 119                    Wall R-10, Interior                     NaN
# 122                                    NaN                     NaN
# 150                    Wall R-10, Interior                     NaN
# 153                                    NaN                     NaN
# 162                    Wall R-10, Interior                     NaN
# ...                                    ...                     ...
# 549882                                 NaN                     NaN
# 549915                 Wall R-10, Interior                     NaN
# 549937                                 NaN                     NaN
# 549963                 Wall R-10, Interior                     NaN
# 549989                                 NaN                     NaN
#
#         upgrade.insulation_wall       upgrade.water_heater_efficiency
# bldg_id
# 119                         NaN  Electric Heat Pump, 66 gal, 3.35 UEF
# 122             Wood Stud, R-13  Electric Heat Pump, 66 gal, 3.35 UEF
# 150             Wood Stud, R-13  Electric Heat Pump, 66 gal, 3.35 UEF
# 153                         NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 162             Wood Stud, R-13  Electric Heat Pump, 80 gal, 3.45 UEF
# ...                         ...                                   ...
# 549882                      NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                      NaN  Electric Heat Pump, 80 gal, 3.45 UEF
# 549937          Wood Stud, R-13  Electric Heat Pump, 66 gal, 3.35 UEF
# 549963                      NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 549989          Wood Stud, R-13  Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 354 columns]
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 10 (MP10)
# ====================================================================================================================================================================
# You'll notice that the number of rows differs from df_euss_am_mp7 and df_euss_am_mp10.
#       - df_euss_am_baseline_home has fewer rows (representative dwelling units) because a tech filter was applied.
#       - df_euss_am_mp10_home will have the same number of rows as df_euss_am_baseline_home after df_enduse_compare function is run.
#       - df_enduse_compare function performs an inner merge on the two dataframes, keeping only the rows that are present in both dataframes.
# ====================================================================================================================================================================
# df_euss_am_mp10_home will be created by running the df_enduse_compare function (contains post-retrofit consumption data for the entire home in 2024).
# process_euss_data.py file contains the function definition.
#
# Documentation for df_enduse_compare function:
# Creates a comparison DataFrame by merging multiple DataFrames based on measure packages.
#
#     This function constructs a new DataFrame (df_compare) that includes columns
#     from df_mp, df_cooking_range, and merges them with df_baseline to compare
#     baseline vs. measure package outputs for heating, water heating, clothes drying,
#     and cooking.
#
#     Args:
#         df_mp: The main DataFrame containing modeling parameters and outputs.
#         input_mp: The input measure package ID (e.g., 'upgrade09', 'upgrade10').
#         menu_mp: The menu measure package number.
#         df_baseline: The baseline DataFrame to merge with df_compare.
#         df_cooking_range: Additional DataFrame for cooking range parameters/outputs.
#
#     Returns:
#         A merged DataFrame (df_compare) that includes relevant columns for
#         baseline and measure packages comparison.
#
# ----------------------------------------------------------------
#
# RESULTING DATAFRAME:
#
#
# Applying combined validation (data quality + retrofit status):
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
#   mp10_heating_consumption: Masked 3385 values
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
#   mp10_waterHeating_consumption: Masked 652 values
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
#   mp10_clothesDrying_consumption: Masked 908 values
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#   mp10_cooking_consumption: Masked 7784 values
#
# ====================================================================================================================================================================
# PUBLIC IMPACTS: DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
#
#
#
#  Creating dataframe to store marginal damages calculations ...
#
# ====================================================================================================================================================================
# df_euss_am_baseline_home: DataFrame containing the baseline scenario data
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#         baseline_cooking_lifetime_damages_health_inmap_h6c fuel_type_heating  \
# bldg_id
# 119                                                 380.50        naturalGas
# 122                                                    NaN           fuelOil
# 150                                                    NaN       electricity
# 153                                                    NaN           fuelOil
# 162                                                    NaN           fuelOil
# ...                                                    ...               ...
# 549882                                                 NaN        naturalGas
# 549915                                                 NaN       electricity
# 549937                                              129.68        naturalGas
# 549963                                                 NaN        naturalGas
# 549989                                              146.99           fuelOil
#
#         fuel_type_waterHeating fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 119                 naturalGas              naturalGas         naturalGas
# 122                    fuelOil             electricity        electricity
# 150                electricity             electricity        electricity
# 153                    fuelOil                     NaN        electricity
# 162                 naturalGas             electricity        electricity
# ...                        ...                     ...                ...
# 549882              naturalGas             electricity        electricity
# 549915             electricity             electricity        electricity
# 549937              naturalGas              naturalGas         naturalGas
# 549963              naturalGas             electricity        electricity
# 549989                 fuelOil             electricity            propane
#
#          baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                  9692.04
# 122                                 56634.48
# 150                                 48835.85
# 153                                 52691.10
# 162                                 69001.23
# ...                                      ...
# 549882                                   NaN
# 549915                              52898.91
# 549937                               8456.00
# 549963                              17473.34
# 549989                              22285.90
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                        351.02
# 122                                        619.28
# 150                                        718.64
# 153                                           NaN
# 162                                       2222.41
# ...                                           ...
# 549882                                     997.02
# 549915                                    1736.07
# 549937                                     982.27
# 549963                                     898.31
# 549989                                     898.31
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 126 columns]
#
# df_baseline_damages_health: DataFrame containing the baseline scenario data with health damages
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          baseline_2038_cooking_damages_so2_inmap_h6c  \
# bldg_id
# 119                                             0.92
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          0.63
# 549963                                           NaN
# 549989                                          0.82
#
#          baseline_2038_cooking_damages_nox_inmap_h6c  \
# bldg_id
# 119                                            17.35
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          7.15
# 549963                                           NaN
# 549989                                          8.32
#
#          baseline_2038_cooking_damages_pm25_inmap_h6c  \
# bldg_id
# 119                                              8.30
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                           0.91
# 549963                                            NaN
# 549989                                           0.68
#
#          baseline_2038_cooking_damages_health_inmap_h6c  \
# bldg_id
# 119                                               26.56
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                             8.69
# 549963                                              NaN
# 549989                                             9.83
#
#          baseline_cooking_lifetime_damages_health_ap2_acs  \
# bldg_id
# 119                                                 37.49
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              20.82
# 549963                                                NaN
# 549989                                              23.53
#
#          baseline_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 96.32
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              53.48
# 549963                                                NaN
# 549989                                              60.44
#
#          baseline_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 130.47
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               73.35
# 549963                                                 NaN
# 549989                                               59.17
#
#          baseline_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 335.21
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              188.47
# 549963                                                 NaN
# 549989                                              152.01
#
#          baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#          baseline_cooking_lifetime_damages_health_inmap_h6c
# bldg_id
# 119                                                 380.50
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              129.68
# 549963                                                 NaN
# 549989                                              146.99
#
# [15651 rows x 1355 columns]
#
#
#
# ==================== SCENARIO: No Inflation Reduction Act ==========
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
#
# ...
# 549915                                              NaN
# 549937                                          -109.24
# 549963                                              NaN
# 549989                                          -119.80
#
#          preIRA_mp10_cooking_climate_npv_central  \
# bldg_id
# 119                                       106.37
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                     76.59
# 549963                                       NaN
# 549989                                    241.05
#
#         preIRA_mp10_cooking_public_npv_central_inmap_h6c  \
# bldg_id
# 119                                               148.22
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                            -54.60
# 549963                                               NaN
# 549989                                             52.78
#
#          preIRA_mp10_cooking_climate_npv_upper  \
# bldg_id
# 119                                     166.96
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                  120.54
# 549963                                     NaN
# 549989                                  380.96
#
#         preIRA_mp10_cooking_public_npv_upper_inmap_h6c
# bldg_id
# 119                                             208.81
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                          -10.65
# 549963                                             NaN
# 549989                                          192.69
#
# [15651 rows x 494 columns]
#
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PRIVATE IMPACT
# ====================================================================================================================================================================
# Completed Steps:
# 1. Calculate annual operating (fuel) costs
# 2. Calculate equipment capital costs (For space heating, include ductwork and weatherization (MP10 and MP10))
# 3. Calculate replacement cost (replacing existing piece of eqipment with similar technology)
#
# ----------------------------------------------------------------------------------------------------------------------
# Step 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
# ----------------------------------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT (NO INFLATION REDUCTION ACT):
#
# Processing AP2 model...
#   Method: private_discount_rate_fixed_low
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp10_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Calculating costs for heating...
#           input_mp: upgrade10, menu_mp: 10, policy_scenario: No Inflation Reduction Act
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jorda\AppData\Local\anaconda3\envs\cmu-tare-model\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:219, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:227, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:119, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'mp10_heating_installationCost'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_2096\1903754146.py:28
#      25 # Get the specific DataFrame for this RCM × discount rate combination
#      26 df = DATAFRAMES_MP10_RCM_DISCOUNT_RATE[rcm_model][discount_rate_col]
# ---> 28 df = calculate_private_npv(
#      29     df=df,
#      30     df_fuel_costs=df_mp10_noIRA_fuel_costs,
#      31     df_baseline_costs=df_baseline_fuel_costs,
#      32     menu_mp=menu_mp,
#      33     input_mp=input_mp,
#      34     policy_scenario='No Inflation Reduction Act',
#      35     discount_rate_col=discount_rate_col,
#      36     base_year=2024,
#      37     verbose=verbose
#      38     )
#      40 # Update the DataFrame back in the dictionary
#      41 DATAFRAMES_MP10_RCM_DISCOUNT_RATE[rcm_model][discount_rate_col] = df
#
# File c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\private_impact\calculate_lifetime_private_impact.py:148, in calculate_private_npv(df, df_fuel_costs, df_baseline_costs, input_mp, menu_mp, policy_scenario, discount_rate_col, base_year, verbose)
#     144 df_copy, valid_mask, all_columns_to_mask, category_columns_to_mask = initialize_validation_tracking(
#     145     df_copy, category, menu_mp, verbose=verbose)
#     147 # Calculate total and net capital costs based on policy scenario
# --> 148 total_capital_cost, net_capital_cost = calculate_capital_costs(
#     149     df_copy=df_copy,
#     150     category=category,
#     151     input_mp=input_mp,
#     152     menu_mp=menu_mp,
#     153     policy_scenario=policy_scenario,
#     154     valid_mask=valid_mask
#     155 )
#     157 # ===== Calculate private discount factors for fixed and variable methods =====
#     158 # Calculate and get NPV values using FIXED discounting method
#     159 result_cols = calculate_and_update_npv(
#     160     df_measure_costs=df_fuel_costs_copy,
#     161     df_baseline_costs=df_baseline_costs_copy,
#    (...)    173     verbose=verbose
#     174 )
#
# File c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\private_impact\calculate_lifetime_private_impact.py:240, in calculate_capital_costs(df_copy, category, input_mp, menu_mp, policy_scenario, valid_mask)
#     237     else:
#     238         weatherization_cost = 0.0
# --> 240     total_capital_cost = (df_copy[f'mp{menu_mp}_{category}_installationCost'].fillna(0) +
#     241                           weatherization_cost +
#     242                           df_copy[f'mp{menu_mp}_heating_installation_premium'].fillna(0))
#     243     net_capital_cost = total_capital_cost - df_copy[f'mp{menu_mp}_{category}_replacementCost'].fillna(0)
#     245 else:
#
# File c:\Users\jorda\AppData\Local\anaconda3\envs\cmu-tare-model\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\jorda\AppData\Local\anaconda3\envs\cmu-tare-model\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'mp10_heating_installationCost'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jorda\AppData\Local\anaconda3\envs\cmu-tare-model\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:219, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:227, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:119, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'mp10_heating_installationCost'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 16
#      13 print(f"Running file: {file_path}")
#      15 # iPthon magic command to run a .py file and import variables into the current IPython session
# ---> 16 get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.
#      18 print("Advanced Retrofit Scenario - Model Run Complete")
#
# File c:\Users\jorda\AppData\Local\anaconda3\envs\cmu-tare-model\Lib\site-packages\IPython\core\interactiveshell.py:2486, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2484     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2485 with self.builtin_trap:
# -> 2486     result = fn(*args, **kwargs)
#    2488 # The code below prevents the output from being displayed
#    2489 # when using magics with decorator @output_can_be_silenced
#    2490 # when the last Python token in the expression is a ';'.
#    2491 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\jorda\AppData\Local\anaconda3\envs\cmu-tare-model\Lib\site-packages\IPython\core\magics\execution.py:748, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     746     with preserve_keys(self.shell.user_ns, '__file__'):
#     747         self.shell.user_ns['__file__'] = filename
# --> 748         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     749     return
#     751 # Control the response to exit() calls made by the script being run
#
# File c:\Users\jorda\AppData\Local\anaconda3\envs\cmu-tare-model\Lib\site-packages\IPython\core\interactiveshell.py:2977, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2975 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2976 if raise_exceptions:
# -> 2977     result.raise_error()
#    2978 elif not result.success:
#    2979     break
#
# File c:\Users\jorda\AppData\Local\anaconda3\envs\cmu-tare-model\Lib\site-packages\IPython\core\interactiveshell.py:310, in ExecutionResult.raise_error(self)
#     308     raise self.error_before_exec
#     309 if self.error_in_exec is not None:
# --> 310     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_2096\1903754146.py:28
#      25 # Get the specific DataFrame for this RCM × discount rate combination
#      26 df = DATAFRAMES_MP10_RCM_DISCOUNT_RATE[rcm_model][discount_rate_col]
# ---> 28 df = calculate_private_npv(
#      29     df=df,
#      30     df_fuel_costs=df_mp10_noIRA_fuel_costs,
#      31     df_baseline_costs=df_baseline_fuel_costs,
#      32     menu_mp=menu_mp,
#      33     input_mp=input_mp,
#      34     policy_scenario='No Inflation Reduction Act',
#      35     discount_rate_col=discount_rate_col,
#      36     base_year=2024,
#      37     verbose=verbose
#      38     )
#      40 # Update the DataFrame back in the dictionary
#      41 DATAFRAMES_MP10_RCM_DISCOUNT_RATE[rcm_model][discount_rate_col] = df
#
# File c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\private_impact\calculate_lifetime_private_impact.py:148, in calculate_private_npv(df, df_fuel_costs, df_baseline_costs, input_mp, menu_mp, policy_scenario, discount_rate_col, base_year, verbose)
#     144 df_copy, valid_mask, all_columns_to_mask, category_columns_to_mask = initialize_validation_tracking(
#     145     df_copy, category, menu_mp, verbose=verbose)
#     147 # Calculate total and net capital costs based on policy scenario
# --> 148 total_capital_cost, net_capital_cost = calculate_capital_costs(
#     149     df_copy=df_copy,
#     150     category=category,
#     151     input_mp=input_mp,
#     152     menu_mp=menu_mp,
#     153     policy_scenario=policy_scenario,
#     154     valid_mask=valid_mask
#     155 )
#     157 # ===== Calculate private discount factors for fixed and variable methods =====
#     158 # Calculate and get NPV values using FIXED discounting method
#     159 result_cols = calculate_and_update_npv(
#     160     df_measure_costs=df_fuel_costs_copy,
#     161     df_baseline_costs=df_baseline_costs_copy,
#    (...)    173     verbose=verbose
#     174 )
#
# File c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\private_impact\calculate_lifetime_private_impact.py:240, in calculate_capital_costs(df_copy, category, input_mp, menu_mp, policy_scenario, valid_mask)
#     237     else:
#     238         weatherization_cost = 0.0
# --> 240     total_capital_cost = (df_copy[f'mp{menu_mp}_{category}_installationCost'].fillna(0) +
#     241                           weatherization_cost +
#     242                           df_copy[f'mp{menu_mp}_heating_installation_premium'].fillna(0))
#     243     net_capital_cost = total_capital_cost - df_copy[f'mp{menu_mp}_{category}_replacementCost'].fillna(0)
#     245 else:
#
# File c:\Users\jorda\AppData\Local\anaconda3\envs\cmu-tare-model\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\jorda\AppData\Local\anaconda3\envs\cmu-tare-model\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'mp10_heating_installationCost'

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUPPLEMENTAL DATA
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp10_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp10_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUMMARY RESULTS FOR RCM MODELS AND DISCOUNT RATES SENSITIVITY ANALYSIS
# ===================================================================================================================================================================================
DATAFRAMES_MP10_RCM_DISCOUNT_RATE_RESULTS = {
    'ap2': {
        'private_discount_rate_fixed_low': df_euss_am_mp10_home_ap2_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp10_home_ap2_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp10_home_ap2_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp10_home_ap2_variable
    },
    'easiur': {
        'private_discount_rate_fixed_low': df_euss_am_mp10_home_easiur_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp10_home_easiur_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp10_home_easiur_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp10_home_easiur_variable
    },
    'inmap': {
        'private_discount_rate_fixed_low': df_euss_am_mp10_home_inmap_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp10_home_inmap_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp10_home_inmap_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp10_home_inmap_variable
    }
}

# Process each RCM model
for rcm_model in RCM_MODELS:
    print(f"Exporting SUMMARY RESULTS for {rcm_model.upper()} model...")
    
    # Process each discount method
    for discount_rate_col in PRIVATE_DISCOUNT_RATE_COLS:
        print(f"  Private Discounting Method: {discount_rate_col}")
        
        # Get the specific DataFrame for this RCM × discount rate combination
        df_results_export = DATAFRAMES_MP10_RCM_DISCOUNT_RATE_RESULTS[rcm_model][discount_rate_col]
        
        # Export summary results with explicit sensitivity parameters
        export_model_run_output(
            df_results_export=df_results_export,
            results_category='summary',  # Simplified - no parsing needed!
            menu_mp=menu_mp,
            output_folder_path=output_folder_path,
            location_id=location_id,
            results_export_formatted_date=model_run_date_time,
            rcm_model=rcm_model,  # Explicit sensitivity parameter
            discount_rate_col=discount_rate_col  # Explicit sensitivity parameter
        )
