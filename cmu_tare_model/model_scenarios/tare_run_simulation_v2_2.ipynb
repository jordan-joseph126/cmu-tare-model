# %%
"""
This file runs all of the code responsible for generating the output CSVs but does not visualize the data.
Data visualization is done in the main program.
"""

# %%
import os
import pandas as pd
# from IPython import get_ipython

# Format the name of the exported results file using the location ID
from datetime import datetime
result_export_time = datetime.now()
model_run_date_time = result_export_time.strftime("%Y-%m-%d_%H-%M")

from config import PROJECT_ROOT
from cmu_tare_model.utils.export_model_run_results import export_model_run_output

print(f"""
The results will be exported using the export_model_run_output function.
Documentation for this function:
{export_model_run_output.__doc__}

""")

# %% [markdown]
# # Baseline Scenario

# %%
# ===================================================================================================================================================================================
# Measure Package 0: Baseline
# ===================================================================================================================================================================================
# BASELINE Pre-IRA Scenario:
menu_mp = 0
input_mp = 'baseline'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_baseline_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")

print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Baseline Scenario - Model Run Complete")

# %%
print(output_folder_path)

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_baseline_damages_climate,
    results_category='damages_climate_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_baseline_damages_health,
    results_category='damages_health_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_baseline_fuel_costs,
    results_category='fuel_costs_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# ===== SUMMARY RESULTS =====
export_model_run_output(
    df_results_export=df_euss_am_baseline_home,
    results_category='summary_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# %%
print("""
Scenarios for Basic, Moderate, and Advanced Retrofit
- Rows in the Baseline CSV are merged with the Post-Retrofit Measure Package.
- The same filters are applied.

-------------------------------------------------------------------------------------------------------
MODEL SCENARIOS
-------------------------------------------------------------------------------------------------------
- BASIC/MODERATE/ADVANCED Pre-IRA Scenario:
    - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
    - AEO2023 No Inflation Reduction Act
    - Cambium 2021 MidCase
      
- BASIC/MODERATE/ADVANCED IRA-Reference Scenario:
    - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
    - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
    - Cambium 2022 and 2023 MidCase
""")

# %% [markdown]
# -------------------------------------------------------------------------------------------------------
# # POST-RETROFIT SCENARIOS: Basic (MP8), Moderate (MP9), Advanced (MP10)
# -------------------------------------------------------------------------------------------------------
# ## No IRA Scenario:
# - AEO2023 No Inflation Reduction Act
# - Cambium 2021 MidCase
# ## IRA-Reference Scenario:
# - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
# - Cambium 2022 and 2023 MidCase
# -------------------------------------------------------------------------------------------------------

# %%
from cmu_tare_model.constants import CR_FUNCTIONS, RCM_MODELS
from cmu_tare_model.utils.discounting import PRIVATE_DISCOUNT_RATE_COLS

# %% [markdown]
# ## Basic Retrofit: Measure Package 8 (MP8)

# %%
# Measure Package 8
menu_mp = 8
input_mp = 'upgrade08'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_basic_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Basic Retrofit Scenario - Model Run Complete")

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUPPLEMENTAL DATA
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp8_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp8_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUMMARY RESULTS FOR RCM MODELS AND DISCOUNT RATES SENSITIVITY ANALYSIS
# ===================================================================================================================================================================================
DATAFRAMES_MP8_RCM_DISCOUNT_RATE_RESULTS = {
    'ap2': {
        'private_discount_rate_fixed_low': df_euss_am_mp8_home_ap2_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp8_home_ap2_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp8_home_ap2_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp8_home_ap2_variable
    },
    'easiur': {
        'private_discount_rate_fixed_low': df_euss_am_mp8_home_easiur_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp8_home_easiur_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp8_home_easiur_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp8_home_easiur_variable
    },
    'inmap': {
        'private_discount_rate_fixed_low': df_euss_am_mp8_home_inmap_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp8_home_inmap_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp8_home_inmap_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp8_home_inmap_variable
    }
}

# Process each RCM model
for rcm_model in RCM_MODELS:
    print(f"Exporting SUMMARY RESULTS for {rcm_model.upper()} model...")
    
    # Process each discount method
    for discount_rate_col in PRIVATE_DISCOUNT_RATE_COLS:
        print(f"  Private Discounting Method: {discount_rate_col}")
        
        # Get the specific DataFrame for this RCM × discount rate combination
        df_results_export = DATAFRAMES_MP8_RCM_DISCOUNT_RATE_RESULTS[rcm_model][discount_rate_col]
        
        # Export summary results with explicit sensitivity parameters
        export_model_run_output(
            df_results_export=df_results_export,
            results_category='summary',  # Simplified - no parsing needed!
            menu_mp=menu_mp,
            output_folder_path=output_folder_path,
            location_id=location_id,
            results_export_formatted_date=model_run_date_time,
            rcm_model=rcm_model,  # Explicit sensitivity parameter
            discount_rate_col=discount_rate_col  # Explicit sensitivity parameter
        )

# %% [markdown]
# ## Moderate Retrofit: Measure Package 9 (MP9)

# %%
# Measure Package 9
menu_mp = 9
input_mp = 'upgrade09'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_moderate_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Moderate Retrofit Scenario - Model Run Complete")

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUPPLEMENTAL DATA
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp9_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp9_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUMMARY RESULTS FOR RCM MODELS AND DISCOUNT RATES SENSITIVITY ANALYSIS
# ===================================================================================================================================================================================
DATAFRAMES_MP9_RCM_DISCOUNT_RATE_RESULTS = {
    'ap2': {
        'private_discount_rate_fixed_low': df_euss_am_mp9_home_ap2_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp9_home_ap2_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp9_home_ap2_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp9_home_ap2_variable
    },
    'easiur': {
        'private_discount_rate_fixed_low': df_euss_am_mp9_home_easiur_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp9_home_easiur_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp9_home_easiur_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp9_home_easiur_variable
    },
    'inmap': {
        'private_discount_rate_fixed_low': df_euss_am_mp9_home_inmap_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp9_home_inmap_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp9_home_inmap_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp9_home_inmap_variable
    }
}

# Process each RCM model
for rcm_model in RCM_MODELS:
    print(f"Exporting SUMMARY RESULTS for {rcm_model.upper()} model...")
    
    # Process each discount method
    for discount_rate_col in PRIVATE_DISCOUNT_RATE_COLS:
        print(f"  Private Discounting Method: {discount_rate_col}")
        
        # Get the specific DataFrame for this RCM × discount rate combination
        df_results_export = DATAFRAMES_MP9_RCM_DISCOUNT_RATE_RESULTS[rcm_model][discount_rate_col]
        
        # Export summary results with explicit sensitivity parameters
        export_model_run_output(
            df_results_export=df_results_export,
            results_category='summary',  # Simplified - no parsing needed!
            menu_mp=menu_mp,
            output_folder_path=output_folder_path,
            location_id=location_id,
            results_export_formatted_date=model_run_date_time,
            rcm_model=rcm_model,  # Explicit sensitivity parameter
            discount_rate_col=discount_rate_col  # Explicit sensitivity parameter
        )

# %% [markdown]
# ## Advanced Retrofit: Measure Package 10 (MP10)

# %%
import os
import pandas as pd
# from IPython import get_ipython

# Format the name of the exported results file using the location ID
from datetime import datetime
result_export_time = datetime.now()
# model_run_date_time = result_export_time.strftime("%Y-%m-%d_%H-%M")
model_run_date_time = "2026-01-26_13-55"

from config import PROJECT_ROOT
from cmu_tare_model.utils.export_model_run_results import export_model_run_output

print(f"""
The results will be exported using the export_model_run_output function.
Documentation for this function:
{export_model_run_output.__doc__}

""")
# Out:
# Project root directory: c:\users\jorda\desktop\projects\cmu-tare-model
#
# The results will be exported using the export_model_run_output function.
# Documentation for this function:
# Export model run results to CSV files with sensitivity tracking.
#
#     This function exports DataFrame results to CSV files organized by result type.
#     For retrofit summary results, it adds sensitivity columns (RCM model and discount
#     rate method) to the DataFrame before export, enabling easy filtering and analysis
#     of sensitivity scenarios.
#
#     Directory Structure:
#         baseline_summary/summary_baseline/
#             - baseline_results_{location_id}_{date}.csv
#
#         retrofit_mp{menu_mp}_results/summary_mp{menu_mp}_{rcm_model}_{discount_rate_col}/
#             - mp{menu_mp}_results_{location_id}_{date}.csv
#             - DataFrame includes: rcm_model, discount_rate_col columns
#
#         supplemental_data_damages/{results_category}/
#             - mp{menu_mp}_{results_category}_{location_id}_{date}.csv
#
#         supplemental_data_fuelCosts/{results_category}/
#             - mp{menu_mp}_{results_category}_{location_id}_{date}.csv
#
#     Args:
#         df_results_export: DataFrame containing the results to export.
#         results_category: Category of results being exported. Valid options:
#             - 'summary_baseline': Baseline summary results
#             - 'summary': Retrofit summary results (requires rcm_model and discount_rate_col)
#             - 'damages_climate_IRA', 'damages_climate_noIRA': Climate damages
#             - 'damages_health_IRA', 'damages_health_noIRA': Health damages
#             - 'fuel_costs_IRA', 'fuel_costs_noIRA': Fuel costs
#         menu_mp: Measure package identifier (0 for baseline, 8/9/10 for retrofits).
#         output_folder_path: Base directory for all exports.
#         location_id: Location identifier for the filename (e.g., 'NYC', 'LA').
#         results_export_formatted_date: Date string for the filename (e.g., '2024_01_15').
#         rcm_model: RCM model used for health damage calculations (e.g., 'ap2', 'easiur',
#             'inmap'). Required when results_category='summary' and menu_mp != 0.
#         discount_rate_col: Discount rate method used (e.g., 'private_discount_rate_fixed_base',
#             'private_discount_rate_variable'). Required when results_category='summary' and menu_mp != 0.
#
#     Raises:
#         ValueError: If any required parameter is missing, results_category is invalid,
#             or sensitivity parameters are missing when required.
#         OSError: If there is an error creating directories or writing the file.

# %%
# Measure Package 10
menu_mp = 10
input_mp = 'upgrade10'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_advanced_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Advanced Retrofit Scenario - Model Run Complete")
# Out:
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_advanced_v2_2.ipynb
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_baseline_v2_2.ipynb
#
# =========================================================================================================
# Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
# Let's start by reading the data from the NREL EUSS Database.
#
# Make sure that the zipped folders stay organized as they are once unzipped.
# If changes are made to the file path, then the program will not run properly.
# ==========================================================================================================
#
# Project root directory: c:\users\jorda\desktop\projects\cmu-tare-model
# Result outputs will be exported here: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results
#
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# Load data from the NREL EUSS Database for the baseline scenario and apply various filters.
#
# DATA: NREL EUSS Database
# HOUSING FILTERS: Occupied units and Single Family Homes
# GEOGRAPHIC FILTERS: National, State, or City
#
# Additional details data can be found in the official End-Use Load Profiles/Savings Shapes documentation.
# Our methodology is detailed in the process_euss_data.py file and its associated imports.
#
# RESULTS OUTPUT:
#
# Retrieved data for filename: baseline_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\baseline_metadata_and_annual_results.csv
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 259)
# You chose to analyze all of the United States.
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline
#
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 239            0  242.131013           True   1690.0
# 273            0  242.131013           True   1690.0
# 307            0  242.131013           True   1220.0
# 409            0  242.131013           True   1220.0
# 517            0  242.131013           True   1220.0
# ...          ...         ...            ...      ...
# 548226         0  242.131013           True   2176.0
# 548228         0  242.131013           True   1690.0
# 548417         0  242.131013           True    885.0
# 549740         0  242.131013           True   1220.0
# 549938         0  242.131013           True    885.0
#
#                        in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 239      Non-CBSA East South Central                               3A
# 273      Non-CBSA East South Central                               3A
# 307      Non-CBSA East South Central                               3A
# 409      Non-CBSA East South Central                               3A
# 517      Non-CBSA East South Central                               3A
# ...                              ...                              ...
# 548226             Non-CBSA Mountain                               6B
# 548228             Non-CBSA Mountain                               6B
# 548417             Non-CBSA Mountain                               6B
# 549740             Non-CBSA Mountain                               7B
# 549938             Non-CBSA Mountain                               6B
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 239                                             3A                     Hour20
# 273                                             3A                     Hour12
# 307                                             3A                      Hour0
# 409                                             3A                     Hour20
# 517                                             3A                      Hour1
# ...                                            ...                        ...
# 548226                                          6B                      Hour3
# 548228                                          6B                      Hour6
# 548417                                          6B                     Hour18
# 549740                                          7B                      Hour4
# 549938                                          6B                      Hour2
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 239                3                        Hot-Humid  ...
# 273                3                      Mixed-Humid  ...
# 307                4                        Hot-Humid  ...
# 409                2                        Hot-Humid  ...
# 517                3                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 548226             4                             Cold  ...
# 548228             4                             Cold  ...
# 548417             2                             Cold  ...
# 549740             2                        Very Cold  ...
# 549938             2                             Cold  ...
#
#         out.emissions.natural_gas.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 239                                             215.943534
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1642.477930
# 517                                               0.000000
# ...                                                    ...
# 548226                                        15324.356044
# 548228                                         8192.601682
# 548417                                         5212.758359
# 549740                                            0.000000
# 549938                                         9625.513133
#
#         out.emissions.propane.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 239                                               0.000000
# 273                                               0.000000
# 307                                               0.000000
# 409                                               0.000000
# 517                                               0.000000
# ...                                                    ...
# 548226                                            0.000000
# 548228                                            0.000000
# 548417                                            0.000000
# 549740                                          268.627834
# 549938                                            0.000000
#
#         out.emissions.electricity.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                            8773.384074
# 273                                           11296.731129
# 307                                            8750.011820
# 409                                            5725.103641
# 517                                            8932.439414
# ...                                                    ...
# 548226                                         2313.298407
# 548228                                         1889.439924
# 548417                                         2112.907195
# 549740                                        11423.104685
# 549938                                         1109.233379
#
#         out.emissions.fuel_oil.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                                    0.0
# 273                                                    0.0
# 307                                                    0.0
# 409                                                    0.0
# 517                                                    0.0
# ...                                                    ...
# 548226                                                 0.0
# 548228                                                 0.0
# 548417                                                 0.0
# 549740                                                 0.0
# 549938                                                 0.0
#
#         out.emissions.natural_gas.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                             215.943534
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1642.477930
# 517                                               0.000000
# ...                                                    ...
# 548226                                        15324.356044
# 548228                                         8192.601682
# 548417                                         5212.758359
# 549740                                            0.000000
# 549938                                         9625.513133
#
#         out.emissions.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                               0.000000
# 273                                               0.000000
# 307                                               0.000000
# 409                                               0.000000
# 517                                               0.000000
# ...                                                    ...
# 548226                                            0.000000
# 548228                                            0.000000
# 548417                                            0.000000
# 549740                                          268.627834
# 549938                                            0.000000
#
#         out.emissions.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 239                                            3565.038262
# 273                                            4339.903757
# 307                                            3345.187937
# 409                                            3784.993820
# 517                                            3441.414837
# ...                                                    ...
# 548226                                        16802.023908
# 548228                                         9394.122057
# 548417                                         6546.826589
# 549740                                         7173.561517
# 549938                                        10320.128613
#
#         out.emissions.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 239                                            6416.193347
# 273                                            8193.678510
# 307                                            6249.625611
# 409                                            5489.549041
# 517                                            6415.303853
# ...                                                    ...
# 548226                                        16545.095582
# 548228                                         9195.903552
# 548417                                         6318.763521
# 549740                                         5931.433285
# 549938                                        10198.241539
#
#         out.emissions.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 239                                            5755.373221
# 273                                            7254.665194
# 307                                            5587.946834
# 409                                            5164.458936
# 517                                            5721.073473
# ...                                                    ...
# 548226                                        16472.920871
# 548228                                         9129.578822
# 548417                                         6253.986448
# 549740                                         4609.821155
# 549938                                        10166.744085
#
#         out.emissions.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg
# bldg_id
# 239                                            8989.327608
# 273                                           11296.731129
# 307                                            8750.011820
# 409                                            7367.581571
# 517                                            8932.439414
# ...                                                    ...
# 548226                                        17637.654451
# 548228                                        10082.041606
# 548417                                         7325.665554
# 549740                                        11691.732519
# 549938                                        10734.746512
#
# [331531 rows x 259 columns]
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# In addition to the housing type and occupancy filters, the data has been filtered for fuel and technology
# Please see the energy_consumption_and_metadata folder for more details on data processing.
#
# We employ the df_enduse_refactored function to process the data and create a new dataframe, which is part of the 5-step data validation process:
# 1. Mask Initialization with initialize_validation_tracking()
# 2. Series Initialization with create_retrofit_only_series()
# 3. Valid-Only Calculation for qualifying homes
# 4. Valid-Only Updates using list-based collection
# 5. Final Masking with apply_final_masking()
#
# ----------------------------------------------------------------
#
# RESULTS OUTPUT (BASELINE):
#
# Processing column: in.clothes_dryer
# Initial data types: object
# Data types after processing: object
# Processing column: in.cooking_range
# Initial data types: object
# Data types after processing: object
# Calculated total heating consumption
# Calculated total waterHeating consumption
# Calculated total clothesDrying consumption
# Calculated total cooking consumption
#
# Applying data validation (baseline only):
#   base_electricity_heating_consumption: Masked 71320 values
#   base_naturalGas_heating_consumption: Masked 71320 values
#   base_fuelOil_heating_consumption: Masked 71320 values
#   base_propane_heating_consumption: Masked 71320 values
#   baseline_heating_consumption: Masked 61081 values
#   base_electricity_waterHeating_consumption: Masked 8732 values
#   base_naturalGas_waterHeating_consumption: Masked 8732 values
#   base_fuelOil_waterHeating_consumption: Masked 8732 values
#   base_propane_waterHeating_consumption: Masked 8732 values
#   baseline_waterHeating_consumption: Masked 8063 values
#   base_electricity_clothesDrying_consumption: Masked 14958 values
#   base_naturalGas_clothesDrying_consumption: Masked 14958 values
#   base_propane_clothesDrying_consumption: Masked 14958 values
#   base_naturalGas_cooking_consumption: Masked 205158 values
#   base_propane_cooking_consumption: Masked 205158 values
#
# ====================================================================================================================================================================
#
# DATAFRAME: df_euss_am_baseline_home
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#         urbanicity  ... valid_fuel_heating valid_tech_heating include_heating  \
# bldg_id             ...
# 239          Rural  ...               True               True            True
# 273       Suburban  ...               True               True            True
# 307       Suburban  ...               True              False           False
# 409          Rural  ...               True               True            True
# 517          Rural  ...               True              False           False
# ...            ...  ...                ...                ...             ...
# 548226       Rural  ...               True               True            True
# 548228       Rural  ...               True               True            True
# 548417       Rural  ...               True               True            True
# 549740       Rural  ...               True               True            True
# 549938       Rural  ...               True              False           False
#
#         valid_fuel_waterHeating valid_tech_waterHeating  include_waterHeating  \
# bldg_id
# 239                        True                    True                  True
# 273                        True                    True                  True
# 307                        True                    True                  True
# 409                        True                    True                  True
# 517                        True                    True                  True
# ...                         ...                     ...                   ...
# 548226                     True                    True                  True
# 548228                     True                    True                  True
# 548417                     True                    True                  True
# 549740                     True                    True                  True
# 549938                     True                    True                  True
#
#          valid_fuel_clothesDrying include_clothesDrying valid_fuel_cooking  \
# bldg_id
# 239                          True                  True               True
# 273                          True                  True              False
# 307                          True                  True              False
# 409                          True                  True               True
# 517                          True                  True              False
# ...                           ...                   ...                ...
# 548226                       True                  True              False
# 548228                       True                  True              False
# 548417                       True                  True              False
# 549740                       True                  True               True
# 549938                       True                  True               True
#
#         include_cooking
# bldg_id
# 239                True
# 273               False
# 307               False
# 409                True
# 517               False
# ...                 ...
# 548226            False
# 548228            False
# 548417            False
# 549740             True
# 549938             True
#
# [331531 rows x 61 columns]
#
#
#
#     -------------------------------------------------------------------------------------------------------
#     PRE-IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2021 RELEASE
#     -------------------------------------------------------------------------------------------------------
#
#
#
#     Retrieved data for filename: cambium21_midCase_annual_gea.xlsx
#     Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\projections\cambium21_midCase_annual_gea.xlsx
#
#     Loading dataframe ...
#
#               dataset scenario gea_region  year  cef_gen  aer_co2e_kg_per_MWh  \
# 0    Cambium_2021  MidCase      AZNMc  2022      NaN                423.2
# 1    Cambium_2021  MidCase      AZNMc  2024      NaN                389.5
# 2    Cambium_2021  MidCase      AZNMc  2026      NaN                374.7
# 3    Cambium_2021  MidCase      AZNMc  2028      NaN                364.8
# 4    Cambium_2021  MidCase      AZNMc  2030      NaN                315.8
# ..            ...      ...        ...   ...      ...                  ...
# 295  Cambium_2021  MidCase      SRVCc  2042      NaN                240.8
# 296  Cambium_2021  MidCase      SRVCc  2044      NaN                222.5
# 297  Cambium_2021  MidCase      SRVCc  2046      NaN                178.5
# 298  Cambium_2021  MidCase      SRVCc  2048      NaN                182.1
# 299  Cambium_2021  MidCase      SRVCc  2050      NaN                169.3
#
#      lrmer_co2e_kg_per_MWh  srmer_co2e_kg_per_MWh  generation  \
# 0                    525.6                  811.8   143037980
# 1                    488.4                  808.4   151806820
# 2                    423.1                  816.0   154638340
# 3                    315.8                  784.7   159426910
# 4                    313.6                  749.8   175350740
# ..                     ...                    ...         ...
# 295                  313.9                  805.5   400253860
# 296                  314.6                  786.1   427886080
# 297                  320.6                  754.9   444492960
# 298                  317.9                  751.3   453625180
# 299                  306.7                  718.3   466444480
#
#      variable_generation  ...  total_coal  total_natural_gas  total_oil  \
# 0             27345228.0  ...  32912356.0         40391114.7    29364.0
# 1             29423460.0  ...  27460646.0         52221791.8    14086.3
# 2             29648762.0  ...  26772840.0         53833046.4     8814.2
# 3             32619604.0  ...  26693880.0         55589546.7    10161.3
# 4             50951904.0  ...  24898662.0         54122073.2    13228.5
# ..                   ...  ...         ...                ...        ...
# 295           96427260.0  ...  37576316.0        117368159.3     2205.4
# 296          115764890.0  ...  33240228.0        125603043.3     1392.8
# 297          150328400.0  ...  27152428.0        105858843.0       74.8
# 298          152065260.0  ...  27861414.0        111393181.0       49.1
# 299          154687700.0  ...  14777366.0        134385100.3        9.9
#
#      total_nuclear  total_renewable  fraction_coal  fraction_natural_gas  \
# 0         31446266       37669404.5       0.231047              0.283549
# 1         31446266       40074547.2       0.181597              0.345343
# 2         31446266       41990327.2       0.173792              0.349449
# 3         31446266       45101365.5       0.168054              0.349969
# 4         31446266       64294435.2       0.142462              0.309668
# ..             ...              ...            ...                   ...
# 295      122300980      121063293.0       0.094339              0.294665
# 296      122300980      144866950.7       0.078026              0.294834
# 297      122300980      187251355.2       0.061353              0.239195
# 298      122300980      190141835.5       0.061682              0.246610
# 299      122300980      193718661.2       0.031767              0.288887
#
#      fraction_oil  fraction_nuclear  fraction_renewable
# 0    2.061377e-04          0.220755            0.264442
# 1    9.315268e-05          0.207954            0.265013
# 2    5.721601e-05          0.204129            0.272574
# 3    6.397143e-05          0.197973            0.283940
# 4    7.568889e-05          0.179925            0.367870
# ..            ...               ...                 ...
# 295  5.536880e-06          0.307049            0.303942
# 296  3.269387e-06          0.287083            0.340053
# 297  1.690152e-07          0.276347            0.423106
# 298  1.087011e-07          0.270759            0.420950
# 299  2.128199e-08          0.262910            0.416436
#
# [300 rows x 43 columns]
#
#     Creating lookup dictionary for LRMER and SRMER ...
#     -------------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------------
#     IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2022 RELEASE
#     -------------------------------------------------------------------------------------------------------
#
#
#     Retrieved data for filename: cambium22_allScenarios_annual_gea.xlsx
#     Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\projections\cambium22_allScenarios_annual_gea.xlsx
#
#     Loading dataframe ...
#
#           data_source scenario gea_region  year  cef_gen  aer_co2e_kg_per_MWh  \
# 0    Cambium_2022  MidCase      AZNMc  2024     0.63                279.4
# 1    Cambium_2022  MidCase      AZNMc  2026     0.69                237.5
# 2    Cambium_2022  MidCase      AZNMc  2028     0.80                157.9
# 3    Cambium_2022  MidCase      AZNMc  2030     0.84                133.3
# 4    Cambium_2022  MidCase      AZNMc  2035     0.89                 81.9
# ..            ...      ...        ...   ...      ...                  ...
# 155  Cambium_2022  MidCase      SRVCc  2030     0.75                147.1
# 156  Cambium_2022  MidCase      SRVCc  2035     0.83                 92.1
# 157  Cambium_2022  MidCase      SRVCc  2040     0.86                 75.5
# 158  Cambium_2022  MidCase      SRVCc  2045     0.93                 38.7
# 159  Cambium_2022  MidCase      SRVCc  2050     0.93                 38.9
#
#      lrmer_co2e_kg_per_MWh  srmer_co2e_kg_per_MWh  generation  \
# 0                    326.9                  777.1   185725700
# 1                    193.9                  709.7   192790580
# 2                    130.5                  576.4   193906060
# 3                    103.7                  486.7   193562020
# 4                    149.4                  398.4   210627860
# ..                     ...                    ...         ...
# 155                  211.7                  662.9   391723170
# 156                  211.6                  583.4   459622500
# 157                  188.3                  540.5   481364480
# 158                  142.2                  497.4   501150400
# 159                  113.2                  511.2   501907700
#
#      variable_generation  ...  total_coal  total_natural_gas  total_oil  \
# 0             74605900.0  ...  22849070.0         46188801.1    35759.0
# 1             87517200.0  ...  21009922.0         38928884.4    26155.8
# 2            108173544.0  ...  14483350.0         25156486.8    19751.4
# 3            113367950.0  ...  13433882.0         18404394.4     2684.8
# 4            128952530.0  ...   8231337.5         14217323.4     4222.1
# ..                   ...  ...         ...                ...        ...
# 155          139815250.0  ...  17312904.0         79749385.0     2648.2
# 156          209080400.0  ...   8787109.0         67359566.6     2424.3
# 157          229834830.0  ...   6132569.5         60580299.5     2979.2
# 158          265812640.0  ...   4301606.5         28826117.4      748.2
# 159          271552540.0  ...   1924772.2         34071135.0       17.9
#
#      total_nuclear  total_renewable  fraction_coal  fraction_natural_gas  \
# 0       30865014.0       85518978.5       0.123204              0.249053
# 1       30392044.0      102169009.2       0.109128              0.202201
# 2       29352388.0      124638520.0       0.074791              0.129907
# 3       28571094.0      132901330.4       0.069493              0.095205
# 4       27536908.0      160412983.2       0.039122              0.067572
# ..             ...              ...            ...                   ...
# 155    119012670.0      173052397.5       0.044491              0.204943
# 156    116559336.0      264783518.0       0.019207              0.147237
# 157    115754584.0      296807708.5       0.012795              0.126399
# 158    114458344.0      352150817.0       0.008608              0.057683
# 159    111073256.0      353415175.0       0.003846              0.068076
#
#      fraction_oil  fraction_nuclear  fraction_renewable
# 0    1.928149e-04          0.166426            0.461124
# 1    1.358559e-04          0.157859            0.530676
# 2    1.019951e-04          0.151574            0.643626
# 3    1.388833e-05          0.147797            0.687492
# 4    2.006675e-05          0.130877            0.762409
# ..            ...               ...                 ...
# 155  6.805438e-06          0.305843            0.444716
# 156  5.299110e-06          0.254779            0.578772
# 157  6.216015e-06          0.241519            0.619281
# 158  1.497186e-06          0.229037            0.704671
# 159  3.576535e-08          0.221932            0.706146
#
# [160 rows x 44 columns]
#
#     Creating lookup dictionary for 2024 LRMER and SRMER ...
#     -------------------------------------------------------------------------------------------------------
#
# Fuel sources in df_grid_mix: {'Natural Gas', 'Renewable', 'Coal', 'Nuclear', 'Oil'}
# Fuel sources in df_grid_emis_factors: {'Renewables', 'Natural Gas', 'Coal', 'Nuclear', 'Oil'}
# Retrieved data for filename: bls_cpiu_2005-2023.xlsx
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\inflation_data\bls_cpiu_2005-2023.xlsx
#     year  cpiu_annual
# 0   2005      195.300
# 1   2006      201.600
# 2   2007      207.342
# 3   2008      215.303
# 4   2009      214.537
# 5   2010      218.056
# 6   2011      224.939
# 7   2012      229.594
# 8   2013      232.957
# 9   2014      236.736
# 10  2015      237.017
# 11  2016      240.007
# 12  2017      245.120
# 13  2018      251.107
# 14  2019      255.657
# 15  2020      258.811
# 16  2021      270.970
# 17  2022      292.655
# 18  2023      304.702
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
#     ===================================================================================================================================================================================
#     HEALTH IMPACTS (MARGINAL SOCIAL COSTS): FOSSIL FUELS
#     ===================================================================================================================================================================================
#     Model: RCM
#     Output Area: county_fips
#     Geography: Counties
#     Pollutant: NOX,SO2,PM25
#     VSL: 11.45M (Inflated from 11.0M USD2022 to 11.45M USD2023)
#         CPI Ratio for 2022 to 2023: 1.04116
#         VSL2023 = VSL2022 * 1.04116 = 11.0M * 1.04116 = 11.45 M
#
#     Previously used VSL values (from formerly proposed VSL Guidance):
#         VSL: 12.71M (Inflated from 11.3M USD2021 to 12.71M USD2023)
#             CPI Ratio for 2021 to 2023: 1.1244861054729305
#             VSL2023 = VSL2021 * 1.1244861054729305 = 11.3M * 1.1244861054729305 = 12.71 M
#
#     Stack Height: ground level
#
#     C-R Function: ACS or H6C
#     ===================================================================================================================================================================================
#     - Clean the data so that only annual values are retained.
#     - Convert 'county_fips' to string and pad with leading zeros (to ensure a 5-digit format)
#
#     DATAFRAME: Ground Level, ACS C-R Function
#
#             fips state_abbr pollutant   model  season      elevated  \
# 0       1001         AL      pm25     ap2  annual  ground level
# 1       1001         AL       so2     ap2  annual  ground level
# 2       1001         AL       nox     ap2  annual  ground level
# 3       1001         AL      pm25  easiur  annual  ground level
# 4       1001         AL       so2  easiur  annual  ground level
# ...      ...        ...       ...     ...     ...           ...
# 65269  56045         WY       so2  easiur  annual  ground level
# 65270  56045         WY       nox  easiur  annual  ground level
# 65283  56045         WY      pm25   inmap  annual  ground level
# 65284  56045         WY       so2   inmap  annual  ground level
# 65285  56045         WY       nox   inmap  annual  ground level
#
#               damage county_fips state  damage_usd2023
# 0       41623.096517       01001    AL    41623.096517
# 1       22731.015752       01001    AL    22731.015752
# 2        3010.575674       01001    AL     3010.575674
# 3      119852.974197       01001    AL   119852.974197
# 4       23058.154823       01001    AL    23058.154823
# ...              ...         ...   ...             ...
# 65269   13403.747963       56045    WY    13403.747963
# 65270    2459.401698       56045    WY     2459.401698
# 65283   14435.839015       56045    WY    14435.839015
# 65284    9987.857779       56045    WY     9987.857779
# 65285    8759.638368       56045    WY     8759.638368
#
# [27978 rows x 10 columns]
#
#     DATAFRAME: Ground Level, H6C C-R Function
#
#             fips state_abbr pollutant   model  season      elevated  \
# 0       1001         AL      pm25     ap2  annual  ground level
# 1       1001         AL       so2     ap2  annual  ground level
# 2       1001         AL       nox     ap2  annual  ground level
# 3       1001         AL      pm25  easiur  annual  ground level
# 4       1001         AL       so2  easiur  annual  ground level
# ...      ...        ...       ...     ...     ...           ...
# 65269  56045         WY       so2  easiur  annual  ground level
# 65270  56045         WY       nox  easiur  annual  ground level
# 65283  56045         WY      pm25   inmap  annual  ground level
# 65284  56045         WY       so2   inmap  annual  ground level
# 65285  56045         WY       nox   inmap  annual  ground level
#
#               damage county_fips state  damage_usd2023
# 0      106941.745238       01001    AL   106941.745238
# 1       58401.827196       01001    AL    58401.827196
# 2        7733.583867       01001    AL     7733.583867
# 3      307939.819428       01001    AL   307939.819428
# 4       59242.354181       01001    AL    59242.354181
# ...              ...         ...   ...             ...
# 65269   34437.033708       56045    WY    34437.033708
# 65270    6317.438130       56045    WY     6317.438130
# 65283   37088.812286       56045    WY    37088.812286
# 65284   25660.497570       56045    WY    25660.497570
# 65285   22504.801260       56045    WY    22504.801260
#
# [27978 rows x 10 columns]
#
#     ====================================================================================================================================================================================
#     CREATES LOOKUP DICTIONARY: HEALTH IMPACTS (MSC) FROM FOSSIL FUELS
#     ===================================================================================================================================================================================
#
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
#     ===================================================================================================================================================================================
#     HEALTH IMPACTS (MARGINAL SOCIAL COSTS): ELECTRICITY GENERATION
#     ===================================================================================================================================================================================
#     Model: RCM
#     Output Area: county_fips
#     Geography: Counties
#     Pollutant: NOX,SO2,PM25
#     VSL: 11.45M (Inflated from 11.0M USD2022 to 11.45M USD2023)
#         CPI Ratio for 2022 to 2023: 1.04116
#         VSL2023 = VSL2022 * 1.04116 = 11.0M * 1.04116 = 11.45 M
#
#     Previously used VSL values (from formerly proposed VSL Guidance):
#         VSL: 12.71M (Inflated from 11.3M USD2021 to 12.71M USD2023)
#             CPI Ratio for 2021 to 2023: 1.1244861054729305
#             VSL2023 = VSL2021 * 1.1244861054729305 = 11.3M * 1.1244861054729305 = 12.71 M
#
#     Stack Height: high stack
#
#     C-R Function: ACS or H6C
#     ===================================================================================================================================================================================
#     - Clean the data so that only annual values are retained.
#     - Convert 'county_fips' to string and pad with leading zeros (to ensure a 5-digit format)
#
#     DATAFRAME: Elevated (High Stack), ACS C-R Function
#
#             fips state_abbr pollutant   model  season    elevated        damage  \
# 0       1001         AL      pm25     ap2  annual  high stack  23337.829921
# 1       1001         AL       so2     ap2  annual  high stack  18174.760357
# 2       1001         AL       nox     ap2  annual  high stack   2846.740555
# 3       1001         AL      pm25  easiur  annual  high stack  63124.135246
# 4       1001         AL       so2  easiur  annual  high stack  21527.986143
# ...      ...        ...       ...     ...     ...         ...           ...
# 65269  56045         WY       so2  easiur  annual  high stack  15066.815244
# 65270  56045         WY       nox  easiur  annual  high stack   2475.044741
# 65283  56045         WY      pm25   inmap  annual  high stack  15535.888213
# 65284  56045         WY       so2   inmap  annual  high stack  11205.936757
# 65285  56045         WY       nox   inmap  annual  high stack   9072.079939
#
#       county_fips state  damage_usd2023
# 0           01001    AL    23337.829921
# 1           01001    AL    18174.760357
# 2           01001    AL     2846.740555
# 3           01001    AL    63124.135246
# 4           01001    AL    21527.986143
# ...           ...   ...             ...
# 65269       56045    WY    15066.815244
# 65270       56045    WY     2475.044741
# 65283       56045    WY    15535.888213
# 65284       56045    WY    11205.936757
# 65285       56045    WY     9072.079939
#
# [27978 rows x 10 columns]
#
#     DATAFRAME: Elevated (High Stack), H6C C-R Function
#
#             fips state_abbr pollutant   model  season    elevated         damage  \
# 0       1001         AL      pm25     ap2  annual  high stack   59960.930738
# 1       1001         AL       so2     ap2  annual  high stack   46695.320844
# 2       1001         AL       nox     ap2  annual  high stack    7312.638003
# 3       1001         AL      pm25  easiur  annual  high stack  162184.927329
# 4       1001         AL       so2  easiur  annual  high stack   55310.851705
# ...      ...        ...       ...     ...     ...         ...            ...
# 65269  56045         WY       so2  easiur  annual  high stack   38709.996044
# 65270  56045         WY       nox  easiur  annual  high stack    6357.630210
# 65283  56045         WY      pm25   inmap  annual  high stack   39915.197510
# 65284  56045         WY       so2   inmap  annual  high stack   28790.139799
# 65285  56045         WY       nox   inmap  annual  high stack   23307.565574
#
#       county_fips state  damage_usd2023
# 0           01001    AL    59960.930738
# 1           01001    AL    46695.320844
# 2           01001    AL     7312.638003
# 3           01001    AL   162184.927329
# 4           01001    AL    55310.851705
# ...           ...   ...             ...
# 65269       56045    WY    38709.996044
# 65270       56045    WY     6357.630210
# 65283       56045    WY    39915.197510
# 65284       56045    WY    28790.139799
# 65285       56045    WY    23307.565574
#
# [27978 rows x 10 columns]
#
#     ====================================================================================================================================================================================
#     CREATES LOOKUP DICTIONARY: HEALTH IMPACTS (MSC) FROM ELECTRICITY GENERATION
#     ===================================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# PUBLIC IMPACTS (BASELINE): DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
# Detailed documentation of the methods used to calculate the climate and public health impacts can be
# found in the public_impacts folder of the cmu-tare-model package. All monetary values are in 2023
# inflation-adjusted dollars ($USD2023).
# - data_processing sub-folder: contains the data processing scripts used for lookup dictionaries
# - calculations sub-folder: contains the calculations for emissions from fossul fuel appliances
# - Main folder contains the scripts for calculating lifetime climate and public health impacts as
#   as well as climate NPV, health NPV, and combined public NPV.
#
# Step 1: Calculate the baseline marginal damages for climate and health-related emissions
# Step 2: Calculate the post-retrofit marginal damages for climate and health-related emissions
# Step 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
#
# ...
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#         urbanicity  ... public_discount_rate private_discount_rate_fixed_low  \
# bldg_id             ...
# 239          Rural  ...                 0.02                            0.02
# 273       Suburban  ...                 0.02                            0.02
# 307       Suburban  ...                 0.02                            0.02
# 409          Rural  ...                 0.02                            0.02
# 517          Rural  ...                 0.02                            0.02
# ...            ...  ...                  ...                             ...
# 548226       Rural  ...                 0.02                            0.02
# 548228       Rural  ...                 0.02                            0.02
# 548417       Rural  ...                 0.02                            0.02
# 549740       Rural  ...                 0.02                            0.02
# 549938       Rural  ...                 0.02                            0.02
#
#         private_discount_rate_fixed_base private_discount_rate_fixed_high  \
# bldg_id
# 239                                 0.07                             0.12
# 273                                 0.07                             0.12
# 307                                 0.07                             0.12
# 409                                 0.07                             0.12
# 517                                 0.07                             0.12
# ...                                  ...                              ...
# 548226                              0.07                             0.12
# 548228                              0.07                             0.12
# 548417                              0.07                             0.12
# 549740                              0.07                             0.12
# 549938                              0.07                             0.12
#
#         private_discount_rate_variable  mp10_heating_rebate_amount  \
# bldg_id
# 239                           0.070000                         0.0
# 273                           0.070000                         0.0
# 307                           0.296480                         NaN
# 409                           0.347147                      8000.0
# 517                           0.289032                         NaN
# ...                                ...                         ...
# 548226                        0.283535                      8000.0
# 548228                        0.070000                         0.0
# 548417                        0.302509                      8000.0
# 549740                        0.070000                         0.0
# 549938                        0.203304                         NaN
#
#          weatherization_rebate_amount mp10_waterHeating_rebate_amount  \
# bldg_id
# 239                               0.0                            0.00
# 273                               0.0                            0.00
# 307                               0.0                         1750.00
# 409                            1600.0                         1750.00
# 517                               0.0                         1750.00
# ...                               ...                             ...
# 548226                            0.0                         1750.00
# 548228                            0.0                            0.00
# 548417                            0.0                         1750.00
# 549740                            0.0                            0.00
# 549938                            0.0                         1682.43
#
#          mp10_clothesDrying_rebate_amount mp10_cooking_rebate_amount
# bldg_id
# 239                                   0.0                        0.0
# 273                                   0.0                        NaN
# 307                                 840.0                        NaN
# 409                                 840.0                      840.0
# 517                                 840.0                        NaN
# ...                                   ...                        ...
# 548226                              840.0                        NaN
# 548228                                0.0                        NaN
# 548417                              840.0                        NaN
# 549740                                0.0                        0.0
# 549938                              840.0                      840.0
#
# [331531 rows x 445 columns]
#
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: OVERVIEW
# ====================================================================================================================================================================
#
# -------------------------------------------------------
# PUBLIC IMPACTS: CLIMATE AND HEALTH
# -------------------------------------------------------
# calculate_lifetime_public_impact.py file contains the definition for the calculate_public_npv function.
# Additional information on emissions/damage factor lookups as well as marginal damages calculation methods can be found in the public_impact folder.
#
# --------------------------------------------------------
# PRIVATE IMPACTS: LIFETIME CAPITAL COSTS AND SAVINGS
# --------------------------------------------------------
# calculate_lifetime_private_impact.py file contains the definition for the calculate_private_npv function.
# Additional information on fuel price lookups as well as capital costs calculation methods can be found in the private_impact folder.
#
# --------------------------------------------------------
# ADOPTION POTENTIAL
# --------------------------------------------------------
# determine_adoption_potential_sensitivity.py file contains the definitions for:
# - adoption_decision function (combined climate + health analysis)
# - calculate_climate_only_adoption_robust function (climate-only analysis)
# - calculate_health_only_adoption_robust function (health-only analysis)
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
#
# ====================================================================================================================================================================
# Scenario No Inflation Reduction Act:
# Advanced Retrofit: Measure Package 10
# Fuel Costs: AEO2023 No Inflation Reduction Act
# Electricity Grid: Cambium 2021 MidCase Scenario
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PUBLIC IMPACT
# ====================================================================================================================================================================
# Completed Steps:
# 1. Calculate the baseline marginal damages for climate and health-related emissions                         [COMPLETED]
# 2. Calculate the post-retrofit marginal damages for climate and health-related emissions                    [COMPLETED]
#
# REMAINING STEP:
# Step 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
# -------------------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT:
#
# Calculating Public NPV for different RCM models and discount methods ...
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PRIVATE IMPACT
# ====================================================================================================================================================================
# Completed Steps:
# 1. Calculate annual operating (fuel) costs                                                                  [COMPLETED]
# 2. Calculate equipment capital costs (For space heating, include ductwork and weatherization (MP9-10))      [COMPLETED]
# 3. Calculate replacement cost (replacing existing piece of eqipment with similar technology)                [COMPLETED]
#
# REMAINING STEP:
# Step 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
# ----------------------------------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT (NO INFLATION REDUCTION ACT):
#
# Calculating Private NPV for different RCM models and discount methods ...
#
# ====================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): ADOPTION POTENTIAL
# ====================================================================================================
# determine_adoption_potential_sensitivity.py file contains the definitions for:
# - adoption_decision function (combined climate + health analysis)
# - calculate_climate_only_adoption_robust function (climate-only analysis)
# - calculate_health_only_adoption_robust function (health-only analysis)
#
# -----------------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT (NO INFLATION REDUCTION ACT):
#
# Determining Adoption Potential for different RCM models and discount rate methods ...
#
# ================================================================================
# PRE-PROCESSING DIAGNOSTIC: Checking for duplicate columns
# ================================================================================
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Advanced IRA-Reference:
# Advanced Retrofit: Measure Package 10
# Fuel Costs: AEO2023 Reference Case
# Electricity Grid: Cambium 2023 MidCase Scenario
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PUBLIC IMPACT
# ====================================================================================================================================================================
# STEP 1. Calculate the baseline marginal damages for climate and health-related emissions                    [COMPLETED]
# STEP 2. Calculate the post-retrofit marginal damages for climate and health-related emissions               [COMPLETED]
#
# REMAINING STEP:
# STEP 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
#
# ---------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT:
#
# Calculating Public NPV for different RCM models and discount methods ...
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PRIVATE IMPACT
# ====================================================================================================================================================================
# STEP 1: Calculate annual operating (fuel) costs                                                             [COMPLETED]
# STEP 2: Calculate equipment capital costs (HEATING: include ductwork and weatherization (MP10 and MP10))    [COMPLETED]
# STEP 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)           [COMPLETED]
#
# REMAINING STEP:
# STEP 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
# ----------------------------------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT (AEO2023 REFERENCE CASE):
#
# Calculating Private NPV for different RCM models and discount methods ...
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): ADOPTION POTENTIAL
# ====================================================================================================================================================================
# determine_adoption_potential_sensitivity_robust.py file contains the definitions for:
# - adoption_decision function (combined climate + health analysis)
# - calculate_climate_only_adoption_robust function (climate-only analysis)
# - calculate_health_only_adoption_robust function (health-only analysis)
#
# -----------------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT (AEO2023 REFERENCE CASE):
#
# Determining Adoption Potential for different RCM models and discount rate methods ...
#
# ================================================================================
# PRE-PROCESSING DIAGNOSTIC: Checking for duplicate columns
# ================================================================================
# The code took 70 minutes and 5 seconds to execute.
# Advanced Retrofit Scenario - Model Run Complete

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUPPLEMENTAL DATA
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp10_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp10_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)
# Out:
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_noIRA
# Saved to: mp10_damages_climate_noIRA_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_noIRA\mp10_damages_climate_noIRA_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_IRA
# Saved to: mp10_damages_climate_IRA_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_IRA\mp10_damages_climate_IRA_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_noIRA
# Saved to: mp10_damages_health_noIRA_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_noIRA\mp10_damages_health_noIRA_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_IRA
# Saved to: mp10_damages_health_IRA_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_IRA\mp10_damages_health_IRA_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_noIRA
# Saved to: mp10_fuel_costs_noIRA_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_noIRA\mp10_fuel_costs_noIRA_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_IRA
# Saved to: mp10_fuel_costs_IRA_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_IRA\mp10_fuel_costs_IRA_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV - SUMMARY RESULTS FOR RCM MODELS AND DISCOUNT RATES SENSITIVITY ANALYSIS
# ===================================================================================================================================================================================
DATAFRAMES_MP10_RCM_DISCOUNT_RATE_RESULTS = {
    'ap2': {
        'private_discount_rate_fixed_low': df_euss_am_mp10_home_ap2_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp10_home_ap2_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp10_home_ap2_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp10_home_ap2_variable
    },
    'easiur': {
        'private_discount_rate_fixed_low': df_euss_am_mp10_home_easiur_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp10_home_easiur_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp10_home_easiur_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp10_home_easiur_variable
    },
    'inmap': {
        'private_discount_rate_fixed_low': df_euss_am_mp10_home_inmap_fixed_low,
        'private_discount_rate_fixed_base': df_euss_am_mp10_home_inmap_fixed_base,
        'private_discount_rate_fixed_high': df_euss_am_mp10_home_inmap_fixed_high,
        'private_discount_rate_variable': df_euss_am_mp10_home_inmap_variable
    }
}

# Process each RCM model
for rcm_model in RCM_MODELS:
    print(f"Exporting SUMMARY RESULTS for {rcm_model.upper()} model...")
    
    # Process each discount method
    for discount_rate_col in PRIVATE_DISCOUNT_RATE_COLS:
        print(f"  Private Discounting Method: {discount_rate_col}")
        
        # Get the specific DataFrame for this RCM × discount rate combination
        df_results_export = DATAFRAMES_MP10_RCM_DISCOUNT_RATE_RESULTS[rcm_model][discount_rate_col]
        
        # Export summary results with explicit sensitivity parameters
        export_model_run_output(
            df_results_export=df_results_export,
            results_category='summary',  # Simplified - no parsing needed!
            menu_mp=menu_mp,
            output_folder_path=output_folder_path,
            location_id=location_id,
            results_export_formatted_date=model_run_date_time,
            rcm_model=rcm_model,  # Explicit sensitivity parameter
            discount_rate_col=discount_rate_col  # Explicit sensitivity parameter
        )
# Out:
# Exporting SUMMARY RESULTS for AP2 model...
#   Private Discounting Method: private_discount_rate_fixed_low
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_fixed_low
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_ap2_private_discount_rate_fixed_low\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_base
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_fixed_base
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_ap2_private_discount_rate_fixed_base\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_high
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_fixed_high
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_ap2_private_discount_rate_fixed_high\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_variable
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: private_discount_rate_variable
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_ap2_private_discount_rate_variable\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for EASIUR model...
#   Private Discounting Method: private_discount_rate_fixed_low
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_fixed_low
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_easiur_private_discount_rate_fixed_low\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_base
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_fixed_base
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_easiur_private_discount_rate_fixed_base\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_high
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_fixed_high
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_easiur_private_discount_rate_fixed_high\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_variable
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: private_discount_rate_variable
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_easiur_private_discount_rate_variable\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for INMAP model...
#   Private Discounting Method: private_discount_rate_fixed_low
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_fixed_low
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_inmap_private_discount_rate_fixed_low\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_base
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_fixed_base
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_inmap_private_discount_rate_fixed_base\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_fixed_high
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_fixed_high
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_inmap_private_discount_rate_fixed_high\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
#
#   Private Discounting Method: private_discount_rate_variable
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: private_discount_rate_variable
# Saved to: mp10_results_National_2026-01-26_13-55.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_inmap_private_discount_rate_variable\mp10_results_National_2026-01-26_13-55.csv
# ---------------------------------------------------------------------------------------------------------
