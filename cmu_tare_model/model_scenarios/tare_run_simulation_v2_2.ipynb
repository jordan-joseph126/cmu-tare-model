# %%
"""
This file runs all of the code responsible for generating the output CSVs but does not visualize the data.
Data visualization is done in the main program.
"""
# Out:
# '\nThis file runs all of the code responsible for generating the output CSVs but does not visualize the data.\nData visualization is done in the main program.\n'

# %%
import os
import pandas as pd

# Format the name of the exported results file using the location ID
from datetime import datetime
result_export_time = datetime.now()
model_run_date_time = result_export_time.strftime("%Y-%m-%d_%H-%M")

from config import PROJECT_ROOT
from cmu_tare_model.constants import RCM_MODELS
from cmu_tare_model.utils.discounting import PRIVATE_DISCOUNT_RATE_COLS, PRIVATE_DISCOUNT_RATE_SHORT_KEYS
from cmu_tare_model.utils.export_model_run_results import export_model_run_output

print(f"""
The results will be exported using the export_model_run_output function.
Documentation for this function:
{export_model_run_output.__doc__}

""")
# Out:
# Project root directory: c:\users\jorda\desktop\projects\cmu-tare-model
#
# The results will be exported using the export_model_run_output function.
# Documentation for this function:
# Export model run results to CSV files with sensitivity tracking.
#
#     This function exports DataFrame results to CSV files organized by result type.
#     For retrofit summary results, it uses short discount rate keys for directory naming
#     while maintaining backward compatibility with full column names in exported DataFrames.
#
#     Directory Structure:
#         baseline_summary/summary_baseline/
#             - baseline_results_{location_id}_{date}.csv
#
#         retrofit_mp{menu_mp}_results/summary_mp{menu_mp}_{rcm_model}_{discount_rate_short}/
#             - mp{menu_mp}_results_{location_id}_{date}.csv
#             - Directory uses short key (e.g., 'fixed_base')
#             - DataFrame columns use full names (e.g., 'private_discount_rate_fixed_base')
#
#     Args:
#         df_results_export: DataFrame containing the results to export.
#         results_category: Category of results being exported. Valid options:
#             - 'summary_baseline': Baseline summary results
#             - 'summary': Retrofit summary results (requires rcm_model and discount_rate_short)
#             - 'damages_climate_IRA', 'damages_climate_noIRA': Climate damages
#             - 'damages_health_IRA', 'damages_health_noIRA': Health damages
#             - 'fuel_costs_IRA', 'fuel_costs_noIRA': Fuel costs
#         menu_mp: Measure package identifier (0 for baseline, 8/9/10 for retrofits).
#         output_folder_path: Base directory for all exports.
#         location_id: Location identifier for the filename (e.g., 'NYC', 'LA').
#         results_export_formatted_date: Date string for the filename (e.g., '2024_01_15').
#         rcm_model: RCM model used for health damage calculations (e.g., 'ap2', 'easiur',
#             'inmap'). Required when results_category='summary' and menu_mp != 0.
#         discount_rate_short: Short key for discount rate method (e.g., 'fixed_base', 'variable').
#             'private_discount_rate_variable'). Required when results_category='summary' and menu_mp != 0.
#
#     Raises:
#         ValueError: If any required parameter is missing, results_category is invalid,
#             or sensitivity parameters are missing when required.
#         OSError: If there is an error creating directories or writing the file.

# %% [markdown]
# # EUSS Baseline Measure Package (MP0)

# %%
# ===================================================================================================================================================================================
# Measure Package 0: Baseline
# ===================================================================================================================================================================================
# BASELINE Pre-IRA Scenario:
menu_mp = 0
input_mp = 'baseline'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_baseline_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")

print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print(f"Model Run Complete for Baseline (MP{menu_mp})")
# Out:
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_baseline_v2_2.ipynb
#
# =========================================================================================================
# Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
# Let's start by reading the data from the NREL EUSS Database.
#
# Make sure that the zipped folders stay organized as they are once unzipped.
# If changes are made to the file path, then the program will not run properly.
# ==========================================================================================================
#
# Project root directory: c:\users\jorda\desktop\projects\cmu-tare-model
# Result outputs will be exported here: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results
#
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# Load data from the NREL EUSS Database for the baseline scenario and apply various filters.
#
# DATA: NREL EUSS Database
# HOUSING FILTERS: Occupied units and Single Family Homes
# GEOGRAPHIC FILTERS: National, State, or City
#
# Additional details data can be found in the official End-Use Load Profiles/Savings Shapes documentation.
# Our methodology is detailed in the process_euss_data.py file and its associated imports.
#
#
# Retrieved data for filename: baseline_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\baseline_metadata_and_annual_results.csv
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 259)
# You chose to filter for: PA
# Location ID is: PA
#
# To accurately characterize load profile, it is recommended to select subsets of data with >= 1000 models (~240,000 representative dwelling units).
#
# The following cities (number of models also shown) are available for this state:
#
# in.city
# Not in a census Place      7035
# In another census Place    5851
# PA, Philadelphia           1631
# PA, Pittsburgh              329
# PA, Erie                    105
# PA, Allentown               104
# PA, Reading                  92
# PA, Bethlehem                85
# PA, Scranton                 80
# PA, Harrisburg               63
# PA, Lancaster                58
# PA, Levittown                58
# PA, Altoona                  56
# PA, York                     56
# PA, Wilkes-Barre             48
# Name: count, dtype: int64
# You chose to analyze all of state: PA
# Location ID is: PA
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline
#
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            0  242.131013           True   2152.0
# 122            0  242.131013           True   2176.0
# 150            0  242.131013           True   1690.0
# 153            0  242.131013           True   2176.0
# 162            0  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         0  242.131013           True   1202.0
# 549915         0  242.131013           True   2176.0
# 549937         0  242.131013           True    885.0
# 549963         0  242.131013           True   1690.0
# 549989         0  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions.natural_gas.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            5540.594966
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                             890.321536
# ...                                                    ...
# 549882                                         6675.629132
# 549915                                            0.000000
# 549937                                         7002.945922
# 549963                                         8277.210267
# 549989                                            0.000000
#
#         out.emissions.propane.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions.electricity.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4179.118870
# 122                                            3794.589113
# 150                                           11378.222173
# 153                                            4612.318634
# 162                                            4330.249044
# ...                                                    ...
# 549882                                         2916.093184
# 549915                                        16728.421288
# 549937                                         3823.559604
# 549963                                         3992.118611
# 549989                                         2136.040859
#
#         out.emissions.fuel_oil.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                           13038.928166
# 150                                               0.000000
# 153                                           14589.636195
# 162                                           15002.759507
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                         6042.544365
#
#         out.emissions.natural_gas.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            5540.594966
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                             890.321536
# ...                                                    ...
# 549882                                         6675.629132
# 549915                                            0.000000
# 549937                                         7002.945922
# 549963                                         8277.210267
# 549989                                            0.000000
#
#         out.emissions.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            7380.371515
# 122                                           14675.825549
# 150                                            4530.910597
# 153                                           16564.727059
# 162                                           17837.666007
# ...                                                    ...
# 549882                                         7916.182492
# 549915                                         6870.847124
# 549937                                         8577.560537
# 549963                                         9951.214681
# 549989                                         7176.439561
#
#         out.emissions.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            9495.197860
# 122                                           16590.276103
# 150                                           10702.844907
# 153                                           18949.747039
# 162                                           20060.715408
# ...                                                    ...
# 549882                                         9422.157695
# 549915                                        15814.400458
# 549937                                        10516.078249
# 549963                                        11921.778240
# 549989                                         8281.270372
#
#         out.emissions.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            9035.427108
# 122                                           16204.985672
# 150                                            9290.264827
# 153                                           18437.677994
# 162                                           19596.115712
# ...                                                    ...
# 549882                                         9095.470037
# 549915                                        13772.445542
# 549937                                        10222.759114
# 549963                                        11608.667963
# 549989                                         8040.946248
#
#         out.emissions.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg
# bldg_id
# 119                                            9719.713836
# 122                                           16833.517280
# 150                                           11378.222173
# 153                                           19201.954829
# 162                                           20223.330087
# ...                                                    ...
# 549882                                         9591.722316
# 549915                                        16728.421288
# 549937                                        10826.505527
# 549963                                        12269.328878
# 549989                                         8402.441677
#
# [15651 rows x 259 columns]
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# In addition to the housing type and occupancy filters, the data has been filtered for fuel and technology
# Please see the energy_consumption_and_metadata folder for more details on data processing.
#
# We employ the df_enduse_refactored function to process the data and create a new dataframe, which is part of the 5-step data validation process:
# 1. Mask Initialization with initialize_validation_tracking()
# 2. Series Initialization with create_retrofit_only_series()
# 3. Valid-Only Calculation for qualifying homes
# 4. Valid-Only Updates using list-based collection
# 5. Final Masking with apply_final_masking()
#
# ----------------------------------------------------------------
#
# RESULTS OUTPUT (BASELINE):
#
# Processing column: in.clothes_dryer
# Initial data types: object
# Data types after processing: object
# Processing column: in.cooking_range
# Initial data types: object
# Data types after processing: object
# Calculated total heating consumption
# Calculated total waterHeating consumption
# Calculated total clothesDrying consumption
# Calculated total cooking consumption
#
# Applying data validation (baseline only):
#   base_electricity_heating_consumption: Masked 3385 values
#   base_naturalGas_heating_consumption: Masked 3385 values
#   base_fuelOil_heating_consumption: Masked 3385 values
#   base_propane_heating_consumption: Masked 3385 values
#   baseline_heating_consumption: Masked 2587 values
#   base_electricity_waterHeating_consumption: Masked 652 values
#   base_naturalGas_waterHeating_consumption: Masked 652 values
#   base_fuelOil_waterHeating_consumption: Masked 652 values
#   base_propane_waterHeating_consumption: Masked 652 values
#   baseline_waterHeating_consumption: Masked 628 values
#   base_electricity_clothesDrying_consumption: Masked 908 values
#   base_naturalGas_clothesDrying_consumption: Masked 908 values
#   base_propane_clothesDrying_consumption: Masked 908 values
#   base_naturalGas_cooking_consumption: Masked 7784 values
#   base_propane_cooking_consumption: Masked 7784 values
# Retrieved data for filename: bls_cpiu_2005-2023.xlsx
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\inflation_data\bls_cpiu_2005-2023.xlsx
#     year  cpiu_annual
# 0   2005      195.300
# 1   2006      201.600
# 2   2007      207.342
# 3   2008      215.303
# 4   2009      214.537
# 5   2010      218.056
# 6   2011      224.939
# 7   2012      229.594
# 8   2013      232.957
# 9   2014      236.736
# 10  2015      237.017
# 11  2016      240.007
# 12  2017      245.120
# 13  2018      251.107
# 14  2019      255.657
# 15  2020      258.811
# 16  2021      270.970
# 17  2022      292.655
# 18  2023      304.702
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# ====================================================================================================================================================================
# PUBLIC IMPACTS (BASELINE): DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
# Detailed documentation of the methods used to calculate the climate and public health impacts can be
# found in the public_impacts folder of the cmu-tare-model package. All monetary values are in 2023
# inflation-adjusted dollars ($USD2023).
# - data_processing sub-folder: contains the data processing scripts used for lookup dictionaries
# - calculations sub-folder: contains the calculations for emissions from fossul fuel appliances
# - Main folder contains the scripts for calculating lifetime climate and public health impacts as
#   as well as climate NPV, health NPV, and combined public NPV.
#
# Step 1: Calculate the baseline marginal damages for climate and health-related emissions
# Step 2: Calculate the post-retrofit marginal damages for climate and health-related emissions
# Step 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
#
# ----------------------------------------------------------------------------------------------
# Step 1: Calculate the baseline marginal damages for climate and health-related emissions
# ----------------------------------------------------------------------------------------------
#
#
#
# ==================== PUBLIC IMPACTS (BASELINE): DAMAGES FROM CLIMATE-RELATED EMISSIONS ====================
#
#
#
# ==================== PUBLIC IMPACTS (BASELINE): DAMAGES FROM HEALTH-RELATED EMISSIONS ====================
#
#
#
# =====================================================================================================================================================================
# LIFETIME FUEL COSTS: Baseline Scenario
# =====================================================================================================================================================================
# STEPS
# - Create a mapping dictionary for fuel types
# - Create new merge columns to ensure a proper match.
# - Merge df_copy with df_fuel_prices to get fuel prices for electricity, natural gas, propane, and fuel oil
# - Calculate the per kWh fuel costs for each fuel type and region
# - Calculate the baseline fuel cost
#
# ----------------------------------------------------------------------------------------------------------------------
# Step 1: Calculate annual operating (fuel) costs
# ----------------------------------------------------------------------------------------------------------------------
#
# ====================================================================================================================================================================
# FUEL COSTS RESULTS (BASELINE):
#
#
# The code took 0 minutes and 57 seconds to execute.
# Model Run Complete for Baseline (MP0)

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_baseline_damages_climate,
    results_category='damages_climate_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

export_model_run_output(
    df_results_export=df_baseline_damages_health,
    results_category='damages_health_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_baseline_fuel_costs,
    results_category='fuel_costs_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )

# ===== SUMMARY RESULTS =====
export_model_run_output(
    df_results_export=df_euss_am_baseline_home,
    results_category='summary_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
    )
# Out:
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_baseline
# Saved to: mp0_damages_climate_baseline_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_baseline\mp0_damages_climate_baseline_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_baseline
# Saved to: mp0_damages_health_baseline_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_baseline\mp0_damages_health_baseline_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_baseline
# Saved to: mp0_fuel_costs_baseline_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_baseline\mp0_fuel_costs_baseline_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# BASELINE SUMMARY RESULTS:
# Saved to: baseline_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\baseline_summary\summary_baseline\baseline_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# -------------------------------------------------------------------------------------------------------
# # EUSS Post-Retrofit Measure Packages: MP8, MP8, MP10
# -------------------------------------------------------------------------------------------------------
# ## No IRA Scenario:
# - AEO2023 No Inflation Reduction Act
# - Cambium 2021 MidCase
# ## IRA-Reference Scenario:
# - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
# - Cambium 2022 and 2023 MidCase
# -------------------------------------------------------------------------------------------------------

# %%
print("""
-------------------------------------------------------------------------------------------------------
EUSS Post-Retrofit Measure Packages: MP8, MP9, MP10
-------------------------------------------------------------------------------------------------------
- MP8: Whole Home Electrification (High Efficiency)
- MP9: Whole-Home Electrification + Basic Enclosure Upgrade
- MP10: Whole-Home Electrification + Enhanced Enclosure Upgrade

-------------------------------------------------------------------------------------------------------
TARE MODEL SCENARIOS
-------------------------------------------------------------------------------------------------------
- Pre-IRA Scenario:
    - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
    - AEO2023 No Inflation Reduction Act
    - Cambium 2021 MidCase
      
- IRA-Reference Scenario:
    - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
    - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
    - Cambium 2022 and 2023 MidCase
""")
# Out:
# -------------------------------------------------------------------------------------------------------
# EUSS Post-Retrofit Measure Packages: MP8, MP9, MP10
# -------------------------------------------------------------------------------------------------------
# - MP8: Whole Home Electrification (High Efficiency)
# - MP9: Whole-Home Electrification + Basic Enclosure Upgrade
# - MP10: Whole-Home Electrification + Enhanced Enclosure Upgrade
#
# -------------------------------------------------------------------------------------------------------
# TARE MODEL SCENARIOS
# -------------------------------------------------------------------------------------------------------
# - Pre-IRA Scenario:
#     - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
#     - AEO2023 No Inflation Reduction Act
#     - Cambium 2021 MidCase
#
# - IRA-Reference Scenario:
#     - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
#     - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
#     - Cambium 2022 and 2023 MidCase

# %% [markdown]
# ## MP8: Whole Home Electrification (High Efficiency)

# %%
# Measure Package 8
menu_mp = 8
input_mp = 'upgrade08'

# Pre-set measure package for batch mode
input_measure_package = '8'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the unified scenarios file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_scenarios_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPython magic command to run notebook and import variables into current session
get_ipython().run_line_magic('run', f'-i {file_path}')

print(f"Model Run Complete for EUSS Measure Package: MP{menu_mp}")
# Out:
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_scenarios_v2_2.ipynb
#
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (MP8-10).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 346)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            7  242.131013           True   2152.0
# 122            7  242.131013           True   2176.0
# 150            7  242.131013          False   1690.0
# 153            7  242.131013           True   2176.0
# 162            7  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         7  242.131013           True   1202.0
# 549915         7  242.131013          False   2176.0
# 549937         7  242.131013           True    885.0
# 549963         7  242.131013           True   1690.0
# 549989         7  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4367.397352
# 122                                           10479.768179
# 150                                               0.000000
# 153                                           11048.097647
# 162                                           12947.903971
# ...                                                    ...
# 549882                                         5212.871757
# 549915                                            0.000000
# 549937                                         4636.242910
# 549963                                         4903.857419
# 549989                                         4686.866540
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2552.828291
# 122                                            6954.371623
# 150                                               0.000000
# 153                                            6200.439415
# 162                                            8666.012863
# ...                                                    ...
# 549882                                         3310.560695
# 549915                                            0.000000
# 549937                                         1673.632015
# 549963                                          609.743358
# 549989                                         2436.617472
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            2985.641141
# 122                                            7797.415226
# 150                                               0.000000
# 153                                            7363.122758
# 162                                            9676.629818
# ...                                                    ...
# 549882                                         3739.637305
# 549915                                            0.000000
# 549937                                         2257.364571
# 549963                                         1488.137683
# 549989                                         2959.741017
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2356.289439
# 122                                            6648.492515
# 150                                               0.000000
# 153                                            5775.168899
# 162                                            8324.377523
# ...                                                    ...
# 549882                                         3185.908976
# 549915                                            0.000000
# 549937                                         1154.203887
# 549963                                          -84.117798
# 549989                                         2177.081897
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 119      Electric, 100% Usage  Electric, 100% Usage
# 122                       NaN                   NaN
# 150                       NaN                   NaN
# 153                       NaN                   NaN
# 162                       NaN                   NaN
# ...                       ...                   ...
# 549882                    NaN                   NaN
# 549915                    NaN                   NaN
# 549937   Electric, 120% Usage  Electric, 120% Usage
# 549963                    NaN                   NaN
# 549989                    NaN  Electric, 100% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 122                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 150                                 NaN                                NaN
# 153                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 162                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# ...                                 ...                                ...
# 549882                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
# 549915                              NaN                                NaN
# 549937                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549963                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549989                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150                                       NaN
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                                    NaN
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 346 columns]
#  AVAILABLE EUSS MEASURE PACKAGES FOR TARE MODEL RUN:
#       3: ASHP, Min Efficiency
#       4: ASHP, High Efficiency
#       8: Whole Home Electrification (All Enduses)
#       9: Whole Home Electrification (MP8 + Basic Enclosure Upgrade (MP1))
#       10: Whole Home Electrification (MP8 + Enhanced Enclosure Upgrade (MP2))
#
# [BATCH MODE] Using pre-set Measure Package 8.
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Measure Package 8
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade08_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade08_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 347)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 347)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 347)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 347)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            8  242.131013           True   2152.0
# 122            8  242.131013           True   2176.0
# 150            8  242.131013           True   1690.0
# 153            8  242.131013           True   2176.0
# 162            8  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         8  242.131013           True   1202.0
# 549915         8  242.131013           True   2176.0
# 549937         8  242.131013           True    885.0
# 549963         8  242.131013           True   1690.0
# 549989         8  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            5063.088752
# 122                                           12066.712342
# 150                                            3103.153770
# 153                                           12691.688692
# 162                                           14912.014271
# ...                                                    ...
# 549882                                         5882.269769
# 549915                                         3949.186094
# 549937                                         5643.594000
# 549963                                         6479.951652
# 549989                                         5231.517125
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4214.733128
# 122                                           10590.254662
# 150                                            7434.178003
# 153                                           10026.235230
# 162                                           13274.793477
# ...                                                    ...
# 549882                                         4814.108725
# 549915                                         9153.072186
# 549937                                         3941.494074
# 549963                                         4162.716516
# 549989                                         3713.809302
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            4421.232869
# 122                                           10962.614536
# 150                                            6435.450158
# 153                                           10675.202534
# 162                                           13682.148002
# ...                                                    ...
# 549882                                         5058.857189
# 549915                                         7958.419199
# 549937                                         4289.405772
# 549963                                         4656.122049
# 549989                                         4068.275863
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4103.394799
# 122                                           10472.994231
# 150                                            7914.527787
# 153                                            9808.721813
# 162                                           13130.752498
# ...                                                    ...
# 549882                                         4740.981471
# 549915                                         9734.504122
# 549937                                         3628.586099
# 549963                                         3803.239573
# 549989                                         3542.402188
#
#                                      upgrade.clothes_dryer  \
# bldg_id
# 119      Electric, Premium, Heat Pump, Ventless, 100% U...
# 122      Electric, Premium, Heat Pump, Ventless, 100% U...
# 150      Electric, Premium, Heat Pump, Ventless, 80% Usage
# 153                                                    NaN
# 162      Electric, Premium, Heat Pump, Ventless, 80% Usage
# ...                                                    ...
# 549882   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549915   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549937   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549963   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549989   Electric, Premium, Heat Pump, Ventless, 100% U...
#
#                    upgrade.cooking_range upgrade.hvac_cooling_efficiency  \
# bldg_id
# 119      Electric, Induction, 100% Usage                       Heat Pump
# 122      Electric, Induction, 100% Usage                       Heat Pump
# 150       Electric, Induction, 80% Usage                       Heat Pump
# 153      Electric, Induction, 120% Usage                       Heat Pump
# 162       Electric, Induction, 80% Usage                       Heat Pump
# ...                                  ...                             ...
# 549882   Electric, Induction, 120% Usage                       Heat Pump
# 549915   Electric, Induction, 100% Usage                       Heat Pump
# 549937   Electric, Induction, 120% Usage                       Heat Pump
# 549963   Electric, Induction, 100% Usage                       Heat Pump
# 549989   Electric, Induction, 100% Usage                       Heat Pump
#
#             upgrade.hvac_heating_efficiency upgrade.hvac_heating_type  \
# bldg_id
# 119                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 122                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 150      MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 153                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 162                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# ...                                     ...                       ...
# 549882   MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 549915               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549937               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549963               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549989               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150      Electric Heat Pump, 66 gal, 3.35 UEF
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915   Electric Heat Pump, 80 gal, 3.45 UEF
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 347 columns]
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 8 (MP8)
# ====================================================================================================================================================================
# You'll notice that the number of rows differs from df_euss_am_mp7 and df_euss_am_mpX.
#       - df_euss_am_baseline_home has fewer rows (representative dwelling units) because a tech filter was applied.
#       - df_euss_am_mpX_home will have the same number of rows as df_euss_am_baseline_home after df_enduse_compare function is run.
#       - df_enduse_compare function performs an inner merge on the two dataframes, keeping only the rows that are present in both dataframes.
# ====================================================================================================================================================================
# df_euss_am_mpX_home will be created by running the df_enduse_compare function (contains post-retrofit consumption data for the entire home in 2024).
# process_euss_data.py file contains the function definition.
#
#
#
# Applying combined validation (data quality + retrofit status):
#   mp8_heating_consumption: Masked 3385 values
#   mp8_waterHeating_consumption: Masked 652 values
#   mp8_clothesDrying_consumption: Masked 908 values
#   mp8_cooking_consumption: Masked 7784 values
#
# ====================================================================================================================================================================
# PUBLIC IMPACTS: DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
#
#
#
#  Creating dataframe to store marginal damages calculations ...
#
# ====================================================================================================================================================================
# df_euss_am_baseline_home: DataFrame containing the baseline scenario data
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#         baseline_cooking_lifetime_damages_health_inmap_h6c fuel_type_heating  \
# bldg_id
# 119                                                 380.50        naturalGas
# 122                                                    NaN           fuelOil
# 150                                                    NaN       electricity
# 153                                                    NaN           fuelOil
# 162                                                    NaN           fuelOil
# ...                                                    ...               ...
# 549882                                                 NaN        naturalGas
# 549915                                                 NaN       electricity
# 549937                                              129.68        naturalGas
# 549963                                                 NaN        naturalGas
# 549989                                              146.99           fuelOil
#
#         fuel_type_waterHeating fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 119                 naturalGas              naturalGas         naturalGas
# 122                    fuelOil             electricity        electricity
# 150                electricity             electricity        electricity
# 153                    fuelOil                     NaN        electricity
# 162                 naturalGas             electricity        electricity
# ...                        ...                     ...                ...
# 549882              naturalGas             electricity        electricity
# 549915             electricity             electricity        electricity
# 549937              naturalGas              naturalGas         naturalGas
# 549963              naturalGas             electricity        electricity
# 549989                 fuelOil             electricity            propane
#
#          baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                  9692.04
# 122                                 56634.48
# 150                                 48835.85
# 153                                 52691.10
# 162                                 69001.23
# ...                                      ...
# 549882                                   NaN
# 549915                              52898.91
# 549937                               8456.00
# 549963                              17473.34
# 549989                              22285.90
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                        351.02
# 122                                        619.28
# 150                                        718.64
# 153                                           NaN
# 162                                       2222.41
# ...                                           ...
# 549882                                     997.02
# 549915                                    1736.07
# 549937                                     982.27
# 549963                                     898.31
# 549989                                     898.31
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 126 columns]
#
# df_baseline_damages_health: DataFrame containing the baseline scenario data with health damages
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          baseline_2038_cooking_damages_so2_inmap_h6c  \
# bldg_id
# 119                                             0.92
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          0.63
# 549963                                           NaN
# 549989                                          0.82
#
#          baseline_2038_cooking_damages_nox_inmap_h6c  \
# bldg_id
# 119                                            17.35
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          7.15
# 549963                                           NaN
# 549989                                          8.32
#
#          baseline_2038_cooking_damages_pm25_inmap_h6c  \
# bldg_id
# 119                                              8.30
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                           0.91
# 549963                                            NaN
# 549989                                           0.68
#
#          baseline_2038_cooking_damages_health_inmap_h6c  \
# bldg_id
# 119                                               26.56
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                             8.69
# 549963                                              NaN
# 549989                                             9.83
#
#          baseline_cooking_lifetime_damages_health_ap2_acs  \
# bldg_id
# 119                                                 37.49
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              20.82
# 549963                                                NaN
# 549989                                              23.53
#
#          baseline_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 96.32
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              53.48
# 549963                                                NaN
# 549989                                              60.44
#
#          baseline_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 130.47
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               73.35
# 549963                                                 NaN
# 549989                                               59.17
#
#          baseline_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 335.21
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              188.47
# 549963                                                 NaN
# 549989                                              152.01
#
#          baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#          baseline_cooking_lifetime_damages_health_inmap_h6c
# bldg_id
# 119                                                 380.50
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...
# 150                             946.84                           840.00
# 153                               0.00                              NaN
# 162                               0.00                             0.00
# ...                                ...                              ...
# 549882                         1628.15                           711.25
# 549915                         1451.60                           821.53
# 549937                            0.00                             0.00
# 549963                         1670.10                           840.00
# 549989                            0.00                             0.00
#
#         mp8_cooking_rebate_amount
# bldg_id
# 119                         840.0
# 122                           NaN
# 150                           NaN
# 153                           NaN
# 162                           NaN
# ...                           ...
# 549882                        NaN
# 549915                        NaN
# 549937                        0.0
# 549963                        NaN
# 549989                        0.0
#
# [15651 rows x 414 columns]
#
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: PUBLIC IMPACT
#     - calculate_lifetime_public_impact.py file contains the definition for the calculate_public_npv function.
#     - Additional information on emissions/damage factor lookups as well as marginal damages calculation methods can be found in the public_impact folder.
# ====================================================================================================================================================================
#
# Completed Steps:
# 1. Calculate the baseline marginal damages for climate and health-related emissions                         [COMPLETED]
# 2. Calculate the post-retrofit marginal damages for climate and health-related emissions                    [COMPLETED]
#
# REMAINING STEP:
# Step 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: PRIVATE IMPACT
#     - calculate_lifetime_private_impact.py file contains the definition for the calculate_private_npv function.
#     - Additional information on fuel price lookups as well as capital costs calculation methods can be found in the private_impact folder.
# ====================================================================================================================================================================
#
# Completed Steps:
# 1. Calculate annual operating (fuel) costs                                                                  [COMPLETED]
# 2. Calculate equipment capital costs (For space heating, include ductwork and weatherization (MP9-10))      [COMPLETED]
# 3. Calculate replacement cost (replacing existing piece of eqipment with similar technology)                [COMPLETED]
#
# REMAINING STEP:
# Step 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
# ----------------------------------------------------------------------------------------------------------------------
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: ADOPTION POTENTIAL
#     determine_adoption_potential_sensitivity.py file contains the definitions for:
#         - adoption_decision function (combined climate + health analysis)
#         - calculate_climate_only_adoption_robust function (climate-only analysis)
#         - calculate_health_only_adoption_robust function (health-only analysis)
# ====================================================================================================================================================================
#
# Determine adoption potential based on private NPV and public NPV and decision logic
# Tier 1 (Feasible):                      --> Private NPV (total capital cost) >= 0
# Tier 2 (Feasible vs. Alternative):      --> Private NPV (net capital cost) >= 0
# Tier 3 (Subsidy-Dependent Feasibility): --> Private NPV + Public NPV >= 0
# Tier 4 (Averse):                        --> Private NPV + Public NPV < 0
#
# ----------------------------------------------------------------------------------------------------------------------
#
#
#
# ====================================================================================================================================================================
# Scenario No Inflation Reduction Act:
# Advanced Retrofit: Measure Package 8
# Fuel Costs: AEO2023 No Inflation Reduction Act
# Electricity Grid: Cambium 2021 MidCase Scenario
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PUBLIC IMPACT
# ====================================================================================================================================================================
# - Private discount rate IS used for storing results, but NOT used for public impact calculations.
#
# Calculating Public NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PRIVATE IMPACT
# ====================================================================================================================================================================
#
# Calculating Private NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): ADOPTION POTENTIAL
# ====================================================================================================
#
# Determining Adoption Potential for different RCM models and discount rate methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario IRA-Reference:
# EUSS Measure Package 8
# Fuel Costs: AEO2023 Reference Case
# Electricity Grid: Cambium 2023 MidCase Scenario
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PUBLIC IMPACT
# ====================================================================================================================================================================
# - Private discount rate IS used for storing results, but NOT used for public impact calculations.
#
# Calculating Public NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PRIVATE IMPACT
# ====================================================================================================================================================================
#
# Calculating Private NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): ADOPTION POTENTIAL
# ====================================================================================================
#
# Determining Adoption Potential for different RCM models and discount rate methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# The code took 5 minutes and 28 seconds to execute.
# Model Run Complete for EUSS Measure Package: MP8

# %%
# PRESERVE RESULTS AND PREVENT OVERWRITING OF PREVIOUS MODEL RUN DATA
print(f"""
Preserving MP{menu_mp} results by copying dataframe variables and re-assigning to MP-specific names.
This allows the scenarios file to be re-run for MP{menu_mp} without overwriting previous model run data""")

# Supplemental DataFrames
df_mp8_noIRA_damages_climate = df_mpX_noIRA_damages_climate.copy()
df_mp8_IRA_damages_climate = df_mpX_IRA_damages_climate.copy()
df_mp8_noIRA_damages_health = df_mpX_noIRA_damages_health.copy()
df_mp8_IRA_damages_health = df_mpX_IRA_damages_health.copy()
df_mp8_noIRA_fuel_costs = df_mpX_noIRA_fuel_costs.copy()
df_mp8_IRA_fuel_costs = df_mpX_IRA_fuel_costs.copy()

# Summary results dictionary (nested: discount rate -> RCM model -> DataFrame)
# Structure matches new organization: [discount_rate_short][rcm_model]
DATAFRAMES_MP8_RCM_DISCOUNT_RATE_RESULTS = {
    discount_rate: {
        rcm_model: df.copy()
        for rcm_model, df in rcm_dict.items()
    }
    for discount_rate, rcm_dict in DATAFRAMES_MPX_RCM_DISCOUNT_RATE.items()
}

# Clear the batch mode trigger
input_measure_package = None

print(f"MP{menu_mp} results preserved to MP-specific variable names.")
# Out:
# Preserving MP8 results by copying dataframe variables and re-assigning to MP-specific names.
# This allows the scenarios file to be re-run for MP8 without overwriting previous model run data
# MP8 results preserved to MP-specific variable names.

# %%
# =========================================================================================================
# EXPORT RESULTS TO CSV - SUPPLEMENTAL DATA
# =========================================================================================================
print(f"Exporting MP{menu_mp} Supplemental Data...")

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp8_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp8_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp8_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# =========================================================================================================
# EXPORT RESULTS TO CSV - SUMMARY RESULTS FOR RCM MODELS AND DISCOUNT RATES SENSITIVITY ANALYSIS
# =========================================================================================================

# Process each discount rate, then each RCM model (matches dictionary structure)
for discount_rate_short in PRIVATE_DISCOUNT_RATE_SHORT_KEYS:
    print(f"Exporting SUMMARY RESULTS for discount rate: {discount_rate_short}")
    
    # Process each RCM model for this discount rate
    for rcm_model in RCM_MODELS:
        print(f"  RCM Model: {rcm_model.upper()}")
        
        # Get the specific DataFrame for this discount rate × RCM combination
        df_results_export = DATAFRAMES_MP8_RCM_DISCOUNT_RATE_RESULTS[discount_rate_short][rcm_model]
        
        # Export summary results with explicit sensitivity parameters (using short keys)
        export_model_run_output(
            df_results_export=df_results_export,
            results_category='summary',
            menu_mp=menu_mp,
            output_folder_path=output_folder_path,
            location_id=location_id,
            results_export_formatted_date=model_run_date_time,
            rcm_model=rcm_model,
            discount_rate_short=discount_rate_short
        )
# Out:
# Exporting MP8 Supplemental Data...
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_noIRA
# Saved to: mp8_damages_climate_noIRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_noIRA\mp8_damages_climate_noIRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_IRA
# Saved to: mp8_damages_climate_IRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_IRA\mp8_damages_climate_IRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_noIRA
# Saved to: mp8_damages_health_noIRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_noIRA\mp8_damages_health_noIRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_IRA
# Saved to: mp8_damages_health_IRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_IRA\mp8_damages_health_IRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_noIRA
# Saved to: mp8_fuel_costs_noIRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_noIRA\mp8_fuel_costs_noIRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_IRA
# Saved to: mp8_fuel_costs_IRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_IRA\mp8_fuel_costs_IRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: fixed_low
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_low
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_fixed_low\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_low
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_fixed_low\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_low
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_fixed_low\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: fixed_base
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_base
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_fixed_base\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_base
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_fixed_base\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_base
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_fixed_base\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: fixed_high
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_high
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_fixed_high\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_high
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_fixed_high\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_high
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_fixed_high\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: variable
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: variable
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_ap2_variable\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: variable
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_easiur_variable\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: variable
# Saved to: mp8_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp8_results\summary_mp8_inmap_variable\mp8_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## MP9: Whole Home Electrification + Basic Enclosure Upgrade

# %%
# Measure Package 9
menu_mp = 9
input_mp = 'upgrade09'

# Pre-set measure package for batch mode
input_measure_package = '9'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the unified scenarios file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_scenarios_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPython magic command to run notebook and import variables into current session
get_ipython().run_line_magic('run', f'-i {file_path}')

print(f"Model Run Complete for EUSS Measure Package: MP{menu_mp}")
# Out:
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_scenarios_v2_2.ipynb
#
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (MP8-10).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 346)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            7  242.131013           True   2152.0
# 122            7  242.131013           True   2176.0
# 150            7  242.131013          False   1690.0
# 153            7  242.131013           True   2176.0
# 162            7  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         7  242.131013           True   1202.0
# 549915         7  242.131013          False   2176.0
# 549937         7  242.131013           True    885.0
# 549963         7  242.131013           True   1690.0
# 549989         7  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4367.397352
# 122                                           10479.768179
# 150                                               0.000000
# 153                                           11048.097647
# 162                                           12947.903971
# ...                                                    ...
# 549882                                         5212.871757
# 549915                                            0.000000
# 549937                                         4636.242910
# 549963                                         4903.857419
# 549989                                         4686.866540
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2552.828291
# 122                                            6954.371623
# 150                                               0.000000
# 153                                            6200.439415
# 162                                            8666.012863
# ...                                                    ...
# 549882                                         3310.560695
# 549915                                            0.000000
# 549937                                         1673.632015
# 549963                                          609.743358
# 549989                                         2436.617472
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            2985.641141
# 122                                            7797.415226
# 150                                               0.000000
# 153                                            7363.122758
# 162                                            9676.629818
# ...                                                    ...
# 549882                                         3739.637305
# 549915                                            0.000000
# 549937                                         2257.364571
# 549963                                         1488.137683
# 549989                                         2959.741017
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2356.289439
# 122                                            6648.492515
# 150                                               0.000000
# 153                                            5775.168899
# 162                                            8324.377523
# ...                                                    ...
# 549882                                         3185.908976
# 549915                                            0.000000
# 549937                                         1154.203887
# 549963                                          -84.117798
# 549989                                         2177.081897
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 119      Electric, 100% Usage  Electric, 100% Usage
# 122                       NaN                   NaN
# 150                       NaN                   NaN
# 153                       NaN                   NaN
# 162                       NaN                   NaN
# ...                       ...                   ...
# 549882                    NaN                   NaN
# 549915                    NaN                   NaN
# 549937   Electric, 120% Usage  Electric, 120% Usage
# 549963                    NaN                   NaN
# 549989                    NaN  Electric, 100% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 122                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 150                                 NaN                                NaN
# 153                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 162                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# ...                                 ...                                ...
# 549882                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
# 549915                              NaN                                NaN
# 549937                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549963                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549989                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150                                       NaN
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                                    NaN
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 346 columns]
#  AVAILABLE EUSS MEASURE PACKAGES FOR TARE MODEL RUN:
#       3: ASHP, Min Efficiency
#       4: ASHP, High Efficiency
#       8: Whole Home Electrification (All Enduses)
#       9: Whole Home Electrification (MP8 + Basic Enclosure Upgrade (MP1))
#       10: Whole Home Electrification (MP8 + Enhanced Enclosure Upgrade (MP2))
#
# [BATCH MODE] Using pre-set Measure Package 9.
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Measure Package 9
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade09_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade09_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 351)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 351)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 351)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 351)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            9  242.131013           True   2152.0
# 122            9  242.131013           True   2176.0
# 150            9  242.131013           True   1690.0
# 153            9  242.131013           True   2176.0
# 162            9  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         9  242.131013           True   1202.0
# 549915         9  242.131013           True   2176.0
# 549937         9  242.131013           True    885.0
# 549963         9  242.131013           True   1690.0
# 549989         9  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#                                      upgrade.clothes_dryer  \
# bldg_id
# 119      Electric, Premium, Heat Pump, Ventless, 100% U...
# 122      Electric, Premium, Heat Pump, Ventless, 100% U...
# 150      Electric, Premium, Heat Pump, Ventless, 80% Usage
# 153                                                    NaN
# 162      Electric, Premium, Heat Pump, Ventless, 80% Usage
# ...                                                    ...
# 549882   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549915   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549937   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549963   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549989   Electric, Premium, Heat Pump, Ventless, 100% U...
#
#                    upgrade.cooking_range     upgrade.ducts  \
# bldg_id
# 119      Electric, Induction, 100% Usage               NaN
# 122      Electric, Induction, 100% Usage  10% Leakage, R-8
# 150       Electric, Induction, 80% Usage               NaN
# 153      Electric, Induction, 120% Usage  10% Leakage, R-8
# 162       Electric, Induction, 80% Usage  10% Leakage, R-8
# ...                                  ...               ...
# 549882   Electric, Induction, 120% Usage               NaN
# 549915   Electric, Induction, 100% Usage  10% Leakage, R-8
# 549937   Electric, Induction, 120% Usage               NaN
# 549963   Electric, Induction, 100% Usage               NaN
# 549989   Electric, Induction, 100% Usage               NaN
#
#         upgrade.hvac_cooling_efficiency     upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 122                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 150                           Heat Pump  MSHP, SEER 29.3, 14 HSPF, Max Load
# 153                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 162                           Heat Pump              MSHP, SEER 24, 13 HSPF
# ...                                 ...                                 ...
# 549882                        Heat Pump  MSHP, SEER 29.3, 14 HSPF, Max Load
# 549915                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 549937                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 549963                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 549989                        Heat Pump              MSHP, SEER 24, 13 HSPF
#
#         upgrade.hvac_heating_type upgrade.infiltration_reduction  \
# bldg_id
# 119              Ducted Heat Pump                            NaN
# 122              Ducted Heat Pump                            30%
# 150                           NaN                            30%
# 153              Ducted Heat Pump                            30%
# 162              Ducted Heat Pump                            30%
# ...                           ...                            ...
# 549882                        NaN                            30%
# 549915           Ducted Heat Pump                            30%
# 549937           Ducted Heat Pump                            30%
# 549963           Ducted Heat Pump                            NaN
# 549989           Ducted Heat Pump                            NaN
#
#         upgrade.insulation_ceiling upgrade.insulation_wall  \
# bldg_id
# 119                           R-60                     NaN
# 122                           R-60         Wood Stud, R-13
# 150                           R-60         Wood Stud, R-13
# 153                           R-60                     NaN
# 162                           R-60         Wood Stud, R-13
# ...                            ...                     ...
# 549882                        R-60                     NaN
# 549915                        R-60                     NaN
# 549937                         NaN         Wood Stud, R-13
# 549963                         NaN                     NaN
# 549989                        R-60         Wood Stud, R-13
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150      Electric Heat Pump, 66 gal, 3.35 UEF
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915   Electric Heat Pump, 80 gal, 3.45 UEF
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 351 columns]
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 9 (MP9)
# ====================================================================================================================================================================
# You'll notice that the number of rows differs from df_euss_am_mp7 and df_euss_am_mpX.
#       - df_euss_am_baseline_home has fewer rows (representative dwelling units) because a tech filter was applied.
#       - df_euss_am_mpX_home will have the same number of rows as df_euss_am_baseline_home after df_enduse_compare function is run.
#       - df_enduse_compare function performs an inner merge on the two dataframes, keeping only the rows that are present in both dataframes.
# ====================================================================================================================================================================
# df_euss_am_mpX_home will be created by running the df_enduse_compare function (contains post-retrofit consumption data for the entire home in 2024).
# process_euss_data.py file contains the function definition.
#
#
#
# Applying combined validation (data quality + retrofit status):
#   mp9_heating_consumption: Masked 3385 values
#   mp9_waterHeating_consumption: Masked 652 values
#   mp9_clothesDrying_consumption: Masked 908 values
#   mp9_cooking_consumption: Masked 7784 values
#
# ====================================================================================================================================================================
# PUBLIC IMPACTS: DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
#
#
#
#  Creating dataframe to store marginal damages calculations ...
#
# ====================================================================================================================================================================
# df_euss_am_baseline_home: DataFrame containing the baseline scenario data
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#         baseline_cooking_lifetime_damages_health_inmap_h6c fuel_type_heating  \
# bldg_id
# 119                                                 380.50        naturalGas
# 122                                                    NaN           fuelOil
# 150                                                    NaN       electricity
# 153                                                    NaN           fuelOil
# 162                                                    NaN           fuelOil
# ...                                                    ...               ...
# 549882                                                 NaN        naturalGas
# 549915                                                 NaN       electricity
# 549937                                              129.68        naturalGas
# 549963                                                 NaN        naturalGas
# 549989                                              146.99           fuelOil
#
#         fuel_type_waterHeating fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 119                 naturalGas              naturalGas         naturalGas
# 122                    fuelOil             electricity        electricity
# 150                electricity             electricity        electricity
# 153                    fuelOil                     NaN        electricity
# 162                 naturalGas             electricity        electricity
# ...                        ...                     ...                ...
# 549882              naturalGas             electricity        electricity
# 549915             electricity             electricity        electricity
# 549937              naturalGas              naturalGas         naturalGas
# 549963              naturalGas             electricity        electricity
# 549989                 fuelOil             electricity            propane
#
#          baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                  9692.04
# 122                                 56634.48
# 150                                 48835.85
# 153                                 52691.10
# 162                                 69001.23
# ...                                      ...
# 549882                                   NaN
# 549915                              52898.91
# 549937                               8456.00
# 549963                              17473.34
# 549989                              22285.90
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                        351.02
# 122                                        619.28
# 150                                        718.64
# 153                                           NaN
# 162                                       2222.41
# ...                                           ...
# 549882                                     997.02
# 549915                                    1736.07
# 549937                                     982.27
# 549963                                     898.31
# 549989                                     898.31
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 126 columns]
#
# df_baseline_damages_health: DataFrame containing the baseline scenario data with health damages
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          baseline_2038_cooking_damages_so2_inmap_h6c  \
# bldg_id
# 119                                             0.92
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          0.63
# 549963                                           NaN
# 549989                                          0.82
#
#          baseline_2038_cooking_damages_nox_inmap_h6c  \
# bldg_id
# 119                                            17.35
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          7.15
# 549963                                           NaN
# 549989                                          8.32
#
#          baseline_2038_cooking_damages_pm25_inmap_h6c  \
# bldg_id
# 119                                              8.30
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                           0.91
# 549963                                            NaN
# 549989                                           0.68
#
#          baseline_2038_cooking_damages_health_inmap_h6c  \
# bldg_id
# 119                                               26.56
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                             8.69
# 549963                                              NaN
# 549989                                             9.83
#
#          baseline_cooking_lifetime_damages_health_ap2_acs  \
# bldg_id
# 119                                                 37.49
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              20.82
# 549963                                                NaN
# 549989                                              23.53
#
#          baseline_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 96.32
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              53.48
# 549963                                                NaN
# 549989                                              60.44
#
#          baseline_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 130.47
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               73.35
# 549963                                                 NaN
# 549989                                               59.17
#
#          baseline_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 335.21
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              188.47
# 549963                                                 NaN
# 549989                                              152.01
#
#          baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#          baseline_cooking_lifetime_damages_health_inmap_h6c
# bldg_id
# 119                                                 380.50
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              129.68
# 549963                                                 NaN
# 549989                                              146.99
#
# [15651 rows x 1355 columns]
#
#
#
# ========== SCENARIO: No Inflation Reduction Act ==========
#
#
# ========== SCENARIO: Inflation Reduction Act (AEO2023 Reference Case) ==========
#
#
# ====================================================================================================================================================================
# Post-Retrofit (MP9) Marginal Damages: WHOLE-HOME
# Scenario: No Inflation Reduction Act and AEO2023 Reference Case
# ====================================================================================================================================================================
# calculate_emissions_damages.py file contains the definition for the calculate_marginal_damages function.
# Additional information on emissions and damage factor lookups can be found in the calculate_emissions_damages.py file as well.
#
# CLIMATE DAMAGES: No IRA and IRA-Reference
# --------------------------------------------------------
# Climate Damages (No IRA): df_mp9_noIRA_damages_climate
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# ...
# 150                            1319.29                            840.0
# 153                               0.00                              NaN
# 162                               0.00                              0.0
# ...                                ...                              ...
# 549882                         1485.68                            840.0
# 549915                         1547.25                            840.0
# 549937                         1634.21                            840.0
# 549963                         1565.05                            840.0
# 549989                            0.00                              0.0
#
#         mp9_cooking_rebate_amount
# bldg_id
# 119                        840.00
# 122                           NaN
# 150                           NaN
# 153                           NaN
# 162                           NaN
# ...                           ...
# 549882                        NaN
# 549915                        NaN
# 549937                     105.01
# 549963                        NaN
# 549989                       0.00
#
# [15651 rows x 430 columns]
#
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: PUBLIC IMPACT
#     - calculate_lifetime_public_impact.py file contains the definition for the calculate_public_npv function.
#     - Additional information on emissions/damage factor lookups as well as marginal damages calculation methods can be found in the public_impact folder.
# ====================================================================================================================================================================
#
# Completed Steps:
# 1. Calculate the baseline marginal damages for climate and health-related emissions                         [COMPLETED]
# 2. Calculate the post-retrofit marginal damages for climate and health-related emissions                    [COMPLETED]
#
# REMAINING STEP:
# Step 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: PRIVATE IMPACT
#     - calculate_lifetime_private_impact.py file contains the definition for the calculate_private_npv function.
#     - Additional information on fuel price lookups as well as capital costs calculation methods can be found in the private_impact folder.
# ====================================================================================================================================================================
#
# Completed Steps:
# 1. Calculate annual operating (fuel) costs                                                                  [COMPLETED]
# 2. Calculate equipment capital costs (For space heating, include ductwork and weatherization (MP9-10))      [COMPLETED]
# 3. Calculate replacement cost (replacing existing piece of eqipment with similar technology)                [COMPLETED]
#
# REMAINING STEP:
# Step 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
# ----------------------------------------------------------------------------------------------------------------------
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: ADOPTION POTENTIAL
#     determine_adoption_potential_sensitivity.py file contains the definitions for:
#         - adoption_decision function (combined climate + health analysis)
#         - calculate_climate_only_adoption_robust function (climate-only analysis)
#         - calculate_health_only_adoption_robust function (health-only analysis)
# ====================================================================================================================================================================
#
# Determine adoption potential based on private NPV and public NPV and decision logic
# Tier 1 (Feasible):                      --> Private NPV (total capital cost) >= 0
# Tier 2 (Feasible vs. Alternative):      --> Private NPV (net capital cost) >= 0
# Tier 3 (Subsidy-Dependent Feasibility): --> Private NPV + Public NPV >= 0
# Tier 4 (Averse):                        --> Private NPV + Public NPV < 0
#
# ----------------------------------------------------------------------------------------------------------------------
#
#
#
# ====================================================================================================================================================================
# Scenario No Inflation Reduction Act:
# Advanced Retrofit: Measure Package 9
# Fuel Costs: AEO2023 No Inflation Reduction Act
# Electricity Grid: Cambium 2021 MidCase Scenario
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PUBLIC IMPACT
# ====================================================================================================================================================================
# - Private discount rate IS used for storing results, but NOT used for public impact calculations.
#
# Calculating Public NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PRIVATE IMPACT
# ====================================================================================================================================================================
#
# Calculating Private NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): ADOPTION POTENTIAL
# ====================================================================================================
#
# Determining Adoption Potential for different RCM models and discount rate methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario IRA-Reference:
# EUSS Measure Package 9
# Fuel Costs: AEO2023 Reference Case
# Electricity Grid: Cambium 2023 MidCase Scenario
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PUBLIC IMPACT
# ====================================================================================================================================================================
# - Private discount rate IS used for storing results, but NOT used for public impact calculations.
#
# Calculating Public NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PRIVATE IMPACT
# ====================================================================================================================================================================
#
# Calculating Private NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): ADOPTION POTENTIAL
# ====================================================================================================
#
# Determining Adoption Potential for different RCM models and discount rate methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# The code took 12 minutes and 45 seconds to execute.
# Model Run Complete for EUSS Measure Package: MP9

# %%
# PRESERVE RESULTS AND PREVENT OVERWRITING OF PREVIOUS MODEL RUN DATA
print(f"""
Preserving MP{menu_mp} results by copying dataframe variables and re-assigning to MP-specific names.
This allows the scenarios file to be re-run for MP{menu_mp} without overwriting previous model run data""")

# Supplemental DataFrames
df_mp9_noIRA_damages_climate = df_mpX_noIRA_damages_climate.copy()
df_mp9_IRA_damages_climate = df_mpX_IRA_damages_climate.copy()
df_mp9_noIRA_damages_health = df_mpX_noIRA_damages_health.copy()
df_mp9_IRA_damages_health = df_mpX_IRA_damages_health.copy()
df_mp9_noIRA_fuel_costs = df_mpX_noIRA_fuel_costs.copy()
df_mp9_IRA_fuel_costs = df_mpX_IRA_fuel_costs.copy()

# Summary results dictionary (nested: discount rate -> RCM model -> DataFrame)
# Structure matches new organization: [discount_rate_short][rcm_model]
DATAFRAMES_MP9_RCM_DISCOUNT_RATE_RESULTS = {
    discount_rate: {
        rcm_model: df.copy()
        for rcm_model, df in rcm_dict.items()
    }
    for discount_rate, rcm_dict in DATAFRAMES_MPX_RCM_DISCOUNT_RATE.items()
}

# Clear the batch mode trigger
input_measure_package = None

print(f"MP{menu_mp} results preserved to MP-specific variable names.")
# Out:
# Preserving MP9 results by copying dataframe variables and re-assigning to MP-specific names.
# This allows the scenarios file to be re-run for MP9 without overwriting previous model run data
# MP9 results preserved to MP-specific variable names.

# %%
# =========================================================================================================
# EXPORT RESULTS TO CSV - SUPPLEMENTAL DATA
# =========================================================================================================
print(f"Exporting MP{menu_mp} Supplemental Data...")

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp9_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp9_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp9_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# =========================================================================================================
# EXPORT RESULTS TO CSV - SUMMARY RESULTS FOR RCM MODELS AND DISCOUNT RATES SENSITIVITY ANALYSIS
# =========================================================================================================

# Process each discount rate, then each RCM model (matches dictionary structure)
for discount_rate_short in PRIVATE_DISCOUNT_RATE_SHORT_KEYS:
    print(f"Exporting SUMMARY RESULTS for discount rate: {discount_rate_short}")
    
    # Process each RCM model for this discount rate
    for rcm_model in RCM_MODELS:
        print(f"  RCM Model: {rcm_model.upper()}")
        
        # Get the specific DataFrame for this discount rate × RCM combination
        df_results_export = DATAFRAMES_MP9_RCM_DISCOUNT_RATE_RESULTS[discount_rate_short][rcm_model]
        
        # Export summary results with explicit sensitivity parameters (using short keys)
        export_model_run_output(
            df_results_export=df_results_export,
            results_category='summary',
            menu_mp=menu_mp,
            output_folder_path=output_folder_path,
            location_id=location_id,
            results_export_formatted_date=model_run_date_time,
            rcm_model=rcm_model,
            discount_rate_short=discount_rate_short
        )
# Out:
# Exporting MP9 Supplemental Data...
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_noIRA
# Saved to: mp9_damages_climate_noIRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_noIRA\mp9_damages_climate_noIRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_IRA
# Saved to: mp9_damages_climate_IRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_IRA\mp9_damages_climate_IRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_noIRA
# Saved to: mp9_damages_health_noIRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_noIRA\mp9_damages_health_noIRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_IRA
# Saved to: mp9_damages_health_IRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_IRA\mp9_damages_health_IRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_noIRA
# Saved to: mp9_fuel_costs_noIRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_noIRA\mp9_fuel_costs_noIRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_IRA
# Saved to: mp9_fuel_costs_IRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_IRA\mp9_fuel_costs_IRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: fixed_low
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_low
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_ap2_fixed_low\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_low
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_easiur_fixed_low\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_low
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_inmap_fixed_low\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: fixed_base
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_base
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_ap2_fixed_base\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_base
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_easiur_fixed_base\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_base
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_inmap_fixed_base\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: fixed_high
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_high
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_ap2_fixed_high\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_high
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_easiur_fixed_high\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_high
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_inmap_fixed_high\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: variable
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: variable
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_ap2_variable\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: variable
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_easiur_variable\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: variable
# Saved to: mp9_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp9_results\summary_mp9_inmap_variable\mp9_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## MP10: Whole Home Electrification + Enhanced Enclosure Upgrade

# %%
# Measure Package 10
menu_mp = 10
input_mp = 'upgrade10'

# Pre-set measure package for batch mode
input_measure_package = '10'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the unified scenarios file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_scenarios_v2_2.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPython magic command to run notebook and import variables into current session
get_ipython().run_line_magic('run', f'-i {file_path}')

print(f"Model Run Complete for EUSS Measure Package: MP{menu_mp}")
# Out:
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_scenarios_v2_2.ipynb
#
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (MP8-10).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 346)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            7  242.131013           True   2152.0
# 122            7  242.131013           True   2176.0
# 150            7  242.131013          False   1690.0
# 153            7  242.131013           True   2176.0
# 162            7  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         7  242.131013           True   1202.0
# 549915         7  242.131013          False   2176.0
# 549937         7  242.131013           True    885.0
# 549963         7  242.131013           True   1690.0
# 549989         7  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4367.397352
# 122                                           10479.768179
# 150                                               0.000000
# 153                                           11048.097647
# 162                                           12947.903971
# ...                                                    ...
# 549882                                         5212.871757
# 549915                                            0.000000
# 549937                                         4636.242910
# 549963                                         4903.857419
# 549989                                         4686.866540
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2552.828291
# 122                                            6954.371623
# 150                                               0.000000
# 153                                            6200.439415
# 162                                            8666.012863
# ...                                                    ...
# 549882                                         3310.560695
# 549915                                            0.000000
# 549937                                         1673.632015
# 549963                                          609.743358
# 549989                                         2436.617472
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            2985.641141
# 122                                            7797.415226
# 150                                               0.000000
# 153                                            7363.122758
# 162                                            9676.629818
# ...                                                    ...
# 549882                                         3739.637305
# 549915                                            0.000000
# 549937                                         2257.364571
# 549963                                         1488.137683
# 549989                                         2959.741017
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2356.289439
# 122                                            6648.492515
# 150                                               0.000000
# 153                                            5775.168899
# 162                                            8324.377523
# ...                                                    ...
# 549882                                         3185.908976
# 549915                                            0.000000
# 549937                                         1154.203887
# 549963                                          -84.117798
# 549989                                         2177.081897
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 119      Electric, 100% Usage  Electric, 100% Usage
# 122                       NaN                   NaN
# 150                       NaN                   NaN
# 153                       NaN                   NaN
# 162                       NaN                   NaN
# ...                       ...                   ...
# 549882                    NaN                   NaN
# 549915                    NaN                   NaN
# 549937   Electric, 120% Usage  Electric, 120% Usage
# 549963                    NaN                   NaN
# 549989                    NaN  Electric, 100% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 122                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 150                                 NaN                                NaN
# 153                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 162                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# ...                                 ...                                ...
# 549882                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
# 549915                              NaN                                NaN
# 549937                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549963                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549989                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150                                       NaN
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                                    NaN
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 346 columns]
#  AVAILABLE EUSS MEASURE PACKAGES FOR TARE MODEL RUN:
#       3: ASHP, Min Efficiency
#       4: ASHP, High Efficiency
#       8: Whole Home Electrification (All Enduses)
#       9: Whole Home Electrification (MP8 + Basic Enclosure Upgrade (MP1))
#       10: Whole Home Electrification (MP8 + Enhanced Enclosure Upgrade (MP2))
#
# [BATCH MODE] Using pre-set Measure Package 10.
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Measure Package 10
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade10_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade10_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 354)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 354)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 354)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 354)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119           10  242.131013           True   2152.0
# 122           10  242.131013           True   2176.0
# 150           10  242.131013           True   1690.0
# 153           10  242.131013           True   2176.0
# 162           10  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882        10  242.131013           True   1202.0
# 549915        10  242.131013           True   2176.0
# 549937        10  242.131013           True    885.0
# 549963        10  242.131013           True   1690.0
# 549989        10  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         upgrade.geometry_foundation_type upgrade.hvac_cooling_efficiency  \
# bldg_id
# 119                  Unvented Crawlspace                       Heat Pump
# 122                                  NaN                       Heat Pump
# 150                  Unvented Crawlspace                       Heat Pump
# 153                                  NaN                       Heat Pump
# 162                  Unvented Crawlspace                       Heat Pump
# ...                                  ...                             ...
# 549882                               NaN                       Heat Pump
# 549915               Unvented Crawlspace                       Heat Pump
# 549937                               NaN                       Heat Pump
# 549963               Unvented Crawlspace                       Heat Pump
# 549989                               NaN                       Heat Pump
#
#             upgrade.hvac_heating_efficiency upgrade.hvac_heating_type  \
# bldg_id
# 119                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 122                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 150      MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 153                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 162                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# ...                                     ...                       ...
# 549882   MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
# 549915               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549937               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549963               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549989               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
#
#         upgrade.infiltration_reduction upgrade.insulation_ceiling  \
# bldg_id
# 119                                NaN                       R-60
# 122                                30%                       R-60
# 150                                30%                       R-60
# 153                                30%                       R-60
# 162                                30%                       R-60
# ...                                ...                        ...
# 549882                             30%                       R-60
# 549915                             30%                       R-60
# 549937                             30%                        NaN
# 549963                             NaN                        NaN
# 549989                             NaN                       R-60
#
#         upgrade.insulation_foundation_wall upgrade.insulation_roof  \
# bldg_id
# 119                    Wall R-10, Interior                     NaN
# 122                                    NaN                     NaN
# 150                    Wall R-10, Interior                     NaN
# 153                                    NaN                     NaN
# 162                    Wall R-10, Interior                     NaN
# ...                                    ...                     ...
# 549882                                 NaN                     NaN
# 549915                 Wall R-10, Interior                     NaN
# 549937                                 NaN                     NaN
# 549963                 Wall R-10, Interior                     NaN
# 549989                                 NaN                     NaN
#
#         upgrade.insulation_wall       upgrade.water_heater_efficiency
# bldg_id
# 119                         NaN  Electric Heat Pump, 66 gal, 3.35 UEF
# 122             Wood Stud, R-13  Electric Heat Pump, 66 gal, 3.35 UEF
# 150             Wood Stud, R-13  Electric Heat Pump, 66 gal, 3.35 UEF
# 153                         NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 162             Wood Stud, R-13  Electric Heat Pump, 80 gal, 3.45 UEF
# ...                         ...                                   ...
# 549882                      NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                      NaN  Electric Heat Pump, 80 gal, 3.45 UEF
# 549937          Wood Stud, R-13  Electric Heat Pump, 66 gal, 3.35 UEF
# 549963                      NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 549989          Wood Stud, R-13  Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 354 columns]
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 10 (MP10)
# ====================================================================================================================================================================
# You'll notice that the number of rows differs from df_euss_am_mp7 and df_euss_am_mpX.
#       - df_euss_am_baseline_home has fewer rows (representative dwelling units) because a tech filter was applied.
#       - df_euss_am_mpX_home will have the same number of rows as df_euss_am_baseline_home after df_enduse_compare function is run.
#       - df_enduse_compare function performs an inner merge on the two dataframes, keeping only the rows that are present in both dataframes.
# ====================================================================================================================================================================
# df_euss_am_mpX_home will be created by running the df_enduse_compare function (contains post-retrofit consumption data for the entire home in 2024).
# process_euss_data.py file contains the function definition.
#
#
#
# Applying combined validation (data quality + retrofit status):
#   mp10_heating_consumption: Masked 3385 values
#   mp10_waterHeating_consumption: Masked 652 values
#   mp10_clothesDrying_consumption: Masked 908 values
#   mp10_cooking_consumption: Masked 7784 values
#
# ====================================================================================================================================================================
# PUBLIC IMPACTS: DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
#
#
#
#  Creating dataframe to store marginal damages calculations ...
#
# ====================================================================================================================================================================
# df_euss_am_baseline_home: DataFrame containing the baseline scenario data
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#         baseline_cooking_lifetime_damages_health_inmap_h6c fuel_type_heating  \
# bldg_id
# 119                                                 380.50        naturalGas
# 122                                                    NaN           fuelOil
# 150                                                    NaN       electricity
# 153                                                    NaN           fuelOil
# 162                                                    NaN           fuelOil
# ...                                                    ...               ...
# 549882                                                 NaN        naturalGas
# 549915                                                 NaN       electricity
# 549937                                              129.68        naturalGas
# 549963                                                 NaN        naturalGas
# 549989                                              146.99           fuelOil
#
#         fuel_type_waterHeating fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 119                 naturalGas              naturalGas         naturalGas
# 122                    fuelOil             electricity        electricity
# 150                electricity             electricity        electricity
# 153                    fuelOil                     NaN        electricity
# 162                 naturalGas             electricity        electricity
# ...                        ...                     ...                ...
# 549882              naturalGas             electricity        electricity
# 549915             electricity             electricity        electricity
# 549937              naturalGas              naturalGas         naturalGas
# 549963              naturalGas             electricity        electricity
# 549989                 fuelOil             electricity            propane
#
#          baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                  9692.04
# 122                                 56634.48
# 150                                 48835.85
# 153                                 52691.10
# 162                                 69001.23
# ...                                      ...
# 549882                                   NaN
# 549915                              52898.91
# 549937                               8456.00
# 549963                              17473.34
# 549989                              22285.90
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                        351.02
# 122                                        619.28
# 150                                        718.64
# 153                                           NaN
# 162                                       2222.41
# ...                                           ...
# 549882                                     997.02
# 549915                                    1736.07
# 549937                                     982.27
# 549963                                     898.31
# 549989                                     898.31
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 126 columns]
#
# df_baseline_damages_health: DataFrame containing the baseline scenario data with health damages
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          baseline_2038_cooking_damages_so2_inmap_h6c  \
# bldg_id
# 119                                             0.92
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          0.63
# 549963                                           NaN
# 549989                                          0.82
#
#          baseline_2038_cooking_damages_nox_inmap_h6c  \
# bldg_id
# 119                                            17.35
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                          7.15
# 549963                                           NaN
# 549989                                          8.32
#
#          baseline_2038_cooking_damages_pm25_inmap_h6c  \
# bldg_id
# 119                                              8.30
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                           0.91
# 549963                                            NaN
# 549989                                           0.68
#
#          baseline_2038_cooking_damages_health_inmap_h6c  \
# bldg_id
# 119                                               26.56
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                             8.69
# 549963                                              NaN
# 549989                                             9.83
#
#          baseline_cooking_lifetime_damages_health_ap2_acs  \
# bldg_id
# 119                                                 37.49
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              20.82
# 549963                                                NaN
# 549989                                              23.53
#
#          baseline_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 96.32
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                              53.48
# 549963                                                NaN
# 549989                                              60.44
#
#          baseline_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 130.47
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               73.35
# 549963                                                 NaN
# 549989                                               59.17
#
#          baseline_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 335.21
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              188.47
# 549963                                                 NaN
# 549989                                              152.01
#
#          baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#          baseline_cooking_lifetime_damages_health_inmap_h6c
# bldg_id
# 119                                                 380.50
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              129.68
# 549963                                                 NaN
# 549989                                              146.99
#
# [15651 rows x 1355 columns]
#
#
#
# ========== SCENARIO: No Inflation Reduction Act ==========
#
#
# ========== SCENARIO: Inflation Reduction Act (AEO2023 Reference Case) ==========
#
#
# ====================================================================================================================================================================
# Post-Retrofit (MP10) Marginal Damages: WHOLE-HOME
# Scenario: No Inflation Reduction Act and AEO2023 Reference Case
# ====================================================================================================================================================================
# calculate_emissions_damages.py file contains the definition for the calculate_marginal_damages function.
# Additional information on emissions and damage factor lookups can be found in the calculate_emissions_damages.py file as well.
#
# CLIMATE DAMAGES: No IRA and IRA-Reference
# --------------------------------------------------------
# Climate Damages (No IRA): df_mp10_noIRA_damages_climate
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
# ...
# 150                             1615.94                            840.00
# 153                                0.00                               NaN
# 162                                0.00                              0.00
# ...                                 ...                               ...
# 549882                          1441.69                            840.00
# 549915                          1750.00                            840.00
# 549937                             0.00                              0.00
# 549963                          1512.94                            811.22
# 549989                             0.00                              0.00
#
#         mp10_cooking_rebate_amount
# bldg_id
# 119                          840.0
# 122                            NaN
# 150                            NaN
# 153                            NaN
# 162                            NaN
# ...                            ...
# 549882                         NaN
# 549915                         NaN
# 549937                         0.0
# 549963                         NaN
# 549989                         0.0
#
# [15651 rows x 445 columns]
#
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: PUBLIC IMPACT
#     - calculate_lifetime_public_impact.py file contains the definition for the calculate_public_npv function.
#     - Additional information on emissions/damage factor lookups as well as marginal damages calculation methods can be found in the public_impact folder.
# ====================================================================================================================================================================
#
# Completed Steps:
# 1. Calculate the baseline marginal damages for climate and health-related emissions                         [COMPLETED]
# 2. Calculate the post-retrofit marginal damages for climate and health-related emissions                    [COMPLETED]
#
# REMAINING STEP:
# Step 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: PRIVATE IMPACT
#     - calculate_lifetime_private_impact.py file contains the definition for the calculate_private_npv function.
#     - Additional information on fuel price lookups as well as capital costs calculation methods can be found in the private_impact folder.
# ====================================================================================================================================================================
#
# Completed Steps:
# 1. Calculate annual operating (fuel) costs                                                                  [COMPLETED]
# 2. Calculate equipment capital costs (For space heating, include ductwork and weatherization (MP9-10))      [COMPLETED]
# 3. Calculate replacement cost (replacing existing piece of eqipment with similar technology)                [COMPLETED]
#
# REMAINING STEP:
# Step 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
# ----------------------------------------------------------------------------------------------------------------------
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: ADOPTION POTENTIAL
#     determine_adoption_potential_sensitivity.py file contains the definitions for:
#         - adoption_decision function (combined climate + health analysis)
#         - calculate_climate_only_adoption_robust function (climate-only analysis)
#         - calculate_health_only_adoption_robust function (health-only analysis)
# ====================================================================================================================================================================
#
# Determine adoption potential based on private NPV and public NPV and decision logic
# Tier 1 (Feasible):                      --> Private NPV (total capital cost) >= 0
# Tier 2 (Feasible vs. Alternative):      --> Private NPV (net capital cost) >= 0
# Tier 3 (Subsidy-Dependent Feasibility): --> Private NPV + Public NPV >= 0
# Tier 4 (Averse):                        --> Private NPV + Public NPV < 0
#
# ----------------------------------------------------------------------------------------------------------------------
#
#
#
# ====================================================================================================================================================================
# Scenario No Inflation Reduction Act:
# Advanced Retrofit: Measure Package 10
# Fuel Costs: AEO2023 No Inflation Reduction Act
# Electricity Grid: Cambium 2021 MidCase Scenario
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PUBLIC IMPACT
# ====================================================================================================================================================================
# - Private discount rate IS used for storing results, but NOT used for public impact calculations.
#
# Calculating Public NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PRIVATE IMPACT
# ====================================================================================================================================================================
#
# Calculating Private NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): ADOPTION POTENTIAL
# ====================================================================================================
#
# Determining Adoption Potential for different RCM models and discount rate methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario IRA-Reference:
# EUSS Measure Package 10
# Fuel Costs: AEO2023 Reference Case
# Electricity Grid: Cambium 2023 MidCase Scenario
# ====================================================================================================================================================================
#
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PUBLIC IMPACT
# ====================================================================================================================================================================
# - Private discount rate IS used for storing results, but NOT used for public impact calculations.
#
# Calculating Public NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PRIVATE IMPACT
# ====================================================================================================================================================================
#
# Calculating Private NPV for different RCM models and discount methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#   RCM Model: EASIUR
#   RCM Model: INMAP
#
# ====================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): ADOPTION POTENTIAL
# ====================================================================================================
#
# Determining Adoption Potential for different RCM models and discount rate methods ...
# Discount Rate: fixed_low, Column: private_discount_rate_fixed_low
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_base, Column: private_discount_rate_fixed_base
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: fixed_high, Column: private_discount_rate_fixed_high
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# Discount Rate: variable, Column: private_discount_rate_variable
#   RCM Model: AP2
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: EASIUR
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
#   RCM Model: INMAP
#     Combined climate + health analysis: acs...
#     Combined climate + health analysis: h6c...
#     Climate-only analysis ...
#     Health-only analysis: acs...
#     Health-only analysis: h6c...
# The code took 19 minutes and 45 seconds to execute.
# Model Run Complete for EUSS Measure Package: MP10

# %%
# PRESERVE RESULTS AND PREVENT OVERWRITING OF PREVIOUS MODEL RUN DATA
print(f"""
Preserving MP{menu_mp} results by copying dataframe variables and re-assigning to MP-specific names.
This allows the scenarios file to be re-run for MP{menu_mp} without overwriting previous model run data""")

# Supplemental DataFrames
df_mp10_noIRA_damages_climate = df_mpX_noIRA_damages_climate.copy()
df_mp10_IRA_damages_climate = df_mpX_IRA_damages_climate.copy()
df_mp10_noIRA_damages_health = df_mpX_noIRA_damages_health.copy()
df_mp10_IRA_damages_health = df_mpX_IRA_damages_health.copy()
df_mp10_noIRA_fuel_costs = df_mpX_noIRA_fuel_costs.copy()
df_mp10_IRA_fuel_costs = df_mpX_IRA_fuel_costs.copy()

# Summary results dictionary (nested: discount rate -> RCM model -> DataFrame)
# Structure matches new organization: [discount_rate_short][rcm_model]
DATAFRAMES_MP10_RCM_DISCOUNT_RATE_RESULTS = {
    discount_rate: {
        rcm_model: df.copy()
        for rcm_model, df in rcm_dict.items()
    }
    for discount_rate, rcm_dict in DATAFRAMES_MPX_RCM_DISCOUNT_RATE.items()
}

# Clear the batch mode trigger
input_measure_package = None

print(f"MP{menu_mp} results preserved to MP-specific variable names.")
# Out:
# Preserving MP10 results by copying dataframe variables and re-assigning to MP-specific names.
# This allows the scenarios file to be re-run for MP10 without overwriting previous model run data
# MP10 results preserved to MP-specific variable names.

# %%
# =========================================================================================================
# EXPORT RESULTS TO CSV - SUPPLEMENTAL DATA
# =========================================================================================================
print(f"Exporting MP{menu_mp} Supplemental Data...")

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp10_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp10_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

export_model_run_output(
    df_results_export=df_mp10_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=model_run_date_time
)

# =========================================================================================================
# EXPORT RESULTS TO CSV - SUMMARY RESULTS FOR RCM MODELS AND DISCOUNT RATES SENSITIVITY ANALYSIS
# =========================================================================================================

# Process each discount rate, then each RCM model (matches dictionary structure)
for discount_rate_short in PRIVATE_DISCOUNT_RATE_SHORT_KEYS:
    print(f"Exporting SUMMARY RESULTS for discount rate: {discount_rate_short}")
    
    # Process each RCM model for this discount rate
    for rcm_model in RCM_MODELS:
        print(f"  RCM Model: {rcm_model.upper()}")
        
        # Get the specific DataFrame for this discount rate × RCM combination
        df_results_export = DATAFRAMES_MP10_RCM_DISCOUNT_RATE_RESULTS[discount_rate_short][rcm_model]
        
        # Export summary results with explicit sensitivity parameters (using short keys)
        export_model_run_output(
            df_results_export=df_results_export,
            results_category='summary',
            menu_mp=menu_mp,
            output_folder_path=output_folder_path,
            location_id=location_id,
            results_export_formatted_date=model_run_date_time,
            rcm_model=rcm_model,
            discount_rate_short=discount_rate_short
        )
# Out:
# Exporting MP10 Supplemental Data...
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_noIRA
# Saved to: mp10_damages_climate_noIRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_noIRA\mp10_damages_climate_noIRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_climate_IRA
# Saved to: mp10_damages_climate_IRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_IRA\mp10_damages_climate_IRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_noIRA
# Saved to: mp10_damages_health_noIRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_noIRA\mp10_damages_health_noIRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL DAMAGES: damages_health_IRA
# Saved to: mp10_damages_health_IRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_IRA\mp10_damages_health_IRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_noIRA
# Saved to: mp10_fuel_costs_noIRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_noIRA\mp10_fuel_costs_noIRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL FUEL COSTS: fuel_costs_IRA
# Saved to: mp10_fuel_costs_IRA_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_IRA\mp10_fuel_costs_IRA_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: fixed_low
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_low
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_ap2_fixed_low\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_low
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_easiur_fixed_low\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_low
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_inmap_fixed_low\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: fixed_base
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_base
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_ap2_fixed_base\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_base
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_easiur_fixed_base\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_base
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_inmap_fixed_base\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: fixed_high
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: fixed_high
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_ap2_fixed_high\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: fixed_high
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_easiur_fixed_high\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: fixed_high
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_inmap_fixed_high\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
# Exporting SUMMARY RESULTS for discount rate: variable
#   RCM Model: AP2
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: ap2
#   Discount Rate: variable
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_ap2_variable\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: EASIUR
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: easiur
#   Discount Rate: variable
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_easiur_variable\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
#
#   RCM Model: INMAP
# ---------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 SUMMARY RESULTS:
#   RCM Model: inmap
#   Discount Rate: variable
# Saved to: mp10_results_PA_2026-02-03_20-24.csv
# Full path: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results\retrofit_mp10_results\summary_mp10_inmap_variable\mp10_results_PA_2026-02-03_20-24.csv
# ---------------------------------------------------------------------------------------------------------
