# %%
# import os

# # import from cmu-tare-model package
# from config import PROJECT_ROOT

# # Measure Package 0: Baseline
# menu_mp = 0
# input_mp = 'baseline'

# print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# # Construct the absolute path to the .py file
# relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_baseline_v2_1.ipynb")
# file_path = os.path.join(PROJECT_ROOT, relative_path)

# # On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
# file_path = file_path.replace("\\", "/")

# print(f"Running file: {file_path}")

# # %run magic command to run a .py file and import variables into the current IPython session
# # # If your path has spaces, wrap it in quotes:
# %run -i {file_path} # If your path has NO spaces, no quotes needed.

# print("Baseline Scenario - Model Run Complete")

# # Flag to prevent excessive output in other scenario files
# individual_scenario_run = True
# Out:
# Project root directory: c:\users\jorda\desktop\projects\cmu-tare-model
# PROJECT_ROOT (from config.py): c:\users\jorda\desktop\projects\cmu-tare-model
# Running file: c:/users/jorda/desktop/projects/cmu-tare-model/cmu_tare_model/model_scenarios/tare_baseline_v2_1.ipynb
#
# =========================================================================================================
# Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
# Let's start by reading the data from the NREL EUSS Database.
#
# Make sure that the zipped folders stay organized as they are once unzipped.
# If changes are made to the file path, then the program will not run properly.
# ==========================================================================================================
#
# Project root directory: c:\users\jorda\desktop\projects\cmu-tare-model
# Result outputs will be exported here: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\output_results
#
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# Load data from the NREL EUSS Database for the baseline scenario and apply various filters.
#
# DATA: NREL EUSS Database
# HOUSING FILTERS: Occupied units and Single Family Homes
# GEOGRAPHIC FILTERS: National, State, or City
#
# Additional details data can be found in the official End-Use Load Profiles/Savings Shapes documentation.
# Our methodology is detailed in the process_euss_data.py file and its associated imports.
#
# RESULTS OUTPUT:
#
# Retrieved data for filename: baseline_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\baseline_metadata_and_annual_results.csv
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 259)
# You chose to filter for: PA
# Location ID is: PA
#
# To accurately characterize load profile, it is recommended to select subsets of data with >= 1000 models (~240,000 representative dwelling units).
#
# The following cities (number of models also shown) are available for this state:
#
# in.city
# Not in a census Place      7035
# In another census Place    5851
# PA, Philadelphia           1631
# PA, Pittsburgh              329
# PA, Erie                    105
# PA, Allentown               104
# PA, Reading                  92
# PA, Bethlehem                85
# PA, Scranton                 80
# PA, Harrisburg               63
# PA, Lancaster                58
# PA, Levittown                58
# PA, Altoona                  56
# PA, York                     56
# PA, Wilkes-Barre             48
# Name: count, dtype: int64
# You chose to analyze all of state: PA
# Location ID is: PA
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline
#
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            0  242.131013           True   2152.0
# 122            0  242.131013           True   2176.0
# 150            0  242.131013           True   1690.0
# 153            0  242.131013           True   2176.0
# 162            0  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         0  242.131013           True   1202.0
# 549915         0  242.131013           True   2176.0
# 549937         0  242.131013           True    885.0
# 549963         0  242.131013           True   1690.0
# 549989         0  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions.natural_gas.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            5540.594966
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                             890.321536
# ...                                                    ...
# 549882                                         6675.629132
# 549915                                            0.000000
# 549937                                         7002.945922
# 549963                                         8277.210267
# 549989                                            0.000000
#
#         out.emissions.propane.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions.electricity.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4179.118870
# 122                                            3794.589113
# 150                                           11378.222173
# 153                                            4612.318634
# 162                                            4330.249044
# ...                                                    ...
# 549882                                         2916.093184
# 549915                                        16728.421288
# 549937                                         3823.559604
# 549963                                         3992.118611
# 549989                                         2136.040859
#
#         out.emissions.fuel_oil.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                           13038.928166
# 150                                               0.000000
# 153                                           14589.636195
# 162                                           15002.759507
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                         6042.544365
#
#         out.emissions.natural_gas.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            5540.594966
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                             890.321536
# ...                                                    ...
# 549882                                         6675.629132
# 549915                                            0.000000
# 549937                                         7002.945922
# 549963                                         8277.210267
# 549989                                            0.000000
#
#         out.emissions.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            7380.371515
# 122                                           14675.825549
# 150                                            4530.910597
# 153                                           16564.727059
# 162                                           17837.666007
# ...                                                    ...
# 549882                                         7916.182492
# 549915                                         6870.847124
# 549937                                         8577.560537
# 549963                                         9951.214681
# 549989                                         7176.439561
#
#         out.emissions.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            9495.197860
# 122                                           16590.276103
# 150                                           10702.844907
# 153                                           18949.747039
# 162                                           20060.715408
# ...                                                    ...
# 549882                                         9422.157695
# 549915                                        15814.400458
# 549937                                        10516.078249
# 549963                                        11921.778240
# 549989                                         8281.270372
#
#         out.emissions.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            9035.427108
# 122                                           16204.985672
# 150                                            9290.264827
# 153                                           18437.677994
# 162                                           19596.115712
# ...                                                    ...
# 549882                                         9095.470037
# 549915                                        13772.445542
# 549937                                        10222.759114
# 549963                                        11608.667963
# 549989                                         8040.946248
#
#         out.emissions.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg
# bldg_id
# 119                                            9719.713836
# 122                                           16833.517280
# 150                                           11378.222173
# 153                                           19201.954829
# 162                                           20223.330087
# ...                                                    ...
# 549882                                         9591.722316
# 549915                                        16728.421288
# 549937                                        10826.505527
# 549963                                        12269.328878
# 549989                                         8402.441677
#
# [15651 rows x 259 columns]
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# In addition to the housing type and occupancy filters, the data has been filtered for fuel and technology
# Please see the energy_consumption_and_metadata folder for more details on data processing.
#
# We employ the df_enduse_refactored function to process the data and create a new dataframe, which is part of the 5-step data validation process:
# 1. Mask Initialization with initialize_validation_tracking()
# 2. Series Initialization with create_retrofit_only_series()
# 3. Valid-Only Calculation for qualifying homes
# 4. Valid-Only Updates using list-based collection
# 5. Final Masking with apply_final_masking()
#
# Documentation for df_enduse_refactored function:
# Creates a standardized energy usage DataFrame and applies data quality filters.
#
#     This function creates a new DataFrame with standardized column names and structure,
#     calculates total consumption by fuel type, creates data quality flags for analysis,
#     and sets invalid consumption values to NaN.
#
#     Args:
#         df_baseline: The baseline DataFrame containing raw EUSS/ResStock data.
#
#     Returns:
#         A standardized DataFrame with processed consumption data and data quality flags.
#
#     Raises:
#         ValueError: If required columns are missing from the input DataFrame.
#
# ----------------------------------------------------------------
#
# RESULTS OUTPUT (BASELINE):
#
# Processing column: in.clothes_dryer
# Initial data types: object
# Data types after processing: object
# Processing column: in.cooking_range
# Initial data types: object
# Data types after processing: object
# Calculated total heating consumption
# Calculated total waterHeating consumption
# Calculated total clothesDrying consumption
# Calculated total cooking consumption
#
# Creating data quality flags for all categories
#
# --- Processing heating ---
# Values in base_heating_fuel (top 5):
# base_heating_fuel
# Natural Gas    8594
# Fuel Oil       2922
# Electricity    2722
# Other Fuel      789
# Propane         615
# Name: count, dtype: int64
#   heating: Found 798 homes (5.1%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_heating_fuel
# Other Fuel    789
# Name: count, dtype: int64
# Values in heating_type (top 5):
# heating_type
# Natural Gas Fuel Furnace               5686
# Fuel Oil Fuel Furnace                  1855
# Natural Gas Fuel Wall/Floor Furnace    1437
# Natural Gas Fuel Boiler                1301
# Electricity Baseboard                  1130
# Name: count, dtype: int64
# Allowed values for heating:
# ['Electricity Baseboard', 'Electricity Electric Boiler', 'Electricity Electric Furnace', 'Fuel Oil Fuel Boiler', 'Fuel Oil Fuel Furnace', 'Natural Gas Fuel Boiler', 'Natural Gas Fuel Furnace', 'Propane Fuel Boiler', 'Propane Fuel Furnace']
#   heating: Found 3385 homes (21.6%) with invalid technology types
#   Invalid technology types (top 5):
# heating_type
# Natural Gas Fuel Wall/Floor Furnace    1437
# Electricity ASHP                        684
# Natural Gas Shared Heating              170
# Propane Fuel Wall/Floor Furnace         121
# Fuel Oil Fuel Wall/Floor Furnace         93
# Name: count, dtype: int64
#   heating: Total 3385 homes (21.6%) excluded from analysis
#
# --- Processing waterHeating ---
# Values in base_waterHeating_fuel (top 5):
# base_waterHeating_fuel
# Natural Gas    8669
# Electricity    4652
# Fuel Oil       1728
# Propane         578
# Other Fuel       24
# Name: count, dtype: int64
#   waterHeating: Found 24 homes (0.2%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_waterHeating_fuel
# Other Fuel    24
# Name: count, dtype: int64
# Values in waterHeating_type (top 5):
# waterHeating_type
# Natural Gas Standard    7788
# Electric Standard       3698
# Fuel Oil Standard       1142
# Electric Premium         824
# Natural Gas Premium      673
# Name: count, dtype: int64
# Allowed values for waterHeating:
# ['Electric Premium', 'Electric Standard', 'Fuel Oil Premium', 'Fuel Oil Standard', 'Natural Gas Premium', 'Natural Gas Standard', 'Propane Premium', 'Propane Standard']
#   waterHeating: Found 652 homes (4.2%) with invalid technology types
#   Invalid technology types (top 5):
# waterHeating_type
# FIXME Fuel Oil Indirect       261
# Natural Gas Tankless          208
# Electric Tankless             100
# Electric Heat Pump, 80 gal     30
# Propane Tankless               29
# Name: count, dtype: int64
#   waterHeating: Total 652 homes (4.2%) excluded from analysis
#
# --- Processing clothesDrying ---
# Values in base_clothesDrying_fuel (top 5):
# base_clothesDrying_fuel
# Electricity    10551
# Natural Gas     3899
# Propane          293
# Name: count, dtype: int64
#   clothesDrying: Found 908 homes (5.8%) with invalid fuel types
#   Invalid fuel types (top 5):
# Series([], Name: count, dtype: int64)
#   clothesDrying: Technology validation not applicable (no technology type column)
#   clothesDrying: Total 908 homes (5.8%) excluded from analysis
#
# --- Processing cooking ---
# Values in base_cooking_fuel (top 5):
# base_cooking_fuel
# Electricity    7620
# Natural Gas    6686
# Propane        1181
# Name: count, dtype: int64
#   cooking: Found 7784 homes (49.7%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_cooking_fuel
# Electricity    7620
# Name: count, dtype: int64
#   cooking: Technology validation not applicable (no technology type column)
#   cooking: Total 7784 homes (49.7%) excluded from analysis
#
# Total 9976 homes (63.7%) excluded from all categories
#
# Applying data validation (baseline only):
# Baseline calculation for heating:
#   - 12266 homes have valid data
#   - 3385 homes have invalid data (values will be NaN)
#   base_electricity_heating_consumption: Masked 3385 values
#   base_naturalGas_heating_consumption: Masked 3385 values
#   base_fuelOil_heating_consumption: Masked 3385 values
#   base_propane_heating_consumption: Masked 3385 values
#   baseline_heating_consumption: Masked 2587 values
# Baseline calculation for waterHeating:
#   - 14999 homes have valid data
#   - 652 homes have invalid data (values will be NaN)
#   base_electricity_waterHeating_consumption: Masked 652 values
#   base_naturalGas_waterHeating_consumption: Masked 652 values
#   base_fuelOil_waterHeating_consumption: Masked 652 values
#   base_propane_waterHeating_consumption: Masked 652 values
#   baseline_waterHeating_consumption: Masked 628 values
# Baseline calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 908 homes have invalid data (values will be NaN)
#   base_electricity_clothesDrying_consumption: Masked 908 values
#   base_naturalGas_clothesDrying_consumption: Masked 908 values
#   base_propane_clothesDrying_consumption: Masked 908 values
# Baseline calculation for cooking:
#   - 7867 homes have valid data
#   - 7784 homes have invalid data (values will be NaN)
#   base_electricity_cooking_consumption: Masked 7784 values
#   base_naturalGas_cooking_consumption: Masked 7784 values
#   base_propane_cooking_consumption: Masked 7784 values
#   baseline_cooking_consumption: Masked 7620 values
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline_home
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... valid_fuel_heating  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...               True
# 122      In another census Place   Suburban  ...               True
# 150      In another census Place      Rural  ...               True
# 153        Not in a census Place   Suburban  ...               True
# 162        Not in a census Place   Suburban  ...               True
# ...                          ...        ...  ...                ...
# 549882     Not in a census Place   Suburban  ...               True
# 549915                 Lancaster   Suburban  ...               True
# 549937   In another census Place      Rural  ...               True
# 549963   In another census Place   Suburban  ...               True
# 549989     Not in a census Place      Rural  ...               True
#
#         valid_tech_heating include_heating valid_fuel_waterHeating  \
# bldg_id
# 119                   True            True                    True
# 122                   True            True                    True
# 150                   True            True                    True
# 153                   True            True                    True
# 162                   True            True                    True
# ...                    ...             ...                     ...
# 549882               False           False                    True
# 549915                True            True                    True
# 549937                True            True                    True
# 549963                True            True                    True
# 549989                True            True                    True
#
#         valid_tech_waterHeating  include_waterHeating  \
# bldg_id
# 119                        True                  True
# 122                        True                  True
# 150                        True                  True
# 153                        True                  True
# 162                        True                  True
# ...                         ...                   ...
# 549882                     True                  True
# 549915                     True                  True
# 549937                     True                  True
# 549963                     True                  True
# 549989                     True                  True
#
#          valid_fuel_clothesDrying include_clothesDrying valid_fuel_cooking  \
# bldg_id
# 119                          True                  True               True
# 122                          True                  True              False
# 150                          True                  True              False
# 153                         False                 False              False
# 162                          True                  True              False
# ...                           ...                   ...                ...
# 549882                       True                  True              False
# 549915                       True                  True              False
# 549937                       True                  True               True
# 549963                       True                  True              False
# 549989                       True                  True               True
#
#         include_cooking
# bldg_id
# 119                True
# 122               False
# 150               False
# 153               False
# 162               False
# ...                 ...
# 549882            False
# 549915            False
# 549937             True
# 549963            False
# 549989             True
#
# [15651 rows x 61 columns]
#
#
# ====================================================================================================================================================================
#
# DATAFRAME: df_euss_am_baseline_home
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... valid_fuel_heating  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...               True
# 122      In another census Place   Suburban  ...               True
# 150      In another census Place      Rural  ...               True
# 153        Not in a census Place   Suburban  ...               True
# 162        Not in a census Place   Suburban  ...               True
# ...                          ...        ...  ...                ...
# 549882     Not in a census Place   Suburban  ...               True
# 549915                 Lancaster   Suburban  ...               True
# 549937   In another census Place      Rural  ...               True
# 549963   In another census Place   Suburban  ...               True
# 549989     Not in a census Place      Rural  ...               True
#
#         valid_tech_heating include_heating valid_fuel_waterHeating  \
# bldg_id
# 119                   True            True                    True
# 122                   True            True                    True
# 150                   True            True                    True
# 153                   True            True                    True
# 162                   True            True                    True
# ...                    ...             ...                     ...
# 549882               False           False                    True
# 549915                True            True                    True
# 549937                True            True                    True
# 549963                True            True                    True
# 549989                True            True                    True
#
#         valid_tech_waterHeating  include_waterHeating  \
# bldg_id
# 119                        True                  True
# 122                        True                  True
# 150                        True                  True
# 153                        True                  True
# 162                        True                  True
# ...                         ...                   ...
# 549882                     True                  True
# 549915                     True                  True
# 549937                     True                  True
# 549963                     True                  True
# 549989                     True                  True
#
#          valid_fuel_clothesDrying include_clothesDrying valid_fuel_cooking  \
# bldg_id
# 119                          True                  True               True
# 122                          True                  True              False
# 150                          True                  True              False
# 153                         False                 False              False
# 162                          True                  True              False
# ...                           ...                   ...                ...
# 549882                       True                  True              False
# 549915                       True                  True              False
# 549937                       True                  True               True
# 549963                       True                  True              False
# 549989                       True                  True               True
#
#         include_cooking
# bldg_id
# 119                True
# 122               False
# 150               False
# 153               False
# 162               False
# ...                 ...
# 549882            False
# 549915            False
# 549937             True
# 549963            False
# 549989             True
#
# [15651 rows x 61 columns]
#
#
#
#     -------------------------------------------------------------------------------------------------------
#     PRE-IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2021 RELEASE
#     -------------------------------------------------------------------------------------------------------
#
#
#
#     Retrieved data for filename: cambium21_midCase_annual_gea.xlsx
#     Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\projections\cambium21_midCase_annual_gea.xlsx
#
#     Loading dataframe ...
#
#               dataset scenario gea_region  year  cef_gen  aer_co2e_kg_per_MWh  \
# 0    Cambium_2021  MidCase      AZNMc  2022      NaN                423.2
# 1    Cambium_2021  MidCase      AZNMc  2024      NaN                389.5
# 2    Cambium_2021  MidCase      AZNMc  2026      NaN                374.7
# 3    Cambium_2021  MidCase      AZNMc  2028      NaN                364.8
# 4    Cambium_2021  MidCase      AZNMc  2030      NaN                315.8
# ..            ...      ...        ...   ...      ...                  ...
# 295  Cambium_2021  MidCase      SRVCc  2042      NaN                240.8
# 296  Cambium_2021  MidCase      SRVCc  2044      NaN                222.5
# 297  Cambium_2021  MidCase      SRVCc  2046      NaN                178.5
# 298  Cambium_2021  MidCase      SRVCc  2048      NaN                182.1
# 299  Cambium_2021  MidCase      SRVCc  2050      NaN                169.3
#
#      lrmer_co2e_kg_per_MWh  srmer_co2e_kg_per_MWh  generation  \
# 0                    525.6                  811.8   143037980
# 1                    488.4                  808.4   151806820
# 2                    423.1                  816.0   154638340
# 3                    315.8                  784.7   159426910
# 4                    313.6                  749.8   175350740
# ..                     ...                    ...         ...
# 295                  313.9                  805.5   400253860
# 296                  314.6                  786.1   427886080
# 297                  320.6                  754.9   444492960
# 298                  317.9                  751.3   453625180
# 299                  306.7                  718.3   466444480
#
#      variable_generation  ...  total_coal  total_natural_gas  total_oil  \
# 0             27345228.0  ...  32912356.0         40391114.7    29364.0
# 1             29423460.0  ...  27460646.0         52221791.8    14086.3
# 2             29648762.0  ...  26772840.0         53833046.4     8814.2
# 3             32619604.0  ...  26693880.0         55589546.7    10161.3
# 4             50951904.0  ...  24898662.0         54122073.2    13228.5
# ..                   ...  ...         ...                ...        ...
# 295           96427260.0  ...  37576316.0        117368159.3     2205.4
# 296          115764890.0  ...  33240228.0        125603043.3     1392.8
# 297          150328400.0  ...  27152428.0        105858843.0       74.8
# 298          152065260.0  ...  27861414.0        111393181.0       49.1
# 299          154687700.0  ...  14777366.0        134385100.3        9.9
#
#      total_nuclear  total_renewable  fraction_coal  fraction_natural_gas  \
# 0         31446266       37669404.5       0.231047              0.283549
# 1         31446266       40074547.2       0.181597              0.345343
# 2         31446266       41990327.2       0.173792              0.349449
# 3         31446266       45101365.5       0.168054              0.349969
# 4         31446266       64294435.2       0.142462              0.309668
# ..             ...              ...            ...                   ...
# 295      122300980      121063293.0       0.094339              0.294665
# 296      122300980      144866950.7       0.078026              0.294834
# 297      122300980      187251355.2       0.061353              0.239195
# 298      122300980      190141835.5       0.061682              0.246610
# 299      122300980      193718661.2       0.031767              0.288887
#
#      fraction_oil  fraction_nuclear  fraction_renewable
# 0    2.061377e-04          0.220755            0.264442
# 1    9.315268e-05          0.207954            0.265013
# 2    5.721601e-05          0.204129            0.272574
# 3    6.397143e-05          0.197973            0.283940
# 4    7.568889e-05          0.179925            0.367870
# ..            ...               ...                 ...
# 295  5.536880e-06          0.307049            0.303942
# 296  3.269387e-06          0.287083            0.340053
# 297  1.690152e-07          0.276347            0.423106
# 298  1.087011e-07          0.270759            0.420950
# 299  2.128199e-08          0.262910            0.416436
#
# [300 rows x 43 columns]
#
#     Creating lookup dictionary for LRMER and SRMER ...
#     -------------------------------------------------------------------------------------------------------
#
#
#     -------------------------------------------------------------------------------------------------------
#     IRA LONG RUN AND SHORT RUN MARGINAL EMISSIONS RATES (LRMER, SRMER) FROM CAMBIUM 2022 RELEASE
#     -------------------------------------------------------------------------------------------------------
#
#
#     Retrieved data for filename: cambium22_allScenarios_annual_gea.xlsx
#     Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\projections\cambium22_allScenarios_annual_gea.xlsx
#
#     Loading dataframe ...
#
#           data_source scenario gea_region  year  cef_gen  aer_co2e_kg_per_MWh  \
# 0    Cambium_2022  MidCase      AZNMc  2024     0.63                279.4
# 1    Cambium_2022  MidCase      AZNMc  2026     0.69                237.5
# 2    Cambium_2022  MidCase      AZNMc  2028     0.80                157.9
# 3    Cambium_2022  MidCase      AZNMc  2030     0.84                133.3
# 4    Cambium_2022  MidCase      AZNMc  2035     0.89                 81.9
# ..            ...      ...        ...   ...      ...                  ...
# 155  Cambium_2022  MidCase      SRVCc  2030     0.75                147.1
# 156  Cambium_2022  MidCase      SRVCc  2035     0.83                 92.1
# 157  Cambium_2022  MidCase      SRVCc  2040     0.86                 75.5
# 158  Cambium_2022  MidCase      SRVCc  2045     0.93                 38.7
# 159  Cambium_2022  MidCase      SRVCc  2050     0.93                 38.9
#
#      lrmer_co2e_kg_per_MWh  srmer_co2e_kg_per_MWh  generation  \
# 0                    326.9                  777.1   185725700
# 1                    193.9                  709.7   192790580
# 2                    130.5                  576.4   193906060
# 3                    103.7                  486.7   193562020
# 4                    149.4                  398.4   210627860
# ..                     ...                    ...         ...
# 155                  211.7                  662.9   391723170
# 156                  211.6                  583.4   459622500
# 157                  188.3                  540.5   481364480
# 158                  142.2                  497.4   501150400
# 159                  113.2                  511.2   501907700
#
#      variable_generation  ...  total_coal  total_natural_gas  total_oil  \
# 0             74605900.0  ...  22849070.0         46188801.1    35759.0
# 1             87517200.0  ...  21009922.0         38928884.4    26155.8
# 2            108173544.0  ...  14483350.0         25156486.8    19751.4
# 3            113367950.0  ...  13433882.0         18404394.4     2684.8
# 4            128952530.0  ...   8231337.5         14217323.4     4222.1
# ..                   ...  ...         ...                ...        ...
# 155          139815250.0  ...  17312904.0         79749385.0     2648.2
# 156          209080400.0  ...   8787109.0         67359566.6     2424.3
# 157          229834830.0  ...   6132569.5         60580299.5     2979.2
# 158          265812640.0  ...   4301606.5         28826117.4      748.2
# 159          271552540.0  ...   1924772.2         34071135.0       17.9
#
#      total_nuclear  total_renewable  fraction_coal  fraction_natural_gas  \
# 0       30865014.0       85518978.5       0.123204              0.249053
# 1       30392044.0      102169009.2       0.109128              0.202201
# 2       29352388.0      124638520.0       0.074791              0.129907
# 3       28571094.0      132901330.4       0.069493              0.095205
# 4       27536908.0      160412983.2       0.039122              0.067572
# ..             ...              ...            ...                   ...
# 155    119012670.0      173052397.5       0.044491              0.204943
# 156    116559336.0      264783518.0       0.019207              0.147237
# 157    115754584.0      296807708.5       0.012795              0.126399
# 158    114458344.0      352150817.0       0.008608              0.057683
# 159    111073256.0      353415175.0       0.003846              0.068076
#
#      fraction_oil  fraction_nuclear  fraction_renewable
# 0    1.928149e-04          0.166426            0.461124
# 1    1.358559e-04          0.157859            0.530676
# 2    1.019951e-04          0.151574            0.643626
# 3    1.388833e-05          0.147797            0.687492
# 4    2.006675e-05          0.130877            0.762409
# ..            ...               ...                 ...
# 155  6.805438e-06          0.305843            0.444716
# 156  5.299110e-06          0.254779            0.578772
# 157  6.216015e-06          0.241519            0.619281
# 158  1.497186e-06          0.229037            0.704671
# 159  3.576535e-08          0.221932            0.706146
#
# [160 rows x 44 columns]
#
#     Creating lookup dictionary for 2024 LRMER and SRMER ...
#     -------------------------------------------------------------------------------------------------------
#
# Fuel sources in df_grid_mix: {'Coal', 'Oil', 'Natural Gas', 'Nuclear', 'Renewable'}
# Fuel sources in df_grid_emis_factors: {'Coal', 'Oil', 'Natural Gas', 'Nuclear', 'Renewables'}
# Retrieved data for filename: bls_cpiu_2005-2023.xlsx
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\inflation_data\bls_cpiu_2005-2023.xlsx
#     year  cpiu_annual
# 0   2005      195.300
# 1   2006      201.600
# 2   2007      207.342
# 3   2008      215.303
# 4   2009      214.537
# 5   2010      218.056
# 6   2011      224.939
# 7   2012      229.594
# 8   2013      232.957
# 9   2014      236.736
# 10  2015      237.017
# 11  2016      240.007
# 12  2017      245.120
# 13  2018      251.107
# 14  2019      255.657
# 15  2020      258.811
# 16  2021      270.970
# 17  2022      292.655
# 18  2023      304.702
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# - States: AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
# - Models: ap2, easiur, inmap
# - Pollutants: nox, pm25, so2
#
# Calculating state-level averages for fallback...
# Added state-level fallbacks for 49 states, 3 models, and 3 pollutants:
# ...
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 148.09
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                               50.48
# 549963                                                 NaN
# 549989                                               57.21
#
#         baseline_cooking_lifetime_damages_health_inmap_h6c fuel_type_heating  \
# bldg_id
# 119                                                 380.50        naturalGas
# 122                                                    NaN           fuelOil
# 150                                                    NaN       electricity
# 153                                                    NaN           fuelOil
# 162                                                    NaN           fuelOil
# ...                                                    ...               ...
# 549882                                                 NaN        naturalGas
# 549915                                                 NaN       electricity
# 549937                                              129.68        naturalGas
# 549963                                                 NaN        naturalGas
# 549989                                              146.99           fuelOil
#
#         fuel_type_waterHeating fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 119                 naturalGas              naturalGas         naturalGas
# 122                    fuelOil             electricity        electricity
# 150                electricity             electricity        electricity
# 153                    fuelOil                     NaN        electricity
# 162                 naturalGas             electricity        electricity
# ...                        ...                     ...                ...
# 549882              naturalGas             electricity        electricity
# 549915             electricity             electricity        electricity
# 549937              naturalGas              naturalGas         naturalGas
# 549963              naturalGas             electricity        electricity
# 549989                 fuelOil             electricity            propane
#
#          baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                  9692.04
# 122                                 56634.48
# 150                                 48835.85
# 153                                 52691.10
# 162                                 69001.23
# ...                                      ...
# 549882                                   NaN
# 549915                              52898.91
# 549937                               8456.00
# 549963                              17473.34
# 549989                              22285.90
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                        351.02
# 122                                        619.28
# 150                                        718.64
# 153                                           NaN
# 162                                       2222.41
# ...                                           ...
# 549882                                     997.02
# 549915                                    1736.07
# 549937                                     982.27
# 549963                                     898.31
# 549989                                     898.31
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 126 columns]
#
# df_baseline_fuel_costs: DataFrame containing the baseline scenario data with fuel costs
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  baseline_2030_cooking_fuel_cost  \
# bldg_id                            ...
# 119                          True  ...                            38.66
# 122                          True  ...                              NaN
# 150                          True  ...                              NaN
# 153                         False  ...                              NaN
# 162                          True  ...                              NaN
# ...                           ...  ...                              ...
# 549882                       True  ...                              NaN
# 549915                       True  ...                              NaN
# 549937                       True  ...                            52.58
# 549963                       True  ...                              NaN
# 549989                       True  ...                           108.64
#
#          baseline_2031_cooking_fuel_cost  baseline_2032_cooking_fuel_cost  \
# bldg_id
# 119                                38.81                            38.64
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             52.79                            52.56
# 549963                               NaN                              NaN
# 549989                            109.76                           111.26
#
#          baseline_2033_cooking_fuel_cost  baseline_2034_cooking_fuel_cost  \
# bldg_id
# 119                                39.10                            39.11
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.19                            53.20
# 549963                               NaN                              NaN
# 549989                            112.94                           114.21
#
#          baseline_2035_cooking_fuel_cost  baseline_2036_cooking_fuel_cost  \
# bldg_id
# 119                                39.02                            38.84
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.07                            52.84
# 549963                               NaN                              NaN
# 549989                            115.40                           116.58
#
#          baseline_2037_cooking_fuel_cost  baseline_2038_cooking_fuel_cost  \
# bldg_id
# 119                                39.25                            39.49
# 122                                  NaN                              NaN
# 150                                  NaN                              NaN
# 153                                  NaN                              NaN
# 162                                  NaN                              NaN
# ...                                  ...                              ...
# 549882                               NaN                              NaN
# 549915                               NaN                              NaN
# 549937                             53.38                            53.71
# 549963                               NaN                              NaN
# 549989                            117.97                           119.31
#
#          baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                   589.84
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                802.29
# 549963                                   NaN
# 549989                               1691.55
#
# [15651 rows x 70 columns]
#
#
# The code took 0 minutes and 44 seconds to execute.
# Baseline Scenario - Model Run Complete

# %% [markdown]
# # LOAD EUSS DATA: Annual Energy Consumption and Metadata
# ## MEASURE PACKAGE 7 (MP7): Data for Electric Resistance Cooking

# %%
print(f"""
====================================================================================================================================================================
We assume the use of Electric Resistance (MP7) rather than Induction (MP8-10).
Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
====================================================================================================================================================================
""")
# from cmu_tare_model.constants import ALLOWED_HOUSING_TYPES

# Measure Package 7
menu_mp = 7
input_mp = 'upgrade07'

filename = "upgrade07_metadata_and_annual_results.csv"
relative_path = os.path.join("cmu_tare_model", "data", "euss_data", "resstock_amy2018_release_1.1", "resstock_amy2018_release_1.1_processed_data", filename)

file_path = os.path.join(PROJECT_ROOT, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

# Fix DtypeWarning error in columns 'in.neighbors' and 'in.geometry_stories_low_rise'
columns_to_string = {11: str, 61: str, 121: str, 103: str, 128: str, 129: str}
df_euss_am_mp7 = pd.read_csv(file_path, dtype=columns_to_string, index_col="bldg_id") # UPDATE: Set index to 'bldg_id' (unique identifier)
print(f"DATAFRAME SIZE before applying any filters: {df_euss_am_mp7.shape}")


# Filter for occupied homes
occupancy_filter = df_euss_am_mp7['in.vacancy_status'] == 'Occupied'
df_euss_am_mp7 = df_euss_am_mp7.loc[occupancy_filter]
print(f"DATAFRAME SIZE after filtering for 'Occupied' homes: {df_euss_am_mp7.shape}")

# Filter for allowed housing types
house_type_filter = df_euss_am_mp7['in.geometry_building_type_recs'].isin(ALLOWED_HOUSING_TYPES)
df_euss_am_mp7 = df_euss_am_mp7.loc[house_type_filter]
print(f"Allowed housing types: {ALLOWED_HOUSING_TYPES}")
print(f"DATAFRAME SIZE after filtering for allowed housing types: {df_euss_am_mp7.shape}")

# National Level 
if menu_state == 'N':
    print("You chose to analyze all of the United States.")
    input_state = 'National'

# Filter down to state or city
else:
    print(f"You chose to filter for: {input_state}")
    state_filter = df_euss_am_mp7['in.state'].eq(input_state)
    df_euss_am_mp7 = df_euss_am_mp7.loc[state_filter]

    # Filter for the entire selected state
    if menu_city == 'N':
        print(f"You chose to analyze all of state: {input_state}")
        
    # Filter to a city within the selected state
    else:
        print(f"You chose to filter for: {input_state}, {input_cityFilter}")
        city_filter = df_euss_am_mp7['in.city'].eq(f"{input_state}, {input_cityFilter}")
        df_euss_am_mp7 = df_euss_am_mp7.loc[city_filter]

# Display the filtered dataframe
print(f"DATAFRAME SIZE after applying geographic filter: {df_euss_am_mp7.shape}")
print(df_euss_am_mp7)
# Out:
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (mp9).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 346)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            7  242.131013           True   2152.0
# 122            7  242.131013           True   2176.0
# 150            7  242.131013          False   1690.0
# 153            7  242.131013           True   2176.0
# 162            7  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         7  242.131013           True   1202.0
# 549915         7  242.131013          False   2176.0
# 549937         7  242.131013           True    885.0
# 549963         7  242.131013           True   1690.0
# 549989         7  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                               0.000000
# 122                                               0.000000
# 150                                               0.000000
# 153                                               0.000000
# 162                                               0.000000
# ...                                                    ...
# 549882                                            0.000000
# 549915                                            0.000000
# 549937                                            0.000000
# 549963                                            0.000000
# 549989                                          223.856453
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            4367.397352
# 122                                           10479.768179
# 150                                               0.000000
# 153                                           11048.097647
# 162                                           12947.903971
# ...                                                    ...
# 549882                                         5212.871757
# 549915                                            0.000000
# 549937                                         4636.242910
# 549963                                         4903.857419
# 549989                                         4686.866540
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2552.828291
# 122                                            6954.371623
# 150                                               0.000000
# 153                                            6200.439415
# 162                                            8666.012863
# ...                                                    ...
# 549882                                         3310.560695
# 549915                                            0.000000
# 549937                                         1673.632015
# 549963                                          609.743358
# 549989                                         2436.617472
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 119                                            2985.641141
# 122                                            7797.415226
# 150                                               0.000000
# 153                                            7363.122758
# 162                                            9676.629818
# ...                                                    ...
# 549882                                         3739.637305
# 549915                                            0.000000
# 549937                                         2257.364571
# 549963                                         1488.137683
# 549989                                         2959.741017
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 119                                            2356.289439
# 122                                            6648.492515
# 150                                               0.000000
# 153                                            5775.168899
# 162                                            8324.377523
# ...                                                    ...
# 549882                                         3185.908976
# 549915                                            0.000000
# 549937                                         1154.203887
# 549963                                          -84.117798
# 549989                                         2177.081897
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 119      Electric, 100% Usage  Electric, 100% Usage
# 122                       NaN                   NaN
# 150                       NaN                   NaN
# 153                       NaN                   NaN
# 162                       NaN                   NaN
# ...                       ...                   ...
# 549882                    NaN                   NaN
# 549915                    NaN                   NaN
# 549937   Electric, 120% Usage  Electric, 120% Usage
# 549963                    NaN                   NaN
# 549989                    NaN  Electric, 100% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 122                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 150                                 NaN                                NaN
# 153                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 162                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# ...                                 ...                                ...
# 549882                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
# 549915                              NaN                                NaN
# 549937                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549963                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549989                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150                                       NaN
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915                                    NaN
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 346 columns]

# %% [markdown]
# ## MEASURE PACKAGE 9 (MP9): Metadata, Space Heating, Water Heating, and Clothes Drying

# %%
# Print debugging information
print_debug = False

if print_debug:
    from cmu_tare_model.utils.create_sample_df import create_sample_df

# %%
# Measure Package 9
menu_mp = 9
input_mp = 'upgrade09'
scenario_name = 'Moderate-BAU'
cost_scenario = 'BAU Costs'
grid_scenario = 'Current Electricity Grid'

print(f"""
====================================================================================================================================================================
MODEL SCENARIO
====================================================================================================================================================================
Scenario {scenario_name}:
Moderate Retrofit: Measure Package {menu_mp}
{cost_scenario}
{grid_scenario}
====================================================================================================================================================================
""")

filename = "upgrade09_metadata_and_annual_results.csv"
relative_path = os.path.join("cmu_tare_model", "data", "euss_data", "resstock_amy2018_release_1.1", "resstock_amy2018_release_1.1_processed_data", filename)
file_path = os.path.join(PROJECT_ROOT, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

# Fix DtypeWarning error in columns 'in.neighbors' and 'in.geometry_stories_low_rise'
columns_to_string = {11: str, 61: str, 121: str, 103: str, 128: str, 129: str}
df_euss_am_mp9 = pd.read_csv(file_path, dtype=columns_to_string, index_col="bldg_id") # UPDATE: Set index to 'bldg_id' (unique identifier)
print(f"DATAFRAME SIZE before applying any filters: {df_euss_am_mp9.shape}")

# Filter for occupied homes
occupancy_filter = df_euss_am_mp9['in.vacancy_status'] == 'Occupied'
df_euss_am_mp9 = df_euss_am_mp9.loc[occupancy_filter]
print(f"DATAFRAME SIZE after filtering for 'Occupied' homes: {df_euss_am_mp9.shape}")

# Filter for allowed housing types
house_type_filter = df_euss_am_mp9['in.geometry_building_type_recs'].isin(ALLOWED_HOUSING_TYPES)
df_euss_am_mp9 = df_euss_am_mp9.loc[house_type_filter]
print(f"Allowed housing types: {ALLOWED_HOUSING_TYPES}")
print(f"DATAFRAME SIZE after filtering for allowed housing types: {df_euss_am_mp9.shape}")

# National Level 
if menu_state == 'N':
    print("You chose to analyze all of the United States.")
    input_state = 'National'

# Filter down to state or city
else:
    print(f"You chose to filter for: {input_state}")
    state_filter = df_euss_am_mp9['in.state'].eq(input_state)
    df_euss_am_mp9 = df_euss_am_mp9.loc[state_filter]

    # Filter for the entire selected state
    if menu_city == 'N':
        print(f"You chose to analyze all of state: {input_state}")
        
    # Filter to a city within the selected state
    else:
        print(f"You chose to filter for: {input_state}, {input_cityFilter}")
        city_filter = df_euss_am_mp9['in.city'].eq(f"{input_state}, {input_cityFilter}")
        df_euss_am_mp9 = df_euss_am_mp9.loc[city_filter]

# Display the filtered dataframe
# Display the filtered dataframe
print(f"DATAFRAME SIZE after applying geographic filter: {df_euss_am_mp9.shape}")
print(df_euss_am_mp9)
# Out:
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Moderate-BAU:
# Moderate Retrofit: Measure Package 9
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade09_metadata_and_annual_results.csv
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\resstock_amy2018_release_1.1_processed_data\upgrade09_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 351)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 351)
# Allowed housing types: ['Single-Family Attached', 'Single-Family Detached']
# DATAFRAME SIZE after filtering for allowed housing types: (331531, 351)
# You chose to filter for: PA
# You chose to analyze all of state: PA
# DATAFRAME SIZE after applying geographic filter: (15651, 351)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 119            9  242.131013           True   2152.0
# 122            9  242.131013           True   2176.0
# 150            9  242.131013           True   1690.0
# 153            9  242.131013           True   2176.0
# 162            9  242.131013           True   2663.0
# ...          ...         ...            ...      ...
# 549882         9  242.131013           True   1202.0
# 549915         9  242.131013           True   2176.0
# 549937         9  242.131013           True    885.0
# 549963         9  242.131013           True   1690.0
# 549989         9  242.131013           True   1220.0
#
#                                             in.ahs_region  \
# bldg_id
# 119      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 122      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 150                              Non-CBSA Middle Atlantic
# 153      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 162      CBSA Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# ...                                                   ...
# 549882                           Non-CBSA Middle Atlantic
# 549915                           Non-CBSA Middle Atlantic
# 549937                           Non-CBSA Middle Atlantic
# 549963                           Non-CBSA Middle Atlantic
# 549989                           Non-CBSA Middle Atlantic
#
#         in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 119                                   4A
# 122                                   4A
# 150                                   5A
# 153                                   4A
# 162                                   4A
# ...                                  ...
# 549882                                5A
# 549915                                5A
# 549937                                5A
# 549963                                5A
# 549989                                5A
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 119                                             4A                      Hour1
# 122                                             4A                     Hour18
# 150                                             5A                      Hour2
# 153                                             4A                      Hour6
# 162                                             4A                      Hour8
# ...                                            ...                        ...
# 549882                                          5A                      Hour5
# 549915                                          5A                      Hour0
# 549937                                          5A                     Hour20
# 549963                                          5A                     Hour13
# 549989                                          5A                     Hour22
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 119                4                      Mixed-Humid  ...
# 122                4                      Mixed-Humid  ...
# 150                4                             Cold  ...
# 153                3                      Mixed-Humid  ...
# 162                5                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 549882             2                             Cold  ...
# 549915             5                             Cold  ...
# 549937             4                             Cold  ...
# 549963             3                             Cold  ...
# 549989             3                             Cold  ...
#
#                                      upgrade.clothes_dryer  \
# bldg_id
# 119      Electric, Premium, Heat Pump, Ventless, 100% U...
# 122      Electric, Premium, Heat Pump, Ventless, 100% U...
# 150      Electric, Premium, Heat Pump, Ventless, 80% Usage
# 153                                                    NaN
# 162      Electric, Premium, Heat Pump, Ventless, 80% Usage
# ...                                                    ...
# 549882   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549915   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549937   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549963   Electric, Premium, Heat Pump, Ventless, 100% U...
# 549989   Electric, Premium, Heat Pump, Ventless, 100% U...
#
#                    upgrade.cooking_range     upgrade.ducts  \
# bldg_id
# 119      Electric, Induction, 100% Usage               NaN
# 122      Electric, Induction, 100% Usage  10% Leakage, R-8
# 150       Electric, Induction, 80% Usage               NaN
# 153      Electric, Induction, 120% Usage  10% Leakage, R-8
# 162       Electric, Induction, 80% Usage  10% Leakage, R-8
# ...                                  ...               ...
# 549882   Electric, Induction, 120% Usage               NaN
# 549915   Electric, Induction, 100% Usage  10% Leakage, R-8
# 549937   Electric, Induction, 120% Usage               NaN
# 549963   Electric, Induction, 100% Usage               NaN
# 549989   Electric, Induction, 100% Usage               NaN
#
#         upgrade.hvac_cooling_efficiency     upgrade.hvac_heating_efficiency  \
# bldg_id
# 119                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 122                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 150                           Heat Pump  MSHP, SEER 29.3, 14 HSPF, Max Load
# 153                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 162                           Heat Pump              MSHP, SEER 24, 13 HSPF
# ...                                 ...                                 ...
# 549882                        Heat Pump  MSHP, SEER 29.3, 14 HSPF, Max Load
# 549915                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 549937                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 549963                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 549989                        Heat Pump              MSHP, SEER 24, 13 HSPF
#
#         upgrade.hvac_heating_type upgrade.infiltration_reduction  \
# bldg_id
# 119              Ducted Heat Pump                            NaN
# 122              Ducted Heat Pump                            30%
# 150                           NaN                            30%
# 153              Ducted Heat Pump                            30%
# 162              Ducted Heat Pump                            30%
# ...                           ...                            ...
# 549882                        NaN                            30%
# 549915           Ducted Heat Pump                            30%
# 549937           Ducted Heat Pump                            30%
# 549963           Ducted Heat Pump                            NaN
# 549989           Ducted Heat Pump                            NaN
#
#         upgrade.insulation_ceiling upgrade.insulation_wall  \
# bldg_id
# 119                           R-60                     NaN
# 122                           R-60         Wood Stud, R-13
# 150                           R-60         Wood Stud, R-13
# 153                           R-60                     NaN
# 162                           R-60         Wood Stud, R-13
# ...                            ...                     ...
# 549882                        R-60                     NaN
# 549915                        R-60                     NaN
# 549937                         NaN         Wood Stud, R-13
# 549963                         NaN                     NaN
# 549989                        R-60         Wood Stud, R-13
#
#               upgrade.water_heater_efficiency
# bldg_id
# 119      Electric Heat Pump, 66 gal, 3.35 UEF
# 122      Electric Heat Pump, 66 gal, 3.35 UEF
# 150      Electric Heat Pump, 66 gal, 3.35 UEF
# 153      Electric Heat Pump, 50 gal, 3.45 UEF
# 162      Electric Heat Pump, 80 gal, 3.45 UEF
# ...                                       ...
# 549882   Electric Heat Pump, 50 gal, 3.45 UEF
# 549915   Electric Heat Pump, 80 gal, 3.45 UEF
# 549937   Electric Heat Pump, 66 gal, 3.35 UEF
# 549963   Electric Heat Pump, 50 gal, 3.45 UEF
# 549989   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [15651 rows x 351 columns]

# %% [markdown]
# # Project Future Energy Consumption

# %%
from cmu_tare_model.energy_consumption_and_metadata.process_euss_data import df_enduse_compare

print(F"""
====================================================================================================================================================================
LOAD EUSS DATA FOR MEASURE PACKAGE {menu_mp} (MP{menu_mp})
====================================================================================================================================================================

RESULTING DATAFRAME:
""")

# df_enduse_compare(df_mp, category, df_baseline):
df_euss_am_mp9_home = df_enduse_compare(
    df_mp = df_euss_am_mp9,
    input_mp=input_mp,
    menu_mp=menu_mp,
    df_baseline = df_euss_am_baseline_home,
    df_cooking_range=df_euss_am_mp7,
    )
# Out:
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 9 (MP9)
# ====================================================================================================================================================================
#
# RESULTING DATAFRAME:
#
#
# Applying combined validation (data quality + retrofit status):
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
#   mp9_heating_consumption: Masked 3385 values
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
#   mp9_waterHeating_consumption: Masked 652 values
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
#   mp9_clothesDrying_consumption: Masked 908 values
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#   mp9_cooking_consumption: Masked 7784 values

# %%
if print_debug:
    # Create a sample dataframe for the heating category
    df_sample_heating = create_sample_df(
        df=df_euss_am_mp9_home,
        include_groups=['base_equipment'],
        categories=['heating'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_heating', 'valid_fuel_heating', 'valid_tech_heating', 'include_heating', 'heating_consumption']
    )
    print(df_sample_heating)

    # Create a sample dataframe for the waterHeating category
    df_sample_waterHeating = create_sample_df(
        df=df_euss_am_mp9_home,
        include_groups=['base_equipment'],
        categories=['waterHeating'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_waterHeating', 'valid_fuel_waterHeating', 'valid_tech_waterHeating', 'include_waterHeating', 'waterHeating_consumption']
    )
    print(df_sample_waterHeating)

    # Create a sample dataframe for the clothesDrying category
    df_sample_clothesDrying = create_sample_df(
        df=df_euss_am_mp9_home,
        include_groups=['base_equipment'],
        categories=['clothesDrying'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_clothesDrying', 'valid_fuel_clothesDrying', 'include_clothesDrying', 'clothesDrying_consumption']
    )
    print(df_sample_clothesDrying)

    # Create a sample dataframe for the cooking category
    df_sample_cooking = create_sample_df(
        df=df_euss_am_mp9_home,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', 'cooking_consumption']
    )
    print(df_sample_cooking)

# %% [markdown]
# # PUBLIC IMPACTS: Climate and Health Damages
# ## Scenarios: No IRA and IRA-Reference

# %%
from cmu_tare_model.public_impact.calculate_lifetime_climate_impacts_sensitivity import calculate_lifetime_climate_impacts
from cmu_tare_model.public_impact.calculate_lifetime_health_impacts_sensitivity import calculate_lifetime_health_impacts

print(f"""
====================================================================================================================================================================
PUBLIC IMPACTS: DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
====================================================================================================================================================================

""")

# Make copies from scenario consumption to keep df smaller
print("\n", "Creating dataframe to store marginal damages calculations ...")
# Climate damages: No IRA and IRA-Reference
df_mp9_noIRA_damages_climate = df_euss_am_mp9_home.copy()
df_mp9_IRA_damages_climate = df_euss_am_mp9_home.copy()

# Health damages: No IRA and IRA-Reference
df_mp9_noIRA_damages_health = df_euss_am_mp9_home.copy()
df_mp9_IRA_damages_health = df_euss_am_mp9_home.copy()
# Out:
# ====================================================================================================================================================================
# PUBLIC IMPACTS: DAMAGES FROM CLIMATE AND HEALTH-RELATED EMISSIONS
# ====================================================================================================================================================================
#
#
#
#  Creating dataframe to store marginal damages calculations ...

# %%
print("""
==================== SCENARIO: No Inflation Reduction Act ==========
""")
df_euss_am_mp9_home, df_mp9_noIRA_damages_climate = calculate_lifetime_climate_impacts(
    df=df_euss_am_mp9_home,
    menu_mp=menu_mp, 
    policy_scenario='No Inflation Reduction Act', 
    df_baseline_damages=df_baseline_damages_climate,
    verbose=False  # Add this parameter
    )

df_euss_am_mp9_home, df_mp9_noIRA_damages_health = calculate_lifetime_health_impacts(
    df=df_euss_am_mp9_home,
    menu_mp=menu_mp, 
    policy_scenario='No Inflation Reduction Act', 
    df_baseline_damages=df_baseline_damages_health,
    debug=False,
    verbose=False  # Add this parameter
    )


print("""
==================== SCENARIO: Inflation Reduction Act (AEO2023 Reference Case) ==========
""")
df_euss_am_mp9_home, df_mp9_IRA_damages_climate = calculate_lifetime_climate_impacts(
    df=df_euss_am_mp9_home,
    menu_mp=menu_mp, 
    policy_scenario='AEO2023 Reference Case', 
    df_baseline_damages=df_baseline_damages_climate,
    verbose=False  # Add this parameter
    )


df_euss_am_mp9_home, df_mp9_IRA_damages_health = calculate_lifetime_health_impacts(
    df=df_euss_am_mp9_home,
    menu_mp=menu_mp, 
    policy_scenario='AEO2023 Reference Case', 
    df_baseline_damages=df_baseline_damages_health,
    debug=False,
    verbose=False  # Add this parameter
    )


print(f"""  
====================================================================================================================================================================
Post-Retrofit (mp9) Marginal Damages: WHOLE-HOME
Scenario: No Inflation Reduction Act and AEO2023 Reference Case
====================================================================================================================================================================
calculate_emissions_damages.py file contains the definition for the calculate_marginal_damages function.
Additional information on emissions and damage factor lookups can be found in the calculate_emissions_damages.py file as well. 
      
CLIMATE DAMAGES: No IRA and IRA-Reference
--------------------------------------------------------
Climate Damages (No IRA): df_mp9_noIRA_damages_climate
{df_mp9_noIRA_damages_climate}

Climate Damages (IRA): df_mp9_IRA_damages_climate
{df_mp9_IRA_damages_climate}

HEALTH DAMAGES: No IRA and IRA-Reference
--------------------------------------------------------
Health Damages (No IRA): df_mp9_noIRA_damages_health
{df_mp9_noIRA_damages_health}

Health Damages (IRA): df_mp9_IRA_damages_health
{df_mp9_IRA_damages_health}

SUMMARY DATAFRAME FOR mp9: df_euss_am_mp9_home
{df_euss_am_mp9_home}
====================================================================================================================================================================
""")
# Out:
# ==================== SCENARIO: No Inflation Reduction Act ==========
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
#
# ==================== SCENARIO: Inflation Reduction Act (AEO2023 Reference Case) ==========
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
#
# ====================================================================================================================================================================
# Post-Retrofit (mp9) Marginal Damages: WHOLE-HOME
# Scenario: No Inflation Reduction Act and AEO2023 Reference Case
# ====================================================================================================================================================================
# calculate_emissions_damages.py file contains the definition for the calculate_marginal_damages function.
# Additional information on emissions and damage factor lookups can be found in the calculate_emissions_damages.py file as well.
#
# CLIMATE DAMAGES: No IRA and IRA-Reference
# --------------------------------------------------------
# Climate Damages (No IRA): df_mp9_noIRA_damages_climate
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          preIRA_mp9_cooking_avoided_damages_climate_lrmer_upper  \
# bldg_id
# 119                                                 166.95
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              120.55
# 549963                                                 NaN
# 549989                                              380.99
#
#          preIRA_mp9_cooking_avoided_mt_co2e_lrmer  \
# bldg_id
# 119                                          0.37
# 122                                           NaN
# 150                                           NaN
# 153                                           NaN
# 162                                           NaN
# ...                                           ...
# 549882                                        NaN
# 549915                                        NaN
# 549937                                       0.27
# 549963                                        NaN
# 549989                                       0.90
#
#          preIRA_mp9_cooking_lifetime_mt_co2e_srmer  \
# bldg_id
# 119                                           5.98
# 122                                            NaN
# 150                                            NaN
# 153                                            NaN
# 162                                            NaN
# ...                                            ...
# 549882                                         NaN
# 549915                                         NaN
# 549937                                        8.93
# 549963                                         NaN
# 549989                                        5.11
#
#          preIRA_mp9_cooking_lifetime_damages_climate_srmer_lower  \
# bldg_id
# 119                                                 440.52
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              658.13
# 549963                                                 NaN
# 549989                                              376.58
#
#          preIRA_mp9_cooking_avoided_damages_climate_srmer_lower  \
# bldg_id
# 119                                                -168.60
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -284.18
# 549963                                                 NaN
# 549989                                             -101.83
#
#          preIRA_mp9_cooking_lifetime_damages_climate_srmer_central  \
# bldg_id
# 119                                                1565.05
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             2338.49
# 549963                                                 NaN
# 549989                                             1337.88
#
#          preIRA_mp9_cooking_avoided_damages_climate_srmer_central  \
# bldg_id
# 119                                                -599.59
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1010.75
# 549963                                                 NaN
# 549989                                             -362.41
#
#          preIRA_mp9_cooking_lifetime_damages_climate_srmer_upper  \
# bldg_id
# 119                                                2485.36
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             3713.87
# 549963                                                 NaN
# 549989                                             2124.61
#
#          preIRA_mp9_cooking_avoided_damages_climate_srmer_upper  \
# bldg_id
# 119                                                -952.69
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1606.04
# 549963                                                 NaN
# 549989                                             -576.04
#
#          preIRA_mp9_cooking_avoided_mt_co2e_srmer
# bldg_id
# 119                                         -2.30
# 122                                           NaN
# 150                                           NaN
# 153                                           NaN
# 162                                           NaN
# ...                                           ...
# 549882                                        NaN
# 549915                                        NaN
# 549937                                      -3.87
# 549963                                        NaN
# 549989                                      -1.39
#
# [15651 rows x 515 columns]
#
# Climate Damages (IRA): df_mp9_IRA_damages_climate
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          iraRef_mp9_cooking_avoided_damages_climate_lrmer_upper  \
# bldg_id
# 119                                                 390.79
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              342.11
# 549963                                                 NaN
# 549989                                              572.34
#
#          iraRef_mp9_cooking_avoided_mt_co2e_lrmer  \
# bldg_id
# 119                                          0.93
# 122                                           NaN
# 150                                           NaN
# 153                                           NaN
# 162                                           NaN
# ...                                           ...
# 549882                                        NaN
# 549915                                        NaN
# 549937                                       0.81
# 549963                                        NaN
# 549989                                       1.37
#
#          iraRef_mp9_cooking_lifetime_mt_co2e_srmer  \
# bldg_id
# 119                                           5.25
# 122                                            NaN
# 150                                            NaN
# 153                                            NaN
# 162                                            NaN
# ...                                            ...
# 549882                                         NaN
# 549915                                         NaN
# 549937                                        7.30
# 549963                                         NaN
# 549989                                        4.49
#
#          iraRef_mp9_cooking_lifetime_damages_climate_srmer_lower  \
# bldg_id
# 119                                                 385.00
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              533.74
# 549963                                                 NaN
# 549989                                              329.12
#
#          iraRef_mp9_cooking_avoided_damages_climate_srmer_lower  \
# bldg_id
# 119                                                -113.08
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -159.79
# 549963                                                 NaN
# 549989                                              -54.37
#
#          iraRef_mp9_cooking_lifetime_damages_climate_srmer_central  \
# bldg_id
# 119                                                1369.47
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             1899.76
# 549963                                                 NaN
# 549989                                             1170.69
#
#          iraRef_mp9_cooking_avoided_damages_climate_srmer_central  \
# bldg_id
# 119                                                -404.01
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -572.02
# 549963                                                 NaN
# 549989                                             -195.22
#
#          iraRef_mp9_cooking_lifetime_damages_climate_srmer_upper  \
# bldg_id
# 119                                                2176.10
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             3019.70
# 549963                                                 NaN
# 549989                                             1860.24
#
#          iraRef_mp9_cooking_avoided_damages_climate_srmer_upper  \
# bldg_id
# 119                                                -643.43
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -911.87
# 549963                                                 NaN
# 549989                                             -311.67
#
#          iraRef_mp9_cooking_avoided_mt_co2e_srmer
# bldg_id
# 119                                         -1.57
# 122                                           NaN
# 150                                           NaN
# 153                                           NaN
# 162                                           NaN
# ...                                           ...
# 549882                                        NaN
# 549915                                        NaN
# 549937                                      -2.24
# 549963                                        NaN
# 549989                                      -0.77
#
# [15651 rows x 515 columns]
#
# HEALTH DAMAGES: No IRA and IRA-Reference
# --------------------------------------------------------
# Health Damages (No IRA): df_mp9_noIRA_damages_health
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          preIRA_mp9_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 437.20
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              199.62
# 549963                                                 NaN
# 549989                                              297.36
#
#          preIRA_mp9_cooking_avoided_damages_health_ap2_h6c  \
# bldg_id
# 119                                                -340.88
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -146.14
# 549963                                                 NaN
# 549989                                             -236.92
#
#          preIRA_mp9_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 197.71
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              103.71
# 549963                                                 NaN
# 549989                                              108.76
#
#          preIRA_mp9_cooking_avoided_damages_health_easiur_acs  \
# bldg_id
# 119                                                 -67.24
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -30.36
# 549963                                                 NaN
# 549989                                              -49.59
#
#          preIRA_mp9_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 507.98
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              266.46
# 549963                                                 NaN
# 549989                                              279.44
#
#          preIRA_mp9_cooking_avoided_damages_health_easiur_h6c  \
# bldg_id
# 119                                                -172.77
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -77.99
# 549963                                                 NaN
# 549989                                             -127.43
#
#          preIRA_mp9_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 128.43
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              104.39
# 549963                                                 NaN
# 549989                                              140.35
#
#          preIRA_mp9_cooking_avoided_damages_health_inmap_acs  \
# bldg_id
# 119                                                  19.66
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -53.91
# 549963                                                 NaN
# 549989                                              -83.14
#
#          preIRA_mp9_cooking_lifetime_damages_health_inmap_h6c  \
# bldg_id
# 119                                                 329.97
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              268.21
# 549963                                                 NaN
# 549989                                              360.59
#
#          preIRA_mp9_cooking_avoided_damages_health_inmap_h6c
# bldg_id
# 119                                                  50.53
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -138.53
# 549963                                                 NaN
# 549989                                             -213.60
#
# [15651 rows x 1379 columns]
#
# Health Damages (IRA): df_mp9_IRA_damages_health
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  \
# bldg_id                            ...
# 119                          True  ...
# 122                          True  ...
# 150                          True  ...
# 153                         False  ...
# 162                          True  ...
# ...                           ...  ...
# 549882                       True  ...
# 549915                       True  ...
# 549937                       True  ...
# 549963                       True  ...
# 549989                       True  ...
#
#          iraRef_mp9_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 437.20
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              199.62
# 549963                                                 NaN
# 549989                                              297.36
#
#          iraRef_mp9_cooking_avoided_damages_health_ap2_h6c  \
# bldg_id
# 119                                                -340.88
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -146.14
# 549963                                                 NaN
# 549989                                             -236.92
#
#          iraRef_mp9_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 197.71
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              103.71
# 549963                                                 NaN
# 549989                                              108.76
#
#          iraRef_mp9_cooking_avoided_damages_health_easiur_acs  \
# bldg_id
# 119                                                 -67.24
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -30.36
# 549963                                                 NaN
# 549989                                              -49.59
#
#          iraRef_mp9_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 507.98
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              266.46
# 549963                                                 NaN
# 549989                                              279.44
#
#          iraRef_mp9_cooking_avoided_damages_health_easiur_h6c  \
# bldg_id
# 119                                                -172.77
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -77.99
# 549963                                                 NaN
# 549989                                             -127.43
#
#          iraRef_mp9_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 128.43
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              104.39
# 549963                                                 NaN
# 549989                                              140.35
#
#          iraRef_mp9_cooking_avoided_damages_health_inmap_acs  \
# bldg_id
# 119                                                  19.66
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -53.91
# 549963                                                 NaN
# 549989                                              -83.14
#
#          iraRef_mp9_cooking_lifetime_damages_health_inmap_h6c  \
# bldg_id
# 119                                                 329.97
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              268.21
# 549963                                                 NaN
# 549989                                              360.59
#
#          iraRef_mp9_cooking_avoided_damages_health_inmap_h6c
# bldg_id
# 119                                                  50.53
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -138.53
# 549963                                                 NaN
# 549989                                             -213.60
#
# [15651 rows x 1379 columns]
#
# SUMMARY DATAFRAME FOR mp9: df_euss_am_mp9_home
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_cooking_lifetime_damages_health_ap2_h6c  \
# bldg_id
# 119                                                 437.20
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              199.62
# 549963                                                 NaN
# 549989                                              297.36
#
#         iraRef_mp9_cooking_avoided_damages_health_ap2_h6c  \
# bldg_id
# 119                                               -340.88
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                            -146.14
# 549963                                                NaN
# 549989                                            -236.92
#
#         iraRef_mp9_cooking_lifetime_damages_health_easiur_acs  \
# bldg_id
# 119                                                 197.71
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              103.71
# 549963                                                 NaN
# 549989                                              108.76
#
#         iraRef_mp9_cooking_avoided_damages_health_easiur_acs  \
# bldg_id
# 119                                                 -67.24
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -30.36
# 549963                                                 NaN
# 549989                                              -49.59
#
#         iraRef_mp9_cooking_lifetime_damages_health_easiur_h6c  \
# bldg_id
# 119                                                 507.98
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              266.46
# 549963                                                 NaN
# 549989                                              279.44
#
#          iraRef_mp9_cooking_avoided_damages_health_easiur_h6c  \
# bldg_id
# 119                                                -172.77
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -77.99
# 549963                                                 NaN
# 549989                                             -127.43
#
#          iraRef_mp9_cooking_lifetime_damages_health_inmap_acs  \
# bldg_id
# 119                                                 128.43
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              104.39
# 549963                                                 NaN
# 549989                                              140.35
#
#         iraRef_mp9_cooking_avoided_damages_health_inmap_acs  \
# bldg_id
# 119                                                  19.66
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              -53.91
# 549963                                                 NaN
# 549989                                              -83.14
#
#         iraRef_mp9_cooking_lifetime_damages_health_inmap_h6c  \
# bldg_id
# 119                                                 329.97
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                              268.21
# 549963                                                 NaN
# 549989                                              360.59
#
#         iraRef_mp9_cooking_avoided_damages_health_inmap_h6c
# bldg_id
# 119                                                  50.53
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                             -138.53
# 549963                                                 NaN
# 549989                                             -213.60
#
# [15651 rows x 381 columns]
# ====================================================================================================================================================================

# %%
if print_debug:
   # Create a sample dataframe for the heating category
    df_sample_heating = create_sample_df(
        df=df_euss_am_mp9_home,
        include_groups=['base_equipment'],
        categories=['heating'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_heating', 'valid_fuel_heating', 'include_heating', 'heating_lifetime_damages']
    )
    print(df_sample_heating)

    # Create a sample dataframe for the waterHeating category
    df_sample_waterHeating = create_sample_df(
        df=df_euss_am_mp9_home,
        include_groups=['base_equipment'],
        categories=['waterHeating'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_waterHeating', 'valid_fuel_waterHeating', 'include_waterHeating', 'waterHeating_lifetime_damages']
    )
    print(df_sample_waterHeating)

    # Create a sample dataframe for the clothesDrying category
    df_sample_clothesDrying = create_sample_df(
        df=df_euss_am_mp9_home,
        include_groups=['base_equipment'],
        categories=['clothesDrying'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_clothesDrying', 'valid_fuel_clothesDrying', 'include_clothesDrying', 'clothesDrying_lifetime_damages']
    )
    print(df_sample_clothesDrying)

    # Create a sample dataframe for the cooking category
    df_sample_cooking = create_sample_df(
        df=df_euss_am_mp9_home,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', 'cooking_lifetime_damages']
    )
    print(df_sample_cooking)

# %%
if print_debug:
    print("""
==================== SUMMARY DATAFRAME WITH LIFETIME DAMAGES ==========
""")
    # Create a sample dataframe for the heating category
    df_main_sample = create_sample_df(
        df=df_euss_am_mp9_home,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', 'cooking_lifetime_damages']
    )
    print(f"""
df_main_sample dataframe is created using df_euss_am_mp9_home:
-----------------------------------------------------------------------------

{df_main_sample}

-----------------------------------------------------------------------------
""")


    print("""
==================== CLIMATE IMPACTS WITH ANNUAL AND LIFETIME ==========
""")

    # Create a sample dataframe for the heating category
    df_detailed_climate_noIRA = create_sample_df(
        df=df_mp9_noIRA_damages_climate,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['preIRA'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', f'cooking_damages_health']
    )
    print(f"""
df_detailed_climate_noIRA dataframe is created using df_mp9_noIRA_damages_climate:
-----------------------------------------------------------------------------
          
{df_detailed_climate_noIRA}

-----------------------------------------------------------------------------
""")

    # Create a sample dataframe for the heating category
    df_detailed_climate_IRA = create_sample_df(
        df=df_mp9_IRA_damages_climate,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', f'cooking_damages_health']
    )
    print(f"""
df_detailed_climate_IRA dataframe is created using df_mp9_IRA_damages_climate:
-----------------------------------------------------------------------------
          
{df_detailed_climate_IRA}

-----------------------------------------------------------------------------
""")

    print("""
==================== HEALTH IMPACTS WITH ANNUAL AND LIFETIME ==========
""")
    # Create a sample dataframe for the heating category
    df_detailed_health_noIRA = create_sample_df(
        df=df_mp9_noIRA_damages_health,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['preIRA'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', f'cooking_damages_health']
    )
    print(f"""
df_detailed_health_noIRA dataframe is created using df_mp9_noIRA_damages_health:
-----------------------------------------------------------------------------
          
{df_detailed_health_noIRA}

-----------------------------------------------------------------------------
""")

    # Create a sample dataframe for the heating category
    df_detailed_health_IRA = create_sample_df(
        df=df_mp9_IRA_damages_health,
        include_groups=['base_equipment'],
        categories=['cooking'],
        scenarios=['iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', f'cooking_damages_health']
    )
    print(f"""
df_detailed_health_IRA dataframe is created using df_mp9_IRA_damages_health:
-----------------------------------------------------------------------------
          
{df_detailed_health_IRA}

-----------------------------------------------------------------------------
""")

# %% [markdown]
# # PRIVATE IMPACTS: FUEL COSTS
# ## Scenarios: No IRA and IRA-Reference

# %%
from cmu_tare_model.private_impact.calculate_lifetime_fuel_costs import calculate_lifetime_fuel_costs

print(f"""
====================================================================================================================================================================
PRIVATE IMPACTS: OVERVIEW
====================================================================================================================================================================
Step 1: Calculate annual operating (fuel) costs
Step 2: Calculate equipment capital costs (For space heating, include ductwork and weatherization (MP9 and MP10))
Step 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)
Step 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)

----------------------------------------------------------------------------------------------------------------------
Step 1: Calculate annual operating (fuel) costs
----------------------------------------------------------------------------------------------------------------------

====================================================================================================================================================================
FUEL COSTS RESULTS: No IRA and IRA-Reference

""")

print("\n", "Creating dataframe to store annual fuel cost calculations ...")
# Annual fuel costs: No IRA and IRA-Reference
df_mp9_fuel_costs_noIRA = df_euss_am_mp9_home.copy()
df_mp9_fuel_costs_IRA = df_euss_am_mp9_home.copy()
# Out:
# ====================================================================================================================================================================
# PRIVATE IMPACTS: OVERVIEW
# ====================================================================================================================================================================
# Step 1: Calculate annual operating (fuel) costs
# Step 2: Calculate equipment capital costs (For space heating, include ductwork and weatherization (MP9 and MP10))
# Step 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)
# Step 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
#
# ----------------------------------------------------------------------------------------------------------------------
# Step 1: Calculate annual operating (fuel) costs
# ----------------------------------------------------------------------------------------------------------------------
#
# ====================================================================================================================================================================
# FUEL COSTS RESULTS: No IRA and IRA-Reference
#
#
#
#  Creating dataframe to store annual fuel cost calculations ...

# %%
print("""
==================== SCENARIO: No Inflation Reduction Act ==========
""")
df_euss_am_mp9_home, df_mp9_noIRA_fuel_costs = calculate_lifetime_fuel_costs(
    df=df_euss_am_mp9_home,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    df_baseline_costs=df_baseline_fuel_costs  # Add this line
    )

print("""
==================== SCENARIO: Inflation Reduction Act (AEO2023 Reference Case) ==========
""")
df_euss_am_mp9_home, df_mp9_IRA_fuel_costs = calculate_lifetime_fuel_costs(
    df=df_euss_am_mp9_home,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    df_baseline_costs=df_baseline_fuel_costs  # Add this line
    )


print(f"""  
====================================================================================================================================================================
Creating Dataframes for Lifetime Fuel Costs ...

FUEL COSTS (No IRA): df_mp9_noIRA_fuel_costs
{df_mp9_noIRA_fuel_costs}

FUEL COSTS (IRA): df_mp9_IRA_fuel_costs
{df_mp9_IRA_fuel_costs}

SUMMARY DATAFRAME FOR mp9: df_euss_am_mp9_home
{df_euss_am_mp9_home}

====================================================================================================================================================================
""")
# Out:
# ==================== SCENARIO: No Inflation Reduction Act ==========
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# Calculating Fuel Costs from 2024 to 2039 for heating
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2036 for waterHeating
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2037 for clothesDrying
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2039 for cooking
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'heating'
# Masking 1 columns for category 'waterHeating'
# Masking 1 columns for category 'clothesDrying'
# Masking 3 columns for category 'cooking'
# WARNING: Replacing 4 existing columns. Function was called on data that already contains results.
# Columns being replaced: ['baseline_heating_lifetime_fuel_cost', 'baseline_waterHeating_lifetime_fuel_cost', 'baseline_clothesDrying_lifetime_fuel_cost', 'baseline_cooking_lifetime_fuel_cost']
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'heating'
# Masking 1 columns for category 'waterHeating'
# Masking 1 columns for category 'clothesDrying'
# Masking 48 columns for category 'cooking'
#
# ==================== SCENARIO: Inflation Reduction Act (AEO2023 Reference Case) ==========
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# Calculating Fuel Costs from 2024 to 2039 for heating
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2036 for waterHeating
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2037 for clothesDrying
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
# Calculating Fuel Costs from 2024 to 2039 for cooking
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'heating'
# Masking 1 columns for category 'waterHeating'
# Masking 1 columns for category 'clothesDrying'
# Masking 3 columns for category 'cooking'
# WARNING: Replacing 4 existing columns. Function was called on data that already contains results.
# Columns being replaced: ['baseline_heating_lifetime_fuel_cost', 'baseline_waterHeating_lifetime_fuel_cost', 'baseline_clothesDrying_lifetime_fuel_cost', 'baseline_cooking_lifetime_fuel_cost']
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'heating'
# Masking 1 columns for category 'waterHeating'
# Masking 1 columns for category 'clothesDrying'
# Masking 48 columns for category 'cooking'
#
# ====================================================================================================================================================================
# Creating Dataframes for Lifetime Fuel Costs ...
#
# FUEL COSTS (No IRA): df_mp9_noIRA_fuel_costs
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  baseline_2035_cooking_fuel_cost  \
# bldg_id                            ...
# 119                          True  ...                            39.02
# 122                          True  ...                              NaN
# 150                          True  ...                              NaN
# 153                         False  ...                              NaN
# 162                          True  ...                              NaN
# ...                           ...  ...                              ...
# 549882                       True  ...                              NaN
# 549915                       True  ...                              NaN
# 549937                       True  ...                            53.07
# 549963                       True  ...                              NaN
# 549989                       True  ...                           115.40
#
#          preIRA_mp9_2036_cooking_fuel_cost  baseline_2036_cooking_fuel_cost  \
# bldg_id
# 119                                  86.54                            38.84
# 122                                    NaN                              NaN
# 150                                    NaN                              NaN
# 153                                    NaN                              NaN
# 162                                    NaN                              NaN
# ...                                    ...                              ...
# 549882                                 NaN                              NaN
# 549915                                 NaN                              NaN
# 549937                              117.60                            52.84
# 549963                                 NaN                              NaN
# 549989                               73.98                           116.58
#
#          preIRA_mp9_2037_cooking_fuel_cost  baseline_2037_cooking_fuel_cost  \
# bldg_id
# 119                                  87.04                            39.25
# 122                                    NaN                              NaN
# 150                                    NaN                              NaN
# 153                                    NaN                              NaN
# 162                                    NaN                              NaN
# ...                                    ...                              ...
# 549882                                 NaN                              NaN
# 549915                                 NaN                              NaN
# 549937                              118.27                            53.38
# 549963                                 NaN                              NaN
# 549989                               74.40                           117.97
#
#          preIRA_mp9_2038_cooking_fuel_cost  baseline_2038_cooking_fuel_cost  \
# bldg_id
# 119                                  87.81                            39.49
# 122                                    NaN                              NaN
# 150                                    NaN                              NaN
# 153                                    NaN                              NaN
# 162                                    NaN                              NaN
# ...                                    ...                              ...
# 549882                                 NaN                              NaN
# 549915                                 NaN                              NaN
# 549937                              119.32                            53.71
# 549963                                 NaN                              NaN
# 549989                               75.06                           119.31
#
#          preIRA_mp9_cooking_lifetime_fuel_cost  \
# bldg_id
# 119                                    1240.31
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                 1685.42
# 549963                                     NaN
# 549989                                 1060.28
#
#          preIRA_mp9_cooking_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                            -650.47
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                         -883.13
# 549963                                             NaN
# 549989                                          631.27
#
#          baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                   589.84
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                802.29
# 549963                                   NaN
# 549989                               1691.55
#
# [15651 rows x 133 columns]
#
# FUEL COSTS (IRA): df_mp9_IRA_fuel_costs
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 119             True             True                  True
# 122            False             True                  True
# 150            False             True                  True
# 153            False             True                  True
# 162            False             True                  True
# ...              ...              ...                   ...
# 549882         False            False                  True
# 549915         False             True                  True
# 549937          True             True                  True
# 549963         False             True                  True
# 549989          True             True                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 119                       True             True                True
# 122                       True            False                True
# 150                       True            False                True
# 153                      False            False                True
# 162                       True            False                True
# ...                        ...              ...                 ...
# 549882                    True            False               False
# 549915                    True            False                True
# 549937                    True             True                True
# 549963                    True            False                True
# 549989                    True             True                True
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 119                         True                True                     True
# 122                         True                True                     True
# 150                         True                True                     True
# 153                         True                True                     True
# 162                         True                True                     True
# ...                          ...                 ...                      ...
# 549882                      True                True                     True
# 549915                      True                True                     True
# 549937                      True                True                     True
# 549963                      True                True                     True
# 549989                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  baseline_2035_cooking_fuel_cost  \
# bldg_id                            ...
# 119                          True  ...                            39.02
# 122                          True  ...                              NaN
# 150                          True  ...                              NaN
# 153                         False  ...                              NaN
# 162                          True  ...                              NaN
# ...                           ...  ...                              ...
# 549882                       True  ...                              NaN
# 549915                       True  ...                              NaN
# 549937                       True  ...                            53.07
# 549963                       True  ...                              NaN
# 549989                       True  ...                           115.40
#
#          iraRef_mp9_2036_cooking_fuel_cost  baseline_2036_cooking_fuel_cost  \
# bldg_id
# 119                                  84.01                            38.84
# 122                                    NaN                              NaN
# 150                                    NaN                              NaN
# 153                                    NaN                              NaN
# 162                                    NaN                              NaN
# ...                                    ...                              ...
# 549882                                 NaN                              NaN
# 549915                                 NaN                              NaN
# 549937                              114.15                            52.84
# 549963                                 NaN                              NaN
# 549989                               71.81                           116.58
#
#          iraRef_mp9_2037_cooking_fuel_cost  baseline_2037_cooking_fuel_cost  \
# bldg_id
# 119                                  84.44                            39.25
# 122                                    NaN                              NaN
# 150                                    NaN                              NaN
# 153                                    NaN                              NaN
# 162                                    NaN                              NaN
# ...                                    ...                              ...
# 549882                                 NaN                              NaN
# 549915                                 NaN                              NaN
# 549937                              114.74                            53.38
# 549963                                 NaN                              NaN
# 549989                               72.18                           117.97
#
#          iraRef_mp9_2038_cooking_fuel_cost  baseline_2038_cooking_fuel_cost  \
# bldg_id
# 119                                  85.44                            39.49
# 122                                    NaN                              NaN
# 150                                    NaN                              NaN
# 153                                    NaN                              NaN
# 162                                    NaN                              NaN
# ...                                    ...                              ...
# 549882                                 NaN                              NaN
# 549915                                 NaN                              NaN
# 549937                              116.10                            53.71
# 549963                                 NaN                              NaN
# 549989                               73.04                           119.31
#
#          iraRef_mp9_cooking_lifetime_fuel_cost  \
# bldg_id
# 119                                    1214.19
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                 1649.94
# 549963                                     NaN
# 549989                                 1037.95
#
#          iraRef_mp9_cooking_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                            -624.35
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                         -847.65
# 549963                                             NaN
# 549989                                          653.60
#
#          baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                   589.84
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                802.29
# 549963                                   NaN
# 549989                               1691.55
#
# [15651 rows x 133 columns]
#
# SUMMARY DATAFRAME FOR mp9: df_euss_am_mp9_home
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 119                                 9692.04
# 122                                56634.48
# 150                                48835.85
# 153                                52691.10
# 162                                69001.23
# ...                                     ...
# 549882                                  NaN
# 549915                             52898.91
# 549937                              8456.00
# 549963                             17473.34
# 549989                             22285.90
#
#         iraRef_mp9_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                        1549.89
# 122                                         803.72
# 150                                         851.18
# 153                                        3478.24
# 162                                        1264.00
# ...                                            ...
# 549882                                     2614.62
# 549915                                     2526.82
# 549937                                     4097.48
# 549963                                     1234.93
# 549989                                     1293.06
#
#         iraRef_mp9_waterHeating_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                                 749.66
# 122                                                2142.78
# 150                                                1913.27
# 153                                                9253.82
# 162                                                 606.10
# ...                                                    ...
# 549882                                             -179.49
# 549915                                             7499.44
# 549937                                             1661.02
# 549963                                              682.32
# 549989                                             3571.19
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 119                                      2299.55
# 122                                      2946.50
# 150                                      2764.45
# 153                                     12732.06
# 162                                      1870.10
# ...                                          ...
# 549882                                   2435.13
# 549915                                  10026.26
# 549937                                   5758.50
# 549963                                   1917.25
# 549989                                   4864.25
#
#         iraRef_mp9_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                          606.34
# 122                                          315.42
# 150                                          365.73
# 153                                             NaN
# 162                                         1130.75
# ...                                             ...
# 549882                                       507.65
# 549915                                       883.71
# 549937                                      1696.46
# 549963                                       457.34
# 549989                                       457.34
#
#          iraRef_mp9_clothesDrying_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                                -255.32
# 122                                                 303.86
# 150                                                 352.91
# 153                                                    NaN
# 162                                                1091.66
# ...                                                    ...
# 549882                                              489.37
# 549915                                              852.36
# 549937                                             -714.19
# 549963                                              440.97
# 549989                                              440.97
#
#          baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 119                                         351.02
# 122                                         619.28
# 150                                         718.64
# 153                                            NaN
# 162                                        2222.41
# ...                                            ...
# 549882                                      997.02
# 549915                                     1736.07
# 549937                                      982.27
# 549963                                      898.31
# 549989                                      898.31
#
#         iraRef_mp9_cooking_lifetime_fuel_cost  \
# bldg_id
# 119                                   1214.19
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                1649.94
# 549963                                    NaN
# 549989                                1037.95
#
#         iraRef_mp9_cooking_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                           -624.35
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                        -847.65
# 549963                                            NaN
# 549989                                         653.60
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 119                                  589.84
# 122                                     NaN
# 150                                     NaN
# 153                                     NaN
# 162                                     NaN
# ...                                     ...
# 549882                                  NaN
# 549915                                  NaN
# 549937                               802.29
# 549963                                  NaN
# 549989                              1691.55
#
# [15651 rows x 397 columns]
#
# ====================================================================================================================================================================

# %%
if print_debug:
    # Create a sample dataframe for the heating category
    df_main_sample = create_sample_df(
        df=df_euss_am_mp9_home,
        include_groups=['base_equipment', 'costs'],
        categories=['cooking'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', 'cooking_lifetime_fuel_cost']
    )
    print(f"""
df_main_sample dataframe is created using df_euss_am_mp9_home:
-----------------------------------------------------------------------------

{df_main_sample}

-----------------------------------------------------------------------------
""")

    # Create a sample dataframe for the heating category
    df_detailed_test = create_sample_df(
        df=df_mp9_IRA_fuel_costs,
        include_groups=['base_equipment', 'costs'],
        categories=['cooking'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', f'_fuel_cost']
    )
    print(f"""
df_detailed_test dataframe is created using df_mp9_IRA_fuel_costs:
-----------------------------------------------------------------------------
          
{df_detailed_test}

-----------------------------------------------------------------------------
""")

    # # Create a sample dataframe for the waterHeating category
    # df_sample_waterHeating = create_sample_df(
    #     df=df_euss_am_mp9_home,
    #     include_groups=['base_equipment', 'costs'],
    #     categories=['waterHeating'],
    #     scenarios=['preIRA', 'iraRef'],
    #     metrics=[],
    #     mp_number=menu_mp,
    #     regex_patterns=['upgrade_waterHeating', 'valid_fuel_waterHeating', 'include_waterHeating', 'waterHeating_lifetime_fuel_cost']
    # )
    # print(df_sample_waterHeating)

    # # Create a sample dataframe for the clothesDrying category
    # df_sample_clothesDrying = create_sample_df(
    #     df=df_euss_am_mp9_home,
    #     include_groups=['base_equipment', 'costs'],
    #     categories=['clothesDrying'],
    #     scenarios=['preIRA', 'iraRef'],
    #     metrics=[],
    #     mp_number=menu_mp,
    #     regex_patterns=['upgrade_clothesDrying', 'valid_fuel_clothesDrying', 'include_clothesDrying', 'clothesDrying_lifetime_fuel_cost']
    # )
    # print(df_sample_clothesDrying)

    # # Create a sample dataframe for the cooking category
    # df_sample_cooking = create_sample_df(
    #     df=df_euss_am_mp9_home,
    #     include_groups=['base_equipment', 'costs'],
    #     categories=['cooking'],
    #     scenarios=['preIRA', 'iraRef'],
    #     metrics=[],
    #     mp_number=menu_mp,
    #     regex_patterns=['upgrade_cooking', 'valid_fuel_cooking', 'include_cooking', 'cooking_lifetime_fuel_cost']
    # )
    # print(df_sample_cooking)

# %% [markdown]
# # PRIVATE IMPACTS: CAPITAL COSTS
# ## Scenarios: No IRA and IRA-Reference

# %%
from cmu_tare_model.utils.inflation_adjustment import *
from cmu_tare_model.private_impact.calculations.calculate_equipment_installation_costs import (
    obtain_heating_system_specs,
    calculate_heating_installation_premium,
    calculate_installation_cost
    )
from cmu_tare_model.private_impact.calculations.calculate_equipment_replacement_costs import (
    calculate_replacement_cost
)
from cmu_tare_model.private_impact.calculations.calculate_enclosure_upgrade_costs import calculate_enclosure_retrofit_upgradeCosts

print(f"""
====================================================================================================================================================================
PRIVATE IMPACTS: NET CAPITAL COSTS AND TOTAL CAPITAL COSTS
====================================================================================================================================================================
Step 1: Calculate annual operating (fuel) costs                                                     [COMPLETED]
Step 2: Calculate equipment capital costs (For space heating, include ductwork)
Step 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)

-----------------------------------------------------------------------------------------------------------------------
Step 4 (MP9 AND MP10 SPACE HEATING ONLY): Calculate Enclosure Upgrade Costs

FOR MODERATE (MP9) AND ADVANCED (MP10) ONLY:
calculate_enclosure_upgrade_costs.py file contains the definition for the calculate_enclosure_upgrade_costs function.

NOTE: Total enclosure upgrade costs were originally calculated using another function that employed a data validation framework.
      However, NaN values for these columns are later set to zero in private impact calculations.
      We decided to keep things simple and avoid side effects by using the original approach.

Documentation for calculate_enclosure_upgrade_costs function:
{calculate_enclosure_retrofit_upgradeCosts.__doc__}

====================================================================================================================================================================
LIFETIME CAPITAL COSTS RESULTS: No IRA and IRA-Reference (Rebates)

""")
# Out:
# ====================================================================================================================================================================
# PRIVATE IMPACTS: NET CAPITAL COSTS AND TOTAL CAPITAL COSTS
# ====================================================================================================================================================================
# Step 1: Calculate annual operating (fuel) costs                                                     [COMPLETED]
# Step 2: Calculate equipment capital costs (For space heating, include ductwork)
# Step 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)
#
# -----------------------------------------------------------------------------------------------------------------------
# Step 4 (MP9 AND MP10 SPACE HEATING ONLY): Calculate Enclosure Upgrade Costs
#
# FOR MODERATE (MP9) AND ADVANCED (MP10) ONLY:
# calculate_enclosure_upgrade_costs.py file contains the definition for the calculate_enclosure_upgrade_costs function.
#
# NOTE: Total enclosure upgrade costs were originally calculated using another function that employed a data validation framework.
#       However, NaN values for these columns are later set to zero in private impact calculations.
#       We decided to keep things simple and avoid side effects by using the original approach.
#
# Documentation for calculate_enclosure_upgrade_costs function:
#
#     Calculate the enclosure retrofit upgrade costs based on given parameters and conditions.
#
#     This function uses a probabilistic approach to sample costs from distributions defined
#     by progressive, reference, and conservative estimates. It applies data validation to
#     ensure only valid homes are included in calculations.
#
#     Args:
#         df: DataFrame containing data for different scenarios
#         menu_mp: Measure package identifier (0 for baseline, 8/9/10 for retrofits)
#         cost_dict: Dictionary with cost information for different technology and efficiency combinations
#         retrofit_col: Column name for the retrofit cost to be calculated
#         params_col: Column name for the parameter to use in the cost calculation
#
#     Returns:
#         Updated DataFrame with calculated retrofit costs
#
#     Raises:
#         ValueError: If missing cost data for certain technology and efficiency combinations
#         RuntimeError: If an unexpected error occurs during calculation
#
#     Notes:
#         This function implements the validation framework:
#         1. Uses initialize_validation_tracking() to determine valid homes
#         2. Creates retrofit-only series with NaN for invalid homes
#         3. Calculates values only for valid homes with identifiable technology
#         4. Applies final verification masking
#
#
# ====================================================================================================================================================================
# LIFETIME CAPITAL COSTS RESULTS: No IRA and IRA-Reference (Rebates)

# %%
# Collect Capital Cost Data for different End-uses
filename = "tare_retrofit_costs_cpi.xlsx"
relative_path = os.path.join("cmu_tare_model", "data", "retrofit_costs", filename)
file_path = os.path.join(PROJECT_ROOT, relative_path)

print(f"Retrieved data for filename: {filename}")
print(f"Located at filepath: {file_path}")
print("\n")

df_heating_retrofit_costs = pd.read_excel(io=file_path, sheet_name='heating_costs')
df_waterHeating_retrofit_costs = pd.read_excel(io=file_path, sheet_name='waterHeating_costs')
df_clothesDrying_retrofit_costs = pd.read_excel(io=file_path, sheet_name='clothesDrying_costs')
df_cooking_retrofit_costs = pd.read_excel(io=file_path, sheet_name='cooking_costs')
df_enclosure_retrofit_costs = pd.read_excel(io=file_path, sheet_name='enclosure_upgrade_costs')
# Out:
# Retrieved data for filename: tare_retrofit_costs_cpi.xlsx
# Located at filepath: c:\users\jorda\desktop\projects\cmu-tare-model\cmu_tare_model\data\retrofit_costs\tare_retrofit_costs_cpi.xlsx

# %% [markdown]
# ### Moderate Retrofit (MP9): High-Efficiency Space Heating (MP8) + Basic Enclosure Upgrade (MP1)

# %% [markdown]
# #### Space Heating Capital Costs

# %%
print("""
========================== Capital Costs: Space Heating ==========================

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
""")

# Columns to update
cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
    'cost_per_kBtuh_progressive', 'cost_per_kBtuh_reference', 'cost_per_kBtuh_conservative',
    'otherCost_progressive', 'otherCost_reference', 'otherCost_conservative'
]

# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_heating_retrofit_costs[column] = round((df_heating_retrofit_costs[column] * df_heating_retrofit_costs['cpi_ratio'] * df_heating_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_heating_equipment_cost = df_heating_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')

# Call the function and obtain equipment specifications
print("Obtaining heating system specs ...")
df_euss_am_mp9_home = obtain_heating_system_specs(df=df_euss_am_mp9_home)

# calculate_installation_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Heat Pump for Space Heating ...")
df_euss_am_mp9_home = calculate_installation_cost(df=df_euss_am_mp9_home,
                                                  cost_dict=dict_heating_equipment_cost,
                                                  menu_mp=menu_mp,
                                                  end_use='heating')

# calculate_replacement_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
df_euss_am_mp9_home = calculate_replacement_cost(df=df_euss_am_mp9_home,
                                                 cost_dict=dict_heating_equipment_cost,
                                                 menu_mp=menu_mp,
                                                 end_use='heating')

# Call the function and calculate installation premium based on existing housing characteristics
# calculate_heating_installation_premium(df, menu_mp, cpi_ratio_2023_2013)
print("Calculating Space Heating Specific Premiums (Ex: Removing Hydronic Boiler) ...")
df_euss_am_mp9_home = calculate_heating_installation_premium(df=df_euss_am_mp9_home,
                                                             menu_mp=menu_mp,
                                                             cpi_ratio_2023_2013=cpi_ratio_2023_2013)

# Display the df
print(df_euss_am_mp9_home)
# Out:
# ========================== Capital Costs: Space Heating ==========================
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
#
# Obtaining heating system specs ...
# Calculating Cost of Retrofit Upgrade: Heat Pump for Space Heating ...
# Starting heating installation cost calculation with validation framework
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for heating installation
# After tech filtering: 12266 homes remain valid for heating installation
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'heating'
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
# Starting heating replacement cost calculation with validation framework
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for heating replacement
# After tech filtering: 12266 homes remain valid for heating replacement
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating Space Heating Specific Premiums (Ex: Removing Hydronic Boiler) ...
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_cooking_lifetime_savings_fuel_cost  \
# bldg_id
# 119                                           -624.35
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                        -847.65
# 549963                                            NaN
# 549989                                         653.60
#
#         baseline_cooking_lifetime_fuel_cost total_heating_load_kBtuh  \
# bldg_id
# 119                                  589.84                    88.57
# 122                                     NaN                    89.04
# 150                                     NaN                    69.93
# 153                                     NaN                    92.00
# 162                                     NaN                    82.58
# ...                                     ...                      ...
# 549882                                  NaN                    99.30
# 549915                                  NaN                    75.51
# 549937                               802.29                    44.92
# 549963                                  NaN                    98.06
# 549989                              1691.55                    32.10
#
#         baseline_AFUE baseline_SEER  baseline_HSPF  ugrade_newInstall_HSPF  \
# bldg_id
# 119              80.0           NaN            NaN                    13.0
# 122              92.5           NaN            NaN                    13.0
# 150             100.0           NaN            NaN                    14.0
# 153              80.0           NaN            NaN                    13.0
# 162              80.0           NaN            NaN                    13.0
# ...               ...           ...            ...                     ...
# 549882           68.0           NaN            NaN                    14.0
# 549915          100.0           NaN            NaN                    13.0
# 549937           92.5           NaN            NaN                    13.0
# 549963           80.0           NaN            NaN                    13.0
# 549989           80.0           NaN            NaN                    13.0
#
#         mp9_heating_installationCost mp9_heating_replacementCost  \
# bldg_id
# 119                         25713.63                     3721.65
# 122                         29655.03                     5816.80
# 150                         16024.07                     6666.18
# 153                         26583.01                     5831.90
# 162                         28813.12                     5783.86
# ...                              ...                         ...
# 549882                           NaN                         NaN
# 549915                      24045.51                     7031.11
# 549937                      17884.98                     3499.03
# 549963                      27722.28                     3770.05
# 549989                      14596.54                     5526.41
#
#         mp9_heating_installation_premium
# bldg_id
# 119                                  0.0
# 122                                  0.0
# 150                                  0.0
# 153                                  0.0
# 162                                  0.0
# ...                                  ...
# 549882                               0.0
# 549915                               0.0
# 549937                               0.0
# 549963                               0.0
# 549989                               0.0
#
# [15651 rows x 405 columns]

# %% [markdown]
# #### Weatherization (MP1: Basic Enclosure Upgrade) Capital Costs

# %%
print(f"""
-------------------------------------------------------------------------------------------------
BASIC ENCLOSURE UPGRADE (MP1)
-------------------------------------------------------------------------------------------------
Measure Package 9 (MP9) contains the Basic Enclosure Upgrade (MP1), with the following upgrades: 
    - Attic Floor Insulation
    - Infiltration Reduction
    - Duct Sealing
    - Drill and Fill Wall Insulation      

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...

""")
# Weatherization Capital Costs
cost_columns = [
    'normalized_cost_progressive', 'normalized_cost_reference', 'normalized_cost_conservative',
]

# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_enclosure_retrofit_costs[column] = round((df_enclosure_retrofit_costs[column] * df_enclosure_retrofit_costs['cpi_ratio'] * df_enclosure_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_enclosure_retrofit_cost = df_enclosure_retrofit_costs.set_index(['technology', 'existing_characteristic']).to_dict(orient='index')

# ATTIC FLOOR INSULATION
df_euss_am_mp9_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp9_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='insulation_atticFloor_upgradeCost',
    params_col='out_params_floor_area_attic_ft_2'
    )

# INFILTRATION REDUCTION
df_euss_am_mp9_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp9_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='infiltration_reduction_upgradeCost',
    params_col='square_footage'
    )

# DUCT SEALING
df_euss_am_mp9_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp9_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='duct_sealing_upgradeCost',
    params_col='out_params_duct_unconditioned_surface_area_ft_2'
    )

# DRILL AND FILL WALL INSULATION
df_euss_am_mp9_home = calculate_enclosure_retrofit_upgradeCosts(
    df=df_euss_am_mp9_home,
    menu_mp=menu_mp,
    cost_dict=dict_enclosure_retrofit_cost,
    retrofit_col='insulation_wall_upgradeCost',
    params_col='out_params_wall_area_above_grade_exterior_ft_2'
    )

# Calculate the total upgrade cost
mp9_total_enclosure_upgradeCost = (
    df_euss_am_mp9_home['insulation_atticFloor_upgradeCost'].fillna(0.0) +
    df_euss_am_mp9_home['infiltration_reduction_upgradeCost'].fillna(0.0) +
    df_euss_am_mp9_home['duct_sealing_upgradeCost'].fillna(0.0) +
    df_euss_am_mp9_home['insulation_wall_upgradeCost'].fillna(0.0)
    )
df_euss_am_mp9_home['mp9_enclosure_upgradeCost'] = round(mp9_total_enclosure_upgradeCost, 2)

print(f"""  
----------------------------------------------------------------------------------------------
DATAFRAME WITH MP9 ENCLOSURE COSTS: df_euss_am_mp9_home
      
{df_euss_am_mp9_home}

====================================================================================================================================================================
""")
# Out:
# -------------------------------------------------------------------------------------------------
# BASIC ENCLOSURE UPGRADE (MP1)
# -------------------------------------------------------------------------------------------------
# Measure Package 9 (MP9) contains the Basic Enclosure Upgrade (MP1), with the following upgrades:
#     - Attic Floor Insulation
#     - Infiltration Reduction
#     - Duct Sealing
#     - Drill and Fill Wall Insulation
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
#
#
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): insulation_atticFloor_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for insulation_atticFloor_upgradeCost
# After tech filtering: 11255 homes remain valid for insulation_atticFloor_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): infiltration_reduction_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for infiltration_reduction_upgradeCost
# After tech filtering: 8553 homes remain valid for infiltration_reduction_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): duct_sealing_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for duct_sealing_upgradeCost
# After tech filtering: 5388 homes remain valid for duct_sealing_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
# Calculating enclosure retrofit upgrade costs with validation framework ('include_heating' flags): insulation_wall_upgradeCost
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
# Found 12266 valid homes out of 15651 for insulation_wall_upgradeCost
# After tech filtering: 2933 homes remain valid for insulation_wall_upgradeCost
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'heating'
#
# ----------------------------------------------------------------------------------------------
# DATAFRAME WITH MP9 ENCLOSURE COSTS: df_euss_am_mp9_home
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... baseline_HSPF  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...           NaN
# 122      In another census Place   Suburban  ...           NaN
# 150      In another census Place      Rural  ...           NaN
# 153        Not in a census Place   Suburban  ...           NaN
# 162        Not in a census Place   Suburban  ...           NaN
# ...                          ...        ...  ...           ...
# 549882     Not in a census Place   Suburban  ...           NaN
# 549915                 Lancaster   Suburban  ...           NaN
# 549937   In another census Place      Rural  ...           NaN
# 549963   In another census Place   Suburban  ...           NaN
# 549989     Not in a census Place      Rural  ...           NaN
#
#         ugrade_newInstall_HSPF mp9_heating_installationCost  \
# bldg_id
# 119                       13.0                     25713.63
# 122                       13.0                     29655.03
# 150                       14.0                     16024.07
# 153                       13.0                     26583.01
# 162                       13.0                     28813.12
# ...                        ...                          ...
# 549882                    14.0                          NaN
# 549915                    13.0                     24045.51
# 549937                    13.0                     17884.98
# 549963                    13.0                     27722.28
# 549989                    13.0                     14596.54
#
#         mp9_heating_replacementCost mp9_heating_installation_premium  \
# bldg_id
# 119                         3721.65                              0.0
# 122                         5816.80                              0.0
# 150                         6666.18                              0.0
# 153                         5831.90                              0.0
# 162                         5783.86                              0.0
# ...                             ...                              ...
# 549882                          NaN                              0.0
# 549915                      7031.11                              0.0
# 549937                      3499.03                              0.0
# 549963                      3770.05                              0.0
# 549989                      5526.41                              0.0
#
#          insulation_atticFloor_upgradeCost  \
# bldg_id
# 119                                4261.08
# 122                                8463.24
# 150                                4976.32
# 153                                7474.84
# 162                                3609.88
# ...                                    ...
# 549882                                 NaN
# 549915                             4049.48
# 549937                                0.00
# 549963                                0.00
# 549989                             1009.06
#
#          infiltration_reduction_upgradeCost duct_sealing_upgradeCost  \
# bldg_id
# 119                                    0.00                     0.00
# 122                                 5361.32                  3350.01
# 150                                 5196.63                     0.00
# 153                                 4112.04                  1300.05
# 162                                 7840.46                  2947.26
# ...                                     ...                      ...
# 549882                                  NaN                      NaN
# 549915                              3161.77                  1859.30
# 549937                              1785.10                     0.00
# 549963                                 0.00                     0.00
# 549989                                 0.00                     0.00
#
#         insulation_wall_upgradeCost mp9_enclosure_upgradeCost
# bldg_id
# 119                            0.00                   4261.08
# 122                         6505.61                  23680.18
# 150                         7891.51                  18064.46
# 153                            0.00                  12886.93
# 162                         8973.58                  23371.18
# ...                             ...                       ...
# 549882                          NaN                      0.00
# 549915                         0.00                   9070.55
# 549937                      3131.43                   4916.53
# 549963                         0.00                      0.00
# 549989                      2763.96                   3773.02
#
# [15651 rows x 410 columns]
#
# ====================================================================================================================================================================

# %%
if print_debug:
    # Create a sample dataframe for the heating category
    df_sample_heating = create_sample_df(
        df=df_euss_am_mp9_home,
        include_groups=['base_equipment'],
        categories=['heating'],
        scenarios=['preIRA', 'iraRef'],
        metrics=[],
        mp_number=menu_mp,
        regex_patterns=['valid_fuel_heating', 'include_heating', 'baseline_AFUE', 'baseline_SEER', 'baseline_HSPF', 
                        'hvac_heating_efficiency', 'upgrade_hvac_', 'upgrade_heating','ugrade_newInstall_HSPF']
    )
    print(df_sample_heating)

# %% [markdown]
# ### Water Heating

# %%
print("""
========================== Capital Costs: Water Heating ==========================

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
""")

cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
    'cost_per_gallon_progressive', 'cost_per_gallon_reference', 'cost_per_gallon_conservative',
]

# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_waterHeating_retrofit_costs[column] = round((df_waterHeating_retrofit_costs[column] * df_waterHeating_retrofit_costs['cpi_ratio'] * df_waterHeating_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_waterHeating_equipment_cost = df_waterHeating_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')
# dict_waterHeating_equipment_cost

# calculate_installation_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Electric Heat Pump Water Heater ...")
df_euss_am_mp9_home = calculate_installation_cost(df=df_euss_am_mp9_home,
                                                  cost_dict=dict_waterHeating_equipment_cost,
                                                  menu_mp=menu_mp,
                                                  end_use='waterHeating')

# calculate_replacement_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
df_euss_am_mp9_home = calculate_replacement_cost(df=df_euss_am_mp9_home,
                                                 cost_dict=dict_waterHeating_equipment_cost,
                                                 menu_mp=menu_mp,
                                                 end_use='waterHeating')

# Display the df
print(df_euss_am_mp9_home)
# Out:
# ========================== Capital Costs: Water Heating ==========================
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
#
# Calculating Cost of Retrofit Upgrade: Electric Heat Pump Water Heater ...
# Starting waterHeating installation cost calculation with validation framework
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
# Found 14999 valid homes out of 15651 for waterHeating installation
# After tech filtering: 14999 homes remain valid for waterHeating installation
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'waterHeating'
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
# Starting waterHeating replacement cost calculation with validation framework
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
# Found 14999 valid homes out of 15651 for waterHeating replacement
# After tech filtering: 14999 homes remain valid for waterHeating replacement
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'waterHeating'
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ... mp9_heating_installationCost  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...                     25713.63
# 122      In another census Place   Suburban  ...                     29655.03
# 150      In another census Place      Rural  ...                     16024.07
# 153        Not in a census Place   Suburban  ...                     26583.01
# 162        Not in a census Place   Suburban  ...                     28813.12
# ...                          ...        ...  ...                          ...
# 549882     Not in a census Place   Suburban  ...                          NaN
# 549915                 Lancaster   Suburban  ...                     24045.51
# 549937   In another census Place      Rural  ...                     17884.98
# 549963   In another census Place   Suburban  ...                     27722.28
# 549989     Not in a census Place      Rural  ...                     14596.54
#
#         mp9_heating_replacementCost mp9_heating_installation_premium  \
# bldg_id
# 119                         3721.65                              0.0
# 122                         5816.80                              0.0
# 150                         6666.18                              0.0
# 153                         5831.90                              0.0
# 162                         5783.86                              0.0
# ...                             ...                              ...
# 549882                          NaN                              0.0
# 549915                      7031.11                              0.0
# 549937                      3499.03                              0.0
# 549963                      3770.05                              0.0
# 549989                      5526.41                              0.0
#
#         insulation_atticFloor_upgradeCost infiltration_reduction_upgradeCost  \
# bldg_id
# 119                               4261.08                               0.00
# 122                               8463.24                            5361.32
# 150                               4976.32                            5196.63
# 153                               7474.84                            4112.04
# 162                               3609.88                            7840.46
# ...                                   ...                                ...
# 549882                                NaN                                NaN
# 549915                            4049.48                            3161.77
# 549937                               0.00                            1785.10
# 549963                               0.00                               0.00
# 549989                            1009.06                               0.00
#
#          duct_sealing_upgradeCost  insulation_wall_upgradeCost  \
# bldg_id
# 119                          0.00                         0.00
# 122                       3350.01                      6505.61
# 150                          0.00                      7891.51
# 153                       1300.05                         0.00
# 162                       2947.26                      8973.58
# ...                           ...                          ...
# 549882                        NaN                          NaN
# 549915                    1859.30                         0.00
# 549937                       0.00                      3131.43
# 549963                       0.00                         0.00
# 549989                       0.00                      2763.96
#
#         mp9_enclosure_upgradeCost mp9_waterHeating_installationCost  \
# bldg_id
# 119                       4261.08                           2748.46
# 122                      23680.18                           2828.60
# 150                      18064.46                           2814.90
# 153                      12886.93                           1895.00
# 162                      23371.18                           2808.56
# ...                           ...                               ...
# 549882                       0.00                           3077.60
# 549915                    9070.55                           4351.96
# 549937                    4916.53                           3185.39
# 549963                       0.00                           3403.82
# 549989                    3773.02                           3498.12
#
#         mp9_waterHeating_replacementCost
# bldg_id
# 119                              1891.48
# 122                              2862.44
# 150                              1073.99
# 153                              2707.56
# 162                              2092.94
# ...                                  ...
# 549882                           1661.24
# 549915                           1138.11
# 549937                           1891.48
# 549963                           1661.24
# 549989                           2707.56
#
# [15651 rows x 412 columns]

# %% [markdown]
# ### Clothes Drying

# %%
print("""
========================== Capital Costs: Clothes Drying ==========================

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ... 
""")

# Columns to update
cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
]
 
# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_clothesDrying_retrofit_costs[column] = round((df_clothesDrying_retrofit_costs[column] * df_clothesDrying_retrofit_costs['cpi_ratio'] * df_clothesDrying_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_clothesDrying_equipment_cost = df_clothesDrying_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')
# dict_clothesDrying_equipment_cost

# calculate_installation_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Ventless Heat Pump Clothes Dryer ...")
df_euss_am_mp9_home = calculate_installation_cost(df=df_euss_am_mp9_home,
                                                  cost_dict=dict_clothesDrying_equipment_cost,
                                                  menu_mp=menu_mp,
                                                  end_use='clothesDrying')


# calculate_replacement_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
df_euss_am_mp9_home = calculate_replacement_cost(df=df_euss_am_mp9_home,
                                                 cost_dict=dict_clothesDrying_equipment_cost,
                                                 menu_mp=menu_mp,
                                                 end_use='clothesDrying')

# Display the df
print(df_euss_am_mp9_home)
# Out:
# ========================== Capital Costs: Clothes Drying ==========================
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
#
# Calculating Cost of Retrofit Upgrade: Ventless Heat Pump Clothes Dryer ...
# Starting clothesDrying installation cost calculation with validation framework
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
# Found 14743 valid homes out of 15651 for clothesDrying installation
# After tech filtering: 14743 homes remain valid for clothesDrying installation
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'clothesDrying'
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
# Starting clothesDrying replacement cost calculation with validation framework
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
# Found 14743 valid homes out of 15651 for clothesDrying replacement
# After tech filtering: 14743 homes remain valid for clothesDrying replacement
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'clothesDrying'
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         mp9_heating_installation_premium insulation_atticFloor_upgradeCost  \
# bldg_id
# 119                                  0.0                           4261.08
# 122                                  0.0                           8463.24
# 150                                  0.0                           4976.32
# 153                                  0.0                           7474.84
# 162                                  0.0                           3609.88
# ...                                  ...                               ...
# 549882                               0.0                               NaN
# 549915                               0.0                           4049.48
# 549937                               0.0                              0.00
# 549963                               0.0                              0.00
# 549989                               0.0                           1009.06
#
#         infiltration_reduction_upgradeCost duct_sealing_upgradeCost  \
# bldg_id
# 119                                   0.00                     0.00
# 122                                5361.32                  3350.01
# 150                                5196.63                     0.00
# 153                                4112.04                  1300.05
# 162                                7840.46                  2947.26
# ...                                    ...                      ...
# 549882                                 NaN                      NaN
# 549915                             3161.77                  1859.30
# 549937                             1785.10                     0.00
# 549963                                0.00                     0.00
# 549989                                0.00                     0.00
#
#         insulation_wall_upgradeCost  mp9_enclosure_upgradeCost  \
# bldg_id
# 119                            0.00                    4261.08
# 122                         6505.61                   23680.18
# 150                         7891.51                   18064.46
# 153                            0.00                   12886.93
# 162                         8973.58                   23371.18
# ...                             ...                        ...
# 549882                          NaN                       0.00
# 549915                         0.00                    9070.55
# 549937                      3131.43                    4916.53
# 549963                         0.00                       0.00
# 549989                      2763.96                    3773.02
#
#          mp9_waterHeating_installationCost mp9_waterHeating_replacementCost  \
# bldg_id
# 119                                2748.46                          1891.48
# 122                                2828.60                          2862.44
# 150                                2814.90                          1073.99
# 153                                1895.00                          2707.56
# 162                                2808.56                          2092.94
# ...                                    ...                              ...
# 549882                             3077.60                          1661.24
# 549915                             4351.96                          1138.11
# 549937                             3185.39                          1891.48
# 549963                             3403.82                          1661.24
# 549989                             3498.12                          2707.56
#
#         mp9_clothesDrying_installationCost mp9_clothesDrying_replacementCost
# bldg_id
# 119                                2464.36                           1307.98
# 122                                2536.94                            994.06
# 150                                1307.93                            994.06
# 153                                    NaN                               NaN
# 162                                2054.01                            994.06
# ...                                    ...                               ...
# 549882                             2557.51                            994.06
# 549915                             1725.33                            994.06
# 549937                             2472.00                           1307.98
# 549963                             2280.70                            994.06
# 549989                             2050.39                            994.06
#
# [15651 rows x 414 columns]

# %% [markdown]
# ### Cooking

# %%
print("""
========================== Capital Costs: Cooking ==========================

Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...      
""")

# Columns to update
cost_columns = [
    'unitCost_progressive', 'unitCost_reference', 'unitCost_conservative',
]
 
# Update each cost column by multiplying with cpi_ratio and cost_multiplier
for column in cost_columns:
    df_cooking_retrofit_costs[column] = round((df_cooking_retrofit_costs[column] * df_cooking_retrofit_costs['cpi_ratio'] * df_cooking_retrofit_costs['cost_multiplier']), 2)

# Creating a dictionary from the DataFrame
dict_cooking_equipment_cost = df_cooking_retrofit_costs.set_index(['technology', 'efficiency']).to_dict(orient='index')
# dict_cooking_equipment_cost

# calculate_installation_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Retrofit Upgrade: Electric Resistance Range ...")
df_euss_am_mp9_home = calculate_installation_cost(df=df_euss_am_mp9_home,
                                                  cost_dict=dict_cooking_equipment_cost,
                                                  menu_mp=menu_mp,
                                                  end_use='cooking')

# calculate_replacement_cost(df, cost_dict, menu_mp, end_use)
print("Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...")
df_euss_am_mp9_home = calculate_replacement_cost(df=df_euss_am_mp9_home,
                                                 cost_dict=dict_cooking_equipment_cost,
                                                 menu_mp=menu_mp,
                                                 end_use='cooking')

# Display the df
print(df_euss_am_mp9_home)
# Out:
# ========================== Capital Costs: Cooking ==========================
#
# Obtaining Capital Cost Data from Retrofit Cost Spreadsheet ...
#
# Calculating Cost of Retrofit Upgrade: Electric Resistance Range ...
# Starting cooking installation cost calculation with validation framework
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
# Found 7867 valid homes out of 15651 for cooking installation
# After tech filtering: 7867 homes remain valid for cooking installation
#
# Verifying masking for all calculated columns:
# Masking 1 columns for category 'cooking'
# Calculating Cost of Replacing Existing Equipment with Similar Model/Efficiency ...
# Starting cooking replacement cost calculation with validation framework
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
# Found 7867 valid homes out of 15651 for cooking replacement
# After tech filtering: 7867 homes remain valid for cooking replacement
#
# Verifying masking for all calculated columns:
# Masking 2 columns for category 'cooking'
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         infiltration_reduction_upgradeCost duct_sealing_upgradeCost  \
# bldg_id
# 119                                   0.00                     0.00
# 122                                5361.32                  3350.01
# 150                                5196.63                     0.00
# 153                                4112.04                  1300.05
# 162                                7840.46                  2947.26
# ...                                    ...                      ...
# 549882                                 NaN                      NaN
# 549915                             3161.77                  1859.30
# 549937                             1785.10                     0.00
# 549963                                0.00                     0.00
# 549989                                0.00                     0.00
#
#         insulation_wall_upgradeCost mp9_enclosure_upgradeCost  \
# bldg_id
# 119                            0.00                   4261.08
# 122                         6505.61                  23680.18
# 150                         7891.51                  18064.46
# 153                            0.00                  12886.93
# 162                         8973.58                  23371.18
# ...                             ...                       ...
# 549882                          NaN                      0.00
# 549915                         0.00                   9070.55
# 549937                      3131.43                   4916.53
# 549963                         0.00                      0.00
# 549989                      2763.96                   3773.02
#
#         mp9_waterHeating_installationCost  mp9_waterHeating_replacementCost  \
# bldg_id
# 119                               2748.46                           1891.48
# 122                               2828.60                           2862.44
# 150                               2814.90                           1073.99
# 153                               1895.00                           2707.56
# 162                               2808.56                           2092.94
# ...                                   ...                               ...
# 549882                            3077.60                           1661.24
# 549915                            4351.96                           1138.11
# 549937                            3185.39                           1891.48
# 549963                            3403.82                           1661.24
# 549989                            3498.12                           2707.56
#
#          mp9_clothesDrying_installationCost mp9_clothesDrying_replacementCost  \
# bldg_id
# 119                                 2464.36                           1307.98
# 122                                 2536.94                            994.06
# 150                                 1307.93                            994.06
# 153                                     NaN                               NaN
# 162                                 2054.01                            994.06
# ...                                     ...                               ...
# 549882                              2557.51                            994.06
# 549915                              1725.33                            994.06
# 549937                              2472.00                           1307.98
# 549963                              2280.70                            994.06
# 549989                              2050.39                            994.06
#
#         mp9_cooking_installationCost mp9_cooking_replacementCost
# bldg_id
# 119                          1358.64                     1072.54
# 122                              NaN                         NaN
# 150                              NaN                         NaN
# 153                              NaN                         NaN
# 162                              NaN                         NaN
# ...                              ...                         ...
# 549882                           NaN                         NaN
# 549915                           NaN                         NaN
# 549937                       2119.37                     1072.54
# 549963                           NaN                         NaN
# 549989                       2088.81                     1072.54
#
# [15651 rows x 416 columns]

# %% [markdown]
#  ## Calculate Rebate Amounts (Applicable to IRA-Reference)

# %%
from cmu_tare_model.private_impact.data_processing.determine_rebate_eligibility_and_amount import calculate_percent_AMI, calculate_rebateIRA
from cmu_tare_model.utils.discounting import prepare_discount_rates

print(f"""
====================================================================================================================================================================
CALCULATE HOUSEHOLD PERCENT AREA MEDIAN INCOME (%AMI) AND REBATE ELIGIBILITY/AMOUNTS
====================================================================================================================================================================

""")

# Determine Percent AMI and Rebate Amounts
# This needs to be done before running the calculate_percent_AMI function
df_euss_am_mp9_home = df_euss_am_mp9_home.copy()
df_euss_am_mp9_home = calculate_percent_AMI(df_results_IRA=df_euss_am_mp9_home)

# New function that prepares discount rates (e.g., variable) for NPV calculations and prints the discount rates used if verbose=True
df_euss_am_mp9_home = prepare_discount_rates(df=df_euss_am_mp9_home,
                                             verbose=False)

print("Calculating rebate amounts for Space Heating ...")
df_euss_am_mp9_home = calculate_rebateIRA(df_results_IRA=df_euss_am_mp9_home,
                                          category="heating",
                                          menu_mp=menu_mp)

print("Calculating rebate amounts for Water Heating ...")
df_euss_am_mp9_home = calculate_rebateIRA(df_results_IRA=df_euss_am_mp9_home,
                                          category="waterHeating",
                                          menu_mp=menu_mp)

print("Calculating rebate amounts for Clothes Drying ...")
df_euss_am_mp9_home = calculate_rebateIRA(df_results_IRA=df_euss_am_mp9_home,
                                          category="clothesDrying",
                                          menu_mp=menu_mp)

print("Calculating rebate amounts for Cooking ...")
df_euss_am_mp9_home = calculate_rebateIRA(df_results_IRA=df_euss_am_mp9_home,
                                          category="cooking",
                                          menu_mp=menu_mp)

print(f"""
====================================================================================================================================================================
DATAFRAME: df_euss_am_mp9_home AFTER CALCULATING REBATE AMOUNTS
{df_euss_am_mp9_home}

====================================================================================================================================================================
""")
# Out:
# ====================================================================================================================================================================
# CALCULATE HOUSEHOLD PERCENT AREA MEDIAN INCOME (%AMI) AND REBATE ELIGIBILITY/AMOUNTS
# ====================================================================================================================================================================
#
#
# Calculating rebate amounts for Space Heating ...
# Measure package calculation for heating:
#   - 12266 homes have valid data
#   - 15649 homes will receive retrofits
#   - 12266 homes have both valid data AND will receive retrofits
#   - 3385 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
# Calculating rebate amounts for Water Heating ...
# Measure package calculation for waterHeating:
#   - 14999 homes have valid data
#   - 15551 homes will receive retrofits
#   - 14999 homes have both valid data AND will receive retrofits
#   - 652 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
# Calculating rebate amounts for Clothes Drying ...
# Measure package calculation for clothesDrying:
#   - 14743 homes have valid data
#   - 14743 homes will receive retrofits
#   - 14743 homes have both valid data AND will receive retrofits
#   - 908 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
# Calculating rebate amounts for Cooking ...
# Measure package calculation for cooking:
#   - 7867 homes have valid data
#   - 7867 homes will receive retrofits
#   - 7867 homes have both valid data AND will receive retrofits
#   - 7784 homes excluded (values will be NaN)
#
# Verifying masking for all calculated columns:
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_mp9_home AFTER CALCULATING REBATE AMOUNTS
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...            income_level  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...         Moderate-Income
# 122      In another census Place   Suburban  ...              Low-Income
# 150      In another census Place      Rural  ...         Moderate-Income
# 153        Not in a census Place   Suburban  ...  Middle-to-Upper-Income
# 162        Not in a census Place   Suburban  ...  Middle-to-Upper-Income
# ...                          ...        ...  ...                     ...
# 549882     Not in a census Place   Suburban  ...         Moderate-Income
# 549915                 Lancaster   Suburban  ...         Moderate-Income
# 549937   In another census Place      Rural  ...  Middle-to-Upper-Income
# 549963   In another census Place   Suburban  ...         Moderate-Income
# 549989     Not in a census Place      Rural  ...  Middle-to-Upper-Income
#
#         lmi_or_mui public_discount_rate private_fixed_discount_rate  \
# bldg_id
# 119            LMI                 0.02                        0.07
# 122            LMI                 0.02                        0.07
# 150            LMI                 0.02                        0.07
# 153            MUI                 0.02                        0.07
# 162            MUI                 0.02                        0.07
# ...            ...                  ...                         ...
# 549882         LMI                 0.02                        0.07
# 549915         LMI                 0.02                        0.07
# 549937         MUI                 0.02                        0.07
# 549963         LMI                 0.02                        0.07
# 549989         MUI                 0.02                        0.07
#
#         private_variable_discount_rate  mp9_heating_rebate_amount  \
# bldg_id
# 119                           0.024747                     8000.0
# 122                           0.098613                     8000.0
# 150                           0.061947                     8000.0
# 153                           0.020000                        0.0
# 162                           0.020000                        0.0
# ...                                ...                        ...
# 549882                        0.059080                        NaN
# 549915                        0.031940                     8000.0
# 549937                        0.020000                        0.0
# 549963                        0.036280                     8000.0
# 549989                        0.020000                        0.0
#
#          weatherization_rebate_amount mp9_waterHeating_rebate_amount  \
# bldg_id
# 119                            1600.0                        1374.23
# 122                               0.0                        1750.00
# 150                               0.0                        1407.45
# 153                               0.0                           0.00
# 162                               0.0                           0.00
# ...                               ...                            ...
# 549882                            0.0                        1538.80
# 549915                            0.0                        1750.00
# 549937                            0.0                           0.00
# 549963                            0.0                        1701.91
# 549989                            0.0                           0.00
#
#          mp9_clothesDrying_rebate_amount mp9_cooking_rebate_amount
# bldg_id
# 119                               840.00                    679.32
# 122                               840.00                       NaN
# 150                               653.97                       NaN
# 153                                  NaN                       NaN
# 162                                 0.00                       NaN
# ...                                  ...                       ...
# 549882                            840.00                       NaN
# 549915                            840.00                       NaN
# 549937                              0.00                      0.00
# 549963                            840.00                       NaN
# 549989                              0.00                      0.00
#
# [15651 rows x 429 columns]
#
# ====================================================================================================================================================================

# %% [markdown]
# # SCENARIO ANALYSIS:
# ## "No Inflation Reduction Act" and "AEO2023 Reference Case"
# ## Public Impact, Private Impact and Adoption Potential (Degree of Adoption Feasibility)

# %%
from cmu_tare_model.private_impact.calculate_lifetime_private_impact import calculate_private_npv
from cmu_tare_model.public_impact.calculate_lifetime_public_impact_sensitivity import calculate_public_npv
from cmu_tare_model.adoption_potential.determine_adoption_potential_sensitivity import *

print(f"""  
====================================================================================================================================================================
SCENARIO ANALYSIS: OVERVIEW
====================================================================================================================================================================

-------------------------------------------------------
PUBLIC IMPACTS: CLIMATE AND HEALTH
-------------------------------------------------------

--------------------------------------------------------
PRIVATE IMPACTS: LIFETIME CAPITAL COSTS AND SAVINGS
--------------------------------------------------------

--------------------------------------------------------
ADOPTION POTENTIAL
--------------------------------------------------------
determine_adoption_potential_sensitivity.py file contains the definitions for:
- adoption_decision function (combined climate + health analysis)
- calculate_climate_only_adoption_robust function (climate-only analysis)
- calculate_health_only_adoption_robust function (health-only analysis)
      
--------------------------------------------------------------------------------------------------------------------------------------------------------------------

""")
# Out:
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS: OVERVIEW
# ====================================================================================================================================================================
#
# -------------------------------------------------------
# PUBLIC IMPACTS: CLIMATE AND HEALTH
# -------------------------------------------------------
#
# --------------------------------------------------------
# PRIVATE IMPACTS: LIFETIME CAPITAL COSTS AND SAVINGS
# --------------------------------------------------------
#
# --------------------------------------------------------
# ADOPTION POTENTIAL
# --------------------------------------------------------
# determine_adoption_potential_sensitivity.py file contains the definitions for:
# - adoption_decision function (combined climate + health analysis)
# - calculate_climate_only_adoption_robust function (climate-only analysis)
# - calculate_health_only_adoption_robust function (health-only analysis)
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Moderate MEASURE PACKAGE (MP9): NO INFLATION REDUCTION ACT
# ## Assumptions
# - NREL End-Use Savings Shapes Database: Measure Package 9
# - AEO2023 No Inflation Reduction Act:  HDD and Fuel Price Projections
# - Cambium 2021 MidCase Scenario

# %%
# Measure Package 9
scenario_name = 'No Inflation Reduction Act'
cost_scenario = 'Fuel Costs: AEO2023 No Inflation Reduction Act'
grid_scenario = 'Electricity Grid: Cambium 2021 MidCase Scenario'

print(f"""
====================================================================================================================================================================
Scenario {scenario_name}:
Moderate Retrofit: Measure Package {menu_mp}
{cost_scenario}
{grid_scenario}
====================================================================================================================================================================
""")
# Out:
# ====================================================================================================================================================================
# Scenario No Inflation Reduction Act:
# Moderate Retrofit: Measure Package 9
# Fuel Costs: AEO2023 No Inflation Reduction Act
# Electricity Grid: Cambium 2021 MidCase Scenario
# ====================================================================================================================================================================

# %%
print(f"""  
====================================================================================================================================================================
SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PUBLIC IMPACT 
====================================================================================================================================================================
STEP 1. Calculate the baseline marginal damages for climate and health-related emissions         [COMPLETED]
STEP 2. Calculate the post-retrofit marginal damages for climate and health-related emissions    [COMPLETED]
STEP 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)

---------------------------------------------------------------------------------------------

RESULTS OUTPUT:
""")

# Create copies to prevent overwriting the original dataframe and compare the differences
df_euss_am_mp9_home_ap2 = df_euss_am_mp9_home.copy()
df_euss_am_mp9_home_easiur = df_euss_am_mp9_home.copy()
df_euss_am_mp9_home_inmap = df_euss_am_mp9_home.copy()

# ========================== AP2  ========================== 
df_euss_am_mp9_home_ap2 = calculate_public_npv(
    df=df_euss_am_mp9_home_ap2,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp9_noIRA_damages_climate,
    df_mp_health=df_mp9_noIRA_damages_health,
    menu_mp="9",
    policy_scenario='No Inflation Reduction Act',
    rcm_model='ap2',
    base_year=2024,
)

# ====================== EASIUR ========================== 
df_euss_am_mp9_home_easiur = calculate_public_npv(
    df=df_euss_am_mp9_home_easiur,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp9_noIRA_damages_climate,
    df_mp_health=df_mp9_noIRA_damages_health,
    menu_mp="9",
    policy_scenario='No Inflation Reduction Act',
    rcm_model='easiur',
    base_year=2024,
)

# ========================== InMAP ========================== 
df_euss_am_mp9_home_inmap = calculate_public_npv(
    df=df_euss_am_mp9_home_inmap,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp9_noIRA_damages_climate,
    df_mp_health=df_mp9_noIRA_damages_health,
    menu_mp="9",
    policy_scenario='No Inflation Reduction Act',
    rcm_model='inmap',
    base_year=2024,
)

print(f"""  
====================================================================================================================================================================
DATAFRAME FOR mp9 AFTER CALCULATING PUBLIC NPV (NO IRA): df_euss_am_mp9_home

-----------------------------------------------
AP2: 
-----------------------------------------------

{df_euss_am_mp9_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp9_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp9_home_inmap}
      
""")
# Out:
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PUBLIC IMPACT
# ====================================================================================================================================================================
# STEP 1. Calculate the baseline marginal damages for climate and health-related emissions         [COMPLETED]
# STEP 2. Calculate the post-retrofit marginal damages for climate and health-related emissions    [COMPLETED]
# STEP 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
#
# ---------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT:
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Verifying masking for all calculated columns:
#
# ====================================================================================================================================================================
# DATAFRAME FOR mp9 AFTER CALCULATING PUBLIC NPV (NO IRA): df_euss_am_mp9_home
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp9_clothesDrying_public_npv_central_ap2_h6c  \
# bldg_id
# 119                                                   9.78
# 122                                                 295.27
# 150                                                 295.32
# 153                                                    NaN
# 162                                                1060.72
# ...                                                    ...
# 549882                                              466.75
# 549915                                              798.68
# 549937                                              235.36
# 549963                                              401.60
# 549989                                              399.86
#
#         preIRA_mp9_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                         229.76
# 122                                         314.41
# 150                                         365.15
# 153                                            NaN
# 162                                        1129.56
# ...                                            ...
# 549882                                      506.33
# 549915                                      881.90
# 549937                                      577.42
# 549963                                      476.07
# 549989                                      456.24
#
#         preIRA_mp9_clothesDrying_public_npv_upper_ap2_h6c  \
# bldg_id
# 119                                                 94.59
# 122                                                412.35
# 150                                                431.28
# 153                                                   NaN
# 162                                               1481.32
# ...                                                   ...
# 549882                                             655.28
# 549915                                            1127.04
# 549937                                             449.16
# 549963                                             578.59
# 549989                                             569.73
#
#         preIRA_mp9_cooking_climate_npv_lower  \
# bldg_id
# 119                                    30.63
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                 21.95
# 549963                                   NaN
# 549989                                 68.47
#
#         preIRA_mp9_cooking_health_npv_ap2_h6c  \
# bldg_id
# 119                                   -299.42
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                -135.35
# 549963                                    NaN
# 549989                                -208.25
#
#          preIRA_mp9_cooking_public_npv_lower_ap2_h6c  \
# bldg_id
# 119                                          -268.79
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                       -113.40
# 549963                                           NaN
# 549989                                       -139.78
#
#          preIRA_mp9_cooking_climate_npv_central  \
# bldg_id
# 119                                      106.37
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                    76.59
# 549963                                      NaN
# 549989                                   241.05
#
#         preIRA_mp9_cooking_public_npv_central_ap2_h6c  \
# bldg_id
# 119                                           -193.05
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                         -58.76
# 549963                                            NaN
# 549989                                          32.80
#
#          preIRA_mp9_cooking_climate_npv_upper  \
# bldg_id
# 119                                    166.96
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                 120.54
# 549963                                    NaN
# 549989                                 380.96
#
#         preIRA_mp9_cooking_public_npv_upper_ap2_h6c
# bldg_id
# 119                                         -132.46
# 122                                             NaN
# 150                                             NaN
# 153                                             NaN
# 162                                             NaN
# ...                                             ...
# 549882                                          NaN
# 549915                                          NaN
# 549937                                       -14.81
# 549963                                          NaN
# 549989                                       172.71
#
# [15651 rows x 485 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp9_clothesDrying_public_npv_central_easiur_h6c  \
# bldg_id
# 119                                                 102.16
# 122                                                 309.99
# 150                                                 331.59
# 153                                                    NaN
# 162                                                1113.74
# ...                                                    ...
# 549882                                              489.97
# 549915                                              844.81
# 549937                                              315.24
# 549963                                              366.72
# 549989                                              392.31
#
#         preIRA_mp9_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                         229.76
# 122                                         314.41
# 150                                         365.15
# 153                                            NaN
# 162                                        1129.56
# ...                                            ...
# 549882                                      506.33
# 549915                                      881.90
# 549937                                      577.42
# 549963                                      476.07
# 549989                                      456.24
#
#         preIRA_mp9_clothesDrying_public_npv_upper_easiur_h6c  \
# bldg_id
# 119                                                 186.97
# 122                                                 427.07
# 150                                                 467.55
# 153                                                    NaN
# 162                                                1534.34
# ...                                                    ...
# 549882                                              678.50
# 549915                                             1173.17
# 549937                                              529.04
# 549963                                              543.71
# 549989                                              562.18
#
#         preIRA_mp9_cooking_climate_npv_lower  \
# bldg_id
# 119                                    30.63
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                 21.95
# 549963                                   NaN
# 549989                                 68.47
#
#         preIRA_mp9_cooking_health_npv_easiur_h6c  \
# bldg_id
# 119                                      -152.59
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                    -77.98
# 549963                                       NaN
# 549989                                   -112.46
#
#          preIRA_mp9_cooking_public_npv_lower_easiur_h6c  \
# bldg_id
# 119                                             -121.96
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                           -56.03
# 549963                                              NaN
# 549989                                           -43.99
#
#          preIRA_mp9_cooking_climate_npv_central  \
# bldg_id
# 119                                      106.37
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                    76.59
# 549963                                      NaN
# 549989                                   241.05
#
#         preIRA_mp9_cooking_public_npv_central_easiur_h6c  \
# bldg_id
# 119                                               -46.22
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                             -1.39
# 549963                                               NaN
# 549989                                            128.59
#
#          preIRA_mp9_cooking_climate_npv_upper  \
# bldg_id
# 119                                    166.96
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                 120.54
# 549963                                    NaN
# 549989                                 380.96
#
#         preIRA_mp9_cooking_public_npv_upper_easiur_h6c
# bldg_id
# 119                                              14.37
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                           42.56
# 549963                                             NaN
# 549989                                          268.50
#
# [15651 rows x 485 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp9_clothesDrying_public_npv_central_inmap_h6c  \
# bldg_id
# 119                                                 197.48
# 122                                                 271.40
# 150                                                 390.62
# 153                                                    NaN
# 162                                                 975.09
# ...                                                    ...
# 549882                                              571.21
# 549915                                              880.44
# 549937                                              251.84
# 549963                                              375.18
# 549989                                              423.82
#
#         preIRA_mp9_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                         229.76
# 122                                         314.41
# 150                                         365.15
# 153                                            NaN
# 162                                        1129.56
# ...                                            ...
# 549882                                      506.33
# 549915                                      881.90
# 549937                                      577.42
# 549963                                      476.07
# 549989                                      456.24
#
#         preIRA_mp9_clothesDrying_public_npv_upper_inmap_h6c  \
# bldg_id
# 119                                                 282.29
# 122                                                 388.48
# 150                                                 526.58
# 153                                                    NaN
# 162                                                1395.69
# ...                                                    ...
# 549882                                              759.74
# 549915                                             1208.80
# 549937                                              465.64
# 549963                                              552.17
# 549989                                              593.69
#
#         preIRA_mp9_cooking_climate_npv_lower  \
# bldg_id
# 119                                    30.63
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                 21.95
# 549963                                   NaN
# 549989                                 68.47
#
#         preIRA_mp9_cooking_health_npv_inmap_h6c  \
# bldg_id
# 119                                       41.85
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                  -131.19
# 549963                                      NaN
# 549989                                  -188.27
#
#          preIRA_mp9_cooking_public_npv_lower_inmap_h6c  \
# bldg_id
# 119                                              72.48
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                         -109.24
# 549963                                             NaN
# 549989                                         -119.80
#
#          preIRA_mp9_cooking_climate_npv_central  \
# bldg_id
# 119                                      106.37
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                    76.59
# 549963                                      NaN
# 549989                                   241.05
#
#         preIRA_mp9_cooking_public_npv_central_inmap_h6c  \
# bldg_id
# 119                                              148.22
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                           -54.60
# 549963                                              NaN
# 549989                                            52.78
#
#          preIRA_mp9_cooking_climate_npv_upper  \
# bldg_id
# 119                                    166.96
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                 120.54
# 549963                                    NaN
# 549989                                 380.96
#
#         preIRA_mp9_cooking_public_npv_upper_inmap_h6c
# bldg_id
# 119                                            208.81
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                         -10.65
# 549963                                            NaN
# 549989                                         192.69
#
# [15651 rows x 485 columns]

# %%
print(f"""
====================================================================================================================================================================
SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PRIVATE IMPACT
====================================================================================================================================================================
STEP 1: Calculate annual operating (fuel) costs                                                          [COMPLETED]
STEP 2: Calculate equipment capital costs (HEATING: include ductwork and weatherization (MP9 and MP10))  [COMPLETED]
STEP 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)        [COMPLETED]
STEP 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
----------------------------------------------------------------------------------------------------------------------

RESULTS OUTPUT (NO INFLATION REDUCTION ACT):
""")


# ========================== AP2  ========================== 
df_euss_am_mp9_home_ap2 = calculate_private_npv(
    df=df_euss_am_mp9_home_ap2,
    df_fuel_costs=df_mp9_noIRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='No Inflation Reduction Act',
    base_year=2024,
    verbose=False  # Add this parameter
    )

# ====================== EASIUR ========================== 
df_euss_am_mp9_home_easiur = calculate_private_npv(
    df=df_euss_am_mp9_home_easiur,
    df_fuel_costs=df_mp9_noIRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='No Inflation Reduction Act',
    base_year=2024,
    verbose=False  # Add this parameter
    )

# ====================== InMAP ========================== 
df_euss_am_mp9_home_inmap = calculate_private_npv(
    df=df_euss_am_mp9_home_inmap,
    df_fuel_costs=df_mp9_noIRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='No Inflation Reduction Act',
    base_year=2024,
    verbose=False  # Add this parameter
    )


print(f"""  
====================================================================================================================================================================
DATAFRAME FOR mp9 AFTER CALCULATING PRIVATE NPV (NO INFLATION REDUCTION ACT): df_euss_am_mp9_home

-----------------------------------------------
AP2: 
-----------------------------------------------

{df_euss_am_mp9_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp9_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp9_home_inmap}
      
""")
# Out:
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): PRIVATE IMPACT
# ====================================================================================================================================================================
# STEP 1: Calculate annual operating (fuel) costs                                                          [COMPLETED]
# STEP 2: Calculate equipment capital costs (HEATING: include ductwork and weatherization (MP9 and MP10))  [COMPLETED]
# STEP 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)        [COMPLETED]
# STEP 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
# ----------------------------------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT (NO INFLATION REDUCTION ACT):
#
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Calculating costs for heating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Calculating costs for heating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Verifying masking for all calculated columns:
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Calculating costs for heating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: No Inflation Reduction Act
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: No Inflation Reduction Act --> scenario_prefix: preIRA_mp9_
#
#
# Verifying masking for all calculated columns:
#
# ====================================================================================================================================================================
# DATAFRAME FOR mp9 AFTER CALCULATING PRIVATE NPV (NO INFLATION REDUCTION ACT): df_euss_am_mp9_home
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp9_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                        -2222.70
# 122                                        -1310.06
# 150                                        -1480.90
# 153                                         4663.01
# 162                                        -2383.54
# ...                                             ...
# 549882                                     -3218.65
# 549915                                       887.94
# 549937                                     -2023.83
# 549963                                     -2924.39
# 549989                                      -966.97
#
#         preIRA_mp9_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                         -331.22
# 122                                         1552.38
# 150                                         -406.91
# 153                                         7370.57
# 162                                         -290.60
# ...                                             ...
# 549882                                     -1557.41
# 549915                                      2026.05
# 549937                                      -132.35
# 549963                                     -1263.15
# 549989                                      1740.59
#
#         preIRA_mp9_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                        2464.36
# 122                                        2536.94
# 150                                        1307.93
# 153                                            NaN
# 162                                        2054.01
# ...                                            ...
# 549882                                     2557.51
# 549915                                     1725.33
# 549937                                     2472.00
# 549963                                     2280.70
# 549989                                     2050.39
#
#         preIRA_mp9_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                      1156.38
# 122                                      1542.88
# 150                                       313.87
# 153                                          NaN
# 162                                      1059.95
# ...                                          ...
# 549882                                   1563.45
# 549915                                    731.27
# 549937                                   1164.02
# 549963                                   1286.64
# 549989                                   1056.33
#
#         preIRA_mp9_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                         -2643.69
# 122                                         -2334.00
# 150                                         -1072.21
# 153                                              NaN
# 162                                         -1324.86
# ...                                              ...
# 549882                                      -2230.66
# 549915                                      -1156.02
# 549937                                      -2973.61
# 549963                                      -1986.17
# 549989                                      -1755.86
#
#          preIRA_mp9_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                          -1335.71
# 122                                          -1339.94
# 150                                            -78.15
# 153                                               NaN
# 162                                           -330.80
# ...                                               ...
# 549882                                       -1236.60
# 549915                                        -161.96
# 549937                                       -1665.63
# 549963                                        -992.11
# 549989                                        -761.80
#
#          preIRA_mp9_cooking_total_capitalCost  \
# bldg_id
# 119                                   1358.64
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                2119.37
# 549963                                    NaN
# 549989                                2088.81
#
#         preIRA_mp9_cooking_net_capitalCost  \
# bldg_id
# 119                                 286.10
# 122                                    NaN
# 150                                    NaN
# 153                                    NaN
# 162                                    NaN
# ...                                    ...
# 549882                                 NaN
# 549915                                 NaN
# 549937                             1046.83
# 549963                                 NaN
# 549989                             1016.27
#
#          preIRA_mp9_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                    -1770.68
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -2678.78
# 549963                                      NaN
# 549989                                 -1675.60
#
#         preIRA_mp9_cooking_private_npv_moreWTP
# bldg_id
# 119                                    -698.14
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                -1606.24
# 549963                                     NaN
# 549989                                 -603.06
#
# [15651 rows x 501 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp9_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                        -2222.70
# 122                                        -1310.06
# 150                                        -1480.90
# 153                                         4663.01
# 162                                        -2383.54
# ...                                             ...
# 549882                                     -3218.65
# 549915                                       887.94
# 549937                                     -2023.83
# 549963                                     -2924.39
# 549989                                      -966.97
#
#         preIRA_mp9_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                         -331.22
# 122                                         1552.38
# 150                                         -406.91
# 153                                         7370.57
# 162                                         -290.60
# ...                                             ...
# 549882                                     -1557.41
# 549915                                      2026.05
# 549937                                      -132.35
# 549963                                     -1263.15
# 549989                                      1740.59
#
#         preIRA_mp9_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                        2464.36
# 122                                        2536.94
# 150                                        1307.93
# 153                                            NaN
# 162                                        2054.01
# ...                                            ...
# 549882                                     2557.51
# 549915                                     1725.33
# 549937                                     2472.00
# 549963                                     2280.70
# 549989                                     2050.39
#
#         preIRA_mp9_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                      1156.38
# 122                                      1542.88
# 150                                       313.87
# 153                                          NaN
# 162                                      1059.95
# ...                                          ...
# 549882                                   1563.45
# 549915                                    731.27
# 549937                                   1164.02
# 549963                                   1286.64
# 549989                                   1056.33
#
#         preIRA_mp9_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                         -2643.69
# 122                                         -2334.00
# 150                                         -1072.21
# 153                                              NaN
# 162                                         -1324.86
# ...                                              ...
# 549882                                      -2230.66
# 549915                                      -1156.02
# 549937                                      -2973.61
# 549963                                      -1986.17
# 549989                                      -1755.86
#
#          preIRA_mp9_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                          -1335.71
# 122                                          -1339.94
# 150                                            -78.15
# 153                                               NaN
# 162                                           -330.80
# ...                                               ...
# 549882                                       -1236.60
# 549915                                        -161.96
# 549937                                       -1665.63
# 549963                                        -992.11
# 549989                                        -761.80
#
#          preIRA_mp9_cooking_total_capitalCost  \
# bldg_id
# 119                                   1358.64
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                2119.37
# 549963                                    NaN
# 549989                                2088.81
#
#         preIRA_mp9_cooking_net_capitalCost  \
# bldg_id
# 119                                 286.10
# 122                                    NaN
# 150                                    NaN
# 153                                    NaN
# 162                                    NaN
# ...                                    ...
# 549882                                 NaN
# 549915                                 NaN
# 549937                             1046.83
# 549963                                 NaN
# 549989                             1016.27
#
#          preIRA_mp9_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                    -1770.68
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -2678.78
# 549963                                      NaN
# 549989                                 -1675.60
#
#         preIRA_mp9_cooking_private_npv_moreWTP
# bldg_id
# 119                                    -698.14
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                -1606.24
# 549963                                     NaN
# 549989                                 -603.06
#
# [15651 rows x 501 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp9_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                        -2222.70
# 122                                        -1310.06
# 150                                        -1480.90
# 153                                         4663.01
# 162                                        -2383.54
# ...                                             ...
# 549882                                     -3218.65
# 549915                                       887.94
# 549937                                     -2023.83
# 549963                                     -2924.39
# 549989                                      -966.97
#
#         preIRA_mp9_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                         -331.22
# 122                                         1552.38
# 150                                         -406.91
# 153                                         7370.57
# 162                                         -290.60
# ...                                             ...
# 549882                                     -1557.41
# 549915                                      2026.05
# 549937                                      -132.35
# 549963                                     -1263.15
# 549989                                      1740.59
#
#         preIRA_mp9_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                        2464.36
# 122                                        2536.94
# 150                                        1307.93
# 153                                            NaN
# 162                                        2054.01
# ...                                            ...
# 549882                                     2557.51
# 549915                                     1725.33
# 549937                                     2472.00
# 549963                                     2280.70
# 549989                                     2050.39
#
#         preIRA_mp9_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                      1156.38
# 122                                      1542.88
# 150                                       313.87
# 153                                          NaN
# 162                                      1059.95
# ...                                          ...
# 549882                                   1563.45
# 549915                                    731.27
# 549937                                   1164.02
# 549963                                   1286.64
# 549989                                   1056.33
#
#         preIRA_mp9_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                         -2643.69
# 122                                         -2334.00
# 150                                         -1072.21
# 153                                              NaN
# 162                                         -1324.86
# ...                                              ...
# 549882                                      -2230.66
# 549915                                      -1156.02
# 549937                                      -2973.61
# 549963                                      -1986.17
# 549989                                      -1755.86
#
#          preIRA_mp9_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                          -1335.71
# 122                                          -1339.94
# 150                                            -78.15
# 153                                               NaN
# 162                                           -330.80
# ...                                               ...
# 549882                                       -1236.60
# 549915                                        -161.96
# 549937                                       -1665.63
# 549963                                        -992.11
# 549989                                        -761.80
#
#          preIRA_mp9_cooking_total_capitalCost  \
# bldg_id
# 119                                   1358.64
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                2119.37
# 549963                                    NaN
# 549989                                2088.81
#
#         preIRA_mp9_cooking_net_capitalCost  \
# bldg_id
# 119                                 286.10
# 122                                    NaN
# 150                                    NaN
# 153                                    NaN
# 162                                    NaN
# ...                                    ...
# 549882                                 NaN
# 549915                                 NaN
# 549937                             1046.83
# 549963                                 NaN
# 549989                             1016.27
#
#          preIRA_mp9_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                    -1770.68
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -2678.78
# 549963                                      NaN
# 549989                                 -1675.60
#
#         preIRA_mp9_cooking_private_npv_moreWTP
# bldg_id
# 119                                    -698.14
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                -1606.24
# 549963                                     NaN
# 549989                                 -603.06
#
# [15651 rows x 501 columns]

# %%
print(f"""
====================================================================================================================================================================
SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): ADOPTION POTENTIAL
====================================================================================================================================================================
determine_adoption_potential_sensitivity.py file contains the definitions for:
- adoption_decision function (combined climate + health analysis)
- calculate_climate_only_adoption_robust function (climate-only analysis)
- calculate_health_only_adoption_robust function (health-only analysis)
      
RESULTS OUTPUT (NO INFLATION REDUCTION ACT):
""")

# ========================== AP2  ========================== 
print("Processing AP2 model...")

# Combined climate + health analysis (existing)
df_euss_am_mp9_home_ap2 = adoption_decision(
    df=df_euss_am_mp9_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='ap2',
    cr_function='acs',
    )

df_euss_am_mp9_home_ap2 = adoption_decision(
    df=df_euss_am_mp9_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='ap2',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp9_home_ap2 = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp9_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp9_home_ap2 = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='ap2',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp9_home_ap2 = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='ap2',
    cr_function='h6c',
    verbose=False
    )

# ====================== EASIUR ========================== 
print("Processing EASIUR model...")

# Combined climate + health analysis (existing)
df_euss_am_mp9_home_easiur = adoption_decision(
    df=df_euss_am_mp9_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='easiur',
    cr_function='acs',
    )

df_euss_am_mp9_home_easiur = adoption_decision(
    df=df_euss_am_mp9_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='easiur',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp9_home_easiur = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp9_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp9_home_easiur = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='easiur',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp9_home_easiur = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='easiur',
    cr_function='h6c',
    verbose=False
    )

# ====================== InMAP ========================== 
print("Processing InMAP model...")

# Combined climate + health analysis (existing)
df_euss_am_mp9_home_inmap = adoption_decision(
    df=df_euss_am_mp9_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='inmap',
    cr_function='acs',
    )

df_euss_am_mp9_home_inmap = adoption_decision(
    df=df_euss_am_mp9_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='inmap',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp9_home_inmap = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp9_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp9_home_inmap = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='inmap',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp9_home_inmap = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='No Inflation Reduction Act',
    rcm_model='inmap',
    cr_function='h6c',
    verbose=False
    )

print(f"""
====================================================================================================================================================================
DATAFRAME FOR MP9 AFTER DETERMINING ADOPTION FEASIBILITY (NO INFLATION REDUCTION ACT): df_euss_am_mp9_home
Includes: Combined (Climate + Health), Climate-Only, and Health-Only Adoption Analysis

-----------------------------------------------
AP2: 
-----------------------------------------------

{df_euss_am_mp9_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp9_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp9_home_inmap}
      
""")
# Out:
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (NO INFLATION REDUCTION ACT): ADOPTION POTENTIAL
# ====================================================================================================================================================================
# determine_adoption_potential_sensitivity.py file contains the definitions for:
# - adoption_decision function (combined climate + health analysis)
# - calculate_climate_only_adoption_robust function (climate-only analysis)
# - calculate_health_only_adoption_robust function (health-only analysis)
#
# RESULTS OUTPUT (NO INFLATION REDUCTION ACT):
#
# Processing AP2 model...
# Fixed 12 duplicate columns
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | ap2-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | ap2-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Climate-only Analysis: No Inflation Reduction Act
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | ap2-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | ap2-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# Processing EASIUR model...
# Fixed 12 duplicate columns
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | easiur-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | easiur-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Climate-only Analysis: No Inflation Reduction Act
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | easiur-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | easiur-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# Processing InMAP model...
# Fixed 12 duplicate columns
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | inmap-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Adoption Analysis: No Inflation Reduction Act | inmap-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Climate-only Analysis: No Inflation Reduction Act
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | inmap-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: No Inflation Reduction Act --
#               scenario_prefix: f'preIRA_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_preIRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_preIRA'
#
#
# Health-only Analysis: No Inflation Reduction Act | inmap-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
#
# ====================================================================================================================================================================
# DATAFRAME FOR MP9 AFTER DETERMINING ADOPTION FEASIBILITY (NO INFLATION REDUCTION ACT): df_euss_am_mp9_home
# Includes: Combined (Climate + Health), Climate-Only, and Health-Only Adoption Analysis
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp9_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                              -591.77
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                          -1529.65
# 549963                                               NaN
# 549989                                           -362.01
#
#         preIRA_mp9_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                            -531.18
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                        -1485.70
# 549963                                             NaN
# 549989                                         -222.10
#
#         preIRA_mp9_heating_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                           -24712.92
# 122                                           -12795.73
# 150                                             3784.16
# 153                                            -6056.72
# 162                                            -5759.89
# ...                                                 ...
# 549882                                              NaN
# 549915                                          7851.63
# 549937                                        -17664.68
# 549963                                        -21224.74
# 549989                                          -700.44
#
#         preIRA_mp9_waterHeating_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                                -446.90
# 122                                                1576.50
# 150                                                -261.75
# 153                                                7442.46
# 162                                                -385.16
# ...                                                    ...
# 549882                                            -1778.78
# 549915                                             2900.56
# 549937                                             -234.48
# 549963                                            -1314.12
# 549989                                             1704.49
#
#         preIRA_mp9_clothesDrying_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                               -1388.31
# 122                                               -1301.82
# 150                                                 -52.41
# 153                                                    NaN
# 162                                                -193.89
# ...                                                    ...
# 549882                                            -1178.63
# 549915                                              -66.54
# 549937                                            -1715.54
# 549963                                             -952.20
# 549989                                             -717.64
#
#          preIRA_mp9_cooking_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                              -814.67
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                          -1658.92
# 549963                                               NaN
# 549989                                           -684.10
#
#          preIRA_mp9_heating_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                            -25398.28
# 122                                            -10084.53
# 150                                              8569.23
# 153                                             -4733.08
# 162                                             -2867.65
# ...                                                  ...
# 549882                                               NaN
# 549915                                          15448.68
# 549937                                         -17828.43
# 549963                                         -21931.43
# 549989                                           -568.34
#
#         preIRA_mp9_waterHeating_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                                -628.50
# 122                                                1614.34
# 150                                                 -33.95
# 153                                                7555.28
# 162                                                -533.57
# ...                                                    ...
# 549882                                            -2126.25
# 549915                                             4272.92
# 549937                                             -394.80
# 549963                                            -1394.11
# 549989                                             1647.82
#
#          preIRA_mp9_clothesDrying_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                               -1470.88
# 122                                               -1242.00
# 150                                                 -12.02
# 153                                                    NaN
# 162                                                  20.96
# ...                                                    ...
# 549882                                            -1087.65
# 549915                                               83.18
# 549937                                            -1793.89
# 549963                                             -889.59
# 549989                                             -648.31
#
#         preIRA_mp9_cooking_total_npv_healthOnly_ap2_h6c
# bldg_id
# 119                                             -997.56
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                         -1741.59
# 549963                                              NaN
# 549989                                          -811.31
#
# [15651 rows x 609 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp9_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                              -591.77
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                          -1529.65
# 549963                                               NaN
# 549989                                           -362.01
#
#         preIRA_mp9_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                            -531.18
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                        -1485.70
# 549963                                             NaN
# 549989                                         -222.10
#
#         preIRA_mp9_heating_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                              -23494.85
# 122                                               -7978.38
# 150                                                5484.45
# 153                                               -1251.55
# 162                                                  67.81
# ...                                                    ...
# 549882                                                 NaN
# 549915                                             8804.01
# 549937                                           -17265.73
# 549963                                           -20156.21
# 549989                                              -85.24
#
#         preIRA_mp9_waterHeating_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                                -153.12
# 122                                                1821.67
# 150                                                -182.87
# 153                                                8626.00
# 162                                                -146.31
# ...                                                    ...
# 549882                                            -1549.76
# 549915                                             3060.94
# 549937                                               32.18
# 549963                                            -1194.64
# 549989                                             1845.15
#
#         preIRA_mp9_clothesDrying_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                               -1352.37
# 122                                               -1296.06
# 150                                                 -38.31
# 153                                                    NaN
# 162                                                -173.27
# ...                                                    ...
# 549882                                            -1169.59
# 549915                                              -48.60
# 549937                                            -1684.48
# 549963                                             -965.80
# 549989                                             -720.55
#
#          preIRA_mp9_cooking_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                                -757.52
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1636.59
# 549963                                                 NaN
# 549989                                             -646.82
#
#          preIRA_mp9_heating_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                              -22268.62
# 122                                                2292.83
# 150                                               12937.86
# 153                                                7613.00
# 162                                               12105.57
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            17895.69
# 549937                                           -16803.38
# 549963                                           -19186.04
# 549989                                             1012.35
#
#         preIRA_mp9_waterHeating_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                                 126.38
# 122                                                2244.24
# 150                                                 168.73
# 153                                               10596.17
# 162                                                  80.14
# ...                                                    ...
# 549882                                            -1537.75
# 549915                                             4684.95
# 549937                                              290.36
# 549963                                            -1087.18
# 549989                                             2009.26
#
#          preIRA_mp9_clothesDrying_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                               -1378.50
# 122                                               -1227.28
# 150                                                  24.25
# 153                                                    NaN
# 162                                                  73.98
# ...                                                    ...
# 549882                                            -1064.43
# 549915                                              129.31
# 549937                                            -1714.01
# 549963                                             -924.47
# 549989                                             -655.86
#
#         preIRA_mp9_cooking_total_npv_healthOnly_easiur_h6c
# bldg_id
# 119                                                -850.73
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1684.22
# 549963                                                 NaN
# 549989                                             -715.52
#
# [15651 rows x 609 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         preIRA_mp9_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                              -591.77
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                          -1529.65
# 549963                                               NaN
# 549989                                           -362.01
#
#         preIRA_mp9_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                            -531.18
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                        -1485.70
# 549963                                             NaN
# 549989                                         -222.10
#
#         preIRA_mp9_heating_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                             -22833.10
# 122                                              -5711.98
# 150                                               8182.53
# 153                                              -2927.54
# 162                                               2934.84
# ...                                                   ...
# 549882                                                NaN
# 549915                                            9467.02
# 549937                                          -17486.34
# 549963                                          -20315.17
# 549989                                            -448.12
#
#         preIRA_mp9_waterHeating_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                                   7.17
# 122                                                1966.83
# 150                                                 -52.75
# 153                                                8244.25
# 162                                                 -15.78
# ...                                                    ...
# 549882                                            -1708.17
# 549915                                             3192.13
# 549937                                             -121.18
# 549963                                            -1212.69
# 549989                                             1748.97
#
#         preIRA_mp9_clothesDrying_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                               -1315.24
# 122                                               -1311.11
# 150                                                 -15.33
# 153                                                    NaN
# 162                                                -227.23
# ...                                                    ...
# 549882                                            -1137.99
# 549915                                              -34.72
# 549937                                            -1709.13
# 549963                                             -962.50
# 549989                                             -708.29
#
#          preIRA_mp9_cooking_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                                -681.84
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1657.30
# 549963                                                 NaN
# 549989                                             -676.36
#
#          preIRA_mp9_heating_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                              -20568.42
# 122                                                8115.97
# 150                                               19870.02
# 153                                                3306.82
# 162                                               19471.90
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            19599.12
# 549937                                           -17370.20
# 549963                                           -19594.42
# 549989                                               79.86
#
#         preIRA_mp9_waterHeating_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                                 538.22
# 122                                                2617.34
# 150                                                 503.06
# 153                                                9615.34
# 162                                                 415.54
# ...                                                    ...
# 549882                                            -1944.73
# 549915                                             5022.04
# 549937                                             -103.62
# 549963                                            -1133.45
# 549989                                             1762.13
#
#          preIRA_mp9_clothesDrying_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                               -1283.18
# 122                                               -1265.87
# 150                                                  83.28
# 153                                                    NaN
# 162                                                 -64.67
# ...                                                    ...
# 549882                                             -983.19
# 549915                                              164.94
# 549937                                            -1777.41
# 549963                                             -916.01
# 549989                                             -624.35
#
#         preIRA_mp9_cooking_total_npv_healthOnly_inmap_h6c
# bldg_id
# 119                                               -656.29
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                           -1737.43
# 549963                                                NaN
# 549989                                            -791.33
#
# [15651 rows x 609 columns]

# %% [markdown]
# ## Moderate MEASURE PACKAGE (MP9): AEO2023 REFERENCE CASE
# ## Assumptions
# - NREL End-Use Savings Shapes Database: Measure Package 9
# - AEO2023 REFERENCE CASE: HDD and Fuel Price Projections
# - Cambium 2023 MidCase Scenario

# %%
# Measure Package 9
scenario_name = 'Moderate IRA-Reference'
cost_scenario = 'Fuel Costs: AEO2023 Reference Case'
grid_scenario = 'Electricity Grid: Cambium 2023 MidCase Scenario'

print(f"""
====================================================================================================================================================================
MODEL SCENARIO
====================================================================================================================================================================
Scenario {scenario_name}:
Moderate Retrofit: Measure Package {menu_mp}
{cost_scenario}
{grid_scenario}
====================================================================================================================================================================
""")
# Out:
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Moderate IRA-Reference:
# Moderate Retrofit: Measure Package 9
# Fuel Costs: AEO2023 Reference Case
# Electricity Grid: Cambium 2023 MidCase Scenario
# ====================================================================================================================================================================

# %%
print(f"""  
====================================================================================================================================================================
SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PUBLIC IMPACT 
====================================================================================================================================================================
STEP 1. Calculate the baseline marginal damages for climate and health-related emissions         [COMPLETED]
STEP 2. Calculate the post-retrofit marginal damages for climate and health-related emissions    [COMPLETED]
STEP 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)

---------------------------------------------------------------------------------------------

RESULTS OUTPUT (AEO2023 REFERENCE CASE):
""")

# ========================== AP2  ========================== 
df_euss_am_mp9_home_ap2 = calculate_public_npv(
    df=df_euss_am_mp9_home_ap2,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp9_IRA_damages_climate,
    df_mp_health=df_mp9_IRA_damages_health,
    menu_mp="9",
    policy_scenario='AEO2023 Reference Case',
    rcm_model='ap2',
    base_year=2024,
)

# ====================== EASIUR ========================== 
df_euss_am_mp9_home_easiur = calculate_public_npv(
    df=df_euss_am_mp9_home_easiur,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp9_IRA_damages_climate,
    df_mp_health=df_mp9_IRA_damages_health,
    menu_mp="9",
    policy_scenario='AEO2023 Reference Case',
    rcm_model='easiur',
    base_year=2024,
)

# ========================== InMAP ========================== 
df_euss_am_mp9_home_inmap = calculate_public_npv(
    df=df_euss_am_mp9_home_inmap,
    df_baseline_climate=df_baseline_damages_climate,
    df_baseline_health=df_baseline_damages_health,
    df_mp_climate=df_mp9_IRA_damages_climate,
    df_mp_health=df_mp9_IRA_damages_health,
    menu_mp="9",
    policy_scenario='AEO2023 Reference Case',
    rcm_model='inmap',
    base_year=2024,
)

print(f"""  
=====================================================================================================================================================================
DATAFRAME FOR mp9 AFTER CALCULATING PUBLIC NPV (AEO2023 REFERENCE CASE): df_euss_am_mp9_home

-----------------------------------------------
AP2: 
-----------------------------------------------
      
{df_euss_am_mp9_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp9_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp9_home_inmap}
      
""")
# Out:
#
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PUBLIC IMPACT
# ====================================================================================================================================================================
# STEP 1. Calculate the baseline marginal damages for climate and health-related emissions         [COMPLETED]
# STEP 2. Calculate the post-retrofit marginal damages for climate and health-related emissions    [COMPLETED]
# STEP 3: Discount climate and health impacts and calculate lifetime public impacts (public NPV)
#
# ---------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT (AEO2023 REFERENCE CASE):
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Verifying masking for all calculated columns:
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Verifying masking for all calculated columns:
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# Baseline Climate DataFrame: ✓ Valid
# Baseline Health DataFrame: ✓ Valid
# Retrofit Climate DataFrame: ✓ Valid
# Retrofit Health DataFrame: ✓ Valid
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Verifying masking for all calculated columns:
#
# =====================================================================================================================================================================
# DATAFRAME FOR mp9 AFTER CALCULATING PUBLIC NPV (AEO2023 REFERENCE CASE): df_euss_am_mp9_home
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_clothesDrying_public_npv_central_ap2_h6c  \
# bldg_id
# 119                                                  89.78
# 122                                                 336.88
# 150                                                 343.57
# 153                                                    NaN
# 162                                                1209.88
# ...                                                    ...
# 549882                                              533.72
# 549915                                              915.26
# 549937                                              374.90
# 549963                                              439.22
# 549989                                              460.17
#
#         iraRef_mp9_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                         357.75
# 122                                         380.96
# 150                                         442.35
# 153                                            NaN
# 162                                        1368.22
# ...                                            ...
# 549882                                      613.48
# 549915                                     1068.42
# 549937                                      799.95
# 549963                                      536.06
# 549989                                      552.77
#
#         iraRef_mp9_clothesDrying_public_npv_upper_ap2_h6c  \
# bldg_id
# 119                                                222.58
# 122                                                478.90
# 150                                                508.48
# 153                                                   NaN
# 162                                               1719.98
# ...                                                   ...
# 549882                                             762.43
# 549915                                            1313.56
# 549937                                             671.69
# 549963                                             638.58
# 549989                                             666.26
#
#         iraRef_mp9_cooking_climate_npv_lower  \
# bldg_id
# 119                                    69.50
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                 61.03
# 549963                                   NaN
# 549989                                101.67
#
#         iraRef_mp9_cooking_health_npv_ap2_h6c  \
# bldg_id
# 119                                   -299.42
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                -135.35
# 549963                                    NaN
# 549989                                -208.25
#
#          iraRef_mp9_cooking_public_npv_lower_ap2_h6c  \
# bldg_id
# 119                                          -229.92
# 122                                              NaN
# 150                                              NaN
# 153                                              NaN
# 162                                              NaN
# ...                                              ...
# 549882                                           NaN
# 549915                                           NaN
# 549937                                        -74.32
# 549963                                           NaN
# 549989                                       -106.58
#
#          iraRef_mp9_cooking_climate_npv_central  \
# bldg_id
# 119                                      246.33
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                   215.90
# 549963                                      NaN
# 549989                                   360.67
#
#         iraRef_mp9_cooking_public_npv_central_ap2_h6c  \
# bldg_id
# 119                                            -53.09
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                          80.55
# 549963                                            NaN
# 549989                                         152.42
#
#          iraRef_mp9_cooking_climate_npv_upper  \
# bldg_id
# 119                                    390.79
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                 342.13
# 549963                                    NaN
# 549989                                 572.35
#
#         iraRef_mp9_cooking_public_npv_upper_ap2_h6c
# bldg_id
# 119                                           91.37
# 122                                             NaN
# 150                                             NaN
# 153                                             NaN
# 162                                             NaN
# ...                                             ...
# 549882                                          NaN
# 549915                                          NaN
# 549937                                       206.78
# 549963                                          NaN
# 549989                                       364.10
#
# [15651 rows x 665 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_clothesDrying_public_npv_central_easiur_h6c  \
# bldg_id
# 119                                                 182.16
# 122                                                 351.60
# 150                                                 379.84
# 153                                                    NaN
# 162                                                1262.90
# ...                                                    ...
# 549882                                              556.94
# 549915                                              961.39
# 549937                                              454.78
# 549963                                              404.34
# 549989                                              452.62
#
#         iraRef_mp9_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                         357.75
# 122                                         380.96
# 150                                         442.35
# 153                                            NaN
# 162                                        1368.22
# ...                                            ...
# 549882                                      613.48
# 549915                                     1068.42
# 549937                                      799.95
# 549963                                      536.06
# 549989                                      552.77
#
#         iraRef_mp9_clothesDrying_public_npv_upper_easiur_h6c  \
# bldg_id
# 119                                                 314.96
# 122                                                 493.62
# 150                                                 544.75
# 153                                                    NaN
# 162                                                1773.00
# ...                                                    ...
# 549882                                              785.65
# 549915                                             1359.69
# 549937                                              751.57
# 549963                                              603.70
# 549989                                              658.71
#
#         iraRef_mp9_cooking_climate_npv_lower  \
# bldg_id
# 119                                    69.50
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                 61.03
# 549963                                   NaN
# 549989                                101.67
#
#         iraRef_mp9_cooking_health_npv_easiur_h6c  \
# bldg_id
# 119                                      -152.59
# 122                                          NaN
# 150                                          NaN
# 153                                          NaN
# 162                                          NaN
# ...                                          ...
# 549882                                       NaN
# 549915                                       NaN
# 549937                                    -77.98
# 549963                                       NaN
# 549989                                   -112.46
#
#          iraRef_mp9_cooking_public_npv_lower_easiur_h6c  \
# bldg_id
# 119                                              -83.09
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                           -16.95
# 549963                                              NaN
# 549989                                           -10.79
#
#          iraRef_mp9_cooking_climate_npv_central  \
# bldg_id
# 119                                      246.33
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                   215.90
# 549963                                      NaN
# 549989                                   360.67
#
#         iraRef_mp9_cooking_public_npv_central_easiur_h6c  \
# bldg_id
# 119                                                93.74
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                            137.92
# 549963                                               NaN
# 549989                                            248.21
#
#          iraRef_mp9_cooking_climate_npv_upper  \
# bldg_id
# 119                                    390.79
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                 342.13
# 549963                                    NaN
# 549989                                 572.35
#
#         iraRef_mp9_cooking_public_npv_upper_easiur_h6c
# bldg_id
# 119                                             238.20
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                          264.15
# 549963                                             NaN
# 549989                                          459.89
#
# [15651 rows x 665 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_clothesDrying_public_npv_central_inmap_h6c  \
# bldg_id
# 119                                                 277.48
# 122                                                 313.01
# 150                                                 438.87
# 153                                                    NaN
# 162                                                1124.25
# ...                                                    ...
# 549882                                              638.18
# 549915                                              997.02
# 549937                                              391.38
# 549963                                              412.80
# 549989                                              484.13
#
#         iraRef_mp9_clothesDrying_climate_npv_upper  \
# bldg_id
# 119                                         357.75
# 122                                         380.96
# 150                                         442.35
# 153                                            NaN
# 162                                        1368.22
# ...                                            ...
# 549882                                      613.48
# 549915                                     1068.42
# 549937                                      799.95
# 549963                                      536.06
# 549989                                      552.77
#
#         iraRef_mp9_clothesDrying_public_npv_upper_inmap_h6c  \
# bldg_id
# 119                                                 410.28
# 122                                                 455.03
# 150                                                 603.78
# 153                                                    NaN
# 162                                                1634.35
# ...                                                    ...
# 549882                                              866.89
# 549915                                             1395.32
# 549937                                              688.17
# 549963                                              612.16
# 549989                                              690.22
#
#         iraRef_mp9_cooking_climate_npv_lower  \
# bldg_id
# 119                                    69.50
# 122                                      NaN
# 150                                      NaN
# 153                                      NaN
# 162                                      NaN
# ...                                      ...
# 549882                                   NaN
# 549915                                   NaN
# 549937                                 61.03
# 549963                                   NaN
# 549989                                101.67
#
#         iraRef_mp9_cooking_health_npv_inmap_h6c  \
# bldg_id
# 119                                       41.85
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                  -131.19
# 549963                                      NaN
# 549989                                  -188.27
#
#          iraRef_mp9_cooking_public_npv_lower_inmap_h6c  \
# bldg_id
# 119                                             111.35
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                          -70.16
# 549963                                             NaN
# 549989                                          -86.60
#
#          iraRef_mp9_cooking_climate_npv_central  \
# bldg_id
# 119                                      246.33
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                   215.90
# 549963                                      NaN
# 549989                                   360.67
#
#         iraRef_mp9_cooking_public_npv_central_inmap_h6c  \
# bldg_id
# 119                                              288.18
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                            84.71
# 549963                                              NaN
# 549989                                           172.40
#
#          iraRef_mp9_cooking_climate_npv_upper  \
# bldg_id
# 119                                    390.79
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                 342.13
# 549963                                    NaN
# 549989                                 572.35
#
#         iraRef_mp9_cooking_public_npv_upper_inmap_h6c
# bldg_id
# 119                                            432.64
# 122                                               NaN
# 150                                               NaN
# 153                                               NaN
# 162                                               NaN
# ...                                               ...
# 549882                                            NaN
# 549915                                            NaN
# 549937                                         210.94
# 549963                                            NaN
# 549989                                         384.08
#
# [15651 rows x 665 columns]

# %%
print(f"""
====================================================================================================================================================================
SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PRIVATE IMPACT
====================================================================================================================================================================
STEP 1: Calculate annual operating (fuel) costs                                                          [COMPLETED]
STEP 2: Calculate equipment capital costs (HEATING: include ductwork and weatherization (MP9 and MP10))  [COMPLETED]
STEP 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)        [COMPLETED]
STEP 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
----------------------------------------------------------------------------------------------------------------------

RESULTS OUTPUT (AEO2023 REFERENCE CASE):
""")


# ========================== AP2  ========================== 
df_euss_am_mp9_home_ap2 = calculate_private_npv(
    df=df_euss_am_mp9_home_ap2,
    df_fuel_costs=df_mp9_IRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='AEO2023 Reference Case',
    base_year=2024,
    verbose=False  # Add this parameter
    )

# ====================== EASIUR ========================== 
df_euss_am_mp9_home_easiur = calculate_private_npv(
    df=df_euss_am_mp9_home_easiur,
    df_fuel_costs=df_mp9_IRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='AEO2023 Reference Case',
    base_year=2024,
    verbose=False  # Add this parameter
    )

# ====================== InMAP ========================== 
df_euss_am_mp9_home_inmap = calculate_private_npv(
    df=df_euss_am_mp9_home_inmap,
    df_fuel_costs=df_mp9_IRA_fuel_costs,
    df_baseline_costs=df_baseline_fuel_costs,
    menu_mp=menu_mp,
    input_mp=input_mp,
    policy_scenario='AEO2023 Reference Case',
    base_year=2024,
    verbose=False  # Add this parameter
    )



print(f"""  
=====================================================================================================================================================================
DATAFRAME FOR mp9 AFTER CALCULATING PRIVATE NPV (AEO2023 REFERENCE CASE): df_euss_am_mp9_home

-----------------------------------------------
AP2: 
-----------------------------------------------
      
{df_euss_am_mp9_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp9_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp9_home_inmap}
      
""")
# Out:
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): PRIVATE IMPACT
# ====================================================================================================================================================================
# STEP 1: Calculate annual operating (fuel) costs                                                          [COMPLETED]
# STEP 2: Calculate equipment capital costs (HEATING: include ductwork and weatherization (MP9 and MP10))  [COMPLETED]
# STEP 3: Calculate replacement cost (replacing existing piece of eqipment with similar technology)        [COMPLETED]
# STEP 4: Calculate net equipment capital costs and private NPV (less WTP and more WTP)
# ----------------------------------------------------------------------------------------------------------------------
#
# RESULTS OUTPUT (AEO2023 REFERENCE CASE):
#
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Calculating costs for heating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Verifying masking for all calculated columns:
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Calculating costs for heating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Verifying masking for all calculated columns:
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Calculating costs for heating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for heating with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Calculating costs for waterHeating...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for waterHeating with lifetime: 12 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Calculating costs for clothesDrying...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for clothesDrying with lifetime: 13 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Calculating costs for cooking...
#           input_mp: upgrade09, menu_mp: 9, policy_scenario: AEO2023 Reference Case
# Calculating Private NPV for cooking with lifetime: 15 years
#           policy_scenario: AEO2023 Reference Case --> scenario_prefix: iraRef_mp9_
#
#
# Verifying masking for all calculated columns:
#
# =====================================================================================================================================================================
# DATAFRAME FOR mp9 AFTER CALCULATING PRIVATE NPV (AEO2023 REFERENCE CASE): df_euss_am_mp9_home
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                         -830.10
# 122                                          449.48
# 150                                          -63.36
# 153                                         4704.24
# 162                                        -2368.56
# ...                                             ...
# 549882                                     -1648.87
# 549915                                      2667.87
# 549937                                     -1975.26
# 549963                                     -1207.84
# 549989                                      -951.65
#
#         iraRef_mp9_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                         1061.38
# 122                                         3311.92
# 150                                         1010.63
# 153                                         7411.80
# 162                                         -275.62
# ...                                             ...
# 549882                                        12.37
# 549915                                      3805.98
# 549937                                       -83.78
# 549963                                       453.40
# 549989                                      1755.91
#
#         iraRef_mp9_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                        1624.36
# 122                                        1696.94
# 150                                         653.96
# 153                                            NaN
# 162                                        2054.01
# ...                                            ...
# 549882                                     1717.51
# 549915                                      885.33
# 549937                                     2472.00
# 549963                                     1440.70
# 549989                                     2050.39
#
#         iraRef_mp9_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                       316.38
# 122                                       702.88
# 150                                      -340.10
# 153                                          NaN
# 162                                      1059.95
# ...                                          ...
# 549882                                    723.45
# 549915                                   -108.73
# 549937                                   1164.02
# 549963                                    446.64
# 549989                                   1056.33
#
#         iraRef_mp9_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                         -1796.42
# 122                                         -1490.22
# 150                                          -413.87
# 153                                              NaN
# 162                                         -1311.32
# ...                                              ...
# 549882                                      -1384.60
# 549915                                       -305.44
# 549937                                      -2953.30
# 549963                                      -1140.69
# 549989                                      -1750.38
#
#          iraRef_mp9_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                           -488.44
# 122                                           -496.16
# 150                                            580.19
# 153                                               NaN
# 162                                           -317.26
# ...                                               ...
# 549882                                        -390.54
# 549915                                         688.62
# 549937                                       -1645.32
# 549963                                        -146.63
# 549989                                        -756.32
#
#          iraRef_mp9_cooking_total_capitalCost  \
# bldg_id
# 119                                    679.32
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                2119.37
# 549963                                    NaN
# 549989                                2088.81
#
#         iraRef_mp9_cooking_net_capitalCost  \
# bldg_id
# 119                                -393.22
# 122                                    NaN
# 150                                    NaN
# 153                                    NaN
# 162                                    NaN
# ...                                    ...
# 549882                                 NaN
# 549915                                 NaN
# 549937                             1046.83
# 549963                                 NaN
# 549989                             1016.27
#
#          iraRef_mp9_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                    -1076.86
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -2659.08
# 549963                                      NaN
# 549989                                 -1663.21
#
#         iraRef_mp9_cooking_private_npv_moreWTP
# bldg_id
# 119                                      -4.32
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                -1586.54
# 549963                                     NaN
# 549989                                 -590.67
#
# [15651 rows x 681 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                         -830.10
# 122                                          449.48
# 150                                          -63.36
# 153                                         4704.24
# 162                                        -2368.56
# ...                                             ...
# 549882                                     -1648.87
# 549915                                      2667.87
# 549937                                     -1975.26
# 549963                                     -1207.84
# 549989                                      -951.65
#
#         iraRef_mp9_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                         1061.38
# 122                                         3311.92
# 150                                         1010.63
# 153                                         7411.80
# 162                                         -275.62
# ...                                             ...
# 549882                                        12.37
# 549915                                      3805.98
# 549937                                       -83.78
# 549963                                       453.40
# 549989                                      1755.91
#
#         iraRef_mp9_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                        1624.36
# 122                                        1696.94
# 150                                         653.96
# 153                                            NaN
# 162                                        2054.01
# ...                                            ...
# 549882                                     1717.51
# 549915                                      885.33
# 549937                                     2472.00
# 549963                                     1440.70
# 549989                                     2050.39
#
#         iraRef_mp9_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                       316.38
# 122                                       702.88
# 150                                      -340.10
# 153                                          NaN
# 162                                      1059.95
# ...                                          ...
# 549882                                    723.45
# 549915                                   -108.73
# 549937                                   1164.02
# 549963                                    446.64
# 549989                                   1056.33
#
#         iraRef_mp9_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                         -1796.42
# 122                                         -1490.22
# 150                                          -413.87
# 153                                              NaN
# 162                                         -1311.32
# ...                                              ...
# 549882                                      -1384.60
# 549915                                       -305.44
# 549937                                      -2953.30
# 549963                                      -1140.69
# 549989                                      -1750.38
#
#          iraRef_mp9_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                           -488.44
# 122                                           -496.16
# 150                                            580.19
# 153                                               NaN
# 162                                           -317.26
# ...                                               ...
# 549882                                        -390.54
# 549915                                         688.62
# 549937                                       -1645.32
# 549963                                        -146.63
# 549989                                        -756.32
#
#          iraRef_mp9_cooking_total_capitalCost  \
# bldg_id
# 119                                    679.32
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                2119.37
# 549963                                    NaN
# 549989                                2088.81
#
#         iraRef_mp9_cooking_net_capitalCost  \
# bldg_id
# 119                                -393.22
# 122                                    NaN
# 150                                    NaN
# 153                                    NaN
# 162                                    NaN
# ...                                    ...
# 549882                                 NaN
# 549915                                 NaN
# 549937                             1046.83
# 549963                                 NaN
# 549989                             1016.27
#
#          iraRef_mp9_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                    -1076.86
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -2659.08
# 549963                                      NaN
# 549989                                 -1663.21
#
#         iraRef_mp9_cooking_private_npv_moreWTP
# bldg_id
# 119                                      -4.32
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                -1586.54
# 549963                                     NaN
# 549989                                 -590.67
#
# [15651 rows x 681 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_waterHeating_private_npv_lessWTP  \
# bldg_id
# 119                                         -830.10
# 122                                          449.48
# 150                                          -63.36
# 153                                         4704.24
# 162                                        -2368.56
# ...                                             ...
# 549882                                     -1648.87
# 549915                                      2667.87
# 549937                                     -1975.26
# 549963                                     -1207.84
# 549989                                      -951.65
#
#         iraRef_mp9_waterHeating_private_npv_moreWTP  \
# bldg_id
# 119                                         1061.38
# 122                                         3311.92
# 150                                         1010.63
# 153                                         7411.80
# 162                                         -275.62
# ...                                             ...
# 549882                                        12.37
# 549915                                      3805.98
# 549937                                       -83.78
# 549963                                       453.40
# 549989                                      1755.91
#
#         iraRef_mp9_clothesDrying_total_capitalCost  \
# bldg_id
# 119                                        1624.36
# 122                                        1696.94
# 150                                         653.96
# 153                                            NaN
# 162                                        2054.01
# ...                                            ...
# 549882                                     1717.51
# 549915                                      885.33
# 549937                                     2472.00
# 549963                                     1440.70
# 549989                                     2050.39
#
#         iraRef_mp9_clothesDrying_net_capitalCost  \
# bldg_id
# 119                                       316.38
# 122                                       702.88
# 150                                      -340.10
# 153                                          NaN
# 162                                      1059.95
# ...                                          ...
# 549882                                    723.45
# 549915                                   -108.73
# 549937                                   1164.02
# 549963                                    446.64
# 549989                                   1056.33
#
#         iraRef_mp9_clothesDrying_private_npv_lessWTP  \
# bldg_id
# 119                                         -1796.42
# 122                                         -1490.22
# 150                                          -413.87
# 153                                              NaN
# 162                                         -1311.32
# ...                                              ...
# 549882                                      -1384.60
# 549915                                       -305.44
# 549937                                      -2953.30
# 549963                                      -1140.69
# 549989                                      -1750.38
#
#          iraRef_mp9_clothesDrying_private_npv_moreWTP  \
# bldg_id
# 119                                           -488.44
# 122                                           -496.16
# 150                                            580.19
# 153                                               NaN
# 162                                           -317.26
# ...                                               ...
# 549882                                        -390.54
# 549915                                         688.62
# 549937                                       -1645.32
# 549963                                        -146.63
# 549989                                        -756.32
#
#          iraRef_mp9_cooking_total_capitalCost  \
# bldg_id
# 119                                    679.32
# 122                                       NaN
# 150                                       NaN
# 153                                       NaN
# 162                                       NaN
# ...                                       ...
# 549882                                    NaN
# 549915                                    NaN
# 549937                                2119.37
# 549963                                    NaN
# 549989                                2088.81
#
#         iraRef_mp9_cooking_net_capitalCost  \
# bldg_id
# 119                                -393.22
# 122                                    NaN
# 150                                    NaN
# 153                                    NaN
# 162                                    NaN
# ...                                    ...
# 549882                                 NaN
# 549915                                 NaN
# 549937                             1046.83
# 549963                                 NaN
# 549989                             1016.27
#
#          iraRef_mp9_cooking_private_npv_lessWTP  \
# bldg_id
# 119                                    -1076.86
# 122                                         NaN
# 150                                         NaN
# 153                                         NaN
# 162                                         NaN
# ...                                         ...
# 549882                                      NaN
# 549915                                      NaN
# 549937                                 -2659.08
# 549963                                      NaN
# 549989                                 -1663.21
#
#         iraRef_mp9_cooking_private_npv_moreWTP
# bldg_id
# 119                                      -4.32
# 122                                        NaN
# 150                                        NaN
# 153                                        NaN
# 162                                        NaN
# ...                                        ...
# 549882                                     NaN
# 549915                                     NaN
# 549937                                -1586.54
# 549963                                     NaN
# 549989                                 -590.67
#
# [15651 rows x 681 columns]

# %%
print(f"""
====================================================================================================================================================================
SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): ADOPTION POTENTIAL
====================================================================================================================================================================
determine_adoption_potential_sensitivity.py file contains the definitions for:
- adoption_decision function (combined climate + health analysis)
- calculate_climate_only_adoption_robust function (climate-only analysis)
- calculate_health_only_adoption_robust function (health-only analysis)
      
RESULTS OUTPUT (AEO2023 REFERENCE CASE):
""")

# ========================== AP2  ========================== 
print("Processing AP2 model...")

# Combined climate + health analysis (existing)
df_euss_am_mp9_home_ap2 = adoption_decision(
    df=df_euss_am_mp9_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='ap2',
    cr_function='acs',
    )

df_euss_am_mp9_home_ap2 = adoption_decision(
    df=df_euss_am_mp9_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='ap2',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp9_home_ap2 = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp9_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp9_home_ap2 = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='ap2',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp9_home_ap2 = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_ap2,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='ap2',
    cr_function='h6c',
    verbose=False
    )

# ====================== EASIUR ========================== 
print("Processing EASIUR model...")

# Combined climate + health analysis (existing)
df_euss_am_mp9_home_easiur = adoption_decision(
    df=df_euss_am_mp9_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='easiur',
    cr_function='acs',
    )

df_euss_am_mp9_home_easiur = adoption_decision(
    df=df_euss_am_mp9_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='easiur',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp9_home_easiur = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp9_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp9_home_easiur = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='easiur',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp9_home_easiur = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_easiur,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='easiur',
    cr_function='h6c',
    verbose=False
    )

# ====================== InMAP ========================== 
print("Processing InMAP model...")

# Combined climate + health analysis (existing)
df_euss_am_mp9_home_inmap = adoption_decision(
    df=df_euss_am_mp9_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='inmap',
    cr_function='acs',
    )

df_euss_am_mp9_home_inmap = adoption_decision(
    df=df_euss_am_mp9_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='inmap',
    cr_function='h6c',
    )

# Climate-only analysis (new)
df_euss_am_mp9_home_inmap = calculate_climate_only_adoption_robust(
    df=df_euss_am_mp9_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    verbose=False
    )

# Health-only analysis (new)
df_euss_am_mp9_home_inmap = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='inmap',
    cr_function='acs',
    verbose=False
    )

df_euss_am_mp9_home_inmap = calculate_health_only_adoption_robust(
    df=df_euss_am_mp9_home_inmap,
    menu_mp=menu_mp,
    policy_scenario='AEO2023 Reference Case',
    rcm_model='inmap',
    cr_function='h6c',
    verbose=False
    )

print(f"""
====================================================================================================================================================================
DATAFRAME FOR MP9 AFTER DETERMINING ADOPTION FEASIBILITY (AEO2023 REFERENCE CASE): df_euss_am_mp9_home
Includes: Combined (Climate + Health), Climate-Only, and Health-Only Adoption Analysis

-----------------------------------------------   
AP2: 
-----------------------------------------------
      
{df_euss_am_mp9_home_ap2}

-----------------------------------------------
EASIUR:
-----------------------------------------------

{df_euss_am_mp9_home_easiur}

-----------------------------------------------
InMAP:
-----------------------------------------------

{df_euss_am_mp9_home_inmap}
      
""")
# Out:
# ====================================================================================================================================================================
# SCENARIO ANALYSIS (AEO2023 REFERENCE CASE): ADOPTION POTENTIAL
# ====================================================================================================================================================================
# determine_adoption_potential_sensitivity.py file contains the definitions for:
# - adoption_decision function (combined climate + health analysis)
# - calculate_climate_only_adoption_robust function (climate-only analysis)
# - calculate_health_only_adoption_robust function (health-only analysis)
#
# RESULTS OUTPUT (AEO2023 REFERENCE CASE):
#
# Processing AP2 model...
# Fixed 12 duplicate columns
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | ap2-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | ap2-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Climate-only Analysis: AEO2023 Reference Case
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | ap2-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | ap2-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# Processing EASIUR model...
# Fixed 12 duplicate columns
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | easiur-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | easiur-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Climate-only Analysis: AEO2023 Reference Case
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | easiur-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | easiur-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# Processing InMAP model...
# Fixed 12 duplicate columns
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | inmap-acs
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Adoption Analysis: AEO2023 Reference Case | inmap-h6c
#
# Verifying masking for all calculated columns:
#
# Summary:
#   heating: 12,266/15,651 valid homes, 3 scenarios
#   waterHeating: 14,999/15,651 valid homes, 3 scenarios
#   clothesDrying: 14,743/15,651 valid homes, 3 scenarios
#   cooking: 7,867/15,651 valid homes, 3 scenarios
#   Total columns: 240
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Climate-only Analysis: AEO2023 Reference Case
#
# Verifying masking for all calculated columns:
#   Climate-only: 48 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | inmap-acs
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
# -- Scenario: Inflation Reduction Act (IRA) Reference --
#               scenario_prefix: 'iraRef_mp9_', cambium_scenario: 'MidCase', lookup_emissions_fossil_fuel: 'lookup_emissions_fossil_fuel',
#               lookup_emissions_electricity_climate: 'lookup_emissions_electricity_climate_IRA', lookup_emissions_electricity_health: 'lookup_emissions_electricity_health', lookup_fuel_prices: 'lookup_fuel_prices_iraRef'
#
#
# Health-only Analysis: AEO2023 Reference Case | inmap-h6c
#
# Verifying masking for all calculated columns:
#   Health-only: 8 columns added
#
# ====================================================================================================================================================================
# DATAFRAME FOR MP9 AFTER DETERMINING ADOPTION FEASIBILITY (AEO2023 REFERENCE CASE): df_euss_am_mp9_home
# Includes: Combined (Climate + Health), Climate-Only, and Health-Only Adoption Analysis
#
# -----------------------------------------------
# AP2:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                               242.01
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                          -1370.64
# 549963                                               NaN
# 549989                                           -230.00
#
#         iraRef_mp9_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                             386.47
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                        -1244.41
# 549963                                             NaN
# 549989                                          -18.32
#
#         iraRef_mp9_heating_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                           -15033.99
# 122                                            -4721.81
# 150                                            11845.30
# 153                                            -5916.64
# 162                                            -5644.57
# ...                                                 ...
# 549882                                              NaN
# 549915                                         15943.15
# 549937                                        -17596.11
# 549963                                        -13075.46
# 549989                                          -654.67
#
#         iraRef_mp9_waterHeating_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                                 945.70
# 122                                                3336.04
# 150                                                1155.79
# 153                                                7483.69
# 162                                                -370.18
# ...                                                    ...
# 549882                                             -209.00
# 549915                                             4680.49
# 549937                                             -185.91
# 549963                                              402.43
# 549989                                             1719.81
#
#         iraRef_mp9_clothesDrying_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                                -541.04
# 122                                                -458.04
# 150                                                 605.93
# 153                                                    NaN
# 162                                                -180.35
# ...                                                    ...
# 549882                                             -332.57
# 549915                                              784.04
# 549937                                            -1695.23
# 549963                                             -106.72
# 549989                                             -712.16
#
#          iraRef_mp9_cooking_total_npv_healthOnly_ap2_acs  \
# bldg_id
# 119                                              -120.85
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                          -1639.22
# 549963                                               NaN
# 549989                                           -671.71
#
#          iraRef_mp9_heating_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                            -15719.35
# 122                                             -2010.61
# 150                                             16630.37
# 153                                             -4593.00
# 162                                             -2752.33
# ...                                                  ...
# 549882                                               NaN
# 549915                                          23540.20
# 549937                                         -17759.86
# 549963                                         -13782.15
# 549989                                           -522.57
#
#         iraRef_mp9_waterHeating_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                                 764.10
# 122                                                3373.88
# 150                                                1383.59
# 153                                                7596.51
# 162                                                -518.59
# ...                                                    ...
# 549882                                             -556.47
# 549915                                             6052.85
# 549937                                             -346.23
# 549963                                              322.44
# 549989                                             1663.14
#
#          iraRef_mp9_clothesDrying_total_npv_healthOnly_ap2_h6c  \
# bldg_id
# 119                                                -623.61
# 122                                                -398.22
# 150                                                 646.32
# 153                                                    NaN
# 162                                                  34.50
# ...                                                    ...
# 549882                                             -241.59
# 549915                                              933.76
# 549937                                            -1773.58
# 549963                                              -44.11
# 549989                                             -642.83
#
#         iraRef_mp9_cooking_total_npv_healthOnly_ap2_h6c
# bldg_id
# 119                                             -303.74
# 122                                                 NaN
# 150                                                 NaN
# 153                                                 NaN
# 162                                                 NaN
# ...                                                 ...
# 549882                                              NaN
# 549915                                              NaN
# 549937                                         -1721.89
# 549963                                              NaN
# 549989                                          -798.92
#
# [15651 rows x 789 columns]
#
# -----------------------------------------------
# EASIUR:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                               242.01
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                          -1370.64
# 549963                                               NaN
# 549989                                           -230.00
#
#         iraRef_mp9_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                             386.47
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                        -1244.41
# 549963                                             NaN
# 549989                                          -18.32
#
#         iraRef_mp9_heating_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                              -13815.92
# 122                                                  95.54
# 150                                               13545.59
# 153                                               -1111.47
# 162                                                 183.13
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            16895.53
# 549937                                           -17197.16
# 549963                                           -12006.93
# 549989                                              -39.47
#
#         iraRef_mp9_waterHeating_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                                1239.48
# 122                                                3581.21
# 150                                                1234.67
# 153                                                8667.23
# 162                                                -131.33
# ...                                                    ...
# 549882                                               20.02
# 549915                                             4840.87
# 549937                                               80.75
# 549963                                              521.91
# 549989                                             1860.47
#
#         iraRef_mp9_clothesDrying_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                                -505.10
# 122                                                -452.28
# 150                                                 620.03
# 153                                                    NaN
# 162                                                -159.73
# ...                                                    ...
# 549882                                             -323.53
# 549915                                              801.98
# 549937                                            -1664.17
# 549963                                             -120.32
# 549989                                             -715.07
#
#          iraRef_mp9_cooking_total_npv_healthOnly_easiur_acs  \
# bldg_id
# 119                                                 -63.70
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1616.89
# 549963                                                 NaN
# 549989                                             -634.43
#
#          iraRef_mp9_heating_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                              -12589.69
# 122                                               10366.75
# 150                                               20999.00
# 153                                                7753.08
# 162                                               12220.89
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            25987.21
# 549937                                           -16734.81
# 549963                                           -11036.76
# 549989                                             1058.12
#
#         iraRef_mp9_waterHeating_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                                1518.98
# 122                                                4003.78
# 150                                                1586.27
# 153                                               10637.40
# 162                                                  95.12
# ...                                                    ...
# 549882                                               32.03
# 549915                                             6464.88
# 549937                                              338.93
# 549963                                              629.37
# 549989                                             2024.58
#
#          iraRef_mp9_clothesDrying_total_npv_healthOnly_easiur_h6c  \
# bldg_id
# 119                                                -531.23
# 122                                                -383.50
# 150                                                 682.59
# 153                                                    NaN
# 162                                                  87.52
# ...                                                    ...
# 549882                                             -218.37
# 549915                                              979.89
# 549937                                            -1693.70
# 549963                                              -78.99
# 549989                                             -650.38
#
#         iraRef_mp9_cooking_total_npv_healthOnly_easiur_h6c
# bldg_id
# 119                                                -156.91
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1664.52
# 549963                                                 NaN
# 549989                                             -703.13
#
# [15651 rows x 789 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region  census_division census_division_recs  \
# bldg_id
# 119              2152.0     Northeast  Middle Atlantic      Middle Atlantic
# 122              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 150              1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 153              2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 162              2663.0     Northeast  Middle Atlantic      Middle Atlantic
# ...                 ...           ...              ...                  ...
# 549882           1202.0     Northeast  Middle Atlantic      Middle Atlantic
# 549915           2176.0     Northeast  Middle Atlantic      Middle Atlantic
# 549937            885.0     Northeast  Middle Atlantic      Middle Atlantic
# 549963           1690.0     Northeast  Middle Atlantic      Middle Atlantic
# 549989           1220.0     Northeast  Middle Atlantic      Middle Atlantic
#
#         building_america_climate_zone  reeds_balancing_area gea_region state  \
# bldg_id
# 119                       Mixed-Humid                   122      RFCEc    PA
# 122                       Mixed-Humid                   122      RFCEc    PA
# 150                              Cold                   122      RFCEc    PA
# 153                       Mixed-Humid                   122      RFCEc    PA
# 162                       Mixed-Humid                   122      RFCEc    PA
# ...                               ...                   ...        ...   ...
# 549882                           Cold                   122      RFCEc    PA
# 549915                           Cold                   122      RFCEc    PA
# 549937                           Cold                   115      RFCWc    PA
# 549963                           Cold                   115      RFCWc    PA
# 549989                           Cold                   122      RFCEc    PA
#
#                             city urbanicity  ...  \
# bldg_id                                      ...
# 119        Not in a census Place   Suburban  ...
# 122      In another census Place   Suburban  ...
# 150      In another census Place      Rural  ...
# 153        Not in a census Place   Suburban  ...
# 162        Not in a census Place   Suburban  ...
# ...                          ...        ...  ...
# 549882     Not in a census Place   Suburban  ...
# 549915                 Lancaster   Suburban  ...
# 549937   In another census Place      Rural  ...
# 549963   In another census Place   Suburban  ...
# 549989     Not in a census Place      Rural  ...
#
#         iraRef_mp9_cooking_total_npv_climateOnly_central  \
# bldg_id
# 119                                               242.01
# 122                                                  NaN
# 150                                                  NaN
# 153                                                  NaN
# 162                                                  NaN
# ...                                                  ...
# 549882                                               NaN
# 549915                                               NaN
# 549937                                          -1370.64
# 549963                                               NaN
# 549989                                           -230.00
#
#         iraRef_mp9_cooking_total_npv_climateOnly_upper  \
# bldg_id
# 119                                             386.47
# 122                                                NaN
# 150                                                NaN
# 153                                                NaN
# 162                                                NaN
# ...                                                ...
# 549882                                             NaN
# 549915                                             NaN
# 549937                                        -1244.41
# 549963                                             NaN
# 549989                                          -18.32
#
#         iraRef_mp9_heating_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                             -13154.17
# 122                                               2361.94
# 150                                              16243.67
# 153                                              -2787.46
# 162                                               3050.16
# ...                                                   ...
# 549882                                                NaN
# 549915                                           17558.54
# 549937                                          -17417.77
# 549963                                          -12165.89
# 549989                                            -402.35
#
#         iraRef_mp9_waterHeating_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                                1399.77
# 122                                                3726.37
# 150                                                1364.79
# 153                                                8285.48
# 162                                                  -0.80
# ...                                                    ...
# 549882                                             -138.39
# 549915                                             4972.06
# 549937                                              -72.61
# 549963                                              503.86
# 549989                                             1764.29
#
#         iraRef_mp9_clothesDrying_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                                -467.97
# 122                                                -467.33
# 150                                                 643.01
# 153                                                    NaN
# 162                                                -213.69
# ...                                                    ...
# 549882                                             -291.93
# 549915                                              815.86
# 549937                                            -1688.82
# 549963                                             -117.02
# 549989                                             -702.81
#
#          iraRef_mp9_cooking_total_npv_healthOnly_inmap_acs  \
# bldg_id
# 119                                                  11.98
# 122                                                    NaN
# 150                                                    NaN
# 153                                                    NaN
# 162                                                    NaN
# ...                                                    ...
# 549882                                                 NaN
# 549915                                                 NaN
# 549937                                            -1637.60
# 549963                                                 NaN
# 549989                                             -663.97
#
#          iraRef_mp9_heating_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                              -10889.49
# 122                                               16189.89
# 150                                               27931.16
# 153                                                3446.90
# 162                                               19587.22
# ...                                                    ...
# 549882                                                 NaN
# 549915                                            27690.64
# 549937                                           -17301.63
# 549963                                           -11445.14
# 549989                                              125.63
#
#         iraRef_mp9_waterHeating_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                                1930.82
# 122                                                4376.88
# 150                                                1920.60
# 153                                                9656.57
# 162                                                 430.52
# ...                                                    ...
# 549882                                             -374.95
# 549915                                             6801.97
# 549937                                              -55.05
# 549963                                              583.10
# 549989                                             1777.45
#
#          iraRef_mp9_clothesDrying_total_npv_healthOnly_inmap_h6c  \
# bldg_id
# 119                                                -435.91
# 122                                                -422.09
# 150                                                 741.62
# 153                                                    NaN
# 162                                                 -51.13
# ...                                                    ...
# 549882                                             -137.13
# 549915                                             1015.52
# 549937                                            -1757.10
# 549963                                              -70.53
# 549989                                             -618.87
#
#         iraRef_mp9_cooking_total_npv_healthOnly_inmap_h6c
# bldg_id
# 119                                                 37.53
# 122                                                   NaN
# 150                                                   NaN
# 153                                                   NaN
# 162                                                   NaN
# ...                                                   ...
# 549882                                                NaN
# 549915                                                NaN
# 549937                                           -1717.73
# 549963                                                NaN
# 549989                                            -778.94
#
# [15651 rows x 789 columns]

# %% [markdown]
# # Model Runtime

# %%
# Flag to prevent excessive output in other scenario files
individual_scenario_run = False

# Get the current datetime again
end_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Calculate the elapsed time
elapsed_time = datetime.strptime(end_time, "%Y-%m-%d_%H-%M-%S") - datetime.strptime(start_time, "%Y-%m-%d_%H-%M-%S")

# Format the elapsed time
elapsed_seconds = elapsed_time.total_seconds()
elapsed_minutes = int(elapsed_seconds // 60)
elapsed_seconds = int(elapsed_seconds % 60)

# Print the elapsed time
print(f"The code took {elapsed_minutes} minutes and {elapsed_seconds} seconds to execute.")
# Out:
# The code took 3 minutes and 3 seconds to execute.
