# %%
"""
This file runs all of the code responsible for generating the output CSVs but does not visualize the data.
Data visualization is done in the main program.
"""
# Out:
# '\nThis file runs all of the code responsible for generating the output CSVs but does not visualize the data.\nData visualization is done in the main program.\n'

# %%
import os
import pandas as pd
# from IPython import get_ipython

# Format the name of the exported results file using the location ID
from datetime import datetime
result_export_time = datetime.now()
results_export_formatted_date = result_export_time.strftime("%Y-%m-%d_%H-%M")

from config import PROJECT_ROOT
from cmu_tare_model.utils.export_model_run_results import export_model_run_output

print(f"""
The results will be exported using the export_model_run_output function.
Documentation for this function:
{export_model_run_output.__doc__}

""")
# Out:
# Project root directory: c:\users\14128\research\cmu-tare-model
#
# The results will be exported using the export_model_run_output function.
# Documentation for this function:
# Export data for various result categories to appropriate directories.
#
#     This function exports DataFrame results to CSV files in the appropriate
#     directory based on the results category and measure package. It supports
#     the expanded sensitivity analysis categories and directory structure.
#
#     Args:
#         df_results_export: DataFrame containing the data to be exported.
#         results_category: Type of results being exported:
#             - For summaries: 'summary_baseline', 'summary_basic_ap2', etc.
#             - For damages: 'damages_climate_IRA', 'damages_climate_noIRA', etc.
#             - For fuel costs: 'fuel_costs_IRA', 'fuel_costs_noIRA'
#             - For consumption: 'consumption'
#         menu_mp: Measure package identifier (0 for baseline, 8/9/10 for retrofits).
#         output_folder_path: Base directory for exporting results. If None, uses
#             a global/predefined variable.
#         location_id: Location identifier for the filename. If None, uses
#             a global/predefined variable.
#         results_export_formatted_date: Formatted date string for the filename. If None,
#             uses a global/predefined variable.
#
#     Raises:
#         ValueError: If the results_category is not recognized or if required
#             parameters are missing.
#         OSError: If there is an error creating directories or writing the file.

# %% [markdown]
# # Baseline Scenario

# %%
# ===================================================================================================================================================================================
# Measure Package 0: Baseline
# ===================================================================================================================================================================================
# BASELINE Pre-IRA Scenario:
menu_mp = 0
input_mp = 'baseline'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_baseline_v2_1.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")

print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Baseline Scenario - Model Run Complete")
# Out:
# PROJECT_ROOT (from config.py): c:\users\14128\research\cmu-tare-model
# Running file: c:/users/14128/research/cmu-tare-model/cmu_tare_model/model_scenarios/tare_baseline_v2_1.ipynb
#
# =========================================================================================================
# Welcome to the Trade-off Analysis of residential Retrofits for energy Equity Tool (TARE Model)
# Let's start by reading the data from the NREL EUSS Database.
#
# Make sure that the zipped folders stay organized as they are once unzipped.
# If changes are made to the file path, then the program will not run properly.
# ==========================================================================================================
#
# Project root directory: c:\users\14128\research\cmu-tare-model
# Result outputs will be exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results
#
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# Load data from the NREL EUSS Database for the baseline scenario and apply various filters.
#
# DATA: NREL EUSS Database
# HOUSING FILTERS: Occupied units and Single Family Homes
# GEOGRAPHIC FILTERS: National, State, or City
#
# Additional details data can be found in the official End-Use Load Profiles/Savings Shapes documentation.
# Our methodology is detailed in the process_euss_data.py file and its associated imports.
#
# RESULTS OUTPUT:
#
# Retrieved data for filename: baseline_metadata_and_annual_results.csv
# Located at filepath: c:\users\14128\research\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\state\baseline_metadata_and_annual_results.csv
# You chose to analyze all of the United States.
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline
#
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 239            0  242.131013           True   1690.0
# 273            0  242.131013           True   1690.0
# 307            0  242.131013           True   1220.0
# 409            0  242.131013           True   1220.0
# 517            0  242.131013           True   1220.0
# ...          ...         ...            ...      ...
# 548226         0  242.131013           True   2176.0
# 548228         0  242.131013           True   1690.0
# 548417         0  242.131013           True    885.0
# 549740         0  242.131013           True   1220.0
# 549938         0  242.131013           True    885.0
#
#                        in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 239      Non-CBSA East South Central                               3A
# 273      Non-CBSA East South Central                               3A
# 307      Non-CBSA East South Central                               3A
# 409      Non-CBSA East South Central                               3A
# 517      Non-CBSA East South Central                               3A
# ...                              ...                              ...
# 548226             Non-CBSA Mountain                               6B
# 548228             Non-CBSA Mountain                               6B
# 548417             Non-CBSA Mountain                               6B
# 549740             Non-CBSA Mountain                               7B
# 549938             Non-CBSA Mountain                               6B
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 239                                             3A                     Hour20
# 273                                             3A                     Hour12
# 307                                             3A                      Hour0
# 409                                             3A                     Hour20
# 517                                             3A                      Hour1
# ...                                            ...                        ...
# 548226                                          6B                      Hour3
# 548228                                          6B                      Hour6
# 548417                                          6B                     Hour18
# 549740                                          7B                      Hour4
# 549938                                          6B                      Hour2
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 239                3                        Hot-Humid  ...
# 273                3                      Mixed-Humid  ...
# 307                4                        Hot-Humid  ...
# 409                2                        Hot-Humid  ...
# 517                3                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 548226             4                             Cold  ...
# 548228             4                             Cold  ...
# 548417             2                             Cold  ...
# 549740             2                        Very Cold  ...
# 549938             2                             Cold  ...
#
#         out.emissions.natural_gas.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 239                                             215.943534
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1642.477930
# 517                                               0.000000
# ...                                                    ...
# 548226                                        15324.356044
# 548228                                         8192.601682
# 548417                                         5212.758359
# 549740                                            0.000000
# 549938                                         9625.513133
#
#         out.emissions.propane.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 239                                               0.000000
# 273                                               0.000000
# 307                                               0.000000
# 409                                               0.000000
# 517                                               0.000000
# ...                                                    ...
# 548226                                            0.000000
# 548228                                            0.000000
# 548417                                            0.000000
# 549740                                          268.627834
# 549938                                            0.000000
#
#         out.emissions.electricity.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                            8773.384074
# 273                                           11296.731129
# 307                                            8750.011820
# 409                                            5725.103641
# 517                                            8932.439414
# ...                                                    ...
# 548226                                         2313.298407
# 548228                                         1889.439924
# 548417                                         2112.907195
# 549740                                        11423.104685
# 549938                                         1109.233379
#
#         out.emissions.fuel_oil.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                                    0.0
# 273                                                    0.0
# 307                                                    0.0
# 409                                                    0.0
# 517                                                    0.0
# ...                                                    ...
# 548226                                                 0.0
# 548228                                                 0.0
# 548417                                                 0.0
# 549740                                                 0.0
# 549938                                                 0.0
#
#         out.emissions.natural_gas.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                             215.943534
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1642.477930
# 517                                               0.000000
# ...                                                    ...
# 548226                                        15324.356044
# 548228                                         8192.601682
# 548417                                         5212.758359
# 549740                                            0.000000
# 549938                                         9625.513133
#
#         out.emissions.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                               0.000000
# 273                                               0.000000
# 307                                               0.000000
# 409                                               0.000000
# 517                                               0.000000
# ...                                                    ...
# 548226                                            0.000000
# 548228                                            0.000000
# 548417                                            0.000000
# 549740                                          268.627834
# 549938                                            0.000000
#
#         out.emissions.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 239                                            3565.038262
# 273                                            4339.903757
# 307                                            3345.187937
# 409                                            3784.993820
# 517                                            3441.414837
# ...                                                    ...
# 548226                                        16802.023908
# 548228                                         9394.122057
# 548417                                         6546.826589
# 549740                                         7173.561517
# 549938                                        10320.128613
#
#         out.emissions.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 239                                            6416.193347
# 273                                            8193.678510
# 307                                            6249.625611
# 409                                            5489.549041
# 517                                            6415.303853
# ...                                                    ...
# 548226                                        16545.095582
# 548228                                         9195.903552
# 548417                                         6318.763521
# 549740                                         5931.433285
# 549938                                        10198.241539
#
#         out.emissions.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 239                                            5755.373221
# 273                                            7254.665194
# 307                                            5587.946834
# 409                                            5164.458936
# 517                                            5721.073473
# ...                                                    ...
# 548226                                        16472.920871
# 548228                                         9129.578822
# 548417                                         6253.986448
# 549740                                         4609.821155
# 549938                                        10166.744085
#
#         out.emissions.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg
# bldg_id
# 239                                            8989.327608
# 273                                           11296.731129
# 307                                            8750.011820
# 409                                            7367.581571
# 517                                            8932.439414
# ...                                                    ...
# 548226                                        17637.654451
# 548228                                        10082.041606
# 548417                                         7325.665554
# 549740                                        11691.732519
# 549938                                        10734.746512
#
# [331531 rows x 259 columns]
#
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR BASELINE SCENARIO: MEASURE PACKAGE 0 (MP0)
# ====================================================================================================================================================================
# In addition to the housing type and occupancy filters, the data has been filtered for fuel and technology
# Please see the energy_consumption_and_metadata folder for more details on data processing.
#
# We employ the df_enduse_refactored function to process the data and create a new dataframe, which is part of the 5-step data validation process:
# 1. Mask Initialization with initialize_validation_tracking()
# 2. Series Initialization with create_retrofit_only_series()
# 3. Valid-Only Calculation for qualifying homes
# 4. Valid-Only Updates using list-based collection
# 5. Final Masking with apply_final_masking()
#
# Documentation for df_enduse_refactored function:
# Creates a standardized energy usage DataFrame and applies data quality filters.
#
#     This function creates a new DataFrame with standardized column names and structure,
#     calculates total consumption by fuel type, creates data quality flags for analysis,
#     and sets invalid consumption values to NaN.
#
#     Args:
#         df_baseline: The baseline DataFrame containing raw EUSS/ResStock data.
#
#     Returns:
#         A standardized DataFrame with processed consumption data and data quality flags.
#
#     Raises:
#         ValueError: If required columns are missing from the input DataFrame.
#
# ----------------------------------------------------------------
#
# RESULTS OUTPUT (BASELINE):
#
# Processing column: in.clothes_dryer
# Initial data types: object
# Data types after processing: object
# Processing column: in.cooking_range
# Initial data types: object
# Data types after processing: object
# Calculated total heating consumption
# Calculated total waterHeating consumption
# Calculated total clothesDrying consumption
# Calculated total cooking consumption
#
# Creating data quality flags for all categories
#
# --- Processing heating ---
# Values in base_heating_fuel (top 5):
# base_heating_fuel
# Natural Gas    180939
# Electricity    105792
# Propane         17474
# Fuel Oil        17152
# Other Fuel       9277
# Name: count, dtype: int64
#   heating: Found 10174 homes (3.1%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_heating_fuel
# Other Fuel    9277
# Name: count, dtype: int64
# Values in heating_type (top 5):
# heating_type
# Natural Gas Fuel Furnace               133233
# Electricity Electric Furnace            49934
# Electricity ASHP                        31347
# Natural Gas Fuel Wall/Floor Furnace     24219
# Electricity Baseboard                   23383
# Name: count, dtype: int64
# Allowed values for heating:
# ['Electricity Baseboard', 'Electricity Electric Boiler', 'Electricity Electric Furnace', 'Fuel Oil Fuel Boiler', 'Fuel Oil Fuel Furnace', 'Natural Gas Fuel Boiler', 'Natural Gas Fuel Furnace', 'Propane Fuel Boiler', 'Propane Fuel Furnace']
#   heating: Found 71320 homes (21.5%) with invalid technology types
#   Invalid technology types (top 5):
# heating_type
# Electricity ASHP                       31347
# Natural Gas Fuel Wall/Floor Furnace    24219
# Propane Fuel Wall/Floor Furnace         3531
# Natural Gas Shared Heating               740
# Fuel Oil Fuel Wall/Floor Furnace         516
# Name: count, dtype: int64
#   heating: Total 71320 homes (21.5%) excluded from analysis
#
# --- Processing waterHeating ---
# Values in base_waterHeating_fuel (top 5):
# base_waterHeating_fuel
# Natural Gas    178823
# Electricity    130283
# Propane         12905
# Fuel Oil         8851
# Other Fuel        669
# Name: count, dtype: int64
#   waterHeating: Found 669 homes (0.2%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_waterHeating_fuel
# Other Fuel    669
# Name: count, dtype: int64
# Values in waterHeating_type (top 5):
# waterHeating_type
# Natural Gas Standard    154319
# Electric Standard       112162
# Natural Gas Premium      21890
# Electric Premium         15369
# Propane Standard         10873
# Name: count, dtype: int64
# Allowed values for waterHeating:
# ['Electric Premium', 'Electric Standard', 'Fuel Oil Premium', 'Fuel Oil Standard', 'Natural Gas Premium', 'Natural Gas Standard', 'Propane Premium', 'Propane Standard']
#   waterHeating: Found 8732 homes (2.6%) with invalid technology types
#   Invalid technology types (top 5):
# waterHeating_type
# Natural Gas Tankless          2614
# FIXME Fuel Oil Indirect       2068
# Electric Tankless             1900
# Electric Heat Pump, 80 gal     852
# Other Fuel                     669
# Name: count, dtype: int64
#   waterHeating: Total 8732 homes (2.6%) excluded from analysis
#
# --- Processing clothesDrying ---
# Values in base_clothesDrying_fuel (top 5):
# base_clothesDrying_fuel
# Electricity    240564
# Natural Gas     71456
# Propane          4553
# Name: count, dtype: int64
#   clothesDrying: Found 14958 homes (4.5%) with invalid fuel types
#   Invalid fuel types (top 5):
# Series([], Name: count, dtype: int64)
#   clothesDrying: Technology validation not applicable (no technology type column)
#   clothesDrying: Total 14958 homes (4.5%) excluded from analysis
#
# --- Processing cooking ---
# Values in base_cooking_fuel (top 5):
# base_cooking_fuel
# Electricity    201946
# Natural Gas    110595
# Propane         15778
# Name: count, dtype: int64
#   cooking: Found 205158 homes (61.9%) with invalid fuel types
#   Invalid fuel types (top 5):
# base_cooking_fuel
# Electricity    201946
# Name: count, dtype: int64
#   cooking: Technology validation not applicable (no technology type column)
#   cooking: Total 205158 homes (61.9%) excluded from analysis
#
# Total 234634 homes (70.8%) excluded from all categories
#
# Applying data validation (baseline only):
# Baseline calculation for heating:
#   - 260211 homes have valid data
#   - 71320 homes have invalid data (values will be NaN)
#   base_electricity_heating_consumption: Masked 71320 values
#   base_naturalGas_heating_consumption: Masked 71320 values
#   base_fuelOil_heating_consumption: Masked 71320 values
#   base_propane_heating_consumption: Masked 71320 values
#   baseline_heating_consumption: Masked 61081 values
# Baseline calculation for waterHeating:
#   - 322799 homes have valid data
#   - 8732 homes have invalid data (values will be NaN)
#   base_electricity_waterHeating_consumption: Masked 8732 values
#   base_naturalGas_waterHeating_consumption: Masked 8732 values
#   base_fuelOil_waterHeating_consumption: Masked 8732 values
#   base_propane_waterHeating_consumption: Masked 8732 values
#   baseline_waterHeating_consumption: Masked 8063 values
# Baseline calculation for clothesDrying:
#   - 316573 homes have valid data
#   - 14958 homes have invalid data (values will be NaN)
#   base_electricity_clothesDrying_consumption: Masked 14958 values
#   base_naturalGas_clothesDrying_consumption: Masked 14958 values
#   base_propane_clothesDrying_consumption: Masked 14958 values
# Baseline calculation for cooking:
#   - 126373 homes have valid data
#   - 205158 homes have invalid data (values will be NaN)
#   base_electricity_cooking_consumption: Masked 205158 values
#   base_naturalGas_cooking_consumption: Masked 205158 values
#   base_propane_cooking_consumption: Masked 205158 values
#   baseline_cooking_consumption: Masked 201946 values
#
# ====================================================================================================================================================================
# DATAFRAME: df_euss_am_baseline_home
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ... valid_fuel_heating valid_tech_heating include_heating  \
# bldg_id            ...
# 239      G0100390  ...               True               True            True
# 273      G0100150  ...               True               True            True
# 307      G0100850  ...               True              False           False
# 409      G0100050  ...               True               True            True
# 517      G0101270  ...               True              False           False
# ...           ...  ...                ...                ...             ...
# 548226   G5600050  ...               True               True            True
# 548228   G5600010  ...               True               True            True
# 548417   G5600250  ...               True               True            True
# 549740   G5600390  ...               True               True            True
# 549938   G5600010  ...               True              False           False
#
#         valid_fuel_waterHeating  valid_tech_waterHeating  \
# bldg_id
# 239                        True                     True
# 273                        True                     True
# 307                        True                     True
# 409                        True                     True
# 517                        True                     True
# ...                         ...                      ...
# 548226                     True                     True
# 548228                     True                     True
# 548417                     True                     True
# 549740                     True                     True
# 549938                     True                     True
#
#          include_waterHeating valid_fuel_clothesDrying include_clothesDrying  \
# bldg_id
# 239                      True                     True                  True
# 273                      True                     True                  True
# 307                      True                     True                  True
# 409                      True                     True                  True
# 517                      True                     True                  True
# ...                       ...                      ...                   ...
# 548226                   True                     True                  True
# 548228                   True                     True                  True
# 548417                   True                     True                  True
# 549740                   True                     True                  True
# 549938                   True                     True                  True
#
#         valid_fuel_cooking include_cooking
# bldg_id
# 239                   True            True
# 273                  False           False
# 307                  False           False
# 409                   True            True
# 517                  False           False
# ...                    ...             ...
# 548226               False           False
# 548228               False           False
# 548417               False           False
# 549740                True            True
# 549938                True            True
#
# [331531 rows x 60 columns]
#
# Retrieved data for filename: aeo_projections_2022_2050.xlsx
# Located at filepath: c:\users\14128\research\cmu-tare-model\cmu_tare_model\data\projections\aeo_projections_2022_2050.xlsx
#
# ====================================================================================================================================================================
# PROJECT FUTURE ENERGY CONSUMPTION: BASELINE SCENARIO
# ====================================================================================================================================================================
# project_future_energy_consumption.py file was used to calculate/project the annual energy consumption
# for each home in the dataframe.
#
# Documentation for project_future_energy_consumption function:
# Projects future energy consumption based on baseline or upgraded equipment specifications.
#
#     This function calculates projected energy consumption for each equipment category (heating,
#     water heating, clothes drying, and cooking) for future years based on their expected lifetime.
#     It applies climate adjustment factors for heating and water heating categories.
#
#     Args:
#         df: The input DataFrame containing baseline consumption data.
#         menu_mp: Indicates the measure package to apply. 0 for baseline, or a positive integer
#             (e.g., 8, 9, 10) for retrofit scenarios.
#         base_year: The starting year for projections. Defaults to 2024.
#
#     Returns:
#         A tuple containing two DataFrames:
#             - df_copy: The updated DataFrame with all columns including the projected consumption data.
#             - df_consumption: The DataFrame containing only the projected consumption data.
#
#     Raises:
#         KeyError: If the 'census_division' column is missing from the DataFrame.
#
#
# RESULTS OUTPUT (BASELINE):
#
#
# Determining valid homes for calculations:
# Baseline calculation for heating:
#   - 260211 homes have valid data
#   - 71320 homes have invalid data (values will be NaN)
# Baseline calculation for waterHeating:
#   - 322799 homes have valid data
#   - 8732 homes have invalid data (values will be NaN)
# Baseline calculation for clothesDrying:
#   - 316573 homes have valid data
#   - 14958 homes have invalid data (values will be NaN)
# Baseline calculation for cooking:
#   - 126373 homes have valid data
#   - 205158 homes have invalid data (values will be NaN)
#
# ===== Processing HEATING =====
# Projecting consumption for 260211 out of 331531 homes
# Projecting Future Energy Consumption (Baseline Equipment): heating
#
# ===== Processing WATERHEATING =====
# Projecting consumption for 322799 out of 331531 homes
# Projecting Future Energy Consumption (Baseline Equipment): waterHeating
#
# ===== Processing CLOTHESDRYING =====
# Projecting consumption for 316573 out of 331531 homes
# Projecting Future Energy Consumption (Baseline Equipment): clothesDrying
#
# ===== Processing COOKING =====
# Projecting consumption for 126373 out of 331531 homes
# Projecting Future Energy Consumption (Baseline Equipment): cooking
#
# Verifying masking for all projected columns:
# Masking 16 columns for category 'heating'
# Masking 13 columns for category 'waterHeating'
# Masking 14 columns for category 'clothesDrying'
# Masking 16 columns for category 'cooking'
#
# ====================================================================================================================================================================
#
# DATAFRAME: df_euss_am_baseline_home
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ... baseline_2029_cooking_consumption  \
# bldg_id            ...
# 239      G0100390  ...                            979.44
# 273      G0100150  ...                               NaN
# 307      G0100850  ...                               NaN
# 409      G0100050  ...                           1009.63
# 517      G0101270  ...                               NaN
# ...           ...  ...                               ...
# 548226   G5600050  ...                               NaN
# 548228   G5600010  ...                               NaN
# 548417   G5600250  ...                               NaN
# 549740   G5600390  ...                           1009.63
# 549938   G5600010  ...                           1004.94
#
#         baseline_2030_cooking_consumption baseline_2031_cooking_consumption  \
# bldg_id
# 239                                979.44                            979.44
# 273                                   NaN                               NaN
# 307                                   NaN                               NaN
# 409                               1009.63                           1009.63
# 517                                   NaN                               NaN
# ...                                   ...                               ...
# 548226                                NaN                               NaN
# 548228                                NaN                               NaN
# 548417                                NaN                               NaN
# 549740                            1009.63                           1009.63
# 549938                            1004.94                           1004.94
#
#         baseline_2032_cooking_consumption  baseline_2033_cooking_consumption  \
# bldg_id
# 239                                979.44                             979.44
# 273                                   NaN                                NaN
# 307                                   NaN                                NaN
# 409                               1009.63                            1009.63
# 517                                   NaN                                NaN
# ...                                   ...                                ...
# 548226                                NaN                                NaN
# 548228                                NaN                                NaN
# 548417                                NaN                                NaN
# 549740                            1009.63                            1009.63
# 549938                            1004.94                            1004.94
#
#          baseline_2034_cooking_consumption baseline_2035_cooking_consumption  \
# bldg_id
# 239                                 979.44                            979.44
# 273                                    NaN                               NaN
# 307                                    NaN                               NaN
# 409                                1009.63                           1009.63
# 517                                    NaN                               NaN
# ...                                    ...                               ...
# 548226                                 NaN                               NaN
# 548228                                 NaN                               NaN
# 548417                                 NaN                               NaN
# 549740                             1009.63                           1009.63
# 549938                             1004.94                           1004.94
#
#         baseline_2036_cooking_consumption baseline_2037_cooking_consumption  \
# bldg_id
# 239                                979.44                            979.44
# 273                                   NaN                               NaN
# 307                                   NaN                               NaN
# 409                               1009.63                           1009.63
# 517                                   NaN                               NaN
# ...                                   ...                               ...
# 548226                                NaN                               NaN
# 548228                                NaN                               NaN
# 548417                                NaN                               NaN
# 549740                            1009.63                           1009.63
# 549938                            1004.94                           1004.94
#
#         baseline_2038_cooking_consumption
# bldg_id
# 239                                979.44
# 273                                   NaN
# 307                                   NaN
# 409                               1009.63
# 517                                   NaN
# ...                                   ...
# 548226                                NaN
# 548228                                NaN
# 548417                                NaN
# 549740                            1009.63
# 549938                            1004.94
#
# [331531 rows x 115 columns]
#
# DATAFRAME: df_baseline_scenario_consumption
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ... baseline_2029_cooking_consumption  \
# bldg_id            ...
# 239      G0100390  ...                            979.44
# 273      G0100150  ...                               NaN
# 307      G0100850  ...                               NaN
# 409      G0100050  ...                           1009.63
# 517      G0101270  ...                               NaN
# ...           ...  ...                               ...
# 548226   G5600050  ...                               NaN
# 548228   G5600010  ...                               NaN
# 548417   G5600250  ...                               NaN
# 549740   G5600390  ...                           1009.63
# 549938   G5600010  ...                           1004.94
#
#         baseline_2030_cooking_consumption baseline_2031_cooking_consumption  \
# bldg_id
# 239                                979.44                            979.44
# 273                                   NaN                               NaN
# 307                                   NaN                               NaN
# 409                               1009.63                           1009.63
# 517                                   NaN                               NaN
# ...                                   ...                               ...
# 548226                                NaN                               NaN
# 548228                                NaN                               NaN
# 548417                                NaN                               NaN
# 549740                            1009.63                           1009.63
# 549938                            1004.94                           1004.94
#
#         baseline_2032_cooking_consumption  baseline_2033_cooking_consumption  \
# bldg_id
# 239                                979.44                             979.44
# 273                                   NaN                                NaN
# 307                                   NaN                                NaN
# 409                               1009.63                            1009.63
# 517                                   NaN                                NaN
# ...                                   ...                                ...
# 548226                                NaN                                NaN
# 548228                                NaN                                NaN
# 548417                                NaN                                NaN
# 549740                            1009.63                            1009.63
# 549938                            1004.94                            1004.94
#
#          baseline_2034_cooking_consumption baseline_2035_cooking_consumption  \
# bldg_id
# 239                                 979.44                            979.44
# 273                                    NaN                               NaN
# 307                                    NaN                               NaN
# 409                                1009.63                           1009.63
# 517                                    NaN                               NaN
# ...                                    ...                               ...
# 548226                                 NaN                               NaN
# 548228                                 NaN                               NaN
# 548417                                 NaN                               NaN
# 549740                             1009.63                           1009.63
# 549938                             1004.94                           1004.94
#
#         baseline_2036_cooking_consumption baseline_2037_cooking_consumption  \
# bldg_id
# 239                                979.44                            979.44
# 273                                   NaN                               NaN
# 307                                   NaN                               NaN
# 409                               1009.63                           1009.63
# 517                                   NaN                               NaN
# ...                                   ...                               ...
# 548226                                NaN                               NaN
# 548228                                NaN                               NaN
# 548417                                NaN                               NaN
# 549740                            1009.63                           1009.63
# ...
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ... baseline_cooking_lifetime_damages_health_InMAP_acs  \
# bldg_id            ...
# 239      G0100390  ...                                              13.10
# 273      G0100150  ...                                                NaN
# 307      G0100850  ...                                                NaN
# 409      G0100050  ...                                              24.25
# 517      G0101270  ...                                                NaN
# ...           ...  ...                                                ...
# 548226   G5600050  ...                                                NaN
# 548228   G5600010  ...                                                NaN
# 548417   G5600250  ...                                                NaN
# 549740   G5600390  ...                                              30.16
# 549938   G5600010  ...                                              32.47
#
#         baseline_cooking_lifetime_damages_health_InMAP_h6c fuel_type_heating  \
# bldg_id
# 239                                                  33.66       electricity
# 273                                                    NaN       electricity
# 307                                                    NaN       electricity
# 409                                                  62.30        naturalGas
# 517                                                    NaN       electricity
# ...                                                    ...               ...
# 548226                                                 NaN        naturalGas
# 548228                                                 NaN        naturalGas
# 548417                                                 NaN        naturalGas
# 549740                                               77.49       electricity
# 549938                                               83.41        naturalGas
#
#         fuel_type_waterHeating  fuel_type_clothesDrying  fuel_type_cooking  \
# bldg_id
# 239                electricity              electricity         naturalGas
# 273                electricity              electricity        electricity
# 307                electricity              electricity        electricity
# 409                 naturalGas              electricity         naturalGas
# 517                electricity              electricity        electricity
# ...                        ...                      ...                ...
# 548226              naturalGas              electricity        electricity
# 548228              naturalGas              electricity        electricity
# 548417              naturalGas              electricity        electricity
# 549740             electricity              electricity            propane
# 549938              naturalGas              electricity         naturalGas
#
#         baseline_heating_lifetime_fuel_cost  \
# bldg_id
# 239                                 8755.01
# 273                                12967.49
# 307                                     NaN
# 409                                 1007.06
# 517                                     NaN
# ...                                     ...
# 548226                             37186.50
# 548228                             18562.23
# 548417                              8991.10
# 549740                             41775.54
# 549938                                  NaN
#
#         baseline_waterHeating_lifetime_fuel_cost  \
# bldg_id
# 239                                      3397.68
# 273                                      4609.14
# 307                                      4333.81
# 409                                      2819.10
# 517                                      1927.74
# ...                                          ...
# 548226                                   2031.12
# 548228                                   2131.32
# 548417                                   3592.33
# 549740                                   6793.94
# 549938                                   2765.07
#
#         baseline_clothesDrying_lifetime_fuel_cost  \
# bldg_id
# 239                                        893.45
# 273                                       2106.84
# 307                                       1101.08
# 409                                        817.58
# 517                                        714.76
# ...                                           ...
# 548226                                     578.49
# 548228                                     578.49
# 548417                                    1323.54
# 549740                                     694.19
# 549938                                    1705.39
#
#         baseline_cooking_lifetime_fuel_cost
# bldg_id
# 239                                  809.79
# 273                                     NaN
# 307                                     NaN
# 409                                  834.75
# 517                                     NaN
# ...                                     ...
# 548226                                  NaN
# 548228                                  NaN
# 548417                                  NaN
# 549740                              1531.41
# 549938                               628.97
#
# [331531 rows x 180 columns]
#
# df_baseline_fuel_costs: DataFrame containing the baseline scenario data with fuel costs
#          include_all  include_heating  include_waterHeating  \
# bldg_id
# 239             True             True                  True
# 273            False             True                  True
# 307            False            False                  True
# 409             True             True                  True
# 517            False            False                  True
# ...              ...              ...                   ...
# 548226         False             True                  True
# 548228         False             True                  True
# 548417         False             True                  True
# 549740          True             True                  True
# 549938         False            False                  True
#
#          include_clothesDrying  include_cooking  valid_tech_heating  \
# bldg_id
# 239                       True             True                True
# 273                       True            False                True
# 307                       True            False               False
# 409                       True             True                True
# 517                       True            False               False
# ...                        ...              ...                 ...
# 548226                    True            False                True
# 548228                    True            False                True
# 548417                    True            False                True
# 549740                    True             True                True
# 549938                    True             True               False
#
#          valid_tech_waterHeating  valid_fuel_heating  valid_fuel_waterHeating  \
# bldg_id
# 239                         True                True                     True
# 273                         True                True                     True
# 307                         True                True                     True
# 409                         True                True                     True
# 517                         True                True                     True
# ...                          ...                 ...                      ...
# 548226                      True                True                     True
# 548228                      True                True                     True
# 548417                      True                True                     True
# 549740                      True                True                     True
# 549938                      True                True                     True
#
#          valid_fuel_clothesDrying  ...  baseline_2030_cooking_fuel_cost  \
# bldg_id                            ...
# 239                          True  ...                            53.84
# 273                          True  ...                              NaN
# 307                          True  ...                              NaN
# 409                          True  ...                            55.50
# 517                          True  ...                              NaN
# ...                           ...  ...                              ...
# 548226                       True  ...                              NaN
# 548228                       True  ...                              NaN
# 548417                       True  ...                              NaN
# 549740                       True  ...                            98.35
# 549938                       True  ...                            41.70
#
#          baseline_2031_cooking_fuel_cost  baseline_2032_cooking_fuel_cost  \
# bldg_id
# 239                                54.43                            54.95
# 273                                  NaN                              NaN
# 307                                  NaN                              NaN
# 409                                56.11                            56.64
# 517                                  NaN                              NaN
# ...                                  ...                              ...
# 548226                               NaN                              NaN
# 548228                               NaN                              NaN
# 548417                               NaN                              NaN
# 549740                             99.37                           100.73
# 549938                             42.33                            42.72
#
#          baseline_2033_cooking_fuel_cost  baseline_2034_cooking_fuel_cost  \
# bldg_id
# 239                                55.63                            56.10
# 273                                  NaN                              NaN
# 307                                  NaN                              NaN
# 409                                57.34                            57.82
# 517                                  NaN                              NaN
# ...                                  ...                              ...
# 548226                               NaN                              NaN
# 548228                               NaN                              NaN
# 548417                               NaN                              NaN
# 549740                            102.25                           103.40
# 549938                             43.15                            43.40
#
#          baseline_2035_cooking_fuel_cost  baseline_2036_cooking_fuel_cost  \
# bldg_id
# 239                                56.49                            56.75
# 273                                  NaN                              NaN
# 307                                  NaN                              NaN
# 409                                58.23                            58.50
# 517                                  NaN                              NaN
# ...                                  ...                              ...
# 548226                               NaN                              NaN
# 548228                               NaN                              NaN
# 548417                               NaN                              NaN
# 549740                            104.47                           105.54
# 549938                             43.63                            43.74
#
#          baseline_2037_cooking_fuel_cost  baseline_2038_cooking_fuel_cost  \
# bldg_id
# 239                                57.40                            57.94
# 273                                  NaN                              NaN
# 307                                  NaN                              NaN
# 409                                59.17                            59.73
# 517                                  NaN                              NaN
# ...                                  ...                              ...
# 548226                               NaN                              NaN
# 548228                               NaN                              NaN
# 548417                               NaN                              NaN
# 549740                            106.80                           108.02
# 549938                             44.15                            44.41
#
#          baseline_cooking_lifetime_fuel_cost
# bldg_id
# 239                                   809.79
# 273                                      NaN
# 307                                      NaN
# 409                                   834.75
# 517                                      NaN
# ...                                      ...
# 548226                                   NaN
# 548228                                   NaN
# 548417                                   NaN
# 549740                               1531.41
# 549938                                628.97
#
# [331531 rows x 70 columns]
#
#
# The code took 11 minutes and 40 seconds to execute.
# Baseline Scenario - Model Run Complete

# %%
print(output_folder_path)
# Out:
# c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV
# ===================================================================================================================================================================================

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_baseline_damages_climate,
    results_category='damages_climate_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_baseline_damages_health,
    results_category='damages_health_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_baseline_fuel_costs,
    results_category='fuel_costs_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

# ===== SUMMARY RESULTS =====
export_model_run_output(
    df_results_export=df_euss_am_baseline_home,
    results_category='summary_baseline',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )
# Out:
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_climate_baseline
# Dataframe results will be saved in this csv file: mp0_damages_climate_baseline_National_2025-05-15_21-39.csv
# Dataframe for MP0 damages_climate_baseline results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_baseline\mp0_damages_climate_baseline_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_health_baseline
# Dataframe results will be saved in this csv file: mp0_damages_health_baseline_National_2025-05-15_21-39.csv
# Dataframe for MP0 damages_health_baseline results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_baseline\mp0_damages_health_baseline_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: fuel_costs_baseline
# Dataframe results will be saved in this csv file: mp0_fuel_costs_baseline_National_2025-05-15_21-39.csv
# Dataframe for MP0 fuel_costs_baseline results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_baseline\mp0_fuel_costs_baseline_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# BASELINE SUMMARY RESULTS:
# Dataframe results will be saved in this csv file: baseline_results_National_2025-05-15_21-39.csv
# Dataframe for MP0 summary_baseline results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\baseline_summary\summary_baseline\baseline_results_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------

# %%
print("""
Scenarios for Basic, Moderate, and Advanced Retrofit
- Rows in the Baseline CSV are merged with the Post-Retrofit Measure Package.
- The same filters are applied.

-------------------------------------------------------------------------------------------------------
MODEL SCENARIOS
-------------------------------------------------------------------------------------------------------
- BASIC/MODERATE/ADVANCED Pre-IRA Scenario:
    - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
    - AEO2023 No Inflation Reduction Act
    - Cambium 2021 MidCase
      
- BASIC/MODERATE/ADVANCED IRA-Reference Scenario:
    - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
    - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
    - Cambium 2022 and 2023 MidCase
""")
# Out:
# Scenarios for Basic, Moderate, and Advanced Retrofit
# - Rows in the Baseline CSV are merged with the Post-Retrofit Measure Package.
# - The same filters are applied.
#
# -------------------------------------------------------------------------------------------------------
# MODEL SCENARIOS
# -------------------------------------------------------------------------------------------------------
# - BASIC/MODERATE/ADVANCED Pre-IRA Scenario:
#     - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
#     - AEO2023 No Inflation Reduction Act
#     - Cambium 2021 MidCase
#
# - BASIC/MODERATE/ADVANCED IRA-Reference Scenario:
#     - NREL End-Use Savings Shapes Database: Measure Package 8/9/10
#     - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
#     - Cambium 2022 and 2023 MidCase

# %% [markdown]
# -------------------------------------------------------------------------------------------------------
# # POST-RETROFIT SCENARIOS: Basic (MP8), Moderate (MP9), Advanced (MP10)
# -------------------------------------------------------------------------------------------------------
# ## No IRA Scenario:
# - AEO2023 No Inflation Reduction Act
# - Cambium 2021 MidCase
# ## IRA-Reference Scenario:
# - AEO2023 REFERENCE CASE - HDD and Fuel Price Projections
# - Cambium 2022 and 2023 MidCase
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Basic Retrofit: Measure Package 8 (MP8)

# %%
# Measure Package 8
menu_mp = 8
input_mp = 'upgrade08'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_basic_v2_1.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Basic Retrofit Scenario - Model Run Complete")
# Out:
# PROJECT_ROOT (from config.py): c:\users\14128\research\cmu-tare-model
# Running file: c:/users/14128/research/cmu-tare-model/cmu_tare_model/model_scenarios/tare_basic_v2_1.ipynb
#
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (MP8).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\14128\research\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\state\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# DATAFRAME SIZE after filtering for 'Single-Family Attached' and 'Single-Family Detached' homes: (331531, 346)
# You chose to analyze all of the United States.
# DATAFRAME SIZE after applying geographic filter: (331531, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 239            7  242.131013           True   1690.0
# 273            7  242.131013          False   1690.0
# 307            7  242.131013          False   1220.0
# 409            7  242.131013           True   1220.0
# 517            7  242.131013          False   1220.0
# ...          ...         ...            ...      ...
# 548226         7  242.131013           True   2176.0
# 548228         7  242.131013           True   1690.0
# 548417         7  242.131013           True    885.0
# 549740         7  242.131013           True   1220.0
# 549938         7  242.131013           True    885.0
#
#                        in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 239      Non-CBSA East South Central                               3A
# 273      Non-CBSA East South Central                               3A
# 307      Non-CBSA East South Central                               3A
# 409      Non-CBSA East South Central                               3A
# 517      Non-CBSA East South Central                               3A
# ...                              ...                              ...
# 548226             Non-CBSA Mountain                               6B
# 548228             Non-CBSA Mountain                               6B
# 548417             Non-CBSA Mountain                               6B
# 549740             Non-CBSA Mountain                               7B
# 549938             Non-CBSA Mountain                               6B
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 239                                             3A                     Hour20
# 273                                             3A                     Hour12
# 307                                             3A                      Hour0
# 409                                             3A                     Hour20
# 517                                             3A                      Hour1
# ...                                            ...                        ...
# 548226                                          6B                      Hour3
# 548228                                          6B                      Hour6
# 548417                                          6B                     Hour18
# 549740                                          7B                      Hour4
# 549938                                          6B                      Hour2
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 239                3                        Hot-Humid  ...
# 273                3                      Mixed-Humid  ...
# 307                4                        Hot-Humid  ...
# 409                2                        Hot-Humid  ...
# 517                3                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 548226             4                             Cold  ...
# 548228             4                             Cold  ...
# 548417             2                             Cold  ...
# 549740             2                        Very Cold  ...
# 549938             2                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                               0.000000
# 273                                               0.000000
# 307                                               0.000000
# 409                                               0.000000
# 517                                               0.000000
# ...                                                    ...
# 548226                                            0.000000
# 548228                                            0.000000
# 548417                                            0.000000
# 549740                                          268.627834
# 549938                                            0.000000
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 239                                             142.374480
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1439.855043
# 517                                               0.000000
# ...                                                    ...
# 548226                                         8790.508547
# 548228                                         5124.531468
# 548417                                         3748.197047
# 549740                                          152.327658
# 549938                                         7833.858198
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 239                                              75.157988
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1235.288966
# 517                                               0.000000
# ...                                                    ...
# 548226                                         9652.472396
# 548228                                         5456.571515
# 548417                                         3986.523550
# 549740                                          178.841946
# 549938                                         8061.021339
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 239                                              91.998512
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1299.421938
# 517                                               0.000000
# ...                                                    ...
# 548226                                        10147.078588
# 548228                                         5713.602807
# 548417                                         4071.210606
# 549740                                          198.041150
# 549938                                         8199.976187
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                              19.421011
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1129.822844
# 517                                               0.000000
# ...                                                    ...
# 548226                                         5326.981989
# 548228                                         3463.786920
# 548417                                         3004.825830
# 549740                                           75.301777
# 549938                                         6852.064771
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 239                       NaN  Electric, 100% Usage
# 273                       NaN                   NaN
# 307                       NaN                   NaN
# 409                       NaN  Electric, 120% Usage
# 517                       NaN                   NaN
# ...                       ...                   ...
# 548226                    NaN                   NaN
# 548228                    NaN                   NaN
# 548417                    NaN                   NaN
# 549740                    NaN  Electric, 120% Usage
# 549938                    NaN   Electric, 80% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 239                                 NaN                                NaN
# 273                                 NaN                                NaN
# 307                                 NaN                                NaN
# 409                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 517                                 NaN                                NaN
# ...                                 ...                                ...
# 548226                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 548228                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 548417                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549740                              NaN                                NaN
# 549938                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
#
#               upgrade.water_heater_efficiency
# bldg_id
# 239                                       NaN
# 273                                       NaN
# 307                                       NaN
# 409      Electric Heat Pump, 50 gal, 3.45 UEF
# 517                                       NaN
# ...                                       ...
# 548226   Electric Heat Pump, 66 gal, 3.35 UEF
# 548228   Electric Heat Pump, 66 gal, 3.35 UEF
# 548417   Electric Heat Pump, 50 gal, 3.45 UEF
# 549740                                    NaN
# 549938   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [331531 rows x 346 columns]
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Basic-BAU:
# Basic Retrofit: Measure Package 8
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade08_metadata_and_annual_results.csv
# Located at filepath: c:\users\14128\research\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\state\upgrade08_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 347)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 347)
# DATAFRAME SIZE after filtering for 'Single-Family Attached' and 'Single-Family Detached' homes: (331531, 347)
# You chose to analyze all of the United States.
# DATAFRAME SIZE after applying geographic filter: (331531, 347)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 239            8  242.131013           True   1690.0
# 273            8  242.131013           True   1690.0
# 307            8  242.131013           True   1220.0
# 409            8  242.131013           True   1220.0
# 517            8  242.131013           True   1220.0
# ...          ...         ...            ...      ...
# 548226         8  242.131013           True   2176.0
# 548228         8  242.131013           True   1690.0
# 548417         8  242.131013           True    885.0
# 549740         8  242.131013           True   1220.0
# 549938         8  242.131013           True    885.0
#
#                        in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 239      Non-CBSA East South Central                               3A
# 273      Non-CBSA East South Central                               3A
# 307      Non-CBSA East South Central                               3A
# 409      Non-CBSA East South Central                               3A
# 517      Non-CBSA East South Central                               3A
# ...                              ...                              ...
# 548226             Non-CBSA Mountain                               6B
# 548228             Non-CBSA Mountain                               6B
# 548417             Non-CBSA Mountain                               6B
# 549740             Non-CBSA Mountain                               7B
# 549938             Non-CBSA Mountain                               6B
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 239                                             3A                     Hour20
# 273                                             3A                     Hour12
# 307                                             3A                      Hour0
# 409                                             3A                     Hour20
# 517                                             3A                      Hour1
# ...                                            ...                        ...
# 548226                                          6B                      Hour3
# 548228                                          6B                      Hour6
# 548417                                          6B                     Hour18
# 549740                                          7B                      Hour4
# 549938                                          6B                      Hour2
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 239                3                        Hot-Humid  ...
# 273                3                      Mixed-Humid  ...
# 307                4                        Hot-Humid  ...
# 409                2                        Hot-Humid  ...
# 517                3                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 548226             4                             Cold  ...
# 548228             4                             Cold  ...
# 548417             2                             Cold  ...
# 549740             2                        Very Cold  ...
# 549938             2                             Cold  ...
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 239                                            1887.869588
# 273                                            2355.351410
# 307                                            1399.898998
# 409                                            1877.362574
# 517                                            1533.599432
# ...                                                    ...
# 548226                                        10526.028704
# 548228                                         6095.411916
# 548417                                         4422.476166
# 549740                                         3295.130844
# 549938                                         8585.635388
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 239                                            3309.780516
# 273                                            4481.959362
# 307                                            2594.169607
# 409                                            1991.130798
# 517                                            2851.013565
# ...                                                    ...
# 548226                                        11172.116151
# 548228                                         6322.017139
# 548417                                         4554.667951
# 549740                                         2733.143505
# 549938                                         8716.973513
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 239                                            2975.726519
# 273                                            3932.995114
# 307                                            2328.429795
# 409                                            2011.527032
# 517                                            2551.672538
# ...                                                    ...
# 548226                                        11534.918833
# 548228                                         6497.639486
# 548417                                         4598.532148
# 549740                                         2154.651754
# 549938                                         8798.731723
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                            4560.862209
# 273                                            6062.861674
# 307                                            3657.914475
# 409                                            2289.243950
# 517                                            3978.273612
# ...                                                    ...
# 548226                                         8031.176776
# 548228                                         4976.686210
# 548417                                         4027.179941
# 549740                                         5254.338718
# 549938                                         8026.064790
#
#                                      upgrade.clothes_dryer  \
# bldg_id
# 239      Electric, Premium, Heat Pump, Ventless, 100% U...
# 273      Electric, Premium, Heat Pump, Ventless, 100% U...
# 307      Electric, Premium, Heat Pump, Ventless, 100% U...
# 409      Electric, Premium, Heat Pump, Ventless, 120% U...
# 517      Electric, Premium, Heat Pump, Ventless, 80% Usage
# ...                                                    ...
# 548226   Electric, Premium, Heat Pump, Ventless, 100% U...
# 548228   Electric, Premium, Heat Pump, Ventless, 100% U...
# 548417   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549740   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549938   Electric, Premium, Heat Pump, Ventless, 80% Usage
#
#                    upgrade.cooking_range upgrade.hvac_cooling_efficiency  \
# bldg_id
# 239      Electric, Induction, 100% Usage                       Heat Pump
# 273      Electric, Induction, 100% Usage                       Heat Pump
# 307      Electric, Induction, 100% Usage                       Heat Pump
# 409      Electric, Induction, 120% Usage                       Heat Pump
# 517       Electric, Induction, 80% Usage                       Heat Pump
# ...                                  ...                             ...
# 548226   Electric, Induction, 100% Usage                       Heat Pump
# 548228   Electric, Induction, 100% Usage                       Heat Pump
# 548417   Electric, Induction, 120% Usage                       Heat Pump
# 549740   Electric, Induction, 120% Usage                       Heat Pump
# 549938    Electric, Induction, 80% Usage                       Heat Pump
#
#             upgrade.hvac_heating_efficiency upgrade.hvac_heating_type  \
# bldg_id
# 239                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 273                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 307                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 409                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 517                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# ...                                     ...                       ...
# 548226               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 548228               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 548417               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549740               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549938   MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
#
#               upgrade.water_heater_efficiency
# bldg_id
# 239      Electric Heat Pump, 50 gal, 3.45 UEF
# 273      Electric Heat Pump, 50 gal, 3.45 UEF
# 307      Electric Heat Pump, 66 gal, 3.35 UEF
# 409      Electric Heat Pump, 50 gal, 3.45 UEF
# 517      Electric Heat Pump, 50 gal, 3.45 UEF
# ...                                       ...
# 548226   Electric Heat Pump, 66 gal, 3.35 UEF
# 548228   Electric Heat Pump, 66 gal, 3.35 UEF
# 548417   Electric Heat Pump, 50 gal, 3.45 UEF
# 549740   Electric Heat Pump, 50 gal, 3.45 UEF
# 549938   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [331531 rows x 347 columns]
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 8 (MP8)
# ====================================================================================================================================================================
# You'll notice that the number of rows differs from df_euss_am_mp7 and df_euss_am_mp8.
#       - df_euss_am_baseline_home has fewer rows (representative dwelling units) because a tech filter was applied.
#       - df_euss_am_mp8_home will have the same number of rows as df_euss_am_baseline_home after df_enduse_compare function is run.
#       - df_enduse_compare function performs an inner merge on the two dataframes, keeping only the rows that are present in both dataframes.
# ====================================================================================================================================================================
# df_euss_am_mp8_home will be created by running the df_enduse_compare function (contains post-retrofit consumption data for the entire home in 2024).
# process_euss_data.py file contains the function definition.
#
# Documentation for df_enduse_compare function:
# Creates a comparison DataFrame by merging multiple DataFrames based on measure packages.
#
#     This function constructs a new DataFrame (df_compare) that includes columns
#     from df_mp, df_cooking_range, and merges them with df_baseline to compare
#     baseline vs. measure package outputs for heating, water heating, clothes drying,
#     and cooking.
#
#     Args:
#         df_mp: The main DataFrame containing modeling parameters and outputs.
#         input_mp: The input measure package ID (e.g., 'upgrade09', 'upgrade10').
#         menu_mp: The menu measure package number.
#         df_baseline: The baseline DataFrame to merge with df_compare.
#         df_cooking_range: Additional DataFrame for cooking range parameters/outputs.
#
#     Returns:
#         A merged DataFrame (df_compare) that includes relevant columns for
#         baseline and measure packages comparison.
#
# ----------------------------------------------------------------
#
# RESULTING DATAFRAME:
#
#
# Applying combined validation (data quality + retrofit status):
# Measure package calculation for heating:
#   - 260211 homes have valid data
#   - 331523 homes will receive retrofits
#   - 260209 homes have both valid data AND will receive retrofits
#   - 71322 homes excluded (values will be NaN)
#   base_electricity_heating_consumption: Masked 2 values
#   base_naturalGas_heating_consumption: Masked 2 values
#   base_fuelOil_heating_consumption: Masked 2 values
#   base_propane_heating_consumption: Masked 2 values
#   baseline_heating_consumption: Masked 2 values
#   mp8_heating_consumption: Masked 71322 values
# Measure package calculation for waterHeating:
#   - 322799 homes have valid data
#   - 329628 homes will receive retrofits
#   - 322796 homes have both valid data AND will receive retrofits
#   - 8735 homes excluded (values will be NaN)
#   base_electricity_waterHeating_consumption: Masked 3 values
#   base_naturalGas_waterHeating_consumption: Masked 3 values
#   base_fuelOil_waterHeating_consumption: Masked 3 values
#   base_propane_waterHeating_consumption: Masked 3 values
#   baseline_waterHeating_consumption: Masked 3 values
#   mp8_waterHeating_consumption: Masked 8735 values
# Measure package calculation for clothesDrying:
#   - 316573 homes have valid data
#   - 316570 homes will receive retrofits
#   - 316570 homes have both valid data AND will receive retrofits
#   - 14961 homes excluded (values will be NaN)
#   base_electricity_clothesDrying_consumption: Masked 3 values
#   base_naturalGas_clothesDrying_consumption: Masked 3 values
#   base_propane_clothesDrying_consumption: Masked 3 values
#   baseline_clothesDrying_consumption: Masked 3 values
#   mp8_clothesDrying_consumption: Masked 14961 values
# Measure package calculation for cooking:
#   - 126373 homes have valid data
#   - 126373 homes will receive retrofits
#   - 126373 homes have both valid data AND will receive retrofits
#   - 205158 homes excluded (values will be NaN)
#   mp8_cooking_consumption: Masked 205158 values
#
# ====================================================================================================================================================================
# PROJECT FUTURE ENERGY CONSUMPTION
# ====================================================================================================================================================================
# project_future_energy_consumption.py file was used to calculate/project the annual energy consumption
# for each home in the dataframe.
#
# Documentation for project_future_energy_consumption function:
# Projects future energy consumption based on baseline or upgraded equipment specifications.
#
#     This function calculates projected energy consumption for each equipment category (heating,
#     water heating, clothes drying, and cooking) for future years based on their expected lifetime.
#     It applies climate adjustment factors for heating and water heating categories.
#
#     Args:
#         df: The input DataFrame containing baseline consumption data.
#         menu_mp: Indicates the measure package to apply. 0 for baseline, or a positive integer
#             (e.g., 8, 9, 10) for retrofit scenarios.
#         base_year: The starting year for projections. Defaults to 2024.
#
#     Returns:
#         A tuple containing two DataFrames:
#             - df_copy: The updated DataFrame with all columns including the projected consumption data.
#             - df_consumption: The DataFrame containing only the projected consumption data.
#
#     Raises:
#         KeyError: If the 'census_division' column is missing from the DataFrame.
#
#
# RESULTS OUTPUT:
#
#
# Determining valid homes for calculations:
# Measure package calculation for heating:
#   - 260211 homes have valid data
#   - 331523 homes will receive retrofits
#   - 260209 homes have both valid data AND will receive retrofits
#   - 71322 homes excluded (values will be NaN)
# Measure package calculation for waterHeating:
#   - 322799 homes have valid data
#   - 329628 homes will receive retrofits
#   - 322796 homes have both valid data AND will receive retrofits
#   - 8735 homes excluded (values will be NaN)
# Measure package calculation for clothesDrying:
#   - 316573 homes have valid data
#   - 316570 homes will receive retrofits
#   - 316570 homes have both valid data AND will receive retrofits
#   - 14961 homes excluded (values will be NaN)
# Measure package calculation for cooking:
#   - 126373 homes have valid data
#   - 126373 homes will receive retrofits
#   - 126373 homes have both valid data AND will receive retrofits
#   - 205158 homes excluded (values will be NaN)
#
# ===== Processing HEATING =====
# Projecting consumption for 260209 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): heating
#
# ===== Processing WATERHEATING =====
# Projecting consumption for 322796 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): waterHeating
#
# ===== Processing CLOTHESDRYING =====
# Projecting consumption for 316570 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): clothesDrying
#
# ===== Processing COOKING =====
# Projecting consumption for 126373 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): cooking
#
# Verifying masking for all projected columns:
# Masking 47 columns for category 'heating'
# Masking 38 columns for category 'waterHeating'
# Masking 41 columns for category 'clothesDrying'
# Masking 47 columns for category 'cooking'
#
# ====================================================================================================================================================================
# DATAFRAME FOR MEASURE PACKAGE 8 (MP8):
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ... mp8_2034_cooking_consumption  \
# bldg_id            ...
# 239      G0100390  ...                       471.26
# 273      G0100150  ...                          NaN
# 307      G0100850  ...                          NaN
# 409      G0100050  ...                       486.50
# 517      G0101270  ...                          NaN
# ...           ...  ...                          ...
# 548226   G5600050  ...                          NaN
# 548228   G5600010  ...                          NaN
# 548417   G5600250  ...                          NaN
# 549740   G5600390  ...                       486.50
# 549938   G5600010  ...                       482.69
#
#         mp8_2034_cooking_reduction_consumption mp8_2035_cooking_consumption  \
# bldg_id
# 239                                     508.18                       471.26
# 273                                        NaN                          NaN
# 307                                        NaN                          NaN
# 409                                     523.13                       486.50
# 517                                        NaN                          NaN
# ...                                        ...                          ...
# 548226                                     NaN                          NaN
# 548228                                     NaN                          NaN
# 548417                                     NaN                          NaN
# 549740                                  523.13                       486.50
# 549938                                  522.25                       482.69
#
#         mp8_2035_cooking_reduction_consumption  mp8_2036_cooking_consumption  \
# bldg_id
# 239                                     508.18                        471.26
# 273                                        NaN                           NaN
# 307                                        NaN                           NaN
# 409                                     523.13                        486.50
# 517                                        NaN                           NaN
# ...                                        ...                           ...
# 548226                                     NaN                           NaN
# 548228                                     NaN                           NaN
# 548417                                     NaN                           NaN
# 549740                                  523.13                        486.50
# 549938                                  522.25                        482.69
#
#          mp8_2036_cooking_reduction_consumption mp8_2037_cooking_consumption  \
# bldg_id
# 239                                      508.18                       471.26
# 273                                         NaN                          NaN
# 307                                         NaN                          NaN
# 409                                      523.13                       486.50
# 517                                         NaN                          NaN
# ...                                         ...                          ...
# 548226                                      NaN                          NaN
# 548228                                      NaN                          NaN
# 548417                                      NaN                          NaN
# 549740                                   523.13                       486.50
# 549938                                   522.25                       482.69
#
#         mp8_2037_cooking_reduction_consumption mp8_2038_cooking_consumption  \
# bldg_id
# 239                                     508.18                       471.26
# 273                                        NaN                          NaN
# 307                                        NaN                          NaN
# 409                                     523.13                       486.50
# 517                                        NaN                          NaN
# ...                                        ...                          ...
# 548226                                     NaN                          NaN
# 548228                                     NaN                          NaN
# 548417                                     NaN                          NaN
# 549740                                  523.13                       486.50
# 549938                                  522.25                       482.69
#
#         mp8_2038_cooking_reduction_consumption
# bldg_id
# 239                                     508.18
# 273                                        NaN
# 307                                        NaN
# 409                                     523.13
# 517                                        NaN
# ...                                        ...
# 548226                                     NaN
# 548228                                     NaN
# 548417                                     NaN
# 549740                                  523.13
# 549938                                  522.25
#
# [331531 rows x 311 columns]
#
# DATAFRAME (Consumption Cols): df_mp8_consumption
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ... mp8_2034_cooking_consumption  \
# bldg_id            ...
# 239      G0100390  ...                       471.26
# 273      G0100150  ...                          NaN
# 307      G0100850  ...                          NaN
# 409      G0100050  ...                       486.50
# 517      G0101270  ...                          NaN
# ...           ...  ...                          ...
# 548226   G5600050  ...                          NaN
# 548228   G5600010  ...                          NaN
# 548417   G5600250  ...                          NaN
# 549740   G5600390  ...                       486.50
# 549938   G5600010  ...                       482.69
#
#         mp8_2034_cooking_reduction_consumption mp8_2035_cooking_consumption  \
# bldg_id
# 239                                     508.18                       471.26
# 273                                        NaN                          NaN
# 307                                        NaN                          NaN
# 409                                     523.13                       486.50
# 517                                        NaN                          NaN
# ...                                        ...                          ...
# 548226                                     NaN                          NaN
# 548228                                     NaN                          NaN
# 548417                                     NaN                          NaN
# 549740                                  523.13                       486.50
# 549938                                  522.25                       482.69
#
#         mp8_2035_cooking_reduction_consumption  mp8_2036_cooking_consumption  \
# bldg_id
# 239                                     508.18                        471.26
# 273                                        NaN                           NaN
# 307                                        NaN                           NaN
# 409                                     523.13                        486.50
# 517                                        NaN                           NaN
# ...                                        ...                           ...
# 548226                                     NaN                           NaN
# 548228                                     NaN                           NaN
# 548417                                     NaN                           NaN
# 549740                                  523.13                        486.50
# 549938                                  522.25                        482.69
#
#          mp8_2036_cooking_reduction_consumption mp8_2037_cooking_consumption  \
# bldg_id
# 239                                      508.18                       471.26
# 273                                         NaN                          NaN
# 307                                         NaN                          NaN
# 409                                      523.13                       486.50
# 517                                         NaN                          NaN
# ...                                         ...                          ...
# 548226                                      NaN                          NaN
# 548228                                      NaN                          NaN
# 548417                                      NaN                          NaN
# 549740                                   523.13                       486.50
# 549938                                   522.25                       482.69
#
#         mp8_2037_cooking_reduction_consumption mp8_2038_cooking_consumption  \
# bldg_id
# 239                                     508.18                       471.26
# 273                                        NaN                          NaN
# ...
# 409                                       Public Benefit
# 517                                       Public Benefit
# ...                                                  ...
# 548226                                    Public Benefit
# 548228                                    Public Benefit
# 548417                                    Public Benefit
# 549740                                    Public Benefit
# 549938                                    Public Benefit
#
#          iraRef_mp8_cooking_health_sensitivity  \
# bldg_id
# 239                                EASIUR, h6c
# 273                                        NaN
# 307                                        NaN
# 409                                EASIUR, h6c
# 517                                        NaN
# ...                                        ...
# 548226                                     NaN
# 548228                                     NaN
# 548417                                     NaN
# 549740                             EASIUR, h6c
# 549938                             EASIUR, h6c
#
#          iraRef_mp8_cooking_benefit_upper_EASIUR_h6c  \
# bldg_id
# 239                                           181.84
# 273                                              NaN
# 307                                              NaN
# 409                                             0.00
# 517                                              NaN
# ...                                              ...
# 548226                                           NaN
# 548228                                           NaN
# 548417                                           NaN
# 549740                                        678.06
# 549938                                          0.00
#
#         iraRef_mp8_cooking_total_npv_lessWTP_upper_EASIUR_h6c  \
# bldg_id
# 239                                               -1353.40
# 273                                                    NaN
# 307                                                    NaN
# 409                                                -417.78
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                             -687.85
# 549938                                             -803.83
#
#          iraRef_mp8_cooking_total_npv_moreWTP_upper_EASIUR_h6c  \
# bldg_id
# 239                                                -280.86
# 273                                                    NaN
# 307                                                    NaN
# 409                                                 654.76
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                              384.69
# 549938                                              268.71
#
#         iraRef_mp8_cooking_adoption_upper_EASIUR_h6c  \
# bldg_id
# 239                                   Tier 4: Averse
# 273                                              NaN
# 307                                              NaN
# 409                 Tier 2: Feasible vs. Alternative
# 517                                              NaN
# ...                                              ...
# 548226                                           NaN
# 548228                                           NaN
# 548417                                           NaN
# 549740         Tier 3: Subsidy-Dependent Feasibility
# 549938         Tier 3: Subsidy-Dependent Feasibility
#
#         iraRef_mp8_cooking_impact_upper_EASIUR_h6c
# bldg_id
# 239                                 Public Benefit
# 273                                            NaN
# 307                                            NaN
# 409                                 Public Benefit
# 517                                            NaN
# ...                                            ...
# 548226                                         NaN
# 548228                                         NaN
# 548417                                         NaN
# 549740                              Public Benefit
# 549938                              Public Benefit
#
# [331531 rows x 725 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ...  \
# bldg_id            ...
# 239      G0100390  ...
# 273      G0100150  ...
# 307      G0100850  ...
# 409      G0100050  ...
# 517      G0101270  ...
# ...           ...  ...
# 548226   G5600050  ...
# 548228   G5600010  ...
# 548417   G5600250  ...
# 549740   G5600390  ...
# 549938   G5600010  ...
#
#         iraRef_mp8_clothesDrying_total_npv_lessWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                               -1134.37
# 273                                                 520.42
# 307                                                  20.14
# 409                                                -355.69
# 517                                                -213.45
# ...                                                    ...
# 548226                                             -923.03
# 548228                                            -1913.20
# 548417                                             -144.61
# 549740                                            -2479.65
# 549938                                              169.76
#
#         iraRef_mp8_clothesDrying_total_npv_moreWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                                -140.31
# 273                                                1514.48
# 307                                                1014.20
# 409                                                 638.37
# 517                                                 780.61
# ...                                                    ...
# 548226                                               71.03
# 548228                                             -919.14
# 548417                                              849.45
# 549740                                            -1485.59
# 549938                                             1163.82
#
#         iraRef_mp8_clothesDrying_adoption_upper_InMAP_h6c  \
# bldg_id
# 239                                        Tier 4: Averse
# 273                      Tier 2: Feasible vs. Alternative
# 307                      Tier 2: Feasible vs. Alternative
# 409                      Tier 2: Feasible vs. Alternative
# 517                      Tier 2: Feasible vs. Alternative
# ...                                                   ...
# 548226              Tier 3: Subsidy-Dependent Feasibility
# 548228                                     Tier 4: Averse
# 548417                   Tier 2: Feasible vs. Alternative
# 549740                                     Tier 4: Averse
# 549938                   Tier 2: Feasible vs. Alternative
#
#         iraRef_mp8_clothesDrying_impact_upper_InMAP_h6c  \
# bldg_id
# 239                                      Public Benefit
# 273                                      Public Benefit
# 307                                      Public Benefit
# 409                                      Public Benefit
# 517                                      Public Benefit
# ...                                                 ...
# 548226                                   Public Benefit
# 548228                                   Public Benefit
# 548417                                   Public Benefit
# 549740                                   Public Benefit
# 549938                                   Public Benefit
#
#          iraRef_mp8_cooking_health_sensitivity  \
# bldg_id
# 239                                 InMAP, h6c
# 273                                        NaN
# 307                                        NaN
# 409                                 InMAP, h6c
# 517                                        NaN
# ...                                        ...
# 548226                                     NaN
# 548228                                     NaN
# 548417                                     NaN
# 549740                              InMAP, h6c
# 549938                              InMAP, h6c
#
#          iraRef_mp8_cooking_benefit_upper_InMAP_h6c  \
# bldg_id
# 239                                          189.18
# 273                                             NaN
# 307                                             NaN
# 409                                            0.00
# 517                                             NaN
# ...                                             ...
# 548226                                          NaN
# 548228                                          NaN
# 548417                                          NaN
# 549740                                       704.45
# 549938                                         0.00
#
#         iraRef_mp8_cooking_total_npv_lessWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                               -1346.06
# 273                                                    NaN
# 307                                                    NaN
# 409                                                -406.66
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                             -661.46
# 549938                                             -808.72
#
#          iraRef_mp8_cooking_total_npv_moreWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                                -273.52
# 273                                                    NaN
# 307                                                    NaN
# 409                                                 665.88
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                              411.08
# 549938                                              263.82
#
#         iraRef_mp8_cooking_adoption_upper_InMAP_h6c  \
# bldg_id
# 239                                  Tier 4: Averse
# 273                                             NaN
# 307                                             NaN
# 409                Tier 2: Feasible vs. Alternative
# 517                                             NaN
# ...                                             ...
# 548226                                          NaN
# 548228                                          NaN
# 548417                                          NaN
# 549740        Tier 3: Subsidy-Dependent Feasibility
# 549938        Tier 3: Subsidy-Dependent Feasibility
#
#         iraRef_mp8_cooking_impact_upper_InMAP_h6c
# bldg_id
# 239                                Public Benefit
# 273                                           NaN
# 307                                           NaN
# 409                                Public Benefit
# 517                                           NaN
# ...                                           ...
# 548226                                        NaN
# 548228                                        NaN
# 548417                                        NaN
# 549740                             Public Benefit
# 549938                             Public Benefit
#
# [331531 rows x 725 columns]
#
#
# The code took 54 minutes and 50 seconds to execute.
# Basic Retrofit Scenario - Model Run Complete

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV
# ===================================================================================================================================================================================

# CONSUMPTION RESULTS
export_model_run_output(
    df_results_export=df_mp8_consumption,
    results_category='consumption',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp8_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp8_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp8_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp8_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp8_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp8_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

# ===== SUMMARY RESULTS =====
# SUMMARY RESULTS
export_model_run_output(
    df_results_export=df_euss_am_mp8_home_ap2,
    results_category='summary_basic_ap2',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_euss_am_mp8_home_easiur,
    results_category='summary_basic_easiur',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_euss_am_mp8_home_inmap,
    results_category='summary_basic_inmap',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )
# Out:
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: consumption
# Dataframe results will be saved in this csv file: mp8_data_consumption_National_2025-05-15_21-39.csv
# Dataframe for MP8 consumption results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_consumption\consumption_all_scenarios\mp8_data_consumption_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_climate_noIRA
# Dataframe results will be saved in this csv file: mp8_damages_climate_noIRA_National_2025-05-15_21-39.csv
# Dataframe for MP8 damages_climate_noIRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_noIRA\mp8_damages_climate_noIRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_climate_IRA
# Dataframe results will be saved in this csv file: mp8_damages_climate_IRA_National_2025-05-15_21-39.csv
# Dataframe for MP8 damages_climate_IRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_IRA\mp8_damages_climate_IRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_health_noIRA
# Dataframe results will be saved in this csv file: mp8_damages_health_noIRA_National_2025-05-15_21-39.csv
# Dataframe for MP8 damages_health_noIRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_noIRA\mp8_damages_health_noIRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_health_IRA
# Dataframe results will be saved in this csv file: mp8_damages_health_IRA_National_2025-05-15_21-39.csv
# Dataframe for MP8 damages_health_IRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_IRA\mp8_damages_health_IRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: fuel_costs_noIRA
# Dataframe results will be saved in this csv file: mp8_fuel_costs_noIRA_National_2025-05-15_21-39.csv
# Dataframe for MP8 fuel_costs_noIRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_noIRA\mp8_fuel_costs_noIRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: fuel_costs_IRA
# Dataframe results will be saved in this csv file: mp8_fuel_costs_IRA_National_2025-05-15_21-39.csv
# Dataframe for MP8 fuel_costs_IRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_IRA\mp8_fuel_costs_IRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 (MP8) RESULTS for model ap2:
# Dataframe results will be saved in this csv file: mp8_results_National_2025-05-15_21-39.csv
# Dataframe for MP8 summary_basic_ap2 results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\retrofit_basic_summary\summary_basic_ap2\mp8_results_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 (MP8) RESULTS for model easiur:
# Dataframe results will be saved in this csv file: mp8_results_National_2025-05-15_21-39.csv
# Dataframe for MP8 summary_basic_easiur results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\retrofit_basic_summary\summary_basic_easiur\mp8_results_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 8 (MP8) RESULTS for model inmap:
# Dataframe results will be saved in this csv file: mp8_results_National_2025-05-15_21-39.csv
# Dataframe for MP8 summary_basic_inmap results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\retrofit_basic_summary\summary_basic_inmap\mp8_results_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Moderate Retrofit: Measure Package 9 (MP9)

# %%
# Measure Package 9
menu_mp = 9
input_mp = 'upgrade09'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_moderate_v2_1.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Moderate Retrofit Scenario - Model Run Complete")
# Out:
# PROJECT_ROOT (from config.py): c:\users\14128\research\cmu-tare-model
# Running file: c:/users/14128/research/cmu-tare-model/cmu_tare_model/model_scenarios/tare_moderate_v2_1.ipynb
#
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (mp9).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\14128\research\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\state\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# DATAFRAME SIZE after filtering for 'Single-Family Attached' and 'Single-Family Detached' homes: (331531, 346)
# You chose to analyze all of the United States.
# DATAFRAME SIZE after applying geographic filter: (331531, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 239            7  242.131013           True   1690.0
# 273            7  242.131013          False   1690.0
# 307            7  242.131013          False   1220.0
# 409            7  242.131013           True   1220.0
# 517            7  242.131013          False   1220.0
# ...          ...         ...            ...      ...
# 548226         7  242.131013           True   2176.0
# 548228         7  242.131013           True   1690.0
# 548417         7  242.131013           True    885.0
# 549740         7  242.131013           True   1220.0
# 549938         7  242.131013           True    885.0
#
#                        in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 239      Non-CBSA East South Central                               3A
# 273      Non-CBSA East South Central                               3A
# 307      Non-CBSA East South Central                               3A
# 409      Non-CBSA East South Central                               3A
# 517      Non-CBSA East South Central                               3A
# ...                              ...                              ...
# 548226             Non-CBSA Mountain                               6B
# 548228             Non-CBSA Mountain                               6B
# 548417             Non-CBSA Mountain                               6B
# 549740             Non-CBSA Mountain                               7B
# 549938             Non-CBSA Mountain                               6B
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 239                                             3A                     Hour20
# 273                                             3A                     Hour12
# 307                                             3A                      Hour0
# 409                                             3A                     Hour20
# 517                                             3A                      Hour1
# ...                                            ...                        ...
# 548226                                          6B                      Hour3
# 548228                                          6B                      Hour6
# 548417                                          6B                     Hour18
# 549740                                          7B                      Hour4
# 549938                                          6B                      Hour2
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 239                3                        Hot-Humid  ...
# 273                3                      Mixed-Humid  ...
# 307                4                        Hot-Humid  ...
# 409                2                        Hot-Humid  ...
# 517                3                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 548226             4                             Cold  ...
# 548228             4                             Cold  ...
# 548417             2                             Cold  ...
# 549740             2                        Very Cold  ...
# 549938             2                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                               0.000000
# 273                                               0.000000
# 307                                               0.000000
# 409                                               0.000000
# 517                                               0.000000
# ...                                                    ...
# 548226                                            0.000000
# 548228                                            0.000000
# 548417                                            0.000000
# 549740                                          268.627834
# 549938                                            0.000000
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 239                                             142.374480
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1439.855043
# 517                                               0.000000
# ...                                                    ...
# 548226                                         8790.508547
# 548228                                         5124.531468
# 548417                                         3748.197047
# 549740                                          152.327658
# 549938                                         7833.858198
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 239                                              75.157988
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1235.288966
# 517                                               0.000000
# ...                                                    ...
# 548226                                         9652.472396
# 548228                                         5456.571515
# 548417                                         3986.523550
# 549740                                          178.841946
# 549938                                         8061.021339
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 239                                              91.998512
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1299.421938
# 517                                               0.000000
# ...                                                    ...
# 548226                                        10147.078588
# 548228                                         5713.602807
# 548417                                         4071.210606
# 549740                                          198.041150
# 549938                                         8199.976187
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                              19.421011
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1129.822844
# 517                                               0.000000
# ...                                                    ...
# 548226                                         5326.981989
# 548228                                         3463.786920
# 548417                                         3004.825830
# 549740                                           75.301777
# 549938                                         6852.064771
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 239                       NaN  Electric, 100% Usage
# 273                       NaN                   NaN
# 307                       NaN                   NaN
# 409                       NaN  Electric, 120% Usage
# 517                       NaN                   NaN
# ...                       ...                   ...
# 548226                    NaN                   NaN
# 548228                    NaN                   NaN
# 548417                    NaN                   NaN
# 549740                    NaN  Electric, 120% Usage
# 549938                    NaN   Electric, 80% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 239                                 NaN                                NaN
# 273                                 NaN                                NaN
# 307                                 NaN                                NaN
# 409                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 517                                 NaN                                NaN
# ...                                 ...                                ...
# 548226                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 548228                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 548417                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549740                              NaN                                NaN
# 549938                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
#
#               upgrade.water_heater_efficiency
# bldg_id
# 239                                       NaN
# 273                                       NaN
# 307                                       NaN
# 409      Electric Heat Pump, 50 gal, 3.45 UEF
# 517                                       NaN
# ...                                       ...
# 548226   Electric Heat Pump, 66 gal, 3.35 UEF
# 548228   Electric Heat Pump, 66 gal, 3.35 UEF
# 548417   Electric Heat Pump, 50 gal, 3.45 UEF
# 549740                                    NaN
# 549938   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [331531 rows x 346 columns]
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Moderate-BAU:
# Moderate Retrofit: Measure Package 9
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade09_metadata_and_annual_results.csv
# Located at filepath: c:\users\14128\research\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\state\upgrade09_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 351)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 351)
# DATAFRAME SIZE after filtering for 'Single-Family Attached' and 'Single-Family Detached' homes: (331531, 351)
# You chose to analyze all of the United States.
# DATAFRAME SIZE after applying geographic filter: (331531, 351)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 239            9  242.131013           True   1690.0
# 273            9  242.131013           True   1690.0
# 307            9  242.131013           True   1220.0
# 409            9  242.131013           True   1220.0
# 517            9  242.131013           True   1220.0
# ...          ...         ...            ...      ...
# 548226         9  242.131013           True   2176.0
# 548228         9  242.131013           True   1690.0
# 548417         9  242.131013           True    885.0
# 549740         9  242.131013           True   1220.0
# 549938         9  242.131013           True    885.0
#
#                        in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 239      Non-CBSA East South Central                               3A
# 273      Non-CBSA East South Central                               3A
# 307      Non-CBSA East South Central                               3A
# 409      Non-CBSA East South Central                               3A
# 517      Non-CBSA East South Central                               3A
# ...                              ...                              ...
# 548226             Non-CBSA Mountain                               6B
# 548228             Non-CBSA Mountain                               6B
# 548417             Non-CBSA Mountain                               6B
# 549740             Non-CBSA Mountain                               7B
# 549938             Non-CBSA Mountain                               6B
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 239                                             3A                     Hour20
# 273                                             3A                     Hour12
# 307                                             3A                      Hour0
# 409                                             3A                     Hour20
# 517                                             3A                      Hour1
# ...                                            ...                        ...
# 548226                                          6B                      Hour3
# 548228                                          6B                      Hour6
# 548417                                          6B                     Hour18
# 549740                                          7B                      Hour4
# 549938                                          6B                      Hour2
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 239                3                        Hot-Humid  ...
# 273                3                      Mixed-Humid  ...
# 307                4                        Hot-Humid  ...
# 409                2                        Hot-Humid  ...
# 517                3                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 548226             4                             Cold  ...
# 548228             4                             Cold  ...
# 548417             2                             Cold  ...
# 549740             2                        Very Cold  ...
# 549938             2                             Cold  ...
#
#                                      upgrade.clothes_dryer  \
# bldg_id
# 239      Electric, Premium, Heat Pump, Ventless, 100% U...
# 273      Electric, Premium, Heat Pump, Ventless, 100% U...
# 307      Electric, Premium, Heat Pump, Ventless, 100% U...
# 409      Electric, Premium, Heat Pump, Ventless, 120% U...
# 517      Electric, Premium, Heat Pump, Ventless, 80% Usage
# ...                                                    ...
# 548226   Electric, Premium, Heat Pump, Ventless, 100% U...
# 548228   Electric, Premium, Heat Pump, Ventless, 100% U...
# 548417   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549740   Electric, Premium, Heat Pump, Ventless, 120% U...
# 549938   Electric, Premium, Heat Pump, Ventless, 80% Usage
#
#                    upgrade.cooking_range     upgrade.ducts  \
# bldg_id
# 239      Electric, Induction, 100% Usage  10% Leakage, R-8
# 273      Electric, Induction, 100% Usage  10% Leakage, R-8
# 307      Electric, Induction, 100% Usage  10% Leakage, R-8
# 409      Electric, Induction, 120% Usage               NaN
# 517       Electric, Induction, 80% Usage  10% Leakage, R-8
# ...                                  ...               ...
# 548226   Electric, Induction, 100% Usage               NaN
# 548228   Electric, Induction, 100% Usage  10% Leakage, R-8
# 548417   Electric, Induction, 120% Usage               NaN
# 549740   Electric, Induction, 120% Usage  10% Leakage, R-8
# 549938    Electric, Induction, 80% Usage               NaN
#
#         upgrade.hvac_cooling_efficiency     upgrade.hvac_heating_efficiency  \
# bldg_id
# 239                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 273                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 307                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 409                           Heat Pump              MSHP, SEER 24, 13 HSPF
# 517                           Heat Pump              MSHP, SEER 24, 13 HSPF
# ...                                 ...                                 ...
# 548226                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 548228                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 548417                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 549740                        Heat Pump              MSHP, SEER 24, 13 HSPF
# 549938                        Heat Pump  MSHP, SEER 29.3, 14 HSPF, Max Load
#
#         upgrade.hvac_heating_type upgrade.infiltration_reduction  \
# bldg_id
# 239              Ducted Heat Pump                            30%
# 273              Ducted Heat Pump                            30%
# 307              Ducted Heat Pump                            30%
# 409              Ducted Heat Pump                            30%
# 517              Ducted Heat Pump                            30%
# ...                           ...                            ...
# 548226           Ducted Heat Pump                            30%
# 548228           Ducted Heat Pump                            30%
# 548417           Ducted Heat Pump                            NaN
# 549740           Ducted Heat Pump                            30%
# 549938                        NaN                            30%
#
#         upgrade.insulation_ceiling upgrade.insulation_wall  \
# bldg_id
# 239                           R-49                     NaN
# 273                            NaN                     NaN
# 307                           R-49                     NaN
# 409                           R-49         Wood Stud, R-13
# 517                           R-49                     NaN
# ...                            ...                     ...
# 548226                        R-60         Wood Stud, R-13
# 548228                        R-60                     NaN
# 548417                        R-60         Wood Stud, R-13
# 549740                        R-60                     NaN
# 549938                        R-60         Wood Stud, R-13
#
#               upgrade.water_heater_efficiency
# bldg_id
# 239      Electric Heat Pump, 50 gal, 3.45 UEF
# 273      Electric Heat Pump, 50 gal, 3.45 UEF
# 307      Electric Heat Pump, 66 gal, 3.35 UEF
# 409      Electric Heat Pump, 50 gal, 3.45 UEF
# 517      Electric Heat Pump, 50 gal, 3.45 UEF
# ...                                       ...
# 548226   Electric Heat Pump, 66 gal, 3.35 UEF
# 548228   Electric Heat Pump, 66 gal, 3.35 UEF
# 548417   Electric Heat Pump, 50 gal, 3.45 UEF
# 549740   Electric Heat Pump, 50 gal, 3.45 UEF
# 549938   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [331531 rows x 351 columns]
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 9 (MP9)
# ====================================================================================================================================================================
# You'll notice that the number of rows differs from df_euss_am_mp7 and df_euss_am_mp9.
#       - df_euss_am_baseline_home has fewer rows (representative dwelling units) because a tech filter was applied.
#       - df_euss_am_mp9_home will have the same number of rows as df_euss_am_baseline_home after df_enduse_compare function is run.
#       - df_enduse_compare function performs an inner merge on the two dataframes, keeping only the rows that are present in both dataframes.
# ====================================================================================================================================================================
# df_euss_am_mp9_home will be created by running the df_enduse_compare function (contains post-retrofit consumption data for the entire home in 2024).
# process_euss_data.py file contains the function definition.
#
# Documentation for df_enduse_compare function:
# Creates a comparison DataFrame by merging multiple DataFrames based on measure packages.
#
#     This function constructs a new DataFrame (df_compare) that includes columns
#     from df_mp, df_cooking_range, and merges them with df_baseline to compare
#     baseline vs. measure package outputs for heating, water heating, clothes drying,
#     and cooking.
#
#     Args:
#         df_mp: The main DataFrame containing modeling parameters and outputs.
#         input_mp: The input measure package ID (e.g., 'upgrade09', 'upgrade10').
#         menu_mp: The menu measure package number.
#         df_baseline: The baseline DataFrame to merge with df_compare.
#         df_cooking_range: Additional DataFrame for cooking range parameters/outputs.
#
#     Returns:
#         A merged DataFrame (df_compare) that includes relevant columns for
#         baseline and measure packages comparison.
#
# ----------------------------------------------------------------
#
# RESULTING DATAFRAME:
#
#
# Applying combined validation (data quality + retrofit status):
# Measure package calculation for heating:
#   - 260211 homes have valid data
#   - 331526 homes will receive retrofits
#   - 260211 homes have both valid data AND will receive retrofits
#   - 71320 homes excluded (values will be NaN)
#   mp9_heating_consumption: Masked 71320 values
# Measure package calculation for waterHeating:
#   - 322799 homes have valid data
#   - 329631 homes will receive retrofits
#   - 322799 homes have both valid data AND will receive retrofits
#   - 8732 homes excluded (values will be NaN)
#   mp9_waterHeating_consumption: Masked 8732 values
# Measure package calculation for clothesDrying:
#   - 316573 homes have valid data
#   - 316573 homes will receive retrofits
#   - 316573 homes have both valid data AND will receive retrofits
#   - 14958 homes excluded (values will be NaN)
#   mp9_clothesDrying_consumption: Masked 14958 values
# Measure package calculation for cooking:
#   - 126373 homes have valid data
#   - 126373 homes will receive retrofits
#   - 126373 homes have both valid data AND will receive retrofits
#   - 205158 homes excluded (values will be NaN)
#   mp9_cooking_consumption: Masked 205158 values
#
# ====================================================================================================================================================================
# PROJECT FUTURE ENERGY CONSUMPTION
# ====================================================================================================================================================================
# project_future_energy_consumption.py file was used to calculate/project the annual energy consumption
# for each home in the dataframe.
#
# Documentation for project_future_energy_consumption function:
# Projects future energy consumption based on baseline or upgraded equipment specifications.
#
#     This function calculates projected energy consumption for each equipment category (heating,
#     water heating, clothes drying, and cooking) for future years based on their expected lifetime.
#     It applies climate adjustment factors for heating and water heating categories.
#
#     Args:
#         df: The input DataFrame containing baseline consumption data.
#         menu_mp: Indicates the measure package to apply. 0 for baseline, or a positive integer
#             (e.g., 8, 9, 10) for retrofit scenarios.
#         base_year: The starting year for projections. Defaults to 2024.
#
#     Returns:
#         A tuple containing two DataFrames:
#             - df_copy: The updated DataFrame with all columns including the projected consumption data.
#             - df_consumption: The DataFrame containing only the projected consumption data.
#
#     Raises:
#         KeyError: If the 'census_division' column is missing from the DataFrame.
#
#
# RESULTS OUTPUT:
#
#
# Determining valid homes for calculations:
# Measure package calculation for heating:
#   - 260211 homes have valid data
#   - 331526 homes will receive retrofits
#   - 260211 homes have both valid data AND will receive retrofits
#   - 71320 homes excluded (values will be NaN)
# Measure package calculation for waterHeating:
#   - 322799 homes have valid data
#   - 329631 homes will receive retrofits
#   - 322799 homes have both valid data AND will receive retrofits
#   - 8732 homes excluded (values will be NaN)
# Measure package calculation for clothesDrying:
#   - 316573 homes have valid data
#   - 316573 homes will receive retrofits
#   - 316573 homes have both valid data AND will receive retrofits
#   - 14958 homes excluded (values will be NaN)
# Measure package calculation for cooking:
#   - 126373 homes have valid data
#   - 126373 homes will receive retrofits
#   - 126373 homes have both valid data AND will receive retrofits
#   - 205158 homes excluded (values will be NaN)
#
# ===== Processing HEATING =====
# Projecting consumption for 260211 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): heating
#
# ===== Processing WATERHEATING =====
# Projecting consumption for 322799 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): waterHeating
#
# ===== Processing CLOTHESDRYING =====
# Projecting consumption for 316573 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): clothesDrying
#
# ===== Processing COOKING =====
# Projecting consumption for 126373 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): cooking
#
# Verifying masking for all projected columns:
# Masking 47 columns for category 'heating'
# Masking 38 columns for category 'waterHeating'
# Masking 41 columns for category 'clothesDrying'
# Masking 47 columns for category 'cooking'
#
# ====================================================================================================================================================================
# DATAFRAME FOR MEASURE PACKAGE 9 (MP9):
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ... mp9_2034_cooking_consumption  \
# bldg_id            ...
# 239      G0100390  ...                       471.26
# 273      G0100150  ...                          NaN
# 307      G0100850  ...                          NaN
# 409      G0100050  ...                       486.50
# 517      G0101270  ...                          NaN
# ...           ...  ...                          ...
# 548226   G5600050  ...                          NaN
# 548228   G5600010  ...                          NaN
# 548417   G5600250  ...                          NaN
# 549740   G5600390  ...                       486.50
# 549938   G5600010  ...                       482.69
#
#         mp9_2034_cooking_reduction_consumption mp9_2035_cooking_consumption  \
# bldg_id
# 239                                     508.18                       471.26
# 273                                        NaN                          NaN
# 307                                        NaN                          NaN
# 409                                     523.13                       486.50
# 517                                        NaN                          NaN
# ...                                        ...                          ...
# 548226                                     NaN                          NaN
# 548228                                     NaN                          NaN
# 548417                                     NaN                          NaN
# 549740                                  523.13                       486.50
# 549938                                  522.25                       482.69
#
#         mp9_2035_cooking_reduction_consumption  mp9_2036_cooking_consumption  \
# bldg_id
# 239                                     508.18                        471.26
# 273                                        NaN                           NaN
# 307                                        NaN                           NaN
# 409                                     523.13                        486.50
# 517                                        NaN                           NaN
# ...                                        ...                           ...
# 548226                                     NaN                           NaN
# 548228                                     NaN                           NaN
# 548417                                     NaN                           NaN
# 549740                                  523.13                        486.50
# 549938                                  522.25                        482.69
#
#          mp9_2036_cooking_reduction_consumption mp9_2037_cooking_consumption  \
# bldg_id
# 239                                      508.18                       471.26
# 273                                         NaN                          NaN
# 307                                         NaN                          NaN
# 409                                      523.13                       486.50
# 517                                         NaN                          NaN
# ...                                         ...                          ...
# 548226                                      NaN                          NaN
# 548228                                      NaN                          NaN
# 548417                                      NaN                          NaN
# 549740                                   523.13                       486.50
# 549938                                   522.25                       482.69
#
#         mp9_2037_cooking_reduction_consumption mp9_2038_cooking_consumption  \
# bldg_id
# 239                                     508.18                       471.26
# 273                                        NaN                          NaN
# 307                                        NaN                          NaN
# 409                                     523.13                       486.50
# 517                                        NaN                          NaN
# ...                                        ...                          ...
# 548226                                     NaN                          NaN
# 548228                                     NaN                          NaN
# 548417                                     NaN                          NaN
# 549740                                  523.13                       486.50
# 549938                                  522.25                       482.69
#
#         mp9_2038_cooking_reduction_consumption
# bldg_id
# 239                                     508.18
# 273                                        NaN
# 307                                        NaN
# 409                                     523.13
# 517                                        NaN
# ...                                        ...
# 548226                                     NaN
# 548228                                     NaN
# 548417                                     NaN
# 549740                                  523.13
# 549938                                  522.25
#
# [331531 rows x 321 columns]
#
# DATAFRAME (Consumption Cols): df_mp9_consumption
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ... mp9_2034_cooking_consumption  \
# bldg_id            ...
# 239      G0100390  ...                       471.26
# 273      G0100150  ...                          NaN
# 307      G0100850  ...                          NaN
# 409      G0100050  ...                       486.50
# 517      G0101270  ...                          NaN
# ...           ...  ...                          ...
# 548226   G5600050  ...                          NaN
# 548228   G5600010  ...                          NaN
# 548417   G5600250  ...                          NaN
# 549740   G5600390  ...                       486.50
# 549938   G5600010  ...                       482.69
#
#         mp9_2034_cooking_reduction_consumption mp9_2035_cooking_consumption  \
# bldg_id
# 239                                     508.18                       471.26
# 273                                        NaN                          NaN
# 307                                        NaN                          NaN
# 409                                     523.13                       486.50
# 517                                        NaN                          NaN
# ...                                        ...                          ...
# 548226                                     NaN                          NaN
# 548228                                     NaN                          NaN
# 548417                                     NaN                          NaN
# 549740                                  523.13                       486.50
# 549938                                  522.25                       482.69
#
#         mp9_2035_cooking_reduction_consumption  mp9_2036_cooking_consumption  \
# bldg_id
# 239                                     508.18                        471.26
# 273                                        NaN                           NaN
# 307                                        NaN                           NaN
# 409                                     523.13                        486.50
# 517                                        NaN                           NaN
# ...                                        ...                           ...
# 548226                                     NaN                           NaN
# 548228                                     NaN                           NaN
# 548417                                     NaN                           NaN
# 549740                                  523.13                        486.50
# 549938                                  522.25                        482.69
#
#          mp9_2036_cooking_reduction_consumption mp9_2037_cooking_consumption  \
# bldg_id
# 239                                      508.18                       471.26
# 273                                         NaN                          NaN
# 307                                         NaN                          NaN
# 409                                      523.13                       486.50
# 517                                         NaN                          NaN
# ...                                         ...                          ...
# 548226                                      NaN                          NaN
# 548228                                      NaN                          NaN
# 548417                                      NaN                          NaN
# 549740                                   523.13                       486.50
# 549938                                   522.25                       482.69
#
#         mp9_2037_cooking_reduction_consumption mp9_2038_cooking_consumption  \
# bldg_id
# 239                                     508.18                       471.26
# 273                                        NaN                          NaN
# 307                                        NaN                          NaN
# 409                                     523.13                       486.50
# 517                                        NaN                          NaN
# ...                                        ...                          ...
# 548226                                     NaN                          NaN
# 548228                                     NaN                          NaN
# 548417                                     NaN                          NaN
# 549740                                  523.13                       486.50
# 549938                                  522.25                       482.69
#
#         mp9_2038_cooking_reduction_consumption
# bldg_id
# 239                                     508.18
# 273                                        NaN
# 307                                        NaN
# 409                                     523.13
# 517                                        NaN
# ...                                        ...
# 548226                                     NaN
# 548228                                     NaN
# 548417                                     NaN
# 549740                                  523.13
# 549938                                  522.25
#
# [331531 rows x 321 columns]
#
#
#         base_heating_fuel                         heating_type  \
# bldg_id
# 239           Electricity         Electricity Electric Furnace
# 273           Electricity         Electricity Electric Furnace
# 307           Electricity                     Electricity ASHP
# 409           Natural Gas             Natural Gas Fuel Furnace
# 517           Electricity                     Electricity ASHP
# ...                   ...                                  ...
# 548226        Natural Gas             Natural Gas Fuel Furnace
# 548228        Natural Gas             Natural Gas Fuel Furnace
# 548417        Natural Gas             Natural Gas Fuel Furnace
# 549740        Electricity         Electricity Electric Furnace
# 549938        Natural Gas  Natural Gas Fuel Wall/Floor Furnace
#
#          base_electricity_heating_consumption  \
# bldg_id
# 239                                   5014.15
# 273                                   7426.71
# 307                                       NaN
# 409                                      0.00
# 517                                       NaN
# ...                                       ...
# 548226                                   0.00
# 548228                                   0.00
# 548417                                   0.00
# 549740                               26304.30
# 549938                                    NaN
#
#          base_fuelOil_heating_consumption  \
# bldg_id
# 239                                   0.0
# 273                                   0.0
# 307                                   NaN
# 409                                   0.0
# 517                                   NaN
# ...                                   ...
# 548226                                0.0
# 548228                                0.0
# 548417                                0.0
# 549740                                0.0
# 549938                                NaN
#
#          base_naturalGas_heating_consumption  \
# bldg_id
# 239                                     0.00
# 273                                     0.00
# ...
# 409                                       Public Benefit
# 517                                       Public Benefit
# ...                                                  ...
# 548226                                    Public Benefit
# 548228                                    Public Benefit
# 548417                                    Public Benefit
# 549740                                    Public Benefit
# 549938                                    Public Benefit
#
#          iraRef_mp9_cooking_health_sensitivity  \
# bldg_id
# 239                                EASIUR, h6c
# 273                                        NaN
# 307                                        NaN
# 409                                EASIUR, h6c
# 517                                        NaN
# ...                                        ...
# 548226                                     NaN
# 548228                                     NaN
# 548417                                     NaN
# 549740                             EASIUR, h6c
# 549938                             EASIUR, h6c
#
#          iraRef_mp9_cooking_benefit_upper_EASIUR_h6c  \
# bldg_id
# 239                                           181.84
# 273                                              NaN
# 307                                              NaN
# 409                                             0.00
# 517                                              NaN
# ...                                              ...
# 548226                                           NaN
# 548228                                           NaN
# 548417                                           NaN
# 549740                                        678.06
# 549938                                          0.00
#
#         iraRef_mp9_cooking_total_npv_lessWTP_upper_EASIUR_h6c  \
# bldg_id
# 239                                               -2263.14
# 273                                                    NaN
# 307                                                    NaN
# 409                                               -1562.49
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                             -891.34
# 549938                                             -980.61
#
#          iraRef_mp9_cooking_total_npv_moreWTP_upper_EASIUR_h6c  \
# bldg_id
# 239                                               -1190.60
# 273                                                    NaN
# 307                                                    NaN
# 409                                                -489.95
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                              181.20
# 549938                                               91.93
#
#         iraRef_mp9_cooking_adoption_upper_EASIUR_h6c  \
# bldg_id
# 239                                   Tier 4: Averse
# 273                                              NaN
# 307                                              NaN
# 409                                   Tier 4: Averse
# 517                                              NaN
# ...                                              ...
# 548226                                           NaN
# 548228                                           NaN
# 548417                                           NaN
# 549740         Tier 3: Subsidy-Dependent Feasibility
# 549938         Tier 3: Subsidy-Dependent Feasibility
#
#         iraRef_mp9_cooking_impact_upper_EASIUR_h6c
# bldg_id
# 239                                 Public Benefit
# 273                                            NaN
# 307                                            NaN
# 409                                 Public Benefit
# 517                                            NaN
# ...                                            ...
# 548226                                         NaN
# 548228                                         NaN
# 548417                                         NaN
# 549740                              Public Benefit
# 549938                              Public Benefit
#
# [331531 rows x 741 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ...  \
# bldg_id            ...
# 239      G0100390  ...
# 273      G0100150  ...
# 307      G0100850  ...
# 409      G0100050  ...
# 517      G0101270  ...
# ...           ...  ...
# 548226   G5600050  ...
# 548228   G5600010  ...
# 548417   G5600250  ...
# 549740   G5600390  ...
# 549938   G5600010  ...
#
#         iraRef_mp9_clothesDrying_total_npv_lessWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                               -1815.73
# 273                                                -432.68
# 307                                                -484.96
# 409                                                -831.08
# 517                                                -319.54
# ...                                                    ...
# 548226                                            -1440.53
# 548228                                            -2421.17
# 548417                                             -654.64
# 549740                                            -1229.54
# 549938                                              845.32
#
#         iraRef_mp9_clothesDrying_total_npv_moreWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                                -821.67
# 273                                                 561.38
# 307                                                 509.10
# 409                                                 162.98
# 517                                                 674.52
# ...                                                    ...
# 548226                                             -446.47
# 548228                                            -1427.11
# 548417                                              339.42
# 549740                                             -235.48
# 549938                                             1839.38
#
#         iraRef_mp9_clothesDrying_adoption_upper_InMAP_h6c  \
# bldg_id
# 239                                        Tier 4: Averse
# 273                 Tier 3: Subsidy-Dependent Feasibility
# 307                 Tier 3: Subsidy-Dependent Feasibility
# 409                 Tier 3: Subsidy-Dependent Feasibility
# 517                      Tier 2: Feasible vs. Alternative
# ...                                                   ...
# 548226                                     Tier 4: Averse
# 548228                                     Tier 4: Averse
# 548417              Tier 3: Subsidy-Dependent Feasibility
# 549740                                     Tier 4: Averse
# 549938                                   Tier 1: Feasible
#
#         iraRef_mp9_clothesDrying_impact_upper_InMAP_h6c  \
# bldg_id
# 239                                      Public Benefit
# 273                                      Public Benefit
# 307                                      Public Benefit
# 409                                      Public Benefit
# 517                                      Public Benefit
# ...                                                 ...
# 548226                                   Public Benefit
# 548228                                   Public Benefit
# 548417                                   Public Benefit
# 549740                                   Public Benefit
# 549938                                   Public Benefit
#
#          iraRef_mp9_cooking_health_sensitivity  \
# bldg_id
# 239                                 InMAP, h6c
# 273                                        NaN
# 307                                        NaN
# 409                                 InMAP, h6c
# 517                                        NaN
# ...                                        ...
# 548226                                     NaN
# 548228                                     NaN
# 548417                                     NaN
# 549740                              InMAP, h6c
# 549938                              InMAP, h6c
#
#          iraRef_mp9_cooking_benefit_upper_InMAP_h6c  \
# bldg_id
# 239                                          189.18
# 273                                             NaN
# 307                                             NaN
# 409                                            0.00
# 517                                             NaN
# ...                                             ...
# 548226                                          NaN
# 548228                                          NaN
# 548417                                          NaN
# 549740                                       704.45
# 549938                                         0.00
#
#         iraRef_mp9_cooking_total_npv_lessWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                               -2255.80
# 273                                                    NaN
# 307                                                    NaN
# 409                                               -1551.37
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                             -864.95
# 549938                                             -985.50
#
#          iraRef_mp9_cooking_total_npv_moreWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                               -1183.26
# 273                                                    NaN
# 307                                                    NaN
# 409                                                -478.83
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                              207.59
# 549938                                               87.04
#
#         iraRef_mp9_cooking_adoption_upper_InMAP_h6c  \
# bldg_id
# 239                                  Tier 4: Averse
# 273                                             NaN
# 307                                             NaN
# 409                                  Tier 4: Averse
# 517                                             NaN
# ...                                             ...
# 548226                                          NaN
# 548228                                          NaN
# 548417                                          NaN
# 549740        Tier 3: Subsidy-Dependent Feasibility
# 549938        Tier 3: Subsidy-Dependent Feasibility
#
#         iraRef_mp9_cooking_impact_upper_InMAP_h6c
# bldg_id
# 239                                Public Benefit
# 273                                           NaN
# 307                                           NaN
# 409                                Public Benefit
# 517                                           NaN
# ...                                           ...
# 548226                                        NaN
# 548228                                        NaN
# 548417                                        NaN
# 549740                             Public Benefit
# 549938                             Public Benefit
#
# [331531 rows x 741 columns]
#
#
# The code took 111 minutes and 42 seconds to execute.
# Moderate Retrofit Scenario - Model Run Complete

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV
# ===================================================================================================================================================================================

# CONSUMPTION RESULTS
export_model_run_output(
    df_results_export=df_mp9_consumption,
    results_category='consumption',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp9_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp9_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp9_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp9_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp9_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp9_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

# ===== SUMMARY RESULTS =====
# SUMMARY RESULTS
export_model_run_output(
    df_results_export=df_euss_am_mp9_home_ap2,
    results_category='summary_moderate_ap2',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_euss_am_mp9_home_easiur,
    results_category='summary_moderate_easiur',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_euss_am_mp9_home_inmap,
    results_category='summary_moderate_inmap',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )
# Out:
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: consumption
# Dataframe results will be saved in this csv file: mp9_data_consumption_National_2025-05-15_21-39.csv
# Dataframe for MP9 consumption results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_consumption\consumption_all_scenarios\mp9_data_consumption_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_climate_noIRA
# Dataframe results will be saved in this csv file: mp9_damages_climate_noIRA_National_2025-05-15_21-39.csv
# Dataframe for MP9 damages_climate_noIRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_noIRA\mp9_damages_climate_noIRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_climate_IRA
# Dataframe results will be saved in this csv file: mp9_damages_climate_IRA_National_2025-05-15_21-39.csv
# Dataframe for MP9 damages_climate_IRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_IRA\mp9_damages_climate_IRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_health_noIRA
# Dataframe results will be saved in this csv file: mp9_damages_health_noIRA_National_2025-05-15_21-39.csv
# Dataframe for MP9 damages_health_noIRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_noIRA\mp9_damages_health_noIRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_health_IRA
# Dataframe results will be saved in this csv file: mp9_damages_health_IRA_National_2025-05-15_21-39.csv
# Dataframe for MP9 damages_health_IRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_IRA\mp9_damages_health_IRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: fuel_costs_noIRA
# Dataframe results will be saved in this csv file: mp9_fuel_costs_noIRA_National_2025-05-15_21-39.csv
# Dataframe for MP9 fuel_costs_noIRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_noIRA\mp9_fuel_costs_noIRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: fuel_costs_IRA
# Dataframe results will be saved in this csv file: mp9_fuel_costs_IRA_National_2025-05-15_21-39.csv
# Dataframe for MP9 fuel_costs_IRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_IRA\mp9_fuel_costs_IRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 (MP9) RESULTS for model ap2:
# Dataframe results will be saved in this csv file: mp9_results_National_2025-05-15_21-39.csv
# Dataframe for MP9 summary_moderate_ap2 results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\retrofit_moderate_summary\summary_moderate_ap2\mp9_results_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 (MP9) RESULTS for model easiur:
# Dataframe results will be saved in this csv file: mp9_results_National_2025-05-15_21-39.csv
# Dataframe for MP9 summary_moderate_easiur results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\retrofit_moderate_summary\summary_moderate_easiur\mp9_results_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 9 (MP9) RESULTS for model inmap:
# Dataframe results will be saved in this csv file: mp9_results_National_2025-05-15_21-39.csv
# Dataframe for MP9 summary_moderate_inmap results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\retrofit_moderate_summary\summary_moderate_inmap\mp9_results_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Advanced Retrofit: Measure Package 10 (MP10)

# %%
# Measure Package 10
menu_mp = 10
input_mp = 'upgrade10'

print(f"PROJECT_ROOT (from config.py): {PROJECT_ROOT}")

# Construct the absolute path to the .py file
relative_path = os.path.join("cmu_tare_model", "model_scenarios", "tare_advanced_v2_1.ipynb")
file_path = os.path.join(PROJECT_ROOT, relative_path)

# On Windows, to avoid any path-escape quirks, convert backslashes to forward slashes
file_path = file_path.replace("\\", "/")
print(f"Running file: {file_path}")

# iPthon magic command to run a .py file and import variables into the current IPython session
get_ipython().run_line_magic('run', f'-i {file_path}')  # If your path has NO spaces, no quotes needed.

print("Advanced Retrofit Scenario - Model Run Complete")
# Out:
# PROJECT_ROOT (from config.py): c:\users\14128\research\cmu-tare-model
# Running file: c:/users/14128/research/cmu-tare-model/cmu_tare_model/model_scenarios/tare_advanced_v2_1.ipynb
#
# ====================================================================================================================================================================
# We assume the use of Electric Resistance (MP7) rather than Induction (MP8-10).
# Electric Resistance is significantly cheaper and only slightly less efficient than Induction.
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade07_metadata_and_annual_results.csv
# Located at filepath: c:\users\14128\research\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\state\upgrade07_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 346)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 346)
# DATAFRAME SIZE after filtering for 'Single-Family Attached' and 'Single-Family Detached' homes: (331531, 346)
# You chose to analyze all of the United States.
# DATAFRAME SIZE after applying geographic filter: (331531, 346)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 239            7  242.131013           True   1690.0
# 273            7  242.131013          False   1690.0
# 307            7  242.131013          False   1220.0
# 409            7  242.131013           True   1220.0
# 517            7  242.131013          False   1220.0
# ...          ...         ...            ...      ...
# 548226         7  242.131013           True   2176.0
# 548228         7  242.131013           True   1690.0
# 548417         7  242.131013           True    885.0
# 549740         7  242.131013           True   1220.0
# 549938         7  242.131013           True    885.0
#
#                        in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 239      Non-CBSA East South Central                               3A
# 273      Non-CBSA East South Central                               3A
# 307      Non-CBSA East South Central                               3A
# 409      Non-CBSA East South Central                               3A
# 517      Non-CBSA East South Central                               3A
# ...                              ...                              ...
# 548226             Non-CBSA Mountain                               6B
# 548228             Non-CBSA Mountain                               6B
# 548417             Non-CBSA Mountain                               6B
# 549740             Non-CBSA Mountain                               7B
# 549938             Non-CBSA Mountain                               6B
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 239                                             3A                     Hour20
# 273                                             3A                     Hour12
# 307                                             3A                      Hour0
# 409                                             3A                     Hour20
# 517                                             3A                      Hour1
# ...                                            ...                        ...
# 548226                                          6B                      Hour3
# 548228                                          6B                      Hour6
# 548417                                          6B                     Hour18
# 549740                                          7B                      Hour4
# 549938                                          6B                      Hour2
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 239                3                        Hot-Humid  ...
# 273                3                      Mixed-Humid  ...
# 307                4                        Hot-Humid  ...
# 409                2                        Hot-Humid  ...
# 517                3                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 548226             4                             Cold  ...
# 548228             4                             Cold  ...
# 548417             2                             Cold  ...
# 549740             2                        Very Cold  ...
# 549938             2                             Cold  ...
#
#         out.emissions_reduction.propane.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                               0.000000
# 273                                               0.000000
# 307                                               0.000000
# 409                                               0.000000
# 517                                               0.000000
# ...                                                    ...
# 548226                                            0.000000
# 548228                                            0.000000
# 548417                                            0.000000
# 549740                                          268.627834
# 549938                                            0.000000
#
#         out.emissions_reduction.all_fuels.lrmer_95_decarb_by_2035_15_2025_start.co2e_kg  \
# bldg_id
# 239                                             142.374480
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1439.855043
# 517                                               0.000000
# ...                                                    ...
# 548226                                         8790.508547
# 548228                                         5124.531468
# 548417                                         3748.197047
# 549740                                          152.327658
# 549938                                         7833.858198
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_15_2025_start.co2e_kg  \
# bldg_id
# 239                                              75.157988
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1235.288966
# 517                                               0.000000
# ...                                                    ...
# 548226                                         9652.472396
# 548228                                         5456.571515
# 548417                                         3986.523550
# 549740                                          178.841946
# 549938                                         8061.021339
#
#         out.emissions_reduction.all_fuels.lrmer_low_re_cost_25_2025_start.co2e_kg  \
# bldg_id
# 239                                              91.998512
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1299.421938
# 517                                               0.000000
# ...                                                    ...
# 548226                                        10147.078588
# 548228                                         5713.602807
# 548417                                         4071.210606
# 549740                                          198.041150
# 549938                                         8199.976187
#
#         out.emissions_reduction.all_fuels.lrmer_mid_case_15_2025_start.co2e_kg  \
# bldg_id
# 239                                              19.421011
# 273                                               0.000000
# 307                                               0.000000
# 409                                            1129.822844
# 517                                               0.000000
# ...                                                    ...
# 548226                                         5326.981989
# 548228                                         3463.786920
# 548417                                         3004.825830
# 549740                                           75.301777
# 549938                                         6852.064771
#
#         upgrade.clothes_dryer upgrade.cooking_range  \
# bldg_id
# 239                       NaN  Electric, 100% Usage
# 273                       NaN                   NaN
# 307                       NaN                   NaN
# 409                       NaN  Electric, 120% Usage
# 517                       NaN                   NaN
# ...                       ...                   ...
# 548226                    NaN                   NaN
# 548228                    NaN                   NaN
# 548417                    NaN                   NaN
# 549740                    NaN  Electric, 120% Usage
# 549938                    NaN   Electric, 80% Usage
#
#         upgrade.hvac_cooling_efficiency    upgrade.hvac_heating_efficiency  \
# bldg_id
# 239                                 NaN                                NaN
# 273                                 NaN                                NaN
# 307                                 NaN                                NaN
# 409                           Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 517                                 NaN                                NaN
# ...                                 ...                                ...
# 548226                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 548228                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 548417                        Heat Pump            ASHP, SEER 15, 9.0 HSPF
# 549740                              NaN                                NaN
# 549938                        Heat Pump  MSHP, SEER 15, 9.0 HSPF, Max Load
#
#               upgrade.water_heater_efficiency
# bldg_id
# 239                                       NaN
# 273                                       NaN
# 307                                       NaN
# 409      Electric Heat Pump, 50 gal, 3.45 UEF
# 517                                       NaN
# ...                                       ...
# 548226   Electric Heat Pump, 66 gal, 3.35 UEF
# 548228   Electric Heat Pump, 66 gal, 3.35 UEF
# 548417   Electric Heat Pump, 50 gal, 3.45 UEF
# 549740                                    NaN
# 549938   Electric Heat Pump, 50 gal, 3.45 UEF
#
# [331531 rows x 346 columns]
#
# ====================================================================================================================================================================
# MODEL SCENARIO
# ====================================================================================================================================================================
# Scenario Advanced-BAU:
# Advanced Retrofit: Measure Package 10
# BAU Costs
# Current Electricity Grid
# ====================================================================================================================================================================
#
# Retrieved data for filename: upgrade10_metadata_and_annual_results.csv
# Located at filepath: c:\users\14128\research\cmu-tare-model\cmu_tare_model\data\euss_data\resstock_amy2018_release_1.1\state\upgrade10_metadata_and_annual_results.csv
#
#
# DATAFRAME SIZE before applying any filters: (548916, 354)
# DATAFRAME SIZE after filtering for 'Occupied' homes: (482597, 354)
# DATAFRAME SIZE after filtering for 'Single-Family Attached' and 'Single-Family Detached' homes: (331531, 354)
# You chose to analyze all of the United States.
# DATAFRAME SIZE after applying geographic filter: (331531, 354)
#          upgrade      weight  applicability  in.sqft  \
# bldg_id
# 239           10  242.131013           True   1690.0
# 273           10  242.131013           True   1690.0
# 307           10  242.131013           True   1220.0
# 409           10  242.131013           True   1220.0
# 517           10  242.131013           True   1220.0
# ...          ...         ...            ...      ...
# 548226        10  242.131013           True   2176.0
# 548228        10  242.131013           True   1690.0
# 548417        10  242.131013           True    885.0
# 549740        10  242.131013           True   1220.0
# 549938        10  242.131013           True    885.0
#
#                        in.ahs_region in.ashrae_iecc_climate_zone_2004  \
# bldg_id
# 239      Non-CBSA East South Central                               3A
# 273      Non-CBSA East South Central                               3A
# 307      Non-CBSA East South Central                               3A
# 409      Non-CBSA East South Central                               3A
# 517      Non-CBSA East South Central                               3A
# ...                              ...                              ...
# 548226             Non-CBSA Mountain                               6B
# 548228             Non-CBSA Mountain                               6B
# 548417             Non-CBSA Mountain                               6B
# 549740             Non-CBSA Mountain                               7B
# 549938             Non-CBSA Mountain                               6B
#
#         in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  \
# bldg_id
# 239                                             3A                     Hour20
# 273                                             3A                     Hour12
# 307                                             3A                      Hour0
# 409                                             3A                     Hour20
# 517                                             3A                      Hour1
# ...                                            ...                        ...
# 548226                                          6B                      Hour3
# 548228                                          6B                      Hour6
# 548417                                          6B                     Hour18
# 549740                                          7B                      Hour4
# 549938                                          6B                      Hour2
#
#          in.bedrooms in.building_america_climate_zone  ...  \
# bldg_id                                                ...
# 239                3                        Hot-Humid  ...
# 273                3                      Mixed-Humid  ...
# 307                4                        Hot-Humid  ...
# 409                2                        Hot-Humid  ...
# 517                3                      Mixed-Humid  ...
# ...              ...                              ...  ...
# 548226             4                             Cold  ...
# 548228             4                             Cold  ...
# 548417             2                             Cold  ...
# 549740             2                        Very Cold  ...
# 549938             2                             Cold  ...
#
#         upgrade.geometry_foundation_type upgrade.hvac_cooling_efficiency  \
# bldg_id
# 239                                  NaN                       Heat Pump
# 273                                  NaN                       Heat Pump
# 307                  Unvented Crawlspace                       Heat Pump
# 409                  Unvented Crawlspace                       Heat Pump
# 517                                  NaN                       Heat Pump
# ...                                  ...                             ...
# 548226                               NaN                       Heat Pump
# 548228                               NaN                       Heat Pump
# 548417                               NaN                       Heat Pump
# 549740                               NaN                       Heat Pump
# 549938                               NaN                       Heat Pump
#
#             upgrade.hvac_heating_efficiency upgrade.hvac_heating_type  \
# bldg_id
# 239                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 273                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 307                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 409                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 517                  MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# ...                                     ...                       ...
# 548226               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 548228               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 548417               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549740               MSHP, SEER 24, 13 HSPF          Ducted Heat Pump
# 549938   MSHP, SEER 29.3, 14 HSPF, Max Load                       NaN
#
#         upgrade.infiltration_reduction upgrade.insulation_ceiling  \
# bldg_id
# 239                                30%                       R-49
# 273                                30%                        NaN
# 307                                30%                       R-49
# 409                                30%                       R-49
# 517                                30%                       R-49
# ...                                ...                        ...
# 548226                             30%                       R-60
# 548228                             30%                       R-60
# 548417                             NaN                       R-60
# 549740                             30%                       R-60
# 549938                             30%                       R-60
#
#         upgrade.insulation_foundation_wall upgrade.insulation_roof  \
# bldg_id
# 239                                    NaN                     NaN
# 273                                    NaN                     NaN
# 307                    Wall R-10, Interior                     NaN
# 409                    Wall R-10, Interior                     NaN
# 517                                    NaN                     NaN
# ...                                    ...                     ...
# 548226                                 NaN                     NaN
# 548228                                 NaN                     NaN
# 548417                                 NaN                     NaN
# 549740                                 NaN                     NaN
# 549938                                 NaN                     NaN
#
#         upgrade.insulation_wall       upgrade.water_heater_efficiency
# bldg_id
# 239                         NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 273                         NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 307                         NaN  Electric Heat Pump, 66 gal, 3.35 UEF
# 409             Wood Stud, R-13  Electric Heat Pump, 50 gal, 3.45 UEF
# 517                         NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# ...                         ...                                   ...
# 548226          Wood Stud, R-13  Electric Heat Pump, 66 gal, 3.35 UEF
# 548228                      NaN  Electric Heat Pump, 66 gal, 3.35 UEF
# 548417          Wood Stud, R-13  Electric Heat Pump, 50 gal, 3.45 UEF
# 549740                      NaN  Electric Heat Pump, 50 gal, 3.45 UEF
# 549938          Wood Stud, R-13  Electric Heat Pump, 50 gal, 3.45 UEF
#
# [331531 rows x 354 columns]
#
# ====================================================================================================================================================================
# LOAD EUSS DATA FOR MEASURE PACKAGE 10 (MP10)
# ====================================================================================================================================================================
# You'll notice that the number of rows differs from df_euss_am_mp7 and df_euss_am_mp10.
#       - df_euss_am_baseline_home has fewer rows (representative dwelling units) because a tech filter was applied.
#       - df_euss_am_mp10_home will have the same number of rows as df_euss_am_baseline_home after df_enduse_compare function is run.
#       - df_enduse_compare function performs an inner merge on the two dataframes, keeping only the rows that are present in both dataframes.
# ====================================================================================================================================================================
# df_euss_am_mp10_home will be created by running the df_enduse_compare function (contains post-retrofit consumption data for the entire home in 2024).
# process_euss_data.py file contains the function definition.
#
# Documentation for df_enduse_compare function:
# Creates a comparison DataFrame by merging multiple DataFrames based on measure packages.
#
#     This function constructs a new DataFrame (df_compare) that includes columns
#     from df_mp, df_cooking_range, and merges them with df_baseline to compare
#     baseline vs. measure package outputs for heating, water heating, clothes drying,
#     and cooking.
#
#     Args:
#         df_mp: The main DataFrame containing modeling parameters and outputs.
#         input_mp: The input measure package ID (e.g., 'upgrade09', 'upgrade10').
#         menu_mp: The menu measure package number.
#         df_baseline: The baseline DataFrame to merge with df_compare.
#         df_cooking_range: Additional DataFrame for cooking range parameters/outputs.
#
#     Returns:
#         A merged DataFrame (df_compare) that includes relevant columns for
#         baseline and measure packages comparison.
#
# ----------------------------------------------------------------
#
# RESULTING DATAFRAME:
#
#
# Applying combined validation (data quality + retrofit status):
# Measure package calculation for heating:
#   - 260211 homes have valid data
#   - 331526 homes will receive retrofits
#   - 260211 homes have both valid data AND will receive retrofits
#   - 71320 homes excluded (values will be NaN)
#   mp10_heating_consumption: Masked 71320 values
# Measure package calculation for waterHeating:
#   - 322799 homes have valid data
#   - 329631 homes will receive retrofits
#   - 322799 homes have both valid data AND will receive retrofits
#   - 8732 homes excluded (values will be NaN)
#   mp10_waterHeating_consumption: Masked 8732 values
# Measure package calculation for clothesDrying:
#   - 316573 homes have valid data
#   - 316573 homes will receive retrofits
#   - 316573 homes have both valid data AND will receive retrofits
#   - 14958 homes excluded (values will be NaN)
#   mp10_clothesDrying_consumption: Masked 14958 values
# Measure package calculation for cooking:
#   - 126373 homes have valid data
#   - 126373 homes will receive retrofits
#   - 126373 homes have both valid data AND will receive retrofits
#   - 205158 homes excluded (values will be NaN)
#   mp10_cooking_consumption: Masked 205158 values
#
# ====================================================================================================================================================================
# PROJECT FUTURE ENERGY CONSUMPTION
# ====================================================================================================================================================================
# project_future_energy_consumption.py file was used to calculate/project the annual energy consumption
# for each home in the dataframe.
#
# Documentation for project_future_energy_consumption function:
# Projects future energy consumption based on baseline or upgraded equipment specifications.
#
#     This function calculates projected energy consumption for each equipment category (heating,
#     water heating, clothes drying, and cooking) for future years based on their expected lifetime.
#     It applies climate adjustment factors for heating and water heating categories.
#
#     Args:
#         df: The input DataFrame containing baseline consumption data.
#         menu_mp: Indicates the measure package to apply. 0 for baseline, or a positive integer
#             (e.g., 8, 9, 10) for retrofit scenarios.
#         base_year: The starting year for projections. Defaults to 2024.
#
#     Returns:
#         A tuple containing two DataFrames:
#             - df_copy: The updated DataFrame with all columns including the projected consumption data.
#             - df_consumption: The DataFrame containing only the projected consumption data.
#
#     Raises:
#         KeyError: If the 'census_division' column is missing from the DataFrame.
#
#
# RESULTS OUTPUT:
#
#
# Determining valid homes for calculations:
# Measure package calculation for heating:
#   - 260211 homes have valid data
#   - 331526 homes will receive retrofits
#   - 260211 homes have both valid data AND will receive retrofits
#   - 71320 homes excluded (values will be NaN)
# Measure package calculation for waterHeating:
#   - 322799 homes have valid data
#   - 329631 homes will receive retrofits
#   - 322799 homes have both valid data AND will receive retrofits
#   - 8732 homes excluded (values will be NaN)
# Measure package calculation for clothesDrying:
#   - 316573 homes have valid data
#   - 316573 homes will receive retrofits
#   - 316573 homes have both valid data AND will receive retrofits
#   - 14958 homes excluded (values will be NaN)
# Measure package calculation for cooking:
#   - 126373 homes have valid data
#   - 126373 homes will receive retrofits
#   - 126373 homes have both valid data AND will receive retrofits
#   - 205158 homes excluded (values will be NaN)
#
# ===== Processing HEATING =====
# Projecting consumption for 260211 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): heating
#
# ===== Processing WATERHEATING =====
# Projecting consumption for 322799 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): waterHeating
#
# ===== Processing CLOTHESDRYING =====
# Projecting consumption for 316573 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): clothesDrying
#
# ===== Processing COOKING =====
# Projecting consumption for 126373 out of 331531 homes
# Projecting Future Energy Consumption (Upgraded Equipment): cooking
#
# Verifying masking for all projected columns:
# Masking 47 columns for category 'heating'
# Masking 38 columns for category 'waterHeating'
# Masking 41 columns for category 'clothesDrying'
# Masking 47 columns for category 'cooking'
#
# ====================================================================================================================================================================
# DATAFRAME FOR MEASURE PACKAGE 10 (MP10):
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ... mp10_2034_cooking_consumption  \
# bldg_id            ...
# 239      G0100390  ...                        471.26
# 273      G0100150  ...                           NaN
# 307      G0100850  ...                           NaN
# 409      G0100050  ...                        486.50
# 517      G0101270  ...                           NaN
# ...           ...  ...                           ...
# 548226   G5600050  ...                           NaN
# 548228   G5600010  ...                           NaN
# 548417   G5600250  ...                           NaN
# 549740   G5600390  ...                        486.50
# 549938   G5600010  ...                        482.69
#
#         mp10_2034_cooking_reduction_consumption mp10_2035_cooking_consumption  \
# bldg_id
# 239                                      508.18                        471.26
# 273                                         NaN                           NaN
# 307                                         NaN                           NaN
# 409                                      523.13                        486.50
# 517                                         NaN                           NaN
# ...                                         ...                           ...
# 548226                                      NaN                           NaN
# 548228                                      NaN                           NaN
# 548417                                      NaN                           NaN
# 549740                                   523.13                        486.50
# 549938                                   522.25                        482.69
#
#         mp10_2035_cooking_reduction_consumption  \
# bldg_id
# 239                                      508.18
# 273                                         NaN
# 307                                         NaN
# 409                                      523.13
# 517                                         NaN
# ...                                         ...
# 548226                                      NaN
# 548228                                      NaN
# 548417                                      NaN
# 549740                                   523.13
# 549938                                   522.25
#
#          mp10_2036_cooking_consumption  \
# bldg_id
# 239                             471.26
# 273                                NaN
# 307                                NaN
# 409                             486.50
# 517                                NaN
# ...                                ...
# 548226                             NaN
# 548228                             NaN
# 548417                             NaN
# 549740                          486.50
# 549938                          482.69
#
#          mp10_2036_cooking_reduction_consumption  \
# bldg_id
# 239                                       508.18
# 273                                          NaN
# 307                                          NaN
# 409                                       523.13
# 517                                          NaN
# ...                                          ...
# 548226                                       NaN
# 548228                                       NaN
# 548417                                       NaN
# 549740                                    523.13
# 549938                                    522.25
#
#         mp10_2037_cooking_consumption mp10_2037_cooking_reduction_consumption  \
# bldg_id
# 239                            471.26                                  508.18
# 273                               NaN                                     NaN
# 307                               NaN                                     NaN
# 409                            486.50                                  523.13
# 517                               NaN                                     NaN
# ...                               ...                                     ...
# 548226                            NaN                                     NaN
# 548228                            NaN                                     NaN
# 548417                            NaN                                     NaN
# 549740                         486.50                                  523.13
# 549938                         482.69                                  522.25
#
#         mp10_2038_cooking_consumption mp10_2038_cooking_reduction_consumption
# bldg_id
# 239                            471.26                                  508.18
# 273                               NaN                                     NaN
# 307                               NaN                                     NaN
# 409                            486.50                                  523.13
# 517                               NaN                                     NaN
# ...                               ...                                     ...
# 548226                            NaN                                     NaN
# 548228                            NaN                                     NaN
# 548417                            NaN                                     NaN
# 549740                         486.50                                  523.13
# 549938                         482.69                                  522.25
#
# [331531 rows x 331 columns]
#
# DATAFRAME (Consumption Cols): df_mp10_consumption
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ... mp10_2034_cooking_consumption  \
# bldg_id            ...
# 239      G0100390  ...                        471.26
# 273      G0100150  ...                           NaN
# 307      G0100850  ...                           NaN
# 409      G0100050  ...                        486.50
# 517      G0101270  ...                           NaN
# ...           ...  ...                           ...
# 548226   G5600050  ...                           NaN
# 548228   G5600010  ...                           NaN
# 548417   G5600250  ...                           NaN
# 549740   G5600390  ...                        486.50
# 549938   G5600010  ...                        482.69
#
#         mp10_2034_cooking_reduction_consumption mp10_2035_cooking_consumption  \
# bldg_id
# 239                                      508.18                        471.26
# 273                                         NaN                           NaN
# 307                                         NaN                           NaN
# 409                                      523.13                        486.50
# 517                                         NaN                           NaN
# ...                                         ...                           ...
# 548226                                      NaN                           NaN
# 548228                                      NaN                           NaN
# 548417                                      NaN                           NaN
# 549740                                   523.13                        486.50
# 549938                                   522.25                        482.69
#
#         mp10_2035_cooking_reduction_consumption  \
# bldg_id
# 239                                      508.18
# 273                                         NaN
# 307                                         NaN
# 409                                      523.13
# 517                                         NaN
# ...                                         ...
# 548226                                      NaN
# 548228                                      NaN
# 548417                                      NaN
# 549740                                   523.13
# 549938                                   522.25
#
#          mp10_2036_cooking_consumption  \
# bldg_id
# 239                             471.26
# 273                                NaN
# 307                                NaN
# 409                             486.50
# 517                                NaN
# ...                                ...
# 548226                             NaN
# 548228                             NaN
# 548417                             NaN
# 549740                          486.50
# 549938                          482.69
#
#          mp10_2036_cooking_reduction_consumption  \
# bldg_id
# 239                                       508.18
# 273                                          NaN
# 307                                          NaN
# 409                                       523.13
# 517                                          NaN
# ...                                          ...
# 548226                                       NaN
# 548228                                       NaN
# 548417                                       NaN
# 549740                                    523.13
# 549938                                    522.25
#
#         mp10_2037_cooking_consumption mp10_2037_cooking_reduction_consumption  \
# bldg_id
# 239                            471.26                                  508.18
# 273                               NaN                                     NaN
# 307                               NaN                                     NaN
# 409                            486.50                                  523.13
# 517                               NaN                                     NaN
# ...                               ...                                     ...
# 548226                            NaN                                     NaN
# 548228                            NaN                                     NaN
# 548417                            NaN                                     NaN
# 549740                         486.50                                  523.13
# 549938                         482.69                                  522.25
#
#         mp10_2038_cooking_consumption mp10_2038_cooking_reduction_consumption
# bldg_id
# 239                            471.26                                  508.18
# 273                               NaN                                     NaN
# 307                               NaN                                     NaN
# 409                            486.50                                  523.13
# 517                               NaN                                     NaN
# ...                               ...                                     ...
# 548226                            NaN                                     NaN
# 548228                            NaN                                     NaN
# 548417                            NaN                                     NaN
# 549740                         486.50                                  523.13
# 549938                         482.69                                  522.25
#
# [331531 rows x 331 columns]
#
#
#         base_heating_fuel                         heating_type  \
# bldg_id
# 239           Electricity         Electricity Electric Furnace
# 273           Electricity         Electricity Electric Furnace
# 307           Electricity                     Electricity ASHP
# 409           Natural Gas             Natural Gas Fuel Furnace
# 517           Electricity                     Electricity ASHP
# ...                   ...                                  ...
# 548226        Natural Gas             Natural Gas Fuel Furnace
# 548228        Natural Gas             Natural Gas Fuel Furnace
# 548417        Natural Gas             Natural Gas Fuel Furnace
# 549740        Electricity         Electricity Electric Furnace
# 549938        Natural Gas  Natural Gas Fuel Wall/Floor Furnace
#
#          base_electricity_heating_consumption  \
# bldg_id
# 239                                   5014.15
# 273                                   7426.71
# 307                                       NaN
# 409                                      0.00
# 517                                       NaN
# ...                                       ...
# 548226                                   0.00
# 548228                                   0.00
# 548417                                   0.00
# 549740                               26304.30
# 549938                                    NaN
#
#          base_fuelOil_heating_consumption  \
# bldg_id
# 239                                   0.0
# 273                                   0.0
# 307                                   NaN
# 409                                   0.0
# 517                                   NaN
# ...                                   ...
# 548226                                0.0
# 548228                                0.0
# 548417                                0.0
# ...
# 548228                                     Public Benefit
# 548417                                     Public Benefit
# 549740                                     Public Benefit
# 549938                                     Public Benefit
#
#          iraRef_mp10_cooking_health_sensitivity  \
# bldg_id
# 239                                 EASIUR, h6c
# 273                                         NaN
# 307                                         NaN
# 409                                 EASIUR, h6c
# 517                                         NaN
# ...                                         ...
# 548226                                      NaN
# 548228                                      NaN
# 548417                                      NaN
# 549740                              EASIUR, h6c
# 549938                              EASIUR, h6c
#
#          iraRef_mp10_cooking_benefit_upper_EASIUR_h6c  \
# bldg_id
# 239                                            181.84
# 273                                               NaN
# 307                                               NaN
# 409                                              0.00
# 517                                               NaN
# ...                                               ...
# 548226                                            NaN
# 548228                                            NaN
# 548417                                            NaN
# 549740                                         678.06
# 549938                                           0.00
#
#         iraRef_mp10_cooking_total_npv_lessWTP_upper_EASIUR_h6c  \
# bldg_id
# 239                                               -1626.80
# 273                                                    NaN
# 307                                                    NaN
# 409                                               -1362.67
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                             -477.06
# 549938                                             -497.78
#
#          iraRef_mp10_cooking_total_npv_moreWTP_upper_EASIUR_h6c  \
# bldg_id
# 239                                                -554.26
# 273                                                    NaN
# 307                                                    NaN
# 409                                                -290.13
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                              595.48
# 549938                                              574.76
#
#         iraRef_mp10_cooking_adoption_upper_EASIUR_h6c  \
# bldg_id
# 239                                    Tier 4: Averse
# 273                                               NaN
# 307                                               NaN
# 409                                    Tier 4: Averse
# 517                                               NaN
# ...                                               ...
# 548226                                            NaN
# 548228                                            NaN
# 548417                                            NaN
# 549740          Tier 3: Subsidy-Dependent Feasibility
# 549938               Tier 2: Feasible vs. Alternative
#
#         iraRef_mp10_cooking_impact_upper_EASIUR_h6c
# bldg_id
# 239                                  Public Benefit
# 273                                             NaN
# 307                                             NaN
# 409                                  Public Benefit
# 517                                             NaN
# ...                                             ...
# 548226                                          NaN
# 548228                                          NaN
# 548417                                          NaN
# 549740                               Public Benefit
# 549938                               Public Benefit
#
# [331531 rows x 756 columns]
#
# -----------------------------------------------
# InMAP:
# -----------------------------------------------
#
#          square_footage census_region     census_division  \
# bldg_id
# 239              1690.0         South  East South Central
# 273              1690.0         South  East South Central
# 307              1220.0         South  East South Central
# 409              1220.0         South  East South Central
# 517              1220.0         South  East South Central
# ...                 ...           ...                 ...
# 548226           2176.0          West            Mountain
# 548228           1690.0          West            Mountain
# 548417            885.0          West            Mountain
# 549740           1220.0          West            Mountain
# 549938            885.0          West            Mountain
#
#         census_division_recs building_america_climate_zone  \
# bldg_id
# 239       East South Central                     Hot-Humid
# 273       East South Central                   Mixed-Humid
# 307       East South Central                     Hot-Humid
# 409       East South Central                     Hot-Humid
# 517       East South Central                   Mixed-Humid
# ...                      ...                           ...
# 548226        Mountain North                          Cold
# 548228        Mountain North                          Cold
# 548417        Mountain North                          Cold
# 549740        Mountain North                     Very Cold
# 549938        Mountain North                          Cold
#
#          reeds_balancing_area gea_region state                     city  \
# bldg_id
# 239                        90      SRSOc    AL    Not in a census Place
# 273                        90      SRSOc    AL  In another census Place
# 307                        90      SRSOc    AL    Not in a census Place
# 409                        90      SRSOc    AL    Not in a census Place
# 517                        89      SRSOc    AL  In another census Place
# ...                       ...        ...   ...                      ...
# 548226                     23      RMPAc    WY  In another census Place
# 548228                     24      RMPAc    WY    Not in a census Place
# 548417                     24      RMPAc    WY                   Casper
# 549740                     21      NWPPc    WY  In another census Place
# 549938                     24      RMPAc    WY    Not in a census Place
#
#            county  ...  \
# bldg_id            ...
# 239      G0100390  ...
# 273      G0100150  ...
# 307      G0100850  ...
# 409      G0100050  ...
# 517      G0101270  ...
# ...           ...  ...
# 548226   G5600050  ...
# 548228   G5600010  ...
# 548417   G5600250  ...
# 549740   G5600390  ...
# 549938   G5600010  ...
#
#         iraRef_mp10_clothesDrying_total_npv_lessWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                               -1059.51
# 273                                                 527.11
# 307                                                 627.59
# 409                                                  64.28
# 517                                                -650.30
# ...                                                    ...
# 548226                                            -1652.68
# 548228                                            -1394.92
# 548417                                              -15.90
# 549740                                            -1160.69
# 549938                                             -264.31
#
#         iraRef_mp10_clothesDrying_total_npv_moreWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                                 -65.45
# 273                                                1521.17
# 307                                                1621.65
# 409                                                1058.34
# 517                                                 343.76
# ...                                                    ...
# 548226                                             -658.62
# 548228                                             -400.86
# 548417                                              978.16
# 549740                                             -166.63
# 549938                                              729.75
#
#         iraRef_mp10_clothesDrying_adoption_upper_InMAP_h6c  \
# bldg_id
# 239                                         Tier 4: Averse
# 273                       Tier 2: Feasible vs. Alternative
# 307                       Tier 2: Feasible vs. Alternative
# 409                       Tier 2: Feasible vs. Alternative
# 517                  Tier 3: Subsidy-Dependent Feasibility
# ...                                                    ...
# 548226                                      Tier 4: Averse
# 548228                                      Tier 4: Averse
# 548417                    Tier 2: Feasible vs. Alternative
# 549740                                      Tier 4: Averse
# 549938               Tier 3: Subsidy-Dependent Feasibility
#
#         iraRef_mp10_clothesDrying_impact_upper_InMAP_h6c  \
# bldg_id
# 239                                       Public Benefit
# 273                                       Public Benefit
# 307                                       Public Benefit
# 409                                       Public Benefit
# 517                                       Public Benefit
# ...                                                  ...
# 548226                                    Public Benefit
# 548228                                    Public Benefit
# 548417                                    Public Benefit
# 549740                                    Public Benefit
# 549938                                    Public Benefit
#
#          iraRef_mp10_cooking_health_sensitivity  \
# bldg_id
# 239                                  InMAP, h6c
# 273                                         NaN
# 307                                         NaN
# 409                                  InMAP, h6c
# 517                                         NaN
# ...                                         ...
# 548226                                      NaN
# 548228                                      NaN
# 548417                                      NaN
# 549740                               InMAP, h6c
# 549938                               InMAP, h6c
#
#          iraRef_mp10_cooking_benefit_upper_InMAP_h6c  \
# bldg_id
# 239                                           189.18
# 273                                              NaN
# 307                                              NaN
# 409                                             0.00
# 517                                              NaN
# ...                                              ...
# 548226                                           NaN
# 548228                                           NaN
# 548417                                           NaN
# 549740                                        704.45
# 549938                                          0.00
#
#         iraRef_mp10_cooking_total_npv_lessWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                               -1619.46
# 273                                                    NaN
# 307                                                    NaN
# 409                                               -1351.55
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                             -450.67
# 549938                                             -502.67
#
#          iraRef_mp10_cooking_total_npv_moreWTP_upper_InMAP_h6c  \
# bldg_id
# 239                                                -546.92
# 273                                                    NaN
# 307                                                    NaN
# 409                                                -279.01
# 517                                                    NaN
# ...                                                    ...
# 548226                                                 NaN
# 548228                                                 NaN
# 548417                                                 NaN
# 549740                                              621.87
# 549938                                              569.87
#
#         iraRef_mp10_cooking_adoption_upper_InMAP_h6c  \
# bldg_id
# 239                                   Tier 4: Averse
# 273                                              NaN
# 307                                              NaN
# 409                                   Tier 4: Averse
# 517                                              NaN
# ...                                              ...
# 548226                                           NaN
# 548228                                           NaN
# 548417                                           NaN
# 549740         Tier 3: Subsidy-Dependent Feasibility
# 549938              Tier 2: Feasible vs. Alternative
#
#         iraRef_mp10_cooking_impact_upper_InMAP_h6c
# bldg_id
# 239                                 Public Benefit
# 273                                            NaN
# 307                                            NaN
# 409                                 Public Benefit
# 517                                            NaN
# ...                                            ...
# 548226                                         NaN
# 548228                                         NaN
# 548417                                         NaN
# 549740                              Public Benefit
# 549938                              Public Benefit
#
# [331531 rows x 756 columns]
#
#
# The code took 168 minutes and 31 seconds to execute.
# Advanced Retrofit Scenario - Model Run Complete

# %%
# ===================================================================================================================================================================================
# EXPORT RESULTS TO CSV
# ===================================================================================================================================================================================

# CONSUMPTION RESULTS
export_model_run_output(
    df_results_export=df_mp10_consumption,
    results_category='consumption',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

# ===== DAMAGES RESULTS =====
export_model_run_output(
    df_results_export=df_mp10_noIRA_damages_climate,
    results_category='damages_climate_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp10_IRA_damages_climate,
    results_category='damages_climate_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp10_noIRA_damages_health,
    results_category='damages_health_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp10_IRA_damages_health,
    results_category='damages_health_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

# ===== FUEL COSTS RESULTS =====
export_model_run_output(
    df_results_export=df_mp10_noIRA_fuel_costs,
    results_category='fuel_costs_noIRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_mp10_IRA_fuel_costs,
    results_category='fuel_costs_IRA',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

# ===== SUMMARY RESULTS =====
# SUMMARY RESULTS
export_model_run_output(
    df_results_export=df_euss_am_mp10_home_ap2,
    results_category='summary_advanced_ap2',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_euss_am_mp10_home_easiur,
    results_category='summary_advanced_easiur',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )

export_model_run_output(
    df_results_export=df_euss_am_mp10_home_inmap,
    results_category='summary_advanced_inmap',
    menu_mp=menu_mp,
    output_folder_path=output_folder_path,
    location_id=location_id,
    results_export_formatted_date=results_export_formatted_date
    )
# Out:
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: consumption
# Dataframe results will be saved in this csv file: mp10_data_consumption_National_2025-05-15_21-39.csv
# Dataframe for MP10 consumption results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_consumption\consumption_all_scenarios\mp10_data_consumption_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_climate_noIRA
# Dataframe results will be saved in this csv file: mp10_damages_climate_noIRA_National_2025-05-15_21-39.csv
# Dataframe for MP10 damages_climate_noIRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_noIRA\mp10_damages_climate_noIRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_climate_IRA
# Dataframe results will be saved in this csv file: mp10_damages_climate_IRA_National_2025-05-15_21-39.csv
# Dataframe for MP10 damages_climate_IRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_climate_IRA\mp10_damages_climate_IRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_health_noIRA
# Dataframe results will be saved in this csv file: mp10_damages_health_noIRA_National_2025-05-15_21-39.csv
# Dataframe for MP10 damages_health_noIRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_noIRA\mp10_damages_health_noIRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: damages_health_IRA
# Dataframe results will be saved in this csv file: mp10_damages_health_IRA_National_2025-05-15_21-39.csv
# Dataframe for MP10 damages_health_IRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_damages\damages_health_IRA\mp10_damages_health_IRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: fuel_costs_noIRA
# Dataframe results will be saved in this csv file: mp10_fuel_costs_noIRA_National_2025-05-15_21-39.csv
# Dataframe for MP10 fuel_costs_noIRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_noIRA\mp10_fuel_costs_noIRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# SUPPLEMENTAL INFORMATION DATAFRAME: fuel_costs_IRA
# Dataframe results will be saved in this csv file: mp10_fuel_costs_IRA_National_2025-05-15_21-39.csv
# Dataframe for MP10 fuel_costs_IRA results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\supplemental_data_fuelCosts\fuel_costs_IRA\mp10_fuel_costs_IRA_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 (MP10) RESULTS for model ap2:
# Dataframe results will be saved in this csv file: mp10_results_National_2025-05-15_21-39.csv
# Dataframe for MP10 summary_advanced_ap2 results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\retrofit_advanced_summary\summary_advanced_ap2\mp10_results_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 (MP10) RESULTS for model easiur:
# Dataframe results will be saved in this csv file: mp10_results_National_2025-05-15_21-39.csv
# Dataframe for MP10 summary_advanced_easiur results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\retrofit_advanced_summary\summary_advanced_easiur\mp10_results_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------
# MEASURE PACKAGE 10 (MP10) RESULTS for model inmap:
# Dataframe results will be saved in this csv file: mp10_results_National_2025-05-15_21-39.csv
# Dataframe for MP10 summary_advanced_inmap results were exported here: c:\users\14128\research\cmu-tare-model\cmu_tare_model\output_results\retrofit_advanced_summary\summary_advanced_inmap\mp10_results_National_2025-05-15_21-39.csv
# -------------------------------------------------------------------------------------------------------
