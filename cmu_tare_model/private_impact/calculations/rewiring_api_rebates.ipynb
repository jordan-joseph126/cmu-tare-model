# %%
import pandas as pd
import requests

# %%
api_key = ""
url = "https://api.rewiringamerica.org/api/v1/calculator"

# %%
response = requests.get(url)
response.text
# Out:
# '{"statusCode":400,"error":"Bad Request","message":"querystring must have required property \'zip\', querystring must have required property \'address\', querystring must match exactly one schema in oneOf"}'

# %%
example_url = f"https://api.rewiringamerica.org/api/v1/calculator"

# %%
utilities_url = f"https://api.rewiringamerica.org/api/v1/utilities"

# %%
headers = {"Authorization": api_key}

response = requests.get(utilities_url,
                        params= {
                        "zip": "80303"
                        }, 
                        headers=headers)

print(response.json())
# Out:
# {'location': {'state': 'CO'}, 'utilities': {'co-xcel-energy': {'name': 'Xcel Energy'}}, 'gas_utilities': {'co-xcel-energy-gas': {'name': 'Xcel Energy'}}, 'gas_utility_affects_incentives': True}

# %%
headers = {"Authorization": api_key}

response = requests.get(example_url,
                        params= {
                        "zip": "80303",
                        "owner_status": "homeowner",
                        "household_income": 80000,
                        "household_size": 2,
                        # "utility": 'co-xcel-energy'
                        }, 
                        headers=headers)

response.json()
# Out:
# {'is_under_80_ami': True,
#  'is_under_150_ami': True,
#  'is_over_150_ami': False,
#  'authorities': {'co-colorado-energy-office': {'name': 'Colorado Energy Office'},
#   'co-city-of-boulder': {'name': 'City of Boulder'},
#   'co-state-of-colorado': {'name': 'State of Colorado'},
#   'co-boulder-county': {'name': 'Boulder County'},
#   'co-power-ahead-colorado': {'name': 'Power Ahead Colorado'}},
#  'coverage': {'state': 'CO', 'utility': None},
#  'location': {'state': 'CO'},
#  'data_partners': {},
#  'incentives': [{'payment_methods': ['pos_rebate'],
#    'authority_type': 'state',
#    'authority': 'co-state-of-colorado',
#    'program': 'Electric-Powered Lawn Equipment Tax Credit',
#    'program_url': 'https://tax.colorado.gov/electric-powered-lawn-equipment-tax-credit',
#    'items': ['electric_outdoor_equipment'],
#    'amount': {'type': 'percent', 'number': 0.3},
#    'owner_status': ['homeowner', 'renter'],
#    'start_date': '2024-01-01',
#    'end_date': '2027-01-01',
#    'short_description': '30% discount off the purchase price of qualifying electric lawn equipment from participating retailers.'},
#   {'payment_methods': ['pos_rebate'],
#    'authority_type': 'state',
#    'authority': 'co-colorado-energy-office',
#    'program': 'Vehicle Exchange Colorado (VXC) Program',
#    'program_url': 'https://energyoffice.colorado.gov/vehicle-exchange-colorado',
#    'items': ['new_electric_vehicle'],
#    'amount': {'type': 'dollar_amount', 'number': 9000},
#    'owner_status': ['homeowner', 'renter'],
#    'short_description': 'Income-qualified Coloradans can receive a $9,000 rebate to replace old or high-emitting vehicles with a new BEV or PHEV.'},
#   {'payment_methods': ['pos_rebate'],
#    'authority_type': 'state',
#    'authority': 'co-colorado-energy-office',
#    'program': 'Vehicle Exchange Colorado (VXC) Program',
#    'program_url': 'https://energyoffice.colorado.gov/vehicle-exchange-colorado',
#    'items': ['used_electric_vehicle'],
#    'amount': {'type': 'dollar_amount', 'number': 6000},
#    'owner_status': ['homeowner', 'renter'],
#    'short_description': 'Income-qualified Coloradans can receive a $6,000 rebate to replace old or high-emitting vehicles with a used BEV or PHEV.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'city',
#    'authority': 'co-city-of-boulder',
#    'program': 'City of Boulder Residential Rebates',
#    'program_url': 'https://bouldercolorado.gov/services/solar-grants',
#    'items': ['rooftop_solar_installation'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 8000},
#    'owner_status': ['homeowner'],
#    'end_date': '2026-12-31',
#    'short_description': 'Rebate for income-qualified residents or eligible nonprofits for photovoltatic or thermal solar. Capped at lowest of 50% of costs, $1/watt, or $8,000.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['ductless_heat_pump'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for ductless heat pump installations. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['ducted_heat_pump'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2025-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for ducted heat pump installations. Your combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['geothermal_heating_installation'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for geothermal heat pump installations. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['air_to_water_heat_pump'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for air to water heat pump installations. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['heat_pump_water_heater'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for heat pump water heater installations. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['electric_stove'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for qualified electric stove installations. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['electric_stove'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for induction cooktop installations. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['heat_pump_clothes_dryer'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for heat pump clothes dryer installations. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['electric_panel'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for a qualified electric panel upgrade. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['other'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for qualified cellular shade installations. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['attic_or_roof_insulation', 'air_sealing'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for qualified attic insulation projects. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['wall_insulation'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for qualified wall insulation projects. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['basement_insulation', 'crawlspace_insulation', 'air_sealing'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for qualified foundation insulation projects. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['floor_insulation', 'air_sealing'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for sub-floor or framed floor insulation. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'county',
#    'authority': 'co-boulder-county',
#    'program': 'Boulder County EnergySmart',
#    'program_url': 'https://energysmartyes.com/rebates/income-qualified-rebates/',
#    'items': ['air_sealing'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 2000},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': '50% off, up to $2,000, for qualified air sealing projects. Combined rebates across Boulder County EnergySmart may not exceed $2,000 in 2026.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'state',
#    'authority': 'co-colorado-energy-office',
#    'program': 'Colorado HEAR Program',
#    'program_url': 'https://energyoffice.colorado.gov/home-energy-rebates',
#    'items': ['electric_stove'],
#    'amount': {'type': 'percent', 'number': 0.5, 'maximum': 840},
#    'owner_status': ['homeowner', 'renter'],
#    'start_date': '2025-11-17',
#    'short_description': 'Rebate of 50% of ENERGY STAR electric stove, cooktop, range, or oven costs for households between 80% and 150% AMI, up to $840.'},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'city',
#    'authority': 'co-city-of-boulder',
#    'program': 'City of Boulder Solar Tax Rebates',
#    'program_url': 'https://bouldercolorado.gov/services/solar-tax-rebates',
#    'items': ['rooftop_solar_installation'],
#    'amount': {'type': 'percent', 'number': 0.006},
#    'owner_status': ['homeowner'],
#    'start_date': '2026-01-01',
#    'end_date': '2026-12-31',
#    'short_description': "Rebate for ~15% of Boulder's sales and use tax for materials and permits on solar electric or thermal installations (roughly 0.6% overall)."},
#   {'payment_methods': ['rebate'],
#    'authority_type': 'other',
#    'authority': 'co-power-ahead-colorado',
#    'program': 'Power Ahead Colorado Incentives & Energy Advising Program',
#    'program_url': 'https://poweraheadcolorado.org/program-requirements',
#    'items': ['ducted_heat_pump', 'ductless_heat_pump'],
#    'amount': {'type': 'dollar_amount', 'number': 1500, 'maximum': 1500},
#    'owner_status': ['homeowner', 'renter'],
#    'start_date': '2026-06-29',
#    'short_description': '$1,500 off of a cold-climate air-source, ducted or ductless heat pump. Cannot be combined with HEAR program rebates.'},
#   {'payment_methods': ['tax_credit', 'pos_rebate'],
#    'authority_type': 'state',
#    'authority': 'co-colorado-energy-office',
#    'program': 'Colorado Electric Vehicle Tax Credits',
#    'program_url': 'https://energyoffice.colorado.gov/transportation/grants-incentives/electric-vehicle-tax-credits',
#    'items': ['new_electric_vehicle'],
#    'amount': {'type': 'dollar_amount', 'number': 2500},
#    'owner_status': ['homeowner', 'renter'],
#    'start_date': '2024-01-01',
#    'end_date': '2029-01-01',
#    'short_description': 'Bonus state tax credit of $2,500 for Coloradans purchasing or leasing an EV with a MSRP up to $35,000. Some dealers offer this as an upfront discount.'},
#   {'payment_methods': ['tax_credit', 'pos_rebate'],
#    'authority_type': 'state',
#    'authority': 'co-colorado-energy-office',
#    'program': 'Colorado Electric Vehicle Tax Credits',
#    'program_url': 'https://energyoffice.colorado.gov/transportation/grants-incentives/electric-vehicle-tax-credits',
#    'items': ['new_electric_vehicle'],
#    'amount': {'type': 'dollar_amount', 'number': 750},
#    'owner_status': ['homeowner', 'renter'],
#    'start_date': '2023-07-01',
#    'short_description': 'State tax credit of $750 for the purchase or lease of a new BEV or PHEV (maximum MSRP: $80,000). Some dealers offer this as an upfront discount.'}]}
